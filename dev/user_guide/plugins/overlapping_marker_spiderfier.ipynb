# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fb5bc5a88aff2188b9447ca9576e7be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fb5bc5a88aff2188b9447ca9576e7be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fb5bc5a88aff2188b9447ca9576e7be = L.map(
#                 &quot;map_9fb5bc5a88aff2188b9447ca9576e7be&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f2dd34fd4a550f61d4afa13582ee0bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f2dd34fd4a550f61d4afa13582ee0bb.addTo(map_9fb5bc5a88aff2188b9447ca9576e7be);
#
#
#             var marker_e6449bcc5d0cd2537085f0532ab96e29 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9fb5bc5a88aff2188b9447ca9576e7be);
#
#
#         var popup_a15ed18840d6a3f4ba052d54e4c7074a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df25249e040493e7904f93ad9d73a848 = $(`&lt;div id=&quot;html_df25249e040493e7904f93ad9d73a848&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a15ed18840d6a3f4ba052d54e4c7074a.setContent(html_df25249e040493e7904f93ad9d73a848);
#
#
#
#         marker_e6449bcc5d0cd2537085f0532ab96e29.bindPopup(popup_a15ed18840d6a3f4ba052d54e4c7074a)
#         ;
#
#
#
#
#             var marker_1035844fecc910e872918c964c262521 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9fb5bc5a88aff2188b9447ca9576e7be);
#
#
#         var popup_eaf46ab4a5c1100a522749b1e98d84bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c566f0262c4374ed2610947b8db10c6d = $(`&lt;div id=&quot;html_c566f0262c4374ed2610947b8db10c6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_eaf46ab4a5c1100a522749b1e98d84bc.setContent(html_c566f0262c4374ed2610947b8db10c6d);
#
#
#
#         marker_1035844fecc910e872918c964c262521.bindPopup(popup_eaf46ab4a5c1100a522749b1e98d84bc)
#         ;
#
#
#
#
#             var marker_e4ee34bc3208a434d5508653b21eb8f0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9fb5bc5a88aff2188b9447ca9576e7be);
#
#
#         var popup_a456dc7fe53347d2eabf6750da0c86dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6147f0ffc03812f29409c8566b38f5b8 = $(`&lt;div id=&quot;html_6147f0ffc03812f29409c8566b38f5b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a456dc7fe53347d2eabf6750da0c86dc.setContent(html_6147f0ffc03812f29409c8566b38f5b8);
#
#
#
#         marker_e4ee34bc3208a434d5508653b21eb8f0.bindPopup(popup_a456dc7fe53347d2eabf6750da0c86dc)
#         ;
#
#
#
#
#             var marker_e3be7b7144d6b0ad8a8c1ee66e9325e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9fb5bc5a88aff2188b9447ca9576e7be);
#
#
#         var popup_c6012126eb86da417c3003dff68eaa4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9de13cdef4a50843c7ddb6fd1786ac5 = $(`&lt;div id=&quot;html_a9de13cdef4a50843c7ddb6fd1786ac5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c6012126eb86da417c3003dff68eaa4a.setContent(html_a9de13cdef4a50843c7ddb6fd1786ac5);
#
#
#
#         marker_e3be7b7144d6b0ad8a8c1ee66e9325e3.bindPopup(popup_c6012126eb86da417c3003dff68eaa4a)
#         ;
#
#
#
#
#             var marker_05731f8644be1460aa90704959752f1b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9fb5bc5a88aff2188b9447ca9576e7be);
#
#
#         var popup_f7c8c3959d62f468bf815ea55514d741 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bb96bcde1d552fa494428e5bf2714fb = $(`&lt;div id=&quot;html_8bb96bcde1d552fa494428e5bf2714fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f7c8c3959d62f468bf815ea55514d741.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6700d7e3eae6fb218b5f95d459c5f6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6700d7e3eae6fb218b5f95d459c5f6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6700d7e3eae6fb218b5f95d459c5f6a = L.map(
#                 &quot;map_d6700d7e3eae6fb218b5f95d459c5f6a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c96f33f421feb2abf31f56351b67a50 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c96f33f421feb2abf31f56351b67a50.addTo(map_d6700d7e3eae6fb218b5f95d459c5f6a);
#
#
#             var feature_group_ce58a0870dd93326dd02bc3efe382821 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_66112451aa7fab8c585336b238c5b6f3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ce58a0870dd93326dd02bc3efe382821);
#
#
#         var popup_0fa87d38567e13b73fcaa90fbb84d419 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb5faacf3d397729f68a069b6d4b31f7 = $(`&lt;div id=&quot;html_cb5faacf3d397729f68a069b6d4b31f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0fa87d38567e13b73fcaa90fbb84d419.setContent(html_cb5faacf3d397729f68a069b6d4b31f7);
#
#
#
#         marker_66112451aa7fab8c585336b238c5b6f3.bindPopup(popup_0fa87d38567e13b73fcaa90fbb84d419)
#         ;
#
#
#
#
#             var marker_dc6c465773a47b3a8b1fb4bf1b2b48d2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ce58a0870dd93326dd02bc3efe382821);
#
#
#         var popup_4323e713064bea00f71c69c6372c115d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecf172a0526563152f419864c973713e = $(`&lt;div id=&quot;html_ecf172a0526563152f419864c973713e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4323e713064bea00f71c69c6372c115d.setContent(html_ecf172a0526563152f419864c973713e);
#
#
#
#         marker_dc6c465773a47b3a8b1fb4bf1b2b48d2.bindPopup(popup_4323e713064bea00f71c69c6372c115d)
#         ;
#
#
#
#
#             var marker_f7002f4d499c1d1cb557ec58f6bdbf03 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ce58a0870dd93326dd02bc3efe382821);
#
#
#         var popup_63cc2f64a97a874e02bef7d9174d2f10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c2ec5bb4efd084f206c95d4a1a95b45 = $(`&lt;div id=&quot;html_6c2ec5bb4efd084f206c95d4a1a95b45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_63cc2f64a97a874e02bef7d9174d2f10.setContent(html_6c2ec5bb4efd084f206c95d4a1a95b45);
#
#
#
#         marker_f7002f4d499c1d1cb557ec58f6bdbf03.bindPopup(popup_63cc2f64a97a874e02bef7d9174d2f10)
#         ;
#
#
#
#
#             var marker_5811dedc55607ba32e175619bd6f86bd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ce58a0870dd93326dd02bc3efe382821);
#
#
#         var popup_5c2515f5c793aa2530ba86997572f378 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_586768bf9fed87eada8ad8c9d4bb2d6a = $(`&lt;div id=&quot;html_586768bf9fed87eada8ad8c9d4bb2d6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5c2515f5c793aa2530ba86997572f378.setContent(html_586768bf9fed87eada8ad8c9d4bb2d6a);
#
#
#
#         marker_5811dedc55607ba32e175619bd6f86bd.bindPopup(popup_5c2515f5c793aa2530ba86997572f378)
#         ;
#
#
#
#
#             var marker_7fafca727f00e7be7cee41389a34c425 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ce58a0870dd93326dd02bc3efe382821);
#
#
#         var popup_958af3837f595854788a1fbca47161b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7fee18017b8099dd54c1142137407ddf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7fee18017b8099dd54c1142137407ddf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7fee18017b8099dd54c1142137407ddf = L.map(
#                 &quot;map_7fee18017b8099dd54c1142137407ddf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_711872598774621e3a5c862e68d9b899 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_711872598774621e3a5c862e68d9b899.addTo(map_7fee18017b8099dd54c1142137407ddf);
#
#
#             var feature_group_31fd176ba9ebc78cc6cfc8bc6f33f90e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_31fd176ba9ebc78cc6cfc8bc6f33f90e.addTo(map_7fee18017b8099dd54c1142137407ddf);
#
#
#             var feature_group_sub_group_d56a015ef1e5a3fff88677d3545fa93e = L.featureGroup.subGroup(
#                 feature_group_31fd176ba9ebc78cc6cfc8bc6f33f90e
#             );
#
#
#             var marker_f156eaaf462a3b29bc76c343421e1e38 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d56a015ef1e5a3fff88677d3545fa93e);
#
#
#         var popup_c9d5d648395837a1a911748a3a13c344 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85f1c8c6d9faab417c5ee7a9d7d82e45 = $(`&lt;div id=&quot;html_85f1c8c6d9faab417c5ee7a9d7d82e45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c9d5d648395837a1a911748a3a13c344.setContent(html_85f1c8c6d9faab417c5ee7a9d7d82e45);
#
#
#
#         marker_f156eaaf462a3b29bc76c343421e1e38.bindPopup(popup_c9d5d648395837a1a911748a3a13c344)
#         ;
#
#
#
#
#             var marker_1e9a4df95fcc527def2cca9155fc8269 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d56a015ef1e5a3fff88677d3545fa93e);
#
#
#         var popup_47b7831e638dc916ef8ae5b4c32c55fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d660bf46fbc2bb1deba164ccb3138b62 = $(`&lt;div id=&quot;html_d660bf46fbc2bb1deba164ccb3138b62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_47b7831e638dc916ef8ae5b4c32c55fb.setContent(html_d660bf46fbc2bb1deba164ccb3138b62);
#
#
#
#         marker_1e9a4df95fcc527def2cca9155fc8269.bindPopup(popup_47b7831e638dc916ef8ae5b4c32c55fb)
#         ;
#
#
#
#
#             var marker_afb3ad4ae1de773f01531d82419e7519 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d56a015ef1e5a3fff88677d3545fa93e);
#
#
#         var popup_c0aee5eb15bd9a919fc4727bcc928520 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_129fba8fe0523a90a9604a5e3f59dcf9 = $(`&lt;div id=&quot;html_129fba8fe0523a90a9604a5e3f59dcf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c0aee5eb15bd9a919fc4727bcc928520.setContent(html_129fba8fe0523a90a9604a5e3f59dcf9);
#
#
#
#         marker_afb3ad4ae1de773f01531d82419e7519.bindPopup(popup_c0aee5eb15bd9a919fc4727bcc928520)
#         ;
#
#
#
#
#             var marker_385dbbae649216f5c128fd12a40bb5a6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d56a015ef1e5a3fff88677d3545fa93e);
#
#
#         var popup_5942063e3def3ad066dc947aacc02d83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb9f725a20cb27d4993b3d845c5eea64 = $(`&lt;div id=&quot;html_cb9f725a20cb27d4993b3d845c5eea64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5942063e3def3ad066dc947aacc02d83.setContent(html_cb9f725a20cb27d4993b3d845c5eea64);
#
#
#
#         marker_
