# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f300853dc14eaf8010bbf284b2807723 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f300853dc14eaf8010bbf284b2807723&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f300853dc14eaf8010bbf284b2807723 = L.map(
#                 &quot;map_f300853dc14eaf8010bbf284b2807723&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6873dd1737753c9919209c9be05b07dd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6873dd1737753c9919209c9be05b07dd.addTo(map_f300853dc14eaf8010bbf284b2807723);
#
#
#             var marker_00acccb640c46b577b71261ffe94178d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f300853dc14eaf8010bbf284b2807723);
#
#
#         var popup_56c9f7d9de1b57bee9912ca330043e3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_360e7fe4b3a8d7fcdb994b5b87a37e53 = $(`&lt;div id=&quot;html_360e7fe4b3a8d7fcdb994b5b87a37e53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_56c9f7d9de1b57bee9912ca330043e3f.setContent(html_360e7fe4b3a8d7fcdb994b5b87a37e53);
#
#
#
#         marker_00acccb640c46b577b71261ffe94178d.bindPopup(popup_56c9f7d9de1b57bee9912ca330043e3f)
#         ;
#
#
#
#
#             var marker_b393796bdaf27de8b725bd7af5b7a6e5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f300853dc14eaf8010bbf284b2807723);
#
#
#         var popup_f81b200aa2ef138937b67a31827b8650 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_baf0c1732675b863873d68dc58caa695 = $(`&lt;div id=&quot;html_baf0c1732675b863873d68dc58caa695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f81b200aa2ef138937b67a31827b8650.setContent(html_baf0c1732675b863873d68dc58caa695);
#
#
#
#         marker_b393796bdaf27de8b725bd7af5b7a6e5.bindPopup(popup_f81b200aa2ef138937b67a31827b8650)
#         ;
#
#
#
#
#             var marker_735d9f0f7d9481b5bdcc3dd160e785d6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f300853dc14eaf8010bbf284b2807723);
#
#
#         var popup_86d94c760eb25ca761e6a8cd54ee9ed4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18075e9958f66a3e9e76aca9dc4f4e13 = $(`&lt;div id=&quot;html_18075e9958f66a3e9e76aca9dc4f4e13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_86d94c760eb25ca761e6a8cd54ee9ed4.setContent(html_18075e9958f66a3e9e76aca9dc4f4e13);
#
#
#
#         marker_735d9f0f7d9481b5bdcc3dd160e785d6.bindPopup(popup_86d94c760eb25ca761e6a8cd54ee9ed4)
#         ;
#
#
#
#
#             var marker_d7ba278f3c0bd72641e37f38a2ba62eb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f300853dc14eaf8010bbf284b2807723);
#
#
#         var popup_3b584bce95d4f01b358f453f82a5ffc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fd96af116ceb5c35cf52dd1dd798cd7 = $(`&lt;div id=&quot;html_4fd96af116ceb5c35cf52dd1dd798cd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3b584bce95d4f01b358f453f82a5ffc7.setContent(html_4fd96af116ceb5c35cf52dd1dd798cd7);
#
#
#
#         marker_d7ba278f3c0bd72641e37f38a2ba62eb.bindPopup(popup_3b584bce95d4f01b358f453f82a5ffc7)
#         ;
#
#
#
#
#             var marker_440aaf50d1f97613107cb77a72cdb379 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f300853dc14eaf8010bbf284b2807723);
#
#
#         var popup_5e7894fa194546b721fccc6cba4a5c80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7632d33d71597571d56aec36371a6e2c = $(`&lt;div id=&quot;html_7632d33d71597571d56aec36371a6e2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5e7894fa194546b721fccc6cba4a5c80.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d0dc479f6b4543969e472dc57d69d612 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d0dc479f6b4543969e472dc57d69d612&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d0dc479f6b4543969e472dc57d69d612 = L.map(
#                 &quot;map_d0dc479f6b4543969e472dc57d69d612&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d711bd520e3c8b77f7874d2d250c472 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d711bd520e3c8b77f7874d2d250c472.addTo(map_d0dc479f6b4543969e472dc57d69d612);
#
#
#             var feature_group_b007a847c1541b5cd60773d2f301edcc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_08af42cfc3b9854543fc7142230b9dda = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b007a847c1541b5cd60773d2f301edcc);
#
#
#         var popup_4826e7877f05d3f9b4f41d25247b3e23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9e97e4de333c8de4c1de286ac366241 = $(`&lt;div id=&quot;html_c9e97e4de333c8de4c1de286ac366241&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4826e7877f05d3f9b4f41d25247b3e23.setContent(html_c9e97e4de333c8de4c1de286ac366241);
#
#
#
#         marker_08af42cfc3b9854543fc7142230b9dda.bindPopup(popup_4826e7877f05d3f9b4f41d25247b3e23)
#         ;
#
#
#
#
#             var marker_4e7e90992c453775c2685a18e19e5ec3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b007a847c1541b5cd60773d2f301edcc);
#
#
#         var popup_f424c078ff74c5a22c45d31e73844ac9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa96fa156826785046c13077c69a5ffc = $(`&lt;div id=&quot;html_aa96fa156826785046c13077c69a5ffc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f424c078ff74c5a22c45d31e73844ac9.setContent(html_aa96fa156826785046c13077c69a5ffc);
#
#
#
#         marker_4e7e90992c453775c2685a18e19e5ec3.bindPopup(popup_f424c078ff74c5a22c45d31e73844ac9)
#         ;
#
#
#
#
#             var marker_bf2a0dbaa7b115fd0af2c17d47056c83 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b007a847c1541b5cd60773d2f301edcc);
#
#
#         var popup_4c9eecf6e51053337392d63ff88c4372 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_134bb5bf10ba0af4289b8faa1d9c4cb5 = $(`&lt;div id=&quot;html_134bb5bf10ba0af4289b8faa1d9c4cb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4c9eecf6e51053337392d63ff88c4372.setContent(html_134bb5bf10ba0af4289b8faa1d9c4cb5);
#
#
#
#         marker_bf2a0dbaa7b115fd0af2c17d47056c83.bindPopup(popup_4c9eecf6e51053337392d63ff88c4372)
#         ;
#
#
#
#
#             var marker_ecddc96bb414b32100321e34f9e23604 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b007a847c1541b5cd60773d2f301edcc);
#
#
#         var popup_d0a63738b4e68d81e8e6370667de5844 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54e428dfe9f891d78bc2ba3ccbe2a78a = $(`&lt;div id=&quot;html_54e428dfe9f891d78bc2ba3ccbe2a78a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d0a63738b4e68d81e8e6370667de5844.setContent(html_54e428dfe9f891d78bc2ba3ccbe2a78a);
#
#
#
#         marker_ecddc96bb414b32100321e34f9e23604.bindPopup(popup_d0a63738b4e68d81e8e6370667de5844)
#         ;
#
#
#
#
#             var marker_49762a8542785103a7d5646920376f22 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b007a847c1541b5cd60773d2f301edcc);
#
#
#         var popup_0a2c8910a3fd570fb43b436092bb1475 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87a3f389e092ceea7555c69830cdd9b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87a3f389e092ceea7555c69830cdd9b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87a3f389e092ceea7555c69830cdd9b1 = L.map(
#                 &quot;map_87a3f389e092ceea7555c69830cdd9b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_54ee06c681cdff9a04f011ae55989487 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_54ee06c681cdff9a04f011ae55989487.addTo(map_87a3f389e092ceea7555c69830cdd9b1);
#
#
#             var feature_group_1d25eb9a707f38585441c319c1d512b5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1d25eb9a707f38585441c319c1d512b5.addTo(map_87a3f389e092ceea7555c69830cdd9b1);
#
#
#             var feature_group_sub_group_0e79e5cb6cca3c2cef42a01aef6b6da9 = L.featureGroup.subGroup(
#                 feature_group_1d25eb9a707f38585441c319c1d512b5
#             );
#
#
#             var marker_e00ae5f511fa9d183f70682ac45b1e01 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e79e5cb6cca3c2cef42a01aef6b6da9);
#
#
#         var popup_103901975f8f5aa4884fb7dd15095037 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88a1b16d9409beaedbbbdb87cbab5382 = $(`&lt;div id=&quot;html_88a1b16d9409beaedbbbdb87cbab5382&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_103901975f8f5aa4884fb7dd15095037.setContent(html_88a1b16d9409beaedbbbdb87cbab5382);
#
#
#
#         marker_e00ae5f511fa9d183f70682ac45b1e01.bindPopup(popup_103901975f8f5aa4884fb7dd15095037)
#         ;
#
#
#
#
#             var marker_bf61a37f9ed2f0efff8bc25573ec74eb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e79e5cb6cca3c2cef42a01aef6b6da9);
#
#
#         var popup_43ad8af18b891fe2f43abb78697a08e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44ecdc2f2da6d1fbb220c41d6389b99d = $(`&lt;div id=&quot;html_44ecdc2f2da6d1fbb220c41d6389b99d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_43ad8af18b891fe2f43abb78697a08e9.setContent(html_44ecdc2f2da6d1fbb220c41d6389b99d);
#
#
#
#         marker_bf61a37f9ed2f0efff8bc25573ec74eb.bindPopup(popup_43ad8af18b891fe2f43abb78697a08e9)
#         ;
#
#
#
#
#             var marker_4340f1a704f5669bb7f1b29784a347d7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e79e5cb6cca3c2cef42a01aef6b6da9);
#
#
#         var popup_54d92edbd8f42c11c4ebb450646d4316 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11cf39a42b574112000e0541154b2ad7 = $(`&lt;div id=&quot;html_11cf39a42b574112000e0541154b2ad7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_54d92edbd8f42c11c4ebb450646d4316.setContent(html_11cf39a42b574112000e0541154b2ad7);
#
#
#
#         marker_4340f1a704f5669bb7f1b29784a347d7.bindPopup(popup_54d92edbd8f42c11c4ebb450646d4316)
#         ;
#
#
#
#
#             var marker_71c07666c12a7540dabc8e6c31c6711a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e79e5cb6cca3c2cef42a01aef6b6da9);
#
#
#         var popup_683c4b8b3b8c4b1e66d7a36ef9603ae0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c432b0137e8e9757fafb7c1ffd8ea72a = $(`&lt;div id=&quot;html_c432b0137e8e9757fafb7c1ffd8ea72a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_683c4b8b3b8c4b1e66d7a36ef9603ae0.setContent(html_c432b0137e8e9757fafb7c1ffd8ea72a);
#
#
#
#         marker_
