# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edbfdfca98885d70ecd7193edf056916 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edbfdfca98885d70ecd7193edf056916&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edbfdfca98885d70ecd7193edf056916 = L.map(
#                 &quot;map_edbfdfca98885d70ecd7193edf056916&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0c349fcfd1bc04ae0f99f4eabc93fff9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0c349fcfd1bc04ae0f99f4eabc93fff9.addTo(map_edbfdfca98885d70ecd7193edf056916);
#
#
#             var marker_78a17e423645d0371e553013d8623aca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_edbfdfca98885d70ecd7193edf056916);
#
#
#         var popup_037bae43e93d9d4c9ec94a728d9e2912 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cccd51e164ec2c9f62b4cb6bf9efe1e = $(`&lt;div id=&quot;html_0cccd51e164ec2c9f62b4cb6bf9efe1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_037bae43e93d9d4c9ec94a728d9e2912.setContent(html_0cccd51e164ec2c9f62b4cb6bf9efe1e);
#
#
#
#         marker_78a17e423645d0371e553013d8623aca.bindPopup(popup_037bae43e93d9d4c9ec94a728d9e2912)
#         ;
#
#
#
#
#             var marker_69a182175c2d76247950952ec699c2e6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_edbfdfca98885d70ecd7193edf056916);
#
#
#         var popup_ee855abbb11f5d34f315d5e9d4b4252c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f3d3c8f2580aa997b10fdb065439266 = $(`&lt;div id=&quot;html_3f3d3c8f2580aa997b10fdb065439266&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ee855abbb11f5d34f315d5e9d4b4252c.setContent(html_3f3d3c8f2580aa997b10fdb065439266);
#
#
#
#         marker_69a182175c2d76247950952ec699c2e6.bindPopup(popup_ee855abbb11f5d34f315d5e9d4b4252c)
#         ;
#
#
#
#
#             var marker_17dca575d53e5b716e64384a023e8955 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_edbfdfca98885d70ecd7193edf056916);
#
#
#         var popup_7dec1b406a67b2eb0f588aaeea9fe4f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c9ea85b30293ce92dfda467c9aef89b = $(`&lt;div id=&quot;html_3c9ea85b30293ce92dfda467c9aef89b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7dec1b406a67b2eb0f588aaeea9fe4f9.setContent(html_3c9ea85b30293ce92dfda467c9aef89b);
#
#
#
#         marker_17dca575d53e5b716e64384a023e8955.bindPopup(popup_7dec1b406a67b2eb0f588aaeea9fe4f9)
#         ;
#
#
#
#
#             var marker_283031b5327905ad57e981939b930026 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_edbfdfca98885d70ecd7193edf056916);
#
#
#         var popup_724ff8f9b844b98fb96f1ee1973e999c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3308950a5d4546de01ca71997a3b96e8 = $(`&lt;div id=&quot;html_3308950a5d4546de01ca71997a3b96e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_724ff8f9b844b98fb96f1ee1973e999c.setContent(html_3308950a5d4546de01ca71997a3b96e8);
#
#
#
#         marker_283031b5327905ad57e981939b930026.bindPopup(popup_724ff8f9b844b98fb96f1ee1973e999c)
#         ;
#
#
#
#
#             var marker_57472a198705c35ee61207e9fca68e91 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_edbfdfca98885d70ecd7193edf056916);
#
#
#         var popup_1e642797c67f407f5552c49e0a3ae7cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abec432ba7a6e4d7c7e341fb143b6146 = $(`&lt;div id=&quot;html_abec432ba7a6e4d7c7e341fb143b6146&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1e642797c67f407f5552c49e0a3ae7cf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c00614e4b353188a1eb6ff6aebcdce75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c00614e4b353188a1eb6ff6aebcdce75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c00614e4b353188a1eb6ff6aebcdce75 = L.map(
#                 &quot;map_c00614e4b353188a1eb6ff6aebcdce75&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94da41a289ffc93079545844d0c73b34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_94da41a289ffc93079545844d0c73b34.addTo(map_c00614e4b353188a1eb6ff6aebcdce75);
#
#
#             var feature_group_f64d3804fe49886bb526f04d6254a8ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1541dfed6b2fecfb8a56287492734fc6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f64d3804fe49886bb526f04d6254a8ee);
#
#
#         var popup_77a8ab51eabf2f1684e0c9f03fba84d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f0ee742db6531746e6231e6de72d8a9 = $(`&lt;div id=&quot;html_9f0ee742db6531746e6231e6de72d8a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_77a8ab51eabf2f1684e0c9f03fba84d6.setContent(html_9f0ee742db6531746e6231e6de72d8a9);
#
#
#
#         marker_1541dfed6b2fecfb8a56287492734fc6.bindPopup(popup_77a8ab51eabf2f1684e0c9f03fba84d6)
#         ;
#
#
#
#
#             var marker_344842f293ed54cb2a6dbe76f7174d10 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f64d3804fe49886bb526f04d6254a8ee);
#
#
#         var popup_dd0786424844db000e2b139eab35dadb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73da69e8193bbec46aaff5e7eff1cbd9 = $(`&lt;div id=&quot;html_73da69e8193bbec46aaff5e7eff1cbd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dd0786424844db000e2b139eab35dadb.setContent(html_73da69e8193bbec46aaff5e7eff1cbd9);
#
#
#
#         marker_344842f293ed54cb2a6dbe76f7174d10.bindPopup(popup_dd0786424844db000e2b139eab35dadb)
#         ;
#
#
#
#
#             var marker_90abb14a8f831b1f57d68208932c6be7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f64d3804fe49886bb526f04d6254a8ee);
#
#
#         var popup_ac7f52c595ba69370f4b7f2df6f7e96b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58e0ffb8db562ed1dfe583acb39930f0 = $(`&lt;div id=&quot;html_58e0ffb8db562ed1dfe583acb39930f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ac7f52c595ba69370f4b7f2df6f7e96b.setContent(html_58e0ffb8db562ed1dfe583acb39930f0);
#
#
#
#         marker_90abb14a8f831b1f57d68208932c6be7.bindPopup(popup_ac7f52c595ba69370f4b7f2df6f7e96b)
#         ;
#
#
#
#
#             var marker_f45e5b76a747015d1a528dab404eb1cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f64d3804fe49886bb526f04d6254a8ee);
#
#
#         var popup_20e31af7113aaf13d6a6db9a5559bf35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2921f20fb404efa3546c9cc8295b1303 = $(`&lt;div id=&quot;html_2921f20fb404efa3546c9cc8295b1303&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_20e31af7113aaf13d6a6db9a5559bf35.setContent(html_2921f20fb404efa3546c9cc8295b1303);
#
#
#
#         marker_f45e5b76a747015d1a528dab404eb1cf.bindPopup(popup_20e31af7113aaf13d6a6db9a5559bf35)
#         ;
#
#
#
#
#             var marker_88c4039bbcf895afe1bb46bc9474349b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f64d3804fe49886bb526f04d6254a8ee);
#
#
#         var popup_47560a8e62385dcce3f10efe506533b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_876d3625d3039be33a5f92fa5ffd7d07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_876d3625d3039be33a5f92fa5ffd7d07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_876d3625d3039be33a5f92fa5ffd7d07 = L.map(
#                 &quot;map_876d3625d3039be33a5f92fa5ffd7d07&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1caa72b838ffb2fa6f015d81e5afc7eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1caa72b838ffb2fa6f015d81e5afc7eb.addTo(map_876d3625d3039be33a5f92fa5ffd7d07);
#
#
#             var feature_group_661fd9b87f89fb3945ba7525df77dcea = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_661fd9b87f89fb3945ba7525df77dcea.addTo(map_876d3625d3039be33a5f92fa5ffd7d07);
#
#
#             var feature_group_sub_group_0b4d3f840d0dd2f777cea4a1d3e9e69c = L.featureGroup.subGroup(
#                 feature_group_661fd9b87f89fb3945ba7525df77dcea
#             );
#
#
#             var marker_67f7379f73d46699071776ca68fb9aa7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b4d3f840d0dd2f777cea4a1d3e9e69c);
#
#
#         var popup_3e2cbf744596bea83ddea49ed8d0d03f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_010da7e7923baf8010ede723517af69f = $(`&lt;div id=&quot;html_010da7e7923baf8010ede723517af69f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3e2cbf744596bea83ddea49ed8d0d03f.setContent(html_010da7e7923baf8010ede723517af69f);
#
#
#
#         marker_67f7379f73d46699071776ca68fb9aa7.bindPopup(popup_3e2cbf744596bea83ddea49ed8d0d03f)
#         ;
#
#
#
#
#             var marker_4e087dc0368fec271067fd369c7d0af3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b4d3f840d0dd2f777cea4a1d3e9e69c);
#
#
#         var popup_c83068b9b769e597886282ebba8f3ed3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e07a537bca08be760c17584151605ff = $(`&lt;div id=&quot;html_9e07a537bca08be760c17584151605ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c83068b9b769e597886282ebba8f3ed3.setContent(html_9e07a537bca08be760c17584151605ff);
#
#
#
#         marker_4e087dc0368fec271067fd369c7d0af3.bindPopup(popup_c83068b9b769e597886282ebba8f3ed3)
#         ;
#
#
#
#
#             var marker_1aed054b73663558d53ae4897c1eeedc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b4d3f840d0dd2f777cea4a1d3e9e69c);
#
#
#         var popup_3c96c3210220099f0bb8110d01521679 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1730a4b2d72a8ae98ef9db4e8074cfca = $(`&lt;div id=&quot;html_1730a4b2d72a8ae98ef9db4e8074cfca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3c96c3210220099f0bb8110d01521679.setContent(html_1730a4b2d72a8ae98ef9db4e8074cfca);
#
#
#
#         marker_1aed054b73663558d53ae4897c1eeedc.bindPopup(popup_3c96c3210220099f0bb8110d01521679)
#         ;
#
#
#
#
#             var marker_f7e6b730919fe252839e9ca13c912afa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0b4d3f840d0dd2f777cea4a1d3e9e69c);
#
#
#         var popup_3c562783d6d47369aae3f5bd2d412a67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8586d69a0ec96147c28d13f0a15a6027 = $(`&lt;div id=&quot;html_8586d69a0ec96147c28d13f0a15a6027&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3c562783d6d47369aae3f5bd2d412a67.setContent(html_8586d69a0ec96147c28d13f0a15a6027);
#
#
#
#         marker_
