# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97641f1fcced6ea5778af919087df46c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97641f1fcced6ea5778af919087df46c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97641f1fcced6ea5778af919087df46c = L.map(
#                 &quot;map_97641f1fcced6ea5778af919087df46c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52b4739c109f6d06a7899912bd73ed22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52b4739c109f6d06a7899912bd73ed22.addTo(map_97641f1fcced6ea5778af919087df46c);
#
#
#             var marker_efdea2935a09259345efedd8ab50af23 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_97641f1fcced6ea5778af919087df46c);
#
#
#         var popup_7d212f9c73e949f5b250613bb78f9c68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6e16a6d59c39b8b70c66350306c83be = $(`&lt;div id=&quot;html_c6e16a6d59c39b8b70c66350306c83be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7d212f9c73e949f5b250613bb78f9c68.setContent(html_c6e16a6d59c39b8b70c66350306c83be);
#
#
#
#         marker_efdea2935a09259345efedd8ab50af23.bindPopup(popup_7d212f9c73e949f5b250613bb78f9c68)
#         ;
#
#
#
#
#             var marker_dd43ceabaa8633d635750dbc2e6194e0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_97641f1fcced6ea5778af919087df46c);
#
#
#         var popup_0dd051f42a9575aadc89b84e9297776c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8552e1145dca3e5b34df6d9fccb1d6d = $(`&lt;div id=&quot;html_b8552e1145dca3e5b34df6d9fccb1d6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0dd051f42a9575aadc89b84e9297776c.setContent(html_b8552e1145dca3e5b34df6d9fccb1d6d);
#
#
#
#         marker_dd43ceabaa8633d635750dbc2e6194e0.bindPopup(popup_0dd051f42a9575aadc89b84e9297776c)
#         ;
#
#
#
#
#             var marker_751ba3603a4787018a9b5f279129da16 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_97641f1fcced6ea5778af919087df46c);
#
#
#         var popup_75844ca20aa7b6dcad0e3fd779df996e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3a91f6559bb1c132567a7d1a31b4ebe = $(`&lt;div id=&quot;html_c3a91f6559bb1c132567a7d1a31b4ebe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_75844ca20aa7b6dcad0e3fd779df996e.setContent(html_c3a91f6559bb1c132567a7d1a31b4ebe);
#
#
#
#         marker_751ba3603a4787018a9b5f279129da16.bindPopup(popup_75844ca20aa7b6dcad0e3fd779df996e)
#         ;
#
#
#
#
#             var marker_69bfab20a6c2f629267ea2cd1d86688d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_97641f1fcced6ea5778af919087df46c);
#
#
#         var popup_74aebf0577ec4f094d54bc9315588521 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56ad9e1ee8158df7f95270fd9f482fd5 = $(`&lt;div id=&quot;html_56ad9e1ee8158df7f95270fd9f482fd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_74aebf0577ec4f094d54bc9315588521.setContent(html_56ad9e1ee8158df7f95270fd9f482fd5);
#
#
#
#         marker_69bfab20a6c2f629267ea2cd1d86688d.bindPopup(popup_74aebf0577ec4f094d54bc9315588521)
#         ;
#
#
#
#
#             var marker_98f548e7ad0170738ec3c7bc2d83b137 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_97641f1fcced6ea5778af919087df46c);
#
#
#         var popup_c8a3df7ab7945771cb5230cc39fa8ceb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_014ccde57c3346466b131afb9295a563 = $(`&lt;div id=&quot;html_014ccde57c3346466b131afb9295a563&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c8a3df7ab7945771cb5230cc39fa8c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01f94c5c1151f9449584160e38947647 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01f94c5c1151f9449584160e38947647&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01f94c5c1151f9449584160e38947647 = L.map(
#                 &quot;map_01f94c5c1151f9449584160e38947647&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea34a8b4470c8b92e3fc34091d63f730 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea34a8b4470c8b92e3fc34091d63f730.addTo(map_01f94c5c1151f9449584160e38947647);
#
#
#             var feature_group_f3503d3b07a6d1d775ea31dbc0dfe3d0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6a090147df4b80a1e47749bdaddcf063 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f3503d3b07a6d1d775ea31dbc0dfe3d0);
#
#
#         var popup_b38805f5041e830e60022a3ad4e6dad9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2f754b1c17678e363f1338478e310f5 = $(`&lt;div id=&quot;html_c2f754b1c17678e363f1338478e310f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b38805f5041e830e60022a3ad4e6dad9.setContent(html_c2f754b1c17678e363f1338478e310f5);
#
#
#
#         marker_6a090147df4b80a1e47749bdaddcf063.bindPopup(popup_b38805f5041e830e60022a3ad4e6dad9)
#         ;
#
#
#
#
#             var marker_50b52ea12d16305cb4a122fb526eeab3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f3503d3b07a6d1d775ea31dbc0dfe3d0);
#
#
#         var popup_b03618b716b5234ff2c9582f07d502de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8024de154b8c62d9cee1969a4619d20b = $(`&lt;div id=&quot;html_8024de154b8c62d9cee1969a4619d20b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b03618b716b5234ff2c9582f07d502de.setContent(html_8024de154b8c62d9cee1969a4619d20b);
#
#
#
#         marker_50b52ea12d16305cb4a122fb526eeab3.bindPopup(popup_b03618b716b5234ff2c9582f07d502de)
#         ;
#
#
#
#
#             var marker_636cded770440a96809791f56d631f8e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f3503d3b07a6d1d775ea31dbc0dfe3d0);
#
#
#         var popup_e12fcfa8b4daa6265876b99eb88b791d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27dd9b66d962e5ed1ebf984c943749f1 = $(`&lt;div id=&quot;html_27dd9b66d962e5ed1ebf984c943749f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e12fcfa8b4daa6265876b99eb88b791d.setContent(html_27dd9b66d962e5ed1ebf984c943749f1);
#
#
#
#         marker_636cded770440a96809791f56d631f8e.bindPopup(popup_e12fcfa8b4daa6265876b99eb88b791d)
#         ;
#
#
#
#
#             var marker_22572a12dea9dc7df17ce8d28c3bc3bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f3503d3b07a6d1d775ea31dbc0dfe3d0);
#
#
#         var popup_63ade4ae1f8d75fd441121912b080274 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf4bffe70dc0b995a278b41b07d5821e = $(`&lt;div id=&quot;html_bf4bffe70dc0b995a278b41b07d5821e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_63ade4ae1f8d75fd441121912b080274.setContent(html_bf4bffe70dc0b995a278b41b07d5821e);
#
#
#
#         marker_22572a12dea9dc7df17ce8d28c3bc3bc.bindPopup(popup_63ade4ae1f8d75fd441121912b080274)
#         ;
#
#
#
#
#             var marker_17b743f42c9e710db508db7c8016d3a8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f3503d3b07a6d1d775ea31dbc0dfe3d0);
#
#
#         var popup_f20668ad91bdeec204d5d46500d91e88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d93cc02cab737e1721e76a99d142e52b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d93cc02cab737e1721e76a99d142e52b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d93cc02cab737e1721e76a99d142e52b = L.map(
#                 &quot;map_d93cc02cab737e1721e76a99d142e52b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81022c073a58aec2d22a5424f51226f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81022c073a58aec2d22a5424f51226f3.addTo(map_d93cc02cab737e1721e76a99d142e52b);
#
#
#             var feature_group_1f308ecd6a76eb4fc0a676f8a71b3cef = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1f308ecd6a76eb4fc0a676f8a71b3cef.addTo(map_d93cc02cab737e1721e76a99d142e52b);
#
#
#             var feature_group_sub_group_804cd01bb42c9db0bb58d181cc9570ca = L.featureGroup.subGroup(
#                 feature_group_1f308ecd6a76eb4fc0a676f8a71b3cef
#             );
#
#
#             var marker_5cbe32d408bcdf33753093a86daca1f5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_804cd01bb42c9db0bb58d181cc9570ca);
#
#
#         var popup_6cf206693a7c9ed0bb1edaa06daffa69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1907636a4aaa5768d2bfa8f9b93c3d37 = $(`&lt;div id=&quot;html_1907636a4aaa5768d2bfa8f9b93c3d37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6cf206693a7c9ed0bb1edaa06daffa69.setContent(html_1907636a4aaa5768d2bfa8f9b93c3d37);
#
#
#
#         marker_5cbe32d408bcdf33753093a86daca1f5.bindPopup(popup_6cf206693a7c9ed0bb1edaa06daffa69)
#         ;
#
#
#
#
#             var marker_4d3561063e8e1232c9635207f798adc7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_804cd01bb42c9db0bb58d181cc9570ca);
#
#
#         var popup_703dbc9db36f6e34efb120d04fa4e30a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edd8b587afb489a2acf74fc9ab20c260 = $(`&lt;div id=&quot;html_edd8b587afb489a2acf74fc9ab20c260&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_703dbc9db36f6e34efb120d04fa4e30a.setContent(html_edd8b587afb489a2acf74fc9ab20c260);
#
#
#
#         marker_4d3561063e8e1232c9635207f798adc7.bindPopup(popup_703dbc9db36f6e34efb120d04fa4e30a)
#         ;
#
#
#
#
#             var marker_e5de89ed6ba2cdf0a99ee7b87ae82c18 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_804cd01bb42c9db0bb58d181cc9570ca);
#
#
#         var popup_b5b3345989992617765f2b013d0c4b24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e46f5f8f4dde8552bd93f4ce7b55ebc = $(`&lt;div id=&quot;html_8e46f5f8f4dde8552bd93f4ce7b55ebc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b5b3345989992617765f2b013d0c4b24.setContent(html_8e46f5f8f4dde8552bd93f4ce7b55ebc);
#
#
#
#         marker_e5de89ed6ba2cdf0a99ee7b87ae82c18.bindPopup(popup_b5b3345989992617765f2b013d0c4b24)
#         ;
#
#
#
#
#             var marker_00c3e3533c75d65648d83c66ed333225 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_804cd01bb42c9db0bb58d181cc9570ca);
#
#
#         var popup_b7a054b4b035f6fd7557f64799c12e99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84d048f33044595426d3560b502a633b = $(`&lt;div id=&quot;html_84d048f33044595426d3560b502a633b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b7a054b4b035f6fd7557f64799c12e99.setContent(html_84d048f33044595426d3560b502a633b);
#
#
#
#         mark
