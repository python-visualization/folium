# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d996f1f49f3c85f7b8a0e3a36489213 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d996f1f49f3c85f7b8a0e3a36489213&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d996f1f49f3c85f7b8a0e3a36489213 = L.map(
#                 &quot;map_3d996f1f49f3c85f7b8a0e3a36489213&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1b03b4df4a2c503cce7e222ae74bf3a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1b03b4df4a2c503cce7e222ae74bf3a4.addTo(map_3d996f1f49f3c85f7b8a0e3a36489213);
#
#
#             var marker_8a16a873338ce5e5680b8e7ff92d1666 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3d996f1f49f3c85f7b8a0e3a36489213);
#
#
#         var popup_f36774b5b72e4365d24f62159c79995a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e91e51bd957633ca360d27b45b9e259f = $(`&lt;div id=&quot;html_e91e51bd957633ca360d27b45b9e259f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f36774b5b72e4365d24f62159c79995a.setContent(html_e91e51bd957633ca360d27b45b9e259f);
#
#
#
#         marker_8a16a873338ce5e5680b8e7ff92d1666.bindPopup(popup_f36774b5b72e4365d24f62159c79995a)
#         ;
#
#
#
#
#             var marker_d186fd0e2782df9ce48e792ca2ec0c22 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3d996f1f49f3c85f7b8a0e3a36489213);
#
#
#         var popup_2cc56c862fc5150957d276f23a6ff0a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0035aa24281b943b20a94fa0001ce786 = $(`&lt;div id=&quot;html_0035aa24281b943b20a94fa0001ce786&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2cc56c862fc5150957d276f23a6ff0a7.setContent(html_0035aa24281b943b20a94fa0001ce786);
#
#
#
#         marker_d186fd0e2782df9ce48e792ca2ec0c22.bindPopup(popup_2cc56c862fc5150957d276f23a6ff0a7)
#         ;
#
#
#
#
#             var marker_3dc1c137a9465007611aed89025177bf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3d996f1f49f3c85f7b8a0e3a36489213);
#
#
#         var popup_f0b257de65ebf3959929734b8d974c42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bdc41eccfb13b7566ae4f2c05d93a89 = $(`&lt;div id=&quot;html_6bdc41eccfb13b7566ae4f2c05d93a89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f0b257de65ebf3959929734b8d974c42.setContent(html_6bdc41eccfb13b7566ae4f2c05d93a89);
#
#
#
#         marker_3dc1c137a9465007611aed89025177bf.bindPopup(popup_f0b257de65ebf3959929734b8d974c42)
#         ;
#
#
#
#
#             var marker_885c2f2e5c53cd3a4ffbcff20a8e2248 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3d996f1f49f3c85f7b8a0e3a36489213);
#
#
#         var popup_02648991a8c78481d2507b9889d8d195 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77713bfd5db16a1eb15086148b07ec07 = $(`&lt;div id=&quot;html_77713bfd5db16a1eb15086148b07ec07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_02648991a8c78481d2507b9889d8d195.setContent(html_77713bfd5db16a1eb15086148b07ec07);
#
#
#
#         marker_885c2f2e5c53cd3a4ffbcff20a8e2248.bindPopup(popup_02648991a8c78481d2507b9889d8d195)
#         ;
#
#
#
#
#             var marker_6d67a42adeb827e8484f6bd9602c22d9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3d996f1f49f3c85f7b8a0e3a36489213);
#
#
#         var popup_0b27c2c4cd80fdd3aef09cf822b80285 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd831ae96a508ba5ff3f230755152e31 = $(`&lt;div id=&quot;html_dd831ae96a508ba5ff3f230755152e31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0b27c2c4cd80fdd3aef09cf822b80285.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcdfb3a9afe16f36234a759cbdb98ff2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcdfb3a9afe16f36234a759cbdb98ff2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcdfb3a9afe16f36234a759cbdb98ff2 = L.map(
#                 &quot;map_bcdfb3a9afe16f36234a759cbdb98ff2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_312ea1183bed429d97e1c77655fff304 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_312ea1183bed429d97e1c77655fff304.addTo(map_bcdfb3a9afe16f36234a759cbdb98ff2);
#
#
#             var feature_group_87e68ee703101521038cb423bafa5b32 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d6b53e3d785711ca6161dbe367a74d81 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_87e68ee703101521038cb423bafa5b32);
#
#
#         var popup_fcc95c95c0b33bf52a295a1d64a5a5f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9983da1931ca46e2903f8b5a0dafd2e = $(`&lt;div id=&quot;html_e9983da1931ca46e2903f8b5a0dafd2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fcc95c95c0b33bf52a295a1d64a5a5f6.setContent(html_e9983da1931ca46e2903f8b5a0dafd2e);
#
#
#
#         marker_d6b53e3d785711ca6161dbe367a74d81.bindPopup(popup_fcc95c95c0b33bf52a295a1d64a5a5f6)
#         ;
#
#
#
#
#             var marker_6be26e4a053b0e14a184bacc5b8ced04 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_87e68ee703101521038cb423bafa5b32);
#
#
#         var popup_84623c11722688b2e08db26e2b965717 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_059ead3ac51f9f47066c6c7b30f326a1 = $(`&lt;div id=&quot;html_059ead3ac51f9f47066c6c7b30f326a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_84623c11722688b2e08db26e2b965717.setContent(html_059ead3ac51f9f47066c6c7b30f326a1);
#
#
#
#         marker_6be26e4a053b0e14a184bacc5b8ced04.bindPopup(popup_84623c11722688b2e08db26e2b965717)
#         ;
#
#
#
#
#             var marker_a79f953c16f7a8c790edda5d22259fb1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_87e68ee703101521038cb423bafa5b32);
#
#
#         var popup_0351da34959516d47b40b63a073b7b76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34299e283948c349b5aa8d2d0cec6105 = $(`&lt;div id=&quot;html_34299e283948c349b5aa8d2d0cec6105&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0351da34959516d47b40b63a073b7b76.setContent(html_34299e283948c349b5aa8d2d0cec6105);
#
#
#
#         marker_a79f953c16f7a8c790edda5d22259fb1.bindPopup(popup_0351da34959516d47b40b63a073b7b76)
#         ;
#
#
#
#
#             var marker_0a20ea2bf34c87b9c7062d4fefe7054d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_87e68ee703101521038cb423bafa5b32);
#
#
#         var popup_f3ec203e340e4304a16882971ca4391a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7eb6f62e2cfee1e180afeb0096765af9 = $(`&lt;div id=&quot;html_7eb6f62e2cfee1e180afeb0096765af9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f3ec203e340e4304a16882971ca4391a.setContent(html_7eb6f62e2cfee1e180afeb0096765af9);
#
#
#
#         marker_0a20ea2bf34c87b9c7062d4fefe7054d.bindPopup(popup_f3ec203e340e4304a16882971ca4391a)
#         ;
#
#
#
#
#             var marker_36b522548992615d6ca9f2f327613d7d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_87e68ee703101521038cb423bafa5b32);
#
#
#         var popup_06c601984d56a17b0e97232949d62f79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5dd246ea514ceb2aa874dac6703485a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5dd246ea514ceb2aa874dac6703485a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5dd246ea514ceb2aa874dac6703485a = L.map(
#                 &quot;map_d5dd246ea514ceb2aa874dac6703485a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0c51125856c3bf02698a478189d54d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0c51125856c3bf02698a478189d54d2.addTo(map_d5dd246ea514ceb2aa874dac6703485a);
#
#
#             var feature_group_ac0bb8b5b1b236a37d8fc61674c20ac4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ac0bb8b5b1b236a37d8fc61674c20ac4.addTo(map_d5dd246ea514ceb2aa874dac6703485a);
#
#
#             var feature_group_sub_group_86c68793ff4db54f8a5f90021b1a9d58 = L.featureGroup.subGroup(
#                 feature_group_ac0bb8b5b1b236a37d8fc61674c20ac4
#             );
#
#
#             var marker_4522ea889ee0885b8b20eda88fd6bb31 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_86c68793ff4db54f8a5f90021b1a9d58);
#
#
#         var popup_b95eaa25f61caf6019cd300fefa77e6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e3828cafae4c3fdf2fdc22177b1eaf1 = $(`&lt;div id=&quot;html_3e3828cafae4c3fdf2fdc22177b1eaf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b95eaa25f61caf6019cd300fefa77e6f.setContent(html_3e3828cafae4c3fdf2fdc22177b1eaf1);
#
#
#
#         marker_4522ea889ee0885b8b20eda88fd6bb31.bindPopup(popup_b95eaa25f61caf6019cd300fefa77e6f)
#         ;
#
#
#
#
#             var marker_c615406278fd80e3db684a88d5df473b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_86c68793ff4db54f8a5f90021b1a9d58);
#
#
#         var popup_aa7cec51045a42b3c27f04e3076cb7fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50baec71360a2839d880f8cf02a77413 = $(`&lt;div id=&quot;html_50baec71360a2839d880f8cf02a77413&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_aa7cec51045a42b3c27f04e3076cb7fd.setContent(html_50baec71360a2839d880f8cf02a77413);
#
#
#
#         marker_c615406278fd80e3db684a88d5df473b.bindPopup(popup_aa7cec51045a42b3c27f04e3076cb7fd)
#         ;
#
#
#
#
#             var marker_e2a7ca6ddc42f6330a06519c8ecd717b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_86c68793ff4db54f8a5f90021b1a9d58);
#
#
#         var popup_93351ed1566c4667790ec197be4520f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56df75cfa51d612b80f9349808cfd3cd = $(`&lt;div id=&quot;html_56df75cfa51d612b80f9349808cfd3cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_93351ed1566c4667790ec197be4520f5.setContent(html_56df75cfa51d612b80f9349808cfd3cd);
#
#
#
#         marker_e2a7ca6ddc42f6330a06519c8ecd717b.bindPopup(popup_93351ed1566c4667790ec197be4520f5)
#         ;
#
#
#
#
#             var marker_56ab67d96e4385b05511c15dd1049e5c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_86c68793ff4db54f8a5f90021b1a9d58);
#
#
#         var popup_3f10e44532f871ba0fdd236d551b9f8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69fb5ac108227c91288e2075d91d706d = $(`&lt;div id=&quot;html_69fb5ac108227c91288e2075d91d706d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3f10e44532f871ba0fdd236d551b9f8b.setContent(html_69fb5ac108227c91288e2075d91d706d);
#
#
#
#         marker_
