# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7675206b340a99c0287c53a08af9d5ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7675206b340a99c0287c53a08af9d5ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7675206b340a99c0287c53a08af9d5ac = L.map(
#                 &quot;map_7675206b340a99c0287c53a08af9d5ac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74e99f5ea4167299a9ad43812fa694b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74e99f5ea4167299a9ad43812fa694b9.addTo(map_7675206b340a99c0287c53a08af9d5ac);
#
#
#             var marker_4e34eafcfa4794a14bc3b80e54a5a7e6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7675206b340a99c0287c53a08af9d5ac);
#
#
#         var popup_0c091a69f499f5cc60471854ebf0d6c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7cb2a760c936007126ee8f8b1cf86db = $(`&lt;div id=&quot;html_f7cb2a760c936007126ee8f8b1cf86db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0c091a69f499f5cc60471854ebf0d6c9.setContent(html_f7cb2a760c936007126ee8f8b1cf86db);
#
#
#
#         marker_4e34eafcfa4794a14bc3b80e54a5a7e6.bindPopup(popup_0c091a69f499f5cc60471854ebf0d6c9)
#         ;
#
#
#
#
#             var marker_cd3c6cb6e66b392167ceeb1d89c9ba4b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7675206b340a99c0287c53a08af9d5ac);
#
#
#         var popup_3d59e2d39691967ece9332e1aebf0a13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68c323f8e257769a69d07ac54917f438 = $(`&lt;div id=&quot;html_68c323f8e257769a69d07ac54917f438&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3d59e2d39691967ece9332e1aebf0a13.setContent(html_68c323f8e257769a69d07ac54917f438);
#
#
#
#         marker_cd3c6cb6e66b392167ceeb1d89c9ba4b.bindPopup(popup_3d59e2d39691967ece9332e1aebf0a13)
#         ;
#
#
#
#
#             var marker_435121bc7d590f4b0863f8146aaf47be = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7675206b340a99c0287c53a08af9d5ac);
#
#
#         var popup_73c60af3c83a47b59e069df0eb971e42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eeaed71474374bf03000426a67ead6ef = $(`&lt;div id=&quot;html_eeaed71474374bf03000426a67ead6ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_73c60af3c83a47b59e069df0eb971e42.setContent(html_eeaed71474374bf03000426a67ead6ef);
#
#
#
#         marker_435121bc7d590f4b0863f8146aaf47be.bindPopup(popup_73c60af3c83a47b59e069df0eb971e42)
#         ;
#
#
#
#
#             var marker_3ff8e50cb1b5576cfff8bfb0e38a3591 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7675206b340a99c0287c53a08af9d5ac);
#
#
#         var popup_adbcf6f7fca94ad84246fd31b11019d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63ac9a87a8abd8eb572d40bdc017c7ce = $(`&lt;div id=&quot;html_63ac9a87a8abd8eb572d40bdc017c7ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_adbcf6f7fca94ad84246fd31b11019d1.setContent(html_63ac9a87a8abd8eb572d40bdc017c7ce);
#
#
#
#         marker_3ff8e50cb1b5576cfff8bfb0e38a3591.bindPopup(popup_adbcf6f7fca94ad84246fd31b11019d1)
#         ;
#
#
#
#
#             var marker_4fdf7ce1be2002c024250cb71687afd2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7675206b340a99c0287c53a08af9d5ac);
#
#
#         var popup_6c5caf321ef55b9d6a4157efe032a37e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a3b1c5133e7ee42da29e0d37f403333 = $(`&lt;div id=&quot;html_2a3b1c5133e7ee42da29e0d37f403333&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6c5caf321ef55b9d6a4157efe032a37e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b9d7936fb946f4d7ca198bfa5d2ccdc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b9d7936fb946f4d7ca198bfa5d2ccdc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b9d7936fb946f4d7ca198bfa5d2ccdc = L.map(
#                 &quot;map_5b9d7936fb946f4d7ca198bfa5d2ccdc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02c6e947440edc4c5fece089c7746a91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_02c6e947440edc4c5fece089c7746a91.addTo(map_5b9d7936fb946f4d7ca198bfa5d2ccdc);
#
#
#             var feature_group_22c0549ec9f2944c51d3eb5e5dfb9a49 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9b3f966df9253b17190e6a856c2b2e4e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_22c0549ec9f2944c51d3eb5e5dfb9a49);
#
#
#         var popup_b6db3a207569d4a7f093f4c4ce50a08d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_992ce7ab45d139bc7cdbc6f5031255cf = $(`&lt;div id=&quot;html_992ce7ab45d139bc7cdbc6f5031255cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b6db3a207569d4a7f093f4c4ce50a08d.setContent(html_992ce7ab45d139bc7cdbc6f5031255cf);
#
#
#
#         marker_9b3f966df9253b17190e6a856c2b2e4e.bindPopup(popup_b6db3a207569d4a7f093f4c4ce50a08d)
#         ;
#
#
#
#
#             var marker_f2bde3c63a10fabcd8cad57bbf25f883 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_22c0549ec9f2944c51d3eb5e5dfb9a49);
#
#
#         var popup_26c7abe2373f3553363f309333c4b2e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3feb056d211584f979893ed3c7d39e65 = $(`&lt;div id=&quot;html_3feb056d211584f979893ed3c7d39e65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_26c7abe2373f3553363f309333c4b2e5.setContent(html_3feb056d211584f979893ed3c7d39e65);
#
#
#
#         marker_f2bde3c63a10fabcd8cad57bbf25f883.bindPopup(popup_26c7abe2373f3553363f309333c4b2e5)
#         ;
#
#
#
#
#             var marker_a9fa398ea1895f01a66ab2092ca36019 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_22c0549ec9f2944c51d3eb5e5dfb9a49);
#
#
#         var popup_29eefd5b3d4c24b75923a32c5a2a25a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3fd58a04ee782af2f2c810609c1afde = $(`&lt;div id=&quot;html_e3fd58a04ee782af2f2c810609c1afde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_29eefd5b3d4c24b75923a32c5a2a25a0.setContent(html_e3fd58a04ee782af2f2c810609c1afde);
#
#
#
#         marker_a9fa398ea1895f01a66ab2092ca36019.bindPopup(popup_29eefd5b3d4c24b75923a32c5a2a25a0)
#         ;
#
#
#
#
#             var marker_3de3b1e04cb7cf4e69f7fb8aa04d9fe8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_22c0549ec9f2944c51d3eb5e5dfb9a49);
#
#
#         var popup_da9dbe6c3673a8e000dbe04429e9241a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6303680c80ef4b35aed2af3b9963687d = $(`&lt;div id=&quot;html_6303680c80ef4b35aed2af3b9963687d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_da9dbe6c3673a8e000dbe04429e9241a.setContent(html_6303680c80ef4b35aed2af3b9963687d);
#
#
#
#         marker_3de3b1e04cb7cf4e69f7fb8aa04d9fe8.bindPopup(popup_da9dbe6c3673a8e000dbe04429e9241a)
#         ;
#
#
#
#
#             var marker_94ae2ed4c76d913dbef89932b1878b5b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_22c0549ec9f2944c51d3eb5e5dfb9a49);
#
#
#         var popup_f2562f584f34774e64048734c208dedb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5a24006a503ec3e020e5ba53990a1d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5a24006a503ec3e020e5ba53990a1d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5a24006a503ec3e020e5ba53990a1d3 = L.map(
#                 &quot;map_c5a24006a503ec3e020e5ba53990a1d3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1af7a5793470c7fd3de0f21a7e20ae43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1af7a5793470c7fd3de0f21a7e20ae43.addTo(map_c5a24006a503ec3e020e5ba53990a1d3);
#
#
#             var feature_group_e6dd231e1c5ee20ce1728fe0850d9bed = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e6dd231e1c5ee20ce1728fe0850d9bed.addTo(map_c5a24006a503ec3e020e5ba53990a1d3);
#
#
#             var feature_group_sub_group_0d1199f4677c3bf412c7905233ba2b4e = L.featureGroup.subGroup(
#                 feature_group_e6dd231e1c5ee20ce1728fe0850d9bed
#             );
#
#
#             var marker_196f8587663ad5da259543dbc5100a4a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d1199f4677c3bf412c7905233ba2b4e);
#
#
#         var popup_b4d667857483a0bfd9e7759811d85ad4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_567ececd785bff84facaf8ce429514e7 = $(`&lt;div id=&quot;html_567ececd785bff84facaf8ce429514e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b4d667857483a0bfd9e7759811d85ad4.setContent(html_567ececd785bff84facaf8ce429514e7);
#
#
#
#         marker_196f8587663ad5da259543dbc5100a4a.bindPopup(popup_b4d667857483a0bfd9e7759811d85ad4)
#         ;
#
#
#
#
#             var marker_30ebd2024fed7bce6dcd8443af68b6e3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d1199f4677c3bf412c7905233ba2b4e);
#
#
#         var popup_a786b4c78d291fba5e2b691edcdf1d5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05a6cf9576ca0553f7a3831fb6010223 = $(`&lt;div id=&quot;html_05a6cf9576ca0553f7a3831fb6010223&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a786b4c78d291fba5e2b691edcdf1d5f.setContent(html_05a6cf9576ca0553f7a3831fb6010223);
#
#
#
#         marker_30ebd2024fed7bce6dcd8443af68b6e3.bindPopup(popup_a786b4c78d291fba5e2b691edcdf1d5f)
#         ;
#
#
#
#
#             var marker_85d40b76d485770daddd6dcea81e9cfb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d1199f4677c3bf412c7905233ba2b4e);
#
#
#         var popup_27397df49a8f62aee930a9efa7d603fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_146ca4694b6a29df518790f022ed2c68 = $(`&lt;div id=&quot;html_146ca4694b6a29df518790f022ed2c68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_27397df49a8f62aee930a9efa7d603fe.setContent(html_146ca4694b6a29df518790f022ed2c68);
#
#
#
#         marker_85d40b76d485770daddd6dcea81e9cfb.bindPopup(popup_27397df49a8f62aee930a9efa7d603fe)
#         ;
#
#
#
#
#             var marker_c49f124e5820760cfb35edbbe3f51787 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d1199f4677c3bf412c7905233ba2b4e);
#
#
#         var popup_34478edcfc7ac794dd0d6a5886ab7e52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7a45ca7cb72f9775d961b71c2aaec3b = $(`&lt;div id=&quot;html_e7a45ca7cb72f9775d961b71c2aaec3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_34478edcfc7ac794dd0d6a5886ab7e52.setContent(html_e7a45ca7cb72f9775d961b71c2aaec3b);
#
#
#
#         marker_
