# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c9b321c8761e742331e883bd4c2cebb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c9b321c8761e742331e883bd4c2cebb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c9b321c8761e742331e883bd4c2cebb = L.map(
#                 &quot;map_7c9b321c8761e742331e883bd4c2cebb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50fcc916b1d069b0eb0328ef741c78a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50fcc916b1d069b0eb0328ef741c78a7.addTo(map_7c9b321c8761e742331e883bd4c2cebb);
#
#
#             var marker_5500a72935f440f8f785310893c07357 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7c9b321c8761e742331e883bd4c2cebb);
#
#
#         var popup_60405b96546aeb711dac5945736db084 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1965caca64f12986dcf148473fc4f6e2 = $(`&lt;div id=&quot;html_1965caca64f12986dcf148473fc4f6e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_60405b96546aeb711dac5945736db084.setContent(html_1965caca64f12986dcf148473fc4f6e2);
#
#
#
#         marker_5500a72935f440f8f785310893c07357.bindPopup(popup_60405b96546aeb711dac5945736db084)
#         ;
#
#
#
#
#             var marker_efb84e47208398b8b760d49c50a85341 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7c9b321c8761e742331e883bd4c2cebb);
#
#
#         var popup_305e44c9ce62d8904a3232f080835c25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa9b28278a479a2952a29cf714e6705e = $(`&lt;div id=&quot;html_aa9b28278a479a2952a29cf714e6705e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_305e44c9ce62d8904a3232f080835c25.setContent(html_aa9b28278a479a2952a29cf714e6705e);
#
#
#
#         marker_efb84e47208398b8b760d49c50a85341.bindPopup(popup_305e44c9ce62d8904a3232f080835c25)
#         ;
#
#
#
#
#             var marker_ad16f6b645fc2a5e0c6a1032116307c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7c9b321c8761e742331e883bd4c2cebb);
#
#
#         var popup_3a9573cd3bcdf1676d1fa2e3bb3a9f6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2f840dfcdcea3adb619711d0f2fae57 = $(`&lt;div id=&quot;html_e2f840dfcdcea3adb619711d0f2fae57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3a9573cd3bcdf1676d1fa2e3bb3a9f6b.setContent(html_e2f840dfcdcea3adb619711d0f2fae57);
#
#
#
#         marker_ad16f6b645fc2a5e0c6a1032116307c5.bindPopup(popup_3a9573cd3bcdf1676d1fa2e3bb3a9f6b)
#         ;
#
#
#
#
#             var marker_122852613f3fb6fdceddfbed6fae4f90 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7c9b321c8761e742331e883bd4c2cebb);
#
#
#         var popup_b06b8bd522fd8028a5e603b3da487f5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_990c518aac29c5dc82886f0e05aec907 = $(`&lt;div id=&quot;html_990c518aac29c5dc82886f0e05aec907&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b06b8bd522fd8028a5e603b3da487f5d.setContent(html_990c518aac29c5dc82886f0e05aec907);
#
#
#
#         marker_122852613f3fb6fdceddfbed6fae4f90.bindPopup(popup_b06b8bd522fd8028a5e603b3da487f5d)
#         ;
#
#
#
#
#             var marker_31fb18818c7097ea95099963798942fb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7c9b321c8761e742331e883bd4c2cebb);
#
#
#         var popup_45ef9ac54482904d1a9c6fc3c419f1e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8932b4d3d30418806ebe198d693af16 = $(`&lt;div id=&quot;html_c8932b4d3d30418806ebe198d693af16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_45ef9ac54482904d1a9c6fc3c419f1e1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_58930ecff9000d1b3bc387911d8099c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_58930ecff9000d1b3bc387911d8099c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_58930ecff9000d1b3bc387911d8099c1 = L.map(
#                 &quot;map_58930ecff9000d1b3bc387911d8099c1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62d705098f512d1b0ad3370250bf32f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62d705098f512d1b0ad3370250bf32f9.addTo(map_58930ecff9000d1b3bc387911d8099c1);
#
#
#             var feature_group_42b0b7a7cd92d55712ce15dfe6eedd86 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1bf2c9b8ebe98c630475d6e76a8caa5f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_42b0b7a7cd92d55712ce15dfe6eedd86);
#
#
#         var popup_02df9e0065b69f6b6736e63c41b66ce2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0868a2465dc2ea349faef29d348ab58 = $(`&lt;div id=&quot;html_e0868a2465dc2ea349faef29d348ab58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_02df9e0065b69f6b6736e63c41b66ce2.setContent(html_e0868a2465dc2ea349faef29d348ab58);
#
#
#
#         marker_1bf2c9b8ebe98c630475d6e76a8caa5f.bindPopup(popup_02df9e0065b69f6b6736e63c41b66ce2)
#         ;
#
#
#
#
#             var marker_fd6c8efe45def334e41b19bf82a1023e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_42b0b7a7cd92d55712ce15dfe6eedd86);
#
#
#         var popup_8a352fb93bb1e84367ca75b825bda770 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f16ff78da54efaf5618e46007620031 = $(`&lt;div id=&quot;html_9f16ff78da54efaf5618e46007620031&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8a352fb93bb1e84367ca75b825bda770.setContent(html_9f16ff78da54efaf5618e46007620031);
#
#
#
#         marker_fd6c8efe45def334e41b19bf82a1023e.bindPopup(popup_8a352fb93bb1e84367ca75b825bda770)
#         ;
#
#
#
#
#             var marker_4f08f1fe2ebac1279c38354cc04f8bce = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_42b0b7a7cd92d55712ce15dfe6eedd86);
#
#
#         var popup_09235f4ef3afc84c8c8bd5d0d3da371c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_941c3d00e3a3304399a2371ca5ae2a69 = $(`&lt;div id=&quot;html_941c3d00e3a3304399a2371ca5ae2a69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_09235f4ef3afc84c8c8bd5d0d3da371c.setContent(html_941c3d00e3a3304399a2371ca5ae2a69);
#
#
#
#         marker_4f08f1fe2ebac1279c38354cc04f8bce.bindPopup(popup_09235f4ef3afc84c8c8bd5d0d3da371c)
#         ;
#
#
#
#
#             var marker_cac96f5a557659dcc09fc5b4636a9369 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_42b0b7a7cd92d55712ce15dfe6eedd86);
#
#
#         var popup_62c8b31b579225ce359ee258e0ebfde2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20a321995ba9f04013ef2d629131efc3 = $(`&lt;div id=&quot;html_20a321995ba9f04013ef2d629131efc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_62c8b31b579225ce359ee258e0ebfde2.setContent(html_20a321995ba9f04013ef2d629131efc3);
#
#
#
#         marker_cac96f5a557659dcc09fc5b4636a9369.bindPopup(popup_62c8b31b579225ce359ee258e0ebfde2)
#         ;
#
#
#
#
#             var marker_b3c663b748f73604ce69b2337542652d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_42b0b7a7cd92d55712ce15dfe6eedd86);
#
#
#         var popup_e68a3424db0bb9833e2351294becee53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c99d0ed8d89c840d7baf0f6ab2d50b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c99d0ed8d89c840d7baf0f6ab2d50b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c99d0ed8d89c840d7baf0f6ab2d50b9 = L.map(
#                 &quot;map_9c99d0ed8d89c840d7baf0f6ab2d50b9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9569c224edf881de5c592ca8cef31fcf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9569c224edf881de5c592ca8cef31fcf.addTo(map_9c99d0ed8d89c840d7baf0f6ab2d50b9);
#
#
#             var feature_group_9cead2b672b1f8993ee62280369202ce = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9cead2b672b1f8993ee62280369202ce.addTo(map_9c99d0ed8d89c840d7baf0f6ab2d50b9);
#
#
#             var feature_group_sub_group_dc049764bf224a18293ce4b2e926d23a = L.featureGroup.subGroup(
#                 feature_group_9cead2b672b1f8993ee62280369202ce
#             );
#
#
#             var marker_4df5daab62aa71b406d1901efef957ab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc049764bf224a18293ce4b2e926d23a);
#
#
#         var popup_3919e0c6685ac5ed829b71928107fb3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95d4bdccacf4986f8df277e99d48ba08 = $(`&lt;div id=&quot;html_95d4bdccacf4986f8df277e99d48ba08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3919e0c6685ac5ed829b71928107fb3e.setContent(html_95d4bdccacf4986f8df277e99d48ba08);
#
#
#
#         marker_4df5daab62aa71b406d1901efef957ab.bindPopup(popup_3919e0c6685ac5ed829b71928107fb3e)
#         ;
#
#
#
#
#             var marker_69399181750736815f11b7553f9f5a6d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc049764bf224a18293ce4b2e926d23a);
#
#
#         var popup_a0f113a117b9fea653ef049e27859f35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4392991679cf8ee8821215451a267d4d = $(`&lt;div id=&quot;html_4392991679cf8ee8821215451a267d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a0f113a117b9fea653ef049e27859f35.setContent(html_4392991679cf8ee8821215451a267d4d);
#
#
#
#         marker_69399181750736815f11b7553f9f5a6d.bindPopup(popup_a0f113a117b9fea653ef049e27859f35)
#         ;
#
#
#
#
#             var marker_b9acf28e7b76de09c213d5ab1a7ab567 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc049764bf224a18293ce4b2e926d23a);
#
#
#         var popup_b50e2fcdf6a2cf42bf32e7c4bfb8804d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b0a42e43e0e29574d0e15ad7b0a6ff8 = $(`&lt;div id=&quot;html_4b0a42e43e0e29574d0e15ad7b0a6ff8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b50e2fcdf6a2cf42bf32e7c4bfb8804d.setContent(html_4b0a42e43e0e29574d0e15ad7b0a6ff8);
#
#
#
#         marker_b9acf28e7b76de09c213d5ab1a7ab567.bindPopup(popup_b50e2fcdf6a2cf42bf32e7c4bfb8804d)
#         ;
#
#
#
#
#             var marker_37f88883041a0a172980496846d94d2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc049764bf224a18293ce4b2e926d23a);
#
#
#         var popup_6711e758f22d53f57c8aae9b0ba41683 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db36768d35fe7c586d31d666487f3317 = $(`&lt;div id=&quot;html_db36768d35fe7c586d31d666487f3317&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6711e758f22d53f57c8aae9b0ba41683.setContent(html_db36768d35fe7c586d31d666487f3317);
#
#
#
#         marker_
