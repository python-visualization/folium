# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f9f1e57b0255fa3f581c448206400f9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f9f1e57b0255fa3f581c448206400f9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f9f1e57b0255fa3f581c448206400f9 = L.map(
#                 &quot;map_5f9f1e57b0255fa3f581c448206400f9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d93f24221413d6d973488cfa823c992 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d93f24221413d6d973488cfa823c992.addTo(map_5f9f1e57b0255fa3f581c448206400f9);
#
#
#             var marker_199f603e40434f8d2d4a5d72ed4a6144 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5f9f1e57b0255fa3f581c448206400f9);
#
#
#         var popup_a16273ce48fc2a5ba9a0d5b0b8e04909 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6bff7341d7687f8aa7a07ed48b6cc6d = $(`&lt;div id=&quot;html_e6bff7341d7687f8aa7a07ed48b6cc6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a16273ce48fc2a5ba9a0d5b0b8e04909.setContent(html_e6bff7341d7687f8aa7a07ed48b6cc6d);
#
#
#
#         marker_199f603e40434f8d2d4a5d72ed4a6144.bindPopup(popup_a16273ce48fc2a5ba9a0d5b0b8e04909)
#         ;
#
#
#
#
#             var marker_9deb18ad04ff29efbdfc174169fe967d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5f9f1e57b0255fa3f581c448206400f9);
#
#
#         var popup_cbacf97e6ede14cf1341be75bc51a7b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f950ff1cb38e8628a752ba0fb28ce2ef = $(`&lt;div id=&quot;html_f950ff1cb38e8628a752ba0fb28ce2ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cbacf97e6ede14cf1341be75bc51a7b1.setContent(html_f950ff1cb38e8628a752ba0fb28ce2ef);
#
#
#
#         marker_9deb18ad04ff29efbdfc174169fe967d.bindPopup(popup_cbacf97e6ede14cf1341be75bc51a7b1)
#         ;
#
#
#
#
#             var marker_a5b4e308418c253087198d8754fd00ff = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5f9f1e57b0255fa3f581c448206400f9);
#
#
#         var popup_37be7912a880299944c78fa383b8475a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7b610f19457fca8589b2c2462c8285e = $(`&lt;div id=&quot;html_d7b610f19457fca8589b2c2462c8285e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_37be7912a880299944c78fa383b8475a.setContent(html_d7b610f19457fca8589b2c2462c8285e);
#
#
#
#         marker_a5b4e308418c253087198d8754fd00ff.bindPopup(popup_37be7912a880299944c78fa383b8475a)
#         ;
#
#
#
#
#             var marker_349bed1f69905df7b842a6b73da924c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5f9f1e57b0255fa3f581c448206400f9);
#
#
#         var popup_4a15549af0b8aebea39b6514c4bc5819 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be16919abeb5e669b43a1379a198b0b3 = $(`&lt;div id=&quot;html_be16919abeb5e669b43a1379a198b0b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4a15549af0b8aebea39b6514c4bc5819.setContent(html_be16919abeb5e669b43a1379a198b0b3);
#
#
#
#         marker_349bed1f69905df7b842a6b73da924c4.bindPopup(popup_4a15549af0b8aebea39b6514c4bc5819)
#         ;
#
#
#
#
#             var marker_248a603b9d4f204594824e350a40ea32 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5f9f1e57b0255fa3f581c448206400f9);
#
#
#         var popup_31bd65f77dfde4ee73a21f9720f938ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9305cf0693b7ccda3ba55a4eb5cc1ccf = $(`&lt;div id=&quot;html_9305cf0693b7ccda3ba55a4eb5cc1ccf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_31bd65f77dfde4ee73a21f9720f938ee.setContent(html_9305cf0693b7ccda3ba55a4eb5cc1ccf);
#
#
#
#         marker_248a603b9d4f204594824e350a40ea32.bindPopup(popup_31bd65f77dfde4ee73a21f9720f938ee)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edb2698e37061c59b54d223ad845bb5c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edb2698e37061c59b54d223ad845bb5c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edb2698e37061c59b54d223ad845bb5c = L.map(
#                 &quot;map_edb2698e37061c59b54d223ad845bb5c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c64d31bc1a9d79a073fd385399965861 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c64d31bc1a9d79a073fd385399965861.addTo(map_edb2698e37061c59b54d223ad845bb5c);
#
#
#             var feature_group_18191dfc9906007cc576b1728abc7fde = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6795801114c3d9a0a1615fbfa9d172b7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_18191dfc9906007cc576b1728abc7fde);
#
#
#         var popup_8e8fe98dbab9eb3afee84cac832e4d0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b787be59c55b4604ad8d31aae257f57b = $(`&lt;div id=&quot;html_b787be59c55b4604ad8d31aae257f57b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8e8fe98dbab9eb3afee84cac832e4d0d.setContent(html_b787be59c55b4604ad8d31aae257f57b);
#
#
#
#         marker_6795801114c3d9a0a1615fbfa9d172b7.bindPopup(popup_8e8fe98dbab9eb3afee84cac832e4d0d)
#         ;
#
#
#
#
#             var marker_6dbc953abdba216e3f5c1a7e9082f962 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_18191dfc9906007cc576b1728abc7fde);
#
#
#         var popup_e5befb7c58d6265afa73f33d145ffe4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1aa8743f4e65a650492f34f64827bfac = $(`&lt;div id=&quot;html_1aa8743f4e65a650492f34f64827bfac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e5befb7c58d6265afa73f33d145ffe4c.setContent(html_1aa8743f4e65a650492f34f64827bfac);
#
#
#
#         marker_6dbc953abdba216e3f5c1a7e9082f962.bindPopup(popup_e5befb7c58d6265afa73f33d145ffe4c)
#         ;
#
#
#
#
#             var marker_0740ec4bf69d264304d32ade4c6c8269 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_18191dfc9906007cc576b1728abc7fde);
#
#
#         var popup_ad0314a1adbe3c7f46f26f299c91d0e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1eb8e50facdf02b89c9cba29981ab6a = $(`&lt;div id=&quot;html_e1eb8e50facdf02b89c9cba29981ab6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ad0314a1adbe3c7f46f26f299c91d0e8.setContent(html_e1eb8e50facdf02b89c9cba29981ab6a);
#
#
#
#         marker_0740ec4bf69d264304d32ade4c6c8269.bindPopup(popup_ad0314a1adbe3c7f46f26f299c91d0e8)
#         ;
#
#
#
#
#             var marker_f72f54d938a36ce64c4cf2b6ad431ae1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_18191dfc9906007cc576b1728abc7fde);
#
#
#         var popup_704d34688cafece01dcfd8abf65dc80b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_917cc7ce29fa54d94cdb38dfbe0c16ad = $(`&lt;div id=&quot;html_917cc7ce29fa54d94cdb38dfbe0c16ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_704d34688cafece01dcfd8abf65dc80b.setContent(html_917cc7ce29fa54d94cdb38dfbe0c16ad);
#
#
#
#         marker_f72f54d938a36ce64c4cf2b6ad431ae1.bindPopup(popup_704d34688cafece01dcfd8abf65dc80b)
#         ;
#
#
#
#
#             var marker_79808552c29275c9c02d18d656991f7d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_18191dfc9906007cc576b1728abc7fde);
#
#
#         var popup_5e61d7a9c0d7f83fbbed706929a1b6ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90dacf7b31df5d9e5193fd931c9f0511 = $(`&lt;div id=&quot;html_90dacf7b31df5d9e5193fd931c9f0511&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_922678cec28998fba1eb3444e7b6f90d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_922678cec28998fba1eb3444e7b6f90d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_922678cec28998fba1eb3444e7b6f90d = L.map(
#                 &quot;map_922678cec28998fba1eb3444e7b6f90d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71c0af96f9a115f6dd22f9917d09afcd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71c0af96f9a115f6dd22f9917d09afcd.addTo(map_922678cec28998fba1eb3444e7b6f90d);
#
#
#             var feature_group_df6518da84c14d9872d3ebe74e2a29d0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_df6518da84c14d9872d3ebe74e2a29d0.addTo(map_922678cec28998fba1eb3444e7b6f90d);
#
#
#             var feature_group_sub_group_1eac6c8e40a38e2af953483c3795e7db = L.featureGroup.subGroup(
#                 feature_group_df6518da84c14d9872d3ebe74e2a29d0
#             );
#
#
#             var marker_b641fd952ff489fa7e28c7af415c5cd1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eac6c8e40a38e2af953483c3795e7db);
#
#
#         var popup_fe9eb61ec20897b1323a327b7ecef75d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb19c43b22117e2bb0e91eae8b1faa3f = $(`&lt;div id=&quot;html_bb19c43b22117e2bb0e91eae8b1faa3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fe9eb61ec20897b1323a327b7ecef75d.setContent(html_bb19c43b22117e2bb0e91eae8b1faa3f);
#
#
#
#         marker_b641fd952ff489fa7e28c7af415c5cd1.bindPopup(popup_fe9eb61ec20897b1323a327b7ecef75d)
#         ;
#
#
#
#
#             var marker_e0c123c40efd63fe207af5b0c3201cf4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eac6c8e40a38e2af953483c3795e7db);
#
#
#         var popup_8a514051030c159fc51da70354804c80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d71088f3c3bcf3acb638f7de4e4886c = $(`&lt;div id=&quot;html_0d71088f3c3bcf3acb638f7de4e4886c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8a514051030c159fc51da70354804c80.setContent(html_0d71088f3c3bcf3acb638f7de4e4886c);
#
#
#
#         marker_e0c123c40efd63fe207af5b0c3201cf4.bindPopup(popup_8a514051030c159fc51da70354804c80)
#         ;
#
#
#
#
#             var marker_2877d02b693d818412e213d45e4d38a9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eac6c8e40a38e2af953483c3795e7db);
#
#
#         var popup_fcc3386d10516eb433fb207e538b6b26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_435a78abf1fac1be099680e669d5df2b = $(`&lt;div id=&quot;html_435a78abf1fac1be099680e669d5df2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fcc3386d10516eb433fb207e538b6b26.setContent(html_435a78abf1fac1be099680e669d5df2b);
#
#
#
#         marker_2877d02b693d818412e213d45e4d38a9.bindPopup(popup_fcc3386d10516eb433fb207e538b6b26)
#         ;
#
#
#
#
#             var marker_a02bdb51455fe3cdca080145bf3a47b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1eac6c8e40a38e2af953483c3795e7db);
#
#
#         var popup_18c6990612c2ac5304ca48dd800c2eba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8aa6773d36263201d2006b482f2150bf = $(`&lt;div id=&quot;html_8aa6773d36263201d2006b482f2150bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_18c6990612c2ac5304ca48dd800c2eba.setContent(html_8aa6773d36263201d2006b482f2150bf);
#
#
#
#         marker_a02bdb51455fe3cdca080145bf3a47b3.bindPopup(popup_18c6990612c2ac5304ca48dd800c2eba)
#         ;
#
#
#
#
#             var marker_ee7999d1ecd6f5c49bfb5c863c908928 = L.marker(
#                 [45.0503999
