# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86b5035d5335110c8579cbd7c03ff170 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86b5035d5335110c8579cbd7c03ff170&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86b5035d5335110c8579cbd7c03ff170 = L.map(
#                 &quot;map_86b5035d5335110c8579cbd7c03ff170&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f50193f0fef9662f280a4490109d1352 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f50193f0fef9662f280a4490109d1352.addTo(map_86b5035d5335110c8579cbd7c03ff170);
#
#
#             var marker_29aa2bf3d0f8c921ea0ab427fd9d686a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_86b5035d5335110c8579cbd7c03ff170);
#
#
#         var popup_34012bfd3944603bc478a31ab9dde4db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4bdea4e28b3e32d5f18f5da2514cfb5 = $(`&lt;div id=&quot;html_a4bdea4e28b3e32d5f18f5da2514cfb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_34012bfd3944603bc478a31ab9dde4db.setContent(html_a4bdea4e28b3e32d5f18f5da2514cfb5);
#
#
#
#         marker_29aa2bf3d0f8c921ea0ab427fd9d686a.bindPopup(popup_34012bfd3944603bc478a31ab9dde4db)
#         ;
#
#
#
#
#             var marker_76533086b9ef983181ab56c1934a5430 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_86b5035d5335110c8579cbd7c03ff170);
#
#
#         var popup_507fad92234f6653463dce2157ff3c3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57a87fb2ec6560b39b42bac9db8dfe03 = $(`&lt;div id=&quot;html_57a87fb2ec6560b39b42bac9db8dfe03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_507fad92234f6653463dce2157ff3c3a.setContent(html_57a87fb2ec6560b39b42bac9db8dfe03);
#
#
#
#         marker_76533086b9ef983181ab56c1934a5430.bindPopup(popup_507fad92234f6653463dce2157ff3c3a)
#         ;
#
#
#
#
#             var marker_0c1c9c49dcd3979495aec180685381f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_86b5035d5335110c8579cbd7c03ff170);
#
#
#         var popup_ddb67d7e21c5da464dadf48c94f67225 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1e20cdddbedcb8adf44bc3244acc98f = $(`&lt;div id=&quot;html_b1e20cdddbedcb8adf44bc3244acc98f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ddb67d7e21c5da464dadf48c94f67225.setContent(html_b1e20cdddbedcb8adf44bc3244acc98f);
#
#
#
#         marker_0c1c9c49dcd3979495aec180685381f4.bindPopup(popup_ddb67d7e21c5da464dadf48c94f67225)
#         ;
#
#
#
#
#             var marker_ec283e074f9afb6ee00c0f4c7d92ea8c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_86b5035d5335110c8579cbd7c03ff170);
#
#
#         var popup_91c90634cf88227d009b839ae7fac137 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9442678ae4f2167e99c2cf30c31da80b = $(`&lt;div id=&quot;html_9442678ae4f2167e99c2cf30c31da80b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_91c90634cf88227d009b839ae7fac137.setContent(html_9442678ae4f2167e99c2cf30c31da80b);
#
#
#
#         marker_ec283e074f9afb6ee00c0f4c7d92ea8c.bindPopup(popup_91c90634cf88227d009b839ae7fac137)
#         ;
#
#
#
#
#             var marker_ebaeac814239b503eb31487723cd189d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_86b5035d5335110c8579cbd7c03ff170);
#
#
#         var popup_17a2f94ac645817ec45a83472110b0d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e61cc8562c9a0461e873da2304a7f778 = $(`&lt;div id=&quot;html_e61cc8562c9a0461e873da2304a7f778&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_17a2f94ac645817ec45a83472110b0d6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77472e269460740ce39bf6191a927ff4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77472e269460740ce39bf6191a927ff4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77472e269460740ce39bf6191a927ff4 = L.map(
#                 &quot;map_77472e269460740ce39bf6191a927ff4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_071ebff15d007af0f183e84b4af59262 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_071ebff15d007af0f183e84b4af59262.addTo(map_77472e269460740ce39bf6191a927ff4);
#
#
#             var feature_group_2f1405363466a9c61fe8fc72787464ba = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e1a75a92e06135faba318a0bfc5991ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2f1405363466a9c61fe8fc72787464ba);
#
#
#         var popup_c3367cf4791434a28c7aaecefbd2db5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1370648966fc5936fc20b1eddc656d5e = $(`&lt;div id=&quot;html_1370648966fc5936fc20b1eddc656d5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c3367cf4791434a28c7aaecefbd2db5c.setContent(html_1370648966fc5936fc20b1eddc656d5e);
#
#
#
#         marker_e1a75a92e06135faba318a0bfc5991ff.bindPopup(popup_c3367cf4791434a28c7aaecefbd2db5c)
#         ;
#
#
#
#
#             var marker_d1e34fbfd0779b684681871026599391 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2f1405363466a9c61fe8fc72787464ba);
#
#
#         var popup_1a8677ab9a02a36862d8d15455a6ab97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14de85a9214bb0ff8179c03ea4f96006 = $(`&lt;div id=&quot;html_14de85a9214bb0ff8179c03ea4f96006&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1a8677ab9a02a36862d8d15455a6ab97.setContent(html_14de85a9214bb0ff8179c03ea4f96006);
#
#
#
#         marker_d1e34fbfd0779b684681871026599391.bindPopup(popup_1a8677ab9a02a36862d8d15455a6ab97)
#         ;
#
#
#
#
#             var marker_158a61a5742f292899dedef322980cc4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2f1405363466a9c61fe8fc72787464ba);
#
#
#         var popup_a79e418806d3e0560f4f0ef69662d033 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d20912ce0b5f361d09838aac2df3f3a2 = $(`&lt;div id=&quot;html_d20912ce0b5f361d09838aac2df3f3a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a79e418806d3e0560f4f0ef69662d033.setContent(html_d20912ce0b5f361d09838aac2df3f3a2);
#
#
#
#         marker_158a61a5742f292899dedef322980cc4.bindPopup(popup_a79e418806d3e0560f4f0ef69662d033)
#         ;
#
#
#
#
#             var marker_02b3ade113f756a9a58864118ebbecb5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2f1405363466a9c61fe8fc72787464ba);
#
#
#         var popup_03be2e7bb170f05d1b8b5a3b88e7e8ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f3c288484431182d6122a17879e20f3 = $(`&lt;div id=&quot;html_7f3c288484431182d6122a17879e20f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_03be2e7bb170f05d1b8b5a3b88e7e8ca.setContent(html_7f3c288484431182d6122a17879e20f3);
#
#
#
#         marker_02b3ade113f756a9a58864118ebbecb5.bindPopup(popup_03be2e7bb170f05d1b8b5a3b88e7e8ca)
#         ;
#
#
#
#
#             var marker_e3d8b79a1b814dad76f45f837911720a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2f1405363466a9c61fe8fc72787464ba);
#
#
#         var popup_4f0eaaea2e70fbac8dd3c64d57985073 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71aef629871d7b6a54b88cbd3910de73 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71aef629871d7b6a54b88cbd3910de73&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71aef629871d7b6a54b88cbd3910de73 = L.map(
#                 &quot;map_71aef629871d7b6a54b88cbd3910de73&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5224884b4709b690bfa68dde684bf6cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5224884b4709b690bfa68dde684bf6cb.addTo(map_71aef629871d7b6a54b88cbd3910de73);
#
#
#             var feature_group_ec1d18e7ee2853e9480683c45a5af106 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ec1d18e7ee2853e9480683c45a5af106.addTo(map_71aef629871d7b6a54b88cbd3910de73);
#
#
#             var feature_group_sub_group_68de012c295c6267ab22e3f416e0567a = L.featureGroup.subGroup(
#                 feature_group_ec1d18e7ee2853e9480683c45a5af106
#             );
#
#
#             var marker_51c566df9113f28a4cacb5f1ca719283 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_68de012c295c6267ab22e3f416e0567a);
#
#
#         var popup_c6739319448e3b8b07ea799d6713ab39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d41f8fabd03a58c4a198c6c70bf663c3 = $(`&lt;div id=&quot;html_d41f8fabd03a58c4a198c6c70bf663c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c6739319448e3b8b07ea799d6713ab39.setContent(html_d41f8fabd03a58c4a198c6c70bf663c3);
#
#
#
#         marker_51c566df9113f28a4cacb5f1ca719283.bindPopup(popup_c6739319448e3b8b07ea799d6713ab39)
#         ;
#
#
#
#
#             var marker_be762e4906e6b4232e30d9f4a79e2dcb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_68de012c295c6267ab22e3f416e0567a);
#
#
#         var popup_f229994807d28f1f1b0276c6afd5e458 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d1a1256f63b26e1552ff3bf944c55d6 = $(`&lt;div id=&quot;html_6d1a1256f63b26e1552ff3bf944c55d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f229994807d28f1f1b0276c6afd5e458.setContent(html_6d1a1256f63b26e1552ff3bf944c55d6);
#
#
#
#         marker_be762e4906e6b4232e30d9f4a79e2dcb.bindPopup(popup_f229994807d28f1f1b0276c6afd5e458)
#         ;
#
#
#
#
#             var marker_a9c6f7a0051534830727ac44bcec5da3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_68de012c295c6267ab22e3f416e0567a);
#
#
#         var popup_64bc76d85f2531df9d7eed5fbf44ce7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5a00145bfd49b1c235ef139a9a54df6 = $(`&lt;div id=&quot;html_c5a00145bfd49b1c235ef139a9a54df6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_64bc76d85f2531df9d7eed5fbf44ce7d.setContent(html_c5a00145bfd49b1c235ef139a9a54df6);
#
#
#
#         marker_a9c6f7a0051534830727ac44bcec5da3.bindPopup(popup_64bc76d85f2531df9d7eed5fbf44ce7d)
#         ;
#
#
#
#
#             var marker_eb70e7b3a32d3754586f10d9fc1b6dd6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_68de012c295c6267ab22e3f416e0567a);
#
#
#         var popup_6224c8c797a7de9cf8d7d32265f5b7fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e62afa63d5d1dc0a0143e4781ce038e = $(`&lt;div id=&quot;html_0e62afa63d5d1dc0a0143e4781ce038e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6224c8c797a7de9cf8d7d32265f5b7fb.setContent(html_0e62afa63d5d1dc0a0143e4781ce038e);
#
#
#
#         marker_
