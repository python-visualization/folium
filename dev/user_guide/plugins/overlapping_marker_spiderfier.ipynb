# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c9c36ca40c9ad53c1c48f227e766300 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c9c36ca40c9ad53c1c48f227e766300&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c9c36ca40c9ad53c1c48f227e766300 = L.map(
#                 &quot;map_2c9c36ca40c9ad53c1c48f227e766300&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46058e6a44272595fc541076a9c55db4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46058e6a44272595fc541076a9c55db4.addTo(map_2c9c36ca40c9ad53c1c48f227e766300);
#
#
#             var marker_6f67c14eecc0dbfa0afba0cfc54959ea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2c9c36ca40c9ad53c1c48f227e766300);
#
#
#         var popup_e7df82ebaa1f70f8bd9fda3839050b55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ddbe69e6c4397a137f6c0f6455cdb32 = $(`&lt;div id=&quot;html_5ddbe69e6c4397a137f6c0f6455cdb32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e7df82ebaa1f70f8bd9fda3839050b55.setContent(html_5ddbe69e6c4397a137f6c0f6455cdb32);
#
#
#
#         marker_6f67c14eecc0dbfa0afba0cfc54959ea.bindPopup(popup_e7df82ebaa1f70f8bd9fda3839050b55)
#         ;
#
#
#
#
#             var marker_8a304600b4e1268e740af5bd50715e2d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2c9c36ca40c9ad53c1c48f227e766300);
#
#
#         var popup_6ebd8a6a7d801e066243cd73d6a6fd5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aceb4889156881d73efe1e712ff99cf5 = $(`&lt;div id=&quot;html_aceb4889156881d73efe1e712ff99cf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6ebd8a6a7d801e066243cd73d6a6fd5d.setContent(html_aceb4889156881d73efe1e712ff99cf5);
#
#
#
#         marker_8a304600b4e1268e740af5bd50715e2d.bindPopup(popup_6ebd8a6a7d801e066243cd73d6a6fd5d)
#         ;
#
#
#
#
#             var marker_67c8a2f657220ab44b618064bf9d201f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2c9c36ca40c9ad53c1c48f227e766300);
#
#
#         var popup_ce1dfc1eea0ce354f72a39caa9da48b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d6b5ca94d4f56b795fea9f97d80b843 = $(`&lt;div id=&quot;html_5d6b5ca94d4f56b795fea9f97d80b843&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ce1dfc1eea0ce354f72a39caa9da48b4.setContent(html_5d6b5ca94d4f56b795fea9f97d80b843);
#
#
#
#         marker_67c8a2f657220ab44b618064bf9d201f.bindPopup(popup_ce1dfc1eea0ce354f72a39caa9da48b4)
#         ;
#
#
#
#
#             var marker_02f4da552499fc34045e993e48f5bd32 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2c9c36ca40c9ad53c1c48f227e766300);
#
#
#         var popup_ec20b63a035586dc812ad6681e13e8c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c98bf95b2773f624d85647228a63d90 = $(`&lt;div id=&quot;html_5c98bf95b2773f624d85647228a63d90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ec20b63a035586dc812ad6681e13e8c6.setContent(html_5c98bf95b2773f624d85647228a63d90);
#
#
#
#         marker_02f4da552499fc34045e993e48f5bd32.bindPopup(popup_ec20b63a035586dc812ad6681e13e8c6)
#         ;
#
#
#
#
#             var marker_aa0210cec6bf526a548605721b3f38b3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2c9c36ca40c9ad53c1c48f227e766300);
#
#
#         var popup_289373f333946031334adc33fb7f87e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82b841db3038742d9e31e698d550f83f = $(`&lt;div id=&quot;html_82b841db3038742d9e31e698d550f83f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_289373f333946031334adc33fb7f87e8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05698a7cc7d805728f1524a4713c6ac6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05698a7cc7d805728f1524a4713c6ac6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05698a7cc7d805728f1524a4713c6ac6 = L.map(
#                 &quot;map_05698a7cc7d805728f1524a4713c6ac6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19669d5a5e933aafcf0230520507e0c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_19669d5a5e933aafcf0230520507e0c3.addTo(map_05698a7cc7d805728f1524a4713c6ac6);
#
#
#             var feature_group_bedec97d10f549a12b3933dffc4a158e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_48641349090e674fe6d7cb47cbd009d8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bedec97d10f549a12b3933dffc4a158e);
#
#
#         var popup_4840c32daa4d24951352ac94f7b12f22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bcbf323af5297b1c7b468b47f9a3f58 = $(`&lt;div id=&quot;html_8bcbf323af5297b1c7b468b47f9a3f58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4840c32daa4d24951352ac94f7b12f22.setContent(html_8bcbf323af5297b1c7b468b47f9a3f58);
#
#
#
#         marker_48641349090e674fe6d7cb47cbd009d8.bindPopup(popup_4840c32daa4d24951352ac94f7b12f22)
#         ;
#
#
#
#
#             var marker_581af8c2754bcc1044e0858cac769f71 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bedec97d10f549a12b3933dffc4a158e);
#
#
#         var popup_dfed491b1e1be3beba0f7751c879cae2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07c7f31969e9946266a483ac364b658a = $(`&lt;div id=&quot;html_07c7f31969e9946266a483ac364b658a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dfed491b1e1be3beba0f7751c879cae2.setContent(html_07c7f31969e9946266a483ac364b658a);
#
#
#
#         marker_581af8c2754bcc1044e0858cac769f71.bindPopup(popup_dfed491b1e1be3beba0f7751c879cae2)
#         ;
#
#
#
#
#             var marker_ca45b9c3c1d3a4d5ead2a158ef2f5714 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bedec97d10f549a12b3933dffc4a158e);
#
#
#         var popup_fa750a100f2acb301c3878168163771a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_596976b194172a0114ba28213dd56d09 = $(`&lt;div id=&quot;html_596976b194172a0114ba28213dd56d09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fa750a100f2acb301c3878168163771a.setContent(html_596976b194172a0114ba28213dd56d09);
#
#
#
#         marker_ca45b9c3c1d3a4d5ead2a158ef2f5714.bindPopup(popup_fa750a100f2acb301c3878168163771a)
#         ;
#
#
#
#
#             var marker_1c5eeb5bec7a0bfbacce59a57d6fbae7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bedec97d10f549a12b3933dffc4a158e);
#
#
#         var popup_9481744285725f37355a73d6c814636a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e257430e59021a28a7ccf063d1ca73f = $(`&lt;div id=&quot;html_5e257430e59021a28a7ccf063d1ca73f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9481744285725f37355a73d6c814636a.setContent(html_5e257430e59021a28a7ccf063d1ca73f);
#
#
#
#         marker_1c5eeb5bec7a0bfbacce59a57d6fbae7.bindPopup(popup_9481744285725f37355a73d6c814636a)
#         ;
#
#
#
#
#             var marker_2b909f984ecab36650a0f8baf5de5410 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bedec97d10f549a12b3933dffc4a158e);
#
#
#         var popup_cb3da23cee8b0931c101671094a77f3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1eb47d13966fe8005fd22a32c39bd774 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1eb47d13966fe8005fd22a32c39bd774&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1eb47d13966fe8005fd22a32c39bd774 = L.map(
#                 &quot;map_1eb47d13966fe8005fd22a32c39bd774&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27745d2152743302a4c3fbec4ff19dda = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27745d2152743302a4c3fbec4ff19dda.addTo(map_1eb47d13966fe8005fd22a32c39bd774);
#
#
#             var feature_group_be666d3a0e1405611654155f1b5c02c0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_be666d3a0e1405611654155f1b5c02c0.addTo(map_1eb47d13966fe8005fd22a32c39bd774);
#
#
#             var feature_group_sub_group_517af2c0dbf31c07980d34c15f4b36cc = L.featureGroup.subGroup(
#                 feature_group_be666d3a0e1405611654155f1b5c02c0
#             );
#
#
#             var marker_5cf194b437e58be6f0471cf06825337f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_517af2c0dbf31c07980d34c15f4b36cc);
#
#
#         var popup_749259a462fd5c132f7bb32c870b98f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3ac36aa6c8e613ef9221730d9e8b757 = $(`&lt;div id=&quot;html_f3ac36aa6c8e613ef9221730d9e8b757&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_749259a462fd5c132f7bb32c870b98f1.setContent(html_f3ac36aa6c8e613ef9221730d9e8b757);
#
#
#
#         marker_5cf194b437e58be6f0471cf06825337f.bindPopup(popup_749259a462fd5c132f7bb32c870b98f1)
#         ;
#
#
#
#
#             var marker_5f02d44dd07dfcc5019373416e75a2e2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_517af2c0dbf31c07980d34c15f4b36cc);
#
#
#         var popup_6384e983e268178bab7aaaeaea5878ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_784df7fdcdbc51b5d194108c504f0e9e = $(`&lt;div id=&quot;html_784df7fdcdbc51b5d194108c504f0e9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6384e983e268178bab7aaaeaea5878ee.setContent(html_784df7fdcdbc51b5d194108c504f0e9e);
#
#
#
#         marker_5f02d44dd07dfcc5019373416e75a2e2.bindPopup(popup_6384e983e268178bab7aaaeaea5878ee)
#         ;
#
#
#
#
#             var marker_482dc4c1f1cf4bc41a92b051ae2d0139 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_517af2c0dbf31c07980d34c15f4b36cc);
#
#
#         var popup_654f779f6b6698eef9d02191930cfd54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea0c6061d5b48edbf000f579fc78d25a = $(`&lt;div id=&quot;html_ea0c6061d5b48edbf000f579fc78d25a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_654f779f6b6698eef9d02191930cfd54.setContent(html_ea0c6061d5b48edbf000f579fc78d25a);
#
#
#
#         marker_482dc4c1f1cf4bc41a92b051ae2d0139.bindPopup(popup_654f779f6b6698eef9d02191930cfd54)
#         ;
#
#
#
#
#             var marker_251b6ad28cba4b15241474738eb68176 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_517af2c0dbf31c07980d34c15f4b36cc);
#
#
#         var popup_21654e460b04c9cdc978024eae0f88bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fc9429568e91619a7997cf1d2297088 = $(`&lt;div id=&quot;html_9fc9429568e91619a7997cf1d2297088&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_21654e460b04c9cdc978024eae0f88bf.setContent(html_9fc9429568e91619a7997cf1d2297088);
#
#
#
#         marker_
