# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_692eff0adfc78b7e5f88b9389021f030 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_692eff0adfc78b7e5f88b9389021f030&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_692eff0adfc78b7e5f88b9389021f030 = L.map(
#                 &quot;map_692eff0adfc78b7e5f88b9389021f030&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9668e7e5b5918fedaa96dfec256705af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9668e7e5b5918fedaa96dfec256705af.addTo(map_692eff0adfc78b7e5f88b9389021f030);
#
#
#             var marker_af4ad1fe46411fc92e4e1c0a2841877c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_692eff0adfc78b7e5f88b9389021f030);
#
#
#         var popup_ce8f61bcba3a2e12cbb9c6c652346a51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c11cccd61528c4553129ce3bceebca2 = $(`&lt;div id=&quot;html_0c11cccd61528c4553129ce3bceebca2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ce8f61bcba3a2e12cbb9c6c652346a51.setContent(html_0c11cccd61528c4553129ce3bceebca2);
#
#
#
#         marker_af4ad1fe46411fc92e4e1c0a2841877c.bindPopup(popup_ce8f61bcba3a2e12cbb9c6c652346a51)
#         ;
#
#
#
#
#             var marker_6591e0d343e8899b8b52a075206f1c2b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_692eff0adfc78b7e5f88b9389021f030);
#
#
#         var popup_ddf996d6b488f949b48fc43975bb267a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_656e34c2d18f0109b7eb281f306118b6 = $(`&lt;div id=&quot;html_656e34c2d18f0109b7eb281f306118b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ddf996d6b488f949b48fc43975bb267a.setContent(html_656e34c2d18f0109b7eb281f306118b6);
#
#
#
#         marker_6591e0d343e8899b8b52a075206f1c2b.bindPopup(popup_ddf996d6b488f949b48fc43975bb267a)
#         ;
#
#
#
#
#             var marker_115b02a646ed2da4b4fcb5198cc8f1a0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_692eff0adfc78b7e5f88b9389021f030);
#
#
#         var popup_b4bffd63ccd91266c231aa26f37e884b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05f9ee7b5e43ed726aa896a228aa8c7c = $(`&lt;div id=&quot;html_05f9ee7b5e43ed726aa896a228aa8c7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b4bffd63ccd91266c231aa26f37e884b.setContent(html_05f9ee7b5e43ed726aa896a228aa8c7c);
#
#
#
#         marker_115b02a646ed2da4b4fcb5198cc8f1a0.bindPopup(popup_b4bffd63ccd91266c231aa26f37e884b)
#         ;
#
#
#
#
#             var marker_19897669094f09a373faa9025a76b1bf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_692eff0adfc78b7e5f88b9389021f030);
#
#
#         var popup_1a663fbe41a9a6608679ddc23dc2a082 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03a8e99ea7e3bb0ed0ad6d534c01a2dc = $(`&lt;div id=&quot;html_03a8e99ea7e3bb0ed0ad6d534c01a2dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1a663fbe41a9a6608679ddc23dc2a082.setContent(html_03a8e99ea7e3bb0ed0ad6d534c01a2dc);
#
#
#
#         marker_19897669094f09a373faa9025a76b1bf.bindPopup(popup_1a663fbe41a9a6608679ddc23dc2a082)
#         ;
#
#
#
#
#             var marker_7e7b1f2b1c91e3ca70238dd01f738e42 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_692eff0adfc78b7e5f88b9389021f030);
#
#
#         var popup_e6995e9872f396f1b9b089ad847fbe50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6774760edf2c93f6d8fed93bd6e9e31b = $(`&lt;div id=&quot;html_6774760edf2c93f6d8fed93bd6e9e31b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e6995e9872f396f1b9b089ad847fbe50.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ace05f452cc68b9ad11f2e81c1664e37 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ace05f452cc68b9ad11f2e81c1664e37&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ace05f452cc68b9ad11f2e81c1664e37 = L.map(
#                 &quot;map_ace05f452cc68b9ad11f2e81c1664e37&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba887a2193d4744b48e9d3e4e8cf4c47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba887a2193d4744b48e9d3e4e8cf4c47.addTo(map_ace05f452cc68b9ad11f2e81c1664e37);
#
#
#             var feature_group_abd05829f9ad7b194147a86e7e2b5590 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4cb3909687d99ff439324c8008eaf69d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_abd05829f9ad7b194147a86e7e2b5590);
#
#
#         var popup_2e1fcc91cd6da59b498a4136ced9ddb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_537f65ba512ba9a90af4db4bb23e6a6c = $(`&lt;div id=&quot;html_537f65ba512ba9a90af4db4bb23e6a6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2e1fcc91cd6da59b498a4136ced9ddb4.setContent(html_537f65ba512ba9a90af4db4bb23e6a6c);
#
#
#
#         marker_4cb3909687d99ff439324c8008eaf69d.bindPopup(popup_2e1fcc91cd6da59b498a4136ced9ddb4)
#         ;
#
#
#
#
#             var marker_ad2695328aa07646e407e5e551528850 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_abd05829f9ad7b194147a86e7e2b5590);
#
#
#         var popup_67bb7acc6a97a3e55c4ea6fa6829300c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7ccb6bc655ca253dd1ef7b2d4233c00 = $(`&lt;div id=&quot;html_d7ccb6bc655ca253dd1ef7b2d4233c00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_67bb7acc6a97a3e55c4ea6fa6829300c.setContent(html_d7ccb6bc655ca253dd1ef7b2d4233c00);
#
#
#
#         marker_ad2695328aa07646e407e5e551528850.bindPopup(popup_67bb7acc6a97a3e55c4ea6fa6829300c)
#         ;
#
#
#
#
#             var marker_43d349fb28c8550efa06f2dd212e69c4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_abd05829f9ad7b194147a86e7e2b5590);
#
#
#         var popup_ee68e7da522a7fc395ea439b24867370 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b14887b503756e7b7cf66975c7d40ace = $(`&lt;div id=&quot;html_b14887b503756e7b7cf66975c7d40ace&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ee68e7da522a7fc395ea439b24867370.setContent(html_b14887b503756e7b7cf66975c7d40ace);
#
#
#
#         marker_43d349fb28c8550efa06f2dd212e69c4.bindPopup(popup_ee68e7da522a7fc395ea439b24867370)
#         ;
#
#
#
#
#             var marker_09a1df9d41f868788911ab397da6017b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_abd05829f9ad7b194147a86e7e2b5590);
#
#
#         var popup_740ddf469bca72e1d0fa05c156bde868 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81b7b6db3be076576b5608818cceeca7 = $(`&lt;div id=&quot;html_81b7b6db3be076576b5608818cceeca7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_740ddf469bca72e1d0fa05c156bde868.setContent(html_81b7b6db3be076576b5608818cceeca7);
#
#
#
#         marker_09a1df9d41f868788911ab397da6017b.bindPopup(popup_740ddf469bca72e1d0fa05c156bde868)
#         ;
#
#
#
#
#             var marker_08b08b179aa42c359675e872ef74a682 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_abd05829f9ad7b194147a86e7e2b5590);
#
#
#         var popup_d88e53732082ca725463637e35ef649d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02afca58c4520cdc6429126e9d5aba8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02afca58c4520cdc6429126e9d5aba8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02afca58c4520cdc6429126e9d5aba8a = L.map(
#                 &quot;map_02afca58c4520cdc6429126e9d5aba8a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7206d16e29dcbe728d0cb1ae080bac37 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7206d16e29dcbe728d0cb1ae080bac37.addTo(map_02afca58c4520cdc6429126e9d5aba8a);
#
#
#             var feature_group_f660e6c6cb1c5852783424523f972743 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f660e6c6cb1c5852783424523f972743.addTo(map_02afca58c4520cdc6429126e9d5aba8a);
#
#
#             var feature_group_sub_group_297585e4c5d8a4c989e13d4fe9257864 = L.featureGroup.subGroup(
#                 feature_group_f660e6c6cb1c5852783424523f972743
#             );
#
#
#             var marker_9f449a685f495880e64ff63982f6af5f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_297585e4c5d8a4c989e13d4fe9257864);
#
#
#         var popup_62391dd6b948b5b3387c0fbd2a7035cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc00fa1a52f64ba31c0e1bd4c59eb531 = $(`&lt;div id=&quot;html_cc00fa1a52f64ba31c0e1bd4c59eb531&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_62391dd6b948b5b3387c0fbd2a7035cd.setContent(html_cc00fa1a52f64ba31c0e1bd4c59eb531);
#
#
#
#         marker_9f449a685f495880e64ff63982f6af5f.bindPopup(popup_62391dd6b948b5b3387c0fbd2a7035cd)
#         ;
#
#
#
#
#             var marker_9624cb9d0c66c81ce325fb4608bc2921 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_297585e4c5d8a4c989e13d4fe9257864);
#
#
#         var popup_d02b219b27bae82ee99d7d8542e08708 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_342b2269b6ae62dd2d010cb9d65ced50 = $(`&lt;div id=&quot;html_342b2269b6ae62dd2d010cb9d65ced50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d02b219b27bae82ee99d7d8542e08708.setContent(html_342b2269b6ae62dd2d010cb9d65ced50);
#
#
#
#         marker_9624cb9d0c66c81ce325fb4608bc2921.bindPopup(popup_d02b219b27bae82ee99d7d8542e08708)
#         ;
#
#
#
#
#             var marker_98f05bd8c8ad745a769e4c6e6587acde = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_297585e4c5d8a4c989e13d4fe9257864);
#
#
#         var popup_049091a2472c201b71cbf468a44ce616 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1b92f608e1ca76e8e05f6ad88fb1fd5 = $(`&lt;div id=&quot;html_d1b92f608e1ca76e8e05f6ad88fb1fd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_049091a2472c201b71cbf468a44ce616.setContent(html_d1b92f608e1ca76e8e05f6ad88fb1fd5);
#
#
#
#         marker_98f05bd8c8ad745a769e4c6e6587acde.bindPopup(popup_049091a2472c201b71cbf468a44ce616)
#         ;
#
#
#
#
#             var marker_6280835325edd971f8d8b9275e0ab6c9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_297585e4c5d8a4c989e13d4fe9257864);
#
#
#         var popup_092eb4b35effd075dfdfb80a66855cec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc8c16b44b435e8ed1399c417ce0bef0 = $(`&lt;div id=&quot;html_fc8c16b44b435e8ed1399c417ce0bef0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_092eb4b35effd075dfdfb80a66855cec.setContent(html_fc8c16b44b435e8ed1399c417ce0bef0);
#
#
#
#         marker_
