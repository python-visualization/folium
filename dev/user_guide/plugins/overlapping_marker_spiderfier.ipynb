# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_edc9aaa2559c6c2be5792791d3ddc969 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_edc9aaa2559c6c2be5792791d3ddc969&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_edc9aaa2559c6c2be5792791d3ddc969 = L.map(
#                 &quot;map_edc9aaa2559c6c2be5792791d3ddc969&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53bdf6fbd8382e3d6112b72a42e0a311 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53bdf6fbd8382e3d6112b72a42e0a311.addTo(map_edc9aaa2559c6c2be5792791d3ddc969);
#
#
#             var marker_f82c561247ab856f905f4bbc2555736a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_edc9aaa2559c6c2be5792791d3ddc969);
#
#
#         var popup_eb624ea0cc250b193d87baae3eb06937 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3eee6a36e77ab8d0150c7338f95d1bfc = $(`&lt;div id=&quot;html_3eee6a36e77ab8d0150c7338f95d1bfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_eb624ea0cc250b193d87baae3eb06937.setContent(html_3eee6a36e77ab8d0150c7338f95d1bfc);
#
#
#
#         marker_f82c561247ab856f905f4bbc2555736a.bindPopup(popup_eb624ea0cc250b193d87baae3eb06937)
#         ;
#
#
#
#
#             var marker_29179551ccc1eb4fb95c489c44bc7f81 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_edc9aaa2559c6c2be5792791d3ddc969);
#
#
#         var popup_5435370e811f62d2c69961d57e43a9a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f58e06b68fa5e0ce493978e298d55503 = $(`&lt;div id=&quot;html_f58e06b68fa5e0ce493978e298d55503&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5435370e811f62d2c69961d57e43a9a6.setContent(html_f58e06b68fa5e0ce493978e298d55503);
#
#
#
#         marker_29179551ccc1eb4fb95c489c44bc7f81.bindPopup(popup_5435370e811f62d2c69961d57e43a9a6)
#         ;
#
#
#
#
#             var marker_d26086436872ddc93a8646ec50fcdb16 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_edc9aaa2559c6c2be5792791d3ddc969);
#
#
#         var popup_c41dae3cb0ad3717bf332591e779ab8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cfd68f2810b946d2fbb470efca3662a = $(`&lt;div id=&quot;html_7cfd68f2810b946d2fbb470efca3662a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c41dae3cb0ad3717bf332591e779ab8c.setContent(html_7cfd68f2810b946d2fbb470efca3662a);
#
#
#
#         marker_d26086436872ddc93a8646ec50fcdb16.bindPopup(popup_c41dae3cb0ad3717bf332591e779ab8c)
#         ;
#
#
#
#
#             var marker_960220b41a41208f0f094a0760bea07a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_edc9aaa2559c6c2be5792791d3ddc969);
#
#
#         var popup_7e146b34dad3a962b803d19dc19fccf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aac0c56de7a9009a689d555a9d8a8e23 = $(`&lt;div id=&quot;html_aac0c56de7a9009a689d555a9d8a8e23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7e146b34dad3a962b803d19dc19fccf6.setContent(html_aac0c56de7a9009a689d555a9d8a8e23);
#
#
#
#         marker_960220b41a41208f0f094a0760bea07a.bindPopup(popup_7e146b34dad3a962b803d19dc19fccf6)
#         ;
#
#
#
#
#             var marker_6521e11411c19293ce18a3f747369f88 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_edc9aaa2559c6c2be5792791d3ddc969);
#
#
#         var popup_fde911fe447b7e4d246f92d123eb3165 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5302706ea35434925ece8389c94fc811 = $(`&lt;div id=&quot;html_5302706ea35434925ece8389c94fc811&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fde911fe447b7e4d246f92d123eb3165.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0aa2ba72fd9889c40f05305e87ae2d38 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0aa2ba72fd9889c40f05305e87ae2d38&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0aa2ba72fd9889c40f05305e87ae2d38 = L.map(
#                 &quot;map_0aa2ba72fd9889c40f05305e87ae2d38&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63345429707789dc6d7f1a61595cb7b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63345429707789dc6d7f1a61595cb7b9.addTo(map_0aa2ba72fd9889c40f05305e87ae2d38);
#
#
#             var feature_group_4c2c594fbc9f4c7f59d7d6aad095e5c5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bf2896cf4ab647f4456c33087ff5ad27 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4c2c594fbc9f4c7f59d7d6aad095e5c5);
#
#
#         var popup_83c9350d6515f7e125c368ae33bf865b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f3ebde05a662762f664660aadb8de48 = $(`&lt;div id=&quot;html_3f3ebde05a662762f664660aadb8de48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_83c9350d6515f7e125c368ae33bf865b.setContent(html_3f3ebde05a662762f664660aadb8de48);
#
#
#
#         marker_bf2896cf4ab647f4456c33087ff5ad27.bindPopup(popup_83c9350d6515f7e125c368ae33bf865b)
#         ;
#
#
#
#
#             var marker_751ef5ff11a406e8afe4fbd264bae4c7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4c2c594fbc9f4c7f59d7d6aad095e5c5);
#
#
#         var popup_158f9a43974088f355d9ea8e66608d93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cab03d01a82f9357657c57a33f71a13d = $(`&lt;div id=&quot;html_cab03d01a82f9357657c57a33f71a13d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_158f9a43974088f355d9ea8e66608d93.setContent(html_cab03d01a82f9357657c57a33f71a13d);
#
#
#
#         marker_751ef5ff11a406e8afe4fbd264bae4c7.bindPopup(popup_158f9a43974088f355d9ea8e66608d93)
#         ;
#
#
#
#
#             var marker_efe7e93e9e032631ac00117c82e5f575 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4c2c594fbc9f4c7f59d7d6aad095e5c5);
#
#
#         var popup_893853f5571296de35b85722b084e310 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65ba03e674e541e5cca949b55f729316 = $(`&lt;div id=&quot;html_65ba03e674e541e5cca949b55f729316&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_893853f5571296de35b85722b084e310.setContent(html_65ba03e674e541e5cca949b55f729316);
#
#
#
#         marker_efe7e93e9e032631ac00117c82e5f575.bindPopup(popup_893853f5571296de35b85722b084e310)
#         ;
#
#
#
#
#             var marker_734c04b5851413a3b2ec7c776ab22466 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4c2c594fbc9f4c7f59d7d6aad095e5c5);
#
#
#         var popup_f5a29d2aba7810d0c6027a9056f1bbbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b327749cd0dde79cea956b26b57dac22 = $(`&lt;div id=&quot;html_b327749cd0dde79cea956b26b57dac22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f5a29d2aba7810d0c6027a9056f1bbbd.setContent(html_b327749cd0dde79cea956b26b57dac22);
#
#
#
#         marker_734c04b5851413a3b2ec7c776ab22466.bindPopup(popup_f5a29d2aba7810d0c6027a9056f1bbbd)
#         ;
#
#
#
#
#             var marker_ea769ba1b49f6ccffe1d95769f6a69e5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4c2c594fbc9f4c7f59d7d6aad095e5c5);
#
#
#         var popup_194a9b86f6307c7a9bbc02ae801bcfd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03db2da6d56b35f8d348d6ef4d937fa6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03db2da6d56b35f8d348d6ef4d937fa6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03db2da6d56b35f8d348d6ef4d937fa6 = L.map(
#                 &quot;map_03db2da6d56b35f8d348d6ef4d937fa6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1a895d738f7e73e4f150e6e44b939d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1a895d738f7e73e4f150e6e44b939d8.addTo(map_03db2da6d56b35f8d348d6ef4d937fa6);
#
#
#             var feature_group_c750fc9c61e047e176d7eca160f7e8b5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c750fc9c61e047e176d7eca160f7e8b5.addTo(map_03db2da6d56b35f8d348d6ef4d937fa6);
#
#
#             var feature_group_sub_group_e26f2f66547867b9f4595f65db318062 = L.featureGroup.subGroup(
#                 feature_group_c750fc9c61e047e176d7eca160f7e8b5
#             );
#
#
#             var marker_1d35f62d04d85e75f4adea7f583b973f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e26f2f66547867b9f4595f65db318062);
#
#
#         var popup_2ce098e8f5c759491f544118c538205e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78be249b27c808635e3ebeee0e5761b4 = $(`&lt;div id=&quot;html_78be249b27c808635e3ebeee0e5761b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2ce098e8f5c759491f544118c538205e.setContent(html_78be249b27c808635e3ebeee0e5761b4);
#
#
#
#         marker_1d35f62d04d85e75f4adea7f583b973f.bindPopup(popup_2ce098e8f5c759491f544118c538205e)
#         ;
#
#
#
#
#             var marker_028fc611d728637d5742e9cd87b59aa0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e26f2f66547867b9f4595f65db318062);
#
#
#         var popup_d0dcd70ec26465196646b205ebcb3204 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d0d29ab167d7fc42adad52c9a57553c = $(`&lt;div id=&quot;html_3d0d29ab167d7fc42adad52c9a57553c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d0dcd70ec26465196646b205ebcb3204.setContent(html_3d0d29ab167d7fc42adad52c9a57553c);
#
#
#
#         marker_028fc611d728637d5742e9cd87b59aa0.bindPopup(popup_d0dcd70ec26465196646b205ebcb3204)
#         ;
#
#
#
#
#             var marker_ae1d4bcd602d0e35a269154f26187dd8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e26f2f66547867b9f4595f65db318062);
#
#
#         var popup_9c3c613e1d14cbef9a12bb9d29e37670 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c11da98800d7cdf78c2af1437e89b710 = $(`&lt;div id=&quot;html_c11da98800d7cdf78c2af1437e89b710&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9c3c613e1d14cbef9a12bb9d29e37670.setContent(html_c11da98800d7cdf78c2af1437e89b710);
#
#
#
#         marker_ae1d4bcd602d0e35a269154f26187dd8.bindPopup(popup_9c3c613e1d14cbef9a12bb9d29e37670)
#         ;
#
#
#
#
#             var marker_840a17e3e2e414a473ddcbaffd41e10a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e26f2f66547867b9f4595f65db318062);
#
#
#         var popup_818faec3151c765d0dd592a797b6e66b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b43aa9b10196a95dde020fc46f9f4c2d = $(`&lt;div id=&quot;html_b43aa9b10196a95dde020fc46f9f4c2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_818faec3151c765d0dd592a797b6e66b.setContent(html_b43aa9b10196a95dde020fc46f9f4c2d);
#
#
#
#         marker_
