# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70078711a6a96debffaecf0538ca5f76 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70078711a6a96debffaecf0538ca5f76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70078711a6a96debffaecf0538ca5f76 = L.map(
#                 &quot;map_70078711a6a96debffaecf0538ca5f76&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a6c8824500268fed161ebb97ccfbd67 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a6c8824500268fed161ebb97ccfbd67.addTo(map_70078711a6a96debffaecf0538ca5f76);
#
#
#             var marker_3057401411d0438ef1f17c0dd4d82705 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_70078711a6a96debffaecf0538ca5f76);
#
#
#         var popup_719ca216933c223a7191c2b150dc8ef5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ba358e70badaaaada58d0105b90d982 = $(`&lt;div id=&quot;html_9ba358e70badaaaada58d0105b90d982&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_719ca216933c223a7191c2b150dc8ef5.setContent(html_9ba358e70badaaaada58d0105b90d982);
#
#
#
#         marker_3057401411d0438ef1f17c0dd4d82705.bindPopup(popup_719ca216933c223a7191c2b150dc8ef5)
#         ;
#
#
#
#
#             var marker_2d1df562043bce14b4a1b8be4af6a5ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_70078711a6a96debffaecf0538ca5f76);
#
#
#         var popup_974f9ee2d1dfe4f2a9c00a9eed01d29d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba6e751350a93013c2cf37191c52578f = $(`&lt;div id=&quot;html_ba6e751350a93013c2cf37191c52578f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_974f9ee2d1dfe4f2a9c00a9eed01d29d.setContent(html_ba6e751350a93013c2cf37191c52578f);
#
#
#
#         marker_2d1df562043bce14b4a1b8be4af6a5ed.bindPopup(popup_974f9ee2d1dfe4f2a9c00a9eed01d29d)
#         ;
#
#
#
#
#             var marker_a0fca3994982d1633ccd4a469852e5ee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_70078711a6a96debffaecf0538ca5f76);
#
#
#         var popup_a68b220c4a8484b3eee9d90b8ef17a18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc8709839cec17c4ff3e43b20159613e = $(`&lt;div id=&quot;html_dc8709839cec17c4ff3e43b20159613e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a68b220c4a8484b3eee9d90b8ef17a18.setContent(html_dc8709839cec17c4ff3e43b20159613e);
#
#
#
#         marker_a0fca3994982d1633ccd4a469852e5ee.bindPopup(popup_a68b220c4a8484b3eee9d90b8ef17a18)
#         ;
#
#
#
#
#             var marker_bb200115ab2feab216554bfd2a47ad55 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_70078711a6a96debffaecf0538ca5f76);
#
#
#         var popup_be26e0c0257e543dd51e412cededa60b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1797580eb72e3b4deb5967b7f9e96bcc = $(`&lt;div id=&quot;html_1797580eb72e3b4deb5967b7f9e96bcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_be26e0c0257e543dd51e412cededa60b.setContent(html_1797580eb72e3b4deb5967b7f9e96bcc);
#
#
#
#         marker_bb200115ab2feab216554bfd2a47ad55.bindPopup(popup_be26e0c0257e543dd51e412cededa60b)
#         ;
#
#
#
#
#             var marker_bdea911c1e360227483b7d1aa4871279 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_70078711a6a96debffaecf0538ca5f76);
#
#
#         var popup_69e6ee442e02ae1208f9230dc4f1fa2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1f287b149ad5f7f3ee1342c74aee8a3 = $(`&lt;div id=&quot;html_e1f287b149ad5f7f3ee1342c74aee8a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_69e6ee442e02ae1208f9230dc4f1fa

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb9b2f20564c6d9c68b163e29fa7d6ce {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb9b2f20564c6d9c68b163e29fa7d6ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb9b2f20564c6d9c68b163e29fa7d6ce = L.map(
#                 &quot;map_eb9b2f20564c6d9c68b163e29fa7d6ce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7edfe18f44ee07f04a234409ee1e3875 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7edfe18f44ee07f04a234409ee1e3875.addTo(map_eb9b2f20564c6d9c68b163e29fa7d6ce);
#
#
#             var feature_group_ef766312fb396831032a88c2a4f4dd5e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9fc7818fba8a276c4058af6fa5ba22fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ef766312fb396831032a88c2a4f4dd5e);
#
#
#         var popup_f3d8c31e52894f866a33aaa3a9d7a237 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d7ad061d1e417f7c80b495ccaab1111 = $(`&lt;div id=&quot;html_8d7ad061d1e417f7c80b495ccaab1111&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f3d8c31e52894f866a33aaa3a9d7a237.setContent(html_8d7ad061d1e417f7c80b495ccaab1111);
#
#
#
#         marker_9fc7818fba8a276c4058af6fa5ba22fd.bindPopup(popup_f3d8c31e52894f866a33aaa3a9d7a237)
#         ;
#
#
#
#
#             var marker_954f4e97e52f8c2feeceeb045ea4dd59 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ef766312fb396831032a88c2a4f4dd5e);
#
#
#         var popup_d0bfed8b7fa236f4de726d345fb14aab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7571fa23e9246dd271ac98e7bc202ddd = $(`&lt;div id=&quot;html_7571fa23e9246dd271ac98e7bc202ddd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d0bfed8b7fa236f4de726d345fb14aab.setContent(html_7571fa23e9246dd271ac98e7bc202ddd);
#
#
#
#         marker_954f4e97e52f8c2feeceeb045ea4dd59.bindPopup(popup_d0bfed8b7fa236f4de726d345fb14aab)
#         ;
#
#
#
#
#             var marker_36b8599dd83ec3f0dbc9eebbc0eedc0b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ef766312fb396831032a88c2a4f4dd5e);
#
#
#         var popup_1ce366e2b5ebbe7c3508e7ad7d57c2d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd0cf1b5d110b4d9f636ded62a5031bf = $(`&lt;div id=&quot;html_dd0cf1b5d110b4d9f636ded62a5031bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1ce366e2b5ebbe7c3508e7ad7d57c2d4.setContent(html_dd0cf1b5d110b4d9f636ded62a5031bf);
#
#
#
#         marker_36b8599dd83ec3f0dbc9eebbc0eedc0b.bindPopup(popup_1ce366e2b5ebbe7c3508e7ad7d57c2d4)
#         ;
#
#
#
#
#             var marker_d214f072c6fb0a6407d797b761fe4002 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ef766312fb396831032a88c2a4f4dd5e);
#
#
#         var popup_e5eac316bcd1607b9425f5ad6bd9c1c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_124cc223acb3bcd6c03f8cbf32d97905 = $(`&lt;div id=&quot;html_124cc223acb3bcd6c03f8cbf32d97905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e5eac316bcd1607b9425f5ad6bd9c1c8.setContent(html_124cc223acb3bcd6c03f8cbf32d97905);
#
#
#
#         marker_d214f072c6fb0a6407d797b761fe4002.bindPopup(popup_e5eac316bcd1607b9425f5ad6bd9c1c8)
#         ;
#
#
#
#
#             var marker_007679e77bdd25bb8ea136d41f971bf1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ef766312fb396831032a88c2a4f4dd5e);
#
#
#         var popup_4d8b22b6897bc3b2216bf605e229809e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a54497347dd96bbad41911c5e4ece87 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a54497347dd96bbad41911c5e4ece87&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a54497347dd96bbad41911c5e4ece87 = L.map(
#                 &quot;map_4a54497347dd96bbad41911c5e4ece87&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73c6c107cfd03e245c23e138a1827082 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73c6c107cfd03e245c23e138a1827082.addTo(map_4a54497347dd96bbad41911c5e4ece87);
#
#
#             var feature_group_3330fdd4d376df3c0a479b4c09953bcf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3330fdd4d376df3c0a479b4c09953bcf.addTo(map_4a54497347dd96bbad41911c5e4ece87);
#
#
#             var feature_group_sub_group_56b295dd6e5aaa06cfc93dafa61898cf = L.featureGroup.subGroup(
#                 feature_group_3330fdd4d376df3c0a479b4c09953bcf
#             );
#
#
#             var marker_b0de89bb9dae6a1bde44a1a97f7e8289 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_56b295dd6e5aaa06cfc93dafa61898cf);
#
#
#         var popup_3682f4f1498c979e2f493a2e55243616 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_956b11ebad2f609e5a0ae30eefc2b7f4 = $(`&lt;div id=&quot;html_956b11ebad2f609e5a0ae30eefc2b7f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3682f4f1498c979e2f493a2e55243616.setContent(html_956b11ebad2f609e5a0ae30eefc2b7f4);
#
#
#
#         marker_b0de89bb9dae6a1bde44a1a97f7e8289.bindPopup(popup_3682f4f1498c979e2f493a2e55243616)
#         ;
#
#
#
#
#             var marker_5f01b5aaaba806298a689eda64e955dc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_56b295dd6e5aaa06cfc93dafa61898cf);
#
#
#         var popup_6dd880c9796149254c273d75046ace88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06aba856fe1b7fda235cf56fc7dc0ff5 = $(`&lt;div id=&quot;html_06aba856fe1b7fda235cf56fc7dc0ff5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6dd880c9796149254c273d75046ace88.setContent(html_06aba856fe1b7fda235cf56fc7dc0ff5);
#
#
#
#         marker_5f01b5aaaba806298a689eda64e955dc.bindPopup(popup_6dd880c9796149254c273d75046ace88)
#         ;
#
#
#
#
#             var marker_9c7fcd3015e5881d57ada7d7be4186b3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_56b295dd6e5aaa06cfc93dafa61898cf);
#
#
#         var popup_c8ac77dc762b63c7b67ad3f8814cd4dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b95f598f8237fa789792ef6643f9ccc2 = $(`&lt;div id=&quot;html_b95f598f8237fa789792ef6643f9ccc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c8ac77dc762b63c7b67ad3f8814cd4dd.setContent(html_b95f598f8237fa789792ef6643f9ccc2);
#
#
#
#         marker_9c7fcd3015e5881d57ada7d7be4186b3.bindPopup(popup_c8ac77dc762b63c7b67ad3f8814cd4dd)
#         ;
#
#
#
#
#             var marker_f99ae3a28c282cbb5261b023eccdb7e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_56b295dd6e5aaa06cfc93dafa61898cf);
#
#
#         var popup_2d5048a2e3f1fbefe722157681256912 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dee914f9fc87ee8e6792602de15c313f = $(`&lt;div id=&quot;html_dee914f9fc87ee8e6792602de15c313f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2d5048a2e3f1fbefe722157681256912.setContent(html_dee914f9fc87ee8e6792602de15c313f);
#
#
#
#         mark
