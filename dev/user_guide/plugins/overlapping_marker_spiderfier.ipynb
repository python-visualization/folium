# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed5d3d2c609959f2e7b7eae010e446c9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed5d3d2c609959f2e7b7eae010e446c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed5d3d2c609959f2e7b7eae010e446c9 = L.map(
#                 &quot;map_ed5d3d2c609959f2e7b7eae010e446c9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_68ed676d90983f6f25d511014b64e474 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_68ed676d90983f6f25d511014b64e474.addTo(map_ed5d3d2c609959f2e7b7eae010e446c9);
#
#
#             var marker_1091985211411aff30f4e79d4042fd3b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ed5d3d2c609959f2e7b7eae010e446c9);
#
#
#         var popup_ce134007f88958057ff2b732f6d289e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93ae23f26011ea3a79da247ea566d258 = $(`&lt;div id=&quot;html_93ae23f26011ea3a79da247ea566d258&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ce134007f88958057ff2b732f6d289e2.setContent(html_93ae23f26011ea3a79da247ea566d258);
#
#
#
#         marker_1091985211411aff30f4e79d4042fd3b.bindPopup(popup_ce134007f88958057ff2b732f6d289e2)
#         ;
#
#
#
#
#             var marker_fee4d0a0c4d41caff072399feeb9169e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ed5d3d2c609959f2e7b7eae010e446c9);
#
#
#         var popup_db3162d3050179e8e47de60ea6c890b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03dd44a9ddd57441d376bad01ef33fac = $(`&lt;div id=&quot;html_03dd44a9ddd57441d376bad01ef33fac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_db3162d3050179e8e47de60ea6c890b2.setContent(html_03dd44a9ddd57441d376bad01ef33fac);
#
#
#
#         marker_fee4d0a0c4d41caff072399feeb9169e.bindPopup(popup_db3162d3050179e8e47de60ea6c890b2)
#         ;
#
#
#
#
#             var marker_7c13856ade074d869013a4e881e252ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ed5d3d2c609959f2e7b7eae010e446c9);
#
#
#         var popup_d0ddb34e90969fa96410fea21047da27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1cbea68265a85dc83feb974f9dac3de = $(`&lt;div id=&quot;html_d1cbea68265a85dc83feb974f9dac3de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d0ddb34e90969fa96410fea21047da27.setContent(html_d1cbea68265a85dc83feb974f9dac3de);
#
#
#
#         marker_7c13856ade074d869013a4e881e252ed.bindPopup(popup_d0ddb34e90969fa96410fea21047da27)
#         ;
#
#
#
#
#             var marker_b5b8fd743fc54495ad24b060c7e72ca2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ed5d3d2c609959f2e7b7eae010e446c9);
#
#
#         var popup_ec06b004c53d942fc9c6abaf521b237d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_694636e0628b13ad7360e714877153ce = $(`&lt;div id=&quot;html_694636e0628b13ad7360e714877153ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ec06b004c53d942fc9c6abaf521b237d.setContent(html_694636e0628b13ad7360e714877153ce);
#
#
#
#         marker_b5b8fd743fc54495ad24b060c7e72ca2.bindPopup(popup_ec06b004c53d942fc9c6abaf521b237d)
#         ;
#
#
#
#
#             var marker_2324b73a534ba2b8947c89f231823ca9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ed5d3d2c609959f2e7b7eae010e446c9);
#
#
#         var popup_6f8e27bb63738c72c0f0a63bd257c5b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c1d2eb623741ebe06d2528f411d4649 = $(`&lt;div id=&quot;html_5c1d2eb623741ebe06d2528f411d4649&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6f8e27bb63738c72c0f0a63bd257c5

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2e968ee96872b5fc577a87b26de885e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2e968ee96872b5fc577a87b26de885e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2e968ee96872b5fc577a87b26de885e = L.map(
#                 &quot;map_e2e968ee96872b5fc577a87b26de885e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_840b431f61c547e8acb374121992c400 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_840b431f61c547e8acb374121992c400.addTo(map_e2e968ee96872b5fc577a87b26de885e);
#
#
#             var feature_group_c7162f70616f7b6a3a878dc1f8421972 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e8d0b501ce4bbcb8b1cb900b2322b12c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c7162f70616f7b6a3a878dc1f8421972);
#
#
#         var popup_a43493096a738e582f995fce75c0c0ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe065521a553747a0d2162c0d8221476 = $(`&lt;div id=&quot;html_fe065521a553747a0d2162c0d8221476&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a43493096a738e582f995fce75c0c0ca.setContent(html_fe065521a553747a0d2162c0d8221476);
#
#
#
#         marker_e8d0b501ce4bbcb8b1cb900b2322b12c.bindPopup(popup_a43493096a738e582f995fce75c0c0ca)
#         ;
#
#
#
#
#             var marker_2df14cdeb092dd8e5e41550ab3c2cb04 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c7162f70616f7b6a3a878dc1f8421972);
#
#
#         var popup_a074fb2d1d17ba2a5f51bd57d94d9485 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2422ce5dcb66e2243539f8d21ec8878 = $(`&lt;div id=&quot;html_e2422ce5dcb66e2243539f8d21ec8878&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a074fb2d1d17ba2a5f51bd57d94d9485.setContent(html_e2422ce5dcb66e2243539f8d21ec8878);
#
#
#
#         marker_2df14cdeb092dd8e5e41550ab3c2cb04.bindPopup(popup_a074fb2d1d17ba2a5f51bd57d94d9485)
#         ;
#
#
#
#
#             var marker_07a66ddcee2515acd044bc2552e6a749 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c7162f70616f7b6a3a878dc1f8421972);
#
#
#         var popup_93452d3f496044b8c86eb6c12d09bf56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_def4e732479695e55d91bb3029b3963c = $(`&lt;div id=&quot;html_def4e732479695e55d91bb3029b3963c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_93452d3f496044b8c86eb6c12d09bf56.setContent(html_def4e732479695e55d91bb3029b3963c);
#
#
#
#         marker_07a66ddcee2515acd044bc2552e6a749.bindPopup(popup_93452d3f496044b8c86eb6c12d09bf56)
#         ;
#
#
#
#
#             var marker_67d59114903390c6278c416d58b9c5df = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c7162f70616f7b6a3a878dc1f8421972);
#
#
#         var popup_f53c35a5c3973f9738c60c9685201874 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a891345bad706c21b1fbc2c271b82e0 = $(`&lt;div id=&quot;html_1a891345bad706c21b1fbc2c271b82e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f53c35a5c3973f9738c60c9685201874.setContent(html_1a891345bad706c21b1fbc2c271b82e0);
#
#
#
#         marker_67d59114903390c6278c416d58b9c5df.bindPopup(popup_f53c35a5c3973f9738c60c9685201874)
#         ;
#
#
#
#
#             var marker_a88dfb949942869a9b9511a4d0492a97 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c7162f70616f7b6a3a878dc1f8421972);
#
#
#         var popup_ca102f5ce5e90eb668d4a28c9ba1cf8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68a12cd3980f7a7370485ab7c014ca56 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68a12cd3980f7a7370485ab7c014ca56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68a12cd3980f7a7370485ab7c014ca56 = L.map(
#                 &quot;map_68a12cd3980f7a7370485ab7c014ca56&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef74947e33a998abedbf42bb8587f224 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef74947e33a998abedbf42bb8587f224.addTo(map_68a12cd3980f7a7370485ab7c014ca56);
#
#
#             var feature_group_c8dd7920010f6c1f260faa9203f89708 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c8dd7920010f6c1f260faa9203f89708.addTo(map_68a12cd3980f7a7370485ab7c014ca56);
#
#
#             var feature_group_sub_group_ce24d36cf8bc589c2d072db5ecb3fe58 = L.featureGroup.subGroup(
#                 feature_group_c8dd7920010f6c1f260faa9203f89708
#             );
#
#
#             var marker_8ccb1b8149544d3ee195bfd3e62cbdba = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ce24d36cf8bc589c2d072db5ecb3fe58);
#
#
#         var popup_08426097e47dd30ab85c68bca5df06de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f545be42ab0feb7e87f76e9a75f2320 = $(`&lt;div id=&quot;html_2f545be42ab0feb7e87f76e9a75f2320&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_08426097e47dd30ab85c68bca5df06de.setContent(html_2f545be42ab0feb7e87f76e9a75f2320);
#
#
#
#         marker_8ccb1b8149544d3ee195bfd3e62cbdba.bindPopup(popup_08426097e47dd30ab85c68bca5df06de)
#         ;
#
#
#
#
#             var marker_3f6d3e471eb07dd0be8bdde4dad4da93 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ce24d36cf8bc589c2d072db5ecb3fe58);
#
#
#         var popup_72fc251d4f10d94a914ba84c3edc01bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d371279f11ebf7e396e8789a497fbe49 = $(`&lt;div id=&quot;html_d371279f11ebf7e396e8789a497fbe49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_72fc251d4f10d94a914ba84c3edc01bb.setContent(html_d371279f11ebf7e396e8789a497fbe49);
#
#
#
#         marker_3f6d3e471eb07dd0be8bdde4dad4da93.bindPopup(popup_72fc251d4f10d94a914ba84c3edc01bb)
#         ;
#
#
#
#
#             var marker_388f91046d00f2f149899c166bc671cb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ce24d36cf8bc589c2d072db5ecb3fe58);
#
#
#         var popup_af60c132cec2a24f205985edaac099af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3a69a7f8e7a80ec53fa3d99a3d0b6ae = $(`&lt;div id=&quot;html_b3a69a7f8e7a80ec53fa3d99a3d0b6ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_af60c132cec2a24f205985edaac099af.setContent(html_b3a69a7f8e7a80ec53fa3d99a3d0b6ae);
#
#
#
#         marker_388f91046d00f2f149899c166bc671cb.bindPopup(popup_af60c132cec2a24f205985edaac099af)
#         ;
#
#
#
#
#             var marker_3d4f4e641f175c8f4be7d3668349a448 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ce24d36cf8bc589c2d072db5ecb3fe58);
#
#
#         var popup_697dbca2390161b49791df77a4cae6db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63ad69e720130dafc17bb57fb9e5decf = $(`&lt;div id=&quot;html_63ad69e720130dafc17bb57fb9e5decf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_697dbca2390161b49791df77a4cae6db.setContent(html_63ad69e720130dafc17bb57fb9e5decf);
#
#
#
#         mark
