# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9da904c67ee16c9ebb21510c9714b7f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9da904c67ee16c9ebb21510c9714b7f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9da904c67ee16c9ebb21510c9714b7f0 = L.map(
#                 &quot;map_9da904c67ee16c9ebb21510c9714b7f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4196615882bbb02442b81661ec29a09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4196615882bbb02442b81661ec29a09.addTo(map_9da904c67ee16c9ebb21510c9714b7f0);
#
#
#             var marker_8f50595cf91b65b6634a756bb7c93e05 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9da904c67ee16c9ebb21510c9714b7f0);
#
#
#         var popup_d7cd5df67431eb0cee7930001175a354 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6679eef684a26fbb6c58c7b574d6b705 = $(`&lt;div id=&quot;html_6679eef684a26fbb6c58c7b574d6b705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d7cd5df67431eb0cee7930001175a354.setContent(html_6679eef684a26fbb6c58c7b574d6b705);
#
#
#
#         marker_8f50595cf91b65b6634a756bb7c93e05.bindPopup(popup_d7cd5df67431eb0cee7930001175a354)
#         ;
#
#
#
#
#             var marker_a003bbfdd4c3157efda27c25c84d24a9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9da904c67ee16c9ebb21510c9714b7f0);
#
#
#         var popup_855be5a2c3a04e7dafd8ae87ed299e41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2edb80985a80fdcb48fa2e9b4d068d00 = $(`&lt;div id=&quot;html_2edb80985a80fdcb48fa2e9b4d068d00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_855be5a2c3a04e7dafd8ae87ed299e41.setContent(html_2edb80985a80fdcb48fa2e9b4d068d00);
#
#
#
#         marker_a003bbfdd4c3157efda27c25c84d24a9.bindPopup(popup_855be5a2c3a04e7dafd8ae87ed299e41)
#         ;
#
#
#
#
#             var marker_45a11cdb4b9841d490b32a7a5262587c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9da904c67ee16c9ebb21510c9714b7f0);
#
#
#         var popup_11404539abd653a2542fb06baf07ddd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca1bf950ee3f94d4b229a66d5f6b6cda = $(`&lt;div id=&quot;html_ca1bf950ee3f94d4b229a66d5f6b6cda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_11404539abd653a2542fb06baf07ddd8.setContent(html_ca1bf950ee3f94d4b229a66d5f6b6cda);
#
#
#
#         marker_45a11cdb4b9841d490b32a7a5262587c.bindPopup(popup_11404539abd653a2542fb06baf07ddd8)
#         ;
#
#
#
#
#             var marker_c74048277ea60afc2900490bb2d265ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9da904c67ee16c9ebb21510c9714b7f0);
#
#
#         var popup_783a602eac9b65500e154f0e5fd694bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4563e40d600da21751fe8dc6514d2a2 = $(`&lt;div id=&quot;html_f4563e40d600da21751fe8dc6514d2a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_783a602eac9b65500e154f0e5fd694bf.setContent(html_f4563e40d600da21751fe8dc6514d2a2);
#
#
#
#         marker_c74048277ea60afc2900490bb2d265ac.bindPopup(popup_783a602eac9b65500e154f0e5fd694bf)
#         ;
#
#
#
#
#             var marker_2481a08f38022ff283d10e5909296746 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9da904c67ee16c9ebb21510c9714b7f0);
#
#
#         var popup_dc5ed9b773eeca50352c0ba7a1aa8575 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d4e1a4d54852b21047768ac1c6ed657 = $(`&lt;div id=&quot;html_6d4e1a4d54852b21047768ac1c6ed657&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dc5ed9b773eeca50352c0ba7a1aa8575.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_459f90e04732adc073c44b81262a7247 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_459f90e04732adc073c44b81262a7247&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_459f90e04732adc073c44b81262a7247 = L.map(
#                 &quot;map_459f90e04732adc073c44b81262a7247&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c16a71ed581a3c7833a2595b2cfeb39b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c16a71ed581a3c7833a2595b2cfeb39b.addTo(map_459f90e04732adc073c44b81262a7247);
#
#
#             var feature_group_ea234691bd7285032a44a58748f72056 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e52aad27fa1629ff1b713d504647699e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ea234691bd7285032a44a58748f72056);
#
#
#         var popup_9801ab95e844fb3865bf6e9dc462466d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dffd51d676a971a254f186fd8719536 = $(`&lt;div id=&quot;html_2dffd51d676a971a254f186fd8719536&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9801ab95e844fb3865bf6e9dc462466d.setContent(html_2dffd51d676a971a254f186fd8719536);
#
#
#
#         marker_e52aad27fa1629ff1b713d504647699e.bindPopup(popup_9801ab95e844fb3865bf6e9dc462466d)
#         ;
#
#
#
#
#             var marker_fb22a422662d0ee4adb12fe6c5ba6d1f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ea234691bd7285032a44a58748f72056);
#
#
#         var popup_6d5ec43476e93958baa21c6184f5a3a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62d0d3f9c71f11cfe37b54cace62277c = $(`&lt;div id=&quot;html_62d0d3f9c71f11cfe37b54cace62277c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6d5ec43476e93958baa21c6184f5a3a7.setContent(html_62d0d3f9c71f11cfe37b54cace62277c);
#
#
#
#         marker_fb22a422662d0ee4adb12fe6c5ba6d1f.bindPopup(popup_6d5ec43476e93958baa21c6184f5a3a7)
#         ;
#
#
#
#
#             var marker_1f1c9ce53a2596b096f7c8cd69466a02 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ea234691bd7285032a44a58748f72056);
#
#
#         var popup_a7d2449e5c2cad13ca04488cae5d7676 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb3776123e3fbd4b2d2455308c6eaba3 = $(`&lt;div id=&quot;html_fb3776123e3fbd4b2d2455308c6eaba3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a7d2449e5c2cad13ca04488cae5d7676.setContent(html_fb3776123e3fbd4b2d2455308c6eaba3);
#
#
#
#         marker_1f1c9ce53a2596b096f7c8cd69466a02.bindPopup(popup_a7d2449e5c2cad13ca04488cae5d7676)
#         ;
#
#
#
#
#             var marker_c9dec68ab722f798d71536bca4c13556 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ea234691bd7285032a44a58748f72056);
#
#
#         var popup_63a328a1227d19eaabc9e43542cdbdc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22bc83ffca638e299c2bad726ae3d660 = $(`&lt;div id=&quot;html_22bc83ffca638e299c2bad726ae3d660&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_63a328a1227d19eaabc9e43542cdbdc5.setContent(html_22bc83ffca638e299c2bad726ae3d660);
#
#
#
#         marker_c9dec68ab722f798d71536bca4c13556.bindPopup(popup_63a328a1227d19eaabc9e43542cdbdc5)
#         ;
#
#
#
#
#             var marker_ef32a12e77f26124b9128534420dc426 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ea234691bd7285032a44a58748f72056);
#
#
#         var popup_d9fa4cb5382ca87788990761581d9aea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4c4d575ad53b36d5d785c39b7593c3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4c4d575ad53b36d5d785c39b7593c3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4c4d575ad53b36d5d785c39b7593c3f = L.map(
#                 &quot;map_c4c4d575ad53b36d5d785c39b7593c3f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b9a9ef894b325a5f6132e6d57ec0a6b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b9a9ef894b325a5f6132e6d57ec0a6b.addTo(map_c4c4d575ad53b36d5d785c39b7593c3f);
#
#
#             var feature_group_63e41770137fce21b626611aa04b7a73 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_63e41770137fce21b626611aa04b7a73.addTo(map_c4c4d575ad53b36d5d785c39b7593c3f);
#
#
#             var feature_group_sub_group_30c093e4ed1eb8f2570d7820b44c0aed = L.featureGroup.subGroup(
#                 feature_group_63e41770137fce21b626611aa04b7a73
#             );
#
#
#             var marker_5302daea8336056346bc31fa0fef2059 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_30c093e4ed1eb8f2570d7820b44c0aed);
#
#
#         var popup_2124bde12432a5b63eaf39694d3cc554 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab763972520b59b95ad890c28efd549c = $(`&lt;div id=&quot;html_ab763972520b59b95ad890c28efd549c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2124bde12432a5b63eaf39694d3cc554.setContent(html_ab763972520b59b95ad890c28efd549c);
#
#
#
#         marker_5302daea8336056346bc31fa0fef2059.bindPopup(popup_2124bde12432a5b63eaf39694d3cc554)
#         ;
#
#
#
#
#             var marker_86791d12886d39ea0159f3a004df14e2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_30c093e4ed1eb8f2570d7820b44c0aed);
#
#
#         var popup_93262e1986a5c2d1a80c5a084ba34312 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cae473c034ce2d648f771b51aa4ce5d = $(`&lt;div id=&quot;html_8cae473c034ce2d648f771b51aa4ce5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_93262e1986a5c2d1a80c5a084ba34312.setContent(html_8cae473c034ce2d648f771b51aa4ce5d);
#
#
#
#         marker_86791d12886d39ea0159f3a004df14e2.bindPopup(popup_93262e1986a5c2d1a80c5a084ba34312)
#         ;
#
#
#
#
#             var marker_217371674527c9e329dae7b2e9245a95 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_30c093e4ed1eb8f2570d7820b44c0aed);
#
#
#         var popup_5da350c8478cf299d6f1a81e3e942c7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42790d8e19cac26aa65a26abf0af5c87 = $(`&lt;div id=&quot;html_42790d8e19cac26aa65a26abf0af5c87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5da350c8478cf299d6f1a81e3e942c7c.setContent(html_42790d8e19cac26aa65a26abf0af5c87);
#
#
#
#         marker_217371674527c9e329dae7b2e9245a95.bindPopup(popup_5da350c8478cf299d6f1a81e3e942c7c)
#         ;
#
#
#
#
#             var marker_0538c8ee08448b52a7576d3d2143bc03 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_30c093e4ed1eb8f2570d7820b44c0aed);
#
#
#         var popup_e555ed71c53efb2049af7e1693b09c94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6eb7fc3806d15ec2409c5332a352b240 = $(`&lt;div id=&quot;html_6eb7fc3806d15ec2409c5332a352b240&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e555ed71c53efb2049af7e1693b09c94.setContent(html_6eb7fc3806d15ec2409c5332a352b240);
#
#
#
#         marker_
