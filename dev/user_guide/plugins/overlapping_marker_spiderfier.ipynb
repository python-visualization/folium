# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54a2ec588d50312f8ebdf594ee7dedfd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54a2ec588d50312f8ebdf594ee7dedfd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54a2ec588d50312f8ebdf594ee7dedfd = L.map(
#                 &quot;map_54a2ec588d50312f8ebdf594ee7dedfd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a2bf4e7bc75842babe0c02d5247e06d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a2bf4e7bc75842babe0c02d5247e06d.addTo(map_54a2ec588d50312f8ebdf594ee7dedfd);
#
#
#             var marker_7c7eae8b4217a1338028db5120fa0a5c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_54a2ec588d50312f8ebdf594ee7dedfd);
#
#
#         var popup_016cd6c0e0fa821a352dcdb07c34b23b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51931e77b8853bff5aafbc2e4165a796 = $(`&lt;div id=&quot;html_51931e77b8853bff5aafbc2e4165a796&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_016cd6c0e0fa821a352dcdb07c34b23b.setContent(html_51931e77b8853bff5aafbc2e4165a796);
#
#
#
#         marker_7c7eae8b4217a1338028db5120fa0a5c.bindPopup(popup_016cd6c0e0fa821a352dcdb07c34b23b)
#         ;
#
#
#
#
#             var marker_5fc9a07901d8f56e7b74ac454220f412 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_54a2ec588d50312f8ebdf594ee7dedfd);
#
#
#         var popup_8cec41ddf65af1b48238670535540993 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09b4535db1add756ba6a4c375e9eae12 = $(`&lt;div id=&quot;html_09b4535db1add756ba6a4c375e9eae12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8cec41ddf65af1b48238670535540993.setContent(html_09b4535db1add756ba6a4c375e9eae12);
#
#
#
#         marker_5fc9a07901d8f56e7b74ac454220f412.bindPopup(popup_8cec41ddf65af1b48238670535540993)
#         ;
#
#
#
#
#             var marker_1fe72ae9e8caaa2435f8de1df3baff6a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_54a2ec588d50312f8ebdf594ee7dedfd);
#
#
#         var popup_117c101c4b28cafae34941602264e9fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa0535d1601c96de3d5af275bec66f53 = $(`&lt;div id=&quot;html_fa0535d1601c96de3d5af275bec66f53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_117c101c4b28cafae34941602264e9fd.setContent(html_fa0535d1601c96de3d5af275bec66f53);
#
#
#
#         marker_1fe72ae9e8caaa2435f8de1df3baff6a.bindPopup(popup_117c101c4b28cafae34941602264e9fd)
#         ;
#
#
#
#
#             var marker_83972f6d3931257968e0107e69b4cf68 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_54a2ec588d50312f8ebdf594ee7dedfd);
#
#
#         var popup_e23e463ff1ca7b6af076f5885cd480eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bfb576bb3ed281adc2ba31c81c50ccb = $(`&lt;div id=&quot;html_8bfb576bb3ed281adc2ba31c81c50ccb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e23e463ff1ca7b6af076f5885cd480eb.setContent(html_8bfb576bb3ed281adc2ba31c81c50ccb);
#
#
#
#         marker_83972f6d3931257968e0107e69b4cf68.bindPopup(popup_e23e463ff1ca7b6af076f5885cd480eb)
#         ;
#
#
#
#
#             var marker_81b28d271c59a9e9769bbdb27c19b1dd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_54a2ec588d50312f8ebdf594ee7dedfd);
#
#
#         var popup_87e4eac18ce5d356035a92e3bad10567 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ed56f90bb59032fcb79263cbf32acc5 = $(`&lt;div id=&quot;html_0ed56f90bb59032fcb79263cbf32acc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_87e4eac18ce5d356035a92e3bad10567.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38701625fa6b0a7770e0be7d4364a1dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38701625fa6b0a7770e0be7d4364a1dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38701625fa6b0a7770e0be7d4364a1dc = L.map(
#                 &quot;map_38701625fa6b0a7770e0be7d4364a1dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_21b7d2b54b1b7abbe31754a4e3b79be7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_21b7d2b54b1b7abbe31754a4e3b79be7.addTo(map_38701625fa6b0a7770e0be7d4364a1dc);
#
#
#             var feature_group_28233f1f67f81b4a2a3eae3dec94f346 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_304eaeaf1148046c81876d0e173138ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_28233f1f67f81b4a2a3eae3dec94f346);
#
#
#         var popup_8f4f8eff5bebae6eacdcb12989c4436a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04d10b1b19cc8960f290ac3b41998a6f = $(`&lt;div id=&quot;html_04d10b1b19cc8960f290ac3b41998a6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8f4f8eff5bebae6eacdcb12989c4436a.setContent(html_04d10b1b19cc8960f290ac3b41998a6f);
#
#
#
#         marker_304eaeaf1148046c81876d0e173138ce.bindPopup(popup_8f4f8eff5bebae6eacdcb12989c4436a)
#         ;
#
#
#
#
#             var marker_a8f79346112d1015ec0a83988e33f5c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_28233f1f67f81b4a2a3eae3dec94f346);
#
#
#         var popup_57e37b9a271c9176a91ad703c4a88aa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7b8690d01b4bfd0fb6e0a3b5176e5ff = $(`&lt;div id=&quot;html_e7b8690d01b4bfd0fb6e0a3b5176e5ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_57e37b9a271c9176a91ad703c4a88aa9.setContent(html_e7b8690d01b4bfd0fb6e0a3b5176e5ff);
#
#
#
#         marker_a8f79346112d1015ec0a83988e33f5c4.bindPopup(popup_57e37b9a271c9176a91ad703c4a88aa9)
#         ;
#
#
#
#
#             var marker_980a7a9f45c7d3a920349794a4753805 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_28233f1f67f81b4a2a3eae3dec94f346);
#
#
#         var popup_f8026f4b9702c2e9f1cf6d9698d85bfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35348c2ec4cfe6cfb2791078cd30876d = $(`&lt;div id=&quot;html_35348c2ec4cfe6cfb2791078cd30876d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f8026f4b9702c2e9f1cf6d9698d85bfb.setContent(html_35348c2ec4cfe6cfb2791078cd30876d);
#
#
#
#         marker_980a7a9f45c7d3a920349794a4753805.bindPopup(popup_f8026f4b9702c2e9f1cf6d9698d85bfb)
#         ;
#
#
#
#
#             var marker_720f8f9a5594975b0d4da29c35522928 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_28233f1f67f81b4a2a3eae3dec94f346);
#
#
#         var popup_95c9addf4ba1973afef6df88af183aa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37e4e343f1f2b269b6bd3f8dafc9e578 = $(`&lt;div id=&quot;html_37e4e343f1f2b269b6bd3f8dafc9e578&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_95c9addf4ba1973afef6df88af183aa8.setContent(html_37e4e343f1f2b269b6bd3f8dafc9e578);
#
#
#
#         marker_720f8f9a5594975b0d4da29c35522928.bindPopup(popup_95c9addf4ba1973afef6df88af183aa8)
#         ;
#
#
#
#
#             var marker_20a9b1424f12db2c2bacf25438a07b41 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_28233f1f67f81b4a2a3eae3dec94f346);
#
#
#         var popup_da0b1de8b2ffe81ff3fc31b480e789a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e28130749f8fc0da91c27681ead0a277 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e28130749f8fc0da91c27681ead0a277&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e28130749f8fc0da91c27681ead0a277 = L.map(
#                 &quot;map_e28130749f8fc0da91c27681ead0a277&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_817b17c979a5dd2376acd9d699551dc9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_817b17c979a5dd2376acd9d699551dc9.addTo(map_e28130749f8fc0da91c27681ead0a277);
#
#
#             var feature_group_fdd5a46e6f8464528cebf2ca59fa89f9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fdd5a46e6f8464528cebf2ca59fa89f9.addTo(map_e28130749f8fc0da91c27681ead0a277);
#
#
#             var feature_group_sub_group_1cfb4008fd2d40681c7baa3e3d1aa971 = L.featureGroup.subGroup(
#                 feature_group_fdd5a46e6f8464528cebf2ca59fa89f9
#             );
#
#
#             var marker_9d3273e4e86ccdcd2b1b3b995b09835b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1cfb4008fd2d40681c7baa3e3d1aa971);
#
#
#         var popup_f566892dd7232ceb9a5248c6ad5693de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f246158064d1995008af63e0170e9868 = $(`&lt;div id=&quot;html_f246158064d1995008af63e0170e9868&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f566892dd7232ceb9a5248c6ad5693de.setContent(html_f246158064d1995008af63e0170e9868);
#
#
#
#         marker_9d3273e4e86ccdcd2b1b3b995b09835b.bindPopup(popup_f566892dd7232ceb9a5248c6ad5693de)
#         ;
#
#
#
#
#             var marker_8151928e0afbc031abbe7f069ad1bba9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1cfb4008fd2d40681c7baa3e3d1aa971);
#
#
#         var popup_d3d598b01f86e29af8e8a48408e6c198 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b793ccb3d9dd9d9bfe61438fd2e10d52 = $(`&lt;div id=&quot;html_b793ccb3d9dd9d9bfe61438fd2e10d52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d3d598b01f86e29af8e8a48408e6c198.setContent(html_b793ccb3d9dd9d9bfe61438fd2e10d52);
#
#
#
#         marker_8151928e0afbc031abbe7f069ad1bba9.bindPopup(popup_d3d598b01f86e29af8e8a48408e6c198)
#         ;
#
#
#
#
#             var marker_04f009a2b05ac683f7a91c0a7b5c691b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1cfb4008fd2d40681c7baa3e3d1aa971);
#
#
#         var popup_22efade8bd63b5b71471267a45f780d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc6069df22a4730042f0cf900cfdca89 = $(`&lt;div id=&quot;html_cc6069df22a4730042f0cf900cfdca89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_22efade8bd63b5b71471267a45f780d3.setContent(html_cc6069df22a4730042f0cf900cfdca89);
#
#
#
#         marker_04f009a2b05ac683f7a91c0a7b5c691b.bindPopup(popup_22efade8bd63b5b71471267a45f780d3)
#         ;
#
#
#
#
#             var marker_08c8d4c60d7ccc1109d55ec38cad2812 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1cfb4008fd2d40681c7baa3e3d1aa971);
#
#
#         var popup_a445b83d498a0aa7297b95c4f909f51d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_592e3a063994651d00b7220842144b36 = $(`&lt;div id=&quot;html_592e3a063994651d00b7220842144b36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a445b83d498a0aa7297b95c4f909f51d.setContent(html_592e3a063994651d00b7220842144b36);
#
#
#
#         marker_
