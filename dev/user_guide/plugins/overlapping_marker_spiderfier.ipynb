# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7efa3bd75a53591ff8729aa0919cc2c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7efa3bd75a53591ff8729aa0919cc2c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7efa3bd75a53591ff8729aa0919cc2c1 = L.map(
#                 &quot;map_7efa3bd75a53591ff8729aa0919cc2c1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcd2df4ce7b4a524fe93683a9026e241 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bcd2df4ce7b4a524fe93683a9026e241.addTo(map_7efa3bd75a53591ff8729aa0919cc2c1);
#
#
#             var marker_4cc9d0bc81af862c9b9d9d729fabe019 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7efa3bd75a53591ff8729aa0919cc2c1);
#
#
#         var popup_0b39b106b618434a706b4c1d6f3fd8a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16f30aa00871777db4a5789520cfc723 = $(`&lt;div id=&quot;html_16f30aa00871777db4a5789520cfc723&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0b39b106b618434a706b4c1d6f3fd8a5.setContent(html_16f30aa00871777db4a5789520cfc723);
#
#
#
#         marker_4cc9d0bc81af862c9b9d9d729fabe019.bindPopup(popup_0b39b106b618434a706b4c1d6f3fd8a5)
#         ;
#
#
#
#
#             var marker_c2ccdc50cb027abacd094b36520865e0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7efa3bd75a53591ff8729aa0919cc2c1);
#
#
#         var popup_4fd6c215a882554873aea36e031a36e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a71b09c0a53b67d72c2afc7502dfe3d = $(`&lt;div id=&quot;html_3a71b09c0a53b67d72c2afc7502dfe3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4fd6c215a882554873aea36e031a36e7.setContent(html_3a71b09c0a53b67d72c2afc7502dfe3d);
#
#
#
#         marker_c2ccdc50cb027abacd094b36520865e0.bindPopup(popup_4fd6c215a882554873aea36e031a36e7)
#         ;
#
#
#
#
#             var marker_967f17514b00b20576ec42c96d456c26 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7efa3bd75a53591ff8729aa0919cc2c1);
#
#
#         var popup_fe33ca6da099efe1b33b01f897edde65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19dbfe4299601b07a56762050d8e0279 = $(`&lt;div id=&quot;html_19dbfe4299601b07a56762050d8e0279&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fe33ca6da099efe1b33b01f897edde65.setContent(html_19dbfe4299601b07a56762050d8e0279);
#
#
#
#         marker_967f17514b00b20576ec42c96d456c26.bindPopup(popup_fe33ca6da099efe1b33b01f897edde65)
#         ;
#
#
#
#
#             var marker_0d0a7fb82bf25330f3f23019dd19d3b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7efa3bd75a53591ff8729aa0919cc2c1);
#
#
#         var popup_6e700123670ea29b0c7308fee80b1dcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6be9927cc2d1f3f69ae27b9065f4f40 = $(`&lt;div id=&quot;html_a6be9927cc2d1f3f69ae27b9065f4f40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6e700123670ea29b0c7308fee80b1dcb.setContent(html_a6be9927cc2d1f3f69ae27b9065f4f40);
#
#
#
#         marker_0d0a7fb82bf25330f3f23019dd19d3b2.bindPopup(popup_6e700123670ea29b0c7308fee80b1dcb)
#         ;
#
#
#
#
#             var marker_66f114402d31606ea67d3873dc474a31 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7efa3bd75a53591ff8729aa0919cc2c1);
#
#
#         var popup_adb404e4b0644c0be698189fb4b8413a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_653817be3a57cdfee85224cf6506a5fb = $(`&lt;div id=&quot;html_653817be3a57cdfee85224cf6506a5fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_adb404e4b0644c0be698189fb4b8413a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c76f0b24513179f03b35435b6217bc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c76f0b24513179f03b35435b6217bc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c76f0b24513179f03b35435b6217bc9 = L.map(
#                 &quot;map_0c76f0b24513179f03b35435b6217bc9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3d7cf8ac53105db81ff62f6b1468239 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b3d7cf8ac53105db81ff62f6b1468239.addTo(map_0c76f0b24513179f03b35435b6217bc9);
#
#
#             var feature_group_ba7d5477d840ba2339bc76468d3f13d9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5ca615381178536c5ef74cb9f0b9d151 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ba7d5477d840ba2339bc76468d3f13d9);
#
#
#         var popup_e3edcce562b8d35feee688dbf16ab066 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff44ca5e7b6b1e301c25ca90d0e8a815 = $(`&lt;div id=&quot;html_ff44ca5e7b6b1e301c25ca90d0e8a815&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e3edcce562b8d35feee688dbf16ab066.setContent(html_ff44ca5e7b6b1e301c25ca90d0e8a815);
#
#
#
#         marker_5ca615381178536c5ef74cb9f0b9d151.bindPopup(popup_e3edcce562b8d35feee688dbf16ab066)
#         ;
#
#
#
#
#             var marker_e51949b8fceaa246a9f25f6017630672 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ba7d5477d840ba2339bc76468d3f13d9);
#
#
#         var popup_c2992fec7338acc526fcd9e7d83fd67b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b5edd9beca1a9cd4190d4d9175d4b75 = $(`&lt;div id=&quot;html_1b5edd9beca1a9cd4190d4d9175d4b75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c2992fec7338acc526fcd9e7d83fd67b.setContent(html_1b5edd9beca1a9cd4190d4d9175d4b75);
#
#
#
#         marker_e51949b8fceaa246a9f25f6017630672.bindPopup(popup_c2992fec7338acc526fcd9e7d83fd67b)
#         ;
#
#
#
#
#             var marker_65732513cba72b037e4610b5eb6e1501 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ba7d5477d840ba2339bc76468d3f13d9);
#
#
#         var popup_855f9a31b5fe237a58a3b5ddfce643d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f67edf232d028045ad5fbea180c38301 = $(`&lt;div id=&quot;html_f67edf232d028045ad5fbea180c38301&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_855f9a31b5fe237a58a3b5ddfce643d3.setContent(html_f67edf232d028045ad5fbea180c38301);
#
#
#
#         marker_65732513cba72b037e4610b5eb6e1501.bindPopup(popup_855f9a31b5fe237a58a3b5ddfce643d3)
#         ;
#
#
#
#
#             var marker_a37e2245cdab5f2831ee2b21b486ee4a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ba7d5477d840ba2339bc76468d3f13d9);
#
#
#         var popup_f2edb68df9d4ceec9ae06e8bef3d39e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56ad44071a706b04b2f0780225d5e595 = $(`&lt;div id=&quot;html_56ad44071a706b04b2f0780225d5e595&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f2edb68df9d4ceec9ae06e8bef3d39e6.setContent(html_56ad44071a706b04b2f0780225d5e595);
#
#
#
#         marker_a37e2245cdab5f2831ee2b21b486ee4a.bindPopup(popup_f2edb68df9d4ceec9ae06e8bef3d39e6)
#         ;
#
#
#
#
#             var marker_5edb60f1952dbb0bbc685c3799f9c033 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ba7d5477d840ba2339bc76468d3f13d9);
#
#
#         var popup_e2a0f75fb33592c02c9bd8083d69b9a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98612b3f3c1ee273e53e8fd6c9856464 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98612b3f3c1ee273e53e8fd6c9856464&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98612b3f3c1ee273e53e8fd6c9856464 = L.map(
#                 &quot;map_98612b3f3c1ee273e53e8fd6c9856464&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93e23003d4dfd52eb5ce51063b8743b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_93e23003d4dfd52eb5ce51063b8743b3.addTo(map_98612b3f3c1ee273e53e8fd6c9856464);
#
#
#             var feature_group_1a070e5d2472e0df1a61eccbffd4016a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1a070e5d2472e0df1a61eccbffd4016a.addTo(map_98612b3f3c1ee273e53e8fd6c9856464);
#
#
#             var feature_group_sub_group_b31e9604104f5cc2ff9bad26c22aae82 = L.featureGroup.subGroup(
#                 feature_group_1a070e5d2472e0df1a61eccbffd4016a
#             );
#
#
#             var marker_b5a3c3e99f5a04dfd481f4056d039ccc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b31e9604104f5cc2ff9bad26c22aae82);
#
#
#         var popup_74c34adf257ab63c9778ea3754cfc37a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b43db8b47705d47a99bf29cbc0e85d39 = $(`&lt;div id=&quot;html_b43db8b47705d47a99bf29cbc0e85d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_74c34adf257ab63c9778ea3754cfc37a.setContent(html_b43db8b47705d47a99bf29cbc0e85d39);
#
#
#
#         marker_b5a3c3e99f5a04dfd481f4056d039ccc.bindPopup(popup_74c34adf257ab63c9778ea3754cfc37a)
#         ;
#
#
#
#
#             var marker_0263a5105e279747133f3f122675a5ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b31e9604104f5cc2ff9bad26c22aae82);
#
#
#         var popup_de829026067185731fc4bd6389f1f13d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35d96aab21b32993eb3aaf23a9acb7b3 = $(`&lt;div id=&quot;html_35d96aab21b32993eb3aaf23a9acb7b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_de829026067185731fc4bd6389f1f13d.setContent(html_35d96aab21b32993eb3aaf23a9acb7b3);
#
#
#
#         marker_0263a5105e279747133f3f122675a5ed.bindPopup(popup_de829026067185731fc4bd6389f1f13d)
#         ;
#
#
#
#
#             var marker_d9a72f6a864006d27532d2962527ce3e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b31e9604104f5cc2ff9bad26c22aae82);
#
#
#         var popup_ce89b3ca2aa5ba3d7e83238f76df1dd6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3eb7ba406d60c299bd93bbfa454bd5b6 = $(`&lt;div id=&quot;html_3eb7ba406d60c299bd93bbfa454bd5b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ce89b3ca2aa5ba3d7e83238f76df1dd6.setContent(html_3eb7ba406d60c299bd93bbfa454bd5b6);
#
#
#
#         marker_d9a72f6a864006d27532d2962527ce3e.bindPopup(popup_ce89b3ca2aa5ba3d7e83238f76df1dd6)
#         ;
#
#
#
#
#             var marker_d61625434dc2b416ffcef1ac23e575de = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b31e9604104f5cc2ff9bad26c22aae82);
#
#
#         var popup_4459a38e29a5a2e8744267d926369b64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74ac9cfca89c07638175e79eda497b2f = $(`&lt;div id=&quot;html_74ac9cfca89c07638175e79eda497b2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4459a38e29a5a2e8744267d926369b64.setContent(html_74ac9cfca89c07638175e79eda497b2f);
#
#
#
#         marker_
