# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3edc9fc57dd898bd9d876dd022bd9904 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3edc9fc57dd898bd9d876dd022bd9904&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3edc9fc57dd898bd9d876dd022bd9904 = L.map(
#                 &quot;map_3edc9fc57dd898bd9d876dd022bd9904&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b76763a94c4fa60f263fe7d0ba0144b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b76763a94c4fa60f263fe7d0ba0144b.addTo(map_3edc9fc57dd898bd9d876dd022bd9904);
#
#
#             var marker_082166ce78c3221f9e770ae94369c6a7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3edc9fc57dd898bd9d876dd022bd9904);
#
#
#         var popup_892804b38465dd0753b699811f8c92b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_777ee756996f2986006cad37922b6abd = $(`&lt;div id=&quot;html_777ee756996f2986006cad37922b6abd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_892804b38465dd0753b699811f8c92b8.setContent(html_777ee756996f2986006cad37922b6abd);
#
#
#
#         marker_082166ce78c3221f9e770ae94369c6a7.bindPopup(popup_892804b38465dd0753b699811f8c92b8)
#         ;
#
#
#
#
#             var marker_f4d7a53aed89f9aef95b03e70120d040 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3edc9fc57dd898bd9d876dd022bd9904);
#
#
#         var popup_8693f26e2d4b27dc57a1db94b9608cb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_353588ce297bc8b2a705858ee76f01b6 = $(`&lt;div id=&quot;html_353588ce297bc8b2a705858ee76f01b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8693f26e2d4b27dc57a1db94b9608cb2.setContent(html_353588ce297bc8b2a705858ee76f01b6);
#
#
#
#         marker_f4d7a53aed89f9aef95b03e70120d040.bindPopup(popup_8693f26e2d4b27dc57a1db94b9608cb2)
#         ;
#
#
#
#
#             var marker_2de6b5b39f1c5fd639e16fb35fbcfb0c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3edc9fc57dd898bd9d876dd022bd9904);
#
#
#         var popup_e09b3102a999b59f984229eb9930867d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4acbf4f1cea1afd49227e3c3c9f2d39 = $(`&lt;div id=&quot;html_a4acbf4f1cea1afd49227e3c3c9f2d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e09b3102a999b59f984229eb9930867d.setContent(html_a4acbf4f1cea1afd49227e3c3c9f2d39);
#
#
#
#         marker_2de6b5b39f1c5fd639e16fb35fbcfb0c.bindPopup(popup_e09b3102a999b59f984229eb9930867d)
#         ;
#
#
#
#
#             var marker_cc5a1f29fbede5b434ab11d9f962de3f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3edc9fc57dd898bd9d876dd022bd9904);
#
#
#         var popup_d4ce3d79c130c06c617975747c24f2be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e49dff39fa28cf94d5d0322454b890f7 = $(`&lt;div id=&quot;html_e49dff39fa28cf94d5d0322454b890f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d4ce3d79c130c06c617975747c24f2be.setContent(html_e49dff39fa28cf94d5d0322454b890f7);
#
#
#
#         marker_cc5a1f29fbede5b434ab11d9f962de3f.bindPopup(popup_d4ce3d79c130c06c617975747c24f2be)
#         ;
#
#
#
#
#             var marker_31561a043eae9949299ec9e54ae95243 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3edc9fc57dd898bd9d876dd022bd9904);
#
#
#         var popup_4246571f55cdf7a6a5280f2d818f9100 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_195a5f8b29c973f14f3eab5cc3f270a6 = $(`&lt;div id=&quot;html_195a5f8b29c973f14f3eab5cc3f270a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4246571f55cdf7a6a5280f2d818f9100.setContent(html_195a5f8b29c973f14f3eab5cc3f270a6);
#
#
#
#         marker_31561a043eae9949299ec9e54ae95243.bindPopup(popup_4246571f55cdf7a6a5280f2d818f9100)
#         ;
#
#
#
#
#             var marker_f3541a3d3c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1ac0638cfbbf58d0ff1d5d908ab2871 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1ac0638cfbbf58d0ff1d5d908ab2871&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1ac0638cfbbf58d0ff1d5d908ab2871 = L.map(
#                 &quot;map_b1ac0638cfbbf58d0ff1d5d908ab2871&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6178d3de14852573e5f314827e2204be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6178d3de14852573e5f314827e2204be.addTo(map_b1ac0638cfbbf58d0ff1d5d908ab2871);
#
#
#             var feature_group_54d885da18f7eb6014c7af98d588e0c5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cdcda9e0518e8810cf03b888f835bf4e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_54d885da18f7eb6014c7af98d588e0c5);
#
#
#         var popup_76a7887c0bdfcc49340f5e3c09170b97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4d7c91ae04ed2adada06113c5bbaec4 = $(`&lt;div id=&quot;html_b4d7c91ae04ed2adada06113c5bbaec4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_76a7887c0bdfcc49340f5e3c09170b97.setContent(html_b4d7c91ae04ed2adada06113c5bbaec4);
#
#
#
#         marker_cdcda9e0518e8810cf03b888f835bf4e.bindPopup(popup_76a7887c0bdfcc49340f5e3c09170b97)
#         ;
#
#
#
#
#             var marker_f5167ca737090e2e0cfb9116de29cbe3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_54d885da18f7eb6014c7af98d588e0c5);
#
#
#         var popup_29951b4180c0b2ba616525bd021654b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_159ccc025aca473bfe16fbd1f1ca87bc = $(`&lt;div id=&quot;html_159ccc025aca473bfe16fbd1f1ca87bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_29951b4180c0b2ba616525bd021654b9.setContent(html_159ccc025aca473bfe16fbd1f1ca87bc);
#
#
#
#         marker_f5167ca737090e2e0cfb9116de29cbe3.bindPopup(popup_29951b4180c0b2ba616525bd021654b9)
#         ;
#
#
#
#
#             var marker_abb317b195019928b0eaaa81bb25618a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_54d885da18f7eb6014c7af98d588e0c5);
#
#
#         var popup_6e58d1cab20b03d6c04750983e591000 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ccce4d35c9916ea37e9a657f3c96ba6 = $(`&lt;div id=&quot;html_6ccce4d35c9916ea37e9a657f3c96ba6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6e58d1cab20b03d6c04750983e591000.setContent(html_6ccce4d35c9916ea37e9a657f3c96ba6);
#
#
#
#         marker_abb317b195019928b0eaaa81bb25618a.bindPopup(popup_6e58d1cab20b03d6c04750983e591000)
#         ;
#
#
#
#
#             var marker_74f7dcd4ce09fad4867fb27b37c8edf1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_54d885da18f7eb6014c7af98d588e0c5);
#
#
#         var popup_f88c58c716c65202f24a2b9494e590f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1613d9132136a06ba6da797da61c7340 = $(`&lt;div id=&quot;html_1613d9132136a06ba6da797da61c7340&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f88c58c716c65202f24a2b9494e590f8.setContent(html_1613d9132136a06ba6da797da61c7340);
#
#
#
#         marker_74f7dcd4ce09fad4867fb27b37c8edf1.bindPopup(popup_f88c58c716c65202f24a2b9494e590f8)
#         ;
#
#
#
#
#             var marker_5ecb46d66f66062106c2a29d55a48a99 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_54d885da18f7eb6014c7af98d588e0c5);
#
#
#         var popup_c544f00af3a7e6d7f052a3415a74914e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_131f9cbee0ee89ead0207666362d72b3 = $(`&lt;div id=&quot;html_131f9cbee0ee89ead0207666362d72b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_c544f00af3a7e6d7f0

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e1ae7209e4b53807a3bb761633ece47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e1ae7209e4b53807a3bb761633ece47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e1ae7209e4b53807a3bb761633ece47 = L.map(
#                 &quot;map_8e1ae7209e4b53807a3bb761633ece47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e19565e58fa2b83fdf07db41d757aef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8e19565e58fa2b83fdf07db41d757aef.addTo(map_8e1ae7209e4b53807a3bb761633ece47);
#
#
#             var feature_group_66775b36eb44ee9f51f7e1697bd715a8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_66775b36eb44ee9f51f7e1697bd715a8.addTo(map_8e1ae7209e4b53807a3bb761633ece47);
#
#
#             var feature_group_sub_group_411469f8a988f9a7b52da97703e4ff11 = L.featureGroup.subGroup(
#                 feature_group_66775b36eb44ee9f51f7e1697bd715a8
#             );
#
#
#             var marker_664251297fee469c6f86c612f73da5f3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_411469f8a988f9a7b52da97703e4ff11);
#
#
#         var popup_73357a3d711695193b014065276a5648 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edbf8a880961a1acaaa3746012903bfe = $(`&lt;div id=&quot;html_edbf8a880961a1acaaa3746012903bfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_73357a3d711695193b014065276a5648.setContent(html_edbf8a880961a1acaaa3746012903bfe);
#
#
#
#         marker_664251297fee469c6f86c612f73da5f3.bindPopup(popup_73357a3d711695193b014065276a5648)
#         ;
#
#
#
#
#             var marker_8e2e4e48bcb7a659ab7373a7a2e3f994 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_411469f8a988f9a7b52da97703e4ff11);
#
#
#         var popup_95aa956c8964c447a9d159ea900c663d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7654f64d3b7af45feb3976e43a124a1a = $(`&lt;div id=&quot;html_7654f64d3b7af45feb3976e43a124a1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_95aa956c8964c447a9d159ea900c663d.setContent(html_7654f64d3b7af45feb3976e43a124a1a);
#
#
#
#         marker_8e2e4e48bcb7a659ab7373a7a2e3f994.bindPopup(popup_95aa956c8964c447a9d159ea900c663d)
#         ;
#
#
#
#
#             var marker_f12814aa81ccc9887c33de3a94b33580 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_411469f8a988f9a7b52da97703e4ff11);
#
#
#         var popup_2bc7b3e2994915166cc6d7154cef5f1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1070c580dfdf6125f3b6218dad8593a2 = $(`&lt;div id=&quot;html_1070c580dfdf6125f3b6218dad8593a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2bc7b3e2994915166cc6d7154cef5f1a.setContent(html_1070c580dfdf6125f3b6218dad8593a2);
#
#
#
#         marker_f12814aa81ccc9887c33de3a94b33580.bindPopup(popup_2bc7b3e2994915166cc6d7154cef5f1a)
#         ;
#
#
#
#
#             var marker_90eae25944c6ecf1752b0dbe32bd50c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_411469f8a988f9a7b52da97703e4ff11);
#
#
#         var popup_443662ff8e4bb8edaafa39ef358da3e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8417280f56784a1e712de39b96a07d71 = $(`&lt;div id=&quot;html_8417280f56784a1e712de39b96a07d71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_443662ff8e4bb8edaafa39ef358da3e8.setContent(html_8417280f56784a1e712de39b96a07d71);
#
#
#
#         marker_90eae25944c6ecf1752b0dbe32bd50c4.bindPopup(popup_443662ff8e4bb8edaafa39ef358da3e8)
#         ;
#
#
#
#
#             var marker_8945f20f848f43e4b0d96a8c0544b6d6 = L.marker(
#                 [45.050399999999996, 3.0504],
