# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5d6bce6df891520602946d47dfc736f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5d6bce6df891520602946d47dfc736f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5d6bce6df891520602946d47dfc736f = L.map(
#                 &quot;map_f5d6bce6df891520602946d47dfc736f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_93eb1d6fb58f7e26c989b39170855fae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_93eb1d6fb58f7e26c989b39170855fae.addTo(map_f5d6bce6df891520602946d47dfc736f);
#
#
#             var marker_b1d07f182220599b652e69658d3d2b7a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f5d6bce6df891520602946d47dfc736f);
#
#
#         var popup_8b7500a8134ba6be179931d6d7812a48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5e62f015a8dc44bca5eb31e30a10579 = $(`&lt;div id=&quot;html_d5e62f015a8dc44bca5eb31e30a10579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8b7500a8134ba6be179931d6d7812a48.setContent(html_d5e62f015a8dc44bca5eb31e30a10579);
#
#
#
#         marker_b1d07f182220599b652e69658d3d2b7a.bindPopup(popup_8b7500a8134ba6be179931d6d7812a48)
#         ;
#
#
#
#
#             var marker_b28781ed522e0d1db42016578f720650 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f5d6bce6df891520602946d47dfc736f);
#
#
#         var popup_26eed65b2a363334feed0b1c9fbadc1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c39246e902ca29f485bfd78b63ef5dc = $(`&lt;div id=&quot;html_2c39246e902ca29f485bfd78b63ef5dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_26eed65b2a363334feed0b1c9fbadc1b.setContent(html_2c39246e902ca29f485bfd78b63ef5dc);
#
#
#
#         marker_b28781ed522e0d1db42016578f720650.bindPopup(popup_26eed65b2a363334feed0b1c9fbadc1b)
#         ;
#
#
#
#
#             var marker_6227d2b41e3232a5dffc05abcbf42704 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f5d6bce6df891520602946d47dfc736f);
#
#
#         var popup_882ac76815cb9000062464291beb417e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6eb1e1733a4a3a8e1e522bf3c6ba8e70 = $(`&lt;div id=&quot;html_6eb1e1733a4a3a8e1e522bf3c6ba8e70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_882ac76815cb9000062464291beb417e.setContent(html_6eb1e1733a4a3a8e1e522bf3c6ba8e70);
#
#
#
#         marker_6227d2b41e3232a5dffc05abcbf42704.bindPopup(popup_882ac76815cb9000062464291beb417e)
#         ;
#
#
#
#
#             var marker_8d2bdac5db7dca83059638698d6c02c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f5d6bce6df891520602946d47dfc736f);
#
#
#         var popup_89758f1b8dacb13c90d6f9821d95b8f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bee9ddc4f244899073e37c256a9735a = $(`&lt;div id=&quot;html_1bee9ddc4f244899073e37c256a9735a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_89758f1b8dacb13c90d6f9821d95b8f3.setContent(html_1bee9ddc4f244899073e37c256a9735a);
#
#
#
#         marker_8d2bdac5db7dca83059638698d6c02c0.bindPopup(popup_89758f1b8dacb13c90d6f9821d95b8f3)
#         ;
#
#
#
#
#             var marker_1775a7eb131cc61dc219aa632b41d7eb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f5d6bce6df891520602946d47dfc736f);
#
#
#         var popup_84e678b78f5bb83a34b69620c1352bf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c14200d9f6d7dea60a64bce38ae3a4e3 = $(`&lt;div id=&quot;html_c14200d9f6d7dea60a64bce38ae3a4e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_84e678b78f5bb83a34b69620c1352bf6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7bef1060e26dc38a0cc9846d2e1b680f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7bef1060e26dc38a0cc9846d2e1b680f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7bef1060e26dc38a0cc9846d2e1b680f = L.map(
#                 &quot;map_7bef1060e26dc38a0cc9846d2e1b680f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_070eb0f45ddbd2790dd4f2d7d20aec6a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_070eb0f45ddbd2790dd4f2d7d20aec6a.addTo(map_7bef1060e26dc38a0cc9846d2e1b680f);
#
#
#             var feature_group_9fdc262b03b5390cec97b82cefb6d2bd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_17d796bada6ee48c9e5d5bf969914ffc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9fdc262b03b5390cec97b82cefb6d2bd);
#
#
#         var popup_d16144d6bbac152a7ce785d5a66f55b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f942a2cb79d98aa4681fd1862a5e4cd = $(`&lt;div id=&quot;html_2f942a2cb79d98aa4681fd1862a5e4cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d16144d6bbac152a7ce785d5a66f55b8.setContent(html_2f942a2cb79d98aa4681fd1862a5e4cd);
#
#
#
#         marker_17d796bada6ee48c9e5d5bf969914ffc.bindPopup(popup_d16144d6bbac152a7ce785d5a66f55b8)
#         ;
#
#
#
#
#             var marker_d00bccc28c939b69c9d3fa319cab7a44 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9fdc262b03b5390cec97b82cefb6d2bd);
#
#
#         var popup_eba25764535a372225b188b6e98aaa53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc1531567d024dac6e58023b546626e3 = $(`&lt;div id=&quot;html_cc1531567d024dac6e58023b546626e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_eba25764535a372225b188b6e98aaa53.setContent(html_cc1531567d024dac6e58023b546626e3);
#
#
#
#         marker_d00bccc28c939b69c9d3fa319cab7a44.bindPopup(popup_eba25764535a372225b188b6e98aaa53)
#         ;
#
#
#
#
#             var marker_f00c65fd9522f1c65148bebe2ab275bd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9fdc262b03b5390cec97b82cefb6d2bd);
#
#
#         var popup_87cbcac574f02245e520eaed3cba8d74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd764b6642929afec1a4eb092752d732 = $(`&lt;div id=&quot;html_fd764b6642929afec1a4eb092752d732&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_87cbcac574f02245e520eaed3cba8d74.setContent(html_fd764b6642929afec1a4eb092752d732);
#
#
#
#         marker_f00c65fd9522f1c65148bebe2ab275bd.bindPopup(popup_87cbcac574f02245e520eaed3cba8d74)
#         ;
#
#
#
#
#             var marker_f395db02e5bb364e228d9d123759b693 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9fdc262b03b5390cec97b82cefb6d2bd);
#
#
#         var popup_226f87e27897ed87e3cb2cf85d94c7b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_778773db29733183f3b543e40fac98e7 = $(`&lt;div id=&quot;html_778773db29733183f3b543e40fac98e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_226f87e27897ed87e3cb2cf85d94c7b3.setContent(html_778773db29733183f3b543e40fac98e7);
#
#
#
#         marker_f395db02e5bb364e228d9d123759b693.bindPopup(popup_226f87e27897ed87e3cb2cf85d94c7b3)
#         ;
#
#
#
#
#             var marker_55c078043baab812985046c3804f96db = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9fdc262b03b5390cec97b82cefb6d2bd);
#
#
#         var popup_afe39cdfba591316b35a75009e14fe14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4becb35aa6527a38f6c912a16029f62a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4becb35aa6527a38f6c912a16029f62a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4becb35aa6527a38f6c912a16029f62a = L.map(
#                 &quot;map_4becb35aa6527a38f6c912a16029f62a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_754c23ac0a69e2873d8e5541dab792db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_754c23ac0a69e2873d8e5541dab792db.addTo(map_4becb35aa6527a38f6c912a16029f62a);
#
#
#             var feature_group_150e03fc81ab2568111276bbd6e5f134 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_150e03fc81ab2568111276bbd6e5f134.addTo(map_4becb35aa6527a38f6c912a16029f62a);
#
#
#             var feature_group_sub_group_02c3e5b0da61248c3b68f79ff5754654 = L.featureGroup.subGroup(
#                 feature_group_150e03fc81ab2568111276bbd6e5f134
#             );
#
#
#             var marker_99822cd0e9255bd31db8c839ca7a3cc8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_02c3e5b0da61248c3b68f79ff5754654);
#
#
#         var popup_c0847b35bb053a1a76aee29f7a1ebb78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a5ddfbc67a6209e6e5c4298172a6275 = $(`&lt;div id=&quot;html_8a5ddfbc67a6209e6e5c4298172a6275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c0847b35bb053a1a76aee29f7a1ebb78.setContent(html_8a5ddfbc67a6209e6e5c4298172a6275);
#
#
#
#         marker_99822cd0e9255bd31db8c839ca7a3cc8.bindPopup(popup_c0847b35bb053a1a76aee29f7a1ebb78)
#         ;
#
#
#
#
#             var marker_4dddc077cbdb760cfaadafd57a9787fa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_02c3e5b0da61248c3b68f79ff5754654);
#
#
#         var popup_a7db60efbdd671e72b7430e39e90700d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f08e9b5048a159213136d355dc5ece9 = $(`&lt;div id=&quot;html_2f08e9b5048a159213136d355dc5ece9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a7db60efbdd671e72b7430e39e90700d.setContent(html_2f08e9b5048a159213136d355dc5ece9);
#
#
#
#         marker_4dddc077cbdb760cfaadafd57a9787fa.bindPopup(popup_a7db60efbdd671e72b7430e39e90700d)
#         ;
#
#
#
#
#             var marker_2e666238ae644e4fff83f8e74c41d7ca = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_02c3e5b0da61248c3b68f79ff5754654);
#
#
#         var popup_bb5bc5970e84f3f8ca54693afee8ddc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_523d1e57f2d5b4d36f0fbf2342c1b6e9 = $(`&lt;div id=&quot;html_523d1e57f2d5b4d36f0fbf2342c1b6e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bb5bc5970e84f3f8ca54693afee8ddc1.setContent(html_523d1e57f2d5b4d36f0fbf2342c1b6e9);
#
#
#
#         marker_2e666238ae644e4fff83f8e74c41d7ca.bindPopup(popup_bb5bc5970e84f3f8ca54693afee8ddc1)
#         ;
#
#
#
#
#             var marker_fb77131b3d560e34090485f70e32ce13 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_02c3e5b0da61248c3b68f79ff5754654);
#
#
#         var popup_2e46b243dd21c1144be331d187988ebd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5d4e48fad555d44b4f7bd2305615a0b = $(`&lt;div id=&quot;html_f5d4e48fad555d44b4f7bd2305615a0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2e46b243dd21c1144be331d187988ebd.setContent(html_f5d4e48fad555d44b4f7bd2305615a0b);
#
#
#
#         marker_
