# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b50db8c9d79a880fd32725e2e2e9180 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b50db8c9d79a880fd32725e2e2e9180&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b50db8c9d79a880fd32725e2e2e9180 = L.map(
#                 &quot;map_3b50db8c9d79a880fd32725e2e2e9180&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f419f972a56fe85710ecf573756bce8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2f419f972a56fe85710ecf573756bce8.addTo(map_3b50db8c9d79a880fd32725e2e2e9180);
#
#
#             var marker_831139a090c46a25a5ac05ba48266bf3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3b50db8c9d79a880fd32725e2e2e9180);
#
#
#         var popup_b9f16c1549a439f9d6fe91d53c76273c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c66f38d51aef8df3d7500070f9ca9517 = $(`&lt;div id=&quot;html_c66f38d51aef8df3d7500070f9ca9517&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b9f16c1549a439f9d6fe91d53c76273c.setContent(html_c66f38d51aef8df3d7500070f9ca9517);
#
#
#
#         marker_831139a090c46a25a5ac05ba48266bf3.bindPopup(popup_b9f16c1549a439f9d6fe91d53c76273c)
#         ;
#
#
#
#
#             var marker_56c651d15b446e1c8027569a35e46666 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3b50db8c9d79a880fd32725e2e2e9180);
#
#
#         var popup_8c5b1252c8ee94303b1cac1138abf2cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe2b89f7ba11dcb51b3344b28d4d388e = $(`&lt;div id=&quot;html_fe2b89f7ba11dcb51b3344b28d4d388e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8c5b1252c8ee94303b1cac1138abf2cc.setContent(html_fe2b89f7ba11dcb51b3344b28d4d388e);
#
#
#
#         marker_56c651d15b446e1c8027569a35e46666.bindPopup(popup_8c5b1252c8ee94303b1cac1138abf2cc)
#         ;
#
#
#
#
#             var marker_601ccc93e3eddf5826fe4555b439a47c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3b50db8c9d79a880fd32725e2e2e9180);
#
#
#         var popup_cda2a1caac53799bee1036b79de84ae6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c98cc394cd5b1d731b63a4160c7cb3e5 = $(`&lt;div id=&quot;html_c98cc394cd5b1d731b63a4160c7cb3e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cda2a1caac53799bee1036b79de84ae6.setContent(html_c98cc394cd5b1d731b63a4160c7cb3e5);
#
#
#
#         marker_601ccc93e3eddf5826fe4555b439a47c.bindPopup(popup_cda2a1caac53799bee1036b79de84ae6)
#         ;
#
#
#
#
#             var marker_449615e2462b2ea5265931c2bb2368a6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3b50db8c9d79a880fd32725e2e2e9180);
#
#
#         var popup_2b8bc3e28b3b18f59b1f9c38e03484f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61e8b2bfd74d256bf9f7b798b8a6f59b = $(`&lt;div id=&quot;html_61e8b2bfd74d256bf9f7b798b8a6f59b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2b8bc3e28b3b18f59b1f9c38e03484f9.setContent(html_61e8b2bfd74d256bf9f7b798b8a6f59b);
#
#
#
#         marker_449615e2462b2ea5265931c2bb2368a6.bindPopup(popup_2b8bc3e28b3b18f59b1f9c38e03484f9)
#         ;
#
#
#
#
#             var marker_ab5754df901b097925ceea9bb4138b8f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3b50db8c9d79a880fd32725e2e2e9180);
#
#
#         var popup_3700f4a9ea58d627de55adb27b14db97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10ce4e0735147ab135ccb8aa4cffabe1 = $(`&lt;div id=&quot;html_10ce4e0735147ab135ccb8aa4cffabe1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3700f4a9ea58d627de55adb27b14db97.setContent(html_10ce4e0735147ab135ccb8aa4cffabe1);
#
#
#
#         marker_ab5754df901b097925ceea9bb4138b8f.bindPopup(popup_3700f4a9ea58d627de55adb27b14db97)
#         ;
#
#
#
#
#             var marker_3cecfa62f3

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcf3e78b97203b40519d6c77fdd6f228 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcf3e78b97203b40519d6c77fdd6f228&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcf3e78b97203b40519d6c77fdd6f228 = L.map(
#                 &quot;map_bcf3e78b97203b40519d6c77fdd6f228&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ed496a108757e2da4ee7ed2300c8303 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ed496a108757e2da4ee7ed2300c8303.addTo(map_bcf3e78b97203b40519d6c77fdd6f228);
#
#
#             var feature_group_23204ea26c43cd12627520afa5e7ce0b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d6a2f1a2e3b92a80902f2272fc5386a1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_23204ea26c43cd12627520afa5e7ce0b);
#
#
#         var popup_63e4a5903689c721c9430455cdacfc20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_770a61f70b82f27ea6d83ddf5b0672d3 = $(`&lt;div id=&quot;html_770a61f70b82f27ea6d83ddf5b0672d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_63e4a5903689c721c9430455cdacfc20.setContent(html_770a61f70b82f27ea6d83ddf5b0672d3);
#
#
#
#         marker_d6a2f1a2e3b92a80902f2272fc5386a1.bindPopup(popup_63e4a5903689c721c9430455cdacfc20)
#         ;
#
#
#
#
#             var marker_b4d409412f85e91d68df6a76973ad3e4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_23204ea26c43cd12627520afa5e7ce0b);
#
#
#         var popup_bff2b1617636a867b8b82f4d64d6692e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57ad1cab75be801d1bc0cce6c21afae6 = $(`&lt;div id=&quot;html_57ad1cab75be801d1bc0cce6c21afae6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bff2b1617636a867b8b82f4d64d6692e.setContent(html_57ad1cab75be801d1bc0cce6c21afae6);
#
#
#
#         marker_b4d409412f85e91d68df6a76973ad3e4.bindPopup(popup_bff2b1617636a867b8b82f4d64d6692e)
#         ;
#
#
#
#
#             var marker_1dc0bf696a85f41aea62ac52898a878e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_23204ea26c43cd12627520afa5e7ce0b);
#
#
#         var popup_6d35eb7595861418cd91d4ed05bd4346 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_246ddc4f08621a3a456d7a0ba702dd31 = $(`&lt;div id=&quot;html_246ddc4f08621a3a456d7a0ba702dd31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6d35eb7595861418cd91d4ed05bd4346.setContent(html_246ddc4f08621a3a456d7a0ba702dd31);
#
#
#
#         marker_1dc0bf696a85f41aea62ac52898a878e.bindPopup(popup_6d35eb7595861418cd91d4ed05bd4346)
#         ;
#
#
#
#
#             var marker_b2769ff309f75828c09dffbb3c886328 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_23204ea26c43cd12627520afa5e7ce0b);
#
#
#         var popup_7ad027e24330e9856c2c1c2ed2012fab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e62fd03fd4d0db0f0a71790b0f975314 = $(`&lt;div id=&quot;html_e62fd03fd4d0db0f0a71790b0f975314&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7ad027e24330e9856c2c1c2ed2012fab.setContent(html_e62fd03fd4d0db0f0a71790b0f975314);
#
#
#
#         marker_b2769ff309f75828c09dffbb3c886328.bindPopup(popup_7ad027e24330e9856c2c1c2ed2012fab)
#         ;
#
#
#
#
#             var marker_9a7ae1f8ee93e1e4a8bb2d9f3399b2d9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_23204ea26c43cd12627520afa5e7ce0b);
#
#
#         var popup_68fc295e22d8b69d2bc43d8780079fa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_996a29ac63506563588d8d1acb1f2ae4 = $(`&lt;div id=&quot;html_996a29ac63506563588d8d1acb1f2ae4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_68fc295e22d8b69d2b

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9de668e6d3343a601652c8ec807f9b9d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9de668e6d3343a601652c8ec807f9b9d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9de668e6d3343a601652c8ec807f9b9d = L.map(
#                 &quot;map_9de668e6d3343a601652c8ec807f9b9d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0ba21d41f3208a86a5da718230c85c0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0ba21d41f3208a86a5da718230c85c0.addTo(map_9de668e6d3343a601652c8ec807f9b9d);
#
#
#             var feature_group_ce51ababd412d16a32140c19c1b71753 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ce51ababd412d16a32140c19c1b71753.addTo(map_9de668e6d3343a601652c8ec807f9b9d);
#
#
#             var feature_group_sub_group_68a8549574ed9ec9f619dbeafc2aa4a5 = L.featureGroup.subGroup(
#                 feature_group_ce51ababd412d16a32140c19c1b71753
#             );
#
#
#             var marker_ca094b71d9f379f111672645d47ab9ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_68a8549574ed9ec9f619dbeafc2aa4a5);
#
#
#         var popup_a7a0bdc9c062a5355276f88db116319a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6495b8231649e2635d33e1aa0555430c = $(`&lt;div id=&quot;html_6495b8231649e2635d33e1aa0555430c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a7a0bdc9c062a5355276f88db116319a.setContent(html_6495b8231649e2635d33e1aa0555430c);
#
#
#
#         marker_ca094b71d9f379f111672645d47ab9ff.bindPopup(popup_a7a0bdc9c062a5355276f88db116319a)
#         ;
#
#
#
#
#             var marker_a23e4ba331b54b39bc16f990583052b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_68a8549574ed9ec9f619dbeafc2aa4a5);
#
#
#         var popup_f65527454dffed5ba37d3264f9856026 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01c78725a97f9da67b9786eecf54300c = $(`&lt;div id=&quot;html_01c78725a97f9da67b9786eecf54300c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f65527454dffed5ba37d3264f9856026.setContent(html_01c78725a97f9da67b9786eecf54300c);
#
#
#
#         marker_a23e4ba331b54b39bc16f990583052b9.bindPopup(popup_f65527454dffed5ba37d3264f9856026)
#         ;
#
#
#
#
#             var marker_ac418d47a0eb0527093e5865f5c64c9d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_68a8549574ed9ec9f619dbeafc2aa4a5);
#
#
#         var popup_1bdbc42ae9ed09510cb1c34ecbe0bbab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0394dc1cd76219bfd2bf4f455cc1905a = $(`&lt;div id=&quot;html_0394dc1cd76219bfd2bf4f455cc1905a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1bdbc42ae9ed09510cb1c34ecbe0bbab.setContent(html_0394dc1cd76219bfd2bf4f455cc1905a);
#
#
#
#         marker_ac418d47a0eb0527093e5865f5c64c9d.bindPopup(popup_1bdbc42ae9ed09510cb1c34ecbe0bbab)
#         ;
#
#
#
#
#             var marker_aa8dcba4e2c6b62c065f461402653743 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_68a8549574ed9ec9f619dbeafc2aa4a5);
#
#
#         var popup_92e89352c8b6444eef22f9dbbf00a4c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5387f972535d90c2355c688628e89e0e = $(`&lt;div id=&quot;html_5387f972535d90c2355c688628e89e0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_92e89352c8b6444eef22f9dbbf00a4c3.setContent(html_5387f972535d90c2355c688628e89e0e);
#
#
#
#         marker_aa8dcba4e2c6b62c065f461402653743.bindPopup(popup_92e89352c8b6444eef22f9dbbf00a4c3)
#         ;
#
#
#
#
#             var marker_fa093b9935e09ff323264d3e6cc30457 = L.marker(
#                 [45.050399999999996, 3.0504],
