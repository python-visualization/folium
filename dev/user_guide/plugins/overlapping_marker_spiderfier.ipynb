# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5225ffc00ff58ad9edd9526cd50943d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5225ffc00ff58ad9edd9526cd50943d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5225ffc00ff58ad9edd9526cd50943d = L.map(
#                 &quot;map_a5225ffc00ff58ad9edd9526cd50943d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1dcd282e77986322bc24d327d677768b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1dcd282e77986322bc24d327d677768b.addTo(map_a5225ffc00ff58ad9edd9526cd50943d);
#
#
#             var marker_373665e8d45a7eb20a75a60c8421eb75 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a5225ffc00ff58ad9edd9526cd50943d);
#
#
#         var popup_849b5698d350e24ca674ace47143fab6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80f0394f01f94dbbbd6b82e829267da9 = $(`&lt;div id=&quot;html_80f0394f01f94dbbbd6b82e829267da9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_849b5698d350e24ca674ace47143fab6.setContent(html_80f0394f01f94dbbbd6b82e829267da9);
#
#
#
#         marker_373665e8d45a7eb20a75a60c8421eb75.bindPopup(popup_849b5698d350e24ca674ace47143fab6)
#         ;
#
#
#
#
#             var marker_3346f11bca7da982495d2c2801e1ecfd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a5225ffc00ff58ad9edd9526cd50943d);
#
#
#         var popup_ef89c909e0bc97f4e4705c8bfc91a4a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c00ecca6e2452ddfeec962c2f187018 = $(`&lt;div id=&quot;html_6c00ecca6e2452ddfeec962c2f187018&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ef89c909e0bc97f4e4705c8bfc91a4a9.setContent(html_6c00ecca6e2452ddfeec962c2f187018);
#
#
#
#         marker_3346f11bca7da982495d2c2801e1ecfd.bindPopup(popup_ef89c909e0bc97f4e4705c8bfc91a4a9)
#         ;
#
#
#
#
#             var marker_1f9965a238d01f4db2a387cd8dc749b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a5225ffc00ff58ad9edd9526cd50943d);
#
#
#         var popup_f652c3dbef02de0a3fb8d24d581aba8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c70941018a54cd04a8099871ab345586 = $(`&lt;div id=&quot;html_c70941018a54cd04a8099871ab345586&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f652c3dbef02de0a3fb8d24d581aba8d.setContent(html_c70941018a54cd04a8099871ab345586);
#
#
#
#         marker_1f9965a238d01f4db2a387cd8dc749b6.bindPopup(popup_f652c3dbef02de0a3fb8d24d581aba8d)
#         ;
#
#
#
#
#             var marker_5538e71099e5f15f5dd4232faa9cd2f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a5225ffc00ff58ad9edd9526cd50943d);
#
#
#         var popup_ed7ef1c4513fff57380a5b62a9dcabd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_807843affc112f3d526f9db020ffe012 = $(`&lt;div id=&quot;html_807843affc112f3d526f9db020ffe012&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ed7ef1c4513fff57380a5b62a9dcabd7.setContent(html_807843affc112f3d526f9db020ffe012);
#
#
#
#         marker_5538e71099e5f15f5dd4232faa9cd2f4.bindPopup(popup_ed7ef1c4513fff57380a5b62a9dcabd7)
#         ;
#
#
#
#
#             var marker_3e0cc3c2bc8c5019446a6c11803113ac = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a5225ffc00ff58ad9edd9526cd50943d);
#
#
#         var popup_7647e2d89b0fffc536b13068ae2c5c95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b190a691ad920001a5a81201af2c9c9d = $(`&lt;div id=&quot;html_b190a691ad920001a5a81201af2c9c9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7647e2d89b0fffc536b13068ae2c5c95.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57242c84d1b4498bc9788680c002060c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57242c84d1b4498bc9788680c002060c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57242c84d1b4498bc9788680c002060c = L.map(
#                 &quot;map_57242c84d1b4498bc9788680c002060c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ac46aface81d0a1581c5b01166323a7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ac46aface81d0a1581c5b01166323a7.addTo(map_57242c84d1b4498bc9788680c002060c);
#
#
#             var feature_group_ecda55ebd7aec0c04d1628c9a8c4a2e2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0dd9016dc31276e8c89c44ace67c7764 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ecda55ebd7aec0c04d1628c9a8c4a2e2);
#
#
#         var popup_cc9dc65ad654ae268e165b86ac4836f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_397820d8fa0c3a3db958baeef480eccc = $(`&lt;div id=&quot;html_397820d8fa0c3a3db958baeef480eccc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cc9dc65ad654ae268e165b86ac4836f7.setContent(html_397820d8fa0c3a3db958baeef480eccc);
#
#
#
#         marker_0dd9016dc31276e8c89c44ace67c7764.bindPopup(popup_cc9dc65ad654ae268e165b86ac4836f7)
#         ;
#
#
#
#
#             var marker_9e8809e0809b9f3e0d87001e11633f62 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ecda55ebd7aec0c04d1628c9a8c4a2e2);
#
#
#         var popup_54614f61e87060e27b6c6e20cd969459 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_666556d74b73aa26241ee6022b48789f = $(`&lt;div id=&quot;html_666556d74b73aa26241ee6022b48789f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_54614f61e87060e27b6c6e20cd969459.setContent(html_666556d74b73aa26241ee6022b48789f);
#
#
#
#         marker_9e8809e0809b9f3e0d87001e11633f62.bindPopup(popup_54614f61e87060e27b6c6e20cd969459)
#         ;
#
#
#
#
#             var marker_a9d0c65228e973fe72c9c323bd914ea3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ecda55ebd7aec0c04d1628c9a8c4a2e2);
#
#
#         var popup_27da6d79bb4813ab466da8990fae4047 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_539658c04e3c35c21db764c13220a00e = $(`&lt;div id=&quot;html_539658c04e3c35c21db764c13220a00e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_27da6d79bb4813ab466da8990fae4047.setContent(html_539658c04e3c35c21db764c13220a00e);
#
#
#
#         marker_a9d0c65228e973fe72c9c323bd914ea3.bindPopup(popup_27da6d79bb4813ab466da8990fae4047)
#         ;
#
#
#
#
#             var marker_c9cc0fae85c460f10a21862aeffbf5ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ecda55ebd7aec0c04d1628c9a8c4a2e2);
#
#
#         var popup_a6db1016a49902ced2cbf96558422f3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43f9717866d3979e841275ad11cf62f3 = $(`&lt;div id=&quot;html_43f9717866d3979e841275ad11cf62f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a6db1016a49902ced2cbf96558422f3d.setContent(html_43f9717866d3979e841275ad11cf62f3);
#
#
#
#         marker_c9cc0fae85c460f10a21862aeffbf5ac.bindPopup(popup_a6db1016a49902ced2cbf96558422f3d)
#         ;
#
#
#
#
#             var marker_50e4b3990946261506b0ed7b5f2534ba = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ecda55ebd7aec0c04d1628c9a8c4a2e2);
#
#
#         var popup_6f26a5f5143927142db066f8953bc567 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa0c8e219cb3d28566dc150f10d04faf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa0c8e219cb3d28566dc150f10d04faf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa0c8e219cb3d28566dc150f10d04faf = L.map(
#                 &quot;map_aa0c8e219cb3d28566dc150f10d04faf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c0d9c782a7ecaf6d43b76bf774f4f46 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c0d9c782a7ecaf6d43b76bf774f4f46.addTo(map_aa0c8e219cb3d28566dc150f10d04faf);
#
#
#             var feature_group_57b7d9076117898b0650c304a348a089 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_57b7d9076117898b0650c304a348a089.addTo(map_aa0c8e219cb3d28566dc150f10d04faf);
#
#
#             var feature_group_sub_group_8904676c2bce1d290d065973577df57e = L.featureGroup.subGroup(
#                 feature_group_57b7d9076117898b0650c304a348a089
#             );
#
#
#             var marker_c1d461632c7b8f8c028475d595349a59 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8904676c2bce1d290d065973577df57e);
#
#
#         var popup_7df498ab8e1280b7ad78a70ab31d8333 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a795a9ced0eb22818ed896c2ac0d831d = $(`&lt;div id=&quot;html_a795a9ced0eb22818ed896c2ac0d831d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7df498ab8e1280b7ad78a70ab31d8333.setContent(html_a795a9ced0eb22818ed896c2ac0d831d);
#
#
#
#         marker_c1d461632c7b8f8c028475d595349a59.bindPopup(popup_7df498ab8e1280b7ad78a70ab31d8333)
#         ;
#
#
#
#
#             var marker_be2cf7e0b4d70a8d20e0bec15ba12a5b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8904676c2bce1d290d065973577df57e);
#
#
#         var popup_9c5d92874c6eb508522181751f72553e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bbadc54c8000d77a2b7af5aa39ab198 = $(`&lt;div id=&quot;html_9bbadc54c8000d77a2b7af5aa39ab198&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9c5d92874c6eb508522181751f72553e.setContent(html_9bbadc54c8000d77a2b7af5aa39ab198);
#
#
#
#         marker_be2cf7e0b4d70a8d20e0bec15ba12a5b.bindPopup(popup_9c5d92874c6eb508522181751f72553e)
#         ;
#
#
#
#
#             var marker_5c0dc5919622c39aa8a2e8b6e4753ac4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8904676c2bce1d290d065973577df57e);
#
#
#         var popup_b7f78c0e50674e40c627d40ba7ed8e24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8e82fa18d8c876dd6b2641523fc823e = $(`&lt;div id=&quot;html_e8e82fa18d8c876dd6b2641523fc823e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b7f78c0e50674e40c627d40ba7ed8e24.setContent(html_e8e82fa18d8c876dd6b2641523fc823e);
#
#
#
#         marker_5c0dc5919622c39aa8a2e8b6e4753ac4.bindPopup(popup_b7f78c0e50674e40c627d40ba7ed8e24)
#         ;
#
#
#
#
#             var marker_cbac3c23884220dc79d0166e659a05b1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8904676c2bce1d290d065973577df57e);
#
#
#         var popup_aa2d9bb63829b97339f87c04a2ebe702 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e65f54cf0cb9ad50cda8a0c284665c54 = $(`&lt;div id=&quot;html_e65f54cf0cb9ad50cda8a0c284665c54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_aa2d9bb63829b97339f87c04a2ebe702.setContent(html_e65f54cf0cb9ad50cda8a0c284665c54);
#
#
#
#         marker_
