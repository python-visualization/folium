# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d14ea54405a120ded389609450ab5652 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d14ea54405a120ded389609450ab5652&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d14ea54405a120ded389609450ab5652 = L.map(
#                 &quot;map_d14ea54405a120ded389609450ab5652&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4c1de674aa35cba12666d4f7246d1a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4c1de674aa35cba12666d4f7246d1a3.addTo(map_d14ea54405a120ded389609450ab5652);
#
#
#             var marker_f2f2acb5af6d103323e80e5c17c44c20 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d14ea54405a120ded389609450ab5652);
#
#
#         var popup_fbcf43b498f4424435fbfdb2b5d8328a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_009e24b8198215005a00bb79f4ffae9f = $(`&lt;div id=&quot;html_009e24b8198215005a00bb79f4ffae9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fbcf43b498f4424435fbfdb2b5d8328a.setContent(html_009e24b8198215005a00bb79f4ffae9f);
#
#
#
#         marker_f2f2acb5af6d103323e80e5c17c44c20.bindPopup(popup_fbcf43b498f4424435fbfdb2b5d8328a)
#         ;
#
#
#
#
#             var marker_3fc0ecd2fa2a47825688f9efe1784c72 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d14ea54405a120ded389609450ab5652);
#
#
#         var popup_4e7bba344c378bd2b945f5118da0e860 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f7565a277b19d6924c8541b54f31d5e = $(`&lt;div id=&quot;html_6f7565a277b19d6924c8541b54f31d5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4e7bba344c378bd2b945f5118da0e860.setContent(html_6f7565a277b19d6924c8541b54f31d5e);
#
#
#
#         marker_3fc0ecd2fa2a47825688f9efe1784c72.bindPopup(popup_4e7bba344c378bd2b945f5118da0e860)
#         ;
#
#
#
#
#             var marker_88b12185676744dd5dadc61184145994 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d14ea54405a120ded389609450ab5652);
#
#
#         var popup_6cbe711b63b63e889c8db384658b8586 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cda7a861ce064216706765919b000b1 = $(`&lt;div id=&quot;html_4cda7a861ce064216706765919b000b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6cbe711b63b63e889c8db384658b8586.setContent(html_4cda7a861ce064216706765919b000b1);
#
#
#
#         marker_88b12185676744dd5dadc61184145994.bindPopup(popup_6cbe711b63b63e889c8db384658b8586)
#         ;
#
#
#
#
#             var marker_1fcbd3483033e7af6ea9396c9f3cdf22 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d14ea54405a120ded389609450ab5652);
#
#
#         var popup_ffabd65640f7656281bb3a96a94e38aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f13fc554c87a87a05eecef239955d95 = $(`&lt;div id=&quot;html_9f13fc554c87a87a05eecef239955d95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ffabd65640f7656281bb3a96a94e38aa.setContent(html_9f13fc554c87a87a05eecef239955d95);
#
#
#
#         marker_1fcbd3483033e7af6ea9396c9f3cdf22.bindPopup(popup_ffabd65640f7656281bb3a96a94e38aa)
#         ;
#
#
#
#
#             var marker_acfe142d11a8862ee34c43c38d55d1a6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d14ea54405a120ded389609450ab5652);
#
#
#         var popup_7e396dc625d609785642ae655d55f996 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86d03b097715ed3fc6a79a2a6e90abaa = $(`&lt;div id=&quot;html_86d03b097715ed3fc6a79a2a6e90abaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7e396dc625d609785642ae655d55f9

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fff3efe0df3e5c433d5d316d16c5f702 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fff3efe0df3e5c433d5d316d16c5f702&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fff3efe0df3e5c433d5d316d16c5f702 = L.map(
#                 &quot;map_fff3efe0df3e5c433d5d316d16c5f702&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77b9cf71ffa6f9f810baf55baefe6875 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77b9cf71ffa6f9f810baf55baefe6875.addTo(map_fff3efe0df3e5c433d5d316d16c5f702);
#
#
#             var feature_group_c36f94c37c14e114fd7d9ed9b3805b8f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bd69c36990fedd81be26d64298e9274c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c36f94c37c14e114fd7d9ed9b3805b8f);
#
#
#         var popup_d412c06e7f9d81e7962334ae05423c05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5b8f959173c265f977c399e8aab4e2d = $(`&lt;div id=&quot;html_a5b8f959173c265f977c399e8aab4e2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d412c06e7f9d81e7962334ae05423c05.setContent(html_a5b8f959173c265f977c399e8aab4e2d);
#
#
#
#         marker_bd69c36990fedd81be26d64298e9274c.bindPopup(popup_d412c06e7f9d81e7962334ae05423c05)
#         ;
#
#
#
#
#             var marker_92093478072226089a2836e4842c7f0b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c36f94c37c14e114fd7d9ed9b3805b8f);
#
#
#         var popup_65f4f58bdb3b6415249018f42fd5b469 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae187574761245812ffbb34acabc1df3 = $(`&lt;div id=&quot;html_ae187574761245812ffbb34acabc1df3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_65f4f58bdb3b6415249018f42fd5b469.setContent(html_ae187574761245812ffbb34acabc1df3);
#
#
#
#         marker_92093478072226089a2836e4842c7f0b.bindPopup(popup_65f4f58bdb3b6415249018f42fd5b469)
#         ;
#
#
#
#
#             var marker_91746fc0ee8d15ee922a5876146309e1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c36f94c37c14e114fd7d9ed9b3805b8f);
#
#
#         var popup_f2bed5819d0b9f1e0664a8399af1a53f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2696e8d6e489f620b3344c4d4041c445 = $(`&lt;div id=&quot;html_2696e8d6e489f620b3344c4d4041c445&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f2bed5819d0b9f1e0664a8399af1a53f.setContent(html_2696e8d6e489f620b3344c4d4041c445);
#
#
#
#         marker_91746fc0ee8d15ee922a5876146309e1.bindPopup(popup_f2bed5819d0b9f1e0664a8399af1a53f)
#         ;
#
#
#
#
#             var marker_92c184e915762abd90eaa386972020c1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c36f94c37c14e114fd7d9ed9b3805b8f);
#
#
#         var popup_db919162399d97b8baf6a829f04440b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_177ed2538c51610849b781e357b61e52 = $(`&lt;div id=&quot;html_177ed2538c51610849b781e357b61e52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_db919162399d97b8baf6a829f04440b5.setContent(html_177ed2538c51610849b781e357b61e52);
#
#
#
#         marker_92c184e915762abd90eaa386972020c1.bindPopup(popup_db919162399d97b8baf6a829f04440b5)
#         ;
#
#
#
#
#             var marker_67ec4f58fed7d8f55b13ff77c28874c2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c36f94c37c14e114fd7d9ed9b3805b8f);
#
#
#         var popup_862c6fb7f8d4f92c356910ae0981e0a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_affc7d9f113c49b32361ebc9364009ea {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_affc7d9f113c49b32361ebc9364009ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_affc7d9f113c49b32361ebc9364009ea = L.map(
#                 &quot;map_affc7d9f113c49b32361ebc9364009ea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ed7cf0f5849f2d868f0ffd14bddf777 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ed7cf0f5849f2d868f0ffd14bddf777.addTo(map_affc7d9f113c49b32361ebc9364009ea);
#
#
#             var feature_group_6b7ff29b8767051bfd00439310bd3006 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6b7ff29b8767051bfd00439310bd3006.addTo(map_affc7d9f113c49b32361ebc9364009ea);
#
#
#             var feature_group_sub_group_4d3d84b35bb1891bda2ebca10dfd1bd7 = L.featureGroup.subGroup(
#                 feature_group_6b7ff29b8767051bfd00439310bd3006
#             );
#
#
#             var marker_0f00beef957ced12b3c99caf62adb99e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4d3d84b35bb1891bda2ebca10dfd1bd7);
#
#
#         var popup_bfb135361e037ad1a70cd482c73118b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f9cc53d65b9392142a475247c74f0be = $(`&lt;div id=&quot;html_1f9cc53d65b9392142a475247c74f0be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bfb135361e037ad1a70cd482c73118b8.setContent(html_1f9cc53d65b9392142a475247c74f0be);
#
#
#
#         marker_0f00beef957ced12b3c99caf62adb99e.bindPopup(popup_bfb135361e037ad1a70cd482c73118b8)
#         ;
#
#
#
#
#             var marker_875d46d184877200c095222a85121ed8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4d3d84b35bb1891bda2ebca10dfd1bd7);
#
#
#         var popup_de6926f4480013da5afe1a9bf704f42b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef96a728f3eb647a1f5d13faeec5489d = $(`&lt;div id=&quot;html_ef96a728f3eb647a1f5d13faeec5489d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_de6926f4480013da5afe1a9bf704f42b.setContent(html_ef96a728f3eb647a1f5d13faeec5489d);
#
#
#
#         marker_875d46d184877200c095222a85121ed8.bindPopup(popup_de6926f4480013da5afe1a9bf704f42b)
#         ;
#
#
#
#
#             var marker_fb99aa8486be0c3a55ba80e5af4fe43f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4d3d84b35bb1891bda2ebca10dfd1bd7);
#
#
#         var popup_99e640ef95bac6c65e2c2a6e68925139 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cc55903176f4a7a01e437cbc8a9d755 = $(`&lt;div id=&quot;html_3cc55903176f4a7a01e437cbc8a9d755&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_99e640ef95bac6c65e2c2a6e68925139.setContent(html_3cc55903176f4a7a01e437cbc8a9d755);
#
#
#
#         marker_fb99aa8486be0c3a55ba80e5af4fe43f.bindPopup(popup_99e640ef95bac6c65e2c2a6e68925139)
#         ;
#
#
#
#
#             var marker_70b4d7d60c53f0a94750de68cab4f594 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4d3d84b35bb1891bda2ebca10dfd1bd7);
#
#
#         var popup_b0b2f2dedea52963ede811152534af33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e5ed274e3d99445872c7675953cb69f = $(`&lt;div id=&quot;html_1e5ed274e3d99445872c7675953cb69f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b0b2f2dedea52963ede811152534af33.setContent(html_1e5ed274e3d99445872c7675953cb69f);
#
#
#
#         mark
