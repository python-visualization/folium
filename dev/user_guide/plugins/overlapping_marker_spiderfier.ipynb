# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_55f9a3947ca0f2c0d276eabeeaf73898 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_55f9a3947ca0f2c0d276eabeeaf73898&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_55f9a3947ca0f2c0d276eabeeaf73898 = L.map(
#                 &quot;map_55f9a3947ca0f2c0d276eabeeaf73898&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a0912ce520f0bdb0a1a71b7abf6a684 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1a0912ce520f0bdb0a1a71b7abf6a684.addTo(map_55f9a3947ca0f2c0d276eabeeaf73898);
#
#
#             var marker_3cb483b93ca0f4ef7802fec754a87a40 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_55f9a3947ca0f2c0d276eabeeaf73898);
#
#
#         var popup_da41c433ccb88b1e6b83795a64f2e85b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90e4e697d870430a95527263794dac02 = $(`&lt;div id=&quot;html_90e4e697d870430a95527263794dac02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_da41c433ccb88b1e6b83795a64f2e85b.setContent(html_90e4e697d870430a95527263794dac02);
#
#
#
#         marker_3cb483b93ca0f4ef7802fec754a87a40.bindPopup(popup_da41c433ccb88b1e6b83795a64f2e85b)
#         ;
#
#
#
#
#             var marker_516ba05591ee834fd63c2b14a319e42f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_55f9a3947ca0f2c0d276eabeeaf73898);
#
#
#         var popup_6f08e1c32a53c663a4b13e05f39ab287 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef9cd4907c90bdad1765e06847179780 = $(`&lt;div id=&quot;html_ef9cd4907c90bdad1765e06847179780&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6f08e1c32a53c663a4b13e05f39ab287.setContent(html_ef9cd4907c90bdad1765e06847179780);
#
#
#
#         marker_516ba05591ee834fd63c2b14a319e42f.bindPopup(popup_6f08e1c32a53c663a4b13e05f39ab287)
#         ;
#
#
#
#
#             var marker_cb5a0f2be847ea956c7ca32ded858255 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_55f9a3947ca0f2c0d276eabeeaf73898);
#
#
#         var popup_9f0301cf50aeb986c40cbdea11082b28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_488df82c279e0b664de8fb9e37819176 = $(`&lt;div id=&quot;html_488df82c279e0b664de8fb9e37819176&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9f0301cf50aeb986c40cbdea11082b28.setContent(html_488df82c279e0b664de8fb9e37819176);
#
#
#
#         marker_cb5a0f2be847ea956c7ca32ded858255.bindPopup(popup_9f0301cf50aeb986c40cbdea11082b28)
#         ;
#
#
#
#
#             var marker_dd5bad68e591d37363306e6f895a2c76 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_55f9a3947ca0f2c0d276eabeeaf73898);
#
#
#         var popup_7c8ed5e77eaf260723363beff0a66e4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a6505ce88105f598246fa665ef265c9 = $(`&lt;div id=&quot;html_6a6505ce88105f598246fa665ef265c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7c8ed5e77eaf260723363beff0a66e4a.setContent(html_6a6505ce88105f598246fa665ef265c9);
#
#
#
#         marker_dd5bad68e591d37363306e6f895a2c76.bindPopup(popup_7c8ed5e77eaf260723363beff0a66e4a)
#         ;
#
#
#
#
#             var marker_b1703e37c8697e271695d5d0f087bf9f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_55f9a3947ca0f2c0d276eabeeaf73898);
#
#
#         var popup_dd2f9b8979d7bb29ba2bd931ccd46afc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac9127e33e12d5aef44fe34d1a61b736 = $(`&lt;div id=&quot;html_ac9127e33e12d5aef44fe34d1a61b736&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dd2f9b8979d7bb29ba2bd931ccd46afc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0c966de1d178466316c84d594fb66746 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0c966de1d178466316c84d594fb66746&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0c966de1d178466316c84d594fb66746 = L.map(
#                 &quot;map_0c966de1d178466316c84d594fb66746&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7fee7790c207962bc5b8e35b2e27ff76 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7fee7790c207962bc5b8e35b2e27ff76.addTo(map_0c966de1d178466316c84d594fb66746);
#
#
#             var feature_group_918bc2d40d0cd639418bcedc5f5299e8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_33b279df9b8ae1bc7e5d2f0a5f1769fc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_918bc2d40d0cd639418bcedc5f5299e8);
#
#
#         var popup_3d3b6da5ea38600bf31c14a7ef1b70d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7110861def80b1634ee34ffef10e04c = $(`&lt;div id=&quot;html_d7110861def80b1634ee34ffef10e04c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3d3b6da5ea38600bf31c14a7ef1b70d1.setContent(html_d7110861def80b1634ee34ffef10e04c);
#
#
#
#         marker_33b279df9b8ae1bc7e5d2f0a5f1769fc.bindPopup(popup_3d3b6da5ea38600bf31c14a7ef1b70d1)
#         ;
#
#
#
#
#             var marker_9fe175e6b298dcd415cf0d0e745e4e35 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_918bc2d40d0cd639418bcedc5f5299e8);
#
#
#         var popup_779dd0bfec06d0af2d840ffcab9425c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a392ba7ebae264ac1f2e37f71ba0db43 = $(`&lt;div id=&quot;html_a392ba7ebae264ac1f2e37f71ba0db43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_779dd0bfec06d0af2d840ffcab9425c5.setContent(html_a392ba7ebae264ac1f2e37f71ba0db43);
#
#
#
#         marker_9fe175e6b298dcd415cf0d0e745e4e35.bindPopup(popup_779dd0bfec06d0af2d840ffcab9425c5)
#         ;
#
#
#
#
#             var marker_1d0639693e295b4edc6dfd36d12edd45 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_918bc2d40d0cd639418bcedc5f5299e8);
#
#
#         var popup_28108994a2885c870665f7531a5540a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48f42549609106d5de48d69c90bb20a4 = $(`&lt;div id=&quot;html_48f42549609106d5de48d69c90bb20a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_28108994a2885c870665f7531a5540a4.setContent(html_48f42549609106d5de48d69c90bb20a4);
#
#
#
#         marker_1d0639693e295b4edc6dfd36d12edd45.bindPopup(popup_28108994a2885c870665f7531a5540a4)
#         ;
#
#
#
#
#             var marker_f36c6a57b63daa0d1ffc9c402d6da354 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_918bc2d40d0cd639418bcedc5f5299e8);
#
#
#         var popup_72550f4727607a7ff3cd1c864ec84786 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82feb352193fa42f8b76382e907f9af8 = $(`&lt;div id=&quot;html_82feb352193fa42f8b76382e907f9af8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_72550f4727607a7ff3cd1c864ec84786.setContent(html_82feb352193fa42f8b76382e907f9af8);
#
#
#
#         marker_f36c6a57b63daa0d1ffc9c402d6da354.bindPopup(popup_72550f4727607a7ff3cd1c864ec84786)
#         ;
#
#
#
#
#             var marker_810a4ed149129a52d6503681982a8014 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_918bc2d40d0cd639418bcedc5f5299e8);
#
#
#         var popup_c96ff2de142492558b01eccd9cf22ac7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4262039924865caa666c558aad5e5105 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4262039924865caa666c558aad5e5105&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4262039924865caa666c558aad5e5105 = L.map(
#                 &quot;map_4262039924865caa666c558aad5e5105&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_137d8ae3aaca0f9f8c3ab6eb414b4a26 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_137d8ae3aaca0f9f8c3ab6eb414b4a26.addTo(map_4262039924865caa666c558aad5e5105);
#
#
#             var feature_group_cd03bf2a09d5da1b3b7009fed351e655 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cd03bf2a09d5da1b3b7009fed351e655.addTo(map_4262039924865caa666c558aad5e5105);
#
#
#             var feature_group_sub_group_4f2db293de498dc8524694e8605c8a93 = L.featureGroup.subGroup(
#                 feature_group_cd03bf2a09d5da1b3b7009fed351e655
#             );
#
#
#             var marker_beb705fe66fb0044080fedf194945a7b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4f2db293de498dc8524694e8605c8a93);
#
#
#         var popup_3e0a2d59ff0e3f91fd0976173a308833 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec6cbeb00848c288eacb1a0cb0147cc5 = $(`&lt;div id=&quot;html_ec6cbeb00848c288eacb1a0cb0147cc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3e0a2d59ff0e3f91fd0976173a308833.setContent(html_ec6cbeb00848c288eacb1a0cb0147cc5);
#
#
#
#         marker_beb705fe66fb0044080fedf194945a7b.bindPopup(popup_3e0a2d59ff0e3f91fd0976173a308833)
#         ;
#
#
#
#
#             var marker_c8d6536241fd98753fecf9f4a994c449 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4f2db293de498dc8524694e8605c8a93);
#
#
#         var popup_15b5d0879df3faa6c08c7a832f4840f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09cf14181df6a9454263fe170b01faec = $(`&lt;div id=&quot;html_09cf14181df6a9454263fe170b01faec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_15b5d0879df3faa6c08c7a832f4840f9.setContent(html_09cf14181df6a9454263fe170b01faec);
#
#
#
#         marker_c8d6536241fd98753fecf9f4a994c449.bindPopup(popup_15b5d0879df3faa6c08c7a832f4840f9)
#         ;
#
#
#
#
#             var marker_cb6c76da4f5063592db75e1f72297f90 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4f2db293de498dc8524694e8605c8a93);
#
#
#         var popup_74eaf0564bd8adb2d45b37fbbb166484 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f7c83dda3b7fed5850f5af7526dfa31 = $(`&lt;div id=&quot;html_2f7c83dda3b7fed5850f5af7526dfa31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_74eaf0564bd8adb2d45b37fbbb166484.setContent(html_2f7c83dda3b7fed5850f5af7526dfa31);
#
#
#
#         marker_cb6c76da4f5063592db75e1f72297f90.bindPopup(popup_74eaf0564bd8adb2d45b37fbbb166484)
#         ;
#
#
#
#
#             var marker_6ce0e2ea04acedfb5935ea71c3a4586d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4f2db293de498dc8524694e8605c8a93);
#
#
#         var popup_cabc9413ce72ba1d595ea4ea83c008e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f7b70a303139881c374cb03c3c8ffb1 = $(`&lt;div id=&quot;html_7f7b70a303139881c374cb03c3c8ffb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cabc9413ce72ba1d595ea4ea83c008e4.setContent(html_7f7b70a303139881c374cb03c3c8ffb1);
#
#
#
#         marker_
