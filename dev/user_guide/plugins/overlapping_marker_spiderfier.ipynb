# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3101fdc3503db698090defee74bcb90 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3101fdc3503db698090defee74bcb90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3101fdc3503db698090defee74bcb90 = L.map(
#                 &quot;map_d3101fdc3503db698090defee74bcb90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_acb5302ce981ecfc7acbe2ef55cd2e66 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_acb5302ce981ecfc7acbe2ef55cd2e66.addTo(map_d3101fdc3503db698090defee74bcb90);
#
#
#             var marker_e2486362f088c37465b9451392c94d83 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d3101fdc3503db698090defee74bcb90);
#
#
#         var popup_bbd345e858c0c8cbe7b487b6798d936d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f12fdbdb3200c1d1e3fa9bdc795ebfc = $(`&lt;div id=&quot;html_3f12fdbdb3200c1d1e3fa9bdc795ebfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bbd345e858c0c8cbe7b487b6798d936d.setContent(html_3f12fdbdb3200c1d1e3fa9bdc795ebfc);
#
#
#
#         marker_e2486362f088c37465b9451392c94d83.bindPopup(popup_bbd345e858c0c8cbe7b487b6798d936d)
#         ;
#
#
#
#
#             var marker_baa812f969f024a3763f2e10dbbb3588 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d3101fdc3503db698090defee74bcb90);
#
#
#         var popup_c2e791f70e50e04d2d62d0ca32e31454 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2f1b3bab98e318584fa45c7fea3c82b = $(`&lt;div id=&quot;html_c2f1b3bab98e318584fa45c7fea3c82b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c2e791f70e50e04d2d62d0ca32e31454.setContent(html_c2f1b3bab98e318584fa45c7fea3c82b);
#
#
#
#         marker_baa812f969f024a3763f2e10dbbb3588.bindPopup(popup_c2e791f70e50e04d2d62d0ca32e31454)
#         ;
#
#
#
#
#             var marker_a5bda16823f96b7390acc197a2ed8541 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d3101fdc3503db698090defee74bcb90);
#
#
#         var popup_8ec8db2d4815fdacfbe1afed43abbfed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a3f0579e414051804dd195478a9563a = $(`&lt;div id=&quot;html_3a3f0579e414051804dd195478a9563a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8ec8db2d4815fdacfbe1afed43abbfed.setContent(html_3a3f0579e414051804dd195478a9563a);
#
#
#
#         marker_a5bda16823f96b7390acc197a2ed8541.bindPopup(popup_8ec8db2d4815fdacfbe1afed43abbfed)
#         ;
#
#
#
#
#             var marker_dcc92810c9bbc6d926ac3c0c46f89fa2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d3101fdc3503db698090defee74bcb90);
#
#
#         var popup_a6a7d4239196602403821b7ea507d1f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b18b4ffefd3277d8779413055261fc73 = $(`&lt;div id=&quot;html_b18b4ffefd3277d8779413055261fc73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a6a7d4239196602403821b7ea507d1f1.setContent(html_b18b4ffefd3277d8779413055261fc73);
#
#
#
#         marker_dcc92810c9bbc6d926ac3c0c46f89fa2.bindPopup(popup_a6a7d4239196602403821b7ea507d1f1)
#         ;
#
#
#
#
#             var marker_8919c599f28e0c552b5bc19a60ed72ea = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d3101fdc3503db698090defee74bcb90);
#
#
#         var popup_35a6d40d4a422869b9abfe0ac5a6189d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_399d110ffcc9f8f831e7a5bb479e052d = $(`&lt;div id=&quot;html_399d110ffcc9f8f831e7a5bb479e052d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_35a6d40d4a422869b9abfe0ac5a618

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_241b2f2597d4d07bc7964edca33945ea {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_241b2f2597d4d07bc7964edca33945ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_241b2f2597d4d07bc7964edca33945ea = L.map(
#                 &quot;map_241b2f2597d4d07bc7964edca33945ea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0bd62bd65d98eb54fb26362485d019d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0bd62bd65d98eb54fb26362485d019d3.addTo(map_241b2f2597d4d07bc7964edca33945ea);
#
#
#             var feature_group_7cd3f0235a4c012ba95eacbc989925f9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ead982b2fca7114c554660d2ff596c3a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7cd3f0235a4c012ba95eacbc989925f9);
#
#
#         var popup_630aaec0c8c1fd304433ca2dfd12c74b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4179e2f0cf6669009737aa74d82e78be = $(`&lt;div id=&quot;html_4179e2f0cf6669009737aa74d82e78be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_630aaec0c8c1fd304433ca2dfd12c74b.setContent(html_4179e2f0cf6669009737aa74d82e78be);
#
#
#
#         marker_ead982b2fca7114c554660d2ff596c3a.bindPopup(popup_630aaec0c8c1fd304433ca2dfd12c74b)
#         ;
#
#
#
#
#             var marker_435b35314cde8b2cc639eb324fbdc72b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7cd3f0235a4c012ba95eacbc989925f9);
#
#
#         var popup_652d628a1a33a1388d4145596b3d0280 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38ed6d1a8c9c7bd37184e3b4ae221a7d = $(`&lt;div id=&quot;html_38ed6d1a8c9c7bd37184e3b4ae221a7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_652d628a1a33a1388d4145596b3d0280.setContent(html_38ed6d1a8c9c7bd37184e3b4ae221a7d);
#
#
#
#         marker_435b35314cde8b2cc639eb324fbdc72b.bindPopup(popup_652d628a1a33a1388d4145596b3d0280)
#         ;
#
#
#
#
#             var marker_b27fa651b973dcada305b9f361a9c97b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7cd3f0235a4c012ba95eacbc989925f9);
#
#
#         var popup_b04281b1201d221ec2edecdf72fcab9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc0a18d7880f7e6e3977a11f9e623313 = $(`&lt;div id=&quot;html_dc0a18d7880f7e6e3977a11f9e623313&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b04281b1201d221ec2edecdf72fcab9c.setContent(html_dc0a18d7880f7e6e3977a11f9e623313);
#
#
#
#         marker_b27fa651b973dcada305b9f361a9c97b.bindPopup(popup_b04281b1201d221ec2edecdf72fcab9c)
#         ;
#
#
#
#
#             var marker_f5888494b7f46ac5d857b908f6ca7ad8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7cd3f0235a4c012ba95eacbc989925f9);
#
#
#         var popup_b25aa318145fa75d16c89680b8a8f4f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b81c00496a9995eb97aea73dd2cf8f7c = $(`&lt;div id=&quot;html_b81c00496a9995eb97aea73dd2cf8f7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b25aa318145fa75d16c89680b8a8f4f8.setContent(html_b81c00496a9995eb97aea73dd2cf8f7c);
#
#
#
#         marker_f5888494b7f46ac5d857b908f6ca7ad8.bindPopup(popup_b25aa318145fa75d16c89680b8a8f4f8)
#         ;
#
#
#
#
#             var marker_3f21a6463e6f9d8c05c4c8c168d3dbf3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7cd3f0235a4c012ba95eacbc989925f9);
#
#
#         var popup_9e799918b37e73212390fee88a24a5f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b22e92f1527dfac8ac3e3563dd9237f7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b22e92f1527dfac8ac3e3563dd9237f7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b22e92f1527dfac8ac3e3563dd9237f7 = L.map(
#                 &quot;map_b22e92f1527dfac8ac3e3563dd9237f7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83814cdafd910ad840b4d422f3fb9a1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_83814cdafd910ad840b4d422f3fb9a1f.addTo(map_b22e92f1527dfac8ac3e3563dd9237f7);
#
#
#             var feature_group_e5c025018cf36d540f11e6228458021b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e5c025018cf36d540f11e6228458021b.addTo(map_b22e92f1527dfac8ac3e3563dd9237f7);
#
#
#             var feature_group_sub_group_c612ae14b07a16a1f632426cbff0cca1 = L.featureGroup.subGroup(
#                 feature_group_e5c025018cf36d540f11e6228458021b
#             );
#
#
#             var marker_8a52736a6c57bfabf69d813b057eb52f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c612ae14b07a16a1f632426cbff0cca1);
#
#
#         var popup_9935293fd53f2db784a3e58c2d27a155 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3499f302ed9770cda6ce89ea7e0d8f8f = $(`&lt;div id=&quot;html_3499f302ed9770cda6ce89ea7e0d8f8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9935293fd53f2db784a3e58c2d27a155.setContent(html_3499f302ed9770cda6ce89ea7e0d8f8f);
#
#
#
#         marker_8a52736a6c57bfabf69d813b057eb52f.bindPopup(popup_9935293fd53f2db784a3e58c2d27a155)
#         ;
#
#
#
#
#             var marker_5a811eac55a293a9ed0b9ac5becf9a95 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c612ae14b07a16a1f632426cbff0cca1);
#
#
#         var popup_05ebe2483c4f1377d7151f5f52f60542 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d79d33de7c8de7a172061f7bdb8857b5 = $(`&lt;div id=&quot;html_d79d33de7c8de7a172061f7bdb8857b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_05ebe2483c4f1377d7151f5f52f60542.setContent(html_d79d33de7c8de7a172061f7bdb8857b5);
#
#
#
#         marker_5a811eac55a293a9ed0b9ac5becf9a95.bindPopup(popup_05ebe2483c4f1377d7151f5f52f60542)
#         ;
#
#
#
#
#             var marker_c314341e0b6306a44fcda73332f1b0e1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c612ae14b07a16a1f632426cbff0cca1);
#
#
#         var popup_7541240c59d9329a43db485f3cb3e093 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a9bf1f1220b0088f45761f1a4850de1 = $(`&lt;div id=&quot;html_6a9bf1f1220b0088f45761f1a4850de1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7541240c59d9329a43db485f3cb3e093.setContent(html_6a9bf1f1220b0088f45761f1a4850de1);
#
#
#
#         marker_c314341e0b6306a44fcda73332f1b0e1.bindPopup(popup_7541240c59d9329a43db485f3cb3e093)
#         ;
#
#
#
#
#             var marker_c699b091e18187f7a857a29bd42bfac3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c612ae14b07a16a1f632426cbff0cca1);
#
#
#         var popup_d5dcc920fe0b6767d15b9bb0ecd71538 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdf60ad9a4ecde4b203d844131e4332b = $(`&lt;div id=&quot;html_bdf60ad9a4ecde4b203d844131e4332b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d5dcc920fe0b6767d15b9bb0ecd71538.setContent(html_bdf60ad9a4ecde4b203d844131e4332b);
#
#
#
#         mark
