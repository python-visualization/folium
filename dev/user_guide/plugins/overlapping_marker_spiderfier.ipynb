# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_716790d9d6a24912991a42e251fdffbc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_716790d9d6a24912991a42e251fdffbc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_716790d9d6a24912991a42e251fdffbc = L.map(
#                 &quot;map_716790d9d6a24912991a42e251fdffbc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b2d97260545ca1fc59c5a08dc858295b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b2d97260545ca1fc59c5a08dc858295b.addTo(map_716790d9d6a24912991a42e251fdffbc);
#
#
#             var marker_dabbfc092c1d52c13db63d1eb46dc859 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_716790d9d6a24912991a42e251fdffbc);
#
#
#         var popup_f89705f42953cc6d5f294ea686b9ad80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc75cdb8daa093ca79113d59e0a7252d = $(`&lt;div id=&quot;html_fc75cdb8daa093ca79113d59e0a7252d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f89705f42953cc6d5f294ea686b9ad80.setContent(html_fc75cdb8daa093ca79113d59e0a7252d);
#
#
#
#         marker_dabbfc092c1d52c13db63d1eb46dc859.bindPopup(popup_f89705f42953cc6d5f294ea686b9ad80)
#         ;
#
#
#
#
#             var marker_bc3f6957ee5fe302ba9888473ce6da71 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_716790d9d6a24912991a42e251fdffbc);
#
#
#         var popup_cddefb54adff2f665b400e109e79c38f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73d340159047119253a17eba57294a74 = $(`&lt;div id=&quot;html_73d340159047119253a17eba57294a74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cddefb54adff2f665b400e109e79c38f.setContent(html_73d340159047119253a17eba57294a74);
#
#
#
#         marker_bc3f6957ee5fe302ba9888473ce6da71.bindPopup(popup_cddefb54adff2f665b400e109e79c38f)
#         ;
#
#
#
#
#             var marker_4a879819751c54cf19d12aa3714aff02 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_716790d9d6a24912991a42e251fdffbc);
#
#
#         var popup_1e947f9f69e0f2018cb91a5a5fd612fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4781d372d436f6d6e8eb193fa98e48d = $(`&lt;div id=&quot;html_d4781d372d436f6d6e8eb193fa98e48d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1e947f9f69e0f2018cb91a5a5fd612fe.setContent(html_d4781d372d436f6d6e8eb193fa98e48d);
#
#
#
#         marker_4a879819751c54cf19d12aa3714aff02.bindPopup(popup_1e947f9f69e0f2018cb91a5a5fd612fe)
#         ;
#
#
#
#
#             var marker_30ec8dbeb9dc735ccd848552d4645a43 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_716790d9d6a24912991a42e251fdffbc);
#
#
#         var popup_ffa89ef3c43105cf171b8af5d717e2d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_771807e3134d459f2e36c3188a185fc5 = $(`&lt;div id=&quot;html_771807e3134d459f2e36c3188a185fc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ffa89ef3c43105cf171b8af5d717e2d1.setContent(html_771807e3134d459f2e36c3188a185fc5);
#
#
#
#         marker_30ec8dbeb9dc735ccd848552d4645a43.bindPopup(popup_ffa89ef3c43105cf171b8af5d717e2d1)
#         ;
#
#
#
#
#             var marker_125a812216080b0cef8cece120e52699 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_716790d9d6a24912991a42e251fdffbc);
#
#
#         var popup_6aee3a64c5066457ed6223967861b37d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d0a24e1c14885021f931253171ab98c = $(`&lt;div id=&quot;html_2d0a24e1c14885021f931253171ab98c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6aee3a64c5066457ed6223967861b37d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d7593c3db925b61aa7a19ab8eb4c913 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d7593c3db925b61aa7a19ab8eb4c913&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d7593c3db925b61aa7a19ab8eb4c913 = L.map(
#                 &quot;map_8d7593c3db925b61aa7a19ab8eb4c913&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49fda003eb03a5d3634ffb69619f9387 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49fda003eb03a5d3634ffb69619f9387.addTo(map_8d7593c3db925b61aa7a19ab8eb4c913);
#
#
#             var feature_group_f83e185b72fb62da5fd830c982aa431b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8d3ae067917c7a0b6b9e28c77bceba46 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f83e185b72fb62da5fd830c982aa431b);
#
#
#         var popup_7801f9296e7d85d0d8886f36412ed550 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e7e19d87e971c11dae08d09d4c18065 = $(`&lt;div id=&quot;html_4e7e19d87e971c11dae08d09d4c18065&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7801f9296e7d85d0d8886f36412ed550.setContent(html_4e7e19d87e971c11dae08d09d4c18065);
#
#
#
#         marker_8d3ae067917c7a0b6b9e28c77bceba46.bindPopup(popup_7801f9296e7d85d0d8886f36412ed550)
#         ;
#
#
#
#
#             var marker_67bc387b1ba7075fa2a63754e2ccbbdf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f83e185b72fb62da5fd830c982aa431b);
#
#
#         var popup_63a9775670508463c94a43da7e5ed579 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f5d4b6e9774a23329ada25a087377a5 = $(`&lt;div id=&quot;html_9f5d4b6e9774a23329ada25a087377a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_63a9775670508463c94a43da7e5ed579.setContent(html_9f5d4b6e9774a23329ada25a087377a5);
#
#
#
#         marker_67bc387b1ba7075fa2a63754e2ccbbdf.bindPopup(popup_63a9775670508463c94a43da7e5ed579)
#         ;
#
#
#
#
#             var marker_a22f8d882c09bd38c6ea0fd1640ccfde = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f83e185b72fb62da5fd830c982aa431b);
#
#
#         var popup_820a4727a366c11a0d36efdd6334358a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8397e008d4dc15d48f39e141b03ac78b = $(`&lt;div id=&quot;html_8397e008d4dc15d48f39e141b03ac78b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_820a4727a366c11a0d36efdd6334358a.setContent(html_8397e008d4dc15d48f39e141b03ac78b);
#
#
#
#         marker_a22f8d882c09bd38c6ea0fd1640ccfde.bindPopup(popup_820a4727a366c11a0d36efdd6334358a)
#         ;
#
#
#
#
#             var marker_089d8da1263a91eb99e4e30ba954a009 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f83e185b72fb62da5fd830c982aa431b);
#
#
#         var popup_157291da69d7aae2db5c02821cc2fd3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29791a4b5080d687ae47c5532fc31100 = $(`&lt;div id=&quot;html_29791a4b5080d687ae47c5532fc31100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_157291da69d7aae2db5c02821cc2fd3b.setContent(html_29791a4b5080d687ae47c5532fc31100);
#
#
#
#         marker_089d8da1263a91eb99e4e30ba954a009.bindPopup(popup_157291da69d7aae2db5c02821cc2fd3b)
#         ;
#
#
#
#
#             var marker_2e5eb15d6b146cad995ce734be778085 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f83e185b72fb62da5fd830c982aa431b);
#
#
#         var popup_7a2aeea159a83b35048f5d8f49d6379e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d69f67a03b1ae28089a68b116f582303 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d69f67a03b1ae28089a68b116f582303&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d69f67a03b1ae28089a68b116f582303 = L.map(
#                 &quot;map_d69f67a03b1ae28089a68b116f582303&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1cbb687d9b08eb5fdfa6bac64ce741e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1cbb687d9b08eb5fdfa6bac64ce741e0.addTo(map_d69f67a03b1ae28089a68b116f582303);
#
#
#             var feature_group_ce4f82580545f9a6b12878b56cc912e6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ce4f82580545f9a6b12878b56cc912e6.addTo(map_d69f67a03b1ae28089a68b116f582303);
#
#
#             var feature_group_sub_group_a32a4fb38332ba787cd44ad8fa5debce = L.featureGroup.subGroup(
#                 feature_group_ce4f82580545f9a6b12878b56cc912e6
#             );
#
#
#             var marker_c038207d05b439107d85ebef016eae99 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a32a4fb38332ba787cd44ad8fa5debce);
#
#
#         var popup_b8d5c2e5bbf6e47f69dbf3581d6130f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47eda135b1323f5c6076936b95d60805 = $(`&lt;div id=&quot;html_47eda135b1323f5c6076936b95d60805&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b8d5c2e5bbf6e47f69dbf3581d6130f2.setContent(html_47eda135b1323f5c6076936b95d60805);
#
#
#
#         marker_c038207d05b439107d85ebef016eae99.bindPopup(popup_b8d5c2e5bbf6e47f69dbf3581d6130f2)
#         ;
#
#
#
#
#             var marker_3724fa2386945a4f4a960a25548cce78 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a32a4fb38332ba787cd44ad8fa5debce);
#
#
#         var popup_0f4107635c1e7c1c1e60ec2c0c6f2343 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_737cfbe4c403b0adb8627690c8754575 = $(`&lt;div id=&quot;html_737cfbe4c403b0adb8627690c8754575&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0f4107635c1e7c1c1e60ec2c0c6f2343.setContent(html_737cfbe4c403b0adb8627690c8754575);
#
#
#
#         marker_3724fa2386945a4f4a960a25548cce78.bindPopup(popup_0f4107635c1e7c1c1e60ec2c0c6f2343)
#         ;
#
#
#
#
#             var marker_e6e838b2f83556bf6095f04fcd9f2e6c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a32a4fb38332ba787cd44ad8fa5debce);
#
#
#         var popup_1f0c46d1b5620f8dda6da311c9cf8316 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bac339af597a5be5da6a89d506e58dce = $(`&lt;div id=&quot;html_bac339af597a5be5da6a89d506e58dce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1f0c46d1b5620f8dda6da311c9cf8316.setContent(html_bac339af597a5be5da6a89d506e58dce);
#
#
#
#         marker_e6e838b2f83556bf6095f04fcd9f2e6c.bindPopup(popup_1f0c46d1b5620f8dda6da311c9cf8316)
#         ;
#
#
#
#
#             var marker_6ca9464efab2073e8741cb091931a452 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a32a4fb38332ba787cd44ad8fa5debce);
#
#
#         var popup_b66cc61396a8216a52c26626e489631f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb444af603abc455ea30244ff2f16189 = $(`&lt;div id=&quot;html_fb444af603abc455ea30244ff2f16189&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b66cc61396a8216a52c26626e489631f.setContent(html_fb444af603abc455ea30244ff2f16189);
#
#
#
#         marker_
