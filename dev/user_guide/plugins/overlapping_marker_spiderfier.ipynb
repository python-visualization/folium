# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2aa647c4eddfc7a06295d9e2d8a71549 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2aa647c4eddfc7a06295d9e2d8a71549&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2aa647c4eddfc7a06295d9e2d8a71549 = L.map(
#                 &quot;map_2aa647c4eddfc7a06295d9e2d8a71549&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_02f3284c9afda2aac05ad1c7c589afd3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_02f3284c9afda2aac05ad1c7c589afd3.addTo(map_2aa647c4eddfc7a06295d9e2d8a71549);
#
#
#             var marker_0b02e92648070d71c1d2808e3b387498 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2aa647c4eddfc7a06295d9e2d8a71549);
#
#
#         var popup_a92123389a27dde1ce85711558af80bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0287e3b528540854f8df7634424f4c59 = $(`&lt;div id=&quot;html_0287e3b528540854f8df7634424f4c59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a92123389a27dde1ce85711558af80bf.setContent(html_0287e3b528540854f8df7634424f4c59);
#
#
#
#         marker_0b02e92648070d71c1d2808e3b387498.bindPopup(popup_a92123389a27dde1ce85711558af80bf)
#         ;
#
#
#
#
#             var marker_e545329ab902a1beae00a1c3240e2d63 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2aa647c4eddfc7a06295d9e2d8a71549);
#
#
#         var popup_aefe2c2be454d139af520cb02191cf3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05990512c73e57fdb9c2751699f8b475 = $(`&lt;div id=&quot;html_05990512c73e57fdb9c2751699f8b475&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_aefe2c2be454d139af520cb02191cf3c.setContent(html_05990512c73e57fdb9c2751699f8b475);
#
#
#
#         marker_e545329ab902a1beae00a1c3240e2d63.bindPopup(popup_aefe2c2be454d139af520cb02191cf3c)
#         ;
#
#
#
#
#             var marker_9393377d89ab6629ca381f00d6a8f998 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2aa647c4eddfc7a06295d9e2d8a71549);
#
#
#         var popup_41041cae66c3cd76d4720a5b6d860836 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71bd8768b6302f257f099de4fd5e55e9 = $(`&lt;div id=&quot;html_71bd8768b6302f257f099de4fd5e55e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_41041cae66c3cd76d4720a5b6d860836.setContent(html_71bd8768b6302f257f099de4fd5e55e9);
#
#
#
#         marker_9393377d89ab6629ca381f00d6a8f998.bindPopup(popup_41041cae66c3cd76d4720a5b6d860836)
#         ;
#
#
#
#
#             var marker_757c66c7971f1e9d4517cd227a596d8a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2aa647c4eddfc7a06295d9e2d8a71549);
#
#
#         var popup_014c0bbeb4af881d80524d1e9f2213f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a09493a09cf751199d48ad4ba036e1a9 = $(`&lt;div id=&quot;html_a09493a09cf751199d48ad4ba036e1a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_014c0bbeb4af881d80524d1e9f2213f6.setContent(html_a09493a09cf751199d48ad4ba036e1a9);
#
#
#
#         marker_757c66c7971f1e9d4517cd227a596d8a.bindPopup(popup_014c0bbeb4af881d80524d1e9f2213f6)
#         ;
#
#
#
#
#             var marker_ba3b549fe919c67c3e79106de19201ac = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2aa647c4eddfc7a06295d9e2d8a71549);
#
#
#         var popup_3389b212b295552a68e115f7b6a882c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59cc40e6b423977861d73f4fdbf8d0b0 = $(`&lt;div id=&quot;html_59cc40e6b423977861d73f4fdbf8d0b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3389b212b295552a68e115f7b6a882

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_577263d9619147007758dc8311c8668e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_577263d9619147007758dc8311c8668e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_577263d9619147007758dc8311c8668e = L.map(
#                 &quot;map_577263d9619147007758dc8311c8668e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f58e16e30ad422df7f44f8fc4e082820 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f58e16e30ad422df7f44f8fc4e082820.addTo(map_577263d9619147007758dc8311c8668e);
#
#
#             var feature_group_587840b497f063e79b13c831d7f9cd31 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ad733133b339c6a35c6af2f0b0d07bea = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_587840b497f063e79b13c831d7f9cd31);
#
#
#         var popup_b0d78ce327fa7ae30ba5d9147866c5db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5d3ebcfacd75a2e4944ee9e70cf8a63 = $(`&lt;div id=&quot;html_a5d3ebcfacd75a2e4944ee9e70cf8a63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b0d78ce327fa7ae30ba5d9147866c5db.setContent(html_a5d3ebcfacd75a2e4944ee9e70cf8a63);
#
#
#
#         marker_ad733133b339c6a35c6af2f0b0d07bea.bindPopup(popup_b0d78ce327fa7ae30ba5d9147866c5db)
#         ;
#
#
#
#
#             var marker_36219f990bec7653fb66f9589db54075 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_587840b497f063e79b13c831d7f9cd31);
#
#
#         var popup_b065d93440e90b285b19b30ca119d953 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b23b54530d717544b9c99c19539e2a2d = $(`&lt;div id=&quot;html_b23b54530d717544b9c99c19539e2a2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b065d93440e90b285b19b30ca119d953.setContent(html_b23b54530d717544b9c99c19539e2a2d);
#
#
#
#         marker_36219f990bec7653fb66f9589db54075.bindPopup(popup_b065d93440e90b285b19b30ca119d953)
#         ;
#
#
#
#
#             var marker_b2cc5ab534aac09d2316b8cfc3635bd3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_587840b497f063e79b13c831d7f9cd31);
#
#
#         var popup_c5d29aa5513548485c3159717d0389ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b109bac0143f37ee0bdd1587ed4505b1 = $(`&lt;div id=&quot;html_b109bac0143f37ee0bdd1587ed4505b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c5d29aa5513548485c3159717d0389ae.setContent(html_b109bac0143f37ee0bdd1587ed4505b1);
#
#
#
#         marker_b2cc5ab534aac09d2316b8cfc3635bd3.bindPopup(popup_c5d29aa5513548485c3159717d0389ae)
#         ;
#
#
#
#
#             var marker_dddde849b92d83e84a339f6f0575cb65 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_587840b497f063e79b13c831d7f9cd31);
#
#
#         var popup_dbc39078b5289dff6e9aa8569ba5efff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a15aa24b3631a7ac5baa3e20e6e0d34 = $(`&lt;div id=&quot;html_1a15aa24b3631a7ac5baa3e20e6e0d34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dbc39078b5289dff6e9aa8569ba5efff.setContent(html_1a15aa24b3631a7ac5baa3e20e6e0d34);
#
#
#
#         marker_dddde849b92d83e84a339f6f0575cb65.bindPopup(popup_dbc39078b5289dff6e9aa8569ba5efff)
#         ;
#
#
#
#
#             var marker_5431273b94b0add5c63e4b9f51acf398 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_587840b497f063e79b13c831d7f9cd31);
#
#
#         var popup_a1eb24cdd31181b6ec4e5f0203493adf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d0b87bee5ac8d3ce8b35afa149ea837 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d0b87bee5ac8d3ce8b35afa149ea837&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d0b87bee5ac8d3ce8b35afa149ea837 = L.map(
#                 &quot;map_4d0b87bee5ac8d3ce8b35afa149ea837&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2fe06d3425b01fae9b1be32e4044c3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2fe06d3425b01fae9b1be32e4044c3d.addTo(map_4d0b87bee5ac8d3ce8b35afa149ea837);
#
#
#             var feature_group_11158027a045df1ad5e211a53cb7df19 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_11158027a045df1ad5e211a53cb7df19.addTo(map_4d0b87bee5ac8d3ce8b35afa149ea837);
#
#
#             var feature_group_sub_group_735245aa2753096ba22d52208346e50e = L.featureGroup.subGroup(
#                 feature_group_11158027a045df1ad5e211a53cb7df19
#             );
#
#
#             var marker_4d2a2d5dc401d298d48369d3c9b082ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_735245aa2753096ba22d52208346e50e);
#
#
#         var popup_429c27b91761fd99928426622653c6bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d59ba213bfd215f7897aea112722c69c = $(`&lt;div id=&quot;html_d59ba213bfd215f7897aea112722c69c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_429c27b91761fd99928426622653c6bb.setContent(html_d59ba213bfd215f7897aea112722c69c);
#
#
#
#         marker_4d2a2d5dc401d298d48369d3c9b082ff.bindPopup(popup_429c27b91761fd99928426622653c6bb)
#         ;
#
#
#
#
#             var marker_a0bcf51860e48ba1313da2ba2e14a687 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_735245aa2753096ba22d52208346e50e);
#
#
#         var popup_114640992ac38c8a4c2529108177b753 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ec8cb0a96d034b033e1f4b250ce8c93 = $(`&lt;div id=&quot;html_4ec8cb0a96d034b033e1f4b250ce8c93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_114640992ac38c8a4c2529108177b753.setContent(html_4ec8cb0a96d034b033e1f4b250ce8c93);
#
#
#
#         marker_a0bcf51860e48ba1313da2ba2e14a687.bindPopup(popup_114640992ac38c8a4c2529108177b753)
#         ;
#
#
#
#
#             var marker_be0a35371dda767009708da6e72877d0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_735245aa2753096ba22d52208346e50e);
#
#
#         var popup_b318dc605cd7a98e2adcb435d5404f56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f48faf2d45abf5dfcbdd937c2d2e76b2 = $(`&lt;div id=&quot;html_f48faf2d45abf5dfcbdd937c2d2e76b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b318dc605cd7a98e2adcb435d5404f56.setContent(html_f48faf2d45abf5dfcbdd937c2d2e76b2);
#
#
#
#         marker_be0a35371dda767009708da6e72877d0.bindPopup(popup_b318dc605cd7a98e2adcb435d5404f56)
#         ;
#
#
#
#
#             var marker_7add58ef904b95e2ae84f7f05f38abff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_735245aa2753096ba22d52208346e50e);
#
#
#         var popup_61d6704070d5590b83513408d54231f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86c6a21f2501614f82add5dc5396e233 = $(`&lt;div id=&quot;html_86c6a21f2501614f82add5dc5396e233&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_61d6704070d5590b83513408d54231f0.setContent(html_86c6a21f2501614f82add5dc5396e233);
#
#
#
#         mark
