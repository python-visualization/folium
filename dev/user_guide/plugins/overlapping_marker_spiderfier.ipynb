# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40f14a96fe69a8be484282e60509eb9e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40f14a96fe69a8be484282e60509eb9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40f14a96fe69a8be484282e60509eb9e = L.map(
#                 &quot;map_40f14a96fe69a8be484282e60509eb9e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ec982dfc88ebdfd0f4d9a0f980a67eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ec982dfc88ebdfd0f4d9a0f980a67eb.addTo(map_40f14a96fe69a8be484282e60509eb9e);
#
#
#             var marker_52e2ca9962128b6ce065c301cee46f99 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_40f14a96fe69a8be484282e60509eb9e);
#
#
#         var popup_bd49c75ce736631f13ec02b32a94af07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_168f221a9d208b2f1f99d22baaaf1800 = $(`&lt;div id=&quot;html_168f221a9d208b2f1f99d22baaaf1800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bd49c75ce736631f13ec02b32a94af07.setContent(html_168f221a9d208b2f1f99d22baaaf1800);
#
#
#
#         marker_52e2ca9962128b6ce065c301cee46f99.bindPopup(popup_bd49c75ce736631f13ec02b32a94af07)
#         ;
#
#
#
#
#             var marker_487b7c50eb33ffd29674a83cbed69ced = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_40f14a96fe69a8be484282e60509eb9e);
#
#
#         var popup_69aff7c73076b0c4cf72e40be9de9086 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dafb12a50c2b7ed5ca05c7f804effcf6 = $(`&lt;div id=&quot;html_dafb12a50c2b7ed5ca05c7f804effcf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_69aff7c73076b0c4cf72e40be9de9086.setContent(html_dafb12a50c2b7ed5ca05c7f804effcf6);
#
#
#
#         marker_487b7c50eb33ffd29674a83cbed69ced.bindPopup(popup_69aff7c73076b0c4cf72e40be9de9086)
#         ;
#
#
#
#
#             var marker_e5d747d9cd87a1a3a2b3691c6a1fd4b7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_40f14a96fe69a8be484282e60509eb9e);
#
#
#         var popup_c1e21b554bf8020427603ac6995bdac4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38c57d473ed7ef7c2c246387afd58106 = $(`&lt;div id=&quot;html_38c57d473ed7ef7c2c246387afd58106&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c1e21b554bf8020427603ac6995bdac4.setContent(html_38c57d473ed7ef7c2c246387afd58106);
#
#
#
#         marker_e5d747d9cd87a1a3a2b3691c6a1fd4b7.bindPopup(popup_c1e21b554bf8020427603ac6995bdac4)
#         ;
#
#
#
#
#             var marker_65e6edd298525dec2e10940efdfa8d86 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_40f14a96fe69a8be484282e60509eb9e);
#
#
#         var popup_382d2457381bea4450689a4fc64ee651 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7f2b4acbdff1da7b67113452d72fa3c = $(`&lt;div id=&quot;html_e7f2b4acbdff1da7b67113452d72fa3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_382d2457381bea4450689a4fc64ee651.setContent(html_e7f2b4acbdff1da7b67113452d72fa3c);
#
#
#
#         marker_65e6edd298525dec2e10940efdfa8d86.bindPopup(popup_382d2457381bea4450689a4fc64ee651)
#         ;
#
#
#
#
#             var marker_10b708bc0137eab0414f27d3de25f20e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_40f14a96fe69a8be484282e60509eb9e);
#
#
#         var popup_a97b76df973271e345850eff70034a4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_313b0c5d1f73b82ae7af5d111ca04a3a = $(`&lt;div id=&quot;html_313b0c5d1f73b82ae7af5d111ca04a3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a97b76df973271e345850eff70034a

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8496c605c7aa9202ff64867f2b1eab6f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8496c605c7aa9202ff64867f2b1eab6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8496c605c7aa9202ff64867f2b1eab6f = L.map(
#                 &quot;map_8496c605c7aa9202ff64867f2b1eab6f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ae3e882062ec10c4e346e6b70ba0f216 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ae3e882062ec10c4e346e6b70ba0f216.addTo(map_8496c605c7aa9202ff64867f2b1eab6f);
#
#
#             var feature_group_5692fe5326fded9e8b0943d67047f52c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f5f5520a992004d5746b2e956032a0ca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5692fe5326fded9e8b0943d67047f52c);
#
#
#         var popup_95cea043ef95130954e633c864c5de83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_800416ae34ce7654e32a5fbbcbf860ab = $(`&lt;div id=&quot;html_800416ae34ce7654e32a5fbbcbf860ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_95cea043ef95130954e633c864c5de83.setContent(html_800416ae34ce7654e32a5fbbcbf860ab);
#
#
#
#         marker_f5f5520a992004d5746b2e956032a0ca.bindPopup(popup_95cea043ef95130954e633c864c5de83)
#         ;
#
#
#
#
#             var marker_1472de2b99ca5bdb5d85feab216d724d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5692fe5326fded9e8b0943d67047f52c);
#
#
#         var popup_1d4cd5f014ecea715155a832138ce9d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a712f606c797306bb64fe6abd5d1aa63 = $(`&lt;div id=&quot;html_a712f606c797306bb64fe6abd5d1aa63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1d4cd5f014ecea715155a832138ce9d7.setContent(html_a712f606c797306bb64fe6abd5d1aa63);
#
#
#
#         marker_1472de2b99ca5bdb5d85feab216d724d.bindPopup(popup_1d4cd5f014ecea715155a832138ce9d7)
#         ;
#
#
#
#
#             var marker_9143cf9e241672d7aec1d1160f9373db = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5692fe5326fded9e8b0943d67047f52c);
#
#
#         var popup_fa4f82e836c2dfc8183cc67171f3abf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0a3d6d2d37cd43fd3f76b9879a2ded0 = $(`&lt;div id=&quot;html_a0a3d6d2d37cd43fd3f76b9879a2ded0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fa4f82e836c2dfc8183cc67171f3abf0.setContent(html_a0a3d6d2d37cd43fd3f76b9879a2ded0);
#
#
#
#         marker_9143cf9e241672d7aec1d1160f9373db.bindPopup(popup_fa4f82e836c2dfc8183cc67171f3abf0)
#         ;
#
#
#
#
#             var marker_d96e5b082885f6eff9f61c9883021156 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5692fe5326fded9e8b0943d67047f52c);
#
#
#         var popup_e61f7ef4c7d08f4f83f75158e2f7ce8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_160823e2917f2c948b4aa1546c002e25 = $(`&lt;div id=&quot;html_160823e2917f2c948b4aa1546c002e25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e61f7ef4c7d08f4f83f75158e2f7ce8f.setContent(html_160823e2917f2c948b4aa1546c002e25);
#
#
#
#         marker_d96e5b082885f6eff9f61c9883021156.bindPopup(popup_e61f7ef4c7d08f4f83f75158e2f7ce8f)
#         ;
#
#
#
#
#             var marker_3e14205f2ec48e97dd6ddbd44f5ceaa2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5692fe5326fded9e8b0943d67047f52c);
#
#
#         var popup_2e1d729052322665ff0ceba76374237a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ec92d964e30757001a3f0cfac543eea {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ec92d964e30757001a3f0cfac543eea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ec92d964e30757001a3f0cfac543eea = L.map(
#                 &quot;map_8ec92d964e30757001a3f0cfac543eea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ecec54c66bcbea8551ddbe35b954bb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ecec54c66bcbea8551ddbe35b954bb7.addTo(map_8ec92d964e30757001a3f0cfac543eea);
#
#
#             var feature_group_4d995114a7e1fb72d7bd12959ccb6625 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4d995114a7e1fb72d7bd12959ccb6625.addTo(map_8ec92d964e30757001a3f0cfac543eea);
#
#
#             var feature_group_sub_group_d322f6fb80db61df3d9e44e57472df28 = L.featureGroup.subGroup(
#                 feature_group_4d995114a7e1fb72d7bd12959ccb6625
#             );
#
#
#             var marker_c9fc986c21da3ffd5644b357ef5a24eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d322f6fb80db61df3d9e44e57472df28);
#
#
#         var popup_9f765e8c7d1adbed174ad903a4229107 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49ca5352e74a6e805d5413f8f8a5aa31 = $(`&lt;div id=&quot;html_49ca5352e74a6e805d5413f8f8a5aa31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9f765e8c7d1adbed174ad903a4229107.setContent(html_49ca5352e74a6e805d5413f8f8a5aa31);
#
#
#
#         marker_c9fc986c21da3ffd5644b357ef5a24eb.bindPopup(popup_9f765e8c7d1adbed174ad903a4229107)
#         ;
#
#
#
#
#             var marker_5448cab243f67f48d63d267fe41b1c87 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d322f6fb80db61df3d9e44e57472df28);
#
#
#         var popup_60d7959152a0fbfefb424d890f581032 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97c13565a3b0cbf333451c6b90627a45 = $(`&lt;div id=&quot;html_97c13565a3b0cbf333451c6b90627a45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_60d7959152a0fbfefb424d890f581032.setContent(html_97c13565a3b0cbf333451c6b90627a45);
#
#
#
#         marker_5448cab243f67f48d63d267fe41b1c87.bindPopup(popup_60d7959152a0fbfefb424d890f581032)
#         ;
#
#
#
#
#             var marker_07916f4ed15ae3faa60d597a00465ffb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d322f6fb80db61df3d9e44e57472df28);
#
#
#         var popup_38571055b4e93d516159ae90b6097e54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d4c65c12f14eb47aa3d412866dcddeb = $(`&lt;div id=&quot;html_6d4c65c12f14eb47aa3d412866dcddeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_38571055b4e93d516159ae90b6097e54.setContent(html_6d4c65c12f14eb47aa3d412866dcddeb);
#
#
#
#         marker_07916f4ed15ae3faa60d597a00465ffb.bindPopup(popup_38571055b4e93d516159ae90b6097e54)
#         ;
#
#
#
#
#             var marker_0bebb5d11bca53ee19131c4837b49f43 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d322f6fb80db61df3d9e44e57472df28);
#
#
#         var popup_6b8244e604c5da9eaa737ba9d2d22fb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71645357f77c3a4480753b27716f650c = $(`&lt;div id=&quot;html_71645357f77c3a4480753b27716f650c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6b8244e604c5da9eaa737ba9d2d22fb5.setContent(html_71645357f77c3a4480753b27716f650c);
#
#
#
#         mark
