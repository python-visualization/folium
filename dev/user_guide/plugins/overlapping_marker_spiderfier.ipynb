# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f16629efcb214d7b157888601057d8f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f16629efcb214d7b157888601057d8f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f16629efcb214d7b157888601057d8f = L.map(
#                 &quot;map_5f16629efcb214d7b157888601057d8f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_867aa91e58c27b95d0b8d4d0f935bc3f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_867aa91e58c27b95d0b8d4d0f935bc3f.addTo(map_5f16629efcb214d7b157888601057d8f);
#
#
#             var marker_17928f1bb751a75c1eec2165b57d1108 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5f16629efcb214d7b157888601057d8f);
#
#
#         var popup_2257ca66ed32e141d57605c2f7a5adb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_107607d29d8e526c5f99189cc4c41cc7 = $(`&lt;div id=&quot;html_107607d29d8e526c5f99189cc4c41cc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2257ca66ed32e141d57605c2f7a5adb5.setContent(html_107607d29d8e526c5f99189cc4c41cc7);
#
#
#
#         marker_17928f1bb751a75c1eec2165b57d1108.bindPopup(popup_2257ca66ed32e141d57605c2f7a5adb5)
#         ;
#
#
#
#
#             var marker_3c3c20873e572ce4691dd350a5a8a6b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5f16629efcb214d7b157888601057d8f);
#
#
#         var popup_36f3e0626fd2d6aaa616509848ca17a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1156edfad947d3b3eceaa2b9dcad51b = $(`&lt;div id=&quot;html_e1156edfad947d3b3eceaa2b9dcad51b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_36f3e0626fd2d6aaa616509848ca17a3.setContent(html_e1156edfad947d3b3eceaa2b9dcad51b);
#
#
#
#         marker_3c3c20873e572ce4691dd350a5a8a6b6.bindPopup(popup_36f3e0626fd2d6aaa616509848ca17a3)
#         ;
#
#
#
#
#             var marker_f33f6a1470da49acd58e0d5b5d814df3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5f16629efcb214d7b157888601057d8f);
#
#
#         var popup_cd5638666f9fc57a0042b3e695d22d2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f303e2d97f5aadd71edf0d684f31035 = $(`&lt;div id=&quot;html_5f303e2d97f5aadd71edf0d684f31035&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cd5638666f9fc57a0042b3e695d22d2b.setContent(html_5f303e2d97f5aadd71edf0d684f31035);
#
#
#
#         marker_f33f6a1470da49acd58e0d5b5d814df3.bindPopup(popup_cd5638666f9fc57a0042b3e695d22d2b)
#         ;
#
#
#
#
#             var marker_2b2db5c26022858f3f23d1eb44c2f2e6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5f16629efcb214d7b157888601057d8f);
#
#
#         var popup_e85e5a5620e1c1eee7c795afcb230d88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90a70750e7da967871e98eddc7666028 = $(`&lt;div id=&quot;html_90a70750e7da967871e98eddc7666028&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e85e5a5620e1c1eee7c795afcb230d88.setContent(html_90a70750e7da967871e98eddc7666028);
#
#
#
#         marker_2b2db5c26022858f3f23d1eb44c2f2e6.bindPopup(popup_e85e5a5620e1c1eee7c795afcb230d88)
#         ;
#
#
#
#
#             var marker_767bccb79e6b2cc583ccdd8e302bdbb4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5f16629efcb214d7b157888601057d8f);
#
#
#         var popup_8dcb5599196bd667b14def763af73383 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e7b9fa9cc4042d013f83350cfec326e = $(`&lt;div id=&quot;html_1e7b9fa9cc4042d013f83350cfec326e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8dcb5599196bd667b14def763af73383.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c09e6c7ebaa30acaa32e4b98fc14457b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c09e6c7ebaa30acaa32e4b98fc14457b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c09e6c7ebaa30acaa32e4b98fc14457b = L.map(
#                 &quot;map_c09e6c7ebaa30acaa32e4b98fc14457b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_443d481658090489ec65b150f73032e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_443d481658090489ec65b150f73032e8.addTo(map_c09e6c7ebaa30acaa32e4b98fc14457b);
#
#
#             var feature_group_ef4aeec65761af5c412260d77065c3fb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_544fe95aa72a33f2c22d61d89ac1ca96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ef4aeec65761af5c412260d77065c3fb);
#
#
#         var popup_92dc2097888688ca7b33af9b5b1f3b75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01e74a252cf5208f31826290668901bc = $(`&lt;div id=&quot;html_01e74a252cf5208f31826290668901bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_92dc2097888688ca7b33af9b5b1f3b75.setContent(html_01e74a252cf5208f31826290668901bc);
#
#
#
#         marker_544fe95aa72a33f2c22d61d89ac1ca96.bindPopup(popup_92dc2097888688ca7b33af9b5b1f3b75)
#         ;
#
#
#
#
#             var marker_9b21c5d6c5330dfb29af69427f82cf83 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ef4aeec65761af5c412260d77065c3fb);
#
#
#         var popup_5f82e25da318d5bd854e039d3a28ff43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5902d739c270768a3807cd5208d49938 = $(`&lt;div id=&quot;html_5902d739c270768a3807cd5208d49938&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5f82e25da318d5bd854e039d3a28ff43.setContent(html_5902d739c270768a3807cd5208d49938);
#
#
#
#         marker_9b21c5d6c5330dfb29af69427f82cf83.bindPopup(popup_5f82e25da318d5bd854e039d3a28ff43)
#         ;
#
#
#
#
#             var marker_b36e4fd24a4b38b7754d6e02951a0241 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ef4aeec65761af5c412260d77065c3fb);
#
#
#         var popup_9d96fe9a9d3b14571cf46f52db66b5a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bec4516244668ba438a9f321e7df747d = $(`&lt;div id=&quot;html_bec4516244668ba438a9f321e7df747d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9d96fe9a9d3b14571cf46f52db66b5a1.setContent(html_bec4516244668ba438a9f321e7df747d);
#
#
#
#         marker_b36e4fd24a4b38b7754d6e02951a0241.bindPopup(popup_9d96fe9a9d3b14571cf46f52db66b5a1)
#         ;
#
#
#
#
#             var marker_595134ad9a36b9f78dd87db14e2d4a90 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ef4aeec65761af5c412260d77065c3fb);
#
#
#         var popup_cd3bc88454c8ed31c946a965babdf8f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9569baa5e442b8eb025f7a5cae57a83c = $(`&lt;div id=&quot;html_9569baa5e442b8eb025f7a5cae57a83c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cd3bc88454c8ed31c946a965babdf8f7.setContent(html_9569baa5e442b8eb025f7a5cae57a83c);
#
#
#
#         marker_595134ad9a36b9f78dd87db14e2d4a90.bindPopup(popup_cd3bc88454c8ed31c946a965babdf8f7)
#         ;
#
#
#
#
#             var marker_83b7c447a62babd469a27ae55be666f5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ef4aeec65761af5c412260d77065c3fb);
#
#
#         var popup_5a2aefb138e1c4b52555abd24f437a10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf9a12f068d2a0dabaeb366a73e1280b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf9a12f068d2a0dabaeb366a73e1280b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf9a12f068d2a0dabaeb366a73e1280b = L.map(
#                 &quot;map_cf9a12f068d2a0dabaeb366a73e1280b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92fe124eae52f54de881e643d295bcb8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92fe124eae52f54de881e643d295bcb8.addTo(map_cf9a12f068d2a0dabaeb366a73e1280b);
#
#
#             var feature_group_b80500ca1eec5980839534e109d670f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b80500ca1eec5980839534e109d670f1.addTo(map_cf9a12f068d2a0dabaeb366a73e1280b);
#
#
#             var feature_group_sub_group_6c7d67a804379f95c89ffe295b1abf88 = L.featureGroup.subGroup(
#                 feature_group_b80500ca1eec5980839534e109d670f1
#             );
#
#
#             var marker_875e73645f63697ddd87320951c1d7d2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c7d67a804379f95c89ffe295b1abf88);
#
#
#         var popup_1d86ce8917895c8595a7a1ec5cb7738d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e68bb7383bbf40afa8bb8dd6c404169 = $(`&lt;div id=&quot;html_2e68bb7383bbf40afa8bb8dd6c404169&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1d86ce8917895c8595a7a1ec5cb7738d.setContent(html_2e68bb7383bbf40afa8bb8dd6c404169);
#
#
#
#         marker_875e73645f63697ddd87320951c1d7d2.bindPopup(popup_1d86ce8917895c8595a7a1ec5cb7738d)
#         ;
#
#
#
#
#             var marker_2709323d1ae2250bff269c573e8b6b4e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c7d67a804379f95c89ffe295b1abf88);
#
#
#         var popup_960edb53473cda59472059961817520c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14e4bc961a34dd532e62a05384673c45 = $(`&lt;div id=&quot;html_14e4bc961a34dd532e62a05384673c45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_960edb53473cda59472059961817520c.setContent(html_14e4bc961a34dd532e62a05384673c45);
#
#
#
#         marker_2709323d1ae2250bff269c573e8b6b4e.bindPopup(popup_960edb53473cda59472059961817520c)
#         ;
#
#
#
#
#             var marker_3ef9990b8ce235037534440eeec8c056 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c7d67a804379f95c89ffe295b1abf88);
#
#
#         var popup_602a2ba7dfe73ffcce8c78071cf87d44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff8e472e31ef75325fe122e739d65195 = $(`&lt;div id=&quot;html_ff8e472e31ef75325fe122e739d65195&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_602a2ba7dfe73ffcce8c78071cf87d44.setContent(html_ff8e472e31ef75325fe122e739d65195);
#
#
#
#         marker_3ef9990b8ce235037534440eeec8c056.bindPopup(popup_602a2ba7dfe73ffcce8c78071cf87d44)
#         ;
#
#
#
#
#             var marker_1124fa234f38195827fd06828bf6d0a1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c7d67a804379f95c89ffe295b1abf88);
#
#
#         var popup_e764a75dbb8d81205a4cfa88e8f5a72a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9691adf0b1fba67c7ecb5aab7278d0f8 = $(`&lt;div id=&quot;html_9691adf0b1fba67c7ecb5aab7278d0f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e764a75dbb8d81205a4cfa88e8f5a72a.setContent(html_9691adf0b1fba67c7ecb5aab7278d0f8);
#
#
#
#         marker_
