# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93d3dfad53a41c834c2a56b009cc097e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93d3dfad53a41c834c2a56b009cc097e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93d3dfad53a41c834c2a56b009cc097e = L.map(
#                 &quot;map_93d3dfad53a41c834c2a56b009cc097e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b370e9c3f10299279a1df9566ab4ff8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b370e9c3f10299279a1df9566ab4ff8.addTo(map_93d3dfad53a41c834c2a56b009cc097e);
#
#
#             var marker_fbe4a22585782bd7c2b13f4ba54901bc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_93d3dfad53a41c834c2a56b009cc097e);
#
#
#         var popup_cb4248cb0ecaeffa0c8f1e25720ea92a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8037ee109879454305fc579c752a7c5d = $(`&lt;div id=&quot;html_8037ee109879454305fc579c752a7c5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cb4248cb0ecaeffa0c8f1e25720ea92a.setContent(html_8037ee109879454305fc579c752a7c5d);
#
#
#
#         marker_fbe4a22585782bd7c2b13f4ba54901bc.bindPopup(popup_cb4248cb0ecaeffa0c8f1e25720ea92a)
#         ;
#
#
#
#
#             var marker_822f375dcd49b69f05fc38ace04c076a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_93d3dfad53a41c834c2a56b009cc097e);
#
#
#         var popup_049cfba5cf76d03ee2fa14b3a28175f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4a8528a2dc088488fe2ccca6ad9ee38 = $(`&lt;div id=&quot;html_a4a8528a2dc088488fe2ccca6ad9ee38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_049cfba5cf76d03ee2fa14b3a28175f4.setContent(html_a4a8528a2dc088488fe2ccca6ad9ee38);
#
#
#
#         marker_822f375dcd49b69f05fc38ace04c076a.bindPopup(popup_049cfba5cf76d03ee2fa14b3a28175f4)
#         ;
#
#
#
#
#             var marker_986694e3f524481dbf5401cba1d883c9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_93d3dfad53a41c834c2a56b009cc097e);
#
#
#         var popup_c25ed8d02dc6a6572349c022d354fd1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfa74aa7165f10356bd3438a847b7204 = $(`&lt;div id=&quot;html_dfa74aa7165f10356bd3438a847b7204&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c25ed8d02dc6a6572349c022d354fd1b.setContent(html_dfa74aa7165f10356bd3438a847b7204);
#
#
#
#         marker_986694e3f524481dbf5401cba1d883c9.bindPopup(popup_c25ed8d02dc6a6572349c022d354fd1b)
#         ;
#
#
#
#
#             var marker_aa4071ca3592a3bfeec34b9904aeff7e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_93d3dfad53a41c834c2a56b009cc097e);
#
#
#         var popup_8987001980d640bed43f9de10226b916 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b49f599856ce2b72c6bbe8da73bbe0c0 = $(`&lt;div id=&quot;html_b49f599856ce2b72c6bbe8da73bbe0c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8987001980d640bed43f9de10226b916.setContent(html_b49f599856ce2b72c6bbe8da73bbe0c0);
#
#
#
#         marker_aa4071ca3592a3bfeec34b9904aeff7e.bindPopup(popup_8987001980d640bed43f9de10226b916)
#         ;
#
#
#
#
#             var marker_c242f6cc18bdb3ad638ad800234ff0cb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_93d3dfad53a41c834c2a56b009cc097e);
#
#
#         var popup_8d4f2ebf34c84367af0939e5af8a7e8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c24a30ecaa2fa8bdef2e7b23e931777 = $(`&lt;div id=&quot;html_8c24a30ecaa2fa8bdef2e7b23e931777&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8d4f2ebf34c84367af0939e5af8a7e8e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f86c9e68c8828491c6b100e28392f2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f86c9e68c8828491c6b100e28392f2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f86c9e68c8828491c6b100e28392f2d = L.map(
#                 &quot;map_3f86c9e68c8828491c6b100e28392f2d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c5ddfea0733b1898ca5c200b017ae38 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c5ddfea0733b1898ca5c200b017ae38.addTo(map_3f86c9e68c8828491c6b100e28392f2d);
#
#
#             var feature_group_2657bc21b0ef9fdb84716cc5eeef2a83 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_66475cc8fa8c2e9c5096804c69e38667 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2657bc21b0ef9fdb84716cc5eeef2a83);
#
#
#         var popup_20cdd14f878fb29b70f55822599fcb33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db4fa328c31549a8e4914bb74c190c83 = $(`&lt;div id=&quot;html_db4fa328c31549a8e4914bb74c190c83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_20cdd14f878fb29b70f55822599fcb33.setContent(html_db4fa328c31549a8e4914bb74c190c83);
#
#
#
#         marker_66475cc8fa8c2e9c5096804c69e38667.bindPopup(popup_20cdd14f878fb29b70f55822599fcb33)
#         ;
#
#
#
#
#             var marker_8d3c3c1a715038afe41426b47d0bd5c6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2657bc21b0ef9fdb84716cc5eeef2a83);
#
#
#         var popup_61b79476ca183e649d964ab33e1d9dca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90356dc5999bc5fa97c616d3c46bcab2 = $(`&lt;div id=&quot;html_90356dc5999bc5fa97c616d3c46bcab2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_61b79476ca183e649d964ab33e1d9dca.setContent(html_90356dc5999bc5fa97c616d3c46bcab2);
#
#
#
#         marker_8d3c3c1a715038afe41426b47d0bd5c6.bindPopup(popup_61b79476ca183e649d964ab33e1d9dca)
#         ;
#
#
#
#
#             var marker_6e61c5824fffe1899751e3c02aa158f9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2657bc21b0ef9fdb84716cc5eeef2a83);
#
#
#         var popup_fd5d9f8dbc9fc3ba5f99c94dbdfbc2b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c9e2718fe20fd2d83317f859d49f0ad = $(`&lt;div id=&quot;html_1c9e2718fe20fd2d83317f859d49f0ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fd5d9f8dbc9fc3ba5f99c94dbdfbc2b1.setContent(html_1c9e2718fe20fd2d83317f859d49f0ad);
#
#
#
#         marker_6e61c5824fffe1899751e3c02aa158f9.bindPopup(popup_fd5d9f8dbc9fc3ba5f99c94dbdfbc2b1)
#         ;
#
#
#
#
#             var marker_5ec7b99e891663eec76cf24ba01421cc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2657bc21b0ef9fdb84716cc5eeef2a83);
#
#
#         var popup_a4c9a36605288b4fdf5401e2de6f1725 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40fd0f36bc64a8f17033802a90fdffc7 = $(`&lt;div id=&quot;html_40fd0f36bc64a8f17033802a90fdffc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a4c9a36605288b4fdf5401e2de6f1725.setContent(html_40fd0f36bc64a8f17033802a90fdffc7);
#
#
#
#         marker_5ec7b99e891663eec76cf24ba01421cc.bindPopup(popup_a4c9a36605288b4fdf5401e2de6f1725)
#         ;
#
#
#
#
#             var marker_9f48d019d8612a63f135dac785f63523 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2657bc21b0ef9fdb84716cc5eeef2a83);
#
#
#         var popup_f2498131081d1bf1b20fed30395b55d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4dc47ac49e65b272813316bcc5f53d5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4dc47ac49e65b272813316bcc5f53d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4dc47ac49e65b272813316bcc5f53d5 = L.map(
#                 &quot;map_e4dc47ac49e65b272813316bcc5f53d5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8342e40188a8da5a503c6bd13881bf26 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8342e40188a8da5a503c6bd13881bf26.addTo(map_e4dc47ac49e65b272813316bcc5f53d5);
#
#
#             var feature_group_ae3af24be52fabdd7ce018192d3b887a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ae3af24be52fabdd7ce018192d3b887a.addTo(map_e4dc47ac49e65b272813316bcc5f53d5);
#
#
#             var feature_group_sub_group_2785baf38e09facd7744dbc571b3ea81 = L.featureGroup.subGroup(
#                 feature_group_ae3af24be52fabdd7ce018192d3b887a
#             );
#
#
#             var marker_9eacb5f71700acd78668c3168c282928 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2785baf38e09facd7744dbc571b3ea81);
#
#
#         var popup_98357398a32482ee2736bb5734478f68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56fc01d6a9ab4b7f10d18bb98b9759b5 = $(`&lt;div id=&quot;html_56fc01d6a9ab4b7f10d18bb98b9759b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_98357398a32482ee2736bb5734478f68.setContent(html_56fc01d6a9ab4b7f10d18bb98b9759b5);
#
#
#
#         marker_9eacb5f71700acd78668c3168c282928.bindPopup(popup_98357398a32482ee2736bb5734478f68)
#         ;
#
#
#
#
#             var marker_4359b2ad7cf0e3660a8bcf1a37c46c85 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2785baf38e09facd7744dbc571b3ea81);
#
#
#         var popup_872b17ab21a01183795d0195f469cac7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e388ae825885d3e3450d5d4e5e1d8bba = $(`&lt;div id=&quot;html_e388ae825885d3e3450d5d4e5e1d8bba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_872b17ab21a01183795d0195f469cac7.setContent(html_e388ae825885d3e3450d5d4e5e1d8bba);
#
#
#
#         marker_4359b2ad7cf0e3660a8bcf1a37c46c85.bindPopup(popup_872b17ab21a01183795d0195f469cac7)
#         ;
#
#
#
#
#             var marker_4b807bfb1b832a00377c4918a7b1bccc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2785baf38e09facd7744dbc571b3ea81);
#
#
#         var popup_4af66feac606ea8c46815f3474f795a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b40e5ba2520698d6e009fe4c92a7c47 = $(`&lt;div id=&quot;html_9b40e5ba2520698d6e009fe4c92a7c47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4af66feac606ea8c46815f3474f795a4.setContent(html_9b40e5ba2520698d6e009fe4c92a7c47);
#
#
#
#         marker_4b807bfb1b832a00377c4918a7b1bccc.bindPopup(popup_4af66feac606ea8c46815f3474f795a4)
#         ;
#
#
#
#
#             var marker_0bac676aaba314ce41a7a800f2a1b514 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2785baf38e09facd7744dbc571b3ea81);
#
#
#         var popup_5070bfd1901dee2dd6f3e85944df2af0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d37b1ae3bfad4e0f0ff95b128cf3d16 = $(`&lt;div id=&quot;html_5d37b1ae3bfad4e0f0ff95b128cf3d16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5070bfd1901dee2dd6f3e85944df2af0.setContent(html_5d37b1ae3bfad4e0f0ff95b128cf3d16);
#
#
#
#         marker_
