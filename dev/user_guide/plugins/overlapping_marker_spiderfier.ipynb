# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c6ed8162bde8fd571f9180fb792fa14 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c6ed8162bde8fd571f9180fb792fa14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c6ed8162bde8fd571f9180fb792fa14 = L.map(
#                 &quot;map_6c6ed8162bde8fd571f9180fb792fa14&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20efa1f2565488e67fe13e06d7153859 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20efa1f2565488e67fe13e06d7153859.addTo(map_6c6ed8162bde8fd571f9180fb792fa14);
#
#
#             var marker_f98cdca2ef32c8a0fba03a99d6155981 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6c6ed8162bde8fd571f9180fb792fa14);
#
#
#         var popup_277c255550140433ee2ab46b6f6ef330 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7a64fe75ec5a2b70df61aa709882fc5 = $(`&lt;div id=&quot;html_a7a64fe75ec5a2b70df61aa709882fc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_277c255550140433ee2ab46b6f6ef330.setContent(html_a7a64fe75ec5a2b70df61aa709882fc5);
#
#
#
#         marker_f98cdca2ef32c8a0fba03a99d6155981.bindPopup(popup_277c255550140433ee2ab46b6f6ef330)
#         ;
#
#
#
#
#             var marker_eae6b409a3c83b1df6d597c0b5294bce = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6c6ed8162bde8fd571f9180fb792fa14);
#
#
#         var popup_605d7d1ee9482bda83ffb820cfc42799 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6bdca29a786396e471a0f396ef2bb8c = $(`&lt;div id=&quot;html_b6bdca29a786396e471a0f396ef2bb8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_605d7d1ee9482bda83ffb820cfc42799.setContent(html_b6bdca29a786396e471a0f396ef2bb8c);
#
#
#
#         marker_eae6b409a3c83b1df6d597c0b5294bce.bindPopup(popup_605d7d1ee9482bda83ffb820cfc42799)
#         ;
#
#
#
#
#             var marker_b8b6c5e79d5ccc87500e5a0482d607ab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6c6ed8162bde8fd571f9180fb792fa14);
#
#
#         var popup_4bb1a14914c4e76dd493ebcdf19dbca4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44ee7d848db1186abc85522a9a58b856 = $(`&lt;div id=&quot;html_44ee7d848db1186abc85522a9a58b856&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4bb1a14914c4e76dd493ebcdf19dbca4.setContent(html_44ee7d848db1186abc85522a9a58b856);
#
#
#
#         marker_b8b6c5e79d5ccc87500e5a0482d607ab.bindPopup(popup_4bb1a14914c4e76dd493ebcdf19dbca4)
#         ;
#
#
#
#
#             var marker_bb8f6460bec660459733fb5bd7ca26d7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6c6ed8162bde8fd571f9180fb792fa14);
#
#
#         var popup_4b7a8352f39c225639d6eea1c94511bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a95242bdc315d91cf9d4a98510cf2d51 = $(`&lt;div id=&quot;html_a95242bdc315d91cf9d4a98510cf2d51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4b7a8352f39c225639d6eea1c94511bc.setContent(html_a95242bdc315d91cf9d4a98510cf2d51);
#
#
#
#         marker_bb8f6460bec660459733fb5bd7ca26d7.bindPopup(popup_4b7a8352f39c225639d6eea1c94511bc)
#         ;
#
#
#
#
#             var marker_a17534f6c10e937db1489f4d5b7415ae = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6c6ed8162bde8fd571f9180fb792fa14);
#
#
#         var popup_920feb06158a236c7fb203bc539f8d9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71fa13bcf33250791199945fef891f81 = $(`&lt;div id=&quot;html_71fa13bcf33250791199945fef891f81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_920feb06158a236c7fb203bc539f8d

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_69111b4c758d0e451a859e37b07758d5 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_69111b4c758d0e451a859e37b07758d5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_69111b4c758d0e451a859e37b07758d5 = L.map(
#                 &quot;map_69111b4c758d0e451a859e37b07758d5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a88dcc9c2a953460578af13c467c3ed9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a88dcc9c2a953460578af13c467c3ed9.addTo(map_69111b4c758d0e451a859e37b07758d5);
#
#
#             var feature_group_669e1958589e5ad3480e96f4809de283 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ace897121b979c1a4e9bd22ba7ffc20b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_669e1958589e5ad3480e96f4809de283);
#
#
#         var popup_c97b464702a73d5222e2dda84a7e038f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1abed2fb6a5b985803f48656b4b1a86 = $(`&lt;div id=&quot;html_d1abed2fb6a5b985803f48656b4b1a86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c97b464702a73d5222e2dda84a7e038f.setContent(html_d1abed2fb6a5b985803f48656b4b1a86);
#
#
#
#         marker_ace897121b979c1a4e9bd22ba7ffc20b.bindPopup(popup_c97b464702a73d5222e2dda84a7e038f)
#         ;
#
#
#
#
#             var marker_3ab0e0422aafadcfd8fc283419adf0a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_669e1958589e5ad3480e96f4809de283);
#
#
#         var popup_1b6731f04530708fce10fd5a52a55866 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a57e9e50ffec6bc9751d07058210182a = $(`&lt;div id=&quot;html_a57e9e50ffec6bc9751d07058210182a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1b6731f04530708fce10fd5a52a55866.setContent(html_a57e9e50ffec6bc9751d07058210182a);
#
#
#
#         marker_3ab0e0422aafadcfd8fc283419adf0a7.bindPopup(popup_1b6731f04530708fce10fd5a52a55866)
#         ;
#
#
#
#
#             var marker_2972312d5d4ff7283a55cea029953b52 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_669e1958589e5ad3480e96f4809de283);
#
#
#         var popup_f0acbd56dda21e572835e09c6f7bed35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89fa2c9ae6472115f4c6bdcc5400bd1c = $(`&lt;div id=&quot;html_89fa2c9ae6472115f4c6bdcc5400bd1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f0acbd56dda21e572835e09c6f7bed35.setContent(html_89fa2c9ae6472115f4c6bdcc5400bd1c);
#
#
#
#         marker_2972312d5d4ff7283a55cea029953b52.bindPopup(popup_f0acbd56dda21e572835e09c6f7bed35)
#         ;
#
#
#
#
#             var marker_4347f1959a4e7c1075f709ef303ec2cb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_669e1958589e5ad3480e96f4809de283);
#
#
#         var popup_cc812a1f2022f76b570455404aa9328b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_854b564ae5fd97ea92cdab842a30f534 = $(`&lt;div id=&quot;html_854b564ae5fd97ea92cdab842a30f534&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cc812a1f2022f76b570455404aa9328b.setContent(html_854b564ae5fd97ea92cdab842a30f534);
#
#
#
#         marker_4347f1959a4e7c1075f709ef303ec2cb.bindPopup(popup_cc812a1f2022f76b570455404aa9328b)
#         ;
#
#
#
#
#             var marker_979997b0c08154fe7566e15467ff0615 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_669e1958589e5ad3480e96f4809de283);
#
#
#         var popup_617cada584cc375ffe5fb65d7fc961e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_366cbbd3924bc1ef9b33ade25f40e59a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_366cbbd3924bc1ef9b33ade25f40e59a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_366cbbd3924bc1ef9b33ade25f40e59a = L.map(
#                 &quot;map_366cbbd3924bc1ef9b33ade25f40e59a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5fcb9c863ca6038b7c5fce0ecbc69a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5fcb9c863ca6038b7c5fce0ecbc69a0.addTo(map_366cbbd3924bc1ef9b33ade25f40e59a);
#
#
#             var feature_group_def74148662976e6a628e6284a791311 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_def74148662976e6a628e6284a791311.addTo(map_366cbbd3924bc1ef9b33ade25f40e59a);
#
#
#             var feature_group_sub_group_8213dfd5bfb4204933b4020a419d54a8 = L.featureGroup.subGroup(
#                 feature_group_def74148662976e6a628e6284a791311
#             );
#
#
#             var marker_62af43c98226677c2838628ea7124b7e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8213dfd5bfb4204933b4020a419d54a8);
#
#
#         var popup_5f093907dd090d0e93ecc9e1b4f9938d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9becbfd1d85cc06f77b8ab79a21b8f41 = $(`&lt;div id=&quot;html_9becbfd1d85cc06f77b8ab79a21b8f41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5f093907dd090d0e93ecc9e1b4f9938d.setContent(html_9becbfd1d85cc06f77b8ab79a21b8f41);
#
#
#
#         marker_62af43c98226677c2838628ea7124b7e.bindPopup(popup_5f093907dd090d0e93ecc9e1b4f9938d)
#         ;
#
#
#
#
#             var marker_264fe3fae88c2b8e7da38698f8eb5e35 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8213dfd5bfb4204933b4020a419d54a8);
#
#
#         var popup_1e1a00a6d571e5d33e49726ae3a3aea9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_838273891d6d66f259bbee82d113c766 = $(`&lt;div id=&quot;html_838273891d6d66f259bbee82d113c766&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1e1a00a6d571e5d33e49726ae3a3aea9.setContent(html_838273891d6d66f259bbee82d113c766);
#
#
#
#         marker_264fe3fae88c2b8e7da38698f8eb5e35.bindPopup(popup_1e1a00a6d571e5d33e49726ae3a3aea9)
#         ;
#
#
#
#
#             var marker_fd9cece8218cc8cff8f602f676489842 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8213dfd5bfb4204933b4020a419d54a8);
#
#
#         var popup_5218662c3696a83590ff60b0f4c507ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33d50e03b9559fa8f71015083646c0ac = $(`&lt;div id=&quot;html_33d50e03b9559fa8f71015083646c0ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5218662c3696a83590ff60b0f4c507ca.setContent(html_33d50e03b9559fa8f71015083646c0ac);
#
#
#
#         marker_fd9cece8218cc8cff8f602f676489842.bindPopup(popup_5218662c3696a83590ff60b0f4c507ca)
#         ;
#
#
#
#
#             var marker_4bd8a9332af159fb99a69167585072d9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8213dfd5bfb4204933b4020a419d54a8);
#
#
#         var popup_bfb4dd9bc39ae5428df3bd7dc580b672 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f36509327cd8858da7a8054243cd9366 = $(`&lt;div id=&quot;html_f36509327cd8858da7a8054243cd9366&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bfb4dd9bc39ae5428df3bd7dc580b672.setContent(html_f36509327cd8858da7a8054243cd9366);
#
#
#
#         mark
