# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cbb8de0457de9f2a3e813dbdc664c4b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cbb8de0457de9f2a3e813dbdc664c4b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cbb8de0457de9f2a3e813dbdc664c4b4 = L.map(
#                 &quot;map_cbb8de0457de9f2a3e813dbdc664c4b4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e65a612fd391a84c656c784c0918892 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e65a612fd391a84c656c784c0918892.addTo(map_cbb8de0457de9f2a3e813dbdc664c4b4);
#
#
#             var marker_437a555509c4952cb30a879a5570fcaa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cbb8de0457de9f2a3e813dbdc664c4b4);
#
#
#         var popup_3ff4dc0701857518f28c07ba05817f8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abf30bbffab1ba97a07d026af21ac457 = $(`&lt;div id=&quot;html_abf30bbffab1ba97a07d026af21ac457&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3ff4dc0701857518f28c07ba05817f8d.setContent(html_abf30bbffab1ba97a07d026af21ac457);
#
#
#
#         marker_437a555509c4952cb30a879a5570fcaa.bindPopup(popup_3ff4dc0701857518f28c07ba05817f8d)
#         ;
#
#
#
#
#             var marker_960f0ef063afa8907812f55144e4c8d7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cbb8de0457de9f2a3e813dbdc664c4b4);
#
#
#         var popup_62e63b78a6998e58990242b5119ed239 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c094770b9fc7bd44403b768d8c1c2b6 = $(`&lt;div id=&quot;html_2c094770b9fc7bd44403b768d8c1c2b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_62e63b78a6998e58990242b5119ed239.setContent(html_2c094770b9fc7bd44403b768d8c1c2b6);
#
#
#
#         marker_960f0ef063afa8907812f55144e4c8d7.bindPopup(popup_62e63b78a6998e58990242b5119ed239)
#         ;
#
#
#
#
#             var marker_5761ae64a8bc2ff2b8ea9d43b2fbf21c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cbb8de0457de9f2a3e813dbdc664c4b4);
#
#
#         var popup_e96417ec0de3abf159e13083adee6c64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56b27dbd462e3fad5ce533d869235187 = $(`&lt;div id=&quot;html_56b27dbd462e3fad5ce533d869235187&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e96417ec0de3abf159e13083adee6c64.setContent(html_56b27dbd462e3fad5ce533d869235187);
#
#
#
#         marker_5761ae64a8bc2ff2b8ea9d43b2fbf21c.bindPopup(popup_e96417ec0de3abf159e13083adee6c64)
#         ;
#
#
#
#
#             var marker_88e8fd7e8d7d68dbe8768006e04040c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cbb8de0457de9f2a3e813dbdc664c4b4);
#
#
#         var popup_cd3870995c8f557738cb5eeda6d26e89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f10626a80ce1702cd6b6bc7ced1ec004 = $(`&lt;div id=&quot;html_f10626a80ce1702cd6b6bc7ced1ec004&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cd3870995c8f557738cb5eeda6d26e89.setContent(html_f10626a80ce1702cd6b6bc7ced1ec004);
#
#
#
#         marker_88e8fd7e8d7d68dbe8768006e04040c8.bindPopup(popup_cd3870995c8f557738cb5eeda6d26e89)
#         ;
#
#
#
#
#             var marker_dbce2ab8cbe891dc2c37b63a91abe0c7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cbb8de0457de9f2a3e813dbdc664c4b4);
#
#
#         var popup_167a6ebda36d2d39ee1be659856abbe7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40482fbffe414b082856dbc57ebd0280 = $(`&lt;div id=&quot;html_40482fbffe414b082856dbc57ebd0280&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_167a6ebda36d2d39ee1be659856abbe7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2dc52aefd1828dfd5b70718c9584cda {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2dc52aefd1828dfd5b70718c9584cda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2dc52aefd1828dfd5b70718c9584cda = L.map(
#                 &quot;map_a2dc52aefd1828dfd5b70718c9584cda&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c78e8daca70ec57232ae910adab5f44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c78e8daca70ec57232ae910adab5f44.addTo(map_a2dc52aefd1828dfd5b70718c9584cda);
#
#
#             var feature_group_f1f1a93c10811ac9e2b43361f4959836 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_88a7f84867e5bd255cfe051349ac27cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f1f1a93c10811ac9e2b43361f4959836);
#
#
#         var popup_4ad6286a274d39426318c0fec1914b70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_163c7e402f38639f05e177898e367bc6 = $(`&lt;div id=&quot;html_163c7e402f38639f05e177898e367bc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4ad6286a274d39426318c0fec1914b70.setContent(html_163c7e402f38639f05e177898e367bc6);
#
#
#
#         marker_88a7f84867e5bd255cfe051349ac27cc.bindPopup(popup_4ad6286a274d39426318c0fec1914b70)
#         ;
#
#
#
#
#             var marker_77986e5bb20c62c73a914480b0fb51ff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f1f1a93c10811ac9e2b43361f4959836);
#
#
#         var popup_849bc51a76f630080cd34970eb6d5431 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d051c136a6ad7bbf87452dca8ec5cfa = $(`&lt;div id=&quot;html_0d051c136a6ad7bbf87452dca8ec5cfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_849bc51a76f630080cd34970eb6d5431.setContent(html_0d051c136a6ad7bbf87452dca8ec5cfa);
#
#
#
#         marker_77986e5bb20c62c73a914480b0fb51ff.bindPopup(popup_849bc51a76f630080cd34970eb6d5431)
#         ;
#
#
#
#
#             var marker_822dc1aac318e43c4641db0912c949f7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f1f1a93c10811ac9e2b43361f4959836);
#
#
#         var popup_fd60c1e3f9c8637f0dc22559e291bf5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fb9f7044fe2da13a238af779abc4b41 = $(`&lt;div id=&quot;html_9fb9f7044fe2da13a238af779abc4b41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fd60c1e3f9c8637f0dc22559e291bf5d.setContent(html_9fb9f7044fe2da13a238af779abc4b41);
#
#
#
#         marker_822dc1aac318e43c4641db0912c949f7.bindPopup(popup_fd60c1e3f9c8637f0dc22559e291bf5d)
#         ;
#
#
#
#
#             var marker_6d12aece322532b6ad44bd6acb014e07 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f1f1a93c10811ac9e2b43361f4959836);
#
#
#         var popup_9a8a07ae7ea13216965632163068c58a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abf9c2dc95ee919dffa0eefe236fa3d3 = $(`&lt;div id=&quot;html_abf9c2dc95ee919dffa0eefe236fa3d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9a8a07ae7ea13216965632163068c58a.setContent(html_abf9c2dc95ee919dffa0eefe236fa3d3);
#
#
#
#         marker_6d12aece322532b6ad44bd6acb014e07.bindPopup(popup_9a8a07ae7ea13216965632163068c58a)
#         ;
#
#
#
#
#             var marker_037fb0ace814c6934da64167542b8ba1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f1f1a93c10811ac9e2b43361f4959836);
#
#
#         var popup_2fa7cf7a02c3799cbc8f97ec27e3df39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7780454a0f8e3e560fa143f1d7d4a5a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7780454a0f8e3e560fa143f1d7d4a5a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7780454a0f8e3e560fa143f1d7d4a5a8 = L.map(
#                 &quot;map_7780454a0f8e3e560fa143f1d7d4a5a8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85fa9389c2f4b6e75ce374386061689b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85fa9389c2f4b6e75ce374386061689b.addTo(map_7780454a0f8e3e560fa143f1d7d4a5a8);
#
#
#             var feature_group_403681a394043bad4e8d12684082f8c4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_403681a394043bad4e8d12684082f8c4.addTo(map_7780454a0f8e3e560fa143f1d7d4a5a8);
#
#
#             var feature_group_sub_group_a8c012a0a5f295993006ae7fa580218a = L.featureGroup.subGroup(
#                 feature_group_403681a394043bad4e8d12684082f8c4
#             );
#
#
#             var marker_3defea6481db80dc59a2c1ebb6be6fb0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8c012a0a5f295993006ae7fa580218a);
#
#
#         var popup_c6dc839449ccac98ecd61fc132373573 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7efae9da73d26c87918bf7880166454 = $(`&lt;div id=&quot;html_d7efae9da73d26c87918bf7880166454&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c6dc839449ccac98ecd61fc132373573.setContent(html_d7efae9da73d26c87918bf7880166454);
#
#
#
#         marker_3defea6481db80dc59a2c1ebb6be6fb0.bindPopup(popup_c6dc839449ccac98ecd61fc132373573)
#         ;
#
#
#
#
#             var marker_86314e85e5a0e02d8c4c45b85a667c8b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8c012a0a5f295993006ae7fa580218a);
#
#
#         var popup_286bc926b2a6bee98e1e83947cb1df84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_545c4ead2075d31fcf96db81a240b2fa = $(`&lt;div id=&quot;html_545c4ead2075d31fcf96db81a240b2fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_286bc926b2a6bee98e1e83947cb1df84.setContent(html_545c4ead2075d31fcf96db81a240b2fa);
#
#
#
#         marker_86314e85e5a0e02d8c4c45b85a667c8b.bindPopup(popup_286bc926b2a6bee98e1e83947cb1df84)
#         ;
#
#
#
#
#             var marker_bd6b414a292e15051652f4829fa6b764 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8c012a0a5f295993006ae7fa580218a);
#
#
#         var popup_9fbfff125a195e7c693a0c83f2475098 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dc16cb3a971db35f3506451493a80b7 = $(`&lt;div id=&quot;html_7dc16cb3a971db35f3506451493a80b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9fbfff125a195e7c693a0c83f2475098.setContent(html_7dc16cb3a971db35f3506451493a80b7);
#
#
#
#         marker_bd6b414a292e15051652f4829fa6b764.bindPopup(popup_9fbfff125a195e7c693a0c83f2475098)
#         ;
#
#
#
#
#             var marker_1a0db5362b329053833fb1693d10eb09 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8c012a0a5f295993006ae7fa580218a);
#
#
#         var popup_aea646c3ff4d7c21498e667158d4328e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e20fc7e79c47edb11ec8c9b116207170 = $(`&lt;div id=&quot;html_e20fc7e79c47edb11ec8c9b116207170&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_aea646c3ff4d7c21498e667158d4328e.setContent(html_e20fc7e79c47edb11ec8c9b116207170);
#
#
#
#         marker_
