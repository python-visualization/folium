# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7937817bccc0a785f555f1f3ec6f16af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7937817bccc0a785f555f1f3ec6f16af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7937817bccc0a785f555f1f3ec6f16af = L.map(
#                 &quot;map_7937817bccc0a785f555f1f3ec6f16af&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc637321c7647e627d2ac87b2dffb7fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc637321c7647e627d2ac87b2dffb7fb.addTo(map_7937817bccc0a785f555f1f3ec6f16af);
#
#
#             var marker_918272b256ac45e3d6bf9142820e2c02 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7937817bccc0a785f555f1f3ec6f16af);
#
#
#         var popup_1d5ccb303a1cf6b211789581523839ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f15abdbeb3a9c37ad34da5d092842828 = $(`&lt;div id=&quot;html_f15abdbeb3a9c37ad34da5d092842828&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1d5ccb303a1cf6b211789581523839ef.setContent(html_f15abdbeb3a9c37ad34da5d092842828);
#
#
#
#         marker_918272b256ac45e3d6bf9142820e2c02.bindPopup(popup_1d5ccb303a1cf6b211789581523839ef)
#         ;
#
#
#
#
#             var marker_85eff970f24cf6c894e0ce78315b66e7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7937817bccc0a785f555f1f3ec6f16af);
#
#
#         var popup_bc314a94359b89a2d9baf4096f9c00a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2c5626d2843482d2e37a3b5f011303d = $(`&lt;div id=&quot;html_c2c5626d2843482d2e37a3b5f011303d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bc314a94359b89a2d9baf4096f9c00a6.setContent(html_c2c5626d2843482d2e37a3b5f011303d);
#
#
#
#         marker_85eff970f24cf6c894e0ce78315b66e7.bindPopup(popup_bc314a94359b89a2d9baf4096f9c00a6)
#         ;
#
#
#
#
#             var marker_10d127fe7dd4a6eb4a588f885acc5c30 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7937817bccc0a785f555f1f3ec6f16af);
#
#
#         var popup_2e2e06140301ce975d0898d3f3fbe464 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6649822697ef276b1103c117dfb9b053 = $(`&lt;div id=&quot;html_6649822697ef276b1103c117dfb9b053&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2e2e06140301ce975d0898d3f3fbe464.setContent(html_6649822697ef276b1103c117dfb9b053);
#
#
#
#         marker_10d127fe7dd4a6eb4a588f885acc5c30.bindPopup(popup_2e2e06140301ce975d0898d3f3fbe464)
#         ;
#
#
#
#
#             var marker_f3ba4ccbd0ca6c5e82d379bfa88f6f44 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7937817bccc0a785f555f1f3ec6f16af);
#
#
#         var popup_9be783e6f2d31351502323c5936aaab5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_180fe8e63d86e2cc3777e974660df563 = $(`&lt;div id=&quot;html_180fe8e63d86e2cc3777e974660df563&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9be783e6f2d31351502323c5936aaab5.setContent(html_180fe8e63d86e2cc3777e974660df563);
#
#
#
#         marker_f3ba4ccbd0ca6c5e82d379bfa88f6f44.bindPopup(popup_9be783e6f2d31351502323c5936aaab5)
#         ;
#
#
#
#
#             var marker_bd50c9340ad67a73f68e7e695772a20a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7937817bccc0a785f555f1f3ec6f16af);
#
#
#         var popup_7ac7e47414a2487f9ace45b9b2229833 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_617df382628832d60aba5a9a464be08f = $(`&lt;div id=&quot;html_617df382628832d60aba5a9a464be08f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7ac7e47414a2487f9ace45b9b2229833.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3e523324f29d0e842024affe37a3fb0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3e523324f29d0e842024affe37a3fb0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3e523324f29d0e842024affe37a3fb0 = L.map(
#                 &quot;map_f3e523324f29d0e842024affe37a3fb0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9f609a4bf96f69d4a7629631075d64f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9f609a4bf96f69d4a7629631075d64f.addTo(map_f3e523324f29d0e842024affe37a3fb0);
#
#
#             var feature_group_ddc283b86d2354b5ff414ecec539f43e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1e2b04974fba1f755882fec755b297d9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ddc283b86d2354b5ff414ecec539f43e);
#
#
#         var popup_30fc6eba9da66dabfa8ff79c01ae6b7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22009aefcdede1c0b3e7b4bd298c52f1 = $(`&lt;div id=&quot;html_22009aefcdede1c0b3e7b4bd298c52f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_30fc6eba9da66dabfa8ff79c01ae6b7d.setContent(html_22009aefcdede1c0b3e7b4bd298c52f1);
#
#
#
#         marker_1e2b04974fba1f755882fec755b297d9.bindPopup(popup_30fc6eba9da66dabfa8ff79c01ae6b7d)
#         ;
#
#
#
#
#             var marker_0f1e99cba2e73d1743e29c9ed6b105db = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ddc283b86d2354b5ff414ecec539f43e);
#
#
#         var popup_2b1a3f2aa7a3f5543df74e1108b4c761 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e545c1a6a7702ed441b1b0ed370dd7eb = $(`&lt;div id=&quot;html_e545c1a6a7702ed441b1b0ed370dd7eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2b1a3f2aa7a3f5543df74e1108b4c761.setContent(html_e545c1a6a7702ed441b1b0ed370dd7eb);
#
#
#
#         marker_0f1e99cba2e73d1743e29c9ed6b105db.bindPopup(popup_2b1a3f2aa7a3f5543df74e1108b4c761)
#         ;
#
#
#
#
#             var marker_f1d63b5f85fcb638e7c54f1617ee0bc2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ddc283b86d2354b5ff414ecec539f43e);
#
#
#         var popup_1f9b8e74e2469403d96255861de24b1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd6bb7fa5d3430e85be5c8ad51d55e32 = $(`&lt;div id=&quot;html_fd6bb7fa5d3430e85be5c8ad51d55e32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1f9b8e74e2469403d96255861de24b1e.setContent(html_fd6bb7fa5d3430e85be5c8ad51d55e32);
#
#
#
#         marker_f1d63b5f85fcb638e7c54f1617ee0bc2.bindPopup(popup_1f9b8e74e2469403d96255861de24b1e)
#         ;
#
#
#
#
#             var marker_1ee734b7de87143b25e83d4ca11203b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ddc283b86d2354b5ff414ecec539f43e);
#
#
#         var popup_b940d14ee653a48b5f076c082d899d20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9034be77a34bc424a7730faea19e673e = $(`&lt;div id=&quot;html_9034be77a34bc424a7730faea19e673e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b940d14ee653a48b5f076c082d899d20.setContent(html_9034be77a34bc424a7730faea19e673e);
#
#
#
#         marker_1ee734b7de87143b25e83d4ca11203b2.bindPopup(popup_b940d14ee653a48b5f076c082d899d20)
#         ;
#
#
#
#
#             var marker_9be4deb0d0533c817f6cdcaf44b19e10 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ddc283b86d2354b5ff414ecec539f43e);
#
#
#         var popup_ea2b0cfe34f09036b7f7ec01b684b0d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f057a6be67fe9a1bdf6019108c5eee00 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f057a6be67fe9a1bdf6019108c5eee00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f057a6be67fe9a1bdf6019108c5eee00 = L.map(
#                 &quot;map_f057a6be67fe9a1bdf6019108c5eee00&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6ed17fe96f896aa638f55ae484700d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6ed17fe96f896aa638f55ae484700d3.addTo(map_f057a6be67fe9a1bdf6019108c5eee00);
#
#
#             var feature_group_f4351f68a24ebcc0fef03c740df0b8ae = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f4351f68a24ebcc0fef03c740df0b8ae.addTo(map_f057a6be67fe9a1bdf6019108c5eee00);
#
#
#             var feature_group_sub_group_25606b3b0f24b28c85a8af96daa4bf57 = L.featureGroup.subGroup(
#                 feature_group_f4351f68a24ebcc0fef03c740df0b8ae
#             );
#
#
#             var marker_6fc77f2ebbed7f75c030ad690a256282 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_25606b3b0f24b28c85a8af96daa4bf57);
#
#
#         var popup_75f7dc418acbf3b66b09b0f607c07e7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89ea476a1e47f10ef5368ca3c80e8c5f = $(`&lt;div id=&quot;html_89ea476a1e47f10ef5368ca3c80e8c5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_75f7dc418acbf3b66b09b0f607c07e7b.setContent(html_89ea476a1e47f10ef5368ca3c80e8c5f);
#
#
#
#         marker_6fc77f2ebbed7f75c030ad690a256282.bindPopup(popup_75f7dc418acbf3b66b09b0f607c07e7b)
#         ;
#
#
#
#
#             var marker_c00d737ef9338af7e9584a5207dcf1f0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_25606b3b0f24b28c85a8af96daa4bf57);
#
#
#         var popup_3253a247ab61a36721fa58dd19781b9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca96e97583bbe165d5a6f4d1fba10b1c = $(`&lt;div id=&quot;html_ca96e97583bbe165d5a6f4d1fba10b1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3253a247ab61a36721fa58dd19781b9f.setContent(html_ca96e97583bbe165d5a6f4d1fba10b1c);
#
#
#
#         marker_c00d737ef9338af7e9584a5207dcf1f0.bindPopup(popup_3253a247ab61a36721fa58dd19781b9f)
#         ;
#
#
#
#
#             var marker_907969e23b15f66a6005385d74e898e3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_25606b3b0f24b28c85a8af96daa4bf57);
#
#
#         var popup_6a93f196ed17dd4f167f97683b1737e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1d0b3e03f64253abf420c4e939a6a30 = $(`&lt;div id=&quot;html_d1d0b3e03f64253abf420c4e939a6a30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6a93f196ed17dd4f167f97683b1737e1.setContent(html_d1d0b3e03f64253abf420c4e939a6a30);
#
#
#
#         marker_907969e23b15f66a6005385d74e898e3.bindPopup(popup_6a93f196ed17dd4f167f97683b1737e1)
#         ;
#
#
#
#
#             var marker_1832ed16e0b77f9f6d624e6a76cfc687 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_25606b3b0f24b28c85a8af96daa4bf57);
#
#
#         var popup_05ebf3a45309629d2d0b991a962427bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8fb507bdcfa41d6b277343349b96408 = $(`&lt;div id=&quot;html_f8fb507bdcfa41d6b277343349b96408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_05ebf3a45309629d2d0b991a962427bf.setContent(html_f8fb507bdcfa41d6b277343349b96408);
#
#
#
#         marker_
