# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fac6f42cf933ba15d6363961eaa726e2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fac6f42cf933ba15d6363961eaa726e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fac6f42cf933ba15d6363961eaa726e2 = L.map(
#                 &quot;map_fac6f42cf933ba15d6363961eaa726e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5b5b5229e37888c4c49155e5908e802 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5b5b5229e37888c4c49155e5908e802.addTo(map_fac6f42cf933ba15d6363961eaa726e2);
#
#
#             var marker_1b55a43ec1a30707718f7f5d8ea4a42a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fac6f42cf933ba15d6363961eaa726e2);
#
#
#         var popup_42f8c5526de33d95ca0a0cdfd52c78f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53c4abb637a82332ed00486a77f27aa1 = $(`&lt;div id=&quot;html_53c4abb637a82332ed00486a77f27aa1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_42f8c5526de33d95ca0a0cdfd52c78f6.setContent(html_53c4abb637a82332ed00486a77f27aa1);
#
#
#
#         marker_1b55a43ec1a30707718f7f5d8ea4a42a.bindPopup(popup_42f8c5526de33d95ca0a0cdfd52c78f6)
#         ;
#
#
#
#
#             var marker_bca5ca683da5b38f8369c554388a1959 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fac6f42cf933ba15d6363961eaa726e2);
#
#
#         var popup_b1637436ff83c49b0578f392213f1417 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58ab3d54c7d90a82a1bf5600de45bb7b = $(`&lt;div id=&quot;html_58ab3d54c7d90a82a1bf5600de45bb7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b1637436ff83c49b0578f392213f1417.setContent(html_58ab3d54c7d90a82a1bf5600de45bb7b);
#
#
#
#         marker_bca5ca683da5b38f8369c554388a1959.bindPopup(popup_b1637436ff83c49b0578f392213f1417)
#         ;
#
#
#
#
#             var marker_4f264cbde8d7b635842e76400289a498 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fac6f42cf933ba15d6363961eaa726e2);
#
#
#         var popup_9310a3302227f34c1c6fecbb4978f49e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9a8e395dd857e8a6cb3bf81cf28db25 = $(`&lt;div id=&quot;html_c9a8e395dd857e8a6cb3bf81cf28db25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9310a3302227f34c1c6fecbb4978f49e.setContent(html_c9a8e395dd857e8a6cb3bf81cf28db25);
#
#
#
#         marker_4f264cbde8d7b635842e76400289a498.bindPopup(popup_9310a3302227f34c1c6fecbb4978f49e)
#         ;
#
#
#
#
#             var marker_1c6bd68bf69b5ac8f90f481fcb69674c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fac6f42cf933ba15d6363961eaa726e2);
#
#
#         var popup_6513a195e87493f66268eb309f457faa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af33357559262e29e40ab20c7c1f2b30 = $(`&lt;div id=&quot;html_af33357559262e29e40ab20c7c1f2b30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6513a195e87493f66268eb309f457faa.setContent(html_af33357559262e29e40ab20c7c1f2b30);
#
#
#
#         marker_1c6bd68bf69b5ac8f90f481fcb69674c.bindPopup(popup_6513a195e87493f66268eb309f457faa)
#         ;
#
#
#
#
#             var marker_cdd387089920f3bb9208d2d0ea1a6e6e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fac6f42cf933ba15d6363961eaa726e2);
#
#
#         var popup_1a73f5c65270ea81283eee3e6a4247fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6eba20d9ad780505787a1fb35da2331 = $(`&lt;div id=&quot;html_f6eba20d9ad780505787a1fb35da2331&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1a73f5c65270ea81283eee3e6a4247fe.setContent(html_f6eba20d9ad780505787a1fb35da2331);
#
#
#
#         marker_cdd387089920f3bb9208d2d0ea1a6e6e.bindPopup(popup_1a73f5c65270ea81283eee3e6a4247fe)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_192721ae5dd2fec53e8475ae555f0f5f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_192721ae5dd2fec53e8475ae555f0f5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_192721ae5dd2fec53e8475ae555f0f5f = L.map(
#                 &quot;map_192721ae5dd2fec53e8475ae555f0f5f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd8becc947cc5ae255b54ae6d431ea93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd8becc947cc5ae255b54ae6d431ea93.addTo(map_192721ae5dd2fec53e8475ae555f0f5f);
#
#
#             var feature_group_1cc1a1eb2a285f5997dcf29baba25fe2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_aaa0867212450fce069108033bde4c17 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1cc1a1eb2a285f5997dcf29baba25fe2);
#
#
#         var popup_26bb6fefdf8211fdab5a12bea2710b9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fc4b30294d5b57e6cd181d167e677c3 = $(`&lt;div id=&quot;html_4fc4b30294d5b57e6cd181d167e677c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_26bb6fefdf8211fdab5a12bea2710b9a.setContent(html_4fc4b30294d5b57e6cd181d167e677c3);
#
#
#
#         marker_aaa0867212450fce069108033bde4c17.bindPopup(popup_26bb6fefdf8211fdab5a12bea2710b9a)
#         ;
#
#
#
#
#             var marker_4d0c1fd91e366266107318b8f5928134 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1cc1a1eb2a285f5997dcf29baba25fe2);
#
#
#         var popup_d13714fd7bcf1ca75f9069aa1e08648e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d77033013a4d8b6a4d37db6ce33ff71b = $(`&lt;div id=&quot;html_d77033013a4d8b6a4d37db6ce33ff71b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d13714fd7bcf1ca75f9069aa1e08648e.setContent(html_d77033013a4d8b6a4d37db6ce33ff71b);
#
#
#
#         marker_4d0c1fd91e366266107318b8f5928134.bindPopup(popup_d13714fd7bcf1ca75f9069aa1e08648e)
#         ;
#
#
#
#
#             var marker_aa2bd1db789e4d4a86f377276831bed7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1cc1a1eb2a285f5997dcf29baba25fe2);
#
#
#         var popup_a58b5974f0adc68a4c133731c1239c09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_240846084d329214020f4769b61d49fb = $(`&lt;div id=&quot;html_240846084d329214020f4769b61d49fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a58b5974f0adc68a4c133731c1239c09.setContent(html_240846084d329214020f4769b61d49fb);
#
#
#
#         marker_aa2bd1db789e4d4a86f377276831bed7.bindPopup(popup_a58b5974f0adc68a4c133731c1239c09)
#         ;
#
#
#
#
#             var marker_a601a558da300aa3dec8e78c8eba71f9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1cc1a1eb2a285f5997dcf29baba25fe2);
#
#
#         var popup_20f176bb4db07b07d682df4578a93de6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22f53b0ceb3103e28c9852895dcdc6c1 = $(`&lt;div id=&quot;html_22f53b0ceb3103e28c9852895dcdc6c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_20f176bb4db07b07d682df4578a93de6.setContent(html_22f53b0ceb3103e28c9852895dcdc6c1);
#
#
#
#         marker_a601a558da300aa3dec8e78c8eba71f9.bindPopup(popup_20f176bb4db07b07d682df4578a93de6)
#         ;
#
#
#
#
#             var marker_a5ebcc030892a43ca2c9fe7f2266d861 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1cc1a1eb2a285f5997dcf29baba25fe2);
#
#
#         var popup_4bc0544e3d18132d6de3543a9e3b17c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d33407c4842744c3a62a5f932bd64b4a = $(`&lt;div id=&quot;html_d33407c4842744c3a62a5f932bd64b4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03933aca869f69707ec840223ede8722 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03933aca869f69707ec840223ede8722&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03933aca869f69707ec840223ede8722 = L.map(
#                 &quot;map_03933aca869f69707ec840223ede8722&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2a896a2e4d3cbea7553d97379e012c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2a896a2e4d3cbea7553d97379e012c1.addTo(map_03933aca869f69707ec840223ede8722);
#
#
#             var feature_group_6a3612dac0e3a19aea51d6ea6f84f68b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6a3612dac0e3a19aea51d6ea6f84f68b.addTo(map_03933aca869f69707ec840223ede8722);
#
#
#             var feature_group_sub_group_10e6b80136d4775383e476390a5bd118 = L.featureGroup.subGroup(
#                 feature_group_6a3612dac0e3a19aea51d6ea6f84f68b
#             );
#
#
#             var marker_a577a9f10058e9adc38ae622460af463 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_10e6b80136d4775383e476390a5bd118);
#
#
#         var popup_3fc4b61c83d13a886c0c81ffe2be0dea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d84b41214bbd6380f17250074be63bc = $(`&lt;div id=&quot;html_2d84b41214bbd6380f17250074be63bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3fc4b61c83d13a886c0c81ffe2be0dea.setContent(html_2d84b41214bbd6380f17250074be63bc);
#
#
#
#         marker_a577a9f10058e9adc38ae622460af463.bindPopup(popup_3fc4b61c83d13a886c0c81ffe2be0dea)
#         ;
#
#
#
#
#             var marker_04d421a96e1e66806d832a71328ffba2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_10e6b80136d4775383e476390a5bd118);
#
#
#         var popup_68360ecf64c0e71673c9e916d0a018fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_576f061173047c1eca9cd2a7d8a4e3af = $(`&lt;div id=&quot;html_576f061173047c1eca9cd2a7d8a4e3af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_68360ecf64c0e71673c9e916d0a018fd.setContent(html_576f061173047c1eca9cd2a7d8a4e3af);
#
#
#
#         marker_04d421a96e1e66806d832a71328ffba2.bindPopup(popup_68360ecf64c0e71673c9e916d0a018fd)
#         ;
#
#
#
#
#             var marker_0203bdcb87613cac0f26aa00004b0c91 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_10e6b80136d4775383e476390a5bd118);
#
#
#         var popup_911e223adeef999cf9bfdf5813d84690 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_389d46b778bb38f731ce191d504d0501 = $(`&lt;div id=&quot;html_389d46b778bb38f731ce191d504d0501&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_911e223adeef999cf9bfdf5813d84690.setContent(html_389d46b778bb38f731ce191d504d0501);
#
#
#
#         marker_0203bdcb87613cac0f26aa00004b0c91.bindPopup(popup_911e223adeef999cf9bfdf5813d84690)
#         ;
#
#
#
#
#             var marker_c584f3f3050a9674affa7d984a39463a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_10e6b80136d4775383e476390a5bd118);
#
#
#         var popup_08abe2d928c376e1f63d633708cab644 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0caa6e8e8261d774e2b4c57f20eafd76 = $(`&lt;div id=&quot;html_0caa6e8e8261d774e2b4c57f20eafd76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_08abe2d928c376e1f63d633708cab644.setContent(html_0caa6e8e8261d774e2b4c57f20eafd76);
#
#
#
#         marker_c584f3f3050a9674affa7d984a39463a.bindPopup(popup_08abe2d928c376e1f63d633708cab644)
#         ;
#
#
#
#
#             var marker_3d99387af436e2d9f3f14be649e2e6c1 = L.marker(
#                 [45.0503999
