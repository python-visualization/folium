# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8629991311de4f60b9f7f7fb1bcc87a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8629991311de4f60b9f7f7fb1bcc87a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8629991311de4f60b9f7f7fb1bcc87a5 = L.map(
#                 &quot;map_8629991311de4f60b9f7f7fb1bcc87a5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19e552897a41b3dcd6d4bd539720a244 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_19e552897a41b3dcd6d4bd539720a244.addTo(map_8629991311de4f60b9f7f7fb1bcc87a5);
#
#
#             var marker_9f46a9e71f94399b1ce6980ae409cd82 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8629991311de4f60b9f7f7fb1bcc87a5);
#
#
#         var popup_5de947f92409553d3f39d5b498e2e369 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8e0e2781703a131d7a26b105818d2b1 = $(`&lt;div id=&quot;html_f8e0e2781703a131d7a26b105818d2b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5de947f92409553d3f39d5b498e2e369.setContent(html_f8e0e2781703a131d7a26b105818d2b1);
#
#
#
#         marker_9f46a9e71f94399b1ce6980ae409cd82.bindPopup(popup_5de947f92409553d3f39d5b498e2e369)
#         ;
#
#
#
#
#             var marker_fc512e59d257a48a789b35472caa65f3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8629991311de4f60b9f7f7fb1bcc87a5);
#
#
#         var popup_1ec14ad1878d1cc22cba9abcdce3c7db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50cd95fe11a95af1fc82f17387d1a192 = $(`&lt;div id=&quot;html_50cd95fe11a95af1fc82f17387d1a192&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1ec14ad1878d1cc22cba9abcdce3c7db.setContent(html_50cd95fe11a95af1fc82f17387d1a192);
#
#
#
#         marker_fc512e59d257a48a789b35472caa65f3.bindPopup(popup_1ec14ad1878d1cc22cba9abcdce3c7db)
#         ;
#
#
#
#
#             var marker_863690420de0030d826a5c9444e703c0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8629991311de4f60b9f7f7fb1bcc87a5);
#
#
#         var popup_4f4f5a46d7ea43d6a9b026e846d74024 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac2223b0e4fb048a6d36fb17ce4b193d = $(`&lt;div id=&quot;html_ac2223b0e4fb048a6d36fb17ce4b193d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4f4f5a46d7ea43d6a9b026e846d74024.setContent(html_ac2223b0e4fb048a6d36fb17ce4b193d);
#
#
#
#         marker_863690420de0030d826a5c9444e703c0.bindPopup(popup_4f4f5a46d7ea43d6a9b026e846d74024)
#         ;
#
#
#
#
#             var marker_157d1320f2f8335151ac725ac5712cdf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8629991311de4f60b9f7f7fb1bcc87a5);
#
#
#         var popup_8792cff8287e4a33be650fcf2c30a542 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_feb9bd0565eb0d14964db19e439533f2 = $(`&lt;div id=&quot;html_feb9bd0565eb0d14964db19e439533f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8792cff8287e4a33be650fcf2c30a542.setContent(html_feb9bd0565eb0d14964db19e439533f2);
#
#
#
#         marker_157d1320f2f8335151ac725ac5712cdf.bindPopup(popup_8792cff8287e4a33be650fcf2c30a542)
#         ;
#
#
#
#
#             var marker_eef8d8a9d676f234d3cc6e5b927242d8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8629991311de4f60b9f7f7fb1bcc87a5);
#
#
#         var popup_67a261bf058a8e94995cc37857c26f2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d191824272d2ce845a35ce05d0ca5ad = $(`&lt;div id=&quot;html_9d191824272d2ce845a35ce05d0ca5ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_67a261bf058a8e94995cc37857c26f2e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6b89a9dbb5011bdd7a490bba7bf8689 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6b89a9dbb5011bdd7a490bba7bf8689&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6b89a9dbb5011bdd7a490bba7bf8689 = L.map(
#                 &quot;map_b6b89a9dbb5011bdd7a490bba7bf8689&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4438534d923d2592ba71d9b1c70c5cb9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4438534d923d2592ba71d9b1c70c5cb9.addTo(map_b6b89a9dbb5011bdd7a490bba7bf8689);
#
#
#             var feature_group_f2ffa6b2f5eedfabeec7559f30a41c21 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ccac1eafb866f76d89608b8f3921ba9d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f2ffa6b2f5eedfabeec7559f30a41c21);
#
#
#         var popup_a21942718a41b5f358f16e6cea71e962 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f061fab505c4a277fca871fd767d586d = $(`&lt;div id=&quot;html_f061fab505c4a277fca871fd767d586d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a21942718a41b5f358f16e6cea71e962.setContent(html_f061fab505c4a277fca871fd767d586d);
#
#
#
#         marker_ccac1eafb866f76d89608b8f3921ba9d.bindPopup(popup_a21942718a41b5f358f16e6cea71e962)
#         ;
#
#
#
#
#             var marker_6a076e9002d203afa4dc03381fc761c8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f2ffa6b2f5eedfabeec7559f30a41c21);
#
#
#         var popup_d020720fc7a2a6d2ddaabbe4b001fe34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bb77cd2f4f8aa9e3813f6d06a92f197 = $(`&lt;div id=&quot;html_5bb77cd2f4f8aa9e3813f6d06a92f197&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d020720fc7a2a6d2ddaabbe4b001fe34.setContent(html_5bb77cd2f4f8aa9e3813f6d06a92f197);
#
#
#
#         marker_6a076e9002d203afa4dc03381fc761c8.bindPopup(popup_d020720fc7a2a6d2ddaabbe4b001fe34)
#         ;
#
#
#
#
#             var marker_94e30aa00b71f136ab0993a0f0446291 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f2ffa6b2f5eedfabeec7559f30a41c21);
#
#
#         var popup_e666d71674c838f69e20232ae517eba8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dba20f1d8cef3932a8d975fd9552c21 = $(`&lt;div id=&quot;html_2dba20f1d8cef3932a8d975fd9552c21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e666d71674c838f69e20232ae517eba8.setContent(html_2dba20f1d8cef3932a8d975fd9552c21);
#
#
#
#         marker_94e30aa00b71f136ab0993a0f0446291.bindPopup(popup_e666d71674c838f69e20232ae517eba8)
#         ;
#
#
#
#
#             var marker_85281b2e78e4ba01d1e14cba23589290 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f2ffa6b2f5eedfabeec7559f30a41c21);
#
#
#         var popup_765543ac48027450def6d2d520c21f62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cffc3dfbe3c4d21d6bb091d6912c7dd1 = $(`&lt;div id=&quot;html_cffc3dfbe3c4d21d6bb091d6912c7dd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_765543ac48027450def6d2d520c21f62.setContent(html_cffc3dfbe3c4d21d6bb091d6912c7dd1);
#
#
#
#         marker_85281b2e78e4ba01d1e14cba23589290.bindPopup(popup_765543ac48027450def6d2d520c21f62)
#         ;
#
#
#
#
#             var marker_6c0d00eb14debba3b448b1c78c7bd0d3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f2ffa6b2f5eedfabeec7559f30a41c21);
#
#
#         var popup_089768671ecaae109fef715480c20b1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a193ea1e2b1779798ecbf905fd06531 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a193ea1e2b1779798ecbf905fd06531&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a193ea1e2b1779798ecbf905fd06531 = L.map(
#                 &quot;map_0a193ea1e2b1779798ecbf905fd06531&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b89950a2606a6dbaf35d4038e927c729 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b89950a2606a6dbaf35d4038e927c729.addTo(map_0a193ea1e2b1779798ecbf905fd06531);
#
#
#             var feature_group_72e1f99f0b74f4560babe3e6e7321511 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_72e1f99f0b74f4560babe3e6e7321511.addTo(map_0a193ea1e2b1779798ecbf905fd06531);
#
#
#             var feature_group_sub_group_9fab662ee855fdfb571d922b7ffe3c8a = L.featureGroup.subGroup(
#                 feature_group_72e1f99f0b74f4560babe3e6e7321511
#             );
#
#
#             var marker_a8fc1231e1e117f93564a9a25a5d1aa2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9fab662ee855fdfb571d922b7ffe3c8a);
#
#
#         var popup_fe8982730e5defd5add9a3ad8415b276 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_984f1b768cabd6935e3322241228226c = $(`&lt;div id=&quot;html_984f1b768cabd6935e3322241228226c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fe8982730e5defd5add9a3ad8415b276.setContent(html_984f1b768cabd6935e3322241228226c);
#
#
#
#         marker_a8fc1231e1e117f93564a9a25a5d1aa2.bindPopup(popup_fe8982730e5defd5add9a3ad8415b276)
#         ;
#
#
#
#
#             var marker_0fc649596e9f6a63b02c0a1066dbafa1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9fab662ee855fdfb571d922b7ffe3c8a);
#
#
#         var popup_2a51186737496ccbc6892098dfeaf7d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f79fb21f97694d6a04676bcbcecb284 = $(`&lt;div id=&quot;html_7f79fb21f97694d6a04676bcbcecb284&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2a51186737496ccbc6892098dfeaf7d7.setContent(html_7f79fb21f97694d6a04676bcbcecb284);
#
#
#
#         marker_0fc649596e9f6a63b02c0a1066dbafa1.bindPopup(popup_2a51186737496ccbc6892098dfeaf7d7)
#         ;
#
#
#
#
#             var marker_c91b3c45492b93ec7384aa7fe22b4767 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9fab662ee855fdfb571d922b7ffe3c8a);
#
#
#         var popup_be14fdae7a38a8f75f8b75abd2582051 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_460eca0043fb89158323dd2a8d07beeb = $(`&lt;div id=&quot;html_460eca0043fb89158323dd2a8d07beeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_be14fdae7a38a8f75f8b75abd2582051.setContent(html_460eca0043fb89158323dd2a8d07beeb);
#
#
#
#         marker_c91b3c45492b93ec7384aa7fe22b4767.bindPopup(popup_be14fdae7a38a8f75f8b75abd2582051)
#         ;
#
#
#
#
#             var marker_d01a1870895a23e94b40d4c87c9bff41 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9fab662ee855fdfb571d922b7ffe3c8a);
#
#
#         var popup_c0d7a341bb6b6e957561b9db61faa6b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_671caedd64fed63fd183b8f2a2d3239f = $(`&lt;div id=&quot;html_671caedd64fed63fd183b8f2a2d3239f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c0d7a341bb6b6e957561b9db61faa6b8.setContent(html_671caedd64fed63fd183b8f2a2d3239f);
#
#
#
#         marker_
