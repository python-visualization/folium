# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d9069fc2b105256cccf58bb4aecbd1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d9069fc2b105256cccf58bb4aecbd1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d9069fc2b105256cccf58bb4aecbd1d = L.map(
#                 &quot;map_3d9069fc2b105256cccf58bb4aecbd1d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_165306a37c11e50afebc2acca109c205 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_165306a37c11e50afebc2acca109c205.addTo(map_3d9069fc2b105256cccf58bb4aecbd1d);
#
#
#             var marker_a2a14b9640d50149de7e90b1c3c5a53a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3d9069fc2b105256cccf58bb4aecbd1d);
#
#
#         var popup_a45cc254f8814c348f510702055a16b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ad4bfc603306f8f6d2d290d7b74c08f = $(`&lt;div id=&quot;html_0ad4bfc603306f8f6d2d290d7b74c08f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a45cc254f8814c348f510702055a16b3.setContent(html_0ad4bfc603306f8f6d2d290d7b74c08f);
#
#
#
#         marker_a2a14b9640d50149de7e90b1c3c5a53a.bindPopup(popup_a45cc254f8814c348f510702055a16b3)
#         ;
#
#
#
#
#             var marker_677b759993fa07537a6c167b2cf87c93 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3d9069fc2b105256cccf58bb4aecbd1d);
#
#
#         var popup_84d51cb4e258c4223ea3b95df355ac3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0de1d03a92d0ee9408c8e698051471d = $(`&lt;div id=&quot;html_c0de1d03a92d0ee9408c8e698051471d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_84d51cb4e258c4223ea3b95df355ac3e.setContent(html_c0de1d03a92d0ee9408c8e698051471d);
#
#
#
#         marker_677b759993fa07537a6c167b2cf87c93.bindPopup(popup_84d51cb4e258c4223ea3b95df355ac3e)
#         ;
#
#
#
#
#             var marker_aac2f5a45df905d7141e79588d748ad0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3d9069fc2b105256cccf58bb4aecbd1d);
#
#
#         var popup_1a54a245fc78f7a21c3d8ceb058a1ae6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad165877840b5bf4d4937af11b9dd99a = $(`&lt;div id=&quot;html_ad165877840b5bf4d4937af11b9dd99a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1a54a245fc78f7a21c3d8ceb058a1ae6.setContent(html_ad165877840b5bf4d4937af11b9dd99a);
#
#
#
#         marker_aac2f5a45df905d7141e79588d748ad0.bindPopup(popup_1a54a245fc78f7a21c3d8ceb058a1ae6)
#         ;
#
#
#
#
#             var marker_5bb175cf37a44ae317ac24eff2423ab8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3d9069fc2b105256cccf58bb4aecbd1d);
#
#
#         var popup_02434b532f984fbfd5645c7312047d04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03f5f49c32ca4c558c4a36ca8ae33037 = $(`&lt;div id=&quot;html_03f5f49c32ca4c558c4a36ca8ae33037&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_02434b532f984fbfd5645c7312047d04.setContent(html_03f5f49c32ca4c558c4a36ca8ae33037);
#
#
#
#         marker_5bb175cf37a44ae317ac24eff2423ab8.bindPopup(popup_02434b532f984fbfd5645c7312047d04)
#         ;
#
#
#
#
#             var marker_b84ad96a53e995f63e58ce039f583f98 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3d9069fc2b105256cccf58bb4aecbd1d);
#
#
#         var popup_13feb5790c702caa45460ba21b1acae1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f90e7b0e8336ba2b1405af5f54a1cfa7 = $(`&lt;div id=&quot;html_f90e7b0e8336ba2b1405af5f54a1cfa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_13feb5790c702caa45460ba21b1acae1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_62e6ebdf23e21009658de8cb7ae399a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_62e6ebdf23e21009658de8cb7ae399a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_62e6ebdf23e21009658de8cb7ae399a0 = L.map(
#                 &quot;map_62e6ebdf23e21009658de8cb7ae399a0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_536ea4e685a7310c482334a7864a6713 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_536ea4e685a7310c482334a7864a6713.addTo(map_62e6ebdf23e21009658de8cb7ae399a0);
#
#
#             var feature_group_ad6fa8444ba830604ead42fb39a55772 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0ddc7e00d784daf7342e627660446f89 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ad6fa8444ba830604ead42fb39a55772);
#
#
#         var popup_840cb5290f56bb45b6d327479f2772fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ca5ec27fdb02f7a2944bd594717dbd3 = $(`&lt;div id=&quot;html_3ca5ec27fdb02f7a2944bd594717dbd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_840cb5290f56bb45b6d327479f2772fb.setContent(html_3ca5ec27fdb02f7a2944bd594717dbd3);
#
#
#
#         marker_0ddc7e00d784daf7342e627660446f89.bindPopup(popup_840cb5290f56bb45b6d327479f2772fb)
#         ;
#
#
#
#
#             var marker_6fcb268e1e1c5c494e0027a330f75075 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ad6fa8444ba830604ead42fb39a55772);
#
#
#         var popup_fda08b7dbc83c8057ff5a941ef1b9fd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_efc22ad070efc44613ce67a8e6ae2f43 = $(`&lt;div id=&quot;html_efc22ad070efc44613ce67a8e6ae2f43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fda08b7dbc83c8057ff5a941ef1b9fd7.setContent(html_efc22ad070efc44613ce67a8e6ae2f43);
#
#
#
#         marker_6fcb268e1e1c5c494e0027a330f75075.bindPopup(popup_fda08b7dbc83c8057ff5a941ef1b9fd7)
#         ;
#
#
#
#
#             var marker_262d3f4d1aef64cc05dd9adcbda9a1e5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ad6fa8444ba830604ead42fb39a55772);
#
#
#         var popup_10319316b6e4a90dfc362e851445a560 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_313a5f0310742ee949f43504ed483799 = $(`&lt;div id=&quot;html_313a5f0310742ee949f43504ed483799&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_10319316b6e4a90dfc362e851445a560.setContent(html_313a5f0310742ee949f43504ed483799);
#
#
#
#         marker_262d3f4d1aef64cc05dd9adcbda9a1e5.bindPopup(popup_10319316b6e4a90dfc362e851445a560)
#         ;
#
#
#
#
#             var marker_e7b00c9585700e76bad025753fe79f9e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ad6fa8444ba830604ead42fb39a55772);
#
#
#         var popup_837c4215d3f832dc43d1686dcc6d4a63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c30ef83eed23cc7a72f1684d3680a40 = $(`&lt;div id=&quot;html_4c30ef83eed23cc7a72f1684d3680a40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_837c4215d3f832dc43d1686dcc6d4a63.setContent(html_4c30ef83eed23cc7a72f1684d3680a40);
#
#
#
#         marker_e7b00c9585700e76bad025753fe79f9e.bindPopup(popup_837c4215d3f832dc43d1686dcc6d4a63)
#         ;
#
#
#
#
#             var marker_5f5d1959b2b8fd2e0cc4286e9e97c610 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ad6fa8444ba830604ead42fb39a55772);
#
#
#         var popup_37baeda128274025c6eca152f8196f38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_500640712ca6eb75e6cfad81e91d1c66 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_500640712ca6eb75e6cfad81e91d1c66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_500640712ca6eb75e6cfad81e91d1c66 = L.map(
#                 &quot;map_500640712ca6eb75e6cfad81e91d1c66&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77bb55fccb3848e1f475f528eb1201bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77bb55fccb3848e1f475f528eb1201bf.addTo(map_500640712ca6eb75e6cfad81e91d1c66);
#
#
#             var feature_group_1ee41ed09737602370ae1a12b12da12a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1ee41ed09737602370ae1a12b12da12a.addTo(map_500640712ca6eb75e6cfad81e91d1c66);
#
#
#             var feature_group_sub_group_e9e626941f2f3bdcfab75754c08fcc4f = L.featureGroup.subGroup(
#                 feature_group_1ee41ed09737602370ae1a12b12da12a
#             );
#
#
#             var marker_b2a75c1ed7e7a65db815b2bb39c5ad29 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e9e626941f2f3bdcfab75754c08fcc4f);
#
#
#         var popup_859a3c5b6b27fb75e2662987fe06ce42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a29ef9dde75a664f0d43212cd99badf5 = $(`&lt;div id=&quot;html_a29ef9dde75a664f0d43212cd99badf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_859a3c5b6b27fb75e2662987fe06ce42.setContent(html_a29ef9dde75a664f0d43212cd99badf5);
#
#
#
#         marker_b2a75c1ed7e7a65db815b2bb39c5ad29.bindPopup(popup_859a3c5b6b27fb75e2662987fe06ce42)
#         ;
#
#
#
#
#             var marker_53740655d41188b86ecb624bc8129b9b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e9e626941f2f3bdcfab75754c08fcc4f);
#
#
#         var popup_5c4371362972e516c499e8ed1ee0d6ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19597e60ac67f469317426c0fa8bebbd = $(`&lt;div id=&quot;html_19597e60ac67f469317426c0fa8bebbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5c4371362972e516c499e8ed1ee0d6ad.setContent(html_19597e60ac67f469317426c0fa8bebbd);
#
#
#
#         marker_53740655d41188b86ecb624bc8129b9b.bindPopup(popup_5c4371362972e516c499e8ed1ee0d6ad)
#         ;
#
#
#
#
#             var marker_22824c4eb13751594bd5d2bb0fa553b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e9e626941f2f3bdcfab75754c08fcc4f);
#
#
#         var popup_93f14f5f743326582262899f143045c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f289042d8fbeea5d2d730ce6996fc56d = $(`&lt;div id=&quot;html_f289042d8fbeea5d2d730ce6996fc56d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_93f14f5f743326582262899f143045c8.setContent(html_f289042d8fbeea5d2d730ce6996fc56d);
#
#
#
#         marker_22824c4eb13751594bd5d2bb0fa553b6.bindPopup(popup_93f14f5f743326582262899f143045c8)
#         ;
#
#
#
#
#             var marker_8aaf360c85e1ae5590a9ee4f6be11d06 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e9e626941f2f3bdcfab75754c08fcc4f);
#
#
#         var popup_dac86a0e985d64a2c56e441db8bd2d18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25bea40dfd365e3cddf25515430f7d29 = $(`&lt;div id=&quot;html_25bea40dfd365e3cddf25515430f7d29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dac86a0e985d64a2c56e441db8bd2d18.setContent(html_25bea40dfd365e3cddf25515430f7d29);
#
#
#
#         marker_
