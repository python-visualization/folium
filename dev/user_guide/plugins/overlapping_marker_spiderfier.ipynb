# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_53e9a3312f57a8f89aee48805e5a792b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_53e9a3312f57a8f89aee48805e5a792b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_53e9a3312f57a8f89aee48805e5a792b = L.map(
#                 &quot;map_53e9a3312f57a8f89aee48805e5a792b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da30b7a8e8d468c422afd476b7cc2b01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da30b7a8e8d468c422afd476b7cc2b01.addTo(map_53e9a3312f57a8f89aee48805e5a792b);
#
#
#             var marker_1c607003f393060ba3126def89149652 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_53e9a3312f57a8f89aee48805e5a792b);
#
#
#         var popup_5ee0b4f82411037e740a20b879df2a32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84708d18e703f43ef860799bac70df8e = $(`&lt;div id=&quot;html_84708d18e703f43ef860799bac70df8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5ee0b4f82411037e740a20b879df2a32.setContent(html_84708d18e703f43ef860799bac70df8e);
#
#
#
#         marker_1c607003f393060ba3126def89149652.bindPopup(popup_5ee0b4f82411037e740a20b879df2a32)
#         ;
#
#
#
#
#             var marker_23214fad07b833adaf40d7d0cf26dab6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_53e9a3312f57a8f89aee48805e5a792b);
#
#
#         var popup_548c5c82665fd580deb59ff78750c8b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0da645c0c41cd8d6dee47b92b7a65c2 = $(`&lt;div id=&quot;html_d0da645c0c41cd8d6dee47b92b7a65c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_548c5c82665fd580deb59ff78750c8b0.setContent(html_d0da645c0c41cd8d6dee47b92b7a65c2);
#
#
#
#         marker_23214fad07b833adaf40d7d0cf26dab6.bindPopup(popup_548c5c82665fd580deb59ff78750c8b0)
#         ;
#
#
#
#
#             var marker_5c553e10caaf5a40e292d833901e2823 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_53e9a3312f57a8f89aee48805e5a792b);
#
#
#         var popup_91c977598d30225d7e3531b42416e407 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_862dd25571fa9be4b61dfde26e4a856e = $(`&lt;div id=&quot;html_862dd25571fa9be4b61dfde26e4a856e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_91c977598d30225d7e3531b42416e407.setContent(html_862dd25571fa9be4b61dfde26e4a856e);
#
#
#
#         marker_5c553e10caaf5a40e292d833901e2823.bindPopup(popup_91c977598d30225d7e3531b42416e407)
#         ;
#
#
#
#
#             var marker_7f232d626a10e36a4ee9ff662b3c2c00 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_53e9a3312f57a8f89aee48805e5a792b);
#
#
#         var popup_bfba3b97cf111861e60ee3e4dd9f653a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef068993c644f64adcd07c0e4caad8a1 = $(`&lt;div id=&quot;html_ef068993c644f64adcd07c0e4caad8a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bfba3b97cf111861e60ee3e4dd9f653a.setContent(html_ef068993c644f64adcd07c0e4caad8a1);
#
#
#
#         marker_7f232d626a10e36a4ee9ff662b3c2c00.bindPopup(popup_bfba3b97cf111861e60ee3e4dd9f653a)
#         ;
#
#
#
#
#             var marker_642e8fd0466b3a688c4a714991b5825a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_53e9a3312f57a8f89aee48805e5a792b);
#
#
#         var popup_37cefa1661b1f794501d1e9fb37d0555 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e79013652f8a992d3c2276e99637dfe = $(`&lt;div id=&quot;html_7e79013652f8a992d3c2276e99637dfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_37cefa1661b1f794501d1e9fb37d0555.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6fac3c1987e8b19f1f0596127fc941e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6fac3c1987e8b19f1f0596127fc941e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6fac3c1987e8b19f1f0596127fc941e = L.map(
#                 &quot;map_b6fac3c1987e8b19f1f0596127fc941e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bff141547a71d69daff53c92a40350f2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bff141547a71d69daff53c92a40350f2.addTo(map_b6fac3c1987e8b19f1f0596127fc941e);
#
#
#             var feature_group_dd629369c4e20ada97f77b84c2f35c01 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_24ea0932ef044596294f6ecdcb1b7c93 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dd629369c4e20ada97f77b84c2f35c01);
#
#
#         var popup_9416d28d8b9441831f18636441217b3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5da305d3f51d27fbde1a69167d5ff6ed = $(`&lt;div id=&quot;html_5da305d3f51d27fbde1a69167d5ff6ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9416d28d8b9441831f18636441217b3e.setContent(html_5da305d3f51d27fbde1a69167d5ff6ed);
#
#
#
#         marker_24ea0932ef044596294f6ecdcb1b7c93.bindPopup(popup_9416d28d8b9441831f18636441217b3e)
#         ;
#
#
#
#
#             var marker_7aae63551320e81c6d517e98d21af076 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dd629369c4e20ada97f77b84c2f35c01);
#
#
#         var popup_7e2922e0df25c4f2f5286126d7b0cdf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b7f6018b004014544fe58d9ac864800 = $(`&lt;div id=&quot;html_9b7f6018b004014544fe58d9ac864800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7e2922e0df25c4f2f5286126d7b0cdf3.setContent(html_9b7f6018b004014544fe58d9ac864800);
#
#
#
#         marker_7aae63551320e81c6d517e98d21af076.bindPopup(popup_7e2922e0df25c4f2f5286126d7b0cdf3)
#         ;
#
#
#
#
#             var marker_0f83d7cb75912337d1b6bf35fdbf5ed6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dd629369c4e20ada97f77b84c2f35c01);
#
#
#         var popup_7f9f99b541f2fe5e00968767cea0a96f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2637584021493bf4b6bb888c5726eb1 = $(`&lt;div id=&quot;html_f2637584021493bf4b6bb888c5726eb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7f9f99b541f2fe5e00968767cea0a96f.setContent(html_f2637584021493bf4b6bb888c5726eb1);
#
#
#
#         marker_0f83d7cb75912337d1b6bf35fdbf5ed6.bindPopup(popup_7f9f99b541f2fe5e00968767cea0a96f)
#         ;
#
#
#
#
#             var marker_fa70543486bdc02378306991fcb703b9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dd629369c4e20ada97f77b84c2f35c01);
#
#
#         var popup_27aa984ab81ce7b6fa6f7f610f0892e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bcc2a1f3d4aafa7e109ec789bc3133d = $(`&lt;div id=&quot;html_8bcc2a1f3d4aafa7e109ec789bc3133d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_27aa984ab81ce7b6fa6f7f610f0892e1.setContent(html_8bcc2a1f3d4aafa7e109ec789bc3133d);
#
#
#
#         marker_fa70543486bdc02378306991fcb703b9.bindPopup(popup_27aa984ab81ce7b6fa6f7f610f0892e1)
#         ;
#
#
#
#
#             var marker_960bb67a80a7d635c847be32695f9d15 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dd629369c4e20ada97f77b84c2f35c01);
#
#
#         var popup_d22a2dd267e3cff65e8bf37a4273f323 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_da75e2f533a64fb1d80b897f73b1dd85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_da75e2f533a64fb1d80b897f73b1dd85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_da75e2f533a64fb1d80b897f73b1dd85 = L.map(
#                 &quot;map_da75e2f533a64fb1d80b897f73b1dd85&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_076f12803d356d31588a6961dd8f5525 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_076f12803d356d31588a6961dd8f5525.addTo(map_da75e2f533a64fb1d80b897f73b1dd85);
#
#
#             var feature_group_fedb29e0011577a25f599ecb538bc4b5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fedb29e0011577a25f599ecb538bc4b5.addTo(map_da75e2f533a64fb1d80b897f73b1dd85);
#
#
#             var feature_group_sub_group_7498e095e4202fbff15ddc62d51fb1e4 = L.featureGroup.subGroup(
#                 feature_group_fedb29e0011577a25f599ecb538bc4b5
#             );
#
#
#             var marker_d74aea1d740ccfbdfb112b23f1c94da9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7498e095e4202fbff15ddc62d51fb1e4);
#
#
#         var popup_d137031d80be447fc464de3cf1795147 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31daec311b9fcb9f69c12d3e2c3d3cbc = $(`&lt;div id=&quot;html_31daec311b9fcb9f69c12d3e2c3d3cbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d137031d80be447fc464de3cf1795147.setContent(html_31daec311b9fcb9f69c12d3e2c3d3cbc);
#
#
#
#         marker_d74aea1d740ccfbdfb112b23f1c94da9.bindPopup(popup_d137031d80be447fc464de3cf1795147)
#         ;
#
#
#
#
#             var marker_9013d49a92d8372fbf7f90ce685deaa8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7498e095e4202fbff15ddc62d51fb1e4);
#
#
#         var popup_307df9d6f59ada2e8af4cab9b401dd33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a79d0aced380c14fbde38fef1e2ab06c = $(`&lt;div id=&quot;html_a79d0aced380c14fbde38fef1e2ab06c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_307df9d6f59ada2e8af4cab9b401dd33.setContent(html_a79d0aced380c14fbde38fef1e2ab06c);
#
#
#
#         marker_9013d49a92d8372fbf7f90ce685deaa8.bindPopup(popup_307df9d6f59ada2e8af4cab9b401dd33)
#         ;
#
#
#
#
#             var marker_2bbf6fb4dbc2e7a674dc6d7e493e435f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7498e095e4202fbff15ddc62d51fb1e4);
#
#
#         var popup_0920237be51f118068e5ebcb90e0e6de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73643f3d01a3e0fc8b05712ccd3ddfd1 = $(`&lt;div id=&quot;html_73643f3d01a3e0fc8b05712ccd3ddfd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0920237be51f118068e5ebcb90e0e6de.setContent(html_73643f3d01a3e0fc8b05712ccd3ddfd1);
#
#
#
#         marker_2bbf6fb4dbc2e7a674dc6d7e493e435f.bindPopup(popup_0920237be51f118068e5ebcb90e0e6de)
#         ;
#
#
#
#
#             var marker_27a54789b3c8edc8010b14ce3791209b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7498e095e4202fbff15ddc62d51fb1e4);
#
#
#         var popup_634d687b85f060cea60698cb85d34cd3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b93c6bd46ffb59827ab560e6e46be3bf = $(`&lt;div id=&quot;html_b93c6bd46ffb59827ab560e6e46be3bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_634d687b85f060cea60698cb85d34cd3.setContent(html_b93c6bd46ffb59827ab560e6e46be3bf);
#
#
#
#         marker_
