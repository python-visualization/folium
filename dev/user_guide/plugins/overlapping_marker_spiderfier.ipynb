# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e69c990f2623818499ed698cf58788e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e69c990f2623818499ed698cf58788e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e69c990f2623818499ed698cf58788e = L.map(
#                 &quot;map_1e69c990f2623818499ed698cf58788e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa223bfa808a6fe6c6c28fbafb58d745 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aa223bfa808a6fe6c6c28fbafb58d745.addTo(map_1e69c990f2623818499ed698cf58788e);
#
#
#             var marker_ebf526063c4fd71a07b47a93e17aa826 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1e69c990f2623818499ed698cf58788e);
#
#
#         var popup_e4748173ea7807237f97c292d79b9875 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccc5863184772ed5d63f008d0f9fb7a5 = $(`&lt;div id=&quot;html_ccc5863184772ed5d63f008d0f9fb7a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e4748173ea7807237f97c292d79b9875.setContent(html_ccc5863184772ed5d63f008d0f9fb7a5);
#
#
#
#         marker_ebf526063c4fd71a07b47a93e17aa826.bindPopup(popup_e4748173ea7807237f97c292d79b9875)
#         ;
#
#
#
#
#             var marker_3bfbf8c2eee3fe51974ece9214667b8a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1e69c990f2623818499ed698cf58788e);
#
#
#         var popup_ecab585fd4d2378a22fd57314dc172ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e27a8d37fde2a49a11e883fb15d74a50 = $(`&lt;div id=&quot;html_e27a8d37fde2a49a11e883fb15d74a50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ecab585fd4d2378a22fd57314dc172ab.setContent(html_e27a8d37fde2a49a11e883fb15d74a50);
#
#
#
#         marker_3bfbf8c2eee3fe51974ece9214667b8a.bindPopup(popup_ecab585fd4d2378a22fd57314dc172ab)
#         ;
#
#
#
#
#             var marker_f5f7dd9692b53e9454a3344c2753ee00 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1e69c990f2623818499ed698cf58788e);
#
#
#         var popup_cf99a5c49e085c1cf52fa8eeaa4a6a38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62d8d39b68a2e37b4ba1c15ab3d0aeb3 = $(`&lt;div id=&quot;html_62d8d39b68a2e37b4ba1c15ab3d0aeb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cf99a5c49e085c1cf52fa8eeaa4a6a38.setContent(html_62d8d39b68a2e37b4ba1c15ab3d0aeb3);
#
#
#
#         marker_f5f7dd9692b53e9454a3344c2753ee00.bindPopup(popup_cf99a5c49e085c1cf52fa8eeaa4a6a38)
#         ;
#
#
#
#
#             var marker_0c56db39684794f68d65cb4fb8b7421b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1e69c990f2623818499ed698cf58788e);
#
#
#         var popup_c3c1f6b7c47a893227ac80020cb5d87e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4923a08a1d476e07c2402d34c5047a7c = $(`&lt;div id=&quot;html_4923a08a1d476e07c2402d34c5047a7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c3c1f6b7c47a893227ac80020cb5d87e.setContent(html_4923a08a1d476e07c2402d34c5047a7c);
#
#
#
#         marker_0c56db39684794f68d65cb4fb8b7421b.bindPopup(popup_c3c1f6b7c47a893227ac80020cb5d87e)
#         ;
#
#
#
#
#             var marker_e9b23dd5b28a945fa1fe8262277e587a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1e69c990f2623818499ed698cf58788e);
#
#
#         var popup_3f022eb9585a4ea4f0e7275c13f72c70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9edf1a024cd24f2851b53df703dc8863 = $(`&lt;div id=&quot;html_9edf1a024cd24f2851b53df703dc8863&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3f022eb9585a4ea4f0e7275c13f72c70.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40018699d41fc625ae10b0215b96ea3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40018699d41fc625ae10b0215b96ea3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40018699d41fc625ae10b0215b96ea3f = L.map(
#                 &quot;map_40018699d41fc625ae10b0215b96ea3f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e735f54edf82571d1c82ebedbdb9921b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e735f54edf82571d1c82ebedbdb9921b.addTo(map_40018699d41fc625ae10b0215b96ea3f);
#
#
#             var feature_group_d576c315e86168c3a82b0cd07615780e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_23c15ffe217cdd338c10fb50d559fd70 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d576c315e86168c3a82b0cd07615780e);
#
#
#         var popup_d46345ce8a8a64e833ff9296fcf77dd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e576df1bab09fd7229b64f8dcf35218c = $(`&lt;div id=&quot;html_e576df1bab09fd7229b64f8dcf35218c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d46345ce8a8a64e833ff9296fcf77dd0.setContent(html_e576df1bab09fd7229b64f8dcf35218c);
#
#
#
#         marker_23c15ffe217cdd338c10fb50d559fd70.bindPopup(popup_d46345ce8a8a64e833ff9296fcf77dd0)
#         ;
#
#
#
#
#             var marker_379b5e9e87a90bf90110ec574ce0d39c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d576c315e86168c3a82b0cd07615780e);
#
#
#         var popup_3c7840b11f11ffe736d177e00042677d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aaca403c250629220aa6e279f3aaf19d = $(`&lt;div id=&quot;html_aaca403c250629220aa6e279f3aaf19d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3c7840b11f11ffe736d177e00042677d.setContent(html_aaca403c250629220aa6e279f3aaf19d);
#
#
#
#         marker_379b5e9e87a90bf90110ec574ce0d39c.bindPopup(popup_3c7840b11f11ffe736d177e00042677d)
#         ;
#
#
#
#
#             var marker_8fbf834eed396da5fa82335d1fe4f81f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d576c315e86168c3a82b0cd07615780e);
#
#
#         var popup_d554b8c9cecc7b7dbf9bf5f2e5dd6433 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1228f3f00c1ad0ec42f263db55d52a4f = $(`&lt;div id=&quot;html_1228f3f00c1ad0ec42f263db55d52a4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d554b8c9cecc7b7dbf9bf5f2e5dd6433.setContent(html_1228f3f00c1ad0ec42f263db55d52a4f);
#
#
#
#         marker_8fbf834eed396da5fa82335d1fe4f81f.bindPopup(popup_d554b8c9cecc7b7dbf9bf5f2e5dd6433)
#         ;
#
#
#
#
#             var marker_9b8be7f2a302b6d8dc5b10e2a68219a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d576c315e86168c3a82b0cd07615780e);
#
#
#         var popup_18a5b524c2b67c8d57e9d583601477d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df272ffbad3549ca0693d5c0d65e0c9b = $(`&lt;div id=&quot;html_df272ffbad3549ca0693d5c0d65e0c9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_18a5b524c2b67c8d57e9d583601477d4.setContent(html_df272ffbad3549ca0693d5c0d65e0c9b);
#
#
#
#         marker_9b8be7f2a302b6d8dc5b10e2a68219a2.bindPopup(popup_18a5b524c2b67c8d57e9d583601477d4)
#         ;
#
#
#
#
#             var marker_25f800fcfcc7daf54a4c797045fa696c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d576c315e86168c3a82b0cd07615780e);
#
#
#         var popup_fe44574c7f18517f0143fa34468f865d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b46a2a041d3a1135e66e512cab8951d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b46a2a041d3a1135e66e512cab8951d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b46a2a041d3a1135e66e512cab8951d0 = L.map(
#                 &quot;map_b46a2a041d3a1135e66e512cab8951d0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61a02fbf25eaab4f14bdd3c333074ab1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61a02fbf25eaab4f14bdd3c333074ab1.addTo(map_b46a2a041d3a1135e66e512cab8951d0);
#
#
#             var feature_group_dcb66c21330d2df96234748243582bdf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dcb66c21330d2df96234748243582bdf.addTo(map_b46a2a041d3a1135e66e512cab8951d0);
#
#
#             var feature_group_sub_group_cc945dddf3218746900a65c798c8fb78 = L.featureGroup.subGroup(
#                 feature_group_dcb66c21330d2df96234748243582bdf
#             );
#
#
#             var marker_032b460e8acd2f74387076d8ac0a2b26 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc945dddf3218746900a65c798c8fb78);
#
#
#         var popup_e3b9d44d777b66a9492e0ae014fcd92e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3b030aa32602e8ae76853647b1557b6 = $(`&lt;div id=&quot;html_c3b030aa32602e8ae76853647b1557b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e3b9d44d777b66a9492e0ae014fcd92e.setContent(html_c3b030aa32602e8ae76853647b1557b6);
#
#
#
#         marker_032b460e8acd2f74387076d8ac0a2b26.bindPopup(popup_e3b9d44d777b66a9492e0ae014fcd92e)
#         ;
#
#
#
#
#             var marker_ac9e917e62641fa5a2faec14206f1304 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc945dddf3218746900a65c798c8fb78);
#
#
#         var popup_acbd2142b09355d8cd797f7fc8903eb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0316b9ce85ab04ac4d173cc809a51b3e = $(`&lt;div id=&quot;html_0316b9ce85ab04ac4d173cc809a51b3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_acbd2142b09355d8cd797f7fc8903eb8.setContent(html_0316b9ce85ab04ac4d173cc809a51b3e);
#
#
#
#         marker_ac9e917e62641fa5a2faec14206f1304.bindPopup(popup_acbd2142b09355d8cd797f7fc8903eb8)
#         ;
#
#
#
#
#             var marker_705672e5cbf0a3b6b7bd9872c922b1c0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc945dddf3218746900a65c798c8fb78);
#
#
#         var popup_5efb6a07311a8218ea37302754a86556 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39e40e6f8ae4443299a5e6f2b0890b8f = $(`&lt;div id=&quot;html_39e40e6f8ae4443299a5e6f2b0890b8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5efb6a07311a8218ea37302754a86556.setContent(html_39e40e6f8ae4443299a5e6f2b0890b8f);
#
#
#
#         marker_705672e5cbf0a3b6b7bd9872c922b1c0.bindPopup(popup_5efb6a07311a8218ea37302754a86556)
#         ;
#
#
#
#
#             var marker_9cf0d8d7f899d8d58540bc45f5519751 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc945dddf3218746900a65c798c8fb78);
#
#
#         var popup_7dbcc1bb2e0586f096144f275606219b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_accbab45317ec7d3c2b74daaee5a0d48 = $(`&lt;div id=&quot;html_accbab45317ec7d3c2b74daaee5a0d48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7dbcc1bb2e0586f096144f275606219b.setContent(html_accbab45317ec7d3c2b74daaee5a0d48);
#
#
#
#         marker_
