# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d8d4e3882c3e384a10e63a6266471fd8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d8d4e3882c3e384a10e63a6266471fd8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d8d4e3882c3e384a10e63a6266471fd8 = L.map(
#                 &quot;map_d8d4e3882c3e384a10e63a6266471fd8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9749849b58a053db0f12e74a801fb55 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9749849b58a053db0f12e74a801fb55.addTo(map_d8d4e3882c3e384a10e63a6266471fd8);
#
#
#             var marker_546f6f5bb13ce8aada883c75a4733737 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d8d4e3882c3e384a10e63a6266471fd8);
#
#
#         var popup_a8a03bd9c3f810b72626479192b110fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ade41c6bf148b92ac3e9cc495f002b0a = $(`&lt;div id=&quot;html_ade41c6bf148b92ac3e9cc495f002b0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a8a03bd9c3f810b72626479192b110fd.setContent(html_ade41c6bf148b92ac3e9cc495f002b0a);
#
#
#
#         marker_546f6f5bb13ce8aada883c75a4733737.bindPopup(popup_a8a03bd9c3f810b72626479192b110fd)
#         ;
#
#
#
#
#             var marker_f65bf15e2c83ea09936eaf3af9c775f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d8d4e3882c3e384a10e63a6266471fd8);
#
#
#         var popup_fdd6b8eba13f74b91ab8fedcf0340395 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_346937adcdc6fad7ac4a7ceaf2e8afb3 = $(`&lt;div id=&quot;html_346937adcdc6fad7ac4a7ceaf2e8afb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fdd6b8eba13f74b91ab8fedcf0340395.setContent(html_346937adcdc6fad7ac4a7ceaf2e8afb3);
#
#
#
#         marker_f65bf15e2c83ea09936eaf3af9c775f4.bindPopup(popup_fdd6b8eba13f74b91ab8fedcf0340395)
#         ;
#
#
#
#
#             var marker_4d087cf61faf4ae402472db4a85e8e50 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d8d4e3882c3e384a10e63a6266471fd8);
#
#
#         var popup_8b5de496a8255a96d173111ded1dc515 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a657d35f27f6503b1aee940b016b7c1a = $(`&lt;div id=&quot;html_a657d35f27f6503b1aee940b016b7c1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8b5de496a8255a96d173111ded1dc515.setContent(html_a657d35f27f6503b1aee940b016b7c1a);
#
#
#
#         marker_4d087cf61faf4ae402472db4a85e8e50.bindPopup(popup_8b5de496a8255a96d173111ded1dc515)
#         ;
#
#
#
#
#             var marker_e84422dd780fc630c5571ea3a0a3a422 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d8d4e3882c3e384a10e63a6266471fd8);
#
#
#         var popup_4bc20658758ee161d70340e7931bb865 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b41088d1ca401c0cab285325a084574 = $(`&lt;div id=&quot;html_7b41088d1ca401c0cab285325a084574&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4bc20658758ee161d70340e7931bb865.setContent(html_7b41088d1ca401c0cab285325a084574);
#
#
#
#         marker_e84422dd780fc630c5571ea3a0a3a422.bindPopup(popup_4bc20658758ee161d70340e7931bb865)
#         ;
#
#
#
#
#             var marker_cc64b06362f24dfe9951c46379b1ae0c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d8d4e3882c3e384a10e63a6266471fd8);
#
#
#         var popup_c389194b6603acda9f59babf10d5b8a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7705751b4cb10d0191b29cf9b7e47954 = $(`&lt;div id=&quot;html_7705751b4cb10d0191b29cf9b7e47954&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c389194b6603acda9f59babf10d5b8a9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f050bb48120c82177fabc0be4b192afc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f050bb48120c82177fabc0be4b192afc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f050bb48120c82177fabc0be4b192afc = L.map(
#                 &quot;map_f050bb48120c82177fabc0be4b192afc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b822a0e5c50f7020ee9ffc5130b70b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b822a0e5c50f7020ee9ffc5130b70b2.addTo(map_f050bb48120c82177fabc0be4b192afc);
#
#
#             var feature_group_627f1f4420aecae1a932c765f3ab9f32 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b4ea1e724827316e845da475a36a8239 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_627f1f4420aecae1a932c765f3ab9f32);
#
#
#         var popup_62df85747627ec1ca51267efdcc60c04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05455fc555a01267dcd9633c9489aee2 = $(`&lt;div id=&quot;html_05455fc555a01267dcd9633c9489aee2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_62df85747627ec1ca51267efdcc60c04.setContent(html_05455fc555a01267dcd9633c9489aee2);
#
#
#
#         marker_b4ea1e724827316e845da475a36a8239.bindPopup(popup_62df85747627ec1ca51267efdcc60c04)
#         ;
#
#
#
#
#             var marker_56c7e4fbd805b6d966660d3d411bac47 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_627f1f4420aecae1a932c765f3ab9f32);
#
#
#         var popup_59afc82bfb2bcb4d6074a871a91162b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48bee4892235c0fae35fb1b8feeac8b0 = $(`&lt;div id=&quot;html_48bee4892235c0fae35fb1b8feeac8b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_59afc82bfb2bcb4d6074a871a91162b9.setContent(html_48bee4892235c0fae35fb1b8feeac8b0);
#
#
#
#         marker_56c7e4fbd805b6d966660d3d411bac47.bindPopup(popup_59afc82bfb2bcb4d6074a871a91162b9)
#         ;
#
#
#
#
#             var marker_e6f65ad5238e8dd0c3d94faf48015095 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_627f1f4420aecae1a932c765f3ab9f32);
#
#
#         var popup_3e23f001a562a74ceccd9d62af7dd098 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cf37c314baf978708e3676ea69a4afe = $(`&lt;div id=&quot;html_7cf37c314baf978708e3676ea69a4afe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3e23f001a562a74ceccd9d62af7dd098.setContent(html_7cf37c314baf978708e3676ea69a4afe);
#
#
#
#         marker_e6f65ad5238e8dd0c3d94faf48015095.bindPopup(popup_3e23f001a562a74ceccd9d62af7dd098)
#         ;
#
#
#
#
#             var marker_d45b04ce570c7f886646e5db98ed16d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_627f1f4420aecae1a932c765f3ab9f32);
#
#
#         var popup_2bda0ae441755117887d9d5c1a8c6468 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5fa3e9055743618988574892f4823c1 = $(`&lt;div id=&quot;html_d5fa3e9055743618988574892f4823c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2bda0ae441755117887d9d5c1a8c6468.setContent(html_d5fa3e9055743618988574892f4823c1);
#
#
#
#         marker_d45b04ce570c7f886646e5db98ed16d6.bindPopup(popup_2bda0ae441755117887d9d5c1a8c6468)
#         ;
#
#
#
#
#             var marker_42ab0b4ba2af7762d917c5073c03d0b5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_627f1f4420aecae1a932c765f3ab9f32);
#
#
#         var popup_eeec2d7d89d36c2e69f0d1dc9e5b46df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca85007ba9d111d1bee3bd6822b667b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca85007ba9d111d1bee3bd6822b667b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca85007ba9d111d1bee3bd6822b667b2 = L.map(
#                 &quot;map_ca85007ba9d111d1bee3bd6822b667b2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11734abd26ffc3cec548bbceeb678c51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_11734abd26ffc3cec548bbceeb678c51.addTo(map_ca85007ba9d111d1bee3bd6822b667b2);
#
#
#             var feature_group_613f71b398215726cc22e98d267cd322 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_613f71b398215726cc22e98d267cd322.addTo(map_ca85007ba9d111d1bee3bd6822b667b2);
#
#
#             var feature_group_sub_group_896ad32252df1d2bb16964aa0ef07949 = L.featureGroup.subGroup(
#                 feature_group_613f71b398215726cc22e98d267cd322
#             );
#
#
#             var marker_24413d536ac7097b67d294a9f740e951 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_896ad32252df1d2bb16964aa0ef07949);
#
#
#         var popup_a88db6a87f4febeb56c3126b3fad2b38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bd7cbb456621f8523fa19f20c922a86 = $(`&lt;div id=&quot;html_4bd7cbb456621f8523fa19f20c922a86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a88db6a87f4febeb56c3126b3fad2b38.setContent(html_4bd7cbb456621f8523fa19f20c922a86);
#
#
#
#         marker_24413d536ac7097b67d294a9f740e951.bindPopup(popup_a88db6a87f4febeb56c3126b3fad2b38)
#         ;
#
#
#
#
#             var marker_5535d6b3ae8d8423d9f8bf0fc719233f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_896ad32252df1d2bb16964aa0ef07949);
#
#
#         var popup_302de242bab752beaeb2ab91c6ea4d47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4c93d7ec7398885f17d432d4085e7b0 = $(`&lt;div id=&quot;html_c4c93d7ec7398885f17d432d4085e7b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_302de242bab752beaeb2ab91c6ea4d47.setContent(html_c4c93d7ec7398885f17d432d4085e7b0);
#
#
#
#         marker_5535d6b3ae8d8423d9f8bf0fc719233f.bindPopup(popup_302de242bab752beaeb2ab91c6ea4d47)
#         ;
#
#
#
#
#             var marker_86621e36c8fa4af24c8fadd39b7c70e1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_896ad32252df1d2bb16964aa0ef07949);
#
#
#         var popup_33ada42e236ddf0d1850902311c616c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b37c958361887dc263a59e580cbb1d1 = $(`&lt;div id=&quot;html_6b37c958361887dc263a59e580cbb1d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_33ada42e236ddf0d1850902311c616c0.setContent(html_6b37c958361887dc263a59e580cbb1d1);
#
#
#
#         marker_86621e36c8fa4af24c8fadd39b7c70e1.bindPopup(popup_33ada42e236ddf0d1850902311c616c0)
#         ;
#
#
#
#
#             var marker_2de1a796b852505c2c6bc9952c0472e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_896ad32252df1d2bb16964aa0ef07949);
#
#
#         var popup_9fbf8effc76f4705ad529c4213e7e32e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_187f1fb486d5ecb0005912c2d4f88ea4 = $(`&lt;div id=&quot;html_187f1fb486d5ecb0005912c2d4f88ea4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9fbf8effc76f4705ad529c4213e7e32e.setContent(html_187f1fb486d5ecb0005912c2d4f88ea4);
#
#
#
#         marker_
