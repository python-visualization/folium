# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c00ff0164c37965ac2f5fcde101e63db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c00ff0164c37965ac2f5fcde101e63db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c00ff0164c37965ac2f5fcde101e63db = L.map(
#                 &quot;map_c00ff0164c37965ac2f5fcde101e63db&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_917300ae205f08b6378263cad53d7bda = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_917300ae205f08b6378263cad53d7bda.addTo(map_c00ff0164c37965ac2f5fcde101e63db);
#
#
#             var marker_20c484279f1aae6845d306133cf29a50 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c00ff0164c37965ac2f5fcde101e63db);
#
#
#         var popup_a5700c7518f281147a6f0b97ebfe2c1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fa2b0a7fb79c29074cf9de5df6387ad = $(`&lt;div id=&quot;html_6fa2b0a7fb79c29074cf9de5df6387ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a5700c7518f281147a6f0b97ebfe2c1f.setContent(html_6fa2b0a7fb79c29074cf9de5df6387ad);
#
#
#
#         marker_20c484279f1aae6845d306133cf29a50.bindPopup(popup_a5700c7518f281147a6f0b97ebfe2c1f)
#         ;
#
#
#
#
#             var marker_df3dd71dbef7daf655d5565eaa2cc42e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c00ff0164c37965ac2f5fcde101e63db);
#
#
#         var popup_fe2ba3af08b6d060f9b8013e34128ccc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30497f5008634f5ba83e2ce5a9523f2b = $(`&lt;div id=&quot;html_30497f5008634f5ba83e2ce5a9523f2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fe2ba3af08b6d060f9b8013e34128ccc.setContent(html_30497f5008634f5ba83e2ce5a9523f2b);
#
#
#
#         marker_df3dd71dbef7daf655d5565eaa2cc42e.bindPopup(popup_fe2ba3af08b6d060f9b8013e34128ccc)
#         ;
#
#
#
#
#             var marker_cc225c0228650c34e9fe8aeca37bf187 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c00ff0164c37965ac2f5fcde101e63db);
#
#
#         var popup_db50e46357f9f5e221d6d8b3e1665c68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cc4f9cee4be3aa05d5495ecd9226b2d = $(`&lt;div id=&quot;html_7cc4f9cee4be3aa05d5495ecd9226b2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_db50e46357f9f5e221d6d8b3e1665c68.setContent(html_7cc4f9cee4be3aa05d5495ecd9226b2d);
#
#
#
#         marker_cc225c0228650c34e9fe8aeca37bf187.bindPopup(popup_db50e46357f9f5e221d6d8b3e1665c68)
#         ;
#
#
#
#
#             var marker_288574051a98adefc12837277c799515 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c00ff0164c37965ac2f5fcde101e63db);
#
#
#         var popup_8ac85791555d533d063a85c10cf5a63b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f465d86766ae25b4a7e89843a3ac845 = $(`&lt;div id=&quot;html_6f465d86766ae25b4a7e89843a3ac845&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8ac85791555d533d063a85c10cf5a63b.setContent(html_6f465d86766ae25b4a7e89843a3ac845);
#
#
#
#         marker_288574051a98adefc12837277c799515.bindPopup(popup_8ac85791555d533d063a85c10cf5a63b)
#         ;
#
#
#
#
#             var marker_1cbc92ced44b8d141a2ea4cdbcd4f6f9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c00ff0164c37965ac2f5fcde101e63db);
#
#
#         var popup_05bb917f12f9f33d5d147960648a837f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f53eb570c3e3bf6df3dd8cd605ee0220 = $(`&lt;div id=&quot;html_f53eb570c3e3bf6df3dd8cd605ee0220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_05bb917f12f9f33d5d147960648a837f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ae86c64283067457c1719b9c21945a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ae86c64283067457c1719b9c21945a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ae86c64283067457c1719b9c21945a1 = L.map(
#                 &quot;map_3ae86c64283067457c1719b9c21945a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_103be0d7c288c44757c21860475e9a20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_103be0d7c288c44757c21860475e9a20.addTo(map_3ae86c64283067457c1719b9c21945a1);
#
#
#             var feature_group_647f744d80232e9a8b74e17e331daecb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2fd16612f21f4cd637959c47f41c2dd0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_647f744d80232e9a8b74e17e331daecb);
#
#
#         var popup_3d7bfdd383c635c23fc99c2b2a5bb985 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4dd5b6e65427b332bad6a811cec4819 = $(`&lt;div id=&quot;html_e4dd5b6e65427b332bad6a811cec4819&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3d7bfdd383c635c23fc99c2b2a5bb985.setContent(html_e4dd5b6e65427b332bad6a811cec4819);
#
#
#
#         marker_2fd16612f21f4cd637959c47f41c2dd0.bindPopup(popup_3d7bfdd383c635c23fc99c2b2a5bb985)
#         ;
#
#
#
#
#             var marker_c69c9cc09bcca3048b324ef2d546533f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_647f744d80232e9a8b74e17e331daecb);
#
#
#         var popup_d25e2aed3293ddfa6fda703e2d89fcda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c085da29b5e3971ffcb6f5b0005be7b = $(`&lt;div id=&quot;html_7c085da29b5e3971ffcb6f5b0005be7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d25e2aed3293ddfa6fda703e2d89fcda.setContent(html_7c085da29b5e3971ffcb6f5b0005be7b);
#
#
#
#         marker_c69c9cc09bcca3048b324ef2d546533f.bindPopup(popup_d25e2aed3293ddfa6fda703e2d89fcda)
#         ;
#
#
#
#
#             var marker_33da5027e2147012d09426576fa13e1e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_647f744d80232e9a8b74e17e331daecb);
#
#
#         var popup_a84a6e6196aa5077571cfc4b5705b266 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cf3d6b5de9ff608a11fb42441107c74 = $(`&lt;div id=&quot;html_1cf3d6b5de9ff608a11fb42441107c74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a84a6e6196aa5077571cfc4b5705b266.setContent(html_1cf3d6b5de9ff608a11fb42441107c74);
#
#
#
#         marker_33da5027e2147012d09426576fa13e1e.bindPopup(popup_a84a6e6196aa5077571cfc4b5705b266)
#         ;
#
#
#
#
#             var marker_efa1b02c5e5fb082585e620972dad3dc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_647f744d80232e9a8b74e17e331daecb);
#
#
#         var popup_f7cf9307146a8a250bb5a00abd9630bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba2b9581223de329f6626b9bf0db0b02 = $(`&lt;div id=&quot;html_ba2b9581223de329f6626b9bf0db0b02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f7cf9307146a8a250bb5a00abd9630bf.setContent(html_ba2b9581223de329f6626b9bf0db0b02);
#
#
#
#         marker_efa1b02c5e5fb082585e620972dad3dc.bindPopup(popup_f7cf9307146a8a250bb5a00abd9630bf)
#         ;
#
#
#
#
#             var marker_3c38b7da7dc820b3be2e06a6934bc2c4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_647f744d80232e9a8b74e17e331daecb);
#
#
#         var popup_b1e01453d3129c2fc9dce479fe1dc465 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_739c16b9a4745c994cefe5caded2346d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_739c16b9a4745c994cefe5caded2346d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_739c16b9a4745c994cefe5caded2346d = L.map(
#                 &quot;map_739c16b9a4745c994cefe5caded2346d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af6c6ccee7003ae7fdf5db068221ce98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af6c6ccee7003ae7fdf5db068221ce98.addTo(map_739c16b9a4745c994cefe5caded2346d);
#
#
#             var feature_group_c54e639a7e03482f2a326512e5fca6d0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c54e639a7e03482f2a326512e5fca6d0.addTo(map_739c16b9a4745c994cefe5caded2346d);
#
#
#             var feature_group_sub_group_7c9fd7bf6ba468ee1e1d18b6ce3cc8ad = L.featureGroup.subGroup(
#                 feature_group_c54e639a7e03482f2a326512e5fca6d0
#             );
#
#
#             var marker_41d10e133b1e1b851d8406eef1b72637 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7c9fd7bf6ba468ee1e1d18b6ce3cc8ad);
#
#
#         var popup_c27d3495404d9a5e77f27b28169f7404 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1828d1834daee69444c3dcad194d9dbe = $(`&lt;div id=&quot;html_1828d1834daee69444c3dcad194d9dbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c27d3495404d9a5e77f27b28169f7404.setContent(html_1828d1834daee69444c3dcad194d9dbe);
#
#
#
#         marker_41d10e133b1e1b851d8406eef1b72637.bindPopup(popup_c27d3495404d9a5e77f27b28169f7404)
#         ;
#
#
#
#
#             var marker_0531cbd372ebc14c7c4153e1d5ec1fe8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7c9fd7bf6ba468ee1e1d18b6ce3cc8ad);
#
#
#         var popup_362acbb94386d329e74778300618db07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3125ffbab8c03502bd16bf56323fb5d = $(`&lt;div id=&quot;html_d3125ffbab8c03502bd16bf56323fb5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_362acbb94386d329e74778300618db07.setContent(html_d3125ffbab8c03502bd16bf56323fb5d);
#
#
#
#         marker_0531cbd372ebc14c7c4153e1d5ec1fe8.bindPopup(popup_362acbb94386d329e74778300618db07)
#         ;
#
#
#
#
#             var marker_31ca74f89dba5f302c6d83e9cd53e534 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7c9fd7bf6ba468ee1e1d18b6ce3cc8ad);
#
#
#         var popup_f58007fe22316e9074dbe1773485d809 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dd8515cc302ed869b30899864972515 = $(`&lt;div id=&quot;html_5dd8515cc302ed869b30899864972515&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f58007fe22316e9074dbe1773485d809.setContent(html_5dd8515cc302ed869b30899864972515);
#
#
#
#         marker_31ca74f89dba5f302c6d83e9cd53e534.bindPopup(popup_f58007fe22316e9074dbe1773485d809)
#         ;
#
#
#
#
#             var marker_e78d5f185594e4e277d9bd5e15a33f29 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7c9fd7bf6ba468ee1e1d18b6ce3cc8ad);
#
#
#         var popup_0e17ee42ff3ad2a3822f948b4fab2250 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_222617651804c5fd857cf301ebf0de80 = $(`&lt;div id=&quot;html_222617651804c5fd857cf301ebf0de80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0e17ee42ff3ad2a3822f948b4fab2250.setContent(html_222617651804c5fd857cf301ebf0de80);
#
#
#
#         marker_
