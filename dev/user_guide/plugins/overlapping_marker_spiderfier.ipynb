# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9084e7afd502b314e6146743595fa82e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9084e7afd502b314e6146743595fa82e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9084e7afd502b314e6146743595fa82e = L.map(
#                 &quot;map_9084e7afd502b314e6146743595fa82e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e279a420285fa5390cf5fcf7deded84b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e279a420285fa5390cf5fcf7deded84b.addTo(map_9084e7afd502b314e6146743595fa82e);
#
#
#             var marker_a1a31b4d74e349537d270a8d765ca9de = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9084e7afd502b314e6146743595fa82e);
#
#
#         var popup_144228cd0d65391cba7b5f650a89394a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43ac74567a0317b80fe924bc4d994bec = $(`&lt;div id=&quot;html_43ac74567a0317b80fe924bc4d994bec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_144228cd0d65391cba7b5f650a89394a.setContent(html_43ac74567a0317b80fe924bc4d994bec);
#
#
#
#         marker_a1a31b4d74e349537d270a8d765ca9de.bindPopup(popup_144228cd0d65391cba7b5f650a89394a)
#         ;
#
#
#
#
#             var marker_15829f37ce2d32c497baf86dc05e45e6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9084e7afd502b314e6146743595fa82e);
#
#
#         var popup_ce74e44f8f53f13e548974ef87c1de5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43193681587024b9462e2833578925a6 = $(`&lt;div id=&quot;html_43193681587024b9462e2833578925a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ce74e44f8f53f13e548974ef87c1de5b.setContent(html_43193681587024b9462e2833578925a6);
#
#
#
#         marker_15829f37ce2d32c497baf86dc05e45e6.bindPopup(popup_ce74e44f8f53f13e548974ef87c1de5b)
#         ;
#
#
#
#
#             var marker_c343ba634e5770d14fb98565ae99781b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9084e7afd502b314e6146743595fa82e);
#
#
#         var popup_2c4dbeddbf9ea665218cd084f4cde4eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_466e2c4361b03cbb13ab1a9b89efa4b4 = $(`&lt;div id=&quot;html_466e2c4361b03cbb13ab1a9b89efa4b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2c4dbeddbf9ea665218cd084f4cde4eb.setContent(html_466e2c4361b03cbb13ab1a9b89efa4b4);
#
#
#
#         marker_c343ba634e5770d14fb98565ae99781b.bindPopup(popup_2c4dbeddbf9ea665218cd084f4cde4eb)
#         ;
#
#
#
#
#             var marker_868397e5f9279b4a791d9f6434f825c3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9084e7afd502b314e6146743595fa82e);
#
#
#         var popup_71a8a52009afa8a04c9c259c521841dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c48e1de6a45fdc13d3bfc780bdcd57a = $(`&lt;div id=&quot;html_9c48e1de6a45fdc13d3bfc780bdcd57a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_71a8a52009afa8a04c9c259c521841dc.setContent(html_9c48e1de6a45fdc13d3bfc780bdcd57a);
#
#
#
#         marker_868397e5f9279b4a791d9f6434f825c3.bindPopup(popup_71a8a52009afa8a04c9c259c521841dc)
#         ;
#
#
#
#
#             var marker_c0f42888deef23dc88566147b6a271f1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9084e7afd502b314e6146743595fa82e);
#
#
#         var popup_586e029197c02445876de58e1fca5efe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebdfd6c0e0af94fee94a82ef163efe26 = $(`&lt;div id=&quot;html_ebdfd6c0e0af94fee94a82ef163efe26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_586e029197c02445876de58e1fca5efe.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc37db876b840cc09843f229752269db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc37db876b840cc09843f229752269db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc37db876b840cc09843f229752269db = L.map(
#                 &quot;map_dc37db876b840cc09843f229752269db&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_265b799c0371885f32e25769b30f9a71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_265b799c0371885f32e25769b30f9a71.addTo(map_dc37db876b840cc09843f229752269db);
#
#
#             var feature_group_1a3ab9ba3f4828df3d7d293a0696d150 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1b53fc079234fda4ca5fa8ead9408539 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1a3ab9ba3f4828df3d7d293a0696d150);
#
#
#         var popup_ae39d73f3a836d72caf700e2e25c83fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_095e510ee4bff344cad6f4f7d9e04456 = $(`&lt;div id=&quot;html_095e510ee4bff344cad6f4f7d9e04456&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ae39d73f3a836d72caf700e2e25c83fd.setContent(html_095e510ee4bff344cad6f4f7d9e04456);
#
#
#
#         marker_1b53fc079234fda4ca5fa8ead9408539.bindPopup(popup_ae39d73f3a836d72caf700e2e25c83fd)
#         ;
#
#
#
#
#             var marker_9ac135841ac2fcf7ab22f4cba19617d3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1a3ab9ba3f4828df3d7d293a0696d150);
#
#
#         var popup_45a05276864768a607bf7e198b8f89be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08baf0c71de45210ab9b6f48f6d3a0d0 = $(`&lt;div id=&quot;html_08baf0c71de45210ab9b6f48f6d3a0d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_45a05276864768a607bf7e198b8f89be.setContent(html_08baf0c71de45210ab9b6f48f6d3a0d0);
#
#
#
#         marker_9ac135841ac2fcf7ab22f4cba19617d3.bindPopup(popup_45a05276864768a607bf7e198b8f89be)
#         ;
#
#
#
#
#             var marker_79978122aa2c78c1c9f6fb199e2c495d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1a3ab9ba3f4828df3d7d293a0696d150);
#
#
#         var popup_13aaf43b2ef70a4fbdd838495c0c8442 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3dd7ba9901cf98d7d9d02333b47d4c2 = $(`&lt;div id=&quot;html_a3dd7ba9901cf98d7d9d02333b47d4c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_13aaf43b2ef70a4fbdd838495c0c8442.setContent(html_a3dd7ba9901cf98d7d9d02333b47d4c2);
#
#
#
#         marker_79978122aa2c78c1c9f6fb199e2c495d.bindPopup(popup_13aaf43b2ef70a4fbdd838495c0c8442)
#         ;
#
#
#
#
#             var marker_b60c5cb294bafbfae36854ba4d67b8a8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1a3ab9ba3f4828df3d7d293a0696d150);
#
#
#         var popup_968015d165307e41ec91fcf480f981d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e3e966ff4d5716c6a2577fb5b72654f = $(`&lt;div id=&quot;html_9e3e966ff4d5716c6a2577fb5b72654f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_968015d165307e41ec91fcf480f981d2.setContent(html_9e3e966ff4d5716c6a2577fb5b72654f);
#
#
#
#         marker_b60c5cb294bafbfae36854ba4d67b8a8.bindPopup(popup_968015d165307e41ec91fcf480f981d2)
#         ;
#
#
#
#
#             var marker_380409cb9532f392cba3a5bd3d697623 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1a3ab9ba3f4828df3d7d293a0696d150);
#
#
#         var popup_54f759ec818ca69f3c4661adce6ee7f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b2c1e9d1710bfab37eb3f8f420c6f56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b2c1e9d1710bfab37eb3f8f420c6f56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b2c1e9d1710bfab37eb3f8f420c6f56 = L.map(
#                 &quot;map_0b2c1e9d1710bfab37eb3f8f420c6f56&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_715cb5aa462924bd057ca131f58a7b58 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_715cb5aa462924bd057ca131f58a7b58.addTo(map_0b2c1e9d1710bfab37eb3f8f420c6f56);
#
#
#             var feature_group_d175dbc92df91ff70cd66f1a9386ab86 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d175dbc92df91ff70cd66f1a9386ab86.addTo(map_0b2c1e9d1710bfab37eb3f8f420c6f56);
#
#
#             var feature_group_sub_group_8f077a19898733dc95b2c817f7bf301d = L.featureGroup.subGroup(
#                 feature_group_d175dbc92df91ff70cd66f1a9386ab86
#             );
#
#
#             var marker_ba5b7503424cbafb3d48f47437fe6321 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8f077a19898733dc95b2c817f7bf301d);
#
#
#         var popup_288a44d364c8a141049dc3c2b4c5ff8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc2171f36f361bfc0190ee5e77d054cf = $(`&lt;div id=&quot;html_cc2171f36f361bfc0190ee5e77d054cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_288a44d364c8a141049dc3c2b4c5ff8b.setContent(html_cc2171f36f361bfc0190ee5e77d054cf);
#
#
#
#         marker_ba5b7503424cbafb3d48f47437fe6321.bindPopup(popup_288a44d364c8a141049dc3c2b4c5ff8b)
#         ;
#
#
#
#
#             var marker_d81b22fd3ae9a8854d5d82b1baad8285 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8f077a19898733dc95b2c817f7bf301d);
#
#
#         var popup_6a62e87163c4a407efd30d1b484b26f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cc1c4ce6397f878f1924db0243a0b40 = $(`&lt;div id=&quot;html_0cc1c4ce6397f878f1924db0243a0b40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6a62e87163c4a407efd30d1b484b26f7.setContent(html_0cc1c4ce6397f878f1924db0243a0b40);
#
#
#
#         marker_d81b22fd3ae9a8854d5d82b1baad8285.bindPopup(popup_6a62e87163c4a407efd30d1b484b26f7)
#         ;
#
#
#
#
#             var marker_2f11a1c69a9be4000557ebb2d7c7392a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8f077a19898733dc95b2c817f7bf301d);
#
#
#         var popup_e78be0e99ef4633e0d2ecc6c79552158 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c677cfb1ceba3aef254f8a38978c1f78 = $(`&lt;div id=&quot;html_c677cfb1ceba3aef254f8a38978c1f78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e78be0e99ef4633e0d2ecc6c79552158.setContent(html_c677cfb1ceba3aef254f8a38978c1f78);
#
#
#
#         marker_2f11a1c69a9be4000557ebb2d7c7392a.bindPopup(popup_e78be0e99ef4633e0d2ecc6c79552158)
#         ;
#
#
#
#
#             var marker_b4b215c98fa7966e7d8bcef1d2a77c25 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8f077a19898733dc95b2c817f7bf301d);
#
#
#         var popup_29a81e798df9e0b549fdce7cfeedc469 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fbba39846562962dd27b6331fba0dcd = $(`&lt;div id=&quot;html_3fbba39846562962dd27b6331fba0dcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_29a81e798df9e0b549fdce7cfeedc469.setContent(html_3fbba39846562962dd27b6331fba0dcd);
#
#
#
#         marker_
