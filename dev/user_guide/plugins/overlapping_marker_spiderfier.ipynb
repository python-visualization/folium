# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b4c26934a6dab334708aedb4649f3f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b4c26934a6dab334708aedb4649f3f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b4c26934a6dab334708aedb4649f3f6 = L.map(
#                 &quot;map_1b4c26934a6dab334708aedb4649f3f6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e888445a67c4591fc8f56417a63f1e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e888445a67c4591fc8f56417a63f1e7.addTo(map_1b4c26934a6dab334708aedb4649f3f6);
#
#
#             var marker_532ae28936fec433717c9a7bf4e48a26 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1b4c26934a6dab334708aedb4649f3f6);
#
#
#         var popup_5a38d0854d7907eb9560f3b83282a5e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_029ca5cfd064f01fad0f65936a154fe2 = $(`&lt;div id=&quot;html_029ca5cfd064f01fad0f65936a154fe2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5a38d0854d7907eb9560f3b83282a5e5.setContent(html_029ca5cfd064f01fad0f65936a154fe2);
#
#
#
#         marker_532ae28936fec433717c9a7bf4e48a26.bindPopup(popup_5a38d0854d7907eb9560f3b83282a5e5)
#         ;
#
#
#
#
#             var marker_17fdf39010e1869b8b57b34eea544827 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1b4c26934a6dab334708aedb4649f3f6);
#
#
#         var popup_d02811675c4dc70d24f99c09634409a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3a77e01d00c32a5e3ca931d8bc31837 = $(`&lt;div id=&quot;html_f3a77e01d00c32a5e3ca931d8bc31837&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d02811675c4dc70d24f99c09634409a2.setContent(html_f3a77e01d00c32a5e3ca931d8bc31837);
#
#
#
#         marker_17fdf39010e1869b8b57b34eea544827.bindPopup(popup_d02811675c4dc70d24f99c09634409a2)
#         ;
#
#
#
#
#             var marker_ffb4f8cbe523ef2221280f7fcd2c8d3b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1b4c26934a6dab334708aedb4649f3f6);
#
#
#         var popup_d809adde594a96961460b23d2ed3b371 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8157d23d5f80ee8cad7e3d5f52cf7e7f = $(`&lt;div id=&quot;html_8157d23d5f80ee8cad7e3d5f52cf7e7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d809adde594a96961460b23d2ed3b371.setContent(html_8157d23d5f80ee8cad7e3d5f52cf7e7f);
#
#
#
#         marker_ffb4f8cbe523ef2221280f7fcd2c8d3b.bindPopup(popup_d809adde594a96961460b23d2ed3b371)
#         ;
#
#
#
#
#             var marker_056fd7670b56ac13d6299d78804c225b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1b4c26934a6dab334708aedb4649f3f6);
#
#
#         var popup_701bee545d34a692af391f45cf5a45f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_289c5776e809c038ce16567c6252d650 = $(`&lt;div id=&quot;html_289c5776e809c038ce16567c6252d650&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_701bee545d34a692af391f45cf5a45f5.setContent(html_289c5776e809c038ce16567c6252d650);
#
#
#
#         marker_056fd7670b56ac13d6299d78804c225b.bindPopup(popup_701bee545d34a692af391f45cf5a45f5)
#         ;
#
#
#
#
#             var marker_5060169f6e039f29549fd1a9935020c2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1b4c26934a6dab334708aedb4649f3f6);
#
#
#         var popup_186fa0af93f8a56bee9099b3a6b76d30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b041189cc5d0429633b8109dd556e40 = $(`&lt;div id=&quot;html_6b041189cc5d0429633b8109dd556e40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_186fa0af93f8a56bee9099b3a6b76d30.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8762c1149f9d657ad74ffcacc8a9f825 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8762c1149f9d657ad74ffcacc8a9f825&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8762c1149f9d657ad74ffcacc8a9f825 = L.map(
#                 &quot;map_8762c1149f9d657ad74ffcacc8a9f825&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff6074b68811c979ddec5dcf4c649310 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff6074b68811c979ddec5dcf4c649310.addTo(map_8762c1149f9d657ad74ffcacc8a9f825);
#
#
#             var feature_group_4d6e6534c23b4416ae694dfe91a3d741 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_68dbc0301801181033949829afb0c104 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4d6e6534c23b4416ae694dfe91a3d741);
#
#
#         var popup_77964e7a913c2235bed90e5db4d69f1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c21bc0ddee9bf66ffaa80867295eef01 = $(`&lt;div id=&quot;html_c21bc0ddee9bf66ffaa80867295eef01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_77964e7a913c2235bed90e5db4d69f1b.setContent(html_c21bc0ddee9bf66ffaa80867295eef01);
#
#
#
#         marker_68dbc0301801181033949829afb0c104.bindPopup(popup_77964e7a913c2235bed90e5db4d69f1b)
#         ;
#
#
#
#
#             var marker_5ec4d07a4284766da39134d0c6f5ac7a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4d6e6534c23b4416ae694dfe91a3d741);
#
#
#         var popup_cbab8edf6ca993ae83ec27931ef1066d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30db3d249d3f45a7572d38967b64de80 = $(`&lt;div id=&quot;html_30db3d249d3f45a7572d38967b64de80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cbab8edf6ca993ae83ec27931ef1066d.setContent(html_30db3d249d3f45a7572d38967b64de80);
#
#
#
#         marker_5ec4d07a4284766da39134d0c6f5ac7a.bindPopup(popup_cbab8edf6ca993ae83ec27931ef1066d)
#         ;
#
#
#
#
#             var marker_89deab1edd11f1053cb24cbb14a5faee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4d6e6534c23b4416ae694dfe91a3d741);
#
#
#         var popup_18c82d5a743086a87e46ce8e688f3723 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e107cb7c93a6fe4b1cf69f64a873069 = $(`&lt;div id=&quot;html_3e107cb7c93a6fe4b1cf69f64a873069&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_18c82d5a743086a87e46ce8e688f3723.setContent(html_3e107cb7c93a6fe4b1cf69f64a873069);
#
#
#
#         marker_89deab1edd11f1053cb24cbb14a5faee.bindPopup(popup_18c82d5a743086a87e46ce8e688f3723)
#         ;
#
#
#
#
#             var marker_2440ea5347753e5622e6ff6be0dc249f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4d6e6534c23b4416ae694dfe91a3d741);
#
#
#         var popup_b3912542eab6dd0b131b1abcdeb3532b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f31862008d77e0cd89f81543d82cbea9 = $(`&lt;div id=&quot;html_f31862008d77e0cd89f81543d82cbea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b3912542eab6dd0b131b1abcdeb3532b.setContent(html_f31862008d77e0cd89f81543d82cbea9);
#
#
#
#         marker_2440ea5347753e5622e6ff6be0dc249f.bindPopup(popup_b3912542eab6dd0b131b1abcdeb3532b)
#         ;
#
#
#
#
#             var marker_2f6ce9875b801b768a3680e464030e9c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4d6e6534c23b4416ae694dfe91a3d741);
#
#
#         var popup_f4d7ac2fa11be5a450ac73feaf9e87c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae7d3b0c05fb23cc5a75e2f6502a03cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae7d3b0c05fb23cc5a75e2f6502a03cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae7d3b0c05fb23cc5a75e2f6502a03cf = L.map(
#                 &quot;map_ae7d3b0c05fb23cc5a75e2f6502a03cf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c11696e8ed76ead2f7facc02e418af09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c11696e8ed76ead2f7facc02e418af09.addTo(map_ae7d3b0c05fb23cc5a75e2f6502a03cf);
#
#
#             var feature_group_71080bc322a6f223fc4a6cce35349fef = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_71080bc322a6f223fc4a6cce35349fef.addTo(map_ae7d3b0c05fb23cc5a75e2f6502a03cf);
#
#
#             var feature_group_sub_group_0c4a924989a41cbbf69ed873dd060b9b = L.featureGroup.subGroup(
#                 feature_group_71080bc322a6f223fc4a6cce35349fef
#             );
#
#
#             var marker_ef2648fbbc08989d900125c7498359df = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0c4a924989a41cbbf69ed873dd060b9b);
#
#
#         var popup_32b0c9255d2937f23830a51fe4d847b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f885f450a7c2ce84cc9949a35a31f14 = $(`&lt;div id=&quot;html_6f885f450a7c2ce84cc9949a35a31f14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_32b0c9255d2937f23830a51fe4d847b8.setContent(html_6f885f450a7c2ce84cc9949a35a31f14);
#
#
#
#         marker_ef2648fbbc08989d900125c7498359df.bindPopup(popup_32b0c9255d2937f23830a51fe4d847b8)
#         ;
#
#
#
#
#             var marker_85e87fae056f91a63b29e3042cb7dc8d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0c4a924989a41cbbf69ed873dd060b9b);
#
#
#         var popup_4f3ba9c403935a87116c9dfe95dda8c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb637bc4374e8c01fe59fa22b1812652 = $(`&lt;div id=&quot;html_cb637bc4374e8c01fe59fa22b1812652&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4f3ba9c403935a87116c9dfe95dda8c9.setContent(html_cb637bc4374e8c01fe59fa22b1812652);
#
#
#
#         marker_85e87fae056f91a63b29e3042cb7dc8d.bindPopup(popup_4f3ba9c403935a87116c9dfe95dda8c9)
#         ;
#
#
#
#
#             var marker_1205c62709e7f05d328a358b2c905b52 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0c4a924989a41cbbf69ed873dd060b9b);
#
#
#         var popup_0b35279f3ec8e65da8933522354dc0cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2798b1b350a65a7648f1c8ccba20387b = $(`&lt;div id=&quot;html_2798b1b350a65a7648f1c8ccba20387b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0b35279f3ec8e65da8933522354dc0cc.setContent(html_2798b1b350a65a7648f1c8ccba20387b);
#
#
#
#         marker_1205c62709e7f05d328a358b2c905b52.bindPopup(popup_0b35279f3ec8e65da8933522354dc0cc)
#         ;
#
#
#
#
#             var marker_6f258e95aeb0f6df75af4a840ea7f642 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0c4a924989a41cbbf69ed873dd060b9b);
#
#
#         var popup_4de65b3c8a9c928cdf0136217a1c94c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1519d324695ab4c7833d4c79d2de75d7 = $(`&lt;div id=&quot;html_1519d324695ab4c7833d4c79d2de75d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4de65b3c8a9c928cdf0136217a1c94c6.setContent(html_1519d324695ab4c7833d4c79d2de75d7);
#
#
#
#         marker_
