# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09d97747c2006088dde5e4a3967b44dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09d97747c2006088dde5e4a3967b44dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09d97747c2006088dde5e4a3967b44dd = L.map(
#                 &quot;map_09d97747c2006088dde5e4a3967b44dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e797432ca2cc3969ba961e43d65b10b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e797432ca2cc3969ba961e43d65b10b.addTo(map_09d97747c2006088dde5e4a3967b44dd);
#
#
#             var marker_3b61305d6e9f00aca7a137ecdd95194a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_09d97747c2006088dde5e4a3967b44dd);
#
#
#         var popup_2829e01353b7376b88ab06a855690a07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfeac2abf25c865b8aa1f9a48fa7caac = $(`&lt;div id=&quot;html_cfeac2abf25c865b8aa1f9a48fa7caac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2829e01353b7376b88ab06a855690a07.setContent(html_cfeac2abf25c865b8aa1f9a48fa7caac);
#
#
#
#         marker_3b61305d6e9f00aca7a137ecdd95194a.bindPopup(popup_2829e01353b7376b88ab06a855690a07)
#         ;
#
#
#
#
#             var marker_fffb0acdab564a4ba0ccf5dbfaf8a369 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_09d97747c2006088dde5e4a3967b44dd);
#
#
#         var popup_2bc8c438100445fbaf456a3bb926e91d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc580d8c90585b11d14ee5da7db1100d = $(`&lt;div id=&quot;html_bc580d8c90585b11d14ee5da7db1100d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2bc8c438100445fbaf456a3bb926e91d.setContent(html_bc580d8c90585b11d14ee5da7db1100d);
#
#
#
#         marker_fffb0acdab564a4ba0ccf5dbfaf8a369.bindPopup(popup_2bc8c438100445fbaf456a3bb926e91d)
#         ;
#
#
#
#
#             var marker_0c54222c7622261a026d7448f2c5a73b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_09d97747c2006088dde5e4a3967b44dd);
#
#
#         var popup_d66c5e11417dbe51be0903683d58ea9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe3af0d42eb2815fddb848be312838e8 = $(`&lt;div id=&quot;html_fe3af0d42eb2815fddb848be312838e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d66c5e11417dbe51be0903683d58ea9b.setContent(html_fe3af0d42eb2815fddb848be312838e8);
#
#
#
#         marker_0c54222c7622261a026d7448f2c5a73b.bindPopup(popup_d66c5e11417dbe51be0903683d58ea9b)
#         ;
#
#
#
#
#             var marker_47d166ccd7b8d65f5764475a724f6ae5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_09d97747c2006088dde5e4a3967b44dd);
#
#
#         var popup_41232537110c7e8cd728a4e183c32c7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a31472390a2bb6d7705d0a7d628e8c42 = $(`&lt;div id=&quot;html_a31472390a2bb6d7705d0a7d628e8c42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_41232537110c7e8cd728a4e183c32c7b.setContent(html_a31472390a2bb6d7705d0a7d628e8c42);
#
#
#
#         marker_47d166ccd7b8d65f5764475a724f6ae5.bindPopup(popup_41232537110c7e8cd728a4e183c32c7b)
#         ;
#
#
#
#
#             var marker_f02f171cb9582247f4d68623cc1c78f3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_09d97747c2006088dde5e4a3967b44dd);
#
#
#         var popup_b7da285d65501da3ea8bafb4b78ebb8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a90632612a3b4a361bfe4df9fc950304 = $(`&lt;div id=&quot;html_a90632612a3b4a361bfe4df9fc950304&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b7da285d65501da3ea8bafb4b78ebb8b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74fa69b0be4a94a1f4bcb5ccd36fb30f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74fa69b0be4a94a1f4bcb5ccd36fb30f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74fa69b0be4a94a1f4bcb5ccd36fb30f = L.map(
#                 &quot;map_74fa69b0be4a94a1f4bcb5ccd36fb30f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd1374c2090fa70e66a3e7731c2004e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fd1374c2090fa70e66a3e7731c2004e6.addTo(map_74fa69b0be4a94a1f4bcb5ccd36fb30f);
#
#
#             var feature_group_db596d16d2dab655f1ed389eee36ede8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d41b70fd1e02ab5a7e3ccdd2ecb1532a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_db596d16d2dab655f1ed389eee36ede8);
#
#
#         var popup_5e72bd1b8b6c09d1aa39c8dece6a7ca1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21ff2be5fd9dd2659ec49f239277dd38 = $(`&lt;div id=&quot;html_21ff2be5fd9dd2659ec49f239277dd38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5e72bd1b8b6c09d1aa39c8dece6a7ca1.setContent(html_21ff2be5fd9dd2659ec49f239277dd38);
#
#
#
#         marker_d41b70fd1e02ab5a7e3ccdd2ecb1532a.bindPopup(popup_5e72bd1b8b6c09d1aa39c8dece6a7ca1)
#         ;
#
#
#
#
#             var marker_c63231f15b12572163e35736dafe64c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_db596d16d2dab655f1ed389eee36ede8);
#
#
#         var popup_d5e01bcee9247d17a2a1ed4c66d3b497 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_574e04ac9981862decd04ed252cb3bd5 = $(`&lt;div id=&quot;html_574e04ac9981862decd04ed252cb3bd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d5e01bcee9247d17a2a1ed4c66d3b497.setContent(html_574e04ac9981862decd04ed252cb3bd5);
#
#
#
#         marker_c63231f15b12572163e35736dafe64c4.bindPopup(popup_d5e01bcee9247d17a2a1ed4c66d3b497)
#         ;
#
#
#
#
#             var marker_f4d4ebf65b45b0c31e2d73851c2263f2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_db596d16d2dab655f1ed389eee36ede8);
#
#
#         var popup_5c43a0a77bfab9e69ba98873ac1b3e65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2884bbaa2b51b7d4f4114796866217bb = $(`&lt;div id=&quot;html_2884bbaa2b51b7d4f4114796866217bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5c43a0a77bfab9e69ba98873ac1b3e65.setContent(html_2884bbaa2b51b7d4f4114796866217bb);
#
#
#
#         marker_f4d4ebf65b45b0c31e2d73851c2263f2.bindPopup(popup_5c43a0a77bfab9e69ba98873ac1b3e65)
#         ;
#
#
#
#
#             var marker_a76be13d397c47fb91f9c4f47b835097 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_db596d16d2dab655f1ed389eee36ede8);
#
#
#         var popup_f9169fdc18dc4f34c0de3ebd01b7ddf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03143200406722f3a2dc676ad2611548 = $(`&lt;div id=&quot;html_03143200406722f3a2dc676ad2611548&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f9169fdc18dc4f34c0de3ebd01b7ddf7.setContent(html_03143200406722f3a2dc676ad2611548);
#
#
#
#         marker_a76be13d397c47fb91f9c4f47b835097.bindPopup(popup_f9169fdc18dc4f34c0de3ebd01b7ddf7)
#         ;
#
#
#
#
#             var marker_6547a8069fafeddbe4eb052196badafc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_db596d16d2dab655f1ed389eee36ede8);
#
#
#         var popup_b2b2409ca5f8f5457fe448b5f3bcbad8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c711259dd07406474314cdd4639f76f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c711259dd07406474314cdd4639f76f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c711259dd07406474314cdd4639f76f = L.map(
#                 &quot;map_6c711259dd07406474314cdd4639f76f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc87e7081d3849eaab5114539f47524e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc87e7081d3849eaab5114539f47524e.addTo(map_6c711259dd07406474314cdd4639f76f);
#
#
#             var feature_group_c5a9e9c9a7c035b4e00ef5d2e481fd00 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c5a9e9c9a7c035b4e00ef5d2e481fd00.addTo(map_6c711259dd07406474314cdd4639f76f);
#
#
#             var feature_group_sub_group_a7c1a67b661e366bab4f8ac7b1dd803c = L.featureGroup.subGroup(
#                 feature_group_c5a9e9c9a7c035b4e00ef5d2e481fd00
#             );
#
#
#             var marker_84aaf7558908645bcca2ab27d9f14cff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a7c1a67b661e366bab4f8ac7b1dd803c);
#
#
#         var popup_9e727f8ac1d248db1777320bec4226d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9bddf1e0e9589195d755dfa3ffaacc3 = $(`&lt;div id=&quot;html_b9bddf1e0e9589195d755dfa3ffaacc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9e727f8ac1d248db1777320bec4226d3.setContent(html_b9bddf1e0e9589195d755dfa3ffaacc3);
#
#
#
#         marker_84aaf7558908645bcca2ab27d9f14cff.bindPopup(popup_9e727f8ac1d248db1777320bec4226d3)
#         ;
#
#
#
#
#             var marker_222180d0b95837d6eec224b8ca7222db = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a7c1a67b661e366bab4f8ac7b1dd803c);
#
#
#         var popup_8f919e0005be8340863cd4c4ac3a4f7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_750919729bc7096fa01e3e1ad03752d4 = $(`&lt;div id=&quot;html_750919729bc7096fa01e3e1ad03752d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8f919e0005be8340863cd4c4ac3a4f7c.setContent(html_750919729bc7096fa01e3e1ad03752d4);
#
#
#
#         marker_222180d0b95837d6eec224b8ca7222db.bindPopup(popup_8f919e0005be8340863cd4c4ac3a4f7c)
#         ;
#
#
#
#
#             var marker_311dc762f7cfca67243252dfbfa8ca74 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a7c1a67b661e366bab4f8ac7b1dd803c);
#
#
#         var popup_2ba04f65ce144b4f294f68529bd40966 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97f5045bb5648fcc0547dbf404f85082 = $(`&lt;div id=&quot;html_97f5045bb5648fcc0547dbf404f85082&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2ba04f65ce144b4f294f68529bd40966.setContent(html_97f5045bb5648fcc0547dbf404f85082);
#
#
#
#         marker_311dc762f7cfca67243252dfbfa8ca74.bindPopup(popup_2ba04f65ce144b4f294f68529bd40966)
#         ;
#
#
#
#
#             var marker_60c9669df65075a3528ccd6de30d7509 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a7c1a67b661e366bab4f8ac7b1dd803c);
#
#
#         var popup_73a1f819b1c47556f3708cf9c26793d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5b6e42a084acd3b5217d90657be6613 = $(`&lt;div id=&quot;html_f5b6e42a084acd3b5217d90657be6613&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_73a1f819b1c47556f3708cf9c26793d2.setContent(html_f5b6e42a084acd3b5217d90657be6613);
#
#
#
#         marker_
