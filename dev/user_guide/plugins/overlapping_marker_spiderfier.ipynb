# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db8c3706c7003e107935d0fb6154032c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db8c3706c7003e107935d0fb6154032c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db8c3706c7003e107935d0fb6154032c = L.map(
#                 &quot;map_db8c3706c7003e107935d0fb6154032c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_404578fce07dc7af1a805eee050acc99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_404578fce07dc7af1a805eee050acc99.addTo(map_db8c3706c7003e107935d0fb6154032c);
#
#
#             var marker_1a96b73525ba0b0155c4db52bf776609 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_db8c3706c7003e107935d0fb6154032c);
#
#
#         var popup_a5323fd244e2e1da88e5a7c2308a67fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4439f0e5e5b8d51cb046088492e6cc0c = $(`&lt;div id=&quot;html_4439f0e5e5b8d51cb046088492e6cc0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a5323fd244e2e1da88e5a7c2308a67fc.setContent(html_4439f0e5e5b8d51cb046088492e6cc0c);
#
#
#
#         marker_1a96b73525ba0b0155c4db52bf776609.bindPopup(popup_a5323fd244e2e1da88e5a7c2308a67fc)
#         ;
#
#
#
#
#             var marker_68159d378e92848179860a42c63d3a24 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_db8c3706c7003e107935d0fb6154032c);
#
#
#         var popup_c84beff1011f32f09bd92a6c76e8ac61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c41facf268f162677ab8933ef28d4003 = $(`&lt;div id=&quot;html_c41facf268f162677ab8933ef28d4003&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c84beff1011f32f09bd92a6c76e8ac61.setContent(html_c41facf268f162677ab8933ef28d4003);
#
#
#
#         marker_68159d378e92848179860a42c63d3a24.bindPopup(popup_c84beff1011f32f09bd92a6c76e8ac61)
#         ;
#
#
#
#
#             var marker_5a252141d8b75d7bcdc6bb172f2711da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_db8c3706c7003e107935d0fb6154032c);
#
#
#         var popup_f011d0e529ab3f4838211f14741b31de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11b700b45278f9dafb8e007c65ee058f = $(`&lt;div id=&quot;html_11b700b45278f9dafb8e007c65ee058f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f011d0e529ab3f4838211f14741b31de.setContent(html_11b700b45278f9dafb8e007c65ee058f);
#
#
#
#         marker_5a252141d8b75d7bcdc6bb172f2711da.bindPopup(popup_f011d0e529ab3f4838211f14741b31de)
#         ;
#
#
#
#
#             var marker_82d14a5c13d90b97ca1ccd6c57c72d2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_db8c3706c7003e107935d0fb6154032c);
#
#
#         var popup_9795a3f175d40e301d9fcbc20a1e333d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96a3fcd02556ac5928ac4f8cd69ffc5a = $(`&lt;div id=&quot;html_96a3fcd02556ac5928ac4f8cd69ffc5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9795a3f175d40e301d9fcbc20a1e333d.setContent(html_96a3fcd02556ac5928ac4f8cd69ffc5a);
#
#
#
#         marker_82d14a5c13d90b97ca1ccd6c57c72d2b.bindPopup(popup_9795a3f175d40e301d9fcbc20a1e333d)
#         ;
#
#
#
#
#             var marker_56aac335d71f8abd858402e6a7942302 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_db8c3706c7003e107935d0fb6154032c);
#
#
#         var popup_4265bee0b38cbf82b15b4dd3a4f5fcbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe2b017652cf44c30594f9f796c5e164 = $(`&lt;div id=&quot;html_fe2b017652cf44c30594f9f796c5e164&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4265bee0b38cbf82b15b4dd3a4f5fcbd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0acbea6a01717013bf97e33d362da684 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0acbea6a01717013bf97e33d362da684&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0acbea6a01717013bf97e33d362da684 = L.map(
#                 &quot;map_0acbea6a01717013bf97e33d362da684&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33b0b97b5c7e89739d221fbfb3b65aef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_33b0b97b5c7e89739d221fbfb3b65aef.addTo(map_0acbea6a01717013bf97e33d362da684);
#
#
#             var feature_group_a5af84406b5f4ee0b4d2380b74c8ddcd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0d9781cec42429a66f084c10ac4ec89f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a5af84406b5f4ee0b4d2380b74c8ddcd);
#
#
#         var popup_eb3e2b719f313d46a6d0c706fc2f6d9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa29bffd37e18a797877d5e0faffc04c = $(`&lt;div id=&quot;html_aa29bffd37e18a797877d5e0faffc04c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_eb3e2b719f313d46a6d0c706fc2f6d9c.setContent(html_aa29bffd37e18a797877d5e0faffc04c);
#
#
#
#         marker_0d9781cec42429a66f084c10ac4ec89f.bindPopup(popup_eb3e2b719f313d46a6d0c706fc2f6d9c)
#         ;
#
#
#
#
#             var marker_1f00acb4762993b9ac511abfbec79784 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a5af84406b5f4ee0b4d2380b74c8ddcd);
#
#
#         var popup_14870a254810e577cab3739ad09cb149 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f1bc3789a9c81de2bb456c77c42a739 = $(`&lt;div id=&quot;html_6f1bc3789a9c81de2bb456c77c42a739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_14870a254810e577cab3739ad09cb149.setContent(html_6f1bc3789a9c81de2bb456c77c42a739);
#
#
#
#         marker_1f00acb4762993b9ac511abfbec79784.bindPopup(popup_14870a254810e577cab3739ad09cb149)
#         ;
#
#
#
#
#             var marker_aad82b9fc100e4f424f680ee32a4e545 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a5af84406b5f4ee0b4d2380b74c8ddcd);
#
#
#         var popup_55713a3ea8e274088abe060a64ffedd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f89be979ec5f2553946b58134e27554 = $(`&lt;div id=&quot;html_9f89be979ec5f2553946b58134e27554&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_55713a3ea8e274088abe060a64ffedd7.setContent(html_9f89be979ec5f2553946b58134e27554);
#
#
#
#         marker_aad82b9fc100e4f424f680ee32a4e545.bindPopup(popup_55713a3ea8e274088abe060a64ffedd7)
#         ;
#
#
#
#
#             var marker_3f8abd3d3b7dbceca262d7a50c1bf43e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a5af84406b5f4ee0b4d2380b74c8ddcd);
#
#
#         var popup_dd524c718e9f59935624eac79e19d0ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f7338f4a7cd001ba8ded408f8c7d8a5 = $(`&lt;div id=&quot;html_2f7338f4a7cd001ba8ded408f8c7d8a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dd524c718e9f59935624eac79e19d0ab.setContent(html_2f7338f4a7cd001ba8ded408f8c7d8a5);
#
#
#
#         marker_3f8abd3d3b7dbceca262d7a50c1bf43e.bindPopup(popup_dd524c718e9f59935624eac79e19d0ab)
#         ;
#
#
#
#
#             var marker_6c267bfceba10e0c326034dd0ee8c5e0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a5af84406b5f4ee0b4d2380b74c8ddcd);
#
#
#         var popup_5caab5a0b40953070ba2102cb01861c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_491eea6c1c870d91802358845e71371d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_491eea6c1c870d91802358845e71371d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_491eea6c1c870d91802358845e71371d = L.map(
#                 &quot;map_491eea6c1c870d91802358845e71371d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_894376e751e1ad843a7f4a564b2fb4f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_894376e751e1ad843a7f4a564b2fb4f1.addTo(map_491eea6c1c870d91802358845e71371d);
#
#
#             var feature_group_b9cf2a476b4bb425a22732086b68607e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b9cf2a476b4bb425a22732086b68607e.addTo(map_491eea6c1c870d91802358845e71371d);
#
#
#             var feature_group_sub_group_4b59ede8eb97dc875ec6ba06aa5f3e94 = L.featureGroup.subGroup(
#                 feature_group_b9cf2a476b4bb425a22732086b68607e
#             );
#
#
#             var marker_0a737983a4339d6b7994a2738c21b2ca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b59ede8eb97dc875ec6ba06aa5f3e94);
#
#
#         var popup_f04db0ad570b386c88e6086ae76f0a8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7eb5308e207e4cce2ca49945c9898141 = $(`&lt;div id=&quot;html_7eb5308e207e4cce2ca49945c9898141&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f04db0ad570b386c88e6086ae76f0a8b.setContent(html_7eb5308e207e4cce2ca49945c9898141);
#
#
#
#         marker_0a737983a4339d6b7994a2738c21b2ca.bindPopup(popup_f04db0ad570b386c88e6086ae76f0a8b)
#         ;
#
#
#
#
#             var marker_8869aa9b73a1e6fac3cd0162f9b54720 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b59ede8eb97dc875ec6ba06aa5f3e94);
#
#
#         var popup_65896a92e8da82ee94b1e61d05111266 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfaff89835bca7561eafe815c2bd03ec = $(`&lt;div id=&quot;html_bfaff89835bca7561eafe815c2bd03ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_65896a92e8da82ee94b1e61d05111266.setContent(html_bfaff89835bca7561eafe815c2bd03ec);
#
#
#
#         marker_8869aa9b73a1e6fac3cd0162f9b54720.bindPopup(popup_65896a92e8da82ee94b1e61d05111266)
#         ;
#
#
#
#
#             var marker_fcf5fae6bdf97d2707763f3d75f4a05f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b59ede8eb97dc875ec6ba06aa5f3e94);
#
#
#         var popup_2b8a09410f84bc433a7adeeb60168dba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93effd4fd4525dd945980d98e9aaa88d = $(`&lt;div id=&quot;html_93effd4fd4525dd945980d98e9aaa88d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2b8a09410f84bc433a7adeeb60168dba.setContent(html_93effd4fd4525dd945980d98e9aaa88d);
#
#
#
#         marker_fcf5fae6bdf97d2707763f3d75f4a05f.bindPopup(popup_2b8a09410f84bc433a7adeeb60168dba)
#         ;
#
#
#
#
#             var marker_099fde60c17bbb3569e1d208ec5602a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b59ede8eb97dc875ec6ba06aa5f3e94);
#
#
#         var popup_286a5076f9d52982310d9ec3e0b54466 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a730bc223dc700cd84081fbfacaf9103 = $(`&lt;div id=&quot;html_a730bc223dc700cd84081fbfacaf9103&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_286a5076f9d52982310d9ec3e0b54466.setContent(html_a730bc223dc700cd84081fbfacaf9103);
#
#
#
#         marker_
