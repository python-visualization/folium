# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89d0776feefb91d5e887b16fea45efd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89d0776feefb91d5e887b16fea45efd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89d0776feefb91d5e887b16fea45efd6 = L.map(
#                 &quot;map_89d0776feefb91d5e887b16fea45efd6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a05e4c9b42ea14157c0efed03b429c3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a05e4c9b42ea14157c0efed03b429c3.addTo(map_89d0776feefb91d5e887b16fea45efd6);
#
#
#             var marker_516662b6eabea969839bc35982733b92 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_89d0776feefb91d5e887b16fea45efd6);
#
#
#         var popup_0f0c206656a189415853fcc133fca6c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4645b9bce9169fb7a5903e682e246bf = $(`&lt;div id=&quot;html_e4645b9bce9169fb7a5903e682e246bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0f0c206656a189415853fcc133fca6c9.setContent(html_e4645b9bce9169fb7a5903e682e246bf);
#
#
#
#         marker_516662b6eabea969839bc35982733b92.bindPopup(popup_0f0c206656a189415853fcc133fca6c9)
#         ;
#
#
#
#
#             var marker_821691ca77ddd4969681c50d8e691cfd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_89d0776feefb91d5e887b16fea45efd6);
#
#
#         var popup_7fc86a6f43489c35664098c8b31e6e4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24f611c8d56bb9024a8b423f8b025360 = $(`&lt;div id=&quot;html_24f611c8d56bb9024a8b423f8b025360&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7fc86a6f43489c35664098c8b31e6e4e.setContent(html_24f611c8d56bb9024a8b423f8b025360);
#
#
#
#         marker_821691ca77ddd4969681c50d8e691cfd.bindPopup(popup_7fc86a6f43489c35664098c8b31e6e4e)
#         ;
#
#
#
#
#             var marker_fcab4bfc2643dd8ce843da2a97570b11 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_89d0776feefb91d5e887b16fea45efd6);
#
#
#         var popup_7337eb7bb8885dc77c9b23fa42f6d5f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6a7c9e0b82bd9a945942d4424f79e05 = $(`&lt;div id=&quot;html_b6a7c9e0b82bd9a945942d4424f79e05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7337eb7bb8885dc77c9b23fa42f6d5f0.setContent(html_b6a7c9e0b82bd9a945942d4424f79e05);
#
#
#
#         marker_fcab4bfc2643dd8ce843da2a97570b11.bindPopup(popup_7337eb7bb8885dc77c9b23fa42f6d5f0)
#         ;
#
#
#
#
#             var marker_96db42301d6b802c5e993142a7c075d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_89d0776feefb91d5e887b16fea45efd6);
#
#
#         var popup_c60326d9ce390ece77ac97ee138a4cf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_596936674862699eab4faf5d00f7b70f = $(`&lt;div id=&quot;html_596936674862699eab4faf5d00f7b70f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c60326d9ce390ece77ac97ee138a4cf9.setContent(html_596936674862699eab4faf5d00f7b70f);
#
#
#
#         marker_96db42301d6b802c5e993142a7c075d6.bindPopup(popup_c60326d9ce390ece77ac97ee138a4cf9)
#         ;
#
#
#
#
#             var marker_56fff2091460bfc97679b05862f62a03 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_89d0776feefb91d5e887b16fea45efd6);
#
#
#         var popup_c4df65a361cf947a18b3af59359519df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b519fbed026ca058cd1046f4c9e3870 = $(`&lt;div id=&quot;html_9b519fbed026ca058cd1046f4c9e3870&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c4df65a361cf947a18b3af59359519df.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d62cbee3a79aaae3d2570c9c9411fac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d62cbee3a79aaae3d2570c9c9411fac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d62cbee3a79aaae3d2570c9c9411fac = L.map(
#                 &quot;map_0d62cbee3a79aaae3d2570c9c9411fac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07f267bf627b2b7aa26d2858a3cea0c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07f267bf627b2b7aa26d2858a3cea0c5.addTo(map_0d62cbee3a79aaae3d2570c9c9411fac);
#
#
#             var feature_group_8daab3ba4ae679839a9ff711b56b9627 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ee50490465b41eb28ea39e02a6c19267 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8daab3ba4ae679839a9ff711b56b9627);
#
#
#         var popup_773ec9e3d72e72b8fe92cfa465f0c1a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd2fea77abb0a2a5d67a838cd21edc09 = $(`&lt;div id=&quot;html_cd2fea77abb0a2a5d67a838cd21edc09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_773ec9e3d72e72b8fe92cfa465f0c1a8.setContent(html_cd2fea77abb0a2a5d67a838cd21edc09);
#
#
#
#         marker_ee50490465b41eb28ea39e02a6c19267.bindPopup(popup_773ec9e3d72e72b8fe92cfa465f0c1a8)
#         ;
#
#
#
#
#             var marker_831a9ebf9293f983a7b3a0ba2c603002 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8daab3ba4ae679839a9ff711b56b9627);
#
#
#         var popup_a07f0de345a3cf05d1aba3711df40208 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a689170251d5735fac57fd827e3e3d69 = $(`&lt;div id=&quot;html_a689170251d5735fac57fd827e3e3d69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a07f0de345a3cf05d1aba3711df40208.setContent(html_a689170251d5735fac57fd827e3e3d69);
#
#
#
#         marker_831a9ebf9293f983a7b3a0ba2c603002.bindPopup(popup_a07f0de345a3cf05d1aba3711df40208)
#         ;
#
#
#
#
#             var marker_6a8ca35123ea7c172cc4287f1599eec6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8daab3ba4ae679839a9ff711b56b9627);
#
#
#         var popup_15b3186dfe069430bcb0ee07cb39f17a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4688e8da0151e4cfb6698a33b2efc8d = $(`&lt;div id=&quot;html_e4688e8da0151e4cfb6698a33b2efc8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_15b3186dfe069430bcb0ee07cb39f17a.setContent(html_e4688e8da0151e4cfb6698a33b2efc8d);
#
#
#
#         marker_6a8ca35123ea7c172cc4287f1599eec6.bindPopup(popup_15b3186dfe069430bcb0ee07cb39f17a)
#         ;
#
#
#
#
#             var marker_b087d43d1f2f271e73393bc48fb14f28 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8daab3ba4ae679839a9ff711b56b9627);
#
#
#         var popup_2571fd51ad0595c691705859a513f295 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbe017ec18706829d28050188fbc0f16 = $(`&lt;div id=&quot;html_bbe017ec18706829d28050188fbc0f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2571fd51ad0595c691705859a513f295.setContent(html_bbe017ec18706829d28050188fbc0f16);
#
#
#
#         marker_b087d43d1f2f271e73393bc48fb14f28.bindPopup(popup_2571fd51ad0595c691705859a513f295)
#         ;
#
#
#
#
#             var marker_e3a2f41b01be956e3f628c6d3e6a21b7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8daab3ba4ae679839a9ff711b56b9627);
#
#
#         var popup_dea6c2b455105d5efbf78cae897dd9ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4aa9fb2783098a273433beb56d2b0786 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4aa9fb2783098a273433beb56d2b0786&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4aa9fb2783098a273433beb56d2b0786 = L.map(
#                 &quot;map_4aa9fb2783098a273433beb56d2b0786&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36345917101761d5d18eaa20dbcfad7a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36345917101761d5d18eaa20dbcfad7a.addTo(map_4aa9fb2783098a273433beb56d2b0786);
#
#
#             var feature_group_b3425ee372c40432397e2231836e776f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b3425ee372c40432397e2231836e776f.addTo(map_4aa9fb2783098a273433beb56d2b0786);
#
#
#             var feature_group_sub_group_fdb273748a87d5465a5f81db26ee40f0 = L.featureGroup.subGroup(
#                 feature_group_b3425ee372c40432397e2231836e776f
#             );
#
#
#             var marker_358eb2449364421c6462c0082303111d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fdb273748a87d5465a5f81db26ee40f0);
#
#
#         var popup_bb3a91b96a04159faaee626fe8c77737 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6766d67bf376d6bb4b0e47e1877c385 = $(`&lt;div id=&quot;html_f6766d67bf376d6bb4b0e47e1877c385&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bb3a91b96a04159faaee626fe8c77737.setContent(html_f6766d67bf376d6bb4b0e47e1877c385);
#
#
#
#         marker_358eb2449364421c6462c0082303111d.bindPopup(popup_bb3a91b96a04159faaee626fe8c77737)
#         ;
#
#
#
#
#             var marker_160c1051b23faada985e616041baed97 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fdb273748a87d5465a5f81db26ee40f0);
#
#
#         var popup_e0e08461a116fb5e9cffecfad9231fb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c522bcd66f3c570959a3aad3dcbd9433 = $(`&lt;div id=&quot;html_c522bcd66f3c570959a3aad3dcbd9433&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e0e08461a116fb5e9cffecfad9231fb3.setContent(html_c522bcd66f3c570959a3aad3dcbd9433);
#
#
#
#         marker_160c1051b23faada985e616041baed97.bindPopup(popup_e0e08461a116fb5e9cffecfad9231fb3)
#         ;
#
#
#
#
#             var marker_b24df68c28cdb5310d91006e0eaba4ee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fdb273748a87d5465a5f81db26ee40f0);
#
#
#         var popup_00d8cb5502aff35019ee6981fe580c9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_730d0b937610521c7db2e62792254abb = $(`&lt;div id=&quot;html_730d0b937610521c7db2e62792254abb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_00d8cb5502aff35019ee6981fe580c9c.setContent(html_730d0b937610521c7db2e62792254abb);
#
#
#
#         marker_b24df68c28cdb5310d91006e0eaba4ee.bindPopup(popup_00d8cb5502aff35019ee6981fe580c9c)
#         ;
#
#
#
#
#             var marker_0209713034c1b726679b632ffb0fcd76 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fdb273748a87d5465a5f81db26ee40f0);
#
#
#         var popup_7c03e7923ff473781c824a6d147170e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2491ae8ef3240158fd57a17f23f5d39 = $(`&lt;div id=&quot;html_e2491ae8ef3240158fd57a17f23f5d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7c03e7923ff473781c824a6d147170e1.setContent(html_e2491ae8ef3240158fd57a17f23f5d39);
#
#
#
#         marker_
