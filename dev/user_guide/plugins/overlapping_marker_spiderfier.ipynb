# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3b9dd120a3835af1e4294ed2ecf2523 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3b9dd120a3835af1e4294ed2ecf2523&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3b9dd120a3835af1e4294ed2ecf2523 = L.map(
#                 &quot;map_a3b9dd120a3835af1e4294ed2ecf2523&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_247efa12d58256066978131d36ce839b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_247efa12d58256066978131d36ce839b.addTo(map_a3b9dd120a3835af1e4294ed2ecf2523);
#
#
#             var marker_795ac5ca6fadb30e8d223d1a891a964e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a3b9dd120a3835af1e4294ed2ecf2523);
#
#
#         var popup_1a405c3f3b46e279b8f00d328b213708 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e97897c3d8a90c34f4b9a3efcfa9761 = $(`&lt;div id=&quot;html_0e97897c3d8a90c34f4b9a3efcfa9761&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1a405c3f3b46e279b8f00d328b213708.setContent(html_0e97897c3d8a90c34f4b9a3efcfa9761);
#
#
#
#         marker_795ac5ca6fadb30e8d223d1a891a964e.bindPopup(popup_1a405c3f3b46e279b8f00d328b213708)
#         ;
#
#
#
#
#             var marker_493ed2b0bb686b441115d60274cfefb0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a3b9dd120a3835af1e4294ed2ecf2523);
#
#
#         var popup_ee9049b141a9c1bb823f30c2246467e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2a96eb5aea6f74433d992f2cc6fe71a = $(`&lt;div id=&quot;html_d2a96eb5aea6f74433d992f2cc6fe71a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ee9049b141a9c1bb823f30c2246467e3.setContent(html_d2a96eb5aea6f74433d992f2cc6fe71a);
#
#
#
#         marker_493ed2b0bb686b441115d60274cfefb0.bindPopup(popup_ee9049b141a9c1bb823f30c2246467e3)
#         ;
#
#
#
#
#             var marker_10f548586ab2724ee175c6bf9872796a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a3b9dd120a3835af1e4294ed2ecf2523);
#
#
#         var popup_43ffe58a796fbb0173c6a4d467fb4e73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_633c3755c39c9aeb06f24731ff275361 = $(`&lt;div id=&quot;html_633c3755c39c9aeb06f24731ff275361&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_43ffe58a796fbb0173c6a4d467fb4e73.setContent(html_633c3755c39c9aeb06f24731ff275361);
#
#
#
#         marker_10f548586ab2724ee175c6bf9872796a.bindPopup(popup_43ffe58a796fbb0173c6a4d467fb4e73)
#         ;
#
#
#
#
#             var marker_5de0b25701c9053dd42b0aade8e6eaf0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a3b9dd120a3835af1e4294ed2ecf2523);
#
#
#         var popup_0c3300ad26c815dd613152d5aec3a4cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a481afe1d604021f9b8a690937c56fa9 = $(`&lt;div id=&quot;html_a481afe1d604021f9b8a690937c56fa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0c3300ad26c815dd613152d5aec3a4cf.setContent(html_a481afe1d604021f9b8a690937c56fa9);
#
#
#
#         marker_5de0b25701c9053dd42b0aade8e6eaf0.bindPopup(popup_0c3300ad26c815dd613152d5aec3a4cf)
#         ;
#
#
#
#
#             var marker_ca5e449194f4ff88450e04dbc4843a12 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a3b9dd120a3835af1e4294ed2ecf2523);
#
#
#         var popup_2afddb4a215932ebea71d48072b56068 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a02aed3119eadb9e5fb9e9dcc47a54f4 = $(`&lt;div id=&quot;html_a02aed3119eadb9e5fb9e9dcc47a54f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2afddb4a215932ebea71d48072b56068.setContent(html_a02aed3119eadb9e5fb9e9dcc47a54f4);
#
#
#
#         marker_ca5e449194f4ff88450e04dbc4843a12.bindPopup(popup_2afddb4a215932ebea71d48072b56068)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c1746baba3f79ac0fa318bf938c7b8c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c1746baba3f79ac0fa318bf938c7b8c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c1746baba3f79ac0fa318bf938c7b8c = L.map(
#                 &quot;map_4c1746baba3f79ac0fa318bf938c7b8c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c67530679f1fd4c52572d248f0c356d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c67530679f1fd4c52572d248f0c356d4.addTo(map_4c1746baba3f79ac0fa318bf938c7b8c);
#
#
#             var feature_group_a4502288e6c3e6fb4d7875f8041e0760 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a2dcc2ff0542de7baec8902b53ac20a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a4502288e6c3e6fb4d7875f8041e0760);
#
#
#         var popup_c0f0ce4ae8457e58053dd59a3b2c1b80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e55cb4a4b4221ca9e90534eb698f7547 = $(`&lt;div id=&quot;html_e55cb4a4b4221ca9e90534eb698f7547&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c0f0ce4ae8457e58053dd59a3b2c1b80.setContent(html_e55cb4a4b4221ca9e90534eb698f7547);
#
#
#
#         marker_a2dcc2ff0542de7baec8902b53ac20a2.bindPopup(popup_c0f0ce4ae8457e58053dd59a3b2c1b80)
#         ;
#
#
#
#
#             var marker_f6696848779000d1e4dff9939367ee70 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a4502288e6c3e6fb4d7875f8041e0760);
#
#
#         var popup_08b746af58ac82ba5301cbc40a07e9d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6910a7e447284a6b770e1a77f612a35e = $(`&lt;div id=&quot;html_6910a7e447284a6b770e1a77f612a35e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_08b746af58ac82ba5301cbc40a07e9d4.setContent(html_6910a7e447284a6b770e1a77f612a35e);
#
#
#
#         marker_f6696848779000d1e4dff9939367ee70.bindPopup(popup_08b746af58ac82ba5301cbc40a07e9d4)
#         ;
#
#
#
#
#             var marker_0a69d09430c48fa3bfcacba774b1a7d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a4502288e6c3e6fb4d7875f8041e0760);
#
#
#         var popup_403602b026ef3a67b74c501b00d62d51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c8ae8c7c1666297061f46976fd86bf7 = $(`&lt;div id=&quot;html_8c8ae8c7c1666297061f46976fd86bf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_403602b026ef3a67b74c501b00d62d51.setContent(html_8c8ae8c7c1666297061f46976fd86bf7);
#
#
#
#         marker_0a69d09430c48fa3bfcacba774b1a7d9.bindPopup(popup_403602b026ef3a67b74c501b00d62d51)
#         ;
#
#
#
#
#             var marker_e370d766ac85c7e7982799a247f9abf4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a4502288e6c3e6fb4d7875f8041e0760);
#
#
#         var popup_5ca7b7f084b6e325556ab5cb206ba68e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b8c9fbc864f29114632272d537d48c4 = $(`&lt;div id=&quot;html_6b8c9fbc864f29114632272d537d48c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5ca7b7f084b6e325556ab5cb206ba68e.setContent(html_6b8c9fbc864f29114632272d537d48c4);
#
#
#
#         marker_e370d766ac85c7e7982799a247f9abf4.bindPopup(popup_5ca7b7f084b6e325556ab5cb206ba68e)
#         ;
#
#
#
#
#             var marker_b85c7213ad8aa67c24af9b9c75f6fa56 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a4502288e6c3e6fb4d7875f8041e0760);
#
#
#         var popup_ffbcdae596d594f1a24ebc5509830929 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75ecf9f31a0f6dc18de93e5f9357ef1f = $(`&lt;div id=&quot;html_75ecf9f31a0f6dc18de93e5f9357ef1f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b610415e6934c5d826d7a744404df02 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b610415e6934c5d826d7a744404df02&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b610415e6934c5d826d7a744404df02 = L.map(
#                 &quot;map_5b610415e6934c5d826d7a744404df02&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9263a419e4f9794f5bcc724afb73d214 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9263a419e4f9794f5bcc724afb73d214.addTo(map_5b610415e6934c5d826d7a744404df02);
#
#
#             var feature_group_b3397ba1b4f5bdcabfb87a9e40edb88a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b3397ba1b4f5bdcabfb87a9e40edb88a.addTo(map_5b610415e6934c5d826d7a744404df02);
#
#
#             var feature_group_sub_group_e87be65cc882b8648497d10b0e5402f9 = L.featureGroup.subGroup(
#                 feature_group_b3397ba1b4f5bdcabfb87a9e40edb88a
#             );
#
#
#             var marker_35f38f71dde424dbcf8cdc30468c53c0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e87be65cc882b8648497d10b0e5402f9);
#
#
#         var popup_65acdb4ecb94f4200da30b03587bd441 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d26162aec9cf2406681349d23e4ab53 = $(`&lt;div id=&quot;html_5d26162aec9cf2406681349d23e4ab53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_65acdb4ecb94f4200da30b03587bd441.setContent(html_5d26162aec9cf2406681349d23e4ab53);
#
#
#
#         marker_35f38f71dde424dbcf8cdc30468c53c0.bindPopup(popup_65acdb4ecb94f4200da30b03587bd441)
#         ;
#
#
#
#
#             var marker_5f0069bfd9da608c3523500237aaa25c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e87be65cc882b8648497d10b0e5402f9);
#
#
#         var popup_8ee5bda6e0791eef55aeb4a8221754a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af47fb12924be9a314bfb5645dff0051 = $(`&lt;div id=&quot;html_af47fb12924be9a314bfb5645dff0051&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8ee5bda6e0791eef55aeb4a8221754a4.setContent(html_af47fb12924be9a314bfb5645dff0051);
#
#
#
#         marker_5f0069bfd9da608c3523500237aaa25c.bindPopup(popup_8ee5bda6e0791eef55aeb4a8221754a4)
#         ;
#
#
#
#
#             var marker_6e93e9036f328095249b4dbd09bef9cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e87be65cc882b8648497d10b0e5402f9);
#
#
#         var popup_1dc14ad7ee82a42bc339f739fea5c002 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50ec71c19ffa33e6cb4c3c4638fdacd9 = $(`&lt;div id=&quot;html_50ec71c19ffa33e6cb4c3c4638fdacd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1dc14ad7ee82a42bc339f739fea5c002.setContent(html_50ec71c19ffa33e6cb4c3c4638fdacd9);
#
#
#
#         marker_6e93e9036f328095249b4dbd09bef9cd.bindPopup(popup_1dc14ad7ee82a42bc339f739fea5c002)
#         ;
#
#
#
#
#             var marker_ef572e5c6687c9c7a5040a26a9d83a3a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e87be65cc882b8648497d10b0e5402f9);
#
#
#         var popup_e293758a81a5f81031eb79b4a577a692 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f1894ac07450c1212a7fafe46598470 = $(`&lt;div id=&quot;html_3f1894ac07450c1212a7fafe46598470&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e293758a81a5f81031eb79b4a577a692.setContent(html_3f1894ac07450c1212a7fafe46598470);
#
#
#
#         marker_ef572e5c6687c9c7a5040a26a9d83a3a.bindPopup(popup_e293758a81a5f81031eb79b4a577a692)
#         ;
#
#
#
#
#             var marker_5f78b3c2a3da3db707ccafda77ce4a78 = L.marker(
#                 [45.0503999
