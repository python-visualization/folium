# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf94e6e417609147098887bb09c8ec66 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf94e6e417609147098887bb09c8ec66&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf94e6e417609147098887bb09c8ec66 = L.map(
#                 &quot;map_cf94e6e417609147098887bb09c8ec66&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfc2622fe6447827fdc9e1e832c65ee4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfc2622fe6447827fdc9e1e832c65ee4.addTo(map_cf94e6e417609147098887bb09c8ec66);
#
#
#             var marker_e8070680f720961c1274f8ff76fab1a9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cf94e6e417609147098887bb09c8ec66);
#
#
#         var popup_f36ca373947f8db239c372aff3eabb17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f80e9aa752baa58f900fd79a2a99cf07 = $(`&lt;div id=&quot;html_f80e9aa752baa58f900fd79a2a99cf07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f36ca373947f8db239c372aff3eabb17.setContent(html_f80e9aa752baa58f900fd79a2a99cf07);
#
#
#
#         marker_e8070680f720961c1274f8ff76fab1a9.bindPopup(popup_f36ca373947f8db239c372aff3eabb17)
#         ;
#
#
#
#
#             var marker_b33b3521141a879066f2c9412837c29c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cf94e6e417609147098887bb09c8ec66);
#
#
#         var popup_c9ede6678351916f4369394e8b772a11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8beaae87d7e30e42608cd6f2d8d9688 = $(`&lt;div id=&quot;html_a8beaae87d7e30e42608cd6f2d8d9688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c9ede6678351916f4369394e8b772a11.setContent(html_a8beaae87d7e30e42608cd6f2d8d9688);
#
#
#
#         marker_b33b3521141a879066f2c9412837c29c.bindPopup(popup_c9ede6678351916f4369394e8b772a11)
#         ;
#
#
#
#
#             var marker_49360ca1ce11ee57194ddcbbda535003 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cf94e6e417609147098887bb09c8ec66);
#
#
#         var popup_9edee1a7ee67d58d86ab10ad0cd65951 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c01da5186fa025a906253b015e13f808 = $(`&lt;div id=&quot;html_c01da5186fa025a906253b015e13f808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9edee1a7ee67d58d86ab10ad0cd65951.setContent(html_c01da5186fa025a906253b015e13f808);
#
#
#
#         marker_49360ca1ce11ee57194ddcbbda535003.bindPopup(popup_9edee1a7ee67d58d86ab10ad0cd65951)
#         ;
#
#
#
#
#             var marker_8225a06ca9b0d84e2afeeedf2f716303 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cf94e6e417609147098887bb09c8ec66);
#
#
#         var popup_e91ac52010d491ff038dd5ccd0474453 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7913f139c204f13d4fa31d1a6c56d2f2 = $(`&lt;div id=&quot;html_7913f139c204f13d4fa31d1a6c56d2f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e91ac52010d491ff038dd5ccd0474453.setContent(html_7913f139c204f13d4fa31d1a6c56d2f2);
#
#
#
#         marker_8225a06ca9b0d84e2afeeedf2f716303.bindPopup(popup_e91ac52010d491ff038dd5ccd0474453)
#         ;
#
#
#
#
#             var marker_3e66979571c7f352f3d626118533ca99 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cf94e6e417609147098887bb09c8ec66);
#
#
#         var popup_11ea6828602d1a337677f641d161edad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e28a082fd9f68f9740355fd373f3cd8 = $(`&lt;div id=&quot;html_0e28a082fd9f68f9740355fd373f3cd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_11ea6828602d1a337677f641d161ed

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93ff53fb4b78d01bcc9c6e0f08c95707 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93ff53fb4b78d01bcc9c6e0f08c95707&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93ff53fb4b78d01bcc9c6e0f08c95707 = L.map(
#                 &quot;map_93ff53fb4b78d01bcc9c6e0f08c95707&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_458bc4555d3bf92cbd4dd67ffc493ce4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_458bc4555d3bf92cbd4dd67ffc493ce4.addTo(map_93ff53fb4b78d01bcc9c6e0f08c95707);
#
#
#             var feature_group_6045bfaae3ef47a816b72b271c604649 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_371716a5aeecfd3e52e59acdfc53e848 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6045bfaae3ef47a816b72b271c604649);
#
#
#         var popup_259a101ef62c317432ac1038d44cac27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ef0254559f6a384463c6fcaaebcd83f = $(`&lt;div id=&quot;html_6ef0254559f6a384463c6fcaaebcd83f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_259a101ef62c317432ac1038d44cac27.setContent(html_6ef0254559f6a384463c6fcaaebcd83f);
#
#
#
#         marker_371716a5aeecfd3e52e59acdfc53e848.bindPopup(popup_259a101ef62c317432ac1038d44cac27)
#         ;
#
#
#
#
#             var marker_754c2916ba2a947487977a70bd045d07 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6045bfaae3ef47a816b72b271c604649);
#
#
#         var popup_19b37ec4cc626f39370b521c72a821c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e83b78ab1782a9b1d760968a424ef6e = $(`&lt;div id=&quot;html_1e83b78ab1782a9b1d760968a424ef6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_19b37ec4cc626f39370b521c72a821c4.setContent(html_1e83b78ab1782a9b1d760968a424ef6e);
#
#
#
#         marker_754c2916ba2a947487977a70bd045d07.bindPopup(popup_19b37ec4cc626f39370b521c72a821c4)
#         ;
#
#
#
#
#             var marker_ec533afd2158ba943e2560ddf8465cc9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6045bfaae3ef47a816b72b271c604649);
#
#
#         var popup_cdf6983c6e02086f6f70c379ef4092d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94a3d30d25e22cd3ebf0ed6dea1b785d = $(`&lt;div id=&quot;html_94a3d30d25e22cd3ebf0ed6dea1b785d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cdf6983c6e02086f6f70c379ef4092d5.setContent(html_94a3d30d25e22cd3ebf0ed6dea1b785d);
#
#
#
#         marker_ec533afd2158ba943e2560ddf8465cc9.bindPopup(popup_cdf6983c6e02086f6f70c379ef4092d5)
#         ;
#
#
#
#
#             var marker_dcb6a68b491947c6aeae4f125f3aaf7c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6045bfaae3ef47a816b72b271c604649);
#
#
#         var popup_5514ab66e286d9828f29d17ee3594bd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eab3692df2329085ff7f2ffc8bece9ac = $(`&lt;div id=&quot;html_eab3692df2329085ff7f2ffc8bece9ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5514ab66e286d9828f29d17ee3594bd4.setContent(html_eab3692df2329085ff7f2ffc8bece9ac);
#
#
#
#         marker_dcb6a68b491947c6aeae4f125f3aaf7c.bindPopup(popup_5514ab66e286d9828f29d17ee3594bd4)
#         ;
#
#
#
#
#             var marker_281a364b5b230e8a716fcd1205308d59 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6045bfaae3ef47a816b72b271c604649);
#
#
#         var popup_85a8a43df37f921665e57759eed5db13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92e0ae8c3e054e3b867d91cfa876a929 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92e0ae8c3e054e3b867d91cfa876a929&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92e0ae8c3e054e3b867d91cfa876a929 = L.map(
#                 &quot;map_92e0ae8c3e054e3b867d91cfa876a929&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5890be5cf1d0129927f5e3b99f1b0c14 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5890be5cf1d0129927f5e3b99f1b0c14.addTo(map_92e0ae8c3e054e3b867d91cfa876a929);
#
#
#             var feature_group_45399a34acbde7649dbdedbd3bbc1473 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_45399a34acbde7649dbdedbd3bbc1473.addTo(map_92e0ae8c3e054e3b867d91cfa876a929);
#
#
#             var feature_group_sub_group_ea2126f5e29ea590dce2ebfe8b189580 = L.featureGroup.subGroup(
#                 feature_group_45399a34acbde7649dbdedbd3bbc1473
#             );
#
#
#             var marker_fa1e81fdc9468ca25b311ca5bd4bf39a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea2126f5e29ea590dce2ebfe8b189580);
#
#
#         var popup_44f98664b88c079fd50a73f9fabb03bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c3975f8ef51d5177c18dbb0eb80830c = $(`&lt;div id=&quot;html_2c3975f8ef51d5177c18dbb0eb80830c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_44f98664b88c079fd50a73f9fabb03bf.setContent(html_2c3975f8ef51d5177c18dbb0eb80830c);
#
#
#
#         marker_fa1e81fdc9468ca25b311ca5bd4bf39a.bindPopup(popup_44f98664b88c079fd50a73f9fabb03bf)
#         ;
#
#
#
#
#             var marker_6216754c9d44b3798c1576ba0410eeb5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea2126f5e29ea590dce2ebfe8b189580);
#
#
#         var popup_4aa11e7817253acff9cf917ad500384a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d54db3e0b24722f19afe83b14648a9ee = $(`&lt;div id=&quot;html_d54db3e0b24722f19afe83b14648a9ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4aa11e7817253acff9cf917ad500384a.setContent(html_d54db3e0b24722f19afe83b14648a9ee);
#
#
#
#         marker_6216754c9d44b3798c1576ba0410eeb5.bindPopup(popup_4aa11e7817253acff9cf917ad500384a)
#         ;
#
#
#
#
#             var marker_39ee4910e2c05db832f4816f15fa54fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea2126f5e29ea590dce2ebfe8b189580);
#
#
#         var popup_d6c4a30eafa1a18fc677d18a6fbbab5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c305d4ba81842a4e2781cc55ab7b144 = $(`&lt;div id=&quot;html_3c305d4ba81842a4e2781cc55ab7b144&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d6c4a30eafa1a18fc677d18a6fbbab5d.setContent(html_3c305d4ba81842a4e2781cc55ab7b144);
#
#
#
#         marker_39ee4910e2c05db832f4816f15fa54fa.bindPopup(popup_d6c4a30eafa1a18fc677d18a6fbbab5d)
#         ;
#
#
#
#
#             var marker_f7a7f06b5fe822535af549b88ea0801f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ea2126f5e29ea590dce2ebfe8b189580);
#
#
#         var popup_42030c76c79fed8d03bcb3d0ea298e6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66e71a0be4d7221ca64c4735082a3149 = $(`&lt;div id=&quot;html_66e71a0be4d7221ca64c4735082a3149&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_42030c76c79fed8d03bcb3d0ea298e6b.setContent(html_66e71a0be4d7221ca64c4735082a3149);
#
#
#
#         mark
