# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01ca3e59f90ce74780ab9d6134042fba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01ca3e59f90ce74780ab9d6134042fba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01ca3e59f90ce74780ab9d6134042fba = L.map(
#                 &quot;map_01ca3e59f90ce74780ab9d6134042fba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e4e8f4be67b64c1e0567efa1db49dbc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e4e8f4be67b64c1e0567efa1db49dbc.addTo(map_01ca3e59f90ce74780ab9d6134042fba);
#
#
#             var marker_6edb4073cfb00dc855dce1a1305d08ee = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_01ca3e59f90ce74780ab9d6134042fba);
#
#
#         var popup_21375b1d9214084523b4d51304144dc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4056b541fb80f26d40f8e556bd27d38 = $(`&lt;div id=&quot;html_c4056b541fb80f26d40f8e556bd27d38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_21375b1d9214084523b4d51304144dc3.setContent(html_c4056b541fb80f26d40f8e556bd27d38);
#
#
#
#         marker_6edb4073cfb00dc855dce1a1305d08ee.bindPopup(popup_21375b1d9214084523b4d51304144dc3)
#         ;
#
#
#
#
#             var marker_afd0fb3dbcbbd29c5a0613c21bdd3b51 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_01ca3e59f90ce74780ab9d6134042fba);
#
#
#         var popup_929374c1ce2cf9fe38adf7c41886d75d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9125c0ce1f4a7e4ab74dfa7fe67b17cc = $(`&lt;div id=&quot;html_9125c0ce1f4a7e4ab74dfa7fe67b17cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_929374c1ce2cf9fe38adf7c41886d75d.setContent(html_9125c0ce1f4a7e4ab74dfa7fe67b17cc);
#
#
#
#         marker_afd0fb3dbcbbd29c5a0613c21bdd3b51.bindPopup(popup_929374c1ce2cf9fe38adf7c41886d75d)
#         ;
#
#
#
#
#             var marker_0939262d2190a8f36677ea1f189d203d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_01ca3e59f90ce74780ab9d6134042fba);
#
#
#         var popup_d4ca8325569b5b27a48f7357ce88c6d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4d0879dd460ee88e4c8d8c3bdefd890 = $(`&lt;div id=&quot;html_a4d0879dd460ee88e4c8d8c3bdefd890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d4ca8325569b5b27a48f7357ce88c6d0.setContent(html_a4d0879dd460ee88e4c8d8c3bdefd890);
#
#
#
#         marker_0939262d2190a8f36677ea1f189d203d.bindPopup(popup_d4ca8325569b5b27a48f7357ce88c6d0)
#         ;
#
#
#
#
#             var marker_e6c329cbdd7395fe91664fce1c8437be = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_01ca3e59f90ce74780ab9d6134042fba);
#
#
#         var popup_3393754d0be6ec3cd07283249a35a4aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0467ce1da101d3cd195f449bfea5150b = $(`&lt;div id=&quot;html_0467ce1da101d3cd195f449bfea5150b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3393754d0be6ec3cd07283249a35a4aa.setContent(html_0467ce1da101d3cd195f449bfea5150b);
#
#
#
#         marker_e6c329cbdd7395fe91664fce1c8437be.bindPopup(popup_3393754d0be6ec3cd07283249a35a4aa)
#         ;
#
#
#
#
#             var marker_c426f026498b4dee4d97364b6cea6b54 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_01ca3e59f90ce74780ab9d6134042fba);
#
#
#         var popup_86185eee729fa0790656e2be2ab2b767 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6199b39172bf3c5111d3c3399576547c = $(`&lt;div id=&quot;html_6199b39172bf3c5111d3c3399576547c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_86185eee729fa0790656e2be2ab2b767.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51b95e8d818af130209dcb98efd4cc6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51b95e8d818af130209dcb98efd4cc6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51b95e8d818af130209dcb98efd4cc6e = L.map(
#                 &quot;map_51b95e8d818af130209dcb98efd4cc6e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ba7d55963dc7cb570db4eb53c437bcd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ba7d55963dc7cb570db4eb53c437bcd.addTo(map_51b95e8d818af130209dcb98efd4cc6e);
#
#
#             var feature_group_302c4338c61ce83e012315b1116e4061 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f706e021c195ae71d137c00cc2e88c4f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_302c4338c61ce83e012315b1116e4061);
#
#
#         var popup_3bcedc4a878857b7935aad64bc4a9fc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_968a243102c4b181377e7384cde4ce23 = $(`&lt;div id=&quot;html_968a243102c4b181377e7384cde4ce23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3bcedc4a878857b7935aad64bc4a9fc2.setContent(html_968a243102c4b181377e7384cde4ce23);
#
#
#
#         marker_f706e021c195ae71d137c00cc2e88c4f.bindPopup(popup_3bcedc4a878857b7935aad64bc4a9fc2)
#         ;
#
#
#
#
#             var marker_1db22a39678b2fb0e386b97b1936a060 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_302c4338c61ce83e012315b1116e4061);
#
#
#         var popup_a9ffc932b72f426d52955f87793d2ad3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09d0f6619d5b4d5408fd5ea737e0c147 = $(`&lt;div id=&quot;html_09d0f6619d5b4d5408fd5ea737e0c147&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a9ffc932b72f426d52955f87793d2ad3.setContent(html_09d0f6619d5b4d5408fd5ea737e0c147);
#
#
#
#         marker_1db22a39678b2fb0e386b97b1936a060.bindPopup(popup_a9ffc932b72f426d52955f87793d2ad3)
#         ;
#
#
#
#
#             var marker_306c9489c4a86b2168c7589d7f3a8368 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_302c4338c61ce83e012315b1116e4061);
#
#
#         var popup_21a1589dd1d2769edca9144816098d36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_938e634ac5faeaccba8ff9cfec9557a4 = $(`&lt;div id=&quot;html_938e634ac5faeaccba8ff9cfec9557a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_21a1589dd1d2769edca9144816098d36.setContent(html_938e634ac5faeaccba8ff9cfec9557a4);
#
#
#
#         marker_306c9489c4a86b2168c7589d7f3a8368.bindPopup(popup_21a1589dd1d2769edca9144816098d36)
#         ;
#
#
#
#
#             var marker_8bf667ffbed55747947e9694214cc407 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_302c4338c61ce83e012315b1116e4061);
#
#
#         var popup_366a9ec5552931c67293b7207ca5cafc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3229e06f58b67516919b90baac966bf2 = $(`&lt;div id=&quot;html_3229e06f58b67516919b90baac966bf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_366a9ec5552931c67293b7207ca5cafc.setContent(html_3229e06f58b67516919b90baac966bf2);
#
#
#
#         marker_8bf667ffbed55747947e9694214cc407.bindPopup(popup_366a9ec5552931c67293b7207ca5cafc)
#         ;
#
#
#
#
#             var marker_de966315c6de6e6cb160916668f9c67d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_302c4338c61ce83e012315b1116e4061);
#
#
#         var popup_6af8f67059cc61b925bd9407c379542c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_911ce05d319552e577a0cd9596690a24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_911ce05d319552e577a0cd9596690a24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_911ce05d319552e577a0cd9596690a24 = L.map(
#                 &quot;map_911ce05d319552e577a0cd9596690a24&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45dbdc0e4d3eca74cc5ae3ba5efd9a7d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45dbdc0e4d3eca74cc5ae3ba5efd9a7d.addTo(map_911ce05d319552e577a0cd9596690a24);
#
#
#             var feature_group_8d0f9056d196248ef4dda38e6595507f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8d0f9056d196248ef4dda38e6595507f.addTo(map_911ce05d319552e577a0cd9596690a24);
#
#
#             var feature_group_sub_group_7bf1e0a5b4f96dfa7a04c04fe8f8af11 = L.featureGroup.subGroup(
#                 feature_group_8d0f9056d196248ef4dda38e6595507f
#             );
#
#
#             var marker_c939da30d899c669302b24d0e4eb44fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7bf1e0a5b4f96dfa7a04c04fe8f8af11);
#
#
#         var popup_9a015451e75045a2696354779e31b481 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78e32793d51c85450b3b92e03224d270 = $(`&lt;div id=&quot;html_78e32793d51c85450b3b92e03224d270&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9a015451e75045a2696354779e31b481.setContent(html_78e32793d51c85450b3b92e03224d270);
#
#
#
#         marker_c939da30d899c669302b24d0e4eb44fd.bindPopup(popup_9a015451e75045a2696354779e31b481)
#         ;
#
#
#
#
#             var marker_a9f3e24e2cb25313976f31128935090c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7bf1e0a5b4f96dfa7a04c04fe8f8af11);
#
#
#         var popup_95e70ec9de307c01bfcbb5655daff16b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c042d6d23a8d21d374eb1c3c67fa90ed = $(`&lt;div id=&quot;html_c042d6d23a8d21d374eb1c3c67fa90ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_95e70ec9de307c01bfcbb5655daff16b.setContent(html_c042d6d23a8d21d374eb1c3c67fa90ed);
#
#
#
#         marker_a9f3e24e2cb25313976f31128935090c.bindPopup(popup_95e70ec9de307c01bfcbb5655daff16b)
#         ;
#
#
#
#
#             var marker_a31f6d662dbb5e5bead84a75ed82ac92 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7bf1e0a5b4f96dfa7a04c04fe8f8af11);
#
#
#         var popup_26ef41f9174151739d479d3029cafd30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81445197a1f2184f9299bfeb44d7902a = $(`&lt;div id=&quot;html_81445197a1f2184f9299bfeb44d7902a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_26ef41f9174151739d479d3029cafd30.setContent(html_81445197a1f2184f9299bfeb44d7902a);
#
#
#
#         marker_a31f6d662dbb5e5bead84a75ed82ac92.bindPopup(popup_26ef41f9174151739d479d3029cafd30)
#         ;
#
#
#
#
#             var marker_e430347ac2941b0967a336a2d2e2bd96 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7bf1e0a5b4f96dfa7a04c04fe8f8af11);
#
#
#         var popup_21772e732540fd8d3392e7a6c268e6c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5f1819917aabbe1b2128af9ada952e8 = $(`&lt;div id=&quot;html_c5f1819917aabbe1b2128af9ada952e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_21772e732540fd8d3392e7a6c268e6c2.setContent(html_c5f1819917aabbe1b2128af9ada952e8);
#
#
#
#         marker_
