# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed1d50e8822e5e39857aa8a7f8210b81 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed1d50e8822e5e39857aa8a7f8210b81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed1d50e8822e5e39857aa8a7f8210b81 = L.map(
#                 &quot;map_ed1d50e8822e5e39857aa8a7f8210b81&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72005f489a180a5687216ab339aad6c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72005f489a180a5687216ab339aad6c5.addTo(map_ed1d50e8822e5e39857aa8a7f8210b81);
#
#
#             var marker_de7d7db9d73cc83f95e87549d30cca18 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ed1d50e8822e5e39857aa8a7f8210b81);
#
#
#         var popup_2b9a4240082aa9c9ed7e6f40192c9f03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0dcb93a0edd16cf66b00910c6ad3d96 = $(`&lt;div id=&quot;html_a0dcb93a0edd16cf66b00910c6ad3d96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2b9a4240082aa9c9ed7e6f40192c9f03.setContent(html_a0dcb93a0edd16cf66b00910c6ad3d96);
#
#
#
#         marker_de7d7db9d73cc83f95e87549d30cca18.bindPopup(popup_2b9a4240082aa9c9ed7e6f40192c9f03)
#         ;
#
#
#
#
#             var marker_6e00ab98a22bfa56f9d1146f2323e392 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ed1d50e8822e5e39857aa8a7f8210b81);
#
#
#         var popup_cf3be00a939c97e64d143451153f92bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a16133bff6c9751ca6b6b612e088fce3 = $(`&lt;div id=&quot;html_a16133bff6c9751ca6b6b612e088fce3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_cf3be00a939c97e64d143451153f92bb.setContent(html_a16133bff6c9751ca6b6b612e088fce3);
#
#
#
#         marker_6e00ab98a22bfa56f9d1146f2323e392.bindPopup(popup_cf3be00a939c97e64d143451153f92bb)
#         ;
#
#
#
#
#             var marker_2411e9862bdf2a43355371b15fd1ec19 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ed1d50e8822e5e39857aa8a7f8210b81);
#
#
#         var popup_aaa8c5539906844a0878c98ca221c976 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b09e346ec9675ea7d128c0793deac192 = $(`&lt;div id=&quot;html_b09e346ec9675ea7d128c0793deac192&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_aaa8c5539906844a0878c98ca221c976.setContent(html_b09e346ec9675ea7d128c0793deac192);
#
#
#
#         marker_2411e9862bdf2a43355371b15fd1ec19.bindPopup(popup_aaa8c5539906844a0878c98ca221c976)
#         ;
#
#
#
#
#             var marker_43934cb18e9bfbdda98c9b2e37690fae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ed1d50e8822e5e39857aa8a7f8210b81);
#
#
#         var popup_4ba07484f1c6f1e10a69d98618dc143b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b83bc416c008ab8c1029fc9fc5c57d8a = $(`&lt;div id=&quot;html_b83bc416c008ab8c1029fc9fc5c57d8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4ba07484f1c6f1e10a69d98618dc143b.setContent(html_b83bc416c008ab8c1029fc9fc5c57d8a);
#
#
#
#         marker_43934cb18e9bfbdda98c9b2e37690fae.bindPopup(popup_4ba07484f1c6f1e10a69d98618dc143b)
#         ;
#
#
#
#
#             var marker_2b75c70746ea9a40418789739f4b5842 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ed1d50e8822e5e39857aa8a7f8210b81);
#
#
#         var popup_ac35846c4243b32f0c468072e1f2ad65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b40b2ecd0e33e45a6b9157d903ec17a = $(`&lt;div id=&quot;html_2b40b2ecd0e33e45a6b9157d903ec17a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ac35846c4243b32f0c468072e1f2ad

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7287ad53b3f43587a889be7e5465d0e6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7287ad53b3f43587a889be7e5465d0e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7287ad53b3f43587a889be7e5465d0e6 = L.map(
#                 &quot;map_7287ad53b3f43587a889be7e5465d0e6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5693e940e2ff5dbd2950377f62c2ecb4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5693e940e2ff5dbd2950377f62c2ecb4.addTo(map_7287ad53b3f43587a889be7e5465d0e6);
#
#
#             var feature_group_35fed1b38b94ac3e7c20eef028ad7db8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_757a67b25642d6b6542a85e2d20b3b89 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_35fed1b38b94ac3e7c20eef028ad7db8);
#
#
#         var popup_35b5c2b91d6cf12dfe4b8dfdc7af2541 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0dab2a88fc892ec349b2432151882a2 = $(`&lt;div id=&quot;html_d0dab2a88fc892ec349b2432151882a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_35b5c2b91d6cf12dfe4b8dfdc7af2541.setContent(html_d0dab2a88fc892ec349b2432151882a2);
#
#
#
#         marker_757a67b25642d6b6542a85e2d20b3b89.bindPopup(popup_35b5c2b91d6cf12dfe4b8dfdc7af2541)
#         ;
#
#
#
#
#             var marker_4df08b61645540c675219c64c4b99332 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_35fed1b38b94ac3e7c20eef028ad7db8);
#
#
#         var popup_1c403c99ff55379c2fde7223243d7557 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e73c371d9ab4a167af74380c9be2cabe = $(`&lt;div id=&quot;html_e73c371d9ab4a167af74380c9be2cabe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1c403c99ff55379c2fde7223243d7557.setContent(html_e73c371d9ab4a167af74380c9be2cabe);
#
#
#
#         marker_4df08b61645540c675219c64c4b99332.bindPopup(popup_1c403c99ff55379c2fde7223243d7557)
#         ;
#
#
#
#
#             var marker_0df4187e56caf84935dcf0bddf4e336e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_35fed1b38b94ac3e7c20eef028ad7db8);
#
#
#         var popup_165a396a9abde1df55245ca47c9490c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5de4b3c8e6e48313f9650efdd9f9ab5b = $(`&lt;div id=&quot;html_5de4b3c8e6e48313f9650efdd9f9ab5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_165a396a9abde1df55245ca47c9490c4.setContent(html_5de4b3c8e6e48313f9650efdd9f9ab5b);
#
#
#
#         marker_0df4187e56caf84935dcf0bddf4e336e.bindPopup(popup_165a396a9abde1df55245ca47c9490c4)
#         ;
#
#
#
#
#             var marker_e9a685b2a545ea57b2ee7a24a00c4633 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_35fed1b38b94ac3e7c20eef028ad7db8);
#
#
#         var popup_357381f8891e1349c1686a1472a1d862 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4809ae9cfa553df20cd67cf087bfb6af = $(`&lt;div id=&quot;html_4809ae9cfa553df20cd67cf087bfb6af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_357381f8891e1349c1686a1472a1d862.setContent(html_4809ae9cfa553df20cd67cf087bfb6af);
#
#
#
#         marker_e9a685b2a545ea57b2ee7a24a00c4633.bindPopup(popup_357381f8891e1349c1686a1472a1d862)
#         ;
#
#
#
#
#             var marker_141cedb26d20e44a058677395ac71d55 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_35fed1b38b94ac3e7c20eef028ad7db8);
#
#
#         var popup_4a3d0d50efb8f95b88372c070b9c8be2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8631a63806fde0fc0698047552c13c4e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8631a63806fde0fc0698047552c13c4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8631a63806fde0fc0698047552c13c4e = L.map(
#                 &quot;map_8631a63806fde0fc0698047552c13c4e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e4e6e2721d502dfc23050f84bafda4de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e4e6e2721d502dfc23050f84bafda4de.addTo(map_8631a63806fde0fc0698047552c13c4e);
#
#
#             var feature_group_47bb77b642a887cb9751e51306eb246d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_47bb77b642a887cb9751e51306eb246d.addTo(map_8631a63806fde0fc0698047552c13c4e);
#
#
#             var feature_group_sub_group_b73a0bd2c365139421ff1d89e2779d35 = L.featureGroup.subGroup(
#                 feature_group_47bb77b642a887cb9751e51306eb246d
#             );
#
#
#             var marker_d2d0b6fef87280bc216efb356e12c680 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b73a0bd2c365139421ff1d89e2779d35);
#
#
#         var popup_08ba85279e3f6453ff6cb710e87960f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f188b07d2b7390dc1d2987d09313805 = $(`&lt;div id=&quot;html_2f188b07d2b7390dc1d2987d09313805&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_08ba85279e3f6453ff6cb710e87960f4.setContent(html_2f188b07d2b7390dc1d2987d09313805);
#
#
#
#         marker_d2d0b6fef87280bc216efb356e12c680.bindPopup(popup_08ba85279e3f6453ff6cb710e87960f4)
#         ;
#
#
#
#
#             var marker_a84254a4035a51fd174553ba6c3ceee5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b73a0bd2c365139421ff1d89e2779d35);
#
#
#         var popup_764a8dcae65973b8f598411f88b7bec0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68f5f1af3a21e1e9d43d925b7b98fcc9 = $(`&lt;div id=&quot;html_68f5f1af3a21e1e9d43d925b7b98fcc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_764a8dcae65973b8f598411f88b7bec0.setContent(html_68f5f1af3a21e1e9d43d925b7b98fcc9);
#
#
#
#         marker_a84254a4035a51fd174553ba6c3ceee5.bindPopup(popup_764a8dcae65973b8f598411f88b7bec0)
#         ;
#
#
#
#
#             var marker_b45d610314284dcf5beb91a18700d473 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b73a0bd2c365139421ff1d89e2779d35);
#
#
#         var popup_b235be713278f383ce3e91ff1f4048dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f4b8525b4f81f75bc0c868859e4c7c8 = $(`&lt;div id=&quot;html_1f4b8525b4f81f75bc0c868859e4c7c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b235be713278f383ce3e91ff1f4048dc.setContent(html_1f4b8525b4f81f75bc0c868859e4c7c8);
#
#
#
#         marker_b45d610314284dcf5beb91a18700d473.bindPopup(popup_b235be713278f383ce3e91ff1f4048dc)
#         ;
#
#
#
#
#             var marker_4784e707c18f24c9d61060072862ce76 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b73a0bd2c365139421ff1d89e2779d35);
#
#
#         var popup_c6d31007c49e516eaf247b66e8b4e766 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc0184032c4d7d99c5b19e7fba4e66cd = $(`&lt;div id=&quot;html_bc0184032c4d7d99c5b19e7fba4e66cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c6d31007c49e516eaf247b66e8b4e766.setContent(html_bc0184032c4d7d99c5b19e7fba4e66cd);
#
#
#
#         mark
