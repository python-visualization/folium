# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0bda55db4157d7a0f8ea0b70bfbafc76 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0bda55db4157d7a0f8ea0b70bfbafc76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0bda55db4157d7a0f8ea0b70bfbafc76 = L.map(
#                 &quot;map_0bda55db4157d7a0f8ea0b70bfbafc76&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ac8be9296a118afa941544beeb98ffc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4ac8be9296a118afa941544beeb98ffc.addTo(map_0bda55db4157d7a0f8ea0b70bfbafc76);
#
#
#             var marker_d765fa23623ebcd155e95fb2813c6388 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0bda55db4157d7a0f8ea0b70bfbafc76);
#
#
#         var popup_f51f0dcbd9c8d757d8962d405b74eb0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49eeca8dc9fd7200171c4cc1985a05ed = $(`&lt;div id=&quot;html_49eeca8dc9fd7200171c4cc1985a05ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f51f0dcbd9c8d757d8962d405b74eb0a.setContent(html_49eeca8dc9fd7200171c4cc1985a05ed);
#
#
#
#         marker_d765fa23623ebcd155e95fb2813c6388.bindPopup(popup_f51f0dcbd9c8d757d8962d405b74eb0a)
#         ;
#
#
#
#
#             var marker_13f3b737613dcba98b78e9a741ea7100 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0bda55db4157d7a0f8ea0b70bfbafc76);
#
#
#         var popup_98aa7abde41465d5ea6f16e43016f65c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adf2277eab16a5211bd4ee744d3a452c = $(`&lt;div id=&quot;html_adf2277eab16a5211bd4ee744d3a452c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_98aa7abde41465d5ea6f16e43016f65c.setContent(html_adf2277eab16a5211bd4ee744d3a452c);
#
#
#
#         marker_13f3b737613dcba98b78e9a741ea7100.bindPopup(popup_98aa7abde41465d5ea6f16e43016f65c)
#         ;
#
#
#
#
#             var marker_a1ba67ecc16aba0d8b558de4cf0cdcd0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0bda55db4157d7a0f8ea0b70bfbafc76);
#
#
#         var popup_307637ec4acd2c673389f54e7abecb08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4724de2c0a751c540efd5c0126fe67da = $(`&lt;div id=&quot;html_4724de2c0a751c540efd5c0126fe67da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_307637ec4acd2c673389f54e7abecb08.setContent(html_4724de2c0a751c540efd5c0126fe67da);
#
#
#
#         marker_a1ba67ecc16aba0d8b558de4cf0cdcd0.bindPopup(popup_307637ec4acd2c673389f54e7abecb08)
#         ;
#
#
#
#
#             var marker_06e348c9aabbb27574cf84235a98a33a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0bda55db4157d7a0f8ea0b70bfbafc76);
#
#
#         var popup_2ae2b53c3a45345ff390a28617eed70f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d98caee225bb55fbeae7142a5187747 = $(`&lt;div id=&quot;html_8d98caee225bb55fbeae7142a5187747&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2ae2b53c3a45345ff390a28617eed70f.setContent(html_8d98caee225bb55fbeae7142a5187747);
#
#
#
#         marker_06e348c9aabbb27574cf84235a98a33a.bindPopup(popup_2ae2b53c3a45345ff390a28617eed70f)
#         ;
#
#
#
#
#             var marker_1a4b572cc8afd41444814b6b94aea24f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0bda55db4157d7a0f8ea0b70bfbafc76);
#
#
#         var popup_016ac9604abf18d1510ca631454c5ebf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd3ff37c827acdf10bf165ffbff830e8 = $(`&lt;div id=&quot;html_cd3ff37c827acdf10bf165ffbff830e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_016ac9604abf18d1510ca631454c5e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b18297e3f90c9eb9e3751ce71bae4c4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b18297e3f90c9eb9e3751ce71bae4c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b18297e3f90c9eb9e3751ce71bae4c4 = L.map(
#                 &quot;map_9b18297e3f90c9eb9e3751ce71bae4c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d26ba1f9b924d90ad7a66af3cff24197 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d26ba1f9b924d90ad7a66af3cff24197.addTo(map_9b18297e3f90c9eb9e3751ce71bae4c4);
#
#
#             var feature_group_9b1f5b5dd6aafd57dd748185240f59a3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_25112c6158df7714f597dac8405cd0a2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9b1f5b5dd6aafd57dd748185240f59a3);
#
#
#         var popup_6e96979912f6cff346affce0a10a1a97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a589501ab1e012985925d22b441a688 = $(`&lt;div id=&quot;html_8a589501ab1e012985925d22b441a688&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6e96979912f6cff346affce0a10a1a97.setContent(html_8a589501ab1e012985925d22b441a688);
#
#
#
#         marker_25112c6158df7714f597dac8405cd0a2.bindPopup(popup_6e96979912f6cff346affce0a10a1a97)
#         ;
#
#
#
#
#             var marker_cdb75ed6236bdab01469b07121f9e067 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9b1f5b5dd6aafd57dd748185240f59a3);
#
#
#         var popup_d89a78ab958f49b9310192c225d70531 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d37d89774a558bc62050f7df48aadc5 = $(`&lt;div id=&quot;html_5d37d89774a558bc62050f7df48aadc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d89a78ab958f49b9310192c225d70531.setContent(html_5d37d89774a558bc62050f7df48aadc5);
#
#
#
#         marker_cdb75ed6236bdab01469b07121f9e067.bindPopup(popup_d89a78ab958f49b9310192c225d70531)
#         ;
#
#
#
#
#             var marker_359346825a280c78c189e9bb4e560020 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9b1f5b5dd6aafd57dd748185240f59a3);
#
#
#         var popup_5f122a433dedf59d3b9ad96133f870c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc2757032ba1b3e00517162acbdf434d = $(`&lt;div id=&quot;html_cc2757032ba1b3e00517162acbdf434d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5f122a433dedf59d3b9ad96133f870c6.setContent(html_cc2757032ba1b3e00517162acbdf434d);
#
#
#
#         marker_359346825a280c78c189e9bb4e560020.bindPopup(popup_5f122a433dedf59d3b9ad96133f870c6)
#         ;
#
#
#
#
#             var marker_194365d88ed2b707a61094d082a234b7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9b1f5b5dd6aafd57dd748185240f59a3);
#
#
#         var popup_8904253ca4ad2f62293229e67591585f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6a048b737ced4fb50f7493ada141c68 = $(`&lt;div id=&quot;html_c6a048b737ced4fb50f7493ada141c68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8904253ca4ad2f62293229e67591585f.setContent(html_c6a048b737ced4fb50f7493ada141c68);
#
#
#
#         marker_194365d88ed2b707a61094d082a234b7.bindPopup(popup_8904253ca4ad2f62293229e67591585f)
#         ;
#
#
#
#
#             var marker_223a4b998a2751ed24bbdcd4f53f6704 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9b1f5b5dd6aafd57dd748185240f59a3);
#
#
#         var popup_872774c1b32c53f510ccf72bae2d2a8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2034d3bd2407f3ef1c698ddc24937209 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2034d3bd2407f3ef1c698ddc24937209&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2034d3bd2407f3ef1c698ddc24937209 = L.map(
#                 &quot;map_2034d3bd2407f3ef1c698ddc24937209&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_864df67aab5b921e194f7bf9fd53e943 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_864df67aab5b921e194f7bf9fd53e943.addTo(map_2034d3bd2407f3ef1c698ddc24937209);
#
#
#             var feature_group_b3b5b4c201c9aacb74926af9c39e54eb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b3b5b4c201c9aacb74926af9c39e54eb.addTo(map_2034d3bd2407f3ef1c698ddc24937209);
#
#
#             var feature_group_sub_group_afb3a39c8da6c37ba202175be7b66081 = L.featureGroup.subGroup(
#                 feature_group_b3b5b4c201c9aacb74926af9c39e54eb
#             );
#
#
#             var marker_3d5861f3528b90eeb2160416b70b6d7e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_afb3a39c8da6c37ba202175be7b66081);
#
#
#         var popup_9488a5fad9703e1782bf328a911af37f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bef7f916f42a04b78f06d7581d12b28 = $(`&lt;div id=&quot;html_6bef7f916f42a04b78f06d7581d12b28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9488a5fad9703e1782bf328a911af37f.setContent(html_6bef7f916f42a04b78f06d7581d12b28);
#
#
#
#         marker_3d5861f3528b90eeb2160416b70b6d7e.bindPopup(popup_9488a5fad9703e1782bf328a911af37f)
#         ;
#
#
#
#
#             var marker_d93000127ac218de30ecc5897b507cb8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_afb3a39c8da6c37ba202175be7b66081);
#
#
#         var popup_c0a21af9172de31c4e4f714a097a718d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfa4c7600a01d9365b61dea0935b7b6b = $(`&lt;div id=&quot;html_cfa4c7600a01d9365b61dea0935b7b6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c0a21af9172de31c4e4f714a097a718d.setContent(html_cfa4c7600a01d9365b61dea0935b7b6b);
#
#
#
#         marker_d93000127ac218de30ecc5897b507cb8.bindPopup(popup_c0a21af9172de31c4e4f714a097a718d)
#         ;
#
#
#
#
#             var marker_2c45ab03ef326ee50f4d0ddd8e4b04d5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_afb3a39c8da6c37ba202175be7b66081);
#
#
#         var popup_ef01c97c123a920addb98a1970e8a8ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5be54b88887efca3c0097ed5d70dac7 = $(`&lt;div id=&quot;html_a5be54b88887efca3c0097ed5d70dac7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ef01c97c123a920addb98a1970e8a8ad.setContent(html_a5be54b88887efca3c0097ed5d70dac7);
#
#
#
#         marker_2c45ab03ef326ee50f4d0ddd8e4b04d5.bindPopup(popup_ef01c97c123a920addb98a1970e8a8ad)
#         ;
#
#
#
#
#             var marker_5916384cb5825479d6577d27f8833922 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_afb3a39c8da6c37ba202175be7b66081);
#
#
#         var popup_a200ed3eead64d3c0f56df954233bf6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b44c692cfd37bacbc824df229ed4bfd1 = $(`&lt;div id=&quot;html_b44c692cfd37bacbc824df229ed4bfd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a200ed3eead64d3c0f56df954233bf6a.setContent(html_b44c692cfd37bacbc824df229ed4bfd1);
#
#
#
#         mark
