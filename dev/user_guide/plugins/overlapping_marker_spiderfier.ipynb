# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a398be338e7b9d9128db298f90adf036 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a398be338e7b9d9128db298f90adf036&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a398be338e7b9d9128db298f90adf036 = L.map(
#                 &quot;map_a398be338e7b9d9128db298f90adf036&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c4d47f3ba005457feb3849a18fd5357 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c4d47f3ba005457feb3849a18fd5357.addTo(map_a398be338e7b9d9128db298f90adf036);
#
#
#             var marker_d8df63a6607992ab2bb1f9e1ceeee289 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a398be338e7b9d9128db298f90adf036);
#
#
#         var popup_5eada3f67cc1d12ec7af183f85c08c42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ff4547bebd20aaadf71b8282153167d = $(`&lt;div id=&quot;html_9ff4547bebd20aaadf71b8282153167d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5eada3f67cc1d12ec7af183f85c08c42.setContent(html_9ff4547bebd20aaadf71b8282153167d);
#
#
#
#         marker_d8df63a6607992ab2bb1f9e1ceeee289.bindPopup(popup_5eada3f67cc1d12ec7af183f85c08c42)
#         ;
#
#
#
#
#             var marker_bed9735dee7ba246ba818d500bd21cb8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a398be338e7b9d9128db298f90adf036);
#
#
#         var popup_0815915b12c80f3b8858bcf625d24236 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4405b470a5e6d095eca49d4b937510e6 = $(`&lt;div id=&quot;html_4405b470a5e6d095eca49d4b937510e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0815915b12c80f3b8858bcf625d24236.setContent(html_4405b470a5e6d095eca49d4b937510e6);
#
#
#
#         marker_bed9735dee7ba246ba818d500bd21cb8.bindPopup(popup_0815915b12c80f3b8858bcf625d24236)
#         ;
#
#
#
#
#             var marker_5ce671b8e9ae8e9c1cf83918d7176d0d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a398be338e7b9d9128db298f90adf036);
#
#
#         var popup_5ec7f5edce632bbc6ae6a690c62a8ccc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27a3612d34dbd4375b98fd0319e75a02 = $(`&lt;div id=&quot;html_27a3612d34dbd4375b98fd0319e75a02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5ec7f5edce632bbc6ae6a690c62a8ccc.setContent(html_27a3612d34dbd4375b98fd0319e75a02);
#
#
#
#         marker_5ce671b8e9ae8e9c1cf83918d7176d0d.bindPopup(popup_5ec7f5edce632bbc6ae6a690c62a8ccc)
#         ;
#
#
#
#
#             var marker_6eb4a19bddf0d06b4b4ab9c3292e8017 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a398be338e7b9d9128db298f90adf036);
#
#
#         var popup_f6712e09b9e0e9e6d05afa1e16106149 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a773ad3dac303cfba3ade30df316327d = $(`&lt;div id=&quot;html_a773ad3dac303cfba3ade30df316327d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f6712e09b9e0e9e6d05afa1e16106149.setContent(html_a773ad3dac303cfba3ade30df316327d);
#
#
#
#         marker_6eb4a19bddf0d06b4b4ab9c3292e8017.bindPopup(popup_f6712e09b9e0e9e6d05afa1e16106149)
#         ;
#
#
#
#
#             var marker_a1b5e01ffcd1e7f8308076b054cf3f73 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a398be338e7b9d9128db298f90adf036);
#
#
#         var popup_dd50777ac727a708ae6e0d1b32e4b040 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_684aa726402add200c86bdf98abbe0ba = $(`&lt;div id=&quot;html_684aa726402add200c86bdf98abbe0ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dd50777ac727a708ae6e0d1b32e4b0

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6643fa3de4957153176ea89278046da8 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6643fa3de4957153176ea89278046da8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6643fa3de4957153176ea89278046da8 = L.map(
#                 &quot;map_6643fa3de4957153176ea89278046da8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17b175e0a3b4f762e66478e1ebdd45a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17b175e0a3b4f762e66478e1ebdd45a5.addTo(map_6643fa3de4957153176ea89278046da8);
#
#
#             var feature_group_1ffcc21c53de9507140dbe34beab7e6a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dadee09bad22337c5c2b05c82ee7eefd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1ffcc21c53de9507140dbe34beab7e6a);
#
#
#         var popup_2108eefa150fc5bec6710a592964f85b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cf42d9a25d73e0dd0e938c1af4f0e79 = $(`&lt;div id=&quot;html_1cf42d9a25d73e0dd0e938c1af4f0e79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2108eefa150fc5bec6710a592964f85b.setContent(html_1cf42d9a25d73e0dd0e938c1af4f0e79);
#
#
#
#         marker_dadee09bad22337c5c2b05c82ee7eefd.bindPopup(popup_2108eefa150fc5bec6710a592964f85b)
#         ;
#
#
#
#
#             var marker_f960010f5877d08247b3fd6726d425b8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1ffcc21c53de9507140dbe34beab7e6a);
#
#
#         var popup_595840bbfed5ea955efdae5213bc4074 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bf8359880f8e8f7f00cfcc4fce1dd7a = $(`&lt;div id=&quot;html_8bf8359880f8e8f7f00cfcc4fce1dd7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_595840bbfed5ea955efdae5213bc4074.setContent(html_8bf8359880f8e8f7f00cfcc4fce1dd7a);
#
#
#
#         marker_f960010f5877d08247b3fd6726d425b8.bindPopup(popup_595840bbfed5ea955efdae5213bc4074)
#         ;
#
#
#
#
#             var marker_72e563869c31a1101290a2ff1cc16868 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1ffcc21c53de9507140dbe34beab7e6a);
#
#
#         var popup_991f3a4f7e728dc91f0dd21890020c9f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2227fdc309b308739f384c2fabe5f40d = $(`&lt;div id=&quot;html_2227fdc309b308739f384c2fabe5f40d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_991f3a4f7e728dc91f0dd21890020c9f.setContent(html_2227fdc309b308739f384c2fabe5f40d);
#
#
#
#         marker_72e563869c31a1101290a2ff1cc16868.bindPopup(popup_991f3a4f7e728dc91f0dd21890020c9f)
#         ;
#
#
#
#
#             var marker_5af35ce5524735cdc2bd9522f18536f1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1ffcc21c53de9507140dbe34beab7e6a);
#
#
#         var popup_f43ea9176e32d37e591a5bd8b4af7203 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_062f3977e7ad7089b82dac356f2d1463 = $(`&lt;div id=&quot;html_062f3977e7ad7089b82dac356f2d1463&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f43ea9176e32d37e591a5bd8b4af7203.setContent(html_062f3977e7ad7089b82dac356f2d1463);
#
#
#
#         marker_5af35ce5524735cdc2bd9522f18536f1.bindPopup(popup_f43ea9176e32d37e591a5bd8b4af7203)
#         ;
#
#
#
#
#             var marker_95aed4deba8468e08b080431e1e9bcb6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1ffcc21c53de9507140dbe34beab7e6a);
#
#
#         var popup_1f23ca87c878ab48bf7c3350a23d0fae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef8ccc3d31db396ae7fb500dd89a112f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef8ccc3d31db396ae7fb500dd89a112f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef8ccc3d31db396ae7fb500dd89a112f = L.map(
#                 &quot;map_ef8ccc3d31db396ae7fb500dd89a112f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_95f39ef43ae1393126ea94bd1b4d5afe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_95f39ef43ae1393126ea94bd1b4d5afe.addTo(map_ef8ccc3d31db396ae7fb500dd89a112f);
#
#
#             var feature_group_bd58ef6db93227c9c5d99d1cdabbe9c3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bd58ef6db93227c9c5d99d1cdabbe9c3.addTo(map_ef8ccc3d31db396ae7fb500dd89a112f);
#
#
#             var feature_group_sub_group_2edbb25d04018e129a5ead18ba20902c = L.featureGroup.subGroup(
#                 feature_group_bd58ef6db93227c9c5d99d1cdabbe9c3
#             );
#
#
#             var marker_e0b3830a5edff4f351b44db62e6fb91c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2edbb25d04018e129a5ead18ba20902c);
#
#
#         var popup_72145fd425f0d5ee2ec5ab77eb869cfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6dd41410aec0d16e343851f8a58a4738 = $(`&lt;div id=&quot;html_6dd41410aec0d16e343851f8a58a4738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_72145fd425f0d5ee2ec5ab77eb869cfe.setContent(html_6dd41410aec0d16e343851f8a58a4738);
#
#
#
#         marker_e0b3830a5edff4f351b44db62e6fb91c.bindPopup(popup_72145fd425f0d5ee2ec5ab77eb869cfe)
#         ;
#
#
#
#
#             var marker_c5530246df71cb4c14c089ceebb7b639 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2edbb25d04018e129a5ead18ba20902c);
#
#
#         var popup_929c6e982c8d8d797e4dc6e8e8ff3d4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35e44b62ab166182ebeca6356a4442fd = $(`&lt;div id=&quot;html_35e44b62ab166182ebeca6356a4442fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_929c6e982c8d8d797e4dc6e8e8ff3d4f.setContent(html_35e44b62ab166182ebeca6356a4442fd);
#
#
#
#         marker_c5530246df71cb4c14c089ceebb7b639.bindPopup(popup_929c6e982c8d8d797e4dc6e8e8ff3d4f)
#         ;
#
#
#
#
#             var marker_a1f26df1aad7bb6a7b26168c50df7270 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2edbb25d04018e129a5ead18ba20902c);
#
#
#         var popup_f22a81532238f6ae941dde8bfa6d58ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b6bcaabd938338035badd39c831a0f1 = $(`&lt;div id=&quot;html_0b6bcaabd938338035badd39c831a0f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f22a81532238f6ae941dde8bfa6d58ca.setContent(html_0b6bcaabd938338035badd39c831a0f1);
#
#
#
#         marker_a1f26df1aad7bb6a7b26168c50df7270.bindPopup(popup_f22a81532238f6ae941dde8bfa6d58ca)
#         ;
#
#
#
#
#             var marker_8c432d8123bf68c9b60c13fd2f021cff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2edbb25d04018e129a5ead18ba20902c);
#
#
#         var popup_40d62485fa587858e4699cd565be91e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4002eac49669dcd79eb6247de4a435cd = $(`&lt;div id=&quot;html_4002eac49669dcd79eb6247de4a435cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_40d62485fa587858e4699cd565be91e6.setContent(html_4002eac49669dcd79eb6247de4a435cd);
#
#
#
#         mark
