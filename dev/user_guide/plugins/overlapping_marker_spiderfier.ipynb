# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e17d665a3c9c625693847ce7e8f05a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e17d665a3c9c625693847ce7e8f05a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e17d665a3c9c625693847ce7e8f05a9 = L.map(
#                 &quot;map_6e17d665a3c9c625693847ce7e8f05a9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b7cf205fee4b3565823f88af13cae0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b7cf205fee4b3565823f88af13cae0a.addTo(map_6e17d665a3c9c625693847ce7e8f05a9);
#
#
#             var marker_fba717babe9d9dc9f15915cc0d272a28 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6e17d665a3c9c625693847ce7e8f05a9);
#
#
#         var popup_a0bd6229a244cc763216d63bcd098387 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83e956a3e4e449341f5a171bbd2c1e97 = $(`&lt;div id=&quot;html_83e956a3e4e449341f5a171bbd2c1e97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a0bd6229a244cc763216d63bcd098387.setContent(html_83e956a3e4e449341f5a171bbd2c1e97);
#
#
#
#         marker_fba717babe9d9dc9f15915cc0d272a28.bindPopup(popup_a0bd6229a244cc763216d63bcd098387)
#         ;
#
#
#
#
#             var marker_3317aaaba2fd131c5b661a3e2aae5844 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6e17d665a3c9c625693847ce7e8f05a9);
#
#
#         var popup_88a069e781bc2f07428ea88f4e1df21c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f238a3a196c948f5ee22928bfb935d13 = $(`&lt;div id=&quot;html_f238a3a196c948f5ee22928bfb935d13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_88a069e781bc2f07428ea88f4e1df21c.setContent(html_f238a3a196c948f5ee22928bfb935d13);
#
#
#
#         marker_3317aaaba2fd131c5b661a3e2aae5844.bindPopup(popup_88a069e781bc2f07428ea88f4e1df21c)
#         ;
#
#
#
#
#             var marker_5cdc7a514de5830eac1acab8aefd4e0c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6e17d665a3c9c625693847ce7e8f05a9);
#
#
#         var popup_07e0ea75df0819bc7330ca0d60cf318d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a463af76ccca600476faf14ad3353d46 = $(`&lt;div id=&quot;html_a463af76ccca600476faf14ad3353d46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_07e0ea75df0819bc7330ca0d60cf318d.setContent(html_a463af76ccca600476faf14ad3353d46);
#
#
#
#         marker_5cdc7a514de5830eac1acab8aefd4e0c.bindPopup(popup_07e0ea75df0819bc7330ca0d60cf318d)
#         ;
#
#
#
#
#             var marker_5b1d394ce1e020e2b5cd2ce5d381329c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6e17d665a3c9c625693847ce7e8f05a9);
#
#
#         var popup_0e83b2f6ed6fda64f4f811494806891f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9e4cf4094203f9a5ff14628a8c8fcf9 = $(`&lt;div id=&quot;html_e9e4cf4094203f9a5ff14628a8c8fcf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0e83b2f6ed6fda64f4f811494806891f.setContent(html_e9e4cf4094203f9a5ff14628a8c8fcf9);
#
#
#
#         marker_5b1d394ce1e020e2b5cd2ce5d381329c.bindPopup(popup_0e83b2f6ed6fda64f4f811494806891f)
#         ;
#
#
#
#
#             var marker_d73edb0213f6f348a4abd5f78a328219 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6e17d665a3c9c625693847ce7e8f05a9);
#
#
#         var popup_c349b18beabeb381db90b4c594d510d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ed4cc5de3e16b658cff9188241f68e5 = $(`&lt;div id=&quot;html_9ed4cc5de3e16b658cff9188241f68e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c349b18beabeb381db90b4c594d510d6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccbce04f3e1e7460ddf3c5ac05ec161f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccbce04f3e1e7460ddf3c5ac05ec161f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccbce04f3e1e7460ddf3c5ac05ec161f = L.map(
#                 &quot;map_ccbce04f3e1e7460ddf3c5ac05ec161f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a162bcc2183c5390cb85107c3e5c531e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a162bcc2183c5390cb85107c3e5c531e.addTo(map_ccbce04f3e1e7460ddf3c5ac05ec161f);
#
#
#             var feature_group_c1fe2c1798e731d2b2ffdbd881080380 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2ce4955fed50b4d6ee9438016fc34572 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c1fe2c1798e731d2b2ffdbd881080380);
#
#
#         var popup_41d80053b944e1069f0b91b216bba171 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71ea219a87b9183ebc52aecdca84021b = $(`&lt;div id=&quot;html_71ea219a87b9183ebc52aecdca84021b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_41d80053b944e1069f0b91b216bba171.setContent(html_71ea219a87b9183ebc52aecdca84021b);
#
#
#
#         marker_2ce4955fed50b4d6ee9438016fc34572.bindPopup(popup_41d80053b944e1069f0b91b216bba171)
#         ;
#
#
#
#
#             var marker_5d541ce99443557c9e1875b93aa0e076 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c1fe2c1798e731d2b2ffdbd881080380);
#
#
#         var popup_0ac01585e2862b3cb478d2ddb6d4d577 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a04000b50fca46a46941845f833ae62b = $(`&lt;div id=&quot;html_a04000b50fca46a46941845f833ae62b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0ac01585e2862b3cb478d2ddb6d4d577.setContent(html_a04000b50fca46a46941845f833ae62b);
#
#
#
#         marker_5d541ce99443557c9e1875b93aa0e076.bindPopup(popup_0ac01585e2862b3cb478d2ddb6d4d577)
#         ;
#
#
#
#
#             var marker_a6bfac33813c3c64bd7167701960d850 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c1fe2c1798e731d2b2ffdbd881080380);
#
#
#         var popup_533ed67a70edb476331c800737d12624 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f056ec8c287368d40a4b7c02b204623 = $(`&lt;div id=&quot;html_3f056ec8c287368d40a4b7c02b204623&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_533ed67a70edb476331c800737d12624.setContent(html_3f056ec8c287368d40a4b7c02b204623);
#
#
#
#         marker_a6bfac33813c3c64bd7167701960d850.bindPopup(popup_533ed67a70edb476331c800737d12624)
#         ;
#
#
#
#
#             var marker_acae5a0afd16dc0091341a9376264ddc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c1fe2c1798e731d2b2ffdbd881080380);
#
#
#         var popup_77b6a87ab4c7c6ef26b0bab5c5df9388 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2384856b4893ce9ce7cf25a35818e899 = $(`&lt;div id=&quot;html_2384856b4893ce9ce7cf25a35818e899&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_77b6a87ab4c7c6ef26b0bab5c5df9388.setContent(html_2384856b4893ce9ce7cf25a35818e899);
#
#
#
#         marker_acae5a0afd16dc0091341a9376264ddc.bindPopup(popup_77b6a87ab4c7c6ef26b0bab5c5df9388)
#         ;
#
#
#
#
#             var marker_ae56e848b0582f08a30169c68fd3d2f0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c1fe2c1798e731d2b2ffdbd881080380);
#
#
#         var popup_1d8cc7731522f0a409812f584b7b59f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77caec9e5d3417bc7a929fb84fed2b61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77caec9e5d3417bc7a929fb84fed2b61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77caec9e5d3417bc7a929fb84fed2b61 = L.map(
#                 &quot;map_77caec9e5d3417bc7a929fb84fed2b61&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07690900f57c34576be8d92bb2d27391 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07690900f57c34576be8d92bb2d27391.addTo(map_77caec9e5d3417bc7a929fb84fed2b61);
#
#
#             var feature_group_d5f2e7d48120d488102c447e4144b7b7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d5f2e7d48120d488102c447e4144b7b7.addTo(map_77caec9e5d3417bc7a929fb84fed2b61);
#
#
#             var feature_group_sub_group_cbc05297f0689e5a6872a6321a7027c8 = L.featureGroup.subGroup(
#                 feature_group_d5f2e7d48120d488102c447e4144b7b7
#             );
#
#
#             var marker_44c819f0b6e590cd63aa10c3d18ac48b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbc05297f0689e5a6872a6321a7027c8);
#
#
#         var popup_fb83d7ffc39b2a1151f806b89554934a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85edbe3bb6db300f648231dc1f7319a5 = $(`&lt;div id=&quot;html_85edbe3bb6db300f648231dc1f7319a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fb83d7ffc39b2a1151f806b89554934a.setContent(html_85edbe3bb6db300f648231dc1f7319a5);
#
#
#
#         marker_44c819f0b6e590cd63aa10c3d18ac48b.bindPopup(popup_fb83d7ffc39b2a1151f806b89554934a)
#         ;
#
#
#
#
#             var marker_1819dff72f48bc27d382866a2a0df0c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbc05297f0689e5a6872a6321a7027c8);
#
#
#         var popup_0e6df08d71e5ecd60069bfc74ce5e677 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d88cd583f2704baa0c0852667428c7e0 = $(`&lt;div id=&quot;html_d88cd583f2704baa0c0852667428c7e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0e6df08d71e5ecd60069bfc74ce5e677.setContent(html_d88cd583f2704baa0c0852667428c7e0);
#
#
#
#         marker_1819dff72f48bc27d382866a2a0df0c9.bindPopup(popup_0e6df08d71e5ecd60069bfc74ce5e677)
#         ;
#
#
#
#
#             var marker_541ecbc223f1f05c8526fda7fafbd1aa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbc05297f0689e5a6872a6321a7027c8);
#
#
#         var popup_bdede59eba2b532559c2f0cfd50f3fa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acc80e73873737e2f682624874510866 = $(`&lt;div id=&quot;html_acc80e73873737e2f682624874510866&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bdede59eba2b532559c2f0cfd50f3fa9.setContent(html_acc80e73873737e2f682624874510866);
#
#
#
#         marker_541ecbc223f1f05c8526fda7fafbd1aa.bindPopup(popup_bdede59eba2b532559c2f0cfd50f3fa9)
#         ;
#
#
#
#
#             var marker_6d74c991d4617d4d202c6b649a2a2e14 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cbc05297f0689e5a6872a6321a7027c8);
#
#
#         var popup_ca525721d76e93c7e25e46134cb02501 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94199270830f91e5090fe77e38178a15 = $(`&lt;div id=&quot;html_94199270830f91e5090fe77e38178a15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ca525721d76e93c7e25e46134cb02501.setContent(html_94199270830f91e5090fe77e38178a15);
#
#
#
#         marker_
