# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_970cf12d6b6f1862ddb2648dbc25206d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_970cf12d6b6f1862ddb2648dbc25206d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_970cf12d6b6f1862ddb2648dbc25206d = L.map(
#                 &quot;map_970cf12d6b6f1862ddb2648dbc25206d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2269f53254a28b7e5e7113a0b7990e69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2269f53254a28b7e5e7113a0b7990e69.addTo(map_970cf12d6b6f1862ddb2648dbc25206d);
#
#
#             var marker_bd82ba7b1038f49ed1ea36899dd80872 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_970cf12d6b6f1862ddb2648dbc25206d);
#
#
#         var popup_37c864cc1d7029d359bd61e606649254 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb78db76d6fec1b8e55b7eea082ff86e = $(`&lt;div id=&quot;html_eb78db76d6fec1b8e55b7eea082ff86e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_37c864cc1d7029d359bd61e606649254.setContent(html_eb78db76d6fec1b8e55b7eea082ff86e);
#
#
#
#         marker_bd82ba7b1038f49ed1ea36899dd80872.bindPopup(popup_37c864cc1d7029d359bd61e606649254)
#         ;
#
#
#
#
#             var marker_bd467978e325ec177b29d42958853fd6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_970cf12d6b6f1862ddb2648dbc25206d);
#
#
#         var popup_ff8e95983b81dbb9a73c6c2fb6155206 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b3cdb4a9b07f40fc00de041e00cae70 = $(`&lt;div id=&quot;html_0b3cdb4a9b07f40fc00de041e00cae70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ff8e95983b81dbb9a73c6c2fb6155206.setContent(html_0b3cdb4a9b07f40fc00de041e00cae70);
#
#
#
#         marker_bd467978e325ec177b29d42958853fd6.bindPopup(popup_ff8e95983b81dbb9a73c6c2fb6155206)
#         ;
#
#
#
#
#             var marker_855b5b0294096779fa2433399c9b4f1d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_970cf12d6b6f1862ddb2648dbc25206d);
#
#
#         var popup_25221564894401e27a57788be7703d98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_524a6b5c505a67d3c2fd2d927ca2c9b7 = $(`&lt;div id=&quot;html_524a6b5c505a67d3c2fd2d927ca2c9b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_25221564894401e27a57788be7703d98.setContent(html_524a6b5c505a67d3c2fd2d927ca2c9b7);
#
#
#
#         marker_855b5b0294096779fa2433399c9b4f1d.bindPopup(popup_25221564894401e27a57788be7703d98)
#         ;
#
#
#
#
#             var marker_9be6972f33292235a5d6828384f61e06 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_970cf12d6b6f1862ddb2648dbc25206d);
#
#
#         var popup_add01950f35ff4aa6133de87d4000c5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a9fe7b2c6eca34b467ea9df80cbdde2 = $(`&lt;div id=&quot;html_3a9fe7b2c6eca34b467ea9df80cbdde2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_add01950f35ff4aa6133de87d4000c5a.setContent(html_3a9fe7b2c6eca34b467ea9df80cbdde2);
#
#
#
#         marker_9be6972f33292235a5d6828384f61e06.bindPopup(popup_add01950f35ff4aa6133de87d4000c5a)
#         ;
#
#
#
#
#             var marker_b146ba3c3097d17a3d3ddd0066c1e332 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_970cf12d6b6f1862ddb2648dbc25206d);
#
#
#         var popup_6264bf79e0da48df9e9c8185275ea8a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_417d4fb6562a96177b0efb89db318a23 = $(`&lt;div id=&quot;html_417d4fb6562a96177b0efb89db318a23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6264bf79e0da48df9e9c8185275ea8

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6205c7c3d832c001487b5e66db7bd5a6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6205c7c3d832c001487b5e66db7bd5a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6205c7c3d832c001487b5e66db7bd5a6 = L.map(
#                 &quot;map_6205c7c3d832c001487b5e66db7bd5a6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_355d0f0be10a6511ba659a184d49d0e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_355d0f0be10a6511ba659a184d49d0e7.addTo(map_6205c7c3d832c001487b5e66db7bd5a6);
#
#
#             var feature_group_9bb6b690b50e74560b12697379850d6b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_12ca07cd6e30dd9d4c26c5eb44117035 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9bb6b690b50e74560b12697379850d6b);
#
#
#         var popup_e0c2fc3cef1fbcf4fce34dfb1b8fc143 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dbe648b8f195fbd53ce28ab56ef111c = $(`&lt;div id=&quot;html_0dbe648b8f195fbd53ce28ab56ef111c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e0c2fc3cef1fbcf4fce34dfb1b8fc143.setContent(html_0dbe648b8f195fbd53ce28ab56ef111c);
#
#
#
#         marker_12ca07cd6e30dd9d4c26c5eb44117035.bindPopup(popup_e0c2fc3cef1fbcf4fce34dfb1b8fc143)
#         ;
#
#
#
#
#             var marker_bd5925d173a0939a9506e7fccf69351a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9bb6b690b50e74560b12697379850d6b);
#
#
#         var popup_eff19e6c15db4ceee0a6eeda559eb962 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e30cd7d99bb2c2bb25b76400f6d8cf7e = $(`&lt;div id=&quot;html_e30cd7d99bb2c2bb25b76400f6d8cf7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_eff19e6c15db4ceee0a6eeda559eb962.setContent(html_e30cd7d99bb2c2bb25b76400f6d8cf7e);
#
#
#
#         marker_bd5925d173a0939a9506e7fccf69351a.bindPopup(popup_eff19e6c15db4ceee0a6eeda559eb962)
#         ;
#
#
#
#
#             var marker_2dd34e28b34cb4fbfccf7128cb1dcec3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9bb6b690b50e74560b12697379850d6b);
#
#
#         var popup_47b9166aa56de5b465aca5df494d837e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38749176c008e929d65b9de51b643a3f = $(`&lt;div id=&quot;html_38749176c008e929d65b9de51b643a3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_47b9166aa56de5b465aca5df494d837e.setContent(html_38749176c008e929d65b9de51b643a3f);
#
#
#
#         marker_2dd34e28b34cb4fbfccf7128cb1dcec3.bindPopup(popup_47b9166aa56de5b465aca5df494d837e)
#         ;
#
#
#
#
#             var marker_fd253b72b66435731fd50bc922d9822f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9bb6b690b50e74560b12697379850d6b);
#
#
#         var popup_4fc0547c5936488470beb44881274700 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f9c4feb3063e46d4d2d983a62183c15 = $(`&lt;div id=&quot;html_4f9c4feb3063e46d4d2d983a62183c15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4fc0547c5936488470beb44881274700.setContent(html_4f9c4feb3063e46d4d2d983a62183c15);
#
#
#
#         marker_fd253b72b66435731fd50bc922d9822f.bindPopup(popup_4fc0547c5936488470beb44881274700)
#         ;
#
#
#
#
#             var marker_839eb4014fb56f48b250f2bd552960b2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9bb6b690b50e74560b12697379850d6b);
#
#
#         var popup_eb9839720dc4545dbe178d6e921176b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0d9c7a7942b275bd71291f62134c7cb9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0d9c7a7942b275bd71291f62134c7cb9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0d9c7a7942b275bd71291f62134c7cb9 = L.map(
#                 &quot;map_0d9c7a7942b275bd71291f62134c7cb9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ac1a32e0180cc9afd1bd3b6bbd8ed2f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ac1a32e0180cc9afd1bd3b6bbd8ed2f.addTo(map_0d9c7a7942b275bd71291f62134c7cb9);
#
#
#             var feature_group_93fdc91959a9aa1156119a7bef0ca04f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_93fdc91959a9aa1156119a7bef0ca04f.addTo(map_0d9c7a7942b275bd71291f62134c7cb9);
#
#
#             var feature_group_sub_group_67cec1d5b18b8bf3ca5f6b61a67ca207 = L.featureGroup.subGroup(
#                 feature_group_93fdc91959a9aa1156119a7bef0ca04f
#             );
#
#
#             var marker_654d7061dde2c4409acc5cd1fd27dfd2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_67cec1d5b18b8bf3ca5f6b61a67ca207);
#
#
#         var popup_6d9f45ce28e1edd27c79d02f4a620e3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd33522be8cee754335aa90a3a0fb236 = $(`&lt;div id=&quot;html_dd33522be8cee754335aa90a3a0fb236&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6d9f45ce28e1edd27c79d02f4a620e3f.setContent(html_dd33522be8cee754335aa90a3a0fb236);
#
#
#
#         marker_654d7061dde2c4409acc5cd1fd27dfd2.bindPopup(popup_6d9f45ce28e1edd27c79d02f4a620e3f)
#         ;
#
#
#
#
#             var marker_22451b879a775889b51fa6945b858138 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_67cec1d5b18b8bf3ca5f6b61a67ca207);
#
#
#         var popup_35752e824be8b5226acb419b2d0a276f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0beca40a0d7b463331d82e9588e9ba6 = $(`&lt;div id=&quot;html_d0beca40a0d7b463331d82e9588e9ba6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_35752e824be8b5226acb419b2d0a276f.setContent(html_d0beca40a0d7b463331d82e9588e9ba6);
#
#
#
#         marker_22451b879a775889b51fa6945b858138.bindPopup(popup_35752e824be8b5226acb419b2d0a276f)
#         ;
#
#
#
#
#             var marker_3730f1db962f3bde3f3e3936887f2862 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_67cec1d5b18b8bf3ca5f6b61a67ca207);
#
#
#         var popup_697c200edd30a2b02e3e57f280b43b30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbcd30b87b2fed060f3f7edc713b9fad = $(`&lt;div id=&quot;html_fbcd30b87b2fed060f3f7edc713b9fad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_697c200edd30a2b02e3e57f280b43b30.setContent(html_fbcd30b87b2fed060f3f7edc713b9fad);
#
#
#
#         marker_3730f1db962f3bde3f3e3936887f2862.bindPopup(popup_697c200edd30a2b02e3e57f280b43b30)
#         ;
#
#
#
#
#             var marker_ad1a65a7dfbd5d30e95decf8aa086392 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_67cec1d5b18b8bf3ca5f6b61a67ca207);
#
#
#         var popup_1e5a41a1a63e689db16e978dd2c78d65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eaadf01f7743e1ad63a18e2c89570e5a = $(`&lt;div id=&quot;html_eaadf01f7743e1ad63a18e2c89570e5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1e5a41a1a63e689db16e978dd2c78d65.setContent(html_eaadf01f7743e1ad63a18e2c89570e5a);
#
#
#
#         mark
