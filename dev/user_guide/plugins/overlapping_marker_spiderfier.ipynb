# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1687b893d978afc68f9a291643452126 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1687b893d978afc68f9a291643452126&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1687b893d978afc68f9a291643452126 = L.map(
#                 &quot;map_1687b893d978afc68f9a291643452126&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d36feaa1689dbfb660887067de720429 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d36feaa1689dbfb660887067de720429.addTo(map_1687b893d978afc68f9a291643452126);
#
#
#             var marker_15f4358ae5b66b3004f5255725841e13 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1687b893d978afc68f9a291643452126);
#
#
#         var popup_d5e893f5d27482969389c176e53515e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ad50b9e433973ffca9e3a4a97e71ac3 = $(`&lt;div id=&quot;html_1ad50b9e433973ffca9e3a4a97e71ac3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d5e893f5d27482969389c176e53515e1.setContent(html_1ad50b9e433973ffca9e3a4a97e71ac3);
#
#
#
#         marker_15f4358ae5b66b3004f5255725841e13.bindPopup(popup_d5e893f5d27482969389c176e53515e1)
#         ;
#
#
#
#
#             var marker_0889fd022a44ca88176cb81612580227 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1687b893d978afc68f9a291643452126);
#
#
#         var popup_956be1d7945c776812708c7086c29df8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_615af057af53fc42d355f4da7dad38f8 = $(`&lt;div id=&quot;html_615af057af53fc42d355f4da7dad38f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_956be1d7945c776812708c7086c29df8.setContent(html_615af057af53fc42d355f4da7dad38f8);
#
#
#
#         marker_0889fd022a44ca88176cb81612580227.bindPopup(popup_956be1d7945c776812708c7086c29df8)
#         ;
#
#
#
#
#             var marker_056cb556ad2e25426140ede3dba8da88 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1687b893d978afc68f9a291643452126);
#
#
#         var popup_b22847beb0829ec179b8d5f7525a2110 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10acaf4171a91a47c8a42a1fe050a978 = $(`&lt;div id=&quot;html_10acaf4171a91a47c8a42a1fe050a978&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b22847beb0829ec179b8d5f7525a2110.setContent(html_10acaf4171a91a47c8a42a1fe050a978);
#
#
#
#         marker_056cb556ad2e25426140ede3dba8da88.bindPopup(popup_b22847beb0829ec179b8d5f7525a2110)
#         ;
#
#
#
#
#             var marker_aeb789af99fbc58b02f7338c6dda1031 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1687b893d978afc68f9a291643452126);
#
#
#         var popup_4316ed2ae01d6f4ab09b8c2d0afe39cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_865279f8d45ab5bc1c91c40693e14e8f = $(`&lt;div id=&quot;html_865279f8d45ab5bc1c91c40693e14e8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4316ed2ae01d6f4ab09b8c2d0afe39cb.setContent(html_865279f8d45ab5bc1c91c40693e14e8f);
#
#
#
#         marker_aeb789af99fbc58b02f7338c6dda1031.bindPopup(popup_4316ed2ae01d6f4ab09b8c2d0afe39cb)
#         ;
#
#
#
#
#             var marker_96e929197b4ef0d280d388ceb114c211 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1687b893d978afc68f9a291643452126);
#
#
#         var popup_f9288b03213c5d8363a6131068c8957b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_415053ecabac6c47b26de612d421a1a7 = $(`&lt;div id=&quot;html_415053ecabac6c47b26de612d421a1a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f9288b03213c5d8363a6131068c8957b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db9067c1480dc1c9bc5b087063158b3c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db9067c1480dc1c9bc5b087063158b3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db9067c1480dc1c9bc5b087063158b3c = L.map(
#                 &quot;map_db9067c1480dc1c9bc5b087063158b3c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a0e451263763cb4dc59b75dee747aee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a0e451263763cb4dc59b75dee747aee.addTo(map_db9067c1480dc1c9bc5b087063158b3c);
#
#
#             var feature_group_1e8e97b5d5f15fa613608bf348157716 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f823b8e8b1da898a5bbc535100d71abf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1e8e97b5d5f15fa613608bf348157716);
#
#
#         var popup_1ce5742bf37ac0e871a130325ebe5256 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02866bfa22a27f0bd34bfc9637f451fd = $(`&lt;div id=&quot;html_02866bfa22a27f0bd34bfc9637f451fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1ce5742bf37ac0e871a130325ebe5256.setContent(html_02866bfa22a27f0bd34bfc9637f451fd);
#
#
#
#         marker_f823b8e8b1da898a5bbc535100d71abf.bindPopup(popup_1ce5742bf37ac0e871a130325ebe5256)
#         ;
#
#
#
#
#             var marker_4e71badabbf1b2fbe0c3d989dfe31c89 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1e8e97b5d5f15fa613608bf348157716);
#
#
#         var popup_e94423b22a8471e8daeebac1c41f0eed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0089f178756a8bacb9e26da58c398e18 = $(`&lt;div id=&quot;html_0089f178756a8bacb9e26da58c398e18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e94423b22a8471e8daeebac1c41f0eed.setContent(html_0089f178756a8bacb9e26da58c398e18);
#
#
#
#         marker_4e71badabbf1b2fbe0c3d989dfe31c89.bindPopup(popup_e94423b22a8471e8daeebac1c41f0eed)
#         ;
#
#
#
#
#             var marker_12c0fbf6e0561fef6c761e2b9eb5c154 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1e8e97b5d5f15fa613608bf348157716);
#
#
#         var popup_bdf3e6bfb0a56a324cd88ba63a4e426a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fda72e2a9f6e8ec3f98f8cb21346ad75 = $(`&lt;div id=&quot;html_fda72e2a9f6e8ec3f98f8cb21346ad75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bdf3e6bfb0a56a324cd88ba63a4e426a.setContent(html_fda72e2a9f6e8ec3f98f8cb21346ad75);
#
#
#
#         marker_12c0fbf6e0561fef6c761e2b9eb5c154.bindPopup(popup_bdf3e6bfb0a56a324cd88ba63a4e426a)
#         ;
#
#
#
#
#             var marker_122adce83574ff8b1389131ec9af67d0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1e8e97b5d5f15fa613608bf348157716);
#
#
#         var popup_ca035723e10685f40bd88913a999ad77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_104446c275d7cc45f5fd43be71182738 = $(`&lt;div id=&quot;html_104446c275d7cc45f5fd43be71182738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ca035723e10685f40bd88913a999ad77.setContent(html_104446c275d7cc45f5fd43be71182738);
#
#
#
#         marker_122adce83574ff8b1389131ec9af67d0.bindPopup(popup_ca035723e10685f40bd88913a999ad77)
#         ;
#
#
#
#
#             var marker_67f9192d1e1273db6c12dc285abb0d1f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1e8e97b5d5f15fa613608bf348157716);
#
#
#         var popup_1d4e0842b24d4a9881e806dc8bd2a564 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06a624a5e4fd21171f6ac268faf7876e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06a624a5e4fd21171f6ac268faf7876e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06a624a5e4fd21171f6ac268faf7876e = L.map(
#                 &quot;map_06a624a5e4fd21171f6ac268faf7876e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49138eaf22cc9eb9005de0f6e6b00724 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49138eaf22cc9eb9005de0f6e6b00724.addTo(map_06a624a5e4fd21171f6ac268faf7876e);
#
#
#             var feature_group_92060ee4ed27fcea9a8261a02f1b85a9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_92060ee4ed27fcea9a8261a02f1b85a9.addTo(map_06a624a5e4fd21171f6ac268faf7876e);
#
#
#             var feature_group_sub_group_0209d26d738b839b63293247dbe02ce4 = L.featureGroup.subGroup(
#                 feature_group_92060ee4ed27fcea9a8261a02f1b85a9
#             );
#
#
#             var marker_7731f6b216d502f6d5acac3df03eb4f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0209d26d738b839b63293247dbe02ce4);
#
#
#         var popup_6559642169793b387f3886f1acd127f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d2f15fb47d30fe8df2048caada55bf8 = $(`&lt;div id=&quot;html_8d2f15fb47d30fe8df2048caada55bf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6559642169793b387f3886f1acd127f0.setContent(html_8d2f15fb47d30fe8df2048caada55bf8);
#
#
#
#         marker_7731f6b216d502f6d5acac3df03eb4f4.bindPopup(popup_6559642169793b387f3886f1acd127f0)
#         ;
#
#
#
#
#             var marker_e94d6fd3c675c5e3831033efe4d724ad = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0209d26d738b839b63293247dbe02ce4);
#
#
#         var popup_5d303119ef1b032f5d0b2f671649f1f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f18b7a9c5726b989377b864714dc145e = $(`&lt;div id=&quot;html_f18b7a9c5726b989377b864714dc145e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5d303119ef1b032f5d0b2f671649f1f4.setContent(html_f18b7a9c5726b989377b864714dc145e);
#
#
#
#         marker_e94d6fd3c675c5e3831033efe4d724ad.bindPopup(popup_5d303119ef1b032f5d0b2f671649f1f4)
#         ;
#
#
#
#
#             var marker_5fefd91ef91209d08b861594562b3f9e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0209d26d738b839b63293247dbe02ce4);
#
#
#         var popup_4c68c6b2e9d390396634c669a6eaf1d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5cc3232f2cd8b9affd47a518eb805d2 = $(`&lt;div id=&quot;html_f5cc3232f2cd8b9affd47a518eb805d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4c68c6b2e9d390396634c669a6eaf1d4.setContent(html_f5cc3232f2cd8b9affd47a518eb805d2);
#
#
#
#         marker_5fefd91ef91209d08b861594562b3f9e.bindPopup(popup_4c68c6b2e9d390396634c669a6eaf1d4)
#         ;
#
#
#
#
#             var marker_f6b8bcb800a21f3576c80e2af1900800 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0209d26d738b839b63293247dbe02ce4);
#
#
#         var popup_932a8f1622468ddc9bffcfa56d39b6d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_778523e2a9b881921b0484ab43eab805 = $(`&lt;div id=&quot;html_778523e2a9b881921b0484ab43eab805&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_932a8f1622468ddc9bffcfa56d39b6d4.setContent(html_778523e2a9b881921b0484ab43eab805);
#
#
#
#         marker_
