# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad3c5d7a39953058ab89ef8ae3895c1b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad3c5d7a39953058ab89ef8ae3895c1b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad3c5d7a39953058ab89ef8ae3895c1b = L.map(
#                 &quot;map_ad3c5d7a39953058ab89ef8ae3895c1b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1045e7ec37f6e9903d94bdbc0d63f5e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1045e7ec37f6e9903d94bdbc0d63f5e5.addTo(map_ad3c5d7a39953058ab89ef8ae3895c1b);
#
#
#             var marker_bd48d277f036ef7b8d2c880aff7ca590 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ad3c5d7a39953058ab89ef8ae3895c1b);
#
#
#         var popup_44d6049952b5931b3a7091e90434c993 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bffe4d5d226ab182a691f31cf747d81 = $(`&lt;div id=&quot;html_0bffe4d5d226ab182a691f31cf747d81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_44d6049952b5931b3a7091e90434c993.setContent(html_0bffe4d5d226ab182a691f31cf747d81);
#
#
#
#         marker_bd48d277f036ef7b8d2c880aff7ca590.bindPopup(popup_44d6049952b5931b3a7091e90434c993)
#         ;
#
#
#
#
#             var marker_2d1eeb9c56edcf8002d953c907c8854d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ad3c5d7a39953058ab89ef8ae3895c1b);
#
#
#         var popup_b776e32db446e3acd684184ad25ab39e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2fdabba10739c3e1379a728bb1aec72 = $(`&lt;div id=&quot;html_c2fdabba10739c3e1379a728bb1aec72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b776e32db446e3acd684184ad25ab39e.setContent(html_c2fdabba10739c3e1379a728bb1aec72);
#
#
#
#         marker_2d1eeb9c56edcf8002d953c907c8854d.bindPopup(popup_b776e32db446e3acd684184ad25ab39e)
#         ;
#
#
#
#
#             var marker_04b66eabdb9d2cfa8b5509a2ae083cbf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ad3c5d7a39953058ab89ef8ae3895c1b);
#
#
#         var popup_6fa10033b091559be7bf926474d8de95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd03b798194cb2051f3a4bf5151bb0de = $(`&lt;div id=&quot;html_cd03b798194cb2051f3a4bf5151bb0de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6fa10033b091559be7bf926474d8de95.setContent(html_cd03b798194cb2051f3a4bf5151bb0de);
#
#
#
#         marker_04b66eabdb9d2cfa8b5509a2ae083cbf.bindPopup(popup_6fa10033b091559be7bf926474d8de95)
#         ;
#
#
#
#
#             var marker_cb8432761b51dc05209d51b078fc3d84 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ad3c5d7a39953058ab89ef8ae3895c1b);
#
#
#         var popup_6997a42d9ced0eaa30a1a04e7621117a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9eaf823359908faa11607522fbbf058 = $(`&lt;div id=&quot;html_f9eaf823359908faa11607522fbbf058&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6997a42d9ced0eaa30a1a04e7621117a.setContent(html_f9eaf823359908faa11607522fbbf058);
#
#
#
#         marker_cb8432761b51dc05209d51b078fc3d84.bindPopup(popup_6997a42d9ced0eaa30a1a04e7621117a)
#         ;
#
#
#
#
#             var marker_2512f28b91d31368290f28d6faaec435 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ad3c5d7a39953058ab89ef8ae3895c1b);
#
#
#         var popup_5fecc23272185b97ab4e331a432dc044 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e556b7eed60fa86622e9f542cb6334a0 = $(`&lt;div id=&quot;html_e556b7eed60fa86622e9f542cb6334a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5fecc23272185b97ab4e331a432dc0

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3daa9e9535039fe8a9ea26c7a6e1f20a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3daa9e9535039fe8a9ea26c7a6e1f20a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3daa9e9535039fe8a9ea26c7a6e1f20a = L.map(
#                 &quot;map_3daa9e9535039fe8a9ea26c7a6e1f20a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_929f834db0ffc125c28959e928058ea7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_929f834db0ffc125c28959e928058ea7.addTo(map_3daa9e9535039fe8a9ea26c7a6e1f20a);
#
#
#             var feature_group_af856290231d6ad27a544bab9e4cb78f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ff0e111b9d7d9be6da609eeac4a889b1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_af856290231d6ad27a544bab9e4cb78f);
#
#
#         var popup_bb27ce281d5f6575c9515abdd75d511e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51c0d51797547e49e318e27798b33104 = $(`&lt;div id=&quot;html_51c0d51797547e49e318e27798b33104&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bb27ce281d5f6575c9515abdd75d511e.setContent(html_51c0d51797547e49e318e27798b33104);
#
#
#
#         marker_ff0e111b9d7d9be6da609eeac4a889b1.bindPopup(popup_bb27ce281d5f6575c9515abdd75d511e)
#         ;
#
#
#
#
#             var marker_1de9f3ecd03385ce7d080d650122fe49 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_af856290231d6ad27a544bab9e4cb78f);
#
#
#         var popup_a3ae981cf02a9dcfb6ed4e514e9e5a4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0edd754647294126c826e9c30e48b1ee = $(`&lt;div id=&quot;html_0edd754647294126c826e9c30e48b1ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a3ae981cf02a9dcfb6ed4e514e9e5a4f.setContent(html_0edd754647294126c826e9c30e48b1ee);
#
#
#
#         marker_1de9f3ecd03385ce7d080d650122fe49.bindPopup(popup_a3ae981cf02a9dcfb6ed4e514e9e5a4f)
#         ;
#
#
#
#
#             var marker_74d17a51c15135ce5e5eee885da2d8ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_af856290231d6ad27a544bab9e4cb78f);
#
#
#         var popup_fbc9dbdec6dc55d17b7d2b64e8ffc548 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a9edc5b749898731f4598cf5bcf6332 = $(`&lt;div id=&quot;html_9a9edc5b749898731f4598cf5bcf6332&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fbc9dbdec6dc55d17b7d2b64e8ffc548.setContent(html_9a9edc5b749898731f4598cf5bcf6332);
#
#
#
#         marker_74d17a51c15135ce5e5eee885da2d8ec.bindPopup(popup_fbc9dbdec6dc55d17b7d2b64e8ffc548)
#         ;
#
#
#
#
#             var marker_940b6b66523f00d3e4cf694b14bd5d2e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_af856290231d6ad27a544bab9e4cb78f);
#
#
#         var popup_637e722c5a34457ea6e5617ad217e465 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9797b9051e4895b62c391a432b2d5034 = $(`&lt;div id=&quot;html_9797b9051e4895b62c391a432b2d5034&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_637e722c5a34457ea6e5617ad217e465.setContent(html_9797b9051e4895b62c391a432b2d5034);
#
#
#
#         marker_940b6b66523f00d3e4cf694b14bd5d2e.bindPopup(popup_637e722c5a34457ea6e5617ad217e465)
#         ;
#
#
#
#
#             var marker_e0170c00673599072898723a27516e43 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_af856290231d6ad27a544bab9e4cb78f);
#
#
#         var popup_4dabe81d2955c1fbf5c3d32fa81b9cbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ea975ef4b4d972f842a9be2c64a642a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ea975ef4b4d972f842a9be2c64a642a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ea975ef4b4d972f842a9be2c64a642a = L.map(
#                 &quot;map_0ea975ef4b4d972f842a9be2c64a642a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cae8404a280164e5a2d0413f4ca889cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cae8404a280164e5a2d0413f4ca889cd.addTo(map_0ea975ef4b4d972f842a9be2c64a642a);
#
#
#             var feature_group_49510eb5246e3e9201c9b2c29fe0a1b3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_49510eb5246e3e9201c9b2c29fe0a1b3.addTo(map_0ea975ef4b4d972f842a9be2c64a642a);
#
#
#             var feature_group_sub_group_5d010b930a3f3094ba5904306276ddb9 = L.featureGroup.subGroup(
#                 feature_group_49510eb5246e3e9201c9b2c29fe0a1b3
#             );
#
#
#             var marker_4b7c49f126ff7b7f49cb2b27f283e902 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d010b930a3f3094ba5904306276ddb9);
#
#
#         var popup_187bc4a9e3c0685bec89d64ba43a9440 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c21d85f1efc5f07ea0e277837c269944 = $(`&lt;div id=&quot;html_c21d85f1efc5f07ea0e277837c269944&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_187bc4a9e3c0685bec89d64ba43a9440.setContent(html_c21d85f1efc5f07ea0e277837c269944);
#
#
#
#         marker_4b7c49f126ff7b7f49cb2b27f283e902.bindPopup(popup_187bc4a9e3c0685bec89d64ba43a9440)
#         ;
#
#
#
#
#             var marker_884256ab3bf10858efbb20fb00ee85bc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d010b930a3f3094ba5904306276ddb9);
#
#
#         var popup_c4fd2142cbf34110c2ab0f2f1c75f8b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0e36f87ac7aa4615bb42950eb45a299 = $(`&lt;div id=&quot;html_d0e36f87ac7aa4615bb42950eb45a299&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c4fd2142cbf34110c2ab0f2f1c75f8b0.setContent(html_d0e36f87ac7aa4615bb42950eb45a299);
#
#
#
#         marker_884256ab3bf10858efbb20fb00ee85bc.bindPopup(popup_c4fd2142cbf34110c2ab0f2f1c75f8b0)
#         ;
#
#
#
#
#             var marker_b07677290532e9e17f5eff352b4ce0c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d010b930a3f3094ba5904306276ddb9);
#
#
#         var popup_2f37d1a5c92385da8b7d96f13d371c92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72fdc529937c58da0ac77fc2617cc171 = $(`&lt;div id=&quot;html_72fdc529937c58da0ac77fc2617cc171&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2f37d1a5c92385da8b7d96f13d371c92.setContent(html_72fdc529937c58da0ac77fc2617cc171);
#
#
#
#         marker_b07677290532e9e17f5eff352b4ce0c5.bindPopup(popup_2f37d1a5c92385da8b7d96f13d371c92)
#         ;
#
#
#
#
#             var marker_6741fa28c910359e0972edb536acd1f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d010b930a3f3094ba5904306276ddb9);
#
#
#         var popup_ff7691de0b81cfda10fd3b5921c0d566 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7246c2e92778e5d19051515b68066c6a = $(`&lt;div id=&quot;html_7246c2e92778e5d19051515b68066c6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ff7691de0b81cfda10fd3b5921c0d566.setContent(html_7246c2e92778e5d19051515b68066c6a);
#
#
#
#         mark
