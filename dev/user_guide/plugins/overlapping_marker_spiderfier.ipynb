# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d30078051ad202ff3f3c84e56900f5dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d30078051ad202ff3f3c84e56900f5dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d30078051ad202ff3f3c84e56900f5dc = L.map(
#                 &quot;map_d30078051ad202ff3f3c84e56900f5dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34da41f901ef1811f08e72438aefea45 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_34da41f901ef1811f08e72438aefea45.addTo(map_d30078051ad202ff3f3c84e56900f5dc);
#
#
#             var marker_3dbed2b22ea2030a46f9bc1888ee1c5d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d30078051ad202ff3f3c84e56900f5dc);
#
#
#         var popup_f22b8c29cd8f3acd26f70bf51b026dd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85c5a7bec347644503b40b8a719fedba = $(`&lt;div id=&quot;html_85c5a7bec347644503b40b8a719fedba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f22b8c29cd8f3acd26f70bf51b026dd0.setContent(html_85c5a7bec347644503b40b8a719fedba);
#
#
#
#         marker_3dbed2b22ea2030a46f9bc1888ee1c5d.bindPopup(popup_f22b8c29cd8f3acd26f70bf51b026dd0)
#         ;
#
#
#
#
#             var marker_18b25be797f5ac4e345160a03e93591b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d30078051ad202ff3f3c84e56900f5dc);
#
#
#         var popup_ffab1f29145cfae4fb3c6f01dfffe14b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0790181085ad309b66ed24c802b74e7c = $(`&lt;div id=&quot;html_0790181085ad309b66ed24c802b74e7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ffab1f29145cfae4fb3c6f01dfffe14b.setContent(html_0790181085ad309b66ed24c802b74e7c);
#
#
#
#         marker_18b25be797f5ac4e345160a03e93591b.bindPopup(popup_ffab1f29145cfae4fb3c6f01dfffe14b)
#         ;
#
#
#
#
#             var marker_e0c34848b70f1e1eceb8f679c6af1385 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d30078051ad202ff3f3c84e56900f5dc);
#
#
#         var popup_2314aa3c60b4f1ad8bc348df39c007ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e27b9b99a624df4b2e822cf6faf00c28 = $(`&lt;div id=&quot;html_e27b9b99a624df4b2e822cf6faf00c28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2314aa3c60b4f1ad8bc348df39c007ae.setContent(html_e27b9b99a624df4b2e822cf6faf00c28);
#
#
#
#         marker_e0c34848b70f1e1eceb8f679c6af1385.bindPopup(popup_2314aa3c60b4f1ad8bc348df39c007ae)
#         ;
#
#
#
#
#             var marker_30c3daf6d3a23f899510a66e72bb681a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d30078051ad202ff3f3c84e56900f5dc);
#
#
#         var popup_09baa48fe4db728f51722c0e5fa0b659 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_477a40c1368f026390f40413915c60cf = $(`&lt;div id=&quot;html_477a40c1368f026390f40413915c60cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_09baa48fe4db728f51722c0e5fa0b659.setContent(html_477a40c1368f026390f40413915c60cf);
#
#
#
#         marker_30c3daf6d3a23f899510a66e72bb681a.bindPopup(popup_09baa48fe4db728f51722c0e5fa0b659)
#         ;
#
#
#
#
#             var marker_5e5118a47867f8d792c7767746a6009c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d30078051ad202ff3f3c84e56900f5dc);
#
#
#         var popup_f5a5c573089fcf040a83fa8e22a8cd4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60bc2fc5a7a4c7b5135c90668d4c7e82 = $(`&lt;div id=&quot;html_60bc2fc5a7a4c7b5135c90668d4c7e82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f5a5c573089fcf040a83fa8e22a8cd4e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a3a6648243adaa0085b20da5bc32a42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a3a6648243adaa0085b20da5bc32a42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a3a6648243adaa0085b20da5bc32a42 = L.map(
#                 &quot;map_9a3a6648243adaa0085b20da5bc32a42&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8bd857c3fb5f538eb32638ca3cb7bd9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d8bd857c3fb5f538eb32638ca3cb7bd9.addTo(map_9a3a6648243adaa0085b20da5bc32a42);
#
#
#             var feature_group_1dc9d4b2f83dd065dabad619a13447b7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_721e34051fedf3f944b06856a97f0e2a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1dc9d4b2f83dd065dabad619a13447b7);
#
#
#         var popup_0bc369da643b6b961383dd9ac51477e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0366c409b452142d530a7563eec1b13b = $(`&lt;div id=&quot;html_0366c409b452142d530a7563eec1b13b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0bc369da643b6b961383dd9ac51477e7.setContent(html_0366c409b452142d530a7563eec1b13b);
#
#
#
#         marker_721e34051fedf3f944b06856a97f0e2a.bindPopup(popup_0bc369da643b6b961383dd9ac51477e7)
#         ;
#
#
#
#
#             var marker_289c31d0bc3cc36ff3fc00d2b62c150b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1dc9d4b2f83dd065dabad619a13447b7);
#
#
#         var popup_9ef063ac2e919e760de13262201b068c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfbb8c894b0031641af864432218d026 = $(`&lt;div id=&quot;html_cfbb8c894b0031641af864432218d026&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9ef063ac2e919e760de13262201b068c.setContent(html_cfbb8c894b0031641af864432218d026);
#
#
#
#         marker_289c31d0bc3cc36ff3fc00d2b62c150b.bindPopup(popup_9ef063ac2e919e760de13262201b068c)
#         ;
#
#
#
#
#             var marker_a200101b00feacaa26e13eda9b1618a7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1dc9d4b2f83dd065dabad619a13447b7);
#
#
#         var popup_3e78ff32b1f57ba5ea6ad422b871889c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ada3789f9fb712e32060d7e1de6fdab = $(`&lt;div id=&quot;html_3ada3789f9fb712e32060d7e1de6fdab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3e78ff32b1f57ba5ea6ad422b871889c.setContent(html_3ada3789f9fb712e32060d7e1de6fdab);
#
#
#
#         marker_a200101b00feacaa26e13eda9b1618a7.bindPopup(popup_3e78ff32b1f57ba5ea6ad422b871889c)
#         ;
#
#
#
#
#             var marker_168c70624790b04a2cad1fcb0ec86246 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1dc9d4b2f83dd065dabad619a13447b7);
#
#
#         var popup_4a15c6416acfebce0c4f499e09e33ea5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d85ff586640435c877bfdf5e296a1910 = $(`&lt;div id=&quot;html_d85ff586640435c877bfdf5e296a1910&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4a15c6416acfebce0c4f499e09e33ea5.setContent(html_d85ff586640435c877bfdf5e296a1910);
#
#
#
#         marker_168c70624790b04a2cad1fcb0ec86246.bindPopup(popup_4a15c6416acfebce0c4f499e09e33ea5)
#         ;
#
#
#
#
#             var marker_edcca1cac9735dabf60c3b9823bb6e64 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1dc9d4b2f83dd065dabad619a13447b7);
#
#
#         var popup_b2971a0803586c1a5c51a01fac99d7f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_376844bb18f8c898dcb5154735ee8553 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_376844bb18f8c898dcb5154735ee8553&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_376844bb18f8c898dcb5154735ee8553 = L.map(
#                 &quot;map_376844bb18f8c898dcb5154735ee8553&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_876f35ebac1746fb1b885e4732c9cdfd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_876f35ebac1746fb1b885e4732c9cdfd.addTo(map_376844bb18f8c898dcb5154735ee8553);
#
#
#             var feature_group_4fb8221cc7d560ff8a13e66f63f371cd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4fb8221cc7d560ff8a13e66f63f371cd.addTo(map_376844bb18f8c898dcb5154735ee8553);
#
#
#             var feature_group_sub_group_c17692a2771d236954e68ded60583a27 = L.featureGroup.subGroup(
#                 feature_group_4fb8221cc7d560ff8a13e66f63f371cd
#             );
#
#
#             var marker_677faeb8dac93e51471191b978690760 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c17692a2771d236954e68ded60583a27);
#
#
#         var popup_73a39def620d2321cfd65a8092fcaf77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55fed1e3852d968e932e55f7c41d77a5 = $(`&lt;div id=&quot;html_55fed1e3852d968e932e55f7c41d77a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_73a39def620d2321cfd65a8092fcaf77.setContent(html_55fed1e3852d968e932e55f7c41d77a5);
#
#
#
#         marker_677faeb8dac93e51471191b978690760.bindPopup(popup_73a39def620d2321cfd65a8092fcaf77)
#         ;
#
#
#
#
#             var marker_094383ce7145997477664a1860b14df6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c17692a2771d236954e68ded60583a27);
#
#
#         var popup_241e52ef12ed5b89056dc295799bd0c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0262d8b7621e38f73d07e693bd36efe6 = $(`&lt;div id=&quot;html_0262d8b7621e38f73d07e693bd36efe6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_241e52ef12ed5b89056dc295799bd0c4.setContent(html_0262d8b7621e38f73d07e693bd36efe6);
#
#
#
#         marker_094383ce7145997477664a1860b14df6.bindPopup(popup_241e52ef12ed5b89056dc295799bd0c4)
#         ;
#
#
#
#
#             var marker_cde6e4b20abd29f07e077feae6292a6c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c17692a2771d236954e68ded60583a27);
#
#
#         var popup_8f09ee3da92f095fc70bd0925f1affc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30b517af86142ab4019647ef40abfd31 = $(`&lt;div id=&quot;html_30b517af86142ab4019647ef40abfd31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8f09ee3da92f095fc70bd0925f1affc9.setContent(html_30b517af86142ab4019647ef40abfd31);
#
#
#
#         marker_cde6e4b20abd29f07e077feae6292a6c.bindPopup(popup_8f09ee3da92f095fc70bd0925f1affc9)
#         ;
#
#
#
#
#             var marker_50cafe840bcf3bcb68ee168fc534a7d3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c17692a2771d236954e68ded60583a27);
#
#
#         var popup_3f0e00cfbc796a34d571247046b77f1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df03a692e832c0a5eb11a9f6248a0759 = $(`&lt;div id=&quot;html_df03a692e832c0a5eb11a9f6248a0759&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3f0e00cfbc796a34d571247046b77f1c.setContent(html_df03a692e832c0a5eb11a9f6248a0759);
#
#
#
#         marker_
