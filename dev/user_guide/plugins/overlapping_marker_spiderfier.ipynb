# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b34aa912e542d640af11f18ca4f4eaae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b34aa912e542d640af11f18ca4f4eaae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b34aa912e542d640af11f18ca4f4eaae = L.map(
#                 &quot;map_b34aa912e542d640af11f18ca4f4eaae&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a9318b07ad6afae22eef840582692e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a9318b07ad6afae22eef840582692e7.addTo(map_b34aa912e542d640af11f18ca4f4eaae);
#
#
#             var marker_14c6e639976909e2dbba76d52e4aef7d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b34aa912e542d640af11f18ca4f4eaae);
#
#
#         var popup_9b48c05c34afb9510f3fa928d06c1c3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47b8cdf9c35131382a8e2d9aa039369e = $(`&lt;div id=&quot;html_47b8cdf9c35131382a8e2d9aa039369e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9b48c05c34afb9510f3fa928d06c1c3a.setContent(html_47b8cdf9c35131382a8e2d9aa039369e);
#
#
#
#         marker_14c6e639976909e2dbba76d52e4aef7d.bindPopup(popup_9b48c05c34afb9510f3fa928d06c1c3a)
#         ;
#
#
#
#
#             var marker_f3a56bce87c4205989841ec2a15282c2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b34aa912e542d640af11f18ca4f4eaae);
#
#
#         var popup_eacf6f17d61d8a60156cd4aaef43439d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54489ac23fb3aca417658b28a602dec9 = $(`&lt;div id=&quot;html_54489ac23fb3aca417658b28a602dec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_eacf6f17d61d8a60156cd4aaef43439d.setContent(html_54489ac23fb3aca417658b28a602dec9);
#
#
#
#         marker_f3a56bce87c4205989841ec2a15282c2.bindPopup(popup_eacf6f17d61d8a60156cd4aaef43439d)
#         ;
#
#
#
#
#             var marker_86a5b5dc4dea0d7b4964979552270979 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b34aa912e542d640af11f18ca4f4eaae);
#
#
#         var popup_ea70c6b07c7de4aad0f17199e8c7b868 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d67c2809711c95bec96945bbe651972b = $(`&lt;div id=&quot;html_d67c2809711c95bec96945bbe651972b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ea70c6b07c7de4aad0f17199e8c7b868.setContent(html_d67c2809711c95bec96945bbe651972b);
#
#
#
#         marker_86a5b5dc4dea0d7b4964979552270979.bindPopup(popup_ea70c6b07c7de4aad0f17199e8c7b868)
#         ;
#
#
#
#
#             var marker_a1a9f71e79c3d7b2e95c94d05abd8141 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b34aa912e542d640af11f18ca4f4eaae);
#
#
#         var popup_81f4b7ed50b40aedae2c8135e6ebd84f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_648bb85a44921691248f56670196e221 = $(`&lt;div id=&quot;html_648bb85a44921691248f56670196e221&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_81f4b7ed50b40aedae2c8135e6ebd84f.setContent(html_648bb85a44921691248f56670196e221);
#
#
#
#         marker_a1a9f71e79c3d7b2e95c94d05abd8141.bindPopup(popup_81f4b7ed50b40aedae2c8135e6ebd84f)
#         ;
#
#
#
#
#             var marker_67747abb84f18c1e5caf2de8fdb2859e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b34aa912e542d640af11f18ca4f4eaae);
#
#
#         var popup_d4c9acb5a1243f166826a745127ea20b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e46772108e8fd3f0226c5731545c0e45 = $(`&lt;div id=&quot;html_e46772108e8fd3f0226c5731545c0e45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d4c9acb5a1243f166826a745127ea20b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d4a50e05046128c0c2cbe34051b1d85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d4a50e05046128c0c2cbe34051b1d85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d4a50e05046128c0c2cbe34051b1d85 = L.map(
#                 &quot;map_5d4a50e05046128c0c2cbe34051b1d85&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff3147fb882b68666ba78e18d5020787 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff3147fb882b68666ba78e18d5020787.addTo(map_5d4a50e05046128c0c2cbe34051b1d85);
#
#
#             var feature_group_1554d62b64f09038e25d80f28153a914 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_705ef8305e706f3a17dfc8874503416a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1554d62b64f09038e25d80f28153a914);
#
#
#         var popup_dd862fa5a8f5438f68411792c6e34af1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0531221b25af4b82650cc7e17b92d7cc = $(`&lt;div id=&quot;html_0531221b25af4b82650cc7e17b92d7cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dd862fa5a8f5438f68411792c6e34af1.setContent(html_0531221b25af4b82650cc7e17b92d7cc);
#
#
#
#         marker_705ef8305e706f3a17dfc8874503416a.bindPopup(popup_dd862fa5a8f5438f68411792c6e34af1)
#         ;
#
#
#
#
#             var marker_914f9e61c36ddd51400d478feb95042d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1554d62b64f09038e25d80f28153a914);
#
#
#         var popup_cfc747cb2f3153e7676a87db938dfbc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a96bff6608e3936774543e53afdfd96a = $(`&lt;div id=&quot;html_a96bff6608e3936774543e53afdfd96a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cfc747cb2f3153e7676a87db938dfbc6.setContent(html_a96bff6608e3936774543e53afdfd96a);
#
#
#
#         marker_914f9e61c36ddd51400d478feb95042d.bindPopup(popup_cfc747cb2f3153e7676a87db938dfbc6)
#         ;
#
#
#
#
#             var marker_28a68fe4a469181b7187c33e06943f68 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1554d62b64f09038e25d80f28153a914);
#
#
#         var popup_6faa9d6feb9b876a8179ece6701a04eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e0ab8ed3b2c610c255f543a410762c0 = $(`&lt;div id=&quot;html_2e0ab8ed3b2c610c255f543a410762c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6faa9d6feb9b876a8179ece6701a04eb.setContent(html_2e0ab8ed3b2c610c255f543a410762c0);
#
#
#
#         marker_28a68fe4a469181b7187c33e06943f68.bindPopup(popup_6faa9d6feb9b876a8179ece6701a04eb)
#         ;
#
#
#
#
#             var marker_4b26b787086b1d97427c4a211d0b2cbd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1554d62b64f09038e25d80f28153a914);
#
#
#         var popup_4c1c5957f478786b5f7bb46fd8d3f585 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6989c6d369ed2897c790449eb4034ad = $(`&lt;div id=&quot;html_b6989c6d369ed2897c790449eb4034ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4c1c5957f478786b5f7bb46fd8d3f585.setContent(html_b6989c6d369ed2897c790449eb4034ad);
#
#
#
#         marker_4b26b787086b1d97427c4a211d0b2cbd.bindPopup(popup_4c1c5957f478786b5f7bb46fd8d3f585)
#         ;
#
#
#
#
#             var marker_929dafdb1cc2818d8d5f5d793c074163 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1554d62b64f09038e25d80f28153a914);
#
#
#         var popup_569a52690b830e14282eba5e1d67e8d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b19b15973eb3bb63434f337667444fea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b19b15973eb3bb63434f337667444fea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b19b15973eb3bb63434f337667444fea = L.map(
#                 &quot;map_b19b15973eb3bb63434f337667444fea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce6d80bbdd32c082dfbce90dd711a896 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce6d80bbdd32c082dfbce90dd711a896.addTo(map_b19b15973eb3bb63434f337667444fea);
#
#
#             var feature_group_3a0c37fc1fccc2d9584eb07f1ecac511 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3a0c37fc1fccc2d9584eb07f1ecac511.addTo(map_b19b15973eb3bb63434f337667444fea);
#
#
#             var feature_group_sub_group_366f5d16fbdabda17186cdc9bab170fc = L.featureGroup.subGroup(
#                 feature_group_3a0c37fc1fccc2d9584eb07f1ecac511
#             );
#
#
#             var marker_2d038041a2867d741f4b7d524aeebbd3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_366f5d16fbdabda17186cdc9bab170fc);
#
#
#         var popup_317d8e247ca72aee700b8fdb7eb8392e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04cbcfb93d424587c62675d164847523 = $(`&lt;div id=&quot;html_04cbcfb93d424587c62675d164847523&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_317d8e247ca72aee700b8fdb7eb8392e.setContent(html_04cbcfb93d424587c62675d164847523);
#
#
#
#         marker_2d038041a2867d741f4b7d524aeebbd3.bindPopup(popup_317d8e247ca72aee700b8fdb7eb8392e)
#         ;
#
#
#
#
#             var marker_22cbcb5502a1a1d4f36bdc1cc3a26704 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_366f5d16fbdabda17186cdc9bab170fc);
#
#
#         var popup_906394ea1bfbb4f51b9ad55e761571fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73924087d4bd96b64e653f9cd2345ef4 = $(`&lt;div id=&quot;html_73924087d4bd96b64e653f9cd2345ef4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_906394ea1bfbb4f51b9ad55e761571fd.setContent(html_73924087d4bd96b64e653f9cd2345ef4);
#
#
#
#         marker_22cbcb5502a1a1d4f36bdc1cc3a26704.bindPopup(popup_906394ea1bfbb4f51b9ad55e761571fd)
#         ;
#
#
#
#
#             var marker_bca5f2225a0abd530e44d08d197f131c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_366f5d16fbdabda17186cdc9bab170fc);
#
#
#         var popup_ed62e9c5b9535f08506d33f6f1e4761c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e39e09c7f0726242625a5dce4910aff = $(`&lt;div id=&quot;html_2e39e09c7f0726242625a5dce4910aff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ed62e9c5b9535f08506d33f6f1e4761c.setContent(html_2e39e09c7f0726242625a5dce4910aff);
#
#
#
#         marker_bca5f2225a0abd530e44d08d197f131c.bindPopup(popup_ed62e9c5b9535f08506d33f6f1e4761c)
#         ;
#
#
#
#
#             var marker_40e537a7871dd9ad96f54a074066a513 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_366f5d16fbdabda17186cdc9bab170fc);
#
#
#         var popup_febd5b268da0854d9cf88768d76dc017 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d1f65802b9692825735041ff6ab8976 = $(`&lt;div id=&quot;html_1d1f65802b9692825735041ff6ab8976&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_febd5b268da0854d9cf88768d76dc017.setContent(html_1d1f65802b9692825735041ff6ab8976);
#
#
#
#         marker_
