# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ceb2cc953e54ddb666ecabe402c5813b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ceb2cc953e54ddb666ecabe402c5813b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ceb2cc953e54ddb666ecabe402c5813b = L.map(
#                 &quot;map_ceb2cc953e54ddb666ecabe402c5813b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b250659f3e5d7ee8fd857c68b6e01f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b250659f3e5d7ee8fd857c68b6e01f7.addTo(map_ceb2cc953e54ddb666ecabe402c5813b);
#
#
#             var marker_07cf955bf197db9ffc1ddc5f2fff9de4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ceb2cc953e54ddb666ecabe402c5813b);
#
#
#         var popup_b67a913ed2779d716579b85a064ae261 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a85abaf821a174cf5b1229fa6b07533a = $(`&lt;div id=&quot;html_a85abaf821a174cf5b1229fa6b07533a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b67a913ed2779d716579b85a064ae261.setContent(html_a85abaf821a174cf5b1229fa6b07533a);
#
#
#
#         marker_07cf955bf197db9ffc1ddc5f2fff9de4.bindPopup(popup_b67a913ed2779d716579b85a064ae261)
#         ;
#
#
#
#
#             var marker_4ee0955ed611361b9598639d20d21454 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ceb2cc953e54ddb666ecabe402c5813b);
#
#
#         var popup_45cbd32b5bccdf6ead30004b71abf294 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03ecbd9ffd9ea8274625c210e035a79b = $(`&lt;div id=&quot;html_03ecbd9ffd9ea8274625c210e035a79b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_45cbd32b5bccdf6ead30004b71abf294.setContent(html_03ecbd9ffd9ea8274625c210e035a79b);
#
#
#
#         marker_4ee0955ed611361b9598639d20d21454.bindPopup(popup_45cbd32b5bccdf6ead30004b71abf294)
#         ;
#
#
#
#
#             var marker_223fec279ba445e23d5f623f91bea5ac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ceb2cc953e54ddb666ecabe402c5813b);
#
#
#         var popup_e17398cb66237ab60c214bb0452b1830 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_661548bc10f2e570a6a0cccfe0e7edc2 = $(`&lt;div id=&quot;html_661548bc10f2e570a6a0cccfe0e7edc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e17398cb66237ab60c214bb0452b1830.setContent(html_661548bc10f2e570a6a0cccfe0e7edc2);
#
#
#
#         marker_223fec279ba445e23d5f623f91bea5ac.bindPopup(popup_e17398cb66237ab60c214bb0452b1830)
#         ;
#
#
#
#
#             var marker_21b25b8794dae671fe6a14c1770d2100 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ceb2cc953e54ddb666ecabe402c5813b);
#
#
#         var popup_c2b4bac93c2f023ebae685fcee19320e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85a8c6ee3a643451a73689c3dacead9e = $(`&lt;div id=&quot;html_85a8c6ee3a643451a73689c3dacead9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c2b4bac93c2f023ebae685fcee19320e.setContent(html_85a8c6ee3a643451a73689c3dacead9e);
#
#
#
#         marker_21b25b8794dae671fe6a14c1770d2100.bindPopup(popup_c2b4bac93c2f023ebae685fcee19320e)
#         ;
#
#
#
#
#             var marker_374b5da53843967bdf3184f58697298e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ceb2cc953e54ddb666ecabe402c5813b);
#
#
#         var popup_8f880d0303963a37cb4bd0515dadee9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d826dbff5479c673028d2c5b7cf3236e = $(`&lt;div id=&quot;html_d826dbff5479c673028d2c5b7cf3236e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8f880d0303963a37cb4bd0515dadee9e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4cca073a17f8143206524aa7dc1df90 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4cca073a17f8143206524aa7dc1df90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4cca073a17f8143206524aa7dc1df90 = L.map(
#                 &quot;map_d4cca073a17f8143206524aa7dc1df90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c31513167ca40092f2153c98ebf96a4d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c31513167ca40092f2153c98ebf96a4d.addTo(map_d4cca073a17f8143206524aa7dc1df90);
#
#
#             var feature_group_f1d577df9fa439d0836bc17ce143c287 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1beafa7a05012cf3435eee218cf13bb4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f1d577df9fa439d0836bc17ce143c287);
#
#
#         var popup_52821f6efdf208921ca6f8a768819cb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fe822575f8dd7087d29d7917768951e = $(`&lt;div id=&quot;html_6fe822575f8dd7087d29d7917768951e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_52821f6efdf208921ca6f8a768819cb0.setContent(html_6fe822575f8dd7087d29d7917768951e);
#
#
#
#         marker_1beafa7a05012cf3435eee218cf13bb4.bindPopup(popup_52821f6efdf208921ca6f8a768819cb0)
#         ;
#
#
#
#
#             var marker_9bb651f764249d201d1f9fd35564df50 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f1d577df9fa439d0836bc17ce143c287);
#
#
#         var popup_1acbfdf773e235c0787d9291acbd6b0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dff72e43881fd0a7ebba042cb2b78cdc = $(`&lt;div id=&quot;html_dff72e43881fd0a7ebba042cb2b78cdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1acbfdf773e235c0787d9291acbd6b0c.setContent(html_dff72e43881fd0a7ebba042cb2b78cdc);
#
#
#
#         marker_9bb651f764249d201d1f9fd35564df50.bindPopup(popup_1acbfdf773e235c0787d9291acbd6b0c)
#         ;
#
#
#
#
#             var marker_bd3fffe5efb590317320950ce5740a6e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f1d577df9fa439d0836bc17ce143c287);
#
#
#         var popup_54361e2f6af613222ce8af3c328d5087 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1986d2c043160361d36c33410e8e63f = $(`&lt;div id=&quot;html_c1986d2c043160361d36c33410e8e63f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_54361e2f6af613222ce8af3c328d5087.setContent(html_c1986d2c043160361d36c33410e8e63f);
#
#
#
#         marker_bd3fffe5efb590317320950ce5740a6e.bindPopup(popup_54361e2f6af613222ce8af3c328d5087)
#         ;
#
#
#
#
#             var marker_4d330c0abcfd7015e63e727481a481bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f1d577df9fa439d0836bc17ce143c287);
#
#
#         var popup_33f817426e393ae7a905b6f8a9fdf02a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b05024ed1397824c2fa9f530fca0ddf = $(`&lt;div id=&quot;html_5b05024ed1397824c2fa9f530fca0ddf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_33f817426e393ae7a905b6f8a9fdf02a.setContent(html_5b05024ed1397824c2fa9f530fca0ddf);
#
#
#
#         marker_4d330c0abcfd7015e63e727481a481bc.bindPopup(popup_33f817426e393ae7a905b6f8a9fdf02a)
#         ;
#
#
#
#
#             var marker_fa473a047c76b86b57e5e880a9788f49 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f1d577df9fa439d0836bc17ce143c287);
#
#
#         var popup_c92d80d271c9d5ac823b886ef118dcf1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73128855a53d94e3d0d76f099660ccc7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73128855a53d94e3d0d76f099660ccc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73128855a53d94e3d0d76f099660ccc7 = L.map(
#                 &quot;map_73128855a53d94e3d0d76f099660ccc7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c88a52ec7b1667c8501b115d1249355b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c88a52ec7b1667c8501b115d1249355b.addTo(map_73128855a53d94e3d0d76f099660ccc7);
#
#
#             var feature_group_d1846e1dd467a0e27882a4e247d9ff83 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d1846e1dd467a0e27882a4e247d9ff83.addTo(map_73128855a53d94e3d0d76f099660ccc7);
#
#
#             var feature_group_sub_group_90d07d94479b6881136cdf07c34fcd13 = L.featureGroup.subGroup(
#                 feature_group_d1846e1dd467a0e27882a4e247d9ff83
#             );
#
#
#             var marker_b5aa99aa38a99519438bc80da42f534d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_90d07d94479b6881136cdf07c34fcd13);
#
#
#         var popup_f1048fdbbb3d699801d1f88aab4c5fe4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d76d953f574e6eef8400bf46a808935 = $(`&lt;div id=&quot;html_4d76d953f574e6eef8400bf46a808935&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f1048fdbbb3d699801d1f88aab4c5fe4.setContent(html_4d76d953f574e6eef8400bf46a808935);
#
#
#
#         marker_b5aa99aa38a99519438bc80da42f534d.bindPopup(popup_f1048fdbbb3d699801d1f88aab4c5fe4)
#         ;
#
#
#
#
#             var marker_65c7ce2ea220c214e529ac56fd1a7869 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_90d07d94479b6881136cdf07c34fcd13);
#
#
#         var popup_bda7a74325d27f8eb2b436869273244f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3c715c9ea000a8bc50fd8def7f097d6 = $(`&lt;div id=&quot;html_c3c715c9ea000a8bc50fd8def7f097d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bda7a74325d27f8eb2b436869273244f.setContent(html_c3c715c9ea000a8bc50fd8def7f097d6);
#
#
#
#         marker_65c7ce2ea220c214e529ac56fd1a7869.bindPopup(popup_bda7a74325d27f8eb2b436869273244f)
#         ;
#
#
#
#
#             var marker_6498686720f0c3f1fc4725d10939c213 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_90d07d94479b6881136cdf07c34fcd13);
#
#
#         var popup_55d2b70d5d920e71c69d25144fbac0fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d96ad61940677cdba54eec04d33479cc = $(`&lt;div id=&quot;html_d96ad61940677cdba54eec04d33479cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_55d2b70d5d920e71c69d25144fbac0fc.setContent(html_d96ad61940677cdba54eec04d33479cc);
#
#
#
#         marker_6498686720f0c3f1fc4725d10939c213.bindPopup(popup_55d2b70d5d920e71c69d25144fbac0fc)
#         ;
#
#
#
#
#             var marker_9e9fc86eb2ed0cfadfdf51bcb70b2893 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_90d07d94479b6881136cdf07c34fcd13);
#
#
#         var popup_8ac5dfa202ebc88f603c0dfe11ee81e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_062043cfaadb3bf6e1e78dfee07ec1e2 = $(`&lt;div id=&quot;html_062043cfaadb3bf6e1e78dfee07ec1e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8ac5dfa202ebc88f603c0dfe11ee81e5.setContent(html_062043cfaadb3bf6e1e78dfee07ec1e2);
#
#
#
#         marker_
