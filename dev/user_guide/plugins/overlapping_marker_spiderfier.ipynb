# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38f46f3558d5c4a1305cc5993f6d411c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38f46f3558d5c4a1305cc5993f6d411c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38f46f3558d5c4a1305cc5993f6d411c = L.map(
#                 &quot;map_38f46f3558d5c4a1305cc5993f6d411c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1086b801f4790c616baad9cbd2530a6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1086b801f4790c616baad9cbd2530a6.addTo(map_38f46f3558d5c4a1305cc5993f6d411c);
#
#
#             var marker_ff499f0a11191f1ed0f48eeeca5e82f2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_38f46f3558d5c4a1305cc5993f6d411c);
#
#
#         var popup_46a0267c139eb3d093fbde9047986c61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1caa0bc67c75756c529f8536345bbda8 = $(`&lt;div id=&quot;html_1caa0bc67c75756c529f8536345bbda8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_46a0267c139eb3d093fbde9047986c61.setContent(html_1caa0bc67c75756c529f8536345bbda8);
#
#
#
#         marker_ff499f0a11191f1ed0f48eeeca5e82f2.bindPopup(popup_46a0267c139eb3d093fbde9047986c61)
#         ;
#
#
#
#
#             var marker_b8695131c2f425043b579bd0771ac663 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_38f46f3558d5c4a1305cc5993f6d411c);
#
#
#         var popup_d724e842fe90b4b38d40e79820208597 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e46e4579041c2aafd3e18b8e63f6ca7 = $(`&lt;div id=&quot;html_0e46e4579041c2aafd3e18b8e63f6ca7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d724e842fe90b4b38d40e79820208597.setContent(html_0e46e4579041c2aafd3e18b8e63f6ca7);
#
#
#
#         marker_b8695131c2f425043b579bd0771ac663.bindPopup(popup_d724e842fe90b4b38d40e79820208597)
#         ;
#
#
#
#
#             var marker_7df7a2811b7eb22d6fb9f02e273c573f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_38f46f3558d5c4a1305cc5993f6d411c);
#
#
#         var popup_d6a3ed76c5f602aa859257f270f1cecf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c1be1fb6c97e0d33bc76281a5b388a5 = $(`&lt;div id=&quot;html_1c1be1fb6c97e0d33bc76281a5b388a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d6a3ed76c5f602aa859257f270f1cecf.setContent(html_1c1be1fb6c97e0d33bc76281a5b388a5);
#
#
#
#         marker_7df7a2811b7eb22d6fb9f02e273c573f.bindPopup(popup_d6a3ed76c5f602aa859257f270f1cecf)
#         ;
#
#
#
#
#             var marker_a1382490224377a20f242847855d1139 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_38f46f3558d5c4a1305cc5993f6d411c);
#
#
#         var popup_b630c8184d7d82ef09ec789eff6b27ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf37cd444fc04b63f8ebf08d73779cb1 = $(`&lt;div id=&quot;html_bf37cd444fc04b63f8ebf08d73779cb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b630c8184d7d82ef09ec789eff6b27ae.setContent(html_bf37cd444fc04b63f8ebf08d73779cb1);
#
#
#
#         marker_a1382490224377a20f242847855d1139.bindPopup(popup_b630c8184d7d82ef09ec789eff6b27ae)
#         ;
#
#
#
#
#             var marker_4c13b85d51e8abbc544a47c4d80adf90 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_38f46f3558d5c4a1305cc5993f6d411c);
#
#
#         var popup_2c8e5eb3b1673b8a0667a77b84ed9f75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af4af41c02226afee160ff9cff9adb1d = $(`&lt;div id=&quot;html_af4af41c02226afee160ff9cff9adb1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2c8e5eb3b1673b8a0667a77b84ed9f75.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec44822afb25194c29dcc9ed5dc8a04d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec44822afb25194c29dcc9ed5dc8a04d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec44822afb25194c29dcc9ed5dc8a04d = L.map(
#                 &quot;map_ec44822afb25194c29dcc9ed5dc8a04d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90808895f8ce7a2b6e408e8d14f71fb3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90808895f8ce7a2b6e408e8d14f71fb3.addTo(map_ec44822afb25194c29dcc9ed5dc8a04d);
#
#
#             var feature_group_66211600fd30311610b53d731a15cc80 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cbc2d6ab03464177807ab02b1717ce2e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_66211600fd30311610b53d731a15cc80);
#
#
#         var popup_a9c278f23a39fae3f28f6ecb4e323ae9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e85d46f812897a47bd13411f3c2ad081 = $(`&lt;div id=&quot;html_e85d46f812897a47bd13411f3c2ad081&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a9c278f23a39fae3f28f6ecb4e323ae9.setContent(html_e85d46f812897a47bd13411f3c2ad081);
#
#
#
#         marker_cbc2d6ab03464177807ab02b1717ce2e.bindPopup(popup_a9c278f23a39fae3f28f6ecb4e323ae9)
#         ;
#
#
#
#
#             var marker_94902bf1d426eee91a572a7e3d693f3b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_66211600fd30311610b53d731a15cc80);
#
#
#         var popup_74ee9c077bacb9ca9006353fa5683af5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33ea3359270c4c97c120faa94ace543a = $(`&lt;div id=&quot;html_33ea3359270c4c97c120faa94ace543a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_74ee9c077bacb9ca9006353fa5683af5.setContent(html_33ea3359270c4c97c120faa94ace543a);
#
#
#
#         marker_94902bf1d426eee91a572a7e3d693f3b.bindPopup(popup_74ee9c077bacb9ca9006353fa5683af5)
#         ;
#
#
#
#
#             var marker_91b54715d08d4417af1cb071d66b8d21 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_66211600fd30311610b53d731a15cc80);
#
#
#         var popup_6ca307594b03c561625a9e747a6fa17a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9c0739e51a106a39e18da9668232abc = $(`&lt;div id=&quot;html_e9c0739e51a106a39e18da9668232abc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6ca307594b03c561625a9e747a6fa17a.setContent(html_e9c0739e51a106a39e18da9668232abc);
#
#
#
#         marker_91b54715d08d4417af1cb071d66b8d21.bindPopup(popup_6ca307594b03c561625a9e747a6fa17a)
#         ;
#
#
#
#
#             var marker_0896f47647b6a9fa4f4571cba05fcc25 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_66211600fd30311610b53d731a15cc80);
#
#
#         var popup_f50bf8eb67a1262ffaa91a9031255902 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3123f25c8c283ed4496ffcbc1313d375 = $(`&lt;div id=&quot;html_3123f25c8c283ed4496ffcbc1313d375&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f50bf8eb67a1262ffaa91a9031255902.setContent(html_3123f25c8c283ed4496ffcbc1313d375);
#
#
#
#         marker_0896f47647b6a9fa4f4571cba05fcc25.bindPopup(popup_f50bf8eb67a1262ffaa91a9031255902)
#         ;
#
#
#
#
#             var marker_7d663617467aa2d9fb817323cd01eead = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_66211600fd30311610b53d731a15cc80);
#
#
#         var popup_009973484a68767518c270f22f90ea1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a75b6c7ded8ff01d0f923df63a44e905 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a75b6c7ded8ff01d0f923df63a44e905&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a75b6c7ded8ff01d0f923df63a44e905 = L.map(
#                 &quot;map_a75b6c7ded8ff01d0f923df63a44e905&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de11ce1bb651dbf4a1c32584d93af31e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de11ce1bb651dbf4a1c32584d93af31e.addTo(map_a75b6c7ded8ff01d0f923df63a44e905);
#
#
#             var feature_group_80895d6919c2c2528ed5d732405501c8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_80895d6919c2c2528ed5d732405501c8.addTo(map_a75b6c7ded8ff01d0f923df63a44e905);
#
#
#             var feature_group_sub_group_8571cf5aaf65ef3497e231b1224e28cd = L.featureGroup.subGroup(
#                 feature_group_80895d6919c2c2528ed5d732405501c8
#             );
#
#
#             var marker_50175974b45827931cb70750d56f95d1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8571cf5aaf65ef3497e231b1224e28cd);
#
#
#         var popup_2eb9c8ed2eb26270e6966565392cf866 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98b674a991508735b6c4404533982ae3 = $(`&lt;div id=&quot;html_98b674a991508735b6c4404533982ae3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2eb9c8ed2eb26270e6966565392cf866.setContent(html_98b674a991508735b6c4404533982ae3);
#
#
#
#         marker_50175974b45827931cb70750d56f95d1.bindPopup(popup_2eb9c8ed2eb26270e6966565392cf866)
#         ;
#
#
#
#
#             var marker_1bc491122dd614b65197460fbc45b630 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8571cf5aaf65ef3497e231b1224e28cd);
#
#
#         var popup_ff4ddd6fa13790e94bd3779d70c49592 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bdc4d437a0e1d897798cfc1e03f910e = $(`&lt;div id=&quot;html_1bdc4d437a0e1d897798cfc1e03f910e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ff4ddd6fa13790e94bd3779d70c49592.setContent(html_1bdc4d437a0e1d897798cfc1e03f910e);
#
#
#
#         marker_1bc491122dd614b65197460fbc45b630.bindPopup(popup_ff4ddd6fa13790e94bd3779d70c49592)
#         ;
#
#
#
#
#             var marker_e9c263eae7abc9b048484d61d793f592 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8571cf5aaf65ef3497e231b1224e28cd);
#
#
#         var popup_3bd824df405acdbcb076d3191576a78e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b2c66621a11b315fc6fe8a402323a8d = $(`&lt;div id=&quot;html_7b2c66621a11b315fc6fe8a402323a8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3bd824df405acdbcb076d3191576a78e.setContent(html_7b2c66621a11b315fc6fe8a402323a8d);
#
#
#
#         marker_e9c263eae7abc9b048484d61d793f592.bindPopup(popup_3bd824df405acdbcb076d3191576a78e)
#         ;
#
#
#
#
#             var marker_b739288666b512ecc0a6fd65bdb87413 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8571cf5aaf65ef3497e231b1224e28cd);
#
#
#         var popup_ecff1ba0faedf9018b3c894638d27435 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0745509a3fc883c31c44f96f99c48b12 = $(`&lt;div id=&quot;html_0745509a3fc883c31c44f96f99c48b12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ecff1ba0faedf9018b3c894638d27435.setContent(html_0745509a3fc883c31c44f96f99c48b12);
#
#
#
#         marker_
