# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6fed9979cc3a2edbbc2efc17170c519 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6fed9979cc3a2edbbc2efc17170c519&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6fed9979cc3a2edbbc2efc17170c519 = L.map(
#                 &quot;map_d6fed9979cc3a2edbbc2efc17170c519&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c81a0fd77d1929a08a7ada7283c62448 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c81a0fd77d1929a08a7ada7283c62448.addTo(map_d6fed9979cc3a2edbbc2efc17170c519);
#
#
#             var marker_8cc0f4d87e6a03b9ed0a0ed4c8a69f76 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d6fed9979cc3a2edbbc2efc17170c519);
#
#
#         var popup_b1d6d216d2c03b5b6e5c6a0848647c31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6aca70469c5ede5ac220fc41fda6e5d = $(`&lt;div id=&quot;html_c6aca70469c5ede5ac220fc41fda6e5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b1d6d216d2c03b5b6e5c6a0848647c31.setContent(html_c6aca70469c5ede5ac220fc41fda6e5d);
#
#
#
#         marker_8cc0f4d87e6a03b9ed0a0ed4c8a69f76.bindPopup(popup_b1d6d216d2c03b5b6e5c6a0848647c31)
#         ;
#
#
#
#
#             var marker_b027ee46352714d3e4ea15febe30eccb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d6fed9979cc3a2edbbc2efc17170c519);
#
#
#         var popup_b2da361ffe5afcadb83759290240587f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae5acedef37d49cd6eec243e92f8fa47 = $(`&lt;div id=&quot;html_ae5acedef37d49cd6eec243e92f8fa47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b2da361ffe5afcadb83759290240587f.setContent(html_ae5acedef37d49cd6eec243e92f8fa47);
#
#
#
#         marker_b027ee46352714d3e4ea15febe30eccb.bindPopup(popup_b2da361ffe5afcadb83759290240587f)
#         ;
#
#
#
#
#             var marker_d7d8e55945bca985a3d7f62e52416acb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d6fed9979cc3a2edbbc2efc17170c519);
#
#
#         var popup_c0426a8e036c96be70512b9e8fca6bb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dea2f934314859324ce95f9185566de0 = $(`&lt;div id=&quot;html_dea2f934314859324ce95f9185566de0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c0426a8e036c96be70512b9e8fca6bb5.setContent(html_dea2f934314859324ce95f9185566de0);
#
#
#
#         marker_d7d8e55945bca985a3d7f62e52416acb.bindPopup(popup_c0426a8e036c96be70512b9e8fca6bb5)
#         ;
#
#
#
#
#             var marker_8a1c441f944ddf15a250ae514f9ff67d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d6fed9979cc3a2edbbc2efc17170c519);
#
#
#         var popup_346bc07ed9fc2c1d20c269d99a6ae49e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cb0a6c7e374d8d84c7b496af49530ab = $(`&lt;div id=&quot;html_7cb0a6c7e374d8d84c7b496af49530ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_346bc07ed9fc2c1d20c269d99a6ae49e.setContent(html_7cb0a6c7e374d8d84c7b496af49530ab);
#
#
#
#         marker_8a1c441f944ddf15a250ae514f9ff67d.bindPopup(popup_346bc07ed9fc2c1d20c269d99a6ae49e)
#         ;
#
#
#
#
#             var marker_8775c8ddd7b7dcc749f61d6cb158cec8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d6fed9979cc3a2edbbc2efc17170c519);
#
#
#         var popup_7e651a07b0f613b952d59c20e84a80a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_783da042cd742a4f4c5346c6a30bf32e = $(`&lt;div id=&quot;html_783da042cd742a4f4c5346c6a30bf32e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7e651a07b0f613b952d59c20e84a80a3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_defdb33c106234507e94689f62483d07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_defdb33c106234507e94689f62483d07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_defdb33c106234507e94689f62483d07 = L.map(
#                 &quot;map_defdb33c106234507e94689f62483d07&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_97394a506e71c48ab315c42aa93bd5d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_97394a506e71c48ab315c42aa93bd5d8.addTo(map_defdb33c106234507e94689f62483d07);
#
#
#             var feature_group_744fac2cc6f181d98fba2927071a6794 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c77eaf108f065934be2c03f019cd0998 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_744fac2cc6f181d98fba2927071a6794);
#
#
#         var popup_ba7e07366c840b2cb3579ccefe01f650 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85479d23743b7afcc9ef7a7604c83ab6 = $(`&lt;div id=&quot;html_85479d23743b7afcc9ef7a7604c83ab6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ba7e07366c840b2cb3579ccefe01f650.setContent(html_85479d23743b7afcc9ef7a7604c83ab6);
#
#
#
#         marker_c77eaf108f065934be2c03f019cd0998.bindPopup(popup_ba7e07366c840b2cb3579ccefe01f650)
#         ;
#
#
#
#
#             var marker_f0a022c13ecae7264fd8b1840345e4c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_744fac2cc6f181d98fba2927071a6794);
#
#
#         var popup_09d058b331e78c527276af7877354075 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9975e3498f402d46eb48ca33fb010e7f = $(`&lt;div id=&quot;html_9975e3498f402d46eb48ca33fb010e7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_09d058b331e78c527276af7877354075.setContent(html_9975e3498f402d46eb48ca33fb010e7f);
#
#
#
#         marker_f0a022c13ecae7264fd8b1840345e4c9.bindPopup(popup_09d058b331e78c527276af7877354075)
#         ;
#
#
#
#
#             var marker_5e62fcd57232edb03e25ac905b96f564 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_744fac2cc6f181d98fba2927071a6794);
#
#
#         var popup_94c9f37da9088a0d4c18c2c6805048b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96138e742731cab7f3ed4190d313bc02 = $(`&lt;div id=&quot;html_96138e742731cab7f3ed4190d313bc02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_94c9f37da9088a0d4c18c2c6805048b8.setContent(html_96138e742731cab7f3ed4190d313bc02);
#
#
#
#         marker_5e62fcd57232edb03e25ac905b96f564.bindPopup(popup_94c9f37da9088a0d4c18c2c6805048b8)
#         ;
#
#
#
#
#             var marker_7474d16d5ea26d48fa6b2d6fe0dcdcd1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_744fac2cc6f181d98fba2927071a6794);
#
#
#         var popup_23209eeaddcdbb44a1809d2f775cb1a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f7abafe3c6562125011366b74a81a8c = $(`&lt;div id=&quot;html_6f7abafe3c6562125011366b74a81a8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_23209eeaddcdbb44a1809d2f775cb1a1.setContent(html_6f7abafe3c6562125011366b74a81a8c);
#
#
#
#         marker_7474d16d5ea26d48fa6b2d6fe0dcdcd1.bindPopup(popup_23209eeaddcdbb44a1809d2f775cb1a1)
#         ;
#
#
#
#
#             var marker_97b33d4bd11862d2b049f6ea2ab78700 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_744fac2cc6f181d98fba2927071a6794);
#
#
#         var popup_a9569e7a7d8fdb60c1b05a2b3573a12c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_875bbd66f9022327ba72d017827bf9ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_875bbd66f9022327ba72d017827bf9ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_875bbd66f9022327ba72d017827bf9ba = L.map(
#                 &quot;map_875bbd66f9022327ba72d017827bf9ba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_096f4669e55160c85af5eeeb1f86b623 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_096f4669e55160c85af5eeeb1f86b623.addTo(map_875bbd66f9022327ba72d017827bf9ba);
#
#
#             var feature_group_b388a921feb136ac56648b3f95372e15 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b388a921feb136ac56648b3f95372e15.addTo(map_875bbd66f9022327ba72d017827bf9ba);
#
#
#             var feature_group_sub_group_add80c1e2a06f09538ba3f0dc2db4178 = L.featureGroup.subGroup(
#                 feature_group_b388a921feb136ac56648b3f95372e15
#             );
#
#
#             var marker_6ec3a2d1e7e876242fe581f38fbc812b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_add80c1e2a06f09538ba3f0dc2db4178);
#
#
#         var popup_fe67bf5c738309dd99a6ddc00cc0067b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab55bf527d92cc629cf77604b71a6174 = $(`&lt;div id=&quot;html_ab55bf527d92cc629cf77604b71a6174&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fe67bf5c738309dd99a6ddc00cc0067b.setContent(html_ab55bf527d92cc629cf77604b71a6174);
#
#
#
#         marker_6ec3a2d1e7e876242fe581f38fbc812b.bindPopup(popup_fe67bf5c738309dd99a6ddc00cc0067b)
#         ;
#
#
#
#
#             var marker_44d17f87eebcb0fe46b66872b869ed8d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_add80c1e2a06f09538ba3f0dc2db4178);
#
#
#         var popup_08c05880d5523491a28fb9306c8515e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e84fb966facf6c76ff5477fac436f226 = $(`&lt;div id=&quot;html_e84fb966facf6c76ff5477fac436f226&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_08c05880d5523491a28fb9306c8515e2.setContent(html_e84fb966facf6c76ff5477fac436f226);
#
#
#
#         marker_44d17f87eebcb0fe46b66872b869ed8d.bindPopup(popup_08c05880d5523491a28fb9306c8515e2)
#         ;
#
#
#
#
#             var marker_47b71b3398619e9b45f73d7f9cbe5d40 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_add80c1e2a06f09538ba3f0dc2db4178);
#
#
#         var popup_edfd35332d20d4b46f884df76d5d7e59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2c052283b65adf83e304b5949ef5259 = $(`&lt;div id=&quot;html_d2c052283b65adf83e304b5949ef5259&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_edfd35332d20d4b46f884df76d5d7e59.setContent(html_d2c052283b65adf83e304b5949ef5259);
#
#
#
#         marker_47b71b3398619e9b45f73d7f9cbe5d40.bindPopup(popup_edfd35332d20d4b46f884df76d5d7e59)
#         ;
#
#
#
#
#             var marker_c19fc77c22d46d89125088dc621d4fc0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_add80c1e2a06f09538ba3f0dc2db4178);
#
#
#         var popup_5575efc28ccda4a01b88760abf22d9fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49dddabf66b60df6042962b1f088bcfd = $(`&lt;div id=&quot;html_49dddabf66b60df6042962b1f088bcfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5575efc28ccda4a01b88760abf22d9fd.setContent(html_49dddabf66b60df6042962b1f088bcfd);
#
#
#
#         marker_
