# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a37b1e1d74c430792f7acefbcbd75f4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a37b1e1d74c430792f7acefbcbd75f4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a37b1e1d74c430792f7acefbcbd75f4a = L.map(
#                 &quot;map_a37b1e1d74c430792f7acefbcbd75f4a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df78abd2b9e7b7d8e2c315a4fcc7820c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df78abd2b9e7b7d8e2c315a4fcc7820c.addTo(map_a37b1e1d74c430792f7acefbcbd75f4a);
#
#
#             var marker_33c8890e0038caa5e2dd6496020bbe69 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a37b1e1d74c430792f7acefbcbd75f4a);
#
#
#         var popup_2db3853ab8b5884ea5e1419d5daf3adb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_660e9851d0c98cabcc942e16058db18a = $(`&lt;div id=&quot;html_660e9851d0c98cabcc942e16058db18a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2db3853ab8b5884ea5e1419d5daf3adb.setContent(html_660e9851d0c98cabcc942e16058db18a);
#
#
#
#         marker_33c8890e0038caa5e2dd6496020bbe69.bindPopup(popup_2db3853ab8b5884ea5e1419d5daf3adb)
#         ;
#
#
#
#
#             var marker_07008ad935800086381ad6d716c8ac13 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a37b1e1d74c430792f7acefbcbd75f4a);
#
#
#         var popup_0b469b4bf323664f8c82d83faff57da7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_861996eb7ebf0f1171eb1a4dd807a451 = $(`&lt;div id=&quot;html_861996eb7ebf0f1171eb1a4dd807a451&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0b469b4bf323664f8c82d83faff57da7.setContent(html_861996eb7ebf0f1171eb1a4dd807a451);
#
#
#
#         marker_07008ad935800086381ad6d716c8ac13.bindPopup(popup_0b469b4bf323664f8c82d83faff57da7)
#         ;
#
#
#
#
#             var marker_66b14cf2e5caf439e4c90a1d1fad4273 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a37b1e1d74c430792f7acefbcbd75f4a);
#
#
#         var popup_532f7fb27ed09e98a1f449914137d92c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9e7d0b244c7f332d608f8ebbf2863cb = $(`&lt;div id=&quot;html_f9e7d0b244c7f332d608f8ebbf2863cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_532f7fb27ed09e98a1f449914137d92c.setContent(html_f9e7d0b244c7f332d608f8ebbf2863cb);
#
#
#
#         marker_66b14cf2e5caf439e4c90a1d1fad4273.bindPopup(popup_532f7fb27ed09e98a1f449914137d92c)
#         ;
#
#
#
#
#             var marker_7aef873d6137e2a6efcf18c079b2e7e7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a37b1e1d74c430792f7acefbcbd75f4a);
#
#
#         var popup_e471ce7ff539db886d772c1b09177904 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40ab15cee8139b3b70d053b78ace5540 = $(`&lt;div id=&quot;html_40ab15cee8139b3b70d053b78ace5540&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e471ce7ff539db886d772c1b09177904.setContent(html_40ab15cee8139b3b70d053b78ace5540);
#
#
#
#         marker_7aef873d6137e2a6efcf18c079b2e7e7.bindPopup(popup_e471ce7ff539db886d772c1b09177904)
#         ;
#
#
#
#
#             var marker_7ea0088607ae1c893f6544e8b74b0e88 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a37b1e1d74c430792f7acefbcbd75f4a);
#
#
#         var popup_941fbea07fb795cc260e46bdbff6bc71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6ef17c83f74aa9fd0b62e75fb44fd3c = $(`&lt;div id=&quot;html_e6ef17c83f74aa9fd0b62e75fb44fd3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_941fbea07fb795cc260e46bdbff6bc71.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_992bdb7a73ded84ae52ad8d384b81b0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_992bdb7a73ded84ae52ad8d384b81b0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_992bdb7a73ded84ae52ad8d384b81b0a = L.map(
#                 &quot;map_992bdb7a73ded84ae52ad8d384b81b0a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1255fbddb84e654e70565d5a57fe9b0a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1255fbddb84e654e70565d5a57fe9b0a.addTo(map_992bdb7a73ded84ae52ad8d384b81b0a);
#
#
#             var feature_group_68f9b584236486fcec49b10f1bf2310f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_21b566bceeb790432ee5ca903ff123e2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_68f9b584236486fcec49b10f1bf2310f);
#
#
#         var popup_74a16df671b877b3ff3e5d8147a9d231 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2937f6d6e339f70bcbd87fd64e21476b = $(`&lt;div id=&quot;html_2937f6d6e339f70bcbd87fd64e21476b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_74a16df671b877b3ff3e5d8147a9d231.setContent(html_2937f6d6e339f70bcbd87fd64e21476b);
#
#
#
#         marker_21b566bceeb790432ee5ca903ff123e2.bindPopup(popup_74a16df671b877b3ff3e5d8147a9d231)
#         ;
#
#
#
#
#             var marker_10d4100e8c40c06ecbd4973d334350ac = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_68f9b584236486fcec49b10f1bf2310f);
#
#
#         var popup_7a2b00c7c7eaec22c89a1c8a0789056e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74b7a0544b13671e54d889aee84fd119 = $(`&lt;div id=&quot;html_74b7a0544b13671e54d889aee84fd119&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7a2b00c7c7eaec22c89a1c8a0789056e.setContent(html_74b7a0544b13671e54d889aee84fd119);
#
#
#
#         marker_10d4100e8c40c06ecbd4973d334350ac.bindPopup(popup_7a2b00c7c7eaec22c89a1c8a0789056e)
#         ;
#
#
#
#
#             var marker_422afdfd7685787e37bb2d258a92b96b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_68f9b584236486fcec49b10f1bf2310f);
#
#
#         var popup_bcdb55ca0b7ada36a327d3f5e26c6058 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_474726beed441c9d5a7dc58f4fd80c9a = $(`&lt;div id=&quot;html_474726beed441c9d5a7dc58f4fd80c9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bcdb55ca0b7ada36a327d3f5e26c6058.setContent(html_474726beed441c9d5a7dc58f4fd80c9a);
#
#
#
#         marker_422afdfd7685787e37bb2d258a92b96b.bindPopup(popup_bcdb55ca0b7ada36a327d3f5e26c6058)
#         ;
#
#
#
#
#             var marker_5bace4b1a519d8b53c75e68c5138b519 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_68f9b584236486fcec49b10f1bf2310f);
#
#
#         var popup_84a7b2d52ba7e365f7742a1c459e84c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62377dd158104d8b500d12209b323d59 = $(`&lt;div id=&quot;html_62377dd158104d8b500d12209b323d59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_84a7b2d52ba7e365f7742a1c459e84c5.setContent(html_62377dd158104d8b500d12209b323d59);
#
#
#
#         marker_5bace4b1a519d8b53c75e68c5138b519.bindPopup(popup_84a7b2d52ba7e365f7742a1c459e84c5)
#         ;
#
#
#
#
#             var marker_86d5879e4a1ae758218d1b35cfd7d803 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_68f9b584236486fcec49b10f1bf2310f);
#
#
#         var popup_5c7bca888ae23ce4db90d86d7ab53c12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5e9b8324979463067c7d6c1a38dcb83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5e9b8324979463067c7d6c1a38dcb83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5e9b8324979463067c7d6c1a38dcb83 = L.map(
#                 &quot;map_e5e9b8324979463067c7d6c1a38dcb83&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cdba4b57c32618a0c0c1c7311f45f2a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2cdba4b57c32618a0c0c1c7311f45f2a.addTo(map_e5e9b8324979463067c7d6c1a38dcb83);
#
#
#             var feature_group_dfbdafc36aa483dfde44e975fca78d23 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dfbdafc36aa483dfde44e975fca78d23.addTo(map_e5e9b8324979463067c7d6c1a38dcb83);
#
#
#             var feature_group_sub_group_b2c177aa9109bdbba540735d671f64fb = L.featureGroup.subGroup(
#                 feature_group_dfbdafc36aa483dfde44e975fca78d23
#             );
#
#
#             var marker_119dc67390d49a74bf78ac623f23db42 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2c177aa9109bdbba540735d671f64fb);
#
#
#         var popup_69294bcfd6ff225cb451bf13eca11598 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_955a5b693ed8fdf9b1ce24bdb1451ea4 = $(`&lt;div id=&quot;html_955a5b693ed8fdf9b1ce24bdb1451ea4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_69294bcfd6ff225cb451bf13eca11598.setContent(html_955a5b693ed8fdf9b1ce24bdb1451ea4);
#
#
#
#         marker_119dc67390d49a74bf78ac623f23db42.bindPopup(popup_69294bcfd6ff225cb451bf13eca11598)
#         ;
#
#
#
#
#             var marker_d480f8b173767a14fe999d99d783f869 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2c177aa9109bdbba540735d671f64fb);
#
#
#         var popup_511d91385003b1187aff57b9e8ba48f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca6e87521ceaa9bd4cdfed005ec9f195 = $(`&lt;div id=&quot;html_ca6e87521ceaa9bd4cdfed005ec9f195&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_511d91385003b1187aff57b9e8ba48f2.setContent(html_ca6e87521ceaa9bd4cdfed005ec9f195);
#
#
#
#         marker_d480f8b173767a14fe999d99d783f869.bindPopup(popup_511d91385003b1187aff57b9e8ba48f2)
#         ;
#
#
#
#
#             var marker_ffc643be3ae94531dd6b03d5cba16267 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2c177aa9109bdbba540735d671f64fb);
#
#
#         var popup_e700e3f5f5cc3201e74307eaea187636 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c659e27952d6117c5f718e29295ec5c = $(`&lt;div id=&quot;html_4c659e27952d6117c5f718e29295ec5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e700e3f5f5cc3201e74307eaea187636.setContent(html_4c659e27952d6117c5f718e29295ec5c);
#
#
#
#         marker_ffc643be3ae94531dd6b03d5cba16267.bindPopup(popup_e700e3f5f5cc3201e74307eaea187636)
#         ;
#
#
#
#
#             var marker_d1f71901186b807f0da74a1f75605518 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b2c177aa9109bdbba540735d671f64fb);
#
#
#         var popup_1dcc3a70fbcf5877490cdcbd26154390 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8206eb7567dd559204f25b81bf481106 = $(`&lt;div id=&quot;html_8206eb7567dd559204f25b81bf481106&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1dcc3a70fbcf5877490cdcbd26154390.setContent(html_8206eb7567dd559204f25b81bf481106);
#
#
#
#         marker_
