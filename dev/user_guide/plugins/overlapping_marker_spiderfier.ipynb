# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac9c87d2388ced9fa78b717e1e24a9e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac9c87d2388ced9fa78b717e1e24a9e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac9c87d2388ced9fa78b717e1e24a9e0 = L.map(
#                 &quot;map_ac9c87d2388ced9fa78b717e1e24a9e0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e2bf5646d70f1a758c82a70de502cd5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e2bf5646d70f1a758c82a70de502cd5.addTo(map_ac9c87d2388ced9fa78b717e1e24a9e0);
#
#
#             var marker_7ccfa3463560d8e827fd792f99f1e3b9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ac9c87d2388ced9fa78b717e1e24a9e0);
#
#
#         var popup_2251f8ff481dbc28ceb1cfc400e7b2b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db8a8373262f7461345f6dc25ecb166b = $(`&lt;div id=&quot;html_db8a8373262f7461345f6dc25ecb166b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2251f8ff481dbc28ceb1cfc400e7b2b5.setContent(html_db8a8373262f7461345f6dc25ecb166b);
#
#
#
#         marker_7ccfa3463560d8e827fd792f99f1e3b9.bindPopup(popup_2251f8ff481dbc28ceb1cfc400e7b2b5)
#         ;
#
#
#
#
#             var marker_53d30e8255fc7a6d680fbb7087becb65 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ac9c87d2388ced9fa78b717e1e24a9e0);
#
#
#         var popup_2163ba6fc9d1b8a7ee504c3b92986e4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_500ad2e45da5275f9da37e1bc954fe16 = $(`&lt;div id=&quot;html_500ad2e45da5275f9da37e1bc954fe16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2163ba6fc9d1b8a7ee504c3b92986e4d.setContent(html_500ad2e45da5275f9da37e1bc954fe16);
#
#
#
#         marker_53d30e8255fc7a6d680fbb7087becb65.bindPopup(popup_2163ba6fc9d1b8a7ee504c3b92986e4d)
#         ;
#
#
#
#
#             var marker_a0525c3ad8dbfbae8c41b2c43f53aec7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ac9c87d2388ced9fa78b717e1e24a9e0);
#
#
#         var popup_96fb9c4e0efb3ecf10456c90a3bf5531 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee15bb96aa1f06e1fa0c6fbc7825a462 = $(`&lt;div id=&quot;html_ee15bb96aa1f06e1fa0c6fbc7825a462&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_96fb9c4e0efb3ecf10456c90a3bf5531.setContent(html_ee15bb96aa1f06e1fa0c6fbc7825a462);
#
#
#
#         marker_a0525c3ad8dbfbae8c41b2c43f53aec7.bindPopup(popup_96fb9c4e0efb3ecf10456c90a3bf5531)
#         ;
#
#
#
#
#             var marker_a07f9da085b319293954440e794f3194 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ac9c87d2388ced9fa78b717e1e24a9e0);
#
#
#         var popup_1631311467740e7accc0b7f656d4efac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ab8b747b7c11ec2f6ce70bb8ab79bc4 = $(`&lt;div id=&quot;html_3ab8b747b7c11ec2f6ce70bb8ab79bc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1631311467740e7accc0b7f656d4efac.setContent(html_3ab8b747b7c11ec2f6ce70bb8ab79bc4);
#
#
#
#         marker_a07f9da085b319293954440e794f3194.bindPopup(popup_1631311467740e7accc0b7f656d4efac)
#         ;
#
#
#
#
#             var marker_4f3c8a59a0a1bf0d8d02f186ba0c36b8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ac9c87d2388ced9fa78b717e1e24a9e0);
#
#
#         var popup_0801a56e65261dbd790af88dfb802468 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f19ba84584e6258056a6adde13bc116b = $(`&lt;div id=&quot;html_f19ba84584e6258056a6adde13bc116b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0801a56e65261dbd790af88dfb802468.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_310e4093d5ba608719f01562de777d85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_310e4093d5ba608719f01562de777d85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_310e4093d5ba608719f01562de777d85 = L.map(
#                 &quot;map_310e4093d5ba608719f01562de777d85&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31fedaee0407e891370e58f315e6550a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_31fedaee0407e891370e58f315e6550a.addTo(map_310e4093d5ba608719f01562de777d85);
#
#
#             var feature_group_e66954804bbf1db8eff256306c43ee1e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5f5ef846b7b6a70ce86691860fa4c28c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e66954804bbf1db8eff256306c43ee1e);
#
#
#         var popup_84e2bba8ef9f2e10a7cc4db1157ffbb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_044f7f06166043b73f1ff211086a05b3 = $(`&lt;div id=&quot;html_044f7f06166043b73f1ff211086a05b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_84e2bba8ef9f2e10a7cc4db1157ffbb8.setContent(html_044f7f06166043b73f1ff211086a05b3);
#
#
#
#         marker_5f5ef846b7b6a70ce86691860fa4c28c.bindPopup(popup_84e2bba8ef9f2e10a7cc4db1157ffbb8)
#         ;
#
#
#
#
#             var marker_51a3e94320670e46800e1c8cc3ece85e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e66954804bbf1db8eff256306c43ee1e);
#
#
#         var popup_c621128b06b204fc706bc3acf6d50f17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e2ecbe2dbd586d4912b4a2db99951b6 = $(`&lt;div id=&quot;html_2e2ecbe2dbd586d4912b4a2db99951b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c621128b06b204fc706bc3acf6d50f17.setContent(html_2e2ecbe2dbd586d4912b4a2db99951b6);
#
#
#
#         marker_51a3e94320670e46800e1c8cc3ece85e.bindPopup(popup_c621128b06b204fc706bc3acf6d50f17)
#         ;
#
#
#
#
#             var marker_038d216f3085fd15b5aff7d56c8767a3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e66954804bbf1db8eff256306c43ee1e);
#
#
#         var popup_21761caf8f2b6776ec1cfa085753b98b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92eb7d694e3bdac07f136953aa099c9b = $(`&lt;div id=&quot;html_92eb7d694e3bdac07f136953aa099c9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_21761caf8f2b6776ec1cfa085753b98b.setContent(html_92eb7d694e3bdac07f136953aa099c9b);
#
#
#
#         marker_038d216f3085fd15b5aff7d56c8767a3.bindPopup(popup_21761caf8f2b6776ec1cfa085753b98b)
#         ;
#
#
#
#
#             var marker_74be5c22915778aba845c171b3fef5a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e66954804bbf1db8eff256306c43ee1e);
#
#
#         var popup_e591bb00a8c91e82680932f351f28724 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_864ecb492df34faef79527c37f68e4f1 = $(`&lt;div id=&quot;html_864ecb492df34faef79527c37f68e4f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e591bb00a8c91e82680932f351f28724.setContent(html_864ecb492df34faef79527c37f68e4f1);
#
#
#
#         marker_74be5c22915778aba845c171b3fef5a5.bindPopup(popup_e591bb00a8c91e82680932f351f28724)
#         ;
#
#
#
#
#             var marker_4deda6a7ccaf3f9d1c0324b167a5f070 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e66954804bbf1db8eff256306c43ee1e);
#
#
#         var popup_7aaad057ed205c5d94ebaf018f7cc128 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20c5da2e975bb18075fc85f6ba38905e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20c5da2e975bb18075fc85f6ba38905e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20c5da2e975bb18075fc85f6ba38905e = L.map(
#                 &quot;map_20c5da2e975bb18075fc85f6ba38905e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3eef66ba5cdeb5f3899676dab54ad02 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b3eef66ba5cdeb5f3899676dab54ad02.addTo(map_20c5da2e975bb18075fc85f6ba38905e);
#
#
#             var feature_group_15f2c6d29385612724602599c013a27f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_15f2c6d29385612724602599c013a27f.addTo(map_20c5da2e975bb18075fc85f6ba38905e);
#
#
#             var feature_group_sub_group_1416a2ac983058a37eb2f8f01533ea4f = L.featureGroup.subGroup(
#                 feature_group_15f2c6d29385612724602599c013a27f
#             );
#
#
#             var marker_f938ff5d2af03e65a44aa8a50f171839 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1416a2ac983058a37eb2f8f01533ea4f);
#
#
#         var popup_1dea1af412f5227d1bec7ba8485cad8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0ba7d8c411ecacae138af0270085d50 = $(`&lt;div id=&quot;html_a0ba7d8c411ecacae138af0270085d50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1dea1af412f5227d1bec7ba8485cad8b.setContent(html_a0ba7d8c411ecacae138af0270085d50);
#
#
#
#         marker_f938ff5d2af03e65a44aa8a50f171839.bindPopup(popup_1dea1af412f5227d1bec7ba8485cad8b)
#         ;
#
#
#
#
#             var marker_398d5fe522164d9497248dd2de86539e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1416a2ac983058a37eb2f8f01533ea4f);
#
#
#         var popup_9ea77d0a691c0e15d8ac4993853aa3b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0e036ae26ca9215d922917c438fde5c = $(`&lt;div id=&quot;html_d0e036ae26ca9215d922917c438fde5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9ea77d0a691c0e15d8ac4993853aa3b6.setContent(html_d0e036ae26ca9215d922917c438fde5c);
#
#
#
#         marker_398d5fe522164d9497248dd2de86539e.bindPopup(popup_9ea77d0a691c0e15d8ac4993853aa3b6)
#         ;
#
#
#
#
#             var marker_46d8d0b52522c0af1966dabe7978cd18 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1416a2ac983058a37eb2f8f01533ea4f);
#
#
#         var popup_72a0a0eece5672f77e9909da78ba495f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1751504d0532a8f7380a7b1cdaa5a982 = $(`&lt;div id=&quot;html_1751504d0532a8f7380a7b1cdaa5a982&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_72a0a0eece5672f77e9909da78ba495f.setContent(html_1751504d0532a8f7380a7b1cdaa5a982);
#
#
#
#         marker_46d8d0b52522c0af1966dabe7978cd18.bindPopup(popup_72a0a0eece5672f77e9909da78ba495f)
#         ;
#
#
#
#
#             var marker_7bac79b3bc01f6d588273d957e05f423 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1416a2ac983058a37eb2f8f01533ea4f);
#
#
#         var popup_80b904d03907cce42db894bc64109417 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52ff37745e5f5ed8232beef65ec4fb55 = $(`&lt;div id=&quot;html_52ff37745e5f5ed8232beef65ec4fb55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_80b904d03907cce42db894bc64109417.setContent(html_52ff37745e5f5ed8232beef65ec4fb55);
#
#
#
#         marker_
