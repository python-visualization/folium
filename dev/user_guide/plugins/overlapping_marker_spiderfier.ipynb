# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e27b3f5d82a2fc7aacf1e2a6e079154 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e27b3f5d82a2fc7aacf1e2a6e079154&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e27b3f5d82a2fc7aacf1e2a6e079154 = L.map(
#                 &quot;map_6e27b3f5d82a2fc7aacf1e2a6e079154&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_06d8f585c1e4e0afd56a7b8e57216233 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_06d8f585c1e4e0afd56a7b8e57216233.addTo(map_6e27b3f5d82a2fc7aacf1e2a6e079154);
#
#
#             var marker_db529f8f0df7aef56ef48df79de3f13c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6e27b3f5d82a2fc7aacf1e2a6e079154);
#
#
#         var popup_6c14c8ad80fa82a37a00b9bc973baf07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54ac777cf2b8abd3bda8ad37c4857882 = $(`&lt;div id=&quot;html_54ac777cf2b8abd3bda8ad37c4857882&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6c14c8ad80fa82a37a00b9bc973baf07.setContent(html_54ac777cf2b8abd3bda8ad37c4857882);
#
#
#
#         marker_db529f8f0df7aef56ef48df79de3f13c.bindPopup(popup_6c14c8ad80fa82a37a00b9bc973baf07)
#         ;
#
#
#
#
#             var marker_bfe0e86857a7e5d0fc79d1a18b3e6d6a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6e27b3f5d82a2fc7aacf1e2a6e079154);
#
#
#         var popup_e934bc1dcab57f5b16e30b6d00852264 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51cb22a8e6af8d24869e2d3bd0f30944 = $(`&lt;div id=&quot;html_51cb22a8e6af8d24869e2d3bd0f30944&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e934bc1dcab57f5b16e30b6d00852264.setContent(html_51cb22a8e6af8d24869e2d3bd0f30944);
#
#
#
#         marker_bfe0e86857a7e5d0fc79d1a18b3e6d6a.bindPopup(popup_e934bc1dcab57f5b16e30b6d00852264)
#         ;
#
#
#
#
#             var marker_8adb84bf8014eb740fc2c28e9c50a0f8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6e27b3f5d82a2fc7aacf1e2a6e079154);
#
#
#         var popup_1ad3d55bd2b06ac120dc16b113a1a0a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be27b7a806e2e3599d7dcebeef49efc2 = $(`&lt;div id=&quot;html_be27b7a806e2e3599d7dcebeef49efc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1ad3d55bd2b06ac120dc16b113a1a0a4.setContent(html_be27b7a806e2e3599d7dcebeef49efc2);
#
#
#
#         marker_8adb84bf8014eb740fc2c28e9c50a0f8.bindPopup(popup_1ad3d55bd2b06ac120dc16b113a1a0a4)
#         ;
#
#
#
#
#             var marker_21e8b9606d9adfa7d78029ea7dad230e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6e27b3f5d82a2fc7aacf1e2a6e079154);
#
#
#         var popup_ee68f4079c8ec1ee705582c441a47773 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a02a63489b71d4608b8eed22fbcea7f4 = $(`&lt;div id=&quot;html_a02a63489b71d4608b8eed22fbcea7f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ee68f4079c8ec1ee705582c441a47773.setContent(html_a02a63489b71d4608b8eed22fbcea7f4);
#
#
#
#         marker_21e8b9606d9adfa7d78029ea7dad230e.bindPopup(popup_ee68f4079c8ec1ee705582c441a47773)
#         ;
#
#
#
#
#             var marker_c6369164363abe2fa5127b5430670789 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6e27b3f5d82a2fc7aacf1e2a6e079154);
#
#
#         var popup_df70af9f8c8bed4e3389ecb27e88491a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36aae80a3e097a179a842d1e346ffb6f = $(`&lt;div id=&quot;html_36aae80a3e097a179a842d1e346ffb6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_df70af9f8c8bed4e3389ecb27e88491a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_318b7dfca8572502cbbb2b15ee3aad04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_318b7dfca8572502cbbb2b15ee3aad04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_318b7dfca8572502cbbb2b15ee3aad04 = L.map(
#                 &quot;map_318b7dfca8572502cbbb2b15ee3aad04&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db272353e1742daaec48a0c665b4c877 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db272353e1742daaec48a0c665b4c877.addTo(map_318b7dfca8572502cbbb2b15ee3aad04);
#
#
#             var feature_group_788a4f8619352abccdb23589914235ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f846ffd3e445d1254e57a38ebf557ab0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_788a4f8619352abccdb23589914235ee);
#
#
#         var popup_f87815360cbe3de2986d18adcad23b64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36ec3c403ea33da0b44fc991a97857f5 = $(`&lt;div id=&quot;html_36ec3c403ea33da0b44fc991a97857f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f87815360cbe3de2986d18adcad23b64.setContent(html_36ec3c403ea33da0b44fc991a97857f5);
#
#
#
#         marker_f846ffd3e445d1254e57a38ebf557ab0.bindPopup(popup_f87815360cbe3de2986d18adcad23b64)
#         ;
#
#
#
#
#             var marker_cdfa85b4c497af27fd9a094225aed949 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_788a4f8619352abccdb23589914235ee);
#
#
#         var popup_a91c851000aad2805d0d2c42a61a5037 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f7e17c249cfd2064fec0a99f01521ea = $(`&lt;div id=&quot;html_9f7e17c249cfd2064fec0a99f01521ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a91c851000aad2805d0d2c42a61a5037.setContent(html_9f7e17c249cfd2064fec0a99f01521ea);
#
#
#
#         marker_cdfa85b4c497af27fd9a094225aed949.bindPopup(popup_a91c851000aad2805d0d2c42a61a5037)
#         ;
#
#
#
#
#             var marker_16df5639ae18817a8cbb6cd61ff233ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_788a4f8619352abccdb23589914235ee);
#
#
#         var popup_41b345973ee350e7b28cbb8b553d5f16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf872b707bfecf953a1fe59ebba1a1f7 = $(`&lt;div id=&quot;html_cf872b707bfecf953a1fe59ebba1a1f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_41b345973ee350e7b28cbb8b553d5f16.setContent(html_cf872b707bfecf953a1fe59ebba1a1f7);
#
#
#
#         marker_16df5639ae18817a8cbb6cd61ff233ae.bindPopup(popup_41b345973ee350e7b28cbb8b553d5f16)
#         ;
#
#
#
#
#             var marker_1b63d33eae27824332c261acdc744aad = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_788a4f8619352abccdb23589914235ee);
#
#
#         var popup_4a2054a59fc476e6237ab6ccd0199e23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_747ae039bb878ad311a3880caed43458 = $(`&lt;div id=&quot;html_747ae039bb878ad311a3880caed43458&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4a2054a59fc476e6237ab6ccd0199e23.setContent(html_747ae039bb878ad311a3880caed43458);
#
#
#
#         marker_1b63d33eae27824332c261acdc744aad.bindPopup(popup_4a2054a59fc476e6237ab6ccd0199e23)
#         ;
#
#
#
#
#             var marker_595fd3df9f7e63c7e0d7d59167e53d8f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_788a4f8619352abccdb23589914235ee);
#
#
#         var popup_c3bc7145c8dcb07130d33e4768a6364e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_821f9db109f2d7aca76e5ecd0303a1de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_821f9db109f2d7aca76e5ecd0303a1de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_821f9db109f2d7aca76e5ecd0303a1de = L.map(
#                 &quot;map_821f9db109f2d7aca76e5ecd0303a1de&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3c8295c06d9ae1333732c3b4bc819dc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3c8295c06d9ae1333732c3b4bc819dc.addTo(map_821f9db109f2d7aca76e5ecd0303a1de);
#
#
#             var feature_group_32134c42dcd5ba5d9e28585950d935cf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_32134c42dcd5ba5d9e28585950d935cf.addTo(map_821f9db109f2d7aca76e5ecd0303a1de);
#
#
#             var feature_group_sub_group_0314c6115c6ac44f0e710ab9328e83a3 = L.featureGroup.subGroup(
#                 feature_group_32134c42dcd5ba5d9e28585950d935cf
#             );
#
#
#             var marker_15b3f6c09b08f217214d43d603f4d9e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0314c6115c6ac44f0e710ab9328e83a3);
#
#
#         var popup_d1eb1a48029b863a85e3c1178a58cdf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8329e7ddc9d9da8052dfa6ae5a2f21f6 = $(`&lt;div id=&quot;html_8329e7ddc9d9da8052dfa6ae5a2f21f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d1eb1a48029b863a85e3c1178a58cdf2.setContent(html_8329e7ddc9d9da8052dfa6ae5a2f21f6);
#
#
#
#         marker_15b3f6c09b08f217214d43d603f4d9e1.bindPopup(popup_d1eb1a48029b863a85e3c1178a58cdf2)
#         ;
#
#
#
#
#             var marker_18c94b3201ef3a8ddc941f316b61ee17 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0314c6115c6ac44f0e710ab9328e83a3);
#
#
#         var popup_ef1bbf78fdcb401eaf16108559d91c36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2732d35638e592ed4250a9aae1d880c = $(`&lt;div id=&quot;html_d2732d35638e592ed4250a9aae1d880c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ef1bbf78fdcb401eaf16108559d91c36.setContent(html_d2732d35638e592ed4250a9aae1d880c);
#
#
#
#         marker_18c94b3201ef3a8ddc941f316b61ee17.bindPopup(popup_ef1bbf78fdcb401eaf16108559d91c36)
#         ;
#
#
#
#
#             var marker_7527a1a13e220ddeece3070f50edd886 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0314c6115c6ac44f0e710ab9328e83a3);
#
#
#         var popup_bcddacc5c7091d4546b16131abc3210e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71ebd81cb3df975cadd39bec54464951 = $(`&lt;div id=&quot;html_71ebd81cb3df975cadd39bec54464951&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bcddacc5c7091d4546b16131abc3210e.setContent(html_71ebd81cb3df975cadd39bec54464951);
#
#
#
#         marker_7527a1a13e220ddeece3070f50edd886.bindPopup(popup_bcddacc5c7091d4546b16131abc3210e)
#         ;
#
#
#
#
#             var marker_53fee127cf18225157be92152e6379ef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0314c6115c6ac44f0e710ab9328e83a3);
#
#
#         var popup_0438c758cb9d233077337b3910b171cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a770e46c8f5616ddad964bdc0cc4e81a = $(`&lt;div id=&quot;html_a770e46c8f5616ddad964bdc0cc4e81a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0438c758cb9d233077337b3910b171cd.setContent(html_a770e46c8f5616ddad964bdc0cc4e81a);
#
#
#
#         marker_
