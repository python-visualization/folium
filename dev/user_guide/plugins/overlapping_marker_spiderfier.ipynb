# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83ed9281e6e8573cc5ed2478533ff5c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83ed9281e6e8573cc5ed2478533ff5c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83ed9281e6e8573cc5ed2478533ff5c1 = L.map(
#                 &quot;map_83ed9281e6e8573cc5ed2478533ff5c1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_649fbc5a8535efa5a6450779c4921457 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_649fbc5a8535efa5a6450779c4921457.addTo(map_83ed9281e6e8573cc5ed2478533ff5c1);
#
#
#             var marker_3e45bba4675f91584eadcde862769b47 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_83ed9281e6e8573cc5ed2478533ff5c1);
#
#
#         var popup_cf5906d760d198ad9a79c62289a7843f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1310856b98fa0c5cc2412264e9fc632a = $(`&lt;div id=&quot;html_1310856b98fa0c5cc2412264e9fc632a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cf5906d760d198ad9a79c62289a7843f.setContent(html_1310856b98fa0c5cc2412264e9fc632a);
#
#
#
#         marker_3e45bba4675f91584eadcde862769b47.bindPopup(popup_cf5906d760d198ad9a79c62289a7843f)
#         ;
#
#
#
#
#             var marker_6a59358bf9fcfc72c7a689bbe0a5a501 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_83ed9281e6e8573cc5ed2478533ff5c1);
#
#
#         var popup_b7385992805d261b48b8abc28d87cdef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_426cf63e0f2921b266ed41481919111a = $(`&lt;div id=&quot;html_426cf63e0f2921b266ed41481919111a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b7385992805d261b48b8abc28d87cdef.setContent(html_426cf63e0f2921b266ed41481919111a);
#
#
#
#         marker_6a59358bf9fcfc72c7a689bbe0a5a501.bindPopup(popup_b7385992805d261b48b8abc28d87cdef)
#         ;
#
#
#
#
#             var marker_867b56679ffc23502f682abcab5d0b04 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_83ed9281e6e8573cc5ed2478533ff5c1);
#
#
#         var popup_df4f3194924892b04a880552e7e5d98e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_649a68b82c1a47c78ebb15f9930ccb21 = $(`&lt;div id=&quot;html_649a68b82c1a47c78ebb15f9930ccb21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_df4f3194924892b04a880552e7e5d98e.setContent(html_649a68b82c1a47c78ebb15f9930ccb21);
#
#
#
#         marker_867b56679ffc23502f682abcab5d0b04.bindPopup(popup_df4f3194924892b04a880552e7e5d98e)
#         ;
#
#
#
#
#             var marker_8e629fb61869a87f8e874d0f4270cdb3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_83ed9281e6e8573cc5ed2478533ff5c1);
#
#
#         var popup_37a6f35da9c4c859b01fbc60ffc6fc38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e0babe4f3fe8f7f36d603873a833e4a = $(`&lt;div id=&quot;html_8e0babe4f3fe8f7f36d603873a833e4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_37a6f35da9c4c859b01fbc60ffc6fc38.setContent(html_8e0babe4f3fe8f7f36d603873a833e4a);
#
#
#
#         marker_8e629fb61869a87f8e874d0f4270cdb3.bindPopup(popup_37a6f35da9c4c859b01fbc60ffc6fc38)
#         ;
#
#
#
#
#             var marker_c66d1a3daa89a6a42bf487b7a808497f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_83ed9281e6e8573cc5ed2478533ff5c1);
#
#
#         var popup_993727ede7705d4ee517674244901120 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc75ceae3507c772f16184ee0be173fa = $(`&lt;div id=&quot;html_fc75ceae3507c772f16184ee0be173fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_993727ede7705d4ee517674244901120.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4876840b6a1cc88ed18db0812d38442d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4876840b6a1cc88ed18db0812d38442d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4876840b6a1cc88ed18db0812d38442d = L.map(
#                 &quot;map_4876840b6a1cc88ed18db0812d38442d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9577a5630dfede01d48fed04f559fd4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9577a5630dfede01d48fed04f559fd4.addTo(map_4876840b6a1cc88ed18db0812d38442d);
#
#
#             var feature_group_ce1d03956e5d4417cf2a3e5950e791db = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c2a212bd19acf243c4d39e143639e669 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ce1d03956e5d4417cf2a3e5950e791db);
#
#
#         var popup_da59d0871938f6fa01b5d0216235192b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c970f647ab988bb809d45952339420f4 = $(`&lt;div id=&quot;html_c970f647ab988bb809d45952339420f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_da59d0871938f6fa01b5d0216235192b.setContent(html_c970f647ab988bb809d45952339420f4);
#
#
#
#         marker_c2a212bd19acf243c4d39e143639e669.bindPopup(popup_da59d0871938f6fa01b5d0216235192b)
#         ;
#
#
#
#
#             var marker_ff29e75bb1d1306f5ab2feb10d758c8b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ce1d03956e5d4417cf2a3e5950e791db);
#
#
#         var popup_922e91382d30b3bd31abb3e26c52d57f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_704fdff53b8f5790dad9a013eec6a06c = $(`&lt;div id=&quot;html_704fdff53b8f5790dad9a013eec6a06c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_922e91382d30b3bd31abb3e26c52d57f.setContent(html_704fdff53b8f5790dad9a013eec6a06c);
#
#
#
#         marker_ff29e75bb1d1306f5ab2feb10d758c8b.bindPopup(popup_922e91382d30b3bd31abb3e26c52d57f)
#         ;
#
#
#
#
#             var marker_ff3ed51a5a26666f2fc5f6814b06f49f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ce1d03956e5d4417cf2a3e5950e791db);
#
#
#         var popup_773b83108c34034974449808e563fc3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a96cee88100a1920c4a5e31edf97912 = $(`&lt;div id=&quot;html_9a96cee88100a1920c4a5e31edf97912&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_773b83108c34034974449808e563fc3c.setContent(html_9a96cee88100a1920c4a5e31edf97912);
#
#
#
#         marker_ff3ed51a5a26666f2fc5f6814b06f49f.bindPopup(popup_773b83108c34034974449808e563fc3c)
#         ;
#
#
#
#
#             var marker_71ae4788f9e1d0fb3678ed3ee2642115 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ce1d03956e5d4417cf2a3e5950e791db);
#
#
#         var popup_ce8290ea52470031aa4f51b76b739552 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4324dd6fa5b04fea1fd7e372567d5e99 = $(`&lt;div id=&quot;html_4324dd6fa5b04fea1fd7e372567d5e99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ce8290ea52470031aa4f51b76b739552.setContent(html_4324dd6fa5b04fea1fd7e372567d5e99);
#
#
#
#         marker_71ae4788f9e1d0fb3678ed3ee2642115.bindPopup(popup_ce8290ea52470031aa4f51b76b739552)
#         ;
#
#
#
#
#             var marker_123fdcd9cc86cfc0e966cb6e7f2ac3d3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ce1d03956e5d4417cf2a3e5950e791db);
#
#
#         var popup_753885866d09f6f14aec2a863eb3f734 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a3adde2b22bb9ee4bb2188131a98ab0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a3adde2b22bb9ee4bb2188131a98ab0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a3adde2b22bb9ee4bb2188131a98ab0 = L.map(
#                 &quot;map_7a3adde2b22bb9ee4bb2188131a98ab0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_843f5c3a2b0913139a3248c6369abc06 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_843f5c3a2b0913139a3248c6369abc06.addTo(map_7a3adde2b22bb9ee4bb2188131a98ab0);
#
#
#             var feature_group_e85208b435111bb45b10f4a9808ca2a0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e85208b435111bb45b10f4a9808ca2a0.addTo(map_7a3adde2b22bb9ee4bb2188131a98ab0);
#
#
#             var feature_group_sub_group_243c2c58f47a0dbfd70880d3dc87b331 = L.featureGroup.subGroup(
#                 feature_group_e85208b435111bb45b10f4a9808ca2a0
#             );
#
#
#             var marker_555367dc7289aa71c7cf7eaa4cb7310e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_243c2c58f47a0dbfd70880d3dc87b331);
#
#
#         var popup_887385b6b3a9154ce7336c016a23628d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_548e44db8895a93a3e51d4e3c87db39a = $(`&lt;div id=&quot;html_548e44db8895a93a3e51d4e3c87db39a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_887385b6b3a9154ce7336c016a23628d.setContent(html_548e44db8895a93a3e51d4e3c87db39a);
#
#
#
#         marker_555367dc7289aa71c7cf7eaa4cb7310e.bindPopup(popup_887385b6b3a9154ce7336c016a23628d)
#         ;
#
#
#
#
#             var marker_a9d0ec07098ffdb7b616f37d97af578b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_243c2c58f47a0dbfd70880d3dc87b331);
#
#
#         var popup_94690204bc794f890cb8765d104c7d3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dac5a015c08eeb6ff1eda089ec01e47 = $(`&lt;div id=&quot;html_5dac5a015c08eeb6ff1eda089ec01e47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_94690204bc794f890cb8765d104c7d3a.setContent(html_5dac5a015c08eeb6ff1eda089ec01e47);
#
#
#
#         marker_a9d0ec07098ffdb7b616f37d97af578b.bindPopup(popup_94690204bc794f890cb8765d104c7d3a)
#         ;
#
#
#
#
#             var marker_79209dc9ab6180d7002f4015d3e01a15 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_243c2c58f47a0dbfd70880d3dc87b331);
#
#
#         var popup_fd0160a37f00bc5475667fc4e8f39610 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d81159ae26750e88c52c757a4ef90c85 = $(`&lt;div id=&quot;html_d81159ae26750e88c52c757a4ef90c85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fd0160a37f00bc5475667fc4e8f39610.setContent(html_d81159ae26750e88c52c757a4ef90c85);
#
#
#
#         marker_79209dc9ab6180d7002f4015d3e01a15.bindPopup(popup_fd0160a37f00bc5475667fc4e8f39610)
#         ;
#
#
#
#
#             var marker_8a3ef81cf63340d8582d3eb679f317c2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_243c2c58f47a0dbfd70880d3dc87b331);
#
#
#         var popup_4279170d3238216d59a823b1324f3f4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e129d972b24a3ce5509c969d16522537 = $(`&lt;div id=&quot;html_e129d972b24a3ce5509c969d16522537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4279170d3238216d59a823b1324f3f4f.setContent(html_e129d972b24a3ce5509c969d16522537);
#
#
#
#         marker_
