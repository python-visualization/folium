# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fe008416273ea00c1418a4d20087082 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fe008416273ea00c1418a4d20087082&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fe008416273ea00c1418a4d20087082 = L.map(
#                 &quot;map_6fe008416273ea00c1418a4d20087082&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38ce750d3abd8ade3a0072b694daf85c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38ce750d3abd8ade3a0072b694daf85c.addTo(map_6fe008416273ea00c1418a4d20087082);
#
#
#             var marker_37e8f57a9873edd76b50d1190b7f2323 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6fe008416273ea00c1418a4d20087082);
#
#
#         var popup_96ae0b7ab4e75713a323fe59a9bdd380 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d614f1cb39a8986a3037d7652f045703 = $(`&lt;div id=&quot;html_d614f1cb39a8986a3037d7652f045703&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_96ae0b7ab4e75713a323fe59a9bdd380.setContent(html_d614f1cb39a8986a3037d7652f045703);
#
#
#
#         marker_37e8f57a9873edd76b50d1190b7f2323.bindPopup(popup_96ae0b7ab4e75713a323fe59a9bdd380)
#         ;
#
#
#
#
#             var marker_cf084ec403e5f3cd010bc301983e0303 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6fe008416273ea00c1418a4d20087082);
#
#
#         var popup_c8b7d8ac5591aa63bcef7ecf9f6493e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d3fb9a9961f9963cf1d8467c09d4a6c = $(`&lt;div id=&quot;html_7d3fb9a9961f9963cf1d8467c09d4a6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c8b7d8ac5591aa63bcef7ecf9f6493e1.setContent(html_7d3fb9a9961f9963cf1d8467c09d4a6c);
#
#
#
#         marker_cf084ec403e5f3cd010bc301983e0303.bindPopup(popup_c8b7d8ac5591aa63bcef7ecf9f6493e1)
#         ;
#
#
#
#
#             var marker_62da6b7925d9d0db36c1300f68d986d3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6fe008416273ea00c1418a4d20087082);
#
#
#         var popup_6b9070091e4b5d10cbe6b4f9804822f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8df697481659617734c96bd58d258239 = $(`&lt;div id=&quot;html_8df697481659617734c96bd58d258239&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6b9070091e4b5d10cbe6b4f9804822f6.setContent(html_8df697481659617734c96bd58d258239);
#
#
#
#         marker_62da6b7925d9d0db36c1300f68d986d3.bindPopup(popup_6b9070091e4b5d10cbe6b4f9804822f6)
#         ;
#
#
#
#
#             var marker_cf9a1481d0b5860553f01fd829d545fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6fe008416273ea00c1418a4d20087082);
#
#
#         var popup_77a8d78830ec7954e56f02474cfb608b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ceb306b8e6225a48e7a36b47ebe9dd1 = $(`&lt;div id=&quot;html_9ceb306b8e6225a48e7a36b47ebe9dd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_77a8d78830ec7954e56f02474cfb608b.setContent(html_9ceb306b8e6225a48e7a36b47ebe9dd1);
#
#
#
#         marker_cf9a1481d0b5860553f01fd829d545fd.bindPopup(popup_77a8d78830ec7954e56f02474cfb608b)
#         ;
#
#
#
#
#             var marker_397b19b8827fb10ad476d006df0bb4d1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6fe008416273ea00c1418a4d20087082);
#
#
#         var popup_ec9733269930413eec25757acc9b38ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3247ede248bd71af2ebd55e90e2391d6 = $(`&lt;div id=&quot;html_3247ede248bd71af2ebd55e90e2391d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ec9733269930413eec25757acc9b38ce.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e2fed67ca71cc087922fd6e711e8b96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e2fed67ca71cc087922fd6e711e8b96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e2fed67ca71cc087922fd6e711e8b96 = L.map(
#                 &quot;map_1e2fed67ca71cc087922fd6e711e8b96&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_90788fe8ebed7471f688659fa60cac1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_90788fe8ebed7471f688659fa60cac1a.addTo(map_1e2fed67ca71cc087922fd6e711e8b96);
#
#
#             var feature_group_518e976d21a325f54a7e97c94013c9de = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c882b716228714e4eeb946a5b65608e5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_518e976d21a325f54a7e97c94013c9de);
#
#
#         var popup_4ec15e397a62508a8ab0f2d9190d850a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39df39c7de018814aec462f44c07f59d = $(`&lt;div id=&quot;html_39df39c7de018814aec462f44c07f59d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4ec15e397a62508a8ab0f2d9190d850a.setContent(html_39df39c7de018814aec462f44c07f59d);
#
#
#
#         marker_c882b716228714e4eeb946a5b65608e5.bindPopup(popup_4ec15e397a62508a8ab0f2d9190d850a)
#         ;
#
#
#
#
#             var marker_1cf65f640050bb27c665d272bae2bd51 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_518e976d21a325f54a7e97c94013c9de);
#
#
#         var popup_c32e8cca7ec56f912faa57ab63bbdce5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fefd9b5c34bf3b5700ab9ebc139073e5 = $(`&lt;div id=&quot;html_fefd9b5c34bf3b5700ab9ebc139073e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c32e8cca7ec56f912faa57ab63bbdce5.setContent(html_fefd9b5c34bf3b5700ab9ebc139073e5);
#
#
#
#         marker_1cf65f640050bb27c665d272bae2bd51.bindPopup(popup_c32e8cca7ec56f912faa57ab63bbdce5)
#         ;
#
#
#
#
#             var marker_c00867672b5a7f68800b660b9854bbf0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_518e976d21a325f54a7e97c94013c9de);
#
#
#         var popup_b47f8df8f47537b001cdfbc60356ef33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c81c36e175e483e7bbc852eb91d8ab3 = $(`&lt;div id=&quot;html_7c81c36e175e483e7bbc852eb91d8ab3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b47f8df8f47537b001cdfbc60356ef33.setContent(html_7c81c36e175e483e7bbc852eb91d8ab3);
#
#
#
#         marker_c00867672b5a7f68800b660b9854bbf0.bindPopup(popup_b47f8df8f47537b001cdfbc60356ef33)
#         ;
#
#
#
#
#             var marker_ce74195e5e345fa34a00a41943ab694a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_518e976d21a325f54a7e97c94013c9de);
#
#
#         var popup_ab00a29200015ea5b27be2055a25b645 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c073aeb84e317ffeee4b0b1433d57ccf = $(`&lt;div id=&quot;html_c073aeb84e317ffeee4b0b1433d57ccf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ab00a29200015ea5b27be2055a25b645.setContent(html_c073aeb84e317ffeee4b0b1433d57ccf);
#
#
#
#         marker_ce74195e5e345fa34a00a41943ab694a.bindPopup(popup_ab00a29200015ea5b27be2055a25b645)
#         ;
#
#
#
#
#             var marker_aa6841098625c6b7ed671fdf00cc03d5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_518e976d21a325f54a7e97c94013c9de);
#
#
#         var popup_a6d531c487bc6c315ea1ea3e4a05adb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bcf0369510825324a02b704047f4d8bf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bcf0369510825324a02b704047f4d8bf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bcf0369510825324a02b704047f4d8bf = L.map(
#                 &quot;map_bcf0369510825324a02b704047f4d8bf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_20d78c5b5603655b98b4512362319b62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_20d78c5b5603655b98b4512362319b62.addTo(map_bcf0369510825324a02b704047f4d8bf);
#
#
#             var feature_group_413b1078eaed749967d1c82f664841a4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_413b1078eaed749967d1c82f664841a4.addTo(map_bcf0369510825324a02b704047f4d8bf);
#
#
#             var feature_group_sub_group_749f19f55bf5945ccb5ceeebe5c898e7 = L.featureGroup.subGroup(
#                 feature_group_413b1078eaed749967d1c82f664841a4
#             );
#
#
#             var marker_85ce223f6ce0c91908f574d493c00e33 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_749f19f55bf5945ccb5ceeebe5c898e7);
#
#
#         var popup_4add3c2032e93808107b5e2fb14f1de6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5058864d8609983b0205c957de64c6db = $(`&lt;div id=&quot;html_5058864d8609983b0205c957de64c6db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4add3c2032e93808107b5e2fb14f1de6.setContent(html_5058864d8609983b0205c957de64c6db);
#
#
#
#         marker_85ce223f6ce0c91908f574d493c00e33.bindPopup(popup_4add3c2032e93808107b5e2fb14f1de6)
#         ;
#
#
#
#
#             var marker_b90dfa7a4e8469bb5a88be144be2d750 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_749f19f55bf5945ccb5ceeebe5c898e7);
#
#
#         var popup_7f9e506eac3234c8ff84b917fc246d75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10f88bdf9022ae21adbdb5a7b5ff1239 = $(`&lt;div id=&quot;html_10f88bdf9022ae21adbdb5a7b5ff1239&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7f9e506eac3234c8ff84b917fc246d75.setContent(html_10f88bdf9022ae21adbdb5a7b5ff1239);
#
#
#
#         marker_b90dfa7a4e8469bb5a88be144be2d750.bindPopup(popup_7f9e506eac3234c8ff84b917fc246d75)
#         ;
#
#
#
#
#             var marker_43df8d03fdc3a1a2dd679e0fb13721e0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_749f19f55bf5945ccb5ceeebe5c898e7);
#
#
#         var popup_d145346cc9ba5cadf976b3b53345d25b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce7ef2858da29a97e2227f0c505c1813 = $(`&lt;div id=&quot;html_ce7ef2858da29a97e2227f0c505c1813&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d145346cc9ba5cadf976b3b53345d25b.setContent(html_ce7ef2858da29a97e2227f0c505c1813);
#
#
#
#         marker_43df8d03fdc3a1a2dd679e0fb13721e0.bindPopup(popup_d145346cc9ba5cadf976b3b53345d25b)
#         ;
#
#
#
#
#             var marker_46e63f054d8f209c0c6496f054cd1212 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_749f19f55bf5945ccb5ceeebe5c898e7);
#
#
#         var popup_b6918b7432899e388df61bf329096529 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8923571ce8f12546f7813e23b1228665 = $(`&lt;div id=&quot;html_8923571ce8f12546f7813e23b1228665&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b6918b7432899e388df61bf329096529.setContent(html_8923571ce8f12546f7813e23b1228665);
#
#
#
#         marker_
