# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d826653e3192635f285e477a52070a01 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d826653e3192635f285e477a52070a01&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d826653e3192635f285e477a52070a01 = L.map(
#                 &quot;map_d826653e3192635f285e477a52070a01&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f480d8bb7f7d0651ae2e3dc7a39ae35b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f480d8bb7f7d0651ae2e3dc7a39ae35b.addTo(map_d826653e3192635f285e477a52070a01);
#
#
#             var marker_f3aef5bc62200e5fdad8dcb32572e9b2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d826653e3192635f285e477a52070a01);
#
#
#         var popup_469105f2ef403d50d363bbf878e83d51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9058ae01986a8718f05b0f7e2c2ffc78 = $(`&lt;div id=&quot;html_9058ae01986a8718f05b0f7e2c2ffc78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_469105f2ef403d50d363bbf878e83d51.setContent(html_9058ae01986a8718f05b0f7e2c2ffc78);
#
#
#
#         marker_f3aef5bc62200e5fdad8dcb32572e9b2.bindPopup(popup_469105f2ef403d50d363bbf878e83d51)
#         ;
#
#
#
#
#             var marker_3e4d52c338621b5897f89c4ffdab0fa2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d826653e3192635f285e477a52070a01);
#
#
#         var popup_8045e04f76d58f3cc83c244821d269f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39e9092e1403914700dd0fdbf46ba52e = $(`&lt;div id=&quot;html_39e9092e1403914700dd0fdbf46ba52e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8045e04f76d58f3cc83c244821d269f5.setContent(html_39e9092e1403914700dd0fdbf46ba52e);
#
#
#
#         marker_3e4d52c338621b5897f89c4ffdab0fa2.bindPopup(popup_8045e04f76d58f3cc83c244821d269f5)
#         ;
#
#
#
#
#             var marker_901d8431354398c4e5ce018448e17848 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d826653e3192635f285e477a52070a01);
#
#
#         var popup_ef31b3bc14bfdacb5376a16802dba257 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9abdd5ba3c2b5a1d850928e81203534d = $(`&lt;div id=&quot;html_9abdd5ba3c2b5a1d850928e81203534d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ef31b3bc14bfdacb5376a16802dba257.setContent(html_9abdd5ba3c2b5a1d850928e81203534d);
#
#
#
#         marker_901d8431354398c4e5ce018448e17848.bindPopup(popup_ef31b3bc14bfdacb5376a16802dba257)
#         ;
#
#
#
#
#             var marker_5035cc4cdf2d84b6dc70e5c38062ab08 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d826653e3192635f285e477a52070a01);
#
#
#         var popup_aedcef30f21d6b0093e3feb7c349cbe7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c19d418bc60cc7e6f0f7cc41eb56b4f = $(`&lt;div id=&quot;html_7c19d418bc60cc7e6f0f7cc41eb56b4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_aedcef30f21d6b0093e3feb7c349cbe7.setContent(html_7c19d418bc60cc7e6f0f7cc41eb56b4f);
#
#
#
#         marker_5035cc4cdf2d84b6dc70e5c38062ab08.bindPopup(popup_aedcef30f21d6b0093e3feb7c349cbe7)
#         ;
#
#
#
#
#             var marker_12fc08c4567d5356fc611eb8eebc83f4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d826653e3192635f285e477a52070a01);
#
#
#         var popup_625700a9f428ed2ffc8801e7753f73aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccd003f061f44b9ea13eac1963ca94da = $(`&lt;div id=&quot;html_ccd003f061f44b9ea13eac1963ca94da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_625700a9f428ed2ffc8801e7753f73

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab0d672aaf8c3bce1a0e5d1ab167937f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab0d672aaf8c3bce1a0e5d1ab167937f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab0d672aaf8c3bce1a0e5d1ab167937f = L.map(
#                 &quot;map_ab0d672aaf8c3bce1a0e5d1ab167937f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5ea2a9a9864bac3c2dbaa29dfc2a72d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5ea2a9a9864bac3c2dbaa29dfc2a72d6.addTo(map_ab0d672aaf8c3bce1a0e5d1ab167937f);
#
#
#             var feature_group_6eb3ec8ad4c260ea9688064a0b068567 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c719d037ccc7921d82ac0ba866851a04 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6eb3ec8ad4c260ea9688064a0b068567);
#
#
#         var popup_6c740e1a87b98474998bbf36d6cb7689 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec3c3885d4b09b2428daabf5b4353fa6 = $(`&lt;div id=&quot;html_ec3c3885d4b09b2428daabf5b4353fa6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6c740e1a87b98474998bbf36d6cb7689.setContent(html_ec3c3885d4b09b2428daabf5b4353fa6);
#
#
#
#         marker_c719d037ccc7921d82ac0ba866851a04.bindPopup(popup_6c740e1a87b98474998bbf36d6cb7689)
#         ;
#
#
#
#
#             var marker_5b9f51622e46c00948d97d277dfa370b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6eb3ec8ad4c260ea9688064a0b068567);
#
#
#         var popup_b48068b86ac846c6e04f72521ef478e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62e75cd26cad6685b4f707dc9de7f712 = $(`&lt;div id=&quot;html_62e75cd26cad6685b4f707dc9de7f712&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b48068b86ac846c6e04f72521ef478e2.setContent(html_62e75cd26cad6685b4f707dc9de7f712);
#
#
#
#         marker_5b9f51622e46c00948d97d277dfa370b.bindPopup(popup_b48068b86ac846c6e04f72521ef478e2)
#         ;
#
#
#
#
#             var marker_0e67bb38693f6ab4a4e4fca6e18f8c31 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6eb3ec8ad4c260ea9688064a0b068567);
#
#
#         var popup_c2f24260e706a7b445821401465d200c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74945882619210e9f12f07a469280104 = $(`&lt;div id=&quot;html_74945882619210e9f12f07a469280104&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c2f24260e706a7b445821401465d200c.setContent(html_74945882619210e9f12f07a469280104);
#
#
#
#         marker_0e67bb38693f6ab4a4e4fca6e18f8c31.bindPopup(popup_c2f24260e706a7b445821401465d200c)
#         ;
#
#
#
#
#             var marker_4249546821b0dd8e9808a3ccaef88354 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6eb3ec8ad4c260ea9688064a0b068567);
#
#
#         var popup_32cf8bd713fed8a3ee2b7acd9700f49f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b1d7f4322dafc20ee3d9543f7cde348 = $(`&lt;div id=&quot;html_6b1d7f4322dafc20ee3d9543f7cde348&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_32cf8bd713fed8a3ee2b7acd9700f49f.setContent(html_6b1d7f4322dafc20ee3d9543f7cde348);
#
#
#
#         marker_4249546821b0dd8e9808a3ccaef88354.bindPopup(popup_32cf8bd713fed8a3ee2b7acd9700f49f)
#         ;
#
#
#
#
#             var marker_96d33100d8185e54722095ea45055d61 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6eb3ec8ad4c260ea9688064a0b068567);
#
#
#         var popup_9671aaeff069ae53804e0ac72109cedc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11244895bc990a42273689a25b64942d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11244895bc990a42273689a25b64942d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11244895bc990a42273689a25b64942d = L.map(
#                 &quot;map_11244895bc990a42273689a25b64942d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f700f581d82a2bb54721da27a6d02431 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f700f581d82a2bb54721da27a6d02431.addTo(map_11244895bc990a42273689a25b64942d);
#
#
#             var feature_group_ecf3164459966ee1173350f25e23066f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ecf3164459966ee1173350f25e23066f.addTo(map_11244895bc990a42273689a25b64942d);
#
#
#             var feature_group_sub_group_0d14ea0922d79cb0baf47e0bfac24f55 = L.featureGroup.subGroup(
#                 feature_group_ecf3164459966ee1173350f25e23066f
#             );
#
#
#             var marker_639d81ff3f9361d21fc71164acd69055 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d14ea0922d79cb0baf47e0bfac24f55);
#
#
#         var popup_ad723ee0a957a1fce845725807af5753 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec08517eb5225e75b8a89947cbafd6a9 = $(`&lt;div id=&quot;html_ec08517eb5225e75b8a89947cbafd6a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ad723ee0a957a1fce845725807af5753.setContent(html_ec08517eb5225e75b8a89947cbafd6a9);
#
#
#
#         marker_639d81ff3f9361d21fc71164acd69055.bindPopup(popup_ad723ee0a957a1fce845725807af5753)
#         ;
#
#
#
#
#             var marker_b3dfac9e0a12515038985a2f21a89a73 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d14ea0922d79cb0baf47e0bfac24f55);
#
#
#         var popup_bf829e011b1401641906b488c175c6f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a1904b480da1402ec960656f228f896 = $(`&lt;div id=&quot;html_7a1904b480da1402ec960656f228f896&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bf829e011b1401641906b488c175c6f9.setContent(html_7a1904b480da1402ec960656f228f896);
#
#
#
#         marker_b3dfac9e0a12515038985a2f21a89a73.bindPopup(popup_bf829e011b1401641906b488c175c6f9)
#         ;
#
#
#
#
#             var marker_1afc695de92f51c8510dcf486052aabf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d14ea0922d79cb0baf47e0bfac24f55);
#
#
#         var popup_830bdcdc3e1b9d08cfe4eee8d7dae4cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0718d6df703cedf4e6baf808950525b4 = $(`&lt;div id=&quot;html_0718d6df703cedf4e6baf808950525b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_830bdcdc3e1b9d08cfe4eee8d7dae4cc.setContent(html_0718d6df703cedf4e6baf808950525b4);
#
#
#
#         marker_1afc695de92f51c8510dcf486052aabf.bindPopup(popup_830bdcdc3e1b9d08cfe4eee8d7dae4cc)
#         ;
#
#
#
#
#             var marker_93ca1feee58d35ef44cf2f92d272ce32 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0d14ea0922d79cb0baf47e0bfac24f55);
#
#
#         var popup_06055ee322a94ba90f89f6ae549f8929 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8c8472f7229e181ddc6a6f955b34fe2 = $(`&lt;div id=&quot;html_f8c8472f7229e181ddc6a6f955b34fe2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_06055ee322a94ba90f89f6ae549f8929.setContent(html_f8c8472f7229e181ddc6a6f955b34fe2);
#
#
#
#         mark
