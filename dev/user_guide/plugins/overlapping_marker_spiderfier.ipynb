# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1560a067f1081f7f8503d4173d092c7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1560a067f1081f7f8503d4173d092c7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1560a067f1081f7f8503d4173d092c7e = L.map(
#                 &quot;map_1560a067f1081f7f8503d4173d092c7e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8f90e0180453d9c67bb97fec3b8f920 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8f90e0180453d9c67bb97fec3b8f920.addTo(map_1560a067f1081f7f8503d4173d092c7e);
#
#
#             var marker_59731b5adbc177fb3e03162617f5b5f2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1560a067f1081f7f8503d4173d092c7e);
#
#
#         var popup_54f319324729ca0cc01e8651b9a2a731 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca424eac6c9da97d934cf7c49900b0d1 = $(`&lt;div id=&quot;html_ca424eac6c9da97d934cf7c49900b0d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_54f319324729ca0cc01e8651b9a2a731.setContent(html_ca424eac6c9da97d934cf7c49900b0d1);
#
#
#
#         marker_59731b5adbc177fb3e03162617f5b5f2.bindPopup(popup_54f319324729ca0cc01e8651b9a2a731)
#         ;
#
#
#
#
#             var marker_841a534383f1ecbc5a20209f129e3676 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1560a067f1081f7f8503d4173d092c7e);
#
#
#         var popup_4f21c90eb0169fe4eda42f308d935478 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd923f2c1effc993d7701ad23ca9af0a = $(`&lt;div id=&quot;html_bd923f2c1effc993d7701ad23ca9af0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4f21c90eb0169fe4eda42f308d935478.setContent(html_bd923f2c1effc993d7701ad23ca9af0a);
#
#
#
#         marker_841a534383f1ecbc5a20209f129e3676.bindPopup(popup_4f21c90eb0169fe4eda42f308d935478)
#         ;
#
#
#
#
#             var marker_e4d11eedd6300815e9e0b76a32e70678 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1560a067f1081f7f8503d4173d092c7e);
#
#
#         var popup_7201dc5ad9f5dba38382a8ff426286fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44806312e4a72faa5389a310a9e25ac0 = $(`&lt;div id=&quot;html_44806312e4a72faa5389a310a9e25ac0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7201dc5ad9f5dba38382a8ff426286fb.setContent(html_44806312e4a72faa5389a310a9e25ac0);
#
#
#
#         marker_e4d11eedd6300815e9e0b76a32e70678.bindPopup(popup_7201dc5ad9f5dba38382a8ff426286fb)
#         ;
#
#
#
#
#             var marker_6ed99583edf918395d3115cf4697345a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1560a067f1081f7f8503d4173d092c7e);
#
#
#         var popup_80bed12f75548851b5f7d4a3677640f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0b295ba8d72d30fd87ec030c97d4f00 = $(`&lt;div id=&quot;html_b0b295ba8d72d30fd87ec030c97d4f00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_80bed12f75548851b5f7d4a3677640f8.setContent(html_b0b295ba8d72d30fd87ec030c97d4f00);
#
#
#
#         marker_6ed99583edf918395d3115cf4697345a.bindPopup(popup_80bed12f75548851b5f7d4a3677640f8)
#         ;
#
#
#
#
#             var marker_ba7ba050d25fa813115867cc2a1b21dc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1560a067f1081f7f8503d4173d092c7e);
#
#
#         var popup_97c43f5768c7b3b865ddd4d5212bb255 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ca9f77093f0800c7bf9f1fbd327069a = $(`&lt;div id=&quot;html_7ca9f77093f0800c7bf9f1fbd327069a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_97c43f5768c7b3b865ddd4d5212bb255.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_442459c70a5c98d89ab2e1c45493a5c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_442459c70a5c98d89ab2e1c45493a5c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_442459c70a5c98d89ab2e1c45493a5c9 = L.map(
#                 &quot;map_442459c70a5c98d89ab2e1c45493a5c9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8fc90124bf625f4f5d2c9d56ac779ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d8fc90124bf625f4f5d2c9d56ac779ae.addTo(map_442459c70a5c98d89ab2e1c45493a5c9);
#
#
#             var feature_group_c950b47763c28c39d8f7dc1747e416b2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_87893283137ee4fe37073b90ef1ed6e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c950b47763c28c39d8f7dc1747e416b2);
#
#
#         var popup_da356d0a775bbb37cefb440f0ce3fe81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47651325cc75cffee5afa805dc9a3648 = $(`&lt;div id=&quot;html_47651325cc75cffee5afa805dc9a3648&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_da356d0a775bbb37cefb440f0ce3fe81.setContent(html_47651325cc75cffee5afa805dc9a3648);
#
#
#
#         marker_87893283137ee4fe37073b90ef1ed6e0.bindPopup(popup_da356d0a775bbb37cefb440f0ce3fe81)
#         ;
#
#
#
#
#             var marker_bdf5f8077d52e8214cb798459e79cb59 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c950b47763c28c39d8f7dc1747e416b2);
#
#
#         var popup_291e09faadfa0a3f7c3bea43ad523673 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_273af147b63d1e5009352feaad3aaef8 = $(`&lt;div id=&quot;html_273af147b63d1e5009352feaad3aaef8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_291e09faadfa0a3f7c3bea43ad523673.setContent(html_273af147b63d1e5009352feaad3aaef8);
#
#
#
#         marker_bdf5f8077d52e8214cb798459e79cb59.bindPopup(popup_291e09faadfa0a3f7c3bea43ad523673)
#         ;
#
#
#
#
#             var marker_966315049bc2d2df684376ee491ab261 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c950b47763c28c39d8f7dc1747e416b2);
#
#
#         var popup_b992243087cb3bef8b5943caa8103bf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f03d00a64d233b546bd1581eea990e7c = $(`&lt;div id=&quot;html_f03d00a64d233b546bd1581eea990e7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b992243087cb3bef8b5943caa8103bf9.setContent(html_f03d00a64d233b546bd1581eea990e7c);
#
#
#
#         marker_966315049bc2d2df684376ee491ab261.bindPopup(popup_b992243087cb3bef8b5943caa8103bf9)
#         ;
#
#
#
#
#             var marker_68dac9e2bb78941c1fb64fdb7a0f7cba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c950b47763c28c39d8f7dc1747e416b2);
#
#
#         var popup_e2ead0c6bea686e7768ed8a95f740a30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a42713f5919531af6243ca3b6a2be0d = $(`&lt;div id=&quot;html_9a42713f5919531af6243ca3b6a2be0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e2ead0c6bea686e7768ed8a95f740a30.setContent(html_9a42713f5919531af6243ca3b6a2be0d);
#
#
#
#         marker_68dac9e2bb78941c1fb64fdb7a0f7cba.bindPopup(popup_e2ead0c6bea686e7768ed8a95f740a30)
#         ;
#
#
#
#
#             var marker_6eb34f3405ecbfa0704411f91bbd8707 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c950b47763c28c39d8f7dc1747e416b2);
#
#
#         var popup_c448c1745735a93a9bdf8172686bc15d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb6a7641f67f8c640b85490b04b35cd0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb6a7641f67f8c640b85490b04b35cd0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb6a7641f67f8c640b85490b04b35cd0 = L.map(
#                 &quot;map_cb6a7641f67f8c640b85490b04b35cd0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c5a4475f1540d5148a3052db02356b6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c5a4475f1540d5148a3052db02356b6.addTo(map_cb6a7641f67f8c640b85490b04b35cd0);
#
#
#             var feature_group_044c43fd46aa12ebf16982a207b9ec8b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_044c43fd46aa12ebf16982a207b9ec8b.addTo(map_cb6a7641f67f8c640b85490b04b35cd0);
#
#
#             var feature_group_sub_group_ef3ffdef185f46b41d813feb8c9b1782 = L.featureGroup.subGroup(
#                 feature_group_044c43fd46aa12ebf16982a207b9ec8b
#             );
#
#
#             var marker_0beebf435aa63f52d5bd5fef0392e1f1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef3ffdef185f46b41d813feb8c9b1782);
#
#
#         var popup_9e5f537c864a567acd300a840497246d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f86a6dda2a99f046b88ba61317274b1 = $(`&lt;div id=&quot;html_9f86a6dda2a99f046b88ba61317274b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9e5f537c864a567acd300a840497246d.setContent(html_9f86a6dda2a99f046b88ba61317274b1);
#
#
#
#         marker_0beebf435aa63f52d5bd5fef0392e1f1.bindPopup(popup_9e5f537c864a567acd300a840497246d)
#         ;
#
#
#
#
#             var marker_9eac60f1c7b3c02f4c22f7a2ca6f129f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef3ffdef185f46b41d813feb8c9b1782);
#
#
#         var popup_7f3a96d71dd61e3b2d9210c1ff8690af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f219226f0df805cd8f41b364fc5d2f6 = $(`&lt;div id=&quot;html_2f219226f0df805cd8f41b364fc5d2f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7f3a96d71dd61e3b2d9210c1ff8690af.setContent(html_2f219226f0df805cd8f41b364fc5d2f6);
#
#
#
#         marker_9eac60f1c7b3c02f4c22f7a2ca6f129f.bindPopup(popup_7f3a96d71dd61e3b2d9210c1ff8690af)
#         ;
#
#
#
#
#             var marker_ae41832a9fbbbe4064f2d88a1e75688f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef3ffdef185f46b41d813feb8c9b1782);
#
#
#         var popup_27d4dd7bab6630f607a6cecac93fc5f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d0c3a0865426d19bd00d997b2b25897 = $(`&lt;div id=&quot;html_4d0c3a0865426d19bd00d997b2b25897&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_27d4dd7bab6630f607a6cecac93fc5f0.setContent(html_4d0c3a0865426d19bd00d997b2b25897);
#
#
#
#         marker_ae41832a9fbbbe4064f2d88a1e75688f.bindPopup(popup_27d4dd7bab6630f607a6cecac93fc5f0)
#         ;
#
#
#
#
#             var marker_7fff4c7476f47ade75a005407b8761e6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ef3ffdef185f46b41d813feb8c9b1782);
#
#
#         var popup_09a09c99c251b1a6a4dd79d79864bc76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d65207d7f4f6bed7c94b9950d0ed184b = $(`&lt;div id=&quot;html_d65207d7f4f6bed7c94b9950d0ed184b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_09a09c99c251b1a6a4dd79d79864bc76.setContent(html_d65207d7f4f6bed7c94b9950d0ed184b);
#
#
#
#         marker_
