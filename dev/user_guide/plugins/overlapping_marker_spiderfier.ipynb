# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e10f349236eb9797db0a367cd5ab5d24 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e10f349236eb9797db0a367cd5ab5d24&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e10f349236eb9797db0a367cd5ab5d24 = L.map(
#                 &quot;map_e10f349236eb9797db0a367cd5ab5d24&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_401c606b6900ae808bf02205f33c29fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_401c606b6900ae808bf02205f33c29fb.addTo(map_e10f349236eb9797db0a367cd5ab5d24);
#
#
#             var marker_81d62dc60aaac973181b0a58a538f0bb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e10f349236eb9797db0a367cd5ab5d24);
#
#
#         var popup_8a3e9b232b035198545c44f4ff822e77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef11e7c9f1843e34729f4190cfd1e92e = $(`&lt;div id=&quot;html_ef11e7c9f1843e34729f4190cfd1e92e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8a3e9b232b035198545c44f4ff822e77.setContent(html_ef11e7c9f1843e34729f4190cfd1e92e);
#
#
#
#         marker_81d62dc60aaac973181b0a58a538f0bb.bindPopup(popup_8a3e9b232b035198545c44f4ff822e77)
#         ;
#
#
#
#
#             var marker_9a40abe8ba449b1ff4a87199d0312056 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e10f349236eb9797db0a367cd5ab5d24);
#
#
#         var popup_f1651d5e778acdabc3231813f500106c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbbf4632ffeefc60da473003994aa747 = $(`&lt;div id=&quot;html_dbbf4632ffeefc60da473003994aa747&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f1651d5e778acdabc3231813f500106c.setContent(html_dbbf4632ffeefc60da473003994aa747);
#
#
#
#         marker_9a40abe8ba449b1ff4a87199d0312056.bindPopup(popup_f1651d5e778acdabc3231813f500106c)
#         ;
#
#
#
#
#             var marker_35ce53cbba6210fe6f69bac7ef2fa751 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e10f349236eb9797db0a367cd5ab5d24);
#
#
#         var popup_5c1f0c5217c4d11bbfec9dbf1229565e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8df3f635036e73d602dcf9d6b0ec7a2 = $(`&lt;div id=&quot;html_e8df3f635036e73d602dcf9d6b0ec7a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5c1f0c5217c4d11bbfec9dbf1229565e.setContent(html_e8df3f635036e73d602dcf9d6b0ec7a2);
#
#
#
#         marker_35ce53cbba6210fe6f69bac7ef2fa751.bindPopup(popup_5c1f0c5217c4d11bbfec9dbf1229565e)
#         ;
#
#
#
#
#             var marker_c5f2d04e816e575c3182d9624dc91154 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e10f349236eb9797db0a367cd5ab5d24);
#
#
#         var popup_4e24a8df7b58b52d2ae4d469f613de01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4a67c2d94b02753ea4118773ec18fe7 = $(`&lt;div id=&quot;html_d4a67c2d94b02753ea4118773ec18fe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4e24a8df7b58b52d2ae4d469f613de01.setContent(html_d4a67c2d94b02753ea4118773ec18fe7);
#
#
#
#         marker_c5f2d04e816e575c3182d9624dc91154.bindPopup(popup_4e24a8df7b58b52d2ae4d469f613de01)
#         ;
#
#
#
#
#             var marker_35b2eeba813fdd7bb05c90cb6044e9b8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e10f349236eb9797db0a367cd5ab5d24);
#
#
#         var popup_7bba0772a8a2eefc8325ed7fdbd849df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba3f7048b1ec81e13687d50b109e64ea = $(`&lt;div id=&quot;html_ba3f7048b1ec81e13687d50b109e64ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7bba0772a8a2eefc8325ed7fdbd849df.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fa9f6a2562d61eb503ebdf422fd9976 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fa9f6a2562d61eb503ebdf422fd9976&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fa9f6a2562d61eb503ebdf422fd9976 = L.map(
#                 &quot;map_5fa9f6a2562d61eb503ebdf422fd9976&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce9d344b3d557089401dfc07ca2fde61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce9d344b3d557089401dfc07ca2fde61.addTo(map_5fa9f6a2562d61eb503ebdf422fd9976);
#
#
#             var feature_group_95381d7cab803617a648e934b4d438dc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1b17f92a57f8afa2589e5fbc1ac6e6b8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_95381d7cab803617a648e934b4d438dc);
#
#
#         var popup_58b47feb0c304c6bd9bd486d7f3aaa43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b5e6350c0a9165d9aef993d10331e1b = $(`&lt;div id=&quot;html_0b5e6350c0a9165d9aef993d10331e1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_58b47feb0c304c6bd9bd486d7f3aaa43.setContent(html_0b5e6350c0a9165d9aef993d10331e1b);
#
#
#
#         marker_1b17f92a57f8afa2589e5fbc1ac6e6b8.bindPopup(popup_58b47feb0c304c6bd9bd486d7f3aaa43)
#         ;
#
#
#
#
#             var marker_af7f5a2018f84c37480bafc4edbac996 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_95381d7cab803617a648e934b4d438dc);
#
#
#         var popup_c2b64142eb8856866a3bea4f2ff520f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f6d01998a67bdc4861f57aad9f794a1 = $(`&lt;div id=&quot;html_2f6d01998a67bdc4861f57aad9f794a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c2b64142eb8856866a3bea4f2ff520f1.setContent(html_2f6d01998a67bdc4861f57aad9f794a1);
#
#
#
#         marker_af7f5a2018f84c37480bafc4edbac996.bindPopup(popup_c2b64142eb8856866a3bea4f2ff520f1)
#         ;
#
#
#
#
#             var marker_c6dddf0804bb96b9b02cc3f127b199ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_95381d7cab803617a648e934b4d438dc);
#
#
#         var popup_b582168cc038c36fbd88864b67380b87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26595e2c1c63d13e1fec9e0b6ae9062b = $(`&lt;div id=&quot;html_26595e2c1c63d13e1fec9e0b6ae9062b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b582168cc038c36fbd88864b67380b87.setContent(html_26595e2c1c63d13e1fec9e0b6ae9062b);
#
#
#
#         marker_c6dddf0804bb96b9b02cc3f127b199ec.bindPopup(popup_b582168cc038c36fbd88864b67380b87)
#         ;
#
#
#
#
#             var marker_b34b32cc1c84e12d92fec2285bb035fe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_95381d7cab803617a648e934b4d438dc);
#
#
#         var popup_950743dfae43b66193c9064f4a707bd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_161c5571999779dfe11e25f82d841de0 = $(`&lt;div id=&quot;html_161c5571999779dfe11e25f82d841de0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_950743dfae43b66193c9064f4a707bd9.setContent(html_161c5571999779dfe11e25f82d841de0);
#
#
#
#         marker_b34b32cc1c84e12d92fec2285bb035fe.bindPopup(popup_950743dfae43b66193c9064f4a707bd9)
#         ;
#
#
#
#
#             var marker_ff88fad882c6421426d35f09ffe9d46f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_95381d7cab803617a648e934b4d438dc);
#
#
#         var popup_5321ed048e7e060debafc78993319799 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_466d17f83798ee273ee5febfe3be5ff3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_466d17f83798ee273ee5febfe3be5ff3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_466d17f83798ee273ee5febfe3be5ff3 = L.map(
#                 &quot;map_466d17f83798ee273ee5febfe3be5ff3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5788e7b9826fa52cf0419143af6fe31d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5788e7b9826fa52cf0419143af6fe31d.addTo(map_466d17f83798ee273ee5febfe3be5ff3);
#
#
#             var feature_group_198347baa5ad08ac1b52ff92b955567b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_198347baa5ad08ac1b52ff92b955567b.addTo(map_466d17f83798ee273ee5febfe3be5ff3);
#
#
#             var feature_group_sub_group_4b19165aced4b15dc7896731d0b5f231 = L.featureGroup.subGroup(
#                 feature_group_198347baa5ad08ac1b52ff92b955567b
#             );
#
#
#             var marker_92dba196a515a476dccf66cc1282d07e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b19165aced4b15dc7896731d0b5f231);
#
#
#         var popup_ef27941cdc8e781095355fb6520ba9ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6960554246464064e704eceaf269088 = $(`&lt;div id=&quot;html_b6960554246464064e704eceaf269088&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ef27941cdc8e781095355fb6520ba9ef.setContent(html_b6960554246464064e704eceaf269088);
#
#
#
#         marker_92dba196a515a476dccf66cc1282d07e.bindPopup(popup_ef27941cdc8e781095355fb6520ba9ef)
#         ;
#
#
#
#
#             var marker_f042ae048381effaf650634c93c55597 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b19165aced4b15dc7896731d0b5f231);
#
#
#         var popup_981d8f565e942f01e01a6caa3fdd8f07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f718b4041e2c66dd9f3a11ccc5a0d97f = $(`&lt;div id=&quot;html_f718b4041e2c66dd9f3a11ccc5a0d97f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_981d8f565e942f01e01a6caa3fdd8f07.setContent(html_f718b4041e2c66dd9f3a11ccc5a0d97f);
#
#
#
#         marker_f042ae048381effaf650634c93c55597.bindPopup(popup_981d8f565e942f01e01a6caa3fdd8f07)
#         ;
#
#
#
#
#             var marker_9eb534f7761a2a60267fda09cf95ccc9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b19165aced4b15dc7896731d0b5f231);
#
#
#         var popup_fdc8278a2990662e59ef17dbd474a44e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_836cb2c11dc160a4ce201fa542daa888 = $(`&lt;div id=&quot;html_836cb2c11dc160a4ce201fa542daa888&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fdc8278a2990662e59ef17dbd474a44e.setContent(html_836cb2c11dc160a4ce201fa542daa888);
#
#
#
#         marker_9eb534f7761a2a60267fda09cf95ccc9.bindPopup(popup_fdc8278a2990662e59ef17dbd474a44e)
#         ;
#
#
#
#
#             var marker_72401c78bc643973390f14ea067ea39e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b19165aced4b15dc7896731d0b5f231);
#
#
#         var popup_d20e95a926a7c528cdaf036cd8cbcdec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_210c8a8ef03f7bd5d11a1ae08eef479d = $(`&lt;div id=&quot;html_210c8a8ef03f7bd5d11a1ae08eef479d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d20e95a926a7c528cdaf036cd8cbcdec.setContent(html_210c8a8ef03f7bd5d11a1ae08eef479d);
#
#
#
#         marker_
