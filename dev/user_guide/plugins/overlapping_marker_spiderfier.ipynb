# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_284100edcf7f138c5a83acf4e1a238b9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_284100edcf7f138c5a83acf4e1a238b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_284100edcf7f138c5a83acf4e1a238b9 = L.map(
#                 &quot;map_284100edcf7f138c5a83acf4e1a238b9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f40436a8a56fb181d7d6eb761a51313 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f40436a8a56fb181d7d6eb761a51313.addTo(map_284100edcf7f138c5a83acf4e1a238b9);
#
#
#             var marker_5eec0a945b193a4c290c21252fe4e2b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_284100edcf7f138c5a83acf4e1a238b9);
#
#
#         var popup_243780ec8087732ac3ef33650bdcb58b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e666a7e49e8096cda8ef26e8aba672f = $(`&lt;div id=&quot;html_8e666a7e49e8096cda8ef26e8aba672f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_243780ec8087732ac3ef33650bdcb58b.setContent(html_8e666a7e49e8096cda8ef26e8aba672f);
#
#
#
#         marker_5eec0a945b193a4c290c21252fe4e2b3.bindPopup(popup_243780ec8087732ac3ef33650bdcb58b)
#         ;
#
#
#
#
#             var marker_0300e658d472fd443c19494f312d959a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_284100edcf7f138c5a83acf4e1a238b9);
#
#
#         var popup_1648f78c56aa2001c38e56a56e073c18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5189cc95f88e213f976c856d7eed3c6d = $(`&lt;div id=&quot;html_5189cc95f88e213f976c856d7eed3c6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1648f78c56aa2001c38e56a56e073c18.setContent(html_5189cc95f88e213f976c856d7eed3c6d);
#
#
#
#         marker_0300e658d472fd443c19494f312d959a.bindPopup(popup_1648f78c56aa2001c38e56a56e073c18)
#         ;
#
#
#
#
#             var marker_4643f31f5df17f9792c76c9feb7be424 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_284100edcf7f138c5a83acf4e1a238b9);
#
#
#         var popup_f99adcb456781aae8e53aa92a49184f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ab39df04bff75de86c94f817c139c78 = $(`&lt;div id=&quot;html_7ab39df04bff75de86c94f817c139c78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f99adcb456781aae8e53aa92a49184f4.setContent(html_7ab39df04bff75de86c94f817c139c78);
#
#
#
#         marker_4643f31f5df17f9792c76c9feb7be424.bindPopup(popup_f99adcb456781aae8e53aa92a49184f4)
#         ;
#
#
#
#
#             var marker_cd567ed4c91770fbc084c75a8dcae8fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_284100edcf7f138c5a83acf4e1a238b9);
#
#
#         var popup_a0d33d63c152d539c43b4d9795fbcec8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7da02a41b54a940c08c3163a2b87b540 = $(`&lt;div id=&quot;html_7da02a41b54a940c08c3163a2b87b540&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a0d33d63c152d539c43b4d9795fbcec8.setContent(html_7da02a41b54a940c08c3163a2b87b540);
#
#
#
#         marker_cd567ed4c91770fbc084c75a8dcae8fd.bindPopup(popup_a0d33d63c152d539c43b4d9795fbcec8)
#         ;
#
#
#
#
#             var marker_5ee8c3353fac87928ca80d3db2ea472a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_284100edcf7f138c5a83acf4e1a238b9);
#
#
#         var popup_461d2c75113900f1c73e1b3636a3c468 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77d4823d9f43c8cc65507ed2f42c0d57 = $(`&lt;div id=&quot;html_77d4823d9f43c8cc65507ed2f42c0d57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_461d2c75113900f1c73e1b3636a3c4

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92343fa51bfc2e37b6457559ed84be53 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92343fa51bfc2e37b6457559ed84be53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92343fa51bfc2e37b6457559ed84be53 = L.map(
#                 &quot;map_92343fa51bfc2e37b6457559ed84be53&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f063704598f4fda063a43349c381a1be = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f063704598f4fda063a43349c381a1be.addTo(map_92343fa51bfc2e37b6457559ed84be53);
#
#
#             var feature_group_d15d3edd00af3feb1b3f76d597ad4784 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ce593336e75c2919e13369a399dfe167 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d15d3edd00af3feb1b3f76d597ad4784);
#
#
#         var popup_304f424aae6484f448edb9c2c1f9cee1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8481052fe1511bcfba2348c5f6a23e6a = $(`&lt;div id=&quot;html_8481052fe1511bcfba2348c5f6a23e6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_304f424aae6484f448edb9c2c1f9cee1.setContent(html_8481052fe1511bcfba2348c5f6a23e6a);
#
#
#
#         marker_ce593336e75c2919e13369a399dfe167.bindPopup(popup_304f424aae6484f448edb9c2c1f9cee1)
#         ;
#
#
#
#
#             var marker_691ac5711fbd75af42423c5b085160af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d15d3edd00af3feb1b3f76d597ad4784);
#
#
#         var popup_3320a5ebaa33b213ad062ca65fb19842 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d14e3f7e996bce0f907f04a5c4f1f2f7 = $(`&lt;div id=&quot;html_d14e3f7e996bce0f907f04a5c4f1f2f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3320a5ebaa33b213ad062ca65fb19842.setContent(html_d14e3f7e996bce0f907f04a5c4f1f2f7);
#
#
#
#         marker_691ac5711fbd75af42423c5b085160af.bindPopup(popup_3320a5ebaa33b213ad062ca65fb19842)
#         ;
#
#
#
#
#             var marker_efeeb6d6df300d39e8409e2d38ca5b86 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d15d3edd00af3feb1b3f76d597ad4784);
#
#
#         var popup_15a1b7fa5fe0b51e8124b233461cae09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc310a383d69ee9818a459e70a285008 = $(`&lt;div id=&quot;html_cc310a383d69ee9818a459e70a285008&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_15a1b7fa5fe0b51e8124b233461cae09.setContent(html_cc310a383d69ee9818a459e70a285008);
#
#
#
#         marker_efeeb6d6df300d39e8409e2d38ca5b86.bindPopup(popup_15a1b7fa5fe0b51e8124b233461cae09)
#         ;
#
#
#
#
#             var marker_bda05cda6f91862fe4e62a376605b64a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d15d3edd00af3feb1b3f76d597ad4784);
#
#
#         var popup_3db15efbda925424efa93daa4308fa43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_613bca7a5ab208b0fc727e338507bb25 = $(`&lt;div id=&quot;html_613bca7a5ab208b0fc727e338507bb25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3db15efbda925424efa93daa4308fa43.setContent(html_613bca7a5ab208b0fc727e338507bb25);
#
#
#
#         marker_bda05cda6f91862fe4e62a376605b64a.bindPopup(popup_3db15efbda925424efa93daa4308fa43)
#         ;
#
#
#
#
#             var marker_eeb3403387551e651237e36097ef1643 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d15d3edd00af3feb1b3f76d597ad4784);
#
#
#         var popup_438e967e66aadbc933454547b60ecd29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ca7317fa73573c88a825435fde3d8dd {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ca7317fa73573c88a825435fde3d8dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ca7317fa73573c88a825435fde3d8dd = L.map(
#                 &quot;map_6ca7317fa73573c88a825435fde3d8dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be8576a6aa6c01afd276381a5d53cc38 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be8576a6aa6c01afd276381a5d53cc38.addTo(map_6ca7317fa73573c88a825435fde3d8dd);
#
#
#             var feature_group_fca2e48a9e6f32dcf99124ea46e01bf1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fca2e48a9e6f32dcf99124ea46e01bf1.addTo(map_6ca7317fa73573c88a825435fde3d8dd);
#
#
#             var feature_group_sub_group_203671b3fa2329a63b4b0dc53c565d1c = L.featureGroup.subGroup(
#                 feature_group_fca2e48a9e6f32dcf99124ea46e01bf1
#             );
#
#
#             var marker_f58216f1ab1e52892c4a67e028df29b7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_203671b3fa2329a63b4b0dc53c565d1c);
#
#
#         var popup_46e98ba3e8c1c7d275a88a5c76d3a0bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0709f7feb76b2b558faf89db5fef0422 = $(`&lt;div id=&quot;html_0709f7feb76b2b558faf89db5fef0422&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_46e98ba3e8c1c7d275a88a5c76d3a0bd.setContent(html_0709f7feb76b2b558faf89db5fef0422);
#
#
#
#         marker_f58216f1ab1e52892c4a67e028df29b7.bindPopup(popup_46e98ba3e8c1c7d275a88a5c76d3a0bd)
#         ;
#
#
#
#
#             var marker_09f2f7b90885b9fec82e94253044e9b4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_203671b3fa2329a63b4b0dc53c565d1c);
#
#
#         var popup_dda9f022696321b41290f5d9789ccc06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9ae5e8f760b94faf61d5a84240d6d7e = $(`&lt;div id=&quot;html_f9ae5e8f760b94faf61d5a84240d6d7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_dda9f022696321b41290f5d9789ccc06.setContent(html_f9ae5e8f760b94faf61d5a84240d6d7e);
#
#
#
#         marker_09f2f7b90885b9fec82e94253044e9b4.bindPopup(popup_dda9f022696321b41290f5d9789ccc06)
#         ;
#
#
#
#
#             var marker_6a2a7088a0bebc1e517f1b294834db23 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_203671b3fa2329a63b4b0dc53c565d1c);
#
#
#         var popup_e7136282e6d637ff11d0f6b45d76e24d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd67acce6b170208d19ec6785db7a950 = $(`&lt;div id=&quot;html_cd67acce6b170208d19ec6785db7a950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e7136282e6d637ff11d0f6b45d76e24d.setContent(html_cd67acce6b170208d19ec6785db7a950);
#
#
#
#         marker_6a2a7088a0bebc1e517f1b294834db23.bindPopup(popup_e7136282e6d637ff11d0f6b45d76e24d)
#         ;
#
#
#
#
#             var marker_bf8c7d9253d833adfe07eafc593c850a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_203671b3fa2329a63b4b0dc53c565d1c);
#
#
#         var popup_9e515acc829b7940bc78fbacec71be00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04f139fe8c33f952bc2f35a1c987fbc1 = $(`&lt;div id=&quot;html_04f139fe8c33f952bc2f35a1c987fbc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9e515acc829b7940bc78fbacec71be00.setContent(html_04f139fe8c33f952bc2f35a1c987fbc1);
#
#
#
#         mark
