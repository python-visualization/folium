# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1840044cec7bc6c7374e092d0374543d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1840044cec7bc6c7374e092d0374543d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1840044cec7bc6c7374e092d0374543d = L.map(
#                 &quot;map_1840044cec7bc6c7374e092d0374543d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c3865a8c9f2c61b482ede95883a5787 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c3865a8c9f2c61b482ede95883a5787.addTo(map_1840044cec7bc6c7374e092d0374543d);
#
#
#             var marker_54ab877fdf13714f8b2fc7f7a293c859 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1840044cec7bc6c7374e092d0374543d);
#
#
#         var popup_9bdcd34bf15fe0a7e1d37923756950ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c68573648bbfa54e9dc6aa99227d66a = $(`&lt;div id=&quot;html_2c68573648bbfa54e9dc6aa99227d66a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9bdcd34bf15fe0a7e1d37923756950ab.setContent(html_2c68573648bbfa54e9dc6aa99227d66a);
#
#
#
#         marker_54ab877fdf13714f8b2fc7f7a293c859.bindPopup(popup_9bdcd34bf15fe0a7e1d37923756950ab)
#         ;
#
#
#
#
#             var marker_adecf5692548ff73f03a96a356c258bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1840044cec7bc6c7374e092d0374543d);
#
#
#         var popup_bfb1a0b52184d8a54d3127e166a72be1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5db104e300009339edae311e02f7495e = $(`&lt;div id=&quot;html_5db104e300009339edae311e02f7495e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bfb1a0b52184d8a54d3127e166a72be1.setContent(html_5db104e300009339edae311e02f7495e);
#
#
#
#         marker_adecf5692548ff73f03a96a356c258bf.bindPopup(popup_bfb1a0b52184d8a54d3127e166a72be1)
#         ;
#
#
#
#
#             var marker_e44af3e165b79e3b468bebd775a75202 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1840044cec7bc6c7374e092d0374543d);
#
#
#         var popup_bb5c6aff9195f532e0ef39f2c4377ff1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67e6e684ce8f3bbf0114edcd6c89cf9f = $(`&lt;div id=&quot;html_67e6e684ce8f3bbf0114edcd6c89cf9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bb5c6aff9195f532e0ef39f2c4377ff1.setContent(html_67e6e684ce8f3bbf0114edcd6c89cf9f);
#
#
#
#         marker_e44af3e165b79e3b468bebd775a75202.bindPopup(popup_bb5c6aff9195f532e0ef39f2c4377ff1)
#         ;
#
#
#
#
#             var marker_27013b5e9467fc319e0a106d9cfdf4ab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1840044cec7bc6c7374e092d0374543d);
#
#
#         var popup_5f09e98ba5dd2ce2b6b679879b61f887 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f096448cab380677f4fa9417f4d60fc7 = $(`&lt;div id=&quot;html_f096448cab380677f4fa9417f4d60fc7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5f09e98ba5dd2ce2b6b679879b61f887.setContent(html_f096448cab380677f4fa9417f4d60fc7);
#
#
#
#         marker_27013b5e9467fc319e0a106d9cfdf4ab.bindPopup(popup_5f09e98ba5dd2ce2b6b679879b61f887)
#         ;
#
#
#
#
#             var marker_1061e7d6c6d0132e64f610af1cb07af2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1840044cec7bc6c7374e092d0374543d);
#
#
#         var popup_7c8b159cdbf45c4fcd8372c001fc2c97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fdb89d4b70b3dd3bbdce14039ef8527 = $(`&lt;div id=&quot;html_2fdb89d4b70b3dd3bbdce14039ef8527&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7c8b159cdbf45c4fcd8372c001fc2c97.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad3d36c81fdc476b7b7a1c80f6e40599 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad3d36c81fdc476b7b7a1c80f6e40599&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad3d36c81fdc476b7b7a1c80f6e40599 = L.map(
#                 &quot;map_ad3d36c81fdc476b7b7a1c80f6e40599&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4171a5717017dbd233902c4225dc115 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4171a5717017dbd233902c4225dc115.addTo(map_ad3d36c81fdc476b7b7a1c80f6e40599);
#
#
#             var feature_group_33cabc6be33b7da0433af514d317fdbc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ac6f6ab2a6bff243993a882a2ff2c34f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_33cabc6be33b7da0433af514d317fdbc);
#
#
#         var popup_b974d4a9a21a3a0a664da5dbc18a47f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e3022ee7388b39da2e5818545e6c36f = $(`&lt;div id=&quot;html_1e3022ee7388b39da2e5818545e6c36f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b974d4a9a21a3a0a664da5dbc18a47f1.setContent(html_1e3022ee7388b39da2e5818545e6c36f);
#
#
#
#         marker_ac6f6ab2a6bff243993a882a2ff2c34f.bindPopup(popup_b974d4a9a21a3a0a664da5dbc18a47f1)
#         ;
#
#
#
#
#             var marker_a64a6601a6cae497bb79ba504612e40c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_33cabc6be33b7da0433af514d317fdbc);
#
#
#         var popup_3b649fa03fa6763fd25cf33992180ee2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c7c7767ea482b5fad80d84f9720e128 = $(`&lt;div id=&quot;html_4c7c7767ea482b5fad80d84f9720e128&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3b649fa03fa6763fd25cf33992180ee2.setContent(html_4c7c7767ea482b5fad80d84f9720e128);
#
#
#
#         marker_a64a6601a6cae497bb79ba504612e40c.bindPopup(popup_3b649fa03fa6763fd25cf33992180ee2)
#         ;
#
#
#
#
#             var marker_a74ca8d35441806744651db446e57709 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_33cabc6be33b7da0433af514d317fdbc);
#
#
#         var popup_546ace1d12436ed1d9e46a2061a10ce4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee0b26f9b8452cae6aaa425c4122b1b7 = $(`&lt;div id=&quot;html_ee0b26f9b8452cae6aaa425c4122b1b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_546ace1d12436ed1d9e46a2061a10ce4.setContent(html_ee0b26f9b8452cae6aaa425c4122b1b7);
#
#
#
#         marker_a74ca8d35441806744651db446e57709.bindPopup(popup_546ace1d12436ed1d9e46a2061a10ce4)
#         ;
#
#
#
#
#             var marker_0382aa8a762e4d84d5e4925ee33dda10 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_33cabc6be33b7da0433af514d317fdbc);
#
#
#         var popup_40fd8773385bce43f2e936bc0f4db48b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d95eeb5ab270e5d3d8756cbfc87d0241 = $(`&lt;div id=&quot;html_d95eeb5ab270e5d3d8756cbfc87d0241&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_40fd8773385bce43f2e936bc0f4db48b.setContent(html_d95eeb5ab270e5d3d8756cbfc87d0241);
#
#
#
#         marker_0382aa8a762e4d84d5e4925ee33dda10.bindPopup(popup_40fd8773385bce43f2e936bc0f4db48b)
#         ;
#
#
#
#
#             var marker_3758317966cec2a62f171003cb130b03 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_33cabc6be33b7da0433af514d317fdbc);
#
#
#         var popup_36bcbe26d872fe100ce4791a5621208a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9bd64fc1dfd08dec045b9986cea5327c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9bd64fc1dfd08dec045b9986cea5327c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9bd64fc1dfd08dec045b9986cea5327c = L.map(
#                 &quot;map_9bd64fc1dfd08dec045b9986cea5327c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f18e8f2f0fd3ac41066061ba175fb828 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f18e8f2f0fd3ac41066061ba175fb828.addTo(map_9bd64fc1dfd08dec045b9986cea5327c);
#
#
#             var feature_group_a1278885a6aa0c5ff7bc272d98fdf531 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a1278885a6aa0c5ff7bc272d98fdf531.addTo(map_9bd64fc1dfd08dec045b9986cea5327c);
#
#
#             var feature_group_sub_group_9a18a2c40a43e851f96d54bfa89809cc = L.featureGroup.subGroup(
#                 feature_group_a1278885a6aa0c5ff7bc272d98fdf531
#             );
#
#
#             var marker_ad364ce74adef3a47b05d8ec66687899 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a18a2c40a43e851f96d54bfa89809cc);
#
#
#         var popup_71a780981204d412839c1270ff612c56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36200c37a754a224518e247336397579 = $(`&lt;div id=&quot;html_36200c37a754a224518e247336397579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_71a780981204d412839c1270ff612c56.setContent(html_36200c37a754a224518e247336397579);
#
#
#
#         marker_ad364ce74adef3a47b05d8ec66687899.bindPopup(popup_71a780981204d412839c1270ff612c56)
#         ;
#
#
#
#
#             var marker_ae284349100c3223aaaab8bcddf17988 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a18a2c40a43e851f96d54bfa89809cc);
#
#
#         var popup_2bd9f650adb3af27fb8cd69a91cfd2ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d37a1a56aac56b764962a12630e77b88 = $(`&lt;div id=&quot;html_d37a1a56aac56b764962a12630e77b88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2bd9f650adb3af27fb8cd69a91cfd2ec.setContent(html_d37a1a56aac56b764962a12630e77b88);
#
#
#
#         marker_ae284349100c3223aaaab8bcddf17988.bindPopup(popup_2bd9f650adb3af27fb8cd69a91cfd2ec)
#         ;
#
#
#
#
#             var marker_c64762dbf60c8f338b1f346f981ac6ee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a18a2c40a43e851f96d54bfa89809cc);
#
#
#         var popup_d72ba5e5efcd647d4229ebbf7f1056d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87947fe2c846ac23ac217494906618f0 = $(`&lt;div id=&quot;html_87947fe2c846ac23ac217494906618f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d72ba5e5efcd647d4229ebbf7f1056d0.setContent(html_87947fe2c846ac23ac217494906618f0);
#
#
#
#         marker_c64762dbf60c8f338b1f346f981ac6ee.bindPopup(popup_d72ba5e5efcd647d4229ebbf7f1056d0)
#         ;
#
#
#
#
#             var marker_7b0a25886b7696f8595d1f05f62836dd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a18a2c40a43e851f96d54bfa89809cc);
#
#
#         var popup_403c2ad6feafee57dc4a7cf6ff3c639e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a894513b7776482471ae7f0faa3cd5e = $(`&lt;div id=&quot;html_0a894513b7776482471ae7f0faa3cd5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_403c2ad6feafee57dc4a7cf6ff3c639e.setContent(html_0a894513b7776482471ae7f0faa3cd5e);
#
#
#
#         marker_
