# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad007f6358bd0212aae70b723fd0c890 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad007f6358bd0212aae70b723fd0c890&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad007f6358bd0212aae70b723fd0c890 = L.map(
#                 &quot;map_ad007f6358bd0212aae70b723fd0c890&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb7fdb16a151f12b3b236c4f51754ab6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb7fdb16a151f12b3b236c4f51754ab6.addTo(map_ad007f6358bd0212aae70b723fd0c890);
#
#
#             var marker_62cf9a6424f4d68e113678e28bbfc14d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ad007f6358bd0212aae70b723fd0c890);
#
#
#         var popup_03acea0d7d8af5ad12b280cf819d4ddf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02a51dc8b5a6b1750b689b7d8f7641f9 = $(`&lt;div id=&quot;html_02a51dc8b5a6b1750b689b7d8f7641f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_03acea0d7d8af5ad12b280cf819d4ddf.setContent(html_02a51dc8b5a6b1750b689b7d8f7641f9);
#
#
#
#         marker_62cf9a6424f4d68e113678e28bbfc14d.bindPopup(popup_03acea0d7d8af5ad12b280cf819d4ddf)
#         ;
#
#
#
#
#             var marker_dc4cbb401f7bdca5846900b4b0316720 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ad007f6358bd0212aae70b723fd0c890);
#
#
#         var popup_87560119197775406a6cda8146b83874 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1baed8bf21c4416579790ece1918bcee = $(`&lt;div id=&quot;html_1baed8bf21c4416579790ece1918bcee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_87560119197775406a6cda8146b83874.setContent(html_1baed8bf21c4416579790ece1918bcee);
#
#
#
#         marker_dc4cbb401f7bdca5846900b4b0316720.bindPopup(popup_87560119197775406a6cda8146b83874)
#         ;
#
#
#
#
#             var marker_b15945e13e969c86dd96c39336119add = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ad007f6358bd0212aae70b723fd0c890);
#
#
#         var popup_ce6dff92c66cae002163be9910f3ff5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_289ffb0b3f43bc6b6f7c8ae5cd4871f4 = $(`&lt;div id=&quot;html_289ffb0b3f43bc6b6f7c8ae5cd4871f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ce6dff92c66cae002163be9910f3ff5f.setContent(html_289ffb0b3f43bc6b6f7c8ae5cd4871f4);
#
#
#
#         marker_b15945e13e969c86dd96c39336119add.bindPopup(popup_ce6dff92c66cae002163be9910f3ff5f)
#         ;
#
#
#
#
#             var marker_6e6f66fd5175a24179708fc88a5da2c5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ad007f6358bd0212aae70b723fd0c890);
#
#
#         var popup_07d69527f610c801df8e74265aedd70b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ee561ffa82d2f684c966e9d781f1c7c = $(`&lt;div id=&quot;html_2ee561ffa82d2f684c966e9d781f1c7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_07d69527f610c801df8e74265aedd70b.setContent(html_2ee561ffa82d2f684c966e9d781f1c7c);
#
#
#
#         marker_6e6f66fd5175a24179708fc88a5da2c5.bindPopup(popup_07d69527f610c801df8e74265aedd70b)
#         ;
#
#
#
#
#             var marker_8a5a27facca0f0cd7489a43b0154d0b6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ad007f6358bd0212aae70b723fd0c890);
#
#
#         var popup_4d78c7bd403acb320e92fa22dcc505da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b4f51797e282a2e384db8711dd315f4 = $(`&lt;div id=&quot;html_3b4f51797e282a2e384db8711dd315f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4d78c7bd403acb320e92fa22dcc505

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee22decb7e7bd15c4fcefc03dd3ad7dd {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee22decb7e7bd15c4fcefc03dd3ad7dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee22decb7e7bd15c4fcefc03dd3ad7dd = L.map(
#                 &quot;map_ee22decb7e7bd15c4fcefc03dd3ad7dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e006b6277e43d7de35223070ddf5de8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e006b6277e43d7de35223070ddf5de8.addTo(map_ee22decb7e7bd15c4fcefc03dd3ad7dd);
#
#
#             var feature_group_7a1bc502d0a316299a759c2c994f924f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_30aa04cd8c07f1c1b40d8492d03e7e3b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7a1bc502d0a316299a759c2c994f924f);
#
#
#         var popup_9b91886510216889cd1a4d9b33b17815 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_346fbc9ae4a28e0748e77a54dc908d28 = $(`&lt;div id=&quot;html_346fbc9ae4a28e0748e77a54dc908d28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9b91886510216889cd1a4d9b33b17815.setContent(html_346fbc9ae4a28e0748e77a54dc908d28);
#
#
#
#         marker_30aa04cd8c07f1c1b40d8492d03e7e3b.bindPopup(popup_9b91886510216889cd1a4d9b33b17815)
#         ;
#
#
#
#
#             var marker_4ce549569dd4f625fc50b8e2f1cf166a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7a1bc502d0a316299a759c2c994f924f);
#
#
#         var popup_8c13726554fd59bafe5de716564ce803 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fbc3f60f9aaffb564084857e5a0a2ea = $(`&lt;div id=&quot;html_3fbc3f60f9aaffb564084857e5a0a2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8c13726554fd59bafe5de716564ce803.setContent(html_3fbc3f60f9aaffb564084857e5a0a2ea);
#
#
#
#         marker_4ce549569dd4f625fc50b8e2f1cf166a.bindPopup(popup_8c13726554fd59bafe5de716564ce803)
#         ;
#
#
#
#
#             var marker_adf3e5091160dfbf960e70c335f81c45 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7a1bc502d0a316299a759c2c994f924f);
#
#
#         var popup_ca734302174b305e33d9f2b60cf77d11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9247e4df41dfb607861dce4ac1414912 = $(`&lt;div id=&quot;html_9247e4df41dfb607861dce4ac1414912&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ca734302174b305e33d9f2b60cf77d11.setContent(html_9247e4df41dfb607861dce4ac1414912);
#
#
#
#         marker_adf3e5091160dfbf960e70c335f81c45.bindPopup(popup_ca734302174b305e33d9f2b60cf77d11)
#         ;
#
#
#
#
#             var marker_753979e780181d2b597f121b59789cd0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7a1bc502d0a316299a759c2c994f924f);
#
#
#         var popup_4ad9d5a92c4f83bcd46494bb16940b4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e32896a1c99e37e0dde1119bf57c32b0 = $(`&lt;div id=&quot;html_e32896a1c99e37e0dde1119bf57c32b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4ad9d5a92c4f83bcd46494bb16940b4d.setContent(html_e32896a1c99e37e0dde1119bf57c32b0);
#
#
#
#         marker_753979e780181d2b597f121b59789cd0.bindPopup(popup_4ad9d5a92c4f83bcd46494bb16940b4d)
#         ;
#
#
#
#
#             var marker_a634859537b476618b47f78031226690 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7a1bc502d0a316299a759c2c994f924f);
#
#
#         var popup_649c342e1c06a674aea4faf1b869df9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50c84b48af6a2b97257443a94b5bb6ff {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50c84b48af6a2b97257443a94b5bb6ff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50c84b48af6a2b97257443a94b5bb6ff = L.map(
#                 &quot;map_50c84b48af6a2b97257443a94b5bb6ff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfb108018215ba73f930763f827e9ff3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfb108018215ba73f930763f827e9ff3.addTo(map_50c84b48af6a2b97257443a94b5bb6ff);
#
#
#             var feature_group_4f247d433e246fdbec42ecdef6c2d70b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4f247d433e246fdbec42ecdef6c2d70b.addTo(map_50c84b48af6a2b97257443a94b5bb6ff);
#
#
#             var feature_group_sub_group_57b15d894dfb181de0dc2a3170d6db2c = L.featureGroup.subGroup(
#                 feature_group_4f247d433e246fdbec42ecdef6c2d70b
#             );
#
#
#             var marker_11e26f79f757ebc645bec32f153f9a19 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_57b15d894dfb181de0dc2a3170d6db2c);
#
#
#         var popup_540dab70445711e67665868c77993acd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2632ad5a62acba06daf9775666af5e41 = $(`&lt;div id=&quot;html_2632ad5a62acba06daf9775666af5e41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_540dab70445711e67665868c77993acd.setContent(html_2632ad5a62acba06daf9775666af5e41);
#
#
#
#         marker_11e26f79f757ebc645bec32f153f9a19.bindPopup(popup_540dab70445711e67665868c77993acd)
#         ;
#
#
#
#
#             var marker_76ca160e5d2d0209cb447e9fc8dc960d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_57b15d894dfb181de0dc2a3170d6db2c);
#
#
#         var popup_9e19a2b120a56a6172b18206713f76b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75251289183d1880630bc39dba7ec4ba = $(`&lt;div id=&quot;html_75251289183d1880630bc39dba7ec4ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9e19a2b120a56a6172b18206713f76b7.setContent(html_75251289183d1880630bc39dba7ec4ba);
#
#
#
#         marker_76ca160e5d2d0209cb447e9fc8dc960d.bindPopup(popup_9e19a2b120a56a6172b18206713f76b7)
#         ;
#
#
#
#
#             var marker_089dc01b906cb140bb8a42e60503bb9e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_57b15d894dfb181de0dc2a3170d6db2c);
#
#
#         var popup_775558cb334a2648ac86c3e7f6275e61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fb9641f3f1d2098fac3c92fe70f742d = $(`&lt;div id=&quot;html_5fb9641f3f1d2098fac3c92fe70f742d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_775558cb334a2648ac86c3e7f6275e61.setContent(html_5fb9641f3f1d2098fac3c92fe70f742d);
#
#
#
#         marker_089dc01b906cb140bb8a42e60503bb9e.bindPopup(popup_775558cb334a2648ac86c3e7f6275e61)
#         ;
#
#
#
#
#             var marker_10d073ac8c028530696d8ad6faad02fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_57b15d894dfb181de0dc2a3170d6db2c);
#
#
#         var popup_4843b960c2bd33182925834c4bf50aa2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11fc7164fd0cbed9d62880421cfd38f4 = $(`&lt;div id=&quot;html_11fc7164fd0cbed9d62880421cfd38f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4843b960c2bd33182925834c4bf50aa2.setContent(html_11fc7164fd0cbed9d62880421cfd38f4);
#
#
#
#         mark
