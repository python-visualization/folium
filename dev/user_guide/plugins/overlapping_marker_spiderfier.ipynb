# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_304f9ba916966fc996eb2c18ffc43e5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_304f9ba916966fc996eb2c18ffc43e5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_304f9ba916966fc996eb2c18ffc43e5f = L.map(
#                 &quot;map_304f9ba916966fc996eb2c18ffc43e5f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6e9899484502befad246e8e722c37de = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d6e9899484502befad246e8e722c37de.addTo(map_304f9ba916966fc996eb2c18ffc43e5f);
#
#
#             var marker_a026ba8642a83376561740751a4523c3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_304f9ba916966fc996eb2c18ffc43e5f);
#
#
#         var popup_97234d948e3c0c48c8d8b599e090b1ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81a6e53f65d66e52ce8c119436beb046 = $(`&lt;div id=&quot;html_81a6e53f65d66e52ce8c119436beb046&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_97234d948e3c0c48c8d8b599e090b1ce.setContent(html_81a6e53f65d66e52ce8c119436beb046);
#
#
#
#         marker_a026ba8642a83376561740751a4523c3.bindPopup(popup_97234d948e3c0c48c8d8b599e090b1ce)
#         ;
#
#
#
#
#             var marker_54b0dc70d06dfe262ccc004bdb0cbe60 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_304f9ba916966fc996eb2c18ffc43e5f);
#
#
#         var popup_e648239b2da19cfd16ef565f702a29a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9222252eb1312b471090cff46d3e2a6c = $(`&lt;div id=&quot;html_9222252eb1312b471090cff46d3e2a6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e648239b2da19cfd16ef565f702a29a7.setContent(html_9222252eb1312b471090cff46d3e2a6c);
#
#
#
#         marker_54b0dc70d06dfe262ccc004bdb0cbe60.bindPopup(popup_e648239b2da19cfd16ef565f702a29a7)
#         ;
#
#
#
#
#             var marker_21b758d48e694f5ff782512962d4b7df = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_304f9ba916966fc996eb2c18ffc43e5f);
#
#
#         var popup_b3a0373273425427d3041b092ee75545 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d67c2bb78cb399570b7d8dc075022fd = $(`&lt;div id=&quot;html_7d67c2bb78cb399570b7d8dc075022fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b3a0373273425427d3041b092ee75545.setContent(html_7d67c2bb78cb399570b7d8dc075022fd);
#
#
#
#         marker_21b758d48e694f5ff782512962d4b7df.bindPopup(popup_b3a0373273425427d3041b092ee75545)
#         ;
#
#
#
#
#             var marker_7f5dc21eb621389d23c384d9d80072a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_304f9ba916966fc996eb2c18ffc43e5f);
#
#
#         var popup_9a889097426a75d7362729ecc9c2fceb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b03c3c60b1b9f4df63d7d9bab93866ef = $(`&lt;div id=&quot;html_b03c3c60b1b9f4df63d7d9bab93866ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9a889097426a75d7362729ecc9c2fceb.setContent(html_b03c3c60b1b9f4df63d7d9bab93866ef);
#
#
#
#         marker_7f5dc21eb621389d23c384d9d80072a3.bindPopup(popup_9a889097426a75d7362729ecc9c2fceb)
#         ;
#
#
#
#
#             var marker_159da15df08e74810894a5e884a8c37a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_304f9ba916966fc996eb2c18ffc43e5f);
#
#
#         var popup_74e1a8b0ef32453212cfa103f9d7702d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b56c1b62f2642c96b09a75df5ae3021 = $(`&lt;div id=&quot;html_2b56c1b62f2642c96b09a75df5ae3021&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_74e1a8b0ef32453212cfa103f9d7702d.setContent(html_2b56c1b62f2642c96b09a75df5ae3021);
#
#
#
#         marker_159da15df08e74810894a5e884a8c37a.bindPopup(popup_74e1a8b0ef32453212cfa103f9d7702d)
#         ;
#
#
#
#
#             var marker_3b20ebe130

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d60442fbd112ae984cee26a737c40b71 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d60442fbd112ae984cee26a737c40b71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d60442fbd112ae984cee26a737c40b71 = L.map(
#                 &quot;map_d60442fbd112ae984cee26a737c40b71&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_061e58079936d9be87d1b15ee7f1c874 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_061e58079936d9be87d1b15ee7f1c874.addTo(map_d60442fbd112ae984cee26a737c40b71);
#
#
#             var feature_group_cb6e2dd9cd20a0d66fa62fc6e5131841 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b22f573e8854442d649594e472b0446a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cb6e2dd9cd20a0d66fa62fc6e5131841);
#
#
#         var popup_9e615155b841ddd21c04084b335a8a54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c23172bbce4ba290cb5bd5c617001a16 = $(`&lt;div id=&quot;html_c23172bbce4ba290cb5bd5c617001a16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9e615155b841ddd21c04084b335a8a54.setContent(html_c23172bbce4ba290cb5bd5c617001a16);
#
#
#
#         marker_b22f573e8854442d649594e472b0446a.bindPopup(popup_9e615155b841ddd21c04084b335a8a54)
#         ;
#
#
#
#
#             var marker_067d6bba3ff2fa3f3debd00083b5a44f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cb6e2dd9cd20a0d66fa62fc6e5131841);
#
#
#         var popup_a44a59cfac9ef2564b59065742465dd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aaae54294a4bcad6da6e6099968add01 = $(`&lt;div id=&quot;html_aaae54294a4bcad6da6e6099968add01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a44a59cfac9ef2564b59065742465dd2.setContent(html_aaae54294a4bcad6da6e6099968add01);
#
#
#
#         marker_067d6bba3ff2fa3f3debd00083b5a44f.bindPopup(popup_a44a59cfac9ef2564b59065742465dd2)
#         ;
#
#
#
#
#             var marker_f888d7bef51f04e65410e7ad55862de3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cb6e2dd9cd20a0d66fa62fc6e5131841);
#
#
#         var popup_63de253d07389b44a1d29cbb936d797d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d4ae2bc82bfb47c918996e79e4c49ec = $(`&lt;div id=&quot;html_5d4ae2bc82bfb47c918996e79e4c49ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_63de253d07389b44a1d29cbb936d797d.setContent(html_5d4ae2bc82bfb47c918996e79e4c49ec);
#
#
#
#         marker_f888d7bef51f04e65410e7ad55862de3.bindPopup(popup_63de253d07389b44a1d29cbb936d797d)
#         ;
#
#
#
#
#             var marker_954ba1687679285b858a88a010764fe0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cb6e2dd9cd20a0d66fa62fc6e5131841);
#
#
#         var popup_e900038f1c130a90ac8df56ec304c673 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2c2b0622c163e8fe440535a422c2311 = $(`&lt;div id=&quot;html_b2c2b0622c163e8fe440535a422c2311&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e900038f1c130a90ac8df56ec304c673.setContent(html_b2c2b0622c163e8fe440535a422c2311);
#
#
#
#         marker_954ba1687679285b858a88a010764fe0.bindPopup(popup_e900038f1c130a90ac8df56ec304c673)
#         ;
#
#
#
#
#             var marker_2f9b51ce839c86bdeebe36f737d4da5f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cb6e2dd9cd20a0d66fa62fc6e5131841);
#
#
#         var popup_b78d7e9572c472ab13e27353a2c236be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3928d1f09a77aa69a8a78866dbc3681 = $(`&lt;div id=&quot;html_c3928d1f09a77aa69a8a78866dbc3681&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_b78d7e9572c472ab13

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d800ddfa667abab9d26ed37779d7fd4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d800ddfa667abab9d26ed37779d7fd4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d800ddfa667abab9d26ed37779d7fd4 = L.map(
#                 &quot;map_6d800ddfa667abab9d26ed37779d7fd4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61522894b8e4eaa4b40a2d3d8c1e27fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61522894b8e4eaa4b40a2d3d8c1e27fc.addTo(map_6d800ddfa667abab9d26ed37779d7fd4);
#
#
#             var feature_group_1cfef4d0472bd1d87af80c440d5e7e8a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1cfef4d0472bd1d87af80c440d5e7e8a.addTo(map_6d800ddfa667abab9d26ed37779d7fd4);
#
#
#             var feature_group_sub_group_efda9babe88fe9e279d5a0597eaf14ec = L.featureGroup.subGroup(
#                 feature_group_1cfef4d0472bd1d87af80c440d5e7e8a
#             );
#
#
#             var marker_89ddad64ae3713649053ecb2b3412e34 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_efda9babe88fe9e279d5a0597eaf14ec);
#
#
#         var popup_80a3058f2081084e3bb27a6cfd3545a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6610cd07a7b13c9d0a9d6f7e68a125cb = $(`&lt;div id=&quot;html_6610cd07a7b13c9d0a9d6f7e68a125cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_80a3058f2081084e3bb27a6cfd3545a5.setContent(html_6610cd07a7b13c9d0a9d6f7e68a125cb);
#
#
#
#         marker_89ddad64ae3713649053ecb2b3412e34.bindPopup(popup_80a3058f2081084e3bb27a6cfd3545a5)
#         ;
#
#
#
#
#             var marker_a7b8d7d6b93d7d17848ccf2a3b1efbaa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_efda9babe88fe9e279d5a0597eaf14ec);
#
#
#         var popup_ae9e83c88ba2dfbb9572f67708a7577c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b23a9f163a8b0e99456cee390f2095b = $(`&lt;div id=&quot;html_0b23a9f163a8b0e99456cee390f2095b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ae9e83c88ba2dfbb9572f67708a7577c.setContent(html_0b23a9f163a8b0e99456cee390f2095b);
#
#
#
#         marker_a7b8d7d6b93d7d17848ccf2a3b1efbaa.bindPopup(popup_ae9e83c88ba2dfbb9572f67708a7577c)
#         ;
#
#
#
#
#             var marker_c5932c8ab50c18ade8d1a9f5b146740d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_efda9babe88fe9e279d5a0597eaf14ec);
#
#
#         var popup_e1140e16819568f76a45b065e461b121 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_838059c49746d446353a8507c08ee208 = $(`&lt;div id=&quot;html_838059c49746d446353a8507c08ee208&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e1140e16819568f76a45b065e461b121.setContent(html_838059c49746d446353a8507c08ee208);
#
#
#
#         marker_c5932c8ab50c18ade8d1a9f5b146740d.bindPopup(popup_e1140e16819568f76a45b065e461b121)
#         ;
#
#
#
#
#             var marker_34b790658949b089a65ac27801587ee2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_efda9babe88fe9e279d5a0597eaf14ec);
#
#
#         var popup_d566af0d08020a6543fae35c45f68189 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f63f62629a066418ee36eeb41d6c5471 = $(`&lt;div id=&quot;html_f63f62629a066418ee36eeb41d6c5471&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d566af0d08020a6543fae35c45f68189.setContent(html_f63f62629a066418ee36eeb41d6c5471);
#
#
#
#         marker_34b790658949b089a65ac27801587ee2.bindPopup(popup_d566af0d08020a6543fae35c45f68189)
#         ;
#
#
#
#
#             var marker_91b1b40c9c3b5cc94584599425a7a78c = L.marker(
#                 [45.050399999999996, 3.0504],
