# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9a0fcce18f220b7c11419a6f823721f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9a0fcce18f220b7c11419a6f823721f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9a0fcce18f220b7c11419a6f823721f = L.map(
#                 &quot;map_d9a0fcce18f220b7c11419a6f823721f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba180138da5c0d5eeaa1ceef24cec17f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba180138da5c0d5eeaa1ceef24cec17f.addTo(map_d9a0fcce18f220b7c11419a6f823721f);
#
#
#             var marker_e82ade53ffb0624221306f6ddfa0840c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d9a0fcce18f220b7c11419a6f823721f);
#
#
#         var popup_9f285d464416e2f73f1804aa60c0951c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14c8dd46f261fb7455183c9d5ce593f3 = $(`&lt;div id=&quot;html_14c8dd46f261fb7455183c9d5ce593f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9f285d464416e2f73f1804aa60c0951c.setContent(html_14c8dd46f261fb7455183c9d5ce593f3);
#
#
#
#         marker_e82ade53ffb0624221306f6ddfa0840c.bindPopup(popup_9f285d464416e2f73f1804aa60c0951c)
#         ;
#
#
#
#
#             var marker_655274a290f3c9f0ea2edf0a3fc827b7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d9a0fcce18f220b7c11419a6f823721f);
#
#
#         var popup_bde6ab4c6e318337e435f8651c76f5ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e17f60b39ec69171fe43342a1b6590d = $(`&lt;div id=&quot;html_9e17f60b39ec69171fe43342a1b6590d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bde6ab4c6e318337e435f8651c76f5ca.setContent(html_9e17f60b39ec69171fe43342a1b6590d);
#
#
#
#         marker_655274a290f3c9f0ea2edf0a3fc827b7.bindPopup(popup_bde6ab4c6e318337e435f8651c76f5ca)
#         ;
#
#
#
#
#             var marker_fdaa16604f4c93c0e0061d59a881c55a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d9a0fcce18f220b7c11419a6f823721f);
#
#
#         var popup_0d589f78e62e46a99d36d1aeaf4644b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d3ca1c71acec13b705e84fc0f288c54 = $(`&lt;div id=&quot;html_4d3ca1c71acec13b705e84fc0f288c54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0d589f78e62e46a99d36d1aeaf4644b2.setContent(html_4d3ca1c71acec13b705e84fc0f288c54);
#
#
#
#         marker_fdaa16604f4c93c0e0061d59a881c55a.bindPopup(popup_0d589f78e62e46a99d36d1aeaf4644b2)
#         ;
#
#
#
#
#             var marker_986b66a6ca1639cd939ab6f70229e266 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d9a0fcce18f220b7c11419a6f823721f);
#
#
#         var popup_29d3dcfa4a8de99a478eda688a7aba46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c40ba73d017bd67d19bcb66ada186f7 = $(`&lt;div id=&quot;html_4c40ba73d017bd67d19bcb66ada186f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_29d3dcfa4a8de99a478eda688a7aba46.setContent(html_4c40ba73d017bd67d19bcb66ada186f7);
#
#
#
#         marker_986b66a6ca1639cd939ab6f70229e266.bindPopup(popup_29d3dcfa4a8de99a478eda688a7aba46)
#         ;
#
#
#
#
#             var marker_003692e3a2d8ef7131ad739982f1e8aa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d9a0fcce18f220b7c11419a6f823721f);
#
#
#         var popup_5de7382914a33262df831f90d0b06794 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d71fbbb65bda672d0554fc2d4a84ebff = $(`&lt;div id=&quot;html_d71fbbb65bda672d0554fc2d4a84ebff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5de7382914a33262df831f90d0b06794.setContent(html_d71fbbb65bda672d0554fc2d4a84ebff);
#
#
#
#         marker_003692e3a2d8ef7131ad739982f1e8aa.bindPopup(popup_5de7382914a33262df831f90d0b06794)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_996a2665f0292f1e7bd63ef7e7e9b296 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_996a2665f0292f1e7bd63ef7e7e9b296&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_996a2665f0292f1e7bd63ef7e7e9b296 = L.map(
#                 &quot;map_996a2665f0292f1e7bd63ef7e7e9b296&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df8ab84fcba40ee0839e57c896a0f08c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df8ab84fcba40ee0839e57c896a0f08c.addTo(map_996a2665f0292f1e7bd63ef7e7e9b296);
#
#
#             var feature_group_6354bbb5ccffb34a6fdb1e1084297a31 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d16b9b4aacb52db63dc90d4469f83a9d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6354bbb5ccffb34a6fdb1e1084297a31);
#
#
#         var popup_089bdca33f714a3b892ffd8548273c28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e764297dac11ea8402e4a532b09ba70 = $(`&lt;div id=&quot;html_9e764297dac11ea8402e4a532b09ba70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_089bdca33f714a3b892ffd8548273c28.setContent(html_9e764297dac11ea8402e4a532b09ba70);
#
#
#
#         marker_d16b9b4aacb52db63dc90d4469f83a9d.bindPopup(popup_089bdca33f714a3b892ffd8548273c28)
#         ;
#
#
#
#
#             var marker_982f0e2f0c3376730e40ad8f26b678a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6354bbb5ccffb34a6fdb1e1084297a31);
#
#
#         var popup_1c429cabc029c9b5ee132aa3cb810601 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3037b581c0ce1211395c6c36dfffe3f = $(`&lt;div id=&quot;html_f3037b581c0ce1211395c6c36dfffe3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1c429cabc029c9b5ee132aa3cb810601.setContent(html_f3037b581c0ce1211395c6c36dfffe3f);
#
#
#
#         marker_982f0e2f0c3376730e40ad8f26b678a0.bindPopup(popup_1c429cabc029c9b5ee132aa3cb810601)
#         ;
#
#
#
#
#             var marker_81e55af4b9541528c6e94e1abf1e25e2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6354bbb5ccffb34a6fdb1e1084297a31);
#
#
#         var popup_eccccd1ed75fe4d5a932c2b1d4e48a6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_490abb63b1b3b084e3ec975d4e03ba8c = $(`&lt;div id=&quot;html_490abb63b1b3b084e3ec975d4e03ba8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_eccccd1ed75fe4d5a932c2b1d4e48a6a.setContent(html_490abb63b1b3b084e3ec975d4e03ba8c);
#
#
#
#         marker_81e55af4b9541528c6e94e1abf1e25e2.bindPopup(popup_eccccd1ed75fe4d5a932c2b1d4e48a6a)
#         ;
#
#
#
#
#             var marker_57f64c19fc008f5245f284df64f4fb1b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6354bbb5ccffb34a6fdb1e1084297a31);
#
#
#         var popup_2b4ffc6c1d1a585fb8620214ca6e9768 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71914e21723c1f616c36ab797d8a19fe = $(`&lt;div id=&quot;html_71914e21723c1f616c36ab797d8a19fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2b4ffc6c1d1a585fb8620214ca6e9768.setContent(html_71914e21723c1f616c36ab797d8a19fe);
#
#
#
#         marker_57f64c19fc008f5245f284df64f4fb1b.bindPopup(popup_2b4ffc6c1d1a585fb8620214ca6e9768)
#         ;
#
#
#
#
#             var marker_e2736ae50bc6774d9c0ff65c4afcfaad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6354bbb5ccffb34a6fdb1e1084297a31);
#
#
#         var popup_1fefa5966b6fe7596d7969aec30479c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc369781ca823493beeaac8e654a3b42 = $(`&lt;div id=&quot;html_cc369781ca823493beeaac8e654a3b42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78473e47016cd7ea33e275d5bb853ed3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78473e47016cd7ea33e275d5bb853ed3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78473e47016cd7ea33e275d5bb853ed3 = L.map(
#                 &quot;map_78473e47016cd7ea33e275d5bb853ed3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_014c2d3405a974dfefca4dfc4a87e246 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_014c2d3405a974dfefca4dfc4a87e246.addTo(map_78473e47016cd7ea33e275d5bb853ed3);
#
#
#             var feature_group_9afe44bc122cadfbc2f4ba99899e717a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9afe44bc122cadfbc2f4ba99899e717a.addTo(map_78473e47016cd7ea33e275d5bb853ed3);
#
#
#             var feature_group_sub_group_3c9d65c195a570da4a62513d235d5239 = L.featureGroup.subGroup(
#                 feature_group_9afe44bc122cadfbc2f4ba99899e717a
#             );
#
#
#             var marker_b75b602f6007be67ba907a44662a2b78 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3c9d65c195a570da4a62513d235d5239);
#
#
#         var popup_da99fa0f79583d67b562e6f6978c3805 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4db5933116f9f88cffa3a0ef736e5b7a = $(`&lt;div id=&quot;html_4db5933116f9f88cffa3a0ef736e5b7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_da99fa0f79583d67b562e6f6978c3805.setContent(html_4db5933116f9f88cffa3a0ef736e5b7a);
#
#
#
#         marker_b75b602f6007be67ba907a44662a2b78.bindPopup(popup_da99fa0f79583d67b562e6f6978c3805)
#         ;
#
#
#
#
#             var marker_4217cb80c9f7256f39408de556b3ce30 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3c9d65c195a570da4a62513d235d5239);
#
#
#         var popup_6b0010061c0c77428a164920d468bf86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be5de181c1471a28d9e48879e92f02b1 = $(`&lt;div id=&quot;html_be5de181c1471a28d9e48879e92f02b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6b0010061c0c77428a164920d468bf86.setContent(html_be5de181c1471a28d9e48879e92f02b1);
#
#
#
#         marker_4217cb80c9f7256f39408de556b3ce30.bindPopup(popup_6b0010061c0c77428a164920d468bf86)
#         ;
#
#
#
#
#             var marker_648ec2461db136eb50e063633fc7dc17 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3c9d65c195a570da4a62513d235d5239);
#
#
#         var popup_eba47b827928c5884f87529855be89cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_336e9222173a15844b65cd9088fbb2fe = $(`&lt;div id=&quot;html_336e9222173a15844b65cd9088fbb2fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_eba47b827928c5884f87529855be89cf.setContent(html_336e9222173a15844b65cd9088fbb2fe);
#
#
#
#         marker_648ec2461db136eb50e063633fc7dc17.bindPopup(popup_eba47b827928c5884f87529855be89cf)
#         ;
#
#
#
#
#             var marker_e1e3b3bf1f6e4ba968ef47713d7c248d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3c9d65c195a570da4a62513d235d5239);
#
#
#         var popup_170e4916bc0614d6c1b7f2fd107e81a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7e6d3bea704556225be25b95e91ee50 = $(`&lt;div id=&quot;html_d7e6d3bea704556225be25b95e91ee50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_170e4916bc0614d6c1b7f2fd107e81a6.setContent(html_d7e6d3bea704556225be25b95e91ee50);
#
#
#
#         marker_e1e3b3bf1f6e4ba968ef47713d7c248d.bindPopup(popup_170e4916bc0614d6c1b7f2fd107e81a6)
#         ;
#
#
#
#
#             var marker_341ddbebb9096a1d3a4d7201ada60a29 = L.marker(
#                 [45.0503999
