# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_401ba4ea2bd1c1706a27731ae80d451a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_401ba4ea2bd1c1706a27731ae80d451a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_401ba4ea2bd1c1706a27731ae80d451a = L.map(
#                 &quot;map_401ba4ea2bd1c1706a27731ae80d451a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_222a966b2b04cd21d0b13ca4a08648e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_222a966b2b04cd21d0b13ca4a08648e5.addTo(map_401ba4ea2bd1c1706a27731ae80d451a);
#
#
#             var marker_087ae9e1b7a9b465018f1d72b81fe710 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_401ba4ea2bd1c1706a27731ae80d451a);
#
#
#         var popup_c3d68db7610557614b58fe0bddbab787 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6408ae6e02a1acee4486e1c9dcfe9f8 = $(`&lt;div id=&quot;html_f6408ae6e02a1acee4486e1c9dcfe9f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c3d68db7610557614b58fe0bddbab787.setContent(html_f6408ae6e02a1acee4486e1c9dcfe9f8);
#
#
#
#         marker_087ae9e1b7a9b465018f1d72b81fe710.bindPopup(popup_c3d68db7610557614b58fe0bddbab787)
#         ;
#
#
#
#
#             var marker_8591c1b7172aeceab09401a5398c95bc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_401ba4ea2bd1c1706a27731ae80d451a);
#
#
#         var popup_8335807fd9a3ebac5855f08e686c65fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd0371a8db947185028d08b32eb9399f = $(`&lt;div id=&quot;html_fd0371a8db947185028d08b32eb9399f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8335807fd9a3ebac5855f08e686c65fa.setContent(html_fd0371a8db947185028d08b32eb9399f);
#
#
#
#         marker_8591c1b7172aeceab09401a5398c95bc.bindPopup(popup_8335807fd9a3ebac5855f08e686c65fa)
#         ;
#
#
#
#
#             var marker_460db4bc8c7413d78c0c1e3f4443f2c7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_401ba4ea2bd1c1706a27731ae80d451a);
#
#
#         var popup_36d45a9d83e6519d8ddb46f9a808737e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_940566d74196278fec823f181c787f60 = $(`&lt;div id=&quot;html_940566d74196278fec823f181c787f60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_36d45a9d83e6519d8ddb46f9a808737e.setContent(html_940566d74196278fec823f181c787f60);
#
#
#
#         marker_460db4bc8c7413d78c0c1e3f4443f2c7.bindPopup(popup_36d45a9d83e6519d8ddb46f9a808737e)
#         ;
#
#
#
#
#             var marker_c5eff054e5b5aad28ced3fc2a4ce45a1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_401ba4ea2bd1c1706a27731ae80d451a);
#
#
#         var popup_aadcc43fbe811899386d70c57e6cbb53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60dabdf525d7a5c8499c0315742f038d = $(`&lt;div id=&quot;html_60dabdf525d7a5c8499c0315742f038d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_aadcc43fbe811899386d70c57e6cbb53.setContent(html_60dabdf525d7a5c8499c0315742f038d);
#
#
#
#         marker_c5eff054e5b5aad28ced3fc2a4ce45a1.bindPopup(popup_aadcc43fbe811899386d70c57e6cbb53)
#         ;
#
#
#
#
#             var marker_42c0e3fbd7fd31cd162e7d2fec7dbd17 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_401ba4ea2bd1c1706a27731ae80d451a);
#
#
#         var popup_173f1a64c918c1b6394d55a70809bffa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6aca15242d2601e426f82031ee5db2ea = $(`&lt;div id=&quot;html_6aca15242d2601e426f82031ee5db2ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_173f1a64c918c1b6394d55a70809bffa.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae2c626eca8b1bd6e08de6df6eb92b83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae2c626eca8b1bd6e08de6df6eb92b83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae2c626eca8b1bd6e08de6df6eb92b83 = L.map(
#                 &quot;map_ae2c626eca8b1bd6e08de6df6eb92b83&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d166ae945805761c8ec7006d8742b331 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d166ae945805761c8ec7006d8742b331.addTo(map_ae2c626eca8b1bd6e08de6df6eb92b83);
#
#
#             var feature_group_555edccb0a77085212e12adc8c7b178c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0c4675e77cc245ee546c155a2e3bf565 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_555edccb0a77085212e12adc8c7b178c);
#
#
#         var popup_63478bf5f4dd79e7137b43bebc965b24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09c7eeee016e022f3269b995aed72793 = $(`&lt;div id=&quot;html_09c7eeee016e022f3269b995aed72793&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_63478bf5f4dd79e7137b43bebc965b24.setContent(html_09c7eeee016e022f3269b995aed72793);
#
#
#
#         marker_0c4675e77cc245ee546c155a2e3bf565.bindPopup(popup_63478bf5f4dd79e7137b43bebc965b24)
#         ;
#
#
#
#
#             var marker_f9dc0c0a2a6c2b5733002ddf659482cf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_555edccb0a77085212e12adc8c7b178c);
#
#
#         var popup_c9f0353e3570c27068a42e1963df662e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ce31116103021c10774113ab8d43599 = $(`&lt;div id=&quot;html_5ce31116103021c10774113ab8d43599&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c9f0353e3570c27068a42e1963df662e.setContent(html_5ce31116103021c10774113ab8d43599);
#
#
#
#         marker_f9dc0c0a2a6c2b5733002ddf659482cf.bindPopup(popup_c9f0353e3570c27068a42e1963df662e)
#         ;
#
#
#
#
#             var marker_c4fa340ce3d526f7e2c1f997708a45e1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_555edccb0a77085212e12adc8c7b178c);
#
#
#         var popup_9e2b29c8b458044f0c7004e03e068ee5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_971654bd6bca5278b8e93b5d3f9fa284 = $(`&lt;div id=&quot;html_971654bd6bca5278b8e93b5d3f9fa284&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9e2b29c8b458044f0c7004e03e068ee5.setContent(html_971654bd6bca5278b8e93b5d3f9fa284);
#
#
#
#         marker_c4fa340ce3d526f7e2c1f997708a45e1.bindPopup(popup_9e2b29c8b458044f0c7004e03e068ee5)
#         ;
#
#
#
#
#             var marker_7ba519e7bdc5b6b422a76dd7a909aba0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_555edccb0a77085212e12adc8c7b178c);
#
#
#         var popup_55cfae8c2bae891c865c66b7c6a054e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_532e5f6f6da209da25f2619b16165d2e = $(`&lt;div id=&quot;html_532e5f6f6da209da25f2619b16165d2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_55cfae8c2bae891c865c66b7c6a054e1.setContent(html_532e5f6f6da209da25f2619b16165d2e);
#
#
#
#         marker_7ba519e7bdc5b6b422a76dd7a909aba0.bindPopup(popup_55cfae8c2bae891c865c66b7c6a054e1)
#         ;
#
#
#
#
#             var marker_1f4f093db501974cf39138f7061078d6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_555edccb0a77085212e12adc8c7b178c);
#
#
#         var popup_e67373320004eb740622e624fbfea5e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_593a0911f7a0d57eee06d13de2d9ee7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_593a0911f7a0d57eee06d13de2d9ee7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_593a0911f7a0d57eee06d13de2d9ee7d = L.map(
#                 &quot;map_593a0911f7a0d57eee06d13de2d9ee7d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b55d708c2c790c304beadeb5eeee4ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b55d708c2c790c304beadeb5eeee4ba.addTo(map_593a0911f7a0d57eee06d13de2d9ee7d);
#
#
#             var feature_group_821be21f07b015d0d75ee7638def6bae = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_821be21f07b015d0d75ee7638def6bae.addTo(map_593a0911f7a0d57eee06d13de2d9ee7d);
#
#
#             var feature_group_sub_group_ed81f974ad17a98519e2c60b1dba8a3a = L.featureGroup.subGroup(
#                 feature_group_821be21f07b015d0d75ee7638def6bae
#             );
#
#
#             var marker_3108924dd05e5eb25bdf05a790d80633 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed81f974ad17a98519e2c60b1dba8a3a);
#
#
#         var popup_b0e6967cf721a8f24e0f0841a574f1fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34a45f3b8a5718e15eb705604374cf28 = $(`&lt;div id=&quot;html_34a45f3b8a5718e15eb705604374cf28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b0e6967cf721a8f24e0f0841a574f1fd.setContent(html_34a45f3b8a5718e15eb705604374cf28);
#
#
#
#         marker_3108924dd05e5eb25bdf05a790d80633.bindPopup(popup_b0e6967cf721a8f24e0f0841a574f1fd)
#         ;
#
#
#
#
#             var marker_042d092822c18231eb6343a6625ab068 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed81f974ad17a98519e2c60b1dba8a3a);
#
#
#         var popup_bc0a9ee557432fbffe4bf93d12d1f723 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c61dd223ef50b04f18d334ef73a32da = $(`&lt;div id=&quot;html_0c61dd223ef50b04f18d334ef73a32da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bc0a9ee557432fbffe4bf93d12d1f723.setContent(html_0c61dd223ef50b04f18d334ef73a32da);
#
#
#
#         marker_042d092822c18231eb6343a6625ab068.bindPopup(popup_bc0a9ee557432fbffe4bf93d12d1f723)
#         ;
#
#
#
#
#             var marker_5e881515c572cae6244de76b2b639bf5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed81f974ad17a98519e2c60b1dba8a3a);
#
#
#         var popup_aee8d1dae9d65754fa3fef25036a31b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f100adabd541ea185de3e46cb1df3b76 = $(`&lt;div id=&quot;html_f100adabd541ea185de3e46cb1df3b76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_aee8d1dae9d65754fa3fef25036a31b2.setContent(html_f100adabd541ea185de3e46cb1df3b76);
#
#
#
#         marker_5e881515c572cae6244de76b2b639bf5.bindPopup(popup_aee8d1dae9d65754fa3fef25036a31b2)
#         ;
#
#
#
#
#             var marker_3590f287167f0df74791fdfa82d000d5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed81f974ad17a98519e2c60b1dba8a3a);
#
#
#         var popup_f5050626ba8ddf40be3a604342084c30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cbad07c648fb86dd9dcbfb0a06a7fba = $(`&lt;div id=&quot;html_3cbad07c648fb86dd9dcbfb0a06a7fba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f5050626ba8ddf40be3a604342084c30.setContent(html_3cbad07c648fb86dd9dcbfb0a06a7fba);
#
#
#
#         marker_
