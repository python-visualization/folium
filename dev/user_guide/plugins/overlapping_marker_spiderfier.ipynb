# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7dfeb288cbec8ee8ace9eaf1c4c24f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7dfeb288cbec8ee8ace9eaf1c4c24f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7dfeb288cbec8ee8ace9eaf1c4c24f3 = L.map(
#                 &quot;map_c7dfeb288cbec8ee8ace9eaf1c4c24f3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_553d56248072ecd31305e826efc24b2e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_553d56248072ecd31305e826efc24b2e.addTo(map_c7dfeb288cbec8ee8ace9eaf1c4c24f3);
#
#
#             var marker_b5fddeefd2b9edd0b960b511f0e3169e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c7dfeb288cbec8ee8ace9eaf1c4c24f3);
#
#
#         var popup_08ec348571dbee5566701cbc83ad5ef2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb8ff03f6172dd1ca0d0574dab8d8a8d = $(`&lt;div id=&quot;html_fb8ff03f6172dd1ca0d0574dab8d8a8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_08ec348571dbee5566701cbc83ad5ef2.setContent(html_fb8ff03f6172dd1ca0d0574dab8d8a8d);
#
#
#
#         marker_b5fddeefd2b9edd0b960b511f0e3169e.bindPopup(popup_08ec348571dbee5566701cbc83ad5ef2)
#         ;
#
#
#
#
#             var marker_5dae4bc70802b8a6b9ced6d4b4f42b1d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c7dfeb288cbec8ee8ace9eaf1c4c24f3);
#
#
#         var popup_28448a6740a3117dfb18c3be80a97702 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_905b8ae4179f965a67fc4910e0f15d31 = $(`&lt;div id=&quot;html_905b8ae4179f965a67fc4910e0f15d31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_28448a6740a3117dfb18c3be80a97702.setContent(html_905b8ae4179f965a67fc4910e0f15d31);
#
#
#
#         marker_5dae4bc70802b8a6b9ced6d4b4f42b1d.bindPopup(popup_28448a6740a3117dfb18c3be80a97702)
#         ;
#
#
#
#
#             var marker_c2daca5ec6c1d6cf960fd8fb34ca1d45 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c7dfeb288cbec8ee8ace9eaf1c4c24f3);
#
#
#         var popup_9f66901c2fb3fe17db5fc4f2bd6c5ad7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0b2846ef96fb2e49ebe809aca0c259b = $(`&lt;div id=&quot;html_f0b2846ef96fb2e49ebe809aca0c259b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9f66901c2fb3fe17db5fc4f2bd6c5ad7.setContent(html_f0b2846ef96fb2e49ebe809aca0c259b);
#
#
#
#         marker_c2daca5ec6c1d6cf960fd8fb34ca1d45.bindPopup(popup_9f66901c2fb3fe17db5fc4f2bd6c5ad7)
#         ;
#
#
#
#
#             var marker_a2b64406ffee0b7b1583d2eaef141f5a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c7dfeb288cbec8ee8ace9eaf1c4c24f3);
#
#
#         var popup_302bfa76fde8f53aea2ac308881d0066 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_587f3f4f616bc57d18cddcc5e39200ef = $(`&lt;div id=&quot;html_587f3f4f616bc57d18cddcc5e39200ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_302bfa76fde8f53aea2ac308881d0066.setContent(html_587f3f4f616bc57d18cddcc5e39200ef);
#
#
#
#         marker_a2b64406ffee0b7b1583d2eaef141f5a.bindPopup(popup_302bfa76fde8f53aea2ac308881d0066)
#         ;
#
#
#
#
#             var marker_ee82c67f881acd021b47c93962d90aa4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c7dfeb288cbec8ee8ace9eaf1c4c24f3);
#
#
#         var popup_af51077399603c539ac19168133a2189 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9077b07d631c97e2baa6aa3f5753a05f = $(`&lt;div id=&quot;html_9077b07d631c97e2baa6aa3f5753a05f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_af51077399603c539ac19168133a2189.setContent(html_9077b07d631c97e2baa6aa3f5753a05f);
#
#
#
#         marker_ee82c67f881acd021b47c93962d90aa4.bindPopup(popup_af51077399603c539ac19168133a2189)
#         ;
#
#
#
#
#             var marker_cc6a4789f3

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6047ccea0e9a0c43d3e05373df3dcf3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6047ccea0e9a0c43d3e05373df3dcf3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6047ccea0e9a0c43d3e05373df3dcf3 = L.map(
#                 &quot;map_f6047ccea0e9a0c43d3e05373df3dcf3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a642953a8ab45a52a2d1471e7d9c8ac1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a642953a8ab45a52a2d1471e7d9c8ac1.addTo(map_f6047ccea0e9a0c43d3e05373df3dcf3);
#
#
#             var feature_group_af5e67dae82726d8a18d23c823692df2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f06665aedd335e890fa6078af05a69f1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_af5e67dae82726d8a18d23c823692df2);
#
#
#         var popup_f37bdf9b3b996fd294a75e3e817c5cf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b47e124f7049d617835df469e2ad160 = $(`&lt;div id=&quot;html_7b47e124f7049d617835df469e2ad160&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f37bdf9b3b996fd294a75e3e817c5cf2.setContent(html_7b47e124f7049d617835df469e2ad160);
#
#
#
#         marker_f06665aedd335e890fa6078af05a69f1.bindPopup(popup_f37bdf9b3b996fd294a75e3e817c5cf2)
#         ;
#
#
#
#
#             var marker_4c2c5a8e4dd4d49ff998eb4b8026cf7b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_af5e67dae82726d8a18d23c823692df2);
#
#
#         var popup_71d84dbef595cd278d8564bfe080a4c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c3d9767dc90539d798dd09f6598cc00 = $(`&lt;div id=&quot;html_1c3d9767dc90539d798dd09f6598cc00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_71d84dbef595cd278d8564bfe080a4c1.setContent(html_1c3d9767dc90539d798dd09f6598cc00);
#
#
#
#         marker_4c2c5a8e4dd4d49ff998eb4b8026cf7b.bindPopup(popup_71d84dbef595cd278d8564bfe080a4c1)
#         ;
#
#
#
#
#             var marker_e105c10a2d2a1d82322b6db7a55a93da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_af5e67dae82726d8a18d23c823692df2);
#
#
#         var popup_f707f3ef54ea73a2cf3ba26cefc51b06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bee08e5a9623dbab110def3d10a4183 = $(`&lt;div id=&quot;html_5bee08e5a9623dbab110def3d10a4183&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f707f3ef54ea73a2cf3ba26cefc51b06.setContent(html_5bee08e5a9623dbab110def3d10a4183);
#
#
#
#         marker_e105c10a2d2a1d82322b6db7a55a93da.bindPopup(popup_f707f3ef54ea73a2cf3ba26cefc51b06)
#         ;
#
#
#
#
#             var marker_c0cc811391ef4ed80cbf8033c07ecb0a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_af5e67dae82726d8a18d23c823692df2);
#
#
#         var popup_096c7fda6f3b6b71993ae38ea12a6d09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b59cf544fd0ae3cb6b5d5dbda140ec7 = $(`&lt;div id=&quot;html_1b59cf544fd0ae3cb6b5d5dbda140ec7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_096c7fda6f3b6b71993ae38ea12a6d09.setContent(html_1b59cf544fd0ae3cb6b5d5dbda140ec7);
#
#
#
#         marker_c0cc811391ef4ed80cbf8033c07ecb0a.bindPopup(popup_096c7fda6f3b6b71993ae38ea12a6d09)
#         ;
#
#
#
#
#             var marker_22ebeacea3e96cab1e42f5cd7abf0075 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_af5e67dae82726d8a18d23c823692df2);
#
#
#         var popup_ee1b6c30c4e95414f59a2b463bf8c4db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4735fc135b64c49bce5a615dc3c22018 = $(`&lt;div id=&quot;html_4735fc135b64c49bce5a615dc3c22018&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_ee1b6c30c4e95414f5

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbcfa328a3f8792cef98d84bc1e3ffad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbcfa328a3f8792cef98d84bc1e3ffad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbcfa328a3f8792cef98d84bc1e3ffad = L.map(
#                 &quot;map_fbcfa328a3f8792cef98d84bc1e3ffad&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d25663b72a067c7e8b108010b7314e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d25663b72a067c7e8b108010b7314e8.addTo(map_fbcfa328a3f8792cef98d84bc1e3ffad);
#
#
#             var feature_group_33ef97664b8d71833345a6b265849f32 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_33ef97664b8d71833345a6b265849f32.addTo(map_fbcfa328a3f8792cef98d84bc1e3ffad);
#
#
#             var feature_group_sub_group_7a78478294273aaea0a031452cad314f = L.featureGroup.subGroup(
#                 feature_group_33ef97664b8d71833345a6b265849f32
#             );
#
#
#             var marker_9c07742a5d2c8e9970c6caa7229886e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7a78478294273aaea0a031452cad314f);
#
#
#         var popup_d4367c633bac249c8c793a5ca46e63b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca448a3639588643e0768c86baadc349 = $(`&lt;div id=&quot;html_ca448a3639588643e0768c86baadc349&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d4367c633bac249c8c793a5ca46e63b8.setContent(html_ca448a3639588643e0768c86baadc349);
#
#
#
#         marker_9c07742a5d2c8e9970c6caa7229886e0.bindPopup(popup_d4367c633bac249c8c793a5ca46e63b8)
#         ;
#
#
#
#
#             var marker_4c4b5fc8f0b174774a9a9daeba78eb00 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7a78478294273aaea0a031452cad314f);
#
#
#         var popup_e1189d259c277cc9b23eec60394bfcd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4702f3b79720da6cd8f965237811336a = $(`&lt;div id=&quot;html_4702f3b79720da6cd8f965237811336a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e1189d259c277cc9b23eec60394bfcd4.setContent(html_4702f3b79720da6cd8f965237811336a);
#
#
#
#         marker_4c4b5fc8f0b174774a9a9daeba78eb00.bindPopup(popup_e1189d259c277cc9b23eec60394bfcd4)
#         ;
#
#
#
#
#             var marker_8dd1971948b4117a15f5d86651e06c56 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7a78478294273aaea0a031452cad314f);
#
#
#         var popup_d65cd7b8965f56ce699d1d12eaced8d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_439dafe902ab13ff8f67a8128f43d4bc = $(`&lt;div id=&quot;html_439dafe902ab13ff8f67a8128f43d4bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d65cd7b8965f56ce699d1d12eaced8d8.setContent(html_439dafe902ab13ff8f67a8128f43d4bc);
#
#
#
#         marker_8dd1971948b4117a15f5d86651e06c56.bindPopup(popup_d65cd7b8965f56ce699d1d12eaced8d8)
#         ;
#
#
#
#
#             var marker_e2e282fdc404126d9ae525704ff09065 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7a78478294273aaea0a031452cad314f);
#
#
#         var popup_7e320e633e48107226a06c2c2ef1c4ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f86727250021ebe0d105b4968ad5acae = $(`&lt;div id=&quot;html_f86727250021ebe0d105b4968ad5acae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7e320e633e48107226a06c2c2ef1c4ba.setContent(html_f86727250021ebe0d105b4968ad5acae);
#
#
#
#         marker_e2e282fdc404126d9ae525704ff09065.bindPopup(popup_7e320e633e48107226a06c2c2ef1c4ba)
#         ;
#
#
#
#
#             var marker_aba8d582fbec57b3e0258a3b87f7f8e3 = L.marker(
#                 [45.050399999999996, 3.0504],
