# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a3a0c34cd9a42ee90a558681531b909 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a3a0c34cd9a42ee90a558681531b909&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a3a0c34cd9a42ee90a558681531b909 = L.map(
#                 &quot;map_0a3a0c34cd9a42ee90a558681531b909&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd65c4ef136f321da87e3d65797060f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd65c4ef136f321da87e3d65797060f8.addTo(map_0a3a0c34cd9a42ee90a558681531b909);
#
#
#             var marker_3cfca8b9dc0a888f0e77c1e126e7a054 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0a3a0c34cd9a42ee90a558681531b909);
#
#
#         var popup_ca78f710671570a14c0595d44c741078 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23f9707062caaa70ebd9d853e2e38dd1 = $(`&lt;div id=&quot;html_23f9707062caaa70ebd9d853e2e38dd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ca78f710671570a14c0595d44c741078.setContent(html_23f9707062caaa70ebd9d853e2e38dd1);
#
#
#
#         marker_3cfca8b9dc0a888f0e77c1e126e7a054.bindPopup(popup_ca78f710671570a14c0595d44c741078)
#         ;
#
#
#
#
#             var marker_d94da10eade3ff1ec56f9e0f2d2540c0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0a3a0c34cd9a42ee90a558681531b909);
#
#
#         var popup_0899027f6d3f70ab7d4c7d6d75fd1dcc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1977d822c29f054b891565afd58477b9 = $(`&lt;div id=&quot;html_1977d822c29f054b891565afd58477b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0899027f6d3f70ab7d4c7d6d75fd1dcc.setContent(html_1977d822c29f054b891565afd58477b9);
#
#
#
#         marker_d94da10eade3ff1ec56f9e0f2d2540c0.bindPopup(popup_0899027f6d3f70ab7d4c7d6d75fd1dcc)
#         ;
#
#
#
#
#             var marker_ac31bf9f1c65569f4743776ce43588dd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0a3a0c34cd9a42ee90a558681531b909);
#
#
#         var popup_d6defa417f616bb85f75bf2d25c93573 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a3dfb45a8196748def5474667cce107 = $(`&lt;div id=&quot;html_8a3dfb45a8196748def5474667cce107&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d6defa417f616bb85f75bf2d25c93573.setContent(html_8a3dfb45a8196748def5474667cce107);
#
#
#
#         marker_ac31bf9f1c65569f4743776ce43588dd.bindPopup(popup_d6defa417f616bb85f75bf2d25c93573)
#         ;
#
#
#
#
#             var marker_7f2bc54320efccebb119cf67f1502800 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0a3a0c34cd9a42ee90a558681531b909);
#
#
#         var popup_0e3eb03b7518df241c927571b149d2cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a4487ce504509f93ec67ebd4e218a2e = $(`&lt;div id=&quot;html_9a4487ce504509f93ec67ebd4e218a2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0e3eb03b7518df241c927571b149d2cd.setContent(html_9a4487ce504509f93ec67ebd4e218a2e);
#
#
#
#         marker_7f2bc54320efccebb119cf67f1502800.bindPopup(popup_0e3eb03b7518df241c927571b149d2cd)
#         ;
#
#
#
#
#             var marker_269ecca9f0fc6f83c14504e982e2a6c6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0a3a0c34cd9a42ee90a558681531b909);
#
#
#         var popup_886481db377dbfd6210eed626aadb496 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_876e6ffef9675d389cc42478bb01d503 = $(`&lt;div id=&quot;html_876e6ffef9675d389cc42478bb01d503&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_886481db377dbfd6210eed626aadb496.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c59fc75252376b37273ed6ef3cc2dfa4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c59fc75252376b37273ed6ef3cc2dfa4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c59fc75252376b37273ed6ef3cc2dfa4 = L.map(
#                 &quot;map_c59fc75252376b37273ed6ef3cc2dfa4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96fe81c6d34f4d686e80b6e91cc5c33b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96fe81c6d34f4d686e80b6e91cc5c33b.addTo(map_c59fc75252376b37273ed6ef3cc2dfa4);
#
#
#             var feature_group_4a4682d4b8090d213eb627818472473e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2070336c591104fc3b3b69883b448753 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4a4682d4b8090d213eb627818472473e);
#
#
#         var popup_a489a903d22f706599f42a4084250eee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8b7eb50a610d4cf096a6bdd7abf1362 = $(`&lt;div id=&quot;html_a8b7eb50a610d4cf096a6bdd7abf1362&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a489a903d22f706599f42a4084250eee.setContent(html_a8b7eb50a610d4cf096a6bdd7abf1362);
#
#
#
#         marker_2070336c591104fc3b3b69883b448753.bindPopup(popup_a489a903d22f706599f42a4084250eee)
#         ;
#
#
#
#
#             var marker_f50aa1526e6371a762091ae7bf60f861 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4a4682d4b8090d213eb627818472473e);
#
#
#         var popup_2243767c0a01fb1270d61e9fe3e6478a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b2ab577ac2ddfddba8fcc390e992e24 = $(`&lt;div id=&quot;html_3b2ab577ac2ddfddba8fcc390e992e24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2243767c0a01fb1270d61e9fe3e6478a.setContent(html_3b2ab577ac2ddfddba8fcc390e992e24);
#
#
#
#         marker_f50aa1526e6371a762091ae7bf60f861.bindPopup(popup_2243767c0a01fb1270d61e9fe3e6478a)
#         ;
#
#
#
#
#             var marker_ec4fdf2af5d6e49f265345260c26641a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4a4682d4b8090d213eb627818472473e);
#
#
#         var popup_4fd80a11060f099c4eed81c1409d0684 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c07436ae01943187b473da34a88a3584 = $(`&lt;div id=&quot;html_c07436ae01943187b473da34a88a3584&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4fd80a11060f099c4eed81c1409d0684.setContent(html_c07436ae01943187b473da34a88a3584);
#
#
#
#         marker_ec4fdf2af5d6e49f265345260c26641a.bindPopup(popup_4fd80a11060f099c4eed81c1409d0684)
#         ;
#
#
#
#
#             var marker_da70d031747c1a7926b406506fb1324c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4a4682d4b8090d213eb627818472473e);
#
#
#         var popup_dfd9a0f45086e5bde3976c2d1a23f031 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_691acad8218abb6416c37ec54f6bc7c2 = $(`&lt;div id=&quot;html_691acad8218abb6416c37ec54f6bc7c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dfd9a0f45086e5bde3976c2d1a23f031.setContent(html_691acad8218abb6416c37ec54f6bc7c2);
#
#
#
#         marker_da70d031747c1a7926b406506fb1324c.bindPopup(popup_dfd9a0f45086e5bde3976c2d1a23f031)
#         ;
#
#
#
#
#             var marker_49b70684ce9aa98bf3c382dc6e691863 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4a4682d4b8090d213eb627818472473e);
#
#
#         var popup_3c3ddb6774f43d6fabcd2cf18c73c7ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6bfb04f852eba5286fa354988eeaa4dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6bfb04f852eba5286fa354988eeaa4dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6bfb04f852eba5286fa354988eeaa4dd = L.map(
#                 &quot;map_6bfb04f852eba5286fa354988eeaa4dd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be733691678c279f399a16b14ddf04e3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be733691678c279f399a16b14ddf04e3.addTo(map_6bfb04f852eba5286fa354988eeaa4dd);
#
#
#             var feature_group_1b02476b9fffe4a856d916b3de689418 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1b02476b9fffe4a856d916b3de689418.addTo(map_6bfb04f852eba5286fa354988eeaa4dd);
#
#
#             var feature_group_sub_group_baaaa8fa065951f92e1c77c7865c76c3 = L.featureGroup.subGroup(
#                 feature_group_1b02476b9fffe4a856d916b3de689418
#             );
#
#
#             var marker_3321d8aaf05cfe669949c9910d082c4d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_baaaa8fa065951f92e1c77c7865c76c3);
#
#
#         var popup_1879a20c13e496ba6514a06590480c25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dc4b0460097c366ac2c912aae04e7db = $(`&lt;div id=&quot;html_9dc4b0460097c366ac2c912aae04e7db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1879a20c13e496ba6514a06590480c25.setContent(html_9dc4b0460097c366ac2c912aae04e7db);
#
#
#
#         marker_3321d8aaf05cfe669949c9910d082c4d.bindPopup(popup_1879a20c13e496ba6514a06590480c25)
#         ;
#
#
#
#
#             var marker_646a3002b07d42b4fdabf1ede5796b29 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_baaaa8fa065951f92e1c77c7865c76c3);
#
#
#         var popup_06451539b2e9cc4293518ffc341df6b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72277fcf7168b8be8b0a5f30f9b3b216 = $(`&lt;div id=&quot;html_72277fcf7168b8be8b0a5f30f9b3b216&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_06451539b2e9cc4293518ffc341df6b6.setContent(html_72277fcf7168b8be8b0a5f30f9b3b216);
#
#
#
#         marker_646a3002b07d42b4fdabf1ede5796b29.bindPopup(popup_06451539b2e9cc4293518ffc341df6b6)
#         ;
#
#
#
#
#             var marker_5b21c7d38843c5faf6df02b434ae34c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_baaaa8fa065951f92e1c77c7865c76c3);
#
#
#         var popup_e1b3cd6dcd8c004e3c6a2d7479645831 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71efbb74b59455bd9f237adc1d6466bc = $(`&lt;div id=&quot;html_71efbb74b59455bd9f237adc1d6466bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e1b3cd6dcd8c004e3c6a2d7479645831.setContent(html_71efbb74b59455bd9f237adc1d6466bc);
#
#
#
#         marker_5b21c7d38843c5faf6df02b434ae34c1.bindPopup(popup_e1b3cd6dcd8c004e3c6a2d7479645831)
#         ;
#
#
#
#
#             var marker_9c288fa4633750f67bee9a8ea64b6554 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_baaaa8fa065951f92e1c77c7865c76c3);
#
#
#         var popup_0d3d4816a65ea2a04b12e1d3a92fe0ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e2c1aefbb20b861cfd671fbaa2e869d = $(`&lt;div id=&quot;html_0e2c1aefbb20b861cfd671fbaa2e869d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0d3d4816a65ea2a04b12e1d3a92fe0ee.setContent(html_0e2c1aefbb20b861cfd671fbaa2e869d);
#
#
#
#         marker_
