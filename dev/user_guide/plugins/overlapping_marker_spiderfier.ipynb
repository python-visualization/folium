# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e18c510eb19eeb0c5239ad172da39580 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e18c510eb19eeb0c5239ad172da39580&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e18c510eb19eeb0c5239ad172da39580 = L.map(
#                 &quot;map_e18c510eb19eeb0c5239ad172da39580&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6be206369784ca867e3e0d8aedd5acaf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6be206369784ca867e3e0d8aedd5acaf.addTo(map_e18c510eb19eeb0c5239ad172da39580);
#
#
#             var marker_1351377616e763953cf4b8a17a03c7be = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e18c510eb19eeb0c5239ad172da39580);
#
#
#         var popup_79c0fc1429c99d9847f2b4dc6dd80671 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e61514eb83e655deab4da90ee040f0b2 = $(`&lt;div id=&quot;html_e61514eb83e655deab4da90ee040f0b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_79c0fc1429c99d9847f2b4dc6dd80671.setContent(html_e61514eb83e655deab4da90ee040f0b2);
#
#
#
#         marker_1351377616e763953cf4b8a17a03c7be.bindPopup(popup_79c0fc1429c99d9847f2b4dc6dd80671)
#         ;
#
#
#
#
#             var marker_8980c80592ce5d8d0b53ba63103fdbb9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e18c510eb19eeb0c5239ad172da39580);
#
#
#         var popup_de82358a76135f4fa34e5bc6de8e76b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbe5f9c4233c6d96bbfa860c88e83970 = $(`&lt;div id=&quot;html_dbe5f9c4233c6d96bbfa860c88e83970&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_de82358a76135f4fa34e5bc6de8e76b9.setContent(html_dbe5f9c4233c6d96bbfa860c88e83970);
#
#
#
#         marker_8980c80592ce5d8d0b53ba63103fdbb9.bindPopup(popup_de82358a76135f4fa34e5bc6de8e76b9)
#         ;
#
#
#
#
#             var marker_03d175a9e488a579e50d3038108bf53c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e18c510eb19eeb0c5239ad172da39580);
#
#
#         var popup_32738dc062fefca5089276c80bfbff49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ceb3e7b385e82dfe76a2ff497b6810cb = $(`&lt;div id=&quot;html_ceb3e7b385e82dfe76a2ff497b6810cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_32738dc062fefca5089276c80bfbff49.setContent(html_ceb3e7b385e82dfe76a2ff497b6810cb);
#
#
#
#         marker_03d175a9e488a579e50d3038108bf53c.bindPopup(popup_32738dc062fefca5089276c80bfbff49)
#         ;
#
#
#
#
#             var marker_05dc1ad5ca198ba97c5c757d19e702fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e18c510eb19eeb0c5239ad172da39580);
#
#
#         var popup_b9f1f3ffb2f527e00d7fbff7ddd9d5f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3b6218c4ccfadf18b012d2c933677fc = $(`&lt;div id=&quot;html_d3b6218c4ccfadf18b012d2c933677fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b9f1f3ffb2f527e00d7fbff7ddd9d5f0.setContent(html_d3b6218c4ccfadf18b012d2c933677fc);
#
#
#
#         marker_05dc1ad5ca198ba97c5c757d19e702fd.bindPopup(popup_b9f1f3ffb2f527e00d7fbff7ddd9d5f0)
#         ;
#
#
#
#
#             var marker_0b6c27dcf427dba58230e25fa7492552 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e18c510eb19eeb0c5239ad172da39580);
#
#
#         var popup_3d48a75363f92255078f489f55bfeb67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_479824a5ac4a7d3b4ad88a8bc1efd65a = $(`&lt;div id=&quot;html_479824a5ac4a7d3b4ad88a8bc1efd65a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3d48a75363f92255078f489f55bfeb67.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9ad3f8e1efdacf6b14af04e1441c00b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9ad3f8e1efdacf6b14af04e1441c00b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9ad3f8e1efdacf6b14af04e1441c00b = L.map(
#                 &quot;map_d9ad3f8e1efdacf6b14af04e1441c00b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a59f493507609eeec1d9ac349e0bcc87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a59f493507609eeec1d9ac349e0bcc87.addTo(map_d9ad3f8e1efdacf6b14af04e1441c00b);
#
#
#             var feature_group_ba16647f13b3a528d4154d97d95b9adc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b4f1c470b6adc68b48784bb9653ab234 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ba16647f13b3a528d4154d97d95b9adc);
#
#
#         var popup_754d06bc1902d6912aff8a4b246ee247 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0dc5b192ea374c0645fee615a99ffa5 = $(`&lt;div id=&quot;html_b0dc5b192ea374c0645fee615a99ffa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_754d06bc1902d6912aff8a4b246ee247.setContent(html_b0dc5b192ea374c0645fee615a99ffa5);
#
#
#
#         marker_b4f1c470b6adc68b48784bb9653ab234.bindPopup(popup_754d06bc1902d6912aff8a4b246ee247)
#         ;
#
#
#
#
#             var marker_a6d1dfcda4f22633ca13d767addf03a4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ba16647f13b3a528d4154d97d95b9adc);
#
#
#         var popup_9c53065b46e1135a85c325f37aa5a039 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c7c497501efffdc434f4f603b0fdf0e = $(`&lt;div id=&quot;html_5c7c497501efffdc434f4f603b0fdf0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9c53065b46e1135a85c325f37aa5a039.setContent(html_5c7c497501efffdc434f4f603b0fdf0e);
#
#
#
#         marker_a6d1dfcda4f22633ca13d767addf03a4.bindPopup(popup_9c53065b46e1135a85c325f37aa5a039)
#         ;
#
#
#
#
#             var marker_b4a3701b6cc83520dc3781adac48cb12 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ba16647f13b3a528d4154d97d95b9adc);
#
#
#         var popup_c812d7d9cd9d2412046cd9bd54fae617 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3246169f908c27fa074c0ba1bc9f91e2 = $(`&lt;div id=&quot;html_3246169f908c27fa074c0ba1bc9f91e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c812d7d9cd9d2412046cd9bd54fae617.setContent(html_3246169f908c27fa074c0ba1bc9f91e2);
#
#
#
#         marker_b4a3701b6cc83520dc3781adac48cb12.bindPopup(popup_c812d7d9cd9d2412046cd9bd54fae617)
#         ;
#
#
#
#
#             var marker_2b877d74b521f2d443f4675a3d3aa31b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ba16647f13b3a528d4154d97d95b9adc);
#
#
#         var popup_f65b5fc90e3f53cc2e0b04923da40423 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbf78ef4903f5c52d1f6cd5bd61edd56 = $(`&lt;div id=&quot;html_cbf78ef4903f5c52d1f6cd5bd61edd56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f65b5fc90e3f53cc2e0b04923da40423.setContent(html_cbf78ef4903f5c52d1f6cd5bd61edd56);
#
#
#
#         marker_2b877d74b521f2d443f4675a3d3aa31b.bindPopup(popup_f65b5fc90e3f53cc2e0b04923da40423)
#         ;
#
#
#
#
#             var marker_8fe4e41048668a33bf770589d7df776b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ba16647f13b3a528d4154d97d95b9adc);
#
#
#         var popup_54fd8364d2ea192ff3b0b135fbd172da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37153b4848437487e307fef53ffc6393 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37153b4848437487e307fef53ffc6393&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37153b4848437487e307fef53ffc6393 = L.map(
#                 &quot;map_37153b4848437487e307fef53ffc6393&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0bbaf0b496d2dc84f782e2f88d3e39cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0bbaf0b496d2dc84f782e2f88d3e39cf.addTo(map_37153b4848437487e307fef53ffc6393);
#
#
#             var feature_group_ed74b64ea948e009b022ecea29324a66 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ed74b64ea948e009b022ecea29324a66.addTo(map_37153b4848437487e307fef53ffc6393);
#
#
#             var feature_group_sub_group_cc28ee2d0d2d8999ac73b85dc1d3069c = L.featureGroup.subGroup(
#                 feature_group_ed74b64ea948e009b022ecea29324a66
#             );
#
#
#             var marker_62fc53ae89afb86bd60ed23466716156 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc28ee2d0d2d8999ac73b85dc1d3069c);
#
#
#         var popup_193a2cfd69b36d777972306de256d3b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80fc450a7e09ba01783102888c90092b = $(`&lt;div id=&quot;html_80fc450a7e09ba01783102888c90092b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_193a2cfd69b36d777972306de256d3b7.setContent(html_80fc450a7e09ba01783102888c90092b);
#
#
#
#         marker_62fc53ae89afb86bd60ed23466716156.bindPopup(popup_193a2cfd69b36d777972306de256d3b7)
#         ;
#
#
#
#
#             var marker_eb2b412133768a517fa385f5f6abe392 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc28ee2d0d2d8999ac73b85dc1d3069c);
#
#
#         var popup_00143b61fcdc9bbe5c5aa1f1e208abd6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3d82178f86a18fe97eeb42757265fe8 = $(`&lt;div id=&quot;html_a3d82178f86a18fe97eeb42757265fe8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_00143b61fcdc9bbe5c5aa1f1e208abd6.setContent(html_a3d82178f86a18fe97eeb42757265fe8);
#
#
#
#         marker_eb2b412133768a517fa385f5f6abe392.bindPopup(popup_00143b61fcdc9bbe5c5aa1f1e208abd6)
#         ;
#
#
#
#
#             var marker_621b3c6d15b8f2ea7e5c5acbb5ce9b93 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc28ee2d0d2d8999ac73b85dc1d3069c);
#
#
#         var popup_71183fb7accb1c0bddef2af3ed2bfa76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_744c966bef8a3ff86fc3229a62b459cc = $(`&lt;div id=&quot;html_744c966bef8a3ff86fc3229a62b459cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_71183fb7accb1c0bddef2af3ed2bfa76.setContent(html_744c966bef8a3ff86fc3229a62b459cc);
#
#
#
#         marker_621b3c6d15b8f2ea7e5c5acbb5ce9b93.bindPopup(popup_71183fb7accb1c0bddef2af3ed2bfa76)
#         ;
#
#
#
#
#             var marker_485eb487927fec22b16d1cfcf39a97b1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cc28ee2d0d2d8999ac73b85dc1d3069c);
#
#
#         var popup_2c6689cbf6053d27188129d184d317d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e197039df2180b40982cbf84f9411391 = $(`&lt;div id=&quot;html_e197039df2180b40982cbf84f9411391&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2c6689cbf6053d27188129d184d317d8.setContent(html_e197039df2180b40982cbf84f9411391);
#
#
#
#         marker_
