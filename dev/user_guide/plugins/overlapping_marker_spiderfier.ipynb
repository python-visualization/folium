# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1b75b9f69a4879a15166b85655914a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1b75b9f69a4879a15166b85655914a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1b75b9f69a4879a15166b85655914a9 = L.map(
#                 &quot;map_c1b75b9f69a4879a15166b85655914a9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1ee82b10906bdb8d8381fdaaa2a9961 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e1ee82b10906bdb8d8381fdaaa2a9961.addTo(map_c1b75b9f69a4879a15166b85655914a9);
#
#
#             var marker_71137c1253927bdc90a01fdbcbb339cb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c1b75b9f69a4879a15166b85655914a9);
#
#
#         var popup_2d7bfe0d739f094e4478f46b7717746e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd6a02014e2f8c9b44d79b926d1e7396 = $(`&lt;div id=&quot;html_dd6a02014e2f8c9b44d79b926d1e7396&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2d7bfe0d739f094e4478f46b7717746e.setContent(html_dd6a02014e2f8c9b44d79b926d1e7396);
#
#
#
#         marker_71137c1253927bdc90a01fdbcbb339cb.bindPopup(popup_2d7bfe0d739f094e4478f46b7717746e)
#         ;
#
#
#
#
#             var marker_ef9a46421c6d1e260258bccd0c272ed5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c1b75b9f69a4879a15166b85655914a9);
#
#
#         var popup_f36d52acfab95a6b2506800b76ba8e91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcc0b0380dc9293ddc07f3037cad22ac = $(`&lt;div id=&quot;html_bcc0b0380dc9293ddc07f3037cad22ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f36d52acfab95a6b2506800b76ba8e91.setContent(html_bcc0b0380dc9293ddc07f3037cad22ac);
#
#
#
#         marker_ef9a46421c6d1e260258bccd0c272ed5.bindPopup(popup_f36d52acfab95a6b2506800b76ba8e91)
#         ;
#
#
#
#
#             var marker_1e5fff2651875b302fda0e40f1fe89cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c1b75b9f69a4879a15166b85655914a9);
#
#
#         var popup_a18632d17c7fd40e94d49601e35428ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d131dcf61b75c9b9059a3be88d7d17d = $(`&lt;div id=&quot;html_6d131dcf61b75c9b9059a3be88d7d17d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a18632d17c7fd40e94d49601e35428ea.setContent(html_6d131dcf61b75c9b9059a3be88d7d17d);
#
#
#
#         marker_1e5fff2651875b302fda0e40f1fe89cf.bindPopup(popup_a18632d17c7fd40e94d49601e35428ea)
#         ;
#
#
#
#
#             var marker_5810fc6d22b3201f05f8836bfbb1e0f5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c1b75b9f69a4879a15166b85655914a9);
#
#
#         var popup_3969ce76e301a723772e36ac87332727 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc8bde6d61950f48c833601172d472fa = $(`&lt;div id=&quot;html_cc8bde6d61950f48c833601172d472fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3969ce76e301a723772e36ac87332727.setContent(html_cc8bde6d61950f48c833601172d472fa);
#
#
#
#         marker_5810fc6d22b3201f05f8836bfbb1e0f5.bindPopup(popup_3969ce76e301a723772e36ac87332727)
#         ;
#
#
#
#
#             var marker_8f9820a9d5c203cb7a9f1b18aba59596 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c1b75b9f69a4879a15166b85655914a9);
#
#
#         var popup_a30c7f858da1a48e5db15d0665d8784a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39f49c6be871edc6b2aa14a348a44c97 = $(`&lt;div id=&quot;html_39f49c6be871edc6b2aa14a348a44c97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a30c7f858da1a48e5db15d0665d8784a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8aba09d8383fde6f301c179fbd1b42e7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8aba09d8383fde6f301c179fbd1b42e7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8aba09d8383fde6f301c179fbd1b42e7 = L.map(
#                 &quot;map_8aba09d8383fde6f301c179fbd1b42e7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14112643065e3e02244a25f36b010680 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_14112643065e3e02244a25f36b010680.addTo(map_8aba09d8383fde6f301c179fbd1b42e7);
#
#
#             var feature_group_6ee4ec897121e6c7e656f15fa3ea9029 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8f8420c3832e585e19532e2314d2c3ae = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6ee4ec897121e6c7e656f15fa3ea9029);
#
#
#         var popup_8e77b3521669129959650a9b491b5159 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5775018fdeb93d2c1eaa6253547eed5d = $(`&lt;div id=&quot;html_5775018fdeb93d2c1eaa6253547eed5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8e77b3521669129959650a9b491b5159.setContent(html_5775018fdeb93d2c1eaa6253547eed5d);
#
#
#
#         marker_8f8420c3832e585e19532e2314d2c3ae.bindPopup(popup_8e77b3521669129959650a9b491b5159)
#         ;
#
#
#
#
#             var marker_34e14dc51b63383bd3a61b6c98563a14 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6ee4ec897121e6c7e656f15fa3ea9029);
#
#
#         var popup_c86423c81a0a7cb03d5b7b876bf4d2c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb0fb9af5201241f8256ab27793bd2ba = $(`&lt;div id=&quot;html_eb0fb9af5201241f8256ab27793bd2ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c86423c81a0a7cb03d5b7b876bf4d2c6.setContent(html_eb0fb9af5201241f8256ab27793bd2ba);
#
#
#
#         marker_34e14dc51b63383bd3a61b6c98563a14.bindPopup(popup_c86423c81a0a7cb03d5b7b876bf4d2c6)
#         ;
#
#
#
#
#             var marker_2540aebd0394d2dfb882216d542d50be = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6ee4ec897121e6c7e656f15fa3ea9029);
#
#
#         var popup_7384d82d9cc203adf0e06538cd91f167 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25e8b5bcca937c3b6f0d5b5182ea7c40 = $(`&lt;div id=&quot;html_25e8b5bcca937c3b6f0d5b5182ea7c40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7384d82d9cc203adf0e06538cd91f167.setContent(html_25e8b5bcca937c3b6f0d5b5182ea7c40);
#
#
#
#         marker_2540aebd0394d2dfb882216d542d50be.bindPopup(popup_7384d82d9cc203adf0e06538cd91f167)
#         ;
#
#
#
#
#             var marker_a67b41fd2b7dab22b5a798a7b7a34507 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6ee4ec897121e6c7e656f15fa3ea9029);
#
#
#         var popup_4bb1fb22d68e420e2005f3be5981a541 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54ad25b1b4a4d7488128f952b7cc4ac3 = $(`&lt;div id=&quot;html_54ad25b1b4a4d7488128f952b7cc4ac3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4bb1fb22d68e420e2005f3be5981a541.setContent(html_54ad25b1b4a4d7488128f952b7cc4ac3);
#
#
#
#         marker_a67b41fd2b7dab22b5a798a7b7a34507.bindPopup(popup_4bb1fb22d68e420e2005f3be5981a541)
#         ;
#
#
#
#
#             var marker_d2402ea01a0ff3f78b4d0a949de35352 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6ee4ec897121e6c7e656f15fa3ea9029);
#
#
#         var popup_aed640b253f8493fc52fbbf1beb8798c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dcbc8ccfb72ca350b198d76c8d2e6e26 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dcbc8ccfb72ca350b198d76c8d2e6e26&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dcbc8ccfb72ca350b198d76c8d2e6e26 = L.map(
#                 &quot;map_dcbc8ccfb72ca350b198d76c8d2e6e26&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c1e0c5d1637bd0ee179aee9b0f892e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c1e0c5d1637bd0ee179aee9b0f892e0.addTo(map_dcbc8ccfb72ca350b198d76c8d2e6e26);
#
#
#             var feature_group_0610fa51f1a551f339b83d7034209135 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0610fa51f1a551f339b83d7034209135.addTo(map_dcbc8ccfb72ca350b198d76c8d2e6e26);
#
#
#             var feature_group_sub_group_2e5ee844d10bbbe40d7699c984814ee1 = L.featureGroup.subGroup(
#                 feature_group_0610fa51f1a551f339b83d7034209135
#             );
#
#
#             var marker_ab69bc0c80950809753daeb3dddaac3d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e5ee844d10bbbe40d7699c984814ee1);
#
#
#         var popup_54507797adee57a6fb66c47263b1f8e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_375bb9a4a72e13bd9c9683483c283a3c = $(`&lt;div id=&quot;html_375bb9a4a72e13bd9c9683483c283a3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_54507797adee57a6fb66c47263b1f8e6.setContent(html_375bb9a4a72e13bd9c9683483c283a3c);
#
#
#
#         marker_ab69bc0c80950809753daeb3dddaac3d.bindPopup(popup_54507797adee57a6fb66c47263b1f8e6)
#         ;
#
#
#
#
#             var marker_48e5be2f8e89560ba16b72a27cacd27c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e5ee844d10bbbe40d7699c984814ee1);
#
#
#         var popup_6c5c81088f4a8c1084da67ef1c4ddd5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adec7f73ef9b8e2b32d8af998c165b7a = $(`&lt;div id=&quot;html_adec7f73ef9b8e2b32d8af998c165b7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6c5c81088f4a8c1084da67ef1c4ddd5c.setContent(html_adec7f73ef9b8e2b32d8af998c165b7a);
#
#
#
#         marker_48e5be2f8e89560ba16b72a27cacd27c.bindPopup(popup_6c5c81088f4a8c1084da67ef1c4ddd5c)
#         ;
#
#
#
#
#             var marker_18d7f4e3c93add379951e037851baf91 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e5ee844d10bbbe40d7699c984814ee1);
#
#
#         var popup_3fbeef42757765bed099acf579da2ab6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7176b3a81883ef6a481b7fffd3c8aa06 = $(`&lt;div id=&quot;html_7176b3a81883ef6a481b7fffd3c8aa06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3fbeef42757765bed099acf579da2ab6.setContent(html_7176b3a81883ef6a481b7fffd3c8aa06);
#
#
#
#         marker_18d7f4e3c93add379951e037851baf91.bindPopup(popup_3fbeef42757765bed099acf579da2ab6)
#         ;
#
#
#
#
#             var marker_7d010177cfdf622a9e90ceb90f78eb82 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e5ee844d10bbbe40d7699c984814ee1);
#
#
#         var popup_76d13f0ca05aa9d8020338aa280984de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33b2121bf0c0a021028e7b347156d407 = $(`&lt;div id=&quot;html_33b2121bf0c0a021028e7b347156d407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_76d13f0ca05aa9d8020338aa280984de.setContent(html_33b2121bf0c0a021028e7b347156d407);
#
#
#
#         marker_
