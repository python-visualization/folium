# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6acfdeb8a8be814e1748428231943df4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6acfdeb8a8be814e1748428231943df4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6acfdeb8a8be814e1748428231943df4 = L.map(
#                 &quot;map_6acfdeb8a8be814e1748428231943df4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_425216eaf7dcca0c475df60006d0bff5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_425216eaf7dcca0c475df60006d0bff5.addTo(map_6acfdeb8a8be814e1748428231943df4);
#
#
#             var marker_8a7cc08851a9bf0c4d72ac6a8544c791 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6acfdeb8a8be814e1748428231943df4);
#
#
#         var popup_d38fab411b7f463aa040ad2296b84f58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86a267d2756b9ee4934f81de0ec393a7 = $(`&lt;div id=&quot;html_86a267d2756b9ee4934f81de0ec393a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d38fab411b7f463aa040ad2296b84f58.setContent(html_86a267d2756b9ee4934f81de0ec393a7);
#
#
#
#         marker_8a7cc08851a9bf0c4d72ac6a8544c791.bindPopup(popup_d38fab411b7f463aa040ad2296b84f58)
#         ;
#
#
#
#
#             var marker_99267f67e1d980cc730edbcf90483a43 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6acfdeb8a8be814e1748428231943df4);
#
#
#         var popup_af88505dd6429f75190996425ceff749 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e057d078174a80c5ffb1eae7ae987be = $(`&lt;div id=&quot;html_2e057d078174a80c5ffb1eae7ae987be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_af88505dd6429f75190996425ceff749.setContent(html_2e057d078174a80c5ffb1eae7ae987be);
#
#
#
#         marker_99267f67e1d980cc730edbcf90483a43.bindPopup(popup_af88505dd6429f75190996425ceff749)
#         ;
#
#
#
#
#             var marker_e1b5abfe31525b55e0893a4c6a5854d1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6acfdeb8a8be814e1748428231943df4);
#
#
#         var popup_388dab78d1d84f2b9ef398c0bc210002 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e04dd5bd332c45f095f4eb0ec42dfb44 = $(`&lt;div id=&quot;html_e04dd5bd332c45f095f4eb0ec42dfb44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_388dab78d1d84f2b9ef398c0bc210002.setContent(html_e04dd5bd332c45f095f4eb0ec42dfb44);
#
#
#
#         marker_e1b5abfe31525b55e0893a4c6a5854d1.bindPopup(popup_388dab78d1d84f2b9ef398c0bc210002)
#         ;
#
#
#
#
#             var marker_1e45083819d396fd959c58dacd8e252b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6acfdeb8a8be814e1748428231943df4);
#
#
#         var popup_db2ac10b2c54609f189c65d3d1a75f23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1e80d064262a90dfb8d9f38e556d875 = $(`&lt;div id=&quot;html_e1e80d064262a90dfb8d9f38e556d875&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_db2ac10b2c54609f189c65d3d1a75f23.setContent(html_e1e80d064262a90dfb8d9f38e556d875);
#
#
#
#         marker_1e45083819d396fd959c58dacd8e252b.bindPopup(popup_db2ac10b2c54609f189c65d3d1a75f23)
#         ;
#
#
#
#
#             var marker_e8e39098f18c9a58454de565ae9c7d9a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6acfdeb8a8be814e1748428231943df4);
#
#
#         var popup_bb153cbda8a316e05d73e3161267ee08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_575477c86f435e9319f5e2bb0180839e = $(`&lt;div id=&quot;html_575477c86f435e9319f5e2bb0180839e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bb153cbda8a316e05d73e3161267ee08.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_46b33e0a260f561187f72e73328f1bfd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_46b33e0a260f561187f72e73328f1bfd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_46b33e0a260f561187f72e73328f1bfd = L.map(
#                 &quot;map_46b33e0a260f561187f72e73328f1bfd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80b2fc7dccecc03fff2174551853878c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_80b2fc7dccecc03fff2174551853878c.addTo(map_46b33e0a260f561187f72e73328f1bfd);
#
#
#             var feature_group_48e15d628bc60c1156f12227e54642c8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fcaf5ac28891d35a807b0f83653a57bc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_48e15d628bc60c1156f12227e54642c8);
#
#
#         var popup_4580b90cdba6762738c1b138a6ad0a58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73b4e27fcabb2d10fbbf63f9468da3bf = $(`&lt;div id=&quot;html_73b4e27fcabb2d10fbbf63f9468da3bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4580b90cdba6762738c1b138a6ad0a58.setContent(html_73b4e27fcabb2d10fbbf63f9468da3bf);
#
#
#
#         marker_fcaf5ac28891d35a807b0f83653a57bc.bindPopup(popup_4580b90cdba6762738c1b138a6ad0a58)
#         ;
#
#
#
#
#             var marker_71fd2f4ca2040115f7c9fd3a0e47d3cf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_48e15d628bc60c1156f12227e54642c8);
#
#
#         var popup_b04c2b6b400f0233113cd5e75453d5ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b81c2e942104092362fe125f449f059e = $(`&lt;div id=&quot;html_b81c2e942104092362fe125f449f059e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b04c2b6b400f0233113cd5e75453d5ee.setContent(html_b81c2e942104092362fe125f449f059e);
#
#
#
#         marker_71fd2f4ca2040115f7c9fd3a0e47d3cf.bindPopup(popup_b04c2b6b400f0233113cd5e75453d5ee)
#         ;
#
#
#
#
#             var marker_8a726d87f27cecaca7745391f751a1ad = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_48e15d628bc60c1156f12227e54642c8);
#
#
#         var popup_6de151203ae9e7717d20aded54e9761b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17302c7389e9f4a2ddbce49d86ad0460 = $(`&lt;div id=&quot;html_17302c7389e9f4a2ddbce49d86ad0460&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6de151203ae9e7717d20aded54e9761b.setContent(html_17302c7389e9f4a2ddbce49d86ad0460);
#
#
#
#         marker_8a726d87f27cecaca7745391f751a1ad.bindPopup(popup_6de151203ae9e7717d20aded54e9761b)
#         ;
#
#
#
#
#             var marker_8829b21f7cb061a473345cd1ad801e00 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_48e15d628bc60c1156f12227e54642c8);
#
#
#         var popup_f2aeca1aee362b2086b453d69cf752af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e094d9ae441a3a0d1adfa5f6aada01b0 = $(`&lt;div id=&quot;html_e094d9ae441a3a0d1adfa5f6aada01b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f2aeca1aee362b2086b453d69cf752af.setContent(html_e094d9ae441a3a0d1adfa5f6aada01b0);
#
#
#
#         marker_8829b21f7cb061a473345cd1ad801e00.bindPopup(popup_f2aeca1aee362b2086b453d69cf752af)
#         ;
#
#
#
#
#             var marker_2eded51b766eec95e4d28976f39dd6bd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_48e15d628bc60c1156f12227e54642c8);
#
#
#         var popup_7fcb1e524a5be48699652c61b4650947 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_578f36e8c3e706e4315672a0ab67ea93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_578f36e8c3e706e4315672a0ab67ea93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_578f36e8c3e706e4315672a0ab67ea93 = L.map(
#                 &quot;map_578f36e8c3e706e4315672a0ab67ea93&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be26006fa04c86d7122d74ef4d3f1b12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be26006fa04c86d7122d74ef4d3f1b12.addTo(map_578f36e8c3e706e4315672a0ab67ea93);
#
#
#             var feature_group_f61467fc60becbdbb01d869f2cdfbcab = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f61467fc60becbdbb01d869f2cdfbcab.addTo(map_578f36e8c3e706e4315672a0ab67ea93);
#
#
#             var feature_group_sub_group_406a034a7e3deacf7bfac9fed2eef423 = L.featureGroup.subGroup(
#                 feature_group_f61467fc60becbdbb01d869f2cdfbcab
#             );
#
#
#             var marker_b4af8c4a8af2115b3f408489eb68ae37 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_406a034a7e3deacf7bfac9fed2eef423);
#
#
#         var popup_1dddcf02b82a2fe5e495d175d6e83830 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7d88d94c372e932d36bde55c6280e35 = $(`&lt;div id=&quot;html_f7d88d94c372e932d36bde55c6280e35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1dddcf02b82a2fe5e495d175d6e83830.setContent(html_f7d88d94c372e932d36bde55c6280e35);
#
#
#
#         marker_b4af8c4a8af2115b3f408489eb68ae37.bindPopup(popup_1dddcf02b82a2fe5e495d175d6e83830)
#         ;
#
#
#
#
#             var marker_f94604f0dabdb78edf01de0adeab6ce7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_406a034a7e3deacf7bfac9fed2eef423);
#
#
#         var popup_be8871ced70a7176837cb1f39dcf4531 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9412534c87150d4bc9667c12ff892dae = $(`&lt;div id=&quot;html_9412534c87150d4bc9667c12ff892dae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_be8871ced70a7176837cb1f39dcf4531.setContent(html_9412534c87150d4bc9667c12ff892dae);
#
#
#
#         marker_f94604f0dabdb78edf01de0adeab6ce7.bindPopup(popup_be8871ced70a7176837cb1f39dcf4531)
#         ;
#
#
#
#
#             var marker_76532244c6ae9a179ad2afd6afcbdc72 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_406a034a7e3deacf7bfac9fed2eef423);
#
#
#         var popup_51f87458334c065d4e26d496496b9795 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e407f56e079c46b965737e3e315bcf5e = $(`&lt;div id=&quot;html_e407f56e079c46b965737e3e315bcf5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_51f87458334c065d4e26d496496b9795.setContent(html_e407f56e079c46b965737e3e315bcf5e);
#
#
#
#         marker_76532244c6ae9a179ad2afd6afcbdc72.bindPopup(popup_51f87458334c065d4e26d496496b9795)
#         ;
#
#
#
#
#             var marker_809cbec2503d09e1f6e1f6b2160dead2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_406a034a7e3deacf7bfac9fed2eef423);
#
#
#         var popup_4d9f63f3570d2872859d3f8948a491fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2365fb367e80dfd5328feba68d32e83 = $(`&lt;div id=&quot;html_e2365fb367e80dfd5328feba68d32e83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4d9f63f3570d2872859d3f8948a491fa.setContent(html_e2365fb367e80dfd5328feba68d32e83);
#
#
#
#         marker_
