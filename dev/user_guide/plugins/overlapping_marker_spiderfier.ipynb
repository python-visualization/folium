# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1abec4ad5112200514950923baa6093c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1abec4ad5112200514950923baa6093c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1abec4ad5112200514950923baa6093c = L.map(
#                 &quot;map_1abec4ad5112200514950923baa6093c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9e36abd890465afacf9d82766afe5bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b9e36abd890465afacf9d82766afe5bf.addTo(map_1abec4ad5112200514950923baa6093c);
#
#
#             var marker_cf3f49260b671a1b7340bc734032bcd4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1abec4ad5112200514950923baa6093c);
#
#
#         var popup_91f9ea65bccbad6898abf5b5de5aba5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce63db9085338b67a9c86ceadd68e67c = $(`&lt;div id=&quot;html_ce63db9085338b67a9c86ceadd68e67c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_91f9ea65bccbad6898abf5b5de5aba5c.setContent(html_ce63db9085338b67a9c86ceadd68e67c);
#
#
#
#         marker_cf3f49260b671a1b7340bc734032bcd4.bindPopup(popup_91f9ea65bccbad6898abf5b5de5aba5c)
#         ;
#
#
#
#
#             var marker_fd830c9622259a739a28c50134118b27 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1abec4ad5112200514950923baa6093c);
#
#
#         var popup_77a8070f56fd5312522a190f240a8efc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82a9c307d97753e4844a3142e1004abe = $(`&lt;div id=&quot;html_82a9c307d97753e4844a3142e1004abe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_77a8070f56fd5312522a190f240a8efc.setContent(html_82a9c307d97753e4844a3142e1004abe);
#
#
#
#         marker_fd830c9622259a739a28c50134118b27.bindPopup(popup_77a8070f56fd5312522a190f240a8efc)
#         ;
#
#
#
#
#             var marker_bfa9171e0ca4c62783b515a709ba1b7f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1abec4ad5112200514950923baa6093c);
#
#
#         var popup_8321dd16ab950451d8aa3cf93227633a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f31fbd4945780e966b8db3d9dc5e40db = $(`&lt;div id=&quot;html_f31fbd4945780e966b8db3d9dc5e40db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8321dd16ab950451d8aa3cf93227633a.setContent(html_f31fbd4945780e966b8db3d9dc5e40db);
#
#
#
#         marker_bfa9171e0ca4c62783b515a709ba1b7f.bindPopup(popup_8321dd16ab950451d8aa3cf93227633a)
#         ;
#
#
#
#
#             var marker_96c9f6f7a466338183b7347618edf762 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1abec4ad5112200514950923baa6093c);
#
#
#         var popup_adf498286f213909ca6236b40fcfaa95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca91a092fb8f975ffb621349909ec203 = $(`&lt;div id=&quot;html_ca91a092fb8f975ffb621349909ec203&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_adf498286f213909ca6236b40fcfaa95.setContent(html_ca91a092fb8f975ffb621349909ec203);
#
#
#
#         marker_96c9f6f7a466338183b7347618edf762.bindPopup(popup_adf498286f213909ca6236b40fcfaa95)
#         ;
#
#
#
#
#             var marker_ed095870215e45d9748fd56db797e6b7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1abec4ad5112200514950923baa6093c);
#
#
#         var popup_0cdcac991d512d482f9cc66dd1c96227 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f365750e57d875fd555a9ff165cb680c = $(`&lt;div id=&quot;html_f365750e57d875fd555a9ff165cb680c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0cdcac991d512d482f9cc66dd1c962

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_15faeacc077651de1fc30d9eda457196 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_15faeacc077651de1fc30d9eda457196&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_15faeacc077651de1fc30d9eda457196 = L.map(
#                 &quot;map_15faeacc077651de1fc30d9eda457196&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4719bd0e984e4a4cea367fa9f9df85cf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4719bd0e984e4a4cea367fa9f9df85cf.addTo(map_15faeacc077651de1fc30d9eda457196);
#
#
#             var feature_group_89100266abb6afbd8525de56cde0f440 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0eb1fd8d723ec43bb80de0c8ba3f183d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_89100266abb6afbd8525de56cde0f440);
#
#
#         var popup_30c1b4ab988455b946c92b9affa847eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef228be99b2a8355eb3a1b6a11883db2 = $(`&lt;div id=&quot;html_ef228be99b2a8355eb3a1b6a11883db2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_30c1b4ab988455b946c92b9affa847eb.setContent(html_ef228be99b2a8355eb3a1b6a11883db2);
#
#
#
#         marker_0eb1fd8d723ec43bb80de0c8ba3f183d.bindPopup(popup_30c1b4ab988455b946c92b9affa847eb)
#         ;
#
#
#
#
#             var marker_2187fb8005f14bb916722bdf69cb6f92 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_89100266abb6afbd8525de56cde0f440);
#
#
#         var popup_fe73bad5f26b368ba16022faa0841a4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce848de8787295ccd3b6cf19cdf334c0 = $(`&lt;div id=&quot;html_ce848de8787295ccd3b6cf19cdf334c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fe73bad5f26b368ba16022faa0841a4e.setContent(html_ce848de8787295ccd3b6cf19cdf334c0);
#
#
#
#         marker_2187fb8005f14bb916722bdf69cb6f92.bindPopup(popup_fe73bad5f26b368ba16022faa0841a4e)
#         ;
#
#
#
#
#             var marker_e8c57e1a978589a877689866d4a9ca39 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_89100266abb6afbd8525de56cde0f440);
#
#
#         var popup_ec529b8a1eed840794b6a6761051c484 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f931792185e0a65012e4ae0c1ba7140 = $(`&lt;div id=&quot;html_8f931792185e0a65012e4ae0c1ba7140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ec529b8a1eed840794b6a6761051c484.setContent(html_8f931792185e0a65012e4ae0c1ba7140);
#
#
#
#         marker_e8c57e1a978589a877689866d4a9ca39.bindPopup(popup_ec529b8a1eed840794b6a6761051c484)
#         ;
#
#
#
#
#             var marker_aa1df393151c742ef27c88d440d727b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_89100266abb6afbd8525de56cde0f440);
#
#
#         var popup_bb451fa27b8d798b58b1bc5cf129024c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16c7aa34043f16d999c174d3b292642e = $(`&lt;div id=&quot;html_16c7aa34043f16d999c174d3b292642e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bb451fa27b8d798b58b1bc5cf129024c.setContent(html_16c7aa34043f16d999c174d3b292642e);
#
#
#
#         marker_aa1df393151c742ef27c88d440d727b3.bindPopup(popup_bb451fa27b8d798b58b1bc5cf129024c)
#         ;
#
#
#
#
#             var marker_742c019f95a4bf321ec92aef59258850 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_89100266abb6afbd8525de56cde0f440);
#
#
#         var popup_1fde19c1644dfcf83dd6521331c91b61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bd71313aab104372c19468b6b6556e4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bd71313aab104372c19468b6b6556e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bd71313aab104372c19468b6b6556e4 = L.map(
#                 &quot;map_8bd71313aab104372c19468b6b6556e4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e752dd33c5586a198b017cb8a9bcb901 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e752dd33c5586a198b017cb8a9bcb901.addTo(map_8bd71313aab104372c19468b6b6556e4);
#
#
#             var feature_group_cb1885fe993691f7fb3a4a4c3e635bcb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cb1885fe993691f7fb3a4a4c3e635bcb.addTo(map_8bd71313aab104372c19468b6b6556e4);
#
#
#             var feature_group_sub_group_2b51c8c7f7492555a6696f2992eb1580 = L.featureGroup.subGroup(
#                 feature_group_cb1885fe993691f7fb3a4a4c3e635bcb
#             );
#
#
#             var marker_17691d863977938c729609c28a6ea391 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b51c8c7f7492555a6696f2992eb1580);
#
#
#         var popup_8bed55b040214c0873e8bcbb5832f0c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebeaf85119dd2072363b0d12ea620579 = $(`&lt;div id=&quot;html_ebeaf85119dd2072363b0d12ea620579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8bed55b040214c0873e8bcbb5832f0c7.setContent(html_ebeaf85119dd2072363b0d12ea620579);
#
#
#
#         marker_17691d863977938c729609c28a6ea391.bindPopup(popup_8bed55b040214c0873e8bcbb5832f0c7)
#         ;
#
#
#
#
#             var marker_4f7b2f216b7e8bf00c4c2033fdd461f2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b51c8c7f7492555a6696f2992eb1580);
#
#
#         var popup_a886f5d5ea091600868bbb5e1b68a066 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f04f6b07e16f86bad70a30906217dfd = $(`&lt;div id=&quot;html_0f04f6b07e16f86bad70a30906217dfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a886f5d5ea091600868bbb5e1b68a066.setContent(html_0f04f6b07e16f86bad70a30906217dfd);
#
#
#
#         marker_4f7b2f216b7e8bf00c4c2033fdd461f2.bindPopup(popup_a886f5d5ea091600868bbb5e1b68a066)
#         ;
#
#
#
#
#             var marker_80d6ff2dd85e82f6b4731875011528c2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b51c8c7f7492555a6696f2992eb1580);
#
#
#         var popup_a6519940d325324cdebdabcefab36009 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd86ac86ffe49cf5c2f2c8c2d569f2b2 = $(`&lt;div id=&quot;html_dd86ac86ffe49cf5c2f2c8c2d569f2b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a6519940d325324cdebdabcefab36009.setContent(html_dd86ac86ffe49cf5c2f2c8c2d569f2b2);
#
#
#
#         marker_80d6ff2dd85e82f6b4731875011528c2.bindPopup(popup_a6519940d325324cdebdabcefab36009)
#         ;
#
#
#
#
#             var marker_178e7e4770e4fc5294f68f183849b9c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b51c8c7f7492555a6696f2992eb1580);
#
#
#         var popup_23cf02759f5e8502acac0269a69dceac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b508e8c2ccde9e1acc3665843c63dc78 = $(`&lt;div id=&quot;html_b508e8c2ccde9e1acc3665843c63dc78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_23cf02759f5e8502acac0269a69dceac.setContent(html_b508e8c2ccde9e1acc3665843c63dc78);
#
#
#
#         mark
