# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b42b36cbc233b3ef59874383fe409b7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b42b36cbc233b3ef59874383fe409b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b42b36cbc233b3ef59874383fe409b7 = L.map(
#                 &quot;map_5b42b36cbc233b3ef59874383fe409b7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d8e081b370bb0f6880ffbbce621cede = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d8e081b370bb0f6880ffbbce621cede.addTo(map_5b42b36cbc233b3ef59874383fe409b7);
#
#
#             var marker_d41676916a5af5ce35eba46f3bee96b0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5b42b36cbc233b3ef59874383fe409b7);
#
#
#         var popup_76908d69b96b070e991e2eb8d4ede3cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dc314d8bc90b61f9ae31b8491ea99bb = $(`&lt;div id=&quot;html_9dc314d8bc90b61f9ae31b8491ea99bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_76908d69b96b070e991e2eb8d4ede3cc.setContent(html_9dc314d8bc90b61f9ae31b8491ea99bb);
#
#
#
#         marker_d41676916a5af5ce35eba46f3bee96b0.bindPopup(popup_76908d69b96b070e991e2eb8d4ede3cc)
#         ;
#
#
#
#
#             var marker_31b74dbf49ecb4482824cafaf5b195ff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5b42b36cbc233b3ef59874383fe409b7);
#
#
#         var popup_2a895db09fb54d08f5becf214e1ee298 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8920f523bcfdd5861928c945f7e4b986 = $(`&lt;div id=&quot;html_8920f523bcfdd5861928c945f7e4b986&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2a895db09fb54d08f5becf214e1ee298.setContent(html_8920f523bcfdd5861928c945f7e4b986);
#
#
#
#         marker_31b74dbf49ecb4482824cafaf5b195ff.bindPopup(popup_2a895db09fb54d08f5becf214e1ee298)
#         ;
#
#
#
#
#             var marker_4a1db0b8fcd9e54e2965a16d64af31d7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5b42b36cbc233b3ef59874383fe409b7);
#
#
#         var popup_11d71f2b127016daddd2fe330bdb7740 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_623a6d3937b4fc374edf5b6e721fcb7a = $(`&lt;div id=&quot;html_623a6d3937b4fc374edf5b6e721fcb7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_11d71f2b127016daddd2fe330bdb7740.setContent(html_623a6d3937b4fc374edf5b6e721fcb7a);
#
#
#
#         marker_4a1db0b8fcd9e54e2965a16d64af31d7.bindPopup(popup_11d71f2b127016daddd2fe330bdb7740)
#         ;
#
#
#
#
#             var marker_658f6c9a053951755708ee39ef6be65a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5b42b36cbc233b3ef59874383fe409b7);
#
#
#         var popup_7f0b1847cb6162695aefa4bb0d41464b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36d5593fdae73b76a84d7cd44718babb = $(`&lt;div id=&quot;html_36d5593fdae73b76a84d7cd44718babb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7f0b1847cb6162695aefa4bb0d41464b.setContent(html_36d5593fdae73b76a84d7cd44718babb);
#
#
#
#         marker_658f6c9a053951755708ee39ef6be65a.bindPopup(popup_7f0b1847cb6162695aefa4bb0d41464b)
#         ;
#
#
#
#
#             var marker_29a7607bdb04efaf9c90a92ca4912363 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5b42b36cbc233b3ef59874383fe409b7);
#
#
#         var popup_fb9bacc37ce69e3bfede8faa79a74115 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2177979076ef293699a608b75b10ecac = $(`&lt;div id=&quot;html_2177979076ef293699a608b75b10ecac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fb9bacc37ce69e3bfede8faa79a74115.setContent(html_2177979076ef293699a608b75b10ecac);
#
#
#
#         marker_29a7607bdb04efaf9c90a92ca4912363.bindPopup(popup_fb9bacc37ce69e3bfede8faa79a74115)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5ca11182fca50b037433f9f902aebab {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5ca11182fca50b037433f9f902aebab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5ca11182fca50b037433f9f902aebab = L.map(
#                 &quot;map_b5ca11182fca50b037433f9f902aebab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1dc6d65c60e32f23f7c8774cc9871e36 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1dc6d65c60e32f23f7c8774cc9871e36.addTo(map_b5ca11182fca50b037433f9f902aebab);
#
#
#             var feature_group_7a442788adf32ef55f7418fac416d036 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e20c738bce8c33cf23b4a5e71868d813 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7a442788adf32ef55f7418fac416d036);
#
#
#         var popup_8c1b4246e97e240e10a34597f86cb9b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e563afeb59ee3b9f20e14a457e007277 = $(`&lt;div id=&quot;html_e563afeb59ee3b9f20e14a457e007277&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8c1b4246e97e240e10a34597f86cb9b4.setContent(html_e563afeb59ee3b9f20e14a457e007277);
#
#
#
#         marker_e20c738bce8c33cf23b4a5e71868d813.bindPopup(popup_8c1b4246e97e240e10a34597f86cb9b4)
#         ;
#
#
#
#
#             var marker_db18d7ed6cf8ff291fed316ce61ba024 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7a442788adf32ef55f7418fac416d036);
#
#
#         var popup_3331d4da7d6427ad2bc34b2149f01292 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3572465c8034672bdd2339fb663f168f = $(`&lt;div id=&quot;html_3572465c8034672bdd2339fb663f168f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3331d4da7d6427ad2bc34b2149f01292.setContent(html_3572465c8034672bdd2339fb663f168f);
#
#
#
#         marker_db18d7ed6cf8ff291fed316ce61ba024.bindPopup(popup_3331d4da7d6427ad2bc34b2149f01292)
#         ;
#
#
#
#
#             var marker_cb77aa0c9054f1812dd23b42e0812446 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7a442788adf32ef55f7418fac416d036);
#
#
#         var popup_a227c45ed99e2645f89a82fb8f992f65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e96f99eb3ac39361254b38371609f716 = $(`&lt;div id=&quot;html_e96f99eb3ac39361254b38371609f716&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a227c45ed99e2645f89a82fb8f992f65.setContent(html_e96f99eb3ac39361254b38371609f716);
#
#
#
#         marker_cb77aa0c9054f1812dd23b42e0812446.bindPopup(popup_a227c45ed99e2645f89a82fb8f992f65)
#         ;
#
#
#
#
#             var marker_5329f63eb26f0e1328772f89338f3da9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7a442788adf32ef55f7418fac416d036);
#
#
#         var popup_64df55c5de09b18e215239f310bcf602 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6868dcb3d841a235c7722b948b783140 = $(`&lt;div id=&quot;html_6868dcb3d841a235c7722b948b783140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_64df55c5de09b18e215239f310bcf602.setContent(html_6868dcb3d841a235c7722b948b783140);
#
#
#
#         marker_5329f63eb26f0e1328772f89338f3da9.bindPopup(popup_64df55c5de09b18e215239f310bcf602)
#         ;
#
#
#
#
#             var marker_6053500c198c8b3c7b24fe426efe6bf0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7a442788adf32ef55f7418fac416d036);
#
#
#         var popup_ca8952753d312f79ff8550c2ba211272 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2001e7e8f371ec985a88d808884ee115 = $(`&lt;div id=&quot;html_2001e7e8f371ec985a88d808884ee115&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6df530770aa801fe9eed8bc8dc5aa0eb {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6df530770aa801fe9eed8bc8dc5aa0eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6df530770aa801fe9eed8bc8dc5aa0eb = L.map(
#                 &quot;map_6df530770aa801fe9eed8bc8dc5aa0eb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bbf959e8ddce08f6af060300e7157251 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bbf959e8ddce08f6af060300e7157251.addTo(map_6df530770aa801fe9eed8bc8dc5aa0eb);
#
#
#             var feature_group_acb80c0c9fc8c3d58d8034b51636232c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_acb80c0c9fc8c3d58d8034b51636232c.addTo(map_6df530770aa801fe9eed8bc8dc5aa0eb);
#
#
#             var feature_group_sub_group_9a8326b74f302e3666487a9479fa37f3 = L.featureGroup.subGroup(
#                 feature_group_acb80c0c9fc8c3d58d8034b51636232c
#             );
#
#
#             var marker_86aa5b4e843ddb60050fab94f5ad1784 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a8326b74f302e3666487a9479fa37f3);
#
#
#         var popup_448e69334875f81a529c3ff22903b110 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2002868a5762517334a5b05c69df626 = $(`&lt;div id=&quot;html_e2002868a5762517334a5b05c69df626&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_448e69334875f81a529c3ff22903b110.setContent(html_e2002868a5762517334a5b05c69df626);
#
#
#
#         marker_86aa5b4e843ddb60050fab94f5ad1784.bindPopup(popup_448e69334875f81a529c3ff22903b110)
#         ;
#
#
#
#
#             var marker_4274617a49702256af0412c84fc6b8ab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a8326b74f302e3666487a9479fa37f3);
#
#
#         var popup_95ab9a06772d4ce5b23d79d727febb12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8d7f51dd07a9ddbc08f15ce3886675e = $(`&lt;div id=&quot;html_b8d7f51dd07a9ddbc08f15ce3886675e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_95ab9a06772d4ce5b23d79d727febb12.setContent(html_b8d7f51dd07a9ddbc08f15ce3886675e);
#
#
#
#         marker_4274617a49702256af0412c84fc6b8ab.bindPopup(popup_95ab9a06772d4ce5b23d79d727febb12)
#         ;
#
#
#
#
#             var marker_0d94b5db895b3c34ac8956f04a2f9db6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a8326b74f302e3666487a9479fa37f3);
#
#
#         var popup_a99f0a906c105a74b612e6861870e634 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e6511212a165859c21fcf60e9847f46 = $(`&lt;div id=&quot;html_6e6511212a165859c21fcf60e9847f46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a99f0a906c105a74b612e6861870e634.setContent(html_6e6511212a165859c21fcf60e9847f46);
#
#
#
#         marker_0d94b5db895b3c34ac8956f04a2f9db6.bindPopup(popup_a99f0a906c105a74b612e6861870e634)
#         ;
#
#
#
#
#             var marker_095c4fd567dcc313e19a0c0293a70203 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9a8326b74f302e3666487a9479fa37f3);
#
#
#         var popup_68891b0e71b885b26f52c7282b1ec81e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64394d48485c73631aeef83714a35dab = $(`&lt;div id=&quot;html_64394d48485c73631aeef83714a35dab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_68891b0e71b885b26f52c7282b1ec81e.setContent(html_64394d48485c73631aeef83714a35dab);
#
#
#
#         marker_095c4fd567dcc313e19a0c0293a70203.bindPopup(popup_68891b0e71b885b26f52c7282b1ec81e)
#         ;
#
#
#
#
#             var marker_4a1a1e0563377c57076b4a2c3d3454b2 = L.marker(
#                 [45.0503999
