# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ec6a56c77d9ecdf3f5d8dbeb455e31d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ec6a56c77d9ecdf3f5d8dbeb455e31d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ec6a56c77d9ecdf3f5d8dbeb455e31d = L.map(
#                 &quot;map_2ec6a56c77d9ecdf3f5d8dbeb455e31d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9955003e6edb8d3bdc11afe38e4b2138 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9955003e6edb8d3bdc11afe38e4b2138.addTo(map_2ec6a56c77d9ecdf3f5d8dbeb455e31d);
#
#
#             var marker_3fb7b3ddb3d794e3f3911b4d7c001c66 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2ec6a56c77d9ecdf3f5d8dbeb455e31d);
#
#
#         var popup_0fb0a92d295a28cb44ec20bea7733133 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_394f9de408dac07ca8e5274de1b9c74d = $(`&lt;div id=&quot;html_394f9de408dac07ca8e5274de1b9c74d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0fb0a92d295a28cb44ec20bea7733133.setContent(html_394f9de408dac07ca8e5274de1b9c74d);
#
#
#
#         marker_3fb7b3ddb3d794e3f3911b4d7c001c66.bindPopup(popup_0fb0a92d295a28cb44ec20bea7733133)
#         ;
#
#
#
#
#             var marker_80d49c71df604f5f4cf0ae36576567ef = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2ec6a56c77d9ecdf3f5d8dbeb455e31d);
#
#
#         var popup_9d5205c2754594f2e6229f6889b68834 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_737695249d34e1e48cdde73ef06d4495 = $(`&lt;div id=&quot;html_737695249d34e1e48cdde73ef06d4495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9d5205c2754594f2e6229f6889b68834.setContent(html_737695249d34e1e48cdde73ef06d4495);
#
#
#
#         marker_80d49c71df604f5f4cf0ae36576567ef.bindPopup(popup_9d5205c2754594f2e6229f6889b68834)
#         ;
#
#
#
#
#             var marker_59044abbd56646177d5f1073fa87f974 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2ec6a56c77d9ecdf3f5d8dbeb455e31d);
#
#
#         var popup_29aad65ca2274215b1ff509f6883880d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aba5918fe46edbc2654aa3614512ee7d = $(`&lt;div id=&quot;html_aba5918fe46edbc2654aa3614512ee7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_29aad65ca2274215b1ff509f6883880d.setContent(html_aba5918fe46edbc2654aa3614512ee7d);
#
#
#
#         marker_59044abbd56646177d5f1073fa87f974.bindPopup(popup_29aad65ca2274215b1ff509f6883880d)
#         ;
#
#
#
#
#             var marker_99c2d45fe3b20924deb71841881ae109 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2ec6a56c77d9ecdf3f5d8dbeb455e31d);
#
#
#         var popup_5ae5f05dac0e14941e836f23635d7f57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbeb4438f6eaf0df01936d314377dcbd = $(`&lt;div id=&quot;html_cbeb4438f6eaf0df01936d314377dcbd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5ae5f05dac0e14941e836f23635d7f57.setContent(html_cbeb4438f6eaf0df01936d314377dcbd);
#
#
#
#         marker_99c2d45fe3b20924deb71841881ae109.bindPopup(popup_5ae5f05dac0e14941e836f23635d7f57)
#         ;
#
#
#
#
#             var marker_9bd9dcf86f75eefee83c5754971175d9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2ec6a56c77d9ecdf3f5d8dbeb455e31d);
#
#
#         var popup_eb35dfc9f90dd608976485f5637d4fbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e592e6690e4bf7afdefd1bac6679d95 = $(`&lt;div id=&quot;html_3e592e6690e4bf7afdefd1bac6679d95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eb35dfc9f90dd608976485f5637d4fbb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6bc414af33e1dc783e9f0f1c44c1019e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6bc414af33e1dc783e9f0f1c44c1019e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6bc414af33e1dc783e9f0f1c44c1019e = L.map(
#                 &quot;map_6bc414af33e1dc783e9f0f1c44c1019e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2b8aa34d2186ed6283b89c2f32802654 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2b8aa34d2186ed6283b89c2f32802654.addTo(map_6bc414af33e1dc783e9f0f1c44c1019e);
#
#
#             var feature_group_92fcc4319c85b82d55566be46a6e4f89 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_54f68c45ae44aebfa55c218712684c1f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_92fcc4319c85b82d55566be46a6e4f89);
#
#
#         var popup_e2cad46d7299c8195b3de8ccabbe7920 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_793d56f1bad58e1fb2abeee1daeccba4 = $(`&lt;div id=&quot;html_793d56f1bad58e1fb2abeee1daeccba4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e2cad46d7299c8195b3de8ccabbe7920.setContent(html_793d56f1bad58e1fb2abeee1daeccba4);
#
#
#
#         marker_54f68c45ae44aebfa55c218712684c1f.bindPopup(popup_e2cad46d7299c8195b3de8ccabbe7920)
#         ;
#
#
#
#
#             var marker_f1293e20e60ee68f222fff228f726b94 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_92fcc4319c85b82d55566be46a6e4f89);
#
#
#         var popup_0f9c02b11c4235ac8bff41d0ef0bfc3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e6f9efc93e99c490bf25e08dcfb2ba0 = $(`&lt;div id=&quot;html_7e6f9efc93e99c490bf25e08dcfb2ba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0f9c02b11c4235ac8bff41d0ef0bfc3a.setContent(html_7e6f9efc93e99c490bf25e08dcfb2ba0);
#
#
#
#         marker_f1293e20e60ee68f222fff228f726b94.bindPopup(popup_0f9c02b11c4235ac8bff41d0ef0bfc3a)
#         ;
#
#
#
#
#             var marker_c8a5f1df69f8b249ba4586728be29c03 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_92fcc4319c85b82d55566be46a6e4f89);
#
#
#         var popup_c5f4817d5a56d238d410e457459bab47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c71a816098e81844a696fb6402c82e6b = $(`&lt;div id=&quot;html_c71a816098e81844a696fb6402c82e6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c5f4817d5a56d238d410e457459bab47.setContent(html_c71a816098e81844a696fb6402c82e6b);
#
#
#
#         marker_c8a5f1df69f8b249ba4586728be29c03.bindPopup(popup_c5f4817d5a56d238d410e457459bab47)
#         ;
#
#
#
#
#             var marker_48a0a727daf6a874ef5c823f9297444d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_92fcc4319c85b82d55566be46a6e4f89);
#
#
#         var popup_1c2d78142e5e76ce79404336ee3c7061 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad11545fcff6e4286288d4254704c98a = $(`&lt;div id=&quot;html_ad11545fcff6e4286288d4254704c98a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1c2d78142e5e76ce79404336ee3c7061.setContent(html_ad11545fcff6e4286288d4254704c98a);
#
#
#
#         marker_48a0a727daf6a874ef5c823f9297444d.bindPopup(popup_1c2d78142e5e76ce79404336ee3c7061)
#         ;
#
#
#
#
#             var marker_92d51926d703de8b82e3f7e858c8c21e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_92fcc4319c85b82d55566be46a6e4f89);
#
#
#         var popup_d7fe52bdea647db651cc113d64210f6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c699ef9b217e385cb5aad762ae1591b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c699ef9b217e385cb5aad762ae1591b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c699ef9b217e385cb5aad762ae1591b0 = L.map(
#                 &quot;map_c699ef9b217e385cb5aad762ae1591b0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66316cf329b762bdce5c7878d4b3546b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66316cf329b762bdce5c7878d4b3546b.addTo(map_c699ef9b217e385cb5aad762ae1591b0);
#
#
#             var feature_group_5edd4d2b64cbe558f43e630fb10ab5d8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5edd4d2b64cbe558f43e630fb10ab5d8.addTo(map_c699ef9b217e385cb5aad762ae1591b0);
#
#
#             var feature_group_sub_group_fd19f52c9406e13c0494284824f6c41a = L.featureGroup.subGroup(
#                 feature_group_5edd4d2b64cbe558f43e630fb10ab5d8
#             );
#
#
#             var marker_27280b553983c8f5e5099df03fe5a352 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd19f52c9406e13c0494284824f6c41a);
#
#
#         var popup_b48a3d3f983c725d00226e11db090b32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ada81182d5d5f43d79c978fc6f187c4d = $(`&lt;div id=&quot;html_ada81182d5d5f43d79c978fc6f187c4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b48a3d3f983c725d00226e11db090b32.setContent(html_ada81182d5d5f43d79c978fc6f187c4d);
#
#
#
#         marker_27280b553983c8f5e5099df03fe5a352.bindPopup(popup_b48a3d3f983c725d00226e11db090b32)
#         ;
#
#
#
#
#             var marker_f9eac7c6a0a51b9648b78dcea36cdd02 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd19f52c9406e13c0494284824f6c41a);
#
#
#         var popup_71c4c90d4dd7e2c274c6780347dca851 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e3612291e00cb12fdbf3f449ac29619 = $(`&lt;div id=&quot;html_0e3612291e00cb12fdbf3f449ac29619&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_71c4c90d4dd7e2c274c6780347dca851.setContent(html_0e3612291e00cb12fdbf3f449ac29619);
#
#
#
#         marker_f9eac7c6a0a51b9648b78dcea36cdd02.bindPopup(popup_71c4c90d4dd7e2c274c6780347dca851)
#         ;
#
#
#
#
#             var marker_18db965c3d0fd9711f0338fa8629d7b1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd19f52c9406e13c0494284824f6c41a);
#
#
#         var popup_2afd3fb0ae006a3d4f1fa6131da9e373 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2c9ebe8547605a3e2450f622a5c896a = $(`&lt;div id=&quot;html_a2c9ebe8547605a3e2450f622a5c896a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2afd3fb0ae006a3d4f1fa6131da9e373.setContent(html_a2c9ebe8547605a3e2450f622a5c896a);
#
#
#
#         marker_18db965c3d0fd9711f0338fa8629d7b1.bindPopup(popup_2afd3fb0ae006a3d4f1fa6131da9e373)
#         ;
#
#
#
#
#             var marker_c865cc3ea20a05595cf783f719e5e794 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fd19f52c9406e13c0494284824f6c41a);
#
#
#         var popup_6d8b88cb8264eb40a439d6ad5bb8b36c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47225b1ec10add4fcd29601714dc89ba = $(`&lt;div id=&quot;html_47225b1ec10add4fcd29601714dc89ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6d8b88cb8264eb40a439d6ad5bb8b36c.setContent(html_47225b1ec10add4fcd29601714dc89ba);
#
#
#
#         marker_
