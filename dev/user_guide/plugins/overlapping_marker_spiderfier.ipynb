# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b2f40d33bbe105cffb5674b90352b0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b2f40d33bbe105cffb5674b90352b0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b2f40d33bbe105cffb5674b90352b0c = L.map(
#                 &quot;map_6b2f40d33bbe105cffb5674b90352b0c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4bb15be15f6e744d43663fbcadad2d2d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4bb15be15f6e744d43663fbcadad2d2d.addTo(map_6b2f40d33bbe105cffb5674b90352b0c);
#
#
#             var marker_32fada7d0ee2fae3aab47223d67e5b65 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6b2f40d33bbe105cffb5674b90352b0c);
#
#
#         var popup_1f6f54f7520acd1a6ef5098e01382b24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_847a27834fa209b2c0d21b03b08299bb = $(`&lt;div id=&quot;html_847a27834fa209b2c0d21b03b08299bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1f6f54f7520acd1a6ef5098e01382b24.setContent(html_847a27834fa209b2c0d21b03b08299bb);
#
#
#
#         marker_32fada7d0ee2fae3aab47223d67e5b65.bindPopup(popup_1f6f54f7520acd1a6ef5098e01382b24)
#         ;
#
#
#
#
#             var marker_042b988299fca469f7d7351081875d18 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6b2f40d33bbe105cffb5674b90352b0c);
#
#
#         var popup_1f431966ed4e9e59d42d77522451d8a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12d14cb95c128601a9717012dacc9676 = $(`&lt;div id=&quot;html_12d14cb95c128601a9717012dacc9676&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1f431966ed4e9e59d42d77522451d8a3.setContent(html_12d14cb95c128601a9717012dacc9676);
#
#
#
#         marker_042b988299fca469f7d7351081875d18.bindPopup(popup_1f431966ed4e9e59d42d77522451d8a3)
#         ;
#
#
#
#
#             var marker_a7b64186d4f7085833e1405e1dd52c87 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6b2f40d33bbe105cffb5674b90352b0c);
#
#
#         var popup_6f6610132d833965e50c085523d6f874 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b8c4897cd851639384aa6f7f45d52ae = $(`&lt;div id=&quot;html_7b8c4897cd851639384aa6f7f45d52ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6f6610132d833965e50c085523d6f874.setContent(html_7b8c4897cd851639384aa6f7f45d52ae);
#
#
#
#         marker_a7b64186d4f7085833e1405e1dd52c87.bindPopup(popup_6f6610132d833965e50c085523d6f874)
#         ;
#
#
#
#
#             var marker_d8da7adbdb832b002a23179327d965d5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6b2f40d33bbe105cffb5674b90352b0c);
#
#
#         var popup_931122303f53724ea41261ff10e53297 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_863b1dd3245c226d15faaa6a025a7b4c = $(`&lt;div id=&quot;html_863b1dd3245c226d15faaa6a025a7b4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_931122303f53724ea41261ff10e53297.setContent(html_863b1dd3245c226d15faaa6a025a7b4c);
#
#
#
#         marker_d8da7adbdb832b002a23179327d965d5.bindPopup(popup_931122303f53724ea41261ff10e53297)
#         ;
#
#
#
#
#             var marker_e52f02c20cf21d3a4aa715aa09548d25 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6b2f40d33bbe105cffb5674b90352b0c);
#
#
#         var popup_e26f5af98a14c1279173b0e95506b4e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4af1b96e58437e460e9704b253b6b30 = $(`&lt;div id=&quot;html_e4af1b96e58437e460e9704b253b6b30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e26f5af98a14c1279173b0e95506b4e3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0518b13d4267cb56ff9f6524a164923 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0518b13d4267cb56ff9f6524a164923&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0518b13d4267cb56ff9f6524a164923 = L.map(
#                 &quot;map_a0518b13d4267cb56ff9f6524a164923&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a8bd7c626ae0f6c338082c49e9d5df1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a8bd7c626ae0f6c338082c49e9d5df1.addTo(map_a0518b13d4267cb56ff9f6524a164923);
#
#
#             var feature_group_d7cd2d6a6d1d8ca67912faab9c9a50e8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bda2c9a825b92e0afecf56707e308f03 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d7cd2d6a6d1d8ca67912faab9c9a50e8);
#
#
#         var popup_8b25f1137d9f35b15d48ea2000322b17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b4c8d6f12b13f1644101161c0350c37 = $(`&lt;div id=&quot;html_5b4c8d6f12b13f1644101161c0350c37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8b25f1137d9f35b15d48ea2000322b17.setContent(html_5b4c8d6f12b13f1644101161c0350c37);
#
#
#
#         marker_bda2c9a825b92e0afecf56707e308f03.bindPopup(popup_8b25f1137d9f35b15d48ea2000322b17)
#         ;
#
#
#
#
#             var marker_267e2da7d4c71a8b412c1f4452f4e2ec = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d7cd2d6a6d1d8ca67912faab9c9a50e8);
#
#
#         var popup_50d41ffba1225e08d3b65a4f87730b7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_705e509114cca25bdd1fe09a0cecd7c5 = $(`&lt;div id=&quot;html_705e509114cca25bdd1fe09a0cecd7c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_50d41ffba1225e08d3b65a4f87730b7e.setContent(html_705e509114cca25bdd1fe09a0cecd7c5);
#
#
#
#         marker_267e2da7d4c71a8b412c1f4452f4e2ec.bindPopup(popup_50d41ffba1225e08d3b65a4f87730b7e)
#         ;
#
#
#
#
#             var marker_4be7c45090387941d65077665c3e2b86 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d7cd2d6a6d1d8ca67912faab9c9a50e8);
#
#
#         var popup_dbc5ed1bf01a6d2ceccacb28b3a5a0aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e871fe02de3a15bc0484111a1b34d4c4 = $(`&lt;div id=&quot;html_e871fe02de3a15bc0484111a1b34d4c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_dbc5ed1bf01a6d2ceccacb28b3a5a0aa.setContent(html_e871fe02de3a15bc0484111a1b34d4c4);
#
#
#
#         marker_4be7c45090387941d65077665c3e2b86.bindPopup(popup_dbc5ed1bf01a6d2ceccacb28b3a5a0aa)
#         ;
#
#
#
#
#             var marker_08f861a8196172daa0d6264da24a94e6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d7cd2d6a6d1d8ca67912faab9c9a50e8);
#
#
#         var popup_8d540f79fb1190ade88fe5172ec2cbe0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2a2be47cd36fbabada9a415201e86c0 = $(`&lt;div id=&quot;html_e2a2be47cd36fbabada9a415201e86c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8d540f79fb1190ade88fe5172ec2cbe0.setContent(html_e2a2be47cd36fbabada9a415201e86c0);
#
#
#
#         marker_08f861a8196172daa0d6264da24a94e6.bindPopup(popup_8d540f79fb1190ade88fe5172ec2cbe0)
#         ;
#
#
#
#
#             var marker_c90074f40e960c4cb5dafd665441b8cd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d7cd2d6a6d1d8ca67912faab9c9a50e8);
#
#
#         var popup_9a7efac162b83b3bcea6d0fbefe9c2db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4034c4a56efd2cd45b5e62239f6262fc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4034c4a56efd2cd45b5e62239f6262fc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4034c4a56efd2cd45b5e62239f6262fc = L.map(
#                 &quot;map_4034c4a56efd2cd45b5e62239f6262fc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40b360c2501a186fd400f0186a484108 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_40b360c2501a186fd400f0186a484108.addTo(map_4034c4a56efd2cd45b5e62239f6262fc);
#
#
#             var feature_group_d1815262a25569618077130392567de4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d1815262a25569618077130392567de4.addTo(map_4034c4a56efd2cd45b5e62239f6262fc);
#
#
#             var feature_group_sub_group_37990e5b95476ef78813f57c69d5c0aa = L.featureGroup.subGroup(
#                 feature_group_d1815262a25569618077130392567de4
#             );
#
#
#             var marker_d280145d15997ad94653a194b5ee44e7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_37990e5b95476ef78813f57c69d5c0aa);
#
#
#         var popup_70f75b836ae7ec3e396442f006fd7ba8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f55c8fcbaa9c2e924075f1faecd16f4 = $(`&lt;div id=&quot;html_3f55c8fcbaa9c2e924075f1faecd16f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_70f75b836ae7ec3e396442f006fd7ba8.setContent(html_3f55c8fcbaa9c2e924075f1faecd16f4);
#
#
#
#         marker_d280145d15997ad94653a194b5ee44e7.bindPopup(popup_70f75b836ae7ec3e396442f006fd7ba8)
#         ;
#
#
#
#
#             var marker_ab3e86b603d10c28905bc4ab7e0a7f7e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_37990e5b95476ef78813f57c69d5c0aa);
#
#
#         var popup_80bf7ce139969536b5a350e4b9e8114c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_750e0d31afc790432122f2e958a28226 = $(`&lt;div id=&quot;html_750e0d31afc790432122f2e958a28226&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_80bf7ce139969536b5a350e4b9e8114c.setContent(html_750e0d31afc790432122f2e958a28226);
#
#
#
#         marker_ab3e86b603d10c28905bc4ab7e0a7f7e.bindPopup(popup_80bf7ce139969536b5a350e4b9e8114c)
#         ;
#
#
#
#
#             var marker_c1de040f03e1778c78294760899e4d3b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_37990e5b95476ef78813f57c69d5c0aa);
#
#
#         var popup_6d6f30c66edbea9033d55c59235bec73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5437beedf3525a3b4481ffd2c788dae7 = $(`&lt;div id=&quot;html_5437beedf3525a3b4481ffd2c788dae7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6d6f30c66edbea9033d55c59235bec73.setContent(html_5437beedf3525a3b4481ffd2c788dae7);
#
#
#
#         marker_c1de040f03e1778c78294760899e4d3b.bindPopup(popup_6d6f30c66edbea9033d55c59235bec73)
#         ;
#
#
#
#
#             var marker_35414f501d2e45d592ed55ec867aefb4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_37990e5b95476ef78813f57c69d5c0aa);
#
#
#         var popup_dd8f31bc9b455c505e39c25fd3027dd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2669466aa6f850a4e407cf0fa00c85f9 = $(`&lt;div id=&quot;html_2669466aa6f850a4e407cf0fa00c85f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dd8f31bc9b455c505e39c25fd3027dd5.setContent(html_2669466aa6f850a4e407cf0fa00c85f9);
#
#
#
#         marker_
