# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70ccb5abf07e88ebb649df3af6b94c60 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70ccb5abf07e88ebb649df3af6b94c60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70ccb5abf07e88ebb649df3af6b94c60 = L.map(
#                 &quot;map_70ccb5abf07e88ebb649df3af6b94c60&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b344fffaf36ef8b24ce1069ce6ad6975 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b344fffaf36ef8b24ce1069ce6ad6975.addTo(map_70ccb5abf07e88ebb649df3af6b94c60);
#
#
#             var marker_51d9cffeb9646e9d0fbe2643b91640e8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_70ccb5abf07e88ebb649df3af6b94c60);
#
#
#         var popup_49eb24e3a95629ea5ee488b8cedbe254 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1943ce605cce2b334a105ef25172246 = $(`&lt;div id=&quot;html_b1943ce605cce2b334a105ef25172246&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_49eb24e3a95629ea5ee488b8cedbe254.setContent(html_b1943ce605cce2b334a105ef25172246);
#
#
#
#         marker_51d9cffeb9646e9d0fbe2643b91640e8.bindPopup(popup_49eb24e3a95629ea5ee488b8cedbe254)
#         ;
#
#
#
#
#             var marker_c246fc1248e2e5b1c660d00d1690305a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_70ccb5abf07e88ebb649df3af6b94c60);
#
#
#         var popup_77d0e34f76f71a0628473bc21b9f0972 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e9d4178431989736e0e0f965352262c = $(`&lt;div id=&quot;html_1e9d4178431989736e0e0f965352262c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_77d0e34f76f71a0628473bc21b9f0972.setContent(html_1e9d4178431989736e0e0f965352262c);
#
#
#
#         marker_c246fc1248e2e5b1c660d00d1690305a.bindPopup(popup_77d0e34f76f71a0628473bc21b9f0972)
#         ;
#
#
#
#
#             var marker_ce1f5322bfb8d80acb6f3de61601ec61 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_70ccb5abf07e88ebb649df3af6b94c60);
#
#
#         var popup_14cd9f87ffe49e8f61b5d42eea47b480 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c4c9cfb68f5c4001d8d907fab6f8ec9 = $(`&lt;div id=&quot;html_7c4c9cfb68f5c4001d8d907fab6f8ec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_14cd9f87ffe49e8f61b5d42eea47b480.setContent(html_7c4c9cfb68f5c4001d8d907fab6f8ec9);
#
#
#
#         marker_ce1f5322bfb8d80acb6f3de61601ec61.bindPopup(popup_14cd9f87ffe49e8f61b5d42eea47b480)
#         ;
#
#
#
#
#             var marker_bdc27da28c37955cc61b9b03b9de3ac7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_70ccb5abf07e88ebb649df3af6b94c60);
#
#
#         var popup_b0c471a5a5b45249693256410b18617d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0fafaaa949f20b72cf58ec552b58046 = $(`&lt;div id=&quot;html_f0fafaaa949f20b72cf58ec552b58046&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b0c471a5a5b45249693256410b18617d.setContent(html_f0fafaaa949f20b72cf58ec552b58046);
#
#
#
#         marker_bdc27da28c37955cc61b9b03b9de3ac7.bindPopup(popup_b0c471a5a5b45249693256410b18617d)
#         ;
#
#
#
#
#             var marker_dadd0a676cb984c8a150580f9abd199d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_70ccb5abf07e88ebb649df3af6b94c60);
#
#
#         var popup_a8c3cc7de12367515d1252d2063b9068 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7e1d8cf8cefd0f0c38ce0c8caed3ba4 = $(`&lt;div id=&quot;html_c7e1d8cf8cefd0f0c38ce0c8caed3ba4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a8c3cc7de12367515d1252d2063b9068.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f2dee8350676fd875e26603c65b0a47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f2dee8350676fd875e26603c65b0a47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f2dee8350676fd875e26603c65b0a47 = L.map(
#                 &quot;map_0f2dee8350676fd875e26603c65b0a47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eed6e6ac25b9c0f403672eb74ee6f8ca = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eed6e6ac25b9c0f403672eb74ee6f8ca.addTo(map_0f2dee8350676fd875e26603c65b0a47);
#
#
#             var feature_group_7d84b352e843bbbbb742959352b63a28 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_856be9fc53fcc37fd6a391ae2992301b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7d84b352e843bbbbb742959352b63a28);
#
#
#         var popup_40f7a849703fe9a7733dbc9c876607f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b806d2655569554d50161d7c4dbac770 = $(`&lt;div id=&quot;html_b806d2655569554d50161d7c4dbac770&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_40f7a849703fe9a7733dbc9c876607f4.setContent(html_b806d2655569554d50161d7c4dbac770);
#
#
#
#         marker_856be9fc53fcc37fd6a391ae2992301b.bindPopup(popup_40f7a849703fe9a7733dbc9c876607f4)
#         ;
#
#
#
#
#             var marker_eb67e4097cc5b19eb3daba802ae66035 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7d84b352e843bbbbb742959352b63a28);
#
#
#         var popup_9920a4444fcca80d55fd30e849791d0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab32601eee7857462ede816144205841 = $(`&lt;div id=&quot;html_ab32601eee7857462ede816144205841&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9920a4444fcca80d55fd30e849791d0f.setContent(html_ab32601eee7857462ede816144205841);
#
#
#
#         marker_eb67e4097cc5b19eb3daba802ae66035.bindPopup(popup_9920a4444fcca80d55fd30e849791d0f)
#         ;
#
#
#
#
#             var marker_ef62c89be10caca489481514227b2651 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7d84b352e843bbbbb742959352b63a28);
#
#
#         var popup_eb6acad121d590491013f51ffe8c7b8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af396609174808c8476ce86cb1349484 = $(`&lt;div id=&quot;html_af396609174808c8476ce86cb1349484&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_eb6acad121d590491013f51ffe8c7b8b.setContent(html_af396609174808c8476ce86cb1349484);
#
#
#
#         marker_ef62c89be10caca489481514227b2651.bindPopup(popup_eb6acad121d590491013f51ffe8c7b8b)
#         ;
#
#
#
#
#             var marker_2b9978685d5839e92ecaa1326be9ceb9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7d84b352e843bbbbb742959352b63a28);
#
#
#         var popup_ab7842ec6cdad39720012f8c885d786a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76a06251ac18401440ce84a80fc4deff = $(`&lt;div id=&quot;html_76a06251ac18401440ce84a80fc4deff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ab7842ec6cdad39720012f8c885d786a.setContent(html_76a06251ac18401440ce84a80fc4deff);
#
#
#
#         marker_2b9978685d5839e92ecaa1326be9ceb9.bindPopup(popup_ab7842ec6cdad39720012f8c885d786a)
#         ;
#
#
#
#
#             var marker_1618f6db3679d0e6f4efe4288c0f6577 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7d84b352e843bbbbb742959352b63a28);
#
#
#         var popup_7f425d9ef0f7851fb1f89c5aa173a40e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fa6d62e555f9beef0f5bfc474b2e6c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fa6d62e555f9beef0f5bfc474b2e6c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fa6d62e555f9beef0f5bfc474b2e6c9 = L.map(
#                 &quot;map_6fa6d62e555f9beef0f5bfc474b2e6c9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18c2e16d6153a4ee09dffdc1375d953b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18c2e16d6153a4ee09dffdc1375d953b.addTo(map_6fa6d62e555f9beef0f5bfc474b2e6c9);
#
#
#             var feature_group_151996b9286472af67b43502d919925f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_151996b9286472af67b43502d919925f.addTo(map_6fa6d62e555f9beef0f5bfc474b2e6c9);
#
#
#             var feature_group_sub_group_2b31da4b7664a85c1e66e546fc8dd3b9 = L.featureGroup.subGroup(
#                 feature_group_151996b9286472af67b43502d919925f
#             );
#
#
#             var marker_4038286aa8bbb6dfeed4cc06f45ebd0c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b31da4b7664a85c1e66e546fc8dd3b9);
#
#
#         var popup_495fb40e960e427a0660244d18d74bff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f94cf1185c823536c2b836de00f9dec = $(`&lt;div id=&quot;html_1f94cf1185c823536c2b836de00f9dec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_495fb40e960e427a0660244d18d74bff.setContent(html_1f94cf1185c823536c2b836de00f9dec);
#
#
#
#         marker_4038286aa8bbb6dfeed4cc06f45ebd0c.bindPopup(popup_495fb40e960e427a0660244d18d74bff)
#         ;
#
#
#
#
#             var marker_8c0f572b4c10f1c361e04976593821b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b31da4b7664a85c1e66e546fc8dd3b9);
#
#
#         var popup_56cf12d85b6b6f6f343b31a61b43428a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a177104827bbd527b1dc6fbde2ca8a8d = $(`&lt;div id=&quot;html_a177104827bbd527b1dc6fbde2ca8a8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_56cf12d85b6b6f6f343b31a61b43428a.setContent(html_a177104827bbd527b1dc6fbde2ca8a8d);
#
#
#
#         marker_8c0f572b4c10f1c361e04976593821b6.bindPopup(popup_56cf12d85b6b6f6f343b31a61b43428a)
#         ;
#
#
#
#
#             var marker_cff651e556aef7576538f6acb52a1751 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b31da4b7664a85c1e66e546fc8dd3b9);
#
#
#         var popup_a78709137062abe231ed3de649352540 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f67551146156ad962c348f40cddd3060 = $(`&lt;div id=&quot;html_f67551146156ad962c348f40cddd3060&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a78709137062abe231ed3de649352540.setContent(html_f67551146156ad962c348f40cddd3060);
#
#
#
#         marker_cff651e556aef7576538f6acb52a1751.bindPopup(popup_a78709137062abe231ed3de649352540)
#         ;
#
#
#
#
#             var marker_7202c20cf19e7950df1e765f0e138436 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2b31da4b7664a85c1e66e546fc8dd3b9);
#
#
#         var popup_86cd10d324eaa82eff85cfa642ff79e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1a9b538784ee150b1fe4cb230408c21 = $(`&lt;div id=&quot;html_f1a9b538784ee150b1fe4cb230408c21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_86cd10d324eaa82eff85cfa642ff79e3.setContent(html_f1a9b538784ee150b1fe4cb230408c21);
#
#
#
#         marker_
