# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b57f08bbe9d1f139e0080e7c03041825 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b57f08bbe9d1f139e0080e7c03041825&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b57f08bbe9d1f139e0080e7c03041825 = L.map(
#                 &quot;map_b57f08bbe9d1f139e0080e7c03041825&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c181a472b0d4e9793423f595262e9d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c181a472b0d4e9793423f595262e9d0.addTo(map_b57f08bbe9d1f139e0080e7c03041825);
#
#
#             var marker_281f5de34c347df91ec2e227cb1d4ddb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b57f08bbe9d1f139e0080e7c03041825);
#
#
#         var popup_f6b0171e50d8ae96e68fbed6f2fb2b35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6abd995d0d1dde1f420077b5700f2518 = $(`&lt;div id=&quot;html_6abd995d0d1dde1f420077b5700f2518&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f6b0171e50d8ae96e68fbed6f2fb2b35.setContent(html_6abd995d0d1dde1f420077b5700f2518);
#
#
#
#         marker_281f5de34c347df91ec2e227cb1d4ddb.bindPopup(popup_f6b0171e50d8ae96e68fbed6f2fb2b35)
#         ;
#
#
#
#
#             var marker_292739d541ff73192ef0d021bf745264 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b57f08bbe9d1f139e0080e7c03041825);
#
#
#         var popup_89dcc0b5355a512d7bd0da500cb84561 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c88291f9c919b6bfa4f938f640951d28 = $(`&lt;div id=&quot;html_c88291f9c919b6bfa4f938f640951d28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_89dcc0b5355a512d7bd0da500cb84561.setContent(html_c88291f9c919b6bfa4f938f640951d28);
#
#
#
#         marker_292739d541ff73192ef0d021bf745264.bindPopup(popup_89dcc0b5355a512d7bd0da500cb84561)
#         ;
#
#
#
#
#             var marker_9957f425ee4f396dd61a37c3bf0f5f62 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b57f08bbe9d1f139e0080e7c03041825);
#
#
#         var popup_d50db4ea5b939882bfdbaa4d9c2f33aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc3a4cc2915a79dd060e60629fa9d5d3 = $(`&lt;div id=&quot;html_dc3a4cc2915a79dd060e60629fa9d5d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d50db4ea5b939882bfdbaa4d9c2f33aa.setContent(html_dc3a4cc2915a79dd060e60629fa9d5d3);
#
#
#
#         marker_9957f425ee4f396dd61a37c3bf0f5f62.bindPopup(popup_d50db4ea5b939882bfdbaa4d9c2f33aa)
#         ;
#
#
#
#
#             var marker_f37b85bd73dfb3c702e3bfa70d548822 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b57f08bbe9d1f139e0080e7c03041825);
#
#
#         var popup_42593778aca9b0bc6b9ed20f4ee7badc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb1f8b9bce3c3a618ecd303cf477df29 = $(`&lt;div id=&quot;html_cb1f8b9bce3c3a618ecd303cf477df29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_42593778aca9b0bc6b9ed20f4ee7badc.setContent(html_cb1f8b9bce3c3a618ecd303cf477df29);
#
#
#
#         marker_f37b85bd73dfb3c702e3bfa70d548822.bindPopup(popup_42593778aca9b0bc6b9ed20f4ee7badc)
#         ;
#
#
#
#
#             var marker_ce010cfe461ff631f7a9fa835208214c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b57f08bbe9d1f139e0080e7c03041825);
#
#
#         var popup_1b70ef2b9f3867c991cfd0010fdae69c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39b85390997746c4b054455bcdd71141 = $(`&lt;div id=&quot;html_39b85390997746c4b054455bcdd71141&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1b70ef2b9f3867c991cfd0010fdae69c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_855c3f487f09d38fae4ba5c7d435641c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_855c3f487f09d38fae4ba5c7d435641c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_855c3f487f09d38fae4ba5c7d435641c = L.map(
#                 &quot;map_855c3f487f09d38fae4ba5c7d435641c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_674357623eb94c6ad4f58a4729038cff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_674357623eb94c6ad4f58a4729038cff.addTo(map_855c3f487f09d38fae4ba5c7d435641c);
#
#
#             var feature_group_de730d371c03faa34e5aa0ebaf21371d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8ad0a6b1b8bcc88a94c428343fb3ea63 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_de730d371c03faa34e5aa0ebaf21371d);
#
#
#         var popup_9faf0fb1377aab5c3e72815759d822ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3eb3cad7722690c9ae04fa83efa867ff = $(`&lt;div id=&quot;html_3eb3cad7722690c9ae04fa83efa867ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9faf0fb1377aab5c3e72815759d822ec.setContent(html_3eb3cad7722690c9ae04fa83efa867ff);
#
#
#
#         marker_8ad0a6b1b8bcc88a94c428343fb3ea63.bindPopup(popup_9faf0fb1377aab5c3e72815759d822ec)
#         ;
#
#
#
#
#             var marker_b4bc3bc75da7a37d1f52d97dbd443882 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_de730d371c03faa34e5aa0ebaf21371d);
#
#
#         var popup_2e09fa372710607ef7c720b661bff5aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f76077a171fa8fa2f2d752b71a213d9 = $(`&lt;div id=&quot;html_5f76077a171fa8fa2f2d752b71a213d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2e09fa372710607ef7c720b661bff5aa.setContent(html_5f76077a171fa8fa2f2d752b71a213d9);
#
#
#
#         marker_b4bc3bc75da7a37d1f52d97dbd443882.bindPopup(popup_2e09fa372710607ef7c720b661bff5aa)
#         ;
#
#
#
#
#             var marker_17d82f413368e46221bb6efd643d4268 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_de730d371c03faa34e5aa0ebaf21371d);
#
#
#         var popup_9b4c27ca12232710df5f338d6614d200 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc7d5280956b77f399210a98315761cf = $(`&lt;div id=&quot;html_dc7d5280956b77f399210a98315761cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9b4c27ca12232710df5f338d6614d200.setContent(html_dc7d5280956b77f399210a98315761cf);
#
#
#
#         marker_17d82f413368e46221bb6efd643d4268.bindPopup(popup_9b4c27ca12232710df5f338d6614d200)
#         ;
#
#
#
#
#             var marker_d6ff4e6f557bb1f1e905c3730a0e1849 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_de730d371c03faa34e5aa0ebaf21371d);
#
#
#         var popup_0f76dab4de8fb044695a1756f609dff1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90fdbddca3867a10beef388546630fd0 = $(`&lt;div id=&quot;html_90fdbddca3867a10beef388546630fd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0f76dab4de8fb044695a1756f609dff1.setContent(html_90fdbddca3867a10beef388546630fd0);
#
#
#
#         marker_d6ff4e6f557bb1f1e905c3730a0e1849.bindPopup(popup_0f76dab4de8fb044695a1756f609dff1)
#         ;
#
#
#
#
#             var marker_26003487eb9e50273c12d95de0ff8fbd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_de730d371c03faa34e5aa0ebaf21371d);
#
#
#         var popup_edfcfe3cba689ead5c087492ac4d93a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b941a55ea25c1035ce8e95cc297ad89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b941a55ea25c1035ce8e95cc297ad89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b941a55ea25c1035ce8e95cc297ad89 = L.map(
#                 &quot;map_3b941a55ea25c1035ce8e95cc297ad89&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1434befbfbbe14280a3730bec66b00f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1434befbfbbe14280a3730bec66b00f9.addTo(map_3b941a55ea25c1035ce8e95cc297ad89);
#
#
#             var feature_group_cdbd3a826c79ae7a891526e65ebf75ca = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cdbd3a826c79ae7a891526e65ebf75ca.addTo(map_3b941a55ea25c1035ce8e95cc297ad89);
#
#
#             var feature_group_sub_group_3bc2d15fa421f77c18eb394cb3c5e5d3 = L.featureGroup.subGroup(
#                 feature_group_cdbd3a826c79ae7a891526e65ebf75ca
#             );
#
#
#             var marker_8f52f057a42f207167725a6fa18bdc54 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bc2d15fa421f77c18eb394cb3c5e5d3);
#
#
#         var popup_bd6e7fb1222f268ee20c0681ed8d0f96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45fe1cda9d885f6618bbc989428cdced = $(`&lt;div id=&quot;html_45fe1cda9d885f6618bbc989428cdced&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bd6e7fb1222f268ee20c0681ed8d0f96.setContent(html_45fe1cda9d885f6618bbc989428cdced);
#
#
#
#         marker_8f52f057a42f207167725a6fa18bdc54.bindPopup(popup_bd6e7fb1222f268ee20c0681ed8d0f96)
#         ;
#
#
#
#
#             var marker_a8485c53400418b2094d420298c69363 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bc2d15fa421f77c18eb394cb3c5e5d3);
#
#
#         var popup_4eacfb98540791e2b35b0bdb0560fa44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf73dbac5acf933753f6cd2346bca04a = $(`&lt;div id=&quot;html_bf73dbac5acf933753f6cd2346bca04a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4eacfb98540791e2b35b0bdb0560fa44.setContent(html_bf73dbac5acf933753f6cd2346bca04a);
#
#
#
#         marker_a8485c53400418b2094d420298c69363.bindPopup(popup_4eacfb98540791e2b35b0bdb0560fa44)
#         ;
#
#
#
#
#             var marker_b1855aaf341a04f2ac2db7edff02742b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bc2d15fa421f77c18eb394cb3c5e5d3);
#
#
#         var popup_4bf1df24fd61ee8b9c0609a966c84604 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4243a87499056793bac522adb5aeff3 = $(`&lt;div id=&quot;html_d4243a87499056793bac522adb5aeff3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4bf1df24fd61ee8b9c0609a966c84604.setContent(html_d4243a87499056793bac522adb5aeff3);
#
#
#
#         marker_b1855aaf341a04f2ac2db7edff02742b.bindPopup(popup_4bf1df24fd61ee8b9c0609a966c84604)
#         ;
#
#
#
#
#             var marker_b3b35d244970587bbebe229e7c0994c5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3bc2d15fa421f77c18eb394cb3c5e5d3);
#
#
#         var popup_07ab6e19971c7f6edab3add6d048f07e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f888e8af3e41871f8f60b3ca0b258f3a = $(`&lt;div id=&quot;html_f888e8af3e41871f8f60b3ca0b258f3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_07ab6e19971c7f6edab3add6d048f07e.setContent(html_f888e8af3e41871f8f60b3ca0b258f3a);
#
#
#
#         marker_
