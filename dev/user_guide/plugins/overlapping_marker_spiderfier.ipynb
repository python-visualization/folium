# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_578dcbdeb94dd20f059224168399616a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_578dcbdeb94dd20f059224168399616a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_578dcbdeb94dd20f059224168399616a = L.map(
#                 &quot;map_578dcbdeb94dd20f059224168399616a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b55483229359e77e2e98ec19e982d44b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b55483229359e77e2e98ec19e982d44b.addTo(map_578dcbdeb94dd20f059224168399616a);
#
#
#             var marker_cbaa61183535497023410f278e07e2f2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_578dcbdeb94dd20f059224168399616a);
#
#
#         var popup_5c47f29a59674798825f5d960d50bf82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3c81bb33bb4b33009ec93bf5f5f7b11 = $(`&lt;div id=&quot;html_b3c81bb33bb4b33009ec93bf5f5f7b11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5c47f29a59674798825f5d960d50bf82.setContent(html_b3c81bb33bb4b33009ec93bf5f5f7b11);
#
#
#
#         marker_cbaa61183535497023410f278e07e2f2.bindPopup(popup_5c47f29a59674798825f5d960d50bf82)
#         ;
#
#
#
#
#             var marker_f842462850944fb692d47dd67c596ea6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_578dcbdeb94dd20f059224168399616a);
#
#
#         var popup_e2fcb464aa2be7757c3db82f8dc13c67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25768ef841e679b3c0be3b526f758bbf = $(`&lt;div id=&quot;html_25768ef841e679b3c0be3b526f758bbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e2fcb464aa2be7757c3db82f8dc13c67.setContent(html_25768ef841e679b3c0be3b526f758bbf);
#
#
#
#         marker_f842462850944fb692d47dd67c596ea6.bindPopup(popup_e2fcb464aa2be7757c3db82f8dc13c67)
#         ;
#
#
#
#
#             var marker_a9305b24ed2b5fb5fecc6b38e9a13b9a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_578dcbdeb94dd20f059224168399616a);
#
#
#         var popup_cb97e8cb2cc3edf22190f2ee681d0865 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9054a88b20fc26eaada56cb608510a6 = $(`&lt;div id=&quot;html_a9054a88b20fc26eaada56cb608510a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cb97e8cb2cc3edf22190f2ee681d0865.setContent(html_a9054a88b20fc26eaada56cb608510a6);
#
#
#
#         marker_a9305b24ed2b5fb5fecc6b38e9a13b9a.bindPopup(popup_cb97e8cb2cc3edf22190f2ee681d0865)
#         ;
#
#
#
#
#             var marker_e911de519579376196068a71289d12cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_578dcbdeb94dd20f059224168399616a);
#
#
#         var popup_741613d751c27a96b2b9864a819dd6ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3e4b0a8b1ee7c853ef18e3e16201cc3 = $(`&lt;div id=&quot;html_c3e4b0a8b1ee7c853ef18e3e16201cc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_741613d751c27a96b2b9864a819dd6ba.setContent(html_c3e4b0a8b1ee7c853ef18e3e16201cc3);
#
#
#
#         marker_e911de519579376196068a71289d12cd.bindPopup(popup_741613d751c27a96b2b9864a819dd6ba)
#         ;
#
#
#
#
#             var marker_a1f38353d4cea12e13a4b95a2cb5ab0a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_578dcbdeb94dd20f059224168399616a);
#
#
#         var popup_c9f6ff1678dd753f6215484fb174e187 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4b0a26e4ffcba180d23da888452e0d7 = $(`&lt;div id=&quot;html_a4b0a26e4ffcba180d23da888452e0d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c9f6ff1678dd753f6215484fb174e187.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cc6fa416e1f8c278c121ad795007a35 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cc6fa416e1f8c278c121ad795007a35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cc6fa416e1f8c278c121ad795007a35 = L.map(
#                 &quot;map_1cc6fa416e1f8c278c121ad795007a35&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_214845281021405f8778b6664ca0978d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_214845281021405f8778b6664ca0978d.addTo(map_1cc6fa416e1f8c278c121ad795007a35);
#
#
#             var feature_group_8dc592a6e693fc671ea9c824b389cfd4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_23689e0b0889277a5a3e01a4a1719fff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8dc592a6e693fc671ea9c824b389cfd4);
#
#
#         var popup_b7e4ff5b05ffc0a5aba1184e4d006eef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60d4d800f54513db6994a0774e781d95 = $(`&lt;div id=&quot;html_60d4d800f54513db6994a0774e781d95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b7e4ff5b05ffc0a5aba1184e4d006eef.setContent(html_60d4d800f54513db6994a0774e781d95);
#
#
#
#         marker_23689e0b0889277a5a3e01a4a1719fff.bindPopup(popup_b7e4ff5b05ffc0a5aba1184e4d006eef)
#         ;
#
#
#
#
#             var marker_45b9b8559a1bae876e4352d244802d53 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8dc592a6e693fc671ea9c824b389cfd4);
#
#
#         var popup_8eef7ecb884b392a82ecb0ee24eb342d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72959171ecf8670d454006720a72de4b = $(`&lt;div id=&quot;html_72959171ecf8670d454006720a72de4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8eef7ecb884b392a82ecb0ee24eb342d.setContent(html_72959171ecf8670d454006720a72de4b);
#
#
#
#         marker_45b9b8559a1bae876e4352d244802d53.bindPopup(popup_8eef7ecb884b392a82ecb0ee24eb342d)
#         ;
#
#
#
#
#             var marker_e6a971898ecb5219943fe571e76e5641 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8dc592a6e693fc671ea9c824b389cfd4);
#
#
#         var popup_68d2013fac97587a80c4403ba8fae1a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8421cf49574a7e99e54bdc84e083b13c = $(`&lt;div id=&quot;html_8421cf49574a7e99e54bdc84e083b13c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_68d2013fac97587a80c4403ba8fae1a0.setContent(html_8421cf49574a7e99e54bdc84e083b13c);
#
#
#
#         marker_e6a971898ecb5219943fe571e76e5641.bindPopup(popup_68d2013fac97587a80c4403ba8fae1a0)
#         ;
#
#
#
#
#             var marker_f535fecb12940ccfc996c6fb72780373 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8dc592a6e693fc671ea9c824b389cfd4);
#
#
#         var popup_ef629424d4e715bb1b5f114361f593f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93a809e1743d982fc33ba4e8425ce696 = $(`&lt;div id=&quot;html_93a809e1743d982fc33ba4e8425ce696&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ef629424d4e715bb1b5f114361f593f6.setContent(html_93a809e1743d982fc33ba4e8425ce696);
#
#
#
#         marker_f535fecb12940ccfc996c6fb72780373.bindPopup(popup_ef629424d4e715bb1b5f114361f593f6)
#         ;
#
#
#
#
#             var marker_c4be2964b2424a74b30f2ea74ac82132 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8dc592a6e693fc671ea9c824b389cfd4);
#
#
#         var popup_c9dfb34049975d4a542ec3113203a846 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_82fade143e28f7874d9e10acaab9eccc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_82fade143e28f7874d9e10acaab9eccc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_82fade143e28f7874d9e10acaab9eccc = L.map(
#                 &quot;map_82fade143e28f7874d9e10acaab9eccc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1f0adcdceea84d556e35c4b9e281b9e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d1f0adcdceea84d556e35c4b9e281b9e.addTo(map_82fade143e28f7874d9e10acaab9eccc);
#
#
#             var feature_group_5c2a4c49e327f25693cf71779346e411 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5c2a4c49e327f25693cf71779346e411.addTo(map_82fade143e28f7874d9e10acaab9eccc);
#
#
#             var feature_group_sub_group_a7513bcf918dc3c08e0b547cc53ae046 = L.featureGroup.subGroup(
#                 feature_group_5c2a4c49e327f25693cf71779346e411
#             );
#
#
#             var marker_fc6982145e5859d90175dd78e536b9a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a7513bcf918dc3c08e0b547cc53ae046);
#
#
#         var popup_5d77d54bb4adb521b84434a2f53cd513 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3739931a3aa3b652ab3aa5b1ef96f3e9 = $(`&lt;div id=&quot;html_3739931a3aa3b652ab3aa5b1ef96f3e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5d77d54bb4adb521b84434a2f53cd513.setContent(html_3739931a3aa3b652ab3aa5b1ef96f3e9);
#
#
#
#         marker_fc6982145e5859d90175dd78e536b9a6.bindPopup(popup_5d77d54bb4adb521b84434a2f53cd513)
#         ;
#
#
#
#
#             var marker_51fdd289134effae7dd5c2ee5e0ed9e3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a7513bcf918dc3c08e0b547cc53ae046);
#
#
#         var popup_e9d07db44719568f37261a96f372dacf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01789f57167e7cbc935d7e69bba56550 = $(`&lt;div id=&quot;html_01789f57167e7cbc935d7e69bba56550&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e9d07db44719568f37261a96f372dacf.setContent(html_01789f57167e7cbc935d7e69bba56550);
#
#
#
#         marker_51fdd289134effae7dd5c2ee5e0ed9e3.bindPopup(popup_e9d07db44719568f37261a96f372dacf)
#         ;
#
#
#
#
#             var marker_1bd59154a0945ae70b32f9f1681cda6a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a7513bcf918dc3c08e0b547cc53ae046);
#
#
#         var popup_c54c4fc5ae861a2be6739da2efc806d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_781560b2d9f6db6fa255b925a67af690 = $(`&lt;div id=&quot;html_781560b2d9f6db6fa255b925a67af690&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c54c4fc5ae861a2be6739da2efc806d1.setContent(html_781560b2d9f6db6fa255b925a67af690);
#
#
#
#         marker_1bd59154a0945ae70b32f9f1681cda6a.bindPopup(popup_c54c4fc5ae861a2be6739da2efc806d1)
#         ;
#
#
#
#
#             var marker_9ec80fc5eb4b56bbbba7be9ba52efd4a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a7513bcf918dc3c08e0b547cc53ae046);
#
#
#         var popup_449876ad0252356aa24294439521e7c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ca02dd7b18194b4e7d14ffcbf09b8df = $(`&lt;div id=&quot;html_6ca02dd7b18194b4e7d14ffcbf09b8df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_449876ad0252356aa24294439521e7c1.setContent(html_6ca02dd7b18194b4e7d14ffcbf09b8df);
#
#
#
#         marker_
