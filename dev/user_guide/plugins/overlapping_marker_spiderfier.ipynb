# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9b486ea96662c8f0e3513aa7e325b48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9b486ea96662c8f0e3513aa7e325b48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9b486ea96662c8f0e3513aa7e325b48 = L.map(
#                 &quot;map_f9b486ea96662c8f0e3513aa7e325b48&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3788842975408e9b4e8e4b4d1280c2db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3788842975408e9b4e8e4b4d1280c2db.addTo(map_f9b486ea96662c8f0e3513aa7e325b48);
#
#
#             var marker_936f6a17eac88352cbb4c88ab719b128 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f9b486ea96662c8f0e3513aa7e325b48);
#
#
#         var popup_769968f02af0e4ca008c1f70d44376d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9f53868d66ad25418051af0357796a4 = $(`&lt;div id=&quot;html_e9f53868d66ad25418051af0357796a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_769968f02af0e4ca008c1f70d44376d1.setContent(html_e9f53868d66ad25418051af0357796a4);
#
#
#
#         marker_936f6a17eac88352cbb4c88ab719b128.bindPopup(popup_769968f02af0e4ca008c1f70d44376d1)
#         ;
#
#
#
#
#             var marker_1c50664e3cceb3c35d8e310188128b32 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f9b486ea96662c8f0e3513aa7e325b48);
#
#
#         var popup_88654998b18d6cdf4989391a13831483 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97e262c60e5ffa3adacb9fd9bcd12113 = $(`&lt;div id=&quot;html_97e262c60e5ffa3adacb9fd9bcd12113&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_88654998b18d6cdf4989391a13831483.setContent(html_97e262c60e5ffa3adacb9fd9bcd12113);
#
#
#
#         marker_1c50664e3cceb3c35d8e310188128b32.bindPopup(popup_88654998b18d6cdf4989391a13831483)
#         ;
#
#
#
#
#             var marker_5cad86139bbf142ca0f58dc85461a6bd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f9b486ea96662c8f0e3513aa7e325b48);
#
#
#         var popup_42701ac738ada2d21b29f20fea60b620 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8be191a341a6612bb6a70c30ac6b89f6 = $(`&lt;div id=&quot;html_8be191a341a6612bb6a70c30ac6b89f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_42701ac738ada2d21b29f20fea60b620.setContent(html_8be191a341a6612bb6a70c30ac6b89f6);
#
#
#
#         marker_5cad86139bbf142ca0f58dc85461a6bd.bindPopup(popup_42701ac738ada2d21b29f20fea60b620)
#         ;
#
#
#
#
#             var marker_f709fb37b4eb35d6ec9ae0496eaea98a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f9b486ea96662c8f0e3513aa7e325b48);
#
#
#         var popup_f1fb30d51c3ce3d8153312acf5e9f132 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2340f3713aaf7f192983bdd21f8d6b2c = $(`&lt;div id=&quot;html_2340f3713aaf7f192983bdd21f8d6b2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f1fb30d51c3ce3d8153312acf5e9f132.setContent(html_2340f3713aaf7f192983bdd21f8d6b2c);
#
#
#
#         marker_f709fb37b4eb35d6ec9ae0496eaea98a.bindPopup(popup_f1fb30d51c3ce3d8153312acf5e9f132)
#         ;
#
#
#
#
#             var marker_904881cf2da135238af16786ee66dc00 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f9b486ea96662c8f0e3513aa7e325b48);
#
#
#         var popup_c95101e8995612e0dfc7be3daa1a3096 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff049c9ca7adb4d2df7e6d0ac830b50b = $(`&lt;div id=&quot;html_ff049c9ca7adb4d2df7e6d0ac830b50b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c95101e8995612e0dfc7be3daa1a3096.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3a5a9621af8871f797f229d0f70ebb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3a5a9621af8871f797f229d0f70ebb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3a5a9621af8871f797f229d0f70ebb2 = L.map(
#                 &quot;map_b3a5a9621af8871f797f229d0f70ebb2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_436fa8808d052056ca0136ffe4fbe260 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_436fa8808d052056ca0136ffe4fbe260.addTo(map_b3a5a9621af8871f797f229d0f70ebb2);
#
#
#             var feature_group_f1fe46c041a966e5bd895c848f6f4eed = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_13d297eedf74351a9e55b3ed44b4886e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f1fe46c041a966e5bd895c848f6f4eed);
#
#
#         var popup_e9ea4d75f164076f6d2d622d1a076bf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d26680ca739527ec0b6f82141174634 = $(`&lt;div id=&quot;html_6d26680ca739527ec0b6f82141174634&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e9ea4d75f164076f6d2d622d1a076bf7.setContent(html_6d26680ca739527ec0b6f82141174634);
#
#
#
#         marker_13d297eedf74351a9e55b3ed44b4886e.bindPopup(popup_e9ea4d75f164076f6d2d622d1a076bf7)
#         ;
#
#
#
#
#             var marker_2a67ca17f57862295cafe5decd4f50db = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f1fe46c041a966e5bd895c848f6f4eed);
#
#
#         var popup_c24bc729f0bc79b30ed91716265c86b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55729b7cbab75d56817e2554f1b3442d = $(`&lt;div id=&quot;html_55729b7cbab75d56817e2554f1b3442d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c24bc729f0bc79b30ed91716265c86b8.setContent(html_55729b7cbab75d56817e2554f1b3442d);
#
#
#
#         marker_2a67ca17f57862295cafe5decd4f50db.bindPopup(popup_c24bc729f0bc79b30ed91716265c86b8)
#         ;
#
#
#
#
#             var marker_89e82b72b368b6851480baf8e150e467 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f1fe46c041a966e5bd895c848f6f4eed);
#
#
#         var popup_ff2430fdd96225a1d5066d2bc6a6c95f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_560944a3927b83c639ae9fa47bae4dd9 = $(`&lt;div id=&quot;html_560944a3927b83c639ae9fa47bae4dd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ff2430fdd96225a1d5066d2bc6a6c95f.setContent(html_560944a3927b83c639ae9fa47bae4dd9);
#
#
#
#         marker_89e82b72b368b6851480baf8e150e467.bindPopup(popup_ff2430fdd96225a1d5066d2bc6a6c95f)
#         ;
#
#
#
#
#             var marker_051332726b90b21d57169797146969a2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f1fe46c041a966e5bd895c848f6f4eed);
#
#
#         var popup_6fa74b4770ab5867e658cbe48ee614eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63aaa44cfac7ffc4412a992ba531f620 = $(`&lt;div id=&quot;html_63aaa44cfac7ffc4412a992ba531f620&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6fa74b4770ab5867e658cbe48ee614eb.setContent(html_63aaa44cfac7ffc4412a992ba531f620);
#
#
#
#         marker_051332726b90b21d57169797146969a2.bindPopup(popup_6fa74b4770ab5867e658cbe48ee614eb)
#         ;
#
#
#
#
#             var marker_ac9f3fcc59a38f8204cd87e4c6fd28dc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f1fe46c041a966e5bd895c848f6f4eed);
#
#
#         var popup_1dd92b0c9457cc03fb22ad65029dbfd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1d0881885620a7b63d59ea71fabfc889 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1d0881885620a7b63d59ea71fabfc889&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1d0881885620a7b63d59ea71fabfc889 = L.map(
#                 &quot;map_1d0881885620a7b63d59ea71fabfc889&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f3d40763a5aa8b3c5438aa09d2cd2e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f3d40763a5aa8b3c5438aa09d2cd2e7.addTo(map_1d0881885620a7b63d59ea71fabfc889);
#
#
#             var feature_group_d73fd1dfa7c7a385f321e4d6a2a9e2ef = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d73fd1dfa7c7a385f321e4d6a2a9e2ef.addTo(map_1d0881885620a7b63d59ea71fabfc889);
#
#
#             var feature_group_sub_group_5dfd3d1a3bcbdeeddcf396fdd973cfe8 = L.featureGroup.subGroup(
#                 feature_group_d73fd1dfa7c7a385f321e4d6a2a9e2ef
#             );
#
#
#             var marker_f1c5b203d3fefc374cdc4d26741ab7b5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5dfd3d1a3bcbdeeddcf396fdd973cfe8);
#
#
#         var popup_d9d7aac541a68a491fe878e5e0ffb556 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84866523727f2c71350e685d867ab33c = $(`&lt;div id=&quot;html_84866523727f2c71350e685d867ab33c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d9d7aac541a68a491fe878e5e0ffb556.setContent(html_84866523727f2c71350e685d867ab33c);
#
#
#
#         marker_f1c5b203d3fefc374cdc4d26741ab7b5.bindPopup(popup_d9d7aac541a68a491fe878e5e0ffb556)
#         ;
#
#
#
#
#             var marker_6ac9edd2efa5e040f467191d5d626c27 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5dfd3d1a3bcbdeeddcf396fdd973cfe8);
#
#
#         var popup_4efef91a86551a7a2b9a141dcba6148c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e77275176e5da879e2a76b9e2d189e68 = $(`&lt;div id=&quot;html_e77275176e5da879e2a76b9e2d189e68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4efef91a86551a7a2b9a141dcba6148c.setContent(html_e77275176e5da879e2a76b9e2d189e68);
#
#
#
#         marker_6ac9edd2efa5e040f467191d5d626c27.bindPopup(popup_4efef91a86551a7a2b9a141dcba6148c)
#         ;
#
#
#
#
#             var marker_ce4a80a847cac523b0c065961fa8b7e1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5dfd3d1a3bcbdeeddcf396fdd973cfe8);
#
#
#         var popup_3443d4a7deb3ca3faf5c7635b56387f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fce0c3532bcd95e173d86f7b6c398462 = $(`&lt;div id=&quot;html_fce0c3532bcd95e173d86f7b6c398462&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3443d4a7deb3ca3faf5c7635b56387f5.setContent(html_fce0c3532bcd95e173d86f7b6c398462);
#
#
#
#         marker_ce4a80a847cac523b0c065961fa8b7e1.bindPopup(popup_3443d4a7deb3ca3faf5c7635b56387f5)
#         ;
#
#
#
#
#             var marker_487e4be21d7f4c7c0902433a972826e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5dfd3d1a3bcbdeeddcf396fdd973cfe8);
#
#
#         var popup_544f7f44cf60fd0803ed4446d4683c8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b586d9512858437cd4e20c2b4e51436 = $(`&lt;div id=&quot;html_1b586d9512858437cd4e20c2b4e51436&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_544f7f44cf60fd0803ed4446d4683c8f.setContent(html_1b586d9512858437cd4e20c2b4e51436);
#
#
#
#         marker_
