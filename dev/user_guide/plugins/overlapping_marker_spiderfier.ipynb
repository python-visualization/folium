# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14e8eb16116d648a04bcd249d337635d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14e8eb16116d648a04bcd249d337635d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14e8eb16116d648a04bcd249d337635d = L.map(
#                 &quot;map_14e8eb16116d648a04bcd249d337635d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afd3ee75f54d60c0f597a55a3176857a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afd3ee75f54d60c0f597a55a3176857a.addTo(map_14e8eb16116d648a04bcd249d337635d);
#
#
#             var marker_a66533796262ac1dbf3222464cb4f0b7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_14e8eb16116d648a04bcd249d337635d);
#
#
#         var popup_3e225e3dac16a51c527031efa793f6c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30cd3f7b29acd3119d28ee10ee6be4fa = $(`&lt;div id=&quot;html_30cd3f7b29acd3119d28ee10ee6be4fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3e225e3dac16a51c527031efa793f6c1.setContent(html_30cd3f7b29acd3119d28ee10ee6be4fa);
#
#
#
#         marker_a66533796262ac1dbf3222464cb4f0b7.bindPopup(popup_3e225e3dac16a51c527031efa793f6c1)
#         ;
#
#
#
#
#             var marker_cbc86283723bea574c430b8756e1eaa2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_14e8eb16116d648a04bcd249d337635d);
#
#
#         var popup_efa79d553cd7534c960b157f307ab92a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f108be00d3cd7db1977ca83d00a49c4a = $(`&lt;div id=&quot;html_f108be00d3cd7db1977ca83d00a49c4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_efa79d553cd7534c960b157f307ab92a.setContent(html_f108be00d3cd7db1977ca83d00a49c4a);
#
#
#
#         marker_cbc86283723bea574c430b8756e1eaa2.bindPopup(popup_efa79d553cd7534c960b157f307ab92a)
#         ;
#
#
#
#
#             var marker_0140982843e1cc4fb14eade2339d229b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_14e8eb16116d648a04bcd249d337635d);
#
#
#         var popup_a03ef07290ecbf074d557797e435f268 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bddca06619160bf1c4c65f5f5d1ebe6e = $(`&lt;div id=&quot;html_bddca06619160bf1c4c65f5f5d1ebe6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a03ef07290ecbf074d557797e435f268.setContent(html_bddca06619160bf1c4c65f5f5d1ebe6e);
#
#
#
#         marker_0140982843e1cc4fb14eade2339d229b.bindPopup(popup_a03ef07290ecbf074d557797e435f268)
#         ;
#
#
#
#
#             var marker_ebdd106bb7430815f79e8f4b9a297e0c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_14e8eb16116d648a04bcd249d337635d);
#
#
#         var popup_4e0cba029b8441c50ec985da01ce614d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f41392adc6ba6f685db11a184d288f34 = $(`&lt;div id=&quot;html_f41392adc6ba6f685db11a184d288f34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4e0cba029b8441c50ec985da01ce614d.setContent(html_f41392adc6ba6f685db11a184d288f34);
#
#
#
#         marker_ebdd106bb7430815f79e8f4b9a297e0c.bindPopup(popup_4e0cba029b8441c50ec985da01ce614d)
#         ;
#
#
#
#
#             var marker_99d70767b92df36dd1e9a05e827e59b6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_14e8eb16116d648a04bcd249d337635d);
#
#
#         var popup_374cd750dfc1a0aa1f1343e4d4deb76e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fc1a8101947224bca98bead51b4abc5 = $(`&lt;div id=&quot;html_1fc1a8101947224bca98bead51b4abc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_374cd750dfc1a0aa1f1343e4d4deb7

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a44c3f92b9762356ae9c72e789cd801e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a44c3f92b9762356ae9c72e789cd801e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a44c3f92b9762356ae9c72e789cd801e = L.map(
#                 &quot;map_a44c3f92b9762356ae9c72e789cd801e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2926220bdc9059e4eab44bfd087069c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2926220bdc9059e4eab44bfd087069c7.addTo(map_a44c3f92b9762356ae9c72e789cd801e);
#
#
#             var feature_group_aaa3e51db0d63af4c1de1547bddc083a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2de130bc1d65710f80effef9f20dcf1d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_aaa3e51db0d63af4c1de1547bddc083a);
#
#
#         var popup_1ca3e33e54d94f27961c7acaed374b68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b41fcf990b295404b08e491a830c695 = $(`&lt;div id=&quot;html_6b41fcf990b295404b08e491a830c695&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1ca3e33e54d94f27961c7acaed374b68.setContent(html_6b41fcf990b295404b08e491a830c695);
#
#
#
#         marker_2de130bc1d65710f80effef9f20dcf1d.bindPopup(popup_1ca3e33e54d94f27961c7acaed374b68)
#         ;
#
#
#
#
#             var marker_97df3cc8d2c84021269b4fcce5ff5e46 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_aaa3e51db0d63af4c1de1547bddc083a);
#
#
#         var popup_e1e0e075b01f7e96a5f23c39a2c8febc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f9d034070dfc4869050d044f6a02c5b = $(`&lt;div id=&quot;html_5f9d034070dfc4869050d044f6a02c5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e1e0e075b01f7e96a5f23c39a2c8febc.setContent(html_5f9d034070dfc4869050d044f6a02c5b);
#
#
#
#         marker_97df3cc8d2c84021269b4fcce5ff5e46.bindPopup(popup_e1e0e075b01f7e96a5f23c39a2c8febc)
#         ;
#
#
#
#
#             var marker_d93e4a39b943934cf09b9acb79c39a49 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_aaa3e51db0d63af4c1de1547bddc083a);
#
#
#         var popup_9b2a696afd37fadc3a23c8d606c042cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8118608e196f6610e5e8b3d0dafbc9fd = $(`&lt;div id=&quot;html_8118608e196f6610e5e8b3d0dafbc9fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9b2a696afd37fadc3a23c8d606c042cf.setContent(html_8118608e196f6610e5e8b3d0dafbc9fd);
#
#
#
#         marker_d93e4a39b943934cf09b9acb79c39a49.bindPopup(popup_9b2a696afd37fadc3a23c8d606c042cf)
#         ;
#
#
#
#
#             var marker_a6ec241c708485aae5e47b72a711eb0f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_aaa3e51db0d63af4c1de1547bddc083a);
#
#
#         var popup_ca90ddafecf9935efd923e68499916f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6605671752187f011ad81138b131753f = $(`&lt;div id=&quot;html_6605671752187f011ad81138b131753f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ca90ddafecf9935efd923e68499916f3.setContent(html_6605671752187f011ad81138b131753f);
#
#
#
#         marker_a6ec241c708485aae5e47b72a711eb0f.bindPopup(popup_ca90ddafecf9935efd923e68499916f3)
#         ;
#
#
#
#
#             var marker_c3100f12c03e531e62f318ca94bd7fe3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_aaa3e51db0d63af4c1de1547bddc083a);
#
#
#         var popup_d7d3e236354efdcbd1ed574bb6dc41ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_789bed446a059f453effe595d10be956 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_789bed446a059f453effe595d10be956&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_789bed446a059f453effe595d10be956 = L.map(
#                 &quot;map_789bed446a059f453effe595d10be956&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0790580ec6b9a39355476f7670f1b165 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0790580ec6b9a39355476f7670f1b165.addTo(map_789bed446a059f453effe595d10be956);
#
#
#             var feature_group_7476a2f5b6c2816e81930fc7442427a2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7476a2f5b6c2816e81930fc7442427a2.addTo(map_789bed446a059f453effe595d10be956);
#
#
#             var feature_group_sub_group_eed0cb9daf5defdd659793b41aadc7dc = L.featureGroup.subGroup(
#                 feature_group_7476a2f5b6c2816e81930fc7442427a2
#             );
#
#
#             var marker_6ae02c2aeb16d309ada893cb04dae3d0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_eed0cb9daf5defdd659793b41aadc7dc);
#
#
#         var popup_7aab27ad87bbf78c1c1b99f7911e6df2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ced38d5f322ffd1e093e9ec75d33208 = $(`&lt;div id=&quot;html_2ced38d5f322ffd1e093e9ec75d33208&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7aab27ad87bbf78c1c1b99f7911e6df2.setContent(html_2ced38d5f322ffd1e093e9ec75d33208);
#
#
#
#         marker_6ae02c2aeb16d309ada893cb04dae3d0.bindPopup(popup_7aab27ad87bbf78c1c1b99f7911e6df2)
#         ;
#
#
#
#
#             var marker_ce3bbb39f9d89f8c461ae97924c33507 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_eed0cb9daf5defdd659793b41aadc7dc);
#
#
#         var popup_36769b593d6efbbc07802e0c0a8bf60b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e5c5a08e6ba81daeae1876c645da200 = $(`&lt;div id=&quot;html_5e5c5a08e6ba81daeae1876c645da200&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_36769b593d6efbbc07802e0c0a8bf60b.setContent(html_5e5c5a08e6ba81daeae1876c645da200);
#
#
#
#         marker_ce3bbb39f9d89f8c461ae97924c33507.bindPopup(popup_36769b593d6efbbc07802e0c0a8bf60b)
#         ;
#
#
#
#
#             var marker_01b00eaf241490ecb96b619a606afa84 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_eed0cb9daf5defdd659793b41aadc7dc);
#
#
#         var popup_1e74123af042562963362ceba5eb47af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d18c6eeb3ab77beb3a71e2bfdbd5b5a1 = $(`&lt;div id=&quot;html_d18c6eeb3ab77beb3a71e2bfdbd5b5a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1e74123af042562963362ceba5eb47af.setContent(html_d18c6eeb3ab77beb3a71e2bfdbd5b5a1);
#
#
#
#         marker_01b00eaf241490ecb96b619a606afa84.bindPopup(popup_1e74123af042562963362ceba5eb47af)
#         ;
#
#
#
#
#             var marker_4a1b0a597db037f0d1bca26874060b69 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_eed0cb9daf5defdd659793b41aadc7dc);
#
#
#         var popup_3e051809e905a9471ee6c57775e2d6bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba7233ae7d72ded12c544f41a6888707 = $(`&lt;div id=&quot;html_ba7233ae7d72ded12c544f41a6888707&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3e051809e905a9471ee6c57775e2d6bf.setContent(html_ba7233ae7d72ded12c544f41a6888707);
#
#
#
#         mark
