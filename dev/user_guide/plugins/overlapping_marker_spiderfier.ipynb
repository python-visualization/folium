# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_858a5a554ca0bf0438718546c017cc57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_858a5a554ca0bf0438718546c017cc57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_858a5a554ca0bf0438718546c017cc57 = L.map(
#                 &quot;map_858a5a554ca0bf0438718546c017cc57&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b115f6ce3544e9119ae932097bc0816f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b115f6ce3544e9119ae932097bc0816f.addTo(map_858a5a554ca0bf0438718546c017cc57);
#
#
#             var marker_83c9057a08a2c37d4101f2cc98927025 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_858a5a554ca0bf0438718546c017cc57);
#
#
#         var popup_a7ed2c28ef652351ff0d9facb4f12e60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_052892cf2669df3a23c38010ace49b72 = $(`&lt;div id=&quot;html_052892cf2669df3a23c38010ace49b72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a7ed2c28ef652351ff0d9facb4f12e60.setContent(html_052892cf2669df3a23c38010ace49b72);
#
#
#
#         marker_83c9057a08a2c37d4101f2cc98927025.bindPopup(popup_a7ed2c28ef652351ff0d9facb4f12e60)
#         ;
#
#
#
#
#             var marker_7de7dd7d2db7d2df05a02df26e2094b0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_858a5a554ca0bf0438718546c017cc57);
#
#
#         var popup_429959824d95c12a489f173ca4f360a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6dde3fddd7cdfd09b5d5056e41f3480b = $(`&lt;div id=&quot;html_6dde3fddd7cdfd09b5d5056e41f3480b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_429959824d95c12a489f173ca4f360a7.setContent(html_6dde3fddd7cdfd09b5d5056e41f3480b);
#
#
#
#         marker_7de7dd7d2db7d2df05a02df26e2094b0.bindPopup(popup_429959824d95c12a489f173ca4f360a7)
#         ;
#
#
#
#
#             var marker_b0997ae8b7a898c5a51b40cf70a88fc5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_858a5a554ca0bf0438718546c017cc57);
#
#
#         var popup_5a3ed4a2a74e1ca3d021543a3b656fd6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42fe1901f2902a01d45e5cdf17285c25 = $(`&lt;div id=&quot;html_42fe1901f2902a01d45e5cdf17285c25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5a3ed4a2a74e1ca3d021543a3b656fd6.setContent(html_42fe1901f2902a01d45e5cdf17285c25);
#
#
#
#         marker_b0997ae8b7a898c5a51b40cf70a88fc5.bindPopup(popup_5a3ed4a2a74e1ca3d021543a3b656fd6)
#         ;
#
#
#
#
#             var marker_3d2ce9b4de4b095ddfdcbce78b74c6f2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_858a5a554ca0bf0438718546c017cc57);
#
#
#         var popup_af3f2df957d2f943895149809c50e687 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a89dac796e83a91109c936b8bfb165e8 = $(`&lt;div id=&quot;html_a89dac796e83a91109c936b8bfb165e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_af3f2df957d2f943895149809c50e687.setContent(html_a89dac796e83a91109c936b8bfb165e8);
#
#
#
#         marker_3d2ce9b4de4b095ddfdcbce78b74c6f2.bindPopup(popup_af3f2df957d2f943895149809c50e687)
#         ;
#
#
#
#
#             var marker_e8d2336c33359635c8ebee4841f8bbc7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_858a5a554ca0bf0438718546c017cc57);
#
#
#         var popup_57b5083837c3f30d0ae0112d1aafe7c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f8b4ae38e9d231a0a4ccd37c7b5aa01 = $(`&lt;div id=&quot;html_5f8b4ae38e9d231a0a4ccd37c7b5aa01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_57b5083837c3f30d0ae0112d1aafe7c6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35ceec43f1165d57436cb1edb40e4be6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35ceec43f1165d57436cb1edb40e4be6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35ceec43f1165d57436cb1edb40e4be6 = L.map(
#                 &quot;map_35ceec43f1165d57436cb1edb40e4be6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f94489263ad5f8edbb5efdc6d36794d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f94489263ad5f8edbb5efdc6d36794d7.addTo(map_35ceec43f1165d57436cb1edb40e4be6);
#
#
#             var feature_group_537c7cdfbecdddd6cda55587242d85c0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3d3c7330028db94ed567318b0966768c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_537c7cdfbecdddd6cda55587242d85c0);
#
#
#         var popup_2ba815b8d7c2b9d22dfc64a30eec3861 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbe4e87625ca132a94a9aa7ad65e222e = $(`&lt;div id=&quot;html_fbe4e87625ca132a94a9aa7ad65e222e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2ba815b8d7c2b9d22dfc64a30eec3861.setContent(html_fbe4e87625ca132a94a9aa7ad65e222e);
#
#
#
#         marker_3d3c7330028db94ed567318b0966768c.bindPopup(popup_2ba815b8d7c2b9d22dfc64a30eec3861)
#         ;
#
#
#
#
#             var marker_f7fe90d7095771013626eae6de5863e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_537c7cdfbecdddd6cda55587242d85c0);
#
#
#         var popup_1ef577b311683cf846900f0f1b34f9f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8645ade7da3bd802a484f06dd7160dd3 = $(`&lt;div id=&quot;html_8645ade7da3bd802a484f06dd7160dd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1ef577b311683cf846900f0f1b34f9f5.setContent(html_8645ade7da3bd802a484f06dd7160dd3);
#
#
#
#         marker_f7fe90d7095771013626eae6de5863e8.bindPopup(popup_1ef577b311683cf846900f0f1b34f9f5)
#         ;
#
#
#
#
#             var marker_a7987a3af1bd76a1a70980d81a85d1ea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_537c7cdfbecdddd6cda55587242d85c0);
#
#
#         var popup_c43b76d77650fd64b8490098cd059caa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50351185404da6b7a57fecaee8a424c3 = $(`&lt;div id=&quot;html_50351185404da6b7a57fecaee8a424c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c43b76d77650fd64b8490098cd059caa.setContent(html_50351185404da6b7a57fecaee8a424c3);
#
#
#
#         marker_a7987a3af1bd76a1a70980d81a85d1ea.bindPopup(popup_c43b76d77650fd64b8490098cd059caa)
#         ;
#
#
#
#
#             var marker_c970661a43d3a9763354386b334c101a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_537c7cdfbecdddd6cda55587242d85c0);
#
#
#         var popup_8675af3233e3f9aea6effea99cc55585 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9daebd9d65234b28d8add6e8cfdfa4f2 = $(`&lt;div id=&quot;html_9daebd9d65234b28d8add6e8cfdfa4f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8675af3233e3f9aea6effea99cc55585.setContent(html_9daebd9d65234b28d8add6e8cfdfa4f2);
#
#
#
#         marker_c970661a43d3a9763354386b334c101a.bindPopup(popup_8675af3233e3f9aea6effea99cc55585)
#         ;
#
#
#
#
#             var marker_981bb08cfd963225edb5e5e90e96651a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_537c7cdfbecdddd6cda55587242d85c0);
#
#
#         var popup_f83451ed3d043c6eb4eae54938a134c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_871ada41cc073125eb67ce9c529ff199 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_871ada41cc073125eb67ce9c529ff199&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_871ada41cc073125eb67ce9c529ff199 = L.map(
#                 &quot;map_871ada41cc073125eb67ce9c529ff199&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65768f39afa53dde74941a7712da594d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65768f39afa53dde74941a7712da594d.addTo(map_871ada41cc073125eb67ce9c529ff199);
#
#
#             var feature_group_2ab0df17f0a7ac5d5449167171ce6628 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2ab0df17f0a7ac5d5449167171ce6628.addTo(map_871ada41cc073125eb67ce9c529ff199);
#
#
#             var feature_group_sub_group_b4303e36584b385e8d17bd0ad662ebf4 = L.featureGroup.subGroup(
#                 feature_group_2ab0df17f0a7ac5d5449167171ce6628
#             );
#
#
#             var marker_404024c4467da99d19f2a86726c38f6c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b4303e36584b385e8d17bd0ad662ebf4);
#
#
#         var popup_4da8df41318379595c6d893e711beaf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8226a37ed12ef7f1287fd25baf89b02 = $(`&lt;div id=&quot;html_a8226a37ed12ef7f1287fd25baf89b02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4da8df41318379595c6d893e711beaf7.setContent(html_a8226a37ed12ef7f1287fd25baf89b02);
#
#
#
#         marker_404024c4467da99d19f2a86726c38f6c.bindPopup(popup_4da8df41318379595c6d893e711beaf7)
#         ;
#
#
#
#
#             var marker_268a3a0ac5196db85c92db48cf380487 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b4303e36584b385e8d17bd0ad662ebf4);
#
#
#         var popup_d1e42f4991828ab3472987973a49aa5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38da0b81796480790ca953b075b52e82 = $(`&lt;div id=&quot;html_38da0b81796480790ca953b075b52e82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d1e42f4991828ab3472987973a49aa5c.setContent(html_38da0b81796480790ca953b075b52e82);
#
#
#
#         marker_268a3a0ac5196db85c92db48cf380487.bindPopup(popup_d1e42f4991828ab3472987973a49aa5c)
#         ;
#
#
#
#
#             var marker_840e5d892006015e82bdc7dd4673a32a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b4303e36584b385e8d17bd0ad662ebf4);
#
#
#         var popup_f0ac99f0dcfd5bbec1d458d3818f9b80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_161f9234f2e4b2f0d60313d03a031d4d = $(`&lt;div id=&quot;html_161f9234f2e4b2f0d60313d03a031d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f0ac99f0dcfd5bbec1d458d3818f9b80.setContent(html_161f9234f2e4b2f0d60313d03a031d4d);
#
#
#
#         marker_840e5d892006015e82bdc7dd4673a32a.bindPopup(popup_f0ac99f0dcfd5bbec1d458d3818f9b80)
#         ;
#
#
#
#
#             var marker_e95f3fb07720f2c7f2122385d3d84c06 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b4303e36584b385e8d17bd0ad662ebf4);
#
#
#         var popup_5186ffdcf0cab800349ca869e6cd8f27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a302691497aa7c1b20c33be0e2f1d013 = $(`&lt;div id=&quot;html_a302691497aa7c1b20c33be0e2f1d013&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5186ffdcf0cab800349ca869e6cd8f27.setContent(html_a302691497aa7c1b20c33be0e2f1d013);
#
#
#
#         marker_
