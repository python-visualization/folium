# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd7eec4455f38086732ccb0ad5f58745 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd7eec4455f38086732ccb0ad5f58745&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd7eec4455f38086732ccb0ad5f58745 = L.map(
#                 &quot;map_bd7eec4455f38086732ccb0ad5f58745&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83fbf55d423eb991f72c04273a41227e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_83fbf55d423eb991f72c04273a41227e.addTo(map_bd7eec4455f38086732ccb0ad5f58745);
#
#
#             var marker_86418a22d57a1c471d20fe778b0c78b1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bd7eec4455f38086732ccb0ad5f58745);
#
#
#         var popup_8b8e90e239873ff49905bcc000981cd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8bf6da61b28128ea43ca2c9a916e1c6 = $(`&lt;div id=&quot;html_a8bf6da61b28128ea43ca2c9a916e1c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8b8e90e239873ff49905bcc000981cd9.setContent(html_a8bf6da61b28128ea43ca2c9a916e1c6);
#
#
#
#         marker_86418a22d57a1c471d20fe778b0c78b1.bindPopup(popup_8b8e90e239873ff49905bcc000981cd9)
#         ;
#
#
#
#
#             var marker_9aeb4e0bf41af709d69df04cc733a56c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bd7eec4455f38086732ccb0ad5f58745);
#
#
#         var popup_b3a0050997aa74a948b9be8e4093bdd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb6e92b60a7635f9d78bfc93280179a6 = $(`&lt;div id=&quot;html_fb6e92b60a7635f9d78bfc93280179a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b3a0050997aa74a948b9be8e4093bdd7.setContent(html_fb6e92b60a7635f9d78bfc93280179a6);
#
#
#
#         marker_9aeb4e0bf41af709d69df04cc733a56c.bindPopup(popup_b3a0050997aa74a948b9be8e4093bdd7)
#         ;
#
#
#
#
#             var marker_95a4fc866eabef0b18536086d01471cc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bd7eec4455f38086732ccb0ad5f58745);
#
#
#         var popup_410a160d635767a4b6380dba6539e899 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_819db794f39eda279bb8feefb9217927 = $(`&lt;div id=&quot;html_819db794f39eda279bb8feefb9217927&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_410a160d635767a4b6380dba6539e899.setContent(html_819db794f39eda279bb8feefb9217927);
#
#
#
#         marker_95a4fc866eabef0b18536086d01471cc.bindPopup(popup_410a160d635767a4b6380dba6539e899)
#         ;
#
#
#
#
#             var marker_827f3f06bffc9b7b9aba63d4014adf15 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bd7eec4455f38086732ccb0ad5f58745);
#
#
#         var popup_c92dc50db2cb20c41e9d5d65c829d4e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_273bc7b0e6f49039c002d78e21d0d9ed = $(`&lt;div id=&quot;html_273bc7b0e6f49039c002d78e21d0d9ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c92dc50db2cb20c41e9d5d65c829d4e3.setContent(html_273bc7b0e6f49039c002d78e21d0d9ed);
#
#
#
#         marker_827f3f06bffc9b7b9aba63d4014adf15.bindPopup(popup_c92dc50db2cb20c41e9d5d65c829d4e3)
#         ;
#
#
#
#
#             var marker_261af3eee077a94b3db132d395a1a4e7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bd7eec4455f38086732ccb0ad5f58745);
#
#
#         var popup_ee551ba46848bd33b741d351375fb3a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16ecf78a92f647b7b10ebf077f3eac7b = $(`&lt;div id=&quot;html_16ecf78a92f647b7b10ebf077f3eac7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ee551ba46848bd33b741d351375fb3a2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50f29e6f118f52aea21176a4954439f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50f29e6f118f52aea21176a4954439f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50f29e6f118f52aea21176a4954439f2 = L.map(
#                 &quot;map_50f29e6f118f52aea21176a4954439f2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dffc23e575823e17794f57565e865106 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dffc23e575823e17794f57565e865106.addTo(map_50f29e6f118f52aea21176a4954439f2);
#
#
#             var feature_group_c8b7dfddcbd7e10f04acd7b0a86f27ba = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ba88d1b4bb0e68e4c12709d19f70f26b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c8b7dfddcbd7e10f04acd7b0a86f27ba);
#
#
#         var popup_2c9d2d8d77d0a8d972ed403cddea3695 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cb0945f16e8041038ee89cdb9604ad2 = $(`&lt;div id=&quot;html_8cb0945f16e8041038ee89cdb9604ad2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2c9d2d8d77d0a8d972ed403cddea3695.setContent(html_8cb0945f16e8041038ee89cdb9604ad2);
#
#
#
#         marker_ba88d1b4bb0e68e4c12709d19f70f26b.bindPopup(popup_2c9d2d8d77d0a8d972ed403cddea3695)
#         ;
#
#
#
#
#             var marker_49b77a6ab487a726ab150ee0c3ec1757 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c8b7dfddcbd7e10f04acd7b0a86f27ba);
#
#
#         var popup_fd8ccb67622b624185175ace858a7930 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbc994fc738fa1b2f60284a27c1a39f5 = $(`&lt;div id=&quot;html_dbc994fc738fa1b2f60284a27c1a39f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fd8ccb67622b624185175ace858a7930.setContent(html_dbc994fc738fa1b2f60284a27c1a39f5);
#
#
#
#         marker_49b77a6ab487a726ab150ee0c3ec1757.bindPopup(popup_fd8ccb67622b624185175ace858a7930)
#         ;
#
#
#
#
#             var marker_776a083edd1681222e3558fbe903e610 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c8b7dfddcbd7e10f04acd7b0a86f27ba);
#
#
#         var popup_780c1a97aba412127e6aaab3601240bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f3a8029f88202852638d9ba52da2a6c = $(`&lt;div id=&quot;html_2f3a8029f88202852638d9ba52da2a6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_780c1a97aba412127e6aaab3601240bc.setContent(html_2f3a8029f88202852638d9ba52da2a6c);
#
#
#
#         marker_776a083edd1681222e3558fbe903e610.bindPopup(popup_780c1a97aba412127e6aaab3601240bc)
#         ;
#
#
#
#
#             var marker_3340ec53388a536b9cd52ca018dbfcae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c8b7dfddcbd7e10f04acd7b0a86f27ba);
#
#
#         var popup_f858dd3a81d1d4ef903fef1b106b0144 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef7cec220314fc2867b29245a410dad4 = $(`&lt;div id=&quot;html_ef7cec220314fc2867b29245a410dad4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f858dd3a81d1d4ef903fef1b106b0144.setContent(html_ef7cec220314fc2867b29245a410dad4);
#
#
#
#         marker_3340ec53388a536b9cd52ca018dbfcae.bindPopup(popup_f858dd3a81d1d4ef903fef1b106b0144)
#         ;
#
#
#
#
#             var marker_c763d28df09c8d9fa21f688ac5f397b6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c8b7dfddcbd7e10f04acd7b0a86f27ba);
#
#
#         var popup_4a83a56a136dc987a059dbab4bebe809 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_033dd1fd5d4f0eb762beecd9ab8fbae3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_033dd1fd5d4f0eb762beecd9ab8fbae3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_033dd1fd5d4f0eb762beecd9ab8fbae3 = L.map(
#                 &quot;map_033dd1fd5d4f0eb762beecd9ab8fbae3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afe325454acd5badfb5e2e2f61f30ab5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afe325454acd5badfb5e2e2f61f30ab5.addTo(map_033dd1fd5d4f0eb762beecd9ab8fbae3);
#
#
#             var feature_group_21697b8fd3bc0059e318effa2d311e71 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_21697b8fd3bc0059e318effa2d311e71.addTo(map_033dd1fd5d4f0eb762beecd9ab8fbae3);
#
#
#             var feature_group_sub_group_3269b46743da729dc5968a45cc3f8e25 = L.featureGroup.subGroup(
#                 feature_group_21697b8fd3bc0059e318effa2d311e71
#             );
#
#
#             var marker_c34525c410dcb1127769178397cfe91f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3269b46743da729dc5968a45cc3f8e25);
#
#
#         var popup_f488adbf4f55bb6d3ef05dcf91afb460 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36bd1dff6d9698fd8453cf59bd0965f2 = $(`&lt;div id=&quot;html_36bd1dff6d9698fd8453cf59bd0965f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f488adbf4f55bb6d3ef05dcf91afb460.setContent(html_36bd1dff6d9698fd8453cf59bd0965f2);
#
#
#
#         marker_c34525c410dcb1127769178397cfe91f.bindPopup(popup_f488adbf4f55bb6d3ef05dcf91afb460)
#         ;
#
#
#
#
#             var marker_ab61484a194506ef20679c2cb89a36da = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3269b46743da729dc5968a45cc3f8e25);
#
#
#         var popup_330e1c4558367eba792fdb852daf2e40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa0fabb25a0c0811e08ebafe1e3ad46f = $(`&lt;div id=&quot;html_aa0fabb25a0c0811e08ebafe1e3ad46f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_330e1c4558367eba792fdb852daf2e40.setContent(html_aa0fabb25a0c0811e08ebafe1e3ad46f);
#
#
#
#         marker_ab61484a194506ef20679c2cb89a36da.bindPopup(popup_330e1c4558367eba792fdb852daf2e40)
#         ;
#
#
#
#
#             var marker_6a4b6a49a27af4773d2f55210226c0eb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3269b46743da729dc5968a45cc3f8e25);
#
#
#         var popup_6058ba5b4b8169b15427a67fea6a89e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3604cc0ef87aba651df0068b0ac75b99 = $(`&lt;div id=&quot;html_3604cc0ef87aba651df0068b0ac75b99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6058ba5b4b8169b15427a67fea6a89e3.setContent(html_3604cc0ef87aba651df0068b0ac75b99);
#
#
#
#         marker_6a4b6a49a27af4773d2f55210226c0eb.bindPopup(popup_6058ba5b4b8169b15427a67fea6a89e3)
#         ;
#
#
#
#
#             var marker_02a2f2b8ad663ccc6f5ab31945836053 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3269b46743da729dc5968a45cc3f8e25);
#
#
#         var popup_d9a1724f594afd2b950c8a57064ace86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cee88d2d2bab89f167d1d6b925be6bad = $(`&lt;div id=&quot;html_cee88d2d2bab89f167d1d6b925be6bad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d9a1724f594afd2b950c8a57064ace86.setContent(html_cee88d2d2bab89f167d1d6b925be6bad);
#
#
#
#         marker_
