# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43910393f9007e31401395977ebd9914 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43910393f9007e31401395977ebd9914&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43910393f9007e31401395977ebd9914 = L.map(
#                 &quot;map_43910393f9007e31401395977ebd9914&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1be957d0a1fa19b2c9902b2338f8215 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d1be957d0a1fa19b2c9902b2338f8215.addTo(map_43910393f9007e31401395977ebd9914);
#
#
#             var marker_08c15fe4359c7ac788d48031ed0ea5ab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_43910393f9007e31401395977ebd9914);
#
#
#         var popup_e1345f094248a967a7a061ed879dcb91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e89619d576e078e7f4cdac3d2fc80965 = $(`&lt;div id=&quot;html_e89619d576e078e7f4cdac3d2fc80965&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e1345f094248a967a7a061ed879dcb91.setContent(html_e89619d576e078e7f4cdac3d2fc80965);
#
#
#
#         marker_08c15fe4359c7ac788d48031ed0ea5ab.bindPopup(popup_e1345f094248a967a7a061ed879dcb91)
#         ;
#
#
#
#
#             var marker_b2438fa9d91ed8283fdff3820bf9e12e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_43910393f9007e31401395977ebd9914);
#
#
#         var popup_d0135caa05071e77049572d68a1ae02a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b87feb5350ac261888d16eabbd4d937 = $(`&lt;div id=&quot;html_4b87feb5350ac261888d16eabbd4d937&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d0135caa05071e77049572d68a1ae02a.setContent(html_4b87feb5350ac261888d16eabbd4d937);
#
#
#
#         marker_b2438fa9d91ed8283fdff3820bf9e12e.bindPopup(popup_d0135caa05071e77049572d68a1ae02a)
#         ;
#
#
#
#
#             var marker_8748e6faa4a6c28bb5485e5ab8fa5788 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_43910393f9007e31401395977ebd9914);
#
#
#         var popup_8abc3395b4d18a73007129bf53d614b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4799b2fe6308ec2b4d530c8b66c2fff = $(`&lt;div id=&quot;html_b4799b2fe6308ec2b4d530c8b66c2fff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8abc3395b4d18a73007129bf53d614b1.setContent(html_b4799b2fe6308ec2b4d530c8b66c2fff);
#
#
#
#         marker_8748e6faa4a6c28bb5485e5ab8fa5788.bindPopup(popup_8abc3395b4d18a73007129bf53d614b1)
#         ;
#
#
#
#
#             var marker_e34a296f7cf1771bb9155c5749e5cc44 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_43910393f9007e31401395977ebd9914);
#
#
#         var popup_01bc3225bbc9c856f674026eb4242ff8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_215daacf4e5cc87ef2b7bdc608dc4b7f = $(`&lt;div id=&quot;html_215daacf4e5cc87ef2b7bdc608dc4b7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_01bc3225bbc9c856f674026eb4242ff8.setContent(html_215daacf4e5cc87ef2b7bdc608dc4b7f);
#
#
#
#         marker_e34a296f7cf1771bb9155c5749e5cc44.bindPopup(popup_01bc3225bbc9c856f674026eb4242ff8)
#         ;
#
#
#
#
#             var marker_39f84ea996e302e8b50d8b93d216462c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_43910393f9007e31401395977ebd9914);
#
#
#         var popup_8c847ecfee325f6cc6e795b1d6bcb459 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ba9b0a68c6e7e7fca030485dbdda74d = $(`&lt;div id=&quot;html_5ba9b0a68c6e7e7fca030485dbdda74d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8c847ecfee325f6cc6e795b1d6bcb459.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de9dca7b9607640386ff6991e9000d58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de9dca7b9607640386ff6991e9000d58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de9dca7b9607640386ff6991e9000d58 = L.map(
#                 &quot;map_de9dca7b9607640386ff6991e9000d58&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bdaf7f677b125e583f77f07778edfb77 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bdaf7f677b125e583f77f07778edfb77.addTo(map_de9dca7b9607640386ff6991e9000d58);
#
#
#             var feature_group_3bd0757a515b0c8e1af0ed85b730ca33 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e5a823a52d3332f1dbc14a0fda53f33e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3bd0757a515b0c8e1af0ed85b730ca33);
#
#
#         var popup_43cc51b30a6d01a8376d40d360fe5659 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52e55aaafa273a78a7c75bc49263beb9 = $(`&lt;div id=&quot;html_52e55aaafa273a78a7c75bc49263beb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_43cc51b30a6d01a8376d40d360fe5659.setContent(html_52e55aaafa273a78a7c75bc49263beb9);
#
#
#
#         marker_e5a823a52d3332f1dbc14a0fda53f33e.bindPopup(popup_43cc51b30a6d01a8376d40d360fe5659)
#         ;
#
#
#
#
#             var marker_b6979b8ceb9e0e92281f11acea2ffb7c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3bd0757a515b0c8e1af0ed85b730ca33);
#
#
#         var popup_4853e28fe8601bf00084011c8609e116 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d373b4702e328ee34800497cc8fbd273 = $(`&lt;div id=&quot;html_d373b4702e328ee34800497cc8fbd273&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4853e28fe8601bf00084011c8609e116.setContent(html_d373b4702e328ee34800497cc8fbd273);
#
#
#
#         marker_b6979b8ceb9e0e92281f11acea2ffb7c.bindPopup(popup_4853e28fe8601bf00084011c8609e116)
#         ;
#
#
#
#
#             var marker_6edb96ccfd50ba17a58e5967dfe6fac9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3bd0757a515b0c8e1af0ed85b730ca33);
#
#
#         var popup_5d26e77708bfe953976f5b2ae354b83e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d166856e7e8745d3e53f56a7b719808 = $(`&lt;div id=&quot;html_7d166856e7e8745d3e53f56a7b719808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5d26e77708bfe953976f5b2ae354b83e.setContent(html_7d166856e7e8745d3e53f56a7b719808);
#
#
#
#         marker_6edb96ccfd50ba17a58e5967dfe6fac9.bindPopup(popup_5d26e77708bfe953976f5b2ae354b83e)
#         ;
#
#
#
#
#             var marker_9b347c9475c7833a25a11b7c8c85bfa9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3bd0757a515b0c8e1af0ed85b730ca33);
#
#
#         var popup_4ec945efa92ac3329bc0a72500f61507 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b92e94812c954a5062ff0cea2c688602 = $(`&lt;div id=&quot;html_b92e94812c954a5062ff0cea2c688602&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4ec945efa92ac3329bc0a72500f61507.setContent(html_b92e94812c954a5062ff0cea2c688602);
#
#
#
#         marker_9b347c9475c7833a25a11b7c8c85bfa9.bindPopup(popup_4ec945efa92ac3329bc0a72500f61507)
#         ;
#
#
#
#
#             var marker_017aaba5d97888862fc82933d2519af1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3bd0757a515b0c8e1af0ed85b730ca33);
#
#
#         var popup_fd6bab997c3770aa5079f524ee56c3da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38842af68ba1df023968bcad80222630 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38842af68ba1df023968bcad80222630&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38842af68ba1df023968bcad80222630 = L.map(
#                 &quot;map_38842af68ba1df023968bcad80222630&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7cf12f729d8df8d08d11bf4bb82d124a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7cf12f729d8df8d08d11bf4bb82d124a.addTo(map_38842af68ba1df023968bcad80222630);
#
#
#             var feature_group_80fe4449d8a19a0a14816cd5e9b2da34 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_80fe4449d8a19a0a14816cd5e9b2da34.addTo(map_38842af68ba1df023968bcad80222630);
#
#
#             var feature_group_sub_group_c73c35c9594a330bbf30d9f3aa8cf1c4 = L.featureGroup.subGroup(
#                 feature_group_80fe4449d8a19a0a14816cd5e9b2da34
#             );
#
#
#             var marker_ce6e92f1a68fe1bfc4baeed9c83c20ec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c73c35c9594a330bbf30d9f3aa8cf1c4);
#
#
#         var popup_b2cee06ea1d4d1d47407b8fa0581408e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fa00b28821d6659a37852c9c37426fd = $(`&lt;div id=&quot;html_7fa00b28821d6659a37852c9c37426fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b2cee06ea1d4d1d47407b8fa0581408e.setContent(html_7fa00b28821d6659a37852c9c37426fd);
#
#
#
#         marker_ce6e92f1a68fe1bfc4baeed9c83c20ec.bindPopup(popup_b2cee06ea1d4d1d47407b8fa0581408e)
#         ;
#
#
#
#
#             var marker_51d2319d1ae9e54cb324f5b86d9a6f18 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c73c35c9594a330bbf30d9f3aa8cf1c4);
#
#
#         var popup_02aaa9eaf90c8768e781a896d83a0452 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f852551f7d23a351370c416b71c26d34 = $(`&lt;div id=&quot;html_f852551f7d23a351370c416b71c26d34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_02aaa9eaf90c8768e781a896d83a0452.setContent(html_f852551f7d23a351370c416b71c26d34);
#
#
#
#         marker_51d2319d1ae9e54cb324f5b86d9a6f18.bindPopup(popup_02aaa9eaf90c8768e781a896d83a0452)
#         ;
#
#
#
#
#             var marker_31833578a970e3d66de797834874db90 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c73c35c9594a330bbf30d9f3aa8cf1c4);
#
#
#         var popup_39b363c2b0f8631a309044eeab1f6af1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f5af58e47d529bfe69bece56e035738 = $(`&lt;div id=&quot;html_3f5af58e47d529bfe69bece56e035738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_39b363c2b0f8631a309044eeab1f6af1.setContent(html_3f5af58e47d529bfe69bece56e035738);
#
#
#
#         marker_31833578a970e3d66de797834874db90.bindPopup(popup_39b363c2b0f8631a309044eeab1f6af1)
#         ;
#
#
#
#
#             var marker_a1a5694401dfddcf18ef26d43ef8a3ef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c73c35c9594a330bbf30d9f3aa8cf1c4);
#
#
#         var popup_d6a87228ce3418ab94cd59fa1e279c8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b47e1a9800a1e71e82180361c41399d = $(`&lt;div id=&quot;html_2b47e1a9800a1e71e82180361c41399d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d6a87228ce3418ab94cd59fa1e279c8a.setContent(html_2b47e1a9800a1e71e82180361c41399d);
#
#
#
#         marker_
