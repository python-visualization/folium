# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ed185209d0ee5132d38bf3b9d11d73a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ed185209d0ee5132d38bf3b9d11d73a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ed185209d0ee5132d38bf3b9d11d73a = L.map(
#                 &quot;map_4ed185209d0ee5132d38bf3b9d11d73a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85585d067d61ba9ed9d08c0a67cb9db9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85585d067d61ba9ed9d08c0a67cb9db9.addTo(map_4ed185209d0ee5132d38bf3b9d11d73a);
#
#
#             var marker_829cf2cca88e8c60ea5e4185702b543e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4ed185209d0ee5132d38bf3b9d11d73a);
#
#
#         var popup_7f65515fe8e0587241e48af32e4c1f1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6e200323c1d972720b4ec104e7078f1 = $(`&lt;div id=&quot;html_f6e200323c1d972720b4ec104e7078f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7f65515fe8e0587241e48af32e4c1f1a.setContent(html_f6e200323c1d972720b4ec104e7078f1);
#
#
#
#         marker_829cf2cca88e8c60ea5e4185702b543e.bindPopup(popup_7f65515fe8e0587241e48af32e4c1f1a)
#         ;
#
#
#
#
#             var marker_c9feee1e387047a5a0fe30739e410571 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4ed185209d0ee5132d38bf3b9d11d73a);
#
#
#         var popup_b3ff2b651e18727c48d507c1803c1f46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eae7c8db649a076a71e0882dab073e23 = $(`&lt;div id=&quot;html_eae7c8db649a076a71e0882dab073e23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b3ff2b651e18727c48d507c1803c1f46.setContent(html_eae7c8db649a076a71e0882dab073e23);
#
#
#
#         marker_c9feee1e387047a5a0fe30739e410571.bindPopup(popup_b3ff2b651e18727c48d507c1803c1f46)
#         ;
#
#
#
#
#             var marker_927eaf7b2d34be648125c7ef68899ff4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4ed185209d0ee5132d38bf3b9d11d73a);
#
#
#         var popup_a797e644b0cff5ce55f7c47438392804 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e092b814d3ca07a0940dd54fd4ba5e34 = $(`&lt;div id=&quot;html_e092b814d3ca07a0940dd54fd4ba5e34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a797e644b0cff5ce55f7c47438392804.setContent(html_e092b814d3ca07a0940dd54fd4ba5e34);
#
#
#
#         marker_927eaf7b2d34be648125c7ef68899ff4.bindPopup(popup_a797e644b0cff5ce55f7c47438392804)
#         ;
#
#
#
#
#             var marker_17355a6270960fbd62f055b8e0321117 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4ed185209d0ee5132d38bf3b9d11d73a);
#
#
#         var popup_4b06e9f048774081cd820861e7b277b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea53fc138d23e68eb011bf292996bc7d = $(`&lt;div id=&quot;html_ea53fc138d23e68eb011bf292996bc7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4b06e9f048774081cd820861e7b277b6.setContent(html_ea53fc138d23e68eb011bf292996bc7d);
#
#
#
#         marker_17355a6270960fbd62f055b8e0321117.bindPopup(popup_4b06e9f048774081cd820861e7b277b6)
#         ;
#
#
#
#
#             var marker_87591d152b5839cd02b5c320c6857343 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4ed185209d0ee5132d38bf3b9d11d73a);
#
#
#         var popup_f4a7d92935ab63329c8d8f85aaf9c47f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3126d99df616a48c4ba31f45d892122 = $(`&lt;div id=&quot;html_c3126d99df616a48c4ba31f45d892122&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f4a7d92935ab63329c8d8f85aaf9c47f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_520514279c6e998e3f932e648069105b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_520514279c6e998e3f932e648069105b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_520514279c6e998e3f932e648069105b = L.map(
#                 &quot;map_520514279c6e998e3f932e648069105b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a1b67b0061bb8cc29d49e5e3037269a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a1b67b0061bb8cc29d49e5e3037269a.addTo(map_520514279c6e998e3f932e648069105b);
#
#
#             var feature_group_93f6996a77867990ca7547e728a4cf12 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0562deab774b1b4a76c7a81c9382d675 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_93f6996a77867990ca7547e728a4cf12);
#
#
#         var popup_b4f0a2ac3d9a46c2ce9b278c6d3fc7b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b54aceebe6cc055588c8a42740e11bf0 = $(`&lt;div id=&quot;html_b54aceebe6cc055588c8a42740e11bf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b4f0a2ac3d9a46c2ce9b278c6d3fc7b8.setContent(html_b54aceebe6cc055588c8a42740e11bf0);
#
#
#
#         marker_0562deab774b1b4a76c7a81c9382d675.bindPopup(popup_b4f0a2ac3d9a46c2ce9b278c6d3fc7b8)
#         ;
#
#
#
#
#             var marker_c24958bad56546d70d24a66238a9135c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_93f6996a77867990ca7547e728a4cf12);
#
#
#         var popup_05c1ee009d5913b7fdc369f9a04d6cd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d955bede0d9a7dd9116bd905d1c25ea = $(`&lt;div id=&quot;html_2d955bede0d9a7dd9116bd905d1c25ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_05c1ee009d5913b7fdc369f9a04d6cd1.setContent(html_2d955bede0d9a7dd9116bd905d1c25ea);
#
#
#
#         marker_c24958bad56546d70d24a66238a9135c.bindPopup(popup_05c1ee009d5913b7fdc369f9a04d6cd1)
#         ;
#
#
#
#
#             var marker_eb37836cc474c7978d5597ac649ed501 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_93f6996a77867990ca7547e728a4cf12);
#
#
#         var popup_9e60adfcbfc3a745aa2426e0536637c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a14addd2b26521390b0e3f31c83aa702 = $(`&lt;div id=&quot;html_a14addd2b26521390b0e3f31c83aa702&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9e60adfcbfc3a745aa2426e0536637c6.setContent(html_a14addd2b26521390b0e3f31c83aa702);
#
#
#
#         marker_eb37836cc474c7978d5597ac649ed501.bindPopup(popup_9e60adfcbfc3a745aa2426e0536637c6)
#         ;
#
#
#
#
#             var marker_3e85ff69891dfb3c8fc3ca6adbb8eaa9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_93f6996a77867990ca7547e728a4cf12);
#
#
#         var popup_34d7ca8bc4a270f729fb6e03f9482808 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3352f0aff6cae2a8e7d7684c9f7ea6ab = $(`&lt;div id=&quot;html_3352f0aff6cae2a8e7d7684c9f7ea6ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_34d7ca8bc4a270f729fb6e03f9482808.setContent(html_3352f0aff6cae2a8e7d7684c9f7ea6ab);
#
#
#
#         marker_3e85ff69891dfb3c8fc3ca6adbb8eaa9.bindPopup(popup_34d7ca8bc4a270f729fb6e03f9482808)
#         ;
#
#
#
#
#             var marker_ab0b1254289fab1078355300156b27c5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_93f6996a77867990ca7547e728a4cf12);
#
#
#         var popup_14d061d8ba28ae2329b694283477dda2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b619a0adc8b078c7f2156344736f4f7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b619a0adc8b078c7f2156344736f4f7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b619a0adc8b078c7f2156344736f4f7e = L.map(
#                 &quot;map_b619a0adc8b078c7f2156344736f4f7e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7bd0193c6ab2cc6a0fda9ce6de217765 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7bd0193c6ab2cc6a0fda9ce6de217765.addTo(map_b619a0adc8b078c7f2156344736f4f7e);
#
#
#             var feature_group_a22d1b9260fb5e6e0884959ab27d0126 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a22d1b9260fb5e6e0884959ab27d0126.addTo(map_b619a0adc8b078c7f2156344736f4f7e);
#
#
#             var feature_group_sub_group_25ae304f30a7d42f4b65592dca6f3562 = L.featureGroup.subGroup(
#                 feature_group_a22d1b9260fb5e6e0884959ab27d0126
#             );
#
#
#             var marker_8264db6f62fcb826327f4890133a55ba = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_25ae304f30a7d42f4b65592dca6f3562);
#
#
#         var popup_798a6143142623b35cafceb7cbcfbe69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a34195d3eb99b03c0bba274fbc67409 = $(`&lt;div id=&quot;html_0a34195d3eb99b03c0bba274fbc67409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_798a6143142623b35cafceb7cbcfbe69.setContent(html_0a34195d3eb99b03c0bba274fbc67409);
#
#
#
#         marker_8264db6f62fcb826327f4890133a55ba.bindPopup(popup_798a6143142623b35cafceb7cbcfbe69)
#         ;
#
#
#
#
#             var marker_d4a289d68e04d8b2354717b5643409b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_25ae304f30a7d42f4b65592dca6f3562);
#
#
#         var popup_4ffab5bc131e06d6090859f9fb37403a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67a495e92759cbecddf2f2fadaf48e7f = $(`&lt;div id=&quot;html_67a495e92759cbecddf2f2fadaf48e7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4ffab5bc131e06d6090859f9fb37403a.setContent(html_67a495e92759cbecddf2f2fadaf48e7f);
#
#
#
#         marker_d4a289d68e04d8b2354717b5643409b9.bindPopup(popup_4ffab5bc131e06d6090859f9fb37403a)
#         ;
#
#
#
#
#             var marker_4db433c7b8c8ec9012b194eefcb20277 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_25ae304f30a7d42f4b65592dca6f3562);
#
#
#         var popup_9c972a9a2e5f5e6969e37b54174d099a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e59951646fc6eee62f65e5d94b41728 = $(`&lt;div id=&quot;html_9e59951646fc6eee62f65e5d94b41728&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9c972a9a2e5f5e6969e37b54174d099a.setContent(html_9e59951646fc6eee62f65e5d94b41728);
#
#
#
#         marker_4db433c7b8c8ec9012b194eefcb20277.bindPopup(popup_9c972a9a2e5f5e6969e37b54174d099a)
#         ;
#
#
#
#
#             var marker_251372bd2e7a592f88d64c343355c69e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_25ae304f30a7d42f4b65592dca6f3562);
#
#
#         var popup_d34fb8c2dff685081b814233a54cae8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa80df1e300e456f9596e1ebc5f0b3ea = $(`&lt;div id=&quot;html_fa80df1e300e456f9596e1ebc5f0b3ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d34fb8c2dff685081b814233a54cae8d.setContent(html_fa80df1e300e456f9596e1ebc5f0b3ea);
#
#
#
#         marker_
