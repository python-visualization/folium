# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7999f69674f98f72cac6ec2b0b49eda {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7999f69674f98f72cac6ec2b0b49eda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7999f69674f98f72cac6ec2b0b49eda = L.map(
#                 &quot;map_f7999f69674f98f72cac6ec2b0b49eda&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e1dc857a25903dbcb452d21c8a4740f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e1dc857a25903dbcb452d21c8a4740f5.addTo(map_f7999f69674f98f72cac6ec2b0b49eda);
#
#
#             var marker_0e01ae75e4bc57db02e5e088df416199 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f7999f69674f98f72cac6ec2b0b49eda);
#
#
#         var popup_6bf5fa9973913d29901bfb905fa199b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee1b23287ddac6e4dc7bb12c320575d2 = $(`&lt;div id=&quot;html_ee1b23287ddac6e4dc7bb12c320575d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6bf5fa9973913d29901bfb905fa199b1.setContent(html_ee1b23287ddac6e4dc7bb12c320575d2);
#
#
#
#         marker_0e01ae75e4bc57db02e5e088df416199.bindPopup(popup_6bf5fa9973913d29901bfb905fa199b1)
#         ;
#
#
#
#
#             var marker_cbc1b58ae54f1e9f459f680639c88241 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f7999f69674f98f72cac6ec2b0b49eda);
#
#
#         var popup_8cd80f28aaab33016e6bfcb9f27bfaa9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65291020cb59efee60300e8ea4435b68 = $(`&lt;div id=&quot;html_65291020cb59efee60300e8ea4435b68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8cd80f28aaab33016e6bfcb9f27bfaa9.setContent(html_65291020cb59efee60300e8ea4435b68);
#
#
#
#         marker_cbc1b58ae54f1e9f459f680639c88241.bindPopup(popup_8cd80f28aaab33016e6bfcb9f27bfaa9)
#         ;
#
#
#
#
#             var marker_01db001c817581b71e45838bc224fedf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f7999f69674f98f72cac6ec2b0b49eda);
#
#
#         var popup_145d683e40b9d99a488bd05ece0e9db2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56637d18d3330517ea8f3e0ac50496a9 = $(`&lt;div id=&quot;html_56637d18d3330517ea8f3e0ac50496a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_145d683e40b9d99a488bd05ece0e9db2.setContent(html_56637d18d3330517ea8f3e0ac50496a9);
#
#
#
#         marker_01db001c817581b71e45838bc224fedf.bindPopup(popup_145d683e40b9d99a488bd05ece0e9db2)
#         ;
#
#
#
#
#             var marker_381aeeb60bf7652eed14aac4d9cdfc1e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f7999f69674f98f72cac6ec2b0b49eda);
#
#
#         var popup_81b6bbbdf7dae918056c88dfc54896db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ef26823d1740a5ec317e7974e07407f = $(`&lt;div id=&quot;html_0ef26823d1740a5ec317e7974e07407f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_81b6bbbdf7dae918056c88dfc54896db.setContent(html_0ef26823d1740a5ec317e7974e07407f);
#
#
#
#         marker_381aeeb60bf7652eed14aac4d9cdfc1e.bindPopup(popup_81b6bbbdf7dae918056c88dfc54896db)
#         ;
#
#
#
#
#             var marker_a84c67a50ebe718a09c71e6f991b608c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f7999f69674f98f72cac6ec2b0b49eda);
#
#
#         var popup_285b6071669df43ab57c231441340782 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6349133eb50ee096d5fdc3aa5b42213e = $(`&lt;div id=&quot;html_6349133eb50ee096d5fdc3aa5b42213e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_285b6071669df43ab57c231441340782.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9c68bf7b05b151175a3484de732c6125 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9c68bf7b05b151175a3484de732c6125&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9c68bf7b05b151175a3484de732c6125 = L.map(
#                 &quot;map_9c68bf7b05b151175a3484de732c6125&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4f610af9bdf3630151e3cbf69db988e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4f610af9bdf3630151e3cbf69db988e.addTo(map_9c68bf7b05b151175a3484de732c6125);
#
#
#             var feature_group_d9709c511f24fc3b9011d002fe0ba493 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bc8806f755953a3ab0e65340c8848dc5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d9709c511f24fc3b9011d002fe0ba493);
#
#
#         var popup_58ee30e8c1594696f927e5beacaf301c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0cc0537173419df2e63481febd6d546 = $(`&lt;div id=&quot;html_b0cc0537173419df2e63481febd6d546&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_58ee30e8c1594696f927e5beacaf301c.setContent(html_b0cc0537173419df2e63481febd6d546);
#
#
#
#         marker_bc8806f755953a3ab0e65340c8848dc5.bindPopup(popup_58ee30e8c1594696f927e5beacaf301c)
#         ;
#
#
#
#
#             var marker_f38c729e5699a59e60eab2cd5b0e0fd8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d9709c511f24fc3b9011d002fe0ba493);
#
#
#         var popup_539e014f609ec86b61e18a6b0adbade1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_410c61cc506b2d0a0acc0d5543302ea8 = $(`&lt;div id=&quot;html_410c61cc506b2d0a0acc0d5543302ea8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_539e014f609ec86b61e18a6b0adbade1.setContent(html_410c61cc506b2d0a0acc0d5543302ea8);
#
#
#
#         marker_f38c729e5699a59e60eab2cd5b0e0fd8.bindPopup(popup_539e014f609ec86b61e18a6b0adbade1)
#         ;
#
#
#
#
#             var marker_129d2a5eeb9948cb2e605744edacd502 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d9709c511f24fc3b9011d002fe0ba493);
#
#
#         var popup_14ff1a2c0694d161c324d3ff61f288f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b16a620ca724fab555169f54a8efc1f7 = $(`&lt;div id=&quot;html_b16a620ca724fab555169f54a8efc1f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_14ff1a2c0694d161c324d3ff61f288f9.setContent(html_b16a620ca724fab555169f54a8efc1f7);
#
#
#
#         marker_129d2a5eeb9948cb2e605744edacd502.bindPopup(popup_14ff1a2c0694d161c324d3ff61f288f9)
#         ;
#
#
#
#
#             var marker_ae4309a73d72f5f8ac46990fd908f650 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d9709c511f24fc3b9011d002fe0ba493);
#
#
#         var popup_f2560cd778953d0ea2a18582fc31178f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f8b654b4a5b1346fb4a83da5694589a = $(`&lt;div id=&quot;html_2f8b654b4a5b1346fb4a83da5694589a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f2560cd778953d0ea2a18582fc31178f.setContent(html_2f8b654b4a5b1346fb4a83da5694589a);
#
#
#
#         marker_ae4309a73d72f5f8ac46990fd908f650.bindPopup(popup_f2560cd778953d0ea2a18582fc31178f)
#         ;
#
#
#
#
#             var marker_befc65ed3e54599751fcd8d0690c4012 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d9709c511f24fc3b9011d002fe0ba493);
#
#
#         var popup_50665808e5fe5805c9a787b90f600ce6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71461910d029ce1b7ab73d75297f4914 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71461910d029ce1b7ab73d75297f4914&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71461910d029ce1b7ab73d75297f4914 = L.map(
#                 &quot;map_71461910d029ce1b7ab73d75297f4914&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9ef84ae30702ddf3616b0c431522d09 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9ef84ae30702ddf3616b0c431522d09.addTo(map_71461910d029ce1b7ab73d75297f4914);
#
#
#             var feature_group_08e65482f7064df5eaab674502c96f1f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_08e65482f7064df5eaab674502c96f1f.addTo(map_71461910d029ce1b7ab73d75297f4914);
#
#
#             var feature_group_sub_group_8e182b32a8de3117427f02ab1b9b4eb5 = L.featureGroup.subGroup(
#                 feature_group_08e65482f7064df5eaab674502c96f1f
#             );
#
#
#             var marker_7c5f9bebdcce371387daaa7347deb57d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e182b32a8de3117427f02ab1b9b4eb5);
#
#
#         var popup_4f22d82dbe87b39cbf409f28b13b594b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e80b354ecc6e3c2c23c9cd8d677d7662 = $(`&lt;div id=&quot;html_e80b354ecc6e3c2c23c9cd8d677d7662&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4f22d82dbe87b39cbf409f28b13b594b.setContent(html_e80b354ecc6e3c2c23c9cd8d677d7662);
#
#
#
#         marker_7c5f9bebdcce371387daaa7347deb57d.bindPopup(popup_4f22d82dbe87b39cbf409f28b13b594b)
#         ;
#
#
#
#
#             var marker_70568c3efcb39f336e22fae7f12ab366 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e182b32a8de3117427f02ab1b9b4eb5);
#
#
#         var popup_73c1e85db078ff312a9f4781a8038877 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbe5537db5e4a71282e9a1c497565caa = $(`&lt;div id=&quot;html_fbe5537db5e4a71282e9a1c497565caa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_73c1e85db078ff312a9f4781a8038877.setContent(html_fbe5537db5e4a71282e9a1c497565caa);
#
#
#
#         marker_70568c3efcb39f336e22fae7f12ab366.bindPopup(popup_73c1e85db078ff312a9f4781a8038877)
#         ;
#
#
#
#
#             var marker_44ae6e551adca99ae9f62302f2c43751 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e182b32a8de3117427f02ab1b9b4eb5);
#
#
#         var popup_538d1c0ddbdc0dc90a8d5d81c735183e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f023058bd32de0f3a18b2c18f0078d9c = $(`&lt;div id=&quot;html_f023058bd32de0f3a18b2c18f0078d9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_538d1c0ddbdc0dc90a8d5d81c735183e.setContent(html_f023058bd32de0f3a18b2c18f0078d9c);
#
#
#
#         marker_44ae6e551adca99ae9f62302f2c43751.bindPopup(popup_538d1c0ddbdc0dc90a8d5d81c735183e)
#         ;
#
#
#
#
#             var marker_f3cefcbd68bc25e32a7be7a72b9889ca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e182b32a8de3117427f02ab1b9b4eb5);
#
#
#         var popup_f542fbe083576702f42666e3cbe51d14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4913667cd51ba0b908a4c1e545bd97aa = $(`&lt;div id=&quot;html_4913667cd51ba0b908a4c1e545bd97aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f542fbe083576702f42666e3cbe51d14.setContent(html_4913667cd51ba0b908a4c1e545bd97aa);
#
#
#
#         marker_
