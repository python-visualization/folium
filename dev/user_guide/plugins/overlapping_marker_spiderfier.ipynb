# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bdb16ca7f25d2c79369e5bf1b3fdca59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bdb16ca7f25d2c79369e5bf1b3fdca59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bdb16ca7f25d2c79369e5bf1b3fdca59 = L.map(
#                 &quot;map_bdb16ca7f25d2c79369e5bf1b3fdca59&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75d7018d9993967cf16c4b4ecbc8791e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75d7018d9993967cf16c4b4ecbc8791e.addTo(map_bdb16ca7f25d2c79369e5bf1b3fdca59);
#
#
#             var marker_bbf4a1193c628f22479799eb1bba0db4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bdb16ca7f25d2c79369e5bf1b3fdca59);
#
#
#         var popup_4b7fee834dfdfe228a9152e8fee4bb2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b1dd894800f2febf32f12158185ba4c = $(`&lt;div id=&quot;html_5b1dd894800f2febf32f12158185ba4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4b7fee834dfdfe228a9152e8fee4bb2f.setContent(html_5b1dd894800f2febf32f12158185ba4c);
#
#
#
#         marker_bbf4a1193c628f22479799eb1bba0db4.bindPopup(popup_4b7fee834dfdfe228a9152e8fee4bb2f)
#         ;
#
#
#
#
#             var marker_0a8e865aa53377ade27922f1f53df2e4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bdb16ca7f25d2c79369e5bf1b3fdca59);
#
#
#         var popup_f2cd18da5f9f6dad81bfdda4fa91b657 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a63c4e1e7b052d3c01b743a915f8f11d = $(`&lt;div id=&quot;html_a63c4e1e7b052d3c01b743a915f8f11d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f2cd18da5f9f6dad81bfdda4fa91b657.setContent(html_a63c4e1e7b052d3c01b743a915f8f11d);
#
#
#
#         marker_0a8e865aa53377ade27922f1f53df2e4.bindPopup(popup_f2cd18da5f9f6dad81bfdda4fa91b657)
#         ;
#
#
#
#
#             var marker_5c038f943f10f820d4567689f40e7de1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bdb16ca7f25d2c79369e5bf1b3fdca59);
#
#
#         var popup_f6d96a352b06ab29c9d1b0bac33cfab5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34afbdb581e718405a31a7374ed96188 = $(`&lt;div id=&quot;html_34afbdb581e718405a31a7374ed96188&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f6d96a352b06ab29c9d1b0bac33cfab5.setContent(html_34afbdb581e718405a31a7374ed96188);
#
#
#
#         marker_5c038f943f10f820d4567689f40e7de1.bindPopup(popup_f6d96a352b06ab29c9d1b0bac33cfab5)
#         ;
#
#
#
#
#             var marker_969630c05968d3d9d05b957107af66b7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bdb16ca7f25d2c79369e5bf1b3fdca59);
#
#
#         var popup_0f145c7dfa6a507085647be478b1fc91 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce23b8733c7c5dd2ccc3aea74ebfbaaf = $(`&lt;div id=&quot;html_ce23b8733c7c5dd2ccc3aea74ebfbaaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0f145c7dfa6a507085647be478b1fc91.setContent(html_ce23b8733c7c5dd2ccc3aea74ebfbaaf);
#
#
#
#         marker_969630c05968d3d9d05b957107af66b7.bindPopup(popup_0f145c7dfa6a507085647be478b1fc91)
#         ;
#
#
#
#
#             var marker_86c2d2af643612141076e546590d66ae = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bdb16ca7f25d2c79369e5bf1b3fdca59);
#
#
#         var popup_c7e7e960b672048242ad4f5aea3ef395 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4282f28975fde0e70552716e5421cede = $(`&lt;div id=&quot;html_4282f28975fde0e70552716e5421cede&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c7e7e960b672048242ad4f5aea3ef395.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_540c75a86fa3da68f4a4391374ae0306 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_540c75a86fa3da68f4a4391374ae0306&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_540c75a86fa3da68f4a4391374ae0306 = L.map(
#                 &quot;map_540c75a86fa3da68f4a4391374ae0306&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7a7c9256c1448a6f3f644ac98a3bd3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c7a7c9256c1448a6f3f644ac98a3bd3d.addTo(map_540c75a86fa3da68f4a4391374ae0306);
#
#
#             var feature_group_deb0b4ee68777719e34d44b7b2788d03 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bb500733a472c1c2fc640dc1e0b7605e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_deb0b4ee68777719e34d44b7b2788d03);
#
#
#         var popup_ee3a98724154c35d2c1abf6cf9720252 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80833f1b5fd3a0bfd41d36d944377784 = $(`&lt;div id=&quot;html_80833f1b5fd3a0bfd41d36d944377784&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ee3a98724154c35d2c1abf6cf9720252.setContent(html_80833f1b5fd3a0bfd41d36d944377784);
#
#
#
#         marker_bb500733a472c1c2fc640dc1e0b7605e.bindPopup(popup_ee3a98724154c35d2c1abf6cf9720252)
#         ;
#
#
#
#
#             var marker_19caba44a3df5c48491ac98f87d9ad78 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_deb0b4ee68777719e34d44b7b2788d03);
#
#
#         var popup_7a8b0d51d765d2f6fa0065a7b31e01c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5fe32fd777b26c1ae7942349fee0fcb = $(`&lt;div id=&quot;html_a5fe32fd777b26c1ae7942349fee0fcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7a8b0d51d765d2f6fa0065a7b31e01c2.setContent(html_a5fe32fd777b26c1ae7942349fee0fcb);
#
#
#
#         marker_19caba44a3df5c48491ac98f87d9ad78.bindPopup(popup_7a8b0d51d765d2f6fa0065a7b31e01c2)
#         ;
#
#
#
#
#             var marker_9b392d60bae2fd382d4e17a3735a1685 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_deb0b4ee68777719e34d44b7b2788d03);
#
#
#         var popup_7f2f3a26c632d9787aae946a4e82137d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_977470561d4e62b47650d34a5acdaac2 = $(`&lt;div id=&quot;html_977470561d4e62b47650d34a5acdaac2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7f2f3a26c632d9787aae946a4e82137d.setContent(html_977470561d4e62b47650d34a5acdaac2);
#
#
#
#         marker_9b392d60bae2fd382d4e17a3735a1685.bindPopup(popup_7f2f3a26c632d9787aae946a4e82137d)
#         ;
#
#
#
#
#             var marker_b4c63cc3c439c365298e757722dc4f1f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_deb0b4ee68777719e34d44b7b2788d03);
#
#
#         var popup_e05e0c4b5b787bd82be9fef0088523bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_491fd7ba2b083a239918aeb1f6184655 = $(`&lt;div id=&quot;html_491fd7ba2b083a239918aeb1f6184655&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e05e0c4b5b787bd82be9fef0088523bd.setContent(html_491fd7ba2b083a239918aeb1f6184655);
#
#
#
#         marker_b4c63cc3c439c365298e757722dc4f1f.bindPopup(popup_e05e0c4b5b787bd82be9fef0088523bd)
#         ;
#
#
#
#
#             var marker_cfa226a9bbf986480c1c4b54b844af69 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_deb0b4ee68777719e34d44b7b2788d03);
#
#
#         var popup_6bd7f78927f9287ab3fd815a2142b269 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0299a8ac7c497382a2825c69bbd4a91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0299a8ac7c497382a2825c69bbd4a91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0299a8ac7c497382a2825c69bbd4a91 = L.map(
#                 &quot;map_e0299a8ac7c497382a2825c69bbd4a91&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5eabb3b08d0df733545e559d48beb4fe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5eabb3b08d0df733545e559d48beb4fe.addTo(map_e0299a8ac7c497382a2825c69bbd4a91);
#
#
#             var feature_group_ab7bd201955781b7e13bba7d6ed11601 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ab7bd201955781b7e13bba7d6ed11601.addTo(map_e0299a8ac7c497382a2825c69bbd4a91);
#
#
#             var feature_group_sub_group_b56c47263a2a6551007fd88703a2a1db = L.featureGroup.subGroup(
#                 feature_group_ab7bd201955781b7e13bba7d6ed11601
#             );
#
#
#             var marker_26ed2e1307e550c139175f8d4be7dd82 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b56c47263a2a6551007fd88703a2a1db);
#
#
#         var popup_83ab00bea4148404e85eb71fe0c4a111 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62535a7f01cb0025c24be904230c9859 = $(`&lt;div id=&quot;html_62535a7f01cb0025c24be904230c9859&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_83ab00bea4148404e85eb71fe0c4a111.setContent(html_62535a7f01cb0025c24be904230c9859);
#
#
#
#         marker_26ed2e1307e550c139175f8d4be7dd82.bindPopup(popup_83ab00bea4148404e85eb71fe0c4a111)
#         ;
#
#
#
#
#             var marker_4a859a238add8dc6deca06ab5d24d0fc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b56c47263a2a6551007fd88703a2a1db);
#
#
#         var popup_fdd472ebb3292621c3e855bd61f3b538 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_332c88fd5927b2af9c695ff1a6aac48a = $(`&lt;div id=&quot;html_332c88fd5927b2af9c695ff1a6aac48a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fdd472ebb3292621c3e855bd61f3b538.setContent(html_332c88fd5927b2af9c695ff1a6aac48a);
#
#
#
#         marker_4a859a238add8dc6deca06ab5d24d0fc.bindPopup(popup_fdd472ebb3292621c3e855bd61f3b538)
#         ;
#
#
#
#
#             var marker_b8493b32fcca6b3c7c0de0f9cb56cd6b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b56c47263a2a6551007fd88703a2a1db);
#
#
#         var popup_6cb6681c1a325d687c2e7bac6e98d943 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76b44d561c913c4e8a4c4d5daedaff8b = $(`&lt;div id=&quot;html_76b44d561c913c4e8a4c4d5daedaff8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6cb6681c1a325d687c2e7bac6e98d943.setContent(html_76b44d561c913c4e8a4c4d5daedaff8b);
#
#
#
#         marker_b8493b32fcca6b3c7c0de0f9cb56cd6b.bindPopup(popup_6cb6681c1a325d687c2e7bac6e98d943)
#         ;
#
#
#
#
#             var marker_4a548522b08f97c6910cdbb30625a4fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b56c47263a2a6551007fd88703a2a1db);
#
#
#         var popup_aa4bf0a3dff1e62cd8ca6a66cdbcef83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f676c48c4f6cdeceadbe94c8da037fab = $(`&lt;div id=&quot;html_f676c48c4f6cdeceadbe94c8da037fab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_aa4bf0a3dff1e62cd8ca6a66cdbcef83.setContent(html_f676c48c4f6cdeceadbe94c8da037fab);
#
#
#
#         marker_
