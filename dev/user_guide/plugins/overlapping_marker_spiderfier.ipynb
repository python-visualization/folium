# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa8b2093832cd5c12fd2899549f66f97 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa8b2093832cd5c12fd2899549f66f97&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa8b2093832cd5c12fd2899549f66f97 = L.map(
#                 &quot;map_fa8b2093832cd5c12fd2899549f66f97&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b58e57e743ceb0d9c69bf54d472aa31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b58e57e743ceb0d9c69bf54d472aa31.addTo(map_fa8b2093832cd5c12fd2899549f66f97);
#
#
#             var marker_503edd157350ac1299b66d2f87615d7d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fa8b2093832cd5c12fd2899549f66f97);
#
#
#         var popup_c66b48f07441a76299d464674c9d3f76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23698f7f2c4eb4fef855916e08d12461 = $(`&lt;div id=&quot;html_23698f7f2c4eb4fef855916e08d12461&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c66b48f07441a76299d464674c9d3f76.setContent(html_23698f7f2c4eb4fef855916e08d12461);
#
#
#
#         marker_503edd157350ac1299b66d2f87615d7d.bindPopup(popup_c66b48f07441a76299d464674c9d3f76)
#         ;
#
#
#
#
#             var marker_12acb63636970a5bc6ca4b141a89e590 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fa8b2093832cd5c12fd2899549f66f97);
#
#
#         var popup_3b14945f056c967785fc6511329baeb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caa1e3f2a588430588003e0470111351 = $(`&lt;div id=&quot;html_caa1e3f2a588430588003e0470111351&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3b14945f056c967785fc6511329baeb4.setContent(html_caa1e3f2a588430588003e0470111351);
#
#
#
#         marker_12acb63636970a5bc6ca4b141a89e590.bindPopup(popup_3b14945f056c967785fc6511329baeb4)
#         ;
#
#
#
#
#             var marker_376bbae9938e91a048a8347b62bb1297 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fa8b2093832cd5c12fd2899549f66f97);
#
#
#         var popup_cf73f591e0924ecaaf98b0e5b39f09aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42650df805ff0b6f9b6b17e8e8127c2a = $(`&lt;div id=&quot;html_42650df805ff0b6f9b6b17e8e8127c2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cf73f591e0924ecaaf98b0e5b39f09aa.setContent(html_42650df805ff0b6f9b6b17e8e8127c2a);
#
#
#
#         marker_376bbae9938e91a048a8347b62bb1297.bindPopup(popup_cf73f591e0924ecaaf98b0e5b39f09aa)
#         ;
#
#
#
#
#             var marker_919caac7a5d7e87ada728a76144d0e3a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fa8b2093832cd5c12fd2899549f66f97);
#
#
#         var popup_e52ec5bc97bfe64017da6f7858cf78d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd418a73a4e6379cb6653be8f0dc72b7 = $(`&lt;div id=&quot;html_bd418a73a4e6379cb6653be8f0dc72b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e52ec5bc97bfe64017da6f7858cf78d7.setContent(html_bd418a73a4e6379cb6653be8f0dc72b7);
#
#
#
#         marker_919caac7a5d7e87ada728a76144d0e3a.bindPopup(popup_e52ec5bc97bfe64017da6f7858cf78d7)
#         ;
#
#
#
#
#             var marker_387aa0b928e17509a60eea13a478cb33 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fa8b2093832cd5c12fd2899549f66f97);
#
#
#         var popup_72e3f7c8fc94cb4e798f144380845182 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79903cd416e496e40b581a2fb1a2bd97 = $(`&lt;div id=&quot;html_79903cd416e496e40b581a2fb1a2bd97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_72e3f7c8fc94cb4e798f144380845182.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b98d2b99d74f1e30a2cd0afc687186a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b98d2b99d74f1e30a2cd0afc687186a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b98d2b99d74f1e30a2cd0afc687186a4 = L.map(
#                 &quot;map_b98d2b99d74f1e30a2cd0afc687186a4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_170556e843862667aa4cd07793399bb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_170556e843862667aa4cd07793399bb7.addTo(map_b98d2b99d74f1e30a2cd0afc687186a4);
#
#
#             var feature_group_ec54c4f941b915353a8c526aed4d6efb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7b29e8ed5f722802c1dea5f96721e5c7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ec54c4f941b915353a8c526aed4d6efb);
#
#
#         var popup_7815d34abebde4d7bdc4e3ed903dc10d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ff2a564759dd2a8e1f1e2565b83a018 = $(`&lt;div id=&quot;html_4ff2a564759dd2a8e1f1e2565b83a018&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7815d34abebde4d7bdc4e3ed903dc10d.setContent(html_4ff2a564759dd2a8e1f1e2565b83a018);
#
#
#
#         marker_7b29e8ed5f722802c1dea5f96721e5c7.bindPopup(popup_7815d34abebde4d7bdc4e3ed903dc10d)
#         ;
#
#
#
#
#             var marker_91ce493a70962ad8037173fab3aabc5e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ec54c4f941b915353a8c526aed4d6efb);
#
#
#         var popup_3a6e27e86008a77aa42434979d486334 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70fe794ae3dca0e41f389ad62422414a = $(`&lt;div id=&quot;html_70fe794ae3dca0e41f389ad62422414a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3a6e27e86008a77aa42434979d486334.setContent(html_70fe794ae3dca0e41f389ad62422414a);
#
#
#
#         marker_91ce493a70962ad8037173fab3aabc5e.bindPopup(popup_3a6e27e86008a77aa42434979d486334)
#         ;
#
#
#
#
#             var marker_f47a7e5e4d4dd51276ab4f137941e0d5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ec54c4f941b915353a8c526aed4d6efb);
#
#
#         var popup_d9cf8ca9042bc300dd478269837edeca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0cc8fdd0f685b45632335720b409ed2 = $(`&lt;div id=&quot;html_d0cc8fdd0f685b45632335720b409ed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d9cf8ca9042bc300dd478269837edeca.setContent(html_d0cc8fdd0f685b45632335720b409ed2);
#
#
#
#         marker_f47a7e5e4d4dd51276ab4f137941e0d5.bindPopup(popup_d9cf8ca9042bc300dd478269837edeca)
#         ;
#
#
#
#
#             var marker_396c744b45b040764d53cf604e62c8e7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ec54c4f941b915353a8c526aed4d6efb);
#
#
#         var popup_3cdcca676cc061b51a283eaae83f83b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eaf72ee6e0dc10b460c0a8113ea26a04 = $(`&lt;div id=&quot;html_eaf72ee6e0dc10b460c0a8113ea26a04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3cdcca676cc061b51a283eaae83f83b2.setContent(html_eaf72ee6e0dc10b460c0a8113ea26a04);
#
#
#
#         marker_396c744b45b040764d53cf604e62c8e7.bindPopup(popup_3cdcca676cc061b51a283eaae83f83b2)
#         ;
#
#
#
#
#             var marker_aca6c27e560247e58fab90279c04942c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ec54c4f941b915353a8c526aed4d6efb);
#
#
#         var popup_bcc08f1b441667489a95dfb6f6ce784f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c64486f0f36b71215cc9ea5f2461046 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c64486f0f36b71215cc9ea5f2461046&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c64486f0f36b71215cc9ea5f2461046 = L.map(
#                 &quot;map_5c64486f0f36b71215cc9ea5f2461046&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ec53d18d17fadd2b4daacd19408ef4f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ec53d18d17fadd2b4daacd19408ef4f.addTo(map_5c64486f0f36b71215cc9ea5f2461046);
#
#
#             var feature_group_5076712cc011cd76382ba037035b0f7f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5076712cc011cd76382ba037035b0f7f.addTo(map_5c64486f0f36b71215cc9ea5f2461046);
#
#
#             var feature_group_sub_group_ec46b0ca5571066217d7985d68da2e78 = L.featureGroup.subGroup(
#                 feature_group_5076712cc011cd76382ba037035b0f7f
#             );
#
#
#             var marker_cf8c7c912649a1c2fcf718ca50fea29c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec46b0ca5571066217d7985d68da2e78);
#
#
#         var popup_bad0c7588d820faa4e5ba79a41c2584f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54fdf6c3fc40159b60cbdf4019ba25a6 = $(`&lt;div id=&quot;html_54fdf6c3fc40159b60cbdf4019ba25a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bad0c7588d820faa4e5ba79a41c2584f.setContent(html_54fdf6c3fc40159b60cbdf4019ba25a6);
#
#
#
#         marker_cf8c7c912649a1c2fcf718ca50fea29c.bindPopup(popup_bad0c7588d820faa4e5ba79a41c2584f)
#         ;
#
#
#
#
#             var marker_4784c18e55943e910ed275f3b93de7a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec46b0ca5571066217d7985d68da2e78);
#
#
#         var popup_f842c8b094438e4c5a6bcbab8f919f8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfee7d0692642a67adc9e1ec9c2aae73 = $(`&lt;div id=&quot;html_bfee7d0692642a67adc9e1ec9c2aae73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f842c8b094438e4c5a6bcbab8f919f8e.setContent(html_bfee7d0692642a67adc9e1ec9c2aae73);
#
#
#
#         marker_4784c18e55943e910ed275f3b93de7a6.bindPopup(popup_f842c8b094438e4c5a6bcbab8f919f8e)
#         ;
#
#
#
#
#             var marker_7d5ca78bc7f781c89af5baefcd790ccc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec46b0ca5571066217d7985d68da2e78);
#
#
#         var popup_41f76410e6e073d7f4ab558188e65e0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d37061b113536df592bbbdb24f67010a = $(`&lt;div id=&quot;html_d37061b113536df592bbbdb24f67010a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_41f76410e6e073d7f4ab558188e65e0f.setContent(html_d37061b113536df592bbbdb24f67010a);
#
#
#
#         marker_7d5ca78bc7f781c89af5baefcd790ccc.bindPopup(popup_41f76410e6e073d7f4ab558188e65e0f)
#         ;
#
#
#
#
#             var marker_f54c368225da0b721fa9d4aaa2b83a16 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec46b0ca5571066217d7985d68da2e78);
#
#
#         var popup_c895a9fc2d9cc73ff09235a380ddee21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b14b387204eeaa33bd568a104c8fbf88 = $(`&lt;div id=&quot;html_b14b387204eeaa33bd568a104c8fbf88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c895a9fc2d9cc73ff09235a380ddee21.setContent(html_b14b387204eeaa33bd568a104c8fbf88);
#
#
#
#         marker_
