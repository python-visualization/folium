# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa2ac43ae5dfe29ee8fd5d198dea10cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa2ac43ae5dfe29ee8fd5d198dea10cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa2ac43ae5dfe29ee8fd5d198dea10cd = L.map(
#                 &quot;map_fa2ac43ae5dfe29ee8fd5d198dea10cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa31ff80f15c68a083a47d57e49c408e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa31ff80f15c68a083a47d57e49c408e.addTo(map_fa2ac43ae5dfe29ee8fd5d198dea10cd);
#
#
#             var marker_16d9626e10ea396c1364aba0faab8941 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fa2ac43ae5dfe29ee8fd5d198dea10cd);
#
#
#         var popup_ed7180e597ea1cb8c4767da889a1d329 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab3f3d8263d9d6a133d3f5bbd18b46c1 = $(`&lt;div id=&quot;html_ab3f3d8263d9d6a133d3f5bbd18b46c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ed7180e597ea1cb8c4767da889a1d329.setContent(html_ab3f3d8263d9d6a133d3f5bbd18b46c1);
#
#
#
#         marker_16d9626e10ea396c1364aba0faab8941.bindPopup(popup_ed7180e597ea1cb8c4767da889a1d329)
#         ;
#
#
#
#
#             var marker_7093d3a45a151be2c456caad38877f9d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fa2ac43ae5dfe29ee8fd5d198dea10cd);
#
#
#         var popup_654b0525f669148b09d2bdcce75b8590 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca1c2e68e12e7d700717cb3af4c03f5d = $(`&lt;div id=&quot;html_ca1c2e68e12e7d700717cb3af4c03f5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_654b0525f669148b09d2bdcce75b8590.setContent(html_ca1c2e68e12e7d700717cb3af4c03f5d);
#
#
#
#         marker_7093d3a45a151be2c456caad38877f9d.bindPopup(popup_654b0525f669148b09d2bdcce75b8590)
#         ;
#
#
#
#
#             var marker_af8f02438e88a389ad51256db6152d91 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fa2ac43ae5dfe29ee8fd5d198dea10cd);
#
#
#         var popup_18b14c64f9a9168015b89ae774d5d6cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d4508fcaf8d71b1938e3e16714de3b2 = $(`&lt;div id=&quot;html_6d4508fcaf8d71b1938e3e16714de3b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_18b14c64f9a9168015b89ae774d5d6cd.setContent(html_6d4508fcaf8d71b1938e3e16714de3b2);
#
#
#
#         marker_af8f02438e88a389ad51256db6152d91.bindPopup(popup_18b14c64f9a9168015b89ae774d5d6cd)
#         ;
#
#
#
#
#             var marker_912092721f310157bc063ebff03ad7a9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fa2ac43ae5dfe29ee8fd5d198dea10cd);
#
#
#         var popup_a6a081036a6fcaaa18d4da2f754692f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bdbc834180b93c6b1a8951427c64304 = $(`&lt;div id=&quot;html_1bdbc834180b93c6b1a8951427c64304&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a6a081036a6fcaaa18d4da2f754692f6.setContent(html_1bdbc834180b93c6b1a8951427c64304);
#
#
#
#         marker_912092721f310157bc063ebff03ad7a9.bindPopup(popup_a6a081036a6fcaaa18d4da2f754692f6)
#         ;
#
#
#
#
#             var marker_ef1c85edd961974a3ef80490f64519a4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fa2ac43ae5dfe29ee8fd5d198dea10cd);
#
#
#         var popup_69ef8d568159a35f5eda8f7ab8d1e7e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5467a97321bf748cee9cc97f76b81aa = $(`&lt;div id=&quot;html_d5467a97321bf748cee9cc97f76b81aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_69ef8d568159a35f5eda8f7ab8d1e7e1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d529d5cc8d52357b38bbd001821e838 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d529d5cc8d52357b38bbd001821e838&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d529d5cc8d52357b38bbd001821e838 = L.map(
#                 &quot;map_7d529d5cc8d52357b38bbd001821e838&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e88c76f67a55f05da7c7d979e5b13f63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e88c76f67a55f05da7c7d979e5b13f63.addTo(map_7d529d5cc8d52357b38bbd001821e838);
#
#
#             var feature_group_e926cef3aa756d9ceff53e507e4d0ba0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_96bff964292b2f36390cda481d726b13 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e926cef3aa756d9ceff53e507e4d0ba0);
#
#
#         var popup_13f6db408f82356fc97a850315d7afd0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b45622d4edf8f7ae96d734d70539e4ac = $(`&lt;div id=&quot;html_b45622d4edf8f7ae96d734d70539e4ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_13f6db408f82356fc97a850315d7afd0.setContent(html_b45622d4edf8f7ae96d734d70539e4ac);
#
#
#
#         marker_96bff964292b2f36390cda481d726b13.bindPopup(popup_13f6db408f82356fc97a850315d7afd0)
#         ;
#
#
#
#
#             var marker_a9cf5694acc6604a90433fbe449ef136 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e926cef3aa756d9ceff53e507e4d0ba0);
#
#
#         var popup_e65ee9d274b434df562beb4d8451c97e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eef64c51f73264f94d3b6bf0b0470a6a = $(`&lt;div id=&quot;html_eef64c51f73264f94d3b6bf0b0470a6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e65ee9d274b434df562beb4d8451c97e.setContent(html_eef64c51f73264f94d3b6bf0b0470a6a);
#
#
#
#         marker_a9cf5694acc6604a90433fbe449ef136.bindPopup(popup_e65ee9d274b434df562beb4d8451c97e)
#         ;
#
#
#
#
#             var marker_479ec689b35049ea48ba68e35498b3b9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e926cef3aa756d9ceff53e507e4d0ba0);
#
#
#         var popup_3422f1bbac8bdfd1a358d65241ab3495 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f040a980d38b3fa02cd34854d65c721 = $(`&lt;div id=&quot;html_0f040a980d38b3fa02cd34854d65c721&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3422f1bbac8bdfd1a358d65241ab3495.setContent(html_0f040a980d38b3fa02cd34854d65c721);
#
#
#
#         marker_479ec689b35049ea48ba68e35498b3b9.bindPopup(popup_3422f1bbac8bdfd1a358d65241ab3495)
#         ;
#
#
#
#
#             var marker_b8e7170d842383bf7214e373cb75ebf6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e926cef3aa756d9ceff53e507e4d0ba0);
#
#
#         var popup_7d2183916f3ab84819747d59a72bb9b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d3593397a53558141077abb92d9dcdb = $(`&lt;div id=&quot;html_1d3593397a53558141077abb92d9dcdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7d2183916f3ab84819747d59a72bb9b7.setContent(html_1d3593397a53558141077abb92d9dcdb);
#
#
#
#         marker_b8e7170d842383bf7214e373cb75ebf6.bindPopup(popup_7d2183916f3ab84819747d59a72bb9b7)
#         ;
#
#
#
#
#             var marker_a4536994aff8b80c6fef3957f4407fa6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e926cef3aa756d9ceff53e507e4d0ba0);
#
#
#         var popup_910e5921d4459a2aab2a70b658af1717 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95392684bbae65096739bcd61453ebe7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95392684bbae65096739bcd61453ebe7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95392684bbae65096739bcd61453ebe7 = L.map(
#                 &quot;map_95392684bbae65096739bcd61453ebe7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ca2f1b983a3c6b4ba7fcb0349fcfb03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ca2f1b983a3c6b4ba7fcb0349fcfb03.addTo(map_95392684bbae65096739bcd61453ebe7);
#
#
#             var feature_group_b6375e17edc4463bab91725dee67a552 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b6375e17edc4463bab91725dee67a552.addTo(map_95392684bbae65096739bcd61453ebe7);
#
#
#             var feature_group_sub_group_5d0073b0ac7703599d88eaf1b952e0c7 = L.featureGroup.subGroup(
#                 feature_group_b6375e17edc4463bab91725dee67a552
#             );
#
#
#             var marker_560af1b5704129a17c251eee71484580 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d0073b0ac7703599d88eaf1b952e0c7);
#
#
#         var popup_25077df156db30b8ba4727cff990bab1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59de9a473f61c950319e03d927ce61a7 = $(`&lt;div id=&quot;html_59de9a473f61c950319e03d927ce61a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_25077df156db30b8ba4727cff990bab1.setContent(html_59de9a473f61c950319e03d927ce61a7);
#
#
#
#         marker_560af1b5704129a17c251eee71484580.bindPopup(popup_25077df156db30b8ba4727cff990bab1)
#         ;
#
#
#
#
#             var marker_9520cb546323e3f46353c22a3eb0b4af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d0073b0ac7703599d88eaf1b952e0c7);
#
#
#         var popup_2dc5dd13ef4e8cc7476c5831e5765544 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f154c9bab2acb29b5df3a1813e6a806 = $(`&lt;div id=&quot;html_6f154c9bab2acb29b5df3a1813e6a806&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2dc5dd13ef4e8cc7476c5831e5765544.setContent(html_6f154c9bab2acb29b5df3a1813e6a806);
#
#
#
#         marker_9520cb546323e3f46353c22a3eb0b4af.bindPopup(popup_2dc5dd13ef4e8cc7476c5831e5765544)
#         ;
#
#
#
#
#             var marker_9470b1ab775717d44485130479e32c03 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d0073b0ac7703599d88eaf1b952e0c7);
#
#
#         var popup_ffcb862dbae9af58e5e18fbbf4aa2066 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49d34c53d92441d9dee591d2bf0ca672 = $(`&lt;div id=&quot;html_49d34c53d92441d9dee591d2bf0ca672&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ffcb862dbae9af58e5e18fbbf4aa2066.setContent(html_49d34c53d92441d9dee591d2bf0ca672);
#
#
#
#         marker_9470b1ab775717d44485130479e32c03.bindPopup(popup_ffcb862dbae9af58e5e18fbbf4aa2066)
#         ;
#
#
#
#
#             var marker_f60b89c5ccbc2744a4b4eb6aedfdd6e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d0073b0ac7703599d88eaf1b952e0c7);
#
#
#         var popup_979b14a0a3072e16ad30c4c6d3419cc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c12207fbd616b45fee63e156bf194f9 = $(`&lt;div id=&quot;html_5c12207fbd616b45fee63e156bf194f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_979b14a0a3072e16ad30c4c6d3419cc8.setContent(html_5c12207fbd616b45fee63e156bf194f9);
#
#
#
#         marker_
