# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f57710933451d200e33a88dce843a4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f57710933451d200e33a88dce843a4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f57710933451d200e33a88dce843a4a = L.map(
#                 &quot;map_1f57710933451d200e33a88dce843a4a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd827c778d2d5dd821eed26b37aa6a2e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd827c778d2d5dd821eed26b37aa6a2e.addTo(map_1f57710933451d200e33a88dce843a4a);
#
#
#             var marker_04ebb38512233802f8e803ce151026a3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1f57710933451d200e33a88dce843a4a);
#
#
#         var popup_d43ef02e0700c08422ec2ba78afafab1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9a987a04a4c9ee98c60c4b4dd999e4b = $(`&lt;div id=&quot;html_e9a987a04a4c9ee98c60c4b4dd999e4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d43ef02e0700c08422ec2ba78afafab1.setContent(html_e9a987a04a4c9ee98c60c4b4dd999e4b);
#
#
#
#         marker_04ebb38512233802f8e803ce151026a3.bindPopup(popup_d43ef02e0700c08422ec2ba78afafab1)
#         ;
#
#
#
#
#             var marker_f83c4e2c62a9f399c7b2febf09f9250e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1f57710933451d200e33a88dce843a4a);
#
#
#         var popup_f9e36257fa73ee15cb412d04ff3f8d68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85b3e4a8fa427a3c39ed0425c9d1eacc = $(`&lt;div id=&quot;html_85b3e4a8fa427a3c39ed0425c9d1eacc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f9e36257fa73ee15cb412d04ff3f8d68.setContent(html_85b3e4a8fa427a3c39ed0425c9d1eacc);
#
#
#
#         marker_f83c4e2c62a9f399c7b2febf09f9250e.bindPopup(popup_f9e36257fa73ee15cb412d04ff3f8d68)
#         ;
#
#
#
#
#             var marker_07d75a22afe387e221e58e1382804c55 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1f57710933451d200e33a88dce843a4a);
#
#
#         var popup_44b5cfe8a00a29b310141d1752b9db5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0532caf002c8d9725e16b398b3f42ea1 = $(`&lt;div id=&quot;html_0532caf002c8d9725e16b398b3f42ea1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_44b5cfe8a00a29b310141d1752b9db5d.setContent(html_0532caf002c8d9725e16b398b3f42ea1);
#
#
#
#         marker_07d75a22afe387e221e58e1382804c55.bindPopup(popup_44b5cfe8a00a29b310141d1752b9db5d)
#         ;
#
#
#
#
#             var marker_5bf4c7b7649843ec01515abec94e7741 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1f57710933451d200e33a88dce843a4a);
#
#
#         var popup_34eb375385564318e32f9f128b65323e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96dae150e46ee7252411a2bcf7273167 = $(`&lt;div id=&quot;html_96dae150e46ee7252411a2bcf7273167&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_34eb375385564318e32f9f128b65323e.setContent(html_96dae150e46ee7252411a2bcf7273167);
#
#
#
#         marker_5bf4c7b7649843ec01515abec94e7741.bindPopup(popup_34eb375385564318e32f9f128b65323e)
#         ;
#
#
#
#
#             var marker_ccdc0a6d869353b8c25b96abb431169e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1f57710933451d200e33a88dce843a4a);
#
#
#         var popup_26ba2e5b4ac0151496186c443ee1ea1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db9a408b07c0ccfffe7cd784f4f98b33 = $(`&lt;div id=&quot;html_db9a408b07c0ccfffe7cd784f4f98b33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_26ba2e5b4ac0151496186c443ee1ea1c.setContent(html_db9a408b07c0ccfffe7cd784f4f98b33);
#
#
#
#         marker_ccdc0a6d869353b8c25b96abb431169e.bindPopup(popup_26ba2e5b4ac0151496186c443ee1ea1c)
#         ;
#
#
#
#
#             var marker_c0431eae9c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d46a05b3cd59d8af108ef6617fe4658 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d46a05b3cd59d8af108ef6617fe4658&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d46a05b3cd59d8af108ef6617fe4658 = L.map(
#                 &quot;map_5d46a05b3cd59d8af108ef6617fe4658&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_73dd33984aa39eeb028918eafe328951 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_73dd33984aa39eeb028918eafe328951.addTo(map_5d46a05b3cd59d8af108ef6617fe4658);
#
#
#             var feature_group_fd52fcfa34e8769d0202e449740f7646 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a51311784602bc158ac8cafa47c52c12 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fd52fcfa34e8769d0202e449740f7646);
#
#
#         var popup_2e34bf268a01ef2e6d97d0b7a09a308d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1592c8d4bbd2bcfc50fec37b7ac16d7e = $(`&lt;div id=&quot;html_1592c8d4bbd2bcfc50fec37b7ac16d7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2e34bf268a01ef2e6d97d0b7a09a308d.setContent(html_1592c8d4bbd2bcfc50fec37b7ac16d7e);
#
#
#
#         marker_a51311784602bc158ac8cafa47c52c12.bindPopup(popup_2e34bf268a01ef2e6d97d0b7a09a308d)
#         ;
#
#
#
#
#             var marker_0d6badd47fff259b48334696ccf99cb9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fd52fcfa34e8769d0202e449740f7646);
#
#
#         var popup_fbf91588a707b961e4fcd7aff0120021 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e6ccec2eadcf2f2b2ea6a61fa958cd7 = $(`&lt;div id=&quot;html_1e6ccec2eadcf2f2b2ea6a61fa958cd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fbf91588a707b961e4fcd7aff0120021.setContent(html_1e6ccec2eadcf2f2b2ea6a61fa958cd7);
#
#
#
#         marker_0d6badd47fff259b48334696ccf99cb9.bindPopup(popup_fbf91588a707b961e4fcd7aff0120021)
#         ;
#
#
#
#
#             var marker_89d1ced4fab33fadf32bae28cd9007b9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fd52fcfa34e8769d0202e449740f7646);
#
#
#         var popup_3d3ff4a3782e7b9c4b5107a85b6f761e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2537ee00a287f44e1accbb74ae0eaa13 = $(`&lt;div id=&quot;html_2537ee00a287f44e1accbb74ae0eaa13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3d3ff4a3782e7b9c4b5107a85b6f761e.setContent(html_2537ee00a287f44e1accbb74ae0eaa13);
#
#
#
#         marker_89d1ced4fab33fadf32bae28cd9007b9.bindPopup(popup_3d3ff4a3782e7b9c4b5107a85b6f761e)
#         ;
#
#
#
#
#             var marker_b897d549e662a749754acfd2db9f203e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fd52fcfa34e8769d0202e449740f7646);
#
#
#         var popup_a236515becbffaf3986fb3f3d0925ab7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf8746d0ae24d6c96e4ed72eab91e9e8 = $(`&lt;div id=&quot;html_cf8746d0ae24d6c96e4ed72eab91e9e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a236515becbffaf3986fb3f3d0925ab7.setContent(html_cf8746d0ae24d6c96e4ed72eab91e9e8);
#
#
#
#         marker_b897d549e662a749754acfd2db9f203e.bindPopup(popup_a236515becbffaf3986fb3f3d0925ab7)
#         ;
#
#
#
#
#             var marker_99cf91285963e1835b0a9f57ef4a28a8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fd52fcfa34e8769d0202e449740f7646);
#
#
#         var popup_408016f746e03e81def67d1d99cdcea4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3301fb3980aaa5710a32692c3bced48c = $(`&lt;div id=&quot;html_3301fb3980aaa5710a32692c3bced48c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_408016f746e03e81de

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_25b20831a61f69ca75f70e7d4ffc9d1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_25b20831a61f69ca75f70e7d4ffc9d1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_25b20831a61f69ca75f70e7d4ffc9d1c = L.map(
#                 &quot;map_25b20831a61f69ca75f70e7d4ffc9d1c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e699fa85f0b0d16d343f7a16bc9632df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e699fa85f0b0d16d343f7a16bc9632df.addTo(map_25b20831a61f69ca75f70e7d4ffc9d1c);
#
#
#             var feature_group_417a23c704c9be818f939d292f7f3db4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_417a23c704c9be818f939d292f7f3db4.addTo(map_25b20831a61f69ca75f70e7d4ffc9d1c);
#
#
#             var feature_group_sub_group_740f1bfe654bc6b3eced3997b2c9f55d = L.featureGroup.subGroup(
#                 feature_group_417a23c704c9be818f939d292f7f3db4
#             );
#
#
#             var marker_78ebe559f30cdde08352607ea80dfaca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_740f1bfe654bc6b3eced3997b2c9f55d);
#
#
#         var popup_9a48d61a787438890a6839f70e8f20f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8a7015c2115c765a97cd877261bd289 = $(`&lt;div id=&quot;html_f8a7015c2115c765a97cd877261bd289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9a48d61a787438890a6839f70e8f20f9.setContent(html_f8a7015c2115c765a97cd877261bd289);
#
#
#
#         marker_78ebe559f30cdde08352607ea80dfaca.bindPopup(popup_9a48d61a787438890a6839f70e8f20f9)
#         ;
#
#
#
#
#             var marker_e618d141b045a7f79711e69ce686d7ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_740f1bfe654bc6b3eced3997b2c9f55d);
#
#
#         var popup_02d87981115b25b2448e7d7194e73083 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c16858e4552d40b421c2f3cd077e9e6 = $(`&lt;div id=&quot;html_5c16858e4552d40b421c2f3cd077e9e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_02d87981115b25b2448e7d7194e73083.setContent(html_5c16858e4552d40b421c2f3cd077e9e6);
#
#
#
#         marker_e618d141b045a7f79711e69ce686d7ea.bindPopup(popup_02d87981115b25b2448e7d7194e73083)
#         ;
#
#
#
#
#             var marker_13e8eea74a0eee58a464d2e9c3abf8f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_740f1bfe654bc6b3eced3997b2c9f55d);
#
#
#         var popup_75cca30dc90a5d50b93be13e9fd447f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e262975f353e5608d5a40e6688ae385e = $(`&lt;div id=&quot;html_e262975f353e5608d5a40e6688ae385e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_75cca30dc90a5d50b93be13e9fd447f4.setContent(html_e262975f353e5608d5a40e6688ae385e);
#
#
#
#         marker_13e8eea74a0eee58a464d2e9c3abf8f6.bindPopup(popup_75cca30dc90a5d50b93be13e9fd447f4)
#         ;
#
#
#
#
#             var marker_8916f4b2116ce73f4a5f5ff48b2167a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_740f1bfe654bc6b3eced3997b2c9f55d);
#
#
#         var popup_feda942090995f8841dfbb48328b1c95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dff26f5bdf875e8d363b5b657554dbc0 = $(`&lt;div id=&quot;html_dff26f5bdf875e8d363b5b657554dbc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_feda942090995f8841dfbb48328b1c95.setContent(html_dff26f5bdf875e8d363b5b657554dbc0);
#
#
#
#         marker_8916f4b2116ce73f4a5f5ff48b2167a5.bindPopup(popup_feda942090995f8841dfbb48328b1c95)
#         ;
#
#
#
#
#             var marker_6baed0360a311fe3ad387966e1fcb9fe = L.marker(
#                 [45.050399999999996, 3.0504],
