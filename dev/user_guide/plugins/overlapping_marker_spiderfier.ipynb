# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a5412a816248d6e201a94d2a3256c74 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a5412a816248d6e201a94d2a3256c74&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a5412a816248d6e201a94d2a3256c74 = L.map(
#                 &quot;map_3a5412a816248d6e201a94d2a3256c74&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9cb5ea6c18975a9740e3a276af454e44 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9cb5ea6c18975a9740e3a276af454e44.addTo(map_3a5412a816248d6e201a94d2a3256c74);
#
#
#             var marker_9f70d4aeaeaa678e37f497f83906d64f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3a5412a816248d6e201a94d2a3256c74);
#
#
#         var popup_003c75b03db65c83ec33c97c5c360dc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04845c8324b75cd18789e453cf42c524 = $(`&lt;div id=&quot;html_04845c8324b75cd18789e453cf42c524&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_003c75b03db65c83ec33c97c5c360dc9.setContent(html_04845c8324b75cd18789e453cf42c524);
#
#
#
#         marker_9f70d4aeaeaa678e37f497f83906d64f.bindPopup(popup_003c75b03db65c83ec33c97c5c360dc9)
#         ;
#
#
#
#
#             var marker_3dd6d6ccde3feba4491bf85d752aedc4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3a5412a816248d6e201a94d2a3256c74);
#
#
#         var popup_67dc94c3445b33ab694b06509eac090a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7decb1fbc5fd746dbdc61d4aa8de7b4 = $(`&lt;div id=&quot;html_e7decb1fbc5fd746dbdc61d4aa8de7b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_67dc94c3445b33ab694b06509eac090a.setContent(html_e7decb1fbc5fd746dbdc61d4aa8de7b4);
#
#
#
#         marker_3dd6d6ccde3feba4491bf85d752aedc4.bindPopup(popup_67dc94c3445b33ab694b06509eac090a)
#         ;
#
#
#
#
#             var marker_9b4a56244536ff08001a1aaf86ab67bd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3a5412a816248d6e201a94d2a3256c74);
#
#
#         var popup_bcdae52462c799944a25ade0edb47bbd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b22954cbb165809e0df8560df0244b5f = $(`&lt;div id=&quot;html_b22954cbb165809e0df8560df0244b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bcdae52462c799944a25ade0edb47bbd.setContent(html_b22954cbb165809e0df8560df0244b5f);
#
#
#
#         marker_9b4a56244536ff08001a1aaf86ab67bd.bindPopup(popup_bcdae52462c799944a25ade0edb47bbd)
#         ;
#
#
#
#
#             var marker_b196cd9dddd35db2a9a941ce1379799d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3a5412a816248d6e201a94d2a3256c74);
#
#
#         var popup_d9022bf0712fedf252cd3a2bc3b4ed87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7362e179d5ea2a9b4ad2a9f7d5bf32fb = $(`&lt;div id=&quot;html_7362e179d5ea2a9b4ad2a9f7d5bf32fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d9022bf0712fedf252cd3a2bc3b4ed87.setContent(html_7362e179d5ea2a9b4ad2a9f7d5bf32fb);
#
#
#
#         marker_b196cd9dddd35db2a9a941ce1379799d.bindPopup(popup_d9022bf0712fedf252cd3a2bc3b4ed87)
#         ;
#
#
#
#
#             var marker_a3309c095997d0b35d4fe67958f97bf1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3a5412a816248d6e201a94d2a3256c74);
#
#
#         var popup_7b76109196c59163225f1b3b120ce718 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e51cdee075186df71f619225dcc218b0 = $(`&lt;div id=&quot;html_e51cdee075186df71f619225dcc218b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7b76109196c59163225f1b3b120ce718.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_615a9366e9c23b4f7f3e8265e279c5cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_615a9366e9c23b4f7f3e8265e279c5cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_615a9366e9c23b4f7f3e8265e279c5cd = L.map(
#                 &quot;map_615a9366e9c23b4f7f3e8265e279c5cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50c4dfbc0ed5b45f81fde62ca79d9d17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50c4dfbc0ed5b45f81fde62ca79d9d17.addTo(map_615a9366e9c23b4f7f3e8265e279c5cd);
#
#
#             var feature_group_3c50a8556a6bc7b6a846c932a42ecdcb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a09eaf5d22c5f45b7a5796a9d1bd4724 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3c50a8556a6bc7b6a846c932a42ecdcb);
#
#
#         var popup_b1b08cf58054bbcb21f574b6c2d1f5c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41d8799525252993d917e5ec2a3aa4ef = $(`&lt;div id=&quot;html_41d8799525252993d917e5ec2a3aa4ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b1b08cf58054bbcb21f574b6c2d1f5c9.setContent(html_41d8799525252993d917e5ec2a3aa4ef);
#
#
#
#         marker_a09eaf5d22c5f45b7a5796a9d1bd4724.bindPopup(popup_b1b08cf58054bbcb21f574b6c2d1f5c9)
#         ;
#
#
#
#
#             var marker_ce7d1143b27a391b97e78dfab39169d6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3c50a8556a6bc7b6a846c932a42ecdcb);
#
#
#         var popup_ba2699f3e472c983ec362cc8faf7cd48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bd25e6f0c3a15fe2f57e095a4e99bf7 = $(`&lt;div id=&quot;html_3bd25e6f0c3a15fe2f57e095a4e99bf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ba2699f3e472c983ec362cc8faf7cd48.setContent(html_3bd25e6f0c3a15fe2f57e095a4e99bf7);
#
#
#
#         marker_ce7d1143b27a391b97e78dfab39169d6.bindPopup(popup_ba2699f3e472c983ec362cc8faf7cd48)
#         ;
#
#
#
#
#             var marker_c1d81a5327a86232448274ee2c2d5174 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3c50a8556a6bc7b6a846c932a42ecdcb);
#
#
#         var popup_76247fe16a5e3cd5ead62e3538cae472 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bda6e683dc9a78fb1da685155907092e = $(`&lt;div id=&quot;html_bda6e683dc9a78fb1da685155907092e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_76247fe16a5e3cd5ead62e3538cae472.setContent(html_bda6e683dc9a78fb1da685155907092e);
#
#
#
#         marker_c1d81a5327a86232448274ee2c2d5174.bindPopup(popup_76247fe16a5e3cd5ead62e3538cae472)
#         ;
#
#
#
#
#             var marker_2f291aa29919ca854ee93cd6d2c581be = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3c50a8556a6bc7b6a846c932a42ecdcb);
#
#
#         var popup_332f389fa12d3a8a63b8e2cebed3a75d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35f73d611f16454691b55a54db169288 = $(`&lt;div id=&quot;html_35f73d611f16454691b55a54db169288&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_332f389fa12d3a8a63b8e2cebed3a75d.setContent(html_35f73d611f16454691b55a54db169288);
#
#
#
#         marker_2f291aa29919ca854ee93cd6d2c581be.bindPopup(popup_332f389fa12d3a8a63b8e2cebed3a75d)
#         ;
#
#
#
#
#             var marker_333a92c7a039967c6f27dc2049798332 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3c50a8556a6bc7b6a846c932a42ecdcb);
#
#
#         var popup_8abafba68848de9846cff223c13d9a53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c35b1d7cdf38cb92d640e6492f319823 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c35b1d7cdf38cb92d640e6492f319823&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c35b1d7cdf38cb92d640e6492f319823 = L.map(
#                 &quot;map_c35b1d7cdf38cb92d640e6492f319823&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cedc236509d4ad539291de82d5af73c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cedc236509d4ad539291de82d5af73c2.addTo(map_c35b1d7cdf38cb92d640e6492f319823);
#
#
#             var feature_group_e3c489b568422430491d2e1b038e0c54 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e3c489b568422430491d2e1b038e0c54.addTo(map_c35b1d7cdf38cb92d640e6492f319823);
#
#
#             var feature_group_sub_group_bcfe9f9f738ccab8e23011251d94259b = L.featureGroup.subGroup(
#                 feature_group_e3c489b568422430491d2e1b038e0c54
#             );
#
#
#             var marker_599b90ee600ceb6964d4bf76abe7af26 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bcfe9f9f738ccab8e23011251d94259b);
#
#
#         var popup_c83f11e0e1ed1c1239b97e8765d13a5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea9c798c16cd7a4f8ad85a66d53901e2 = $(`&lt;div id=&quot;html_ea9c798c16cd7a4f8ad85a66d53901e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c83f11e0e1ed1c1239b97e8765d13a5b.setContent(html_ea9c798c16cd7a4f8ad85a66d53901e2);
#
#
#
#         marker_599b90ee600ceb6964d4bf76abe7af26.bindPopup(popup_c83f11e0e1ed1c1239b97e8765d13a5b)
#         ;
#
#
#
#
#             var marker_c8f5434769306cde1a6ac8cd558b40e0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bcfe9f9f738ccab8e23011251d94259b);
#
#
#         var popup_7d923a7fffa09f34d2909a7dec8295e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98cf652abef2456f5eac8ffe4fb2a097 = $(`&lt;div id=&quot;html_98cf652abef2456f5eac8ffe4fb2a097&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7d923a7fffa09f34d2909a7dec8295e2.setContent(html_98cf652abef2456f5eac8ffe4fb2a097);
#
#
#
#         marker_c8f5434769306cde1a6ac8cd558b40e0.bindPopup(popup_7d923a7fffa09f34d2909a7dec8295e2)
#         ;
#
#
#
#
#             var marker_812bce70c09de4903636b97be83b82d4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bcfe9f9f738ccab8e23011251d94259b);
#
#
#         var popup_41644bfab0f12ecb793918109b821394 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c243f116354f42ad7c0223d4bc4d5ea9 = $(`&lt;div id=&quot;html_c243f116354f42ad7c0223d4bc4d5ea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_41644bfab0f12ecb793918109b821394.setContent(html_c243f116354f42ad7c0223d4bc4d5ea9);
#
#
#
#         marker_812bce70c09de4903636b97be83b82d4.bindPopup(popup_41644bfab0f12ecb793918109b821394)
#         ;
#
#
#
#
#             var marker_24d85117557f697e65a737c2e4c490cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bcfe9f9f738ccab8e23011251d94259b);
#
#
#         var popup_66b9320575535970eaeedc14518f2644 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6953d84bf89d1ce7ef8dcae918af4148 = $(`&lt;div id=&quot;html_6953d84bf89d1ce7ef8dcae918af4148&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_66b9320575535970eaeedc14518f2644.setContent(html_6953d84bf89d1ce7ef8dcae918af4148);
#
#
#
#         marker_
