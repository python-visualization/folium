# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_020742b004e10fc72d219f8cc4ed8993 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_020742b004e10fc72d219f8cc4ed8993&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_020742b004e10fc72d219f8cc4ed8993 = L.map(
#                 &quot;map_020742b004e10fc72d219f8cc4ed8993&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_edd0481e49c5d1f97b90944d5b7e76a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_edd0481e49c5d1f97b90944d5b7e76a4.addTo(map_020742b004e10fc72d219f8cc4ed8993);
#
#
#             var marker_25f6eb72076dcedb3c65fcf2321b0300 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_020742b004e10fc72d219f8cc4ed8993);
#
#
#         var popup_723634524b75da38c513de3bac55ae34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_227adb92ff345cf9088bdbb28c7d90de = $(`&lt;div id=&quot;html_227adb92ff345cf9088bdbb28c7d90de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_723634524b75da38c513de3bac55ae34.setContent(html_227adb92ff345cf9088bdbb28c7d90de);
#
#
#
#         marker_25f6eb72076dcedb3c65fcf2321b0300.bindPopup(popup_723634524b75da38c513de3bac55ae34)
#         ;
#
#
#
#
#             var marker_a23f1e83091769e6cd80c66d3065e9cb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_020742b004e10fc72d219f8cc4ed8993);
#
#
#         var popup_e30d6e17a6094ebcf41750701e5a6da5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15777b0e0d863a373deed89a74aedc73 = $(`&lt;div id=&quot;html_15777b0e0d863a373deed89a74aedc73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e30d6e17a6094ebcf41750701e5a6da5.setContent(html_15777b0e0d863a373deed89a74aedc73);
#
#
#
#         marker_a23f1e83091769e6cd80c66d3065e9cb.bindPopup(popup_e30d6e17a6094ebcf41750701e5a6da5)
#         ;
#
#
#
#
#             var marker_fa89b6a579eb2b42b78c5b75f1095f57 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_020742b004e10fc72d219f8cc4ed8993);
#
#
#         var popup_2056e3ab293e2fe4b775b3f91277f290 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_341cd94ec8f1019418d91ea4a6e71e50 = $(`&lt;div id=&quot;html_341cd94ec8f1019418d91ea4a6e71e50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2056e3ab293e2fe4b775b3f91277f290.setContent(html_341cd94ec8f1019418d91ea4a6e71e50);
#
#
#
#         marker_fa89b6a579eb2b42b78c5b75f1095f57.bindPopup(popup_2056e3ab293e2fe4b775b3f91277f290)
#         ;
#
#
#
#
#             var marker_eaddd8eaf00d942fa7412131d0a5be9d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_020742b004e10fc72d219f8cc4ed8993);
#
#
#         var popup_1bbf282b6369d05d19e83669199fcdee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f74623f8f6ee68de2ca8102267ce6d2 = $(`&lt;div id=&quot;html_8f74623f8f6ee68de2ca8102267ce6d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1bbf282b6369d05d19e83669199fcdee.setContent(html_8f74623f8f6ee68de2ca8102267ce6d2);
#
#
#
#         marker_eaddd8eaf00d942fa7412131d0a5be9d.bindPopup(popup_1bbf282b6369d05d19e83669199fcdee)
#         ;
#
#
#
#
#             var marker_faee1918e9db1082be62b3bde72e8616 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_020742b004e10fc72d219f8cc4ed8993);
#
#
#         var popup_1455ec22e938bb7ff725294b7605f8d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a678c29fe60edf1aada98e7f3f7c7815 = $(`&lt;div id=&quot;html_a678c29fe60edf1aada98e7f3f7c7815&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1455ec22e938bb7ff725294b7605f8d4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a800831bf4614844c4acd0712b380993 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a800831bf4614844c4acd0712b380993&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a800831bf4614844c4acd0712b380993 = L.map(
#                 &quot;map_a800831bf4614844c4acd0712b380993&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3b58833fc7d5a1713db077eb7aa8fd6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3b58833fc7d5a1713db077eb7aa8fd6.addTo(map_a800831bf4614844c4acd0712b380993);
#
#
#             var feature_group_5d1605ed79ba39693ef32c8a06b78e7a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e018500e14d6ce58ca76f40f930705e5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5d1605ed79ba39693ef32c8a06b78e7a);
#
#
#         var popup_1c5a319f9b6297507522a72ff6d8ffca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68e049e2d804eedfefc0fd0784ada9ed = $(`&lt;div id=&quot;html_68e049e2d804eedfefc0fd0784ada9ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1c5a319f9b6297507522a72ff6d8ffca.setContent(html_68e049e2d804eedfefc0fd0784ada9ed);
#
#
#
#         marker_e018500e14d6ce58ca76f40f930705e5.bindPopup(popup_1c5a319f9b6297507522a72ff6d8ffca)
#         ;
#
#
#
#
#             var marker_e59bad24965c41e91c3820111fdb8a3d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5d1605ed79ba39693ef32c8a06b78e7a);
#
#
#         var popup_90dd77ad721020161860a67faf5f034e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_802c13017e52599d0274a35a3e58fac1 = $(`&lt;div id=&quot;html_802c13017e52599d0274a35a3e58fac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_90dd77ad721020161860a67faf5f034e.setContent(html_802c13017e52599d0274a35a3e58fac1);
#
#
#
#         marker_e59bad24965c41e91c3820111fdb8a3d.bindPopup(popup_90dd77ad721020161860a67faf5f034e)
#         ;
#
#
#
#
#             var marker_0b2a364333b88ef7effd4c4305138140 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5d1605ed79ba39693ef32c8a06b78e7a);
#
#
#         var popup_da630f64b3bfa9f7b681d5b1271fc2ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd9ecf5d0ba3f6cb14b3902dfaecf95d = $(`&lt;div id=&quot;html_fd9ecf5d0ba3f6cb14b3902dfaecf95d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_da630f64b3bfa9f7b681d5b1271fc2ff.setContent(html_fd9ecf5d0ba3f6cb14b3902dfaecf95d);
#
#
#
#         marker_0b2a364333b88ef7effd4c4305138140.bindPopup(popup_da630f64b3bfa9f7b681d5b1271fc2ff)
#         ;
#
#
#
#
#             var marker_805dcbc2d61a32cf525237f55b414c2c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5d1605ed79ba39693ef32c8a06b78e7a);
#
#
#         var popup_c2829d386311a35acb447df7fea4b10a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b23c4b70fb577f6b91bc9151dea7084 = $(`&lt;div id=&quot;html_4b23c4b70fb577f6b91bc9151dea7084&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c2829d386311a35acb447df7fea4b10a.setContent(html_4b23c4b70fb577f6b91bc9151dea7084);
#
#
#
#         marker_805dcbc2d61a32cf525237f55b414c2c.bindPopup(popup_c2829d386311a35acb447df7fea4b10a)
#         ;
#
#
#
#
#             var marker_2a1e1a075b37298a31e3514ccf15acb1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5d1605ed79ba39693ef32c8a06b78e7a);
#
#
#         var popup_8161873f557ee29737b4432ad8d05983 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7f7b860c3f8a8147f340ac328b20ecf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7f7b860c3f8a8147f340ac328b20ecf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7f7b860c3f8a8147f340ac328b20ecf = L.map(
#                 &quot;map_f7f7b860c3f8a8147f340ac328b20ecf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80b9a112de9529a3083e67806ec9c2b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_80b9a112de9529a3083e67806ec9c2b7.addTo(map_f7f7b860c3f8a8147f340ac328b20ecf);
#
#
#             var feature_group_20fd7a751c64935ad6224a42c25fc406 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_20fd7a751c64935ad6224a42c25fc406.addTo(map_f7f7b860c3f8a8147f340ac328b20ecf);
#
#
#             var feature_group_sub_group_92b6fce92bba340ffe91bfcff23732ec = L.featureGroup.subGroup(
#                 feature_group_20fd7a751c64935ad6224a42c25fc406
#             );
#
#
#             var marker_fc8fa4ab305ee992e302c29e16ffed7e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_92b6fce92bba340ffe91bfcff23732ec);
#
#
#         var popup_5768ca1287b4c556553aa72f06737833 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e402a96ec14da16c9e79bda8616fbcfa = $(`&lt;div id=&quot;html_e402a96ec14da16c9e79bda8616fbcfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5768ca1287b4c556553aa72f06737833.setContent(html_e402a96ec14da16c9e79bda8616fbcfa);
#
#
#
#         marker_fc8fa4ab305ee992e302c29e16ffed7e.bindPopup(popup_5768ca1287b4c556553aa72f06737833)
#         ;
#
#
#
#
#             var marker_7113735ba4fb36dde972ceb86bf91acc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_92b6fce92bba340ffe91bfcff23732ec);
#
#
#         var popup_50256e5dd6bbd61d3ce58915d3212e0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc1978a9738927b4d43cca136d39773c = $(`&lt;div id=&quot;html_bc1978a9738927b4d43cca136d39773c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_50256e5dd6bbd61d3ce58915d3212e0f.setContent(html_bc1978a9738927b4d43cca136d39773c);
#
#
#
#         marker_7113735ba4fb36dde972ceb86bf91acc.bindPopup(popup_50256e5dd6bbd61d3ce58915d3212e0f)
#         ;
#
#
#
#
#             var marker_c3e669d91bfda1afb45c10cff88af55a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_92b6fce92bba340ffe91bfcff23732ec);
#
#
#         var popup_9b500d4b6bd9e2db18bef0d5e7549865 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8ae1978a0f0cc28c0c61de3c7698c9f = $(`&lt;div id=&quot;html_f8ae1978a0f0cc28c0c61de3c7698c9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9b500d4b6bd9e2db18bef0d5e7549865.setContent(html_f8ae1978a0f0cc28c0c61de3c7698c9f);
#
#
#
#         marker_c3e669d91bfda1afb45c10cff88af55a.bindPopup(popup_9b500d4b6bd9e2db18bef0d5e7549865)
#         ;
#
#
#
#
#             var marker_3d1b308b1fc91a007fc2c4d82eefb67e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_92b6fce92bba340ffe91bfcff23732ec);
#
#
#         var popup_a6d57e287a1a21fd18817f2b1e438c09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa069f6edd6fb64aa2c0c5ac417a26d1 = $(`&lt;div id=&quot;html_fa069f6edd6fb64aa2c0c5ac417a26d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a6d57e287a1a21fd18817f2b1e438c09.setContent(html_fa069f6edd6fb64aa2c0c5ac417a26d1);
#
#
#
#         marker_
