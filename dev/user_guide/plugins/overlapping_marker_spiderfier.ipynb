# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bf9dba10cf4cad050ef8e2893090424 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bf9dba10cf4cad050ef8e2893090424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bf9dba10cf4cad050ef8e2893090424 = L.map(
#                 &quot;map_4bf9dba10cf4cad050ef8e2893090424&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31560a8d28bd6b95effa12b2d1650349 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_31560a8d28bd6b95effa12b2d1650349.addTo(map_4bf9dba10cf4cad050ef8e2893090424);
#
#
#             var marker_bb2cbf73fa51ad3e3bfa9721d1b9ecd8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4bf9dba10cf4cad050ef8e2893090424);
#
#
#         var popup_7cdf224c1b7a395259a78840c475251a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6704b5a11d1cc330d61e399ec041c7ad = $(`&lt;div id=&quot;html_6704b5a11d1cc330d61e399ec041c7ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7cdf224c1b7a395259a78840c475251a.setContent(html_6704b5a11d1cc330d61e399ec041c7ad);
#
#
#
#         marker_bb2cbf73fa51ad3e3bfa9721d1b9ecd8.bindPopup(popup_7cdf224c1b7a395259a78840c475251a)
#         ;
#
#
#
#
#             var marker_e0e23817476ed41ceb41c9049a0c74f0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4bf9dba10cf4cad050ef8e2893090424);
#
#
#         var popup_a59a7defb6d388b557f37698666e8c1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c6d68e503518b21cdf89a66d98ee24b = $(`&lt;div id=&quot;html_9c6d68e503518b21cdf89a66d98ee24b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a59a7defb6d388b557f37698666e8c1f.setContent(html_9c6d68e503518b21cdf89a66d98ee24b);
#
#
#
#         marker_e0e23817476ed41ceb41c9049a0c74f0.bindPopup(popup_a59a7defb6d388b557f37698666e8c1f)
#         ;
#
#
#
#
#             var marker_c33f30324a54cef27f66aac764d1ed53 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4bf9dba10cf4cad050ef8e2893090424);
#
#
#         var popup_ee9d2b050e382291358c7e3434c02aa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4abb122a00d0c38b01d9c32606d22f61 = $(`&lt;div id=&quot;html_4abb122a00d0c38b01d9c32606d22f61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ee9d2b050e382291358c7e3434c02aa8.setContent(html_4abb122a00d0c38b01d9c32606d22f61);
#
#
#
#         marker_c33f30324a54cef27f66aac764d1ed53.bindPopup(popup_ee9d2b050e382291358c7e3434c02aa8)
#         ;
#
#
#
#
#             var marker_88405261f8867c02336babbb40b0ad84 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4bf9dba10cf4cad050ef8e2893090424);
#
#
#         var popup_b972bac603e221e1b8de05fe6bf98157 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc6890e3962fd6c688a9086c464efe77 = $(`&lt;div id=&quot;html_bc6890e3962fd6c688a9086c464efe77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b972bac603e221e1b8de05fe6bf98157.setContent(html_bc6890e3962fd6c688a9086c464efe77);
#
#
#
#         marker_88405261f8867c02336babbb40b0ad84.bindPopup(popup_b972bac603e221e1b8de05fe6bf98157)
#         ;
#
#
#
#
#             var marker_d3fc53332ec8275adc116b1c3c6cadcd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4bf9dba10cf4cad050ef8e2893090424);
#
#
#         var popup_43616773946a9a1c673c27ce5ab23cdb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dfe4f82f7e4dfcd833469a72bef40e8 = $(`&lt;div id=&quot;html_0dfe4f82f7e4dfcd833469a72bef40e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_43616773946a9a1c673c27ce5ab23c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_821cc856faa0f8f3450b613e9f6041d0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_821cc856faa0f8f3450b613e9f6041d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_821cc856faa0f8f3450b613e9f6041d0 = L.map(
#                 &quot;map_821cc856faa0f8f3450b613e9f6041d0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eaf711849a393e91df71456f21db1609 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eaf711849a393e91df71456f21db1609.addTo(map_821cc856faa0f8f3450b613e9f6041d0);
#
#
#             var feature_group_3d4c94ac578cc3fa90ad4126ed30a9ae = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_66ae3c20dd9740c5e84a7975efc191ec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3d4c94ac578cc3fa90ad4126ed30a9ae);
#
#
#         var popup_4c3aa355982e8bccb0a93a3b8ff898bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_575104ce4e45daf25e5c64dc197a4a22 = $(`&lt;div id=&quot;html_575104ce4e45daf25e5c64dc197a4a22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4c3aa355982e8bccb0a93a3b8ff898bd.setContent(html_575104ce4e45daf25e5c64dc197a4a22);
#
#
#
#         marker_66ae3c20dd9740c5e84a7975efc191ec.bindPopup(popup_4c3aa355982e8bccb0a93a3b8ff898bd)
#         ;
#
#
#
#
#             var marker_d8b46db6f350ff63eaeb5c47d372a908 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3d4c94ac578cc3fa90ad4126ed30a9ae);
#
#
#         var popup_678c6307eb5b2e65905607eaba1bf50b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03421cc6aa43701b69470b62e1d9aa43 = $(`&lt;div id=&quot;html_03421cc6aa43701b69470b62e1d9aa43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_678c6307eb5b2e65905607eaba1bf50b.setContent(html_03421cc6aa43701b69470b62e1d9aa43);
#
#
#
#         marker_d8b46db6f350ff63eaeb5c47d372a908.bindPopup(popup_678c6307eb5b2e65905607eaba1bf50b)
#         ;
#
#
#
#
#             var marker_dfe08ddb29b7c4f1ad230892669abce2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3d4c94ac578cc3fa90ad4126ed30a9ae);
#
#
#         var popup_59526557575c28e4885a0dd38020880d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05801674bebdea419414cf3b5db78834 = $(`&lt;div id=&quot;html_05801674bebdea419414cf3b5db78834&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_59526557575c28e4885a0dd38020880d.setContent(html_05801674bebdea419414cf3b5db78834);
#
#
#
#         marker_dfe08ddb29b7c4f1ad230892669abce2.bindPopup(popup_59526557575c28e4885a0dd38020880d)
#         ;
#
#
#
#
#             var marker_d040298b8a74d710ec4990483bd07243 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3d4c94ac578cc3fa90ad4126ed30a9ae);
#
#
#         var popup_29f15d95f00a19c90ceb525e1ee1306e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f49c3f77438b0c2a81f5629b5d7e0468 = $(`&lt;div id=&quot;html_f49c3f77438b0c2a81f5629b5d7e0468&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_29f15d95f00a19c90ceb525e1ee1306e.setContent(html_f49c3f77438b0c2a81f5629b5d7e0468);
#
#
#
#         marker_d040298b8a74d710ec4990483bd07243.bindPopup(popup_29f15d95f00a19c90ceb525e1ee1306e)
#         ;
#
#
#
#
#             var marker_86fbb44687e04124bac7df30bbb633e2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3d4c94ac578cc3fa90ad4126ed30a9ae);
#
#
#         var popup_4ee7708bc1e838f2f48f61ed22fb0c01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ad982dee9c7e9d4e6aa39e1b0b376c3c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ad982dee9c7e9d4e6aa39e1b0b376c3c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ad982dee9c7e9d4e6aa39e1b0b376c3c = L.map(
#                 &quot;map_ad982dee9c7e9d4e6aa39e1b0b376c3c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55fab3c3830d9ef740210d89cb4118bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_55fab3c3830d9ef740210d89cb4118bc.addTo(map_ad982dee9c7e9d4e6aa39e1b0b376c3c);
#
#
#             var feature_group_e45994a67493ceca211b3df389c26f57 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e45994a67493ceca211b3df389c26f57.addTo(map_ad982dee9c7e9d4e6aa39e1b0b376c3c);
#
#
#             var feature_group_sub_group_c80714e8f6002376476a0142c124fd6c = L.featureGroup.subGroup(
#                 feature_group_e45994a67493ceca211b3df389c26f57
#             );
#
#
#             var marker_6f560c8a157cf554bd953c5d676a7ef4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c80714e8f6002376476a0142c124fd6c);
#
#
#         var popup_d9cc3816519a12b9e062253649254907 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e372b232a4728ffba47cf7aa8c2de34 = $(`&lt;div id=&quot;html_2e372b232a4728ffba47cf7aa8c2de34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d9cc3816519a12b9e062253649254907.setContent(html_2e372b232a4728ffba47cf7aa8c2de34);
#
#
#
#         marker_6f560c8a157cf554bd953c5d676a7ef4.bindPopup(popup_d9cc3816519a12b9e062253649254907)
#         ;
#
#
#
#
#             var marker_94ebd78241c8b734c2d87fb49e28610e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c80714e8f6002376476a0142c124fd6c);
#
#
#         var popup_1124b11926e7f62bf5887d9119681eea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f519b6da746302dc719d628d863fe950 = $(`&lt;div id=&quot;html_f519b6da746302dc719d628d863fe950&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1124b11926e7f62bf5887d9119681eea.setContent(html_f519b6da746302dc719d628d863fe950);
#
#
#
#         marker_94ebd78241c8b734c2d87fb49e28610e.bindPopup(popup_1124b11926e7f62bf5887d9119681eea)
#         ;
#
#
#
#
#             var marker_54fbfdda3275fab86afee750cb627304 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c80714e8f6002376476a0142c124fd6c);
#
#
#         var popup_a0081467f33e80c6076f3d0af113f15a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a66db41e5ca614e87178da59caf68445 = $(`&lt;div id=&quot;html_a66db41e5ca614e87178da59caf68445&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a0081467f33e80c6076f3d0af113f15a.setContent(html_a66db41e5ca614e87178da59caf68445);
#
#
#
#         marker_54fbfdda3275fab86afee750cb627304.bindPopup(popup_a0081467f33e80c6076f3d0af113f15a)
#         ;
#
#
#
#
#             var marker_4c965dbf2ecf720ad1648a9c2ad3e848 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c80714e8f6002376476a0142c124fd6c);
#
#
#         var popup_7c4d9586c2e0da5a4b9fc871e8a7e0e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc59f540a020dcfa01a560abe05ad13a = $(`&lt;div id=&quot;html_cc59f540a020dcfa01a560abe05ad13a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7c4d9586c2e0da5a4b9fc871e8a7e0e9.setContent(html_cc59f540a020dcfa01a560abe05ad13a);
#
#
#
#         mark
