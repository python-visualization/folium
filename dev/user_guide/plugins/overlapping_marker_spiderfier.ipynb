# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9b358900ccea3a75e3076c0eb778ac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9b358900ccea3a75e3076c0eb778ac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9b358900ccea3a75e3076c0eb778ac4 = L.map(
#                 &quot;map_e9b358900ccea3a75e3076c0eb778ac4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ee4d9cb11a6635519cc32d367e8570b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3ee4d9cb11a6635519cc32d367e8570b.addTo(map_e9b358900ccea3a75e3076c0eb778ac4);
#
#
#             var marker_d7de59a221a0fa1a229ced505b770a10 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e9b358900ccea3a75e3076c0eb778ac4);
#
#
#         var popup_8455f107536aa837438c3abb9fd09b81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3cc0414325cde1cfb9bd24185fb9951 = $(`&lt;div id=&quot;html_a3cc0414325cde1cfb9bd24185fb9951&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8455f107536aa837438c3abb9fd09b81.setContent(html_a3cc0414325cde1cfb9bd24185fb9951);
#
#
#
#         marker_d7de59a221a0fa1a229ced505b770a10.bindPopup(popup_8455f107536aa837438c3abb9fd09b81)
#         ;
#
#
#
#
#             var marker_f04bd01a49fb1a56821e737c8415c6f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e9b358900ccea3a75e3076c0eb778ac4);
#
#
#         var popup_90b4b57a123e485b09b50c6d4d792bba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b1eb839e9022e3626bfc210369ff331 = $(`&lt;div id=&quot;html_0b1eb839e9022e3626bfc210369ff331&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_90b4b57a123e485b09b50c6d4d792bba.setContent(html_0b1eb839e9022e3626bfc210369ff331);
#
#
#
#         marker_f04bd01a49fb1a56821e737c8415c6f4.bindPopup(popup_90b4b57a123e485b09b50c6d4d792bba)
#         ;
#
#
#
#
#             var marker_aa82b8562ea0e2d9a8416a1b4f17a433 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e9b358900ccea3a75e3076c0eb778ac4);
#
#
#         var popup_c136f2be676f5687d3b2ccac2adee13e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aadf2adc590e4f9a44e6dd436d337eeb = $(`&lt;div id=&quot;html_aadf2adc590e4f9a44e6dd436d337eeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c136f2be676f5687d3b2ccac2adee13e.setContent(html_aadf2adc590e4f9a44e6dd436d337eeb);
#
#
#
#         marker_aa82b8562ea0e2d9a8416a1b4f17a433.bindPopup(popup_c136f2be676f5687d3b2ccac2adee13e)
#         ;
#
#
#
#
#             var marker_d57597069959d247a0902f6502d26bbd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e9b358900ccea3a75e3076c0eb778ac4);
#
#
#         var popup_a3bb64776e5482fc97ef836e6de98269 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c639b67aab0c0a5b6cc0c7d812039829 = $(`&lt;div id=&quot;html_c639b67aab0c0a5b6cc0c7d812039829&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a3bb64776e5482fc97ef836e6de98269.setContent(html_c639b67aab0c0a5b6cc0c7d812039829);
#
#
#
#         marker_d57597069959d247a0902f6502d26bbd.bindPopup(popup_a3bb64776e5482fc97ef836e6de98269)
#         ;
#
#
#
#
#             var marker_33fffe25a9fc54ebc389061b2b95242b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e9b358900ccea3a75e3076c0eb778ac4);
#
#
#         var popup_365df9ab8dbaf8eec5e8898e53fa424c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7add8231a616074debd365688014979c = $(`&lt;div id=&quot;html_7add8231a616074debd365688014979c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_365df9ab8dbaf8eec5e8898e53fa424c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a8a3ff2c63e78225e1a3931a2574b0ae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a8a3ff2c63e78225e1a3931a2574b0ae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a8a3ff2c63e78225e1a3931a2574b0ae = L.map(
#                 &quot;map_a8a3ff2c63e78225e1a3931a2574b0ae&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d66b45e2de63e83e17447f5c4be38997 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d66b45e2de63e83e17447f5c4be38997.addTo(map_a8a3ff2c63e78225e1a3931a2574b0ae);
#
#
#             var feature_group_89a8677902dfcf14b0cc8d6b66f869ed = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7bfaf58b52a0def5a2973de0debac99f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_89a8677902dfcf14b0cc8d6b66f869ed);
#
#
#         var popup_a7be629560cfdaf1beee2331099eec6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e613d46eb544af644ad72d1f696a9254 = $(`&lt;div id=&quot;html_e613d46eb544af644ad72d1f696a9254&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a7be629560cfdaf1beee2331099eec6a.setContent(html_e613d46eb544af644ad72d1f696a9254);
#
#
#
#         marker_7bfaf58b52a0def5a2973de0debac99f.bindPopup(popup_a7be629560cfdaf1beee2331099eec6a)
#         ;
#
#
#
#
#             var marker_b7899db60df5d7c71f76e595ab8e86c8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_89a8677902dfcf14b0cc8d6b66f869ed);
#
#
#         var popup_a9727b31a594c79df25cedf37c684355 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24ec6814e38322d103f5a743b37c691d = $(`&lt;div id=&quot;html_24ec6814e38322d103f5a743b37c691d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a9727b31a594c79df25cedf37c684355.setContent(html_24ec6814e38322d103f5a743b37c691d);
#
#
#
#         marker_b7899db60df5d7c71f76e595ab8e86c8.bindPopup(popup_a9727b31a594c79df25cedf37c684355)
#         ;
#
#
#
#
#             var marker_f83e6e9f4af2c309b3958785e6ed8d84 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_89a8677902dfcf14b0cc8d6b66f869ed);
#
#
#         var popup_030b710970594935e00092e99876f5f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c64ea253c13b98c840ffcfe7ca5b50ad = $(`&lt;div id=&quot;html_c64ea253c13b98c840ffcfe7ca5b50ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_030b710970594935e00092e99876f5f4.setContent(html_c64ea253c13b98c840ffcfe7ca5b50ad);
#
#
#
#         marker_f83e6e9f4af2c309b3958785e6ed8d84.bindPopup(popup_030b710970594935e00092e99876f5f4)
#         ;
#
#
#
#
#             var marker_c353f516422f927ad6ac41401aee6ad3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_89a8677902dfcf14b0cc8d6b66f869ed);
#
#
#         var popup_2b758d538d01caabdd090e78ba40657e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83a240818ae72af98e1e647e64c8373c = $(`&lt;div id=&quot;html_83a240818ae72af98e1e647e64c8373c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2b758d538d01caabdd090e78ba40657e.setContent(html_83a240818ae72af98e1e647e64c8373c);
#
#
#
#         marker_c353f516422f927ad6ac41401aee6ad3.bindPopup(popup_2b758d538d01caabdd090e78ba40657e)
#         ;
#
#
#
#
#             var marker_9d290e55051e976498606022a437f80e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_89a8677902dfcf14b0cc8d6b66f869ed);
#
#
#         var popup_15d326c4dfc5a0826233739877f9072c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd667e171940cb62ee2690dadc90ba8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd667e171940cb62ee2690dadc90ba8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd667e171940cb62ee2690dadc90ba8d = L.map(
#                 &quot;map_dd667e171940cb62ee2690dadc90ba8d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a440b52690a9bdcc92a71f2a5c4f713 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a440b52690a9bdcc92a71f2a5c4f713.addTo(map_dd667e171940cb62ee2690dadc90ba8d);
#
#
#             var feature_group_00a17be8f815985bec7ea057e9976b0a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_00a17be8f815985bec7ea057e9976b0a.addTo(map_dd667e171940cb62ee2690dadc90ba8d);
#
#
#             var feature_group_sub_group_36123d23e872c2cc2f063b9c60ace9bc = L.featureGroup.subGroup(
#                 feature_group_00a17be8f815985bec7ea057e9976b0a
#             );
#
#
#             var marker_2d0e45999396fa465590e8ef44be8e96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_36123d23e872c2cc2f063b9c60ace9bc);
#
#
#         var popup_84d75146227cb698719dc7f6af9cbb76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27d607482ec6de10d6e7fe55b41dbcfd = $(`&lt;div id=&quot;html_27d607482ec6de10d6e7fe55b41dbcfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_84d75146227cb698719dc7f6af9cbb76.setContent(html_27d607482ec6de10d6e7fe55b41dbcfd);
#
#
#
#         marker_2d0e45999396fa465590e8ef44be8e96.bindPopup(popup_84d75146227cb698719dc7f6af9cbb76)
#         ;
#
#
#
#
#             var marker_8c5cfa504888e07e5afdbba9091762b0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_36123d23e872c2cc2f063b9c60ace9bc);
#
#
#         var popup_f288ab278eedd0f096079415bbb4095a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3f6ac8435abe0561a03004f2ff5f132 = $(`&lt;div id=&quot;html_d3f6ac8435abe0561a03004f2ff5f132&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f288ab278eedd0f096079415bbb4095a.setContent(html_d3f6ac8435abe0561a03004f2ff5f132);
#
#
#
#         marker_8c5cfa504888e07e5afdbba9091762b0.bindPopup(popup_f288ab278eedd0f096079415bbb4095a)
#         ;
#
#
#
#
#             var marker_d279cb166d66c07a099e49ddd447c50d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_36123d23e872c2cc2f063b9c60ace9bc);
#
#
#         var popup_52ab776c472fbc4e11699372d55e2f2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0c77be303d69342dafe2cfe9364e151 = $(`&lt;div id=&quot;html_f0c77be303d69342dafe2cfe9364e151&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_52ab776c472fbc4e11699372d55e2f2c.setContent(html_f0c77be303d69342dafe2cfe9364e151);
#
#
#
#         marker_d279cb166d66c07a099e49ddd447c50d.bindPopup(popup_52ab776c472fbc4e11699372d55e2f2c)
#         ;
#
#
#
#
#             var marker_01d44b7397cf1833365a227fdca47519 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_36123d23e872c2cc2f063b9c60ace9bc);
#
#
#         var popup_a13f7c28dfdaeca1277f197ba98e7bdd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce34bcb5a662f54833a0f754c6c283b3 = $(`&lt;div id=&quot;html_ce34bcb5a662f54833a0f754c6c283b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a13f7c28dfdaeca1277f197ba98e7bdd.setContent(html_ce34bcb5a662f54833a0f754c6c283b3);
#
#
#
#         marker_
