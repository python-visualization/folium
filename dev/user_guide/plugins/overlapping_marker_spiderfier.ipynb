# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2fe39d11a8a06578bfc55b1cc695ce16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2fe39d11a8a06578bfc55b1cc695ce16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2fe39d11a8a06578bfc55b1cc695ce16 = L.map(
#                 &quot;map_2fe39d11a8a06578bfc55b1cc695ce16&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff9aaec761edbafeef26723f605bb0ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff9aaec761edbafeef26723f605bb0ea.addTo(map_2fe39d11a8a06578bfc55b1cc695ce16);
#
#
#             var marker_c1e748b88a38ca794d353bef87e36f1e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2fe39d11a8a06578bfc55b1cc695ce16);
#
#
#         var popup_0eaac5f265728dd949cbc48930db3a7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66da47601e21549817f3e8c5e43b1996 = $(`&lt;div id=&quot;html_66da47601e21549817f3e8c5e43b1996&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0eaac5f265728dd949cbc48930db3a7e.setContent(html_66da47601e21549817f3e8c5e43b1996);
#
#
#
#         marker_c1e748b88a38ca794d353bef87e36f1e.bindPopup(popup_0eaac5f265728dd949cbc48930db3a7e)
#         ;
#
#
#
#
#             var marker_cae9ff7d38c27085e71d06a07aef9d72 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2fe39d11a8a06578bfc55b1cc695ce16);
#
#
#         var popup_3621d3453a422c7aeb2b11a6d5a29c6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8222bbb2637c6613b31dc8f350868450 = $(`&lt;div id=&quot;html_8222bbb2637c6613b31dc8f350868450&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3621d3453a422c7aeb2b11a6d5a29c6b.setContent(html_8222bbb2637c6613b31dc8f350868450);
#
#
#
#         marker_cae9ff7d38c27085e71d06a07aef9d72.bindPopup(popup_3621d3453a422c7aeb2b11a6d5a29c6b)
#         ;
#
#
#
#
#             var marker_c06eef3585f8c8f515f09b3739932553 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2fe39d11a8a06578bfc55b1cc695ce16);
#
#
#         var popup_d428236b1cc11f8971f3a55d62af85dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b1bb5e2aac76d63d0d1e40dbd9305d3 = $(`&lt;div id=&quot;html_6b1bb5e2aac76d63d0d1e40dbd9305d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d428236b1cc11f8971f3a55d62af85dc.setContent(html_6b1bb5e2aac76d63d0d1e40dbd9305d3);
#
#
#
#         marker_c06eef3585f8c8f515f09b3739932553.bindPopup(popup_d428236b1cc11f8971f3a55d62af85dc)
#         ;
#
#
#
#
#             var marker_3eadfa6c62d6fbf69b81c2455a7f6a82 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2fe39d11a8a06578bfc55b1cc695ce16);
#
#
#         var popup_9ff4437bb4e08c4cf6410d414ad1a720 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29c38c93ad8ab8ea1e790c058ecb96cc = $(`&lt;div id=&quot;html_29c38c93ad8ab8ea1e790c058ecb96cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9ff4437bb4e08c4cf6410d414ad1a720.setContent(html_29c38c93ad8ab8ea1e790c058ecb96cc);
#
#
#
#         marker_3eadfa6c62d6fbf69b81c2455a7f6a82.bindPopup(popup_9ff4437bb4e08c4cf6410d414ad1a720)
#         ;
#
#
#
#
#             var marker_c548c23914c0319fbd5898a05b43c717 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2fe39d11a8a06578bfc55b1cc695ce16);
#
#
#         var popup_067b8c1ddd386adcc05f9917413a8494 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffa23bf9ba98809ec8ebd743adee3ebd = $(`&lt;div id=&quot;html_ffa23bf9ba98809ec8ebd743adee3ebd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_067b8c1ddd386adcc05f9917413a8494.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c663546fe1fa5d84b5139d0aa93fc07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c663546fe1fa5d84b5139d0aa93fc07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c663546fe1fa5d84b5139d0aa93fc07 = L.map(
#                 &quot;map_5c663546fe1fa5d84b5139d0aa93fc07&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d91ed43bb243731843e8085d8bcf9202 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d91ed43bb243731843e8085d8bcf9202.addTo(map_5c663546fe1fa5d84b5139d0aa93fc07);
#
#
#             var feature_group_f5e446c111753f14752ccdc469543aab = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1bf07658dba76064661c546766750272 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f5e446c111753f14752ccdc469543aab);
#
#
#         var popup_3dc52ca05759001d7aab75705fc22d90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_551c3bb651f567cf7d6301d991184c7b = $(`&lt;div id=&quot;html_551c3bb651f567cf7d6301d991184c7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3dc52ca05759001d7aab75705fc22d90.setContent(html_551c3bb651f567cf7d6301d991184c7b);
#
#
#
#         marker_1bf07658dba76064661c546766750272.bindPopup(popup_3dc52ca05759001d7aab75705fc22d90)
#         ;
#
#
#
#
#             var marker_bc29d18dd2fb766515b500b38bddbc32 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f5e446c111753f14752ccdc469543aab);
#
#
#         var popup_fc38dc5b2885bb661d8819d40d3a93a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64631228de3d79063f50ccdc44f2f6b2 = $(`&lt;div id=&quot;html_64631228de3d79063f50ccdc44f2f6b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fc38dc5b2885bb661d8819d40d3a93a8.setContent(html_64631228de3d79063f50ccdc44f2f6b2);
#
#
#
#         marker_bc29d18dd2fb766515b500b38bddbc32.bindPopup(popup_fc38dc5b2885bb661d8819d40d3a93a8)
#         ;
#
#
#
#
#             var marker_e0e7f23300a7090f2b93854ac0e447c9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f5e446c111753f14752ccdc469543aab);
#
#
#         var popup_59512b5c6acec26c435558fb329fdc50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdb6f04688aaa30af8825de9a630d417 = $(`&lt;div id=&quot;html_fdb6f04688aaa30af8825de9a630d417&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_59512b5c6acec26c435558fb329fdc50.setContent(html_fdb6f04688aaa30af8825de9a630d417);
#
#
#
#         marker_e0e7f23300a7090f2b93854ac0e447c9.bindPopup(popup_59512b5c6acec26c435558fb329fdc50)
#         ;
#
#
#
#
#             var marker_be49f16ed435cd42cd1fec2f72ae16fa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f5e446c111753f14752ccdc469543aab);
#
#
#         var popup_f853f56a9c422c78e6c73acbbab41472 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f51935758f6fc55156ec499bda3ce7c = $(`&lt;div id=&quot;html_8f51935758f6fc55156ec499bda3ce7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f853f56a9c422c78e6c73acbbab41472.setContent(html_8f51935758f6fc55156ec499bda3ce7c);
#
#
#
#         marker_be49f16ed435cd42cd1fec2f72ae16fa.bindPopup(popup_f853f56a9c422c78e6c73acbbab41472)
#         ;
#
#
#
#
#             var marker_8b013550d0320f42e4cb478afdef4d98 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f5e446c111753f14752ccdc469543aab);
#
#
#         var popup_d2d0c9bfbc24d548b60182ca79d2b9d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1cf26cef2415f6040fcc090bcf395b95 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1cf26cef2415f6040fcc090bcf395b95&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1cf26cef2415f6040fcc090bcf395b95 = L.map(
#                 &quot;map_1cf26cef2415f6040fcc090bcf395b95&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aea710cc333138b8de26f033aed629f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aea710cc333138b8de26f033aed629f1.addTo(map_1cf26cef2415f6040fcc090bcf395b95);
#
#
#             var feature_group_f57c9fc9929fa0aa696725225e6e5ac7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f57c9fc9929fa0aa696725225e6e5ac7.addTo(map_1cf26cef2415f6040fcc090bcf395b95);
#
#
#             var feature_group_sub_group_e4d2d1138cd5e333068110b61a4babb5 = L.featureGroup.subGroup(
#                 feature_group_f57c9fc9929fa0aa696725225e6e5ac7
#             );
#
#
#             var marker_a438a90f6c9300208aec762aa44728e8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e4d2d1138cd5e333068110b61a4babb5);
#
#
#         var popup_218f1d0a5332e305004d531cd8e42b49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce1c110b38f4c05724a592fab25c2f24 = $(`&lt;div id=&quot;html_ce1c110b38f4c05724a592fab25c2f24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_218f1d0a5332e305004d531cd8e42b49.setContent(html_ce1c110b38f4c05724a592fab25c2f24);
#
#
#
#         marker_a438a90f6c9300208aec762aa44728e8.bindPopup(popup_218f1d0a5332e305004d531cd8e42b49)
#         ;
#
#
#
#
#             var marker_fcbe68a5f565a86bca1ed50e01f1d702 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e4d2d1138cd5e333068110b61a4babb5);
#
#
#         var popup_bdd88a1212570fbd40b8a67bb42f5cdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c72eff7600d646f51fb468080752f861 = $(`&lt;div id=&quot;html_c72eff7600d646f51fb468080752f861&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bdd88a1212570fbd40b8a67bb42f5cdf.setContent(html_c72eff7600d646f51fb468080752f861);
#
#
#
#         marker_fcbe68a5f565a86bca1ed50e01f1d702.bindPopup(popup_bdd88a1212570fbd40b8a67bb42f5cdf)
#         ;
#
#
#
#
#             var marker_9e7e17671c2b78c39e05ec0e2275b5a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e4d2d1138cd5e333068110b61a4babb5);
#
#
#         var popup_ed64b0cd73d6fd668879241ccd5c0e92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a8b9349db7fa69f82f80108b726b649 = $(`&lt;div id=&quot;html_3a8b9349db7fa69f82f80108b726b649&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ed64b0cd73d6fd668879241ccd5c0e92.setContent(html_3a8b9349db7fa69f82f80108b726b649);
#
#
#
#         marker_9e7e17671c2b78c39e05ec0e2275b5a2.bindPopup(popup_ed64b0cd73d6fd668879241ccd5c0e92)
#         ;
#
#
#
#
#             var marker_d86991fe99b405ba5414462c9a7fc437 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e4d2d1138cd5e333068110b61a4babb5);
#
#
#         var popup_3bd54b652691643bc2aa70d220da672b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_097e4043ab26f324d0b6ba61c76bbe51 = $(`&lt;div id=&quot;html_097e4043ab26f324d0b6ba61c76bbe51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3bd54b652691643bc2aa70d220da672b.setContent(html_097e4043ab26f324d0b6ba61c76bbe51);
#
#
#
#         marker_
