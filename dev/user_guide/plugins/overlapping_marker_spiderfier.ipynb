# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6c2edfdb3070fc36325c16c6bf2f4cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6c2edfdb3070fc36325c16c6bf2f4cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6c2edfdb3070fc36325c16c6bf2f4cd = L.map(
#                 &quot;map_d6c2edfdb3070fc36325c16c6bf2f4cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09efc0c9d58c4f8ecbd18e9d9eda47bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09efc0c9d58c4f8ecbd18e9d9eda47bb.addTo(map_d6c2edfdb3070fc36325c16c6bf2f4cd);
#
#
#             var marker_8d5d5a0dce93bbb78d6fbf7eef9bb2dd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d6c2edfdb3070fc36325c16c6bf2f4cd);
#
#
#         var popup_5bd479c548a83b0d52968f4e50c37696 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4752ec380186ea8586cbd171d0ac1ed = $(`&lt;div id=&quot;html_f4752ec380186ea8586cbd171d0ac1ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5bd479c548a83b0d52968f4e50c37696.setContent(html_f4752ec380186ea8586cbd171d0ac1ed);
#
#
#
#         marker_8d5d5a0dce93bbb78d6fbf7eef9bb2dd.bindPopup(popup_5bd479c548a83b0d52968f4e50c37696)
#         ;
#
#
#
#
#             var marker_5b896c6f83d608043cbaf147c6f29bf4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d6c2edfdb3070fc36325c16c6bf2f4cd);
#
#
#         var popup_c520f8ff1ab0d43ffeeafe6a68136a4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9413c006bdd5b38027eabb4af543d62 = $(`&lt;div id=&quot;html_e9413c006bdd5b38027eabb4af543d62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c520f8ff1ab0d43ffeeafe6a68136a4c.setContent(html_e9413c006bdd5b38027eabb4af543d62);
#
#
#
#         marker_5b896c6f83d608043cbaf147c6f29bf4.bindPopup(popup_c520f8ff1ab0d43ffeeafe6a68136a4c)
#         ;
#
#
#
#
#             var marker_fd8b658d6b91fdeea77c6d633aed71aa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d6c2edfdb3070fc36325c16c6bf2f4cd);
#
#
#         var popup_f4a465f3ef411ffdeeab34134f50e5f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19f77c08e69903ed4d68ca5059e68149 = $(`&lt;div id=&quot;html_19f77c08e69903ed4d68ca5059e68149&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f4a465f3ef411ffdeeab34134f50e5f8.setContent(html_19f77c08e69903ed4d68ca5059e68149);
#
#
#
#         marker_fd8b658d6b91fdeea77c6d633aed71aa.bindPopup(popup_f4a465f3ef411ffdeeab34134f50e5f8)
#         ;
#
#
#
#
#             var marker_86872738549755d0f46474ffae8b8eca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d6c2edfdb3070fc36325c16c6bf2f4cd);
#
#
#         var popup_c6629ad99426b7f6da32ed629a703461 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abda29bb4f0be08bb8c3deaf8c6eaae8 = $(`&lt;div id=&quot;html_abda29bb4f0be08bb8c3deaf8c6eaae8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c6629ad99426b7f6da32ed629a703461.setContent(html_abda29bb4f0be08bb8c3deaf8c6eaae8);
#
#
#
#         marker_86872738549755d0f46474ffae8b8eca.bindPopup(popup_c6629ad99426b7f6da32ed629a703461)
#         ;
#
#
#
#
#             var marker_e4edfb6bb661c5b777aa9821e8d0cbb7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d6c2edfdb3070fc36325c16c6bf2f4cd);
#
#
#         var popup_2964dbeb6f8819f1822c65745a8c2994 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb1d16a17daa00e4163143fadc3febf2 = $(`&lt;div id=&quot;html_eb1d16a17daa00e4163143fadc3febf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2964dbeb6f8819f1822c65745a8c2994.setContent(html_eb1d16a17daa00e4163143fadc3febf2);
#
#
#
#         marker_e4edfb6bb661c5b777aa9821e8d0cbb7.bindPopup(popup_2964dbeb6f8819f1822c65745a8c2994)
#         ;
#
#
#
#
#             var marker_3a20b09817

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85b09ea2f4d757aa585daa1813c59947 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85b09ea2f4d757aa585daa1813c59947&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85b09ea2f4d757aa585daa1813c59947 = L.map(
#                 &quot;map_85b09ea2f4d757aa585daa1813c59947&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e0e58758d595bdd0cb067c3dd0d6cbb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e0e58758d595bdd0cb067c3dd0d6cbb.addTo(map_85b09ea2f4d757aa585daa1813c59947);
#
#
#             var feature_group_86603adbfab59b1b32582367092960ed = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e96859f300f9155d2b44f4dbf50acdb4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_86603adbfab59b1b32582367092960ed);
#
#
#         var popup_1db03a65817edeae86c5595c6a5f8ced = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23e9e86fe770e1c0364a43c63c443111 = $(`&lt;div id=&quot;html_23e9e86fe770e1c0364a43c63c443111&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1db03a65817edeae86c5595c6a5f8ced.setContent(html_23e9e86fe770e1c0364a43c63c443111);
#
#
#
#         marker_e96859f300f9155d2b44f4dbf50acdb4.bindPopup(popup_1db03a65817edeae86c5595c6a5f8ced)
#         ;
#
#
#
#
#             var marker_be8a2c25812af7f8ca3cb76a30289c8f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_86603adbfab59b1b32582367092960ed);
#
#
#         var popup_21ea76b8380d43303a34d5a3fd103359 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29cf5743a2f711dd11251fc7a68bfb82 = $(`&lt;div id=&quot;html_29cf5743a2f711dd11251fc7a68bfb82&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_21ea76b8380d43303a34d5a3fd103359.setContent(html_29cf5743a2f711dd11251fc7a68bfb82);
#
#
#
#         marker_be8a2c25812af7f8ca3cb76a30289c8f.bindPopup(popup_21ea76b8380d43303a34d5a3fd103359)
#         ;
#
#
#
#
#             var marker_27ce26ae9b090ab9a944f3e94452f8f6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_86603adbfab59b1b32582367092960ed);
#
#
#         var popup_0dfa96c238e6de05e39c4d3a81e0115e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5092c28d181132de209c57ff324e523c = $(`&lt;div id=&quot;html_5092c28d181132de209c57ff324e523c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0dfa96c238e6de05e39c4d3a81e0115e.setContent(html_5092c28d181132de209c57ff324e523c);
#
#
#
#         marker_27ce26ae9b090ab9a944f3e94452f8f6.bindPopup(popup_0dfa96c238e6de05e39c4d3a81e0115e)
#         ;
#
#
#
#
#             var marker_067514426d7c46cb6286c9db137f8f7f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_86603adbfab59b1b32582367092960ed);
#
#
#         var popup_f1a12cce291c838fd10ef0107c4ba980 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc064a16e2eb98a934102b0db9aa9265 = $(`&lt;div id=&quot;html_bc064a16e2eb98a934102b0db9aa9265&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f1a12cce291c838fd10ef0107c4ba980.setContent(html_bc064a16e2eb98a934102b0db9aa9265);
#
#
#
#         marker_067514426d7c46cb6286c9db137f8f7f.bindPopup(popup_f1a12cce291c838fd10ef0107c4ba980)
#         ;
#
#
#
#
#             var marker_f28dc0512afbb2d4cc4f5fbccb6b9af4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_86603adbfab59b1b32582367092960ed);
#
#
#         var popup_57c6594e7032567f14f87fa9aac98f77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12d1ca0f1336134c7dc8a4eeaf7a6920 = $(`&lt;div id=&quot;html_12d1ca0f1336134c7dc8a4eeaf7a6920&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_57c6594e7032567f14

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78dc69ad5150435bee333a0e6c4dbc57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78dc69ad5150435bee333a0e6c4dbc57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78dc69ad5150435bee333a0e6c4dbc57 = L.map(
#                 &quot;map_78dc69ad5150435bee333a0e6c4dbc57&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53f1a80cff522d07e8306c9329ce6b8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53f1a80cff522d07e8306c9329ce6b8d.addTo(map_78dc69ad5150435bee333a0e6c4dbc57);
#
#
#             var feature_group_a3dbd4bc7d668e5cdbe6948cac9f0a52 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a3dbd4bc7d668e5cdbe6948cac9f0a52.addTo(map_78dc69ad5150435bee333a0e6c4dbc57);
#
#
#             var feature_group_sub_group_2214c4fa4e915e85c4f0f729cd56a760 = L.featureGroup.subGroup(
#                 feature_group_a3dbd4bc7d668e5cdbe6948cac9f0a52
#             );
#
#
#             var marker_165003fc2023f5b5094e69603cc6c1ac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2214c4fa4e915e85c4f0f729cd56a760);
#
#
#         var popup_a4f4835cfc28fa7410d42fedcdf005fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3942e24415876042a0cf23416aede296 = $(`&lt;div id=&quot;html_3942e24415876042a0cf23416aede296&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a4f4835cfc28fa7410d42fedcdf005fe.setContent(html_3942e24415876042a0cf23416aede296);
#
#
#
#         marker_165003fc2023f5b5094e69603cc6c1ac.bindPopup(popup_a4f4835cfc28fa7410d42fedcdf005fe)
#         ;
#
#
#
#
#             var marker_d3ad2c0b6e960f97290e4b51c41557dc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2214c4fa4e915e85c4f0f729cd56a760);
#
#
#         var popup_002030056eff8e2bcb3a9986b6b6939f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed515603ecb6242c79e23c69f1d81c07 = $(`&lt;div id=&quot;html_ed515603ecb6242c79e23c69f1d81c07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_002030056eff8e2bcb3a9986b6b6939f.setContent(html_ed515603ecb6242c79e23c69f1d81c07);
#
#
#
#         marker_d3ad2c0b6e960f97290e4b51c41557dc.bindPopup(popup_002030056eff8e2bcb3a9986b6b6939f)
#         ;
#
#
#
#
#             var marker_b9accb151f755ae389047bdb7d46d8c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2214c4fa4e915e85c4f0f729cd56a760);
#
#
#         var popup_d02bd2ee69278d4f353a69d2e0475df9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d0607c4e3c7f07b1963f8b9ab63a3f5 = $(`&lt;div id=&quot;html_3d0607c4e3c7f07b1963f8b9ab63a3f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d02bd2ee69278d4f353a69d2e0475df9.setContent(html_3d0607c4e3c7f07b1963f8b9ab63a3f5);
#
#
#
#         marker_b9accb151f755ae389047bdb7d46d8c5.bindPopup(popup_d02bd2ee69278d4f353a69d2e0475df9)
#         ;
#
#
#
#
#             var marker_d4694035e46d76e6ec235e2d261dcd97 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2214c4fa4e915e85c4f0f729cd56a760);
#
#
#         var popup_f8b31ba19885529a69f6f1aef3d16888 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de2bdc73be06edc9a44b167dc832806d = $(`&lt;div id=&quot;html_de2bdc73be06edc9a44b167dc832806d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f8b31ba19885529a69f6f1aef3d16888.setContent(html_de2bdc73be06edc9a44b167dc832806d);
#
#
#
#         marker_d4694035e46d76e6ec235e2d261dcd97.bindPopup(popup_f8b31ba19885529a69f6f1aef3d16888)
#         ;
#
#
#
#
#             var marker_80888fdfb642a55acff5daa5c3b652de = L.marker(
#                 [45.050399999999996, 3.0504],
