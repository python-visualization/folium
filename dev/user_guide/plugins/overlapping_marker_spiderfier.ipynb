# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_830b6f6d9d934bf87ca163f88685c5a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_830b6f6d9d934bf87ca163f88685c5a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_830b6f6d9d934bf87ca163f88685c5a3 = L.map(
#                 &quot;map_830b6f6d9d934bf87ca163f88685c5a3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17a34830671f9a89a6750fa64c166e8c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17a34830671f9a89a6750fa64c166e8c.addTo(map_830b6f6d9d934bf87ca163f88685c5a3);
#
#
#             var marker_9e6d36eaa379bdc55406b176180d32f0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_830b6f6d9d934bf87ca163f88685c5a3);
#
#
#         var popup_663eeb1bccc2b50ab708773a4272aab0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb16b7f2ccc58450fcfca9802e804a67 = $(`&lt;div id=&quot;html_eb16b7f2ccc58450fcfca9802e804a67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_663eeb1bccc2b50ab708773a4272aab0.setContent(html_eb16b7f2ccc58450fcfca9802e804a67);
#
#
#
#         marker_9e6d36eaa379bdc55406b176180d32f0.bindPopup(popup_663eeb1bccc2b50ab708773a4272aab0)
#         ;
#
#
#
#
#             var marker_c22d6caf41660eaad448ede2c88f03de = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_830b6f6d9d934bf87ca163f88685c5a3);
#
#
#         var popup_054493f821af972247b0eddc64d320b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8ff6e7c236188fef758581f00870ea8 = $(`&lt;div id=&quot;html_d8ff6e7c236188fef758581f00870ea8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_054493f821af972247b0eddc64d320b4.setContent(html_d8ff6e7c236188fef758581f00870ea8);
#
#
#
#         marker_c22d6caf41660eaad448ede2c88f03de.bindPopup(popup_054493f821af972247b0eddc64d320b4)
#         ;
#
#
#
#
#             var marker_bb59decbc6d151605e33b95ed908e9aa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_830b6f6d9d934bf87ca163f88685c5a3);
#
#
#         var popup_00b3310c414cfe90be3b51dca8020ea8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_510893d976443ed5558be73106e39a31 = $(`&lt;div id=&quot;html_510893d976443ed5558be73106e39a31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_00b3310c414cfe90be3b51dca8020ea8.setContent(html_510893d976443ed5558be73106e39a31);
#
#
#
#         marker_bb59decbc6d151605e33b95ed908e9aa.bindPopup(popup_00b3310c414cfe90be3b51dca8020ea8)
#         ;
#
#
#
#
#             var marker_a86b4bfb46d54e0e446049f071326cc7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_830b6f6d9d934bf87ca163f88685c5a3);
#
#
#         var popup_a419c7a05398868cf96af180348763ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2089ec1d80696ff952bf5ccccb950463 = $(`&lt;div id=&quot;html_2089ec1d80696ff952bf5ccccb950463&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a419c7a05398868cf96af180348763ae.setContent(html_2089ec1d80696ff952bf5ccccb950463);
#
#
#
#         marker_a86b4bfb46d54e0e446049f071326cc7.bindPopup(popup_a419c7a05398868cf96af180348763ae)
#         ;
#
#
#
#
#             var marker_3c665a44aefaf1ff6c55cf67c8b0c738 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_830b6f6d9d934bf87ca163f88685c5a3);
#
#
#         var popup_05324668e9cc64a3e7076494f7e3eca6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2566f8276ea4460a3ca36963dd0d32f = $(`&lt;div id=&quot;html_e2566f8276ea4460a3ca36963dd0d32f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_05324668e9cc64a3e7076494f7e3eca6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8ce7f567d425fee07a669cee2b63dd5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8ce7f567d425fee07a669cee2b63dd5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8ce7f567d425fee07a669cee2b63dd5b = L.map(
#                 &quot;map_8ce7f567d425fee07a669cee2b63dd5b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05e64442fcb44940c609bc3e15945629 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05e64442fcb44940c609bc3e15945629.addTo(map_8ce7f567d425fee07a669cee2b63dd5b);
#
#
#             var feature_group_72be527c31c8fb1bc6437e8655f16da2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_71fce54288b5b20a99211bed7a3f6334 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_72be527c31c8fb1bc6437e8655f16da2);
#
#
#         var popup_2b0e9a5ba32ad6d727d89f873dbc9a1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ea90ad1a8e636089a429dcbecc5c9f3 = $(`&lt;div id=&quot;html_0ea90ad1a8e636089a429dcbecc5c9f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2b0e9a5ba32ad6d727d89f873dbc9a1b.setContent(html_0ea90ad1a8e636089a429dcbecc5c9f3);
#
#
#
#         marker_71fce54288b5b20a99211bed7a3f6334.bindPopup(popup_2b0e9a5ba32ad6d727d89f873dbc9a1b)
#         ;
#
#
#
#
#             var marker_96991e42e7c01b02100634f860b80672 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_72be527c31c8fb1bc6437e8655f16da2);
#
#
#         var popup_20b30493ac4719aad20ebd5e29c5840a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d27c809cb128009e2f546e8c73184be5 = $(`&lt;div id=&quot;html_d27c809cb128009e2f546e8c73184be5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_20b30493ac4719aad20ebd5e29c5840a.setContent(html_d27c809cb128009e2f546e8c73184be5);
#
#
#
#         marker_96991e42e7c01b02100634f860b80672.bindPopup(popup_20b30493ac4719aad20ebd5e29c5840a)
#         ;
#
#
#
#
#             var marker_2ddabfd212492fb0e89a4e0c432b4c45 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_72be527c31c8fb1bc6437e8655f16da2);
#
#
#         var popup_467a7234bb6e635ade69d5cb9222aa1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec191039092477c67ba92d344b69caca = $(`&lt;div id=&quot;html_ec191039092477c67ba92d344b69caca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_467a7234bb6e635ade69d5cb9222aa1c.setContent(html_ec191039092477c67ba92d344b69caca);
#
#
#
#         marker_2ddabfd212492fb0e89a4e0c432b4c45.bindPopup(popup_467a7234bb6e635ade69d5cb9222aa1c)
#         ;
#
#
#
#
#             var marker_b5d37afcdfa605de9c6b5bf9189ba8c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_72be527c31c8fb1bc6437e8655f16da2);
#
#
#         var popup_1da135fed8678b3e122db46e4d027079 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc38525f379324de99be3433b6d14fe3 = $(`&lt;div id=&quot;html_fc38525f379324de99be3433b6d14fe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1da135fed8678b3e122db46e4d027079.setContent(html_fc38525f379324de99be3433b6d14fe3);
#
#
#
#         marker_b5d37afcdfa605de9c6b5bf9189ba8c0.bindPopup(popup_1da135fed8678b3e122db46e4d027079)
#         ;
#
#
#
#
#             var marker_b0355ff62cb04a0d08f4ddd7828bb435 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_72be527c31c8fb1bc6437e8655f16da2);
#
#
#         var popup_30639498625d4364c854bfeda5b44b27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6aad65fb483d3b894895018f481bca5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6aad65fb483d3b894895018f481bca5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6aad65fb483d3b894895018f481bca5e = L.map(
#                 &quot;map_6aad65fb483d3b894895018f481bca5e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd80fffe4ecb7d0570b02ab34272bfce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fd80fffe4ecb7d0570b02ab34272bfce.addTo(map_6aad65fb483d3b894895018f481bca5e);
#
#
#             var feature_group_98fa24d2649956a66ee6e4c1a6c33b32 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_98fa24d2649956a66ee6e4c1a6c33b32.addTo(map_6aad65fb483d3b894895018f481bca5e);
#
#
#             var feature_group_sub_group_d21d1ba27b470761fa2f5dccf824bded = L.featureGroup.subGroup(
#                 feature_group_98fa24d2649956a66ee6e4c1a6c33b32
#             );
#
#
#             var marker_c2d4b76f0d8384ff65f3dceeea0f5c23 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d21d1ba27b470761fa2f5dccf824bded);
#
#
#         var popup_136cc946676182079639d0006c25cad4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c779c4da6aaf957ebc53e62463661a35 = $(`&lt;div id=&quot;html_c779c4da6aaf957ebc53e62463661a35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_136cc946676182079639d0006c25cad4.setContent(html_c779c4da6aaf957ebc53e62463661a35);
#
#
#
#         marker_c2d4b76f0d8384ff65f3dceeea0f5c23.bindPopup(popup_136cc946676182079639d0006c25cad4)
#         ;
#
#
#
#
#             var marker_7ee6d89847f57475da359a6b342072d3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d21d1ba27b470761fa2f5dccf824bded);
#
#
#         var popup_1ddf6b400ccbc481c7182c21b464988b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_080d1dbc284a626ac7ecc2a1f9a17af1 = $(`&lt;div id=&quot;html_080d1dbc284a626ac7ecc2a1f9a17af1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1ddf6b400ccbc481c7182c21b464988b.setContent(html_080d1dbc284a626ac7ecc2a1f9a17af1);
#
#
#
#         marker_7ee6d89847f57475da359a6b342072d3.bindPopup(popup_1ddf6b400ccbc481c7182c21b464988b)
#         ;
#
#
#
#
#             var marker_54cf3dcc517ad309151a10c0f959bfe2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d21d1ba27b470761fa2f5dccf824bded);
#
#
#         var popup_d159400748d0609964fafd995cc32229 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73f603d4f50488a7d461413b52487e3c = $(`&lt;div id=&quot;html_73f603d4f50488a7d461413b52487e3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d159400748d0609964fafd995cc32229.setContent(html_73f603d4f50488a7d461413b52487e3c);
#
#
#
#         marker_54cf3dcc517ad309151a10c0f959bfe2.bindPopup(popup_d159400748d0609964fafd995cc32229)
#         ;
#
#
#
#
#             var marker_4fb09bb28ac6186df42de51ccb8303e6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d21d1ba27b470761fa2f5dccf824bded);
#
#
#         var popup_eaa0a00ed0a429b0830e1f7d0f711b05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f74768097a71333a2d7e1ede2fc04f2 = $(`&lt;div id=&quot;html_2f74768097a71333a2d7e1ede2fc04f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_eaa0a00ed0a429b0830e1f7d0f711b05.setContent(html_2f74768097a71333a2d7e1ede2fc04f2);
#
#
#
#         marker_
