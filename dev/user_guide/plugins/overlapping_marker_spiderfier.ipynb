# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4329ca4d2714cd7c38f8b0c84287a8f8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4329ca4d2714cd7c38f8b0c84287a8f8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4329ca4d2714cd7c38f8b0c84287a8f8 = L.map(
#                 &quot;map_4329ca4d2714cd7c38f8b0c84287a8f8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f77963c3262c48f97c1d310650f61aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f77963c3262c48f97c1d310650f61aa.addTo(map_4329ca4d2714cd7c38f8b0c84287a8f8);
#
#
#             var marker_783f762ae519e5f01761329518719c30 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4329ca4d2714cd7c38f8b0c84287a8f8);
#
#
#         var popup_f742ab825ccb824c628c7df16c1b585b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53928089ff8630f4199e809c72a55e98 = $(`&lt;div id=&quot;html_53928089ff8630f4199e809c72a55e98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f742ab825ccb824c628c7df16c1b585b.setContent(html_53928089ff8630f4199e809c72a55e98);
#
#
#
#         marker_783f762ae519e5f01761329518719c30.bindPopup(popup_f742ab825ccb824c628c7df16c1b585b)
#         ;
#
#
#
#
#             var marker_7bca31e00cc22524a6e0831053fef43f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4329ca4d2714cd7c38f8b0c84287a8f8);
#
#
#         var popup_2d52e3c030873e14b6d414c02ffe2d0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45a3808c697328150ab06c9343e05325 = $(`&lt;div id=&quot;html_45a3808c697328150ab06c9343e05325&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2d52e3c030873e14b6d414c02ffe2d0f.setContent(html_45a3808c697328150ab06c9343e05325);
#
#
#
#         marker_7bca31e00cc22524a6e0831053fef43f.bindPopup(popup_2d52e3c030873e14b6d414c02ffe2d0f)
#         ;
#
#
#
#
#             var marker_63aecd5fe6b4a90ea0c0afc1273240f9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4329ca4d2714cd7c38f8b0c84287a8f8);
#
#
#         var popup_b193125dadfed3e9b1a995caf6588f76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08e8097e40a5d49638ab3ea1e7d77ace = $(`&lt;div id=&quot;html_08e8097e40a5d49638ab3ea1e7d77ace&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b193125dadfed3e9b1a995caf6588f76.setContent(html_08e8097e40a5d49638ab3ea1e7d77ace);
#
#
#
#         marker_63aecd5fe6b4a90ea0c0afc1273240f9.bindPopup(popup_b193125dadfed3e9b1a995caf6588f76)
#         ;
#
#
#
#
#             var marker_f3a8091edccfd2e89bf40d729c8e6f39 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4329ca4d2714cd7c38f8b0c84287a8f8);
#
#
#         var popup_d142eaf831185aa4a525ca3355dbf91e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c629eece773e806680bf4543337e2f4 = $(`&lt;div id=&quot;html_5c629eece773e806680bf4543337e2f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d142eaf831185aa4a525ca3355dbf91e.setContent(html_5c629eece773e806680bf4543337e2f4);
#
#
#
#         marker_f3a8091edccfd2e89bf40d729c8e6f39.bindPopup(popup_d142eaf831185aa4a525ca3355dbf91e)
#         ;
#
#
#
#
#             var marker_28b24ede883c66ccf62dfffb2ee4f45f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4329ca4d2714cd7c38f8b0c84287a8f8);
#
#
#         var popup_0286f6df14e97ca0f207f3093341ecd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb3ed148db950b5b564cd7fe1b80e0d9 = $(`&lt;div id=&quot;html_fb3ed148db950b5b564cd7fe1b80e0d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0286f6df14e97ca0f207f3093341ecd8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f8172c0353473e468cc68b07a68416a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f8172c0353473e468cc68b07a68416a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f8172c0353473e468cc68b07a68416a9 = L.map(
#                 &quot;map_f8172c0353473e468cc68b07a68416a9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca322a7603bc336c25e674be7a9e474a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ca322a7603bc336c25e674be7a9e474a.addTo(map_f8172c0353473e468cc68b07a68416a9);
#
#
#             var feature_group_668f3104471481d837649d14e189580c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_277f832cf305336c48d0849dcc447743 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_668f3104471481d837649d14e189580c);
#
#
#         var popup_3b2de176c232a67cc7b6a124f7dedf08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73771767d0794e77c72e5d8df68b9ae2 = $(`&lt;div id=&quot;html_73771767d0794e77c72e5d8df68b9ae2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3b2de176c232a67cc7b6a124f7dedf08.setContent(html_73771767d0794e77c72e5d8df68b9ae2);
#
#
#
#         marker_277f832cf305336c48d0849dcc447743.bindPopup(popup_3b2de176c232a67cc7b6a124f7dedf08)
#         ;
#
#
#
#
#             var marker_438392120355151d396ad0a3b4b3e6a4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_668f3104471481d837649d14e189580c);
#
#
#         var popup_7621ee631b814ea692ed0d4ca930700e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ea7a00bcd6e60b68496949dddb436a8 = $(`&lt;div id=&quot;html_8ea7a00bcd6e60b68496949dddb436a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7621ee631b814ea692ed0d4ca930700e.setContent(html_8ea7a00bcd6e60b68496949dddb436a8);
#
#
#
#         marker_438392120355151d396ad0a3b4b3e6a4.bindPopup(popup_7621ee631b814ea692ed0d4ca930700e)
#         ;
#
#
#
#
#             var marker_d758105edfe63981f464bf9a18a7f44a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_668f3104471481d837649d14e189580c);
#
#
#         var popup_94d934c8a457e28a3c3fd50bb9ea1334 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f585d50486b9357994376c25c1696c3b = $(`&lt;div id=&quot;html_f585d50486b9357994376c25c1696c3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_94d934c8a457e28a3c3fd50bb9ea1334.setContent(html_f585d50486b9357994376c25c1696c3b);
#
#
#
#         marker_d758105edfe63981f464bf9a18a7f44a.bindPopup(popup_94d934c8a457e28a3c3fd50bb9ea1334)
#         ;
#
#
#
#
#             var marker_d56f95a634bfaaa35376ec638b39b01a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_668f3104471481d837649d14e189580c);
#
#
#         var popup_d3f5d1613fd27ff1e5a7744cde9b4b47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a15ee7100e68d9747f3f3d1cdaa1850 = $(`&lt;div id=&quot;html_5a15ee7100e68d9747f3f3d1cdaa1850&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d3f5d1613fd27ff1e5a7744cde9b4b47.setContent(html_5a15ee7100e68d9747f3f3d1cdaa1850);
#
#
#
#         marker_d56f95a634bfaaa35376ec638b39b01a.bindPopup(popup_d3f5d1613fd27ff1e5a7744cde9b4b47)
#         ;
#
#
#
#
#             var marker_d579a00313e2073a8f1d2e2a9df13c41 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_668f3104471481d837649d14e189580c);
#
#
#         var popup_fe28552e7f2b83b6cd9780333c728422 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bce3c4da45c0c4a88e39d7fbd000684 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bce3c4da45c0c4a88e39d7fbd000684&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bce3c4da45c0c4a88e39d7fbd000684 = L.map(
#                 &quot;map_4bce3c4da45c0c4a88e39d7fbd000684&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0df63ff0a7e155e3a5babf8a4574d67 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0df63ff0a7e155e3a5babf8a4574d67.addTo(map_4bce3c4da45c0c4a88e39d7fbd000684);
#
#
#             var feature_group_2788080340dd734e7d6d9a0f8a5afe52 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2788080340dd734e7d6d9a0f8a5afe52.addTo(map_4bce3c4da45c0c4a88e39d7fbd000684);
#
#
#             var feature_group_sub_group_17b5a694c316a64cfa72e5d1e395bf58 = L.featureGroup.subGroup(
#                 feature_group_2788080340dd734e7d6d9a0f8a5afe52
#             );
#
#
#             var marker_1ba7386e80451112ed266b93a69c50fc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_17b5a694c316a64cfa72e5d1e395bf58);
#
#
#         var popup_ed3293ec3e3d54b60c71b906377ab45f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc062f5ac51a8913a2b484c6288c223a = $(`&lt;div id=&quot;html_dc062f5ac51a8913a2b484c6288c223a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ed3293ec3e3d54b60c71b906377ab45f.setContent(html_dc062f5ac51a8913a2b484c6288c223a);
#
#
#
#         marker_1ba7386e80451112ed266b93a69c50fc.bindPopup(popup_ed3293ec3e3d54b60c71b906377ab45f)
#         ;
#
#
#
#
#             var marker_cd82865e567451d4ad351b8e90ead4df = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_17b5a694c316a64cfa72e5d1e395bf58);
#
#
#         var popup_f715967c0a0cafd4b168f5dcd348645a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_462e5db38fe811c9a5ec456ce9d98bb5 = $(`&lt;div id=&quot;html_462e5db38fe811c9a5ec456ce9d98bb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f715967c0a0cafd4b168f5dcd348645a.setContent(html_462e5db38fe811c9a5ec456ce9d98bb5);
#
#
#
#         marker_cd82865e567451d4ad351b8e90ead4df.bindPopup(popup_f715967c0a0cafd4b168f5dcd348645a)
#         ;
#
#
#
#
#             var marker_0de37518c7a9bb06c4906988e3b08479 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_17b5a694c316a64cfa72e5d1e395bf58);
#
#
#         var popup_d435ee141190bad13fa72fa7c8cdbdbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e4b5e0ac4a4d8bd70796b22c867b12c = $(`&lt;div id=&quot;html_7e4b5e0ac4a4d8bd70796b22c867b12c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d435ee141190bad13fa72fa7c8cdbdbe.setContent(html_7e4b5e0ac4a4d8bd70796b22c867b12c);
#
#
#
#         marker_0de37518c7a9bb06c4906988e3b08479.bindPopup(popup_d435ee141190bad13fa72fa7c8cdbdbe)
#         ;
#
#
#
#
#             var marker_cfa86c3b400965ca948f751466703a37 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_17b5a694c316a64cfa72e5d1e395bf58);
#
#
#         var popup_994f2cb2959c133cfc0f3423aeb3f61f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d2225585aa5e2cc97c5bc3db62652e6 = $(`&lt;div id=&quot;html_9d2225585aa5e2cc97c5bc3db62652e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_994f2cb2959c133cfc0f3423aeb3f61f.setContent(html_9d2225585aa5e2cc97c5bc3db62652e6);
#
#
#
#         marker_
