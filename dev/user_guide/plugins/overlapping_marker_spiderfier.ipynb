# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a39265b2306803053c25d92e3bf7b13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a39265b2306803053c25d92e3bf7b13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a39265b2306803053c25d92e3bf7b13 = L.map(
#                 &quot;map_1a39265b2306803053c25d92e3bf7b13&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80324fae26357d53152646f322daa29c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_80324fae26357d53152646f322daa29c.addTo(map_1a39265b2306803053c25d92e3bf7b13);
#
#
#             var marker_193b432110f4cd4f92c98de7e466a965 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1a39265b2306803053c25d92e3bf7b13);
#
#
#         var popup_0b76ad5c33d5292f0b895fe4efffbc79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63a869c9f7d0a8c02a3507739eb31ffb = $(`&lt;div id=&quot;html_63a869c9f7d0a8c02a3507739eb31ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0b76ad5c33d5292f0b895fe4efffbc79.setContent(html_63a869c9f7d0a8c02a3507739eb31ffb);
#
#
#
#         marker_193b432110f4cd4f92c98de7e466a965.bindPopup(popup_0b76ad5c33d5292f0b895fe4efffbc79)
#         ;
#
#
#
#
#             var marker_90eb5c92669a64e2d59492d4e1c39843 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1a39265b2306803053c25d92e3bf7b13);
#
#
#         var popup_8271d16b58f37129ce4e92bf4e5656dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c7a9c0f290e48f4cdf8f43c8773b6a1 = $(`&lt;div id=&quot;html_2c7a9c0f290e48f4cdf8f43c8773b6a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8271d16b58f37129ce4e92bf4e5656dc.setContent(html_2c7a9c0f290e48f4cdf8f43c8773b6a1);
#
#
#
#         marker_90eb5c92669a64e2d59492d4e1c39843.bindPopup(popup_8271d16b58f37129ce4e92bf4e5656dc)
#         ;
#
#
#
#
#             var marker_c655d3923cf0f612bfdf51cba7e8b2c4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1a39265b2306803053c25d92e3bf7b13);
#
#
#         var popup_da1dc0b65166241c7dfe5791ff86255c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f4fb08ab4891d6c1ccf43dc41ba3b27 = $(`&lt;div id=&quot;html_5f4fb08ab4891d6c1ccf43dc41ba3b27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_da1dc0b65166241c7dfe5791ff86255c.setContent(html_5f4fb08ab4891d6c1ccf43dc41ba3b27);
#
#
#
#         marker_c655d3923cf0f612bfdf51cba7e8b2c4.bindPopup(popup_da1dc0b65166241c7dfe5791ff86255c)
#         ;
#
#
#
#
#             var marker_6a2a465632d1659f209b54a9d5a1fafd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1a39265b2306803053c25d92e3bf7b13);
#
#
#         var popup_6e5e6309ef2213220d541dec84b47f23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_463411f17940aa152f5087c021fbd6d1 = $(`&lt;div id=&quot;html_463411f17940aa152f5087c021fbd6d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6e5e6309ef2213220d541dec84b47f23.setContent(html_463411f17940aa152f5087c021fbd6d1);
#
#
#
#         marker_6a2a465632d1659f209b54a9d5a1fafd.bindPopup(popup_6e5e6309ef2213220d541dec84b47f23)
#         ;
#
#
#
#
#             var marker_60e440e71d053f6c17ba94edf397e3cc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1a39265b2306803053c25d92e3bf7b13);
#
#
#         var popup_c59c514ddd9666dba7898676a8f6f64a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59ee92ae2274a1699a4e109e259924ad = $(`&lt;div id=&quot;html_59ee92ae2274a1699a4e109e259924ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c59c514ddd9666dba7898676a8f6f64a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ccd5468fd5c6a7fe8783ad66e94109f5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ccd5468fd5c6a7fe8783ad66e94109f5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ccd5468fd5c6a7fe8783ad66e94109f5 = L.map(
#                 &quot;map_ccd5468fd5c6a7fe8783ad66e94109f5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98dbcc4e2fe289c3cf4a64420f5fce13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_98dbcc4e2fe289c3cf4a64420f5fce13.addTo(map_ccd5468fd5c6a7fe8783ad66e94109f5);
#
#
#             var feature_group_36129bf43bba60f49e2c2de59204a421 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8ed3e00bc2b2643e5e2c2de05cbe8328 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_36129bf43bba60f49e2c2de59204a421);
#
#
#         var popup_63f48f0aa1333cd787d09a5624e1606e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8a6526fc0a42e2222ceac3b07f3d9de = $(`&lt;div id=&quot;html_e8a6526fc0a42e2222ceac3b07f3d9de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_63f48f0aa1333cd787d09a5624e1606e.setContent(html_e8a6526fc0a42e2222ceac3b07f3d9de);
#
#
#
#         marker_8ed3e00bc2b2643e5e2c2de05cbe8328.bindPopup(popup_63f48f0aa1333cd787d09a5624e1606e)
#         ;
#
#
#
#
#             var marker_12415a12ba33924617af4c59b85ed626 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_36129bf43bba60f49e2c2de59204a421);
#
#
#         var popup_cba931d109bf3aaaaba11b96739d76b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f44bb2b9349b6bdb50614b3d572023c5 = $(`&lt;div id=&quot;html_f44bb2b9349b6bdb50614b3d572023c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cba931d109bf3aaaaba11b96739d76b8.setContent(html_f44bb2b9349b6bdb50614b3d572023c5);
#
#
#
#         marker_12415a12ba33924617af4c59b85ed626.bindPopup(popup_cba931d109bf3aaaaba11b96739d76b8)
#         ;
#
#
#
#
#             var marker_9a604669c224621491f57202c60b9a48 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_36129bf43bba60f49e2c2de59204a421);
#
#
#         var popup_c76999c4e8691c83552fb733ccb6ce0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c270ca23a8dafd5aef5b85ec8e4d90f2 = $(`&lt;div id=&quot;html_c270ca23a8dafd5aef5b85ec8e4d90f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c76999c4e8691c83552fb733ccb6ce0f.setContent(html_c270ca23a8dafd5aef5b85ec8e4d90f2);
#
#
#
#         marker_9a604669c224621491f57202c60b9a48.bindPopup(popup_c76999c4e8691c83552fb733ccb6ce0f)
#         ;
#
#
#
#
#             var marker_51076e2eb409e54842525a8deaa7c9d9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_36129bf43bba60f49e2c2de59204a421);
#
#
#         var popup_5c123316b8a8e680b535b8acff2ce8db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5a951ab65b916b2fe02476ca2465cb9 = $(`&lt;div id=&quot;html_a5a951ab65b916b2fe02476ca2465cb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5c123316b8a8e680b535b8acff2ce8db.setContent(html_a5a951ab65b916b2fe02476ca2465cb9);
#
#
#
#         marker_51076e2eb409e54842525a8deaa7c9d9.bindPopup(popup_5c123316b8a8e680b535b8acff2ce8db)
#         ;
#
#
#
#
#             var marker_157008cccdddf17cea8e5c3c95973df9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_36129bf43bba60f49e2c2de59204a421);
#
#
#         var popup_e4bbc9ba8ea3aaf160e602aa11b1a643 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5f39912629f6290686e4025eb3ba7b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5f39912629f6290686e4025eb3ba7b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5f39912629f6290686e4025eb3ba7b2 = L.map(
#                 &quot;map_c5f39912629f6290686e4025eb3ba7b2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_97c72ec77d4767ecfc7bfa1b7ee0b39f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_97c72ec77d4767ecfc7bfa1b7ee0b39f.addTo(map_c5f39912629f6290686e4025eb3ba7b2);
#
#
#             var feature_group_c823aa3161714c6998a6a4e63d52e01b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c823aa3161714c6998a6a4e63d52e01b.addTo(map_c5f39912629f6290686e4025eb3ba7b2);
#
#
#             var feature_group_sub_group_812f27891e6a3424e7b003a4c3f3dea8 = L.featureGroup.subGroup(
#                 feature_group_c823aa3161714c6998a6a4e63d52e01b
#             );
#
#
#             var marker_a3ed16887508c86d5ae186b2c3ed27bd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_812f27891e6a3424e7b003a4c3f3dea8);
#
#
#         var popup_fc0aca4650aa641795b433c67530d75f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27a959dcb0c831212b866f5e827a6e91 = $(`&lt;div id=&quot;html_27a959dcb0c831212b866f5e827a6e91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fc0aca4650aa641795b433c67530d75f.setContent(html_27a959dcb0c831212b866f5e827a6e91);
#
#
#
#         marker_a3ed16887508c86d5ae186b2c3ed27bd.bindPopup(popup_fc0aca4650aa641795b433c67530d75f)
#         ;
#
#
#
#
#             var marker_c2656ff16b1450dcb14573a39a37adf3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_812f27891e6a3424e7b003a4c3f3dea8);
#
#
#         var popup_1e2a61d65eb5aef6526716a053804b25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb1b194df1de3c113c43f194e9125328 = $(`&lt;div id=&quot;html_bb1b194df1de3c113c43f194e9125328&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1e2a61d65eb5aef6526716a053804b25.setContent(html_bb1b194df1de3c113c43f194e9125328);
#
#
#
#         marker_c2656ff16b1450dcb14573a39a37adf3.bindPopup(popup_1e2a61d65eb5aef6526716a053804b25)
#         ;
#
#
#
#
#             var marker_bd0edefb9aed5cf6cbdc6f183a3a023e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_812f27891e6a3424e7b003a4c3f3dea8);
#
#
#         var popup_c340fad60fbd5c2f14c280867fbd4396 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90a10453064d8b9d56512994bc3d3428 = $(`&lt;div id=&quot;html_90a10453064d8b9d56512994bc3d3428&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c340fad60fbd5c2f14c280867fbd4396.setContent(html_90a10453064d8b9d56512994bc3d3428);
#
#
#
#         marker_bd0edefb9aed5cf6cbdc6f183a3a023e.bindPopup(popup_c340fad60fbd5c2f14c280867fbd4396)
#         ;
#
#
#
#
#             var marker_e4ac25efc5ca9b1dd12fd0fd423c03f7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_812f27891e6a3424e7b003a4c3f3dea8);
#
#
#         var popup_9f9d3a9862648d9e3ef7b747302f136e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ed7781a3d2486fd89a46c1ccfa7b8b9 = $(`&lt;div id=&quot;html_3ed7781a3d2486fd89a46c1ccfa7b8b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9f9d3a9862648d9e3ef7b747302f136e.setContent(html_3ed7781a3d2486fd89a46c1ccfa7b8b9);
#
#
#
#         marker_
