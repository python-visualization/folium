# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5fa687c3e318e9c0344cf15a4d5a2301 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5fa687c3e318e9c0344cf15a4d5a2301&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5fa687c3e318e9c0344cf15a4d5a2301 = L.map(
#                 &quot;map_5fa687c3e318e9c0344cf15a4d5a2301&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a7207916cf88961385a3c956128b784 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a7207916cf88961385a3c956128b784.addTo(map_5fa687c3e318e9c0344cf15a4d5a2301);
#
#
#             var marker_a9d3055501973837f776dd269a58bb21 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5fa687c3e318e9c0344cf15a4d5a2301);
#
#
#         var popup_854b0d218fd389adac0c221067c3fa4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34ac5aac8390950d7577a53cd7debc00 = $(`&lt;div id=&quot;html_34ac5aac8390950d7577a53cd7debc00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_854b0d218fd389adac0c221067c3fa4f.setContent(html_34ac5aac8390950d7577a53cd7debc00);
#
#
#
#         marker_a9d3055501973837f776dd269a58bb21.bindPopup(popup_854b0d218fd389adac0c221067c3fa4f)
#         ;
#
#
#
#
#             var marker_1d5a356fbce9a5501dd9674176c02926 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5fa687c3e318e9c0344cf15a4d5a2301);
#
#
#         var popup_500061848815c91842012a2c48c9fd8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35cfed8b70c2c44a10ab93cd5dcc5cf9 = $(`&lt;div id=&quot;html_35cfed8b70c2c44a10ab93cd5dcc5cf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_500061848815c91842012a2c48c9fd8b.setContent(html_35cfed8b70c2c44a10ab93cd5dcc5cf9);
#
#
#
#         marker_1d5a356fbce9a5501dd9674176c02926.bindPopup(popup_500061848815c91842012a2c48c9fd8b)
#         ;
#
#
#
#
#             var marker_c3b93ea759458856a87b7d0a3b10acf0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5fa687c3e318e9c0344cf15a4d5a2301);
#
#
#         var popup_0863b5f1a57f405e3d6a928faef7b33d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fab3f2ac9e4aa7b43badf27b73049aaf = $(`&lt;div id=&quot;html_fab3f2ac9e4aa7b43badf27b73049aaf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0863b5f1a57f405e3d6a928faef7b33d.setContent(html_fab3f2ac9e4aa7b43badf27b73049aaf);
#
#
#
#         marker_c3b93ea759458856a87b7d0a3b10acf0.bindPopup(popup_0863b5f1a57f405e3d6a928faef7b33d)
#         ;
#
#
#
#
#             var marker_498275795d827526a2581f08282a6207 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5fa687c3e318e9c0344cf15a4d5a2301);
#
#
#         var popup_e3638b49a74d1366f21b0949dc061b4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0d0c8e91c6eec77c1a54bdb18bbdc1b = $(`&lt;div id=&quot;html_c0d0c8e91c6eec77c1a54bdb18bbdc1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e3638b49a74d1366f21b0949dc061b4f.setContent(html_c0d0c8e91c6eec77c1a54bdb18bbdc1b);
#
#
#
#         marker_498275795d827526a2581f08282a6207.bindPopup(popup_e3638b49a74d1366f21b0949dc061b4f)
#         ;
#
#
#
#
#             var marker_a0b12996ad84dcb58c5e07e4ba1b4cb4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5fa687c3e318e9c0344cf15a4d5a2301);
#
#
#         var popup_848909e299c929abc4c988432ab2f802 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d70ce68264750bbb69656e6b041086fc = $(`&lt;div id=&quot;html_d70ce68264750bbb69656e6b041086fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_848909e299c929abc4c988432ab2f802.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e406c78ff684f6570481a2a856fb6fe3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e406c78ff684f6570481a2a856fb6fe3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e406c78ff684f6570481a2a856fb6fe3 = L.map(
#                 &quot;map_e406c78ff684f6570481a2a856fb6fe3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28f76e269f0fd2f4d633307b15b15051 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_28f76e269f0fd2f4d633307b15b15051.addTo(map_e406c78ff684f6570481a2a856fb6fe3);
#
#
#             var feature_group_8ca2adf07131cab65d8ed49c0853ed60 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c4dfa316745bca71cb7d2ddcc818b323 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8ca2adf07131cab65d8ed49c0853ed60);
#
#
#         var popup_5db3ceeb23e7acf7df034c62801bb8a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a92e98604939ba30a8e91f9606f310a = $(`&lt;div id=&quot;html_9a92e98604939ba30a8e91f9606f310a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5db3ceeb23e7acf7df034c62801bb8a9.setContent(html_9a92e98604939ba30a8e91f9606f310a);
#
#
#
#         marker_c4dfa316745bca71cb7d2ddcc818b323.bindPopup(popup_5db3ceeb23e7acf7df034c62801bb8a9)
#         ;
#
#
#
#
#             var marker_80fea7433e2f3e406f127466918e3d9d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8ca2adf07131cab65d8ed49c0853ed60);
#
#
#         var popup_6f516211d8c14e904b76fe6266e13aa6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfac9b3b8b112d23f34d5a7f67cc0724 = $(`&lt;div id=&quot;html_bfac9b3b8b112d23f34d5a7f67cc0724&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6f516211d8c14e904b76fe6266e13aa6.setContent(html_bfac9b3b8b112d23f34d5a7f67cc0724);
#
#
#
#         marker_80fea7433e2f3e406f127466918e3d9d.bindPopup(popup_6f516211d8c14e904b76fe6266e13aa6)
#         ;
#
#
#
#
#             var marker_b2e4bd43086148dc283bb3cac5d7dd9e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8ca2adf07131cab65d8ed49c0853ed60);
#
#
#         var popup_7fb271e1ec0443174eecf54918ad444a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bdcbe9aca78d1c7464f89a405df28b5 = $(`&lt;div id=&quot;html_9bdcbe9aca78d1c7464f89a405df28b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7fb271e1ec0443174eecf54918ad444a.setContent(html_9bdcbe9aca78d1c7464f89a405df28b5);
#
#
#
#         marker_b2e4bd43086148dc283bb3cac5d7dd9e.bindPopup(popup_7fb271e1ec0443174eecf54918ad444a)
#         ;
#
#
#
#
#             var marker_e954f3baee637524788757ba0feee457 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8ca2adf07131cab65d8ed49c0853ed60);
#
#
#         var popup_975946cdf3f3243e509bcf45c77b9c7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e836ed93c5b3babb7d91526037854dbf = $(`&lt;div id=&quot;html_e836ed93c5b3babb7d91526037854dbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_975946cdf3f3243e509bcf45c77b9c7d.setContent(html_e836ed93c5b3babb7d91526037854dbf);
#
#
#
#         marker_e954f3baee637524788757ba0feee457.bindPopup(popup_975946cdf3f3243e509bcf45c77b9c7d)
#         ;
#
#
#
#
#             var marker_d3286932ac853e194a981c1dbc546b48 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8ca2adf07131cab65d8ed49c0853ed60);
#
#
#         var popup_45d3d933ae10a08c8e3c39030dff02ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eeba333cce636d41d33c07d425d5b5c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eeba333cce636d41d33c07d425d5b5c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eeba333cce636d41d33c07d425d5b5c9 = L.map(
#                 &quot;map_eeba333cce636d41d33c07d425d5b5c9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88f78f71c73bbb4b26c6583f295d2042 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88f78f71c73bbb4b26c6583f295d2042.addTo(map_eeba333cce636d41d33c07d425d5b5c9);
#
#
#             var feature_group_d1ef36e7415be7b7472ffa0a87396995 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d1ef36e7415be7b7472ffa0a87396995.addTo(map_eeba333cce636d41d33c07d425d5b5c9);
#
#
#             var feature_group_sub_group_18c1dd436769e9c8349ac9b58ee1937d = L.featureGroup.subGroup(
#                 feature_group_d1ef36e7415be7b7472ffa0a87396995
#             );
#
#
#             var marker_077553e22e19b32a635088524546e9e8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_18c1dd436769e9c8349ac9b58ee1937d);
#
#
#         var popup_c956a698f286138106b4e357f4c6f57f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d22514cd94218136bc19ac509da65e22 = $(`&lt;div id=&quot;html_d22514cd94218136bc19ac509da65e22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c956a698f286138106b4e357f4c6f57f.setContent(html_d22514cd94218136bc19ac509da65e22);
#
#
#
#         marker_077553e22e19b32a635088524546e9e8.bindPopup(popup_c956a698f286138106b4e357f4c6f57f)
#         ;
#
#
#
#
#             var marker_7936e75a6c8a4d6bd0f02131acee38a4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_18c1dd436769e9c8349ac9b58ee1937d);
#
#
#         var popup_1f4844c8c0e8c40e181647654e5aa813 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d977b98a8e5ba4f5edcb907a9e024087 = $(`&lt;div id=&quot;html_d977b98a8e5ba4f5edcb907a9e024087&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1f4844c8c0e8c40e181647654e5aa813.setContent(html_d977b98a8e5ba4f5edcb907a9e024087);
#
#
#
#         marker_7936e75a6c8a4d6bd0f02131acee38a4.bindPopup(popup_1f4844c8c0e8c40e181647654e5aa813)
#         ;
#
#
#
#
#             var marker_d2e39a374f6804fb846882bea6605626 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_18c1dd436769e9c8349ac9b58ee1937d);
#
#
#         var popup_48015692549d3dc01d963b0bda953ea6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4f2bd65fb5bd61d2f9ca19cd0827c38 = $(`&lt;div id=&quot;html_f4f2bd65fb5bd61d2f9ca19cd0827c38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_48015692549d3dc01d963b0bda953ea6.setContent(html_f4f2bd65fb5bd61d2f9ca19cd0827c38);
#
#
#
#         marker_d2e39a374f6804fb846882bea6605626.bindPopup(popup_48015692549d3dc01d963b0bda953ea6)
#         ;
#
#
#
#
#             var marker_2d3920d849212098b7e03e8283b39646 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_18c1dd436769e9c8349ac9b58ee1937d);
#
#
#         var popup_e5ecaa1fb848521d5e27211a1fd74438 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_388048d56c3d3024207f7f0fd752b0e5 = $(`&lt;div id=&quot;html_388048d56c3d3024207f7f0fd752b0e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e5ecaa1fb848521d5e27211a1fd74438.setContent(html_388048d56c3d3024207f7f0fd752b0e5);
#
#
#
#         marker_
