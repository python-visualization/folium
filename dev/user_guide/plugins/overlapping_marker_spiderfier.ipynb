# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41f06791940aa0a6d0d28121cb477e18 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41f06791940aa0a6d0d28121cb477e18&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41f06791940aa0a6d0d28121cb477e18 = L.map(
#                 &quot;map_41f06791940aa0a6d0d28121cb477e18&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b23b36c05f356f3bdf4ca9959b5a712f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b23b36c05f356f3bdf4ca9959b5a712f.addTo(map_41f06791940aa0a6d0d28121cb477e18);
#
#
#             var marker_24d213d191d451acbf729d98889e29f5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_41f06791940aa0a6d0d28121cb477e18);
#
#
#         var popup_4016d8a8c2111ebdaaed2d7ce56a38d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82970794dc9b012c472dfa39de9c8997 = $(`&lt;div id=&quot;html_82970794dc9b012c472dfa39de9c8997&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4016d8a8c2111ebdaaed2d7ce56a38d6.setContent(html_82970794dc9b012c472dfa39de9c8997);
#
#
#
#         marker_24d213d191d451acbf729d98889e29f5.bindPopup(popup_4016d8a8c2111ebdaaed2d7ce56a38d6)
#         ;
#
#
#
#
#             var marker_9754ceff678bf9883dd36597c1ab12ae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_41f06791940aa0a6d0d28121cb477e18);
#
#
#         var popup_bf1131edc634c485fd2c93a2cfc8d540 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33dc662915eb4f2c6d29a6d1592ee772 = $(`&lt;div id=&quot;html_33dc662915eb4f2c6d29a6d1592ee772&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bf1131edc634c485fd2c93a2cfc8d540.setContent(html_33dc662915eb4f2c6d29a6d1592ee772);
#
#
#
#         marker_9754ceff678bf9883dd36597c1ab12ae.bindPopup(popup_bf1131edc634c485fd2c93a2cfc8d540)
#         ;
#
#
#
#
#             var marker_0aa7484ae9539d7d5a49b74a0b236ae6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_41f06791940aa0a6d0d28121cb477e18);
#
#
#         var popup_eb42024081c9c84a11f1ad8d65ef5c00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a5a65c2a1a26bd2706fd22d54d0e6e8 = $(`&lt;div id=&quot;html_1a5a65c2a1a26bd2706fd22d54d0e6e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_eb42024081c9c84a11f1ad8d65ef5c00.setContent(html_1a5a65c2a1a26bd2706fd22d54d0e6e8);
#
#
#
#         marker_0aa7484ae9539d7d5a49b74a0b236ae6.bindPopup(popup_eb42024081c9c84a11f1ad8d65ef5c00)
#         ;
#
#
#
#
#             var marker_619ec49ee142a242549675cf634996b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_41f06791940aa0a6d0d28121cb477e18);
#
#
#         var popup_5c26c4144bccd2f76e7a3cf8a38b4af9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da2710b8e71be3df15c9c9cb41c554ca = $(`&lt;div id=&quot;html_da2710b8e71be3df15c9c9cb41c554ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5c26c4144bccd2f76e7a3cf8a38b4af9.setContent(html_da2710b8e71be3df15c9c9cb41c554ca);
#
#
#
#         marker_619ec49ee142a242549675cf634996b3.bindPopup(popup_5c26c4144bccd2f76e7a3cf8a38b4af9)
#         ;
#
#
#
#
#             var marker_4c2d59e2d1f7a45e580152d01eb52a59 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_41f06791940aa0a6d0d28121cb477e18);
#
#
#         var popup_7cb61b988a010c3e8302f333d6eb01c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aca0c257e394a4ad8b699ad0052ff33d = $(`&lt;div id=&quot;html_aca0c257e394a4ad8b699ad0052ff33d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7cb61b988a010c3e8302f333d6eb01

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5384817cf7392516be55ce4eb4fecc43 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5384817cf7392516be55ce4eb4fecc43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5384817cf7392516be55ce4eb4fecc43 = L.map(
#                 &quot;map_5384817cf7392516be55ce4eb4fecc43&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8cfd2c1b2cd0551e7347ce23ece3f2b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d8cfd2c1b2cd0551e7347ce23ece3f2b.addTo(map_5384817cf7392516be55ce4eb4fecc43);
#
#
#             var feature_group_88c464ffe6ce3278cc9f44dddd943bde = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3536f6a3a10dca26666a8b680c01d482 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_88c464ffe6ce3278cc9f44dddd943bde);
#
#
#         var popup_9c0c413b1d968488bfa95a585542ac9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37bed805c9dc070cc650742de3f17132 = $(`&lt;div id=&quot;html_37bed805c9dc070cc650742de3f17132&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9c0c413b1d968488bfa95a585542ac9d.setContent(html_37bed805c9dc070cc650742de3f17132);
#
#
#
#         marker_3536f6a3a10dca26666a8b680c01d482.bindPopup(popup_9c0c413b1d968488bfa95a585542ac9d)
#         ;
#
#
#
#
#             var marker_10d8290578202dce2a52ce8e7e80dcef = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_88c464ffe6ce3278cc9f44dddd943bde);
#
#
#         var popup_3cd0cd415eeef8fda7df3a0e2912963c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ece30a4f6e73961acefbfa37bbb8622 = $(`&lt;div id=&quot;html_3ece30a4f6e73961acefbfa37bbb8622&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3cd0cd415eeef8fda7df3a0e2912963c.setContent(html_3ece30a4f6e73961acefbfa37bbb8622);
#
#
#
#         marker_10d8290578202dce2a52ce8e7e80dcef.bindPopup(popup_3cd0cd415eeef8fda7df3a0e2912963c)
#         ;
#
#
#
#
#             var marker_4c72a33d72cab3d633c754d1975153cb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_88c464ffe6ce3278cc9f44dddd943bde);
#
#
#         var popup_89caed19d9214ea0d85642d4f75b1b51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c6f6f20dd3557d2e6eeeac2d565e47d = $(`&lt;div id=&quot;html_8c6f6f20dd3557d2e6eeeac2d565e47d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_89caed19d9214ea0d85642d4f75b1b51.setContent(html_8c6f6f20dd3557d2e6eeeac2d565e47d);
#
#
#
#         marker_4c72a33d72cab3d633c754d1975153cb.bindPopup(popup_89caed19d9214ea0d85642d4f75b1b51)
#         ;
#
#
#
#
#             var marker_43ec9f5e0241fb71e85edb01d238b6d7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_88c464ffe6ce3278cc9f44dddd943bde);
#
#
#         var popup_bf8cab507a738301f6e1428ef15b8e07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07ddffef21aa658f8323ee3fc841e280 = $(`&lt;div id=&quot;html_07ddffef21aa658f8323ee3fc841e280&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bf8cab507a738301f6e1428ef15b8e07.setContent(html_07ddffef21aa658f8323ee3fc841e280);
#
#
#
#         marker_43ec9f5e0241fb71e85edb01d238b6d7.bindPopup(popup_bf8cab507a738301f6e1428ef15b8e07)
#         ;
#
#
#
#
#             var marker_6c890897ca33126501ccd2955d60607a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_88c464ffe6ce3278cc9f44dddd943bde);
#
#
#         var popup_02209bba13861846b644536df192f2d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ff72ec543d830d2369a1c5571fd5094b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ff72ec543d830d2369a1c5571fd5094b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ff72ec543d830d2369a1c5571fd5094b = L.map(
#                 &quot;map_ff72ec543d830d2369a1c5571fd5094b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d0237cf0efc373a08eddeb91205e538 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d0237cf0efc373a08eddeb91205e538.addTo(map_ff72ec543d830d2369a1c5571fd5094b);
#
#
#             var feature_group_0f573c14feb133ec64c3338fd07f7cc3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0f573c14feb133ec64c3338fd07f7cc3.addTo(map_ff72ec543d830d2369a1c5571fd5094b);
#
#
#             var feature_group_sub_group_9cfc7a3eb34460bc50dfc7d6cd82c22e = L.featureGroup.subGroup(
#                 feature_group_0f573c14feb133ec64c3338fd07f7cc3
#             );
#
#
#             var marker_93f28c4782425048bbcc340a80be5707 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9cfc7a3eb34460bc50dfc7d6cd82c22e);
#
#
#         var popup_88415e32a8a91bc7110eba2e8226b908 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c58705cf244115641ad4d0ab0eec1ca8 = $(`&lt;div id=&quot;html_c58705cf244115641ad4d0ab0eec1ca8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_88415e32a8a91bc7110eba2e8226b908.setContent(html_c58705cf244115641ad4d0ab0eec1ca8);
#
#
#
#         marker_93f28c4782425048bbcc340a80be5707.bindPopup(popup_88415e32a8a91bc7110eba2e8226b908)
#         ;
#
#
#
#
#             var marker_ef0711e2bb845599c452372dac56adc5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9cfc7a3eb34460bc50dfc7d6cd82c22e);
#
#
#         var popup_b32ce6e599fdd3a8d75b448fba52e61e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0719a3f02e2a90778f696776e219b61e = $(`&lt;div id=&quot;html_0719a3f02e2a90778f696776e219b61e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b32ce6e599fdd3a8d75b448fba52e61e.setContent(html_0719a3f02e2a90778f696776e219b61e);
#
#
#
#         marker_ef0711e2bb845599c452372dac56adc5.bindPopup(popup_b32ce6e599fdd3a8d75b448fba52e61e)
#         ;
#
#
#
#
#             var marker_a68a1dcab50121a41e6aafba65ff38e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9cfc7a3eb34460bc50dfc7d6cd82c22e);
#
#
#         var popup_1f58204303eae5da478de1ff24ad5be6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdaaa5bddc0c88ee56285b59237ba2fb = $(`&lt;div id=&quot;html_cdaaa5bddc0c88ee56285b59237ba2fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1f58204303eae5da478de1ff24ad5be6.setContent(html_cdaaa5bddc0c88ee56285b59237ba2fb);
#
#
#
#         marker_a68a1dcab50121a41e6aafba65ff38e8.bindPopup(popup_1f58204303eae5da478de1ff24ad5be6)
#         ;
#
#
#
#
#             var marker_239ae4a8350883da4a246b628b2ad7ae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9cfc7a3eb34460bc50dfc7d6cd82c22e);
#
#
#         var popup_1c1993b6ceae12d851267a7a755859ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8175d57ec80f7964e69a4c92c8684721 = $(`&lt;div id=&quot;html_8175d57ec80f7964e69a4c92c8684721&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1c1993b6ceae12d851267a7a755859ec.setContent(html_8175d57ec80f7964e69a4c92c8684721);
#
#
#
#         mark
