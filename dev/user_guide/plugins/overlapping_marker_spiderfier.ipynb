# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c654278160c8d38ffe083a2e020d535 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c654278160c8d38ffe083a2e020d535&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c654278160c8d38ffe083a2e020d535 = L.map(
#                 &quot;map_8c654278160c8d38ffe083a2e020d535&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3fb3ccb9a3282b5fe366067f7037a158 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3fb3ccb9a3282b5fe366067f7037a158.addTo(map_8c654278160c8d38ffe083a2e020d535);
#
#
#             var marker_e7c0d4bcf1fd6515b12c4490de7c4a87 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8c654278160c8d38ffe083a2e020d535);
#
#
#         var popup_80ff96af4d9964ec5a590311af5ae2c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28d63fb90a093274aa1faae315157b92 = $(`&lt;div id=&quot;html_28d63fb90a093274aa1faae315157b92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_80ff96af4d9964ec5a590311af5ae2c4.setContent(html_28d63fb90a093274aa1faae315157b92);
#
#
#
#         marker_e7c0d4bcf1fd6515b12c4490de7c4a87.bindPopup(popup_80ff96af4d9964ec5a590311af5ae2c4)
#         ;
#
#
#
#
#             var marker_474f5479592a762de7614c7f80e1c499 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8c654278160c8d38ffe083a2e020d535);
#
#
#         var popup_c6afdc1dfc5a0dd354d1914ccc485ce1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_769897d807480fb2f34e79f94f2e24fa = $(`&lt;div id=&quot;html_769897d807480fb2f34e79f94f2e24fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c6afdc1dfc5a0dd354d1914ccc485ce1.setContent(html_769897d807480fb2f34e79f94f2e24fa);
#
#
#
#         marker_474f5479592a762de7614c7f80e1c499.bindPopup(popup_c6afdc1dfc5a0dd354d1914ccc485ce1)
#         ;
#
#
#
#
#             var marker_d6f577e8d840038dae8d17d8391b13ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8c654278160c8d38ffe083a2e020d535);
#
#
#         var popup_92268c9138ad6d0e4e8ad33df8b97571 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed907f8bc9abc00a635a9f82db4bba61 = $(`&lt;div id=&quot;html_ed907f8bc9abc00a635a9f82db4bba61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_92268c9138ad6d0e4e8ad33df8b97571.setContent(html_ed907f8bc9abc00a635a9f82db4bba61);
#
#
#
#         marker_d6f577e8d840038dae8d17d8391b13ed.bindPopup(popup_92268c9138ad6d0e4e8ad33df8b97571)
#         ;
#
#
#
#
#             var marker_dc69d2eb967021d0028ac204b8bde48e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8c654278160c8d38ffe083a2e020d535);
#
#
#         var popup_cea5cdc009900b7803eaf7a38276874b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28db040e3720c988724671d4c823e0b2 = $(`&lt;div id=&quot;html_28db040e3720c988724671d4c823e0b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cea5cdc009900b7803eaf7a38276874b.setContent(html_28db040e3720c988724671d4c823e0b2);
#
#
#
#         marker_dc69d2eb967021d0028ac204b8bde48e.bindPopup(popup_cea5cdc009900b7803eaf7a38276874b)
#         ;
#
#
#
#
#             var marker_e7146b00a04851ab88760dd5a0d23fea = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8c654278160c8d38ffe083a2e020d535);
#
#
#         var popup_7839cab5d65ff85829fe76834dd721fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e377e1c6c3156d6f8964d52272db4232 = $(`&lt;div id=&quot;html_e377e1c6c3156d6f8964d52272db4232&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7839cab5d65ff85829fe76834dd721fe.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2580a54c5dbf5d41f0030f26853ad99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2580a54c5dbf5d41f0030f26853ad99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2580a54c5dbf5d41f0030f26853ad99 = L.map(
#                 &quot;map_f2580a54c5dbf5d41f0030f26853ad99&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d8586e58c6ed373fdfb0ba3c9a6f1036 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d8586e58c6ed373fdfb0ba3c9a6f1036.addTo(map_f2580a54c5dbf5d41f0030f26853ad99);
#
#
#             var feature_group_0e2acb7cb2f9e24cef2ece6c501c5616 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e0daa9933206cb9cc3231d91c84c8029 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0e2acb7cb2f9e24cef2ece6c501c5616);
#
#
#         var popup_14e71f6b56d57ef0b786645b8c759f5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab5853459eb774c0b3ba10e632a63fdc = $(`&lt;div id=&quot;html_ab5853459eb774c0b3ba10e632a63fdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_14e71f6b56d57ef0b786645b8c759f5f.setContent(html_ab5853459eb774c0b3ba10e632a63fdc);
#
#
#
#         marker_e0daa9933206cb9cc3231d91c84c8029.bindPopup(popup_14e71f6b56d57ef0b786645b8c759f5f)
#         ;
#
#
#
#
#             var marker_79731af22167f75ccc2e5137248fb926 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0e2acb7cb2f9e24cef2ece6c501c5616);
#
#
#         var popup_b5d8a98d9a4045ecdf6cd69e691d6876 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_640b8a02fbfd6ab8cedf3fe9ae42ff7b = $(`&lt;div id=&quot;html_640b8a02fbfd6ab8cedf3fe9ae42ff7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b5d8a98d9a4045ecdf6cd69e691d6876.setContent(html_640b8a02fbfd6ab8cedf3fe9ae42ff7b);
#
#
#
#         marker_79731af22167f75ccc2e5137248fb926.bindPopup(popup_b5d8a98d9a4045ecdf6cd69e691d6876)
#         ;
#
#
#
#
#             var marker_28900fb6336e86c31331555a43a2b4a3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0e2acb7cb2f9e24cef2ece6c501c5616);
#
#
#         var popup_20d92e7d9fe561adcaefa62e44b37c90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_856b11f6ba8014f478ae28bed9cbc98b = $(`&lt;div id=&quot;html_856b11f6ba8014f478ae28bed9cbc98b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_20d92e7d9fe561adcaefa62e44b37c90.setContent(html_856b11f6ba8014f478ae28bed9cbc98b);
#
#
#
#         marker_28900fb6336e86c31331555a43a2b4a3.bindPopup(popup_20d92e7d9fe561adcaefa62e44b37c90)
#         ;
#
#
#
#
#             var marker_99eab040eeb5168ab4fe1ae1fac5a6ee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0e2acb7cb2f9e24cef2ece6c501c5616);
#
#
#         var popup_8327f4ee565d325edababad49f6bf444 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ac65c6c1573de329a396f8c2a244c51 = $(`&lt;div id=&quot;html_0ac65c6c1573de329a396f8c2a244c51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8327f4ee565d325edababad49f6bf444.setContent(html_0ac65c6c1573de329a396f8c2a244c51);
#
#
#
#         marker_99eab040eeb5168ab4fe1ae1fac5a6ee.bindPopup(popup_8327f4ee565d325edababad49f6bf444)
#         ;
#
#
#
#
#             var marker_57e1fbbd14f31ae94870ffbd3d6d0a03 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0e2acb7cb2f9e24cef2ece6c501c5616);
#
#
#         var popup_95bd6313cb16d6de529afbfc729ad365 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb252b2de2ad623ba964f77903b813b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb252b2de2ad623ba964f77903b813b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb252b2de2ad623ba964f77903b813b1 = L.map(
#                 &quot;map_bb252b2de2ad623ba964f77903b813b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eccfa3f08923d5efe7a1f79167ff92a0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eccfa3f08923d5efe7a1f79167ff92a0.addTo(map_bb252b2de2ad623ba964f77903b813b1);
#
#
#             var feature_group_845ad533b4f7664ec5ed8dd0c612a2f0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_845ad533b4f7664ec5ed8dd0c612a2f0.addTo(map_bb252b2de2ad623ba964f77903b813b1);
#
#
#             var feature_group_sub_group_df68c46413cc0c8415ac89b79061ccf1 = L.featureGroup.subGroup(
#                 feature_group_845ad533b4f7664ec5ed8dd0c612a2f0
#             );
#
#
#             var marker_6654adfd813ca7c7ac1eb44b30721f47 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_df68c46413cc0c8415ac89b79061ccf1);
#
#
#         var popup_2563ec457d4208d3b80fb37ec912f76f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d5004565563ae9bfb5131a242d28f55 = $(`&lt;div id=&quot;html_1d5004565563ae9bfb5131a242d28f55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2563ec457d4208d3b80fb37ec912f76f.setContent(html_1d5004565563ae9bfb5131a242d28f55);
#
#
#
#         marker_6654adfd813ca7c7ac1eb44b30721f47.bindPopup(popup_2563ec457d4208d3b80fb37ec912f76f)
#         ;
#
#
#
#
#             var marker_ad030f3d935b5a5749154ec5ef6db5af = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_df68c46413cc0c8415ac89b79061ccf1);
#
#
#         var popup_a5ebb911def33476677dbff292f2ee1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f6442510e11b6009645ae28f1738ee8 = $(`&lt;div id=&quot;html_0f6442510e11b6009645ae28f1738ee8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a5ebb911def33476677dbff292f2ee1e.setContent(html_0f6442510e11b6009645ae28f1738ee8);
#
#
#
#         marker_ad030f3d935b5a5749154ec5ef6db5af.bindPopup(popup_a5ebb911def33476677dbff292f2ee1e)
#         ;
#
#
#
#
#             var marker_e407b114f229d083649f75a670bf7560 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_df68c46413cc0c8415ac89b79061ccf1);
#
#
#         var popup_f08cfdfc5ede0eb124f27a208c0fc48c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e107c6c9c755a29ead8157e7200b8d17 = $(`&lt;div id=&quot;html_e107c6c9c755a29ead8157e7200b8d17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f08cfdfc5ede0eb124f27a208c0fc48c.setContent(html_e107c6c9c755a29ead8157e7200b8d17);
#
#
#
#         marker_e407b114f229d083649f75a670bf7560.bindPopup(popup_f08cfdfc5ede0eb124f27a208c0fc48c)
#         ;
#
#
#
#
#             var marker_6d5594c0a93fded6d58256d21980cf8b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_df68c46413cc0c8415ac89b79061ccf1);
#
#
#         var popup_ee9982c016e1fb56a53dc0efcfcc7304 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de4215ef55afd32639612bd84f1eafd5 = $(`&lt;div id=&quot;html_de4215ef55afd32639612bd84f1eafd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ee9982c016e1fb56a53dc0efcfcc7304.setContent(html_de4215ef55afd32639612bd84f1eafd5);
#
#
#
#         marker_
