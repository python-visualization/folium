# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2406de8e3196063a3664dd2fcf496ea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2406de8e3196063a3664dd2fcf496ea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b2406de8e3196063a3664dd2fcf496ea = L.map(
#                 &quot;map_b2406de8e3196063a3664dd2fcf496ea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ea35e9c997a57a8bbd07f197961e5d1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ea35e9c997a57a8bbd07f197961e5d1b.addTo(map_b2406de8e3196063a3664dd2fcf496ea);
#
#
#             var marker_4ac7099ebe17f2c09348c641289a56ca = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b2406de8e3196063a3664dd2fcf496ea);
#
#
#         var popup_98ea14d769b7d0e0b40617796912f5be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_124c12de6026530b20a258ffa027babb = $(`&lt;div id=&quot;html_124c12de6026530b20a258ffa027babb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_98ea14d769b7d0e0b40617796912f5be.setContent(html_124c12de6026530b20a258ffa027babb);
#
#
#
#         marker_4ac7099ebe17f2c09348c641289a56ca.bindPopup(popup_98ea14d769b7d0e0b40617796912f5be)
#         ;
#
#
#
#
#             var marker_dee7018552008ab04b16a4dc01149493 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b2406de8e3196063a3664dd2fcf496ea);
#
#
#         var popup_e94392226eafb76174c51cdaf51b975d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7d7c5b874679885efa77cb5d5c6aa3a = $(`&lt;div id=&quot;html_e7d7c5b874679885efa77cb5d5c6aa3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e94392226eafb76174c51cdaf51b975d.setContent(html_e7d7c5b874679885efa77cb5d5c6aa3a);
#
#
#
#         marker_dee7018552008ab04b16a4dc01149493.bindPopup(popup_e94392226eafb76174c51cdaf51b975d)
#         ;
#
#
#
#
#             var marker_624ab6926439e18cd818ca6019e2dc85 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b2406de8e3196063a3664dd2fcf496ea);
#
#
#         var popup_bda6ba55054135a68e9453e3bbca16ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81414ccf46f645c9f9ba2c4a4cfb4721 = $(`&lt;div id=&quot;html_81414ccf46f645c9f9ba2c4a4cfb4721&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bda6ba55054135a68e9453e3bbca16ad.setContent(html_81414ccf46f645c9f9ba2c4a4cfb4721);
#
#
#
#         marker_624ab6926439e18cd818ca6019e2dc85.bindPopup(popup_bda6ba55054135a68e9453e3bbca16ad)
#         ;
#
#
#
#
#             var marker_83acff711a294047088d1818aa37030c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b2406de8e3196063a3664dd2fcf496ea);
#
#
#         var popup_2bf21bfc347f95ed34938a1a4887585c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1498f7b517ea35f80d9b6fd75157164 = $(`&lt;div id=&quot;html_d1498f7b517ea35f80d9b6fd75157164&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2bf21bfc347f95ed34938a1a4887585c.setContent(html_d1498f7b517ea35f80d9b6fd75157164);
#
#
#
#         marker_83acff711a294047088d1818aa37030c.bindPopup(popup_2bf21bfc347f95ed34938a1a4887585c)
#         ;
#
#
#
#
#             var marker_d1494f6c3c05ac22de64e6a0a603fdb3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b2406de8e3196063a3664dd2fcf496ea);
#
#
#         var popup_1c12598572d4a8ccab1c4743b6d9736a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb3cb9762be0e4b1a0c523b9460c12ab = $(`&lt;div id=&quot;html_cb3cb9762be0e4b1a0c523b9460c12ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1c12598572d4a8ccab1c4743b6d9736a.setContent(html_cb3cb9762be0e4b1a0c523b9460c12ab);
#
#
#
#         marker_d1494f6c3c05ac22de64e6a0a603fdb3.bindPopup(popup_1c12598572d4a8ccab1c4743b6d9736a)
#         ;
#
#
#
#
#             var marker_d6de944152

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba7c51a1b4aeb444ff1ed7ae10f26fae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba7c51a1b4aeb444ff1ed7ae10f26fae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba7c51a1b4aeb444ff1ed7ae10f26fae = L.map(
#                 &quot;map_ba7c51a1b4aeb444ff1ed7ae10f26fae&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_461f56149a66daec5f7c362cb0d938b6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_461f56149a66daec5f7c362cb0d938b6.addTo(map_ba7c51a1b4aeb444ff1ed7ae10f26fae);
#
#
#             var feature_group_7f5bbb7915e5f564fae711ef51cebf69 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_469deb8dd2b8890b8b78aa52c4730285 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7f5bbb7915e5f564fae711ef51cebf69);
#
#
#         var popup_25fec801b8fee9f4fbc7fe673bcef8dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6f68e03c10ad5ed4512177b98932bb7 = $(`&lt;div id=&quot;html_a6f68e03c10ad5ed4512177b98932bb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_25fec801b8fee9f4fbc7fe673bcef8dc.setContent(html_a6f68e03c10ad5ed4512177b98932bb7);
#
#
#
#         marker_469deb8dd2b8890b8b78aa52c4730285.bindPopup(popup_25fec801b8fee9f4fbc7fe673bcef8dc)
#         ;
#
#
#
#
#             var marker_0aa3b133bc7d0b30af61a3268ffbd5c2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7f5bbb7915e5f564fae711ef51cebf69);
#
#
#         var popup_21dd76d7f3f0fa03b45afc916c25c9f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b974d0c14e55ce6be210d697e1cabcb = $(`&lt;div id=&quot;html_1b974d0c14e55ce6be210d697e1cabcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_21dd76d7f3f0fa03b45afc916c25c9f0.setContent(html_1b974d0c14e55ce6be210d697e1cabcb);
#
#
#
#         marker_0aa3b133bc7d0b30af61a3268ffbd5c2.bindPopup(popup_21dd76d7f3f0fa03b45afc916c25c9f0)
#         ;
#
#
#
#
#             var marker_0804be4c36ad376cc02d938c9298da54 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7f5bbb7915e5f564fae711ef51cebf69);
#
#
#         var popup_e08a3d0c9ec283a4f4f225a9a5dc82de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6570df5528902fc1973f567083a1851a = $(`&lt;div id=&quot;html_6570df5528902fc1973f567083a1851a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e08a3d0c9ec283a4f4f225a9a5dc82de.setContent(html_6570df5528902fc1973f567083a1851a);
#
#
#
#         marker_0804be4c36ad376cc02d938c9298da54.bindPopup(popup_e08a3d0c9ec283a4f4f225a9a5dc82de)
#         ;
#
#
#
#
#             var marker_aaa44cb72672655e02876b7c6f0ce3fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7f5bbb7915e5f564fae711ef51cebf69);
#
#
#         var popup_eff6329dacd203be7f22cd10a26faaba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64db8e4d480b4fa118ca42eb33be962f = $(`&lt;div id=&quot;html_64db8e4d480b4fa118ca42eb33be962f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_eff6329dacd203be7f22cd10a26faaba.setContent(html_64db8e4d480b4fa118ca42eb33be962f);
#
#
#
#         marker_aaa44cb72672655e02876b7c6f0ce3fd.bindPopup(popup_eff6329dacd203be7f22cd10a26faaba)
#         ;
#
#
#
#
#             var marker_75936dc38d60bae26daa74ff66de8d1d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7f5bbb7915e5f564fae711ef51cebf69);
#
#
#         var popup_a6abdb36e46de14191c1b33940bcf187 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe02f95bbca812c62f7c4f6f4729fba1 = $(`&lt;div id=&quot;html_fe02f95bbca812c62f7c4f6f4729fba1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_a6abdb36e46de14191

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_db6486f721c51335d012fe7c978675fe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_db6486f721c51335d012fe7c978675fe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_db6486f721c51335d012fe7c978675fe = L.map(
#                 &quot;map_db6486f721c51335d012fe7c978675fe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42977147bb9d66dae217a97c935be240 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_42977147bb9d66dae217a97c935be240.addTo(map_db6486f721c51335d012fe7c978675fe);
#
#
#             var feature_group_e1cb7b1742028ad88ffc893418c1ac4f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e1cb7b1742028ad88ffc893418c1ac4f.addTo(map_db6486f721c51335d012fe7c978675fe);
#
#
#             var feature_group_sub_group_5414eb3394fb3267ca03eaacbbfb722e = L.featureGroup.subGroup(
#                 feature_group_e1cb7b1742028ad88ffc893418c1ac4f
#             );
#
#
#             var marker_e120af7ed1bd3ab8743e06e24b2d4f4c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5414eb3394fb3267ca03eaacbbfb722e);
#
#
#         var popup_0e59155b5a127a9877174789dd61c30a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7eff18b22c3a98960ff8b2a668912e2f = $(`&lt;div id=&quot;html_7eff18b22c3a98960ff8b2a668912e2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0e59155b5a127a9877174789dd61c30a.setContent(html_7eff18b22c3a98960ff8b2a668912e2f);
#
#
#
#         marker_e120af7ed1bd3ab8743e06e24b2d4f4c.bindPopup(popup_0e59155b5a127a9877174789dd61c30a)
#         ;
#
#
#
#
#             var marker_6effdeda638335be36b12e4e359ab608 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5414eb3394fb3267ca03eaacbbfb722e);
#
#
#         var popup_42687fdb7983da0f65c2f0b7c34cc536 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69f2c1c4efd7201dafe0043b5162306a = $(`&lt;div id=&quot;html_69f2c1c4efd7201dafe0043b5162306a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_42687fdb7983da0f65c2f0b7c34cc536.setContent(html_69f2c1c4efd7201dafe0043b5162306a);
#
#
#
#         marker_6effdeda638335be36b12e4e359ab608.bindPopup(popup_42687fdb7983da0f65c2f0b7c34cc536)
#         ;
#
#
#
#
#             var marker_e4a4ebfc23c9394b5996efc4fdf18cb6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5414eb3394fb3267ca03eaacbbfb722e);
#
#
#         var popup_3e8861ab6633f10c051bb7e4f782c8ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14f90c2abdafcfd7a6ab7e7a5d615066 = $(`&lt;div id=&quot;html_14f90c2abdafcfd7a6ab7e7a5d615066&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3e8861ab6633f10c051bb7e4f782c8ff.setContent(html_14f90c2abdafcfd7a6ab7e7a5d615066);
#
#
#
#         marker_e4a4ebfc23c9394b5996efc4fdf18cb6.bindPopup(popup_3e8861ab6633f10c051bb7e4f782c8ff)
#         ;
#
#
#
#
#             var marker_44f42157ec1affedf5bc2cb7d588016e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5414eb3394fb3267ca03eaacbbfb722e);
#
#
#         var popup_bf0d2bd52fe013bc00d3c06011196b12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbacda2db0dac24e158e64f5436da41d = $(`&lt;div id=&quot;html_cbacda2db0dac24e158e64f5436da41d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bf0d2bd52fe013bc00d3c06011196b12.setContent(html_cbacda2db0dac24e158e64f5436da41d);
#
#
#
#         marker_44f42157ec1affedf5bc2cb7d588016e.bindPopup(popup_bf0d2bd52fe013bc00d3c06011196b12)
#         ;
#
#
#
#
#             var marker_057711880f47e891aba4020d8d5b44a7 = L.marker(
#                 [45.050399999999996, 3.0504],
