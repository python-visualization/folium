# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7f9a41c4d0ec7c953b20c380d18fb9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7f9a41c4d0ec7c953b20c380d18fb9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7f9a41c4d0ec7c953b20c380d18fb9e = L.map(
#                 &quot;map_b7f9a41c4d0ec7c953b20c380d18fb9e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abca47d27bb46d1c1c39eccc18babb5d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_abca47d27bb46d1c1c39eccc18babb5d.addTo(map_b7f9a41c4d0ec7c953b20c380d18fb9e);
#
#
#             var marker_cd0ca69bf9af3dc3d5e72e0f4fdf6d8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b7f9a41c4d0ec7c953b20c380d18fb9e);
#
#
#         var popup_fcda1719d180382f4cc6e7f584b67471 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4317f9a8d28abe4a47fa10d740efbfd = $(`&lt;div id=&quot;html_b4317f9a8d28abe4a47fa10d740efbfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fcda1719d180382f4cc6e7f584b67471.setContent(html_b4317f9a8d28abe4a47fa10d740efbfd);
#
#
#
#         marker_cd0ca69bf9af3dc3d5e72e0f4fdf6d8e.bindPopup(popup_fcda1719d180382f4cc6e7f584b67471)
#         ;
#
#
#
#
#             var marker_292f715ac0363d1a23d64ce7bb9d1a27 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b7f9a41c4d0ec7c953b20c380d18fb9e);
#
#
#         var popup_a57f089254bb48d13c3aa2306abca536 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91f62314539afab6151a211aad3e7311 = $(`&lt;div id=&quot;html_91f62314539afab6151a211aad3e7311&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a57f089254bb48d13c3aa2306abca536.setContent(html_91f62314539afab6151a211aad3e7311);
#
#
#
#         marker_292f715ac0363d1a23d64ce7bb9d1a27.bindPopup(popup_a57f089254bb48d13c3aa2306abca536)
#         ;
#
#
#
#
#             var marker_1f458ddf634ae578a26de0a238fc075f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b7f9a41c4d0ec7c953b20c380d18fb9e);
#
#
#         var popup_8a5720a52db46c51a19594e5b96195b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_697196c20cb8ada16c55b463fcfe45b8 = $(`&lt;div id=&quot;html_697196c20cb8ada16c55b463fcfe45b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8a5720a52db46c51a19594e5b96195b3.setContent(html_697196c20cb8ada16c55b463fcfe45b8);
#
#
#
#         marker_1f458ddf634ae578a26de0a238fc075f.bindPopup(popup_8a5720a52db46c51a19594e5b96195b3)
#         ;
#
#
#
#
#             var marker_5ab4f127f38973331d62e7bc9eb54d88 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b7f9a41c4d0ec7c953b20c380d18fb9e);
#
#
#         var popup_bef48510ed2d8918c7eeb6874c953589 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52431f82db5cf2d0f672e97ed9bcecd6 = $(`&lt;div id=&quot;html_52431f82db5cf2d0f672e97ed9bcecd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bef48510ed2d8918c7eeb6874c953589.setContent(html_52431f82db5cf2d0f672e97ed9bcecd6);
#
#
#
#         marker_5ab4f127f38973331d62e7bc9eb54d88.bindPopup(popup_bef48510ed2d8918c7eeb6874c953589)
#         ;
#
#
#
#
#             var marker_cc70e12c20bd03f1e2af7853aeefe508 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b7f9a41c4d0ec7c953b20c380d18fb9e);
#
#
#         var popup_19106b677d5b579a278bfd009d495ff8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68163b9d8999065f60592c62d9149391 = $(`&lt;div id=&quot;html_68163b9d8999065f60592c62d9149391&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_19106b677d5b579a278bfd009d495ff8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f4ce498c90781c93490df7a68874a8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f4ce498c90781c93490df7a68874a8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f4ce498c90781c93490df7a68874a8e = L.map(
#                 &quot;map_1f4ce498c90781c93490df7a68874a8e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4648b48e02e781ca9cea53d1ec5a7f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a4648b48e02e781ca9cea53d1ec5a7f1.addTo(map_1f4ce498c90781c93490df7a68874a8e);
#
#
#             var feature_group_3d843dba097961b00b16baac3dc9104f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_144b8cc693d4384d604888ba2c1792f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3d843dba097961b00b16baac3dc9104f);
#
#
#         var popup_18d18bed52d341de09156c4cc7df4cb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6461dae1badc5de9367f3291cbd5fed = $(`&lt;div id=&quot;html_c6461dae1badc5de9367f3291cbd5fed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_18d18bed52d341de09156c4cc7df4cb8.setContent(html_c6461dae1badc5de9367f3291cbd5fed);
#
#
#
#         marker_144b8cc693d4384d604888ba2c1792f4.bindPopup(popup_18d18bed52d341de09156c4cc7df4cb8)
#         ;
#
#
#
#
#             var marker_7b884e564adb91c4902a13305f65b7fd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3d843dba097961b00b16baac3dc9104f);
#
#
#         var popup_60c4fb5b5bc3c6061084ad9aa9e651b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_512c8c74471142cea5ed19a2d188c1b6 = $(`&lt;div id=&quot;html_512c8c74471142cea5ed19a2d188c1b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_60c4fb5b5bc3c6061084ad9aa9e651b8.setContent(html_512c8c74471142cea5ed19a2d188c1b6);
#
#
#
#         marker_7b884e564adb91c4902a13305f65b7fd.bindPopup(popup_60c4fb5b5bc3c6061084ad9aa9e651b8)
#         ;
#
#
#
#
#             var marker_ba96535afeba805948e280f0fa6ad0ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3d843dba097961b00b16baac3dc9104f);
#
#
#         var popup_7af6c337f89ea434c5ab1426fd6852bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21184e46cc8933ee7b9dd761fbae47cd = $(`&lt;div id=&quot;html_21184e46cc8933ee7b9dd761fbae47cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7af6c337f89ea434c5ab1426fd6852bb.setContent(html_21184e46cc8933ee7b9dd761fbae47cd);
#
#
#
#         marker_ba96535afeba805948e280f0fa6ad0ec.bindPopup(popup_7af6c337f89ea434c5ab1426fd6852bb)
#         ;
#
#
#
#
#             var marker_8fef5b27e4ceffabe584f8f34f11b1d8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3d843dba097961b00b16baac3dc9104f);
#
#
#         var popup_4ac9cee02a57f1f26fd383010affbc4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be8d040a2b3cd36f93c72d10d5faf198 = $(`&lt;div id=&quot;html_be8d040a2b3cd36f93c72d10d5faf198&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4ac9cee02a57f1f26fd383010affbc4c.setContent(html_be8d040a2b3cd36f93c72d10d5faf198);
#
#
#
#         marker_8fef5b27e4ceffabe584f8f34f11b1d8.bindPopup(popup_4ac9cee02a57f1f26fd383010affbc4c)
#         ;
#
#
#
#
#             var marker_15614431e353615e0e48715cd8d81829 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3d843dba097961b00b16baac3dc9104f);
#
#
#         var popup_ffe92fb576f7fb9fa66c3065add7bc29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f89486434e0f11a0b4542574fb9f9e3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f89486434e0f11a0b4542574fb9f9e3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f89486434e0f11a0b4542574fb9f9e3b = L.map(
#                 &quot;map_f89486434e0f11a0b4542574fb9f9e3b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f768d9ae86e044d730f48642da78391e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f768d9ae86e044d730f48642da78391e.addTo(map_f89486434e0f11a0b4542574fb9f9e3b);
#
#
#             var feature_group_2a34759bc5ac9a651c8196f2f03d5adf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2a34759bc5ac9a651c8196f2f03d5adf.addTo(map_f89486434e0f11a0b4542574fb9f9e3b);
#
#
#             var feature_group_sub_group_977cf93a87eddbb9a729703cacf734cd = L.featureGroup.subGroup(
#                 feature_group_2a34759bc5ac9a651c8196f2f03d5adf
#             );
#
#
#             var marker_696f63ef155b9e894c0a2024e6aeb8df = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_977cf93a87eddbb9a729703cacf734cd);
#
#
#         var popup_e278f24846d4f90366e3472f11581d8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_716073f9a477fe9c9d25bd4091f47e0d = $(`&lt;div id=&quot;html_716073f9a477fe9c9d25bd4091f47e0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e278f24846d4f90366e3472f11581d8c.setContent(html_716073f9a477fe9c9d25bd4091f47e0d);
#
#
#
#         marker_696f63ef155b9e894c0a2024e6aeb8df.bindPopup(popup_e278f24846d4f90366e3472f11581d8c)
#         ;
#
#
#
#
#             var marker_9f3c85c875b08c7c708cdc41702d3764 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_977cf93a87eddbb9a729703cacf734cd);
#
#
#         var popup_675ff85b87143e121f9dccc66904cbe9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7618fd5fe90a4582672e1aaedd43e568 = $(`&lt;div id=&quot;html_7618fd5fe90a4582672e1aaedd43e568&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_675ff85b87143e121f9dccc66904cbe9.setContent(html_7618fd5fe90a4582672e1aaedd43e568);
#
#
#
#         marker_9f3c85c875b08c7c708cdc41702d3764.bindPopup(popup_675ff85b87143e121f9dccc66904cbe9)
#         ;
#
#
#
#
#             var marker_1e4d772dd2e6eed4091bf35472a6aeb4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_977cf93a87eddbb9a729703cacf734cd);
#
#
#         var popup_60e3ed2da3353c76b4a71a24b358c56e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ace115341235c15071784fb64f0b8c2 = $(`&lt;div id=&quot;html_7ace115341235c15071784fb64f0b8c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_60e3ed2da3353c76b4a71a24b358c56e.setContent(html_7ace115341235c15071784fb64f0b8c2);
#
#
#
#         marker_1e4d772dd2e6eed4091bf35472a6aeb4.bindPopup(popup_60e3ed2da3353c76b4a71a24b358c56e)
#         ;
#
#
#
#
#             var marker_a576e3a56276671b0ad7b16003ce34d1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_977cf93a87eddbb9a729703cacf734cd);
#
#
#         var popup_0cc51679f6516d06de2d529c8dabcd29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9521279320e9ed228813c1c8c4ad71e = $(`&lt;div id=&quot;html_b9521279320e9ed228813c1c8c4ad71e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0cc51679f6516d06de2d529c8dabcd29.setContent(html_b9521279320e9ed228813c1c8c4ad71e);
#
#
#
#         marker_
