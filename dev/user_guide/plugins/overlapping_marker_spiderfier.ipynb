# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02e45aab24f13ea38d9b27b7c8b997cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02e45aab24f13ea38d9b27b7c8b997cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02e45aab24f13ea38d9b27b7c8b997cd = L.map(
#                 &quot;map_02e45aab24f13ea38d9b27b7c8b997cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d618d7cab676512e3cafb411db0c1ec1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d618d7cab676512e3cafb411db0c1ec1.addTo(map_02e45aab24f13ea38d9b27b7c8b997cd);
#
#
#             var marker_0e0fe2df470e5d970b2de10d917388c6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_02e45aab24f13ea38d9b27b7c8b997cd);
#
#
#         var popup_80be8ae3891617e34cabef8ce1d12601 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a730d3f2b61f7d3e8f079b5ce06726bf = $(`&lt;div id=&quot;html_a730d3f2b61f7d3e8f079b5ce06726bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_80be8ae3891617e34cabef8ce1d12601.setContent(html_a730d3f2b61f7d3e8f079b5ce06726bf);
#
#
#
#         marker_0e0fe2df470e5d970b2de10d917388c6.bindPopup(popup_80be8ae3891617e34cabef8ce1d12601)
#         ;
#
#
#
#
#             var marker_c5bebc2c8cde1777001ae23a628e7b65 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_02e45aab24f13ea38d9b27b7c8b997cd);
#
#
#         var popup_3d793850459d0f61a11efd8cbc2d6e71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8001a06e34a22daf033d20c27d2e38f7 = $(`&lt;div id=&quot;html_8001a06e34a22daf033d20c27d2e38f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3d793850459d0f61a11efd8cbc2d6e71.setContent(html_8001a06e34a22daf033d20c27d2e38f7);
#
#
#
#         marker_c5bebc2c8cde1777001ae23a628e7b65.bindPopup(popup_3d793850459d0f61a11efd8cbc2d6e71)
#         ;
#
#
#
#
#             var marker_09d8f66326aed3602786fc841e2127db = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_02e45aab24f13ea38d9b27b7c8b997cd);
#
#
#         var popup_5da91b9626f382a323e6a33198487d32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49c76dda34fa866a460173367e3bc436 = $(`&lt;div id=&quot;html_49c76dda34fa866a460173367e3bc436&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5da91b9626f382a323e6a33198487d32.setContent(html_49c76dda34fa866a460173367e3bc436);
#
#
#
#         marker_09d8f66326aed3602786fc841e2127db.bindPopup(popup_5da91b9626f382a323e6a33198487d32)
#         ;
#
#
#
#
#             var marker_7935447a302c9ae721697091d7ce2669 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_02e45aab24f13ea38d9b27b7c8b997cd);
#
#
#         var popup_15d44fbc6d581d498bf08ddcb7423799 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7b82424a85a93992105db4610ae4275 = $(`&lt;div id=&quot;html_b7b82424a85a93992105db4610ae4275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_15d44fbc6d581d498bf08ddcb7423799.setContent(html_b7b82424a85a93992105db4610ae4275);
#
#
#
#         marker_7935447a302c9ae721697091d7ce2669.bindPopup(popup_15d44fbc6d581d498bf08ddcb7423799)
#         ;
#
#
#
#
#             var marker_f40731fbfd722bcf71b8877be4e7b83b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_02e45aab24f13ea38d9b27b7c8b997cd);
#
#
#         var popup_ecdb86d2f9f5f43ce0cd0c2560f0a819 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_071f3649c758cdeee767a5d0185ff31f = $(`&lt;div id=&quot;html_071f3649c758cdeee767a5d0185ff31f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ecdb86d2f9f5f43ce0cd0c2560f0a819.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cbb67ebb5bf65a694c325bf1d1cbf60 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cbb67ebb5bf65a694c325bf1d1cbf60&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cbb67ebb5bf65a694c325bf1d1cbf60 = L.map(
#                 &quot;map_0cbb67ebb5bf65a694c325bf1d1cbf60&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ffac4fb431794dec7559f2f6b8245d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ffac4fb431794dec7559f2f6b8245d3.addTo(map_0cbb67ebb5bf65a694c325bf1d1cbf60);
#
#
#             var feature_group_7b49e9c47ecb26bc2ec60049cb8d0a91 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8f8be66c320dbba3223070470953301c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7b49e9c47ecb26bc2ec60049cb8d0a91);
#
#
#         var popup_d91ca017fb52442dab26617b4327bc14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1ee34667037c4c5c84e69a7c372fce2 = $(`&lt;div id=&quot;html_b1ee34667037c4c5c84e69a7c372fce2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d91ca017fb52442dab26617b4327bc14.setContent(html_b1ee34667037c4c5c84e69a7c372fce2);
#
#
#
#         marker_8f8be66c320dbba3223070470953301c.bindPopup(popup_d91ca017fb52442dab26617b4327bc14)
#         ;
#
#
#
#
#             var marker_4b7da61b77193c8f134e4d7a317b2b4f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7b49e9c47ecb26bc2ec60049cb8d0a91);
#
#
#         var popup_d2052c0ce680b36a41107e8cf89949f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71ba98a9d67f2ff51150d0ba1d10ebe6 = $(`&lt;div id=&quot;html_71ba98a9d67f2ff51150d0ba1d10ebe6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d2052c0ce680b36a41107e8cf89949f9.setContent(html_71ba98a9d67f2ff51150d0ba1d10ebe6);
#
#
#
#         marker_4b7da61b77193c8f134e4d7a317b2b4f.bindPopup(popup_d2052c0ce680b36a41107e8cf89949f9)
#         ;
#
#
#
#
#             var marker_7ddee5715ff2ab6bd59f3655b473c46b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7b49e9c47ecb26bc2ec60049cb8d0a91);
#
#
#         var popup_40a28e6f47de2e7c614c5317549baa97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31b8c7ca1a06ee212c843f4da22834d0 = $(`&lt;div id=&quot;html_31b8c7ca1a06ee212c843f4da22834d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_40a28e6f47de2e7c614c5317549baa97.setContent(html_31b8c7ca1a06ee212c843f4da22834d0);
#
#
#
#         marker_7ddee5715ff2ab6bd59f3655b473c46b.bindPopup(popup_40a28e6f47de2e7c614c5317549baa97)
#         ;
#
#
#
#
#             var marker_59dfa87fb8ac65f2f4b159a020dd894f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7b49e9c47ecb26bc2ec60049cb8d0a91);
#
#
#         var popup_aae6f9a1c15e0a896f1f4f21e2eba300 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b22b7d1373276eb2e800cd59bd40d14 = $(`&lt;div id=&quot;html_4b22b7d1373276eb2e800cd59bd40d14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_aae6f9a1c15e0a896f1f4f21e2eba300.setContent(html_4b22b7d1373276eb2e800cd59bd40d14);
#
#
#
#         marker_59dfa87fb8ac65f2f4b159a020dd894f.bindPopup(popup_aae6f9a1c15e0a896f1f4f21e2eba300)
#         ;
#
#
#
#
#             var marker_046f718e99744f83e7cce33f7d707011 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7b49e9c47ecb26bc2ec60049cb8d0a91);
#
#
#         var popup_0d43bbe929f36fe5a3779fe128d7d3fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_affeac4d22b1a7e978a7fd6fcb5ac8d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_affeac4d22b1a7e978a7fd6fcb5ac8d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_affeac4d22b1a7e978a7fd6fcb5ac8d1 = L.map(
#                 &quot;map_affeac4d22b1a7e978a7fd6fcb5ac8d1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c8873c7e70fa6875357c4a8c60a78d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5c8873c7e70fa6875357c4a8c60a78d1.addTo(map_affeac4d22b1a7e978a7fd6fcb5ac8d1);
#
#
#             var feature_group_9066de1ae920462ea431d9832ad332e3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9066de1ae920462ea431d9832ad332e3.addTo(map_affeac4d22b1a7e978a7fd6fcb5ac8d1);
#
#
#             var feature_group_sub_group_50a32891ee5dfccb91d9708ac43d1f95 = L.featureGroup.subGroup(
#                 feature_group_9066de1ae920462ea431d9832ad332e3
#             );
#
#
#             var marker_bbe2439b6041d39336f0814fe0d3e9e6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_50a32891ee5dfccb91d9708ac43d1f95);
#
#
#         var popup_3ec60a6fff9e37fc6b418cef88d6331c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96a90d951eee753dff29f80d71ef04f3 = $(`&lt;div id=&quot;html_96a90d951eee753dff29f80d71ef04f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3ec60a6fff9e37fc6b418cef88d6331c.setContent(html_96a90d951eee753dff29f80d71ef04f3);
#
#
#
#         marker_bbe2439b6041d39336f0814fe0d3e9e6.bindPopup(popup_3ec60a6fff9e37fc6b418cef88d6331c)
#         ;
#
#
#
#
#             var marker_bb484df9480739d1c9d389b87f041321 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_50a32891ee5dfccb91d9708ac43d1f95);
#
#
#         var popup_89b2f43fd2999fc8d20ab26172109162 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e2bf93a0f7436e2100b54e1faaa907d = $(`&lt;div id=&quot;html_5e2bf93a0f7436e2100b54e1faaa907d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_89b2f43fd2999fc8d20ab26172109162.setContent(html_5e2bf93a0f7436e2100b54e1faaa907d);
#
#
#
#         marker_bb484df9480739d1c9d389b87f041321.bindPopup(popup_89b2f43fd2999fc8d20ab26172109162)
#         ;
#
#
#
#
#             var marker_51ea7b6e1d7ee31ea4b25b32d3f6dd0f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_50a32891ee5dfccb91d9708ac43d1f95);
#
#
#         var popup_4817db8c6f9479098c828d5519a5b71a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5077ccb902d9501b735174058055fba = $(`&lt;div id=&quot;html_c5077ccb902d9501b735174058055fba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4817db8c6f9479098c828d5519a5b71a.setContent(html_c5077ccb902d9501b735174058055fba);
#
#
#
#         marker_51ea7b6e1d7ee31ea4b25b32d3f6dd0f.bindPopup(popup_4817db8c6f9479098c828d5519a5b71a)
#         ;
#
#
#
#
#             var marker_71d38b945793f309c1b210d14298c1a8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_50a32891ee5dfccb91d9708ac43d1f95);
#
#
#         var popup_5421ef950ab455b3cc777f376207c8cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c99b5d5570ac402cee09d27f7ba10cfd = $(`&lt;div id=&quot;html_c99b5d5570ac402cee09d27f7ba10cfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5421ef950ab455b3cc777f376207c8cd.setContent(html_c99b5d5570ac402cee09d27f7ba10cfd);
#
#
#
#         marker_
