# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ec3170cc465d271b3f47eaf664bc4815 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ec3170cc465d271b3f47eaf664bc4815&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ec3170cc465d271b3f47eaf664bc4815 = L.map(
#                 &quot;map_ec3170cc465d271b3f47eaf664bc4815&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b533b431150d9774fdb5f3dc036032cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b533b431150d9774fdb5f3dc036032cb.addTo(map_ec3170cc465d271b3f47eaf664bc4815);
#
#
#             var marker_af412e7038ef7bbed09ed5e1fbbd264d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ec3170cc465d271b3f47eaf664bc4815);
#
#
#         var popup_68485d4ef122ea02bc6e1d4d0d29731d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cadf3efa62eead14ef5edaf76b89c015 = $(`&lt;div id=&quot;html_cadf3efa62eead14ef5edaf76b89c015&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_68485d4ef122ea02bc6e1d4d0d29731d.setContent(html_cadf3efa62eead14ef5edaf76b89c015);
#
#
#
#         marker_af412e7038ef7bbed09ed5e1fbbd264d.bindPopup(popup_68485d4ef122ea02bc6e1d4d0d29731d)
#         ;
#
#
#
#
#             var marker_dbbb26cd2449edb008db3a1ba14ca2b4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ec3170cc465d271b3f47eaf664bc4815);
#
#
#         var popup_00971c7e550c51e85c4962ae0b7420a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36b709ba48ccf59b39dbdb768ca00e32 = $(`&lt;div id=&quot;html_36b709ba48ccf59b39dbdb768ca00e32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_00971c7e550c51e85c4962ae0b7420a3.setContent(html_36b709ba48ccf59b39dbdb768ca00e32);
#
#
#
#         marker_dbbb26cd2449edb008db3a1ba14ca2b4.bindPopup(popup_00971c7e550c51e85c4962ae0b7420a3)
#         ;
#
#
#
#
#             var marker_92222e6b50c20da9c615d63744b6e6cc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ec3170cc465d271b3f47eaf664bc4815);
#
#
#         var popup_1678e096fb29ca039d35068f79955dfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_841ffa007eed3bf4295ea9afadbe76a3 = $(`&lt;div id=&quot;html_841ffa007eed3bf4295ea9afadbe76a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1678e096fb29ca039d35068f79955dfc.setContent(html_841ffa007eed3bf4295ea9afadbe76a3);
#
#
#
#         marker_92222e6b50c20da9c615d63744b6e6cc.bindPopup(popup_1678e096fb29ca039d35068f79955dfc)
#         ;
#
#
#
#
#             var marker_fdd4facd80880caeef7a8d9b5192c1ae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ec3170cc465d271b3f47eaf664bc4815);
#
#
#         var popup_c204ad6bd9e911a8f37fd29a82a8ce20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e99b366fdcd90fa2b28fc0e80de0fa66 = $(`&lt;div id=&quot;html_e99b366fdcd90fa2b28fc0e80de0fa66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c204ad6bd9e911a8f37fd29a82a8ce20.setContent(html_e99b366fdcd90fa2b28fc0e80de0fa66);
#
#
#
#         marker_fdd4facd80880caeef7a8d9b5192c1ae.bindPopup(popup_c204ad6bd9e911a8f37fd29a82a8ce20)
#         ;
#
#
#
#
#             var marker_72e8f581231d11b20f1de39b965953a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ec3170cc465d271b3f47eaf664bc4815);
#
#
#         var popup_ce55476a72f8d0bea9ac40c5c6a7b387 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c12976609af1f9b4528b01b2b24e4d12 = $(`&lt;div id=&quot;html_c12976609af1f9b4528b01b2b24e4d12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ce55476a72f8d0bea9ac40c5c6a7b387.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a378352eb553a7a656428f7c4222f238 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a378352eb553a7a656428f7c4222f238&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a378352eb553a7a656428f7c4222f238 = L.map(
#                 &quot;map_a378352eb553a7a656428f7c4222f238&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b06af661ed5a0d47efeffa3e9da80eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b06af661ed5a0d47efeffa3e9da80eb.addTo(map_a378352eb553a7a656428f7c4222f238);
#
#
#             var feature_group_103acdf152285594ed21a65c71135f65 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a0dc098c1b4318688a0db39055b63a11 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_103acdf152285594ed21a65c71135f65);
#
#
#         var popup_12918f213fc7234f4d6b6bbc47ca617b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb630aae5a58776a0b5af3e9652b2d60 = $(`&lt;div id=&quot;html_eb630aae5a58776a0b5af3e9652b2d60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_12918f213fc7234f4d6b6bbc47ca617b.setContent(html_eb630aae5a58776a0b5af3e9652b2d60);
#
#
#
#         marker_a0dc098c1b4318688a0db39055b63a11.bindPopup(popup_12918f213fc7234f4d6b6bbc47ca617b)
#         ;
#
#
#
#
#             var marker_10c747a74b1485f6f487cd70afc0c44f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_103acdf152285594ed21a65c71135f65);
#
#
#         var popup_3e4a1807c30e0f3299e5e2af6a926505 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c78d2db47e53683f238e712eeea654eb = $(`&lt;div id=&quot;html_c78d2db47e53683f238e712eeea654eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3e4a1807c30e0f3299e5e2af6a926505.setContent(html_c78d2db47e53683f238e712eeea654eb);
#
#
#
#         marker_10c747a74b1485f6f487cd70afc0c44f.bindPopup(popup_3e4a1807c30e0f3299e5e2af6a926505)
#         ;
#
#
#
#
#             var marker_4b415ee1680f7761c830d47947066b08 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_103acdf152285594ed21a65c71135f65);
#
#
#         var popup_c869f1c97cb63e615a28fcfe56b5a46a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53ee02ebc59bda9580a911586363b3fc = $(`&lt;div id=&quot;html_53ee02ebc59bda9580a911586363b3fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c869f1c97cb63e615a28fcfe56b5a46a.setContent(html_53ee02ebc59bda9580a911586363b3fc);
#
#
#
#         marker_4b415ee1680f7761c830d47947066b08.bindPopup(popup_c869f1c97cb63e615a28fcfe56b5a46a)
#         ;
#
#
#
#
#             var marker_a3e4e5bc32c09d86ff0c36946f47ca3d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_103acdf152285594ed21a65c71135f65);
#
#
#         var popup_716a947cb6d3e0c8dcda57ad4ac5e44d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07037fe9b5d6b455d3572904b3a6082c = $(`&lt;div id=&quot;html_07037fe9b5d6b455d3572904b3a6082c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_716a947cb6d3e0c8dcda57ad4ac5e44d.setContent(html_07037fe9b5d6b455d3572904b3a6082c);
#
#
#
#         marker_a3e4e5bc32c09d86ff0c36946f47ca3d.bindPopup(popup_716a947cb6d3e0c8dcda57ad4ac5e44d)
#         ;
#
#
#
#
#             var marker_a0f58faf6b4142fe79121874ad05728b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_103acdf152285594ed21a65c71135f65);
#
#
#         var popup_cd84c9bed197e0803d7c502427757e31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9e13d4de6cac3fafdd6288de17c63a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9e13d4de6cac3fafdd6288de17c63a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9e13d4de6cac3fafdd6288de17c63a8 = L.map(
#                 &quot;map_f9e13d4de6cac3fafdd6288de17c63a8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78498858eb3ffa7913744b4bc50819d3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78498858eb3ffa7913744b4bc50819d3.addTo(map_f9e13d4de6cac3fafdd6288de17c63a8);
#
#
#             var feature_group_1185b4963e0f4e89ae263632fccc63f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1185b4963e0f4e89ae263632fccc63f1.addTo(map_f9e13d4de6cac3fafdd6288de17c63a8);
#
#
#             var feature_group_sub_group_42af6c31d67900a13a2128d87cebf313 = L.featureGroup.subGroup(
#                 feature_group_1185b4963e0f4e89ae263632fccc63f1
#             );
#
#
#             var marker_99352293cc1f934d197731f33021938f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_42af6c31d67900a13a2128d87cebf313);
#
#
#         var popup_63604b75ac0a8e29f6fc56ad28dc9bf1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94b612cbe199784c4a49905df5905cf8 = $(`&lt;div id=&quot;html_94b612cbe199784c4a49905df5905cf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_63604b75ac0a8e29f6fc56ad28dc9bf1.setContent(html_94b612cbe199784c4a49905df5905cf8);
#
#
#
#         marker_99352293cc1f934d197731f33021938f.bindPopup(popup_63604b75ac0a8e29f6fc56ad28dc9bf1)
#         ;
#
#
#
#
#             var marker_7796343eff26312cf7effd876cff2871 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_42af6c31d67900a13a2128d87cebf313);
#
#
#         var popup_f6a2f4b49c9abb873f6128b6e9c55052 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23d3e543fd156fb176862713afd21d3a = $(`&lt;div id=&quot;html_23d3e543fd156fb176862713afd21d3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f6a2f4b49c9abb873f6128b6e9c55052.setContent(html_23d3e543fd156fb176862713afd21d3a);
#
#
#
#         marker_7796343eff26312cf7effd876cff2871.bindPopup(popup_f6a2f4b49c9abb873f6128b6e9c55052)
#         ;
#
#
#
#
#             var marker_c647e51013ac5a1204cc5ac3f0be485d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_42af6c31d67900a13a2128d87cebf313);
#
#
#         var popup_06b378a4e55cf7e6d61107cf332bcd2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca37faf304eba3d82c14db27798726ca = $(`&lt;div id=&quot;html_ca37faf304eba3d82c14db27798726ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_06b378a4e55cf7e6d61107cf332bcd2b.setContent(html_ca37faf304eba3d82c14db27798726ca);
#
#
#
#         marker_c647e51013ac5a1204cc5ac3f0be485d.bindPopup(popup_06b378a4e55cf7e6d61107cf332bcd2b)
#         ;
#
#
#
#
#             var marker_aaf6c38408716f6dc3456d4f265e1bbc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_42af6c31d67900a13a2128d87cebf313);
#
#
#         var popup_41766857f976db6babf86d299330289d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1cd873c94128d1dddc3f41ba29851c0 = $(`&lt;div id=&quot;html_f1cd873c94128d1dddc3f41ba29851c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_41766857f976db6babf86d299330289d.setContent(html_f1cd873c94128d1dddc3f41ba29851c0);
#
#
#
#         marker_
