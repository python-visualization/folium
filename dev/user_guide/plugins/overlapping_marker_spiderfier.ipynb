# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2e6324806b9b40be489abc0860e2263 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2e6324806b9b40be489abc0860e2263&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2e6324806b9b40be489abc0860e2263 = L.map(
#                 &quot;map_c2e6324806b9b40be489abc0860e2263&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7466c8f19defce8fccd44dd8d39e91d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7466c8f19defce8fccd44dd8d39e91d7.addTo(map_c2e6324806b9b40be489abc0860e2263);
#
#
#             var marker_a8012d79e0f239fd5e5000258e00bdaa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c2e6324806b9b40be489abc0860e2263);
#
#
#         var popup_73f8bd6d9879f5266bbbf64e74c97a16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_446730473842a6d8a424d9a1aeb88a63 = $(`&lt;div id=&quot;html_446730473842a6d8a424d9a1aeb88a63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_73f8bd6d9879f5266bbbf64e74c97a16.setContent(html_446730473842a6d8a424d9a1aeb88a63);
#
#
#
#         marker_a8012d79e0f239fd5e5000258e00bdaa.bindPopup(popup_73f8bd6d9879f5266bbbf64e74c97a16)
#         ;
#
#
#
#
#             var marker_dc1bd464298914cb4dfd266c04a1c0e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c2e6324806b9b40be489abc0860e2263);
#
#
#         var popup_4237921f1d36a5cae5899895f9ce5bae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf132bc14268f0b4598adf1d9e876995 = $(`&lt;div id=&quot;html_cf132bc14268f0b4598adf1d9e876995&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4237921f1d36a5cae5899895f9ce5bae.setContent(html_cf132bc14268f0b4598adf1d9e876995);
#
#
#
#         marker_dc1bd464298914cb4dfd266c04a1c0e8.bindPopup(popup_4237921f1d36a5cae5899895f9ce5bae)
#         ;
#
#
#
#
#             var marker_177c3516df44782a783740e6e86cd07e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c2e6324806b9b40be489abc0860e2263);
#
#
#         var popup_ecb6441dd6feac9776c419ef645de3af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff2a13dbab24a1252744543480225bfc = $(`&lt;div id=&quot;html_ff2a13dbab24a1252744543480225bfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ecb6441dd6feac9776c419ef645de3af.setContent(html_ff2a13dbab24a1252744543480225bfc);
#
#
#
#         marker_177c3516df44782a783740e6e86cd07e.bindPopup(popup_ecb6441dd6feac9776c419ef645de3af)
#         ;
#
#
#
#
#             var marker_108c3eee1597493c97182f7cfd3e88c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c2e6324806b9b40be489abc0860e2263);
#
#
#         var popup_c44bff1c84d7488e68e87dde115ec7f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33f2bde999b3fbdc65f66404f9497753 = $(`&lt;div id=&quot;html_33f2bde999b3fbdc65f66404f9497753&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c44bff1c84d7488e68e87dde115ec7f4.setContent(html_33f2bde999b3fbdc65f66404f9497753);
#
#
#
#         marker_108c3eee1597493c97182f7cfd3e88c4.bindPopup(popup_c44bff1c84d7488e68e87dde115ec7f4)
#         ;
#
#
#
#
#             var marker_732d15d6ebb958538a29919df8ecde05 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c2e6324806b9b40be489abc0860e2263);
#
#
#         var popup_2ff8a91858270004e8eee36722fc5a12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b8a320f0940496308d7a02491624245 = $(`&lt;div id=&quot;html_7b8a320f0940496308d7a02491624245&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2ff8a91858270004e8eee36722fc5a12.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_45991d8fab9ec3c809ded05a6b9ba6ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_45991d8fab9ec3c809ded05a6b9ba6ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_45991d8fab9ec3c809ded05a6b9ba6ee = L.map(
#                 &quot;map_45991d8fab9ec3c809ded05a6b9ba6ee&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_306113bd331df3647d26366443d5dd2f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_306113bd331df3647d26366443d5dd2f.addTo(map_45991d8fab9ec3c809ded05a6b9ba6ee);
#
#
#             var feature_group_c9ad4710d2d679482095b1a223d4f821 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_234a4602e14849a8b1bd8b55375cba74 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c9ad4710d2d679482095b1a223d4f821);
#
#
#         var popup_b4695245207e9e4731affd895c818666 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75e7a92859d6230822a0583ea1543e85 = $(`&lt;div id=&quot;html_75e7a92859d6230822a0583ea1543e85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b4695245207e9e4731affd895c818666.setContent(html_75e7a92859d6230822a0583ea1543e85);
#
#
#
#         marker_234a4602e14849a8b1bd8b55375cba74.bindPopup(popup_b4695245207e9e4731affd895c818666)
#         ;
#
#
#
#
#             var marker_959ac76d8c037d889521979772f9385e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c9ad4710d2d679482095b1a223d4f821);
#
#
#         var popup_97cc4cf7c75968f60b313ea87dc30b1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f777a89711fc7d7465c86ded4136987 = $(`&lt;div id=&quot;html_4f777a89711fc7d7465c86ded4136987&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_97cc4cf7c75968f60b313ea87dc30b1e.setContent(html_4f777a89711fc7d7465c86ded4136987);
#
#
#
#         marker_959ac76d8c037d889521979772f9385e.bindPopup(popup_97cc4cf7c75968f60b313ea87dc30b1e)
#         ;
#
#
#
#
#             var marker_77b7783f290f24520f168e6825fbecd5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c9ad4710d2d679482095b1a223d4f821);
#
#
#         var popup_7def03659ce62ad63fd9aca9d1cab2b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6e0ea38a8d97261341e04dfbc1f3e62 = $(`&lt;div id=&quot;html_f6e0ea38a8d97261341e04dfbc1f3e62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7def03659ce62ad63fd9aca9d1cab2b2.setContent(html_f6e0ea38a8d97261341e04dfbc1f3e62);
#
#
#
#         marker_77b7783f290f24520f168e6825fbecd5.bindPopup(popup_7def03659ce62ad63fd9aca9d1cab2b2)
#         ;
#
#
#
#
#             var marker_74b6137a2db5e642e7668ebc10625a6c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c9ad4710d2d679482095b1a223d4f821);
#
#
#         var popup_20d0127c971e8f6acd852a9857bea217 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96e9a8d80c801efd49b9d2b9e82e18d8 = $(`&lt;div id=&quot;html_96e9a8d80c801efd49b9d2b9e82e18d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_20d0127c971e8f6acd852a9857bea217.setContent(html_96e9a8d80c801efd49b9d2b9e82e18d8);
#
#
#
#         marker_74b6137a2db5e642e7668ebc10625a6c.bindPopup(popup_20d0127c971e8f6acd852a9857bea217)
#         ;
#
#
#
#
#             var marker_9b7052c180b1f4f0566c8a6c57a09e04 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c9ad4710d2d679482095b1a223d4f821);
#
#
#         var popup_0077913fe2a01212a6b990e805f04864 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_424f730e50587f27dc39d4a91915c3bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_424f730e50587f27dc39d4a91915c3bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_424f730e50587f27dc39d4a91915c3bb = L.map(
#                 &quot;map_424f730e50587f27dc39d4a91915c3bb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b09b198660f12f2f505dc39beb47b3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b09b198660f12f2f505dc39beb47b3b.addTo(map_424f730e50587f27dc39d4a91915c3bb);
#
#
#             var feature_group_a150b985d2f065381187e90bd9fd99aa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a150b985d2f065381187e90bd9fd99aa.addTo(map_424f730e50587f27dc39d4a91915c3bb);
#
#
#             var feature_group_sub_group_a3639a37e553ef83c9aef31195df6199 = L.featureGroup.subGroup(
#                 feature_group_a150b985d2f065381187e90bd9fd99aa
#             );
#
#
#             var marker_40ed88c65472629a87e55d2013649d36 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3639a37e553ef83c9aef31195df6199);
#
#
#         var popup_be9139aa295df7a4ce4902809197e10d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a35a2218f49c68f953ab95306b4734ca = $(`&lt;div id=&quot;html_a35a2218f49c68f953ab95306b4734ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_be9139aa295df7a4ce4902809197e10d.setContent(html_a35a2218f49c68f953ab95306b4734ca);
#
#
#
#         marker_40ed88c65472629a87e55d2013649d36.bindPopup(popup_be9139aa295df7a4ce4902809197e10d)
#         ;
#
#
#
#
#             var marker_3df9e52c7bb51ce45e63b3e50d83b4c2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3639a37e553ef83c9aef31195df6199);
#
#
#         var popup_188744920606dd0762e044cefe419b58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51713c4455824f078bbf02f46b593ddf = $(`&lt;div id=&quot;html_51713c4455824f078bbf02f46b593ddf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_188744920606dd0762e044cefe419b58.setContent(html_51713c4455824f078bbf02f46b593ddf);
#
#
#
#         marker_3df9e52c7bb51ce45e63b3e50d83b4c2.bindPopup(popup_188744920606dd0762e044cefe419b58)
#         ;
#
#
#
#
#             var marker_bb9141e55221df047ee1bbbdc74f96fb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3639a37e553ef83c9aef31195df6199);
#
#
#         var popup_ac2210251ad9ad9e40536e7446f99176 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62ea9e5fc847b1a52f0849017472c518 = $(`&lt;div id=&quot;html_62ea9e5fc847b1a52f0849017472c518&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ac2210251ad9ad9e40536e7446f99176.setContent(html_62ea9e5fc847b1a52f0849017472c518);
#
#
#
#         marker_bb9141e55221df047ee1bbbdc74f96fb.bindPopup(popup_ac2210251ad9ad9e40536e7446f99176)
#         ;
#
#
#
#
#             var marker_6622d3fe0c2c651acdefe7a8ab75559f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3639a37e553ef83c9aef31195df6199);
#
#
#         var popup_4c949fbf34b174b535311a51e2ea67f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fab2b77d843f530bdb23fe381a048ca = $(`&lt;div id=&quot;html_3fab2b77d843f530bdb23fe381a048ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4c949fbf34b174b535311a51e2ea67f9.setContent(html_3fab2b77d843f530bdb23fe381a048ca);
#
#
#
#         marker_
