# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9dd459845be26e01c4362f84b58d984 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9dd459845be26e01c4362f84b58d984&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9dd459845be26e01c4362f84b58d984 = L.map(
#                 &quot;map_a9dd459845be26e01c4362f84b58d984&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_254420ae171ec4521f40eab8372b397f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_254420ae171ec4521f40eab8372b397f.addTo(map_a9dd459845be26e01c4362f84b58d984);
#
#
#             var marker_acbe8766e5dd90ae26a31524e43412ab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a9dd459845be26e01c4362f84b58d984);
#
#
#         var popup_1b95c590aa1967e11706a1a3d4240d23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ddb364b39fef9e19da5edcfc63bc66e = $(`&lt;div id=&quot;html_5ddb364b39fef9e19da5edcfc63bc66e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1b95c590aa1967e11706a1a3d4240d23.setContent(html_5ddb364b39fef9e19da5edcfc63bc66e);
#
#
#
#         marker_acbe8766e5dd90ae26a31524e43412ab.bindPopup(popup_1b95c590aa1967e11706a1a3d4240d23)
#         ;
#
#
#
#
#             var marker_3550b2a3804af54c8981fd5902bc51d2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a9dd459845be26e01c4362f84b58d984);
#
#
#         var popup_8092f806dea333736261c5db0508b16b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31ab4e4bdce5d3ea7a49b8d2dfc7a3c2 = $(`&lt;div id=&quot;html_31ab4e4bdce5d3ea7a49b8d2dfc7a3c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8092f806dea333736261c5db0508b16b.setContent(html_31ab4e4bdce5d3ea7a49b8d2dfc7a3c2);
#
#
#
#         marker_3550b2a3804af54c8981fd5902bc51d2.bindPopup(popup_8092f806dea333736261c5db0508b16b)
#         ;
#
#
#
#
#             var marker_0a69e4d3b8b6af1a72836b2396eda423 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a9dd459845be26e01c4362f84b58d984);
#
#
#         var popup_a326dd918bee01ab151981e02a11e051 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b8e4ad9609f94c74ed12143beab7f30 = $(`&lt;div id=&quot;html_4b8e4ad9609f94c74ed12143beab7f30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a326dd918bee01ab151981e02a11e051.setContent(html_4b8e4ad9609f94c74ed12143beab7f30);
#
#
#
#         marker_0a69e4d3b8b6af1a72836b2396eda423.bindPopup(popup_a326dd918bee01ab151981e02a11e051)
#         ;
#
#
#
#
#             var marker_b9f25d3d8a1459cdc93f5ad597c60470 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a9dd459845be26e01c4362f84b58d984);
#
#
#         var popup_93b560e5fcf7b1a1a6f27f31dd5430dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8564ad8790053bd3cdcbec23b0ef7a3b = $(`&lt;div id=&quot;html_8564ad8790053bd3cdcbec23b0ef7a3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_93b560e5fcf7b1a1a6f27f31dd5430dd.setContent(html_8564ad8790053bd3cdcbec23b0ef7a3b);
#
#
#
#         marker_b9f25d3d8a1459cdc93f5ad597c60470.bindPopup(popup_93b560e5fcf7b1a1a6f27f31dd5430dd)
#         ;
#
#
#
#
#             var marker_6b56a806bf94d23fcb0fbd94c0389863 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a9dd459845be26e01c4362f84b58d984);
#
#
#         var popup_4657410c7fb27867a8ec2047f8030810 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_807d99c6907b80bce25247fbb6d568c4 = $(`&lt;div id=&quot;html_807d99c6907b80bce25247fbb6d568c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4657410c7fb27867a8ec2047f8030810.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d270d11fd518e2557605fcec0e21a99 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d270d11fd518e2557605fcec0e21a99&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d270d11fd518e2557605fcec0e21a99 = L.map(
#                 &quot;map_5d270d11fd518e2557605fcec0e21a99&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1e0c8a735599010703495e1ac7c67fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d1e0c8a735599010703495e1ac7c67fb.addTo(map_5d270d11fd518e2557605fcec0e21a99);
#
#
#             var feature_group_f64570e123ac8e4d2c449eb7a8c98b07 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_920a6c980244279fb0b53e75dace2871 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f64570e123ac8e4d2c449eb7a8c98b07);
#
#
#         var popup_3917e300c91c8fdb965db8fa6a863122 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adeb200f060299bf3c2bdcf988c86e28 = $(`&lt;div id=&quot;html_adeb200f060299bf3c2bdcf988c86e28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3917e300c91c8fdb965db8fa6a863122.setContent(html_adeb200f060299bf3c2bdcf988c86e28);
#
#
#
#         marker_920a6c980244279fb0b53e75dace2871.bindPopup(popup_3917e300c91c8fdb965db8fa6a863122)
#         ;
#
#
#
#
#             var marker_09018c312e6d657d5272914d4f735bc7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f64570e123ac8e4d2c449eb7a8c98b07);
#
#
#         var popup_332f177c5feae5cd38014f81a14511a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9870f598cdd928d76e6cca2bf2891604 = $(`&lt;div id=&quot;html_9870f598cdd928d76e6cca2bf2891604&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_332f177c5feae5cd38014f81a14511a8.setContent(html_9870f598cdd928d76e6cca2bf2891604);
#
#
#
#         marker_09018c312e6d657d5272914d4f735bc7.bindPopup(popup_332f177c5feae5cd38014f81a14511a8)
#         ;
#
#
#
#
#             var marker_ce2f677be674aea2ce7a16517d9b3cb5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f64570e123ac8e4d2c449eb7a8c98b07);
#
#
#         var popup_64a2c28e695b31e0daccc9dea7af9ff1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16ea896bb01d7d53241fc6053b51ec9e = $(`&lt;div id=&quot;html_16ea896bb01d7d53241fc6053b51ec9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_64a2c28e695b31e0daccc9dea7af9ff1.setContent(html_16ea896bb01d7d53241fc6053b51ec9e);
#
#
#
#         marker_ce2f677be674aea2ce7a16517d9b3cb5.bindPopup(popup_64a2c28e695b31e0daccc9dea7af9ff1)
#         ;
#
#
#
#
#             var marker_0c116c244e42083ffd587d913f05ff76 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f64570e123ac8e4d2c449eb7a8c98b07);
#
#
#         var popup_60fe833853712ae117b71b63b2f55544 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ccd2989f991893642e8d1a940488870 = $(`&lt;div id=&quot;html_5ccd2989f991893642e8d1a940488870&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_60fe833853712ae117b71b63b2f55544.setContent(html_5ccd2989f991893642e8d1a940488870);
#
#
#
#         marker_0c116c244e42083ffd587d913f05ff76.bindPopup(popup_60fe833853712ae117b71b63b2f55544)
#         ;
#
#
#
#
#             var marker_f4947f43c42f2849e8ca9e4a57ee42bc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f64570e123ac8e4d2c449eb7a8c98b07);
#
#
#         var popup_d3123c5db2d766a2a69e8d850a36c323 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39b642946da64511eea79cdaaebb4110 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39b642946da64511eea79cdaaebb4110&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39b642946da64511eea79cdaaebb4110 = L.map(
#                 &quot;map_39b642946da64511eea79cdaaebb4110&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27f145d261f280ae45afd1000b295e87 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27f145d261f280ae45afd1000b295e87.addTo(map_39b642946da64511eea79cdaaebb4110);
#
#
#             var feature_group_83254520adc7ab786ea2d9c3e3acaead = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_83254520adc7ab786ea2d9c3e3acaead.addTo(map_39b642946da64511eea79cdaaebb4110);
#
#
#             var feature_group_sub_group_dd58e8eb405a7fb76c33ba8a57ebfb0f = L.featureGroup.subGroup(
#                 feature_group_83254520adc7ab786ea2d9c3e3acaead
#             );
#
#
#             var marker_c8bda66acd9405a49c1a00a0ee5d7714 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dd58e8eb405a7fb76c33ba8a57ebfb0f);
#
#
#         var popup_1aad4e79c961b75eec4fd47de23e575f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_812dacf5cae2bf462500101ff870a2f8 = $(`&lt;div id=&quot;html_812dacf5cae2bf462500101ff870a2f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1aad4e79c961b75eec4fd47de23e575f.setContent(html_812dacf5cae2bf462500101ff870a2f8);
#
#
#
#         marker_c8bda66acd9405a49c1a00a0ee5d7714.bindPopup(popup_1aad4e79c961b75eec4fd47de23e575f)
#         ;
#
#
#
#
#             var marker_803a442f57af6f8f7ace79c3843c0f33 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dd58e8eb405a7fb76c33ba8a57ebfb0f);
#
#
#         var popup_5e96ff635a082f9e1db221384d668646 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_583d8887c377b8c0b169ef4730dbde52 = $(`&lt;div id=&quot;html_583d8887c377b8c0b169ef4730dbde52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5e96ff635a082f9e1db221384d668646.setContent(html_583d8887c377b8c0b169ef4730dbde52);
#
#
#
#         marker_803a442f57af6f8f7ace79c3843c0f33.bindPopup(popup_5e96ff635a082f9e1db221384d668646)
#         ;
#
#
#
#
#             var marker_20d38ecdf8bee25b54ea84871a31de04 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dd58e8eb405a7fb76c33ba8a57ebfb0f);
#
#
#         var popup_7aef34316945d8c841506b1cd838bbf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52d671922a879753cd6ddf82cecd6c52 = $(`&lt;div id=&quot;html_52d671922a879753cd6ddf82cecd6c52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7aef34316945d8c841506b1cd838bbf3.setContent(html_52d671922a879753cd6ddf82cecd6c52);
#
#
#
#         marker_20d38ecdf8bee25b54ea84871a31de04.bindPopup(popup_7aef34316945d8c841506b1cd838bbf3)
#         ;
#
#
#
#
#             var marker_b5c0253405c1091bcd09005c61a0ecf9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dd58e8eb405a7fb76c33ba8a57ebfb0f);
#
#
#         var popup_e25c24caf56004a717ae89d63793621a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db3933236258304ea4c861b12a200539 = $(`&lt;div id=&quot;html_db3933236258304ea4c861b12a200539&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e25c24caf56004a717ae89d63793621a.setContent(html_db3933236258304ea4c861b12a200539);
#
#
#
#         marker_
