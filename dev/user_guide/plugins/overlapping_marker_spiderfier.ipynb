# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0dd26bcd4a9a8074e73f0789afe2bb46 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0dd26bcd4a9a8074e73f0789afe2bb46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0dd26bcd4a9a8074e73f0789afe2bb46 = L.map(
#                 &quot;map_0dd26bcd4a9a8074e73f0789afe2bb46&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77365b523b3ef9b2407430c65232dedb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77365b523b3ef9b2407430c65232dedb.addTo(map_0dd26bcd4a9a8074e73f0789afe2bb46);
#
#
#             var marker_0ce67f0394ce9346e0119359ec65807f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0dd26bcd4a9a8074e73f0789afe2bb46);
#
#
#         var popup_811e27ff3b3ba70c182c94e1adeeb0f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c59cd0f0ae60e5630337ca77c11b26b5 = $(`&lt;div id=&quot;html_c59cd0f0ae60e5630337ca77c11b26b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_811e27ff3b3ba70c182c94e1adeeb0f1.setContent(html_c59cd0f0ae60e5630337ca77c11b26b5);
#
#
#
#         marker_0ce67f0394ce9346e0119359ec65807f.bindPopup(popup_811e27ff3b3ba70c182c94e1adeeb0f1)
#         ;
#
#
#
#
#             var marker_697a809e43b3f62d98d6fda4365e6124 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0dd26bcd4a9a8074e73f0789afe2bb46);
#
#
#         var popup_b731ce81e311c4acbd75ff92962f2b74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f6b6727ef43f5aa6742c7bb4d34878f = $(`&lt;div id=&quot;html_8f6b6727ef43f5aa6742c7bb4d34878f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b731ce81e311c4acbd75ff92962f2b74.setContent(html_8f6b6727ef43f5aa6742c7bb4d34878f);
#
#
#
#         marker_697a809e43b3f62d98d6fda4365e6124.bindPopup(popup_b731ce81e311c4acbd75ff92962f2b74)
#         ;
#
#
#
#
#             var marker_a3e5d61e3fc56ddbd2470003f34dfc41 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0dd26bcd4a9a8074e73f0789afe2bb46);
#
#
#         var popup_c9e497f4466bf7d568abedbd4df2309f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14f2a211cc6a9acfed487c12b02e3b8d = $(`&lt;div id=&quot;html_14f2a211cc6a9acfed487c12b02e3b8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c9e497f4466bf7d568abedbd4df2309f.setContent(html_14f2a211cc6a9acfed487c12b02e3b8d);
#
#
#
#         marker_a3e5d61e3fc56ddbd2470003f34dfc41.bindPopup(popup_c9e497f4466bf7d568abedbd4df2309f)
#         ;
#
#
#
#
#             var marker_0134af7fca56e9e960ab413e2815e94f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0dd26bcd4a9a8074e73f0789afe2bb46);
#
#
#         var popup_0f5005a2aaeb0aa59497e9fee986b31d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49e271834e74c56151914af8043e40da = $(`&lt;div id=&quot;html_49e271834e74c56151914af8043e40da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0f5005a2aaeb0aa59497e9fee986b31d.setContent(html_49e271834e74c56151914af8043e40da);
#
#
#
#         marker_0134af7fca56e9e960ab413e2815e94f.bindPopup(popup_0f5005a2aaeb0aa59497e9fee986b31d)
#         ;
#
#
#
#
#             var marker_aca6b5a7d8edf2e9103c75e8ac9a0401 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0dd26bcd4a9a8074e73f0789afe2bb46);
#
#
#         var popup_e97c829520879bacd8f831bf9971980e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b0e15548e488173991d1e9872340d28 = $(`&lt;div id=&quot;html_8b0e15548e488173991d1e9872340d28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e97c829520879bacd8f831bf997198

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2803030682e9d5bf95b50c0d379887e3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2803030682e9d5bf95b50c0d379887e3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2803030682e9d5bf95b50c0d379887e3 = L.map(
#                 &quot;map_2803030682e9d5bf95b50c0d379887e3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f83d3cb5899bcc0d8ee4df8e8604d71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f83d3cb5899bcc0d8ee4df8e8604d71.addTo(map_2803030682e9d5bf95b50c0d379887e3);
#
#
#             var feature_group_da5e329f7d67daf5fe308e697d02deb6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_55468e190878fe4c78144a020f5ec157 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_da5e329f7d67daf5fe308e697d02deb6);
#
#
#         var popup_cbaf520bc0c27a6c3a77814dc400ea72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bd358ce324c47b7f7bf80c46a8413f1 = $(`&lt;div id=&quot;html_9bd358ce324c47b7f7bf80c46a8413f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cbaf520bc0c27a6c3a77814dc400ea72.setContent(html_9bd358ce324c47b7f7bf80c46a8413f1);
#
#
#
#         marker_55468e190878fe4c78144a020f5ec157.bindPopup(popup_cbaf520bc0c27a6c3a77814dc400ea72)
#         ;
#
#
#
#
#             var marker_9bbd8ef76e971bc8bbb2a354d634d204 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_da5e329f7d67daf5fe308e697d02deb6);
#
#
#         var popup_20679c67cb788c9220b688c344d21ef4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4390a811d83ba33cad371eb61d19bdf = $(`&lt;div id=&quot;html_c4390a811d83ba33cad371eb61d19bdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_20679c67cb788c9220b688c344d21ef4.setContent(html_c4390a811d83ba33cad371eb61d19bdf);
#
#
#
#         marker_9bbd8ef76e971bc8bbb2a354d634d204.bindPopup(popup_20679c67cb788c9220b688c344d21ef4)
#         ;
#
#
#
#
#             var marker_7fc94a7c6c84c13e020329d381c2b86a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_da5e329f7d67daf5fe308e697d02deb6);
#
#
#         var popup_4ad68f16176f6b6961453aaf1ac08167 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0eb08d33c5f1889f8011d509cd434d2 = $(`&lt;div id=&quot;html_c0eb08d33c5f1889f8011d509cd434d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4ad68f16176f6b6961453aaf1ac08167.setContent(html_c0eb08d33c5f1889f8011d509cd434d2);
#
#
#
#         marker_7fc94a7c6c84c13e020329d381c2b86a.bindPopup(popup_4ad68f16176f6b6961453aaf1ac08167)
#         ;
#
#
#
#
#             var marker_c8ca198a7e707d93d8eeb4b41f15049f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_da5e329f7d67daf5fe308e697d02deb6);
#
#
#         var popup_b1e210791319eb81b458ea3b8cae53f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8077675cf00db766976be53bff5cbe2 = $(`&lt;div id=&quot;html_a8077675cf00db766976be53bff5cbe2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b1e210791319eb81b458ea3b8cae53f2.setContent(html_a8077675cf00db766976be53bff5cbe2);
#
#
#
#         marker_c8ca198a7e707d93d8eeb4b41f15049f.bindPopup(popup_b1e210791319eb81b458ea3b8cae53f2)
#         ;
#
#
#
#
#             var marker_220d1a252b3f3b6043cbc5f41d33c3db = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_da5e329f7d67daf5fe308e697d02deb6);
#
#
#         var popup_fbc7a368eb77ad5b9717e669d6fb5b77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a17178bfc0bd1f32840f97591361c203 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a17178bfc0bd1f32840f97591361c203&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a17178bfc0bd1f32840f97591361c203 = L.map(
#                 &quot;map_a17178bfc0bd1f32840f97591361c203&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_69e522eb0585fc9de9fc6f36dc9ff185 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_69e522eb0585fc9de9fc6f36dc9ff185.addTo(map_a17178bfc0bd1f32840f97591361c203);
#
#
#             var feature_group_a2c747da04552c7317d8d9fb39586608 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a2c747da04552c7317d8d9fb39586608.addTo(map_a17178bfc0bd1f32840f97591361c203);
#
#
#             var feature_group_sub_group_5034bf74984bf3c7aba2716ac5cae063 = L.featureGroup.subGroup(
#                 feature_group_a2c747da04552c7317d8d9fb39586608
#             );
#
#
#             var marker_80dfd2055625af172f56651761ea65a9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5034bf74984bf3c7aba2716ac5cae063);
#
#
#         var popup_d341886e0312979b249031acc76c328c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_246ac333900d7de13398e3c446f362b8 = $(`&lt;div id=&quot;html_246ac333900d7de13398e3c446f362b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d341886e0312979b249031acc76c328c.setContent(html_246ac333900d7de13398e3c446f362b8);
#
#
#
#         marker_80dfd2055625af172f56651761ea65a9.bindPopup(popup_d341886e0312979b249031acc76c328c)
#         ;
#
#
#
#
#             var marker_6776deecf26de7d744413f58cb734f3b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5034bf74984bf3c7aba2716ac5cae063);
#
#
#         var popup_836510d6de89efceaa99f6902f5410c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e2c22c67b624c68b52e17739a6f1ebc = $(`&lt;div id=&quot;html_4e2c22c67b624c68b52e17739a6f1ebc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_836510d6de89efceaa99f6902f5410c0.setContent(html_4e2c22c67b624c68b52e17739a6f1ebc);
#
#
#
#         marker_6776deecf26de7d744413f58cb734f3b.bindPopup(popup_836510d6de89efceaa99f6902f5410c0)
#         ;
#
#
#
#
#             var marker_35d784024d8ddb8f7bd593f5203164bd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5034bf74984bf3c7aba2716ac5cae063);
#
#
#         var popup_48eb9f743796f71fcf954831e9d23716 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0eef463672096d986b5a212e5af3bbd4 = $(`&lt;div id=&quot;html_0eef463672096d986b5a212e5af3bbd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_48eb9f743796f71fcf954831e9d23716.setContent(html_0eef463672096d986b5a212e5af3bbd4);
#
#
#
#         marker_35d784024d8ddb8f7bd593f5203164bd.bindPopup(popup_48eb9f743796f71fcf954831e9d23716)
#         ;
#
#
#
#
#             var marker_e410c44dd74270c1d2cd73529094e9c9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5034bf74984bf3c7aba2716ac5cae063);
#
#
#         var popup_70ce1045ff0c087eac335c6435a0e586 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a032dfd149dc1913cc01a9163414a42 = $(`&lt;div id=&quot;html_5a032dfd149dc1913cc01a9163414a42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_70ce1045ff0c087eac335c6435a0e586.setContent(html_5a032dfd149dc1913cc01a9163414a42);
#
#
#
#         mark
