# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1455fb10ecc2e977dce4c6572a78b03f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1455fb10ecc2e977dce4c6572a78b03f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1455fb10ecc2e977dce4c6572a78b03f = L.map(
#                 &quot;map_1455fb10ecc2e977dce4c6572a78b03f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8209b76ddd64ec90bd0c780b489fbcd3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8209b76ddd64ec90bd0c780b489fbcd3.addTo(map_1455fb10ecc2e977dce4c6572a78b03f);
#
#
#             var marker_20f69d593144aaba4b446a0c5d88ae0f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1455fb10ecc2e977dce4c6572a78b03f);
#
#
#         var popup_d88da1bbb4f6113c23d27d0b9aa0c7ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faeb2fe54f14d0e391663cced366e2fb = $(`&lt;div id=&quot;html_faeb2fe54f14d0e391663cced366e2fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d88da1bbb4f6113c23d27d0b9aa0c7ff.setContent(html_faeb2fe54f14d0e391663cced366e2fb);
#
#
#
#         marker_20f69d593144aaba4b446a0c5d88ae0f.bindPopup(popup_d88da1bbb4f6113c23d27d0b9aa0c7ff)
#         ;
#
#
#
#
#             var marker_93a6da3b83999fb99d43c773e70fc1e2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1455fb10ecc2e977dce4c6572a78b03f);
#
#
#         var popup_aed8dbcfb71817bd17757fed7ca01d35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e0851d8596d0debcae4bfd09e4eecea7 = $(`&lt;div id=&quot;html_e0851d8596d0debcae4bfd09e4eecea7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_aed8dbcfb71817bd17757fed7ca01d35.setContent(html_e0851d8596d0debcae4bfd09e4eecea7);
#
#
#
#         marker_93a6da3b83999fb99d43c773e70fc1e2.bindPopup(popup_aed8dbcfb71817bd17757fed7ca01d35)
#         ;
#
#
#
#
#             var marker_46e42378baf465f135357081127357c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1455fb10ecc2e977dce4c6572a78b03f);
#
#
#         var popup_f8f95d81336ff305d78f48c1f511f000 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9b48e8d6888bfeaedf22423fbcb4a71 = $(`&lt;div id=&quot;html_d9b48e8d6888bfeaedf22423fbcb4a71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f8f95d81336ff305d78f48c1f511f000.setContent(html_d9b48e8d6888bfeaedf22423fbcb4a71);
#
#
#
#         marker_46e42378baf465f135357081127357c5.bindPopup(popup_f8f95d81336ff305d78f48c1f511f000)
#         ;
#
#
#
#
#             var marker_062793ed72685f05f6a760979bdea51b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1455fb10ecc2e977dce4c6572a78b03f);
#
#
#         var popup_1eb78353a1975232d25fd9b1de753296 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36420f5727dd4952cc7e2362158c763c = $(`&lt;div id=&quot;html_36420f5727dd4952cc7e2362158c763c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1eb78353a1975232d25fd9b1de753296.setContent(html_36420f5727dd4952cc7e2362158c763c);
#
#
#
#         marker_062793ed72685f05f6a760979bdea51b.bindPopup(popup_1eb78353a1975232d25fd9b1de753296)
#         ;
#
#
#
#
#             var marker_86ab86f080785bdcf7effd643f1238e7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1455fb10ecc2e977dce4c6572a78b03f);
#
#
#         var popup_21fea38a364eb65f30b0103c4c1503e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7efe5a45ed9f7cca2d7ce42233fe7576 = $(`&lt;div id=&quot;html_7efe5a45ed9f7cca2d7ce42233fe7576&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_21fea38a364eb65f30b0103c4c1503e5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4bdcf0318a07b91191742fc73f90aa9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4bdcf0318a07b91191742fc73f90aa9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4bdcf0318a07b91191742fc73f90aa9 = L.map(
#                 &quot;map_c4bdcf0318a07b91191742fc73f90aa9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c9980a880fbb31551a4d9ccbe8435481 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c9980a880fbb31551a4d9ccbe8435481.addTo(map_c4bdcf0318a07b91191742fc73f90aa9);
#
#
#             var feature_group_bd722c96940f6dbbc0cd8b9d9e419756 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_69862f9338e2043ffee6b8e4969c4659 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_bd722c96940f6dbbc0cd8b9d9e419756);
#
#
#         var popup_699fe52de2b3f0c7665755050f230fcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bbda90a9726d814c991ad704ca55b60 = $(`&lt;div id=&quot;html_0bbda90a9726d814c991ad704ca55b60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_699fe52de2b3f0c7665755050f230fcf.setContent(html_0bbda90a9726d814c991ad704ca55b60);
#
#
#
#         marker_69862f9338e2043ffee6b8e4969c4659.bindPopup(popup_699fe52de2b3f0c7665755050f230fcf)
#         ;
#
#
#
#
#             var marker_373a8e01463208eadaf5ab4440aec6e5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_bd722c96940f6dbbc0cd8b9d9e419756);
#
#
#         var popup_f0baaf0ca590e6bb6c0ab1966d3332ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2cbfb95f023996a612378da3c351786 = $(`&lt;div id=&quot;html_a2cbfb95f023996a612378da3c351786&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f0baaf0ca590e6bb6c0ab1966d3332ab.setContent(html_a2cbfb95f023996a612378da3c351786);
#
#
#
#         marker_373a8e01463208eadaf5ab4440aec6e5.bindPopup(popup_f0baaf0ca590e6bb6c0ab1966d3332ab)
#         ;
#
#
#
#
#             var marker_8e65b1a6ae486cfee77ff211325eaeec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_bd722c96940f6dbbc0cd8b9d9e419756);
#
#
#         var popup_8eabba85edecce8b4a1a100e5e7c56c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad680ac6bcc31538751243088ffd9163 = $(`&lt;div id=&quot;html_ad680ac6bcc31538751243088ffd9163&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8eabba85edecce8b4a1a100e5e7c56c2.setContent(html_ad680ac6bcc31538751243088ffd9163);
#
#
#
#         marker_8e65b1a6ae486cfee77ff211325eaeec.bindPopup(popup_8eabba85edecce8b4a1a100e5e7c56c2)
#         ;
#
#
#
#
#             var marker_ce35bd61353cc1a8e69b633e3dce55c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_bd722c96940f6dbbc0cd8b9d9e419756);
#
#
#         var popup_3a6d5f838972054c27a833059c0e333a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c184c5506a2fb400c1d29a10c3b2c652 = $(`&lt;div id=&quot;html_c184c5506a2fb400c1d29a10c3b2c652&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3a6d5f838972054c27a833059c0e333a.setContent(html_c184c5506a2fb400c1d29a10c3b2c652);
#
#
#
#         marker_ce35bd61353cc1a8e69b633e3dce55c6.bindPopup(popup_3a6d5f838972054c27a833059c0e333a)
#         ;
#
#
#
#
#             var marker_2adba9a16376ff20f85d804c4e448878 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_bd722c96940f6dbbc0cd8b9d9e419756);
#
#
#         var popup_57ed899e921c163747fb55218eb55495 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffefb0e62b6b2a75438e6135ba2c748d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffefb0e62b6b2a75438e6135ba2c748d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffefb0e62b6b2a75438e6135ba2c748d = L.map(
#                 &quot;map_ffefb0e62b6b2a75438e6135ba2c748d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d4e44a665eed91f79cd23b0393052d22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4e44a665eed91f79cd23b0393052d22.addTo(map_ffefb0e62b6b2a75438e6135ba2c748d);
#
#
#             var feature_group_b8d7ce8751111f8786b303ee8b3a087a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b8d7ce8751111f8786b303ee8b3a087a.addTo(map_ffefb0e62b6b2a75438e6135ba2c748d);
#
#
#             var feature_group_sub_group_3ae29089a0520f5b08cb7836c12d7a6a = L.featureGroup.subGroup(
#                 feature_group_b8d7ce8751111f8786b303ee8b3a087a
#             );
#
#
#             var marker_a7547a08b9c000d145d93f9a34bafe8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ae29089a0520f5b08cb7836c12d7a6a);
#
#
#         var popup_476fc89a2d2ab53154c29ffad28e0cdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c9180e8ac491de95291fbc0a7ca8386 = $(`&lt;div id=&quot;html_1c9180e8ac491de95291fbc0a7ca8386&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_476fc89a2d2ab53154c29ffad28e0cdf.setContent(html_1c9180e8ac491de95291fbc0a7ca8386);
#
#
#
#         marker_a7547a08b9c000d145d93f9a34bafe8e.bindPopup(popup_476fc89a2d2ab53154c29ffad28e0cdf)
#         ;
#
#
#
#
#             var marker_1eef2bcaf8afc8a0ef5be10bde9871be = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ae29089a0520f5b08cb7836c12d7a6a);
#
#
#         var popup_2c0cd775835b5be4f88ada5ac15feefc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_698a51147bdb7e71358e05286f05d579 = $(`&lt;div id=&quot;html_698a51147bdb7e71358e05286f05d579&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2c0cd775835b5be4f88ada5ac15feefc.setContent(html_698a51147bdb7e71358e05286f05d579);
#
#
#
#         marker_1eef2bcaf8afc8a0ef5be10bde9871be.bindPopup(popup_2c0cd775835b5be4f88ada5ac15feefc)
#         ;
#
#
#
#
#             var marker_3f6ca5ba6ed0c5dee3ece4f5eaaaa706 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ae29089a0520f5b08cb7836c12d7a6a);
#
#
#         var popup_c5725e7cbc10a94c8b2caa9668951048 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dc27ca51765a9e0edc2090285e64c86 = $(`&lt;div id=&quot;html_0dc27ca51765a9e0edc2090285e64c86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c5725e7cbc10a94c8b2caa9668951048.setContent(html_0dc27ca51765a9e0edc2090285e64c86);
#
#
#
#         marker_3f6ca5ba6ed0c5dee3ece4f5eaaaa706.bindPopup(popup_c5725e7cbc10a94c8b2caa9668951048)
#         ;
#
#
#
#
#             var marker_c5f827c168fd19edabf297dfbf2d5fdb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3ae29089a0520f5b08cb7836c12d7a6a);
#
#
#         var popup_76f0300fecf6b3f463a1cb69b588c588 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cac9b8e40dc9583b8aa0b185268b9140 = $(`&lt;div id=&quot;html_cac9b8e40dc9583b8aa0b185268b9140&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_76f0300fecf6b3f463a1cb69b588c588.setContent(html_cac9b8e40dc9583b8aa0b185268b9140);
#
#
#
#         marker_
