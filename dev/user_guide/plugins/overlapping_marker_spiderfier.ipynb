# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c9a7dc1187d1831f7103f0aaa3ba376 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c9a7dc1187d1831f7103f0aaa3ba376&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c9a7dc1187d1831f7103f0aaa3ba376 = L.map(
#                 &quot;map_5c9a7dc1187d1831f7103f0aaa3ba376&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b1e9d7a2f8148da5c38e537d037b665 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b1e9d7a2f8148da5c38e537d037b665.addTo(map_5c9a7dc1187d1831f7103f0aaa3ba376);
#
#
#             var marker_050b6d84e917dac1cf31a21d86c26422 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5c9a7dc1187d1831f7103f0aaa3ba376);
#
#
#         var popup_cc1d7e4e31bda09b3985103c97be1f7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e874b0dc1f015fc53f682f2756fc1b50 = $(`&lt;div id=&quot;html_e874b0dc1f015fc53f682f2756fc1b50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cc1d7e4e31bda09b3985103c97be1f7b.setContent(html_e874b0dc1f015fc53f682f2756fc1b50);
#
#
#
#         marker_050b6d84e917dac1cf31a21d86c26422.bindPopup(popup_cc1d7e4e31bda09b3985103c97be1f7b)
#         ;
#
#
#
#
#             var marker_ed0663f17df05648d84c088c7d0cf3c7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5c9a7dc1187d1831f7103f0aaa3ba376);
#
#
#         var popup_9710efd8d9bbb31eea1ad8cb53e16820 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0477e49166d3ae990c1874791f72131 = $(`&lt;div id=&quot;html_f0477e49166d3ae990c1874791f72131&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9710efd8d9bbb31eea1ad8cb53e16820.setContent(html_f0477e49166d3ae990c1874791f72131);
#
#
#
#         marker_ed0663f17df05648d84c088c7d0cf3c7.bindPopup(popup_9710efd8d9bbb31eea1ad8cb53e16820)
#         ;
#
#
#
#
#             var marker_eadad33384556aaca98c9f32600da3fe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5c9a7dc1187d1831f7103f0aaa3ba376);
#
#
#         var popup_63e06957acaddd44eb0d6cf873708420 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e90c0cd13ffc0eb2ae8dbcb5f0cdcf6d = $(`&lt;div id=&quot;html_e90c0cd13ffc0eb2ae8dbcb5f0cdcf6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_63e06957acaddd44eb0d6cf873708420.setContent(html_e90c0cd13ffc0eb2ae8dbcb5f0cdcf6d);
#
#
#
#         marker_eadad33384556aaca98c9f32600da3fe.bindPopup(popup_63e06957acaddd44eb0d6cf873708420)
#         ;
#
#
#
#
#             var marker_92cde7be2ea4b3f33b5069cc3198586b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5c9a7dc1187d1831f7103f0aaa3ba376);
#
#
#         var popup_d5866a1d633f5cf06d7dfe31a08720c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c30f9aef8051a3d9c83bdd73f2e4d51 = $(`&lt;div id=&quot;html_4c30f9aef8051a3d9c83bdd73f2e4d51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d5866a1d633f5cf06d7dfe31a08720c9.setContent(html_4c30f9aef8051a3d9c83bdd73f2e4d51);
#
#
#
#         marker_92cde7be2ea4b3f33b5069cc3198586b.bindPopup(popup_d5866a1d633f5cf06d7dfe31a08720c9)
#         ;
#
#
#
#
#             var marker_a977877424260b694043ad2fcb991d14 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5c9a7dc1187d1831f7103f0aaa3ba376);
#
#
#         var popup_13f02ba282f6483d4099bb696a224c41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a88b21d61524b01aa566746a78eaaec = $(`&lt;div id=&quot;html_7a88b21d61524b01aa566746a78eaaec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_13f02ba282f6483d4099bb696a224c41.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c3b6df69dbc218e298da1bda8df56f47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c3b6df69dbc218e298da1bda8df56f47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c3b6df69dbc218e298da1bda8df56f47 = L.map(
#                 &quot;map_c3b6df69dbc218e298da1bda8df56f47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50b5dd7b6f647ff66dd5b008a2b4bbfc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50b5dd7b6f647ff66dd5b008a2b4bbfc.addTo(map_c3b6df69dbc218e298da1bda8df56f47);
#
#
#             var feature_group_521e61ac993b16c1d7e8002513c9d5b7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_33c2f607b73ee55f8401f48e9ddcf89e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_521e61ac993b16c1d7e8002513c9d5b7);
#
#
#         var popup_e3208b290ccb4e5efec84cb2966fb920 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f175c89ece40ce804384ac32c50004d = $(`&lt;div id=&quot;html_6f175c89ece40ce804384ac32c50004d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e3208b290ccb4e5efec84cb2966fb920.setContent(html_6f175c89ece40ce804384ac32c50004d);
#
#
#
#         marker_33c2f607b73ee55f8401f48e9ddcf89e.bindPopup(popup_e3208b290ccb4e5efec84cb2966fb920)
#         ;
#
#
#
#
#             var marker_dea9fad011a1df90061adcffd375c237 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_521e61ac993b16c1d7e8002513c9d5b7);
#
#
#         var popup_132a499c1b8d726d4d425b4d9d6e79da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8cc5ea04ec3e08a0e1837013f593005 = $(`&lt;div id=&quot;html_c8cc5ea04ec3e08a0e1837013f593005&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_132a499c1b8d726d4d425b4d9d6e79da.setContent(html_c8cc5ea04ec3e08a0e1837013f593005);
#
#
#
#         marker_dea9fad011a1df90061adcffd375c237.bindPopup(popup_132a499c1b8d726d4d425b4d9d6e79da)
#         ;
#
#
#
#
#             var marker_06fa403b521585b6d2d5bd059ddead82 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_521e61ac993b16c1d7e8002513c9d5b7);
#
#
#         var popup_fbf255453feb22d6af28e73f77526982 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de445d5e04c55c84ae25370f6e0d4b68 = $(`&lt;div id=&quot;html_de445d5e04c55c84ae25370f6e0d4b68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fbf255453feb22d6af28e73f77526982.setContent(html_de445d5e04c55c84ae25370f6e0d4b68);
#
#
#
#         marker_06fa403b521585b6d2d5bd059ddead82.bindPopup(popup_fbf255453feb22d6af28e73f77526982)
#         ;
#
#
#
#
#             var marker_b69ed65b21f2e02f712c29a8726a533c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_521e61ac993b16c1d7e8002513c9d5b7);
#
#
#         var popup_c76f5c1250dc819300d834eadbb9c67c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20aeb5d2480fe9625b9f88f3012b6cf8 = $(`&lt;div id=&quot;html_20aeb5d2480fe9625b9f88f3012b6cf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c76f5c1250dc819300d834eadbb9c67c.setContent(html_20aeb5d2480fe9625b9f88f3012b6cf8);
#
#
#
#         marker_b69ed65b21f2e02f712c29a8726a533c.bindPopup(popup_c76f5c1250dc819300d834eadbb9c67c)
#         ;
#
#
#
#
#             var marker_331caed5b7ec37d5e22a315fbc86b9ae = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_521e61ac993b16c1d7e8002513c9d5b7);
#
#
#         var popup_5e3dc9b6a3faf2b6e713595ddec44853 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_287b352b3f16268f7fb948d418c916df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_287b352b3f16268f7fb948d418c916df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_287b352b3f16268f7fb948d418c916df = L.map(
#                 &quot;map_287b352b3f16268f7fb948d418c916df&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4930a2cf68ad5a20251f8df245b7214 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a4930a2cf68ad5a20251f8df245b7214.addTo(map_287b352b3f16268f7fb948d418c916df);
#
#
#             var feature_group_22e7fd0413b89b11094d71492cdacae8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_22e7fd0413b89b11094d71492cdacae8.addTo(map_287b352b3f16268f7fb948d418c916df);
#
#
#             var feature_group_sub_group_dc0be24107d696f24b55543f057c67ca = L.featureGroup.subGroup(
#                 feature_group_22e7fd0413b89b11094d71492cdacae8
#             );
#
#
#             var marker_f3f9c6055dcca49c01bf4bd3b7ef127f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc0be24107d696f24b55543f057c67ca);
#
#
#         var popup_1c016ef94adcedb66d9afab68bc49538 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c8bd5b04f273a7bc34db97cacab289e = $(`&lt;div id=&quot;html_7c8bd5b04f273a7bc34db97cacab289e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1c016ef94adcedb66d9afab68bc49538.setContent(html_7c8bd5b04f273a7bc34db97cacab289e);
#
#
#
#         marker_f3f9c6055dcca49c01bf4bd3b7ef127f.bindPopup(popup_1c016ef94adcedb66d9afab68bc49538)
#         ;
#
#
#
#
#             var marker_e70eb580caccabbbd8a564a88c81b2f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc0be24107d696f24b55543f057c67ca);
#
#
#         var popup_e3a60fb58f6edff434ea4c2151793934 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3941f419290202421255b5a4c924979 = $(`&lt;div id=&quot;html_f3941f419290202421255b5a4c924979&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e3a60fb58f6edff434ea4c2151793934.setContent(html_f3941f419290202421255b5a4c924979);
#
#
#
#         marker_e70eb580caccabbbd8a564a88c81b2f4.bindPopup(popup_e3a60fb58f6edff434ea4c2151793934)
#         ;
#
#
#
#
#             var marker_4254d6cc2019d6fdec37cde7d1c714ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc0be24107d696f24b55543f057c67ca);
#
#
#         var popup_09ee2b73468cf56714b25ce2ed98d7bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48395ca53dea5d28de55cd5e0d3e3d85 = $(`&lt;div id=&quot;html_48395ca53dea5d28de55cd5e0d3e3d85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_09ee2b73468cf56714b25ce2ed98d7bd.setContent(html_48395ca53dea5d28de55cd5e0d3e3d85);
#
#
#
#         marker_4254d6cc2019d6fdec37cde7d1c714ec.bindPopup(popup_09ee2b73468cf56714b25ce2ed98d7bd)
#         ;
#
#
#
#
#             var marker_49af9763bf546b3022d86531441a87e8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc0be24107d696f24b55543f057c67ca);
#
#
#         var popup_c8822a9502e3884ccde0c8a53b33e05a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6909ac89bfeb7078f420a2f6feb6230 = $(`&lt;div id=&quot;html_d6909ac89bfeb7078f420a2f6feb6230&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c8822a9502e3884ccde0c8a53b33e05a.setContent(html_d6909ac89bfeb7078f420a2f6feb6230);
#
#
#
#         marker_
