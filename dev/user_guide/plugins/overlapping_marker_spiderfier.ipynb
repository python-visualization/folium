# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57d7e8798dbab8f4d9db91e1d09c12c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57d7e8798dbab8f4d9db91e1d09c12c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57d7e8798dbab8f4d9db91e1d09c12c4 = L.map(
#                 &quot;map_57d7e8798dbab8f4d9db91e1d09c12c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb84a257b251d83e5d7c0c641230643f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb84a257b251d83e5d7c0c641230643f.addTo(map_57d7e8798dbab8f4d9db91e1d09c12c4);
#
#
#             var marker_f575280a80c56e7365e9393bd2a94b09 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_57d7e8798dbab8f4d9db91e1d09c12c4);
#
#
#         var popup_a223d4cdbeaf54d59b7ad095f9880315 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aae5b296721bce0cb14f70754e5f52c0 = $(`&lt;div id=&quot;html_aae5b296721bce0cb14f70754e5f52c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a223d4cdbeaf54d59b7ad095f9880315.setContent(html_aae5b296721bce0cb14f70754e5f52c0);
#
#
#
#         marker_f575280a80c56e7365e9393bd2a94b09.bindPopup(popup_a223d4cdbeaf54d59b7ad095f9880315)
#         ;
#
#
#
#
#             var marker_fa363ccf6bdd50632ad419c16783c77e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_57d7e8798dbab8f4d9db91e1d09c12c4);
#
#
#         var popup_3919b38671787be841b515a8fe868d1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3272b9a16b108c111546ff66e4fa693 = $(`&lt;div id=&quot;html_f3272b9a16b108c111546ff66e4fa693&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3919b38671787be841b515a8fe868d1b.setContent(html_f3272b9a16b108c111546ff66e4fa693);
#
#
#
#         marker_fa363ccf6bdd50632ad419c16783c77e.bindPopup(popup_3919b38671787be841b515a8fe868d1b)
#         ;
#
#
#
#
#             var marker_db9003a824fe4ecc21dcc49b40a0ff68 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_57d7e8798dbab8f4d9db91e1d09c12c4);
#
#
#         var popup_57ad89c641ca83571e3a4a2067aa0f71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a177bee79a0c88f8d1b26196894b4f32 = $(`&lt;div id=&quot;html_a177bee79a0c88f8d1b26196894b4f32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_57ad89c641ca83571e3a4a2067aa0f71.setContent(html_a177bee79a0c88f8d1b26196894b4f32);
#
#
#
#         marker_db9003a824fe4ecc21dcc49b40a0ff68.bindPopup(popup_57ad89c641ca83571e3a4a2067aa0f71)
#         ;
#
#
#
#
#             var marker_98878bc6c202823f046f25d3d4f4c0e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_57d7e8798dbab8f4d9db91e1d09c12c4);
#
#
#         var popup_9a3acbc700cf3c2bfe08b2e5bbb56f5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e15862884286ee407de2179e6304afcd = $(`&lt;div id=&quot;html_e15862884286ee407de2179e6304afcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9a3acbc700cf3c2bfe08b2e5bbb56f5f.setContent(html_e15862884286ee407de2179e6304afcd);
#
#
#
#         marker_98878bc6c202823f046f25d3d4f4c0e3.bindPopup(popup_9a3acbc700cf3c2bfe08b2e5bbb56f5f)
#         ;
#
#
#
#
#             var marker_3a034f36fb08084e3cb65bc8409cf4cf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_57d7e8798dbab8f4d9db91e1d09c12c4);
#
#
#         var popup_1ba3849bf6b43f8829bdb12146a7635c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ecf145116ec9ae3adf2222232e7785c = $(`&lt;div id=&quot;html_9ecf145116ec9ae3adf2222232e7785c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1ba3849bf6b43f8829bdb12146a7635c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d85ee554c44af5c9305d81152e54178 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d85ee554c44af5c9305d81152e54178&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d85ee554c44af5c9305d81152e54178 = L.map(
#                 &quot;map_6d85ee554c44af5c9305d81152e54178&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_657d06b38de39e9c2cc606b66d535313 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_657d06b38de39e9c2cc606b66d535313.addTo(map_6d85ee554c44af5c9305d81152e54178);
#
#
#             var feature_group_9f76e950bbdc53bfb1cdab8286f48618 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dac1c661146d7d3a81c8fbba09c06bf6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9f76e950bbdc53bfb1cdab8286f48618);
#
#
#         var popup_15bca89c3c493173740019548fe44468 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8d6ac37831ac5270060a231420e96a6 = $(`&lt;div id=&quot;html_b8d6ac37831ac5270060a231420e96a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_15bca89c3c493173740019548fe44468.setContent(html_b8d6ac37831ac5270060a231420e96a6);
#
#
#
#         marker_dac1c661146d7d3a81c8fbba09c06bf6.bindPopup(popup_15bca89c3c493173740019548fe44468)
#         ;
#
#
#
#
#             var marker_4472d7cf3a1f754033f25cbf50097f18 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9f76e950bbdc53bfb1cdab8286f48618);
#
#
#         var popup_76147035e9b00c9ae24220fb665cf0de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23ff9a8a1f9d54797b81b77b61b9c371 = $(`&lt;div id=&quot;html_23ff9a8a1f9d54797b81b77b61b9c371&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_76147035e9b00c9ae24220fb665cf0de.setContent(html_23ff9a8a1f9d54797b81b77b61b9c371);
#
#
#
#         marker_4472d7cf3a1f754033f25cbf50097f18.bindPopup(popup_76147035e9b00c9ae24220fb665cf0de)
#         ;
#
#
#
#
#             var marker_178bf20dfcab3f33ed0794e4e941b036 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9f76e950bbdc53bfb1cdab8286f48618);
#
#
#         var popup_ab5c30ac6db1504f785160416d6568a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_637c4e6f46916e985997e57ae8aae82f = $(`&lt;div id=&quot;html_637c4e6f46916e985997e57ae8aae82f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ab5c30ac6db1504f785160416d6568a2.setContent(html_637c4e6f46916e985997e57ae8aae82f);
#
#
#
#         marker_178bf20dfcab3f33ed0794e4e941b036.bindPopup(popup_ab5c30ac6db1504f785160416d6568a2)
#         ;
#
#
#
#
#             var marker_f5ec47571d6aa326062ca6d766c4ab59 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9f76e950bbdc53bfb1cdab8286f48618);
#
#
#         var popup_a879d90453b2412b43782410c054e701 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc5960e68cd7d263e3ca3c08f89d025a = $(`&lt;div id=&quot;html_fc5960e68cd7d263e3ca3c08f89d025a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a879d90453b2412b43782410c054e701.setContent(html_fc5960e68cd7d263e3ca3c08f89d025a);
#
#
#
#         marker_f5ec47571d6aa326062ca6d766c4ab59.bindPopup(popup_a879d90453b2412b43782410c054e701)
#         ;
#
#
#
#
#             var marker_384254c3955f6b7055fe6d49160ac424 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9f76e950bbdc53bfb1cdab8286f48618);
#
#
#         var popup_1ff8cc6d361516098130df5d0b148aba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_337d248147be439b5f41417ef5b614b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_337d248147be439b5f41417ef5b614b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_337d248147be439b5f41417ef5b614b3 = L.map(
#                 &quot;map_337d248147be439b5f41417ef5b614b3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a79fae1abc08f8dac32898ee7028d36 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a79fae1abc08f8dac32898ee7028d36.addTo(map_337d248147be439b5f41417ef5b614b3);
#
#
#             var feature_group_afffb9b96fe436aaac385427a4207fdb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_afffb9b96fe436aaac385427a4207fdb.addTo(map_337d248147be439b5f41417ef5b614b3);
#
#
#             var feature_group_sub_group_75d3bf867ada41066630116228df8f30 = L.featureGroup.subGroup(
#                 feature_group_afffb9b96fe436aaac385427a4207fdb
#             );
#
#
#             var marker_3665fe17d22057de606a6a5039695cad = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_75d3bf867ada41066630116228df8f30);
#
#
#         var popup_e2b77b72e2299738919bcdfee5ba2d1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d214353abe441f0c70cceaeb9d5e1863 = $(`&lt;div id=&quot;html_d214353abe441f0c70cceaeb9d5e1863&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e2b77b72e2299738919bcdfee5ba2d1b.setContent(html_d214353abe441f0c70cceaeb9d5e1863);
#
#
#
#         marker_3665fe17d22057de606a6a5039695cad.bindPopup(popup_e2b77b72e2299738919bcdfee5ba2d1b)
#         ;
#
#
#
#
#             var marker_1c8d6df80aebd19956a85dba8a59fedd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_75d3bf867ada41066630116228df8f30);
#
#
#         var popup_78fcc335650e43c256046d09935a13f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc4a6d31e02497d2a3ef8d84e5556bc1 = $(`&lt;div id=&quot;html_cc4a6d31e02497d2a3ef8d84e5556bc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_78fcc335650e43c256046d09935a13f6.setContent(html_cc4a6d31e02497d2a3ef8d84e5556bc1);
#
#
#
#         marker_1c8d6df80aebd19956a85dba8a59fedd.bindPopup(popup_78fcc335650e43c256046d09935a13f6)
#         ;
#
#
#
#
#             var marker_aa02f49f94aa24bc2c29b2d0bae82b2d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_75d3bf867ada41066630116228df8f30);
#
#
#         var popup_4c4ba4cf0c0e679d946ca0e827728880 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a6642bc5c6e01b7647223431956076d = $(`&lt;div id=&quot;html_2a6642bc5c6e01b7647223431956076d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4c4ba4cf0c0e679d946ca0e827728880.setContent(html_2a6642bc5c6e01b7647223431956076d);
#
#
#
#         marker_aa02f49f94aa24bc2c29b2d0bae82b2d.bindPopup(popup_4c4ba4cf0c0e679d946ca0e827728880)
#         ;
#
#
#
#
#             var marker_5075ca65b5ab21169f9ad41eb003d74e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_75d3bf867ada41066630116228df8f30);
#
#
#         var popup_b849c46e6f1891ed7b13f6c589054e27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3dd584a31ac885b1e0fcf6432c5de6d = $(`&lt;div id=&quot;html_a3dd584a31ac885b1e0fcf6432c5de6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b849c46e6f1891ed7b13f6c589054e27.setContent(html_a3dd584a31ac885b1e0fcf6432c5de6d);
#
#
#
#         marker_
