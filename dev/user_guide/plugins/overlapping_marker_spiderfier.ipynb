# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8ffe1ff9abbd094d9bbda9e673e3879 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8ffe1ff9abbd094d9bbda9e673e3879&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8ffe1ff9abbd094d9bbda9e673e3879 = L.map(
#                 &quot;map_c8ffe1ff9abbd094d9bbda9e673e3879&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4be721ce7314c8c4867c6c3b1ab2f383 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4be721ce7314c8c4867c6c3b1ab2f383.addTo(map_c8ffe1ff9abbd094d9bbda9e673e3879);
#
#
#             var marker_5f39658201fbd8f03621079784234bd5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c8ffe1ff9abbd094d9bbda9e673e3879);
#
#
#         var popup_c8043c0571f440f87a3222f7eeaf002f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f5ccb5a0204eb88082eb765bab632f8 = $(`&lt;div id=&quot;html_3f5ccb5a0204eb88082eb765bab632f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c8043c0571f440f87a3222f7eeaf002f.setContent(html_3f5ccb5a0204eb88082eb765bab632f8);
#
#
#
#         marker_5f39658201fbd8f03621079784234bd5.bindPopup(popup_c8043c0571f440f87a3222f7eeaf002f)
#         ;
#
#
#
#
#             var marker_f04cca7181d185e84fecbd2b4c03392a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c8ffe1ff9abbd094d9bbda9e673e3879);
#
#
#         var popup_39a23a38f3f3c2f42beed1e9e8479a81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_813d47134654ab34493d5806a31b5fc3 = $(`&lt;div id=&quot;html_813d47134654ab34493d5806a31b5fc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_39a23a38f3f3c2f42beed1e9e8479a81.setContent(html_813d47134654ab34493d5806a31b5fc3);
#
#
#
#         marker_f04cca7181d185e84fecbd2b4c03392a.bindPopup(popup_39a23a38f3f3c2f42beed1e9e8479a81)
#         ;
#
#
#
#
#             var marker_5bdf50e64c8374685622999a45d87ee9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c8ffe1ff9abbd094d9bbda9e673e3879);
#
#
#         var popup_ce9886dcecf6835bf5b7ea3a1626dcc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7496c1804073af2a6dcfe6b732c6bd6d = $(`&lt;div id=&quot;html_7496c1804073af2a6dcfe6b732c6bd6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ce9886dcecf6835bf5b7ea3a1626dcc6.setContent(html_7496c1804073af2a6dcfe6b732c6bd6d);
#
#
#
#         marker_5bdf50e64c8374685622999a45d87ee9.bindPopup(popup_ce9886dcecf6835bf5b7ea3a1626dcc6)
#         ;
#
#
#
#
#             var marker_a7b1c0a61ca7f12e9d75b891d15a1b5d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c8ffe1ff9abbd094d9bbda9e673e3879);
#
#
#         var popup_ecc66af165481646312db1badcf953a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_119ca42314d011d0e1eeb7108e4498f5 = $(`&lt;div id=&quot;html_119ca42314d011d0e1eeb7108e4498f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ecc66af165481646312db1badcf953a1.setContent(html_119ca42314d011d0e1eeb7108e4498f5);
#
#
#
#         marker_a7b1c0a61ca7f12e9d75b891d15a1b5d.bindPopup(popup_ecc66af165481646312db1badcf953a1)
#         ;
#
#
#
#
#             var marker_6a2322069c132b554c1dc536a097e744 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c8ffe1ff9abbd094d9bbda9e673e3879);
#
#
#         var popup_034406106c081506cfbab3234ac4910d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_141eb2a5582b83a3fd6bcc6c8cf1e2cc = $(`&lt;div id=&quot;html_141eb2a5582b83a3fd6bcc6c8cf1e2cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_034406106c081506cfbab3234ac4910d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7568656832c25a4e6a417bd427cbe4a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7568656832c25a4e6a417bd427cbe4a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7568656832c25a4e6a417bd427cbe4a3 = L.map(
#                 &quot;map_7568656832c25a4e6a417bd427cbe4a3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5753ed4b6350bb387e1348c395521fa3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5753ed4b6350bb387e1348c395521fa3.addTo(map_7568656832c25a4e6a417bd427cbe4a3);
#
#
#             var feature_group_e7d0102605841031a3c1750a8d9a6251 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_01431f99d418c5d1aed6c2c12e0f73b8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e7d0102605841031a3c1750a8d9a6251);
#
#
#         var popup_9541132a74ea20e0d833208b328e5886 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5219136df1ebed2c60b1559a3d29f69b = $(`&lt;div id=&quot;html_5219136df1ebed2c60b1559a3d29f69b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9541132a74ea20e0d833208b328e5886.setContent(html_5219136df1ebed2c60b1559a3d29f69b);
#
#
#
#         marker_01431f99d418c5d1aed6c2c12e0f73b8.bindPopup(popup_9541132a74ea20e0d833208b328e5886)
#         ;
#
#
#
#
#             var marker_49e6d75d549a6f17b307cd68b50b8746 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e7d0102605841031a3c1750a8d9a6251);
#
#
#         var popup_76fca36135d7f8f1f35ef287e35e8cdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bbf057e03118c783e1e2b94a3be3905 = $(`&lt;div id=&quot;html_0bbf057e03118c783e1e2b94a3be3905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_76fca36135d7f8f1f35ef287e35e8cdf.setContent(html_0bbf057e03118c783e1e2b94a3be3905);
#
#
#
#         marker_49e6d75d549a6f17b307cd68b50b8746.bindPopup(popup_76fca36135d7f8f1f35ef287e35e8cdf)
#         ;
#
#
#
#
#             var marker_7800080c70f19fdd074782f21d27b5fc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e7d0102605841031a3c1750a8d9a6251);
#
#
#         var popup_2d08efcf8ddc49cb4113090651ef46e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_379280057dc79786053e7dade1e86468 = $(`&lt;div id=&quot;html_379280057dc79786053e7dade1e86468&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2d08efcf8ddc49cb4113090651ef46e9.setContent(html_379280057dc79786053e7dade1e86468);
#
#
#
#         marker_7800080c70f19fdd074782f21d27b5fc.bindPopup(popup_2d08efcf8ddc49cb4113090651ef46e9)
#         ;
#
#
#
#
#             var marker_8700dda30291d538d4fe813342b0473a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e7d0102605841031a3c1750a8d9a6251);
#
#
#         var popup_dab701051a9e6e6320bffc9e98043fd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f649114b329e1d67f0fda6452d9d8793 = $(`&lt;div id=&quot;html_f649114b329e1d67f0fda6452d9d8793&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_dab701051a9e6e6320bffc9e98043fd8.setContent(html_f649114b329e1d67f0fda6452d9d8793);
#
#
#
#         marker_8700dda30291d538d4fe813342b0473a.bindPopup(popup_dab701051a9e6e6320bffc9e98043fd8)
#         ;
#
#
#
#
#             var marker_7755b0cc44edc7d8be618439a81a3320 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e7d0102605841031a3c1750a8d9a6251);
#
#
#         var popup_90fb323913592d078c39c9ecce80f6c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a612ac0933d62a8d11f9534085700627 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a612ac0933d62a8d11f9534085700627&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a612ac0933d62a8d11f9534085700627 = L.map(
#                 &quot;map_a612ac0933d62a8d11f9534085700627&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9baf960909afa3dd03a636dff9644cc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9baf960909afa3dd03a636dff9644cc5.addTo(map_a612ac0933d62a8d11f9534085700627);
#
#
#             var feature_group_42127227eb98d520b67fa33ebd1f3efb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_42127227eb98d520b67fa33ebd1f3efb.addTo(map_a612ac0933d62a8d11f9534085700627);
#
#
#             var feature_group_sub_group_be27a7d6488548f09b37e35bd39c7f9b = L.featureGroup.subGroup(
#                 feature_group_42127227eb98d520b67fa33ebd1f3efb
#             );
#
#
#             var marker_f236d454f772bb506d64fba2ecf2e781 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_be27a7d6488548f09b37e35bd39c7f9b);
#
#
#         var popup_280b91c45a5eeed7b4a31a673f63882f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3b2c84f7f07d24fca70e0d702afe819 = $(`&lt;div id=&quot;html_a3b2c84f7f07d24fca70e0d702afe819&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_280b91c45a5eeed7b4a31a673f63882f.setContent(html_a3b2c84f7f07d24fca70e0d702afe819);
#
#
#
#         marker_f236d454f772bb506d64fba2ecf2e781.bindPopup(popup_280b91c45a5eeed7b4a31a673f63882f)
#         ;
#
#
#
#
#             var marker_d81a6377afe49d1c850dd5ea6a4473ce = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_be27a7d6488548f09b37e35bd39c7f9b);
#
#
#         var popup_a11db4834a9257b22010fb9619fe7780 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cc864786525f8d6aa141f10d9007c54 = $(`&lt;div id=&quot;html_7cc864786525f8d6aa141f10d9007c54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a11db4834a9257b22010fb9619fe7780.setContent(html_7cc864786525f8d6aa141f10d9007c54);
#
#
#
#         marker_d81a6377afe49d1c850dd5ea6a4473ce.bindPopup(popup_a11db4834a9257b22010fb9619fe7780)
#         ;
#
#
#
#
#             var marker_8c91bebaf430cd978aca31773c6fd4ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_be27a7d6488548f09b37e35bd39c7f9b);
#
#
#         var popup_afef8493cf6f7368c69fb79ec0771180 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2ba6048a30d5e3019b37740ab7c0270 = $(`&lt;div id=&quot;html_e2ba6048a30d5e3019b37740ab7c0270&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_afef8493cf6f7368c69fb79ec0771180.setContent(html_e2ba6048a30d5e3019b37740ab7c0270);
#
#
#
#         marker_8c91bebaf430cd978aca31773c6fd4ae.bindPopup(popup_afef8493cf6f7368c69fb79ec0771180)
#         ;
#
#
#
#
#             var marker_4279bbe4d4f5a6633a2443de794bc25a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_be27a7d6488548f09b37e35bd39c7f9b);
#
#
#         var popup_10897c43090f7aef645ac3ce51e77099 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ef7f1ac5a81239837d40e0d5468a828 = $(`&lt;div id=&quot;html_9ef7f1ac5a81239837d40e0d5468a828&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_10897c43090f7aef645ac3ce51e77099.setContent(html_9ef7f1ac5a81239837d40e0d5468a828);
#
#
#
#         marker_
