# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a2be0a1ef614657684fe1ae43900ca5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a2be0a1ef614657684fe1ae43900ca5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7a2be0a1ef614657684fe1ae43900ca5 = L.map(
#                 &quot;map_7a2be0a1ef614657684fe1ae43900ca5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_468472b7a302c85ba70f3a78967c7351 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_468472b7a302c85ba70f3a78967c7351.addTo(map_7a2be0a1ef614657684fe1ae43900ca5);
#
#
#             var marker_4d4c076c8081c304b6f7eff7c7db4428 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7a2be0a1ef614657684fe1ae43900ca5);
#
#
#         var popup_9886083ec8d542029a2a14d08a3441d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91475441fce499baebac3d6d3bced31f = $(`&lt;div id=&quot;html_91475441fce499baebac3d6d3bced31f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9886083ec8d542029a2a14d08a3441d6.setContent(html_91475441fce499baebac3d6d3bced31f);
#
#
#
#         marker_4d4c076c8081c304b6f7eff7c7db4428.bindPopup(popup_9886083ec8d542029a2a14d08a3441d6)
#         ;
#
#
#
#
#             var marker_5d0f2996c33f995e5c69a9d127c9646c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7a2be0a1ef614657684fe1ae43900ca5);
#
#
#         var popup_48ba5aac9f0374b7f90dfd8498c3ba3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0e7a1c586d107dddd45265b4bd1ff7a = $(`&lt;div id=&quot;html_c0e7a1c586d107dddd45265b4bd1ff7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_48ba5aac9f0374b7f90dfd8498c3ba3c.setContent(html_c0e7a1c586d107dddd45265b4bd1ff7a);
#
#
#
#         marker_5d0f2996c33f995e5c69a9d127c9646c.bindPopup(popup_48ba5aac9f0374b7f90dfd8498c3ba3c)
#         ;
#
#
#
#
#             var marker_1cd60ffb56d99159331e22b5a7745b48 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7a2be0a1ef614657684fe1ae43900ca5);
#
#
#         var popup_8cce57717ad674cbc674eee7baae6f31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3b835ad3d0cb5ce93da548b60dee769 = $(`&lt;div id=&quot;html_f3b835ad3d0cb5ce93da548b60dee769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8cce57717ad674cbc674eee7baae6f31.setContent(html_f3b835ad3d0cb5ce93da548b60dee769);
#
#
#
#         marker_1cd60ffb56d99159331e22b5a7745b48.bindPopup(popup_8cce57717ad674cbc674eee7baae6f31)
#         ;
#
#
#
#
#             var marker_a6c21b40ce893ac3370f93c45cf3b707 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7a2be0a1ef614657684fe1ae43900ca5);
#
#
#         var popup_995096885a57aadb9921cf847bfb0376 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4782470c27e55df23690e4c75f52463f = $(`&lt;div id=&quot;html_4782470c27e55df23690e4c75f52463f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_995096885a57aadb9921cf847bfb0376.setContent(html_4782470c27e55df23690e4c75f52463f);
#
#
#
#         marker_a6c21b40ce893ac3370f93c45cf3b707.bindPopup(popup_995096885a57aadb9921cf847bfb0376)
#         ;
#
#
#
#
#             var marker_6b62627c0bc6206f7ba07ad678c2230d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7a2be0a1ef614657684fe1ae43900ca5);
#
#
#         var popup_4c7556fdc4b9e455a1639c2942d6c4bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d61703205d6bee2eb2df53d3a262a9e = $(`&lt;div id=&quot;html_0d61703205d6bee2eb2df53d3a262a9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4c7556fdc4b9e455a1639c2942d6c4bc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_201cc10839f50961cb3e5fa6bfe1cb36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_201cc10839f50961cb3e5fa6bfe1cb36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_201cc10839f50961cb3e5fa6bfe1cb36 = L.map(
#                 &quot;map_201cc10839f50961cb3e5fa6bfe1cb36&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85ed880d24e9cc282d08829178c657b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85ed880d24e9cc282d08829178c657b2.addTo(map_201cc10839f50961cb3e5fa6bfe1cb36);
#
#
#             var feature_group_997e6ff3c287ea76046b9736391d2600 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bbe5ad67f76af0cf36d4cf6e74328701 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_997e6ff3c287ea76046b9736391d2600);
#
#
#         var popup_c308965486e72f054c276191c3726a69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a665efe6ab99c62db2c4df903784d3c = $(`&lt;div id=&quot;html_4a665efe6ab99c62db2c4df903784d3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c308965486e72f054c276191c3726a69.setContent(html_4a665efe6ab99c62db2c4df903784d3c);
#
#
#
#         marker_bbe5ad67f76af0cf36d4cf6e74328701.bindPopup(popup_c308965486e72f054c276191c3726a69)
#         ;
#
#
#
#
#             var marker_1bbd91bed466f2ec7c0e5d938a1291c3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_997e6ff3c287ea76046b9736391d2600);
#
#
#         var popup_7f984016cbe7437b1482ba8cd8fd7595 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66c9240ee761489b98b04b3b76a9a539 = $(`&lt;div id=&quot;html_66c9240ee761489b98b04b3b76a9a539&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7f984016cbe7437b1482ba8cd8fd7595.setContent(html_66c9240ee761489b98b04b3b76a9a539);
#
#
#
#         marker_1bbd91bed466f2ec7c0e5d938a1291c3.bindPopup(popup_7f984016cbe7437b1482ba8cd8fd7595)
#         ;
#
#
#
#
#             var marker_4c8b8ed77975db358df42cd0b3f2d507 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_997e6ff3c287ea76046b9736391d2600);
#
#
#         var popup_c47e0abfcdfe23bd4b52c2b6f58cbf1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4627fb10457ad2b9089ace586650294 = $(`&lt;div id=&quot;html_c4627fb10457ad2b9089ace586650294&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c47e0abfcdfe23bd4b52c2b6f58cbf1f.setContent(html_c4627fb10457ad2b9089ace586650294);
#
#
#
#         marker_4c8b8ed77975db358df42cd0b3f2d507.bindPopup(popup_c47e0abfcdfe23bd4b52c2b6f58cbf1f)
#         ;
#
#
#
#
#             var marker_063522489682f5eb4726781275a6d669 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_997e6ff3c287ea76046b9736391d2600);
#
#
#         var popup_cdfccf817984250ecc48a8ee97f3e6a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c00f40c9c2a896ec933fd627ec67a808 = $(`&lt;div id=&quot;html_c00f40c9c2a896ec933fd627ec67a808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cdfccf817984250ecc48a8ee97f3e6a1.setContent(html_c00f40c9c2a896ec933fd627ec67a808);
#
#
#
#         marker_063522489682f5eb4726781275a6d669.bindPopup(popup_cdfccf817984250ecc48a8ee97f3e6a1)
#         ;
#
#
#
#
#             var marker_a14d8566ff9b17af4facabff55b1fc7c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_997e6ff3c287ea76046b9736391d2600);
#
#
#         var popup_6abf3deaeab95635f2766acfdd907106 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73815c1303a79ec3fafb220649e3cbb3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73815c1303a79ec3fafb220649e3cbb3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73815c1303a79ec3fafb220649e3cbb3 = L.map(
#                 &quot;map_73815c1303a79ec3fafb220649e3cbb3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ebedda2bf6e739a600e8e9ea52ec02a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ebedda2bf6e739a600e8e9ea52ec02a.addTo(map_73815c1303a79ec3fafb220649e3cbb3);
#
#
#             var feature_group_e833a0fea18c5cf962002a66c71666c9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e833a0fea18c5cf962002a66c71666c9.addTo(map_73815c1303a79ec3fafb220649e3cbb3);
#
#
#             var feature_group_sub_group_2a849580b9b002ae099dcfd6cca16dae = L.featureGroup.subGroup(
#                 feature_group_e833a0fea18c5cf962002a66c71666c9
#             );
#
#
#             var marker_bff9f0b16a71e0b428e3a73946f21895 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a849580b9b002ae099dcfd6cca16dae);
#
#
#         var popup_fbaf2ee30794db0e306fe687cb8b5112 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a551b186741bf73c46ba4be0180cfa0 = $(`&lt;div id=&quot;html_8a551b186741bf73c46ba4be0180cfa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fbaf2ee30794db0e306fe687cb8b5112.setContent(html_8a551b186741bf73c46ba4be0180cfa0);
#
#
#
#         marker_bff9f0b16a71e0b428e3a73946f21895.bindPopup(popup_fbaf2ee30794db0e306fe687cb8b5112)
#         ;
#
#
#
#
#             var marker_0cda4d249cca7504a961d03351b04d35 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a849580b9b002ae099dcfd6cca16dae);
#
#
#         var popup_931d6b0bbc57c52a8b79d9450007ab60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0548828b56bddb24b51ede4a9e758bb8 = $(`&lt;div id=&quot;html_0548828b56bddb24b51ede4a9e758bb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_931d6b0bbc57c52a8b79d9450007ab60.setContent(html_0548828b56bddb24b51ede4a9e758bb8);
#
#
#
#         marker_0cda4d249cca7504a961d03351b04d35.bindPopup(popup_931d6b0bbc57c52a8b79d9450007ab60)
#         ;
#
#
#
#
#             var marker_7ef25c0633370a9665af8f7eb1450c5e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a849580b9b002ae099dcfd6cca16dae);
#
#
#         var popup_35b88b49c2fa5fc25042661bdff7a383 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59d84d609f0cb07446aa2a0b5aab00b9 = $(`&lt;div id=&quot;html_59d84d609f0cb07446aa2a0b5aab00b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_35b88b49c2fa5fc25042661bdff7a383.setContent(html_59d84d609f0cb07446aa2a0b5aab00b9);
#
#
#
#         marker_7ef25c0633370a9665af8f7eb1450c5e.bindPopup(popup_35b88b49c2fa5fc25042661bdff7a383)
#         ;
#
#
#
#
#             var marker_691b320908cee8ba53840378dba94561 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2a849580b9b002ae099dcfd6cca16dae);
#
#
#         var popup_f31425af99be0e2f8d3abba9ee41254d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a61429512868f50a8932f6be60871acd = $(`&lt;div id=&quot;html_a61429512868f50a8932f6be60871acd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f31425af99be0e2f8d3abba9ee41254d.setContent(html_a61429512868f50a8932f6be60871acd);
#
#
#
#         marker_
