# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94a2fc3c03970507690fe5e6c1693623 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94a2fc3c03970507690fe5e6c1693623&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94a2fc3c03970507690fe5e6c1693623 = L.map(
#                 &quot;map_94a2fc3c03970507690fe5e6c1693623&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5047402b74a895d448e090167391fcd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5047402b74a895d448e090167391fcd.addTo(map_94a2fc3c03970507690fe5e6c1693623);
#
#
#             var marker_447c093ba105f829333dfd6c71a48664 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_94a2fc3c03970507690fe5e6c1693623);
#
#
#         var popup_b2421e643d2514ddbda6f309d958b379 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cf9993a2101d885a6718a43dd876bb5 = $(`&lt;div id=&quot;html_8cf9993a2101d885a6718a43dd876bb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b2421e643d2514ddbda6f309d958b379.setContent(html_8cf9993a2101d885a6718a43dd876bb5);
#
#
#
#         marker_447c093ba105f829333dfd6c71a48664.bindPopup(popup_b2421e643d2514ddbda6f309d958b379)
#         ;
#
#
#
#
#             var marker_3f1077c6b5f9f87688c54b738a06dde3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_94a2fc3c03970507690fe5e6c1693623);
#
#
#         var popup_e2004756586454866f629b0a9598e8ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d3b966e721fa0758918e34ee6a7ab28 = $(`&lt;div id=&quot;html_5d3b966e721fa0758918e34ee6a7ab28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e2004756586454866f629b0a9598e8ca.setContent(html_5d3b966e721fa0758918e34ee6a7ab28);
#
#
#
#         marker_3f1077c6b5f9f87688c54b738a06dde3.bindPopup(popup_e2004756586454866f629b0a9598e8ca)
#         ;
#
#
#
#
#             var marker_7d9f44a5aea0d529d227b21c274f77f1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_94a2fc3c03970507690fe5e6c1693623);
#
#
#         var popup_9a70da52a250fda4a42bf4ed73a165c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e067f5df3ab28f4319dc5bc734fd2b7 = $(`&lt;div id=&quot;html_2e067f5df3ab28f4319dc5bc734fd2b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9a70da52a250fda4a42bf4ed73a165c1.setContent(html_2e067f5df3ab28f4319dc5bc734fd2b7);
#
#
#
#         marker_7d9f44a5aea0d529d227b21c274f77f1.bindPopup(popup_9a70da52a250fda4a42bf4ed73a165c1)
#         ;
#
#
#
#
#             var marker_091d94bdc6e75216adf8ab9ab45609ec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_94a2fc3c03970507690fe5e6c1693623);
#
#
#         var popup_8de051ab2b2576ce14e53eaf86812e84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_062d4526bb2a778817dc92c6949a2212 = $(`&lt;div id=&quot;html_062d4526bb2a778817dc92c6949a2212&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8de051ab2b2576ce14e53eaf86812e84.setContent(html_062d4526bb2a778817dc92c6949a2212);
#
#
#
#         marker_091d94bdc6e75216adf8ab9ab45609ec.bindPopup(popup_8de051ab2b2576ce14e53eaf86812e84)
#         ;
#
#
#
#
#             var marker_f04dd699663ac568ccdf45b7b770fc61 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_94a2fc3c03970507690fe5e6c1693623);
#
#
#         var popup_e88939ef09d19301607d75d6a0891363 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c027617a48667c607cc5a0a5f106cb84 = $(`&lt;div id=&quot;html_c027617a48667c607cc5a0a5f106cb84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e88939ef09d19301607d75d6a0891363.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2123c02747ed05eaa49dd58a7006454 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2123c02747ed05eaa49dd58a7006454&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2123c02747ed05eaa49dd58a7006454 = L.map(
#                 &quot;map_f2123c02747ed05eaa49dd58a7006454&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb4fc56b889ca0dc4525d44a856d9faf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb4fc56b889ca0dc4525d44a856d9faf.addTo(map_f2123c02747ed05eaa49dd58a7006454);
#
#
#             var feature_group_2c1fda9addb96b9ca85db5e3f02fd827 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_849c6691bea2c58cbf662e9ef7f74ab1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2c1fda9addb96b9ca85db5e3f02fd827);
#
#
#         var popup_4a21b7a36202fd2e16dec2844360c4e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41dab672ca9983850a39a9a110d4006c = $(`&lt;div id=&quot;html_41dab672ca9983850a39a9a110d4006c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4a21b7a36202fd2e16dec2844360c4e6.setContent(html_41dab672ca9983850a39a9a110d4006c);
#
#
#
#         marker_849c6691bea2c58cbf662e9ef7f74ab1.bindPopup(popup_4a21b7a36202fd2e16dec2844360c4e6)
#         ;
#
#
#
#
#             var marker_20c8908417dbd6b65f6516cc129459ba = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2c1fda9addb96b9ca85db5e3f02fd827);
#
#
#         var popup_01fa9c72d14c4be4b5c035d6f44641bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f7cb894ebcd6eedf46b6df34e67318c = $(`&lt;div id=&quot;html_7f7cb894ebcd6eedf46b6df34e67318c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_01fa9c72d14c4be4b5c035d6f44641bb.setContent(html_7f7cb894ebcd6eedf46b6df34e67318c);
#
#
#
#         marker_20c8908417dbd6b65f6516cc129459ba.bindPopup(popup_01fa9c72d14c4be4b5c035d6f44641bb)
#         ;
#
#
#
#
#             var marker_5aefdfbe3dd184982b32a3faa7cefd3e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2c1fda9addb96b9ca85db5e3f02fd827);
#
#
#         var popup_84ef21d9026e44ab9fb5531cda120e77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_596314353dd76f3ed7f1081771cbbcb6 = $(`&lt;div id=&quot;html_596314353dd76f3ed7f1081771cbbcb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_84ef21d9026e44ab9fb5531cda120e77.setContent(html_596314353dd76f3ed7f1081771cbbcb6);
#
#
#
#         marker_5aefdfbe3dd184982b32a3faa7cefd3e.bindPopup(popup_84ef21d9026e44ab9fb5531cda120e77)
#         ;
#
#
#
#
#             var marker_1759c24a93986c225a2f46a8920da80b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2c1fda9addb96b9ca85db5e3f02fd827);
#
#
#         var popup_11f05112a3989c925b51da6a441f5ebf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e94dc38c9e2f1fd1f622538ae4529e4 = $(`&lt;div id=&quot;html_3e94dc38c9e2f1fd1f622538ae4529e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_11f05112a3989c925b51da6a441f5ebf.setContent(html_3e94dc38c9e2f1fd1f622538ae4529e4);
#
#
#
#         marker_1759c24a93986c225a2f46a8920da80b.bindPopup(popup_11f05112a3989c925b51da6a441f5ebf)
#         ;
#
#
#
#
#             var marker_bcd8c77c0e9bcba823476ac987c02878 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2c1fda9addb96b9ca85db5e3f02fd827);
#
#
#         var popup_c64c583fdf0e46be5d722f8e0315090f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6ecb99fad514d16435a0bb457d9ab58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6ecb99fad514d16435a0bb457d9ab58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6ecb99fad514d16435a0bb457d9ab58 = L.map(
#                 &quot;map_a6ecb99fad514d16435a0bb457d9ab58&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_329ae69c537e5febac39241541ecf7ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_329ae69c537e5febac39241541ecf7ea.addTo(map_a6ecb99fad514d16435a0bb457d9ab58);
#
#
#             var feature_group_15e5e999ed6e930d7d0444947d720a6d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_15e5e999ed6e930d7d0444947d720a6d.addTo(map_a6ecb99fad514d16435a0bb457d9ab58);
#
#
#             var feature_group_sub_group_da5e1ddcdcf0d2e5b010c743e4960568 = L.featureGroup.subGroup(
#                 feature_group_15e5e999ed6e930d7d0444947d720a6d
#             );
#
#
#             var marker_ce0e99663d2e8eccde35d473ad7a69ef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_da5e1ddcdcf0d2e5b010c743e4960568);
#
#
#         var popup_f2602271ef1f5db1c9c8d2d4314320ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1060a4f1c57f563c32103d64efa65f32 = $(`&lt;div id=&quot;html_1060a4f1c57f563c32103d64efa65f32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f2602271ef1f5db1c9c8d2d4314320ed.setContent(html_1060a4f1c57f563c32103d64efa65f32);
#
#
#
#         marker_ce0e99663d2e8eccde35d473ad7a69ef.bindPopup(popup_f2602271ef1f5db1c9c8d2d4314320ed)
#         ;
#
#
#
#
#             var marker_e523182eec35448b5061e1d3ce673220 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_da5e1ddcdcf0d2e5b010c743e4960568);
#
#
#         var popup_538000af48522ed561845bdfb544ca6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d90274c908dddf4d62c839a3624fc471 = $(`&lt;div id=&quot;html_d90274c908dddf4d62c839a3624fc471&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_538000af48522ed561845bdfb544ca6a.setContent(html_d90274c908dddf4d62c839a3624fc471);
#
#
#
#         marker_e523182eec35448b5061e1d3ce673220.bindPopup(popup_538000af48522ed561845bdfb544ca6a)
#         ;
#
#
#
#
#             var marker_7286c57e9810eb73540587ccc6988cfc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_da5e1ddcdcf0d2e5b010c743e4960568);
#
#
#         var popup_22865ce2184af868799b39297cf9d00b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80f05779b32769509afd0fa5e71ebda6 = $(`&lt;div id=&quot;html_80f05779b32769509afd0fa5e71ebda6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_22865ce2184af868799b39297cf9d00b.setContent(html_80f05779b32769509afd0fa5e71ebda6);
#
#
#
#         marker_7286c57e9810eb73540587ccc6988cfc.bindPopup(popup_22865ce2184af868799b39297cf9d00b)
#         ;
#
#
#
#
#             var marker_5fb49ac27bc0390c1011c00cf22cdc02 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_da5e1ddcdcf0d2e5b010c743e4960568);
#
#
#         var popup_37df9826a66475bd9d2a22458abc9a65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c69545a4e897b0b3e98b8ce3cf676737 = $(`&lt;div id=&quot;html_c69545a4e897b0b3e98b8ce3cf676737&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_37df9826a66475bd9d2a22458abc9a65.setContent(html_c69545a4e897b0b3e98b8ce3cf676737);
#
#
#
#         marker_
