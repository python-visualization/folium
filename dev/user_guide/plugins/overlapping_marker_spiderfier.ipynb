# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48b8d84faae0cd3f7f8157779f9b49b0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48b8d84faae0cd3f7f8157779f9b49b0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_48b8d84faae0cd3f7f8157779f9b49b0 = L.map(
#                 &quot;map_48b8d84faae0cd3f7f8157779f9b49b0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_842d838566fcaa5ac0d3b2c51df804b7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_842d838566fcaa5ac0d3b2c51df804b7.addTo(map_48b8d84faae0cd3f7f8157779f9b49b0);
#
#
#             var marker_222cc4d974e5fa22f45653d4caf666c1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_48b8d84faae0cd3f7f8157779f9b49b0);
#
#
#         var popup_3e1751d98adbde802d8552ccd42daa50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_321d51600690020d4d191e34f6e0dd07 = $(`&lt;div id=&quot;html_321d51600690020d4d191e34f6e0dd07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3e1751d98adbde802d8552ccd42daa50.setContent(html_321d51600690020d4d191e34f6e0dd07);
#
#
#
#         marker_222cc4d974e5fa22f45653d4caf666c1.bindPopup(popup_3e1751d98adbde802d8552ccd42daa50)
#         ;
#
#
#
#
#             var marker_ec5c32d55505b213811b7cbb4e79c161 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_48b8d84faae0cd3f7f8157779f9b49b0);
#
#
#         var popup_9d992bcf7d4c2aadbae112757ccfa77a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bb3b9d9357d7e3133797758091f473f = $(`&lt;div id=&quot;html_4bb3b9d9357d7e3133797758091f473f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9d992bcf7d4c2aadbae112757ccfa77a.setContent(html_4bb3b9d9357d7e3133797758091f473f);
#
#
#
#         marker_ec5c32d55505b213811b7cbb4e79c161.bindPopup(popup_9d992bcf7d4c2aadbae112757ccfa77a)
#         ;
#
#
#
#
#             var marker_4329ad2e33444f8d59d36368829aeae4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_48b8d84faae0cd3f7f8157779f9b49b0);
#
#
#         var popup_cede411cf9749b148d3889ee407b798d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2a3a8b3bb1d8e5337b9d3505a164821 = $(`&lt;div id=&quot;html_e2a3a8b3bb1d8e5337b9d3505a164821&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cede411cf9749b148d3889ee407b798d.setContent(html_e2a3a8b3bb1d8e5337b9d3505a164821);
#
#
#
#         marker_4329ad2e33444f8d59d36368829aeae4.bindPopup(popup_cede411cf9749b148d3889ee407b798d)
#         ;
#
#
#
#
#             var marker_f984cf04c23bfd62f56ca7d968ad4b74 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_48b8d84faae0cd3f7f8157779f9b49b0);
#
#
#         var popup_83764f34f09f9de7cb4f84cf3a6d1cc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df0bea51d52840b0405088df34429142 = $(`&lt;div id=&quot;html_df0bea51d52840b0405088df34429142&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_83764f34f09f9de7cb4f84cf3a6d1cc6.setContent(html_df0bea51d52840b0405088df34429142);
#
#
#
#         marker_f984cf04c23bfd62f56ca7d968ad4b74.bindPopup(popup_83764f34f09f9de7cb4f84cf3a6d1cc6)
#         ;
#
#
#
#
#             var marker_026f60479526cdabdf8e4d553b9831bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_48b8d84faae0cd3f7f8157779f9b49b0);
#
#
#         var popup_671ad34fbc347d6db20cbba3b9db1967 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8eb41d680fa6981b4f6afddf30576f25 = $(`&lt;div id=&quot;html_8eb41d680fa6981b4f6afddf30576f25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_671ad34fbc347d6db20cbba3b9db1967.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa7111e0dda68ab7e5f97c42eb72e599 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa7111e0dda68ab7e5f97c42eb72e599&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa7111e0dda68ab7e5f97c42eb72e599 = L.map(
#                 &quot;map_aa7111e0dda68ab7e5f97c42eb72e599&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a222fbde0182f5609b506387ec27972e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a222fbde0182f5609b506387ec27972e.addTo(map_aa7111e0dda68ab7e5f97c42eb72e599);
#
#
#             var feature_group_fbb5d97b015957f3f696fc76312861bb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c68959f68c4cd5a2baff96a8ebf84cbe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fbb5d97b015957f3f696fc76312861bb);
#
#
#         var popup_6641d45eb2eeb58471e4479c79520235 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac8c9874669b2016486502f5ce47111e = $(`&lt;div id=&quot;html_ac8c9874669b2016486502f5ce47111e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6641d45eb2eeb58471e4479c79520235.setContent(html_ac8c9874669b2016486502f5ce47111e);
#
#
#
#         marker_c68959f68c4cd5a2baff96a8ebf84cbe.bindPopup(popup_6641d45eb2eeb58471e4479c79520235)
#         ;
#
#
#
#
#             var marker_c1509b0985aad1024b7d2ec5a9642aba = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fbb5d97b015957f3f696fc76312861bb);
#
#
#         var popup_9c1dd788bf5d3e9a9a17ff0a9b7e175a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eac3884203dd8f01038dfa369a4179bf = $(`&lt;div id=&quot;html_eac3884203dd8f01038dfa369a4179bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9c1dd788bf5d3e9a9a17ff0a9b7e175a.setContent(html_eac3884203dd8f01038dfa369a4179bf);
#
#
#
#         marker_c1509b0985aad1024b7d2ec5a9642aba.bindPopup(popup_9c1dd788bf5d3e9a9a17ff0a9b7e175a)
#         ;
#
#
#
#
#             var marker_d8960339c167b15d72887c0c22a5c196 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fbb5d97b015957f3f696fc76312861bb);
#
#
#         var popup_859a416bd2bb2cfb5b5c3f9a58d5a2a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_604dfa3fc3b84cd1e3e946163c99336c = $(`&lt;div id=&quot;html_604dfa3fc3b84cd1e3e946163c99336c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_859a416bd2bb2cfb5b5c3f9a58d5a2a3.setContent(html_604dfa3fc3b84cd1e3e946163c99336c);
#
#
#
#         marker_d8960339c167b15d72887c0c22a5c196.bindPopup(popup_859a416bd2bb2cfb5b5c3f9a58d5a2a3)
#         ;
#
#
#
#
#             var marker_a99e0fcf1bf1b57f7f8d8898383ac204 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fbb5d97b015957f3f696fc76312861bb);
#
#
#         var popup_ed033fed042c1b0377df62a4867c53a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_712cfc0df679d08dcc3092d95b14289a = $(`&lt;div id=&quot;html_712cfc0df679d08dcc3092d95b14289a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ed033fed042c1b0377df62a4867c53a0.setContent(html_712cfc0df679d08dcc3092d95b14289a);
#
#
#
#         marker_a99e0fcf1bf1b57f7f8d8898383ac204.bindPopup(popup_ed033fed042c1b0377df62a4867c53a0)
#         ;
#
#
#
#
#             var marker_7b8b7b447e05eaea19338570430dd629 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fbb5d97b015957f3f696fc76312861bb);
#
#
#         var popup_a02824082bc13b25d91e5dda129c2689 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8687c817b4a35076e1c55b1bea44e6b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8687c817b4a35076e1c55b1bea44e6b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8687c817b4a35076e1c55b1bea44e6b2 = L.map(
#                 &quot;map_8687c817b4a35076e1c55b1bea44e6b2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d5a984b489b37f4dd821cfa7774b063c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d5a984b489b37f4dd821cfa7774b063c.addTo(map_8687c817b4a35076e1c55b1bea44e6b2);
#
#
#             var feature_group_b0212c80d6fb3095ae6ea6f41db853a2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b0212c80d6fb3095ae6ea6f41db853a2.addTo(map_8687c817b4a35076e1c55b1bea44e6b2);
#
#
#             var feature_group_sub_group_77391305699883998bc307a547896e36 = L.featureGroup.subGroup(
#                 feature_group_b0212c80d6fb3095ae6ea6f41db853a2
#             );
#
#
#             var marker_fe2438671b51784cf86d594d4aa3ad32 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_77391305699883998bc307a547896e36);
#
#
#         var popup_82d1eb6b9407e28e331a84f6e8b7c3a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c200efa40c1632fcf57c6f4c0b6fcba6 = $(`&lt;div id=&quot;html_c200efa40c1632fcf57c6f4c0b6fcba6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_82d1eb6b9407e28e331a84f6e8b7c3a5.setContent(html_c200efa40c1632fcf57c6f4c0b6fcba6);
#
#
#
#         marker_fe2438671b51784cf86d594d4aa3ad32.bindPopup(popup_82d1eb6b9407e28e331a84f6e8b7c3a5)
#         ;
#
#
#
#
#             var marker_c6200eee3ef461908530e4ce65b65759 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_77391305699883998bc307a547896e36);
#
#
#         var popup_7241b896433da800ffed06698cdf8a1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d07bc941c4189e9f995386900c108835 = $(`&lt;div id=&quot;html_d07bc941c4189e9f995386900c108835&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7241b896433da800ffed06698cdf8a1d.setContent(html_d07bc941c4189e9f995386900c108835);
#
#
#
#         marker_c6200eee3ef461908530e4ce65b65759.bindPopup(popup_7241b896433da800ffed06698cdf8a1d)
#         ;
#
#
#
#
#             var marker_b34a171fbdcbe4a4e8505d1b613ccf1c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_77391305699883998bc307a547896e36);
#
#
#         var popup_b6b406a35995a8b429b6f6f654479dd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16708f228c5317574e1506da6e5811a0 = $(`&lt;div id=&quot;html_16708f228c5317574e1506da6e5811a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b6b406a35995a8b429b6f6f654479dd4.setContent(html_16708f228c5317574e1506da6e5811a0);
#
#
#
#         marker_b34a171fbdcbe4a4e8505d1b613ccf1c.bindPopup(popup_b6b406a35995a8b429b6f6f654479dd4)
#         ;
#
#
#
#
#             var marker_7048e3ed0409bc4bf923b5bcd24bdb65 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_77391305699883998bc307a547896e36);
#
#
#         var popup_6fd4c95b4ae94dc5c48180594a610635 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e07296219ca2bba25c5fbbee48d82c9 = $(`&lt;div id=&quot;html_9e07296219ca2bba25c5fbbee48d82c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6fd4c95b4ae94dc5c48180594a610635.setContent(html_9e07296219ca2bba25c5fbbee48d82c9);
#
#
#
#         marker_
