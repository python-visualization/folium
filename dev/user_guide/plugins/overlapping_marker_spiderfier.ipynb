# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c366d8614900708fa06123f024785aeb {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c366d8614900708fa06123f024785aeb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c366d8614900708fa06123f024785aeb = L.map(
#                 &quot;map_c366d8614900708fa06123f024785aeb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38fa48cbb6ed7ad5cba010495969af89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38fa48cbb6ed7ad5cba010495969af89.addTo(map_c366d8614900708fa06123f024785aeb);
#
#
#             var marker_d4177d3c839eb362609b5ea269e2cdbb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c366d8614900708fa06123f024785aeb);
#
#
#         var popup_2263af6c510e69424c77c071409a6ec6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30f2530cdd1f6341d73fb0b520872e5b = $(`&lt;div id=&quot;html_30f2530cdd1f6341d73fb0b520872e5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2263af6c510e69424c77c071409a6ec6.setContent(html_30f2530cdd1f6341d73fb0b520872e5b);
#
#
#
#         marker_d4177d3c839eb362609b5ea269e2cdbb.bindPopup(popup_2263af6c510e69424c77c071409a6ec6)
#         ;
#
#
#
#
#             var marker_626140d346053feb4a8ad604d65af1bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c366d8614900708fa06123f024785aeb);
#
#
#         var popup_57065d87606d879716105084071db42d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c726eb5f5c0112154185e809f229906 = $(`&lt;div id=&quot;html_2c726eb5f5c0112154185e809f229906&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_57065d87606d879716105084071db42d.setContent(html_2c726eb5f5c0112154185e809f229906);
#
#
#
#         marker_626140d346053feb4a8ad604d65af1bf.bindPopup(popup_57065d87606d879716105084071db42d)
#         ;
#
#
#
#
#             var marker_31dfc566d045dbcb6df57bdf81223833 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c366d8614900708fa06123f024785aeb);
#
#
#         var popup_25baf4284ad0eb3822c33862bcd92f79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38b31b2fe50f896e73f482395f799ec6 = $(`&lt;div id=&quot;html_38b31b2fe50f896e73f482395f799ec6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_25baf4284ad0eb3822c33862bcd92f79.setContent(html_38b31b2fe50f896e73f482395f799ec6);
#
#
#
#         marker_31dfc566d045dbcb6df57bdf81223833.bindPopup(popup_25baf4284ad0eb3822c33862bcd92f79)
#         ;
#
#
#
#
#             var marker_44f61dcf818d1a895b2c49ecb91bbd7e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c366d8614900708fa06123f024785aeb);
#
#
#         var popup_36359d7f499ef204261e76cc5dd17265 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b476c7e91128bb3eb8e36d0c76b6515 = $(`&lt;div id=&quot;html_2b476c7e91128bb3eb8e36d0c76b6515&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_36359d7f499ef204261e76cc5dd17265.setContent(html_2b476c7e91128bb3eb8e36d0c76b6515);
#
#
#
#         marker_44f61dcf818d1a895b2c49ecb91bbd7e.bindPopup(popup_36359d7f499ef204261e76cc5dd17265)
#         ;
#
#
#
#
#             var marker_dfd595153d0e3c47ec567c1545fb7d61 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c366d8614900708fa06123f024785aeb);
#
#
#         var popup_87eb7d5f56662a378a48619f46c11ad6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dcab6e2bbe8c1dce47d720ef25fcdd1 = $(`&lt;div id=&quot;html_3dcab6e2bbe8c1dce47d720ef25fcdd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_87eb7d5f56662a378a48619f46c11ad6.setContent(html_3dcab6e2bbe8c1dce47d720ef25fcdd1);
#
#
#
#         marker_dfd595153d0e3c47ec567c1545fb7d61.bindPopup(popup_87eb7d5f56662a378a48619f46c11ad6)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa1f4d4c321516ead2b3492b77e1df93 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa1f4d4c321516ead2b3492b77e1df93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa1f4d4c321516ead2b3492b77e1df93 = L.map(
#                 &quot;map_aa1f4d4c321516ead2b3492b77e1df93&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_001b978b57c7342b61d640e569ab0b5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_001b978b57c7342b61d640e569ab0b5e.addTo(map_aa1f4d4c321516ead2b3492b77e1df93);
#
#
#             var feature_group_18daf1589898ad27692b6b034063cc94 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0c94ff5b8112d87b3334638414a5e60d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_18daf1589898ad27692b6b034063cc94);
#
#
#         var popup_ab3b933bacc28eac858971491f47924b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba26780d1da22131d03e6f224207d491 = $(`&lt;div id=&quot;html_ba26780d1da22131d03e6f224207d491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ab3b933bacc28eac858971491f47924b.setContent(html_ba26780d1da22131d03e6f224207d491);
#
#
#
#         marker_0c94ff5b8112d87b3334638414a5e60d.bindPopup(popup_ab3b933bacc28eac858971491f47924b)
#         ;
#
#
#
#
#             var marker_cd8360e146bbe5c8624e635185a63dc1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_18daf1589898ad27692b6b034063cc94);
#
#
#         var popup_fe0b61d637ded4eb798ce0fd5d4ab3e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_338a41084e7df98054dfd453ee99eb25 = $(`&lt;div id=&quot;html_338a41084e7df98054dfd453ee99eb25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fe0b61d637ded4eb798ce0fd5d4ab3e5.setContent(html_338a41084e7df98054dfd453ee99eb25);
#
#
#
#         marker_cd8360e146bbe5c8624e635185a63dc1.bindPopup(popup_fe0b61d637ded4eb798ce0fd5d4ab3e5)
#         ;
#
#
#
#
#             var marker_897bc5b62a4c32956365fb4a848a3971 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_18daf1589898ad27692b6b034063cc94);
#
#
#         var popup_8134894cf0e766296e9b3271a51a3a47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e4665d1daa15f8978434e0f2475cadc = $(`&lt;div id=&quot;html_6e4665d1daa15f8978434e0f2475cadc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8134894cf0e766296e9b3271a51a3a47.setContent(html_6e4665d1daa15f8978434e0f2475cadc);
#
#
#
#         marker_897bc5b62a4c32956365fb4a848a3971.bindPopup(popup_8134894cf0e766296e9b3271a51a3a47)
#         ;
#
#
#
#
#             var marker_244fc41a87a68f2142c48c09dfb62eae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_18daf1589898ad27692b6b034063cc94);
#
#
#         var popup_ae008fdf1152f0159e5ed9da5de274c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_906e500036bc6d3644cc49b87b1f9c03 = $(`&lt;div id=&quot;html_906e500036bc6d3644cc49b87b1f9c03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ae008fdf1152f0159e5ed9da5de274c4.setContent(html_906e500036bc6d3644cc49b87b1f9c03);
#
#
#
#         marker_244fc41a87a68f2142c48c09dfb62eae.bindPopup(popup_ae008fdf1152f0159e5ed9da5de274c4)
#         ;
#
#
#
#
#             var marker_d95eaa7a9fb0bb6e0cff22a3a0fef14c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_18daf1589898ad27692b6b034063cc94);
#
#
#         var popup_451c109ba4e3bd3ac7019a5da242e9b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0f144f344ea3eecdc3f59607a93ea81 = $(`&lt;div id=&quot;html_a0f144f344ea3eecdc3f59607a93ea81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0fba88f6758f7ae98e8dd2105c437fb {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0fba88f6758f7ae98e8dd2105c437fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0fba88f6758f7ae98e8dd2105c437fb = L.map(
#                 &quot;map_f0fba88f6758f7ae98e8dd2105c437fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11ed5d1e7909d8cc4cace46afd47c7db = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_11ed5d1e7909d8cc4cace46afd47c7db.addTo(map_f0fba88f6758f7ae98e8dd2105c437fb);
#
#
#             var feature_group_06b1a8d43da44f7c64d3cc2fbfef2001 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_06b1a8d43da44f7c64d3cc2fbfef2001.addTo(map_f0fba88f6758f7ae98e8dd2105c437fb);
#
#
#             var feature_group_sub_group_7cb88f113b9f4e6a778738ddf1e2548a = L.featureGroup.subGroup(
#                 feature_group_06b1a8d43da44f7c64d3cc2fbfef2001
#             );
#
#
#             var marker_b00ab4e556141f7ea13ef7d2d81ba0f8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7cb88f113b9f4e6a778738ddf1e2548a);
#
#
#         var popup_fdb0e020329ffe42a3cd126c23b247a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_682ee30d89d088916481c34f892f9fdd = $(`&lt;div id=&quot;html_682ee30d89d088916481c34f892f9fdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fdb0e020329ffe42a3cd126c23b247a0.setContent(html_682ee30d89d088916481c34f892f9fdd);
#
#
#
#         marker_b00ab4e556141f7ea13ef7d2d81ba0f8.bindPopup(popup_fdb0e020329ffe42a3cd126c23b247a0)
#         ;
#
#
#
#
#             var marker_3886c80912d9ffa47d6ca5f1f7649612 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7cb88f113b9f4e6a778738ddf1e2548a);
#
#
#         var popup_1d96baa9b666c6dcc2ab522bf745cc5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89781841cc78b3e71bc5f3cb7780d07a = $(`&lt;div id=&quot;html_89781841cc78b3e71bc5f3cb7780d07a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1d96baa9b666c6dcc2ab522bf745cc5c.setContent(html_89781841cc78b3e71bc5f3cb7780d07a);
#
#
#
#         marker_3886c80912d9ffa47d6ca5f1f7649612.bindPopup(popup_1d96baa9b666c6dcc2ab522bf745cc5c)
#         ;
#
#
#
#
#             var marker_a42884325c083848919b58bba9f2d9cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7cb88f113b9f4e6a778738ddf1e2548a);
#
#
#         var popup_6e998ec02963242ea295faaa80a6221e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4903e8563c4d523a30735d1df3426a6f = $(`&lt;div id=&quot;html_4903e8563c4d523a30735d1df3426a6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6e998ec02963242ea295faaa80a6221e.setContent(html_4903e8563c4d523a30735d1df3426a6f);
#
#
#
#         marker_a42884325c083848919b58bba9f2d9cd.bindPopup(popup_6e998ec02963242ea295faaa80a6221e)
#         ;
#
#
#
#
#             var marker_3c6bf4aaaa0ae7ba98b78fa279123478 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7cb88f113b9f4e6a778738ddf1e2548a);
#
#
#         var popup_3215c8af2b2c5a32872c49e2040c2abd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0895f17d97f08964c0538dba52a078a = $(`&lt;div id=&quot;html_c0895f17d97f08964c0538dba52a078a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3215c8af2b2c5a32872c49e2040c2abd.setContent(html_c0895f17d97f08964c0538dba52a078a);
#
#
#
#         marker_3c6bf4aaaa0ae7ba98b78fa279123478.bindPopup(popup_3215c8af2b2c5a32872c49e2040c2abd)
#         ;
#
#
#
#
#             var marker_662a38e44fa7b68770556386d68eb601 = L.marker(
#                 [45.0503999
