# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fff687956d302ad9d87e24c37f3f1fc0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fff687956d302ad9d87e24c37f3f1fc0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fff687956d302ad9d87e24c37f3f1fc0 = L.map(
#                 &quot;map_fff687956d302ad9d87e24c37f3f1fc0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f2f04e42f3de28b151b5e0e86e96f5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f2f04e42f3de28b151b5e0e86e96f5e.addTo(map_fff687956d302ad9d87e24c37f3f1fc0);
#
#
#             var marker_fd82dacc4017b01be717178370566e06 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fff687956d302ad9d87e24c37f3f1fc0);
#
#
#         var popup_7712df384bfc2843849eadee85fce6b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3226f4bb10f9b0a4e42d2d3e6318feb8 = $(`&lt;div id=&quot;html_3226f4bb10f9b0a4e42d2d3e6318feb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7712df384bfc2843849eadee85fce6b8.setContent(html_3226f4bb10f9b0a4e42d2d3e6318feb8);
#
#
#
#         marker_fd82dacc4017b01be717178370566e06.bindPopup(popup_7712df384bfc2843849eadee85fce6b8)
#         ;
#
#
#
#
#             var marker_050e82f688840f353749db824fbca3de = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fff687956d302ad9d87e24c37f3f1fc0);
#
#
#         var popup_aae33865cffecc1e323dadbbfcf9d4c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71b394a41a62a4ab0b8eeb87a1150ce8 = $(`&lt;div id=&quot;html_71b394a41a62a4ab0b8eeb87a1150ce8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_aae33865cffecc1e323dadbbfcf9d4c4.setContent(html_71b394a41a62a4ab0b8eeb87a1150ce8);
#
#
#
#         marker_050e82f688840f353749db824fbca3de.bindPopup(popup_aae33865cffecc1e323dadbbfcf9d4c4)
#         ;
#
#
#
#
#             var marker_598d2712eceea856275a84e5123dd191 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fff687956d302ad9d87e24c37f3f1fc0);
#
#
#         var popup_81badd365b33461df6848adf08df2d45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2340a43640084fb8caf9c414b1a98c0f = $(`&lt;div id=&quot;html_2340a43640084fb8caf9c414b1a98c0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_81badd365b33461df6848adf08df2d45.setContent(html_2340a43640084fb8caf9c414b1a98c0f);
#
#
#
#         marker_598d2712eceea856275a84e5123dd191.bindPopup(popup_81badd365b33461df6848adf08df2d45)
#         ;
#
#
#
#
#             var marker_c0e52d8475b7ab38a097d844ad78cc7f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fff687956d302ad9d87e24c37f3f1fc0);
#
#
#         var popup_0ee4b5d509cd362320456b47da8efa67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d737ffb527da0a7bab00e3b76f7d827 = $(`&lt;div id=&quot;html_9d737ffb527da0a7bab00e3b76f7d827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0ee4b5d509cd362320456b47da8efa67.setContent(html_9d737ffb527da0a7bab00e3b76f7d827);
#
#
#
#         marker_c0e52d8475b7ab38a097d844ad78cc7f.bindPopup(popup_0ee4b5d509cd362320456b47da8efa67)
#         ;
#
#
#
#
#             var marker_2859205990a3ff749e676eac2fff1af0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fff687956d302ad9d87e24c37f3f1fc0);
#
#
#         var popup_6c7d95ae4f043dcd8b31133b6bc3850f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45ab7858cfb106c26251bc89da14e96d = $(`&lt;div id=&quot;html_45ab7858cfb106c26251bc89da14e96d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6c7d95ae4f043dcd8b31133b6bc385

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_894757c9d6ddbb99c3ecd4d4a0e6ae0a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_894757c9d6ddbb99c3ecd4d4a0e6ae0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_894757c9d6ddbb99c3ecd4d4a0e6ae0a = L.map(
#                 &quot;map_894757c9d6ddbb99c3ecd4d4a0e6ae0a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f7d3d5d84315ec6bf2bcbc8ffac54ff = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f7d3d5d84315ec6bf2bcbc8ffac54ff.addTo(map_894757c9d6ddbb99c3ecd4d4a0e6ae0a);
#
#
#             var feature_group_0a41f19b2e1e47732a30dedc42d9810d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a4f2851768341c4cb994a2ad04a305b7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0a41f19b2e1e47732a30dedc42d9810d);
#
#
#         var popup_b0db333222c1ddc11d06fb857b470839 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27682019f249f27c050a2e69ec3e987f = $(`&lt;div id=&quot;html_27682019f249f27c050a2e69ec3e987f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b0db333222c1ddc11d06fb857b470839.setContent(html_27682019f249f27c050a2e69ec3e987f);
#
#
#
#         marker_a4f2851768341c4cb994a2ad04a305b7.bindPopup(popup_b0db333222c1ddc11d06fb857b470839)
#         ;
#
#
#
#
#             var marker_fd75d81be500e1a210f81df176cfdcd3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0a41f19b2e1e47732a30dedc42d9810d);
#
#
#         var popup_970a2f6ed3bd009f1f0e2a2f6490b07e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7432475693f9aab598f07aea416c95a4 = $(`&lt;div id=&quot;html_7432475693f9aab598f07aea416c95a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_970a2f6ed3bd009f1f0e2a2f6490b07e.setContent(html_7432475693f9aab598f07aea416c95a4);
#
#
#
#         marker_fd75d81be500e1a210f81df176cfdcd3.bindPopup(popup_970a2f6ed3bd009f1f0e2a2f6490b07e)
#         ;
#
#
#
#
#             var marker_a9460f410c76e20dc733984ddd2b57f2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0a41f19b2e1e47732a30dedc42d9810d);
#
#
#         var popup_142e7054082a9fa63b26ff469cddcfd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2788e2e79b8896bd051c56f58bc03ecb = $(`&lt;div id=&quot;html_2788e2e79b8896bd051c56f58bc03ecb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_142e7054082a9fa63b26ff469cddcfd4.setContent(html_2788e2e79b8896bd051c56f58bc03ecb);
#
#
#
#         marker_a9460f410c76e20dc733984ddd2b57f2.bindPopup(popup_142e7054082a9fa63b26ff469cddcfd4)
#         ;
#
#
#
#
#             var marker_1f50e40584fd29033129c216d507368e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0a41f19b2e1e47732a30dedc42d9810d);
#
#
#         var popup_063ee105437494ec8576e747c45ded92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adb027b21ace5b08fcb51c8296761393 = $(`&lt;div id=&quot;html_adb027b21ace5b08fcb51c8296761393&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_063ee105437494ec8576e747c45ded92.setContent(html_adb027b21ace5b08fcb51c8296761393);
#
#
#
#         marker_1f50e40584fd29033129c216d507368e.bindPopup(popup_063ee105437494ec8576e747c45ded92)
#         ;
#
#
#
#
#             var marker_b6833646b869ef9befb6dabc8fb4b165 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0a41f19b2e1e47732a30dedc42d9810d);
#
#
#         var popup_2b911572c01507213caacad579330b06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a10de95c2610d9ff84b6313f696cee4e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a10de95c2610d9ff84b6313f696cee4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a10de95c2610d9ff84b6313f696cee4e = L.map(
#                 &quot;map_a10de95c2610d9ff84b6313f696cee4e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f69c41887db98c7b012934025d2a0bcb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f69c41887db98c7b012934025d2a0bcb.addTo(map_a10de95c2610d9ff84b6313f696cee4e);
#
#
#             var feature_group_ecc6d12bb8db3cdd2076962a60df55a7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ecc6d12bb8db3cdd2076962a60df55a7.addTo(map_a10de95c2610d9ff84b6313f696cee4e);
#
#
#             var feature_group_sub_group_c92a5345008383e37290f536f65fb241 = L.featureGroup.subGroup(
#                 feature_group_ecc6d12bb8db3cdd2076962a60df55a7
#             );
#
#
#             var marker_501a318dfd3a4f60db3e8dac7bcfc002 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c92a5345008383e37290f536f65fb241);
#
#
#         var popup_fcda67103cf7261247cb620b94f8cf27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4900200933d77bef568950f043b66666 = $(`&lt;div id=&quot;html_4900200933d77bef568950f043b66666&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fcda67103cf7261247cb620b94f8cf27.setContent(html_4900200933d77bef568950f043b66666);
#
#
#
#         marker_501a318dfd3a4f60db3e8dac7bcfc002.bindPopup(popup_fcda67103cf7261247cb620b94f8cf27)
#         ;
#
#
#
#
#             var marker_b0aebe92815d91f5ac7c4be06128654d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c92a5345008383e37290f536f65fb241);
#
#
#         var popup_385dd5a692d4a5f1c98a564ba9a1d082 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d674621a1a4a846b734d1cdf84b5905 = $(`&lt;div id=&quot;html_8d674621a1a4a846b734d1cdf84b5905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_385dd5a692d4a5f1c98a564ba9a1d082.setContent(html_8d674621a1a4a846b734d1cdf84b5905);
#
#
#
#         marker_b0aebe92815d91f5ac7c4be06128654d.bindPopup(popup_385dd5a692d4a5f1c98a564ba9a1d082)
#         ;
#
#
#
#
#             var marker_8b535fd574e0aabad5b1245795990e0d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c92a5345008383e37290f536f65fb241);
#
#
#         var popup_674d3a843553d50d31998afc1e2e40be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef74259b911811af4cb81adaa6f79efe = $(`&lt;div id=&quot;html_ef74259b911811af4cb81adaa6f79efe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_674d3a843553d50d31998afc1e2e40be.setContent(html_ef74259b911811af4cb81adaa6f79efe);
#
#
#
#         marker_8b535fd574e0aabad5b1245795990e0d.bindPopup(popup_674d3a843553d50d31998afc1e2e40be)
#         ;
#
#
#
#
#             var marker_2cdca70d35c2c2833aa1a6012d50a40d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c92a5345008383e37290f536f65fb241);
#
#
#         var popup_1d02483f2060527086be56d7ed25e7c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_986a4a0c7fcd6b6ca7ffcf32674fa17b = $(`&lt;div id=&quot;html_986a4a0c7fcd6b6ca7ffcf32674fa17b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1d02483f2060527086be56d7ed25e7c8.setContent(html_986a4a0c7fcd6b6ca7ffcf32674fa17b);
#
#
#
#         mark
