# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e9cf134b2195214b5b081c341fa991c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e9cf134b2195214b5b081c341fa991c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e9cf134b2195214b5b081c341fa991c = L.map(
#                 &quot;map_6e9cf134b2195214b5b081c341fa991c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61be04da7ea5df1889c604a920f3f098 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61be04da7ea5df1889c604a920f3f098.addTo(map_6e9cf134b2195214b5b081c341fa991c);
#
#
#             var marker_75ad8f30ed163dd0e1435df285563142 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6e9cf134b2195214b5b081c341fa991c);
#
#
#         var popup_b5460432c308bafdc291b79d1ba6c3ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b74554cb5b5c993a4d27c4fec7b40911 = $(`&lt;div id=&quot;html_b74554cb5b5c993a4d27c4fec7b40911&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b5460432c308bafdc291b79d1ba6c3ea.setContent(html_b74554cb5b5c993a4d27c4fec7b40911);
#
#
#
#         marker_75ad8f30ed163dd0e1435df285563142.bindPopup(popup_b5460432c308bafdc291b79d1ba6c3ea)
#         ;
#
#
#
#
#             var marker_22b95840d2618a4f938c5ca5e5c5abbd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6e9cf134b2195214b5b081c341fa991c);
#
#
#         var popup_b5c8212010f53b752ed148baf4ba1efa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43f613a4891651250df7f1bdadd01ad1 = $(`&lt;div id=&quot;html_43f613a4891651250df7f1bdadd01ad1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b5c8212010f53b752ed148baf4ba1efa.setContent(html_43f613a4891651250df7f1bdadd01ad1);
#
#
#
#         marker_22b95840d2618a4f938c5ca5e5c5abbd.bindPopup(popup_b5c8212010f53b752ed148baf4ba1efa)
#         ;
#
#
#
#
#             var marker_a89550957e876a251a5f9fdb331a3083 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6e9cf134b2195214b5b081c341fa991c);
#
#
#         var popup_bef9015e4935a09fa6976634cac6909f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_334f1c7a34f3a4914323aedfd47b00b7 = $(`&lt;div id=&quot;html_334f1c7a34f3a4914323aedfd47b00b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bef9015e4935a09fa6976634cac6909f.setContent(html_334f1c7a34f3a4914323aedfd47b00b7);
#
#
#
#         marker_a89550957e876a251a5f9fdb331a3083.bindPopup(popup_bef9015e4935a09fa6976634cac6909f)
#         ;
#
#
#
#
#             var marker_bd6c254de64e6e37064826b9a62b1b9b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6e9cf134b2195214b5b081c341fa991c);
#
#
#         var popup_1763cf103b47a47e908ed752e11b9c25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2fcebe42d43962c7f168e44830dc81b = $(`&lt;div id=&quot;html_e2fcebe42d43962c7f168e44830dc81b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1763cf103b47a47e908ed752e11b9c25.setContent(html_e2fcebe42d43962c7f168e44830dc81b);
#
#
#
#         marker_bd6c254de64e6e37064826b9a62b1b9b.bindPopup(popup_1763cf103b47a47e908ed752e11b9c25)
#         ;
#
#
#
#
#             var marker_66b9995baba96d7d1de4da18fa13ec31 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6e9cf134b2195214b5b081c341fa991c);
#
#
#         var popup_dc8535b136b93cc9598e12c5d5deee2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6597a437c9a472fc5ae56b73d336379 = $(`&lt;div id=&quot;html_c6597a437c9a472fc5ae56b73d336379&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dc8535b136b93cc9598e12c5d5deee2d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06b58d6d24865abcda0ffd7e473b018f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06b58d6d24865abcda0ffd7e473b018f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06b58d6d24865abcda0ffd7e473b018f = L.map(
#                 &quot;map_06b58d6d24865abcda0ffd7e473b018f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_662fc352b203cea234901d5d6e2e6125 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_662fc352b203cea234901d5d6e2e6125.addTo(map_06b58d6d24865abcda0ffd7e473b018f);
#
#
#             var feature_group_e04fb5a1213218378788e86a0ac8e1c2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_089371b9f3bc5d27c49f31c30438a39d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e04fb5a1213218378788e86a0ac8e1c2);
#
#
#         var popup_4da41468d5575d7585ec7d57077b55c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4b2b8dd655fa5f852185477205f1648 = $(`&lt;div id=&quot;html_d4b2b8dd655fa5f852185477205f1648&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4da41468d5575d7585ec7d57077b55c6.setContent(html_d4b2b8dd655fa5f852185477205f1648);
#
#
#
#         marker_089371b9f3bc5d27c49f31c30438a39d.bindPopup(popup_4da41468d5575d7585ec7d57077b55c6)
#         ;
#
#
#
#
#             var marker_748475445e21c74d3f55f0ec08e46aa3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e04fb5a1213218378788e86a0ac8e1c2);
#
#
#         var popup_29d14a583c5494df5b84e7dd8f3d9302 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36e4b90414ba2cafd9725a3b3b0fbcdb = $(`&lt;div id=&quot;html_36e4b90414ba2cafd9725a3b3b0fbcdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_29d14a583c5494df5b84e7dd8f3d9302.setContent(html_36e4b90414ba2cafd9725a3b3b0fbcdb);
#
#
#
#         marker_748475445e21c74d3f55f0ec08e46aa3.bindPopup(popup_29d14a583c5494df5b84e7dd8f3d9302)
#         ;
#
#
#
#
#             var marker_1fc64323962a8f85af5d1c0bd0729bd9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e04fb5a1213218378788e86a0ac8e1c2);
#
#
#         var popup_a315cf21d76d2f0e462eeea44464f87b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_324e9fe784f76c7c007ef16c5b1f5485 = $(`&lt;div id=&quot;html_324e9fe784f76c7c007ef16c5b1f5485&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a315cf21d76d2f0e462eeea44464f87b.setContent(html_324e9fe784f76c7c007ef16c5b1f5485);
#
#
#
#         marker_1fc64323962a8f85af5d1c0bd0729bd9.bindPopup(popup_a315cf21d76d2f0e462eeea44464f87b)
#         ;
#
#
#
#
#             var marker_270ad5eb8dc80e0c44f21c25bc2da601 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e04fb5a1213218378788e86a0ac8e1c2);
#
#
#         var popup_9532917269988146400cb24110a92bcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16b1fad6c247eff5cb475ebc61311472 = $(`&lt;div id=&quot;html_16b1fad6c247eff5cb475ebc61311472&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9532917269988146400cb24110a92bcb.setContent(html_16b1fad6c247eff5cb475ebc61311472);
#
#
#
#         marker_270ad5eb8dc80e0c44f21c25bc2da601.bindPopup(popup_9532917269988146400cb24110a92bcb)
#         ;
#
#
#
#
#             var marker_3cf437756133a31f803f49ad8c760d3b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e04fb5a1213218378788e86a0ac8e1c2);
#
#
#         var popup_4caadb484437676381b61f1bfa9910b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76f34faec4cfbcec01c8e806824cd846 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76f34faec4cfbcec01c8e806824cd846&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76f34faec4cfbcec01c8e806824cd846 = L.map(
#                 &quot;map_76f34faec4cfbcec01c8e806824cd846&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a26e5f2dd43ed7433159bb78cf7f521 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a26e5f2dd43ed7433159bb78cf7f521.addTo(map_76f34faec4cfbcec01c8e806824cd846);
#
#
#             var feature_group_3ae66a476c373dc0c76f422ad71031a6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3ae66a476c373dc0c76f422ad71031a6.addTo(map_76f34faec4cfbcec01c8e806824cd846);
#
#
#             var feature_group_sub_group_0f332243f37060e2413d0015428e4027 = L.featureGroup.subGroup(
#                 feature_group_3ae66a476c373dc0c76f422ad71031a6
#             );
#
#
#             var marker_aa6031aff37dfa8e1ca5866e6a26da93 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f332243f37060e2413d0015428e4027);
#
#
#         var popup_67be5831eb4d58000bc888c4d167426d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be85e5d9931133db1298b6348e4aea4d = $(`&lt;div id=&quot;html_be85e5d9931133db1298b6348e4aea4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_67be5831eb4d58000bc888c4d167426d.setContent(html_be85e5d9931133db1298b6348e4aea4d);
#
#
#
#         marker_aa6031aff37dfa8e1ca5866e6a26da93.bindPopup(popup_67be5831eb4d58000bc888c4d167426d)
#         ;
#
#
#
#
#             var marker_7fcc25b3c0cfd309236ebcea7fd1947e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f332243f37060e2413d0015428e4027);
#
#
#         var popup_97d8a8c1d38b57fd346c382c2864d3c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b691f93cd805fd804568ed37bab491e8 = $(`&lt;div id=&quot;html_b691f93cd805fd804568ed37bab491e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_97d8a8c1d38b57fd346c382c2864d3c3.setContent(html_b691f93cd805fd804568ed37bab491e8);
#
#
#
#         marker_7fcc25b3c0cfd309236ebcea7fd1947e.bindPopup(popup_97d8a8c1d38b57fd346c382c2864d3c3)
#         ;
#
#
#
#
#             var marker_3df6e0f665c7893111908098de280893 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f332243f37060e2413d0015428e4027);
#
#
#         var popup_f593b28a3680231390c9ec4a3557f13a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0ca8c8adc61eec1a07bd4d40ec733b5 = $(`&lt;div id=&quot;html_b0ca8c8adc61eec1a07bd4d40ec733b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f593b28a3680231390c9ec4a3557f13a.setContent(html_b0ca8c8adc61eec1a07bd4d40ec733b5);
#
#
#
#         marker_3df6e0f665c7893111908098de280893.bindPopup(popup_f593b28a3680231390c9ec4a3557f13a)
#         ;
#
#
#
#
#             var marker_b618ba5a2caeb72879e429a35b0bb8c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0f332243f37060e2413d0015428e4027);
#
#
#         var popup_58175e812067604e1344644a26fe843e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76e5876b57ef628a5f9b3fe3a3a965ec = $(`&lt;div id=&quot;html_76e5876b57ef628a5f9b3fe3a3a965ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_58175e812067604e1344644a26fe843e.setContent(html_76e5876b57ef628a5f9b3fe3a3a965ec);
#
#
#
#         marker_
