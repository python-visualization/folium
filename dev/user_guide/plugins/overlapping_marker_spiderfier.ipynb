# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bfcb1fcdb15777b64dd7e19b95f37066 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bfcb1fcdb15777b64dd7e19b95f37066&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bfcb1fcdb15777b64dd7e19b95f37066 = L.map(
#                 &quot;map_bfcb1fcdb15777b64dd7e19b95f37066&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9eea40e94a5cbe6d5c0cb31817a1bc3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a9eea40e94a5cbe6d5c0cb31817a1bc3.addTo(map_bfcb1fcdb15777b64dd7e19b95f37066);
#
#
#             var marker_970be0bc9779723ca8a6258220299820 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bfcb1fcdb15777b64dd7e19b95f37066);
#
#
#         var popup_380e81296cd56b9a550e1c314ee1448e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29e9d5f39e59acd8a65069589f69ce48 = $(`&lt;div id=&quot;html_29e9d5f39e59acd8a65069589f69ce48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_380e81296cd56b9a550e1c314ee1448e.setContent(html_29e9d5f39e59acd8a65069589f69ce48);
#
#
#
#         marker_970be0bc9779723ca8a6258220299820.bindPopup(popup_380e81296cd56b9a550e1c314ee1448e)
#         ;
#
#
#
#
#             var marker_af5cf66fd2292682b80bae1c2bc826c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bfcb1fcdb15777b64dd7e19b95f37066);
#
#
#         var popup_ac4387553b59399be4611b65eb685896 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcc0b7cd5b2ff752dc0b2a3b5d177c61 = $(`&lt;div id=&quot;html_bcc0b7cd5b2ff752dc0b2a3b5d177c61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ac4387553b59399be4611b65eb685896.setContent(html_bcc0b7cd5b2ff752dc0b2a3b5d177c61);
#
#
#
#         marker_af5cf66fd2292682b80bae1c2bc826c4.bindPopup(popup_ac4387553b59399be4611b65eb685896)
#         ;
#
#
#
#
#             var marker_19aa61c897abe6d45891c5a8da4724b9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bfcb1fcdb15777b64dd7e19b95f37066);
#
#
#         var popup_9df0a699d822dabb6745347ae9a9aa27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_352134cd70303e94ec571064ef3c1ba5 = $(`&lt;div id=&quot;html_352134cd70303e94ec571064ef3c1ba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9df0a699d822dabb6745347ae9a9aa27.setContent(html_352134cd70303e94ec571064ef3c1ba5);
#
#
#
#         marker_19aa61c897abe6d45891c5a8da4724b9.bindPopup(popup_9df0a699d822dabb6745347ae9a9aa27)
#         ;
#
#
#
#
#             var marker_e464f6a2a35fbfb2b1a386d3294e2162 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bfcb1fcdb15777b64dd7e19b95f37066);
#
#
#         var popup_6db1de3cc2a262b8c5a6fcd0cbb86927 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9669260c2f12de764394e89d8b299f79 = $(`&lt;div id=&quot;html_9669260c2f12de764394e89d8b299f79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6db1de3cc2a262b8c5a6fcd0cbb86927.setContent(html_9669260c2f12de764394e89d8b299f79);
#
#
#
#         marker_e464f6a2a35fbfb2b1a386d3294e2162.bindPopup(popup_6db1de3cc2a262b8c5a6fcd0cbb86927)
#         ;
#
#
#
#
#             var marker_b10aeefe29a7444ca2c3ae4e34b73e11 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bfcb1fcdb15777b64dd7e19b95f37066);
#
#
#         var popup_d03e7b8f15a9f42f0eaca8c7dcaa0d5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e91f03ced808938a063773c1b8d89bc3 = $(`&lt;div id=&quot;html_e91f03ced808938a063773c1b8d89bc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d03e7b8f15a9f42f0eaca8c7dcaa0d5c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81b18d7fb3365ff1854fb33c33da0446 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81b18d7fb3365ff1854fb33c33da0446&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81b18d7fb3365ff1854fb33c33da0446 = L.map(
#                 &quot;map_81b18d7fb3365ff1854fb33c33da0446&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_866d5470e29e287a9f566cb26a03fa85 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_866d5470e29e287a9f566cb26a03fa85.addTo(map_81b18d7fb3365ff1854fb33c33da0446);
#
#
#             var feature_group_3b349bc36071824b878a041a5587ea10 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5a88e83c55fcd2804935d845e04a3b0a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3b349bc36071824b878a041a5587ea10);
#
#
#         var popup_982f289d6c36a7e941348e6801aa5833 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c66d66d0e7f0c2dc913ff82c6f2c1fad = $(`&lt;div id=&quot;html_c66d66d0e7f0c2dc913ff82c6f2c1fad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_982f289d6c36a7e941348e6801aa5833.setContent(html_c66d66d0e7f0c2dc913ff82c6f2c1fad);
#
#
#
#         marker_5a88e83c55fcd2804935d845e04a3b0a.bindPopup(popup_982f289d6c36a7e941348e6801aa5833)
#         ;
#
#
#
#
#             var marker_4693f363f1d666b0c7a426e9f82a2731 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3b349bc36071824b878a041a5587ea10);
#
#
#         var popup_2aa9ab5459ddbf1a743e809a21a6aac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cce774347cb2a6d360f641b5f0658e29 = $(`&lt;div id=&quot;html_cce774347cb2a6d360f641b5f0658e29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2aa9ab5459ddbf1a743e809a21a6aac1.setContent(html_cce774347cb2a6d360f641b5f0658e29);
#
#
#
#         marker_4693f363f1d666b0c7a426e9f82a2731.bindPopup(popup_2aa9ab5459ddbf1a743e809a21a6aac1)
#         ;
#
#
#
#
#             var marker_9d9aa943b337d95be739a3c60dd06ae6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3b349bc36071824b878a041a5587ea10);
#
#
#         var popup_3b7db591ba7a48e456db8aeb2033d346 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea9a6958b6f69578ae72d54e1892dd68 = $(`&lt;div id=&quot;html_ea9a6958b6f69578ae72d54e1892dd68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3b7db591ba7a48e456db8aeb2033d346.setContent(html_ea9a6958b6f69578ae72d54e1892dd68);
#
#
#
#         marker_9d9aa943b337d95be739a3c60dd06ae6.bindPopup(popup_3b7db591ba7a48e456db8aeb2033d346)
#         ;
#
#
#
#
#             var marker_0a21bfb18bdabdf30e5eb3f352bc87f8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3b349bc36071824b878a041a5587ea10);
#
#
#         var popup_3f40a72d0a6b8deab90f6c8d83210056 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_215c05c012d9ec90bd7e459997621901 = $(`&lt;div id=&quot;html_215c05c012d9ec90bd7e459997621901&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3f40a72d0a6b8deab90f6c8d83210056.setContent(html_215c05c012d9ec90bd7e459997621901);
#
#
#
#         marker_0a21bfb18bdabdf30e5eb3f352bc87f8.bindPopup(popup_3f40a72d0a6b8deab90f6c8d83210056)
#         ;
#
#
#
#
#             var marker_55afe5368ecf1ba6e96fe24d17bac9eb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3b349bc36071824b878a041a5587ea10);
#
#
#         var popup_78397c544f5fe05543432b9228078ce2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e45c6a7cf4563cfb6fc2efb831ad412 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e45c6a7cf4563cfb6fc2efb831ad412&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e45c6a7cf4563cfb6fc2efb831ad412 = L.map(
#                 &quot;map_5e45c6a7cf4563cfb6fc2efb831ad412&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cf08d2a1761e3adc8a7947c0967f371 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0cf08d2a1761e3adc8a7947c0967f371.addTo(map_5e45c6a7cf4563cfb6fc2efb831ad412);
#
#
#             var feature_group_f9c519c283399095f28c16ef5696051d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f9c519c283399095f28c16ef5696051d.addTo(map_5e45c6a7cf4563cfb6fc2efb831ad412);
#
#
#             var feature_group_sub_group_785ea064283cf955c46d7201efc000e4 = L.featureGroup.subGroup(
#                 feature_group_f9c519c283399095f28c16ef5696051d
#             );
#
#
#             var marker_5baad55dc871bb5dc36b56ff267efcb8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_785ea064283cf955c46d7201efc000e4);
#
#
#         var popup_9aa6e9eb18540ac259183e4fe20d6cc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_463ae090fb4d8b214f2ca166828b20d6 = $(`&lt;div id=&quot;html_463ae090fb4d8b214f2ca166828b20d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9aa6e9eb18540ac259183e4fe20d6cc5.setContent(html_463ae090fb4d8b214f2ca166828b20d6);
#
#
#
#         marker_5baad55dc871bb5dc36b56ff267efcb8.bindPopup(popup_9aa6e9eb18540ac259183e4fe20d6cc5)
#         ;
#
#
#
#
#             var marker_ff68e2fc122ed70082eea4bf9801c039 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_785ea064283cf955c46d7201efc000e4);
#
#
#         var popup_b8748f4df71f261128b6af8d8d1d7f44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df6c5aed16d76522e0fc2b85a7c8bc78 = $(`&lt;div id=&quot;html_df6c5aed16d76522e0fc2b85a7c8bc78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b8748f4df71f261128b6af8d8d1d7f44.setContent(html_df6c5aed16d76522e0fc2b85a7c8bc78);
#
#
#
#         marker_ff68e2fc122ed70082eea4bf9801c039.bindPopup(popup_b8748f4df71f261128b6af8d8d1d7f44)
#         ;
#
#
#
#
#             var marker_8f52014f1e9cc0aa94f9c571cd8ae661 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_785ea064283cf955c46d7201efc000e4);
#
#
#         var popup_ae40e1dfc02cd25a123f669705a3e573 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9e77e560266feb53ec3220e95db468c = $(`&lt;div id=&quot;html_a9e77e560266feb53ec3220e95db468c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ae40e1dfc02cd25a123f669705a3e573.setContent(html_a9e77e560266feb53ec3220e95db468c);
#
#
#
#         marker_8f52014f1e9cc0aa94f9c571cd8ae661.bindPopup(popup_ae40e1dfc02cd25a123f669705a3e573)
#         ;
#
#
#
#
#             var marker_e326e8ede531a3e289c3574762afc709 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_785ea064283cf955c46d7201efc000e4);
#
#
#         var popup_0c062b41701ce141093f47fe9ceb9989 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ed0bb0265c2ea3c1c2b028af643839a = $(`&lt;div id=&quot;html_2ed0bb0265c2ea3c1c2b028af643839a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0c062b41701ce141093f47fe9ceb9989.setContent(html_2ed0bb0265c2ea3c1c2b028af643839a);
#
#
#
#         marker_
