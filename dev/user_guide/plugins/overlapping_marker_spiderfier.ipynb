# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aca08df46f576c2a1a038784ea8cce06 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aca08df46f576c2a1a038784ea8cce06&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aca08df46f576c2a1a038784ea8cce06 = L.map(
#                 &quot;map_aca08df46f576c2a1a038784ea8cce06&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fdd2cac9a11adbb738f34cda1a5e881e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fdd2cac9a11adbb738f34cda1a5e881e.addTo(map_aca08df46f576c2a1a038784ea8cce06);
#
#
#             var marker_a60cc2e1ae311e154af651cd77501f10 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_aca08df46f576c2a1a038784ea8cce06);
#
#
#         var popup_1d5fab9feba23d3392dbb9759b446ed1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1d3bc10947bdb4c54e9d33f40f4679b = $(`&lt;div id=&quot;html_f1d3bc10947bdb4c54e9d33f40f4679b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1d5fab9feba23d3392dbb9759b446ed1.setContent(html_f1d3bc10947bdb4c54e9d33f40f4679b);
#
#
#
#         marker_a60cc2e1ae311e154af651cd77501f10.bindPopup(popup_1d5fab9feba23d3392dbb9759b446ed1)
#         ;
#
#
#
#
#             var marker_cec1265516dc7b1d3c0cf89b6f4e955c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_aca08df46f576c2a1a038784ea8cce06);
#
#
#         var popup_14a969b5196962f3ce4f5be3d038eaee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ac3eb5aed16666a77963a8755d4f104 = $(`&lt;div id=&quot;html_2ac3eb5aed16666a77963a8755d4f104&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_14a969b5196962f3ce4f5be3d038eaee.setContent(html_2ac3eb5aed16666a77963a8755d4f104);
#
#
#
#         marker_cec1265516dc7b1d3c0cf89b6f4e955c.bindPopup(popup_14a969b5196962f3ce4f5be3d038eaee)
#         ;
#
#
#
#
#             var marker_a0bf006b0e67c205f037209a6d253346 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_aca08df46f576c2a1a038784ea8cce06);
#
#
#         var popup_3810d70fc624a188f53aa5eaa6a0d995 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8c04b35f396233fde533011a40c80ab = $(`&lt;div id=&quot;html_a8c04b35f396233fde533011a40c80ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3810d70fc624a188f53aa5eaa6a0d995.setContent(html_a8c04b35f396233fde533011a40c80ab);
#
#
#
#         marker_a0bf006b0e67c205f037209a6d253346.bindPopup(popup_3810d70fc624a188f53aa5eaa6a0d995)
#         ;
#
#
#
#
#             var marker_eb8687a98c8ff0b328593eb933b1f24b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_aca08df46f576c2a1a038784ea8cce06);
#
#
#         var popup_30e4de5eee1f9253435300448d7cfd72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2a02970e7ccf41207aba2f1e7d6d836 = $(`&lt;div id=&quot;html_b2a02970e7ccf41207aba2f1e7d6d836&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_30e4de5eee1f9253435300448d7cfd72.setContent(html_b2a02970e7ccf41207aba2f1e7d6d836);
#
#
#
#         marker_eb8687a98c8ff0b328593eb933b1f24b.bindPopup(popup_30e4de5eee1f9253435300448d7cfd72)
#         ;
#
#
#
#
#             var marker_d428ffcb3536b07078c65f2f487df7bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_aca08df46f576c2a1a038784ea8cce06);
#
#
#         var popup_fb5bea16c9720558591dfbf71bd171c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da1cf0c5e89d5c3040d3d4b201803b05 = $(`&lt;div id=&quot;html_da1cf0c5e89d5c3040d3d4b201803b05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fb5bea16c9720558591dfbf71bd171c9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba2d9ceeb1eea0d9237efb5d14dd208d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba2d9ceeb1eea0d9237efb5d14dd208d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba2d9ceeb1eea0d9237efb5d14dd208d = L.map(
#                 &quot;map_ba2d9ceeb1eea0d9237efb5d14dd208d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da4e395d10ff79338ba7969b5860e486 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da4e395d10ff79338ba7969b5860e486.addTo(map_ba2d9ceeb1eea0d9237efb5d14dd208d);
#
#
#             var feature_group_27b01239f9c2d853df741f15f404e96c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_29fd13ca4cf808a986bb75a0382f287a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_27b01239f9c2d853df741f15f404e96c);
#
#
#         var popup_5f830f661296e315689e9e5de7bcce78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8dbf263ac24cf4450f0f6f39f5c885b9 = $(`&lt;div id=&quot;html_8dbf263ac24cf4450f0f6f39f5c885b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5f830f661296e315689e9e5de7bcce78.setContent(html_8dbf263ac24cf4450f0f6f39f5c885b9);
#
#
#
#         marker_29fd13ca4cf808a986bb75a0382f287a.bindPopup(popup_5f830f661296e315689e9e5de7bcce78)
#         ;
#
#
#
#
#             var marker_186fa89201f1152415e204123fc93bad = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_27b01239f9c2d853df741f15f404e96c);
#
#
#         var popup_19b610487bafcad9d148a60a943e6620 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fde4f03438f5a4481d8ee8910350556 = $(`&lt;div id=&quot;html_6fde4f03438f5a4481d8ee8910350556&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_19b610487bafcad9d148a60a943e6620.setContent(html_6fde4f03438f5a4481d8ee8910350556);
#
#
#
#         marker_186fa89201f1152415e204123fc93bad.bindPopup(popup_19b610487bafcad9d148a60a943e6620)
#         ;
#
#
#
#
#             var marker_148ce0631187ed3ac2d463d9bd6bf9cb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_27b01239f9c2d853df741f15f404e96c);
#
#
#         var popup_9aa07fae1b2e65c25896cc20ec8ac1a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93b1806bc077c350179bcec05d435234 = $(`&lt;div id=&quot;html_93b1806bc077c350179bcec05d435234&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9aa07fae1b2e65c25896cc20ec8ac1a3.setContent(html_93b1806bc077c350179bcec05d435234);
#
#
#
#         marker_148ce0631187ed3ac2d463d9bd6bf9cb.bindPopup(popup_9aa07fae1b2e65c25896cc20ec8ac1a3)
#         ;
#
#
#
#
#             var marker_b7f8e9fd9fc9f9d632db714d8e0ef449 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_27b01239f9c2d853df741f15f404e96c);
#
#
#         var popup_74cd7baa71e3ba8afb79dfc7e887ee5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36229d0905a449a8ef0a02d6181fa113 = $(`&lt;div id=&quot;html_36229d0905a449a8ef0a02d6181fa113&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_74cd7baa71e3ba8afb79dfc7e887ee5d.setContent(html_36229d0905a449a8ef0a02d6181fa113);
#
#
#
#         marker_b7f8e9fd9fc9f9d632db714d8e0ef449.bindPopup(popup_74cd7baa71e3ba8afb79dfc7e887ee5d)
#         ;
#
#
#
#
#             var marker_84fdba91f0c6776f8a95f3ba32c558ce = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_27b01239f9c2d853df741f15f404e96c);
#
#
#         var popup_dd6b3cbea41f4c29aea709523c560de0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52d5a81717bb207920fcec0060d8ff8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52d5a81717bb207920fcec0060d8ff8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52d5a81717bb207920fcec0060d8ff8e = L.map(
#                 &quot;map_52d5a81717bb207920fcec0060d8ff8e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a83d03d387699f6b31eba31ac9278cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a83d03d387699f6b31eba31ac9278cb.addTo(map_52d5a81717bb207920fcec0060d8ff8e);
#
#
#             var feature_group_66531f73bddddfc4d2a9310c29dbc25f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_66531f73bddddfc4d2a9310c29dbc25f.addTo(map_52d5a81717bb207920fcec0060d8ff8e);
#
#
#             var feature_group_sub_group_9accf1279d056e0456fbaeee90ad711f = L.featureGroup.subGroup(
#                 feature_group_66531f73bddddfc4d2a9310c29dbc25f
#             );
#
#
#             var marker_ae4ee96d05c3fb9228ccc7b51f41e96c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9accf1279d056e0456fbaeee90ad711f);
#
#
#         var popup_67537ee956af764dacae5e26d28d694d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd16c26082d78bf5a49d140e090296fa = $(`&lt;div id=&quot;html_bd16c26082d78bf5a49d140e090296fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_67537ee956af764dacae5e26d28d694d.setContent(html_bd16c26082d78bf5a49d140e090296fa);
#
#
#
#         marker_ae4ee96d05c3fb9228ccc7b51f41e96c.bindPopup(popup_67537ee956af764dacae5e26d28d694d)
#         ;
#
#
#
#
#             var marker_8b8299d4df58e3bfa6139a899bb11290 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9accf1279d056e0456fbaeee90ad711f);
#
#
#         var popup_22e9eb67ac036489d00816c860c48df0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d70620b5c2c53be4720ba7a4c22285b = $(`&lt;div id=&quot;html_4d70620b5c2c53be4720ba7a4c22285b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_22e9eb67ac036489d00816c860c48df0.setContent(html_4d70620b5c2c53be4720ba7a4c22285b);
#
#
#
#         marker_8b8299d4df58e3bfa6139a899bb11290.bindPopup(popup_22e9eb67ac036489d00816c860c48df0)
#         ;
#
#
#
#
#             var marker_b4923c50ebf91579702fb0b445023a69 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9accf1279d056e0456fbaeee90ad711f);
#
#
#         var popup_66a910f7d89aa6c82529a41fe765fbbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a9c0f58aa962236f9992331373a7baf = $(`&lt;div id=&quot;html_8a9c0f58aa962236f9992331373a7baf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_66a910f7d89aa6c82529a41fe765fbbf.setContent(html_8a9c0f58aa962236f9992331373a7baf);
#
#
#
#         marker_b4923c50ebf91579702fb0b445023a69.bindPopup(popup_66a910f7d89aa6c82529a41fe765fbbf)
#         ;
#
#
#
#
#             var marker_477c6338189ceb9957b4acc92ab937b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9accf1279d056e0456fbaeee90ad711f);
#
#
#         var popup_6f57102517d0fe687490429e83fc731b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb1b601c0e7222ed7804ad552838034c = $(`&lt;div id=&quot;html_cb1b601c0e7222ed7804ad552838034c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6f57102517d0fe687490429e83fc731b.setContent(html_cb1b601c0e7222ed7804ad552838034c);
#
#
#
#         marker_
