# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fc832a8431a71e838e408e929a9d16dc {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fc832a8431a71e838e408e929a9d16dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fc832a8431a71e838e408e929a9d16dc = L.map(
#                 &quot;map_fc832a8431a71e838e408e929a9d16dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c175747ea58e35a683834db0e4e0a9c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5c175747ea58e35a683834db0e4e0a9c.addTo(map_fc832a8431a71e838e408e929a9d16dc);
#
#
#             var marker_f711e588b9a7e62452ca65d8380b4b44 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fc832a8431a71e838e408e929a9d16dc);
#
#
#         var popup_4d3f241babb08d2ef6f53981d0e386b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a7a6495331a3efe57ab35b019a30a49 = $(`&lt;div id=&quot;html_3a7a6495331a3efe57ab35b019a30a49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4d3f241babb08d2ef6f53981d0e386b0.setContent(html_3a7a6495331a3efe57ab35b019a30a49);
#
#
#
#         marker_f711e588b9a7e62452ca65d8380b4b44.bindPopup(popup_4d3f241babb08d2ef6f53981d0e386b0)
#         ;
#
#
#
#
#             var marker_4ca4cb04890fea26eeac28de8ad87056 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fc832a8431a71e838e408e929a9d16dc);
#
#
#         var popup_b51927d7263bc20a357bd800e77c0328 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd656e68b254b53658f7124967a4d5c6 = $(`&lt;div id=&quot;html_bd656e68b254b53658f7124967a4d5c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b51927d7263bc20a357bd800e77c0328.setContent(html_bd656e68b254b53658f7124967a4d5c6);
#
#
#
#         marker_4ca4cb04890fea26eeac28de8ad87056.bindPopup(popup_b51927d7263bc20a357bd800e77c0328)
#         ;
#
#
#
#
#             var marker_1fd4395629298b8765cf1d67207402ba = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fc832a8431a71e838e408e929a9d16dc);
#
#
#         var popup_8f6b8584c1e3df7f80e2ba963ca0f54d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d80488d12fe99c78eeffe6caeca68d14 = $(`&lt;div id=&quot;html_d80488d12fe99c78eeffe6caeca68d14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8f6b8584c1e3df7f80e2ba963ca0f54d.setContent(html_d80488d12fe99c78eeffe6caeca68d14);
#
#
#
#         marker_1fd4395629298b8765cf1d67207402ba.bindPopup(popup_8f6b8584c1e3df7f80e2ba963ca0f54d)
#         ;
#
#
#
#
#             var marker_e2d9bb30a5aa62ba3597d9684a12740b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fc832a8431a71e838e408e929a9d16dc);
#
#
#         var popup_3f497944841281c58ca9a605255503bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_971f1cae0f200b0e7ea485a4588f695d = $(`&lt;div id=&quot;html_971f1cae0f200b0e7ea485a4588f695d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3f497944841281c58ca9a605255503bf.setContent(html_971f1cae0f200b0e7ea485a4588f695d);
#
#
#
#         marker_e2d9bb30a5aa62ba3597d9684a12740b.bindPopup(popup_3f497944841281c58ca9a605255503bf)
#         ;
#
#
#
#
#             var marker_154b6546ba3e325f49a2290d9c073c2f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fc832a8431a71e838e408e929a9d16dc);
#
#
#         var popup_cfb06cce5178010ac1c17bebe705e235 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e83a23b5446a59543e5c05bc481d57ac = $(`&lt;div id=&quot;html_e83a23b5446a59543e5c05bc481d57ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cfb06cce5178010ac1c17bebe705e2

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_322491de3764e71f713c48ae1de52a6f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_322491de3764e71f713c48ae1de52a6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_322491de3764e71f713c48ae1de52a6f = L.map(
#                 &quot;map_322491de3764e71f713c48ae1de52a6f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a40cc49379b2b3b81c3585dcf73992aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a40cc49379b2b3b81c3585dcf73992aa.addTo(map_322491de3764e71f713c48ae1de52a6f);
#
#
#             var feature_group_28f5f9a221f5bd29f77dd5238f9fad0f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c1ec401cf90ea5465ac41c970659614e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_28f5f9a221f5bd29f77dd5238f9fad0f);
#
#
#         var popup_02688ca1ab2535a2112a110728dd6b86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe51640a1fe11644b6b476b00b98d738 = $(`&lt;div id=&quot;html_fe51640a1fe11644b6b476b00b98d738&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_02688ca1ab2535a2112a110728dd6b86.setContent(html_fe51640a1fe11644b6b476b00b98d738);
#
#
#
#         marker_c1ec401cf90ea5465ac41c970659614e.bindPopup(popup_02688ca1ab2535a2112a110728dd6b86)
#         ;
#
#
#
#
#             var marker_3e8a9ec74440952111121084925e57c5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_28f5f9a221f5bd29f77dd5238f9fad0f);
#
#
#         var popup_74c79a0181232f8e20ee2d068d33df13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67b14dd943ddc1646ccd5094d7ac4a42 = $(`&lt;div id=&quot;html_67b14dd943ddc1646ccd5094d7ac4a42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_74c79a0181232f8e20ee2d068d33df13.setContent(html_67b14dd943ddc1646ccd5094d7ac4a42);
#
#
#
#         marker_3e8a9ec74440952111121084925e57c5.bindPopup(popup_74c79a0181232f8e20ee2d068d33df13)
#         ;
#
#
#
#
#             var marker_dae2175b1596ecc21e7198d6d0a39f14 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_28f5f9a221f5bd29f77dd5238f9fad0f);
#
#
#         var popup_4e5971628defee7476ba6014651792d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13c39690f7ef21b07cde4f4430391289 = $(`&lt;div id=&quot;html_13c39690f7ef21b07cde4f4430391289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4e5971628defee7476ba6014651792d2.setContent(html_13c39690f7ef21b07cde4f4430391289);
#
#
#
#         marker_dae2175b1596ecc21e7198d6d0a39f14.bindPopup(popup_4e5971628defee7476ba6014651792d2)
#         ;
#
#
#
#
#             var marker_6e171a7334900a506f5514d50b055a3a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_28f5f9a221f5bd29f77dd5238f9fad0f);
#
#
#         var popup_cd31b12accfbd648118066459d9a9f98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c06271910ce3e34481f0f9efeba512a2 = $(`&lt;div id=&quot;html_c06271910ce3e34481f0f9efeba512a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cd31b12accfbd648118066459d9a9f98.setContent(html_c06271910ce3e34481f0f9efeba512a2);
#
#
#
#         marker_6e171a7334900a506f5514d50b055a3a.bindPopup(popup_cd31b12accfbd648118066459d9a9f98)
#         ;
#
#
#
#
#             var marker_afd46c85d47ad06c71cfe7006892e7d5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_28f5f9a221f5bd29f77dd5238f9fad0f);
#
#
#         var popup_2036e18b0c13b4cf939a14c78008e35e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c74d2bef0bb3fcbdfce0703a2fa6fc7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c74d2bef0bb3fcbdfce0703a2fa6fc7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c74d2bef0bb3fcbdfce0703a2fa6fc7 = L.map(
#                 &quot;map_2c74d2bef0bb3fcbdfce0703a2fa6fc7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db1047de8e4305b0f3162d8f35fd08aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db1047de8e4305b0f3162d8f35fd08aa.addTo(map_2c74d2bef0bb3fcbdfce0703a2fa6fc7);
#
#
#             var feature_group_a9b30f402d8d2fc96708a9a886580df3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a9b30f402d8d2fc96708a9a886580df3.addTo(map_2c74d2bef0bb3fcbdfce0703a2fa6fc7);
#
#
#             var feature_group_sub_group_04af3291575875e71459ae3c5b7ca3c4 = L.featureGroup.subGroup(
#                 feature_group_a9b30f402d8d2fc96708a9a886580df3
#             );
#
#
#             var marker_4461588cf97cec1ba18e7942d57f44fe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_04af3291575875e71459ae3c5b7ca3c4);
#
#
#         var popup_7059c51f8742afd2b1d2a0e649558bc3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2aeee9b59170c67642bfee4e3400046c = $(`&lt;div id=&quot;html_2aeee9b59170c67642bfee4e3400046c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7059c51f8742afd2b1d2a0e649558bc3.setContent(html_2aeee9b59170c67642bfee4e3400046c);
#
#
#
#         marker_4461588cf97cec1ba18e7942d57f44fe.bindPopup(popup_7059c51f8742afd2b1d2a0e649558bc3)
#         ;
#
#
#
#
#             var marker_1af496a089411d4f53239e62c9af8ad5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_04af3291575875e71459ae3c5b7ca3c4);
#
#
#         var popup_9367735d07cbbaecc5581e7c1b20ef4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33a6769e92e3ab7b95ae3e9292822a9d = $(`&lt;div id=&quot;html_33a6769e92e3ab7b95ae3e9292822a9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9367735d07cbbaecc5581e7c1b20ef4b.setContent(html_33a6769e92e3ab7b95ae3e9292822a9d);
#
#
#
#         marker_1af496a089411d4f53239e62c9af8ad5.bindPopup(popup_9367735d07cbbaecc5581e7c1b20ef4b)
#         ;
#
#
#
#
#             var marker_3050cc5998589596838ac771cdd30f6e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_04af3291575875e71459ae3c5b7ca3c4);
#
#
#         var popup_adfc7d17d7126b5f7633ddd1f120a411 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76cf9981b6e4ca8bcbf955474dd7d4a9 = $(`&lt;div id=&quot;html_76cf9981b6e4ca8bcbf955474dd7d4a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_adfc7d17d7126b5f7633ddd1f120a411.setContent(html_76cf9981b6e4ca8bcbf955474dd7d4a9);
#
#
#
#         marker_3050cc5998589596838ac771cdd30f6e.bindPopup(popup_adfc7d17d7126b5f7633ddd1f120a411)
#         ;
#
#
#
#
#             var marker_94efed61a8e785d33fb2098f92cbaabc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_04af3291575875e71459ae3c5b7ca3c4);
#
#
#         var popup_311e49e805b8d9a2d9b912e93516fae4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_653c41e987dfcdf4ccabfb94e5ef9d2c = $(`&lt;div id=&quot;html_653c41e987dfcdf4ccabfb94e5ef9d2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_311e49e805b8d9a2d9b912e93516fae4.setContent(html_653c41e987dfcdf4ccabfb94e5ef9d2c);
#
#
#
#         mark
