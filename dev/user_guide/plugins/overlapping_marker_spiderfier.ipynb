# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12037e861439ef7762ebaaf3141ad176 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12037e861439ef7762ebaaf3141ad176&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12037e861439ef7762ebaaf3141ad176 = L.map(
#                 &quot;map_12037e861439ef7762ebaaf3141ad176&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d20ffea22d41145da423d2b259ef4408 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d20ffea22d41145da423d2b259ef4408.addTo(map_12037e861439ef7762ebaaf3141ad176);
#
#
#             var marker_045fb98703e502abd057f9b8e3160e58 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_12037e861439ef7762ebaaf3141ad176);
#
#
#         var popup_33068b5ff05390d4c34e99d7ea49af0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bd32ec78bc2b3e887bab20ab2235cec = $(`&lt;div id=&quot;html_1bd32ec78bc2b3e887bab20ab2235cec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_33068b5ff05390d4c34e99d7ea49af0f.setContent(html_1bd32ec78bc2b3e887bab20ab2235cec);
#
#
#
#         marker_045fb98703e502abd057f9b8e3160e58.bindPopup(popup_33068b5ff05390d4c34e99d7ea49af0f)
#         ;
#
#
#
#
#             var marker_487567e4b199f03f1185b8b1c9614ed4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_12037e861439ef7762ebaaf3141ad176);
#
#
#         var popup_caf332f5ea651c4b39e791ea961bd3a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_535c7bc4101ce9b5a5656968591d763e = $(`&lt;div id=&quot;html_535c7bc4101ce9b5a5656968591d763e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_caf332f5ea651c4b39e791ea961bd3a5.setContent(html_535c7bc4101ce9b5a5656968591d763e);
#
#
#
#         marker_487567e4b199f03f1185b8b1c9614ed4.bindPopup(popup_caf332f5ea651c4b39e791ea961bd3a5)
#         ;
#
#
#
#
#             var marker_feb442fa8e23a46a267b6ea685e991a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_12037e861439ef7762ebaaf3141ad176);
#
#
#         var popup_41728fe1c63c06fad29098eac89733a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ab6571e35559a42b31c0ba28a809349 = $(`&lt;div id=&quot;html_8ab6571e35559a42b31c0ba28a809349&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_41728fe1c63c06fad29098eac89733a7.setContent(html_8ab6571e35559a42b31c0ba28a809349);
#
#
#
#         marker_feb442fa8e23a46a267b6ea685e991a2.bindPopup(popup_41728fe1c63c06fad29098eac89733a7)
#         ;
#
#
#
#
#             var marker_dc07d317c5cc0368a221c1d55d9a0a78 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_12037e861439ef7762ebaaf3141ad176);
#
#
#         var popup_b8194630cb0a60d9a83403414bc6c8d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b0582bec0c55d6dc7cea7e3a2110bba = $(`&lt;div id=&quot;html_8b0582bec0c55d6dc7cea7e3a2110bba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b8194630cb0a60d9a83403414bc6c8d3.setContent(html_8b0582bec0c55d6dc7cea7e3a2110bba);
#
#
#
#         marker_dc07d317c5cc0368a221c1d55d9a0a78.bindPopup(popup_b8194630cb0a60d9a83403414bc6c8d3)
#         ;
#
#
#
#
#             var marker_f0df8bd5f55039124b40cf3cc909f5fa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_12037e861439ef7762ebaaf3141ad176);
#
#
#         var popup_f0aa61654610a6509d23567eda6a8d44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56667c8cf24dc06db1e3ec03925d5ad4 = $(`&lt;div id=&quot;html_56667c8cf24dc06db1e3ec03925d5ad4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f0aa61654610a6509d23567eda6a8d44.setContent(html_56667c8cf24dc06db1e3ec03925d5ad4);
#
#
#
#         marker_f0df8bd5f55039124b40cf3cc909f5fa.bindPopup(popup_f0aa61654610a6509d23567eda6a8d44)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c35fa8738842ebfb2483a621aad2128 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c35fa8738842ebfb2483a621aad2128&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c35fa8738842ebfb2483a621aad2128 = L.map(
#                 &quot;map_4c35fa8738842ebfb2483a621aad2128&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_298edc7c67add2d4cee371827780ec51 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_298edc7c67add2d4cee371827780ec51.addTo(map_4c35fa8738842ebfb2483a621aad2128);
#
#
#             var feature_group_f18a97769cec192dc42f6c410e65ed8a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4665cc66a333ab0c2dbce90858b67344 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f18a97769cec192dc42f6c410e65ed8a);
#
#
#         var popup_527aca035ff2afec29b19aa93fcd14ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26f0e5df26401d91215cb5dfce297f57 = $(`&lt;div id=&quot;html_26f0e5df26401d91215cb5dfce297f57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_527aca035ff2afec29b19aa93fcd14ec.setContent(html_26f0e5df26401d91215cb5dfce297f57);
#
#
#
#         marker_4665cc66a333ab0c2dbce90858b67344.bindPopup(popup_527aca035ff2afec29b19aa93fcd14ec)
#         ;
#
#
#
#
#             var marker_e6729cdb4ea148940f5a4a3b9a2fd099 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f18a97769cec192dc42f6c410e65ed8a);
#
#
#         var popup_33f0a709880d9788ee10b7e050c1d489 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a1f9c76fdf2d85cef948072c1c91d04 = $(`&lt;div id=&quot;html_4a1f9c76fdf2d85cef948072c1c91d04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_33f0a709880d9788ee10b7e050c1d489.setContent(html_4a1f9c76fdf2d85cef948072c1c91d04);
#
#
#
#         marker_e6729cdb4ea148940f5a4a3b9a2fd099.bindPopup(popup_33f0a709880d9788ee10b7e050c1d489)
#         ;
#
#
#
#
#             var marker_d3518640be811ac5828157f93255eda2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f18a97769cec192dc42f6c410e65ed8a);
#
#
#         var popup_4828550515a63ad0471c002f4c60f784 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f20cf8418769df179d9a24e35032048f = $(`&lt;div id=&quot;html_f20cf8418769df179d9a24e35032048f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4828550515a63ad0471c002f4c60f784.setContent(html_f20cf8418769df179d9a24e35032048f);
#
#
#
#         marker_d3518640be811ac5828157f93255eda2.bindPopup(popup_4828550515a63ad0471c002f4c60f784)
#         ;
#
#
#
#
#             var marker_eff98f6421463ad6e46edb7bbda494fb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f18a97769cec192dc42f6c410e65ed8a);
#
#
#         var popup_de791bf3725b2986ce29238137333730 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7e7e163623a6b3d4679d92a8db563c7 = $(`&lt;div id=&quot;html_c7e7e163623a6b3d4679d92a8db563c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_de791bf3725b2986ce29238137333730.setContent(html_c7e7e163623a6b3d4679d92a8db563c7);
#
#
#
#         marker_eff98f6421463ad6e46edb7bbda494fb.bindPopup(popup_de791bf3725b2986ce29238137333730)
#         ;
#
#
#
#
#             var marker_a9f455d54b44bce6e17597572197dbc0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f18a97769cec192dc42f6c410e65ed8a);
#
#
#         var popup_cd889f876e0c87cc0eb785bd104f9ddd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a3ca92c13f7b83805f7f2411a8a1b7b = $(`&lt;div id=&quot;html_9a3ca92c13f7b83805f7f2411a8a1b7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63021353f2362b006e00c1e00fa2238f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63021353f2362b006e00c1e00fa2238f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63021353f2362b006e00c1e00fa2238f = L.map(
#                 &quot;map_63021353f2362b006e00c1e00fa2238f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_11cc38689a78ee1f2b4c28cdd885c44c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_11cc38689a78ee1f2b4c28cdd885c44c.addTo(map_63021353f2362b006e00c1e00fa2238f);
#
#
#             var feature_group_c9c8685f071e03981d30ec5499410444 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c9c8685f071e03981d30ec5499410444.addTo(map_63021353f2362b006e00c1e00fa2238f);
#
#
#             var feature_group_sub_group_e3be4f41811b350b9c03d4d20fd24edd = L.featureGroup.subGroup(
#                 feature_group_c9c8685f071e03981d30ec5499410444
#             );
#
#
#             var marker_63421b4dd7d83ee595d932b2b6abd228 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3be4f41811b350b9c03d4d20fd24edd);
#
#
#         var popup_75fe72ca81ca7471840826a78d94e1a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce383e24ee1130bcd535735588de4301 = $(`&lt;div id=&quot;html_ce383e24ee1130bcd535735588de4301&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_75fe72ca81ca7471840826a78d94e1a5.setContent(html_ce383e24ee1130bcd535735588de4301);
#
#
#
#         marker_63421b4dd7d83ee595d932b2b6abd228.bindPopup(popup_75fe72ca81ca7471840826a78d94e1a5)
#         ;
#
#
#
#
#             var marker_5331eb977f52157a6aa1d08211970419 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3be4f41811b350b9c03d4d20fd24edd);
#
#
#         var popup_eed29992ba33ae132cda253596529889 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7dbf833df2b7a46eb1e3404f9a11ab36 = $(`&lt;div id=&quot;html_7dbf833df2b7a46eb1e3404f9a11ab36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_eed29992ba33ae132cda253596529889.setContent(html_7dbf833df2b7a46eb1e3404f9a11ab36);
#
#
#
#         marker_5331eb977f52157a6aa1d08211970419.bindPopup(popup_eed29992ba33ae132cda253596529889)
#         ;
#
#
#
#
#             var marker_633525a3faf99d529cfca49d025e2589 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3be4f41811b350b9c03d4d20fd24edd);
#
#
#         var popup_28003c4a805104c36cc6d172c9bd39ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d87bd5fb51542b49fcd7c517174aa0ab = $(`&lt;div id=&quot;html_d87bd5fb51542b49fcd7c517174aa0ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_28003c4a805104c36cc6d172c9bd39ae.setContent(html_d87bd5fb51542b49fcd7c517174aa0ab);
#
#
#
#         marker_633525a3faf99d529cfca49d025e2589.bindPopup(popup_28003c4a805104c36cc6d172c9bd39ae)
#         ;
#
#
#
#
#             var marker_997733f4d1f455dfaac66ccadcb8f33c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e3be4f41811b350b9c03d4d20fd24edd);
#
#
#         var popup_0cbb68f39f520056b44e79fa4da2d986 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b2f7d6d344b3e3e3ad00ec1b4247f98 = $(`&lt;div id=&quot;html_5b2f7d6d344b3e3e3ad00ec1b4247f98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0cbb68f39f520056b44e79fa4da2d986.setContent(html_5b2f7d6d344b3e3e3ad00ec1b4247f98);
#
#
#
#         marker_997733f4d1f455dfaac66ccadcb8f33c.bindPopup(popup_0cbb68f39f520056b44e79fa4da2d986)
#         ;
#
#
#
#
#             var marker_af1622e2e16eba4bf546ed256da61103 = L.marker(
#                 [45.0503999
