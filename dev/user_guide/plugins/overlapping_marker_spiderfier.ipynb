# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b73444243c40718ab2ed51c46e355cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b73444243c40718ab2ed51c46e355cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b73444243c40718ab2ed51c46e355cf = L.map(
#                 &quot;map_1b73444243c40718ab2ed51c46e355cf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dafeaf71d91ef86a8ec47e30fe490f4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dafeaf71d91ef86a8ec47e30fe490f4a.addTo(map_1b73444243c40718ab2ed51c46e355cf);
#
#
#             var marker_407cee77a3fdaced274b47f792a410f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1b73444243c40718ab2ed51c46e355cf);
#
#
#         var popup_b7855dbbdd561049d6181ea2d0ef555e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dba3ad648e0dcdb245aedf3bf1e2aeb1 = $(`&lt;div id=&quot;html_dba3ad648e0dcdb245aedf3bf1e2aeb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b7855dbbdd561049d6181ea2d0ef555e.setContent(html_dba3ad648e0dcdb245aedf3bf1e2aeb1);
#
#
#
#         marker_407cee77a3fdaced274b47f792a410f4.bindPopup(popup_b7855dbbdd561049d6181ea2d0ef555e)
#         ;
#
#
#
#
#             var marker_0c9807149cf0de979ebb2f228881c45c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1b73444243c40718ab2ed51c46e355cf);
#
#
#         var popup_a63576219bf473727a13dc95d3dbc5ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e8629daaed4c2ff3dde9fbfe2578ed3 = $(`&lt;div id=&quot;html_5e8629daaed4c2ff3dde9fbfe2578ed3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a63576219bf473727a13dc95d3dbc5ab.setContent(html_5e8629daaed4c2ff3dde9fbfe2578ed3);
#
#
#
#         marker_0c9807149cf0de979ebb2f228881c45c.bindPopup(popup_a63576219bf473727a13dc95d3dbc5ab)
#         ;
#
#
#
#
#             var marker_1a269c2a620c96d738bf92551e7fc54a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1b73444243c40718ab2ed51c46e355cf);
#
#
#         var popup_4079edc6365caee3cfadd27b7be3de04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cffde20005e9ac605e55a0fc6c8aa42 = $(`&lt;div id=&quot;html_1cffde20005e9ac605e55a0fc6c8aa42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4079edc6365caee3cfadd27b7be3de04.setContent(html_1cffde20005e9ac605e55a0fc6c8aa42);
#
#
#
#         marker_1a269c2a620c96d738bf92551e7fc54a.bindPopup(popup_4079edc6365caee3cfadd27b7be3de04)
#         ;
#
#
#
#
#             var marker_85a9f83dd1c0bf00167a9a0bc17e6d15 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1b73444243c40718ab2ed51c46e355cf);
#
#
#         var popup_5db2d4e947fa683a5c167f5ecbada007 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48d93386f3813bf328cb84cee281c4f3 = $(`&lt;div id=&quot;html_48d93386f3813bf328cb84cee281c4f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5db2d4e947fa683a5c167f5ecbada007.setContent(html_48d93386f3813bf328cb84cee281c4f3);
#
#
#
#         marker_85a9f83dd1c0bf00167a9a0bc17e6d15.bindPopup(popup_5db2d4e947fa683a5c167f5ecbada007)
#         ;
#
#
#
#
#             var marker_c5eedf5257089035f6e51127bb105bf1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1b73444243c40718ab2ed51c46e355cf);
#
#
#         var popup_7ed8a2f0e78ef4361f019c058e5a57f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bda023343d4202d0b8a61bd0442935c = $(`&lt;div id=&quot;html_2bda023343d4202d0b8a61bd0442935c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7ed8a2f0e78ef4361f019c058e5a57f5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bf7c2ca6655cc2692518a02e9df0a7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bf7c2ca6655cc2692518a02e9df0a7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bf7c2ca6655cc2692518a02e9df0a7e = L.map(
#                 &quot;map_2bf7c2ca6655cc2692518a02e9df0a7e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ed2dfdec4c97ba2e0c01274aa0d74fb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ed2dfdec4c97ba2e0c01274aa0d74fb.addTo(map_2bf7c2ca6655cc2692518a02e9df0a7e);
#
#
#             var feature_group_c29d533394fe68939d2fe1072e50157d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_46bac9d3c7c162f7d5ba3efd1805e074 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c29d533394fe68939d2fe1072e50157d);
#
#
#         var popup_e75f3c6ae1ae4971aab0bf6a47847148 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42844b1da069851de0796c738342f743 = $(`&lt;div id=&quot;html_42844b1da069851de0796c738342f743&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e75f3c6ae1ae4971aab0bf6a47847148.setContent(html_42844b1da069851de0796c738342f743);
#
#
#
#         marker_46bac9d3c7c162f7d5ba3efd1805e074.bindPopup(popup_e75f3c6ae1ae4971aab0bf6a47847148)
#         ;
#
#
#
#
#             var marker_53e50a991cee3e406386a4840f592d42 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c29d533394fe68939d2fe1072e50157d);
#
#
#         var popup_0bebc037334833b9b7f9584dad849726 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_877dc78e793eab3e0e375c5d49d411b2 = $(`&lt;div id=&quot;html_877dc78e793eab3e0e375c5d49d411b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0bebc037334833b9b7f9584dad849726.setContent(html_877dc78e793eab3e0e375c5d49d411b2);
#
#
#
#         marker_53e50a991cee3e406386a4840f592d42.bindPopup(popup_0bebc037334833b9b7f9584dad849726)
#         ;
#
#
#
#
#             var marker_5d929b3db39288bf4d60a542b7bbf326 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c29d533394fe68939d2fe1072e50157d);
#
#
#         var popup_362467517c5430e03a386a9c7627fda2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e7d79f8c23a0e0c65b3ca3e3a59ce62 = $(`&lt;div id=&quot;html_9e7d79f8c23a0e0c65b3ca3e3a59ce62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_362467517c5430e03a386a9c7627fda2.setContent(html_9e7d79f8c23a0e0c65b3ca3e3a59ce62);
#
#
#
#         marker_5d929b3db39288bf4d60a542b7bbf326.bindPopup(popup_362467517c5430e03a386a9c7627fda2)
#         ;
#
#
#
#
#             var marker_dd8a505c78fa3e4da5e27038609192de = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c29d533394fe68939d2fe1072e50157d);
#
#
#         var popup_d6d40c170d16d516db8462f064d14b55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_124fcf68d62a5d34fbaa84399b7d7664 = $(`&lt;div id=&quot;html_124fcf68d62a5d34fbaa84399b7d7664&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d6d40c170d16d516db8462f064d14b55.setContent(html_124fcf68d62a5d34fbaa84399b7d7664);
#
#
#
#         marker_dd8a505c78fa3e4da5e27038609192de.bindPopup(popup_d6d40c170d16d516db8462f064d14b55)
#         ;
#
#
#
#
#             var marker_bbf1e47a323a4b6510cdc2ebf49250a5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c29d533394fe68939d2fe1072e50157d);
#
#
#         var popup_a01b99873b4391c20169f2073bce1abb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a6fde89e969ab82f61500e5eb99244fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a6fde89e969ab82f61500e5eb99244fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a6fde89e969ab82f61500e5eb99244fa = L.map(
#                 &quot;map_a6fde89e969ab82f61500e5eb99244fa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b499979f143b996e2c8e780ef322907c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b499979f143b996e2c8e780ef322907c.addTo(map_a6fde89e969ab82f61500e5eb99244fa);
#
#
#             var feature_group_4e4e952dc200c15e0fd9c6ac627c267e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4e4e952dc200c15e0fd9c6ac627c267e.addTo(map_a6fde89e969ab82f61500e5eb99244fa);
#
#
#             var feature_group_sub_group_63e987e5e8dd966b26abc16e0033db17 = L.featureGroup.subGroup(
#                 feature_group_4e4e952dc200c15e0fd9c6ac627c267e
#             );
#
#
#             var marker_be070c42fcdbcdc17a23cff1ff0e1aa0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_63e987e5e8dd966b26abc16e0033db17);
#
#
#         var popup_c557a1d687ecf5c2406769f61acebc39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c96db5688af1b121ab814eaa236905e = $(`&lt;div id=&quot;html_7c96db5688af1b121ab814eaa236905e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c557a1d687ecf5c2406769f61acebc39.setContent(html_7c96db5688af1b121ab814eaa236905e);
#
#
#
#         marker_be070c42fcdbcdc17a23cff1ff0e1aa0.bindPopup(popup_c557a1d687ecf5c2406769f61acebc39)
#         ;
#
#
#
#
#             var marker_8a8f4ce590c91c9e358e89a26edcb269 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_63e987e5e8dd966b26abc16e0033db17);
#
#
#         var popup_ee68b642154021fcad0d78cabb403001 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e01544e23ee874ea87b487c740fc1cf = $(`&lt;div id=&quot;html_1e01544e23ee874ea87b487c740fc1cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ee68b642154021fcad0d78cabb403001.setContent(html_1e01544e23ee874ea87b487c740fc1cf);
#
#
#
#         marker_8a8f4ce590c91c9e358e89a26edcb269.bindPopup(popup_ee68b642154021fcad0d78cabb403001)
#         ;
#
#
#
#
#             var marker_14c49480f7e6059af61f32e73968392e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_63e987e5e8dd966b26abc16e0033db17);
#
#
#         var popup_50356e9c9d03b568d3aef3fad8121d81 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12f74377a7b09e5efc9c38f0f2f81bd4 = $(`&lt;div id=&quot;html_12f74377a7b09e5efc9c38f0f2f81bd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_50356e9c9d03b568d3aef3fad8121d81.setContent(html_12f74377a7b09e5efc9c38f0f2f81bd4);
#
#
#
#         marker_14c49480f7e6059af61f32e73968392e.bindPopup(popup_50356e9c9d03b568d3aef3fad8121d81)
#         ;
#
#
#
#
#             var marker_94545a64ba921b6d6435d87d467da8f8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_63e987e5e8dd966b26abc16e0033db17);
#
#
#         var popup_a434257de0093f18db61b5ac85e01881 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e98d0bb43bd81e60f0a0aff085b65b77 = $(`&lt;div id=&quot;html_e98d0bb43bd81e60f0a0aff085b65b77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a434257de0093f18db61b5ac85e01881.setContent(html_e98d0bb43bd81e60f0a0aff085b65b77);
#
#
#
#         marker_
