# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d1488150428313cc5b857323a880c2a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d1488150428313cc5b857323a880c2a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d1488150428313cc5b857323a880c2a = L.map(
#                 &quot;map_3d1488150428313cc5b857323a880c2a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e3b6d87522d296f4542f66cd9bff92c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e3b6d87522d296f4542f66cd9bff92c1.addTo(map_3d1488150428313cc5b857323a880c2a);
#
#
#             var marker_2404da6147960c1262dfdaf7b2fc8be4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3d1488150428313cc5b857323a880c2a);
#
#
#         var popup_df1da21a20bf135e603334854bbff40c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d3d4a39663cbff1f0c9d72805384727 = $(`&lt;div id=&quot;html_4d3d4a39663cbff1f0c9d72805384727&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_df1da21a20bf135e603334854bbff40c.setContent(html_4d3d4a39663cbff1f0c9d72805384727);
#
#
#
#         marker_2404da6147960c1262dfdaf7b2fc8be4.bindPopup(popup_df1da21a20bf135e603334854bbff40c)
#         ;
#
#
#
#
#             var marker_5355685640ad0aad326af98560baefbe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3d1488150428313cc5b857323a880c2a);
#
#
#         var popup_4f20e1725465bcfdc697a5deda4942fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac35f0d2fbf1f09f70783a396119c78f = $(`&lt;div id=&quot;html_ac35f0d2fbf1f09f70783a396119c78f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4f20e1725465bcfdc697a5deda4942fb.setContent(html_ac35f0d2fbf1f09f70783a396119c78f);
#
#
#
#         marker_5355685640ad0aad326af98560baefbe.bindPopup(popup_4f20e1725465bcfdc697a5deda4942fb)
#         ;
#
#
#
#
#             var marker_d703121a59a38a0af7e64c1b8c5ebbb7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3d1488150428313cc5b857323a880c2a);
#
#
#         var popup_09e14151a3f5465eabbd635d4b949f8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a72714c3b99b7de50c76d030f1b3a0b = $(`&lt;div id=&quot;html_4a72714c3b99b7de50c76d030f1b3a0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_09e14151a3f5465eabbd635d4b949f8e.setContent(html_4a72714c3b99b7de50c76d030f1b3a0b);
#
#
#
#         marker_d703121a59a38a0af7e64c1b8c5ebbb7.bindPopup(popup_09e14151a3f5465eabbd635d4b949f8e)
#         ;
#
#
#
#
#             var marker_d6a535d6ef99dfc71e14a021101c2650 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3d1488150428313cc5b857323a880c2a);
#
#
#         var popup_824dee587927f3565511bbe5ca3aaee4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae54a8e941265f383809398bc0e55f0a = $(`&lt;div id=&quot;html_ae54a8e941265f383809398bc0e55f0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_824dee587927f3565511bbe5ca3aaee4.setContent(html_ae54a8e941265f383809398bc0e55f0a);
#
#
#
#         marker_d6a535d6ef99dfc71e14a021101c2650.bindPopup(popup_824dee587927f3565511bbe5ca3aaee4)
#         ;
#
#
#
#
#             var marker_286692ecabb225cbebf4d4c1ca21b96d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3d1488150428313cc5b857323a880c2a);
#
#
#         var popup_f76cb954ad8243f13bf178c1c1cb2f57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8861169e688044d699ffc11e8b470d70 = $(`&lt;div id=&quot;html_8861169e688044d699ffc11e8b470d70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f76cb954ad8243f13bf178c1c1cb2f

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eeb8d37ee1cc37162263fa9a26e99b53 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eeb8d37ee1cc37162263fa9a26e99b53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eeb8d37ee1cc37162263fa9a26e99b53 = L.map(
#                 &quot;map_eeb8d37ee1cc37162263fa9a26e99b53&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0183286cbf7576be11815937a8b5ca3b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0183286cbf7576be11815937a8b5ca3b.addTo(map_eeb8d37ee1cc37162263fa9a26e99b53);
#
#
#             var feature_group_3ed86fb8c36348302e721286019e99f4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5a02ccc2cf359a4a51f9105ac708678b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3ed86fb8c36348302e721286019e99f4);
#
#
#         var popup_c6d96d02304aff070367115122e64531 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2464f13c0425bedf88cc3ec7771d7c17 = $(`&lt;div id=&quot;html_2464f13c0425bedf88cc3ec7771d7c17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c6d96d02304aff070367115122e64531.setContent(html_2464f13c0425bedf88cc3ec7771d7c17);
#
#
#
#         marker_5a02ccc2cf359a4a51f9105ac708678b.bindPopup(popup_c6d96d02304aff070367115122e64531)
#         ;
#
#
#
#
#             var marker_2536b8201bc448f1351e692735e6053d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3ed86fb8c36348302e721286019e99f4);
#
#
#         var popup_fe41d94a286ac209c3f4719125e6fa34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e18f540332b88f60e37a6b476a4ad035 = $(`&lt;div id=&quot;html_e18f540332b88f60e37a6b476a4ad035&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fe41d94a286ac209c3f4719125e6fa34.setContent(html_e18f540332b88f60e37a6b476a4ad035);
#
#
#
#         marker_2536b8201bc448f1351e692735e6053d.bindPopup(popup_fe41d94a286ac209c3f4719125e6fa34)
#         ;
#
#
#
#
#             var marker_258a3116433a6904586239907c00e961 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3ed86fb8c36348302e721286019e99f4);
#
#
#         var popup_f4693783090dc8cc424fc03fd3265f28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_754697cab9857e585f508e0be1cec9ec = $(`&lt;div id=&quot;html_754697cab9857e585f508e0be1cec9ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f4693783090dc8cc424fc03fd3265f28.setContent(html_754697cab9857e585f508e0be1cec9ec);
#
#
#
#         marker_258a3116433a6904586239907c00e961.bindPopup(popup_f4693783090dc8cc424fc03fd3265f28)
#         ;
#
#
#
#
#             var marker_b6d8e952d019f2ce7063310a0966446b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3ed86fb8c36348302e721286019e99f4);
#
#
#         var popup_cc824841cc31deb65ee8f185ba60be4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0900b8dfb3c51e4b867b2781f997679d = $(`&lt;div id=&quot;html_0900b8dfb3c51e4b867b2781f997679d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cc824841cc31deb65ee8f185ba60be4c.setContent(html_0900b8dfb3c51e4b867b2781f997679d);
#
#
#
#         marker_b6d8e952d019f2ce7063310a0966446b.bindPopup(popup_cc824841cc31deb65ee8f185ba60be4c)
#         ;
#
#
#
#
#             var marker_b9747afb174d93fd16f770da3d154b41 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3ed86fb8c36348302e721286019e99f4);
#
#
#         var popup_9f2e3dcfdb0d50ee30f5aa76b1286f37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8cbdc47a02be580288be6fc9bdf88676 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8cbdc47a02be580288be6fc9bdf88676&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8cbdc47a02be580288be6fc9bdf88676 = L.map(
#                 &quot;map_8cbdc47a02be580288be6fc9bdf88676&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a1b98642bed0e63951337a8f5c6dc31 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a1b98642bed0e63951337a8f5c6dc31.addTo(map_8cbdc47a02be580288be6fc9bdf88676);
#
#
#             var feature_group_64ffb125f133dae122b31c7590191396 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_64ffb125f133dae122b31c7590191396.addTo(map_8cbdc47a02be580288be6fc9bdf88676);
#
#
#             var feature_group_sub_group_d5c3ad386a3ee96fd532d94482a6d3c6 = L.featureGroup.subGroup(
#                 feature_group_64ffb125f133dae122b31c7590191396
#             );
#
#
#             var marker_b0b8dbb4cd38fbd75fe25fa807efb765 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5c3ad386a3ee96fd532d94482a6d3c6);
#
#
#         var popup_f19f4133e92308b60df4ce1961b80806 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3866bfe9df39c098561ce94d2f46326c = $(`&lt;div id=&quot;html_3866bfe9df39c098561ce94d2f46326c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f19f4133e92308b60df4ce1961b80806.setContent(html_3866bfe9df39c098561ce94d2f46326c);
#
#
#
#         marker_b0b8dbb4cd38fbd75fe25fa807efb765.bindPopup(popup_f19f4133e92308b60df4ce1961b80806)
#         ;
#
#
#
#
#             var marker_7f526e7fc14474b96b6968c10427cdad = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5c3ad386a3ee96fd532d94482a6d3c6);
#
#
#         var popup_26675cbcf823ce3bfc8b11b6c17cfeb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8accc55b6d2ace8b51a7b7302bfd3583 = $(`&lt;div id=&quot;html_8accc55b6d2ace8b51a7b7302bfd3583&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_26675cbcf823ce3bfc8b11b6c17cfeb1.setContent(html_8accc55b6d2ace8b51a7b7302bfd3583);
#
#
#
#         marker_7f526e7fc14474b96b6968c10427cdad.bindPopup(popup_26675cbcf823ce3bfc8b11b6c17cfeb1)
#         ;
#
#
#
#
#             var marker_b02a0386b93f0522cbe1a05ce98c2256 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5c3ad386a3ee96fd532d94482a6d3c6);
#
#
#         var popup_eb7f0790fddd0252a75fc718ae336128 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d874d9be9387f9d05871225e86f9b37c = $(`&lt;div id=&quot;html_d874d9be9387f9d05871225e86f9b37c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_eb7f0790fddd0252a75fc718ae336128.setContent(html_d874d9be9387f9d05871225e86f9b37c);
#
#
#
#         marker_b02a0386b93f0522cbe1a05ce98c2256.bindPopup(popup_eb7f0790fddd0252a75fc718ae336128)
#         ;
#
#
#
#
#             var marker_c226acd62136ba2274616e4e07f73ff1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d5c3ad386a3ee96fd532d94482a6d3c6);
#
#
#         var popup_ba158026957f5a16557670372283acc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41910de1c78d71f10d19c8796cd6fc18 = $(`&lt;div id=&quot;html_41910de1c78d71f10d19c8796cd6fc18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ba158026957f5a16557670372283acc1.setContent(html_41910de1c78d71f10d19c8796cd6fc18);
#
#
#
#         mark
