# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a55fd2adacc6f4c08c8012139d03241 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a55fd2adacc6f4c08c8012139d03241&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a55fd2adacc6f4c08c8012139d03241 = L.map(
#                 &quot;map_0a55fd2adacc6f4c08c8012139d03241&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29a3b24293e43e4a692f96afbe0e590f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29a3b24293e43e4a692f96afbe0e590f.addTo(map_0a55fd2adacc6f4c08c8012139d03241);
#
#
#             var marker_44d199caea4909e59aaa67f4294dff72 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0a55fd2adacc6f4c08c8012139d03241);
#
#
#         var popup_f4bcec9302af4b0e24ed26b9639c7835 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36cd007f18420defb5300658e8056d6a = $(`&lt;div id=&quot;html_36cd007f18420defb5300658e8056d6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f4bcec9302af4b0e24ed26b9639c7835.setContent(html_36cd007f18420defb5300658e8056d6a);
#
#
#
#         marker_44d199caea4909e59aaa67f4294dff72.bindPopup(popup_f4bcec9302af4b0e24ed26b9639c7835)
#         ;
#
#
#
#
#             var marker_b5b406a1bdc341255d14d59144b72799 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0a55fd2adacc6f4c08c8012139d03241);
#
#
#         var popup_ddf0f1b79624af498992d2f0f04859af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_badd50bec289304c8036f66a9aa3d1ca = $(`&lt;div id=&quot;html_badd50bec289304c8036f66a9aa3d1ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ddf0f1b79624af498992d2f0f04859af.setContent(html_badd50bec289304c8036f66a9aa3d1ca);
#
#
#
#         marker_b5b406a1bdc341255d14d59144b72799.bindPopup(popup_ddf0f1b79624af498992d2f0f04859af)
#         ;
#
#
#
#
#             var marker_cc6c35488cc41c072a29f0a02c54d103 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0a55fd2adacc6f4c08c8012139d03241);
#
#
#         var popup_6312e896f5f062439f015fbadb31e1a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a010c709319800e6ea3ecae3947acfd9 = $(`&lt;div id=&quot;html_a010c709319800e6ea3ecae3947acfd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6312e896f5f062439f015fbadb31e1a2.setContent(html_a010c709319800e6ea3ecae3947acfd9);
#
#
#
#         marker_cc6c35488cc41c072a29f0a02c54d103.bindPopup(popup_6312e896f5f062439f015fbadb31e1a2)
#         ;
#
#
#
#
#             var marker_8502322732741cfa7dbd46f7a9fa327d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0a55fd2adacc6f4c08c8012139d03241);
#
#
#         var popup_3fb57b7bb7031afe476836ebbd70bbd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e80b550a4e717dc8996889612883007a = $(`&lt;div id=&quot;html_e80b550a4e717dc8996889612883007a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3fb57b7bb7031afe476836ebbd70bbd1.setContent(html_e80b550a4e717dc8996889612883007a);
#
#
#
#         marker_8502322732741cfa7dbd46f7a9fa327d.bindPopup(popup_3fb57b7bb7031afe476836ebbd70bbd1)
#         ;
#
#
#
#
#             var marker_fe73a6898b5efe6b8fba32f35e637e71 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0a55fd2adacc6f4c08c8012139d03241);
#
#
#         var popup_f06a45b7e49d14c31c160a554536fabb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5cde59f64f273ba40d6d86cb732a4d46 = $(`&lt;div id=&quot;html_5cde59f64f273ba40d6d86cb732a4d46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f06a45b7e49d14c31c160a554536fabb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2660b3355e72472ca7138f3134fd9e62 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2660b3355e72472ca7138f3134fd9e62&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2660b3355e72472ca7138f3134fd9e62 = L.map(
#                 &quot;map_2660b3355e72472ca7138f3134fd9e62&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92494c48c7ef1d91cc14197d076ce562 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92494c48c7ef1d91cc14197d076ce562.addTo(map_2660b3355e72472ca7138f3134fd9e62);
#
#
#             var feature_group_b0e01113aa9d64078ed1f11971139031 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_99ea9e07faf3f180a80829924a6d1e36 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b0e01113aa9d64078ed1f11971139031);
#
#
#         var popup_ea6be3367f04c772a3db1f88617cf5ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2f914bca1d6c7eb04ba04aef36b788b = $(`&lt;div id=&quot;html_b2f914bca1d6c7eb04ba04aef36b788b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ea6be3367f04c772a3db1f88617cf5ba.setContent(html_b2f914bca1d6c7eb04ba04aef36b788b);
#
#
#
#         marker_99ea9e07faf3f180a80829924a6d1e36.bindPopup(popup_ea6be3367f04c772a3db1f88617cf5ba)
#         ;
#
#
#
#
#             var marker_304c98adf97f2d7d295dfa0c12ac9c49 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b0e01113aa9d64078ed1f11971139031);
#
#
#         var popup_67ebc25a0f58e86a2626742aab8fdb85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a31f177671a84979d6df73c0819bd2f = $(`&lt;div id=&quot;html_6a31f177671a84979d6df73c0819bd2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_67ebc25a0f58e86a2626742aab8fdb85.setContent(html_6a31f177671a84979d6df73c0819bd2f);
#
#
#
#         marker_304c98adf97f2d7d295dfa0c12ac9c49.bindPopup(popup_67ebc25a0f58e86a2626742aab8fdb85)
#         ;
#
#
#
#
#             var marker_c2107a963a8230e9de3d0e2aadc09ded = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b0e01113aa9d64078ed1f11971139031);
#
#
#         var popup_0c8aa72e56dab5547976ca2cc104ee9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9a981d372022afffdf81abf1f2185de = $(`&lt;div id=&quot;html_d9a981d372022afffdf81abf1f2185de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0c8aa72e56dab5547976ca2cc104ee9e.setContent(html_d9a981d372022afffdf81abf1f2185de);
#
#
#
#         marker_c2107a963a8230e9de3d0e2aadc09ded.bindPopup(popup_0c8aa72e56dab5547976ca2cc104ee9e)
#         ;
#
#
#
#
#             var marker_3744975244f9445ab4e96b7f630c08bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b0e01113aa9d64078ed1f11971139031);
#
#
#         var popup_26ad5ea1bfc5eaf34a0e3d07d7b7518d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5640d19c968e85ac334936ac4a43132b = $(`&lt;div id=&quot;html_5640d19c968e85ac334936ac4a43132b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_26ad5ea1bfc5eaf34a0e3d07d7b7518d.setContent(html_5640d19c968e85ac334936ac4a43132b);
#
#
#
#         marker_3744975244f9445ab4e96b7f630c08bc.bindPopup(popup_26ad5ea1bfc5eaf34a0e3d07d7b7518d)
#         ;
#
#
#
#
#             var marker_0f6647980774116ea59e9c4bfc2b8b50 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b0e01113aa9d64078ed1f11971139031);
#
#
#         var popup_2837c57a72cbec132459351feb20e85b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a1ecbbc1c4de92bccf4201b90dc84264 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a1ecbbc1c4de92bccf4201b90dc84264&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a1ecbbc1c4de92bccf4201b90dc84264 = L.map(
#                 &quot;map_a1ecbbc1c4de92bccf4201b90dc84264&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c94c2596b467acf0676df0a66aa7cf7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c94c2596b467acf0676df0a66aa7cf7.addTo(map_a1ecbbc1c4de92bccf4201b90dc84264);
#
#
#             var feature_group_e5652a612483e48830637b58318f40ae = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e5652a612483e48830637b58318f40ae.addTo(map_a1ecbbc1c4de92bccf4201b90dc84264);
#
#
#             var feature_group_sub_group_03ef173bfe696a2fbf54b8cd8facfaa8 = L.featureGroup.subGroup(
#                 feature_group_e5652a612483e48830637b58318f40ae
#             );
#
#
#             var marker_abb8b7ea1cdc252fa192b9cbad3c3925 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_03ef173bfe696a2fbf54b8cd8facfaa8);
#
#
#         var popup_627f067d1110ea6092d390382bebeea3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86e0d77e57fe7a29423d1314109fae27 = $(`&lt;div id=&quot;html_86e0d77e57fe7a29423d1314109fae27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_627f067d1110ea6092d390382bebeea3.setContent(html_86e0d77e57fe7a29423d1314109fae27);
#
#
#
#         marker_abb8b7ea1cdc252fa192b9cbad3c3925.bindPopup(popup_627f067d1110ea6092d390382bebeea3)
#         ;
#
#
#
#
#             var marker_28e567cc0061777f808610bf0bb20722 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_03ef173bfe696a2fbf54b8cd8facfaa8);
#
#
#         var popup_8260613a0771c9caf894988e1490e20d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2af2ac3f669b3ac04e680fdebe54e6f = $(`&lt;div id=&quot;html_a2af2ac3f669b3ac04e680fdebe54e6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8260613a0771c9caf894988e1490e20d.setContent(html_a2af2ac3f669b3ac04e680fdebe54e6f);
#
#
#
#         marker_28e567cc0061777f808610bf0bb20722.bindPopup(popup_8260613a0771c9caf894988e1490e20d)
#         ;
#
#
#
#
#             var marker_6790f488946f7a05ee7352a954a20cd1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_03ef173bfe696a2fbf54b8cd8facfaa8);
#
#
#         var popup_1b5ceabc38daac8f1e77caee775b1939 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_488f46b72726014083fdceac8933ce53 = $(`&lt;div id=&quot;html_488f46b72726014083fdceac8933ce53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1b5ceabc38daac8f1e77caee775b1939.setContent(html_488f46b72726014083fdceac8933ce53);
#
#
#
#         marker_6790f488946f7a05ee7352a954a20cd1.bindPopup(popup_1b5ceabc38daac8f1e77caee775b1939)
#         ;
#
#
#
#
#             var marker_669fa15c58ac5ade86565784b0235f0f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_03ef173bfe696a2fbf54b8cd8facfaa8);
#
#
#         var popup_241990a2bf157482650dc20314a58055 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a03bf609fadc53a2f832d96e86ad053 = $(`&lt;div id=&quot;html_3a03bf609fadc53a2f832d96e86ad053&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_241990a2bf157482650dc20314a58055.setContent(html_3a03bf609fadc53a2f832d96e86ad053);
#
#
#
#         marker_
