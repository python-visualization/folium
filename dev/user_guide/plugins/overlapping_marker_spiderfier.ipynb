# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79ec6b0031da0063e824f433611b72c0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79ec6b0031da0063e824f433611b72c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79ec6b0031da0063e824f433611b72c0 = L.map(
#                 &quot;map_79ec6b0031da0063e824f433611b72c0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff3eed2c58f22febefdffe0ac5d27dad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff3eed2c58f22febefdffe0ac5d27dad.addTo(map_79ec6b0031da0063e824f433611b72c0);
#
#
#             var marker_f4da4852db00be9dde24027c2fe21914 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_79ec6b0031da0063e824f433611b72c0);
#
#
#         var popup_1542ffd8b31ec624a821e8ebb7a5d3ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_334e2c2bb9376e17edd8860a3cc8a2dd = $(`&lt;div id=&quot;html_334e2c2bb9376e17edd8860a3cc8a2dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1542ffd8b31ec624a821e8ebb7a5d3ae.setContent(html_334e2c2bb9376e17edd8860a3cc8a2dd);
#
#
#
#         marker_f4da4852db00be9dde24027c2fe21914.bindPopup(popup_1542ffd8b31ec624a821e8ebb7a5d3ae)
#         ;
#
#
#
#
#             var marker_8e954ab0b73768d7100f1747bceec211 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_79ec6b0031da0063e824f433611b72c0);
#
#
#         var popup_6a2fda462c5f67a34ebe2312ffadd11f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30d30e8ebef628af4a221963690e8a1b = $(`&lt;div id=&quot;html_30d30e8ebef628af4a221963690e8a1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6a2fda462c5f67a34ebe2312ffadd11f.setContent(html_30d30e8ebef628af4a221963690e8a1b);
#
#
#
#         marker_8e954ab0b73768d7100f1747bceec211.bindPopup(popup_6a2fda462c5f67a34ebe2312ffadd11f)
#         ;
#
#
#
#
#             var marker_4e95df8f29d99ea7e70b6b61171c3542 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_79ec6b0031da0063e824f433611b72c0);
#
#
#         var popup_49272e88c862d686889bd460110a01ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19d331f695cd34c23227b05504d198c3 = $(`&lt;div id=&quot;html_19d331f695cd34c23227b05504d198c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_49272e88c862d686889bd460110a01ed.setContent(html_19d331f695cd34c23227b05504d198c3);
#
#
#
#         marker_4e95df8f29d99ea7e70b6b61171c3542.bindPopup(popup_49272e88c862d686889bd460110a01ed)
#         ;
#
#
#
#
#             var marker_46757b95bdea9e28f14333272db70065 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_79ec6b0031da0063e824f433611b72c0);
#
#
#         var popup_69a421895d6f8dd8bea881674fc8cf51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_321385cb05ea2fae3fa7eb4ad8494b50 = $(`&lt;div id=&quot;html_321385cb05ea2fae3fa7eb4ad8494b50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_69a421895d6f8dd8bea881674fc8cf51.setContent(html_321385cb05ea2fae3fa7eb4ad8494b50);
#
#
#
#         marker_46757b95bdea9e28f14333272db70065.bindPopup(popup_69a421895d6f8dd8bea881674fc8cf51)
#         ;
#
#
#
#
#             var marker_090433dd0baa8984c12349d664e82522 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_79ec6b0031da0063e824f433611b72c0);
#
#
#         var popup_5c743a65e2e0b11e43851a91ef6d1bd5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8be5582261eaf6e5e30bdda81b6538f3 = $(`&lt;div id=&quot;html_8be5582261eaf6e5e30bdda81b6538f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5c743a65e2e0b11e43851a91ef6d1b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_219d0e1b68308be6ad1824d67b8171e0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_219d0e1b68308be6ad1824d67b8171e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_219d0e1b68308be6ad1824d67b8171e0 = L.map(
#                 &quot;map_219d0e1b68308be6ad1824d67b8171e0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_700216232765e8d7e392e28aa9e6b49e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_700216232765e8d7e392e28aa9e6b49e.addTo(map_219d0e1b68308be6ad1824d67b8171e0);
#
#
#             var feature_group_c83e89a96951ebf1ce6c36bfb48092fb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_757b6d985740f81863a52dd23680b94f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c83e89a96951ebf1ce6c36bfb48092fb);
#
#
#         var popup_d786d375a65c49ef1f5d3d758d6570b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_102bc07c4bc444b007c72ed2c2fef26d = $(`&lt;div id=&quot;html_102bc07c4bc444b007c72ed2c2fef26d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d786d375a65c49ef1f5d3d758d6570b1.setContent(html_102bc07c4bc444b007c72ed2c2fef26d);
#
#
#
#         marker_757b6d985740f81863a52dd23680b94f.bindPopup(popup_d786d375a65c49ef1f5d3d758d6570b1)
#         ;
#
#
#
#
#             var marker_e15ac5ae88c7992f004321d46da80136 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c83e89a96951ebf1ce6c36bfb48092fb);
#
#
#         var popup_3970c9e43d68b344dcc9bd202b1a219e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_920a1bb3488d4c9e7b3f29493ec99598 = $(`&lt;div id=&quot;html_920a1bb3488d4c9e7b3f29493ec99598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3970c9e43d68b344dcc9bd202b1a219e.setContent(html_920a1bb3488d4c9e7b3f29493ec99598);
#
#
#
#         marker_e15ac5ae88c7992f004321d46da80136.bindPopup(popup_3970c9e43d68b344dcc9bd202b1a219e)
#         ;
#
#
#
#
#             var marker_4f25949e0403123211b1f3337847e276 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c83e89a96951ebf1ce6c36bfb48092fb);
#
#
#         var popup_48595ef0e7311cc23e9d2e6cd53b353e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90329bfc482aebbfe88ad28acac1b8bf = $(`&lt;div id=&quot;html_90329bfc482aebbfe88ad28acac1b8bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_48595ef0e7311cc23e9d2e6cd53b353e.setContent(html_90329bfc482aebbfe88ad28acac1b8bf);
#
#
#
#         marker_4f25949e0403123211b1f3337847e276.bindPopup(popup_48595ef0e7311cc23e9d2e6cd53b353e)
#         ;
#
#
#
#
#             var marker_c8e5b2ed10b7a501152b154bf08215bf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c83e89a96951ebf1ce6c36bfb48092fb);
#
#
#         var popup_908a4cea9a18bbc33fca1750d8d92c02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_953b37a7e6dc298c923dad410a10a86f = $(`&lt;div id=&quot;html_953b37a7e6dc298c923dad410a10a86f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_908a4cea9a18bbc33fca1750d8d92c02.setContent(html_953b37a7e6dc298c923dad410a10a86f);
#
#
#
#         marker_c8e5b2ed10b7a501152b154bf08215bf.bindPopup(popup_908a4cea9a18bbc33fca1750d8d92c02)
#         ;
#
#
#
#
#             var marker_96579d730737067e6ef403f01855c26b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c83e89a96951ebf1ce6c36bfb48092fb);
#
#
#         var popup_fc58982fce0ca848ed36717032e1b80f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f006e2386d92ff772c63e7620f29b55c {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f006e2386d92ff772c63e7620f29b55c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f006e2386d92ff772c63e7620f29b55c = L.map(
#                 &quot;map_f006e2386d92ff772c63e7620f29b55c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_311b9102746edd532ed3f66a9284d9d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_311b9102746edd532ed3f66a9284d9d4.addTo(map_f006e2386d92ff772c63e7620f29b55c);
#
#
#             var feature_group_267de484e605ba0b8f60bbf771fa81ca = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_267de484e605ba0b8f60bbf771fa81ca.addTo(map_f006e2386d92ff772c63e7620f29b55c);
#
#
#             var feature_group_sub_group_6c626bc5d96f9b63bd17e9a07b1249e7 = L.featureGroup.subGroup(
#                 feature_group_267de484e605ba0b8f60bbf771fa81ca
#             );
#
#
#             var marker_b34f937bb21c7424e000920ac594136c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c626bc5d96f9b63bd17e9a07b1249e7);
#
#
#         var popup_f63cededd35c0ca9f30eb9cb354aa9b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f463bdaef22de6df5b785a4e86353d89 = $(`&lt;div id=&quot;html_f463bdaef22de6df5b785a4e86353d89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f63cededd35c0ca9f30eb9cb354aa9b7.setContent(html_f463bdaef22de6df5b785a4e86353d89);
#
#
#
#         marker_b34f937bb21c7424e000920ac594136c.bindPopup(popup_f63cededd35c0ca9f30eb9cb354aa9b7)
#         ;
#
#
#
#
#             var marker_1c5a750398d1917d9cd9cff3478fe56c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c626bc5d96f9b63bd17e9a07b1249e7);
#
#
#         var popup_180152a7828da353ecd5704dd41e12b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de0a5ad1e9262b848471a5dbc5b2dc27 = $(`&lt;div id=&quot;html_de0a5ad1e9262b848471a5dbc5b2dc27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_180152a7828da353ecd5704dd41e12b1.setContent(html_de0a5ad1e9262b848471a5dbc5b2dc27);
#
#
#
#         marker_1c5a750398d1917d9cd9cff3478fe56c.bindPopup(popup_180152a7828da353ecd5704dd41e12b1)
#         ;
#
#
#
#
#             var marker_1291a468856b3031f259bc06c496a0d4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c626bc5d96f9b63bd17e9a07b1249e7);
#
#
#         var popup_01711dec531a87ac26ac089e4b818259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6af0c557ec8cb699412c71c5a5769b96 = $(`&lt;div id=&quot;html_6af0c557ec8cb699412c71c5a5769b96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_01711dec531a87ac26ac089e4b818259.setContent(html_6af0c557ec8cb699412c71c5a5769b96);
#
#
#
#         marker_1291a468856b3031f259bc06c496a0d4.bindPopup(popup_01711dec531a87ac26ac089e4b818259)
#         ;
#
#
#
#
#             var marker_693998453f07aac575df32e6d03ce243 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6c626bc5d96f9b63bd17e9a07b1249e7);
#
#
#         var popup_140b56b0e9fdcbb933d009e58f33da92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_307b6cbf9ad95094782fc2085c8ce97e = $(`&lt;div id=&quot;html_307b6cbf9ad95094782fc2085c8ce97e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_140b56b0e9fdcbb933d009e58f33da92.setContent(html_307b6cbf9ad95094782fc2085c8ce97e);
#
#
#
#         mark
