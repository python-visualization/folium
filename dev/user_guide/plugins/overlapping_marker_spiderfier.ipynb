# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f1272c7db5f81d2a65539ae79378401 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f1272c7db5f81d2a65539ae79378401&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f1272c7db5f81d2a65539ae79378401 = L.map(
#                 &quot;map_0f1272c7db5f81d2a65539ae79378401&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a7a87ab63c3ad940ede5f240feae870 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a7a87ab63c3ad940ede5f240feae870.addTo(map_0f1272c7db5f81d2a65539ae79378401);
#
#
#             var marker_4a89211bcdf7bc1585fa0ac4e3d0b94c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_0f1272c7db5f81d2a65539ae79378401);
#
#
#         var popup_2888d04055980889991b43965eeea17b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a10d583d1d316fd5e73db453adeefb0 = $(`&lt;div id=&quot;html_7a10d583d1d316fd5e73db453adeefb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2888d04055980889991b43965eeea17b.setContent(html_7a10d583d1d316fd5e73db453adeefb0);
#
#
#
#         marker_4a89211bcdf7bc1585fa0ac4e3d0b94c.bindPopup(popup_2888d04055980889991b43965eeea17b)
#         ;
#
#
#
#
#             var marker_0a5141983f3ec1f1caec223b4fb12ce9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_0f1272c7db5f81d2a65539ae79378401);
#
#
#         var popup_85d0f8e88e6098624eea152679a5fc77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ad5e366cd61c43dfc14e8ddb3c2f2b0 = $(`&lt;div id=&quot;html_1ad5e366cd61c43dfc14e8ddb3c2f2b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_85d0f8e88e6098624eea152679a5fc77.setContent(html_1ad5e366cd61c43dfc14e8ddb3c2f2b0);
#
#
#
#         marker_0a5141983f3ec1f1caec223b4fb12ce9.bindPopup(popup_85d0f8e88e6098624eea152679a5fc77)
#         ;
#
#
#
#
#             var marker_1c62bd43a9dee11ed37811baa9aa8505 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_0f1272c7db5f81d2a65539ae79378401);
#
#
#         var popup_f80c7bef17da1ac331b558f01499e263 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8916710f43b8bbc3fe12477afb7054c6 = $(`&lt;div id=&quot;html_8916710f43b8bbc3fe12477afb7054c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f80c7bef17da1ac331b558f01499e263.setContent(html_8916710f43b8bbc3fe12477afb7054c6);
#
#
#
#         marker_1c62bd43a9dee11ed37811baa9aa8505.bindPopup(popup_f80c7bef17da1ac331b558f01499e263)
#         ;
#
#
#
#
#             var marker_fdf6f9317898a3f737c99c65955d08da = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_0f1272c7db5f81d2a65539ae79378401);
#
#
#         var popup_60cd89f61baef129410175926572fef1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1ce0e06798baa6a42eaf48e791f0eafc = $(`&lt;div id=&quot;html_1ce0e06798baa6a42eaf48e791f0eafc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_60cd89f61baef129410175926572fef1.setContent(html_1ce0e06798baa6a42eaf48e791f0eafc);
#
#
#
#         marker_fdf6f9317898a3f737c99c65955d08da.bindPopup(popup_60cd89f61baef129410175926572fef1)
#         ;
#
#
#
#
#             var marker_78cc5b53c3453ef47937e75513bee852 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_0f1272c7db5f81d2a65539ae79378401);
#
#
#         var popup_73fc8270672d46492a2557b472d7a9da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a88023e520dd2681bda08a351474f72 = $(`&lt;div id=&quot;html_4a88023e520dd2681bda08a351474f72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_73fc8270672d46492a2557b472d7a9da.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6ede5b062760a288092927049616a7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6ede5b062760a288092927049616a7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6ede5b062760a288092927049616a7c = L.map(
#                 &quot;map_e6ede5b062760a288092927049616a7c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9e1e89f7ae7b48d840e57b2be42fccd4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9e1e89f7ae7b48d840e57b2be42fccd4.addTo(map_e6ede5b062760a288092927049616a7c);
#
#
#             var feature_group_dbdb9c2a761a7df3f6fa41ebb0a39f81 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_06e5cc51c7b9a7a7989284114f46b149 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dbdb9c2a761a7df3f6fa41ebb0a39f81);
#
#
#         var popup_b55625566ee5b2a2b5ee69a6e9261e99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ecd1e8012c634414462812009e30196 = $(`&lt;div id=&quot;html_4ecd1e8012c634414462812009e30196&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b55625566ee5b2a2b5ee69a6e9261e99.setContent(html_4ecd1e8012c634414462812009e30196);
#
#
#
#         marker_06e5cc51c7b9a7a7989284114f46b149.bindPopup(popup_b55625566ee5b2a2b5ee69a6e9261e99)
#         ;
#
#
#
#
#             var marker_6bff3b634f36b0ff3c752d0fee1fb2b2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dbdb9c2a761a7df3f6fa41ebb0a39f81);
#
#
#         var popup_e5cb922e360f7dbe789a37ccd01987cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2200f56a9738d40a2b4a9d014af4d1d9 = $(`&lt;div id=&quot;html_2200f56a9738d40a2b4a9d014af4d1d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e5cb922e360f7dbe789a37ccd01987cd.setContent(html_2200f56a9738d40a2b4a9d014af4d1d9);
#
#
#
#         marker_6bff3b634f36b0ff3c752d0fee1fb2b2.bindPopup(popup_e5cb922e360f7dbe789a37ccd01987cd)
#         ;
#
#
#
#
#             var marker_cf5b5f3d5e4f3df2ff8f4e1b0d57ecbe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dbdb9c2a761a7df3f6fa41ebb0a39f81);
#
#
#         var popup_cfed65c00ab117430eea54d09f7bc89f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb0b1cf640aa65d72f302d5296f87cc3 = $(`&lt;div id=&quot;html_fb0b1cf640aa65d72f302d5296f87cc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cfed65c00ab117430eea54d09f7bc89f.setContent(html_fb0b1cf640aa65d72f302d5296f87cc3);
#
#
#
#         marker_cf5b5f3d5e4f3df2ff8f4e1b0d57ecbe.bindPopup(popup_cfed65c00ab117430eea54d09f7bc89f)
#         ;
#
#
#
#
#             var marker_b0602de1ebf9e1d4733a3baa6b04bcf2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dbdb9c2a761a7df3f6fa41ebb0a39f81);
#
#
#         var popup_0d731b006c6f99f16c4d1006f4d42372 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2292c7b8d5719311835fb26cd7ac534c = $(`&lt;div id=&quot;html_2292c7b8d5719311835fb26cd7ac534c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0d731b006c6f99f16c4d1006f4d42372.setContent(html_2292c7b8d5719311835fb26cd7ac534c);
#
#
#
#         marker_b0602de1ebf9e1d4733a3baa6b04bcf2.bindPopup(popup_0d731b006c6f99f16c4d1006f4d42372)
#         ;
#
#
#
#
#             var marker_a5998ffbb96a0da9d9788a91f4669b91 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dbdb9c2a761a7df3f6fa41ebb0a39f81);
#
#
#         var popup_737ea718c67b6551755525423b41bbf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b2f747323af4b3a2d64ac87e22b31a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b2f747323af4b3a2d64ac87e22b31a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b2f747323af4b3a2d64ac87e22b31a5 = L.map(
#                 &quot;map_2b2f747323af4b3a2d64ac87e22b31a5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b40a1be5741e983d01e5d2779d0a2608 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b40a1be5741e983d01e5d2779d0a2608.addTo(map_2b2f747323af4b3a2d64ac87e22b31a5);
#
#
#             var feature_group_f3b72cee44934e20b870595886dfff88 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f3b72cee44934e20b870595886dfff88.addTo(map_2b2f747323af4b3a2d64ac87e22b31a5);
#
#
#             var feature_group_sub_group_fe2aaa86aa5dc40beed4e6a11ce03e1e = L.featureGroup.subGroup(
#                 feature_group_f3b72cee44934e20b870595886dfff88
#             );
#
#
#             var marker_d91d36bfd4e14a33229224466dc96006 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fe2aaa86aa5dc40beed4e6a11ce03e1e);
#
#
#         var popup_732d254df78cb96672e0c6ebfc6bc89b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fe9ea3b14ee582f89fadaca2e876f68 = $(`&lt;div id=&quot;html_7fe9ea3b14ee582f89fadaca2e876f68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_732d254df78cb96672e0c6ebfc6bc89b.setContent(html_7fe9ea3b14ee582f89fadaca2e876f68);
#
#
#
#         marker_d91d36bfd4e14a33229224466dc96006.bindPopup(popup_732d254df78cb96672e0c6ebfc6bc89b)
#         ;
#
#
#
#
#             var marker_ff872e81e97c82681230f123e71fe779 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fe2aaa86aa5dc40beed4e6a11ce03e1e);
#
#
#         var popup_dde6c50bcca36bc809b5ce1894f2fd17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f974a26373ade7f7bfa2e754f01e84e2 = $(`&lt;div id=&quot;html_f974a26373ade7f7bfa2e754f01e84e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_dde6c50bcca36bc809b5ce1894f2fd17.setContent(html_f974a26373ade7f7bfa2e754f01e84e2);
#
#
#
#         marker_ff872e81e97c82681230f123e71fe779.bindPopup(popup_dde6c50bcca36bc809b5ce1894f2fd17)
#         ;
#
#
#
#
#             var marker_845fb95955f3a32cde2f78d02771a6e7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fe2aaa86aa5dc40beed4e6a11ce03e1e);
#
#
#         var popup_2ff5d2cb0452a3eb335f9e67c3418178 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8f9666991374c0c90b08bf561c3174f = $(`&lt;div id=&quot;html_a8f9666991374c0c90b08bf561c3174f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2ff5d2cb0452a3eb335f9e67c3418178.setContent(html_a8f9666991374c0c90b08bf561c3174f);
#
#
#
#         marker_845fb95955f3a32cde2f78d02771a6e7.bindPopup(popup_2ff5d2cb0452a3eb335f9e67c3418178)
#         ;
#
#
#
#
#             var marker_e387f64cb6394a2035d9282c39f35b9d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fe2aaa86aa5dc40beed4e6a11ce03e1e);
#
#
#         var popup_2139ed22af8e13e750bf5c2c762cb93c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52d17b72468ccf630504dfbb9d18784e = $(`&lt;div id=&quot;html_52d17b72468ccf630504dfbb9d18784e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2139ed22af8e13e750bf5c2c762cb93c.setContent(html_52d17b72468ccf630504dfbb9d18784e);
#
#
#
#         marker_
