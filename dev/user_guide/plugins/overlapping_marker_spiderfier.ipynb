# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d612eaa587c54ed2a35e63ec6f0eeef1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d612eaa587c54ed2a35e63ec6f0eeef1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d612eaa587c54ed2a35e63ec6f0eeef1 = L.map(
#                 &quot;map_d612eaa587c54ed2a35e63ec6f0eeef1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf2aedd3f2f4fd0f0622a133f7c13ae9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf2aedd3f2f4fd0f0622a133f7c13ae9.addTo(map_d612eaa587c54ed2a35e63ec6f0eeef1);
#
#
#             var marker_eef1e2ce7f803d67fc5c79375cd9de40 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d612eaa587c54ed2a35e63ec6f0eeef1);
#
#
#         var popup_5a03186d3fdcd8bf5b2fecbae0871f38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c176832ad9c3e8c877e3af8e157d9e31 = $(`&lt;div id=&quot;html_c176832ad9c3e8c877e3af8e157d9e31&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5a03186d3fdcd8bf5b2fecbae0871f38.setContent(html_c176832ad9c3e8c877e3af8e157d9e31);
#
#
#
#         marker_eef1e2ce7f803d67fc5c79375cd9de40.bindPopup(popup_5a03186d3fdcd8bf5b2fecbae0871f38)
#         ;
#
#
#
#
#             var marker_43af2aebec5d34e0833291f39520e59b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d612eaa587c54ed2a35e63ec6f0eeef1);
#
#
#         var popup_08e0ba67ca93b6ea6420cb92f80e0124 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad67f6dd6a2b474407e5925275baa8bd = $(`&lt;div id=&quot;html_ad67f6dd6a2b474407e5925275baa8bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_08e0ba67ca93b6ea6420cb92f80e0124.setContent(html_ad67f6dd6a2b474407e5925275baa8bd);
#
#
#
#         marker_43af2aebec5d34e0833291f39520e59b.bindPopup(popup_08e0ba67ca93b6ea6420cb92f80e0124)
#         ;
#
#
#
#
#             var marker_0d67bccba6d8a9e505231edc64454ba8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d612eaa587c54ed2a35e63ec6f0eeef1);
#
#
#         var popup_b4788e93ed47678b7f053cbc2da95313 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fda95fb2154cde2b1534cc20a410fa3 = $(`&lt;div id=&quot;html_2fda95fb2154cde2b1534cc20a410fa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b4788e93ed47678b7f053cbc2da95313.setContent(html_2fda95fb2154cde2b1534cc20a410fa3);
#
#
#
#         marker_0d67bccba6d8a9e505231edc64454ba8.bindPopup(popup_b4788e93ed47678b7f053cbc2da95313)
#         ;
#
#
#
#
#             var marker_be82baff7047ea8b494e56e202145931 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d612eaa587c54ed2a35e63ec6f0eeef1);
#
#
#         var popup_de37621ec52ada58dab292825cae4737 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e66646d824bcb3559becfdaa36f93b2b = $(`&lt;div id=&quot;html_e66646d824bcb3559becfdaa36f93b2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_de37621ec52ada58dab292825cae4737.setContent(html_e66646d824bcb3559becfdaa36f93b2b);
#
#
#
#         marker_be82baff7047ea8b494e56e202145931.bindPopup(popup_de37621ec52ada58dab292825cae4737)
#         ;
#
#
#
#
#             var marker_d7edf2b454aff0604e0368ac98ea0a44 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d612eaa587c54ed2a35e63ec6f0eeef1);
#
#
#         var popup_207ae5bc34391f297e02914dc0ce1b64 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cf9d665a62f70af306f64a47ce9c77e = $(`&lt;div id=&quot;html_3cf9d665a62f70af306f64a47ce9c77e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_207ae5bc34391f297e02914dc0ce1b64.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2df34f9b8266f61df4871dcb468b77da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2df34f9b8266f61df4871dcb468b77da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2df34f9b8266f61df4871dcb468b77da = L.map(
#                 &quot;map_2df34f9b8266f61df4871dcb468b77da&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_153d0aefbb3b1db7a96745c9dc0ebb1c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_153d0aefbb3b1db7a96745c9dc0ebb1c.addTo(map_2df34f9b8266f61df4871dcb468b77da);
#
#
#             var feature_group_74c0ebf48fbcd8ddedb54c5bd1a5f1e8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_220156d2d60f7d4f580090784ed15e00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_74c0ebf48fbcd8ddedb54c5bd1a5f1e8);
#
#
#         var popup_f1dc25e23b61a31b8e355f6bada85a74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af6d820a0ae113115916e006f1befa62 = $(`&lt;div id=&quot;html_af6d820a0ae113115916e006f1befa62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f1dc25e23b61a31b8e355f6bada85a74.setContent(html_af6d820a0ae113115916e006f1befa62);
#
#
#
#         marker_220156d2d60f7d4f580090784ed15e00.bindPopup(popup_f1dc25e23b61a31b8e355f6bada85a74)
#         ;
#
#
#
#
#             var marker_a83cbf8f65fa16a00e14757a5d21b20c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_74c0ebf48fbcd8ddedb54c5bd1a5f1e8);
#
#
#         var popup_ef0278dbd7eb7584d234bd684644fe82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d65ec992dd97753ef58cf923681bb418 = $(`&lt;div id=&quot;html_d65ec992dd97753ef58cf923681bb418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ef0278dbd7eb7584d234bd684644fe82.setContent(html_d65ec992dd97753ef58cf923681bb418);
#
#
#
#         marker_a83cbf8f65fa16a00e14757a5d21b20c.bindPopup(popup_ef0278dbd7eb7584d234bd684644fe82)
#         ;
#
#
#
#
#             var marker_681c291ce5671c256e8a1b1f726072b7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_74c0ebf48fbcd8ddedb54c5bd1a5f1e8);
#
#
#         var popup_8deadf72b02a63b63cbb27938ecaa0d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbba9a60f9e1a68c8ac5b48cbef9f1e2 = $(`&lt;div id=&quot;html_bbba9a60f9e1a68c8ac5b48cbef9f1e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8deadf72b02a63b63cbb27938ecaa0d4.setContent(html_bbba9a60f9e1a68c8ac5b48cbef9f1e2);
#
#
#
#         marker_681c291ce5671c256e8a1b1f726072b7.bindPopup(popup_8deadf72b02a63b63cbb27938ecaa0d4)
#         ;
#
#
#
#
#             var marker_a9a75add03d244240e46ed6fced553e1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_74c0ebf48fbcd8ddedb54c5bd1a5f1e8);
#
#
#         var popup_c7bf71e4cce0197808f9651996f3f36b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ec4f350057d0b26dd5ef80ad4fff6d3 = $(`&lt;div id=&quot;html_9ec4f350057d0b26dd5ef80ad4fff6d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c7bf71e4cce0197808f9651996f3f36b.setContent(html_9ec4f350057d0b26dd5ef80ad4fff6d3);
#
#
#
#         marker_a9a75add03d244240e46ed6fced553e1.bindPopup(popup_c7bf71e4cce0197808f9651996f3f36b)
#         ;
#
#
#
#
#             var marker_9a82bfdbb0b68bc41910eaf4adf7ed55 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_74c0ebf48fbcd8ddedb54c5bd1a5f1e8);
#
#
#         var popup_28cb9725abc6de332f5bce8833f77826 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd26ae32aa85b2a2c433ec6bbc60ff5f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd26ae32aa85b2a2c433ec6bbc60ff5f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd26ae32aa85b2a2c433ec6bbc60ff5f = L.map(
#                 &quot;map_fd26ae32aa85b2a2c433ec6bbc60ff5f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a26f5e663a14fc229e8eee0e6e32ac94 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a26f5e663a14fc229e8eee0e6e32ac94.addTo(map_fd26ae32aa85b2a2c433ec6bbc60ff5f);
#
#
#             var feature_group_1d00e5903c278f3fcab4c2312a71ca6b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1d00e5903c278f3fcab4c2312a71ca6b.addTo(map_fd26ae32aa85b2a2c433ec6bbc60ff5f);
#
#
#             var feature_group_sub_group_aecc7f292a3974d44c422d87ef9aa652 = L.featureGroup.subGroup(
#                 feature_group_1d00e5903c278f3fcab4c2312a71ca6b
#             );
#
#
#             var marker_2600b9153b770e84ef4a2ee87cead546 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_aecc7f292a3974d44c422d87ef9aa652);
#
#
#         var popup_2a418020a286955b2edd7100d6f2f53e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80941b06b758434179a548d15d936481 = $(`&lt;div id=&quot;html_80941b06b758434179a548d15d936481&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2a418020a286955b2edd7100d6f2f53e.setContent(html_80941b06b758434179a548d15d936481);
#
#
#
#         marker_2600b9153b770e84ef4a2ee87cead546.bindPopup(popup_2a418020a286955b2edd7100d6f2f53e)
#         ;
#
#
#
#
#             var marker_fc0fc52cd7895f2ebbc66a236c2f9aa3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_aecc7f292a3974d44c422d87ef9aa652);
#
#
#         var popup_0a617c60e860fe280889d7a2b7e363ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed3a26048d948e1a6f227d3fe7ff708b = $(`&lt;div id=&quot;html_ed3a26048d948e1a6f227d3fe7ff708b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0a617c60e860fe280889d7a2b7e363ae.setContent(html_ed3a26048d948e1a6f227d3fe7ff708b);
#
#
#
#         marker_fc0fc52cd7895f2ebbc66a236c2f9aa3.bindPopup(popup_0a617c60e860fe280889d7a2b7e363ae)
#         ;
#
#
#
#
#             var marker_8c52f5a1e7437a29c926dcbc98b66f5f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_aecc7f292a3974d44c422d87ef9aa652);
#
#
#         var popup_b1d8aaa65ba1516e16a0c4efc3a225ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c66e5384f75546191420fb20b2dc561 = $(`&lt;div id=&quot;html_2c66e5384f75546191420fb20b2dc561&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b1d8aaa65ba1516e16a0c4efc3a225ec.setContent(html_2c66e5384f75546191420fb20b2dc561);
#
#
#
#         marker_8c52f5a1e7437a29c926dcbc98b66f5f.bindPopup(popup_b1d8aaa65ba1516e16a0c4efc3a225ec)
#         ;
#
#
#
#
#             var marker_4a73be610aa93686e2694ddb083a17bc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_aecc7f292a3974d44c422d87ef9aa652);
#
#
#         var popup_a1c367dcdb25a483e70a919cf2365e7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0beddf50bcd1fae1f5f7dcab06f9262a = $(`&lt;div id=&quot;html_0beddf50bcd1fae1f5f7dcab06f9262a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a1c367dcdb25a483e70a919cf2365e7b.setContent(html_0beddf50bcd1fae1f5f7dcab06f9262a);
#
#
#
#         marker_
