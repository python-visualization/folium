# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9dbdd245a8e241d899696ca13563bf9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9dbdd245a8e241d899696ca13563bf9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9dbdd245a8e241d899696ca13563bf9 = L.map(
#                 &quot;map_e9dbdd245a8e241d899696ca13563bf9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_667d8031801badc47fde085899ada019 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_667d8031801badc47fde085899ada019.addTo(map_e9dbdd245a8e241d899696ca13563bf9);
#
#
#             var marker_32008a73ed9992fed642f85b9fafe610 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e9dbdd245a8e241d899696ca13563bf9);
#
#
#         var popup_4e25c559098cd7e72e115ce133123ba7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c25f46c602de1254877b1c128d3007ae = $(`&lt;div id=&quot;html_c25f46c602de1254877b1c128d3007ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4e25c559098cd7e72e115ce133123ba7.setContent(html_c25f46c602de1254877b1c128d3007ae);
#
#
#
#         marker_32008a73ed9992fed642f85b9fafe610.bindPopup(popup_4e25c559098cd7e72e115ce133123ba7)
#         ;
#
#
#
#
#             var marker_f4f20e5853683d1ab3b77cf908a6c437 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e9dbdd245a8e241d899696ca13563bf9);
#
#
#         var popup_d22015f9842aee99ac51d60d73681d3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_125592aff7c47c0ea14e1e2db14e0fb7 = $(`&lt;div id=&quot;html_125592aff7c47c0ea14e1e2db14e0fb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d22015f9842aee99ac51d60d73681d3a.setContent(html_125592aff7c47c0ea14e1e2db14e0fb7);
#
#
#
#         marker_f4f20e5853683d1ab3b77cf908a6c437.bindPopup(popup_d22015f9842aee99ac51d60d73681d3a)
#         ;
#
#
#
#
#             var marker_885615ee143f93abe2f10160cf9c3809 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e9dbdd245a8e241d899696ca13563bf9);
#
#
#         var popup_00540feba79611d81ee2bf870bc3672e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac51001488dd5b19663a6629e9250827 = $(`&lt;div id=&quot;html_ac51001488dd5b19663a6629e9250827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_00540feba79611d81ee2bf870bc3672e.setContent(html_ac51001488dd5b19663a6629e9250827);
#
#
#
#         marker_885615ee143f93abe2f10160cf9c3809.bindPopup(popup_00540feba79611d81ee2bf870bc3672e)
#         ;
#
#
#
#
#             var marker_928b26c7190c668e1600505908c527af = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e9dbdd245a8e241d899696ca13563bf9);
#
#
#         var popup_cce2c250df56d40a4b3353e77da352e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dae12cc33f7d9fae12af3e5c786ac8a = $(`&lt;div id=&quot;html_3dae12cc33f7d9fae12af3e5c786ac8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cce2c250df56d40a4b3353e77da352e5.setContent(html_3dae12cc33f7d9fae12af3e5c786ac8a);
#
#
#
#         marker_928b26c7190c668e1600505908c527af.bindPopup(popup_cce2c250df56d40a4b3353e77da352e5)
#         ;
#
#
#
#
#             var marker_f93344a6b1b3f287f90a232762300d56 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e9dbdd245a8e241d899696ca13563bf9);
#
#
#         var popup_0e834e0e4c180f497d422dcb2a380399 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b68dabfcf65801de4db0c4a2d208dddf = $(`&lt;div id=&quot;html_b68dabfcf65801de4db0c4a2d208dddf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0e834e0e4c180f497d422dcb2a380399.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3169d6140826170eb5c7b35f1c970c91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3169d6140826170eb5c7b35f1c970c91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3169d6140826170eb5c7b35f1c970c91 = L.map(
#                 &quot;map_3169d6140826170eb5c7b35f1c970c91&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_768626d2485165a2fa0c8dce4ad62dcb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_768626d2485165a2fa0c8dce4ad62dcb.addTo(map_3169d6140826170eb5c7b35f1c970c91);
#
#
#             var feature_group_ee3bd495ee2aaf23d5e4d5e97a0e7342 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_499866c3b2a8b0134c0cb1a933ed3a20 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ee3bd495ee2aaf23d5e4d5e97a0e7342);
#
#
#         var popup_ac770934f17d9be91b32dd202401a363 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aef554f1be069db2e60309711a2dc316 = $(`&lt;div id=&quot;html_aef554f1be069db2e60309711a2dc316&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ac770934f17d9be91b32dd202401a363.setContent(html_aef554f1be069db2e60309711a2dc316);
#
#
#
#         marker_499866c3b2a8b0134c0cb1a933ed3a20.bindPopup(popup_ac770934f17d9be91b32dd202401a363)
#         ;
#
#
#
#
#             var marker_7279c37ed8bd20a9e1452d01684edaab = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ee3bd495ee2aaf23d5e4d5e97a0e7342);
#
#
#         var popup_ca52d2e4b0cbffc38191971769beafd6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8efd42dfd57bd0666bd52247a7e09e44 = $(`&lt;div id=&quot;html_8efd42dfd57bd0666bd52247a7e09e44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ca52d2e4b0cbffc38191971769beafd6.setContent(html_8efd42dfd57bd0666bd52247a7e09e44);
#
#
#
#         marker_7279c37ed8bd20a9e1452d01684edaab.bindPopup(popup_ca52d2e4b0cbffc38191971769beafd6)
#         ;
#
#
#
#
#             var marker_89b496da3415faab4204ab6481daba73 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ee3bd495ee2aaf23d5e4d5e97a0e7342);
#
#
#         var popup_7c31bf02ffeb84409e96123cc7f2fae9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50c29adb7ebcaa7848434905a43c7127 = $(`&lt;div id=&quot;html_50c29adb7ebcaa7848434905a43c7127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7c31bf02ffeb84409e96123cc7f2fae9.setContent(html_50c29adb7ebcaa7848434905a43c7127);
#
#
#
#         marker_89b496da3415faab4204ab6481daba73.bindPopup(popup_7c31bf02ffeb84409e96123cc7f2fae9)
#         ;
#
#
#
#
#             var marker_662c6b98da659da13b670353880d8308 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ee3bd495ee2aaf23d5e4d5e97a0e7342);
#
#
#         var popup_27efeb21d380ba4660970c1936d72ca5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfb371f418353e130094a0b998036242 = $(`&lt;div id=&quot;html_dfb371f418353e130094a0b998036242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_27efeb21d380ba4660970c1936d72ca5.setContent(html_dfb371f418353e130094a0b998036242);
#
#
#
#         marker_662c6b98da659da13b670353880d8308.bindPopup(popup_27efeb21d380ba4660970c1936d72ca5)
#         ;
#
#
#
#
#             var marker_d57907facf6d8067313e6f0cfee74f05 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ee3bd495ee2aaf23d5e4d5e97a0e7342);
#
#
#         var popup_95883b1a2047b27a3221cc397fa5f591 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_11c9f520e0d2ff056ea594dbf01faae1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_11c9f520e0d2ff056ea594dbf01faae1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_11c9f520e0d2ff056ea594dbf01faae1 = L.map(
#                 &quot;map_11c9f520e0d2ff056ea594dbf01faae1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7073d6f387f23f38d73e6544818228b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7073d6f387f23f38d73e6544818228b0.addTo(map_11c9f520e0d2ff056ea594dbf01faae1);
#
#
#             var feature_group_4aa74aa078b63bfc6a01ded6dad525a7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4aa74aa078b63bfc6a01ded6dad525a7.addTo(map_11c9f520e0d2ff056ea594dbf01faae1);
#
#
#             var feature_group_sub_group_a124e69097e92b4c9e59abb43bd853f4 = L.featureGroup.subGroup(
#                 feature_group_4aa74aa078b63bfc6a01ded6dad525a7
#             );
#
#
#             var marker_3110e79e50cb54e6711ec43db4581b57 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a124e69097e92b4c9e59abb43bd853f4);
#
#
#         var popup_a0b9ac3102433043aea2ee62a4e8235b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59fbe4d84c31cb5ca28c8cc7fccfe017 = $(`&lt;div id=&quot;html_59fbe4d84c31cb5ca28c8cc7fccfe017&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a0b9ac3102433043aea2ee62a4e8235b.setContent(html_59fbe4d84c31cb5ca28c8cc7fccfe017);
#
#
#
#         marker_3110e79e50cb54e6711ec43db4581b57.bindPopup(popup_a0b9ac3102433043aea2ee62a4e8235b)
#         ;
#
#
#
#
#             var marker_a3fda67427640d0f6484828e7f76c859 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a124e69097e92b4c9e59abb43bd853f4);
#
#
#         var popup_fccb8c0a542114e9f226286686a2b5f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12997434c59ee2ffbe17e1833a8ad6b4 = $(`&lt;div id=&quot;html_12997434c59ee2ffbe17e1833a8ad6b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fccb8c0a542114e9f226286686a2b5f5.setContent(html_12997434c59ee2ffbe17e1833a8ad6b4);
#
#
#
#         marker_a3fda67427640d0f6484828e7f76c859.bindPopup(popup_fccb8c0a542114e9f226286686a2b5f5)
#         ;
#
#
#
#
#             var marker_177076775de2cea578f9283bd94b2a85 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a124e69097e92b4c9e59abb43bd853f4);
#
#
#         var popup_46a555650751127ee6328e07fc6ece8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_747b938d58ec10ca88ff7156e8e1b11c = $(`&lt;div id=&quot;html_747b938d58ec10ca88ff7156e8e1b11c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_46a555650751127ee6328e07fc6ece8a.setContent(html_747b938d58ec10ca88ff7156e8e1b11c);
#
#
#
#         marker_177076775de2cea578f9283bd94b2a85.bindPopup(popup_46a555650751127ee6328e07fc6ece8a)
#         ;
#
#
#
#
#             var marker_4fdc58d741ed105cf8b384ac87f7aea5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a124e69097e92b4c9e59abb43bd853f4);
#
#
#         var popup_736875f5ee2d027aab4abe9ce50659b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8788a531f443b9ebf96c3682c60cba9b = $(`&lt;div id=&quot;html_8788a531f443b9ebf96c3682c60cba9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_736875f5ee2d027aab4abe9ce50659b2.setContent(html_8788a531f443b9ebf96c3682c60cba9b);
#
#
#
#         marker_
