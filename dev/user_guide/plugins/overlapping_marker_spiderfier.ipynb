# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7f01ee36a6f4e3b3dab8fe4f3b09c12d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7f01ee36a6f4e3b3dab8fe4f3b09c12d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7f01ee36a6f4e3b3dab8fe4f3b09c12d = L.map(
#                 &quot;map_7f01ee36a6f4e3b3dab8fe4f3b09c12d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f85d7b050d530f5eecd18e625553628 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8f85d7b050d530f5eecd18e625553628.addTo(map_7f01ee36a6f4e3b3dab8fe4f3b09c12d);
#
#
#             var marker_2b459f4f85584e76d373b00a33507e00 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7f01ee36a6f4e3b3dab8fe4f3b09c12d);
#
#
#         var popup_35cd384bdad75ac64e69bec3cb8e3238 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74fd42bac9751d83f8487f639f1f2214 = $(`&lt;div id=&quot;html_74fd42bac9751d83f8487f639f1f2214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_35cd384bdad75ac64e69bec3cb8e3238.setContent(html_74fd42bac9751d83f8487f639f1f2214);
#
#
#
#         marker_2b459f4f85584e76d373b00a33507e00.bindPopup(popup_35cd384bdad75ac64e69bec3cb8e3238)
#         ;
#
#
#
#
#             var marker_befc162e327225512662b2309ad9172c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7f01ee36a6f4e3b3dab8fe4f3b09c12d);
#
#
#         var popup_7daab737e563ec173a29a85c6eb1ecf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a60ae7d2ef649a663f6ce055b136a32 = $(`&lt;div id=&quot;html_1a60ae7d2ef649a663f6ce055b136a32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7daab737e563ec173a29a85c6eb1ecf0.setContent(html_1a60ae7d2ef649a663f6ce055b136a32);
#
#
#
#         marker_befc162e327225512662b2309ad9172c.bindPopup(popup_7daab737e563ec173a29a85c6eb1ecf0)
#         ;
#
#
#
#
#             var marker_d5d0c90fce7420e177af604f3544ff7e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7f01ee36a6f4e3b3dab8fe4f3b09c12d);
#
#
#         var popup_f2b3db59eb1f24ec4c523d348e526d02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d23cefe79e5128b37d5b275a2387372 = $(`&lt;div id=&quot;html_2d23cefe79e5128b37d5b275a2387372&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f2b3db59eb1f24ec4c523d348e526d02.setContent(html_2d23cefe79e5128b37d5b275a2387372);
#
#
#
#         marker_d5d0c90fce7420e177af604f3544ff7e.bindPopup(popup_f2b3db59eb1f24ec4c523d348e526d02)
#         ;
#
#
#
#
#             var marker_5f7b5f369b08af2409dd3bd8e028b5d5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7f01ee36a6f4e3b3dab8fe4f3b09c12d);
#
#
#         var popup_a370fb8d77f4831a5a9c10abe65ab4bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4c466e22431f9541651b8485fdcb1cd = $(`&lt;div id=&quot;html_f4c466e22431f9541651b8485fdcb1cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a370fb8d77f4831a5a9c10abe65ab4bd.setContent(html_f4c466e22431f9541651b8485fdcb1cd);
#
#
#
#         marker_5f7b5f369b08af2409dd3bd8e028b5d5.bindPopup(popup_a370fb8d77f4831a5a9c10abe65ab4bd)
#         ;
#
#
#
#
#             var marker_29d4f121a10c80d23f8647cda937e8a7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7f01ee36a6f4e3b3dab8fe4f3b09c12d);
#
#
#         var popup_ba5e6b5a1dfcee239901ee7614f55c97 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa50d554b9bd086cd8b55cc0857943d7 = $(`&lt;div id=&quot;html_aa50d554b9bd086cd8b55cc0857943d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ba5e6b5a1dfcee239901ee7614f55c97.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa5e2f0e8129d2560f3bc1327fefe407 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa5e2f0e8129d2560f3bc1327fefe407&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa5e2f0e8129d2560f3bc1327fefe407 = L.map(
#                 &quot;map_aa5e2f0e8129d2560f3bc1327fefe407&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1ff95660bd8861aabff2633963c1ed84 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1ff95660bd8861aabff2633963c1ed84.addTo(map_aa5e2f0e8129d2560f3bc1327fefe407);
#
#
#             var feature_group_44827cc0ac9d71b76477e5dd3ebb3b2b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_14189a2a6d6764397079f2027914cc55 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_44827cc0ac9d71b76477e5dd3ebb3b2b);
#
#
#         var popup_0f1d113aff975c586765d811e9716945 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e380d6182fd853d10ac6e5a37cf73b2 = $(`&lt;div id=&quot;html_3e380d6182fd853d10ac6e5a37cf73b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0f1d113aff975c586765d811e9716945.setContent(html_3e380d6182fd853d10ac6e5a37cf73b2);
#
#
#
#         marker_14189a2a6d6764397079f2027914cc55.bindPopup(popup_0f1d113aff975c586765d811e9716945)
#         ;
#
#
#
#
#             var marker_3b7d767b09a40237e4f3f604fae6b672 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_44827cc0ac9d71b76477e5dd3ebb3b2b);
#
#
#         var popup_b6d394df62be7c8a06f526119ac98f83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b5405efacd2d573db1a1216ee555d01 = $(`&lt;div id=&quot;html_2b5405efacd2d573db1a1216ee555d01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b6d394df62be7c8a06f526119ac98f83.setContent(html_2b5405efacd2d573db1a1216ee555d01);
#
#
#
#         marker_3b7d767b09a40237e4f3f604fae6b672.bindPopup(popup_b6d394df62be7c8a06f526119ac98f83)
#         ;
#
#
#
#
#             var marker_862799582d123067e1b310e8957164cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_44827cc0ac9d71b76477e5dd3ebb3b2b);
#
#
#         var popup_ee9153b90079ece811e18004d74758cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_626dd0b24369639d8f5db84367966272 = $(`&lt;div id=&quot;html_626dd0b24369639d8f5db84367966272&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ee9153b90079ece811e18004d74758cc.setContent(html_626dd0b24369639d8f5db84367966272);
#
#
#
#         marker_862799582d123067e1b310e8957164cd.bindPopup(popup_ee9153b90079ece811e18004d74758cc)
#         ;
#
#
#
#
#             var marker_a8bce9fdc7575e1d963ff0ad0b0d6bae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_44827cc0ac9d71b76477e5dd3ebb3b2b);
#
#
#         var popup_680017549e847ee13769e2c8a3d756af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e81e19a1fca03f152a0c2f8cb4b7f73e = $(`&lt;div id=&quot;html_e81e19a1fca03f152a0c2f8cb4b7f73e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_680017549e847ee13769e2c8a3d756af.setContent(html_e81e19a1fca03f152a0c2f8cb4b7f73e);
#
#
#
#         marker_a8bce9fdc7575e1d963ff0ad0b0d6bae.bindPopup(popup_680017549e847ee13769e2c8a3d756af)
#         ;
#
#
#
#
#             var marker_132ec21cf505e08454a636a4aa0cda49 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_44827cc0ac9d71b76477e5dd3ebb3b2b);
#
#
#         var popup_9a06bb60b2a933711de54536d66238a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8659e4694725dc70b2efad78869b61e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8659e4694725dc70b2efad78869b61e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8659e4694725dc70b2efad78869b61e = L.map(
#                 &quot;map_c8659e4694725dc70b2efad78869b61e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_969de6a99f45cc9915a4980afc9743c6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_969de6a99f45cc9915a4980afc9743c6.addTo(map_c8659e4694725dc70b2efad78869b61e);
#
#
#             var feature_group_d061c18affac7ec638269c4a08f9de5c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d061c18affac7ec638269c4a08f9de5c.addTo(map_c8659e4694725dc70b2efad78869b61e);
#
#
#             var feature_group_sub_group_7f8076376a63dfafbbd845a8720a3edd = L.featureGroup.subGroup(
#                 feature_group_d061c18affac7ec638269c4a08f9de5c
#             );
#
#
#             var marker_a95bbbfe767422350e100201836e4d8f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f8076376a63dfafbbd845a8720a3edd);
#
#
#         var popup_ec057719cde17fb6b07e7841051b5995 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a5abfb71bd25b9f3998bb82b177c6a5 = $(`&lt;div id=&quot;html_6a5abfb71bd25b9f3998bb82b177c6a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ec057719cde17fb6b07e7841051b5995.setContent(html_6a5abfb71bd25b9f3998bb82b177c6a5);
#
#
#
#         marker_a95bbbfe767422350e100201836e4d8f.bindPopup(popup_ec057719cde17fb6b07e7841051b5995)
#         ;
#
#
#
#
#             var marker_963b1214542ee65eb224e8db5eb4d7b7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f8076376a63dfafbbd845a8720a3edd);
#
#
#         var popup_7f2da6153b438be3d677718ec3b77835 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea0cce9ddc08485adf9a85eae81fe647 = $(`&lt;div id=&quot;html_ea0cce9ddc08485adf9a85eae81fe647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7f2da6153b438be3d677718ec3b77835.setContent(html_ea0cce9ddc08485adf9a85eae81fe647);
#
#
#
#         marker_963b1214542ee65eb224e8db5eb4d7b7.bindPopup(popup_7f2da6153b438be3d677718ec3b77835)
#         ;
#
#
#
#
#             var marker_85d4a00437bea145558a76cfc6a86c20 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f8076376a63dfafbbd845a8720a3edd);
#
#
#         var popup_ed6a01a95d5d1cb26b91c30bb9fce8ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d55644bd7e13ef1129d0ca7dc4841de5 = $(`&lt;div id=&quot;html_d55644bd7e13ef1129d0ca7dc4841de5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ed6a01a95d5d1cb26b91c30bb9fce8ce.setContent(html_d55644bd7e13ef1129d0ca7dc4841de5);
#
#
#
#         marker_85d4a00437bea145558a76cfc6a86c20.bindPopup(popup_ed6a01a95d5d1cb26b91c30bb9fce8ce)
#         ;
#
#
#
#
#             var marker_e9993afbe20b7c17cdd264f028148ac1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7f8076376a63dfafbbd845a8720a3edd);
#
#
#         var popup_9824dca3a7b4b0f8f798d4659baff692 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_911f00a74883eccdc976aea53dc3bbb5 = $(`&lt;div id=&quot;html_911f00a74883eccdc976aea53dc3bbb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9824dca3a7b4b0f8f798d4659baff692.setContent(html_911f00a74883eccdc976aea53dc3bbb5);
#
#
#
#         marker_
