# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_448f91a0bc0bb11d639c7da532a8e06b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_448f91a0bc0bb11d639c7da532a8e06b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_448f91a0bc0bb11d639c7da532a8e06b = L.map(
#                 &quot;map_448f91a0bc0bb11d639c7da532a8e06b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb0ed08b872091819f7699d9e999642a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb0ed08b872091819f7699d9e999642a.addTo(map_448f91a0bc0bb11d639c7da532a8e06b);
#
#
#             var marker_9d34e35aa7cf7ec2cbb652838a533ab8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_448f91a0bc0bb11d639c7da532a8e06b);
#
#
#         var popup_433c513710311662900af998e39ec383 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_972b97b3ae5daed97e9f615eb6bd720f = $(`&lt;div id=&quot;html_972b97b3ae5daed97e9f615eb6bd720f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_433c513710311662900af998e39ec383.setContent(html_972b97b3ae5daed97e9f615eb6bd720f);
#
#
#
#         marker_9d34e35aa7cf7ec2cbb652838a533ab8.bindPopup(popup_433c513710311662900af998e39ec383)
#         ;
#
#
#
#
#             var marker_ca8e9007dd1a4c9672e6bf813206f295 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_448f91a0bc0bb11d639c7da532a8e06b);
#
#
#         var popup_c07128c4637bdd5fd95f8449b41648f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31aa75a524ee3c46080616280b5680df = $(`&lt;div id=&quot;html_31aa75a524ee3c46080616280b5680df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c07128c4637bdd5fd95f8449b41648f1.setContent(html_31aa75a524ee3c46080616280b5680df);
#
#
#
#         marker_ca8e9007dd1a4c9672e6bf813206f295.bindPopup(popup_c07128c4637bdd5fd95f8449b41648f1)
#         ;
#
#
#
#
#             var marker_e74dc88aec96e956264eff9a45388ed2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_448f91a0bc0bb11d639c7da532a8e06b);
#
#
#         var popup_1cc747844a083582f389047061833e75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7ec7dd4845d79e7e92adc4eb7d011d5 = $(`&lt;div id=&quot;html_f7ec7dd4845d79e7e92adc4eb7d011d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1cc747844a083582f389047061833e75.setContent(html_f7ec7dd4845d79e7e92adc4eb7d011d5);
#
#
#
#         marker_e74dc88aec96e956264eff9a45388ed2.bindPopup(popup_1cc747844a083582f389047061833e75)
#         ;
#
#
#
#
#             var marker_2bd9f96c11423b63215b21875da0805f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_448f91a0bc0bb11d639c7da532a8e06b);
#
#
#         var popup_fa25966a91c467cec3f3f8387b53e13f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0adc1c591a9124d0dca58b12d4e87be = $(`&lt;div id=&quot;html_d0adc1c591a9124d0dca58b12d4e87be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fa25966a91c467cec3f3f8387b53e13f.setContent(html_d0adc1c591a9124d0dca58b12d4e87be);
#
#
#
#         marker_2bd9f96c11423b63215b21875da0805f.bindPopup(popup_fa25966a91c467cec3f3f8387b53e13f)
#         ;
#
#
#
#
#             var marker_9f86bedd60d4ae6d9d37857c4372ff84 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_448f91a0bc0bb11d639c7da532a8e06b);
#
#
#         var popup_dff99a70b0ac7c933d9b6623435c51f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f24f0569d7c7b2048f5d529961be38f = $(`&lt;div id=&quot;html_3f24f0569d7c7b2048f5d529961be38f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dff99a70b0ac7c933d9b6623435c51f9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f6e8c9f15cdaed55c2a3deaa1bf984aa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f6e8c9f15cdaed55c2a3deaa1bf984aa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f6e8c9f15cdaed55c2a3deaa1bf984aa = L.map(
#                 &quot;map_f6e8c9f15cdaed55c2a3deaa1bf984aa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ff4ef050912483c95c459a0b331830f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ff4ef050912483c95c459a0b331830f.addTo(map_f6e8c9f15cdaed55c2a3deaa1bf984aa);
#
#
#             var feature_group_53e78c41a38e9a2218c156d48bff41f9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6c14cc566880b363a37975ce21b0380d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_53e78c41a38e9a2218c156d48bff41f9);
#
#
#         var popup_9d0d4f296bd12f06118f787110b9f54e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba845e42b5a7e67605c60ae8550a1268 = $(`&lt;div id=&quot;html_ba845e42b5a7e67605c60ae8550a1268&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9d0d4f296bd12f06118f787110b9f54e.setContent(html_ba845e42b5a7e67605c60ae8550a1268);
#
#
#
#         marker_6c14cc566880b363a37975ce21b0380d.bindPopup(popup_9d0d4f296bd12f06118f787110b9f54e)
#         ;
#
#
#
#
#             var marker_c796c552a2020775e29e3583b6b93dd4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_53e78c41a38e9a2218c156d48bff41f9);
#
#
#         var popup_08fa4b1da1041d0bff08576e8246f07e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_265e8c760a224d4d2d95068979222023 = $(`&lt;div id=&quot;html_265e8c760a224d4d2d95068979222023&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_08fa4b1da1041d0bff08576e8246f07e.setContent(html_265e8c760a224d4d2d95068979222023);
#
#
#
#         marker_c796c552a2020775e29e3583b6b93dd4.bindPopup(popup_08fa4b1da1041d0bff08576e8246f07e)
#         ;
#
#
#
#
#             var marker_03cf4d443fd509a9aeecb84f1d35cd75 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_53e78c41a38e9a2218c156d48bff41f9);
#
#
#         var popup_32d5a5b0bb98d8c40ad83d63a74f704d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_130873ce41b690ced9247d04b1a50008 = $(`&lt;div id=&quot;html_130873ce41b690ced9247d04b1a50008&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_32d5a5b0bb98d8c40ad83d63a74f704d.setContent(html_130873ce41b690ced9247d04b1a50008);
#
#
#
#         marker_03cf4d443fd509a9aeecb84f1d35cd75.bindPopup(popup_32d5a5b0bb98d8c40ad83d63a74f704d)
#         ;
#
#
#
#
#             var marker_2f6ce947a65c4fb79f891b1ac0385609 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_53e78c41a38e9a2218c156d48bff41f9);
#
#
#         var popup_2230ad93e41a9290511dfd3c9f95238b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1831baab4bc4aff61781e255db3e30fb = $(`&lt;div id=&quot;html_1831baab4bc4aff61781e255db3e30fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2230ad93e41a9290511dfd3c9f95238b.setContent(html_1831baab4bc4aff61781e255db3e30fb);
#
#
#
#         marker_2f6ce947a65c4fb79f891b1ac0385609.bindPopup(popup_2230ad93e41a9290511dfd3c9f95238b)
#         ;
#
#
#
#
#             var marker_a5c2441b99fa704baa80e40e76b85ac0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_53e78c41a38e9a2218c156d48bff41f9);
#
#
#         var popup_970e3e9eee7446fce9aa5eebe07d8c9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a59142cd6b3e4b5e21ebdbb68979f714 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a59142cd6b3e4b5e21ebdbb68979f714&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a59142cd6b3e4b5e21ebdbb68979f714 = L.map(
#                 &quot;map_a59142cd6b3e4b5e21ebdbb68979f714&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_738b8ddb9afc5711ef17023130f661f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_738b8ddb9afc5711ef17023130f661f7.addTo(map_a59142cd6b3e4b5e21ebdbb68979f714);
#
#
#             var feature_group_f6ad13342fee0f87e9d298d6ec0469a7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f6ad13342fee0f87e9d298d6ec0469a7.addTo(map_a59142cd6b3e4b5e21ebdbb68979f714);
#
#
#             var feature_group_sub_group_281e31396f53494745256b2c735d0f87 = L.featureGroup.subGroup(
#                 feature_group_f6ad13342fee0f87e9d298d6ec0469a7
#             );
#
#
#             var marker_4dfe847e0b8b88160871176b28d9aae9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_281e31396f53494745256b2c735d0f87);
#
#
#         var popup_01bcc61f98b33b1b60b6d4dc19de3e29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_172f27a2e5eb3a578eb920a8f646d9e5 = $(`&lt;div id=&quot;html_172f27a2e5eb3a578eb920a8f646d9e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_01bcc61f98b33b1b60b6d4dc19de3e29.setContent(html_172f27a2e5eb3a578eb920a8f646d9e5);
#
#
#
#         marker_4dfe847e0b8b88160871176b28d9aae9.bindPopup(popup_01bcc61f98b33b1b60b6d4dc19de3e29)
#         ;
#
#
#
#
#             var marker_b1737e9f3b32c33890cb3689d3662587 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_281e31396f53494745256b2c735d0f87);
#
#
#         var popup_44d301fa57ba138e84e0f15a4d4a5ae6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f92c298d8aeedf7cec45cd12bda13dd = $(`&lt;div id=&quot;html_8f92c298d8aeedf7cec45cd12bda13dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_44d301fa57ba138e84e0f15a4d4a5ae6.setContent(html_8f92c298d8aeedf7cec45cd12bda13dd);
#
#
#
#         marker_b1737e9f3b32c33890cb3689d3662587.bindPopup(popup_44d301fa57ba138e84e0f15a4d4a5ae6)
#         ;
#
#
#
#
#             var marker_548acbe4dd882e3b85f4719af137aefd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_281e31396f53494745256b2c735d0f87);
#
#
#         var popup_1a557ebd12bea9596d08560bd4d7aaad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c262e1fcdd6ae67b65e7acb6052e954e = $(`&lt;div id=&quot;html_c262e1fcdd6ae67b65e7acb6052e954e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1a557ebd12bea9596d08560bd4d7aaad.setContent(html_c262e1fcdd6ae67b65e7acb6052e954e);
#
#
#
#         marker_548acbe4dd882e3b85f4719af137aefd.bindPopup(popup_1a557ebd12bea9596d08560bd4d7aaad)
#         ;
#
#
#
#
#             var marker_bb14433dcbeb7bd44736f6eb1ff65102 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_281e31396f53494745256b2c735d0f87);
#
#
#         var popup_381ecde719b3080226efcf6dba2e6a02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84113391f9577f09c9ff6cc150e94efc = $(`&lt;div id=&quot;html_84113391f9577f09c9ff6cc150e94efc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_381ecde719b3080226efcf6dba2e6a02.setContent(html_84113391f9577f09c9ff6cc150e94efc);
#
#
#
#         marker_
