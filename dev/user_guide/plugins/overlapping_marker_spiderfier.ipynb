# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1a739e757034a77e7a5ca2409ed39805 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1a739e757034a77e7a5ca2409ed39805&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1a739e757034a77e7a5ca2409ed39805 = L.map(
#                 &quot;map_1a739e757034a77e7a5ca2409ed39805&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6581775e02624ca408156e987710320d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6581775e02624ca408156e987710320d.addTo(map_1a739e757034a77e7a5ca2409ed39805);
#
#
#             var marker_c9e3acf6a875dfd5a80ba7f4d15ab7af = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1a739e757034a77e7a5ca2409ed39805);
#
#
#         var popup_3aee52f0c5254d5402bab861c2a951c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb3e9984e6721ee6f43ce7f287d949c9 = $(`&lt;div id=&quot;html_fb3e9984e6721ee6f43ce7f287d949c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3aee52f0c5254d5402bab861c2a951c9.setContent(html_fb3e9984e6721ee6f43ce7f287d949c9);
#
#
#
#         marker_c9e3acf6a875dfd5a80ba7f4d15ab7af.bindPopup(popup_3aee52f0c5254d5402bab861c2a951c9)
#         ;
#
#
#
#
#             var marker_2c60a12927eacfd8bac98a894829d7a5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1a739e757034a77e7a5ca2409ed39805);
#
#
#         var popup_9fe43ef78d3baf2c75992d026bba0987 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_756cea09b52991b1ca0063b92fb65aee = $(`&lt;div id=&quot;html_756cea09b52991b1ca0063b92fb65aee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9fe43ef78d3baf2c75992d026bba0987.setContent(html_756cea09b52991b1ca0063b92fb65aee);
#
#
#
#         marker_2c60a12927eacfd8bac98a894829d7a5.bindPopup(popup_9fe43ef78d3baf2c75992d026bba0987)
#         ;
#
#
#
#
#             var marker_52c98fb9fee1c482ebbd778796e22c23 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1a739e757034a77e7a5ca2409ed39805);
#
#
#         var popup_1d061e41eca57d33336c7b1bb89d2bcf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71c6a217b62b68a57ccf0d056078917b = $(`&lt;div id=&quot;html_71c6a217b62b68a57ccf0d056078917b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1d061e41eca57d33336c7b1bb89d2bcf.setContent(html_71c6a217b62b68a57ccf0d056078917b);
#
#
#
#         marker_52c98fb9fee1c482ebbd778796e22c23.bindPopup(popup_1d061e41eca57d33336c7b1bb89d2bcf)
#         ;
#
#
#
#
#             var marker_60b8aeacb4dbdf1e756835f1f47daeae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1a739e757034a77e7a5ca2409ed39805);
#
#
#         var popup_865fcac290b3808feb092b2dcfe2be70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2947d1ef230a6861ef5743dad9de1953 = $(`&lt;div id=&quot;html_2947d1ef230a6861ef5743dad9de1953&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_865fcac290b3808feb092b2dcfe2be70.setContent(html_2947d1ef230a6861ef5743dad9de1953);
#
#
#
#         marker_60b8aeacb4dbdf1e756835f1f47daeae.bindPopup(popup_865fcac290b3808feb092b2dcfe2be70)
#         ;
#
#
#
#
#             var marker_a9f5f28cc49607e998900ad8eb3d040a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1a739e757034a77e7a5ca2409ed39805);
#
#
#         var popup_5e9a56ca3b708af86fedeb451e317a2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_640ff40ee1133a6114b469708a90c89b = $(`&lt;div id=&quot;html_640ff40ee1133a6114b469708a90c89b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5e9a56ca3b708af86fedeb451e317a2e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e41d0719b6863403a77be2acf2ec77a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e41d0719b6863403a77be2acf2ec77a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e41d0719b6863403a77be2acf2ec77a = L.map(
#                 &quot;map_7e41d0719b6863403a77be2acf2ec77a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8dd60dd6083bf5a8f6d972cddcd08e28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8dd60dd6083bf5a8f6d972cddcd08e28.addTo(map_7e41d0719b6863403a77be2acf2ec77a);
#
#
#             var feature_group_1f9311621f0923b65b35fc0b8e74976f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0d3a101bd6df4c7a0e49eb2651e9d9d3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1f9311621f0923b65b35fc0b8e74976f);
#
#
#         var popup_efb6f37c7f6d51cab5773a35bb792a49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a42aaa35fa18735d53bfd1fc6b0a8ea4 = $(`&lt;div id=&quot;html_a42aaa35fa18735d53bfd1fc6b0a8ea4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_efb6f37c7f6d51cab5773a35bb792a49.setContent(html_a42aaa35fa18735d53bfd1fc6b0a8ea4);
#
#
#
#         marker_0d3a101bd6df4c7a0e49eb2651e9d9d3.bindPopup(popup_efb6f37c7f6d51cab5773a35bb792a49)
#         ;
#
#
#
#
#             var marker_8eccf23ab0bc0bdf37440d595ec13da4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1f9311621f0923b65b35fc0b8e74976f);
#
#
#         var popup_4ce140306dcb66ddabab7f1a0e0635a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ae05b16864e3b6cd59c64268ecb6a39b = $(`&lt;div id=&quot;html_ae05b16864e3b6cd59c64268ecb6a39b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4ce140306dcb66ddabab7f1a0e0635a3.setContent(html_ae05b16864e3b6cd59c64268ecb6a39b);
#
#
#
#         marker_8eccf23ab0bc0bdf37440d595ec13da4.bindPopup(popup_4ce140306dcb66ddabab7f1a0e0635a3)
#         ;
#
#
#
#
#             var marker_77df4226e7eea24e2be76986e4d2a4e6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1f9311621f0923b65b35fc0b8e74976f);
#
#
#         var popup_5ad06e6fae5b973b0409d4164b207a01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9daedaa5a74419e85b8a12e837a2bb8d = $(`&lt;div id=&quot;html_9daedaa5a74419e85b8a12e837a2bb8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5ad06e6fae5b973b0409d4164b207a01.setContent(html_9daedaa5a74419e85b8a12e837a2bb8d);
#
#
#
#         marker_77df4226e7eea24e2be76986e4d2a4e6.bindPopup(popup_5ad06e6fae5b973b0409d4164b207a01)
#         ;
#
#
#
#
#             var marker_8d9e6718d39db2fa7b5a6e0f00a094b3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1f9311621f0923b65b35fc0b8e74976f);
#
#
#         var popup_189bd5180443cbc5614f361d1fb889a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b78adf0e34c33a4c686800021004b7e9 = $(`&lt;div id=&quot;html_b78adf0e34c33a4c686800021004b7e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_189bd5180443cbc5614f361d1fb889a0.setContent(html_b78adf0e34c33a4c686800021004b7e9);
#
#
#
#         marker_8d9e6718d39db2fa7b5a6e0f00a094b3.bindPopup(popup_189bd5180443cbc5614f361d1fb889a0)
#         ;
#
#
#
#
#             var marker_a518a6709dcffbd36b26a229c8a63909 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1f9311621f0923b65b35fc0b8e74976f);
#
#
#         var popup_c2abb8b1062f1e58cc0f4808d10e8f11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfcfd40bde31176cf6137d56a0de14a8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfcfd40bde31176cf6137d56a0de14a8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfcfd40bde31176cf6137d56a0de14a8 = L.map(
#                 &quot;map_cfcfd40bde31176cf6137d56a0de14a8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f5a44baf528b41d1c08b2a897fbf975f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f5a44baf528b41d1c08b2a897fbf975f.addTo(map_cfcfd40bde31176cf6137d56a0de14a8);
#
#
#             var feature_group_14e27198f1bd719469a1691e4f9f5810 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_14e27198f1bd719469a1691e4f9f5810.addTo(map_cfcfd40bde31176cf6137d56a0de14a8);
#
#
#             var feature_group_sub_group_771f27159af85c8c75a8df39717dc705 = L.featureGroup.subGroup(
#                 feature_group_14e27198f1bd719469a1691e4f9f5810
#             );
#
#
#             var marker_b289c287d1602f90cce09b4e4b338583 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_771f27159af85c8c75a8df39717dc705);
#
#
#         var popup_255aed52fd65ec2ee6a1e0a883b32cf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d29af9ac094ac0ce2fe6179f67176ac = $(`&lt;div id=&quot;html_8d29af9ac094ac0ce2fe6179f67176ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_255aed52fd65ec2ee6a1e0a883b32cf6.setContent(html_8d29af9ac094ac0ce2fe6179f67176ac);
#
#
#
#         marker_b289c287d1602f90cce09b4e4b338583.bindPopup(popup_255aed52fd65ec2ee6a1e0a883b32cf6)
#         ;
#
#
#
#
#             var marker_4e1f9c8c4ee29d78b62dd0ce80378283 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_771f27159af85c8c75a8df39717dc705);
#
#
#         var popup_497ea61f1657033c7634f25314e098a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2546465a4891cb7d9c4dbe76f7178fd7 = $(`&lt;div id=&quot;html_2546465a4891cb7d9c4dbe76f7178fd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_497ea61f1657033c7634f25314e098a6.setContent(html_2546465a4891cb7d9c4dbe76f7178fd7);
#
#
#
#         marker_4e1f9c8c4ee29d78b62dd0ce80378283.bindPopup(popup_497ea61f1657033c7634f25314e098a6)
#         ;
#
#
#
#
#             var marker_31a700e7ba0a50245a4f8a9de2ee4b8b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_771f27159af85c8c75a8df39717dc705);
#
#
#         var popup_a8e3a57f2b6b09991b5a3041e53d85e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a27cb9675ebbc0315a91c62b703c1b12 = $(`&lt;div id=&quot;html_a27cb9675ebbc0315a91c62b703c1b12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a8e3a57f2b6b09991b5a3041e53d85e3.setContent(html_a27cb9675ebbc0315a91c62b703c1b12);
#
#
#
#         marker_31a700e7ba0a50245a4f8a9de2ee4b8b.bindPopup(popup_a8e3a57f2b6b09991b5a3041e53d85e3)
#         ;
#
#
#
#
#             var marker_98d0872762ec36d43b393cc2304724ce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_771f27159af85c8c75a8df39717dc705);
#
#
#         var popup_5e70e74e58885fda02a7036efcd10e3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6567c1ec09ddc5bbf25ce3b94169e586 = $(`&lt;div id=&quot;html_6567c1ec09ddc5bbf25ce3b94169e586&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5e70e74e58885fda02a7036efcd10e3e.setContent(html_6567c1ec09ddc5bbf25ce3b94169e586);
#
#
#
#         marker_
