# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_669a36b91f28624de9dace3438ed0d8e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_669a36b91f28624de9dace3438ed0d8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_669a36b91f28624de9dace3438ed0d8e = L.map(
#                 &quot;map_669a36b91f28624de9dace3438ed0d8e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dee7ca2bbb4061e85553dc61c2dd4440 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dee7ca2bbb4061e85553dc61c2dd4440.addTo(map_669a36b91f28624de9dace3438ed0d8e);
#
#
#             var marker_bc6c9999231e2e122bef461214acc524 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_669a36b91f28624de9dace3438ed0d8e);
#
#
#         var popup_4977f17318ddea34ffbbe45acdf3486e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dba272c0f71f2ad9ee34faa8881d0f2 = $(`&lt;div id=&quot;html_3dba272c0f71f2ad9ee34faa8881d0f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4977f17318ddea34ffbbe45acdf3486e.setContent(html_3dba272c0f71f2ad9ee34faa8881d0f2);
#
#
#
#         marker_bc6c9999231e2e122bef461214acc524.bindPopup(popup_4977f17318ddea34ffbbe45acdf3486e)
#         ;
#
#
#
#
#             var marker_60d27383fd5f303742bbac7054af55c6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_669a36b91f28624de9dace3438ed0d8e);
#
#
#         var popup_556dbb5606af3ca2b60b634db60a3168 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd3adc72a60201b3089ebbd03a44ea83 = $(`&lt;div id=&quot;html_bd3adc72a60201b3089ebbd03a44ea83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_556dbb5606af3ca2b60b634db60a3168.setContent(html_bd3adc72a60201b3089ebbd03a44ea83);
#
#
#
#         marker_60d27383fd5f303742bbac7054af55c6.bindPopup(popup_556dbb5606af3ca2b60b634db60a3168)
#         ;
#
#
#
#
#             var marker_4669f57eec89d00934ef8045e21255ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_669a36b91f28624de9dace3438ed0d8e);
#
#
#         var popup_fc81613471c0e15e1dd9e80bc198397b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d8930ba00588fed10193e515f4f530f = $(`&lt;div id=&quot;html_5d8930ba00588fed10193e515f4f530f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fc81613471c0e15e1dd9e80bc198397b.setContent(html_5d8930ba00588fed10193e515f4f530f);
#
#
#
#         marker_4669f57eec89d00934ef8045e21255ed.bindPopup(popup_fc81613471c0e15e1dd9e80bc198397b)
#         ;
#
#
#
#
#             var marker_3d299d3bb639f68f0572390cea62822d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_669a36b91f28624de9dace3438ed0d8e);
#
#
#         var popup_c973bb780a39f1a27caf2a074c4593a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7a9efb6ca27bfd94563a35d85942a03 = $(`&lt;div id=&quot;html_d7a9efb6ca27bfd94563a35d85942a03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c973bb780a39f1a27caf2a074c4593a5.setContent(html_d7a9efb6ca27bfd94563a35d85942a03);
#
#
#
#         marker_3d299d3bb639f68f0572390cea62822d.bindPopup(popup_c973bb780a39f1a27caf2a074c4593a5)
#         ;
#
#
#
#
#             var marker_b02fd2d57425b38f1760f4592355e85e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_669a36b91f28624de9dace3438ed0d8e);
#
#
#         var popup_02064a4343df67c402236ad635a0e800 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e86548c491c5f31bd3399fa246bc3b0e = $(`&lt;div id=&quot;html_e86548c491c5f31bd3399fa246bc3b0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_02064a4343df67c402236ad635a0e800.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0fa71234d6ed8ddcd0b1c32b60fdc52c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0fa71234d6ed8ddcd0b1c32b60fdc52c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0fa71234d6ed8ddcd0b1c32b60fdc52c = L.map(
#                 &quot;map_0fa71234d6ed8ddcd0b1c32b60fdc52c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3eebad657f58073152fbb6d2f7193417 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3eebad657f58073152fbb6d2f7193417.addTo(map_0fa71234d6ed8ddcd0b1c32b60fdc52c);
#
#
#             var feature_group_6011e04baf041ecdaf0ea9b938948399 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1515ea8609f1d0257a3bcd5f16d2e8f5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6011e04baf041ecdaf0ea9b938948399);
#
#
#         var popup_7a0f01ebd4e354b9d3083225472b1be4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_873eab2c74b981c2381347414a1a5f9a = $(`&lt;div id=&quot;html_873eab2c74b981c2381347414a1a5f9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7a0f01ebd4e354b9d3083225472b1be4.setContent(html_873eab2c74b981c2381347414a1a5f9a);
#
#
#
#         marker_1515ea8609f1d0257a3bcd5f16d2e8f5.bindPopup(popup_7a0f01ebd4e354b9d3083225472b1be4)
#         ;
#
#
#
#
#             var marker_40785e48bbd0e8a9d0a5c8e964075bfc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6011e04baf041ecdaf0ea9b938948399);
#
#
#         var popup_b4f87529834e4bba480e488fa6051807 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a256ede449fdc220472c71a9a827dc35 = $(`&lt;div id=&quot;html_a256ede449fdc220472c71a9a827dc35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b4f87529834e4bba480e488fa6051807.setContent(html_a256ede449fdc220472c71a9a827dc35);
#
#
#
#         marker_40785e48bbd0e8a9d0a5c8e964075bfc.bindPopup(popup_b4f87529834e4bba480e488fa6051807)
#         ;
#
#
#
#
#             var marker_17e10f203bbacdb1b89f7cee56872900 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6011e04baf041ecdaf0ea9b938948399);
#
#
#         var popup_d85caf00fcb1a93842f40cd9838f891f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64a8d4346d4d14b65a262b5371ddbaa9 = $(`&lt;div id=&quot;html_64a8d4346d4d14b65a262b5371ddbaa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d85caf00fcb1a93842f40cd9838f891f.setContent(html_64a8d4346d4d14b65a262b5371ddbaa9);
#
#
#
#         marker_17e10f203bbacdb1b89f7cee56872900.bindPopup(popup_d85caf00fcb1a93842f40cd9838f891f)
#         ;
#
#
#
#
#             var marker_37f614449972344a9ec007f0ab5318bf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6011e04baf041ecdaf0ea9b938948399);
#
#
#         var popup_6b18fb7834c8cdee72b4c43cbcb585bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea8609d23e5b8e7756948d75134a6797 = $(`&lt;div id=&quot;html_ea8609d23e5b8e7756948d75134a6797&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6b18fb7834c8cdee72b4c43cbcb585bf.setContent(html_ea8609d23e5b8e7756948d75134a6797);
#
#
#
#         marker_37f614449972344a9ec007f0ab5318bf.bindPopup(popup_6b18fb7834c8cdee72b4c43cbcb585bf)
#         ;
#
#
#
#
#             var marker_5b85054bdf411fff477839d5cad02685 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6011e04baf041ecdaf0ea9b938948399);
#
#
#         var popup_c27bcce9ab55f5388e5189e720324aef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ab21905a558be7cb6e027f5ac75970e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ab21905a558be7cb6e027f5ac75970e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ab21905a558be7cb6e027f5ac75970e = L.map(
#                 &quot;map_3ab21905a558be7cb6e027f5ac75970e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6caaa8761a38f9aab7cc72227856bb0e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6caaa8761a38f9aab7cc72227856bb0e.addTo(map_3ab21905a558be7cb6e027f5ac75970e);
#
#
#             var feature_group_794fd7249f24603e7a3b2c1318b60bfd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_794fd7249f24603e7a3b2c1318b60bfd.addTo(map_3ab21905a558be7cb6e027f5ac75970e);
#
#
#             var feature_group_sub_group_36d206fdf832bcc9b3aa0200b1347989 = L.featureGroup.subGroup(
#                 feature_group_794fd7249f24603e7a3b2c1318b60bfd
#             );
#
#
#             var marker_915fbf28a4c67dadbeb6d662471e12dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_36d206fdf832bcc9b3aa0200b1347989);
#
#
#         var popup_1bb3d3df9cbf349317da7da46fc2e301 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bf72bdee667a25b3160f3a303d59010 = $(`&lt;div id=&quot;html_7bf72bdee667a25b3160f3a303d59010&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1bb3d3df9cbf349317da7da46fc2e301.setContent(html_7bf72bdee667a25b3160f3a303d59010);
#
#
#
#         marker_915fbf28a4c67dadbeb6d662471e12dc.bindPopup(popup_1bb3d3df9cbf349317da7da46fc2e301)
#         ;
#
#
#
#
#             var marker_1f05a0e00193d887c444eb023c1d2699 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_36d206fdf832bcc9b3aa0200b1347989);
#
#
#         var popup_a65029f0c09c780e6b48c756ba8b7e0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9c1fac7b55f1c5fd77af1ce08819790 = $(`&lt;div id=&quot;html_b9c1fac7b55f1c5fd77af1ce08819790&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a65029f0c09c780e6b48c756ba8b7e0d.setContent(html_b9c1fac7b55f1c5fd77af1ce08819790);
#
#
#
#         marker_1f05a0e00193d887c444eb023c1d2699.bindPopup(popup_a65029f0c09c780e6b48c756ba8b7e0d)
#         ;
#
#
#
#
#             var marker_d11317760d134377d46f35fd8089aeee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_36d206fdf832bcc9b3aa0200b1347989);
#
#
#         var popup_e6c8ce40b80cb8cfa54b35e5dccea165 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abfa89669e04df389ac3ced264ca948f = $(`&lt;div id=&quot;html_abfa89669e04df389ac3ced264ca948f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e6c8ce40b80cb8cfa54b35e5dccea165.setContent(html_abfa89669e04df389ac3ced264ca948f);
#
#
#
#         marker_d11317760d134377d46f35fd8089aeee.bindPopup(popup_e6c8ce40b80cb8cfa54b35e5dccea165)
#         ;
#
#
#
#
#             var marker_3815f42fd3c708587ddbe0f431e304a9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_36d206fdf832bcc9b3aa0200b1347989);
#
#
#         var popup_393cc6847acd4763da1bc8cd6a364f40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fc223cb0275d2f5012c487bc1743ced = $(`&lt;div id=&quot;html_5fc223cb0275d2f5012c487bc1743ced&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_393cc6847acd4763da1bc8cd6a364f40.setContent(html_5fc223cb0275d2f5012c487bc1743ced);
#
#
#
#         marker_
