# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e4b5c4a29f4f28756e7eeb30740bbf1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e4b5c4a29f4f28756e7eeb30740bbf1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e4b5c4a29f4f28756e7eeb30740bbf1 = L.map(
#                 &quot;map_4e4b5c4a29f4f28756e7eeb30740bbf1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_46415285e1d1e486f13abe23363cf04c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_46415285e1d1e486f13abe23363cf04c.addTo(map_4e4b5c4a29f4f28756e7eeb30740bbf1);
#
#
#             var marker_855c6cf4c7116dada1e6cebe5a5a5c9b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4e4b5c4a29f4f28756e7eeb30740bbf1);
#
#
#         var popup_b296b63f3d689fea65dcc39c62865a3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9703a8b4a5a1e0e6bbaea2bfbf4c2c65 = $(`&lt;div id=&quot;html_9703a8b4a5a1e0e6bbaea2bfbf4c2c65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b296b63f3d689fea65dcc39c62865a3a.setContent(html_9703a8b4a5a1e0e6bbaea2bfbf4c2c65);
#
#
#
#         marker_855c6cf4c7116dada1e6cebe5a5a5c9b.bindPopup(popup_b296b63f3d689fea65dcc39c62865a3a)
#         ;
#
#
#
#
#             var marker_6c8364d4514ed409ae27ac1105fe6e17 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4e4b5c4a29f4f28756e7eeb30740bbf1);
#
#
#         var popup_05e542e123e60994973c957917c10d44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47a369181e58d82ec21f4f69c4e6405d = $(`&lt;div id=&quot;html_47a369181e58d82ec21f4f69c4e6405d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_05e542e123e60994973c957917c10d44.setContent(html_47a369181e58d82ec21f4f69c4e6405d);
#
#
#
#         marker_6c8364d4514ed409ae27ac1105fe6e17.bindPopup(popup_05e542e123e60994973c957917c10d44)
#         ;
#
#
#
#
#             var marker_85efa32dcf5c3e25c3144f9700c043c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4e4b5c4a29f4f28756e7eeb30740bbf1);
#
#
#         var popup_16f1290fc7c59b45cae850a5537c14eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7392cf9c575ea539b6d357a700177438 = $(`&lt;div id=&quot;html_7392cf9c575ea539b6d357a700177438&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_16f1290fc7c59b45cae850a5537c14eb.setContent(html_7392cf9c575ea539b6d357a700177438);
#
#
#
#         marker_85efa32dcf5c3e25c3144f9700c043c5.bindPopup(popup_16f1290fc7c59b45cae850a5537c14eb)
#         ;
#
#
#
#
#             var marker_a202ac2bf8f53e4f2db7b23b7b0dbb0c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4e4b5c4a29f4f28756e7eeb30740bbf1);
#
#
#         var popup_e5447da64f5cd0944b0df155783fe761 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_630587fb9a46f8111da6395ec9643473 = $(`&lt;div id=&quot;html_630587fb9a46f8111da6395ec9643473&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e5447da64f5cd0944b0df155783fe761.setContent(html_630587fb9a46f8111da6395ec9643473);
#
#
#
#         marker_a202ac2bf8f53e4f2db7b23b7b0dbb0c.bindPopup(popup_e5447da64f5cd0944b0df155783fe761)
#         ;
#
#
#
#
#             var marker_db9b2cb8f72d73bda80cd74f025cf3ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4e4b5c4a29f4f28756e7eeb30740bbf1);
#
#
#         var popup_a5e54f999174877c6635da7a300a7339 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fb40f31dbe1d222f8f698a3c725d6e7 = $(`&lt;div id=&quot;html_4fb40f31dbe1d222f8f698a3c725d6e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a5e54f999174877c6635da7a300a7339.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_445c7c13bfe4991071114dedc9c1d9ce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_445c7c13bfe4991071114dedc9c1d9ce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_445c7c13bfe4991071114dedc9c1d9ce = L.map(
#                 &quot;map_445c7c13bfe4991071114dedc9c1d9ce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_59b485a008bf2b0007b1b9177cb907a3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_59b485a008bf2b0007b1b9177cb907a3.addTo(map_445c7c13bfe4991071114dedc9c1d9ce);
#
#
#             var feature_group_ac5c10ae25146be6bff2d091ac1dbbb9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4c23ba21bb09fdab84fa12aaf75fd36f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ac5c10ae25146be6bff2d091ac1dbbb9);
#
#
#         var popup_448e9d56d61d3ba451809a74411bcda5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2217e55ba6e738930f6f8afd75102575 = $(`&lt;div id=&quot;html_2217e55ba6e738930f6f8afd75102575&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_448e9d56d61d3ba451809a74411bcda5.setContent(html_2217e55ba6e738930f6f8afd75102575);
#
#
#
#         marker_4c23ba21bb09fdab84fa12aaf75fd36f.bindPopup(popup_448e9d56d61d3ba451809a74411bcda5)
#         ;
#
#
#
#
#             var marker_e1cf45c573ab9a8b5365cdd97fe9190d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ac5c10ae25146be6bff2d091ac1dbbb9);
#
#
#         var popup_f2bcae90f9b614bb70de577e13b35abe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b7dc695b5948c3930fb4d57360ceda1 = $(`&lt;div id=&quot;html_1b7dc695b5948c3930fb4d57360ceda1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f2bcae90f9b614bb70de577e13b35abe.setContent(html_1b7dc695b5948c3930fb4d57360ceda1);
#
#
#
#         marker_e1cf45c573ab9a8b5365cdd97fe9190d.bindPopup(popup_f2bcae90f9b614bb70de577e13b35abe)
#         ;
#
#
#
#
#             var marker_71c8d6ce61f2c90c04ba3646294c96fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ac5c10ae25146be6bff2d091ac1dbbb9);
#
#
#         var popup_2f31a646a7c843f05f1515fae613e042 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d59fa2d0ee0be8a03039c0abbed69999 = $(`&lt;div id=&quot;html_d59fa2d0ee0be8a03039c0abbed69999&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2f31a646a7c843f05f1515fae613e042.setContent(html_d59fa2d0ee0be8a03039c0abbed69999);
#
#
#
#         marker_71c8d6ce61f2c90c04ba3646294c96fa.bindPopup(popup_2f31a646a7c843f05f1515fae613e042)
#         ;
#
#
#
#
#             var marker_1d5f9abc3496d1c3074531776fd13ada = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ac5c10ae25146be6bff2d091ac1dbbb9);
#
#
#         var popup_32507ffc865909914f4f5dac8da26370 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5496ff526694638ef74a49b8a4ea6cd1 = $(`&lt;div id=&quot;html_5496ff526694638ef74a49b8a4ea6cd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_32507ffc865909914f4f5dac8da26370.setContent(html_5496ff526694638ef74a49b8a4ea6cd1);
#
#
#
#         marker_1d5f9abc3496d1c3074531776fd13ada.bindPopup(popup_32507ffc865909914f4f5dac8da26370)
#         ;
#
#
#
#
#             var marker_180cf682928e9fac256081d9cf24780d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ac5c10ae25146be6bff2d091ac1dbbb9);
#
#
#         var popup_b105b67a548d163ec32faf5008726fa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3021384cc91944037138fcda535f47a1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3021384cc91944037138fcda535f47a1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3021384cc91944037138fcda535f47a1 = L.map(
#                 &quot;map_3021384cc91944037138fcda535f47a1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7de699bacc9d8156ef1be6f211a152b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7de699bacc9d8156ef1be6f211a152b1.addTo(map_3021384cc91944037138fcda535f47a1);
#
#
#             var feature_group_b809007ca307296734dc540a4e36ddf8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b809007ca307296734dc540a4e36ddf8.addTo(map_3021384cc91944037138fcda535f47a1);
#
#
#             var feature_group_sub_group_950b84a44a200be53e7ae016b33db9f4 = L.featureGroup.subGroup(
#                 feature_group_b809007ca307296734dc540a4e36ddf8
#             );
#
#
#             var marker_8d212c4fe35d9b7bfebdaca6cf6fbe8b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_950b84a44a200be53e7ae016b33db9f4);
#
#
#         var popup_8ef5b8ad297f4cf1f493e3d65c5000f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5adde89e026c5d4bf5d7cd1d78406519 = $(`&lt;div id=&quot;html_5adde89e026c5d4bf5d7cd1d78406519&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8ef5b8ad297f4cf1f493e3d65c5000f0.setContent(html_5adde89e026c5d4bf5d7cd1d78406519);
#
#
#
#         marker_8d212c4fe35d9b7bfebdaca6cf6fbe8b.bindPopup(popup_8ef5b8ad297f4cf1f493e3d65c5000f0)
#         ;
#
#
#
#
#             var marker_8350bdd8877fc7603dd7a76217a7ee80 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_950b84a44a200be53e7ae016b33db9f4);
#
#
#         var popup_692d0f5b47c4c5a5147169ed5644d577 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d85a5114676aa94cf3e7845790ea061 = $(`&lt;div id=&quot;html_0d85a5114676aa94cf3e7845790ea061&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_692d0f5b47c4c5a5147169ed5644d577.setContent(html_0d85a5114676aa94cf3e7845790ea061);
#
#
#
#         marker_8350bdd8877fc7603dd7a76217a7ee80.bindPopup(popup_692d0f5b47c4c5a5147169ed5644d577)
#         ;
#
#
#
#
#             var marker_b86b28a5e7560456c0f046b6b7a3e7cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_950b84a44a200be53e7ae016b33db9f4);
#
#
#         var popup_1d864a70ddf0b6fee21b82391c2ea4dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80aaa40e8474e51e7936ffb5f625206b = $(`&lt;div id=&quot;html_80aaa40e8474e51e7936ffb5f625206b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1d864a70ddf0b6fee21b82391c2ea4dd.setContent(html_80aaa40e8474e51e7936ffb5f625206b);
#
#
#
#         marker_b86b28a5e7560456c0f046b6b7a3e7cf.bindPopup(popup_1d864a70ddf0b6fee21b82391c2ea4dd)
#         ;
#
#
#
#
#             var marker_70f7d4835144d47e767b9d73ba1fd7a1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_950b84a44a200be53e7ae016b33db9f4);
#
#
#         var popup_d42623833285add97cb55cc39cb93012 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9893f3eda44e79210fb4df7a920beb9 = $(`&lt;div id=&quot;html_c9893f3eda44e79210fb4df7a920beb9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d42623833285add97cb55cc39cb93012.setContent(html_c9893f3eda44e79210fb4df7a920beb9);
#
#
#
#         marker_
