# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29b2ea4baed8aee0e6568c25ed02daca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29b2ea4baed8aee0e6568c25ed02daca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29b2ea4baed8aee0e6568c25ed02daca = L.map(
#                 &quot;map_29b2ea4baed8aee0e6568c25ed02daca&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2662faf8e5f5bd7ef677102237b29e43 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2662faf8e5f5bd7ef677102237b29e43.addTo(map_29b2ea4baed8aee0e6568c25ed02daca);
#
#
#             var marker_cc51e4bac234bf17c6588ed827eaf317 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_29b2ea4baed8aee0e6568c25ed02daca);
#
#
#         var popup_968402fb6026d082d66ae4f12d3c855e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef81d84077c8190e0eefc56d0315be19 = $(`&lt;div id=&quot;html_ef81d84077c8190e0eefc56d0315be19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_968402fb6026d082d66ae4f12d3c855e.setContent(html_ef81d84077c8190e0eefc56d0315be19);
#
#
#
#         marker_cc51e4bac234bf17c6588ed827eaf317.bindPopup(popup_968402fb6026d082d66ae4f12d3c855e)
#         ;
#
#
#
#
#             var marker_6c04d2649167cf9f11b6c10a053c0c8e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_29b2ea4baed8aee0e6568c25ed02daca);
#
#
#         var popup_df0d47186db6f5163072f147908a51dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7360e8bf3731377c3cdd0092c4dac094 = $(`&lt;div id=&quot;html_7360e8bf3731377c3cdd0092c4dac094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_df0d47186db6f5163072f147908a51dd.setContent(html_7360e8bf3731377c3cdd0092c4dac094);
#
#
#
#         marker_6c04d2649167cf9f11b6c10a053c0c8e.bindPopup(popup_df0d47186db6f5163072f147908a51dd)
#         ;
#
#
#
#
#             var marker_45bb7507d1918c5f3381f240b3c90dc3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_29b2ea4baed8aee0e6568c25ed02daca);
#
#
#         var popup_ee045d9c390f5158487ee2a0f1cc8c5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b9d84435395305c04fccf6772bc88c6 = $(`&lt;div id=&quot;html_7b9d84435395305c04fccf6772bc88c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ee045d9c390f5158487ee2a0f1cc8c5e.setContent(html_7b9d84435395305c04fccf6772bc88c6);
#
#
#
#         marker_45bb7507d1918c5f3381f240b3c90dc3.bindPopup(popup_ee045d9c390f5158487ee2a0f1cc8c5e)
#         ;
#
#
#
#
#             var marker_82c69c54de0fa893a01f7f75f7d031d2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_29b2ea4baed8aee0e6568c25ed02daca);
#
#
#         var popup_1396ab897edd261ab47434537b6fa966 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04e35663a1938f1c3885359f85248262 = $(`&lt;div id=&quot;html_04e35663a1938f1c3885359f85248262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1396ab897edd261ab47434537b6fa966.setContent(html_04e35663a1938f1c3885359f85248262);
#
#
#
#         marker_82c69c54de0fa893a01f7f75f7d031d2.bindPopup(popup_1396ab897edd261ab47434537b6fa966)
#         ;
#
#
#
#
#             var marker_416f28bd42138e65d02cb7182540cd93 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_29b2ea4baed8aee0e6568c25ed02daca);
#
#
#         var popup_9344c984c026204e84e7f99aa47482fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2d133033f030c8a91f2b140d3f78bca = $(`&lt;div id=&quot;html_d2d133033f030c8a91f2b140d3f78bca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9344c984c026204e84e7f99aa47482fa.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_361535a57931349de7b9f94f30a07864 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_361535a57931349de7b9f94f30a07864&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_361535a57931349de7b9f94f30a07864 = L.map(
#                 &quot;map_361535a57931349de7b9f94f30a07864&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_25c9617b9511c4c3c058aefe4fffdca7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_25c9617b9511c4c3c058aefe4fffdca7.addTo(map_361535a57931349de7b9f94f30a07864);
#
#
#             var feature_group_d0a197f11958c6f8c309787f6d170beb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8f21f6a32af7460eb4359e564f186cc7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d0a197f11958c6f8c309787f6d170beb);
#
#
#         var popup_2db4b8b4eae9c3e3469c4ef2e6efb21d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e95aec9cf657734d9869f286215e188 = $(`&lt;div id=&quot;html_3e95aec9cf657734d9869f286215e188&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2db4b8b4eae9c3e3469c4ef2e6efb21d.setContent(html_3e95aec9cf657734d9869f286215e188);
#
#
#
#         marker_8f21f6a32af7460eb4359e564f186cc7.bindPopup(popup_2db4b8b4eae9c3e3469c4ef2e6efb21d)
#         ;
#
#
#
#
#             var marker_ece21895d5b76af6592d09dfa9141abd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d0a197f11958c6f8c309787f6d170beb);
#
#
#         var popup_3ec5e385f9b5aa58e39ba80ce6fe568a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36ecbe1cc9facef524fa47c35b7818ac = $(`&lt;div id=&quot;html_36ecbe1cc9facef524fa47c35b7818ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3ec5e385f9b5aa58e39ba80ce6fe568a.setContent(html_36ecbe1cc9facef524fa47c35b7818ac);
#
#
#
#         marker_ece21895d5b76af6592d09dfa9141abd.bindPopup(popup_3ec5e385f9b5aa58e39ba80ce6fe568a)
#         ;
#
#
#
#
#             var marker_e9ea10343cd8c049920c3faae1dddaa2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d0a197f11958c6f8c309787f6d170beb);
#
#
#         var popup_3630511fc18e28029b28050df809589d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8946d7a2dd8be424e593df2fa289f148 = $(`&lt;div id=&quot;html_8946d7a2dd8be424e593df2fa289f148&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3630511fc18e28029b28050df809589d.setContent(html_8946d7a2dd8be424e593df2fa289f148);
#
#
#
#         marker_e9ea10343cd8c049920c3faae1dddaa2.bindPopup(popup_3630511fc18e28029b28050df809589d)
#         ;
#
#
#
#
#             var marker_ecda70fd4c9ed864f0d8351c43951258 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d0a197f11958c6f8c309787f6d170beb);
#
#
#         var popup_76cf36f1cb3acce03abb5b1bb586df9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9e7e2b47aa1723451e7169cbfb17ea0 = $(`&lt;div id=&quot;html_e9e7e2b47aa1723451e7169cbfb17ea0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_76cf36f1cb3acce03abb5b1bb586df9e.setContent(html_e9e7e2b47aa1723451e7169cbfb17ea0);
#
#
#
#         marker_ecda70fd4c9ed864f0d8351c43951258.bindPopup(popup_76cf36f1cb3acce03abb5b1bb586df9e)
#         ;
#
#
#
#
#             var marker_b0f1a9498ab88b0b54d0665bae2bc5b3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d0a197f11958c6f8c309787f6d170beb);
#
#
#         var popup_53a5f8a3f42b1af0b1ffe7e3af8ae256 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f60da95497283fb2730ed86de0b9841 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f60da95497283fb2730ed86de0b9841&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f60da95497283fb2730ed86de0b9841 = L.map(
#                 &quot;map_5f60da95497283fb2730ed86de0b9841&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_de904d2b4c9edaca4aa6e3444e0302b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_de904d2b4c9edaca4aa6e3444e0302b0.addTo(map_5f60da95497283fb2730ed86de0b9841);
#
#
#             var feature_group_e8b8e37922fc4709bb26c25528c3b5bf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e8b8e37922fc4709bb26c25528c3b5bf.addTo(map_5f60da95497283fb2730ed86de0b9841);
#
#
#             var feature_group_sub_group_e8c414f6d039af0ab92c6cd1c92d77a5 = L.featureGroup.subGroup(
#                 feature_group_e8b8e37922fc4709bb26c25528c3b5bf
#             );
#
#
#             var marker_6f0c507061a3bb936b733a08edeb607a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c414f6d039af0ab92c6cd1c92d77a5);
#
#
#         var popup_caab981467b105ab77f199278919d82b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_389c10b998e2cc7a91893c4087e99c8b = $(`&lt;div id=&quot;html_389c10b998e2cc7a91893c4087e99c8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_caab981467b105ab77f199278919d82b.setContent(html_389c10b998e2cc7a91893c4087e99c8b);
#
#
#
#         marker_6f0c507061a3bb936b733a08edeb607a.bindPopup(popup_caab981467b105ab77f199278919d82b)
#         ;
#
#
#
#
#             var marker_5c9ba69e52321f85744bfdc2927bd9a4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c414f6d039af0ab92c6cd1c92d77a5);
#
#
#         var popup_168c0f71c51f75c25f3feb695420d74a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86bc1d27df42d6c58f9034380d686562 = $(`&lt;div id=&quot;html_86bc1d27df42d6c58f9034380d686562&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_168c0f71c51f75c25f3feb695420d74a.setContent(html_86bc1d27df42d6c58f9034380d686562);
#
#
#
#         marker_5c9ba69e52321f85744bfdc2927bd9a4.bindPopup(popup_168c0f71c51f75c25f3feb695420d74a)
#         ;
#
#
#
#
#             var marker_480df2e3373755cf2fe239db71fea886 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c414f6d039af0ab92c6cd1c92d77a5);
#
#
#         var popup_9e1202adfa25f4972481d435459d909d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_166d4e9f9c4a567627df4aa24836237c = $(`&lt;div id=&quot;html_166d4e9f9c4a567627df4aa24836237c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9e1202adfa25f4972481d435459d909d.setContent(html_166d4e9f9c4a567627df4aa24836237c);
#
#
#
#         marker_480df2e3373755cf2fe239db71fea886.bindPopup(popup_9e1202adfa25f4972481d435459d909d)
#         ;
#
#
#
#
#             var marker_674e80fa56db955b00a6ba8a70614d23 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8c414f6d039af0ab92c6cd1c92d77a5);
#
#
#         var popup_5fde1e827191cb4604b55e0bf6227cbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea099db31d7ae050fb3a37e40f4abdac = $(`&lt;div id=&quot;html_ea099db31d7ae050fb3a37e40f4abdac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5fde1e827191cb4604b55e0bf6227cbc.setContent(html_ea099db31d7ae050fb3a37e40f4abdac);
#
#
#
#         marker_
