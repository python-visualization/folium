# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce1485c0735bbd2405480889e5a683c5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce1485c0735bbd2405480889e5a683c5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce1485c0735bbd2405480889e5a683c5 = L.map(
#                 &quot;map_ce1485c0735bbd2405480889e5a683c5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_01b9a4e052060db0bc329ea203d0ac5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_01b9a4e052060db0bc329ea203d0ac5a.addTo(map_ce1485c0735bbd2405480889e5a683c5);
#
#
#             var marker_39e42b57ab28e89a5e00635c9f6bd520 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ce1485c0735bbd2405480889e5a683c5);
#
#
#         var popup_823b71aaf222c2121fd199e3d5819f17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3f0bc573ed75ee2a8fdbc20cf093d88 = $(`&lt;div id=&quot;html_c3f0bc573ed75ee2a8fdbc20cf093d88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_823b71aaf222c2121fd199e3d5819f17.setContent(html_c3f0bc573ed75ee2a8fdbc20cf093d88);
#
#
#
#         marker_39e42b57ab28e89a5e00635c9f6bd520.bindPopup(popup_823b71aaf222c2121fd199e3d5819f17)
#         ;
#
#
#
#
#             var marker_0104829acf368680e423914666dc8441 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ce1485c0735bbd2405480889e5a683c5);
#
#
#         var popup_fac1d4d63ffb80f0a4a3523061031acc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27390b84f558df71c652f4df6117c3b6 = $(`&lt;div id=&quot;html_27390b84f558df71c652f4df6117c3b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fac1d4d63ffb80f0a4a3523061031acc.setContent(html_27390b84f558df71c652f4df6117c3b6);
#
#
#
#         marker_0104829acf368680e423914666dc8441.bindPopup(popup_fac1d4d63ffb80f0a4a3523061031acc)
#         ;
#
#
#
#
#             var marker_6175ef8604e674238aa6fda3da16834b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ce1485c0735bbd2405480889e5a683c5);
#
#
#         var popup_08f6f6c113fc1a7b34cbaa008cdad497 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adcf2fdeb3ba6843e62ff1f9d646ec54 = $(`&lt;div id=&quot;html_adcf2fdeb3ba6843e62ff1f9d646ec54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_08f6f6c113fc1a7b34cbaa008cdad497.setContent(html_adcf2fdeb3ba6843e62ff1f9d646ec54);
#
#
#
#         marker_6175ef8604e674238aa6fda3da16834b.bindPopup(popup_08f6f6c113fc1a7b34cbaa008cdad497)
#         ;
#
#
#
#
#             var marker_07ee3bcf3ddc331abbc02556a5723036 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ce1485c0735bbd2405480889e5a683c5);
#
#
#         var popup_1a1c1a45fe2be214208369c156070844 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06e24a7371fc4f6a14f60f74a49a204a = $(`&lt;div id=&quot;html_06e24a7371fc4f6a14f60f74a49a204a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1a1c1a45fe2be214208369c156070844.setContent(html_06e24a7371fc4f6a14f60f74a49a204a);
#
#
#
#         marker_07ee3bcf3ddc331abbc02556a5723036.bindPopup(popup_1a1c1a45fe2be214208369c156070844)
#         ;
#
#
#
#
#             var marker_2b1324507e45ea187050b7e20b63c551 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ce1485c0735bbd2405480889e5a683c5);
#
#
#         var popup_250b48bc51bb1360e2037a3a60d6996c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d2b21a87e3202786f5a8076e7ca0252 = $(`&lt;div id=&quot;html_5d2b21a87e3202786f5a8076e7ca0252&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_250b48bc51bb1360e2037a3a60d6996c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03ee96ba307c7800fa3552df81ca4fe2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03ee96ba307c7800fa3552df81ca4fe2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03ee96ba307c7800fa3552df81ca4fe2 = L.map(
#                 &quot;map_03ee96ba307c7800fa3552df81ca4fe2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8a1f37596daeb62a5847e31ffe405f01 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a1f37596daeb62a5847e31ffe405f01.addTo(map_03ee96ba307c7800fa3552df81ca4fe2);
#
#
#             var feature_group_69ea6fac1b36605a9289695047d1ca92 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0ec67ff9e6a947fad094988bd833522f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_69ea6fac1b36605a9289695047d1ca92);
#
#
#         var popup_5162a565102cf62e9ed46512c3c7667d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa26b8d5dcf65d79a5edf013d4629a38 = $(`&lt;div id=&quot;html_fa26b8d5dcf65d79a5edf013d4629a38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5162a565102cf62e9ed46512c3c7667d.setContent(html_fa26b8d5dcf65d79a5edf013d4629a38);
#
#
#
#         marker_0ec67ff9e6a947fad094988bd833522f.bindPopup(popup_5162a565102cf62e9ed46512c3c7667d)
#         ;
#
#
#
#
#             var marker_48f874cd4927871434885bea19451635 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_69ea6fac1b36605a9289695047d1ca92);
#
#
#         var popup_d89d54ceb76f059e6a2f1df983da2816 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_742f0ca6ce8db9ef78365ce5b707d88a = $(`&lt;div id=&quot;html_742f0ca6ce8db9ef78365ce5b707d88a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d89d54ceb76f059e6a2f1df983da2816.setContent(html_742f0ca6ce8db9ef78365ce5b707d88a);
#
#
#
#         marker_48f874cd4927871434885bea19451635.bindPopup(popup_d89d54ceb76f059e6a2f1df983da2816)
#         ;
#
#
#
#
#             var marker_2343807d448f148ff4c3d66c452ede22 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_69ea6fac1b36605a9289695047d1ca92);
#
#
#         var popup_59fc3a3394bff7ff547dba33190658dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4266e80aef7317c4c53d78efa69dc428 = $(`&lt;div id=&quot;html_4266e80aef7317c4c53d78efa69dc428&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_59fc3a3394bff7ff547dba33190658dc.setContent(html_4266e80aef7317c4c53d78efa69dc428);
#
#
#
#         marker_2343807d448f148ff4c3d66c452ede22.bindPopup(popup_59fc3a3394bff7ff547dba33190658dc)
#         ;
#
#
#
#
#             var marker_546e106a49b2e9c3c25666d7220b88ce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_69ea6fac1b36605a9289695047d1ca92);
#
#
#         var popup_97979a08230ecce231e4eb4bbf49d36f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_582d2e07ae54bcaf463257e6a3a44886 = $(`&lt;div id=&quot;html_582d2e07ae54bcaf463257e6a3a44886&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_97979a08230ecce231e4eb4bbf49d36f.setContent(html_582d2e07ae54bcaf463257e6a3a44886);
#
#
#
#         marker_546e106a49b2e9c3c25666d7220b88ce.bindPopup(popup_97979a08230ecce231e4eb4bbf49d36f)
#         ;
#
#
#
#
#             var marker_bc2808e877ea67751df984100611f258 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_69ea6fac1b36605a9289695047d1ca92);
#
#
#         var popup_ad6f89f5746974d6959c228fb16c862a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8a4b2b6c4c835ccfb4694d201a01fb4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8a4b2b6c4c835ccfb4694d201a01fb4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8a4b2b6c4c835ccfb4694d201a01fb4b = L.map(
#                 &quot;map_8a4b2b6c4c835ccfb4694d201a01fb4b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03d18c4d2b03c40c3b99294105da0876 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03d18c4d2b03c40c3b99294105da0876.addTo(map_8a4b2b6c4c835ccfb4694d201a01fb4b);
#
#
#             var feature_group_047fa684489ef6c3357ba04bd0d79214 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_047fa684489ef6c3357ba04bd0d79214.addTo(map_8a4b2b6c4c835ccfb4694d201a01fb4b);
#
#
#             var feature_group_sub_group_6a6dbc57fb4dee2ba4750591392ee6e5 = L.featureGroup.subGroup(
#                 feature_group_047fa684489ef6c3357ba04bd0d79214
#             );
#
#
#             var marker_789f7b5b0093a979e671a5b80f6be07c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6a6dbc57fb4dee2ba4750591392ee6e5);
#
#
#         var popup_2dd43310e7b549cd9acb5317e4432e32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93a05090138b4a7a59a4c64b49cc5e73 = $(`&lt;div id=&quot;html_93a05090138b4a7a59a4c64b49cc5e73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2dd43310e7b549cd9acb5317e4432e32.setContent(html_93a05090138b4a7a59a4c64b49cc5e73);
#
#
#
#         marker_789f7b5b0093a979e671a5b80f6be07c.bindPopup(popup_2dd43310e7b549cd9acb5317e4432e32)
#         ;
#
#
#
#
#             var marker_1d9023d004e62935c68a285823806481 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6a6dbc57fb4dee2ba4750591392ee6e5);
#
#
#         var popup_a6824181bc95b93f25086209348278c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e7e5b028cd4d77d379ffc7f55eb16da = $(`&lt;div id=&quot;html_9e7e5b028cd4d77d379ffc7f55eb16da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a6824181bc95b93f25086209348278c5.setContent(html_9e7e5b028cd4d77d379ffc7f55eb16da);
#
#
#
#         marker_1d9023d004e62935c68a285823806481.bindPopup(popup_a6824181bc95b93f25086209348278c5)
#         ;
#
#
#
#
#             var marker_13f434f82a3c421440781d6aab260e0d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6a6dbc57fb4dee2ba4750591392ee6e5);
#
#
#         var popup_c15fa0fcd788e03806a233dcabb50485 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b0d0f39c93fd1aeaa73f993da23a451 = $(`&lt;div id=&quot;html_4b0d0f39c93fd1aeaa73f993da23a451&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c15fa0fcd788e03806a233dcabb50485.setContent(html_4b0d0f39c93fd1aeaa73f993da23a451);
#
#
#
#         marker_13f434f82a3c421440781d6aab260e0d.bindPopup(popup_c15fa0fcd788e03806a233dcabb50485)
#         ;
#
#
#
#
#             var marker_84aa46eea0b1d17808c06ed64f5920e1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6a6dbc57fb4dee2ba4750591392ee6e5);
#
#
#         var popup_dfd66eec37128e854a18fe0dca7805a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34151f235027a26cdcd7a2a4bc411e94 = $(`&lt;div id=&quot;html_34151f235027a26cdcd7a2a4bc411e94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dfd66eec37128e854a18fe0dca7805a1.setContent(html_34151f235027a26cdcd7a2a4bc411e94);
#
#
#
#         marker_
