# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b721909717738bc3defee616eefe2205 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b721909717738bc3defee616eefe2205&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b721909717738bc3defee616eefe2205 = L.map(
#                 &quot;map_b721909717738bc3defee616eefe2205&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_400904e9711f3a9ee81b8ed5f29db85e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_400904e9711f3a9ee81b8ed5f29db85e.addTo(map_b721909717738bc3defee616eefe2205);
#
#
#             var marker_9a3ea1c30d2d0e4b5a73bee308f2ef2f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b721909717738bc3defee616eefe2205);
#
#
#         var popup_84c50d8633de71bcf8e6035005b780df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e23897221284142eb1dc589d01fbe0ac = $(`&lt;div id=&quot;html_e23897221284142eb1dc589d01fbe0ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_84c50d8633de71bcf8e6035005b780df.setContent(html_e23897221284142eb1dc589d01fbe0ac);
#
#
#
#         marker_9a3ea1c30d2d0e4b5a73bee308f2ef2f.bindPopup(popup_84c50d8633de71bcf8e6035005b780df)
#         ;
#
#
#
#
#             var marker_4d2bfd3b1c89ffe275f885de433b1ed6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b721909717738bc3defee616eefe2205);
#
#
#         var popup_686158eb990d337d66bcf3380c2c79b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84ed27f65e2793c4e84d5b24deb77d9c = $(`&lt;div id=&quot;html_84ed27f65e2793c4e84d5b24deb77d9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_686158eb990d337d66bcf3380c2c79b5.setContent(html_84ed27f65e2793c4e84d5b24deb77d9c);
#
#
#
#         marker_4d2bfd3b1c89ffe275f885de433b1ed6.bindPopup(popup_686158eb990d337d66bcf3380c2c79b5)
#         ;
#
#
#
#
#             var marker_69d9f69188e0d1856f183d0846ed8291 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b721909717738bc3defee616eefe2205);
#
#
#         var popup_002050a0c5dbc423f9516fc873e6563c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41f4e2e71656f2fe4cdf3b1281790676 = $(`&lt;div id=&quot;html_41f4e2e71656f2fe4cdf3b1281790676&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_002050a0c5dbc423f9516fc873e6563c.setContent(html_41f4e2e71656f2fe4cdf3b1281790676);
#
#
#
#         marker_69d9f69188e0d1856f183d0846ed8291.bindPopup(popup_002050a0c5dbc423f9516fc873e6563c)
#         ;
#
#
#
#
#             var marker_119b75e4593410ac3de548d3b0e4eee9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b721909717738bc3defee616eefe2205);
#
#
#         var popup_ea9b05310e9d3ebcfe26e8115df2c980 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9802fb276537bff6f9597f9cf1e6b63a = $(`&lt;div id=&quot;html_9802fb276537bff6f9597f9cf1e6b63a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ea9b05310e9d3ebcfe26e8115df2c980.setContent(html_9802fb276537bff6f9597f9cf1e6b63a);
#
#
#
#         marker_119b75e4593410ac3de548d3b0e4eee9.bindPopup(popup_ea9b05310e9d3ebcfe26e8115df2c980)
#         ;
#
#
#
#
#             var marker_d9bbe6f3c0ff58957cb6e5a7d147e661 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b721909717738bc3defee616eefe2205);
#
#
#         var popup_50bc6beba726b4e01aef7d0d85f284fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5c1561f28ceea8e68d28ded9089b08a = $(`&lt;div id=&quot;html_d5c1561f28ceea8e68d28ded9089b08a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_50bc6beba726b4e01aef7d0d85f284fb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29ef951c9b60c34078f3f32560241617 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29ef951c9b60c34078f3f32560241617&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29ef951c9b60c34078f3f32560241617 = L.map(
#                 &quot;map_29ef951c9b60c34078f3f32560241617&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6f1281dafa30ca78c9a7cbfad8601098 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6f1281dafa30ca78c9a7cbfad8601098.addTo(map_29ef951c9b60c34078f3f32560241617);
#
#
#             var feature_group_5c6152c2a4041ad718df3887441e263b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_099432609b1209e6f71ed3a7331f2924 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5c6152c2a4041ad718df3887441e263b);
#
#
#         var popup_5c56abe79a5484a3e9b199d5b49d9352 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ab47367a6142353a8191801e01caff9 = $(`&lt;div id=&quot;html_5ab47367a6142353a8191801e01caff9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5c56abe79a5484a3e9b199d5b49d9352.setContent(html_5ab47367a6142353a8191801e01caff9);
#
#
#
#         marker_099432609b1209e6f71ed3a7331f2924.bindPopup(popup_5c56abe79a5484a3e9b199d5b49d9352)
#         ;
#
#
#
#
#             var marker_f7be78f23af5b0a0555da23b2b27c888 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5c6152c2a4041ad718df3887441e263b);
#
#
#         var popup_33cc664f7d2626d4ae654be40cc96e9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c5ac5f0b623bb596f2bd60e5ab03691 = $(`&lt;div id=&quot;html_0c5ac5f0b623bb596f2bd60e5ab03691&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_33cc664f7d2626d4ae654be40cc96e9b.setContent(html_0c5ac5f0b623bb596f2bd60e5ab03691);
#
#
#
#         marker_f7be78f23af5b0a0555da23b2b27c888.bindPopup(popup_33cc664f7d2626d4ae654be40cc96e9b)
#         ;
#
#
#
#
#             var marker_7033b08a95e1f840597031c866e93e79 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5c6152c2a4041ad718df3887441e263b);
#
#
#         var popup_18a824fbd5e38903ea168e4b8041faf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_beb8fd30e87f64256a9652311ec6867e = $(`&lt;div id=&quot;html_beb8fd30e87f64256a9652311ec6867e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_18a824fbd5e38903ea168e4b8041faf0.setContent(html_beb8fd30e87f64256a9652311ec6867e);
#
#
#
#         marker_7033b08a95e1f840597031c866e93e79.bindPopup(popup_18a824fbd5e38903ea168e4b8041faf0)
#         ;
#
#
#
#
#             var marker_6c1f8b2b2c12849bf2504fd75654f0ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5c6152c2a4041ad718df3887441e263b);
#
#
#         var popup_51d5cf4b8c2e7319ca5f2ce80287953f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0161237d18f7134a53a71e170470f10a = $(`&lt;div id=&quot;html_0161237d18f7134a53a71e170470f10a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_51d5cf4b8c2e7319ca5f2ce80287953f.setContent(html_0161237d18f7134a53a71e170470f10a);
#
#
#
#         marker_6c1f8b2b2c12849bf2504fd75654f0ac.bindPopup(popup_51d5cf4b8c2e7319ca5f2ce80287953f)
#         ;
#
#
#
#
#             var marker_7fe4184196107d9c332c6d361d7a42ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5c6152c2a4041ad718df3887441e263b);
#
#
#         var popup_5d1e8392adbe5596da687d152b50be8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_de73b28f464c9163167bdb8bb43302b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_de73b28f464c9163167bdb8bb43302b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_de73b28f464c9163167bdb8bb43302b9 = L.map(
#                 &quot;map_de73b28f464c9163167bdb8bb43302b9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88b475773578e68d2c8d2faf6f5da303 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88b475773578e68d2c8d2faf6f5da303.addTo(map_de73b28f464c9163167bdb8bb43302b9);
#
#
#             var feature_group_faaaa5d55c36e062dfa90ca8f05d97f1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_faaaa5d55c36e062dfa90ca8f05d97f1.addTo(map_de73b28f464c9163167bdb8bb43302b9);
#
#
#             var feature_group_sub_group_9adc9752f8280b435f9648102f809aae = L.featureGroup.subGroup(
#                 feature_group_faaaa5d55c36e062dfa90ca8f05d97f1
#             );
#
#
#             var marker_381a7e4a4fee7b128f055447a911e5d2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9adc9752f8280b435f9648102f809aae);
#
#
#         var popup_dc68cc3623e0860813a9f7fc8e11a7ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa812709c93e0a4a5474500d207527ef = $(`&lt;div id=&quot;html_fa812709c93e0a4a5474500d207527ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dc68cc3623e0860813a9f7fc8e11a7ca.setContent(html_fa812709c93e0a4a5474500d207527ef);
#
#
#
#         marker_381a7e4a4fee7b128f055447a911e5d2.bindPopup(popup_dc68cc3623e0860813a9f7fc8e11a7ca)
#         ;
#
#
#
#
#             var marker_1852c159acda00ab3f49f609579318dd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9adc9752f8280b435f9648102f809aae);
#
#
#         var popup_898767e43ba6cebdb3b9124790851129 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_736505177465d4e2870c0b9f8903972b = $(`&lt;div id=&quot;html_736505177465d4e2870c0b9f8903972b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_898767e43ba6cebdb3b9124790851129.setContent(html_736505177465d4e2870c0b9f8903972b);
#
#
#
#         marker_1852c159acda00ab3f49f609579318dd.bindPopup(popup_898767e43ba6cebdb3b9124790851129)
#         ;
#
#
#
#
#             var marker_e31d1ff417b3c6c0926af55eb4130f7c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9adc9752f8280b435f9648102f809aae);
#
#
#         var popup_715b4adf865d46bfa78c247caf7a58e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d672a5d450d1b69e2ea2533b81aaf2cd = $(`&lt;div id=&quot;html_d672a5d450d1b69e2ea2533b81aaf2cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_715b4adf865d46bfa78c247caf7a58e8.setContent(html_d672a5d450d1b69e2ea2533b81aaf2cd);
#
#
#
#         marker_e31d1ff417b3c6c0926af55eb4130f7c.bindPopup(popup_715b4adf865d46bfa78c247caf7a58e8)
#         ;
#
#
#
#
#             var marker_b0d8c1e8fa9718e034884dc098ad9706 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9adc9752f8280b435f9648102f809aae);
#
#
#         var popup_1406a08e714d2ca1c49e87682f6b05d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51678a46578f1e0c8c0546cd1a06d4b1 = $(`&lt;div id=&quot;html_51678a46578f1e0c8c0546cd1a06d4b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1406a08e714d2ca1c49e87682f6b05d7.setContent(html_51678a46578f1e0c8c0546cd1a06d4b1);
#
#
#
#         marker_
