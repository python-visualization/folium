# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8336b6788dd5584f6569e7db544bcb30 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8336b6788dd5584f6569e7db544bcb30&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8336b6788dd5584f6569e7db544bcb30 = L.map(
#                 &quot;map_8336b6788dd5584f6569e7db544bcb30&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f0b417bb21c5d9729871a840d07b9d65 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f0b417bb21c5d9729871a840d07b9d65.addTo(map_8336b6788dd5584f6569e7db544bcb30);
#
#
#             var marker_66ba9b2b29a2eb5e1dffd27c4cc22342 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8336b6788dd5584f6569e7db544bcb30);
#
#
#         var popup_9e296c5e92d9c604798f171578d10be9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64d0e8a97c79ecee7c4ddb74b418a383 = $(`&lt;div id=&quot;html_64d0e8a97c79ecee7c4ddb74b418a383&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9e296c5e92d9c604798f171578d10be9.setContent(html_64d0e8a97c79ecee7c4ddb74b418a383);
#
#
#
#         marker_66ba9b2b29a2eb5e1dffd27c4cc22342.bindPopup(popup_9e296c5e92d9c604798f171578d10be9)
#         ;
#
#
#
#
#             var marker_309bb8bf037b915582d56ece96b97526 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8336b6788dd5584f6569e7db544bcb30);
#
#
#         var popup_639c9ccc6872fce19a0ccf06076fa2ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21328b7cbcb8e718e5f81eddb51fb8ae = $(`&lt;div id=&quot;html_21328b7cbcb8e718e5f81eddb51fb8ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_639c9ccc6872fce19a0ccf06076fa2ca.setContent(html_21328b7cbcb8e718e5f81eddb51fb8ae);
#
#
#
#         marker_309bb8bf037b915582d56ece96b97526.bindPopup(popup_639c9ccc6872fce19a0ccf06076fa2ca)
#         ;
#
#
#
#
#             var marker_e76be575d0e8e2a876bd5f5343e65599 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8336b6788dd5584f6569e7db544bcb30);
#
#
#         var popup_2e2b486410ca8f6460da014cfb0c035c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84e26b89f89e3090707239275bcb1a25 = $(`&lt;div id=&quot;html_84e26b89f89e3090707239275bcb1a25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2e2b486410ca8f6460da014cfb0c035c.setContent(html_84e26b89f89e3090707239275bcb1a25);
#
#
#
#         marker_e76be575d0e8e2a876bd5f5343e65599.bindPopup(popup_2e2b486410ca8f6460da014cfb0c035c)
#         ;
#
#
#
#
#             var marker_3cb57c2d4db99370cb27ed9b32acba9c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8336b6788dd5584f6569e7db544bcb30);
#
#
#         var popup_6caaa30efb90aca101a83f1372580a4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b4b94d3968f4f067874551c5d11629f = $(`&lt;div id=&quot;html_8b4b94d3968f4f067874551c5d11629f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6caaa30efb90aca101a83f1372580a4c.setContent(html_8b4b94d3968f4f067874551c5d11629f);
#
#
#
#         marker_3cb57c2d4db99370cb27ed9b32acba9c.bindPopup(popup_6caaa30efb90aca101a83f1372580a4c)
#         ;
#
#
#
#
#             var marker_8d574e8eed1aabc4e2584fe3111be6e6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8336b6788dd5584f6569e7db544bcb30);
#
#
#         var popup_9605dbee938399becc93e56c0b054794 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21c5533d96bdb5e9be68034706c04b36 = $(`&lt;div id=&quot;html_21c5533d96bdb5e9be68034706c04b36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9605dbee938399becc93e56c0b054794.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_569031086a1a38978164a291a51b1bdd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_569031086a1a38978164a291a51b1bdd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_569031086a1a38978164a291a51b1bdd = L.map(
#                 &quot;map_569031086a1a38978164a291a51b1bdd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a9bab9d04e5ccb458c16c37e29c300e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a9bab9d04e5ccb458c16c37e29c300e.addTo(map_569031086a1a38978164a291a51b1bdd);
#
#
#             var feature_group_8de76e3b32275f3d290fce8beebc9331 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_741538d11e35143dcc02b335dfdfbf69 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8de76e3b32275f3d290fce8beebc9331);
#
#
#         var popup_8f557c1116e28942bcc3cb83e704a1e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7c01a29f01951b07533043fdc538757 = $(`&lt;div id=&quot;html_a7c01a29f01951b07533043fdc538757&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8f557c1116e28942bcc3cb83e704a1e7.setContent(html_a7c01a29f01951b07533043fdc538757);
#
#
#
#         marker_741538d11e35143dcc02b335dfdfbf69.bindPopup(popup_8f557c1116e28942bcc3cb83e704a1e7)
#         ;
#
#
#
#
#             var marker_cdd94998d3c2a6d2e0b040c3c4f23a10 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8de76e3b32275f3d290fce8beebc9331);
#
#
#         var popup_0358bd741b4110de64ebe62c8b0de2af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8016925dacd795c93943fdfd055e63bf = $(`&lt;div id=&quot;html_8016925dacd795c93943fdfd055e63bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0358bd741b4110de64ebe62c8b0de2af.setContent(html_8016925dacd795c93943fdfd055e63bf);
#
#
#
#         marker_cdd94998d3c2a6d2e0b040c3c4f23a10.bindPopup(popup_0358bd741b4110de64ebe62c8b0de2af)
#         ;
#
#
#
#
#             var marker_cb20569354613fb8bdc5bfae631c42d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8de76e3b32275f3d290fce8beebc9331);
#
#
#         var popup_5672f0bb8fdf036e8245028e2523520d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_029bcc24b152e1c620050dede2de76fc = $(`&lt;div id=&quot;html_029bcc24b152e1c620050dede2de76fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5672f0bb8fdf036e8245028e2523520d.setContent(html_029bcc24b152e1c620050dede2de76fc);
#
#
#
#         marker_cb20569354613fb8bdc5bfae631c42d9.bindPopup(popup_5672f0bb8fdf036e8245028e2523520d)
#         ;
#
#
#
#
#             var marker_02e7a3851a57c202d7c6088781b3ee78 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8de76e3b32275f3d290fce8beebc9331);
#
#
#         var popup_fe008465c0ad2abb730151530dd6a7a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1738244a81036834d24ccbbd6be24d29 = $(`&lt;div id=&quot;html_1738244a81036834d24ccbbd6be24d29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fe008465c0ad2abb730151530dd6a7a0.setContent(html_1738244a81036834d24ccbbd6be24d29);
#
#
#
#         marker_02e7a3851a57c202d7c6088781b3ee78.bindPopup(popup_fe008465c0ad2abb730151530dd6a7a0)
#         ;
#
#
#
#
#             var marker_3afcf1ce4d01efdfcf126e948d853739 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8de76e3b32275f3d290fce8beebc9331);
#
#
#         var popup_36000569a1e4b520d548ef44cde64cbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfea41d1d7133c7d28726ef35c257687 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfea41d1d7133c7d28726ef35c257687&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfea41d1d7133c7d28726ef35c257687 = L.map(
#                 &quot;map_cfea41d1d7133c7d28726ef35c257687&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2736e3e7fc4ee91fcda3cde72e87fa5b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2736e3e7fc4ee91fcda3cde72e87fa5b.addTo(map_cfea41d1d7133c7d28726ef35c257687);
#
#
#             var feature_group_6c51e74380ffb80a0c969ff654ec226d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6c51e74380ffb80a0c969ff654ec226d.addTo(map_cfea41d1d7133c7d28726ef35c257687);
#
#
#             var feature_group_sub_group_aba870bb08d19f86e4f6fb5046c6d8c0 = L.featureGroup.subGroup(
#                 feature_group_6c51e74380ffb80a0c969ff654ec226d
#             );
#
#
#             var marker_f68765540d4a9ce7a8f1b40e6d51770a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_aba870bb08d19f86e4f6fb5046c6d8c0);
#
#
#         var popup_698d556f29bce49b9ae946d9a2061b96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44e1cec5adaf29fe5cf8301371e597ff = $(`&lt;div id=&quot;html_44e1cec5adaf29fe5cf8301371e597ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_698d556f29bce49b9ae946d9a2061b96.setContent(html_44e1cec5adaf29fe5cf8301371e597ff);
#
#
#
#         marker_f68765540d4a9ce7a8f1b40e6d51770a.bindPopup(popup_698d556f29bce49b9ae946d9a2061b96)
#         ;
#
#
#
#
#             var marker_0a3c1df29cab94ee930963eba66e0c16 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_aba870bb08d19f86e4f6fb5046c6d8c0);
#
#
#         var popup_bc4b444b7ec378410696be81b1c6a36b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1db01a5ba4b4fcda2bb841a31a917dea = $(`&lt;div id=&quot;html_1db01a5ba4b4fcda2bb841a31a917dea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bc4b444b7ec378410696be81b1c6a36b.setContent(html_1db01a5ba4b4fcda2bb841a31a917dea);
#
#
#
#         marker_0a3c1df29cab94ee930963eba66e0c16.bindPopup(popup_bc4b444b7ec378410696be81b1c6a36b)
#         ;
#
#
#
#
#             var marker_cdb2e587c2b9a06ff1de63912e684647 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_aba870bb08d19f86e4f6fb5046c6d8c0);
#
#
#         var popup_b0493ab73c6d6db86ffe3f39c6152e80 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c3e0acd3aeb7f6fa9e096345139523a = $(`&lt;div id=&quot;html_0c3e0acd3aeb7f6fa9e096345139523a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b0493ab73c6d6db86ffe3f39c6152e80.setContent(html_0c3e0acd3aeb7f6fa9e096345139523a);
#
#
#
#         marker_cdb2e587c2b9a06ff1de63912e684647.bindPopup(popup_b0493ab73c6d6db86ffe3f39c6152e80)
#         ;
#
#
#
#
#             var marker_a65cc9fbebb60308fdc24eff24307aa9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_aba870bb08d19f86e4f6fb5046c6d8c0);
#
#
#         var popup_a308b88149d1d8cb94f6b4f67eccb1b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87a1b0ec712c12155a30dea077aaa9c9 = $(`&lt;div id=&quot;html_87a1b0ec712c12155a30dea077aaa9c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a308b88149d1d8cb94f6b4f67eccb1b8.setContent(html_87a1b0ec712c12155a30dea077aaa9c9);
#
#
#
#         marker_
