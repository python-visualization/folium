# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b421382f2996f49e9240fc0170772739 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b421382f2996f49e9240fc0170772739&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b421382f2996f49e9240fc0170772739 = L.map(
#                 &quot;map_b421382f2996f49e9240fc0170772739&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_102aa0a068c986149bc8f8ac45464ae0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_102aa0a068c986149bc8f8ac45464ae0.addTo(map_b421382f2996f49e9240fc0170772739);
#
#
#             var marker_8045889745392bd5c3e7a712605f7c34 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b421382f2996f49e9240fc0170772739);
#
#
#         var popup_8ee809148447442d7620161847abb74b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59eec797b08e846ced99ee9deda64276 = $(`&lt;div id=&quot;html_59eec797b08e846ced99ee9deda64276&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8ee809148447442d7620161847abb74b.setContent(html_59eec797b08e846ced99ee9deda64276);
#
#
#
#         marker_8045889745392bd5c3e7a712605f7c34.bindPopup(popup_8ee809148447442d7620161847abb74b)
#         ;
#
#
#
#
#             var marker_5ab1ff2d59ed9e004c4fa929f842da8a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b421382f2996f49e9240fc0170772739);
#
#
#         var popup_6e708aaf05d5ae366d242299654b19d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c075f441135bc7516d80cc7a9baea5f = $(`&lt;div id=&quot;html_3c075f441135bc7516d80cc7a9baea5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6e708aaf05d5ae366d242299654b19d3.setContent(html_3c075f441135bc7516d80cc7a9baea5f);
#
#
#
#         marker_5ab1ff2d59ed9e004c4fa929f842da8a.bindPopup(popup_6e708aaf05d5ae366d242299654b19d3)
#         ;
#
#
#
#
#             var marker_e9daf12a63587bd77267b0f32bd355ce = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b421382f2996f49e9240fc0170772739);
#
#
#         var popup_afce75a8ba3b1b733f6adf691f93fb58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f33fc0de0df45a2ec420e094903cc2f2 = $(`&lt;div id=&quot;html_f33fc0de0df45a2ec420e094903cc2f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_afce75a8ba3b1b733f6adf691f93fb58.setContent(html_f33fc0de0df45a2ec420e094903cc2f2);
#
#
#
#         marker_e9daf12a63587bd77267b0f32bd355ce.bindPopup(popup_afce75a8ba3b1b733f6adf691f93fb58)
#         ;
#
#
#
#
#             var marker_2688c91ce60dcbe6ce3cd5719efedbda = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b421382f2996f49e9240fc0170772739);
#
#
#         var popup_8c4850f2354bf5f41147a1af5860ad32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d68f090f37a210c3c8227e081d9691b = $(`&lt;div id=&quot;html_0d68f090f37a210c3c8227e081d9691b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8c4850f2354bf5f41147a1af5860ad32.setContent(html_0d68f090f37a210c3c8227e081d9691b);
#
#
#
#         marker_2688c91ce60dcbe6ce3cd5719efedbda.bindPopup(popup_8c4850f2354bf5f41147a1af5860ad32)
#         ;
#
#
#
#
#             var marker_9296a70e3113f11058497a69c85c043c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b421382f2996f49e9240fc0170772739);
#
#
#         var popup_9dc02eccbf5551411ddb84d04f8fecc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54d4297b18e92ab492fcb39ca4b204bb = $(`&lt;div id=&quot;html_54d4297b18e92ab492fcb39ca4b204bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9dc02eccbf5551411ddb84d04f8fecc4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a09361c8f11fb19e85eeef0e2ea50bea {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a09361c8f11fb19e85eeef0e2ea50bea&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a09361c8f11fb19e85eeef0e2ea50bea = L.map(
#                 &quot;map_a09361c8f11fb19e85eeef0e2ea50bea&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9728826dd93927ebe12004f91d1bbe20 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9728826dd93927ebe12004f91d1bbe20.addTo(map_a09361c8f11fb19e85eeef0e2ea50bea);
#
#
#             var feature_group_67e30f00385594684cd6493e8c7ace03 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2a682f8f8f3a901f3dbea8875c16a817 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_67e30f00385594684cd6493e8c7ace03);
#
#
#         var popup_ef6d74d089d2e44f5c434f1fe1136a9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e8aca694c0a2dc7e27a874f0cb740cc = $(`&lt;div id=&quot;html_4e8aca694c0a2dc7e27a874f0cb740cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ef6d74d089d2e44f5c434f1fe1136a9d.setContent(html_4e8aca694c0a2dc7e27a874f0cb740cc);
#
#
#
#         marker_2a682f8f8f3a901f3dbea8875c16a817.bindPopup(popup_ef6d74d089d2e44f5c434f1fe1136a9d)
#         ;
#
#
#
#
#             var marker_cde50951440125ae71500ae9fedcb7df = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_67e30f00385594684cd6493e8c7ace03);
#
#
#         var popup_48ca1ba2ab2dfe9313a8ec1cece3c418 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6151901a023c2e675ce6a1aa788043c = $(`&lt;div id=&quot;html_e6151901a023c2e675ce6a1aa788043c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_48ca1ba2ab2dfe9313a8ec1cece3c418.setContent(html_e6151901a023c2e675ce6a1aa788043c);
#
#
#
#         marker_cde50951440125ae71500ae9fedcb7df.bindPopup(popup_48ca1ba2ab2dfe9313a8ec1cece3c418)
#         ;
#
#
#
#
#             var marker_861b23a931db358cdbe33bbcd9df7d3c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_67e30f00385594684cd6493e8c7ace03);
#
#
#         var popup_a5605e6e082a904b5934b97742c2e715 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac53f588bbccafcdae1cd5c480c5de66 = $(`&lt;div id=&quot;html_ac53f588bbccafcdae1cd5c480c5de66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a5605e6e082a904b5934b97742c2e715.setContent(html_ac53f588bbccafcdae1cd5c480c5de66);
#
#
#
#         marker_861b23a931db358cdbe33bbcd9df7d3c.bindPopup(popup_a5605e6e082a904b5934b97742c2e715)
#         ;
#
#
#
#
#             var marker_90b1f303371bf466c88b97fcead41255 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_67e30f00385594684cd6493e8c7ace03);
#
#
#         var popup_96680b9e42383814960d6c6b3f0c6770 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20f5d020a88e0b1814e39ecc2000590f = $(`&lt;div id=&quot;html_20f5d020a88e0b1814e39ecc2000590f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_96680b9e42383814960d6c6b3f0c6770.setContent(html_20f5d020a88e0b1814e39ecc2000590f);
#
#
#
#         marker_90b1f303371bf466c88b97fcead41255.bindPopup(popup_96680b9e42383814960d6c6b3f0c6770)
#         ;
#
#
#
#
#             var marker_5f8f75a9c7ecc452e22089bf5156e2b2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_67e30f00385594684cd6493e8c7ace03);
#
#
#         var popup_af5359d95a50053f5b55bc20eaa71cf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ae3f59364f8b96a5bae98811c9352abe {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ae3f59364f8b96a5bae98811c9352abe&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ae3f59364f8b96a5bae98811c9352abe = L.map(
#                 &quot;map_ae3f59364f8b96a5bae98811c9352abe&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a68ad0af75d4584e8980646bd75b06bb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a68ad0af75d4584e8980646bd75b06bb.addTo(map_ae3f59364f8b96a5bae98811c9352abe);
#
#
#             var feature_group_134afc35504ac1992c7be99ea1516fe4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_134afc35504ac1992c7be99ea1516fe4.addTo(map_ae3f59364f8b96a5bae98811c9352abe);
#
#
#             var feature_group_sub_group_269a162a108012c88aef2ad801878c85 = L.featureGroup.subGroup(
#                 feature_group_134afc35504ac1992c7be99ea1516fe4
#             );
#
#
#             var marker_e1a5aefada42a4543d15e118148291bc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_269a162a108012c88aef2ad801878c85);
#
#
#         var popup_e5abb174d71f7019f03a8957c705bc09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_898e746af43fc03e88b299bc7f85e5f1 = $(`&lt;div id=&quot;html_898e746af43fc03e88b299bc7f85e5f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e5abb174d71f7019f03a8957c705bc09.setContent(html_898e746af43fc03e88b299bc7f85e5f1);
#
#
#
#         marker_e1a5aefada42a4543d15e118148291bc.bindPopup(popup_e5abb174d71f7019f03a8957c705bc09)
#         ;
#
#
#
#
#             var marker_1dca5d52cf24e670a7b6b0388c1c5729 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_269a162a108012c88aef2ad801878c85);
#
#
#         var popup_2318bcca18de433fe20279544c5a6e03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08033a3ccc3cf19894f95dfc75bac591 = $(`&lt;div id=&quot;html_08033a3ccc3cf19894f95dfc75bac591&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2318bcca18de433fe20279544c5a6e03.setContent(html_08033a3ccc3cf19894f95dfc75bac591);
#
#
#
#         marker_1dca5d52cf24e670a7b6b0388c1c5729.bindPopup(popup_2318bcca18de433fe20279544c5a6e03)
#         ;
#
#
#
#
#             var marker_442178abdfd22c0f4af3a1307346e5bd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_269a162a108012c88aef2ad801878c85);
#
#
#         var popup_4b0e2dd8f9fbd7828c1d7f8d6c1c894e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50653e1a765da0e1c09788b5adf23e90 = $(`&lt;div id=&quot;html_50653e1a765da0e1c09788b5adf23e90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4b0e2dd8f9fbd7828c1d7f8d6c1c894e.setContent(html_50653e1a765da0e1c09788b5adf23e90);
#
#
#
#         marker_442178abdfd22c0f4af3a1307346e5bd.bindPopup(popup_4b0e2dd8f9fbd7828c1d7f8d6c1c894e)
#         ;
#
#
#
#
#             var marker_2a2760f1b12ff80efcdd47ba5fd793e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_269a162a108012c88aef2ad801878c85);
#
#
#         var popup_56f77a241fceedfb3e69c4791218fec9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7967b39a938a0f222fd4b02438e2049e = $(`&lt;div id=&quot;html_7967b39a938a0f222fd4b02438e2049e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_56f77a241fceedfb3e69c4791218fec9.setContent(html_7967b39a938a0f222fd4b02438e2049e);
#
#
#
#         marker_
