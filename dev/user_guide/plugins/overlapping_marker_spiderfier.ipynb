# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_91f27f78ad352a209fadc6a376bc9644 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_91f27f78ad352a209fadc6a376bc9644&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_91f27f78ad352a209fadc6a376bc9644 = L.map(
#                 &quot;map_91f27f78ad352a209fadc6a376bc9644&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aff08a2a84f92f081fde9d92bf33b692 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aff08a2a84f92f081fde9d92bf33b692.addTo(map_91f27f78ad352a209fadc6a376bc9644);
#
#
#             var marker_cf82a6aad8b2d15df06787c2c61ba87f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_91f27f78ad352a209fadc6a376bc9644);
#
#
#         var popup_2ddc7ae47db2b0a9618c525367895b15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_227a56c40494daf5ae99cae2a74b362a = $(`&lt;div id=&quot;html_227a56c40494daf5ae99cae2a74b362a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2ddc7ae47db2b0a9618c525367895b15.setContent(html_227a56c40494daf5ae99cae2a74b362a);
#
#
#
#         marker_cf82a6aad8b2d15df06787c2c61ba87f.bindPopup(popup_2ddc7ae47db2b0a9618c525367895b15)
#         ;
#
#
#
#
#             var marker_f5bb30c0f9e32124291a41055ae78e05 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_91f27f78ad352a209fadc6a376bc9644);
#
#
#         var popup_82ce426ec0afe65b08a2aa01a7904b7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bacafccc7d1c07c47ba10d54270d1c9 = $(`&lt;div id=&quot;html_5bacafccc7d1c07c47ba10d54270d1c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_82ce426ec0afe65b08a2aa01a7904b7f.setContent(html_5bacafccc7d1c07c47ba10d54270d1c9);
#
#
#
#         marker_f5bb30c0f9e32124291a41055ae78e05.bindPopup(popup_82ce426ec0afe65b08a2aa01a7904b7f)
#         ;
#
#
#
#
#             var marker_db27de98e9f32477baffe3461e020c7b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_91f27f78ad352a209fadc6a376bc9644);
#
#
#         var popup_cd6ea3460fa4dc6d86cb8d4640f375f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55bd1d562cb9b57312e17164bbe811a1 = $(`&lt;div id=&quot;html_55bd1d562cb9b57312e17164bbe811a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cd6ea3460fa4dc6d86cb8d4640f375f9.setContent(html_55bd1d562cb9b57312e17164bbe811a1);
#
#
#
#         marker_db27de98e9f32477baffe3461e020c7b.bindPopup(popup_cd6ea3460fa4dc6d86cb8d4640f375f9)
#         ;
#
#
#
#
#             var marker_fa8e010c5a229489fb97d75f9e3dcd21 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_91f27f78ad352a209fadc6a376bc9644);
#
#
#         var popup_9b818d98f5562289a5b5172302339c69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a46f9f4e4ed2dddcf7c0e9c4ee7e2fb = $(`&lt;div id=&quot;html_7a46f9f4e4ed2dddcf7c0e9c4ee7e2fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9b818d98f5562289a5b5172302339c69.setContent(html_7a46f9f4e4ed2dddcf7c0e9c4ee7e2fb);
#
#
#
#         marker_fa8e010c5a229489fb97d75f9e3dcd21.bindPopup(popup_9b818d98f5562289a5b5172302339c69)
#         ;
#
#
#
#
#             var marker_a2645b44cbb59495182e464b9be9e3cb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_91f27f78ad352a209fadc6a376bc9644);
#
#
#         var popup_61edd0f4dd0700004a46f4be7786761c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5027a3a828661c1c73febf2650d3fc5 = $(`&lt;div id=&quot;html_b5027a3a828661c1c73febf2650d3fc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_61edd0f4dd0700004a46f4be7786761c.setContent(html_b5027a3a828661c1c73febf2650d3fc5);
#
#
#
#         marker_a2645b44cbb59495182e464b9be9e3cb.bindPopup(popup_61edd0f4dd0700004a46f4be7786761c)
#         ;
#
#
#
#
#             var marker_6af007904c

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a31faa7f404e194f64efc394aa4a1bf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a31faa7f404e194f64efc394aa4a1bf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a31faa7f404e194f64efc394aa4a1bf0 = L.map(
#                 &quot;map_a31faa7f404e194f64efc394aa4a1bf0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab5280e6af29615e2eff01b370878897 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab5280e6af29615e2eff01b370878897.addTo(map_a31faa7f404e194f64efc394aa4a1bf0);
#
#
#             var feature_group_83644570b61a3c35f56b479189d86371 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0e8080ff486e777b26537cd79e7357eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_83644570b61a3c35f56b479189d86371);
#
#
#         var popup_6319a3f1954670140ef2998aa9e3d5c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_734b9fd9b077f1d7ce2569c5e3df5582 = $(`&lt;div id=&quot;html_734b9fd9b077f1d7ce2569c5e3df5582&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6319a3f1954670140ef2998aa9e3d5c3.setContent(html_734b9fd9b077f1d7ce2569c5e3df5582);
#
#
#
#         marker_0e8080ff486e777b26537cd79e7357eb.bindPopup(popup_6319a3f1954670140ef2998aa9e3d5c3)
#         ;
#
#
#
#
#             var marker_b954b18aced6d2caf61e74931cddc78a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_83644570b61a3c35f56b479189d86371);
#
#
#         var popup_43b0f2aee2c8c653c377bab542f4e31c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e963a14d5a6dd18e05b9b96e2f6f7491 = $(`&lt;div id=&quot;html_e963a14d5a6dd18e05b9b96e2f6f7491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_43b0f2aee2c8c653c377bab542f4e31c.setContent(html_e963a14d5a6dd18e05b9b96e2f6f7491);
#
#
#
#         marker_b954b18aced6d2caf61e74931cddc78a.bindPopup(popup_43b0f2aee2c8c653c377bab542f4e31c)
#         ;
#
#
#
#
#             var marker_75507dd7eb481bb2142dae12546c92c7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_83644570b61a3c35f56b479189d86371);
#
#
#         var popup_67f8cf1f12e9d4c2f1f67f3588e9086b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2d5a532ced68ec18d0586715db201fa = $(`&lt;div id=&quot;html_d2d5a532ced68ec18d0586715db201fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_67f8cf1f12e9d4c2f1f67f3588e9086b.setContent(html_d2d5a532ced68ec18d0586715db201fa);
#
#
#
#         marker_75507dd7eb481bb2142dae12546c92c7.bindPopup(popup_67f8cf1f12e9d4c2f1f67f3588e9086b)
#         ;
#
#
#
#
#             var marker_2fac1bead666f822aa5cd3bca32edd6a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_83644570b61a3c35f56b479189d86371);
#
#
#         var popup_80238cfe00f39950c78380879b4bd1a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f49c3b9ea7bbcfe7e491e814ff49f64 = $(`&lt;div id=&quot;html_9f49c3b9ea7bbcfe7e491e814ff49f64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_80238cfe00f39950c78380879b4bd1a6.setContent(html_9f49c3b9ea7bbcfe7e491e814ff49f64);
#
#
#
#         marker_2fac1bead666f822aa5cd3bca32edd6a.bindPopup(popup_80238cfe00f39950c78380879b4bd1a6)
#         ;
#
#
#
#
#             var marker_76e70fd0f556ec3e618459c6f27be5b1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_83644570b61a3c35f56b479189d86371);
#
#
#         var popup_43c61258c57a06e2d2ce956a00894976 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_483c49622d4c415fc99d96e3ebd3fdad = $(`&lt;div id=&quot;html_483c49622d4c415fc99d96e3ebd3fdad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_43c61258c57a06e2d2

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_981f4b59d777379642ff90ddf73b6e4d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_981f4b59d777379642ff90ddf73b6e4d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_981f4b59d777379642ff90ddf73b6e4d = L.map(
#                 &quot;map_981f4b59d777379642ff90ddf73b6e4d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9de66d849bacf53c60b1bc29d70131aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9de66d849bacf53c60b1bc29d70131aa.addTo(map_981f4b59d777379642ff90ddf73b6e4d);
#
#
#             var feature_group_4346f251ff633be71f55ebc7aad398e8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4346f251ff633be71f55ebc7aad398e8.addTo(map_981f4b59d777379642ff90ddf73b6e4d);
#
#
#             var feature_group_sub_group_8d743444050cbb14dcb5639515f76b28 = L.featureGroup.subGroup(
#                 feature_group_4346f251ff633be71f55ebc7aad398e8
#             );
#
#
#             var marker_fc58ab9513b37bdb2d26adf7cbec66cc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d743444050cbb14dcb5639515f76b28);
#
#
#         var popup_40f3e4c6bb5eb4e7fc6192a93349d75e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70e15e131ece3d941ccc3652417ace37 = $(`&lt;div id=&quot;html_70e15e131ece3d941ccc3652417ace37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_40f3e4c6bb5eb4e7fc6192a93349d75e.setContent(html_70e15e131ece3d941ccc3652417ace37);
#
#
#
#         marker_fc58ab9513b37bdb2d26adf7cbec66cc.bindPopup(popup_40f3e4c6bb5eb4e7fc6192a93349d75e)
#         ;
#
#
#
#
#             var marker_09ec4f3658d20dab797e547870b27328 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d743444050cbb14dcb5639515f76b28);
#
#
#         var popup_56e4f0860a743f5571d9eab8b9706b6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ce544b7d070bc14544d203ec8bb25b4 = $(`&lt;div id=&quot;html_3ce544b7d070bc14544d203ec8bb25b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_56e4f0860a743f5571d9eab8b9706b6a.setContent(html_3ce544b7d070bc14544d203ec8bb25b4);
#
#
#
#         marker_09ec4f3658d20dab797e547870b27328.bindPopup(popup_56e4f0860a743f5571d9eab8b9706b6a)
#         ;
#
#
#
#
#             var marker_b7d209dd5464fd30dc9141d25141d16b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d743444050cbb14dcb5639515f76b28);
#
#
#         var popup_08ae2a6524c26e634d99ecc68d18f93c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1465e5d6675f47c4c68acb30cb98e0ab = $(`&lt;div id=&quot;html_1465e5d6675f47c4c68acb30cb98e0ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_08ae2a6524c26e634d99ecc68d18f93c.setContent(html_1465e5d6675f47c4c68acb30cb98e0ab);
#
#
#
#         marker_b7d209dd5464fd30dc9141d25141d16b.bindPopup(popup_08ae2a6524c26e634d99ecc68d18f93c)
#         ;
#
#
#
#
#             var marker_74ee0f894e4347ddb65ac9ad5e9fef58 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8d743444050cbb14dcb5639515f76b28);
#
#
#         var popup_76224b1c7120a310f43c1ec907754217 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd5bc3837402941b7c16d39008c69443 = $(`&lt;div id=&quot;html_fd5bc3837402941b7c16d39008c69443&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_76224b1c7120a310f43c1ec907754217.setContent(html_fd5bc3837402941b7c16d39008c69443);
#
#
#
#         marker_74ee0f894e4347ddb65ac9ad5e9fef58.bindPopup(popup_76224b1c7120a310f43c1ec907754217)
#         ;
#
#
#
#
#             var marker_861e2487f613a403f449f95ced30f70c = L.marker(
#                 [45.050399999999996, 3.0504],
