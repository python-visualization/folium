# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_042b6e6d1f495e91fdbef2a4f9a16f2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_042b6e6d1f495e91fdbef2a4f9a16f2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_042b6e6d1f495e91fdbef2a4f9a16f2d = L.map(
#                 &quot;map_042b6e6d1f495e91fdbef2a4f9a16f2d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6be513d2556d08ebee20bf6a921bf9a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6be513d2556d08ebee20bf6a921bf9a2.addTo(map_042b6e6d1f495e91fdbef2a4f9a16f2d);
#
#
#             var marker_783289798071fcc0f421c7eb30a00e14 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_042b6e6d1f495e91fdbef2a4f9a16f2d);
#
#
#         var popup_b7cb703189a820719898217acb04f090 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d15a9d001c3fd9bb18d840750e2e6f9 = $(`&lt;div id=&quot;html_6d15a9d001c3fd9bb18d840750e2e6f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b7cb703189a820719898217acb04f090.setContent(html_6d15a9d001c3fd9bb18d840750e2e6f9);
#
#
#
#         marker_783289798071fcc0f421c7eb30a00e14.bindPopup(popup_b7cb703189a820719898217acb04f090)
#         ;
#
#
#
#
#             var marker_ca89412115561bcb9d7779395bf28e88 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_042b6e6d1f495e91fdbef2a4f9a16f2d);
#
#
#         var popup_f3a481d8764b5d01720f42cf82af3d40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3dba1812238b9d9453cf7f4735df2f9 = $(`&lt;div id=&quot;html_f3dba1812238b9d9453cf7f4735df2f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f3a481d8764b5d01720f42cf82af3d40.setContent(html_f3dba1812238b9d9453cf7f4735df2f9);
#
#
#
#         marker_ca89412115561bcb9d7779395bf28e88.bindPopup(popup_f3a481d8764b5d01720f42cf82af3d40)
#         ;
#
#
#
#
#             var marker_a64bb1e3aa74568e57cf87e25ecd2f11 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_042b6e6d1f495e91fdbef2a4f9a16f2d);
#
#
#         var popup_7b2481528077456ccc7b9e44ddee47e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f67d67e88a74e712ea6b71ac0fe4826 = $(`&lt;div id=&quot;html_8f67d67e88a74e712ea6b71ac0fe4826&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7b2481528077456ccc7b9e44ddee47e8.setContent(html_8f67d67e88a74e712ea6b71ac0fe4826);
#
#
#
#         marker_a64bb1e3aa74568e57cf87e25ecd2f11.bindPopup(popup_7b2481528077456ccc7b9e44ddee47e8)
#         ;
#
#
#
#
#             var marker_fea3df197a775219133a392c07e34d46 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_042b6e6d1f495e91fdbef2a4f9a16f2d);
#
#
#         var popup_07133b837e13e7750ac64d3d1a904c21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ad893f4fb51e804d567bb44a9265aac = $(`&lt;div id=&quot;html_9ad893f4fb51e804d567bb44a9265aac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_07133b837e13e7750ac64d3d1a904c21.setContent(html_9ad893f4fb51e804d567bb44a9265aac);
#
#
#
#         marker_fea3df197a775219133a392c07e34d46.bindPopup(popup_07133b837e13e7750ac64d3d1a904c21)
#         ;
#
#
#
#
#             var marker_981e66ab02846ca7e4615a60c0ce9dab = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_042b6e6d1f495e91fdbef2a4f9a16f2d);
#
#
#         var popup_123d1c6d45afe5d49dbca1ec3612f8b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e24e425fd10478197ad19887cba6598 = $(`&lt;div id=&quot;html_6e24e425fd10478197ad19887cba6598&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_123d1c6d45afe5d49dbca1ec3612f8b7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b19422ebee08415c4c31f3501ecdb6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b19422ebee08415c4c31f3501ecdb6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b19422ebee08415c4c31f3501ecdb6d = L.map(
#                 &quot;map_9b19422ebee08415c4c31f3501ecdb6d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18a09703323fa773ddf53a97872fe99a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18a09703323fa773ddf53a97872fe99a.addTo(map_9b19422ebee08415c4c31f3501ecdb6d);
#
#
#             var feature_group_4004721622c32d5dfad7088e56f650d6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c88b8efe65335fe4af29e085a7c6f21d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4004721622c32d5dfad7088e56f650d6);
#
#
#         var popup_d8471db82f499806ae5e2dd21612299a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8abcebbcfc10372ddcb5c03705532ac8 = $(`&lt;div id=&quot;html_8abcebbcfc10372ddcb5c03705532ac8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d8471db82f499806ae5e2dd21612299a.setContent(html_8abcebbcfc10372ddcb5c03705532ac8);
#
#
#
#         marker_c88b8efe65335fe4af29e085a7c6f21d.bindPopup(popup_d8471db82f499806ae5e2dd21612299a)
#         ;
#
#
#
#
#             var marker_b5f54278824fbfb0fbb70ee5ab12412d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4004721622c32d5dfad7088e56f650d6);
#
#
#         var popup_ce570721ec5c4aee8e8045ba66e3652a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b01a3f267a5aa9b7d74cc18263964a7 = $(`&lt;div id=&quot;html_1b01a3f267a5aa9b7d74cc18263964a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ce570721ec5c4aee8e8045ba66e3652a.setContent(html_1b01a3f267a5aa9b7d74cc18263964a7);
#
#
#
#         marker_b5f54278824fbfb0fbb70ee5ab12412d.bindPopup(popup_ce570721ec5c4aee8e8045ba66e3652a)
#         ;
#
#
#
#
#             var marker_1931388b944fc9bf7e6615e21e98abcc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4004721622c32d5dfad7088e56f650d6);
#
#
#         var popup_1101f05d9d1f106d735dfcdcbf51ee7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ebc50e34a37f15dbdd946b2d01869c2c = $(`&lt;div id=&quot;html_ebc50e34a37f15dbdd946b2d01869c2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1101f05d9d1f106d735dfcdcbf51ee7c.setContent(html_ebc50e34a37f15dbdd946b2d01869c2c);
#
#
#
#         marker_1931388b944fc9bf7e6615e21e98abcc.bindPopup(popup_1101f05d9d1f106d735dfcdcbf51ee7c)
#         ;
#
#
#
#
#             var marker_20b3895eb2a0e27c2fa41cd715d0d1c5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4004721622c32d5dfad7088e56f650d6);
#
#
#         var popup_87700701abd976fd652913eaeadc3dba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_210eee86c07ef8945bed9c33cbfad290 = $(`&lt;div id=&quot;html_210eee86c07ef8945bed9c33cbfad290&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_87700701abd976fd652913eaeadc3dba.setContent(html_210eee86c07ef8945bed9c33cbfad290);
#
#
#
#         marker_20b3895eb2a0e27c2fa41cd715d0d1c5.bindPopup(popup_87700701abd976fd652913eaeadc3dba)
#         ;
#
#
#
#
#             var marker_02e233dfa2c8b37a66e915c3c21343f9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4004721622c32d5dfad7088e56f650d6);
#
#
#         var popup_74bf89d57755320069ee4c1f2a688ab1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_862c108bf0039fd499c89a6fb31dc31c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_862c108bf0039fd499c89a6fb31dc31c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_862c108bf0039fd499c89a6fb31dc31c = L.map(
#                 &quot;map_862c108bf0039fd499c89a6fb31dc31c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7215023370267ec1f0f0d9665a84205 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c7215023370267ec1f0f0d9665a84205.addTo(map_862c108bf0039fd499c89a6fb31dc31c);
#
#
#             var feature_group_0715ed6814fba371c033a3eddbdb5231 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0715ed6814fba371c033a3eddbdb5231.addTo(map_862c108bf0039fd499c89a6fb31dc31c);
#
#
#             var feature_group_sub_group_f6dfb4870351aa7862531e37cf97d382 = L.featureGroup.subGroup(
#                 feature_group_0715ed6814fba371c033a3eddbdb5231
#             );
#
#
#             var marker_91c5fe5e50b006a37ff1a6746d56107e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6dfb4870351aa7862531e37cf97d382);
#
#
#         var popup_a6a189032ed188fb2c04cfc21bf3f854 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcc71051afbd9c1d9530131d6a48359e = $(`&lt;div id=&quot;html_dcc71051afbd9c1d9530131d6a48359e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a6a189032ed188fb2c04cfc21bf3f854.setContent(html_dcc71051afbd9c1d9530131d6a48359e);
#
#
#
#         marker_91c5fe5e50b006a37ff1a6746d56107e.bindPopup(popup_a6a189032ed188fb2c04cfc21bf3f854)
#         ;
#
#
#
#
#             var marker_ca2c9fa87f3ad39df5c75fc3ffcab63f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6dfb4870351aa7862531e37cf97d382);
#
#
#         var popup_c3654872c5cc0faa272c624cb165f7e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93b00accc91178baefcdd483098bec20 = $(`&lt;div id=&quot;html_93b00accc91178baefcdd483098bec20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c3654872c5cc0faa272c624cb165f7e7.setContent(html_93b00accc91178baefcdd483098bec20);
#
#
#
#         marker_ca2c9fa87f3ad39df5c75fc3ffcab63f.bindPopup(popup_c3654872c5cc0faa272c624cb165f7e7)
#         ;
#
#
#
#
#             var marker_6641f9919dce4f06f382415824a4dfcd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6dfb4870351aa7862531e37cf97d382);
#
#
#         var popup_95b13e32afd4b03ddaca50d3014ca138 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_422c2e6b6d073834a8801e81ed42958c = $(`&lt;div id=&quot;html_422c2e6b6d073834a8801e81ed42958c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_95b13e32afd4b03ddaca50d3014ca138.setContent(html_422c2e6b6d073834a8801e81ed42958c);
#
#
#
#         marker_6641f9919dce4f06f382415824a4dfcd.bindPopup(popup_95b13e32afd4b03ddaca50d3014ca138)
#         ;
#
#
#
#
#             var marker_8360c22c44d27256d17621e9726d03e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f6dfb4870351aa7862531e37cf97d382);
#
#
#         var popup_e17ebc6f4dcafb256a42ab8af323b2f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a9ad6e4007a94fda72bb62dcaf4744c = $(`&lt;div id=&quot;html_7a9ad6e4007a94fda72bb62dcaf4744c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e17ebc6f4dcafb256a42ab8af323b2f5.setContent(html_7a9ad6e4007a94fda72bb62dcaf4744c);
#
#
#
#         marker_
