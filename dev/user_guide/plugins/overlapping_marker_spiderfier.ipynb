# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b57f62548971fd7040a0e70cfb4d48b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b57f62548971fd7040a0e70cfb4d48b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b57f62548971fd7040a0e70cfb4d48b = L.map(
#                 &quot;map_6b57f62548971fd7040a0e70cfb4d48b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b45ccf54a8012a02441c86a2829fb997 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b45ccf54a8012a02441c86a2829fb997.addTo(map_6b57f62548971fd7040a0e70cfb4d48b);
#
#
#             var marker_d5e9394ee4e86adbb699235d43a0f656 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6b57f62548971fd7040a0e70cfb4d48b);
#
#
#         var popup_0af3eda5ec471a9a5ca6f3b0534aa668 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0cbecda37b8a972773f27edcd675cca = $(`&lt;div id=&quot;html_d0cbecda37b8a972773f27edcd675cca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0af3eda5ec471a9a5ca6f3b0534aa668.setContent(html_d0cbecda37b8a972773f27edcd675cca);
#
#
#
#         marker_d5e9394ee4e86adbb699235d43a0f656.bindPopup(popup_0af3eda5ec471a9a5ca6f3b0534aa668)
#         ;
#
#
#
#
#             var marker_b01cf9cb85cbee35390b53440fedb680 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6b57f62548971fd7040a0e70cfb4d48b);
#
#
#         var popup_4df704c5405640fb5450b5746bac3101 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_922eab3f5f9fd19fc9b90807b65fc791 = $(`&lt;div id=&quot;html_922eab3f5f9fd19fc9b90807b65fc791&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4df704c5405640fb5450b5746bac3101.setContent(html_922eab3f5f9fd19fc9b90807b65fc791);
#
#
#
#         marker_b01cf9cb85cbee35390b53440fedb680.bindPopup(popup_4df704c5405640fb5450b5746bac3101)
#         ;
#
#
#
#
#             var marker_dcef5d819f2bfc2c248202eac21dd770 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6b57f62548971fd7040a0e70cfb4d48b);
#
#
#         var popup_e4d8ef83b385c13bf74ac705a1e9999f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8a5f064c3081a52b48aaa74db8907ba = $(`&lt;div id=&quot;html_a8a5f064c3081a52b48aaa74db8907ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e4d8ef83b385c13bf74ac705a1e9999f.setContent(html_a8a5f064c3081a52b48aaa74db8907ba);
#
#
#
#         marker_dcef5d819f2bfc2c248202eac21dd770.bindPopup(popup_e4d8ef83b385c13bf74ac705a1e9999f)
#         ;
#
#
#
#
#             var marker_d15374c46efee3d063fe9e270b5af22b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6b57f62548971fd7040a0e70cfb4d48b);
#
#
#         var popup_fb2a419ea3a76f0ddf447c208ed573de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20570c0c03e43caf363bac91cb835d60 = $(`&lt;div id=&quot;html_20570c0c03e43caf363bac91cb835d60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fb2a419ea3a76f0ddf447c208ed573de.setContent(html_20570c0c03e43caf363bac91cb835d60);
#
#
#
#         marker_d15374c46efee3d063fe9e270b5af22b.bindPopup(popup_fb2a419ea3a76f0ddf447c208ed573de)
#         ;
#
#
#
#
#             var marker_c88d495164c75b38956b101b82830fde = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6b57f62548971fd7040a0e70cfb4d48b);
#
#
#         var popup_1322fdf5bded2f95b16e140008b7bf94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_056c128394c2153431eee594100b6324 = $(`&lt;div id=&quot;html_056c128394c2153431eee594100b6324&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1322fdf5bded2f95b16e140008b7bf94.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cf1f0ae84ebc063755822d735972abd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cf1f0ae84ebc063755822d735972abd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cf1f0ae84ebc063755822d735972abd = L.map(
#                 &quot;map_0cf1f0ae84ebc063755822d735972abd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d834edccc8ffc202f3eccd57d605867e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d834edccc8ffc202f3eccd57d605867e.addTo(map_0cf1f0ae84ebc063755822d735972abd);
#
#
#             var feature_group_09608bc037207f76dfdab8aaaf7e6f90 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7b9b9307347786cb4d4b48159f117e0b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_09608bc037207f76dfdab8aaaf7e6f90);
#
#
#         var popup_67e9dad5efbc041c30adb11a7081cb7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d906a97b0f44dc6131194efee1c50c6 = $(`&lt;div id=&quot;html_7d906a97b0f44dc6131194efee1c50c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_67e9dad5efbc041c30adb11a7081cb7a.setContent(html_7d906a97b0f44dc6131194efee1c50c6);
#
#
#
#         marker_7b9b9307347786cb4d4b48159f117e0b.bindPopup(popup_67e9dad5efbc041c30adb11a7081cb7a)
#         ;
#
#
#
#
#             var marker_ae3bff406a71cbc540ff834187b9cf1b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_09608bc037207f76dfdab8aaaf7e6f90);
#
#
#         var popup_1150976815dc46834ee12cd15cfa5d8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad5c8fe418117cf41cae0092487fad93 = $(`&lt;div id=&quot;html_ad5c8fe418117cf41cae0092487fad93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1150976815dc46834ee12cd15cfa5d8c.setContent(html_ad5c8fe418117cf41cae0092487fad93);
#
#
#
#         marker_ae3bff406a71cbc540ff834187b9cf1b.bindPopup(popup_1150976815dc46834ee12cd15cfa5d8c)
#         ;
#
#
#
#
#             var marker_96623b92587f0df97c0e983390979054 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_09608bc037207f76dfdab8aaaf7e6f90);
#
#
#         var popup_9d43f9420c375a3f8694b9c6eac0678b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68b75c5ebafd0db8867d2e4a5c6f71b4 = $(`&lt;div id=&quot;html_68b75c5ebafd0db8867d2e4a5c6f71b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9d43f9420c375a3f8694b9c6eac0678b.setContent(html_68b75c5ebafd0db8867d2e4a5c6f71b4);
#
#
#
#         marker_96623b92587f0df97c0e983390979054.bindPopup(popup_9d43f9420c375a3f8694b9c6eac0678b)
#         ;
#
#
#
#
#             var marker_b17c43b6145758ccdf9d36576722eb8e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_09608bc037207f76dfdab8aaaf7e6f90);
#
#
#         var popup_72af500fb547035eabafd16007ea460c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09a7467215ca034b6837bdb12478edc9 = $(`&lt;div id=&quot;html_09a7467215ca034b6837bdb12478edc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_72af500fb547035eabafd16007ea460c.setContent(html_09a7467215ca034b6837bdb12478edc9);
#
#
#
#         marker_b17c43b6145758ccdf9d36576722eb8e.bindPopup(popup_72af500fb547035eabafd16007ea460c)
#         ;
#
#
#
#
#             var marker_db4045cee5ddc0c328194e18af770fc4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_09608bc037207f76dfdab8aaaf7e6f90);
#
#
#         var popup_a4285d0699a9d06a2e59474bda87fe78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4368e92d9507536a78dc5a1cc854609 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4368e92d9507536a78dc5a1cc854609&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4368e92d9507536a78dc5a1cc854609 = L.map(
#                 &quot;map_b4368e92d9507536a78dc5a1cc854609&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_edd10fccba2f1528be5bbc2b8e9dd827 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_edd10fccba2f1528be5bbc2b8e9dd827.addTo(map_b4368e92d9507536a78dc5a1cc854609);
#
#
#             var feature_group_c09ed9f98fc57ea60c4683e63ab1bc57 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c09ed9f98fc57ea60c4683e63ab1bc57.addTo(map_b4368e92d9507536a78dc5a1cc854609);
#
#
#             var feature_group_sub_group_ae8812773c61c1c63b9fab0bcabf326d = L.featureGroup.subGroup(
#                 feature_group_c09ed9f98fc57ea60c4683e63ab1bc57
#             );
#
#
#             var marker_7b6a2d9835a5b5dbf156fcefae4a1350 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae8812773c61c1c63b9fab0bcabf326d);
#
#
#         var popup_b88db7abfcb96b09f6607afa2ea5c0f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_402f91ae64795592a209308a376822f9 = $(`&lt;div id=&quot;html_402f91ae64795592a209308a376822f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b88db7abfcb96b09f6607afa2ea5c0f1.setContent(html_402f91ae64795592a209308a376822f9);
#
#
#
#         marker_7b6a2d9835a5b5dbf156fcefae4a1350.bindPopup(popup_b88db7abfcb96b09f6607afa2ea5c0f1)
#         ;
#
#
#
#
#             var marker_8185797b171edec31be56a8be1d1fda4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae8812773c61c1c63b9fab0bcabf326d);
#
#
#         var popup_d938c0241b07e9452c4379f5d89a410f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6d19e9d89c14982f46d114f1aa2e313 = $(`&lt;div id=&quot;html_c6d19e9d89c14982f46d114f1aa2e313&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d938c0241b07e9452c4379f5d89a410f.setContent(html_c6d19e9d89c14982f46d114f1aa2e313);
#
#
#
#         marker_8185797b171edec31be56a8be1d1fda4.bindPopup(popup_d938c0241b07e9452c4379f5d89a410f)
#         ;
#
#
#
#
#             var marker_86c12bf916d554f2ffa68157b6485538 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae8812773c61c1c63b9fab0bcabf326d);
#
#
#         var popup_282b1385ae8442e33d982ceb32f6cd78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12e329b45fae295ce0fa3cf20a73fe8d = $(`&lt;div id=&quot;html_12e329b45fae295ce0fa3cf20a73fe8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_282b1385ae8442e33d982ceb32f6cd78.setContent(html_12e329b45fae295ce0fa3cf20a73fe8d);
#
#
#
#         marker_86c12bf916d554f2ffa68157b6485538.bindPopup(popup_282b1385ae8442e33d982ceb32f6cd78)
#         ;
#
#
#
#
#             var marker_c4528ba32b5fe53653d98cadb546724d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae8812773c61c1c63b9fab0bcabf326d);
#
#
#         var popup_255a143001426464146684a4296d56e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8a7922f7f612b066c757020300a7984 = $(`&lt;div id=&quot;html_c8a7922f7f612b066c757020300a7984&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_255a143001426464146684a4296d56e6.setContent(html_c8a7922f7f612b066c757020300a7984);
#
#
#
#         marker_
