# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc048896c655ddcf12552d79d8fc4a0f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc048896c655ddcf12552d79d8fc4a0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc048896c655ddcf12552d79d8fc4a0f = L.map(
#                 &quot;map_cc048896c655ddcf12552d79d8fc4a0f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e214b6d5c3dadc7195f34525c8568f13 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e214b6d5c3dadc7195f34525c8568f13.addTo(map_cc048896c655ddcf12552d79d8fc4a0f);
#
#
#             var marker_3f21a76c14dfb79d5a8cd4d89fa346f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cc048896c655ddcf12552d79d8fc4a0f);
#
#
#         var popup_44413e93655f608570152a28b1ab2594 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0102fc4e50fe91f3c3dd11e5e8ce37f3 = $(`&lt;div id=&quot;html_0102fc4e50fe91f3c3dd11e5e8ce37f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_44413e93655f608570152a28b1ab2594.setContent(html_0102fc4e50fe91f3c3dd11e5e8ce37f3);
#
#
#
#         marker_3f21a76c14dfb79d5a8cd4d89fa346f4.bindPopup(popup_44413e93655f608570152a28b1ab2594)
#         ;
#
#
#
#
#             var marker_048ac1a26460a42a8207132f87401dcc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cc048896c655ddcf12552d79d8fc4a0f);
#
#
#         var popup_9d59cac3298cd8c1c392e4000bc6b0de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0858d6430c2c4439794d126aa44f3e9f = $(`&lt;div id=&quot;html_0858d6430c2c4439794d126aa44f3e9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9d59cac3298cd8c1c392e4000bc6b0de.setContent(html_0858d6430c2c4439794d126aa44f3e9f);
#
#
#
#         marker_048ac1a26460a42a8207132f87401dcc.bindPopup(popup_9d59cac3298cd8c1c392e4000bc6b0de)
#         ;
#
#
#
#
#             var marker_eef7caa436bc63b302c096350f884e6b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cc048896c655ddcf12552d79d8fc4a0f);
#
#
#         var popup_92dc6acdeb9009f408601ad98f41ad95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e123d82a737b146a1900220054b3cd3 = $(`&lt;div id=&quot;html_5e123d82a737b146a1900220054b3cd3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_92dc6acdeb9009f408601ad98f41ad95.setContent(html_5e123d82a737b146a1900220054b3cd3);
#
#
#
#         marker_eef7caa436bc63b302c096350f884e6b.bindPopup(popup_92dc6acdeb9009f408601ad98f41ad95)
#         ;
#
#
#
#
#             var marker_6445086f3a8a42c60551ab16035fbad8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cc048896c655ddcf12552d79d8fc4a0f);
#
#
#         var popup_94b82fd8b0512faeeda3f1b21a2a3244 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed969d239d137be8d18e5c23fafa6074 = $(`&lt;div id=&quot;html_ed969d239d137be8d18e5c23fafa6074&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_94b82fd8b0512faeeda3f1b21a2a3244.setContent(html_ed969d239d137be8d18e5c23fafa6074);
#
#
#
#         marker_6445086f3a8a42c60551ab16035fbad8.bindPopup(popup_94b82fd8b0512faeeda3f1b21a2a3244)
#         ;
#
#
#
#
#             var marker_0050ee837445dbbfef9a9b7d457a2fc1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cc048896c655ddcf12552d79d8fc4a0f);
#
#
#         var popup_3c1b7967bc26753a7100a6ccf553a304 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98cf42061086eaa1794644511d998bf7 = $(`&lt;div id=&quot;html_98cf42061086eaa1794644511d998bf7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3c1b7967bc26753a7100a6ccf553a304.setContent(html_98cf42061086eaa1794644511d998bf7);
#
#
#
#         marker_0050ee837445dbbfef9a9b7d457a2fc1.bindPopup(popup_3c1b7967bc26753a7100a6ccf553a304)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe063a79da2b5e051081ab83aebc5c00 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe063a79da2b5e051081ab83aebc5c00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe063a79da2b5e051081ab83aebc5c00 = L.map(
#                 &quot;map_fe063a79da2b5e051081ab83aebc5c00&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98253906fd2cd9732c543084f39c4313 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_98253906fd2cd9732c543084f39c4313.addTo(map_fe063a79da2b5e051081ab83aebc5c00);
#
#
#             var feature_group_80272cfdfd5f716000cfa71f90904a09 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1724d1b67d42ba393b2064f84b3d0594 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_80272cfdfd5f716000cfa71f90904a09);
#
#
#         var popup_7a962dbe5a27abeb8bcbc9796c384a4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a414abcb63481a8448dacc73b4e3333a = $(`&lt;div id=&quot;html_a414abcb63481a8448dacc73b4e3333a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7a962dbe5a27abeb8bcbc9796c384a4d.setContent(html_a414abcb63481a8448dacc73b4e3333a);
#
#
#
#         marker_1724d1b67d42ba393b2064f84b3d0594.bindPopup(popup_7a962dbe5a27abeb8bcbc9796c384a4d)
#         ;
#
#
#
#
#             var marker_ecd3a91828d3e312225f9f7ec4b7eba6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_80272cfdfd5f716000cfa71f90904a09);
#
#
#         var popup_939bd2d784716bc26e8f362f1f447f54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbbcc55fde3791f6c52df37ab6f58cd1 = $(`&lt;div id=&quot;html_cbbcc55fde3791f6c52df37ab6f58cd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_939bd2d784716bc26e8f362f1f447f54.setContent(html_cbbcc55fde3791f6c52df37ab6f58cd1);
#
#
#
#         marker_ecd3a91828d3e312225f9f7ec4b7eba6.bindPopup(popup_939bd2d784716bc26e8f362f1f447f54)
#         ;
#
#
#
#
#             var marker_c14627507bde0f2cc637096b7d2ae636 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_80272cfdfd5f716000cfa71f90904a09);
#
#
#         var popup_2ba67103f4eed127d4218326fff33c0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db11bcd54730f9587f0368e2f4d4db24 = $(`&lt;div id=&quot;html_db11bcd54730f9587f0368e2f4d4db24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2ba67103f4eed127d4218326fff33c0a.setContent(html_db11bcd54730f9587f0368e2f4d4db24);
#
#
#
#         marker_c14627507bde0f2cc637096b7d2ae636.bindPopup(popup_2ba67103f4eed127d4218326fff33c0a)
#         ;
#
#
#
#
#             var marker_a3209e7b3f901b386844e8adf28fb331 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_80272cfdfd5f716000cfa71f90904a09);
#
#
#         var popup_5ba44f83dc6cd9d53ab3b8c44de53081 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f95db1ea0653e95653092af8a3eec909 = $(`&lt;div id=&quot;html_f95db1ea0653e95653092af8a3eec909&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5ba44f83dc6cd9d53ab3b8c44de53081.setContent(html_f95db1ea0653e95653092af8a3eec909);
#
#
#
#         marker_a3209e7b3f901b386844e8adf28fb331.bindPopup(popup_5ba44f83dc6cd9d53ab3b8c44de53081)
#         ;
#
#
#
#
#             var marker_6a13550ea2305d541e1e7f010d5e7988 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_80272cfdfd5f716000cfa71f90904a09);
#
#
#         var popup_e64f8505a22f663a0a8ec0c35f414933 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac661c38efeb8051adf53417f79b1d33 = $(`&lt;div id=&quot;html_ac661c38efeb8051adf53417f79b1d33&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bf757c283853c6e44a15f0dd80275f1f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bf757c283853c6e44a15f0dd80275f1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bf757c283853c6e44a15f0dd80275f1f = L.map(
#                 &quot;map_bf757c283853c6e44a15f0dd80275f1f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b9135f8bce5340ae33c80bded404f82 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b9135f8bce5340ae33c80bded404f82.addTo(map_bf757c283853c6e44a15f0dd80275f1f);
#
#
#             var feature_group_602f38f84420d9c26494a4794eebdd16 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_602f38f84420d9c26494a4794eebdd16.addTo(map_bf757c283853c6e44a15f0dd80275f1f);
#
#
#             var feature_group_sub_group_ba0b8fbb57d6e787db761400b4113252 = L.featureGroup.subGroup(
#                 feature_group_602f38f84420d9c26494a4794eebdd16
#             );
#
#
#             var marker_f4d4e1adeeb8c520fe61a67a81bc4d2b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba0b8fbb57d6e787db761400b4113252);
#
#
#         var popup_8cb427b86448a009ab8b839ab4386193 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f9fe71c6f9a987234b9ee7f5505af92 = $(`&lt;div id=&quot;html_7f9fe71c6f9a987234b9ee7f5505af92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8cb427b86448a009ab8b839ab4386193.setContent(html_7f9fe71c6f9a987234b9ee7f5505af92);
#
#
#
#         marker_f4d4e1adeeb8c520fe61a67a81bc4d2b.bindPopup(popup_8cb427b86448a009ab8b839ab4386193)
#         ;
#
#
#
#
#             var marker_776f2e1ba9b0595278bbd838c7bcc96d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba0b8fbb57d6e787db761400b4113252);
#
#
#         var popup_faf2af55bdc94a2e411eda53eedf86d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de0da63099bc4b6ed0257c08edb8d0db = $(`&lt;div id=&quot;html_de0da63099bc4b6ed0257c08edb8d0db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_faf2af55bdc94a2e411eda53eedf86d7.setContent(html_de0da63099bc4b6ed0257c08edb8d0db);
#
#
#
#         marker_776f2e1ba9b0595278bbd838c7bcc96d.bindPopup(popup_faf2af55bdc94a2e411eda53eedf86d7)
#         ;
#
#
#
#
#             var marker_9ed42f91df7e5a8b69099dbe2aa64b3f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba0b8fbb57d6e787db761400b4113252);
#
#
#         var popup_76c94f05fbf71520e6be65159cad94e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa5b0e4c24c9ea127b25b2cbc8d5b773 = $(`&lt;div id=&quot;html_aa5b0e4c24c9ea127b25b2cbc8d5b773&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_76c94f05fbf71520e6be65159cad94e4.setContent(html_aa5b0e4c24c9ea127b25b2cbc8d5b773);
#
#
#
#         marker_9ed42f91df7e5a8b69099dbe2aa64b3f.bindPopup(popup_76c94f05fbf71520e6be65159cad94e4)
#         ;
#
#
#
#
#             var marker_8f3ad01c7e4c9f2ec19769db20f08bc4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba0b8fbb57d6e787db761400b4113252);
#
#
#         var popup_f14508123c7a2d6bc09a061eaca30a17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfc3aafcdd97adf929f663a1288ca3de = $(`&lt;div id=&quot;html_dfc3aafcdd97adf929f663a1288ca3de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f14508123c7a2d6bc09a061eaca30a17.setContent(html_dfc3aafcdd97adf929f663a1288ca3de);
#
#
#
#         marker_8f3ad01c7e4c9f2ec19769db20f08bc4.bindPopup(popup_f14508123c7a2d6bc09a061eaca30a17)
#         ;
#
#
#
#
#             var marker_8a2e52b14bb62c012c55a6dbd6f03d96 = L.marker(
#                 [45.0503999
