# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_658b5df4dec28614192f798b12713d0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_658b5df4dec28614192f798b12713d0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_658b5df4dec28614192f798b12713d0d = L.map(
#                 &quot;map_658b5df4dec28614192f798b12713d0d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_50875d004b1b841c57ecc5f26f958bf5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_50875d004b1b841c57ecc5f26f958bf5.addTo(map_658b5df4dec28614192f798b12713d0d);
#
#
#             var marker_4282972d5cee177bac3155138a3e38df = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_658b5df4dec28614192f798b12713d0d);
#
#
#         var popup_1ab7fa07530e5f20914fe06f14b2ded0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8388e0497dc4c3e627f6b3afab885716 = $(`&lt;div id=&quot;html_8388e0497dc4c3e627f6b3afab885716&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1ab7fa07530e5f20914fe06f14b2ded0.setContent(html_8388e0497dc4c3e627f6b3afab885716);
#
#
#
#         marker_4282972d5cee177bac3155138a3e38df.bindPopup(popup_1ab7fa07530e5f20914fe06f14b2ded0)
#         ;
#
#
#
#
#             var marker_9e20b743268e2a2e1acb73c424bfe426 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_658b5df4dec28614192f798b12713d0d);
#
#
#         var popup_870703cab2a091031e0818866de94b1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d536175525c491a8f7fd0d37548734d2 = $(`&lt;div id=&quot;html_d536175525c491a8f7fd0d37548734d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_870703cab2a091031e0818866de94b1c.setContent(html_d536175525c491a8f7fd0d37548734d2);
#
#
#
#         marker_9e20b743268e2a2e1acb73c424bfe426.bindPopup(popup_870703cab2a091031e0818866de94b1c)
#         ;
#
#
#
#
#             var marker_5cd65a001de70e537644b93bfee74e21 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_658b5df4dec28614192f798b12713d0d);
#
#
#         var popup_abc19ec64fa1f09c3a86a46dbb852075 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bf63aeb1d636cf4a99cbfc03f5afb25 = $(`&lt;div id=&quot;html_7bf63aeb1d636cf4a99cbfc03f5afb25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_abc19ec64fa1f09c3a86a46dbb852075.setContent(html_7bf63aeb1d636cf4a99cbfc03f5afb25);
#
#
#
#         marker_5cd65a001de70e537644b93bfee74e21.bindPopup(popup_abc19ec64fa1f09c3a86a46dbb852075)
#         ;
#
#
#
#
#             var marker_412eacb763c89777ef6881cf763e1366 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_658b5df4dec28614192f798b12713d0d);
#
#
#         var popup_dda97d578e5b9a256ac9e0cab67a55e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bfcf8b71176f4461ea28bdc8a69b0b8 = $(`&lt;div id=&quot;html_1bfcf8b71176f4461ea28bdc8a69b0b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dda97d578e5b9a256ac9e0cab67a55e5.setContent(html_1bfcf8b71176f4461ea28bdc8a69b0b8);
#
#
#
#         marker_412eacb763c89777ef6881cf763e1366.bindPopup(popup_dda97d578e5b9a256ac9e0cab67a55e5)
#         ;
#
#
#
#
#             var marker_39d10bd84f92cbe827293fd0ca466139 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_658b5df4dec28614192f798b12713d0d);
#
#
#         var popup_4deecfac07c05da8f648583c84ccb035 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d572e9c3ba898cc39c6e657f0fb7085 = $(`&lt;div id=&quot;html_8d572e9c3ba898cc39c6e657f0fb7085&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4deecfac07c05da8f648583c84ccb035.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7739cb429d4d7cc75b2e9ede863e5197 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7739cb429d4d7cc75b2e9ede863e5197&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7739cb429d4d7cc75b2e9ede863e5197 = L.map(
#                 &quot;map_7739cb429d4d7cc75b2e9ede863e5197&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c7d274dae6c8030a1e872bfe32027076 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c7d274dae6c8030a1e872bfe32027076.addTo(map_7739cb429d4d7cc75b2e9ede863e5197);
#
#
#             var feature_group_68705575ba6189984a0344c45c5b5015 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_32fb3888cc18720b126dacc739a2614a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_68705575ba6189984a0344c45c5b5015);
#
#
#         var popup_f47ebbe5f90cb74329647e6b700adc55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6ea3b552c6326f3ea25773e4f4a8af1 = $(`&lt;div id=&quot;html_b6ea3b552c6326f3ea25773e4f4a8af1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f47ebbe5f90cb74329647e6b700adc55.setContent(html_b6ea3b552c6326f3ea25773e4f4a8af1);
#
#
#
#         marker_32fb3888cc18720b126dacc739a2614a.bindPopup(popup_f47ebbe5f90cb74329647e6b700adc55)
#         ;
#
#
#
#
#             var marker_d942a32e5c05319989d8fd04c6412972 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_68705575ba6189984a0344c45c5b5015);
#
#
#         var popup_951e7ac9fc73bab02022a5a51f5f1ce6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f88547bf02a09fb98d33deef5ba6031c = $(`&lt;div id=&quot;html_f88547bf02a09fb98d33deef5ba6031c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_951e7ac9fc73bab02022a5a51f5f1ce6.setContent(html_f88547bf02a09fb98d33deef5ba6031c);
#
#
#
#         marker_d942a32e5c05319989d8fd04c6412972.bindPopup(popup_951e7ac9fc73bab02022a5a51f5f1ce6)
#         ;
#
#
#
#
#             var marker_51aaf0b61dfa4fa74090c5acda79379f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_68705575ba6189984a0344c45c5b5015);
#
#
#         var popup_c831b04c57a721a904129280dbd52a53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_700eb2f95960ac8c9bde9938befb56c9 = $(`&lt;div id=&quot;html_700eb2f95960ac8c9bde9938befb56c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c831b04c57a721a904129280dbd52a53.setContent(html_700eb2f95960ac8c9bde9938befb56c9);
#
#
#
#         marker_51aaf0b61dfa4fa74090c5acda79379f.bindPopup(popup_c831b04c57a721a904129280dbd52a53)
#         ;
#
#
#
#
#             var marker_67330c075d67a56521db6d6e574f3bdf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_68705575ba6189984a0344c45c5b5015);
#
#
#         var popup_08e70ab67c7af7838251531960e70db2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b072ee4a110476f8f4dc1342b294d9a = $(`&lt;div id=&quot;html_0b072ee4a110476f8f4dc1342b294d9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_08e70ab67c7af7838251531960e70db2.setContent(html_0b072ee4a110476f8f4dc1342b294d9a);
#
#
#
#         marker_67330c075d67a56521db6d6e574f3bdf.bindPopup(popup_08e70ab67c7af7838251531960e70db2)
#         ;
#
#
#
#
#             var marker_bd6d6fe4cad85576c29089c1fab2f3e8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_68705575ba6189984a0344c45c5b5015);
#
#
#         var popup_4dbc340ef5a5e30ea5ebc3276f7c7935 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_957ee94f5494c8a34eed130f59f4b30d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_957ee94f5494c8a34eed130f59f4b30d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_957ee94f5494c8a34eed130f59f4b30d = L.map(
#                 &quot;map_957ee94f5494c8a34eed130f59f4b30d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9171a9e854bab1f619132e51e13bc47d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9171a9e854bab1f619132e51e13bc47d.addTo(map_957ee94f5494c8a34eed130f59f4b30d);
#
#
#             var feature_group_d7938c090f5299510977b28733130aac = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d7938c090f5299510977b28733130aac.addTo(map_957ee94f5494c8a34eed130f59f4b30d);
#
#
#             var feature_group_sub_group_acb23434427d5f7715717b1cff483ed4 = L.featureGroup.subGroup(
#                 feature_group_d7938c090f5299510977b28733130aac
#             );
#
#
#             var marker_8c9bb6642e1b55d70100e9faf954da01 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_acb23434427d5f7715717b1cff483ed4);
#
#
#         var popup_61655cb8b0833a67754a3f9ab7d29e5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8aa240edc1e11b0a10e37f1b31a679d = $(`&lt;div id=&quot;html_f8aa240edc1e11b0a10e37f1b31a679d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_61655cb8b0833a67754a3f9ab7d29e5c.setContent(html_f8aa240edc1e11b0a10e37f1b31a679d);
#
#
#
#         marker_8c9bb6642e1b55d70100e9faf954da01.bindPopup(popup_61655cb8b0833a67754a3f9ab7d29e5c)
#         ;
#
#
#
#
#             var marker_e0feef57d278a0522e6c909c22895682 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_acb23434427d5f7715717b1cff483ed4);
#
#
#         var popup_9732c98c6b11fa336f98880aa9d2ca9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f396b0d2cac9ed4a366fdde53e695b1e = $(`&lt;div id=&quot;html_f396b0d2cac9ed4a366fdde53e695b1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9732c98c6b11fa336f98880aa9d2ca9c.setContent(html_f396b0d2cac9ed4a366fdde53e695b1e);
#
#
#
#         marker_e0feef57d278a0522e6c909c22895682.bindPopup(popup_9732c98c6b11fa336f98880aa9d2ca9c)
#         ;
#
#
#
#
#             var marker_c55cb719f3e3b50a98a690fbfe7ae327 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_acb23434427d5f7715717b1cff483ed4);
#
#
#         var popup_304463f09f39fff953610a644dfad871 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_461d3ac8e049f0b278e7189a6d12ef98 = $(`&lt;div id=&quot;html_461d3ac8e049f0b278e7189a6d12ef98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_304463f09f39fff953610a644dfad871.setContent(html_461d3ac8e049f0b278e7189a6d12ef98);
#
#
#
#         marker_c55cb719f3e3b50a98a690fbfe7ae327.bindPopup(popup_304463f09f39fff953610a644dfad871)
#         ;
#
#
#
#
#             var marker_8bb85c8a3cde08ebec84b0863fc1ffcc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_acb23434427d5f7715717b1cff483ed4);
#
#
#         var popup_1ea0cacf68b381fe4fcdf24937053d4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51ffaca6a53d23f2ba5a274963c5cf83 = $(`&lt;div id=&quot;html_51ffaca6a53d23f2ba5a274963c5cf83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1ea0cacf68b381fe4fcdf24937053d4c.setContent(html_51ffaca6a53d23f2ba5a274963c5cf83);
#
#
#
#         marker_
