# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_986c8cf29aaf6ad6e33a69525f4495c2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_986c8cf29aaf6ad6e33a69525f4495c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_986c8cf29aaf6ad6e33a69525f4495c2 = L.map(
#                 &quot;map_986c8cf29aaf6ad6e33a69525f4495c2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e3481383b38453fbf5d96f67138b084 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e3481383b38453fbf5d96f67138b084.addTo(map_986c8cf29aaf6ad6e33a69525f4495c2);
#
#
#             var marker_2e8612c80f61e41dd563618725fc506d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_986c8cf29aaf6ad6e33a69525f4495c2);
#
#
#         var popup_ff90a95f3b16fded0da16585fcf671af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81425219820d3461d4d43e83a67551af = $(`&lt;div id=&quot;html_81425219820d3461d4d43e83a67551af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ff90a95f3b16fded0da16585fcf671af.setContent(html_81425219820d3461d4d43e83a67551af);
#
#
#
#         marker_2e8612c80f61e41dd563618725fc506d.bindPopup(popup_ff90a95f3b16fded0da16585fcf671af)
#         ;
#
#
#
#
#             var marker_c7610632364fabc7693d81808e04c199 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_986c8cf29aaf6ad6e33a69525f4495c2);
#
#
#         var popup_f5a7380d49420a7b3719eed0b89be5d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edd0ebb9849368ba0519e0eaef9629db = $(`&lt;div id=&quot;html_edd0ebb9849368ba0519e0eaef9629db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f5a7380d49420a7b3719eed0b89be5d7.setContent(html_edd0ebb9849368ba0519e0eaef9629db);
#
#
#
#         marker_c7610632364fabc7693d81808e04c199.bindPopup(popup_f5a7380d49420a7b3719eed0b89be5d7)
#         ;
#
#
#
#
#             var marker_23d1c9037474d179d0513a7f6e402b09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_986c8cf29aaf6ad6e33a69525f4495c2);
#
#
#         var popup_9543319516b2b3119d4e2dc2d92e7cd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8366016a46c5499d16100981db6d69cc = $(`&lt;div id=&quot;html_8366016a46c5499d16100981db6d69cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9543319516b2b3119d4e2dc2d92e7cd4.setContent(html_8366016a46c5499d16100981db6d69cc);
#
#
#
#         marker_23d1c9037474d179d0513a7f6e402b09.bindPopup(popup_9543319516b2b3119d4e2dc2d92e7cd4)
#         ;
#
#
#
#
#             var marker_841ad60ecc990e8bb02cf610466f4d56 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_986c8cf29aaf6ad6e33a69525f4495c2);
#
#
#         var popup_96dd9a376d9bb2a7ff1a4cfa3e53ffee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_143240a8f8c2a4c8c9031ae5cd067a28 = $(`&lt;div id=&quot;html_143240a8f8c2a4c8c9031ae5cd067a28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_96dd9a376d9bb2a7ff1a4cfa3e53ffee.setContent(html_143240a8f8c2a4c8c9031ae5cd067a28);
#
#
#
#         marker_841ad60ecc990e8bb02cf610466f4d56.bindPopup(popup_96dd9a376d9bb2a7ff1a4cfa3e53ffee)
#         ;
#
#
#
#
#             var marker_c32393d38ee07aa213230bc2b97a2048 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_986c8cf29aaf6ad6e33a69525f4495c2);
#
#
#         var popup_8617c10b955de57059f91186e3ff87f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0826d6f73a126e959e32f27abe80d6c2 = $(`&lt;div id=&quot;html_0826d6f73a126e959e32f27abe80d6c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8617c10b955de57059f91186e3ff87f9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca64667ff077e70289e1bb77e584bd6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca64667ff077e70289e1bb77e584bd6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca64667ff077e70289e1bb77e584bd6a = L.map(
#                 &quot;map_ca64667ff077e70289e1bb77e584bd6a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9d5b5eac56dcbe4e206ba92909e92af4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9d5b5eac56dcbe4e206ba92909e92af4.addTo(map_ca64667ff077e70289e1bb77e584bd6a);
#
#
#             var feature_group_d575472c400459335e966a1fa5d43dd4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2c24ab54aa2561d5dbe7b5ce5f4fa219 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d575472c400459335e966a1fa5d43dd4);
#
#
#         var popup_6f37f8844986f079d52c86825b397839 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6e1d0dd74380eb860375aff57b8fad8 = $(`&lt;div id=&quot;html_c6e1d0dd74380eb860375aff57b8fad8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6f37f8844986f079d52c86825b397839.setContent(html_c6e1d0dd74380eb860375aff57b8fad8);
#
#
#
#         marker_2c24ab54aa2561d5dbe7b5ce5f4fa219.bindPopup(popup_6f37f8844986f079d52c86825b397839)
#         ;
#
#
#
#
#             var marker_25623640afe6fe49e52a485924c4ce13 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d575472c400459335e966a1fa5d43dd4);
#
#
#         var popup_3502a16cdb1dbed2e21529b9fbf44834 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9fbcd4945154fc8a02803b8d91d3d19 = $(`&lt;div id=&quot;html_a9fbcd4945154fc8a02803b8d91d3d19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3502a16cdb1dbed2e21529b9fbf44834.setContent(html_a9fbcd4945154fc8a02803b8d91d3d19);
#
#
#
#         marker_25623640afe6fe49e52a485924c4ce13.bindPopup(popup_3502a16cdb1dbed2e21529b9fbf44834)
#         ;
#
#
#
#
#             var marker_f4a420eb382353c2d931605c4285ae5a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d575472c400459335e966a1fa5d43dd4);
#
#
#         var popup_279c315888793c63dc5695f3ffad4167 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_402cf5daf21dfb3a3d5290633837222f = $(`&lt;div id=&quot;html_402cf5daf21dfb3a3d5290633837222f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_279c315888793c63dc5695f3ffad4167.setContent(html_402cf5daf21dfb3a3d5290633837222f);
#
#
#
#         marker_f4a420eb382353c2d931605c4285ae5a.bindPopup(popup_279c315888793c63dc5695f3ffad4167)
#         ;
#
#
#
#
#             var marker_db9e5e9e6a445f668c89bfef3d03f2a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d575472c400459335e966a1fa5d43dd4);
#
#
#         var popup_c841b479c34652a3d6b20028bef27939 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c38cf01977aea67d55af2deea590af23 = $(`&lt;div id=&quot;html_c38cf01977aea67d55af2deea590af23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c841b479c34652a3d6b20028bef27939.setContent(html_c38cf01977aea67d55af2deea590af23);
#
#
#
#         marker_db9e5e9e6a445f668c89bfef3d03f2a3.bindPopup(popup_c841b479c34652a3d6b20028bef27939)
#         ;
#
#
#
#
#             var marker_4217a265ad3a0eacb414c09ed10b52b8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d575472c400459335e966a1fa5d43dd4);
#
#
#         var popup_f019224554f6e1f198265aa430c6ea9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_816d57b810059aaae971c344993cff59 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_816d57b810059aaae971c344993cff59&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_816d57b810059aaae971c344993cff59 = L.map(
#                 &quot;map_816d57b810059aaae971c344993cff59&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cabb648eacbed4d558aa3f8f8e9d7f0d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cabb648eacbed4d558aa3f8f8e9d7f0d.addTo(map_816d57b810059aaae971c344993cff59);
#
#
#             var feature_group_d6998d70336f769cbe308ddfac92c14d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d6998d70336f769cbe308ddfac92c14d.addTo(map_816d57b810059aaae971c344993cff59);
#
#
#             var feature_group_sub_group_fcaec81a754db451b423e1e8a4c85bdb = L.featureGroup.subGroup(
#                 feature_group_d6998d70336f769cbe308ddfac92c14d
#             );
#
#
#             var marker_0daabd545c01e66ef5be72e88d10a5c4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_fcaec81a754db451b423e1e8a4c85bdb);
#
#
#         var popup_40024448492cc55dad0e4c9053daf530 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e893f764f1860ea4843dd1cc5b26658 = $(`&lt;div id=&quot;html_5e893f764f1860ea4843dd1cc5b26658&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_40024448492cc55dad0e4c9053daf530.setContent(html_5e893f764f1860ea4843dd1cc5b26658);
#
#
#
#         marker_0daabd545c01e66ef5be72e88d10a5c4.bindPopup(popup_40024448492cc55dad0e4c9053daf530)
#         ;
#
#
#
#
#             var marker_f0389b43cd2d07841fcdb3001a24d0ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_fcaec81a754db451b423e1e8a4c85bdb);
#
#
#         var popup_94fe2f39f8d92d008d20ca292c82830d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf0b61b4bc33cc9824bfafbaea7a1064 = $(`&lt;div id=&quot;html_cf0b61b4bc33cc9824bfafbaea7a1064&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_94fe2f39f8d92d008d20ca292c82830d.setContent(html_cf0b61b4bc33cc9824bfafbaea7a1064);
#
#
#
#         marker_f0389b43cd2d07841fcdb3001a24d0ed.bindPopup(popup_94fe2f39f8d92d008d20ca292c82830d)
#         ;
#
#
#
#
#             var marker_019ebcc1919c36acc96a54469e969442 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_fcaec81a754db451b423e1e8a4c85bdb);
#
#
#         var popup_5a74cb7bb353f23baf52965646cf5f60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c277f87b5415e5d6e3bc928ecd0be1dd = $(`&lt;div id=&quot;html_c277f87b5415e5d6e3bc928ecd0be1dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5a74cb7bb353f23baf52965646cf5f60.setContent(html_c277f87b5415e5d6e3bc928ecd0be1dd);
#
#
#
#         marker_019ebcc1919c36acc96a54469e969442.bindPopup(popup_5a74cb7bb353f23baf52965646cf5f60)
#         ;
#
#
#
#
#             var marker_71ab985d09d97f8f951a1c0c49418096 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_fcaec81a754db451b423e1e8a4c85bdb);
#
#
#         var popup_7a52a0c28e773022c3da78c552e68c83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_366ae67c84bd157b736b19ae2fb3a104 = $(`&lt;div id=&quot;html_366ae67c84bd157b736b19ae2fb3a104&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7a52a0c28e773022c3da78c552e68c83.setContent(html_366ae67c84bd157b736b19ae2fb3a104);
#
#
#
#         marker_
