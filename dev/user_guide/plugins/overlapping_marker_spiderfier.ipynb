# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bac937ce0aabaf9ac1ed1ad173453945 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bac937ce0aabaf9ac1ed1ad173453945&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bac937ce0aabaf9ac1ed1ad173453945 = L.map(
#                 &quot;map_bac937ce0aabaf9ac1ed1ad173453945&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6a31fdc556acced569979f999173246b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6a31fdc556acced569979f999173246b.addTo(map_bac937ce0aabaf9ac1ed1ad173453945);
#
#
#             var marker_d6ebfdb7310c0f193ff515b57a2abccf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bac937ce0aabaf9ac1ed1ad173453945);
#
#
#         var popup_322b5261a7f00d76c3a736a36e66cd2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_370aaac08f2b0f8be76d4a81c7f528a2 = $(`&lt;div id=&quot;html_370aaac08f2b0f8be76d4a81c7f528a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_322b5261a7f00d76c3a736a36e66cd2f.setContent(html_370aaac08f2b0f8be76d4a81c7f528a2);
#
#
#
#         marker_d6ebfdb7310c0f193ff515b57a2abccf.bindPopup(popup_322b5261a7f00d76c3a736a36e66cd2f)
#         ;
#
#
#
#
#             var marker_bba3b3df908af4a46a983be0f14ca1bc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bac937ce0aabaf9ac1ed1ad173453945);
#
#
#         var popup_594e064f4c9ec73b542b19dffb6d4447 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c215593264bde8c5c3a9cc3dc2c7d4a = $(`&lt;div id=&quot;html_1c215593264bde8c5c3a9cc3dc2c7d4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_594e064f4c9ec73b542b19dffb6d4447.setContent(html_1c215593264bde8c5c3a9cc3dc2c7d4a);
#
#
#
#         marker_bba3b3df908af4a46a983be0f14ca1bc.bindPopup(popup_594e064f4c9ec73b542b19dffb6d4447)
#         ;
#
#
#
#
#             var marker_dbf57b3923b3c7b5a3ef2fccf9e09441 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bac937ce0aabaf9ac1ed1ad173453945);
#
#
#         var popup_a41ad8ccc731bd21ec1e5ab5ba855508 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_036133c3b3fc5f3bc99a60a17a1fb3d2 = $(`&lt;div id=&quot;html_036133c3b3fc5f3bc99a60a17a1fb3d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a41ad8ccc731bd21ec1e5ab5ba855508.setContent(html_036133c3b3fc5f3bc99a60a17a1fb3d2);
#
#
#
#         marker_dbf57b3923b3c7b5a3ef2fccf9e09441.bindPopup(popup_a41ad8ccc731bd21ec1e5ab5ba855508)
#         ;
#
#
#
#
#             var marker_787a05af75e29db54c3ad8fa724c91ab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bac937ce0aabaf9ac1ed1ad173453945);
#
#
#         var popup_5c0452d44ae3c5ca796ed7b6d37fd50f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bddb1dd81bb5e55bacd44dac8ec4711 = $(`&lt;div id=&quot;html_7bddb1dd81bb5e55bacd44dac8ec4711&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5c0452d44ae3c5ca796ed7b6d37fd50f.setContent(html_7bddb1dd81bb5e55bacd44dac8ec4711);
#
#
#
#         marker_787a05af75e29db54c3ad8fa724c91ab.bindPopup(popup_5c0452d44ae3c5ca796ed7b6d37fd50f)
#         ;
#
#
#
#
#             var marker_260aea665298f99dde4ac6c8a14c309f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bac937ce0aabaf9ac1ed1ad173453945);
#
#
#         var popup_88cef5e370e956930ea47ef3df8b0bc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1108892faad9ac350c47dbe3dc6e2fd6 = $(`&lt;div id=&quot;html_1108892faad9ac350c47dbe3dc6e2fd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_88cef5e370e956930ea47ef3df8b0bc0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2b0af7319d070d93862ecbde3d4f475 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2b0af7319d070d93862ecbde3d4f475&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2b0af7319d070d93862ecbde3d4f475 = L.map(
#                 &quot;map_a2b0af7319d070d93862ecbde3d4f475&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2316bc399207119d452eac8b4e5cd7e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a2316bc399207119d452eac8b4e5cd7e.addTo(map_a2b0af7319d070d93862ecbde3d4f475);
#
#
#             var feature_group_acbe1bb398eccacd0ae7405afd3008fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9dacdd00ab799d74cc22589c4d5c13ce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_acbe1bb398eccacd0ae7405afd3008fe);
#
#
#         var popup_9436d8f6c2edad4aa71f44f80097d009 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce5393b86585632a09f395575903722c = $(`&lt;div id=&quot;html_ce5393b86585632a09f395575903722c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9436d8f6c2edad4aa71f44f80097d009.setContent(html_ce5393b86585632a09f395575903722c);
#
#
#
#         marker_9dacdd00ab799d74cc22589c4d5c13ce.bindPopup(popup_9436d8f6c2edad4aa71f44f80097d009)
#         ;
#
#
#
#
#             var marker_a8b7c02a6bd6a48a2efee5b0e0cb0835 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_acbe1bb398eccacd0ae7405afd3008fe);
#
#
#         var popup_4e2f046073b3b3b6f2c7ec053071e8af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9bf15a83f1e21a7f5d7decb842b76ba = $(`&lt;div id=&quot;html_f9bf15a83f1e21a7f5d7decb842b76ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4e2f046073b3b3b6f2c7ec053071e8af.setContent(html_f9bf15a83f1e21a7f5d7decb842b76ba);
#
#
#
#         marker_a8b7c02a6bd6a48a2efee5b0e0cb0835.bindPopup(popup_4e2f046073b3b3b6f2c7ec053071e8af)
#         ;
#
#
#
#
#             var marker_b5621ea480fd5580a659d110f41ea2a9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_acbe1bb398eccacd0ae7405afd3008fe);
#
#
#         var popup_8d96172c25b903c4fdec57b2b36b6d0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef8cf29306fc7dbeb3648df8807e5245 = $(`&lt;div id=&quot;html_ef8cf29306fc7dbeb3648df8807e5245&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8d96172c25b903c4fdec57b2b36b6d0d.setContent(html_ef8cf29306fc7dbeb3648df8807e5245);
#
#
#
#         marker_b5621ea480fd5580a659d110f41ea2a9.bindPopup(popup_8d96172c25b903c4fdec57b2b36b6d0d)
#         ;
#
#
#
#
#             var marker_b221365a40f6b6aabea78e2c9129cd2f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_acbe1bb398eccacd0ae7405afd3008fe);
#
#
#         var popup_1ffee3ae627d2cafbe0555b9c44d6df7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca60ce989a9f6eb642a334724ba7a7df = $(`&lt;div id=&quot;html_ca60ce989a9f6eb642a334724ba7a7df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1ffee3ae627d2cafbe0555b9c44d6df7.setContent(html_ca60ce989a9f6eb642a334724ba7a7df);
#
#
#
#         marker_b221365a40f6b6aabea78e2c9129cd2f.bindPopup(popup_1ffee3ae627d2cafbe0555b9c44d6df7)
#         ;
#
#
#
#
#             var marker_1c16447ab0f25ef4f32a3ccdfcbc014d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_acbe1bb398eccacd0ae7405afd3008fe);
#
#
#         var popup_ddbf20a7474f830fc9d822187e5010fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1561d660e2c49fcae655bf684ace02e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1561d660e2c49fcae655bf684ace02e1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1561d660e2c49fcae655bf684ace02e1 = L.map(
#                 &quot;map_1561d660e2c49fcae655bf684ace02e1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec6d071e9420e862de3736761f9a195f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec6d071e9420e862de3736761f9a195f.addTo(map_1561d660e2c49fcae655bf684ace02e1);
#
#
#             var feature_group_c3dec1a25447a7ed0522bbd88ff6159d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c3dec1a25447a7ed0522bbd88ff6159d.addTo(map_1561d660e2c49fcae655bf684ace02e1);
#
#
#             var feature_group_sub_group_df303bdd18e87756879694746c77b178 = L.featureGroup.subGroup(
#                 feature_group_c3dec1a25447a7ed0522bbd88ff6159d
#             );
#
#
#             var marker_4c6e2a18d4a0ec8397772841a78578b9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_df303bdd18e87756879694746c77b178);
#
#
#         var popup_f29bab75f04a78d46f44573f2c84e7da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec6ab3ae938f2d93b420130651278ec9 = $(`&lt;div id=&quot;html_ec6ab3ae938f2d93b420130651278ec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f29bab75f04a78d46f44573f2c84e7da.setContent(html_ec6ab3ae938f2d93b420130651278ec9);
#
#
#
#         marker_4c6e2a18d4a0ec8397772841a78578b9.bindPopup(popup_f29bab75f04a78d46f44573f2c84e7da)
#         ;
#
#
#
#
#             var marker_6175f59760e48bb38307b1682c2cb15e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_df303bdd18e87756879694746c77b178);
#
#
#         var popup_37529fea4036e510e31d8f08fc0cd555 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5186884417bb6bb91a5bf004655ebe3 = $(`&lt;div id=&quot;html_c5186884417bb6bb91a5bf004655ebe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_37529fea4036e510e31d8f08fc0cd555.setContent(html_c5186884417bb6bb91a5bf004655ebe3);
#
#
#
#         marker_6175f59760e48bb38307b1682c2cb15e.bindPopup(popup_37529fea4036e510e31d8f08fc0cd555)
#         ;
#
#
#
#
#             var marker_8fb87585c818b580cf3b146e14ad387e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_df303bdd18e87756879694746c77b178);
#
#
#         var popup_e1958017ede45d3ed7d7f73fcd88cf37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fc4e5697a4d6f82c678a00ef1a61420 = $(`&lt;div id=&quot;html_9fc4e5697a4d6f82c678a00ef1a61420&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e1958017ede45d3ed7d7f73fcd88cf37.setContent(html_9fc4e5697a4d6f82c678a00ef1a61420);
#
#
#
#         marker_8fb87585c818b580cf3b146e14ad387e.bindPopup(popup_e1958017ede45d3ed7d7f73fcd88cf37)
#         ;
#
#
#
#
#             var marker_35f122c11254b6bbe69c41e83df0326d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_df303bdd18e87756879694746c77b178);
#
#
#         var popup_09305cd6e5c3ebd3f2c6874b3714bb5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0dbe00fa970b6fe2790e73fb1923617f = $(`&lt;div id=&quot;html_0dbe00fa970b6fe2790e73fb1923617f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_09305cd6e5c3ebd3f2c6874b3714bb5b.setContent(html_0dbe00fa970b6fe2790e73fb1923617f);
#
#
#
#         marker_
