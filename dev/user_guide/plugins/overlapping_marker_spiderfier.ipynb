# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd51ff265192878df48fe2cbdf259ad1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd51ff265192878df48fe2cbdf259ad1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd51ff265192878df48fe2cbdf259ad1 = L.map(
#                 &quot;map_bd51ff265192878df48fe2cbdf259ad1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62d40e3d40cb388af31abad5925d70a4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62d40e3d40cb388af31abad5925d70a4.addTo(map_bd51ff265192878df48fe2cbdf259ad1);
#
#
#             var marker_600c693c22474c885c0c3ef7f5b7f89d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bd51ff265192878df48fe2cbdf259ad1);
#
#
#         var popup_8872187a14863e252258abcf1cba0f01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d56d5c684e0eba4c4a015a150b711ab = $(`&lt;div id=&quot;html_2d56d5c684e0eba4c4a015a150b711ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8872187a14863e252258abcf1cba0f01.setContent(html_2d56d5c684e0eba4c4a015a150b711ab);
#
#
#
#         marker_600c693c22474c885c0c3ef7f5b7f89d.bindPopup(popup_8872187a14863e252258abcf1cba0f01)
#         ;
#
#
#
#
#             var marker_9195a3dc9442d750cee0fea76de2b535 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bd51ff265192878df48fe2cbdf259ad1);
#
#
#         var popup_4ce20992549e7bca1b371abf727a3aa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8aa6312ca3ecd313d6cb29916b64ceac = $(`&lt;div id=&quot;html_8aa6312ca3ecd313d6cb29916b64ceac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4ce20992549e7bca1b371abf727a3aa8.setContent(html_8aa6312ca3ecd313d6cb29916b64ceac);
#
#
#
#         marker_9195a3dc9442d750cee0fea76de2b535.bindPopup(popup_4ce20992549e7bca1b371abf727a3aa8)
#         ;
#
#
#
#
#             var marker_969e951642b4494066caf1c11e2ca8c5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bd51ff265192878df48fe2cbdf259ad1);
#
#
#         var popup_1f162d3b1f0d63fa5cecc5d283c93c3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0406f0ba5ea4bdf74a7ca83fb115ff9 = $(`&lt;div id=&quot;html_f0406f0ba5ea4bdf74a7ca83fb115ff9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1f162d3b1f0d63fa5cecc5d283c93c3a.setContent(html_f0406f0ba5ea4bdf74a7ca83fb115ff9);
#
#
#
#         marker_969e951642b4494066caf1c11e2ca8c5.bindPopup(popup_1f162d3b1f0d63fa5cecc5d283c93c3a)
#         ;
#
#
#
#
#             var marker_3a66551b9a3a6d18c29c18b3889e6b45 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bd51ff265192878df48fe2cbdf259ad1);
#
#
#         var popup_dce75fdd66eb4fefc4d5785e02d2b4fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7961fc26738f21ed3c44d5d515d7f8bf = $(`&lt;div id=&quot;html_7961fc26738f21ed3c44d5d515d7f8bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dce75fdd66eb4fefc4d5785e02d2b4fe.setContent(html_7961fc26738f21ed3c44d5d515d7f8bf);
#
#
#
#         marker_3a66551b9a3a6d18c29c18b3889e6b45.bindPopup(popup_dce75fdd66eb4fefc4d5785e02d2b4fe)
#         ;
#
#
#
#
#             var marker_1f74535900b05c9b135a91241d6cd696 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bd51ff265192878df48fe2cbdf259ad1);
#
#
#         var popup_fe1aaabf0f24d183fd50802107125924 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b95b16b1269a56c4950c23453e84259 = $(`&lt;div id=&quot;html_8b95b16b1269a56c4950c23453e84259&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fe1aaabf0f24d183fd50802107125924.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c3b9ac39b9228d061b7ca85155271eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c3b9ac39b9228d061b7ca85155271eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c3b9ac39b9228d061b7ca85155271eb = L.map(
#                 &quot;map_5c3b9ac39b9228d061b7ca85155271eb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d84aa9e78b3e733ef1913b0f071ef769 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d84aa9e78b3e733ef1913b0f071ef769.addTo(map_5c3b9ac39b9228d061b7ca85155271eb);
#
#
#             var feature_group_9e2df523fa17080b18b1a477658885ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8e6968941fb2a1ccb6ba0b49f97c0533 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9e2df523fa17080b18b1a477658885ac);
#
#
#         var popup_e8aef133e4eba7ea4d72d968041bde72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01ff1c3cb6a449c2a6fcf73745252ba1 = $(`&lt;div id=&quot;html_01ff1c3cb6a449c2a6fcf73745252ba1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e8aef133e4eba7ea4d72d968041bde72.setContent(html_01ff1c3cb6a449c2a6fcf73745252ba1);
#
#
#
#         marker_8e6968941fb2a1ccb6ba0b49f97c0533.bindPopup(popup_e8aef133e4eba7ea4d72d968041bde72)
#         ;
#
#
#
#
#             var marker_de2b398a716429e8813bfeae800eae88 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9e2df523fa17080b18b1a477658885ac);
#
#
#         var popup_4d6a5f497df28b7dd5c0808d7c8b387c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5edd73118d588a0e2812a6ad99f18ebc = $(`&lt;div id=&quot;html_5edd73118d588a0e2812a6ad99f18ebc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4d6a5f497df28b7dd5c0808d7c8b387c.setContent(html_5edd73118d588a0e2812a6ad99f18ebc);
#
#
#
#         marker_de2b398a716429e8813bfeae800eae88.bindPopup(popup_4d6a5f497df28b7dd5c0808d7c8b387c)
#         ;
#
#
#
#
#             var marker_97a20321d530cad08e93dc1ab5b0c5ea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9e2df523fa17080b18b1a477658885ac);
#
#
#         var popup_b6cfdf09b649bb000ec84073e6877a1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b12373e973ff17891873a763797c701 = $(`&lt;div id=&quot;html_5b12373e973ff17891873a763797c701&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b6cfdf09b649bb000ec84073e6877a1a.setContent(html_5b12373e973ff17891873a763797c701);
#
#
#
#         marker_97a20321d530cad08e93dc1ab5b0c5ea.bindPopup(popup_b6cfdf09b649bb000ec84073e6877a1a)
#         ;
#
#
#
#
#             var marker_efb16b0b5e34dc75404591dd7b5bea8c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9e2df523fa17080b18b1a477658885ac);
#
#
#         var popup_6a4c9081c1262eb31b7ecc93999b6f37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_054b717fdf4b57e043e125a787cf2057 = $(`&lt;div id=&quot;html_054b717fdf4b57e043e125a787cf2057&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6a4c9081c1262eb31b7ecc93999b6f37.setContent(html_054b717fdf4b57e043e125a787cf2057);
#
#
#
#         marker_efb16b0b5e34dc75404591dd7b5bea8c.bindPopup(popup_6a4c9081c1262eb31b7ecc93999b6f37)
#         ;
#
#
#
#
#             var marker_bbf2050ac6b2164ae0bd878c81c53038 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9e2df523fa17080b18b1a477658885ac);
#
#
#         var popup_57902558fe2cc02c9d921dab336113b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1dcf22db4f8db41feb39986bcc357930 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1dcf22db4f8db41feb39986bcc357930&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1dcf22db4f8db41feb39986bcc357930 = L.map(
#                 &quot;map_1dcf22db4f8db41feb39986bcc357930&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da96af568969f9c01e860c6ea5a998c5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da96af568969f9c01e860c6ea5a998c5.addTo(map_1dcf22db4f8db41feb39986bcc357930);
#
#
#             var feature_group_65c216fc30b8619542db80325aa2c118 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_65c216fc30b8619542db80325aa2c118.addTo(map_1dcf22db4f8db41feb39986bcc357930);
#
#
#             var feature_group_sub_group_755f4cb595475ab4bc27200427063143 = L.featureGroup.subGroup(
#                 feature_group_65c216fc30b8619542db80325aa2c118
#             );
#
#
#             var marker_451f7f89b8b1a5eb32eb963de09b378f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_755f4cb595475ab4bc27200427063143);
#
#
#         var popup_557a498cd04a169eee24f0e4d52c2d24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c3416cdb5d2b9ecb845060bdd391d42 = $(`&lt;div id=&quot;html_6c3416cdb5d2b9ecb845060bdd391d42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_557a498cd04a169eee24f0e4d52c2d24.setContent(html_6c3416cdb5d2b9ecb845060bdd391d42);
#
#
#
#         marker_451f7f89b8b1a5eb32eb963de09b378f.bindPopup(popup_557a498cd04a169eee24f0e4d52c2d24)
#         ;
#
#
#
#
#             var marker_9a44cefaa6961532b51f8c8b13ae277a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_755f4cb595475ab4bc27200427063143);
#
#
#         var popup_609b4497377dcffc8222c044eeb2c22b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff046107362408fa3db6579d8b8f5b5f = $(`&lt;div id=&quot;html_ff046107362408fa3db6579d8b8f5b5f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_609b4497377dcffc8222c044eeb2c22b.setContent(html_ff046107362408fa3db6579d8b8f5b5f);
#
#
#
#         marker_9a44cefaa6961532b51f8c8b13ae277a.bindPopup(popup_609b4497377dcffc8222c044eeb2c22b)
#         ;
#
#
#
#
#             var marker_847647396d06f68afe0f6361b210f37b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_755f4cb595475ab4bc27200427063143);
#
#
#         var popup_ed53aa0671d9f91729f02cea8f776d7d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c29d456f9278c77be8974741ec6055c = $(`&lt;div id=&quot;html_5c29d456f9278c77be8974741ec6055c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ed53aa0671d9f91729f02cea8f776d7d.setContent(html_5c29d456f9278c77be8974741ec6055c);
#
#
#
#         marker_847647396d06f68afe0f6361b210f37b.bindPopup(popup_ed53aa0671d9f91729f02cea8f776d7d)
#         ;
#
#
#
#
#             var marker_8fb7542aa4a415b65bd4f79da58517ba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_755f4cb595475ab4bc27200427063143);
#
#
#         var popup_ee2f112f1ab9938553965d59d9f991eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50854396ec0622d4fce52bf68b9413f3 = $(`&lt;div id=&quot;html_50854396ec0622d4fce52bf68b9413f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ee2f112f1ab9938553965d59d9f991eb.setContent(html_50854396ec0622d4fce52bf68b9413f3);
#
#
#
#         marker_
