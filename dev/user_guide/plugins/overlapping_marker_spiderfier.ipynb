# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_950dfd4f89ea133f0b6a666702e14a6a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_950dfd4f89ea133f0b6a666702e14a6a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_950dfd4f89ea133f0b6a666702e14a6a = L.map(
#                 &quot;map_950dfd4f89ea133f0b6a666702e14a6a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d99b7af1483fa89b35ff7eeb1a578347 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d99b7af1483fa89b35ff7eeb1a578347.addTo(map_950dfd4f89ea133f0b6a666702e14a6a);
#
#
#             var marker_36e6414b395e4efad637abae791f566d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_950dfd4f89ea133f0b6a666702e14a6a);
#
#
#         var popup_f8d4942b1343070eaa6c20589a81a390 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_316cc99f1eabfde887c1975474e01276 = $(`&lt;div id=&quot;html_316cc99f1eabfde887c1975474e01276&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f8d4942b1343070eaa6c20589a81a390.setContent(html_316cc99f1eabfde887c1975474e01276);
#
#
#
#         marker_36e6414b395e4efad637abae791f566d.bindPopup(popup_f8d4942b1343070eaa6c20589a81a390)
#         ;
#
#
#
#
#             var marker_56e2d015826ee29cd68d7691d6c405c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_950dfd4f89ea133f0b6a666702e14a6a);
#
#
#         var popup_bcfc27411fccd0c310451caaeb76a01e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36f71c0b4694a0075cec7d3eb2aebebe = $(`&lt;div id=&quot;html_36f71c0b4694a0075cec7d3eb2aebebe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bcfc27411fccd0c310451caaeb76a01e.setContent(html_36f71c0b4694a0075cec7d3eb2aebebe);
#
#
#
#         marker_56e2d015826ee29cd68d7691d6c405c4.bindPopup(popup_bcfc27411fccd0c310451caaeb76a01e)
#         ;
#
#
#
#
#             var marker_a7681e7660634aeae91274548729caac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_950dfd4f89ea133f0b6a666702e14a6a);
#
#
#         var popup_48582bb5f0f8514d142749d38de1b7e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_515f05898e92d8b3e0eecd69a3b6a7d5 = $(`&lt;div id=&quot;html_515f05898e92d8b3e0eecd69a3b6a7d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_48582bb5f0f8514d142749d38de1b7e4.setContent(html_515f05898e92d8b3e0eecd69a3b6a7d5);
#
#
#
#         marker_a7681e7660634aeae91274548729caac.bindPopup(popup_48582bb5f0f8514d142749d38de1b7e4)
#         ;
#
#
#
#
#             var marker_86914b78fe0af7f81941971ffa170a09 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_950dfd4f89ea133f0b6a666702e14a6a);
#
#
#         var popup_4ad1f884c8b125a4e3f75d6a8d15c105 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca456c87765d8f25820a343b7f7c9281 = $(`&lt;div id=&quot;html_ca456c87765d8f25820a343b7f7c9281&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4ad1f884c8b125a4e3f75d6a8d15c105.setContent(html_ca456c87765d8f25820a343b7f7c9281);
#
#
#
#         marker_86914b78fe0af7f81941971ffa170a09.bindPopup(popup_4ad1f884c8b125a4e3f75d6a8d15c105)
#         ;
#
#
#
#
#             var marker_72f06fd6380367655a403ffdbaba8752 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_950dfd4f89ea133f0b6a666702e14a6a);
#
#
#         var popup_074e6bd88049e1be3152da02a0fd3b55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dde37d42b0912c8a4a7fc4395807697c = $(`&lt;div id=&quot;html_dde37d42b0912c8a4a7fc4395807697c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_074e6bd88049e1be3152da02a0fd3b55.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f11af79a983e9fc2ea96fe246ea5c67 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f11af79a983e9fc2ea96fe246ea5c67&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f11af79a983e9fc2ea96fe246ea5c67 = L.map(
#                 &quot;map_1f11af79a983e9fc2ea96fe246ea5c67&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8dd16e69460d62707d2ef6b619fbdb23 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8dd16e69460d62707d2ef6b619fbdb23.addTo(map_1f11af79a983e9fc2ea96fe246ea5c67);
#
#
#             var feature_group_8ea7a13cf75c0fb8df055bc758303eff = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_16edf1cdf2846ec4cd1acc8a205c8ee9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8ea7a13cf75c0fb8df055bc758303eff);
#
#
#         var popup_4d33694af5c0de8dbd11c787e6e43868 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a180037c8dba0fa0c5bc0eb032ad2c41 = $(`&lt;div id=&quot;html_a180037c8dba0fa0c5bc0eb032ad2c41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4d33694af5c0de8dbd11c787e6e43868.setContent(html_a180037c8dba0fa0c5bc0eb032ad2c41);
#
#
#
#         marker_16edf1cdf2846ec4cd1acc8a205c8ee9.bindPopup(popup_4d33694af5c0de8dbd11c787e6e43868)
#         ;
#
#
#
#
#             var marker_f2907ef3e1cc7a1c30c69c3984fa1572 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8ea7a13cf75c0fb8df055bc758303eff);
#
#
#         var popup_f330cdbb8d10da516fcec10273a6571d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c10b9e25d99bfec69c0962fce106e5b5 = $(`&lt;div id=&quot;html_c10b9e25d99bfec69c0962fce106e5b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f330cdbb8d10da516fcec10273a6571d.setContent(html_c10b9e25d99bfec69c0962fce106e5b5);
#
#
#
#         marker_f2907ef3e1cc7a1c30c69c3984fa1572.bindPopup(popup_f330cdbb8d10da516fcec10273a6571d)
#         ;
#
#
#
#
#             var marker_cc17963586d5d30cba6d48876cc39459 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8ea7a13cf75c0fb8df055bc758303eff);
#
#
#         var popup_a5053edc30a83d1b1a555c3e81666768 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73ddd0f96a31c6fa200bb20510ef15df = $(`&lt;div id=&quot;html_73ddd0f96a31c6fa200bb20510ef15df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a5053edc30a83d1b1a555c3e81666768.setContent(html_73ddd0f96a31c6fa200bb20510ef15df);
#
#
#
#         marker_cc17963586d5d30cba6d48876cc39459.bindPopup(popup_a5053edc30a83d1b1a555c3e81666768)
#         ;
#
#
#
#
#             var marker_e03f65272cedf1c4031d4c6b556fc027 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8ea7a13cf75c0fb8df055bc758303eff);
#
#
#         var popup_9d39f9214bef62e9e7cc35994420ef90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d70e0b0f9c15608c74a095c2395b5560 = $(`&lt;div id=&quot;html_d70e0b0f9c15608c74a095c2395b5560&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9d39f9214bef62e9e7cc35994420ef90.setContent(html_d70e0b0f9c15608c74a095c2395b5560);
#
#
#
#         marker_e03f65272cedf1c4031d4c6b556fc027.bindPopup(popup_9d39f9214bef62e9e7cc35994420ef90)
#         ;
#
#
#
#
#             var marker_82f718052da5a29cb0074cb320cdd434 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8ea7a13cf75c0fb8df055bc758303eff);
#
#
#         var popup_01a3b646441bfbe8d572d3732fe4815c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a996dc6ea2114186099b79d21c5c1a89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a996dc6ea2114186099b79d21c5c1a89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a996dc6ea2114186099b79d21c5c1a89 = L.map(
#                 &quot;map_a996dc6ea2114186099b79d21c5c1a89&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da92cc8616e74180565a5e6efb2d9fb9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da92cc8616e74180565a5e6efb2d9fb9.addTo(map_a996dc6ea2114186099b79d21c5c1a89);
#
#
#             var feature_group_14c5ff0e365b490d83d087a7e33a5490 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_14c5ff0e365b490d83d087a7e33a5490.addTo(map_a996dc6ea2114186099b79d21c5c1a89);
#
#
#             var feature_group_sub_group_6954ffec921e242eeb89413a75152f44 = L.featureGroup.subGroup(
#                 feature_group_14c5ff0e365b490d83d087a7e33a5490
#             );
#
#
#             var marker_0d17f3a273ff6d31441d55986640405e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6954ffec921e242eeb89413a75152f44);
#
#
#         var popup_b7d88d89bfc4f6572af995bd514aea90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4feb1b07c98eec79526a6f33ea9e626 = $(`&lt;div id=&quot;html_b4feb1b07c98eec79526a6f33ea9e626&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b7d88d89bfc4f6572af995bd514aea90.setContent(html_b4feb1b07c98eec79526a6f33ea9e626);
#
#
#
#         marker_0d17f3a273ff6d31441d55986640405e.bindPopup(popup_b7d88d89bfc4f6572af995bd514aea90)
#         ;
#
#
#
#
#             var marker_e353aff27ede741434045f63ffda7d3d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6954ffec921e242eeb89413a75152f44);
#
#
#         var popup_899b75043e109353c65978d5312ee5a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8805d3d0b9884787cc1108458127b96 = $(`&lt;div id=&quot;html_d8805d3d0b9884787cc1108458127b96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_899b75043e109353c65978d5312ee5a5.setContent(html_d8805d3d0b9884787cc1108458127b96);
#
#
#
#         marker_e353aff27ede741434045f63ffda7d3d.bindPopup(popup_899b75043e109353c65978d5312ee5a5)
#         ;
#
#
#
#
#             var marker_48acc707ee6ce1042ef303f0660f50c3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6954ffec921e242eeb89413a75152f44);
#
#
#         var popup_188c673d7bf0418fe10e629bddefc2ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82548b251a5a043200668e7ab2ffd81e = $(`&lt;div id=&quot;html_82548b251a5a043200668e7ab2ffd81e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_188c673d7bf0418fe10e629bddefc2ee.setContent(html_82548b251a5a043200668e7ab2ffd81e);
#
#
#
#         marker_48acc707ee6ce1042ef303f0660f50c3.bindPopup(popup_188c673d7bf0418fe10e629bddefc2ee)
#         ;
#
#
#
#
#             var marker_73ed331276f4b97e376b5b59169263b1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6954ffec921e242eeb89413a75152f44);
#
#
#         var popup_ab6043a46e4c1b72522c6c0023f7e035 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c58c9b649e09d952715a90a1a9234d3 = $(`&lt;div id=&quot;html_0c58c9b649e09d952715a90a1a9234d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ab6043a46e4c1b72522c6c0023f7e035.setContent(html_0c58c9b649e09d952715a90a1a9234d3);
#
#
#
#         marker_
