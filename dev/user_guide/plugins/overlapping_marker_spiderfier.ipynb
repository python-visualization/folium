# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c8957d9636bd7434a59a605337185cff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c8957d9636bd7434a59a605337185cff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c8957d9636bd7434a59a605337185cff = L.map(
#                 &quot;map_c8957d9636bd7434a59a605337185cff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8765b083b2dba4730f6e9c6f0172f652 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8765b083b2dba4730f6e9c6f0172f652.addTo(map_c8957d9636bd7434a59a605337185cff);
#
#
#             var marker_a467a26d06e3f2c56047da428260a562 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c8957d9636bd7434a59a605337185cff);
#
#
#         var popup_29096e6185b19dd2645f1eda0fa11811 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6096eafa350927410a55a8f048982675 = $(`&lt;div id=&quot;html_6096eafa350927410a55a8f048982675&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_29096e6185b19dd2645f1eda0fa11811.setContent(html_6096eafa350927410a55a8f048982675);
#
#
#
#         marker_a467a26d06e3f2c56047da428260a562.bindPopup(popup_29096e6185b19dd2645f1eda0fa11811)
#         ;
#
#
#
#
#             var marker_488d3870634796c855ecec077599d222 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c8957d9636bd7434a59a605337185cff);
#
#
#         var popup_6eb04f9aafa1d91eb987a35c8665ebb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5b02ce24b4fdbe2e95e5084a402b39b = $(`&lt;div id=&quot;html_b5b02ce24b4fdbe2e95e5084a402b39b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6eb04f9aafa1d91eb987a35c8665ebb0.setContent(html_b5b02ce24b4fdbe2e95e5084a402b39b);
#
#
#
#         marker_488d3870634796c855ecec077599d222.bindPopup(popup_6eb04f9aafa1d91eb987a35c8665ebb0)
#         ;
#
#
#
#
#             var marker_b8bc5ed30d29316734ded82416e45be7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c8957d9636bd7434a59a605337185cff);
#
#
#         var popup_4548a9e01aad00e636bed31f6767e1b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e9d363a9bca09920b6182cc75ae66e7 = $(`&lt;div id=&quot;html_5e9d363a9bca09920b6182cc75ae66e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4548a9e01aad00e636bed31f6767e1b4.setContent(html_5e9d363a9bca09920b6182cc75ae66e7);
#
#
#
#         marker_b8bc5ed30d29316734ded82416e45be7.bindPopup(popup_4548a9e01aad00e636bed31f6767e1b4)
#         ;
#
#
#
#
#             var marker_2f0dd0d790bd4cfb585d54b53518d3d5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c8957d9636bd7434a59a605337185cff);
#
#
#         var popup_b6cd722d1f3181d9929449661bd33dc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20e2815f4051e4373725d7d4b8c0605c = $(`&lt;div id=&quot;html_20e2815f4051e4373725d7d4b8c0605c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b6cd722d1f3181d9929449661bd33dc6.setContent(html_20e2815f4051e4373725d7d4b8c0605c);
#
#
#
#         marker_2f0dd0d790bd4cfb585d54b53518d3d5.bindPopup(popup_b6cd722d1f3181d9929449661bd33dc6)
#         ;
#
#
#
#
#             var marker_3abc3abefde887ed981d1a477492f6e8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c8957d9636bd7434a59a605337185cff);
#
#
#         var popup_05016380c949011064b4b4561e970834 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e470dd9ce6de8827912338a9b5c8633 = $(`&lt;div id=&quot;html_4e470dd9ce6de8827912338a9b5c8633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_05016380c949011064b4b4561e970834.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f485eaa207b2cce9b7391cf879cb55e0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f485eaa207b2cce9b7391cf879cb55e0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f485eaa207b2cce9b7391cf879cb55e0 = L.map(
#                 &quot;map_f485eaa207b2cce9b7391cf879cb55e0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bbd3499c3a6dba3ab4179e39d419d0b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bbd3499c3a6dba3ab4179e39d419d0b4.addTo(map_f485eaa207b2cce9b7391cf879cb55e0);
#
#
#             var feature_group_d742ceeaf287406ec6d4b43e0fba1608 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bd135fbc3cc4ac113bb864d0fb7af561 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d742ceeaf287406ec6d4b43e0fba1608);
#
#
#         var popup_16fbc5dc674e82fbb42b80cae52ff11c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cee6533dda31cb2df6cc100e68f4875 = $(`&lt;div id=&quot;html_6cee6533dda31cb2df6cc100e68f4875&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_16fbc5dc674e82fbb42b80cae52ff11c.setContent(html_6cee6533dda31cb2df6cc100e68f4875);
#
#
#
#         marker_bd135fbc3cc4ac113bb864d0fb7af561.bindPopup(popup_16fbc5dc674e82fbb42b80cae52ff11c)
#         ;
#
#
#
#
#             var marker_97d93e5de98ecfec82ab75be5709f78c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d742ceeaf287406ec6d4b43e0fba1608);
#
#
#         var popup_7f6da3e0f90955b714d5cfa2f452d2b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08807b0f2c1c6a0da54c067a26bc6dd8 = $(`&lt;div id=&quot;html_08807b0f2c1c6a0da54c067a26bc6dd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7f6da3e0f90955b714d5cfa2f452d2b9.setContent(html_08807b0f2c1c6a0da54c067a26bc6dd8);
#
#
#
#         marker_97d93e5de98ecfec82ab75be5709f78c.bindPopup(popup_7f6da3e0f90955b714d5cfa2f452d2b9)
#         ;
#
#
#
#
#             var marker_983d5420f606957def47a8fab4bc49a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d742ceeaf287406ec6d4b43e0fba1608);
#
#
#         var popup_fbeb43115c74eab61695ccd7ff5032ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90b677dfcf19ef8a85c6cba0808f2890 = $(`&lt;div id=&quot;html_90b677dfcf19ef8a85c6cba0808f2890&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fbeb43115c74eab61695ccd7ff5032ab.setContent(html_90b677dfcf19ef8a85c6cba0808f2890);
#
#
#
#         marker_983d5420f606957def47a8fab4bc49a4.bindPopup(popup_fbeb43115c74eab61695ccd7ff5032ab)
#         ;
#
#
#
#
#             var marker_bae99dda047387ebddf2e7b62dfa88ce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d742ceeaf287406ec6d4b43e0fba1608);
#
#
#         var popup_75461759b515cf0f1d986feb7fe119b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6a55a026f96e9912f38ccae4ee20ae7 = $(`&lt;div id=&quot;html_c6a55a026f96e9912f38ccae4ee20ae7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_75461759b515cf0f1d986feb7fe119b2.setContent(html_c6a55a026f96e9912f38ccae4ee20ae7);
#
#
#
#         marker_bae99dda047387ebddf2e7b62dfa88ce.bindPopup(popup_75461759b515cf0f1d986feb7fe119b2)
#         ;
#
#
#
#
#             var marker_45622b17c94427f1a7c4293ff0fda479 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d742ceeaf287406ec6d4b43e0fba1608);
#
#
#         var popup_6359808b9978f4ceead8806a3755f801 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70e95d08ffa24cfd0f67659ccb972c13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70e95d08ffa24cfd0f67659ccb972c13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70e95d08ffa24cfd0f67659ccb972c13 = L.map(
#                 &quot;map_70e95d08ffa24cfd0f67659ccb972c13&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d33048769e2e8145437f2347dcee2fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d33048769e2e8145437f2347dcee2fc.addTo(map_70e95d08ffa24cfd0f67659ccb972c13);
#
#
#             var feature_group_7967f0a911a5517a4164299f83a140dc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7967f0a911a5517a4164299f83a140dc.addTo(map_70e95d08ffa24cfd0f67659ccb972c13);
#
#
#             var feature_group_sub_group_a3b026f02ecd2180fa0b90cc0fa59788 = L.featureGroup.subGroup(
#                 feature_group_7967f0a911a5517a4164299f83a140dc
#             );
#
#
#             var marker_d3935951d523d7b9ebdf52167f294c5c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3b026f02ecd2180fa0b90cc0fa59788);
#
#
#         var popup_2aac6b3832b2fc55d2083c9475874462 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f156b89ebce77fec6e5652213a2f8de7 = $(`&lt;div id=&quot;html_f156b89ebce77fec6e5652213a2f8de7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2aac6b3832b2fc55d2083c9475874462.setContent(html_f156b89ebce77fec6e5652213a2f8de7);
#
#
#
#         marker_d3935951d523d7b9ebdf52167f294c5c.bindPopup(popup_2aac6b3832b2fc55d2083c9475874462)
#         ;
#
#
#
#
#             var marker_d318033c0ca33d690125e4545e06821e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3b026f02ecd2180fa0b90cc0fa59788);
#
#
#         var popup_f2f5ce9dc9ad2937d38e81d1570bda54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba0914bc0e417bd3fe69698e3c8ede29 = $(`&lt;div id=&quot;html_ba0914bc0e417bd3fe69698e3c8ede29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f2f5ce9dc9ad2937d38e81d1570bda54.setContent(html_ba0914bc0e417bd3fe69698e3c8ede29);
#
#
#
#         marker_d318033c0ca33d690125e4545e06821e.bindPopup(popup_f2f5ce9dc9ad2937d38e81d1570bda54)
#         ;
#
#
#
#
#             var marker_edc09552e9e5dcd78213b1d34c8b933a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3b026f02ecd2180fa0b90cc0fa59788);
#
#
#         var popup_fe31f66a25c20d69b9433cf571502bf6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41744a0752ed7955edbf9302ee6145cc = $(`&lt;div id=&quot;html_41744a0752ed7955edbf9302ee6145cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fe31f66a25c20d69b9433cf571502bf6.setContent(html_41744a0752ed7955edbf9302ee6145cc);
#
#
#
#         marker_edc09552e9e5dcd78213b1d34c8b933a.bindPopup(popup_fe31f66a25c20d69b9433cf571502bf6)
#         ;
#
#
#
#
#             var marker_9f5ef476dd9ab88e11b6f85e2c61adac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3b026f02ecd2180fa0b90cc0fa59788);
#
#
#         var popup_2e128515a7522c88e82f10a7f5a8260f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c3a1894df0dd8705459c478fc159520 = $(`&lt;div id=&quot;html_3c3a1894df0dd8705459c478fc159520&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2e128515a7522c88e82f10a7f5a8260f.setContent(html_3c3a1894df0dd8705459c478fc159520);
#
#
#
#         marker_
