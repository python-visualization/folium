# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88b6a6710ae327dd1c22b3e15a05eb6e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88b6a6710ae327dd1c22b3e15a05eb6e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88b6a6710ae327dd1c22b3e15a05eb6e = L.map(
#                 &quot;map_88b6a6710ae327dd1c22b3e15a05eb6e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88e351f114139ccd1a8a6e380e799330 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88e351f114139ccd1a8a6e380e799330.addTo(map_88b6a6710ae327dd1c22b3e15a05eb6e);
#
#
#             var marker_82500ab2a9d5fa4dce385feeeeb0abfa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_88b6a6710ae327dd1c22b3e15a05eb6e);
#
#
#         var popup_2de80d21dc86b3a67cb603b45df60327 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c48365bcaf25a943ea97a59aa7011cd2 = $(`&lt;div id=&quot;html_c48365bcaf25a943ea97a59aa7011cd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2de80d21dc86b3a67cb603b45df60327.setContent(html_c48365bcaf25a943ea97a59aa7011cd2);
#
#
#
#         marker_82500ab2a9d5fa4dce385feeeeb0abfa.bindPopup(popup_2de80d21dc86b3a67cb603b45df60327)
#         ;
#
#
#
#
#             var marker_1ca8cd52bc11a7af350c7ca3c81d223f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_88b6a6710ae327dd1c22b3e15a05eb6e);
#
#
#         var popup_b1239ddec084a2f127adf830dd4b61f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b83c5f3fcbd74add88e45fbd391dfb64 = $(`&lt;div id=&quot;html_b83c5f3fcbd74add88e45fbd391dfb64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b1239ddec084a2f127adf830dd4b61f8.setContent(html_b83c5f3fcbd74add88e45fbd391dfb64);
#
#
#
#         marker_1ca8cd52bc11a7af350c7ca3c81d223f.bindPopup(popup_b1239ddec084a2f127adf830dd4b61f8)
#         ;
#
#
#
#
#             var marker_f6ac56eafc6f559c5475cebb6fa4581a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_88b6a6710ae327dd1c22b3e15a05eb6e);
#
#
#         var popup_6822c7ea9e218e8e50b1d8f0a31ee9d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e82ed75dcddc2c02a4c2744fae31af1 = $(`&lt;div id=&quot;html_0e82ed75dcddc2c02a4c2744fae31af1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6822c7ea9e218e8e50b1d8f0a31ee9d1.setContent(html_0e82ed75dcddc2c02a4c2744fae31af1);
#
#
#
#         marker_f6ac56eafc6f559c5475cebb6fa4581a.bindPopup(popup_6822c7ea9e218e8e50b1d8f0a31ee9d1)
#         ;
#
#
#
#
#             var marker_0ab7693b4dafa6edc98ba54bc5011436 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_88b6a6710ae327dd1c22b3e15a05eb6e);
#
#
#         var popup_be4f3e9af3424f783c25802d0e2f241b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31f869f5715807453b3594c6acad4401 = $(`&lt;div id=&quot;html_31f869f5715807453b3594c6acad4401&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_be4f3e9af3424f783c25802d0e2f241b.setContent(html_31f869f5715807453b3594c6acad4401);
#
#
#
#         marker_0ab7693b4dafa6edc98ba54bc5011436.bindPopup(popup_be4f3e9af3424f783c25802d0e2f241b)
#         ;
#
#
#
#
#             var marker_8d027e3c7c7013576f3e09b7cf759696 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_88b6a6710ae327dd1c22b3e15a05eb6e);
#
#
#         var popup_079b8bded211058f014e14bca0c97990 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21c22593ce4bf725b23df202ac56dc06 = $(`&lt;div id=&quot;html_21c22593ce4bf725b23df202ac56dc06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_079b8bded211058f014e14bca0c97990.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0817a1564b28045ce79b5ed884d5720d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0817a1564b28045ce79b5ed884d5720d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0817a1564b28045ce79b5ed884d5720d = L.map(
#                 &quot;map_0817a1564b28045ce79b5ed884d5720d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa0fbbc4af0c3e9f99a9a0425db5b7d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa0fbbc4af0c3e9f99a9a0425db5b7d7.addTo(map_0817a1564b28045ce79b5ed884d5720d);
#
#
#             var feature_group_a41f42ba407416277d5ac8a701e70dcc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_81436fca8e9ec9756ea37f6a904da737 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a41f42ba407416277d5ac8a701e70dcc);
#
#
#         var popup_2dceafed983d3574b27165fc9c9620bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a98138815d53cbb9c18fb7fb9c5e1e7a = $(`&lt;div id=&quot;html_a98138815d53cbb9c18fb7fb9c5e1e7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2dceafed983d3574b27165fc9c9620bd.setContent(html_a98138815d53cbb9c18fb7fb9c5e1e7a);
#
#
#
#         marker_81436fca8e9ec9756ea37f6a904da737.bindPopup(popup_2dceafed983d3574b27165fc9c9620bd)
#         ;
#
#
#
#
#             var marker_8f6fa201d013d7b806fd5f6c1d4dbbd8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a41f42ba407416277d5ac8a701e70dcc);
#
#
#         var popup_7e2f638e0ef53cd0612ce12a71edf0d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1e33a3dbf9b0a82f69473abcb4176bf = $(`&lt;div id=&quot;html_b1e33a3dbf9b0a82f69473abcb4176bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7e2f638e0ef53cd0612ce12a71edf0d8.setContent(html_b1e33a3dbf9b0a82f69473abcb4176bf);
#
#
#
#         marker_8f6fa201d013d7b806fd5f6c1d4dbbd8.bindPopup(popup_7e2f638e0ef53cd0612ce12a71edf0d8)
#         ;
#
#
#
#
#             var marker_23bc35bad7af9f2eff13fd62f853071d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a41f42ba407416277d5ac8a701e70dcc);
#
#
#         var popup_35904282f53c88e7e7f495e5ff50e4c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_922e76fd3d913192bd51292259df437b = $(`&lt;div id=&quot;html_922e76fd3d913192bd51292259df437b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_35904282f53c88e7e7f495e5ff50e4c5.setContent(html_922e76fd3d913192bd51292259df437b);
#
#
#
#         marker_23bc35bad7af9f2eff13fd62f853071d.bindPopup(popup_35904282f53c88e7e7f495e5ff50e4c5)
#         ;
#
#
#
#
#             var marker_baead9dc7dd1e79d8b5e206a915a9da6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a41f42ba407416277d5ac8a701e70dcc);
#
#
#         var popup_77883a2eea552b23c9a9148dfb5384db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c01d982a177747cc807ea414b911bc89 = $(`&lt;div id=&quot;html_c01d982a177747cc807ea414b911bc89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_77883a2eea552b23c9a9148dfb5384db.setContent(html_c01d982a177747cc807ea414b911bc89);
#
#
#
#         marker_baead9dc7dd1e79d8b5e206a915a9da6.bindPopup(popup_77883a2eea552b23c9a9148dfb5384db)
#         ;
#
#
#
#
#             var marker_0b08e5b0a5cec85629872205f89be014 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a41f42ba407416277d5ac8a701e70dcc);
#
#
#         var popup_f49b9c997ca7ebb5c49c3fede01a0220 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e2755c4200d388adb1497ed450f6545c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e2755c4200d388adb1497ed450f6545c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e2755c4200d388adb1497ed450f6545c = L.map(
#                 &quot;map_e2755c4200d388adb1497ed450f6545c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fcdc164c9f818297548add115dbebfe3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fcdc164c9f818297548add115dbebfe3.addTo(map_e2755c4200d388adb1497ed450f6545c);
#
#
#             var feature_group_b67780826e8bee41eb09deb9d74b45c4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b67780826e8bee41eb09deb9d74b45c4.addTo(map_e2755c4200d388adb1497ed450f6545c);
#
#
#             var feature_group_sub_group_92f3d1c08ecca236e22cd067fedda807 = L.featureGroup.subGroup(
#                 feature_group_b67780826e8bee41eb09deb9d74b45c4
#             );
#
#
#             var marker_a38aa759e74ece24814e7a1a29280146 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_92f3d1c08ecca236e22cd067fedda807);
#
#
#         var popup_2151b45fb44d80d965755671a7e044a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fbf167da6ccf2f082ba71397a4a25cd = $(`&lt;div id=&quot;html_9fbf167da6ccf2f082ba71397a4a25cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2151b45fb44d80d965755671a7e044a7.setContent(html_9fbf167da6ccf2f082ba71397a4a25cd);
#
#
#
#         marker_a38aa759e74ece24814e7a1a29280146.bindPopup(popup_2151b45fb44d80d965755671a7e044a7)
#         ;
#
#
#
#
#             var marker_71a4d8c368d6238ad20bbcfb47789ceb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_92f3d1c08ecca236e22cd067fedda807);
#
#
#         var popup_3f95f9bf596a6f328821a43404d58cbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ed693e5290971033514855948539498 = $(`&lt;div id=&quot;html_9ed693e5290971033514855948539498&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3f95f9bf596a6f328821a43404d58cbe.setContent(html_9ed693e5290971033514855948539498);
#
#
#
#         marker_71a4d8c368d6238ad20bbcfb47789ceb.bindPopup(popup_3f95f9bf596a6f328821a43404d58cbe)
#         ;
#
#
#
#
#             var marker_edd50071c5646eb0c87b93d316933622 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_92f3d1c08ecca236e22cd067fedda807);
#
#
#         var popup_fb0dd3b813a856fec6cf77534c8ac012 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_953744b87511a5ade3506f5e91ebe7f0 = $(`&lt;div id=&quot;html_953744b87511a5ade3506f5e91ebe7f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fb0dd3b813a856fec6cf77534c8ac012.setContent(html_953744b87511a5ade3506f5e91ebe7f0);
#
#
#
#         marker_edd50071c5646eb0c87b93d316933622.bindPopup(popup_fb0dd3b813a856fec6cf77534c8ac012)
#         ;
#
#
#
#
#             var marker_2b3ab326c3cbde97cd47b77d6735118c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_92f3d1c08ecca236e22cd067fedda807);
#
#
#         var popup_ac734086111700ca59395142f57a2373 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fd707e44d3a177e06e9e90bdc1f6bd9 = $(`&lt;div id=&quot;html_5fd707e44d3a177e06e9e90bdc1f6bd9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ac734086111700ca59395142f57a2373.setContent(html_5fd707e44d3a177e06e9e90bdc1f6bd9);
#
#
#
#         marker_
