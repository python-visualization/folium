# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7f3e87004bdbfeb58fa36a0e4f67a2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7f3e87004bdbfeb58fa36a0e4f67a2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7f3e87004bdbfeb58fa36a0e4f67a2c = L.map(
#                 &quot;map_f7f3e87004bdbfeb58fa36a0e4f67a2c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83e14d823a8c3a3f55c566ef159922ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_83e14d823a8c3a3f55c566ef159922ed.addTo(map_f7f3e87004bdbfeb58fa36a0e4f67a2c);
#
#
#             var marker_15c8771881e2e1fe428d6707c10709d7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f7f3e87004bdbfeb58fa36a0e4f67a2c);
#
#
#         var popup_4a5a6cefb5e32cb83866101201d2315d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a85a85699c2172a01094c83743ee6777 = $(`&lt;div id=&quot;html_a85a85699c2172a01094c83743ee6777&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4a5a6cefb5e32cb83866101201d2315d.setContent(html_a85a85699c2172a01094c83743ee6777);
#
#
#
#         marker_15c8771881e2e1fe428d6707c10709d7.bindPopup(popup_4a5a6cefb5e32cb83866101201d2315d)
#         ;
#
#
#
#
#             var marker_9c104a60e9da70ae2465442188a14d75 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f7f3e87004bdbfeb58fa36a0e4f67a2c);
#
#
#         var popup_5c372374fe1576d27f54f6f6fa454785 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31ce3ad43a907877080e98ebacd9fb27 = $(`&lt;div id=&quot;html_31ce3ad43a907877080e98ebacd9fb27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5c372374fe1576d27f54f6f6fa454785.setContent(html_31ce3ad43a907877080e98ebacd9fb27);
#
#
#
#         marker_9c104a60e9da70ae2465442188a14d75.bindPopup(popup_5c372374fe1576d27f54f6f6fa454785)
#         ;
#
#
#
#
#             var marker_c7a94fc64e11549bf1f3401a6c9cf556 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f7f3e87004bdbfeb58fa36a0e4f67a2c);
#
#
#         var popup_ff91f0be03c325a58d2a19ba0299bef3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dc964433923cc98d167ea6007558ddb = $(`&lt;div id=&quot;html_5dc964433923cc98d167ea6007558ddb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ff91f0be03c325a58d2a19ba0299bef3.setContent(html_5dc964433923cc98d167ea6007558ddb);
#
#
#
#         marker_c7a94fc64e11549bf1f3401a6c9cf556.bindPopup(popup_ff91f0be03c325a58d2a19ba0299bef3)
#         ;
#
#
#
#
#             var marker_75f223f00b4b7ca5e6c631e9a09c2c64 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f7f3e87004bdbfeb58fa36a0e4f67a2c);
#
#
#         var popup_a19cc0638dc967a435f977ba05389196 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a556a3c0419dc527ce1c0a59ab719fb0 = $(`&lt;div id=&quot;html_a556a3c0419dc527ce1c0a59ab719fb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a19cc0638dc967a435f977ba05389196.setContent(html_a556a3c0419dc527ce1c0a59ab719fb0);
#
#
#
#         marker_75f223f00b4b7ca5e6c631e9a09c2c64.bindPopup(popup_a19cc0638dc967a435f977ba05389196)
#         ;
#
#
#
#
#             var marker_16aaead964209e16e444c7968b325d8b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f7f3e87004bdbfeb58fa36a0e4f67a2c);
#
#
#         var popup_f119eb064e0a59c1445169db3749c080 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e8a02deb4bb6c3675cff4c1e5ea2f4e = $(`&lt;div id=&quot;html_2e8a02deb4bb6c3675cff4c1e5ea2f4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f119eb064e0a59c1445169db3749c080.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c71722b36a1decd668b963ad6ea8d6b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c71722b36a1decd668b963ad6ea8d6b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c71722b36a1decd668b963ad6ea8d6b = L.map(
#                 &quot;map_2c71722b36a1decd668b963ad6ea8d6b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62f66eaa4643a80d64ca3e297705174b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62f66eaa4643a80d64ca3e297705174b.addTo(map_2c71722b36a1decd668b963ad6ea8d6b);
#
#
#             var feature_group_59b50a246fe5538cc3c856bafbe0b971 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_92f09670c05eb4642d8c955ea6b7af43 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_59b50a246fe5538cc3c856bafbe0b971);
#
#
#         var popup_c0d5e33e945065c68adde8b90872e803 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_371c3e97f63d0446be88a89239ff9dba = $(`&lt;div id=&quot;html_371c3e97f63d0446be88a89239ff9dba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c0d5e33e945065c68adde8b90872e803.setContent(html_371c3e97f63d0446be88a89239ff9dba);
#
#
#
#         marker_92f09670c05eb4642d8c955ea6b7af43.bindPopup(popup_c0d5e33e945065c68adde8b90872e803)
#         ;
#
#
#
#
#             var marker_5868d15182967d9e77dcf15af8a33112 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_59b50a246fe5538cc3c856bafbe0b971);
#
#
#         var popup_0a8d6e1b652fc8d61a8d49bc6f681b20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_406093f00d25d85d29ebe41c837d34f4 = $(`&lt;div id=&quot;html_406093f00d25d85d29ebe41c837d34f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0a8d6e1b652fc8d61a8d49bc6f681b20.setContent(html_406093f00d25d85d29ebe41c837d34f4);
#
#
#
#         marker_5868d15182967d9e77dcf15af8a33112.bindPopup(popup_0a8d6e1b652fc8d61a8d49bc6f681b20)
#         ;
#
#
#
#
#             var marker_7607dedf29b74c598eb8b06115a8170b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_59b50a246fe5538cc3c856bafbe0b971);
#
#
#         var popup_8e4b78d8651d3420ac1c5635aa93c6b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fea1f344236b62550c51a286823bf20c = $(`&lt;div id=&quot;html_fea1f344236b62550c51a286823bf20c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8e4b78d8651d3420ac1c5635aa93c6b6.setContent(html_fea1f344236b62550c51a286823bf20c);
#
#
#
#         marker_7607dedf29b74c598eb8b06115a8170b.bindPopup(popup_8e4b78d8651d3420ac1c5635aa93c6b6)
#         ;
#
#
#
#
#             var marker_f5e17d85934c424bffa63c203907a502 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_59b50a246fe5538cc3c856bafbe0b971);
#
#
#         var popup_118a6cc64453bce6867e6ed369bd18c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7b573a66df695854565dda10dfa810b = $(`&lt;div id=&quot;html_d7b573a66df695854565dda10dfa810b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_118a6cc64453bce6867e6ed369bd18c0.setContent(html_d7b573a66df695854565dda10dfa810b);
#
#
#
#         marker_f5e17d85934c424bffa63c203907a502.bindPopup(popup_118a6cc64453bce6867e6ed369bd18c0)
#         ;
#
#
#
#
#             var marker_496ca0b7c72a0c4cb548f73309f8c0af = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_59b50a246fe5538cc3c856bafbe0b971);
#
#
#         var popup_7345994fdf1f8b6a198b60b2625663d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f3c771910ba6e52d241e690f931ff89 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f3c771910ba6e52d241e690f931ff89&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f3c771910ba6e52d241e690f931ff89 = L.map(
#                 &quot;map_2f3c771910ba6e52d241e690f931ff89&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1804764ebbae3aba766f78f49c848fd8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1804764ebbae3aba766f78f49c848fd8.addTo(map_2f3c771910ba6e52d241e690f931ff89);
#
#
#             var feature_group_5130ffce660b21cd4f85273335ad3296 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5130ffce660b21cd4f85273335ad3296.addTo(map_2f3c771910ba6e52d241e690f931ff89);
#
#
#             var feature_group_sub_group_21fca5997df2af74c12f14c20343d6d7 = L.featureGroup.subGroup(
#                 feature_group_5130ffce660b21cd4f85273335ad3296
#             );
#
#
#             var marker_d539c45a46d6245841df84034ed6a739 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_21fca5997df2af74c12f14c20343d6d7);
#
#
#         var popup_9f077a37b0a88d98821cad3ad4377083 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_feb10e27afbeefe5906a8e602c541e95 = $(`&lt;div id=&quot;html_feb10e27afbeefe5906a8e602c541e95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9f077a37b0a88d98821cad3ad4377083.setContent(html_feb10e27afbeefe5906a8e602c541e95);
#
#
#
#         marker_d539c45a46d6245841df84034ed6a739.bindPopup(popup_9f077a37b0a88d98821cad3ad4377083)
#         ;
#
#
#
#
#             var marker_0ce375a336f92ecdbc63d6d96298c252 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_21fca5997df2af74c12f14c20343d6d7);
#
#
#         var popup_fd7c019728ac8631a297059d4ad5b1e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06db66294b91683a067f972fdb444eec = $(`&lt;div id=&quot;html_06db66294b91683a067f972fdb444eec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fd7c019728ac8631a297059d4ad5b1e9.setContent(html_06db66294b91683a067f972fdb444eec);
#
#
#
#         marker_0ce375a336f92ecdbc63d6d96298c252.bindPopup(popup_fd7c019728ac8631a297059d4ad5b1e9)
#         ;
#
#
#
#
#             var marker_5e971d1306f5c09c6d6355f69f5cb5e6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_21fca5997df2af74c12f14c20343d6d7);
#
#
#         var popup_0401db3b9b522972d99f4cd1a0c37dea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e458ab28ac421578cdeb569f77c32c5 = $(`&lt;div id=&quot;html_7e458ab28ac421578cdeb569f77c32c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0401db3b9b522972d99f4cd1a0c37dea.setContent(html_7e458ab28ac421578cdeb569f77c32c5);
#
#
#
#         marker_5e971d1306f5c09c6d6355f69f5cb5e6.bindPopup(popup_0401db3b9b522972d99f4cd1a0c37dea)
#         ;
#
#
#
#
#             var marker_f0d64a608d719767bfae9765835a2536 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_21fca5997df2af74c12f14c20343d6d7);
#
#
#         var popup_59c79467ba61d2e74f90ddf772ac4266 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_759ccc3982a37726bac5fe6e185146a2 = $(`&lt;div id=&quot;html_759ccc3982a37726bac5fe6e185146a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_59c79467ba61d2e74f90ddf772ac4266.setContent(html_759ccc3982a37726bac5fe6e185146a2);
#
#
#
#         marker_
