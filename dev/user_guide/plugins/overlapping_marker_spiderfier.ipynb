# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e15aca3d011f7a45a6671ec283587141 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e15aca3d011f7a45a6671ec283587141&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e15aca3d011f7a45a6671ec283587141 = L.map(
#                 &quot;map_e15aca3d011f7a45a6671ec283587141&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6891646ce3420fde7c942567958be898 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6891646ce3420fde7c942567958be898.addTo(map_e15aca3d011f7a45a6671ec283587141);
#
#
#             var marker_f0d85891f5b402f305e8f47aa80414e8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e15aca3d011f7a45a6671ec283587141);
#
#
#         var popup_9eb0d20dde29c9b1d325a03ab99611dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c9f7b2ecdaf7558e0e82f069ecfb97a = $(`&lt;div id=&quot;html_8c9f7b2ecdaf7558e0e82f069ecfb97a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9eb0d20dde29c9b1d325a03ab99611dd.setContent(html_8c9f7b2ecdaf7558e0e82f069ecfb97a);
#
#
#
#         marker_f0d85891f5b402f305e8f47aa80414e8.bindPopup(popup_9eb0d20dde29c9b1d325a03ab99611dd)
#         ;
#
#
#
#
#             var marker_a9054f5e54c0ee31e517cb5f3638ec21 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e15aca3d011f7a45a6671ec283587141);
#
#
#         var popup_238b55d6916d7d6b46da7dbbb518153a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b740345c5569928a305e893b976a442 = $(`&lt;div id=&quot;html_6b740345c5569928a305e893b976a442&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_238b55d6916d7d6b46da7dbbb518153a.setContent(html_6b740345c5569928a305e893b976a442);
#
#
#
#         marker_a9054f5e54c0ee31e517cb5f3638ec21.bindPopup(popup_238b55d6916d7d6b46da7dbbb518153a)
#         ;
#
#
#
#
#             var marker_7f82ed4c83b3b36a5d48e3f18952c6d6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e15aca3d011f7a45a6671ec283587141);
#
#
#         var popup_f4f844236e8fc375fe05db959afba9db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5645c5cb79911eab17bda670d43b37c3 = $(`&lt;div id=&quot;html_5645c5cb79911eab17bda670d43b37c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f4f844236e8fc375fe05db959afba9db.setContent(html_5645c5cb79911eab17bda670d43b37c3);
#
#
#
#         marker_7f82ed4c83b3b36a5d48e3f18952c6d6.bindPopup(popup_f4f844236e8fc375fe05db959afba9db)
#         ;
#
#
#
#
#             var marker_cbe2a7dc356f2458463e01580f363f6d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e15aca3d011f7a45a6671ec283587141);
#
#
#         var popup_4c706ff24038b3fc3f5cdae3a17cf095 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22d0416462ee3d7c72b5c02d3dce0c17 = $(`&lt;div id=&quot;html_22d0416462ee3d7c72b5c02d3dce0c17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4c706ff24038b3fc3f5cdae3a17cf095.setContent(html_22d0416462ee3d7c72b5c02d3dce0c17);
#
#
#
#         marker_cbe2a7dc356f2458463e01580f363f6d.bindPopup(popup_4c706ff24038b3fc3f5cdae3a17cf095)
#         ;
#
#
#
#
#             var marker_89b3c7dffe3b7f2c254510a8d0a1a33e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e15aca3d011f7a45a6671ec283587141);
#
#
#         var popup_6b62758493f21f86ea7616d4aac8d38e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fbab13a041a778025c88ad67072ec17 = $(`&lt;div id=&quot;html_2fbab13a041a778025c88ad67072ec17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6b62758493f21f86ea7616d4aac8d38e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f25db530717113df728b85cc2c28bb7d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f25db530717113df728b85cc2c28bb7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f25db530717113df728b85cc2c28bb7d = L.map(
#                 &quot;map_f25db530717113df728b85cc2c28bb7d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dc578295b933fb4dd81e65eacea032bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dc578295b933fb4dd81e65eacea032bc.addTo(map_f25db530717113df728b85cc2c28bb7d);
#
#
#             var feature_group_fe0f37b32c94ce94cc2d003b29092b2f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9aa23068d9b594ae1c912ef03fbab47c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fe0f37b32c94ce94cc2d003b29092b2f);
#
#
#         var popup_3eb37951f5f997868f6101279b391691 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec2e1ebe815faf3c2bc758918c55c24e = $(`&lt;div id=&quot;html_ec2e1ebe815faf3c2bc758918c55c24e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3eb37951f5f997868f6101279b391691.setContent(html_ec2e1ebe815faf3c2bc758918c55c24e);
#
#
#
#         marker_9aa23068d9b594ae1c912ef03fbab47c.bindPopup(popup_3eb37951f5f997868f6101279b391691)
#         ;
#
#
#
#
#             var marker_959ce7e8e873e96a9da8781f674bf1ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fe0f37b32c94ce94cc2d003b29092b2f);
#
#
#         var popup_0b6ff73201d53be3d4d39c650280b9ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88f4f392e9279f00f73538f01f844527 = $(`&lt;div id=&quot;html_88f4f392e9279f00f73538f01f844527&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0b6ff73201d53be3d4d39c650280b9ae.setContent(html_88f4f392e9279f00f73538f01f844527);
#
#
#
#         marker_959ce7e8e873e96a9da8781f674bf1ee.bindPopup(popup_0b6ff73201d53be3d4d39c650280b9ae)
#         ;
#
#
#
#
#             var marker_06b8f9faeda9ac5f1a74f5f076b53e94 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fe0f37b32c94ce94cc2d003b29092b2f);
#
#
#         var popup_f88cea9ea6f67322eac8c73e37d58371 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ca7e593afc2a6703bec12fc25a053ee = $(`&lt;div id=&quot;html_9ca7e593afc2a6703bec12fc25a053ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f88cea9ea6f67322eac8c73e37d58371.setContent(html_9ca7e593afc2a6703bec12fc25a053ee);
#
#
#
#         marker_06b8f9faeda9ac5f1a74f5f076b53e94.bindPopup(popup_f88cea9ea6f67322eac8c73e37d58371)
#         ;
#
#
#
#
#             var marker_c20eb8d97631729013e21828d90e2957 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fe0f37b32c94ce94cc2d003b29092b2f);
#
#
#         var popup_79c0e44e540b4c482130adb4227feded = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_511c2afd12c56d03b502505cdd9e9b3b = $(`&lt;div id=&quot;html_511c2afd12c56d03b502505cdd9e9b3b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_79c0e44e540b4c482130adb4227feded.setContent(html_511c2afd12c56d03b502505cdd9e9b3b);
#
#
#
#         marker_c20eb8d97631729013e21828d90e2957.bindPopup(popup_79c0e44e540b4c482130adb4227feded)
#         ;
#
#
#
#
#             var marker_d35b21c334c8f59427b21c581a379c49 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fe0f37b32c94ce94cc2d003b29092b2f);
#
#
#         var popup_67cdb049c3ae363ab7544e37618b60fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4d8a27a7cd078fc6ee99d9cb8535ac4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4d8a27a7cd078fc6ee99d9cb8535ac4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4d8a27a7cd078fc6ee99d9cb8535ac4 = L.map(
#                 &quot;map_b4d8a27a7cd078fc6ee99d9cb8535ac4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0734ce2af1f86467e97040ecda8f3a63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0734ce2af1f86467e97040ecda8f3a63.addTo(map_b4d8a27a7cd078fc6ee99d9cb8535ac4);
#
#
#             var feature_group_5c3feb6a7ddcd7f140c608e6f346badb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5c3feb6a7ddcd7f140c608e6f346badb.addTo(map_b4d8a27a7cd078fc6ee99d9cb8535ac4);
#
#
#             var feature_group_sub_group_bcb8a6a5cb9b2c2a1e260dcea5b6b824 = L.featureGroup.subGroup(
#                 feature_group_5c3feb6a7ddcd7f140c608e6f346badb
#             );
#
#
#             var marker_8a1bdb41b0cda19baaf5fe41bd474800 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bcb8a6a5cb9b2c2a1e260dcea5b6b824);
#
#
#         var popup_a0fddaba465cffb7f23ba0fbd67a34c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f57272bca4ad431ea5787d100e4a8da = $(`&lt;div id=&quot;html_9f57272bca4ad431ea5787d100e4a8da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a0fddaba465cffb7f23ba0fbd67a34c9.setContent(html_9f57272bca4ad431ea5787d100e4a8da);
#
#
#
#         marker_8a1bdb41b0cda19baaf5fe41bd474800.bindPopup(popup_a0fddaba465cffb7f23ba0fbd67a34c9)
#         ;
#
#
#
#
#             var marker_ab337607544f18aff51cd3ca9c5fe51d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bcb8a6a5cb9b2c2a1e260dcea5b6b824);
#
#
#         var popup_98b8a0a922215a09ff9acdac75b3a9ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab56ee054b822fada83a9e3158a24701 = $(`&lt;div id=&quot;html_ab56ee054b822fada83a9e3158a24701&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_98b8a0a922215a09ff9acdac75b3a9ac.setContent(html_ab56ee054b822fada83a9e3158a24701);
#
#
#
#         marker_ab337607544f18aff51cd3ca9c5fe51d.bindPopup(popup_98b8a0a922215a09ff9acdac75b3a9ac)
#         ;
#
#
#
#
#             var marker_7cb0e7a3277cc859a9f67cfa9fd3cd2f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bcb8a6a5cb9b2c2a1e260dcea5b6b824);
#
#
#         var popup_38b60a4ffe74919ea5f46cd4a06cd4e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b9ab1267624c15ae0659df6c316f79d = $(`&lt;div id=&quot;html_1b9ab1267624c15ae0659df6c316f79d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_38b60a4ffe74919ea5f46cd4a06cd4e6.setContent(html_1b9ab1267624c15ae0659df6c316f79d);
#
#
#
#         marker_7cb0e7a3277cc859a9f67cfa9fd3cd2f.bindPopup(popup_38b60a4ffe74919ea5f46cd4a06cd4e6)
#         ;
#
#
#
#
#             var marker_c6a47aba839aed5b45c6e8effa07c6fd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bcb8a6a5cb9b2c2a1e260dcea5b6b824);
#
#
#         var popup_d3ded17cfe51baae700fabf077af4d7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a436fb4ffa6c0f9952e4abf550cf5ff = $(`&lt;div id=&quot;html_8a436fb4ffa6c0f9952e4abf550cf5ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d3ded17cfe51baae700fabf077af4d7b.setContent(html_8a436fb4ffa6c0f9952e4abf550cf5ff);
#
#
#
#         marker_
