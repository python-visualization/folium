# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e8f78569a8c2b25cea8407b1e0681a27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e8f78569a8c2b25cea8407b1e0681a27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e8f78569a8c2b25cea8407b1e0681a27 = L.map(
#                 &quot;map_e8f78569a8c2b25cea8407b1e0681a27&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c91b73506119e8ae89acd6521aa061c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c91b73506119e8ae89acd6521aa061c4.addTo(map_e8f78569a8c2b25cea8407b1e0681a27);
#
#
#             var marker_c4632296f3207e31e7090a34a9aa1275 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e8f78569a8c2b25cea8407b1e0681a27);
#
#
#         var popup_f22920a29ac05e782156fbdeb86b8525 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a6a6393753cf5870dd1330c66e05bc4 = $(`&lt;div id=&quot;html_1a6a6393753cf5870dd1330c66e05bc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f22920a29ac05e782156fbdeb86b8525.setContent(html_1a6a6393753cf5870dd1330c66e05bc4);
#
#
#
#         marker_c4632296f3207e31e7090a34a9aa1275.bindPopup(popup_f22920a29ac05e782156fbdeb86b8525)
#         ;
#
#
#
#
#             var marker_51e40530948ed472fec9cb360c29d992 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e8f78569a8c2b25cea8407b1e0681a27);
#
#
#         var popup_ea31943a53a4bb5837e76ee21b47e4db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c38a7e3e02edb3b36d4faa6307532b00 = $(`&lt;div id=&quot;html_c38a7e3e02edb3b36d4faa6307532b00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ea31943a53a4bb5837e76ee21b47e4db.setContent(html_c38a7e3e02edb3b36d4faa6307532b00);
#
#
#
#         marker_51e40530948ed472fec9cb360c29d992.bindPopup(popup_ea31943a53a4bb5837e76ee21b47e4db)
#         ;
#
#
#
#
#             var marker_53186d16669cb46d8adfbff87c6a729d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e8f78569a8c2b25cea8407b1e0681a27);
#
#
#         var popup_d1dd36df94d4e559cb062206516345a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1a3a24e831df486d2569f7ea633ea8c = $(`&lt;div id=&quot;html_a1a3a24e831df486d2569f7ea633ea8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d1dd36df94d4e559cb062206516345a1.setContent(html_a1a3a24e831df486d2569f7ea633ea8c);
#
#
#
#         marker_53186d16669cb46d8adfbff87c6a729d.bindPopup(popup_d1dd36df94d4e559cb062206516345a1)
#         ;
#
#
#
#
#             var marker_5612ba29845420591c3e5b55c8121c21 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e8f78569a8c2b25cea8407b1e0681a27);
#
#
#         var popup_dfad0c33e84d55d310d99f1bf0ea3ea9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fa5e6bf53537dbee4dbd799684fc54b = $(`&lt;div id=&quot;html_1fa5e6bf53537dbee4dbd799684fc54b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dfad0c33e84d55d310d99f1bf0ea3ea9.setContent(html_1fa5e6bf53537dbee4dbd799684fc54b);
#
#
#
#         marker_5612ba29845420591c3e5b55c8121c21.bindPopup(popup_dfad0c33e84d55d310d99f1bf0ea3ea9)
#         ;
#
#
#
#
#             var marker_1d4c905893aaaa52e2f90b616c5aa77f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e8f78569a8c2b25cea8407b1e0681a27);
#
#
#         var popup_911999ca4712ff1c6e9788073b4856aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_649f2371846d286053c638476118d833 = $(`&lt;div id=&quot;html_649f2371846d286053c638476118d833&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_911999ca4712ff1c6e9788073b4856aa.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b35ce90817a7c859efbd19e0bab8268 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b35ce90817a7c859efbd19e0bab8268&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b35ce90817a7c859efbd19e0bab8268 = L.map(
#                 &quot;map_0b35ce90817a7c859efbd19e0bab8268&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07b304b767c8694bcf41f9e0f3f7da80 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07b304b767c8694bcf41f9e0f3f7da80.addTo(map_0b35ce90817a7c859efbd19e0bab8268);
#
#
#             var feature_group_e032af8775897de1bc23d6c0479ba649 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0a9c0bd5675d6791328563e91b16d1fa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e032af8775897de1bc23d6c0479ba649);
#
#
#         var popup_0ad99bcdf8bb336d78bed76a56141c5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45e3410740139317fc4dffbb6a0af965 = $(`&lt;div id=&quot;html_45e3410740139317fc4dffbb6a0af965&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0ad99bcdf8bb336d78bed76a56141c5b.setContent(html_45e3410740139317fc4dffbb6a0af965);
#
#
#
#         marker_0a9c0bd5675d6791328563e91b16d1fa.bindPopup(popup_0ad99bcdf8bb336d78bed76a56141c5b)
#         ;
#
#
#
#
#             var marker_0f3a043cbecb44eba4039f19ff0008f8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e032af8775897de1bc23d6c0479ba649);
#
#
#         var popup_4f0eb52d9ca2687215841f0d0b0967cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea228c9266b514d6d4032f29aa18abb1 = $(`&lt;div id=&quot;html_ea228c9266b514d6d4032f29aa18abb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4f0eb52d9ca2687215841f0d0b0967cc.setContent(html_ea228c9266b514d6d4032f29aa18abb1);
#
#
#
#         marker_0f3a043cbecb44eba4039f19ff0008f8.bindPopup(popup_4f0eb52d9ca2687215841f0d0b0967cc)
#         ;
#
#
#
#
#             var marker_5123c0970afef74eb8e56b29177ccc4a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e032af8775897de1bc23d6c0479ba649);
#
#
#         var popup_2b3ac001dc00e139c2a6598d18acd293 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_446145523ca7ad5f32edd334f9832d34 = $(`&lt;div id=&quot;html_446145523ca7ad5f32edd334f9832d34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2b3ac001dc00e139c2a6598d18acd293.setContent(html_446145523ca7ad5f32edd334f9832d34);
#
#
#
#         marker_5123c0970afef74eb8e56b29177ccc4a.bindPopup(popup_2b3ac001dc00e139c2a6598d18acd293)
#         ;
#
#
#
#
#             var marker_c30d462e45d4459361226f5a22e4d86c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e032af8775897de1bc23d6c0479ba649);
#
#
#         var popup_1900fd6e6ddf86b182ead8769d5be09a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a8d568508dfd0929d2b981e64ae7bdc = $(`&lt;div id=&quot;html_1a8d568508dfd0929d2b981e64ae7bdc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1900fd6e6ddf86b182ead8769d5be09a.setContent(html_1a8d568508dfd0929d2b981e64ae7bdc);
#
#
#
#         marker_c30d462e45d4459361226f5a22e4d86c.bindPopup(popup_1900fd6e6ddf86b182ead8769d5be09a)
#         ;
#
#
#
#
#             var marker_fd0ad25f154efc784aab002cc42918f5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e032af8775897de1bc23d6c0479ba649);
#
#
#         var popup_0b7a5b191fdc4e60ca4a5f73fe6a3e94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac8d77e728412039948459a61ede5d3a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac8d77e728412039948459a61ede5d3a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac8d77e728412039948459a61ede5d3a = L.map(
#                 &quot;map_ac8d77e728412039948459a61ede5d3a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d493783d0e4f108d6f9b2e79bd397f1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d493783d0e4f108d6f9b2e79bd397f1b.addTo(map_ac8d77e728412039948459a61ede5d3a);
#
#
#             var feature_group_1534b76695caa91fdb913130bcc4bd3b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1534b76695caa91fdb913130bcc4bd3b.addTo(map_ac8d77e728412039948459a61ede5d3a);
#
#
#             var feature_group_sub_group_eef7f56214c5061a9bc6cd3b60a29222 = L.featureGroup.subGroup(
#                 feature_group_1534b76695caa91fdb913130bcc4bd3b
#             );
#
#
#             var marker_6558ecc275dae60785172938f3d5b936 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_eef7f56214c5061a9bc6cd3b60a29222);
#
#
#         var popup_85d7fd746817bd6bd8673710c519d83d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e1f148c6602befe94da28045616be17 = $(`&lt;div id=&quot;html_6e1f148c6602befe94da28045616be17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_85d7fd746817bd6bd8673710c519d83d.setContent(html_6e1f148c6602befe94da28045616be17);
#
#
#
#         marker_6558ecc275dae60785172938f3d5b936.bindPopup(popup_85d7fd746817bd6bd8673710c519d83d)
#         ;
#
#
#
#
#             var marker_3cd84496a8cf08684cb1d676d451b6e7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_eef7f56214c5061a9bc6cd3b60a29222);
#
#
#         var popup_c90d1785f8b950e15f2404ebbcf6e9e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a436e25837bd282a160807a003e34b8 = $(`&lt;div id=&quot;html_4a436e25837bd282a160807a003e34b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c90d1785f8b950e15f2404ebbcf6e9e1.setContent(html_4a436e25837bd282a160807a003e34b8);
#
#
#
#         marker_3cd84496a8cf08684cb1d676d451b6e7.bindPopup(popup_c90d1785f8b950e15f2404ebbcf6e9e1)
#         ;
#
#
#
#
#             var marker_7de7f066749a37807e46bda53bd683c6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_eef7f56214c5061a9bc6cd3b60a29222);
#
#
#         var popup_99562f6b483d6e059da04235d66934a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d21adf9cc2a08ad5d89ccd4c306a3491 = $(`&lt;div id=&quot;html_d21adf9cc2a08ad5d89ccd4c306a3491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_99562f6b483d6e059da04235d66934a7.setContent(html_d21adf9cc2a08ad5d89ccd4c306a3491);
#
#
#
#         marker_7de7f066749a37807e46bda53bd683c6.bindPopup(popup_99562f6b483d6e059da04235d66934a7)
#         ;
#
#
#
#
#             var marker_4faf5fca0353f8350d55e32819d0d5c9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_eef7f56214c5061a9bc6cd3b60a29222);
#
#
#         var popup_deb9beefc059a343a5d6dcaf3d28cb57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9e50a7fc9cfd546664e8dbb66c55015 = $(`&lt;div id=&quot;html_d9e50a7fc9cfd546664e8dbb66c55015&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_deb9beefc059a343a5d6dcaf3d28cb57.setContent(html_d9e50a7fc9cfd546664e8dbb66c55015);
#
#
#
#         marker_
