# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_785e5671366ad3b1898151e4f603dbed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_785e5671366ad3b1898151e4f603dbed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_785e5671366ad3b1898151e4f603dbed = L.map(
#                 &quot;map_785e5671366ad3b1898151e4f603dbed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9005c13137aee5ba71f5e4da08628f05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9005c13137aee5ba71f5e4da08628f05.addTo(map_785e5671366ad3b1898151e4f603dbed);
#
#
#             var marker_93d744340b14d17ae23a43fa7738aa33 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_785e5671366ad3b1898151e4f603dbed);
#
#
#         var popup_e6c9062658dcffe196fb18cd6cf4bcb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fe8c2ee6fd2d7af722af808bf589b67 = $(`&lt;div id=&quot;html_3fe8c2ee6fd2d7af722af808bf589b67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e6c9062658dcffe196fb18cd6cf4bcb9.setContent(html_3fe8c2ee6fd2d7af722af808bf589b67);
#
#
#
#         marker_93d744340b14d17ae23a43fa7738aa33.bindPopup(popup_e6c9062658dcffe196fb18cd6cf4bcb9)
#         ;
#
#
#
#
#             var marker_12e30eadf7c9fdd546569d50d0943b45 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_785e5671366ad3b1898151e4f603dbed);
#
#
#         var popup_b05e702e7e5b18c667080d45bc0eab04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d17bac94fd80c2bf4080fd9ce9257582 = $(`&lt;div id=&quot;html_d17bac94fd80c2bf4080fd9ce9257582&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b05e702e7e5b18c667080d45bc0eab04.setContent(html_d17bac94fd80c2bf4080fd9ce9257582);
#
#
#
#         marker_12e30eadf7c9fdd546569d50d0943b45.bindPopup(popup_b05e702e7e5b18c667080d45bc0eab04)
#         ;
#
#
#
#
#             var marker_706ec85416a3cd9037884ca38ed96ac5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_785e5671366ad3b1898151e4f603dbed);
#
#
#         var popup_f2af254c17f02d30720649b846278b54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b217236d5fc43d45f2fa460d45dce68 = $(`&lt;div id=&quot;html_4b217236d5fc43d45f2fa460d45dce68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f2af254c17f02d30720649b846278b54.setContent(html_4b217236d5fc43d45f2fa460d45dce68);
#
#
#
#         marker_706ec85416a3cd9037884ca38ed96ac5.bindPopup(popup_f2af254c17f02d30720649b846278b54)
#         ;
#
#
#
#
#             var marker_53d9f2e2fd86b0601f65110ac86e4884 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_785e5671366ad3b1898151e4f603dbed);
#
#
#         var popup_3f0beaa3b791d899a077b89456c73c82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbb731a6ba34cc8ea2c67b05664d537f = $(`&lt;div id=&quot;html_bbb731a6ba34cc8ea2c67b05664d537f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3f0beaa3b791d899a077b89456c73c82.setContent(html_bbb731a6ba34cc8ea2c67b05664d537f);
#
#
#
#         marker_53d9f2e2fd86b0601f65110ac86e4884.bindPopup(popup_3f0beaa3b791d899a077b89456c73c82)
#         ;
#
#
#
#
#             var marker_60917782dd725df00b2d7f18d33f0d4c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_785e5671366ad3b1898151e4f603dbed);
#
#
#         var popup_2f0b722e18bb4dc1f68e6adf715301d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_489843d5ef0759dd2ece9f2747217e63 = $(`&lt;div id=&quot;html_489843d5ef0759dd2ece9f2747217e63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2f0b722e18bb4dc1f68e6adf715301d6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_365cdfdfb610c8699af105f40dd7380a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_365cdfdfb610c8699af105f40dd7380a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_365cdfdfb610c8699af105f40dd7380a = L.map(
#                 &quot;map_365cdfdfb610c8699af105f40dd7380a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee4b95df70a309bb8c69f532a82a23f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ee4b95df70a309bb8c69f532a82a23f8.addTo(map_365cdfdfb610c8699af105f40dd7380a);
#
#
#             var feature_group_975cb31b349f4c25f44ec20ff34a46ee = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3ce453a7d8fe99efeeec555b5cbf4dc2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_975cb31b349f4c25f44ec20ff34a46ee);
#
#
#         var popup_d8507a3c69751203a50f05a8694a7037 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90a0fa721d0f17cfde34cac7d22774a4 = $(`&lt;div id=&quot;html_90a0fa721d0f17cfde34cac7d22774a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d8507a3c69751203a50f05a8694a7037.setContent(html_90a0fa721d0f17cfde34cac7d22774a4);
#
#
#
#         marker_3ce453a7d8fe99efeeec555b5cbf4dc2.bindPopup(popup_d8507a3c69751203a50f05a8694a7037)
#         ;
#
#
#
#
#             var marker_0fc9cfd14d92bb2e594a91c91e960f52 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_975cb31b349f4c25f44ec20ff34a46ee);
#
#
#         var popup_739003bf6a7cbe1aefc4e449271bc138 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6953cb570a3e6a9e989f2a72cba7589b = $(`&lt;div id=&quot;html_6953cb570a3e6a9e989f2a72cba7589b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_739003bf6a7cbe1aefc4e449271bc138.setContent(html_6953cb570a3e6a9e989f2a72cba7589b);
#
#
#
#         marker_0fc9cfd14d92bb2e594a91c91e960f52.bindPopup(popup_739003bf6a7cbe1aefc4e449271bc138)
#         ;
#
#
#
#
#             var marker_04f4234b2b6a2f819066768941b45a14 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_975cb31b349f4c25f44ec20ff34a46ee);
#
#
#         var popup_e8fff846d72110d47acb4ee11f483df6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_567303ce5e2c6e92b630c07577938973 = $(`&lt;div id=&quot;html_567303ce5e2c6e92b630c07577938973&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e8fff846d72110d47acb4ee11f483df6.setContent(html_567303ce5e2c6e92b630c07577938973);
#
#
#
#         marker_04f4234b2b6a2f819066768941b45a14.bindPopup(popup_e8fff846d72110d47acb4ee11f483df6)
#         ;
#
#
#
#
#             var marker_b53fab8079b6ded797b1cabfd8666269 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_975cb31b349f4c25f44ec20ff34a46ee);
#
#
#         var popup_07f752d7b6b320bb71c233b1a947a74f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3bcfd5666a6613b50c3f6e9c8aa9647 = $(`&lt;div id=&quot;html_b3bcfd5666a6613b50c3f6e9c8aa9647&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_07f752d7b6b320bb71c233b1a947a74f.setContent(html_b3bcfd5666a6613b50c3f6e9c8aa9647);
#
#
#
#         marker_b53fab8079b6ded797b1cabfd8666269.bindPopup(popup_07f752d7b6b320bb71c233b1a947a74f)
#         ;
#
#
#
#
#             var marker_93ce540c0644ac36138de72597c3854b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_975cb31b349f4c25f44ec20ff34a46ee);
#
#
#         var popup_02176380083a3f0707ea74ce419ff2ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb959542b9a7a90910fc617df2d79d6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb959542b9a7a90910fc617df2d79d6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb959542b9a7a90910fc617df2d79d6d = L.map(
#                 &quot;map_eb959542b9a7a90910fc617df2d79d6d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b5352f8154250b68b5168833dbebb48a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b5352f8154250b68b5168833dbebb48a.addTo(map_eb959542b9a7a90910fc617df2d79d6d);
#
#
#             var feature_group_1b98df7993d0e194890cda48e33282f2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1b98df7993d0e194890cda48e33282f2.addTo(map_eb959542b9a7a90910fc617df2d79d6d);
#
#
#             var feature_group_sub_group_6d2ed7d1a3506c0526d4817446e7d612 = L.featureGroup.subGroup(
#                 feature_group_1b98df7993d0e194890cda48e33282f2
#             );
#
#
#             var marker_aecf7de76a7c26d401d4befc29cd909b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6d2ed7d1a3506c0526d4817446e7d612);
#
#
#         var popup_52f913382d6ec97130cf1e28c98046c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21358e99ea0bb2e2dd608da86c588f32 = $(`&lt;div id=&quot;html_21358e99ea0bb2e2dd608da86c588f32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_52f913382d6ec97130cf1e28c98046c7.setContent(html_21358e99ea0bb2e2dd608da86c588f32);
#
#
#
#         marker_aecf7de76a7c26d401d4befc29cd909b.bindPopup(popup_52f913382d6ec97130cf1e28c98046c7)
#         ;
#
#
#
#
#             var marker_c3487eb45600a6b6a4ac894eeee5f7ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6d2ed7d1a3506c0526d4817446e7d612);
#
#
#         var popup_b05264ea7b0dd99b53558c958824be13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14ecac0ab9b07c53d740476afd4c6a22 = $(`&lt;div id=&quot;html_14ecac0ab9b07c53d740476afd4c6a22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b05264ea7b0dd99b53558c958824be13.setContent(html_14ecac0ab9b07c53d740476afd4c6a22);
#
#
#
#         marker_c3487eb45600a6b6a4ac894eeee5f7ea.bindPopup(popup_b05264ea7b0dd99b53558c958824be13)
#         ;
#
#
#
#
#             var marker_3b31aedcfa0352cf774f107cba174156 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6d2ed7d1a3506c0526d4817446e7d612);
#
#
#         var popup_8e0e38969472d26ea55dc5fc6cb88ded = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06ed93f85388dfc59576c04c4bfc025c = $(`&lt;div id=&quot;html_06ed93f85388dfc59576c04c4bfc025c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8e0e38969472d26ea55dc5fc6cb88ded.setContent(html_06ed93f85388dfc59576c04c4bfc025c);
#
#
#
#         marker_3b31aedcfa0352cf774f107cba174156.bindPopup(popup_8e0e38969472d26ea55dc5fc6cb88ded)
#         ;
#
#
#
#
#             var marker_24a4fd0a00c3033a5d46337d3acf9df0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6d2ed7d1a3506c0526d4817446e7d612);
#
#
#         var popup_9ccc26b09733e312bd268aa64dc51e6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e004cd8143ab42ca7630233f1e2d004e = $(`&lt;div id=&quot;html_e004cd8143ab42ca7630233f1e2d004e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9ccc26b09733e312bd268aa64dc51e6e.setContent(html_e004cd8143ab42ca7630233f1e2d004e);
#
#
#
#         marker_
