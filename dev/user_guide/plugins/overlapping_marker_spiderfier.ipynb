# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ecc1d1a6e97f4683da063c852f8b75b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ecc1d1a6e97f4683da063c852f8b75b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ecc1d1a6e97f4683da063c852f8b75b7 = L.map(
#                 &quot;map_ecc1d1a6e97f4683da063c852f8b75b7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d0c49baef88b5525dd39fdf492b1a4b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d0c49baef88b5525dd39fdf492b1a4b.addTo(map_ecc1d1a6e97f4683da063c852f8b75b7);
#
#
#             var marker_709e14f5ad159dc5a8eeb98297be8949 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ecc1d1a6e97f4683da063c852f8b75b7);
#
#
#         var popup_5fb188e565d0c736c2950ee000278566 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4d51f667876cdb4786c69850954cc0f = $(`&lt;div id=&quot;html_b4d51f667876cdb4786c69850954cc0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5fb188e565d0c736c2950ee000278566.setContent(html_b4d51f667876cdb4786c69850954cc0f);
#
#
#
#         marker_709e14f5ad159dc5a8eeb98297be8949.bindPopup(popup_5fb188e565d0c736c2950ee000278566)
#         ;
#
#
#
#
#             var marker_2ce17aa58828ac8ac7af5c4656ecb2ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ecc1d1a6e97f4683da063c852f8b75b7);
#
#
#         var popup_b6bfd0313194c664a042ef5889b860a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7c62f67499c449ebaddfec837a67385 = $(`&lt;div id=&quot;html_b7c62f67499c449ebaddfec837a67385&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b6bfd0313194c664a042ef5889b860a3.setContent(html_b7c62f67499c449ebaddfec837a67385);
#
#
#
#         marker_2ce17aa58828ac8ac7af5c4656ecb2ee.bindPopup(popup_b6bfd0313194c664a042ef5889b860a3)
#         ;
#
#
#
#
#             var marker_7572140a5fe582423ca5b1e27e27ac7d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ecc1d1a6e97f4683da063c852f8b75b7);
#
#
#         var popup_2fa3e766ba4659de17967724939d530d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7143fe05df369e3bad6a1a826e7db17 = $(`&lt;div id=&quot;html_a7143fe05df369e3bad6a1a826e7db17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2fa3e766ba4659de17967724939d530d.setContent(html_a7143fe05df369e3bad6a1a826e7db17);
#
#
#
#         marker_7572140a5fe582423ca5b1e27e27ac7d.bindPopup(popup_2fa3e766ba4659de17967724939d530d)
#         ;
#
#
#
#
#             var marker_24acaec2251c97883c91b66d8ff5cf40 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ecc1d1a6e97f4683da063c852f8b75b7);
#
#
#         var popup_9ace570367d28792b7332d3f886521d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8db2910a4db4ec241c09292c4cdf6d7 = $(`&lt;div id=&quot;html_d8db2910a4db4ec241c09292c4cdf6d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9ace570367d28792b7332d3f886521d3.setContent(html_d8db2910a4db4ec241c09292c4cdf6d7);
#
#
#
#         marker_24acaec2251c97883c91b66d8ff5cf40.bindPopup(popup_9ace570367d28792b7332d3f886521d3)
#         ;
#
#
#
#
#             var marker_143998cb10e4867dae847fbfb8872ed3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ecc1d1a6e97f4683da063c852f8b75b7);
#
#
#         var popup_82a7b590500d69704f36aec8000434d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caacb2d04c3a933c94cce021824ae378 = $(`&lt;div id=&quot;html_caacb2d04c3a933c94cce021824ae378&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_82a7b590500d69704f36aec8000434d0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20cc082d2ad20d2b67b3cca698ae1ca7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20cc082d2ad20d2b67b3cca698ae1ca7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20cc082d2ad20d2b67b3cca698ae1ca7 = L.map(
#                 &quot;map_20cc082d2ad20d2b67b3cca698ae1ca7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_75fec0685b4ceeee01ad026b79cf152b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_75fec0685b4ceeee01ad026b79cf152b.addTo(map_20cc082d2ad20d2b67b3cca698ae1ca7);
#
#
#             var feature_group_f3159d906aba511e73301b7a9716f4d5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2b1a7e7ca64e6ea7de6f3f2702692a8f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f3159d906aba511e73301b7a9716f4d5);
#
#
#         var popup_8407a4039f08973a287f059aa17ec806 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b8c2df24df8f9c2a2c7d28001b45614 = $(`&lt;div id=&quot;html_8b8c2df24df8f9c2a2c7d28001b45614&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8407a4039f08973a287f059aa17ec806.setContent(html_8b8c2df24df8f9c2a2c7d28001b45614);
#
#
#
#         marker_2b1a7e7ca64e6ea7de6f3f2702692a8f.bindPopup(popup_8407a4039f08973a287f059aa17ec806)
#         ;
#
#
#
#
#             var marker_9256c0231940d469fabb666d5a755a1d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f3159d906aba511e73301b7a9716f4d5);
#
#
#         var popup_918d6d5b690a3cf3cc1f4cc6854ce4c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dcc6bf0775a889dac82b81135f1c77a = $(`&lt;div id=&quot;html_2dcc6bf0775a889dac82b81135f1c77a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_918d6d5b690a3cf3cc1f4cc6854ce4c7.setContent(html_2dcc6bf0775a889dac82b81135f1c77a);
#
#
#
#         marker_9256c0231940d469fabb666d5a755a1d.bindPopup(popup_918d6d5b690a3cf3cc1f4cc6854ce4c7)
#         ;
#
#
#
#
#             var marker_82521ff908c27b9d7db82f23497763ab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f3159d906aba511e73301b7a9716f4d5);
#
#
#         var popup_31f7423a782b5d8e3625cc5a3a7b5630 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ac1fb38e2493cf9a141247b95c38de6 = $(`&lt;div id=&quot;html_5ac1fb38e2493cf9a141247b95c38de6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_31f7423a782b5d8e3625cc5a3a7b5630.setContent(html_5ac1fb38e2493cf9a141247b95c38de6);
#
#
#
#         marker_82521ff908c27b9d7db82f23497763ab.bindPopup(popup_31f7423a782b5d8e3625cc5a3a7b5630)
#         ;
#
#
#
#
#             var marker_9b00d153e6c11eebd942a44dd515f4ba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f3159d906aba511e73301b7a9716f4d5);
#
#
#         var popup_1793f196a46476e7f25736aec463fa4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70f2590e2e3dead063e0e773d308c8e9 = $(`&lt;div id=&quot;html_70f2590e2e3dead063e0e773d308c8e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1793f196a46476e7f25736aec463fa4c.setContent(html_70f2590e2e3dead063e0e773d308c8e9);
#
#
#
#         marker_9b00d153e6c11eebd942a44dd515f4ba.bindPopup(popup_1793f196a46476e7f25736aec463fa4c)
#         ;
#
#
#
#
#             var marker_c74f3a83b905fdbdaf3d4dc2ee7cb079 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f3159d906aba511e73301b7a9716f4d5);
#
#
#         var popup_60ff0db0f2686c556b47ae1dc252d40e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3895049ac70893e4d548be6cf006bf1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3895049ac70893e4d548be6cf006bf1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3895049ac70893e4d548be6cf006bf1f = L.map(
#                 &quot;map_3895049ac70893e4d548be6cf006bf1f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96806c7933c6782163e66205f6acaf15 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96806c7933c6782163e66205f6acaf15.addTo(map_3895049ac70893e4d548be6cf006bf1f);
#
#
#             var feature_group_c389b233f94b09327885bfd2cc895da3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c389b233f94b09327885bfd2cc895da3.addTo(map_3895049ac70893e4d548be6cf006bf1f);
#
#
#             var feature_group_sub_group_9529ea64d971a0254554561e2e8bede9 = L.featureGroup.subGroup(
#                 feature_group_c389b233f94b09327885bfd2cc895da3
#             );
#
#
#             var marker_deda0b2e81cc3e393dda2912b73dabc7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9529ea64d971a0254554561e2e8bede9);
#
#
#         var popup_3d843e0958b798d8e56b7ce5d3710c4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b093a938cf320b0f7c74b9d3fc47460 = $(`&lt;div id=&quot;html_9b093a938cf320b0f7c74b9d3fc47460&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3d843e0958b798d8e56b7ce5d3710c4c.setContent(html_9b093a938cf320b0f7c74b9d3fc47460);
#
#
#
#         marker_deda0b2e81cc3e393dda2912b73dabc7.bindPopup(popup_3d843e0958b798d8e56b7ce5d3710c4c)
#         ;
#
#
#
#
#             var marker_aa2b384ccbac80023391d44dca423f5f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9529ea64d971a0254554561e2e8bede9);
#
#
#         var popup_1ffd1409bce35e24196bee153123385a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92555b310a3f0e4b7c9e1b9356ba452c = $(`&lt;div id=&quot;html_92555b310a3f0e4b7c9e1b9356ba452c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1ffd1409bce35e24196bee153123385a.setContent(html_92555b310a3f0e4b7c9e1b9356ba452c);
#
#
#
#         marker_aa2b384ccbac80023391d44dca423f5f.bindPopup(popup_1ffd1409bce35e24196bee153123385a)
#         ;
#
#
#
#
#             var marker_de3380a829bdd1ca0f901238c765aae2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9529ea64d971a0254554561e2e8bede9);
#
#
#         var popup_32f82bd1d61bbe727eefaa0e58a44257 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20f7c4acfbc34a991597ff23a0bd8902 = $(`&lt;div id=&quot;html_20f7c4acfbc34a991597ff23a0bd8902&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_32f82bd1d61bbe727eefaa0e58a44257.setContent(html_20f7c4acfbc34a991597ff23a0bd8902);
#
#
#
#         marker_de3380a829bdd1ca0f901238c765aae2.bindPopup(popup_32f82bd1d61bbe727eefaa0e58a44257)
#         ;
#
#
#
#
#             var marker_641a2cea14afef6e5967edf4a7fabcf2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9529ea64d971a0254554561e2e8bede9);
#
#
#         var popup_83cc809649f0bdf3fe34fa4f4d8ae2f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4f09eaa1dd05f8d90f6dc1ab790f93f = $(`&lt;div id=&quot;html_a4f09eaa1dd05f8d90f6dc1ab790f93f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_83cc809649f0bdf3fe34fa4f4d8ae2f9.setContent(html_a4f09eaa1dd05f8d90f6dc1ab790f93f);
#
#
#
#         marker_
