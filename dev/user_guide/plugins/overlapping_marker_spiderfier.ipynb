# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c63bfdca5892c13e838d070a5b6b0596 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c63bfdca5892c13e838d070a5b6b0596&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c63bfdca5892c13e838d070a5b6b0596 = L.map(
#                 &quot;map_c63bfdca5892c13e838d070a5b6b0596&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9aa28997fa09eb74c01920d31522e026 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9aa28997fa09eb74c01920d31522e026.addTo(map_c63bfdca5892c13e838d070a5b6b0596);
#
#
#             var marker_4728bccfd7b56b4038da2ae31a3c3320 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c63bfdca5892c13e838d070a5b6b0596);
#
#
#         var popup_8effa27fa1e8abc9ac49fb96ea092106 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abc82c962f176200e96d32f03d28d924 = $(`&lt;div id=&quot;html_abc82c962f176200e96d32f03d28d924&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8effa27fa1e8abc9ac49fb96ea092106.setContent(html_abc82c962f176200e96d32f03d28d924);
#
#
#
#         marker_4728bccfd7b56b4038da2ae31a3c3320.bindPopup(popup_8effa27fa1e8abc9ac49fb96ea092106)
#         ;
#
#
#
#
#             var marker_f01de37e3609fabc75feff25031c0a9c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c63bfdca5892c13e838d070a5b6b0596);
#
#
#         var popup_4b2f13a2774ffaaa6090b6100d202810 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d0b67660d1df32726475123ed3b47ac = $(`&lt;div id=&quot;html_1d0b67660d1df32726475123ed3b47ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4b2f13a2774ffaaa6090b6100d202810.setContent(html_1d0b67660d1df32726475123ed3b47ac);
#
#
#
#         marker_f01de37e3609fabc75feff25031c0a9c.bindPopup(popup_4b2f13a2774ffaaa6090b6100d202810)
#         ;
#
#
#
#
#             var marker_eadb87f31f46274710be580989f60fd6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c63bfdca5892c13e838d070a5b6b0596);
#
#
#         var popup_fe27ffe013505cdf110ad01c01a6daa6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2261a50dc6b4cbfd4b10fbba22db328a = $(`&lt;div id=&quot;html_2261a50dc6b4cbfd4b10fbba22db328a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fe27ffe013505cdf110ad01c01a6daa6.setContent(html_2261a50dc6b4cbfd4b10fbba22db328a);
#
#
#
#         marker_eadb87f31f46274710be580989f60fd6.bindPopup(popup_fe27ffe013505cdf110ad01c01a6daa6)
#         ;
#
#
#
#
#             var marker_a09a40537522a71edefff1ea30b0f7f1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c63bfdca5892c13e838d070a5b6b0596);
#
#
#         var popup_f35b9828d67686f5f296c0407d40622e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_524fa88aa8dd849c1053ba3d5d4e18ad = $(`&lt;div id=&quot;html_524fa88aa8dd849c1053ba3d5d4e18ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f35b9828d67686f5f296c0407d40622e.setContent(html_524fa88aa8dd849c1053ba3d5d4e18ad);
#
#
#
#         marker_a09a40537522a71edefff1ea30b0f7f1.bindPopup(popup_f35b9828d67686f5f296c0407d40622e)
#         ;
#
#
#
#
#             var marker_03683a5fc066d58b903c03136dc84eff = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c63bfdca5892c13e838d070a5b6b0596);
#
#
#         var popup_4ee1f5984f16dab6b3963dca7ca753d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f3e0d4336e2b8005433feac02f469c4 = $(`&lt;div id=&quot;html_4f3e0d4336e2b8005433feac02f469c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4ee1f5984f16dab6b3963dca7ca753d9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bff6e3ecd327a5c54b523971cdc30f17 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bff6e3ecd327a5c54b523971cdc30f17&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bff6e3ecd327a5c54b523971cdc30f17 = L.map(
#                 &quot;map_bff6e3ecd327a5c54b523971cdc30f17&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e68358236ae309a6053154db652f8549 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e68358236ae309a6053154db652f8549.addTo(map_bff6e3ecd327a5c54b523971cdc30f17);
#
#
#             var feature_group_e4940f90e48bcba1e4cc7c00e6f752fa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f20b70fdc6d96248fddb2358d15befa4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e4940f90e48bcba1e4cc7c00e6f752fa);
#
#
#         var popup_1e22c75699fad2fc69436e93f0fb6f41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45af3c63a9961534bde697a5ffa65d4b = $(`&lt;div id=&quot;html_45af3c63a9961534bde697a5ffa65d4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1e22c75699fad2fc69436e93f0fb6f41.setContent(html_45af3c63a9961534bde697a5ffa65d4b);
#
#
#
#         marker_f20b70fdc6d96248fddb2358d15befa4.bindPopup(popup_1e22c75699fad2fc69436e93f0fb6f41)
#         ;
#
#
#
#
#             var marker_0782ab57bb552954f60d1e360448e6ad = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e4940f90e48bcba1e4cc7c00e6f752fa);
#
#
#         var popup_61798106185b7d9efdc61ac4a34b75c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c49715861cd0085be9796d24ad1a5d9e = $(`&lt;div id=&quot;html_c49715861cd0085be9796d24ad1a5d9e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_61798106185b7d9efdc61ac4a34b75c3.setContent(html_c49715861cd0085be9796d24ad1a5d9e);
#
#
#
#         marker_0782ab57bb552954f60d1e360448e6ad.bindPopup(popup_61798106185b7d9efdc61ac4a34b75c3)
#         ;
#
#
#
#
#             var marker_0316d76e5c54bee374b5632fb232f9b6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e4940f90e48bcba1e4cc7c00e6f752fa);
#
#
#         var popup_6bfc1d507c9af1bdcbcd362df20dc6f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4591bde94f46eb991e4ae6fb6f3ff6ea = $(`&lt;div id=&quot;html_4591bde94f46eb991e4ae6fb6f3ff6ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6bfc1d507c9af1bdcbcd362df20dc6f4.setContent(html_4591bde94f46eb991e4ae6fb6f3ff6ea);
#
#
#
#         marker_0316d76e5c54bee374b5632fb232f9b6.bindPopup(popup_6bfc1d507c9af1bdcbcd362df20dc6f4)
#         ;
#
#
#
#
#             var marker_5468227917207704e14adfcbc4cc8f35 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e4940f90e48bcba1e4cc7c00e6f752fa);
#
#
#         var popup_9434c8e9dca541f213f5c5d65786c84e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f257e6594f0cf8eef93cae2199d16011 = $(`&lt;div id=&quot;html_f257e6594f0cf8eef93cae2199d16011&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9434c8e9dca541f213f5c5d65786c84e.setContent(html_f257e6594f0cf8eef93cae2199d16011);
#
#
#
#         marker_5468227917207704e14adfcbc4cc8f35.bindPopup(popup_9434c8e9dca541f213f5c5d65786c84e)
#         ;
#
#
#
#
#             var marker_c34ac60b69b369a4339ad46f84bd0008 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e4940f90e48bcba1e4cc7c00e6f752fa);
#
#
#         var popup_516c28d48d9a2ece78f461af2c2d7bb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4788bba4cecfe0b73dda18a4f23c1bcf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4788bba4cecfe0b73dda18a4f23c1bcf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4788bba4cecfe0b73dda18a4f23c1bcf = L.map(
#                 &quot;map_4788bba4cecfe0b73dda18a4f23c1bcf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64e525f12391afef17a581d085949ce3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64e525f12391afef17a581d085949ce3.addTo(map_4788bba4cecfe0b73dda18a4f23c1bcf);
#
#
#             var feature_group_9d1cd2b0e6382bfb23058857b81e1b5a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9d1cd2b0e6382bfb23058857b81e1b5a.addTo(map_4788bba4cecfe0b73dda18a4f23c1bcf);
#
#
#             var feature_group_sub_group_dc4a8e3bb2dc3d528aba66737399fdc5 = L.featureGroup.subGroup(
#                 feature_group_9d1cd2b0e6382bfb23058857b81e1b5a
#             );
#
#
#             var marker_5d27a8f4de250ba70a0af78804cefe24 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc4a8e3bb2dc3d528aba66737399fdc5);
#
#
#         var popup_b3effe6d965f2eb1cebfcbc1257effbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af53bda94901f37b3a91737fcc98a726 = $(`&lt;div id=&quot;html_af53bda94901f37b3a91737fcc98a726&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b3effe6d965f2eb1cebfcbc1257effbe.setContent(html_af53bda94901f37b3a91737fcc98a726);
#
#
#
#         marker_5d27a8f4de250ba70a0af78804cefe24.bindPopup(popup_b3effe6d965f2eb1cebfcbc1257effbe)
#         ;
#
#
#
#
#             var marker_950dd80ac13d348a0d96302ae23e1b85 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc4a8e3bb2dc3d528aba66737399fdc5);
#
#
#         var popup_4a2d8a6e1f263e732e338c7c1b8fc0b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a0cd649c29cb0b073d404f31f75c782 = $(`&lt;div id=&quot;html_6a0cd649c29cb0b073d404f31f75c782&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4a2d8a6e1f263e732e338c7c1b8fc0b2.setContent(html_6a0cd649c29cb0b073d404f31f75c782);
#
#
#
#         marker_950dd80ac13d348a0d96302ae23e1b85.bindPopup(popup_4a2d8a6e1f263e732e338c7c1b8fc0b2)
#         ;
#
#
#
#
#             var marker_bebf4d44a202206570ee4168a3635a07 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc4a8e3bb2dc3d528aba66737399fdc5);
#
#
#         var popup_144661917ccf5afb24eb1aa1bce11f96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_636b62068147ed616ea52e3e16d05705 = $(`&lt;div id=&quot;html_636b62068147ed616ea52e3e16d05705&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_144661917ccf5afb24eb1aa1bce11f96.setContent(html_636b62068147ed616ea52e3e16d05705);
#
#
#
#         marker_bebf4d44a202206570ee4168a3635a07.bindPopup(popup_144661917ccf5afb24eb1aa1bce11f96)
#         ;
#
#
#
#
#             var marker_0a507fadcdd722ae68ddb871b98c79dd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dc4a8e3bb2dc3d528aba66737399fdc5);
#
#
#         var popup_f7f43505deebb0ccabdc021fae6c70dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fee20ba5de94a7ee2929ae63159244a7 = $(`&lt;div id=&quot;html_fee20ba5de94a7ee2929ae63159244a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f7f43505deebb0ccabdc021fae6c70dd.setContent(html_fee20ba5de94a7ee2929ae63159244a7);
#
#
#
#         marker_
