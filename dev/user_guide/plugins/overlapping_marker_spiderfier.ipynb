# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd5c3515879769ecfa7a1fe525f66b29 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd5c3515879769ecfa7a1fe525f66b29&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd5c3515879769ecfa7a1fe525f66b29 = L.map(
#                 &quot;map_bd5c3515879769ecfa7a1fe525f66b29&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9db9a587512fb9a68568b98003a85f1b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9db9a587512fb9a68568b98003a85f1b.addTo(map_bd5c3515879769ecfa7a1fe525f66b29);
#
#
#             var marker_aa16676b7f6c9cdef6875cf69c810f7c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_bd5c3515879769ecfa7a1fe525f66b29);
#
#
#         var popup_5c74deac5476498b1c45e2ede9094804 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48abf20e9d5b9fa154dff8c6fea7e80e = $(`&lt;div id=&quot;html_48abf20e9d5b9fa154dff8c6fea7e80e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5c74deac5476498b1c45e2ede9094804.setContent(html_48abf20e9d5b9fa154dff8c6fea7e80e);
#
#
#
#         marker_aa16676b7f6c9cdef6875cf69c810f7c.bindPopup(popup_5c74deac5476498b1c45e2ede9094804)
#         ;
#
#
#
#
#             var marker_576b1427390ba884b27299b5b529505f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_bd5c3515879769ecfa7a1fe525f66b29);
#
#
#         var popup_dd1b7f2a9895a43ef8fc2e7c625939a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05fa88713e3cd8ab8eb8ece7d86cfb89 = $(`&lt;div id=&quot;html_05fa88713e3cd8ab8eb8ece7d86cfb89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dd1b7f2a9895a43ef8fc2e7c625939a5.setContent(html_05fa88713e3cd8ab8eb8ece7d86cfb89);
#
#
#
#         marker_576b1427390ba884b27299b5b529505f.bindPopup(popup_dd1b7f2a9895a43ef8fc2e7c625939a5)
#         ;
#
#
#
#
#             var marker_a4054403cb26e4e5b5c124f4adce7bcb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_bd5c3515879769ecfa7a1fe525f66b29);
#
#
#         var popup_dd267c652f839c2eb4df9bcc47143e3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82a2f10df46c0f3b2e3294d3bf5c2d96 = $(`&lt;div id=&quot;html_82a2f10df46c0f3b2e3294d3bf5c2d96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_dd267c652f839c2eb4df9bcc47143e3e.setContent(html_82a2f10df46c0f3b2e3294d3bf5c2d96);
#
#
#
#         marker_a4054403cb26e4e5b5c124f4adce7bcb.bindPopup(popup_dd267c652f839c2eb4df9bcc47143e3e)
#         ;
#
#
#
#
#             var marker_8e59f84904189b334c9fbaf4fc2d1867 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_bd5c3515879769ecfa7a1fe525f66b29);
#
#
#         var popup_ff5048bcac449839643bd6424a3876bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_175480822b1458096243d57ed8d46c32 = $(`&lt;div id=&quot;html_175480822b1458096243d57ed8d46c32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ff5048bcac449839643bd6424a3876bc.setContent(html_175480822b1458096243d57ed8d46c32);
#
#
#
#         marker_8e59f84904189b334c9fbaf4fc2d1867.bindPopup(popup_ff5048bcac449839643bd6424a3876bc)
#         ;
#
#
#
#
#             var marker_fe33c30e5cd357b7051ad528a679ca5d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_bd5c3515879769ecfa7a1fe525f66b29);
#
#
#         var popup_6f0747e0366a0c36630c1c000352a550 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_196fdc7a0c638a73ddae2b586b778a0b = $(`&lt;div id=&quot;html_196fdc7a0c638a73ddae2b586b778a0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6f0747e0366a0c36630c1c000352a550.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fdf06dda0eec71b19fa8e80ed8f5adc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fdf06dda0eec71b19fa8e80ed8f5adc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fdf06dda0eec71b19fa8e80ed8f5adc = L.map(
#                 &quot;map_9fdf06dda0eec71b19fa8e80ed8f5adc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e963607e7e031f0676b2d60179fe116 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e963607e7e031f0676b2d60179fe116.addTo(map_9fdf06dda0eec71b19fa8e80ed8f5adc);
#
#
#             var feature_group_9441d9c590d32074f1d4c9736d72e81b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_55db4110ebaf62379f833054e0753433 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9441d9c590d32074f1d4c9736d72e81b);
#
#
#         var popup_a28389f58e2dd697625f6a0836283715 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_479fc9b2150eb04b9aa49cae24ad617e = $(`&lt;div id=&quot;html_479fc9b2150eb04b9aa49cae24ad617e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a28389f58e2dd697625f6a0836283715.setContent(html_479fc9b2150eb04b9aa49cae24ad617e);
#
#
#
#         marker_55db4110ebaf62379f833054e0753433.bindPopup(popup_a28389f58e2dd697625f6a0836283715)
#         ;
#
#
#
#
#             var marker_61ceecab8382a1ed5b749207aa9f8d66 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9441d9c590d32074f1d4c9736d72e81b);
#
#
#         var popup_8371f1469dabfe7fd5736a52c7bee901 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c84de10529673ee536ec50a5f4f3b590 = $(`&lt;div id=&quot;html_c84de10529673ee536ec50a5f4f3b590&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8371f1469dabfe7fd5736a52c7bee901.setContent(html_c84de10529673ee536ec50a5f4f3b590);
#
#
#
#         marker_61ceecab8382a1ed5b749207aa9f8d66.bindPopup(popup_8371f1469dabfe7fd5736a52c7bee901)
#         ;
#
#
#
#
#             var marker_43bd3c85f358eec4c4e94b57545c21b1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9441d9c590d32074f1d4c9736d72e81b);
#
#
#         var popup_9db2fea14c565a0ea9a4e881350ddd7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c406cbb4e94b815f5e172da9aa8dd04 = $(`&lt;div id=&quot;html_4c406cbb4e94b815f5e172da9aa8dd04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9db2fea14c565a0ea9a4e881350ddd7b.setContent(html_4c406cbb4e94b815f5e172da9aa8dd04);
#
#
#
#         marker_43bd3c85f358eec4c4e94b57545c21b1.bindPopup(popup_9db2fea14c565a0ea9a4e881350ddd7b)
#         ;
#
#
#
#
#             var marker_59c134bb26cb0cc359376ebe3380b3ff = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9441d9c590d32074f1d4c9736d72e81b);
#
#
#         var popup_930c4e8545c12e62b2de5b7f078f3348 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4128c187dd829c0743041bb0c17710f = $(`&lt;div id=&quot;html_f4128c187dd829c0743041bb0c17710f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_930c4e8545c12e62b2de5b7f078f3348.setContent(html_f4128c187dd829c0743041bb0c17710f);
#
#
#
#         marker_59c134bb26cb0cc359376ebe3380b3ff.bindPopup(popup_930c4e8545c12e62b2de5b7f078f3348)
#         ;
#
#
#
#
#             var marker_b0687aa19563ea77a16219062b892a6c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9441d9c590d32074f1d4c9736d72e81b);
#
#
#         var popup_404419e2a09d66ce9270f3cfe5be69b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a01cbc7bec7b12f42447ff61d801fc8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a01cbc7bec7b12f42447ff61d801fc8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a01cbc7bec7b12f42447ff61d801fc8 = L.map(
#                 &quot;map_9a01cbc7bec7b12f42447ff61d801fc8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85904ec37e8cc55acee0feb8648fede3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85904ec37e8cc55acee0feb8648fede3.addTo(map_9a01cbc7bec7b12f42447ff61d801fc8);
#
#
#             var feature_group_9892162d3c4516a2b4128c5fe3b62880 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9892162d3c4516a2b4128c5fe3b62880.addTo(map_9a01cbc7bec7b12f42447ff61d801fc8);
#
#
#             var feature_group_sub_group_31d3c0c52bc65fbc45535f653ec91215 = L.featureGroup.subGroup(
#                 feature_group_9892162d3c4516a2b4128c5fe3b62880
#             );
#
#
#             var marker_2b5780721e891619ddfbaf75d375f1cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_31d3c0c52bc65fbc45535f653ec91215);
#
#
#         var popup_2cfdd055da9bcda9d0baa45d94a8d38c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3242e42ead2a17e96fd5e70efb25cc9 = $(`&lt;div id=&quot;html_a3242e42ead2a17e96fd5e70efb25cc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2cfdd055da9bcda9d0baa45d94a8d38c.setContent(html_a3242e42ead2a17e96fd5e70efb25cc9);
#
#
#
#         marker_2b5780721e891619ddfbaf75d375f1cf.bindPopup(popup_2cfdd055da9bcda9d0baa45d94a8d38c)
#         ;
#
#
#
#
#             var marker_4913f34fed9490dbfd06989c92cc63ca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_31d3c0c52bc65fbc45535f653ec91215);
#
#
#         var popup_72e7a51fa9afbf2a604f9ffd4573e64f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9377e72912bb2dc592402b748ebc019a = $(`&lt;div id=&quot;html_9377e72912bb2dc592402b748ebc019a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_72e7a51fa9afbf2a604f9ffd4573e64f.setContent(html_9377e72912bb2dc592402b748ebc019a);
#
#
#
#         marker_4913f34fed9490dbfd06989c92cc63ca.bindPopup(popup_72e7a51fa9afbf2a604f9ffd4573e64f)
#         ;
#
#
#
#
#             var marker_e192b14f21ab5a0c5e3e4f7026cdff0e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_31d3c0c52bc65fbc45535f653ec91215);
#
#
#         var popup_445e29d66ee454b1909361df1af4507f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62bb3b2d2ecf2eab3fbbe275acb32378 = $(`&lt;div id=&quot;html_62bb3b2d2ecf2eab3fbbe275acb32378&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_445e29d66ee454b1909361df1af4507f.setContent(html_62bb3b2d2ecf2eab3fbbe275acb32378);
#
#
#
#         marker_e192b14f21ab5a0c5e3e4f7026cdff0e.bindPopup(popup_445e29d66ee454b1909361df1af4507f)
#         ;
#
#
#
#
#             var marker_185466166ff0375f725da567375e72d9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_31d3c0c52bc65fbc45535f653ec91215);
#
#
#         var popup_9d74e2c42156f014cf2725eaa7c8d283 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_417f672bec173c6801f992122d4dbf23 = $(`&lt;div id=&quot;html_417f672bec173c6801f992122d4dbf23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9d74e2c42156f014cf2725eaa7c8d283.setContent(html_417f672bec173c6801f992122d4dbf23);
#
#
#
#         marker_
