# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_338e411a39657ced89c56566991e33c2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_338e411a39657ced89c56566991e33c2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_338e411a39657ced89c56566991e33c2 = L.map(
#                 &quot;map_338e411a39657ced89c56566991e33c2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_194b96a5377eeb142d9c7100171c0b3f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_194b96a5377eeb142d9c7100171c0b3f.addTo(map_338e411a39657ced89c56566991e33c2);
#
#
#             var marker_75e74a69e84a8c3328eab0529fe67940 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_338e411a39657ced89c56566991e33c2);
#
#
#         var popup_61c78b9f050e33056197a1444d0bc58f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38c7a406900f5a71c9b7e6c192dda3d0 = $(`&lt;div id=&quot;html_38c7a406900f5a71c9b7e6c192dda3d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_61c78b9f050e33056197a1444d0bc58f.setContent(html_38c7a406900f5a71c9b7e6c192dda3d0);
#
#
#
#         marker_75e74a69e84a8c3328eab0529fe67940.bindPopup(popup_61c78b9f050e33056197a1444d0bc58f)
#         ;
#
#
#
#
#             var marker_838d6983e31fecff451e91f634f24025 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_338e411a39657ced89c56566991e33c2);
#
#
#         var popup_d3884a55559f1f6418a264c6125bf6d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6175d97135975bdc1307b303bd78a9c = $(`&lt;div id=&quot;html_d6175d97135975bdc1307b303bd78a9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d3884a55559f1f6418a264c6125bf6d4.setContent(html_d6175d97135975bdc1307b303bd78a9c);
#
#
#
#         marker_838d6983e31fecff451e91f634f24025.bindPopup(popup_d3884a55559f1f6418a264c6125bf6d4)
#         ;
#
#
#
#
#             var marker_c4ff9acbd6ecb96cd4220ff0de1a236b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_338e411a39657ced89c56566991e33c2);
#
#
#         var popup_49dd5dae22b0f756509d84dacb7d8897 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e7f41ad5df3348705cc36d5eaab9ea8 = $(`&lt;div id=&quot;html_9e7f41ad5df3348705cc36d5eaab9ea8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_49dd5dae22b0f756509d84dacb7d8897.setContent(html_9e7f41ad5df3348705cc36d5eaab9ea8);
#
#
#
#         marker_c4ff9acbd6ecb96cd4220ff0de1a236b.bindPopup(popup_49dd5dae22b0f756509d84dacb7d8897)
#         ;
#
#
#
#
#             var marker_049a664b183819b64ec6c34fd9eb3a18 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_338e411a39657ced89c56566991e33c2);
#
#
#         var popup_8688f6b71df35b24a4fe1f6a484ae1ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f128be8eed61b18ab38b5b97c993fc6 = $(`&lt;div id=&quot;html_6f128be8eed61b18ab38b5b97c993fc6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8688f6b71df35b24a4fe1f6a484ae1ed.setContent(html_6f128be8eed61b18ab38b5b97c993fc6);
#
#
#
#         marker_049a664b183819b64ec6c34fd9eb3a18.bindPopup(popup_8688f6b71df35b24a4fe1f6a484ae1ed)
#         ;
#
#
#
#
#             var marker_720bc4262df5f2059668f09f6782dae1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_338e411a39657ced89c56566991e33c2);
#
#
#         var popup_74296ace5a0c172f8e4f546f52121579 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63af6a6c64b81c40954b93d21ea5a5fc = $(`&lt;div id=&quot;html_63af6a6c64b81c40954b93d21ea5a5fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_74296ace5a0c172f8e4f546f52121579.setContent(html_63af6a6c64b81c40954b93d21ea5a5fc);
#
#
#
#         marker_720bc4262df5f2059668f09f6782dae1.bindPopup(popup_74296ace5a0c172f8e4f546f52121579)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0eb9e9fd489de2428a472cbf602deede {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0eb9e9fd489de2428a472cbf602deede&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0eb9e9fd489de2428a472cbf602deede = L.map(
#                 &quot;map_0eb9e9fd489de2428a472cbf602deede&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b1a5df1fee9a43aaf0aa0c6d7899b304 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b1a5df1fee9a43aaf0aa0c6d7899b304.addTo(map_0eb9e9fd489de2428a472cbf602deede);
#
#
#             var feature_group_f4ce6757b4384408c30b71bc181bc6c4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e077970fe19fe300e1ea7d71bb88d28c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f4ce6757b4384408c30b71bc181bc6c4);
#
#
#         var popup_dbb91a6b96ed118611d443e7304e652f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f24f3a94c13bc521763270b6b4400cdd = $(`&lt;div id=&quot;html_f24f3a94c13bc521763270b6b4400cdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dbb91a6b96ed118611d443e7304e652f.setContent(html_f24f3a94c13bc521763270b6b4400cdd);
#
#
#
#         marker_e077970fe19fe300e1ea7d71bb88d28c.bindPopup(popup_dbb91a6b96ed118611d443e7304e652f)
#         ;
#
#
#
#
#             var marker_031bd3af10038d64dac808d19c80c100 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f4ce6757b4384408c30b71bc181bc6c4);
#
#
#         var popup_7d25bb711ac3d4b77e379c8ddaa83ad3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab5218635e770b8b829b73175c4a3bb8 = $(`&lt;div id=&quot;html_ab5218635e770b8b829b73175c4a3bb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7d25bb711ac3d4b77e379c8ddaa83ad3.setContent(html_ab5218635e770b8b829b73175c4a3bb8);
#
#
#
#         marker_031bd3af10038d64dac808d19c80c100.bindPopup(popup_7d25bb711ac3d4b77e379c8ddaa83ad3)
#         ;
#
#
#
#
#             var marker_13b65bbe82175d35b20c8cd555838d66 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f4ce6757b4384408c30b71bc181bc6c4);
#
#
#         var popup_cd096cd99cbd7730b2c5355d306eafdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e83f12d11054f31d891b323f5a100f77 = $(`&lt;div id=&quot;html_e83f12d11054f31d891b323f5a100f77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cd096cd99cbd7730b2c5355d306eafdf.setContent(html_e83f12d11054f31d891b323f5a100f77);
#
#
#
#         marker_13b65bbe82175d35b20c8cd555838d66.bindPopup(popup_cd096cd99cbd7730b2c5355d306eafdf)
#         ;
#
#
#
#
#             var marker_5f633d120c576ba91c2c01175fc92c05 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f4ce6757b4384408c30b71bc181bc6c4);
#
#
#         var popup_5b2980fea6ce0e6f71eb7052e58588d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e11a71c81968346d6ec27a7513545b45 = $(`&lt;div id=&quot;html_e11a71c81968346d6ec27a7513545b45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5b2980fea6ce0e6f71eb7052e58588d2.setContent(html_e11a71c81968346d6ec27a7513545b45);
#
#
#
#         marker_5f633d120c576ba91c2c01175fc92c05.bindPopup(popup_5b2980fea6ce0e6f71eb7052e58588d2)
#         ;
#
#
#
#
#             var marker_b0c73f11f3165c794d719c6738970d88 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f4ce6757b4384408c30b71bc181bc6c4);
#
#
#         var popup_601fbcb0b7de54ad5e28ee11876f0897 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6471d139f923d40957ed68e7a296b6b3 = $(`&lt;div id=&quot;html_6471d139f923d40957ed68e7a296b6b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_681db224004294fb33fdb6be2c29fbf2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_681db224004294fb33fdb6be2c29fbf2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_681db224004294fb33fdb6be2c29fbf2 = L.map(
#                 &quot;map_681db224004294fb33fdb6be2c29fbf2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b931d0fc81909e37b8e7c22d9e51490 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b931d0fc81909e37b8e7c22d9e51490.addTo(map_681db224004294fb33fdb6be2c29fbf2);
#
#
#             var feature_group_a9975867fa58ecfae448318df3f98a73 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a9975867fa58ecfae448318df3f98a73.addTo(map_681db224004294fb33fdb6be2c29fbf2);
#
#
#             var feature_group_sub_group_3e230a7e5d7ee9bc65ea7df22e8a95d6 = L.featureGroup.subGroup(
#                 feature_group_a9975867fa58ecfae448318df3f98a73
#             );
#
#
#             var marker_6560e6c17d8cffee6523f4232fc8f2e9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e230a7e5d7ee9bc65ea7df22e8a95d6);
#
#
#         var popup_a05348754595a107e6ee48acf20d4822 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_985b1941e2b4b6999ccc580ef9cebfba = $(`&lt;div id=&quot;html_985b1941e2b4b6999ccc580ef9cebfba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a05348754595a107e6ee48acf20d4822.setContent(html_985b1941e2b4b6999ccc580ef9cebfba);
#
#
#
#         marker_6560e6c17d8cffee6523f4232fc8f2e9.bindPopup(popup_a05348754595a107e6ee48acf20d4822)
#         ;
#
#
#
#
#             var marker_2d0ff2bf33742bb565bd8219c7e68143 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e230a7e5d7ee9bc65ea7df22e8a95d6);
#
#
#         var popup_20cd39eef327c2f3403f5d5b7a9da424 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e150ede4744ee81341880f2df75ebf1 = $(`&lt;div id=&quot;html_1e150ede4744ee81341880f2df75ebf1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_20cd39eef327c2f3403f5d5b7a9da424.setContent(html_1e150ede4744ee81341880f2df75ebf1);
#
#
#
#         marker_2d0ff2bf33742bb565bd8219c7e68143.bindPopup(popup_20cd39eef327c2f3403f5d5b7a9da424)
#         ;
#
#
#
#
#             var marker_55992995785d7cb52aae11afa7d0acf0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e230a7e5d7ee9bc65ea7df22e8a95d6);
#
#
#         var popup_5796233317cd881eacc6926cb6dc7909 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7119246ddbb2d840929877dbd20858e8 = $(`&lt;div id=&quot;html_7119246ddbb2d840929877dbd20858e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5796233317cd881eacc6926cb6dc7909.setContent(html_7119246ddbb2d840929877dbd20858e8);
#
#
#
#         marker_55992995785d7cb52aae11afa7d0acf0.bindPopup(popup_5796233317cd881eacc6926cb6dc7909)
#         ;
#
#
#
#
#             var marker_f14b07bd6d7216215ad983d048f1b7a0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3e230a7e5d7ee9bc65ea7df22e8a95d6);
#
#
#         var popup_bb400c0319efef6cac7e51fde5fc0d75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fc4f75ebdbd0064ee6e8f4462cb8e4f = $(`&lt;div id=&quot;html_5fc4f75ebdbd0064ee6e8f4462cb8e4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bb400c0319efef6cac7e51fde5fc0d75.setContent(html_5fc4f75ebdbd0064ee6e8f4462cb8e4f);
#
#
#
#         marker_f14b07bd6d7216215ad983d048f1b7a0.bindPopup(popup_bb400c0319efef6cac7e51fde5fc0d75)
#         ;
#
#
#
#
#             var marker_2f18fd3761e614bd44ad62ee7e1e07a5 = L.marker(
#                 [45.0503999
