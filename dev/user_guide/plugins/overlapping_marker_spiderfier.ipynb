# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba884e1dfd5e8c47bd2c7b67ea89f2f2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba884e1dfd5e8c47bd2c7b67ea89f2f2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba884e1dfd5e8c47bd2c7b67ea89f2f2 = L.map(
#                 &quot;map_ba884e1dfd5e8c47bd2c7b67ea89f2f2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e25b0b6ad618537bee6fd40a9f10ce80 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e25b0b6ad618537bee6fd40a9f10ce80.addTo(map_ba884e1dfd5e8c47bd2c7b67ea89f2f2);
#
#
#             var marker_72a836f7c291017d1e1f98d74d4ac210 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ba884e1dfd5e8c47bd2c7b67ea89f2f2);
#
#
#         var popup_9c472652de66cf80ee25e422c61eb868 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1547219e4e4c6ac1c9f6a2ce2e7a007 = $(`&lt;div id=&quot;html_f1547219e4e4c6ac1c9f6a2ce2e7a007&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9c472652de66cf80ee25e422c61eb868.setContent(html_f1547219e4e4c6ac1c9f6a2ce2e7a007);
#
#
#
#         marker_72a836f7c291017d1e1f98d74d4ac210.bindPopup(popup_9c472652de66cf80ee25e422c61eb868)
#         ;
#
#
#
#
#             var marker_1a88e95c0fa9ff177a127633d7228682 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ba884e1dfd5e8c47bd2c7b67ea89f2f2);
#
#
#         var popup_bcee7413962a371cecd5183f5b26668f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc9b4983b8b6229fb1d47d035e0b0f52 = $(`&lt;div id=&quot;html_dc9b4983b8b6229fb1d47d035e0b0f52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bcee7413962a371cecd5183f5b26668f.setContent(html_dc9b4983b8b6229fb1d47d035e0b0f52);
#
#
#
#         marker_1a88e95c0fa9ff177a127633d7228682.bindPopup(popup_bcee7413962a371cecd5183f5b26668f)
#         ;
#
#
#
#
#             var marker_230ce8f561afd2acf007f7fcbfc87324 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ba884e1dfd5e8c47bd2c7b67ea89f2f2);
#
#
#         var popup_d2c5b34624693eec6fa2e8774ed8492b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11162372a47b061488141ab4d8400dc3 = $(`&lt;div id=&quot;html_11162372a47b061488141ab4d8400dc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d2c5b34624693eec6fa2e8774ed8492b.setContent(html_11162372a47b061488141ab4d8400dc3);
#
#
#
#         marker_230ce8f561afd2acf007f7fcbfc87324.bindPopup(popup_d2c5b34624693eec6fa2e8774ed8492b)
#         ;
#
#
#
#
#             var marker_b13d7086cbc24b1fc0b046d53b5bc7ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ba884e1dfd5e8c47bd2c7b67ea89f2f2);
#
#
#         var popup_167845d153710751dd7f67d2e4c7bfec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d72a8b6277d945f30042a2ecdb22220 = $(`&lt;div id=&quot;html_0d72a8b6277d945f30042a2ecdb22220&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_167845d153710751dd7f67d2e4c7bfec.setContent(html_0d72a8b6277d945f30042a2ecdb22220);
#
#
#
#         marker_b13d7086cbc24b1fc0b046d53b5bc7ea.bindPopup(popup_167845d153710751dd7f67d2e4c7bfec)
#         ;
#
#
#
#
#             var marker_d798133c3af8169285f38ec30a680bd7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ba884e1dfd5e8c47bd2c7b67ea89f2f2);
#
#
#         var popup_c5e676440c2e70ef68c7f1ef851cca21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b71cae202634e9909aa0ebd47751631f = $(`&lt;div id=&quot;html_b71cae202634e9909aa0ebd47751631f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c5e676440c2e70ef68c7f1ef851cca21.setContent(html_b71cae202634e9909aa0ebd47751631f);
#
#
#
#         marker_d798133c3af8169285f38ec30a680bd7.bindPopup(popup_c5e676440c2e70ef68c7f1ef851cca21)
#         ;
#
#
#
#
#             var marker_443600ebd9

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a06883883c4751949bbf8c63043198a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a06883883c4751949bbf8c63043198a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a06883883c4751949bbf8c63043198a7 = L.map(
#                 &quot;map_a06883883c4751949bbf8c63043198a7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3db09de6fbcf2ce6252e857ec30e8b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3db09de6fbcf2ce6252e857ec30e8b9.addTo(map_a06883883c4751949bbf8c63043198a7);
#
#
#             var feature_group_167d0acc1e1a6fef49711879fdbe2a76 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3d2cf0eaf4bbd9e8c3398f336c248c99 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_167d0acc1e1a6fef49711879fdbe2a76);
#
#
#         var popup_2b67a525e2fab505da92208043bd9305 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4542fa4c86f1aff5e4184126ba1f470c = $(`&lt;div id=&quot;html_4542fa4c86f1aff5e4184126ba1f470c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2b67a525e2fab505da92208043bd9305.setContent(html_4542fa4c86f1aff5e4184126ba1f470c);
#
#
#
#         marker_3d2cf0eaf4bbd9e8c3398f336c248c99.bindPopup(popup_2b67a525e2fab505da92208043bd9305)
#         ;
#
#
#
#
#             var marker_f6ad08be03df5205708996fa30d1bc11 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_167d0acc1e1a6fef49711879fdbe2a76);
#
#
#         var popup_e66d2c922450c92281870f6102fae7e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_407bbbd1675c4c80079bf93c3e5a6836 = $(`&lt;div id=&quot;html_407bbbd1675c4c80079bf93c3e5a6836&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e66d2c922450c92281870f6102fae7e0.setContent(html_407bbbd1675c4c80079bf93c3e5a6836);
#
#
#
#         marker_f6ad08be03df5205708996fa30d1bc11.bindPopup(popup_e66d2c922450c92281870f6102fae7e0)
#         ;
#
#
#
#
#             var marker_1c5efbc5dbf7495c07049c81cbe7ea19 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_167d0acc1e1a6fef49711879fdbe2a76);
#
#
#         var popup_e25c7850de13dbc9436371f3dc614f4e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9842f7844b078e62c9b6b895e92df760 = $(`&lt;div id=&quot;html_9842f7844b078e62c9b6b895e92df760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e25c7850de13dbc9436371f3dc614f4e.setContent(html_9842f7844b078e62c9b6b895e92df760);
#
#
#
#         marker_1c5efbc5dbf7495c07049c81cbe7ea19.bindPopup(popup_e25c7850de13dbc9436371f3dc614f4e)
#         ;
#
#
#
#
#             var marker_955be61fab403e7a426b6e5e486843c8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_167d0acc1e1a6fef49711879fdbe2a76);
#
#
#         var popup_7e1c5f0648ffaecc9aa28c067672e684 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_748dcd798810f6cc9343393e520cb66e = $(`&lt;div id=&quot;html_748dcd798810f6cc9343393e520cb66e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7e1c5f0648ffaecc9aa28c067672e684.setContent(html_748dcd798810f6cc9343393e520cb66e);
#
#
#
#         marker_955be61fab403e7a426b6e5e486843c8.bindPopup(popup_7e1c5f0648ffaecc9aa28c067672e684)
#         ;
#
#
#
#
#             var marker_a098eb6754c653c60582838e72bdcbe1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_167d0acc1e1a6fef49711879fdbe2a76);
#
#
#         var popup_011aa68c506caa2ce4149da24e862085 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b844071911c7d7b36205df4cedc5a8e = $(`&lt;div id=&quot;html_6b844071911c7d7b36205df4cedc5a8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_011aa68c506caa2ce4

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16eb4b1d8fef09494d492eb236a12a8d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16eb4b1d8fef09494d492eb236a12a8d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16eb4b1d8fef09494d492eb236a12a8d = L.map(
#                 &quot;map_16eb4b1d8fef09494d492eb236a12a8d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a51aa78865c4e0e8023bedcc8046bdf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1a51aa78865c4e0e8023bedcc8046bdf.addTo(map_16eb4b1d8fef09494d492eb236a12a8d);
#
#
#             var feature_group_a624692579a0b4cfb0df33cc479f0ccd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a624692579a0b4cfb0df33cc479f0ccd.addTo(map_16eb4b1d8fef09494d492eb236a12a8d);
#
#
#             var feature_group_sub_group_f23c99abfdd1f71109fa9f4cb73dcc95 = L.featureGroup.subGroup(
#                 feature_group_a624692579a0b4cfb0df33cc479f0ccd
#             );
#
#
#             var marker_18840ad19da1044e07f3665b37ce2c09 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f23c99abfdd1f71109fa9f4cb73dcc95);
#
#
#         var popup_1b643564298bcbb0bbc5e4529319d5d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f9b42a83c3da1b5ef02f863da03060f = $(`&lt;div id=&quot;html_9f9b42a83c3da1b5ef02f863da03060f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1b643564298bcbb0bbc5e4529319d5d3.setContent(html_9f9b42a83c3da1b5ef02f863da03060f);
#
#
#
#         marker_18840ad19da1044e07f3665b37ce2c09.bindPopup(popup_1b643564298bcbb0bbc5e4529319d5d3)
#         ;
#
#
#
#
#             var marker_9819fe6db8f7cd73259253c6504a5f04 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f23c99abfdd1f71109fa9f4cb73dcc95);
#
#
#         var popup_a201a5a2d4fed2478fbe23f2f8fda68f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97ce1cae3617f06437ebe58a486c488f = $(`&lt;div id=&quot;html_97ce1cae3617f06437ebe58a486c488f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a201a5a2d4fed2478fbe23f2f8fda68f.setContent(html_97ce1cae3617f06437ebe58a486c488f);
#
#
#
#         marker_9819fe6db8f7cd73259253c6504a5f04.bindPopup(popup_a201a5a2d4fed2478fbe23f2f8fda68f)
#         ;
#
#
#
#
#             var marker_7d82803edac7d7168129fd1252d2c4ea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f23c99abfdd1f71109fa9f4cb73dcc95);
#
#
#         var popup_62f7eed05b8af23d5166fe03a32f37b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5ed33de3628a288e7ffc7d2dda2e263 = $(`&lt;div id=&quot;html_c5ed33de3628a288e7ffc7d2dda2e263&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_62f7eed05b8af23d5166fe03a32f37b6.setContent(html_c5ed33de3628a288e7ffc7d2dda2e263);
#
#
#
#         marker_7d82803edac7d7168129fd1252d2c4ea.bindPopup(popup_62f7eed05b8af23d5166fe03a32f37b6)
#         ;
#
#
#
#
#             var marker_71fafe2d145037992a91807311a29913 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f23c99abfdd1f71109fa9f4cb73dcc95);
#
#
#         var popup_296b9be84e63dc94d11baee4d1c3ab62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fa8a73ad2e3821e7869ac6a20287b3c = $(`&lt;div id=&quot;html_8fa8a73ad2e3821e7869ac6a20287b3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_296b9be84e63dc94d11baee4d1c3ab62.setContent(html_8fa8a73ad2e3821e7869ac6a20287b3c);
#
#
#
#         marker_71fafe2d145037992a91807311a29913.bindPopup(popup_296b9be84e63dc94d11baee4d1c3ab62)
#         ;
#
#
#
#
#             var marker_e79554b7d351416ec8316785fad4a581 = L.marker(
#                 [45.050399999999996, 3.0504],
