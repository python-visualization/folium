# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8474bfb50321c4885a5236001e2ec747 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8474bfb50321c4885a5236001e2ec747&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8474bfb50321c4885a5236001e2ec747 = L.map(
#                 &quot;map_8474bfb50321c4885a5236001e2ec747&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_006ba299c0a439b4680d4738f61f6db0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_006ba299c0a439b4680d4738f61f6db0.addTo(map_8474bfb50321c4885a5236001e2ec747);
#
#
#             var marker_dd0c0a790bb3176e093d68fd6cc09650 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8474bfb50321c4885a5236001e2ec747);
#
#
#         var popup_8cf2cddf1a3148ee6dd72ec443ef86ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_467a9c24f8f819750b51a1df0e2ab436 = $(`&lt;div id=&quot;html_467a9c24f8f819750b51a1df0e2ab436&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8cf2cddf1a3148ee6dd72ec443ef86ca.setContent(html_467a9c24f8f819750b51a1df0e2ab436);
#
#
#
#         marker_dd0c0a790bb3176e093d68fd6cc09650.bindPopup(popup_8cf2cddf1a3148ee6dd72ec443ef86ca)
#         ;
#
#
#
#
#             var marker_b88758db62eb89b1f68772be8478cd8a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8474bfb50321c4885a5236001e2ec747);
#
#
#         var popup_0ec751c229a21a0b27fe188279dca079 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd7fec8386f5700821b466314b2f5296 = $(`&lt;div id=&quot;html_bd7fec8386f5700821b466314b2f5296&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0ec751c229a21a0b27fe188279dca079.setContent(html_bd7fec8386f5700821b466314b2f5296);
#
#
#
#         marker_b88758db62eb89b1f68772be8478cd8a.bindPopup(popup_0ec751c229a21a0b27fe188279dca079)
#         ;
#
#
#
#
#             var marker_5053f31ebdb35dcd9e435ce6bea5f83a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8474bfb50321c4885a5236001e2ec747);
#
#
#         var popup_b71efd0e225a177feb200e15fcf063a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30a781c77277c1ea9560ece90898e807 = $(`&lt;div id=&quot;html_30a781c77277c1ea9560ece90898e807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b71efd0e225a177feb200e15fcf063a2.setContent(html_30a781c77277c1ea9560ece90898e807);
#
#
#
#         marker_5053f31ebdb35dcd9e435ce6bea5f83a.bindPopup(popup_b71efd0e225a177feb200e15fcf063a2)
#         ;
#
#
#
#
#             var marker_afa9921612d3460fb99c019a891c85d9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8474bfb50321c4885a5236001e2ec747);
#
#
#         var popup_072b3a16b37d25edbf0ce7bb789220ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3945b2ca97c272350b4ed7bd3549fd5e = $(`&lt;div id=&quot;html_3945b2ca97c272350b4ed7bd3549fd5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_072b3a16b37d25edbf0ce7bb789220ae.setContent(html_3945b2ca97c272350b4ed7bd3549fd5e);
#
#
#
#         marker_afa9921612d3460fb99c019a891c85d9.bindPopup(popup_072b3a16b37d25edbf0ce7bb789220ae)
#         ;
#
#
#
#
#             var marker_f40d994d7aac4fd707fcacee6c7c9222 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8474bfb50321c4885a5236001e2ec747);
#
#
#         var popup_1be92e6d0795b85b53a039e5962ec87e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3948be3894bf7e6e66e6d7f18db92925 = $(`&lt;div id=&quot;html_3948be3894bf7e6e66e6d7f18db92925&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1be92e6d0795b85b53a039e5962ec8

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9038aa279b56092b25d97d6b2bc075b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9038aa279b56092b25d97d6b2bc075b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9038aa279b56092b25d97d6b2bc075b = L.map(
#                 &quot;map_c9038aa279b56092b25d97d6b2bc075b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3c1ee31632e09fdbebf44334dde2c15 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3c1ee31632e09fdbebf44334dde2c15.addTo(map_c9038aa279b56092b25d97d6b2bc075b);
#
#
#             var feature_group_898af23af086b7623b9a7d35771a520c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_de69a950164c4f6e2239b14da4664c72 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_898af23af086b7623b9a7d35771a520c);
#
#
#         var popup_d15f16332704648b1bc950ffedc672c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c39731a39af65013716cf6c9b42cf96b = $(`&lt;div id=&quot;html_c39731a39af65013716cf6c9b42cf96b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d15f16332704648b1bc950ffedc672c7.setContent(html_c39731a39af65013716cf6c9b42cf96b);
#
#
#
#         marker_de69a950164c4f6e2239b14da4664c72.bindPopup(popup_d15f16332704648b1bc950ffedc672c7)
#         ;
#
#
#
#
#             var marker_27b57bb33901fd3a2096cd5afc4e6667 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_898af23af086b7623b9a7d35771a520c);
#
#
#         var popup_9d5ff029ed368989ce1fb654d965605f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ada67ce9389df2dfb602ee900799219 = $(`&lt;div id=&quot;html_9ada67ce9389df2dfb602ee900799219&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9d5ff029ed368989ce1fb654d965605f.setContent(html_9ada67ce9389df2dfb602ee900799219);
#
#
#
#         marker_27b57bb33901fd3a2096cd5afc4e6667.bindPopup(popup_9d5ff029ed368989ce1fb654d965605f)
#         ;
#
#
#
#
#             var marker_13a8d1e475cacd566bc57e82ee651aed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_898af23af086b7623b9a7d35771a520c);
#
#
#         var popup_61da39779d7c731bab4e49adc64eb062 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fbe627c926fdb8a42550523e456be13 = $(`&lt;div id=&quot;html_6fbe627c926fdb8a42550523e456be13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_61da39779d7c731bab4e49adc64eb062.setContent(html_6fbe627c926fdb8a42550523e456be13);
#
#
#
#         marker_13a8d1e475cacd566bc57e82ee651aed.bindPopup(popup_61da39779d7c731bab4e49adc64eb062)
#         ;
#
#
#
#
#             var marker_74db288e1109afb43601d217e67b1356 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_898af23af086b7623b9a7d35771a520c);
#
#
#         var popup_664ffcda2b0a270223dc4b9f26d2c0e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd3f23bc0291d3f90441b65d50cb2a46 = $(`&lt;div id=&quot;html_cd3f23bc0291d3f90441b65d50cb2a46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_664ffcda2b0a270223dc4b9f26d2c0e2.setContent(html_cd3f23bc0291d3f90441b65d50cb2a46);
#
#
#
#         marker_74db288e1109afb43601d217e67b1356.bindPopup(popup_664ffcda2b0a270223dc4b9f26d2c0e2)
#         ;
#
#
#
#
#             var marker_508e564c6b2e218ffa29c334009601ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_898af23af086b7623b9a7d35771a520c);
#
#
#         var popup_1622448f56242cd62445669e9a6d051f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03ffe6fe1c484a1c2c9a7b2003c01600 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03ffe6fe1c484a1c2c9a7b2003c01600&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03ffe6fe1c484a1c2c9a7b2003c01600 = L.map(
#                 &quot;map_03ffe6fe1c484a1c2c9a7b2003c01600&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d71664ff4068661e43f42637c2638ae1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d71664ff4068661e43f42637c2638ae1.addTo(map_03ffe6fe1c484a1c2c9a7b2003c01600);
#
#
#             var feature_group_a4aa5908f238727ea21ea8c1c9e42d04 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a4aa5908f238727ea21ea8c1c9e42d04.addTo(map_03ffe6fe1c484a1c2c9a7b2003c01600);
#
#
#             var feature_group_sub_group_ccf004cb596ca8289e578c636db2efbf = L.featureGroup.subGroup(
#                 feature_group_a4aa5908f238727ea21ea8c1c9e42d04
#             );
#
#
#             var marker_20127081d922b1cb17fc13ed944d64ec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ccf004cb596ca8289e578c636db2efbf);
#
#
#         var popup_10cd8853fe1db213226a29106f3a7252 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_daf2e5032c1575b820d6f7ba66377c73 = $(`&lt;div id=&quot;html_daf2e5032c1575b820d6f7ba66377c73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_10cd8853fe1db213226a29106f3a7252.setContent(html_daf2e5032c1575b820d6f7ba66377c73);
#
#
#
#         marker_20127081d922b1cb17fc13ed944d64ec.bindPopup(popup_10cd8853fe1db213226a29106f3a7252)
#         ;
#
#
#
#
#             var marker_b54e016d1f547aaeb40f5aefe57ae972 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ccf004cb596ca8289e578c636db2efbf);
#
#
#         var popup_be7f11c89d340bf4fd0527d446d3c57f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75237c4dcb2a1ba4cb97bc044725eed0 = $(`&lt;div id=&quot;html_75237c4dcb2a1ba4cb97bc044725eed0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_be7f11c89d340bf4fd0527d446d3c57f.setContent(html_75237c4dcb2a1ba4cb97bc044725eed0);
#
#
#
#         marker_b54e016d1f547aaeb40f5aefe57ae972.bindPopup(popup_be7f11c89d340bf4fd0527d446d3c57f)
#         ;
#
#
#
#
#             var marker_2822a79766c1fd9ac298d88de252d497 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ccf004cb596ca8289e578c636db2efbf);
#
#
#         var popup_8e1de1d761e5a1add653f76d9405257f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_687ecdc0ab2a7b060efc41de332c163d = $(`&lt;div id=&quot;html_687ecdc0ab2a7b060efc41de332c163d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8e1de1d761e5a1add653f76d9405257f.setContent(html_687ecdc0ab2a7b060efc41de332c163d);
#
#
#
#         marker_2822a79766c1fd9ac298d88de252d497.bindPopup(popup_8e1de1d761e5a1add653f76d9405257f)
#         ;
#
#
#
#
#             var marker_dbbe3a1703657b65876b4485e5984137 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ccf004cb596ca8289e578c636db2efbf);
#
#
#         var popup_8b48a4006981ff0fe3496a1e71e1aff3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e776eeb69e1dbe3d0bc65d2df4dfe5e = $(`&lt;div id=&quot;html_7e776eeb69e1dbe3d0bc65d2df4dfe5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8b48a4006981ff0fe3496a1e71e1aff3.setContent(html_7e776eeb69e1dbe3d0bc65d2df4dfe5e);
#
#
#
#         mark
