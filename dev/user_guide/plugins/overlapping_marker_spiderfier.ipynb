# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f16b65115bde30d97d6a3868c211090e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f16b65115bde30d97d6a3868c211090e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f16b65115bde30d97d6a3868c211090e = L.map(
#                 &quot;map_f16b65115bde30d97d6a3868c211090e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3e2aaa6c3b1f3f88382396a1f1e100a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3e2aaa6c3b1f3f88382396a1f1e100a.addTo(map_f16b65115bde30d97d6a3868c211090e);
#
#
#             var marker_210ca656cb067f6f63498b02091765e9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f16b65115bde30d97d6a3868c211090e);
#
#
#         var popup_2d7a547552674a7dc0f555ceb8ff5299 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c613c8285277cd396832e4b43bb135e9 = $(`&lt;div id=&quot;html_c613c8285277cd396832e4b43bb135e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2d7a547552674a7dc0f555ceb8ff5299.setContent(html_c613c8285277cd396832e4b43bb135e9);
#
#
#
#         marker_210ca656cb067f6f63498b02091765e9.bindPopup(popup_2d7a547552674a7dc0f555ceb8ff5299)
#         ;
#
#
#
#
#             var marker_a88ae06676fa74b5eeb0b1cba685f6f6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f16b65115bde30d97d6a3868c211090e);
#
#
#         var popup_2e20a8b7ac92a45650b4fb0893d293bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd1eec9763778612e046304f6d920ae2 = $(`&lt;div id=&quot;html_dd1eec9763778612e046304f6d920ae2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2e20a8b7ac92a45650b4fb0893d293bc.setContent(html_dd1eec9763778612e046304f6d920ae2);
#
#
#
#         marker_a88ae06676fa74b5eeb0b1cba685f6f6.bindPopup(popup_2e20a8b7ac92a45650b4fb0893d293bc)
#         ;
#
#
#
#
#             var marker_b5e2447319657812cf68b9dfb3616517 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f16b65115bde30d97d6a3868c211090e);
#
#
#         var popup_7f1f8ccc75530dd243ebf5ce74554b57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b042b715580a6b79d7ecad9699896aef = $(`&lt;div id=&quot;html_b042b715580a6b79d7ecad9699896aef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7f1f8ccc75530dd243ebf5ce74554b57.setContent(html_b042b715580a6b79d7ecad9699896aef);
#
#
#
#         marker_b5e2447319657812cf68b9dfb3616517.bindPopup(popup_7f1f8ccc75530dd243ebf5ce74554b57)
#         ;
#
#
#
#
#             var marker_9f8a32cebd2b5dfad535de91c6b9e925 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f16b65115bde30d97d6a3868c211090e);
#
#
#         var popup_47256a9c0c7008b56294d8b95baa9130 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27db54dde1a775e47cf809686e1d9b83 = $(`&lt;div id=&quot;html_27db54dde1a775e47cf809686e1d9b83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_47256a9c0c7008b56294d8b95baa9130.setContent(html_27db54dde1a775e47cf809686e1d9b83);
#
#
#
#         marker_9f8a32cebd2b5dfad535de91c6b9e925.bindPopup(popup_47256a9c0c7008b56294d8b95baa9130)
#         ;
#
#
#
#
#             var marker_ea567e6ef2cbdd47c27513423a176f99 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f16b65115bde30d97d6a3868c211090e);
#
#
#         var popup_d53420861755f0da58c2c6594665ccb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc8f5513f9aac812b0f990f7759eef66 = $(`&lt;div id=&quot;html_fc8f5513f9aac812b0f990f7759eef66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d53420861755f0da58c2c6594665ccb6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a526e063f4d5af9f025e6b3cdf425424 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a526e063f4d5af9f025e6b3cdf425424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a526e063f4d5af9f025e6b3cdf425424 = L.map(
#                 &quot;map_a526e063f4d5af9f025e6b3cdf425424&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9b9644093c13a4d8c18746f2df69ac77 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9b9644093c13a4d8c18746f2df69ac77.addTo(map_a526e063f4d5af9f025e6b3cdf425424);
#
#
#             var feature_group_8c5898b6347ce179d57d84e8b73af0c6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3abd3ee435a2bf7f0eb06d87c6f75943 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8c5898b6347ce179d57d84e8b73af0c6);
#
#
#         var popup_a229ce082fd43af4cda6d26a1a629457 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5aaeb70e6baa9a11061fff84da0fc2d = $(`&lt;div id=&quot;html_f5aaeb70e6baa9a11061fff84da0fc2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a229ce082fd43af4cda6d26a1a629457.setContent(html_f5aaeb70e6baa9a11061fff84da0fc2d);
#
#
#
#         marker_3abd3ee435a2bf7f0eb06d87c6f75943.bindPopup(popup_a229ce082fd43af4cda6d26a1a629457)
#         ;
#
#
#
#
#             var marker_e70304228670092c569ec41972183ab8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8c5898b6347ce179d57d84e8b73af0c6);
#
#
#         var popup_f5a7e4c8c0dc157ccfcfafa750bb4b3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6d1bf1c2853aa08e2b37a561fefada0 = $(`&lt;div id=&quot;html_b6d1bf1c2853aa08e2b37a561fefada0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f5a7e4c8c0dc157ccfcfafa750bb4b3f.setContent(html_b6d1bf1c2853aa08e2b37a561fefada0);
#
#
#
#         marker_e70304228670092c569ec41972183ab8.bindPopup(popup_f5a7e4c8c0dc157ccfcfafa750bb4b3f)
#         ;
#
#
#
#
#             var marker_cdf5e2ff855b3e65003020fbc0966c6b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8c5898b6347ce179d57d84e8b73af0c6);
#
#
#         var popup_86e106e7815ffd142ba3f7e4d6abbc26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0111fc7904cb6805983a9054feb91415 = $(`&lt;div id=&quot;html_0111fc7904cb6805983a9054feb91415&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_86e106e7815ffd142ba3f7e4d6abbc26.setContent(html_0111fc7904cb6805983a9054feb91415);
#
#
#
#         marker_cdf5e2ff855b3e65003020fbc0966c6b.bindPopup(popup_86e106e7815ffd142ba3f7e4d6abbc26)
#         ;
#
#
#
#
#             var marker_575c776aae3611feecc17bfdcdb69dc1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8c5898b6347ce179d57d84e8b73af0c6);
#
#
#         var popup_68e8b655f9d74ab79f9d5f30faf993a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01eeb0e3d6128aef04eb22b99867f942 = $(`&lt;div id=&quot;html_01eeb0e3d6128aef04eb22b99867f942&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_68e8b655f9d74ab79f9d5f30faf993a5.setContent(html_01eeb0e3d6128aef04eb22b99867f942);
#
#
#
#         marker_575c776aae3611feecc17bfdcdb69dc1.bindPopup(popup_68e8b655f9d74ab79f9d5f30faf993a5)
#         ;
#
#
#
#
#             var marker_0e50d79b50034954e607d94a3c30678e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8c5898b6347ce179d57d84e8b73af0c6);
#
#
#         var popup_f9cfc88dab638cd559a12e32a475bc8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2eda18029894a80246f9579b02668fff {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2eda18029894a80246f9579b02668fff&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2eda18029894a80246f9579b02668fff = L.map(
#                 &quot;map_2eda18029894a80246f9579b02668fff&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9219f519d1e34822de08d8e290607f1c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9219f519d1e34822de08d8e290607f1c.addTo(map_2eda18029894a80246f9579b02668fff);
#
#
#             var feature_group_f71dae03f0e5aa05c755ec4657f18621 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f71dae03f0e5aa05c755ec4657f18621.addTo(map_2eda18029894a80246f9579b02668fff);
#
#
#             var feature_group_sub_group_09b7c86dfd5e6b344e7ae57cff7b6f88 = L.featureGroup.subGroup(
#                 feature_group_f71dae03f0e5aa05c755ec4657f18621
#             );
#
#
#             var marker_918f72a32ba3dec1d1541bbe65e33600 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_09b7c86dfd5e6b344e7ae57cff7b6f88);
#
#
#         var popup_e1c1da438b646ed4aa447d0b7b495fd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88da219d57fa11274a9306fef6260fb3 = $(`&lt;div id=&quot;html_88da219d57fa11274a9306fef6260fb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e1c1da438b646ed4aa447d0b7b495fd2.setContent(html_88da219d57fa11274a9306fef6260fb3);
#
#
#
#         marker_918f72a32ba3dec1d1541bbe65e33600.bindPopup(popup_e1c1da438b646ed4aa447d0b7b495fd2)
#         ;
#
#
#
#
#             var marker_c2de6c2ec9cf2525076959e9c4bd7110 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_09b7c86dfd5e6b344e7ae57cff7b6f88);
#
#
#         var popup_08c8d684e1725bb73085b2e565cfedc2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9456dd5fbdcee7a078bc95c630041ffd = $(`&lt;div id=&quot;html_9456dd5fbdcee7a078bc95c630041ffd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_08c8d684e1725bb73085b2e565cfedc2.setContent(html_9456dd5fbdcee7a078bc95c630041ffd);
#
#
#
#         marker_c2de6c2ec9cf2525076959e9c4bd7110.bindPopup(popup_08c8d684e1725bb73085b2e565cfedc2)
#         ;
#
#
#
#
#             var marker_b1404a0cbad64869cc253c5eb9c84bb1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_09b7c86dfd5e6b344e7ae57cff7b6f88);
#
#
#         var popup_b5cbe4270eaf20f13a1514938b436219 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94d77ae58eeb1c1a028822b0a9f6a9fe = $(`&lt;div id=&quot;html_94d77ae58eeb1c1a028822b0a9f6a9fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b5cbe4270eaf20f13a1514938b436219.setContent(html_94d77ae58eeb1c1a028822b0a9f6a9fe);
#
#
#
#         marker_b1404a0cbad64869cc253c5eb9c84bb1.bindPopup(popup_b5cbe4270eaf20f13a1514938b436219)
#         ;
#
#
#
#
#             var marker_58c100b207664c08e672b262d867ad93 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_09b7c86dfd5e6b344e7ae57cff7b6f88);
#
#
#         var popup_19092ae232c343dc5ee569bce4c6d32d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b600949ec2cc8a16831f8d3e2be7b29 = $(`&lt;div id=&quot;html_4b600949ec2cc8a16831f8d3e2be7b29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_19092ae232c343dc5ee569bce4c6d32d.setContent(html_4b600949ec2cc8a16831f8d3e2be7b29);
#
#
#
#         marker_
