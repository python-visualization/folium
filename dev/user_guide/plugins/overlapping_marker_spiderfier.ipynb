# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f1343ab3f55ca66db816d781913aead4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f1343ab3f55ca66db816d781913aead4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f1343ab3f55ca66db816d781913aead4 = L.map(
#                 &quot;map_f1343ab3f55ca66db816d781913aead4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a2e95a66d022ca7aa285b2af586aacb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a2e95a66d022ca7aa285b2af586aacb7.addTo(map_f1343ab3f55ca66db816d781913aead4);
#
#
#             var marker_d3f1cfef44924d62a0b48b2a11f34ba4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f1343ab3f55ca66db816d781913aead4);
#
#
#         var popup_64f3f286244ace5add6faadab1ca2b3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4dcf0bb8840b6f268153e7987af1d88 = $(`&lt;div id=&quot;html_f4dcf0bb8840b6f268153e7987af1d88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_64f3f286244ace5add6faadab1ca2b3d.setContent(html_f4dcf0bb8840b6f268153e7987af1d88);
#
#
#
#         marker_d3f1cfef44924d62a0b48b2a11f34ba4.bindPopup(popup_64f3f286244ace5add6faadab1ca2b3d)
#         ;
#
#
#
#
#             var marker_3008f469a8e0acca3b7159bbb5e2b162 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f1343ab3f55ca66db816d781913aead4);
#
#
#         var popup_85fa1dcab9ed957a6975fffb00f80543 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_556178a96712508f301ba980a92c7893 = $(`&lt;div id=&quot;html_556178a96712508f301ba980a92c7893&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_85fa1dcab9ed957a6975fffb00f80543.setContent(html_556178a96712508f301ba980a92c7893);
#
#
#
#         marker_3008f469a8e0acca3b7159bbb5e2b162.bindPopup(popup_85fa1dcab9ed957a6975fffb00f80543)
#         ;
#
#
#
#
#             var marker_47ee3cb5a1ff385df8317ce3410fb2ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f1343ab3f55ca66db816d781913aead4);
#
#
#         var popup_a1e96c7880f7049b5044fea7a6dd2345 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5c87b92518e944b604af3659a870783 = $(`&lt;div id=&quot;html_d5c87b92518e944b604af3659a870783&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a1e96c7880f7049b5044fea7a6dd2345.setContent(html_d5c87b92518e944b604af3659a870783);
#
#
#
#         marker_47ee3cb5a1ff385df8317ce3410fb2ed.bindPopup(popup_a1e96c7880f7049b5044fea7a6dd2345)
#         ;
#
#
#
#
#             var marker_0ee898c454985319bdba7c71015fb8f3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f1343ab3f55ca66db816d781913aead4);
#
#
#         var popup_b7ef8399ca571796c2c096859a224925 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d508b729435fc6e125537b0c54fb9ab = $(`&lt;div id=&quot;html_4d508b729435fc6e125537b0c54fb9ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b7ef8399ca571796c2c096859a224925.setContent(html_4d508b729435fc6e125537b0c54fb9ab);
#
#
#
#         marker_0ee898c454985319bdba7c71015fb8f3.bindPopup(popup_b7ef8399ca571796c2c096859a224925)
#         ;
#
#
#
#
#             var marker_8aee2eafc752e35dbd15e7b2c4056c5b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f1343ab3f55ca66db816d781913aead4);
#
#
#         var popup_f335ad4b444cd9245e019172aad02ad0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fb3ccd73e189cb2827be0c4bd70ea9a = $(`&lt;div id=&quot;html_0fb3ccd73e189cb2827be0c4bd70ea9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f335ad4b444cd9245e019172aad02a

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e2c3fc630ef86f09d4eb547e53b969a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e2c3fc630ef86f09d4eb547e53b969a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e2c3fc630ef86f09d4eb547e53b969a = L.map(
#                 &quot;map_2e2c3fc630ef86f09d4eb547e53b969a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8d1b4adb8536eec8951cc757786d35f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8d1b4adb8536eec8951cc757786d35f.addTo(map_2e2c3fc630ef86f09d4eb547e53b969a);
#
#
#             var feature_group_a3abf93b8a7a3f53e19e8ddc066ba224 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_50fdc8ea38b42a012223ac6ee0dfe096 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a3abf93b8a7a3f53e19e8ddc066ba224);
#
#
#         var popup_7129b686cdac0eac41807a13bb4e569a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d08eae695ea83cbbc1451dbde6518e58 = $(`&lt;div id=&quot;html_d08eae695ea83cbbc1451dbde6518e58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7129b686cdac0eac41807a13bb4e569a.setContent(html_d08eae695ea83cbbc1451dbde6518e58);
#
#
#
#         marker_50fdc8ea38b42a012223ac6ee0dfe096.bindPopup(popup_7129b686cdac0eac41807a13bb4e569a)
#         ;
#
#
#
#
#             var marker_e9f0c26c993617797a9641820d8bc724 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a3abf93b8a7a3f53e19e8ddc066ba224);
#
#
#         var popup_03cfddf4efb2ed0dc839024b5743cd23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_540760c06045477217e5e9dbc89d97a8 = $(`&lt;div id=&quot;html_540760c06045477217e5e9dbc89d97a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_03cfddf4efb2ed0dc839024b5743cd23.setContent(html_540760c06045477217e5e9dbc89d97a8);
#
#
#
#         marker_e9f0c26c993617797a9641820d8bc724.bindPopup(popup_03cfddf4efb2ed0dc839024b5743cd23)
#         ;
#
#
#
#
#             var marker_a66266c8a4ac8add3c6dd6617b1fb0a0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a3abf93b8a7a3f53e19e8ddc066ba224);
#
#
#         var popup_39d98b43bb4f950fb5528879e4e51484 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2eeb3782c71eaab76fd0ace8d7d7f62 = $(`&lt;div id=&quot;html_e2eeb3782c71eaab76fd0ace8d7d7f62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_39d98b43bb4f950fb5528879e4e51484.setContent(html_e2eeb3782c71eaab76fd0ace8d7d7f62);
#
#
#
#         marker_a66266c8a4ac8add3c6dd6617b1fb0a0.bindPopup(popup_39d98b43bb4f950fb5528879e4e51484)
#         ;
#
#
#
#
#             var marker_1e3434b66f679933d3e7c2a4183e321f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a3abf93b8a7a3f53e19e8ddc066ba224);
#
#
#         var popup_8b46c8e60174566491e85c862802e45c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e522b4c3b509f494944cd6a5821c93b = $(`&lt;div id=&quot;html_6e522b4c3b509f494944cd6a5821c93b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8b46c8e60174566491e85c862802e45c.setContent(html_6e522b4c3b509f494944cd6a5821c93b);
#
#
#
#         marker_1e3434b66f679933d3e7c2a4183e321f.bindPopup(popup_8b46c8e60174566491e85c862802e45c)
#         ;
#
#
#
#
#             var marker_418c2ee5abf5fcd37421a344fa9b794e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a3abf93b8a7a3f53e19e8ddc066ba224);
#
#
#         var popup_cd6b7db73afe0464d181c771b646d249 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_900f69ca9d5b4e8e6b047bf283c29874 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_900f69ca9d5b4e8e6b047bf283c29874&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_900f69ca9d5b4e8e6b047bf283c29874 = L.map(
#                 &quot;map_900f69ca9d5b4e8e6b047bf283c29874&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_886e517b067af59521aedd0875e89f16 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_886e517b067af59521aedd0875e89f16.addTo(map_900f69ca9d5b4e8e6b047bf283c29874);
#
#
#             var feature_group_2e898de67fc6ce6a0a7aebd49492d3e8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2e898de67fc6ce6a0a7aebd49492d3e8.addTo(map_900f69ca9d5b4e8e6b047bf283c29874);
#
#
#             var feature_group_sub_group_46fbf90f63721f003f0b2daf32c4f708 = L.featureGroup.subGroup(
#                 feature_group_2e898de67fc6ce6a0a7aebd49492d3e8
#             );
#
#
#             var marker_57b734f935512f5c766ac8ef9678f308 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_46fbf90f63721f003f0b2daf32c4f708);
#
#
#         var popup_0e909888145405db88160d4e6d74b6bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67879a7457fbc178bd740f631afe66e9 = $(`&lt;div id=&quot;html_67879a7457fbc178bd740f631afe66e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0e909888145405db88160d4e6d74b6bc.setContent(html_67879a7457fbc178bd740f631afe66e9);
#
#
#
#         marker_57b734f935512f5c766ac8ef9678f308.bindPopup(popup_0e909888145405db88160d4e6d74b6bc)
#         ;
#
#
#
#
#             var marker_97e7e137a5affe77fced495b849357aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_46fbf90f63721f003f0b2daf32c4f708);
#
#
#         var popup_23712382489354cbe77847aca2956eea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_408ef9d3db800edcc95b7162110320f1 = $(`&lt;div id=&quot;html_408ef9d3db800edcc95b7162110320f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_23712382489354cbe77847aca2956eea.setContent(html_408ef9d3db800edcc95b7162110320f1);
#
#
#
#         marker_97e7e137a5affe77fced495b849357aa.bindPopup(popup_23712382489354cbe77847aca2956eea)
#         ;
#
#
#
#
#             var marker_dc12ec03c9393891be9e3f16077a54b3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_46fbf90f63721f003f0b2daf32c4f708);
#
#
#         var popup_3a6d34682b0f39aa4c4bf929982c800a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee8c30bd50f74768b1775425009ad2de = $(`&lt;div id=&quot;html_ee8c30bd50f74768b1775425009ad2de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3a6d34682b0f39aa4c4bf929982c800a.setContent(html_ee8c30bd50f74768b1775425009ad2de);
#
#
#
#         marker_dc12ec03c9393891be9e3f16077a54b3.bindPopup(popup_3a6d34682b0f39aa4c4bf929982c800a)
#         ;
#
#
#
#
#             var marker_6a5355b1cc193ce3692b73593a12bd71 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_46fbf90f63721f003f0b2daf32c4f708);
#
#
#         var popup_2f6cd3c6668cc9cc4bd283b5691b3a59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6abac8dd9df358ce2657b5f3ff0411dc = $(`&lt;div id=&quot;html_6abac8dd9df358ce2657b5f3ff0411dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_2f6cd3c6668cc9cc4bd283b5691b3a59.setContent(html_6abac8dd9df358ce2657b5f3ff0411dc);
#
#
#
#         mark
