# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3e5eac2a2201c45e84e73209061ab5d3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3e5eac2a2201c45e84e73209061ab5d3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3e5eac2a2201c45e84e73209061ab5d3 = L.map(
#                 &quot;map_3e5eac2a2201c45e84e73209061ab5d3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9996045ce654aa185c4bd9ab49855d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9996045ce654aa185c4bd9ab49855d8.addTo(map_3e5eac2a2201c45e84e73209061ab5d3);
#
#
#             var marker_1647d2529d115c1c7eb0d8f078451367 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3e5eac2a2201c45e84e73209061ab5d3);
#
#
#         var popup_6bffb376e254a03f26c0391a83e7e3cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a7597f041eaa8972210d0fb4dfcade3 = $(`&lt;div id=&quot;html_9a7597f041eaa8972210d0fb4dfcade3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6bffb376e254a03f26c0391a83e7e3cf.setContent(html_9a7597f041eaa8972210d0fb4dfcade3);
#
#
#
#         marker_1647d2529d115c1c7eb0d8f078451367.bindPopup(popup_6bffb376e254a03f26c0391a83e7e3cf)
#         ;
#
#
#
#
#             var marker_6a92f072364854d82e4d732907c410bb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3e5eac2a2201c45e84e73209061ab5d3);
#
#
#         var popup_d3528d5e7e3a78050100cd78989a4efb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a90db21c115cac6d88c9503d88db8bc = $(`&lt;div id=&quot;html_1a90db21c115cac6d88c9503d88db8bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d3528d5e7e3a78050100cd78989a4efb.setContent(html_1a90db21c115cac6d88c9503d88db8bc);
#
#
#
#         marker_6a92f072364854d82e4d732907c410bb.bindPopup(popup_d3528d5e7e3a78050100cd78989a4efb)
#         ;
#
#
#
#
#             var marker_2d0ebe4cdbc4b57d5d582ca112373514 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3e5eac2a2201c45e84e73209061ab5d3);
#
#
#         var popup_06b046ce18f09f531267bbc0b3e43f37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12cb1253d840083928d0dc427b690e54 = $(`&lt;div id=&quot;html_12cb1253d840083928d0dc427b690e54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_06b046ce18f09f531267bbc0b3e43f37.setContent(html_12cb1253d840083928d0dc427b690e54);
#
#
#
#         marker_2d0ebe4cdbc4b57d5d582ca112373514.bindPopup(popup_06b046ce18f09f531267bbc0b3e43f37)
#         ;
#
#
#
#
#             var marker_7af4d8767c39002d52f66a16eac70c22 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3e5eac2a2201c45e84e73209061ab5d3);
#
#
#         var popup_2281175b36873581f7a2aeb891c75102 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43e412cd3044e6d0df50dab3309032d2 = $(`&lt;div id=&quot;html_43e412cd3044e6d0df50dab3309032d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2281175b36873581f7a2aeb891c75102.setContent(html_43e412cd3044e6d0df50dab3309032d2);
#
#
#
#         marker_7af4d8767c39002d52f66a16eac70c22.bindPopup(popup_2281175b36873581f7a2aeb891c75102)
#         ;
#
#
#
#
#             var marker_0d0336c7e6e5586b38b2b1e4f8b8024f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3e5eac2a2201c45e84e73209061ab5d3);
#
#
#         var popup_a592bb77c38732eca25a0d6430fb70f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56fc415f0acabb22d865511851ba8b1e = $(`&lt;div id=&quot;html_56fc415f0acabb22d865511851ba8b1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a592bb77c38732eca25a0d6430fb70f6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1ff43c9a1ea066a7ab14758e2a71c45 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1ff43c9a1ea066a7ab14758e2a71c45&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1ff43c9a1ea066a7ab14758e2a71c45 = L.map(
#                 &quot;map_e1ff43c9a1ea066a7ab14758e2a71c45&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b079276c07cea3e677f30cba6211854 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b079276c07cea3e677f30cba6211854.addTo(map_e1ff43c9a1ea066a7ab14758e2a71c45);
#
#
#             var feature_group_6c5b0f4ca8e8009510ea9155d0c17c79 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cab2cd9b481f3ef2edc7fcd7a8f98a07 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6c5b0f4ca8e8009510ea9155d0c17c79);
#
#
#         var popup_2f2336693757ddf6e363429f75587b92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b400d0b3033264ae0ce766cf129549c7 = $(`&lt;div id=&quot;html_b400d0b3033264ae0ce766cf129549c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2f2336693757ddf6e363429f75587b92.setContent(html_b400d0b3033264ae0ce766cf129549c7);
#
#
#
#         marker_cab2cd9b481f3ef2edc7fcd7a8f98a07.bindPopup(popup_2f2336693757ddf6e363429f75587b92)
#         ;
#
#
#
#
#             var marker_28efaa9eec3d0a79ac0a48f56aea160c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6c5b0f4ca8e8009510ea9155d0c17c79);
#
#
#         var popup_9664d26582342210b7b0221138ae79f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c095bee863013f92d00f559fa196f71 = $(`&lt;div id=&quot;html_2c095bee863013f92d00f559fa196f71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9664d26582342210b7b0221138ae79f2.setContent(html_2c095bee863013f92d00f559fa196f71);
#
#
#
#         marker_28efaa9eec3d0a79ac0a48f56aea160c.bindPopup(popup_9664d26582342210b7b0221138ae79f2)
#         ;
#
#
#
#
#             var marker_be59a3eb46b7ec2edae9fbbb303bdf55 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6c5b0f4ca8e8009510ea9155d0c17c79);
#
#
#         var popup_fc41703a5b83e61128bae05762f36cc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45b261c31c16653770166fc5ea045771 = $(`&lt;div id=&quot;html_45b261c31c16653770166fc5ea045771&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fc41703a5b83e61128bae05762f36cc5.setContent(html_45b261c31c16653770166fc5ea045771);
#
#
#
#         marker_be59a3eb46b7ec2edae9fbbb303bdf55.bindPopup(popup_fc41703a5b83e61128bae05762f36cc5)
#         ;
#
#
#
#
#             var marker_93b4c95d3d667644644f464bae8e6b2d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6c5b0f4ca8e8009510ea9155d0c17c79);
#
#
#         var popup_e082d27935eb6db1be944a34bdc80343 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9ab1e888b59d1655ac7ad8d1ee317b1 = $(`&lt;div id=&quot;html_c9ab1e888b59d1655ac7ad8d1ee317b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e082d27935eb6db1be944a34bdc80343.setContent(html_c9ab1e888b59d1655ac7ad8d1ee317b1);
#
#
#
#         marker_93b4c95d3d667644644f464bae8e6b2d.bindPopup(popup_e082d27935eb6db1be944a34bdc80343)
#         ;
#
#
#
#
#             var marker_51bb9fbeb54891b812df798c2a94c898 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6c5b0f4ca8e8009510ea9155d0c17c79);
#
#
#         var popup_3a19adf4de2c1a6876e8ad2a0ef5c4fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6cbead6133905853fefd57b45ece72ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6cbead6133905853fefd57b45ece72ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6cbead6133905853fefd57b45ece72ef = L.map(
#                 &quot;map_6cbead6133905853fefd57b45ece72ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81fe6b871cba2c84b225d49158375c96 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81fe6b871cba2c84b225d49158375c96.addTo(map_6cbead6133905853fefd57b45ece72ef);
#
#
#             var feature_group_eaf1db3391c5c829276cf559adadb031 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_eaf1db3391c5c829276cf559adadb031.addTo(map_6cbead6133905853fefd57b45ece72ef);
#
#
#             var feature_group_sub_group_9657750eeb062d35b1e7e606c07072f4 = L.featureGroup.subGroup(
#                 feature_group_eaf1db3391c5c829276cf559adadb031
#             );
#
#
#             var marker_3046d08a4f0e6c5c9c190806d4b38a3c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9657750eeb062d35b1e7e606c07072f4);
#
#
#         var popup_18a7a5599b195dae9b4dd0092d25d10b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92a8656acaf7b5a5df26017f463bdd20 = $(`&lt;div id=&quot;html_92a8656acaf7b5a5df26017f463bdd20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_18a7a5599b195dae9b4dd0092d25d10b.setContent(html_92a8656acaf7b5a5df26017f463bdd20);
#
#
#
#         marker_3046d08a4f0e6c5c9c190806d4b38a3c.bindPopup(popup_18a7a5599b195dae9b4dd0092d25d10b)
#         ;
#
#
#
#
#             var marker_762ef302ac844fefc451c0d8b9e80e85 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9657750eeb062d35b1e7e606c07072f4);
#
#
#         var popup_39d66500065b3159be5f67c1ce10fc2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdd33c3094d7d88e849a3c7f0d6a9480 = $(`&lt;div id=&quot;html_fdd33c3094d7d88e849a3c7f0d6a9480&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_39d66500065b3159be5f67c1ce10fc2a.setContent(html_fdd33c3094d7d88e849a3c7f0d6a9480);
#
#
#
#         marker_762ef302ac844fefc451c0d8b9e80e85.bindPopup(popup_39d66500065b3159be5f67c1ce10fc2a)
#         ;
#
#
#
#
#             var marker_b12f013eea11df3c3fc3eb213116e0c6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9657750eeb062d35b1e7e606c07072f4);
#
#
#         var popup_67a216490f831f412472eb33bc47031c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2237122af1baaf04f0123907b056631d = $(`&lt;div id=&quot;html_2237122af1baaf04f0123907b056631d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_67a216490f831f412472eb33bc47031c.setContent(html_2237122af1baaf04f0123907b056631d);
#
#
#
#         marker_b12f013eea11df3c3fc3eb213116e0c6.bindPopup(popup_67a216490f831f412472eb33bc47031c)
#         ;
#
#
#
#
#             var marker_de855ab4e8934ff32b133eb186dfc88c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9657750eeb062d35b1e7e606c07072f4);
#
#
#         var popup_992349dde805ebd20216ba6222a7f250 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb70b16aec9267afd30df01d630a5c48 = $(`&lt;div id=&quot;html_cb70b16aec9267afd30df01d630a5c48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_992349dde805ebd20216ba6222a7f250.setContent(html_cb70b16aec9267afd30df01d630a5c48);
#
#
#
#         marker_
