# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d7e9852e4eb7009badedfe4755a6e39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d7e9852e4eb7009badedfe4755a6e39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d7e9852e4eb7009badedfe4755a6e39 = L.map(
#                 &quot;map_4d7e9852e4eb7009badedfe4755a6e39&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bacf0454c0386c99ee3ab3949319ff07 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bacf0454c0386c99ee3ab3949319ff07.addTo(map_4d7e9852e4eb7009badedfe4755a6e39);
#
#
#             var marker_26fad54821ac9ab51d9af8f57838e730 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4d7e9852e4eb7009badedfe4755a6e39);
#
#
#         var popup_7f5b16bb8b169f60c6f5bab25e8cb96f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a05182601d0fae254c8765340696620c = $(`&lt;div id=&quot;html_a05182601d0fae254c8765340696620c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7f5b16bb8b169f60c6f5bab25e8cb96f.setContent(html_a05182601d0fae254c8765340696620c);
#
#
#
#         marker_26fad54821ac9ab51d9af8f57838e730.bindPopup(popup_7f5b16bb8b169f60c6f5bab25e8cb96f)
#         ;
#
#
#
#
#             var marker_e4e2c960532082d90481a6b67c0b59f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4d7e9852e4eb7009badedfe4755a6e39);
#
#
#         var popup_6337577926899fd6fe6dfaef3aa05218 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b412ad50f40d29501b854685bf92e5b0 = $(`&lt;div id=&quot;html_b412ad50f40d29501b854685bf92e5b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6337577926899fd6fe6dfaef3aa05218.setContent(html_b412ad50f40d29501b854685bf92e5b0);
#
#
#
#         marker_e4e2c960532082d90481a6b67c0b59f9.bindPopup(popup_6337577926899fd6fe6dfaef3aa05218)
#         ;
#
#
#
#
#             var marker_fd8935cee1d2c3c0298c32392db11709 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4d7e9852e4eb7009badedfe4755a6e39);
#
#
#         var popup_6a003565fc2accd2d1df2ddd1c41e534 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_464d8430ba7c36d18fb9fa4479d82345 = $(`&lt;div id=&quot;html_464d8430ba7c36d18fb9fa4479d82345&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6a003565fc2accd2d1df2ddd1c41e534.setContent(html_464d8430ba7c36d18fb9fa4479d82345);
#
#
#
#         marker_fd8935cee1d2c3c0298c32392db11709.bindPopup(popup_6a003565fc2accd2d1df2ddd1c41e534)
#         ;
#
#
#
#
#             var marker_5eeb68041a65b2fe3e0ce0557c15161a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4d7e9852e4eb7009badedfe4755a6e39);
#
#
#         var popup_c4148833729a0013cbac0fc13bad8125 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b88c24d51491d19a87181bec9113fdd1 = $(`&lt;div id=&quot;html_b88c24d51491d19a87181bec9113fdd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c4148833729a0013cbac0fc13bad8125.setContent(html_b88c24d51491d19a87181bec9113fdd1);
#
#
#
#         marker_5eeb68041a65b2fe3e0ce0557c15161a.bindPopup(popup_c4148833729a0013cbac0fc13bad8125)
#         ;
#
#
#
#
#             var marker_9aa0e3fb3bdf10791503350267f5adf7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4d7e9852e4eb7009badedfe4755a6e39);
#
#
#         var popup_5362d04d8391ae339379b4bd5dc005a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49dec799e3cd53f4bc467f9af9f080df = $(`&lt;div id=&quot;html_49dec799e3cd53f4bc467f9af9f080df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5362d04d8391ae339379b4bd5dc005a6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7342f433a9ede61c4916f8fb76515f42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7342f433a9ede61c4916f8fb76515f42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7342f433a9ede61c4916f8fb76515f42 = L.map(
#                 &quot;map_7342f433a9ede61c4916f8fb76515f42&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ebe0e5a84f88019f11f74b0e0e3177a2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ebe0e5a84f88019f11f74b0e0e3177a2.addTo(map_7342f433a9ede61c4916f8fb76515f42);
#
#
#             var feature_group_fac2d3a5eb7b3c5063f1f047b5c67533 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_eb57687188436453dac4482b3a12156f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fac2d3a5eb7b3c5063f1f047b5c67533);
#
#
#         var popup_d2eeb50ed415e6ef6f4a66308c690809 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_701b5e4e90664ab20c5f0d4523f9db59 = $(`&lt;div id=&quot;html_701b5e4e90664ab20c5f0d4523f9db59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d2eeb50ed415e6ef6f4a66308c690809.setContent(html_701b5e4e90664ab20c5f0d4523f9db59);
#
#
#
#         marker_eb57687188436453dac4482b3a12156f.bindPopup(popup_d2eeb50ed415e6ef6f4a66308c690809)
#         ;
#
#
#
#
#             var marker_47f1be9bc02839ae027a54ade474ed4d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fac2d3a5eb7b3c5063f1f047b5c67533);
#
#
#         var popup_7b431b92b68d962c22b1c0f2de37f361 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33712138f84f66dc703c6236f0b41408 = $(`&lt;div id=&quot;html_33712138f84f66dc703c6236f0b41408&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_7b431b92b68d962c22b1c0f2de37f361.setContent(html_33712138f84f66dc703c6236f0b41408);
#
#
#
#         marker_47f1be9bc02839ae027a54ade474ed4d.bindPopup(popup_7b431b92b68d962c22b1c0f2de37f361)
#         ;
#
#
#
#
#             var marker_e4d66c047a9d2786126def4de9f79232 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fac2d3a5eb7b3c5063f1f047b5c67533);
#
#
#         var popup_127d67ce9c1935c9e0796e6ec69a7465 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bee852ed88f5397b54e24184c89777d = $(`&lt;div id=&quot;html_1bee852ed88f5397b54e24184c89777d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_127d67ce9c1935c9e0796e6ec69a7465.setContent(html_1bee852ed88f5397b54e24184c89777d);
#
#
#
#         marker_e4d66c047a9d2786126def4de9f79232.bindPopup(popup_127d67ce9c1935c9e0796e6ec69a7465)
#         ;
#
#
#
#
#             var marker_48a4b9ee8738603d95c329143730c7ec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fac2d3a5eb7b3c5063f1f047b5c67533);
#
#
#         var popup_f9e280708368089555e7cbd6378d950d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6da41ab103478f2cc9e8b4e35a06d4cf = $(`&lt;div id=&quot;html_6da41ab103478f2cc9e8b4e35a06d4cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f9e280708368089555e7cbd6378d950d.setContent(html_6da41ab103478f2cc9e8b4e35a06d4cf);
#
#
#
#         marker_48a4b9ee8738603d95c329143730c7ec.bindPopup(popup_f9e280708368089555e7cbd6378d950d)
#         ;
#
#
#
#
#             var marker_17dda581436cef8aa4754de22f5b367b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fac2d3a5eb7b3c5063f1f047b5c67533);
#
#
#         var popup_7552a86a73ca087c177bbf0eab2fe845 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_293a154f39e15a04e831addd98ee880e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_293a154f39e15a04e831addd98ee880e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_293a154f39e15a04e831addd98ee880e = L.map(
#                 &quot;map_293a154f39e15a04e831addd98ee880e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ca3ebf462288cef2bcd6b6e29da8774a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ca3ebf462288cef2bcd6b6e29da8774a.addTo(map_293a154f39e15a04e831addd98ee880e);
#
#
#             var feature_group_a3b12e3d9b0513163aab028cf7c8c08f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a3b12e3d9b0513163aab028cf7c8c08f.addTo(map_293a154f39e15a04e831addd98ee880e);
#
#
#             var feature_group_sub_group_e2fbd420a77956c10b280b72dfd7c320 = L.featureGroup.subGroup(
#                 feature_group_a3b12e3d9b0513163aab028cf7c8c08f
#             );
#
#
#             var marker_b8020e88dfae801e26da4496ef4d8432 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e2fbd420a77956c10b280b72dfd7c320);
#
#
#         var popup_1f6ba9eb3ab3fa8867208599cefafa36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d31fdcb381d3d67dfe4c5842e90d415b = $(`&lt;div id=&quot;html_d31fdcb381d3d67dfe4c5842e90d415b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1f6ba9eb3ab3fa8867208599cefafa36.setContent(html_d31fdcb381d3d67dfe4c5842e90d415b);
#
#
#
#         marker_b8020e88dfae801e26da4496ef4d8432.bindPopup(popup_1f6ba9eb3ab3fa8867208599cefafa36)
#         ;
#
#
#
#
#             var marker_0517a5a31009998b3961324bbe8eb9b7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e2fbd420a77956c10b280b72dfd7c320);
#
#
#         var popup_1705f002de4dbc0016739ada658647fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55f6210c413d38e937c891ee259ac3ba = $(`&lt;div id=&quot;html_55f6210c413d38e937c891ee259ac3ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1705f002de4dbc0016739ada658647fd.setContent(html_55f6210c413d38e937c891ee259ac3ba);
#
#
#
#         marker_0517a5a31009998b3961324bbe8eb9b7.bindPopup(popup_1705f002de4dbc0016739ada658647fd)
#         ;
#
#
#
#
#             var marker_6b9dbd2c958b59e005fcdc74f538f582 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e2fbd420a77956c10b280b72dfd7c320);
#
#
#         var popup_9dd346ec2f619a7c227f8d65f495bc69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fd0ffd56977a3dffaa8c354143df94d = $(`&lt;div id=&quot;html_1fd0ffd56977a3dffaa8c354143df94d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9dd346ec2f619a7c227f8d65f495bc69.setContent(html_1fd0ffd56977a3dffaa8c354143df94d);
#
#
#
#         marker_6b9dbd2c958b59e005fcdc74f538f582.bindPopup(popup_9dd346ec2f619a7c227f8d65f495bc69)
#         ;
#
#
#
#
#             var marker_7303016f6986313eac655f053a99a154 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e2fbd420a77956c10b280b72dfd7c320);
#
#
#         var popup_a63d670f2e6a5b5e9e4be7d92bc92a02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5539aebaedc39e08d13aa942f370c090 = $(`&lt;div id=&quot;html_5539aebaedc39e08d13aa942f370c090&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a63d670f2e6a5b5e9e4be7d92bc92a02.setContent(html_5539aebaedc39e08d13aa942f370c090);
#
#
#
#         marker_
