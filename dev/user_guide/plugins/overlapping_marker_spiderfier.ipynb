# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_99eeefc63e50c93e3f3ebf5ccecdca7e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_99eeefc63e50c93e3f3ebf5ccecdca7e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_99eeefc63e50c93e3f3ebf5ccecdca7e = L.map(
#                 &quot;map_99eeefc63e50c93e3f3ebf5ccecdca7e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_972c3fe6b7849544f5079d97b00ba29d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_972c3fe6b7849544f5079d97b00ba29d.addTo(map_99eeefc63e50c93e3f3ebf5ccecdca7e);
#
#
#             var marker_b79f491f777318c56a7300898539eab0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_99eeefc63e50c93e3f3ebf5ccecdca7e);
#
#
#         var popup_b964c5ad75bfef9afbf5c3be6bfc3d6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56d533af0ae7addb3913c087d94f825e = $(`&lt;div id=&quot;html_56d533af0ae7addb3913c087d94f825e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b964c5ad75bfef9afbf5c3be6bfc3d6b.setContent(html_56d533af0ae7addb3913c087d94f825e);
#
#
#
#         marker_b79f491f777318c56a7300898539eab0.bindPopup(popup_b964c5ad75bfef9afbf5c3be6bfc3d6b)
#         ;
#
#
#
#
#             var marker_8d86b6b0f37cd96adac8257e32e9ec10 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_99eeefc63e50c93e3f3ebf5ccecdca7e);
#
#
#         var popup_956058aca43524d7c08ec6f5de6e38da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4946b5089cd096747eacc9b2401132e = $(`&lt;div id=&quot;html_b4946b5089cd096747eacc9b2401132e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_956058aca43524d7c08ec6f5de6e38da.setContent(html_b4946b5089cd096747eacc9b2401132e);
#
#
#
#         marker_8d86b6b0f37cd96adac8257e32e9ec10.bindPopup(popup_956058aca43524d7c08ec6f5de6e38da)
#         ;
#
#
#
#
#             var marker_fb76383b336bc7184e3cf1c74e42d1d1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_99eeefc63e50c93e3f3ebf5ccecdca7e);
#
#
#         var popup_47ed409db5a6831120ec7637c00a2401 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7aa9f27bb6247b76750d364a788b4cb3 = $(`&lt;div id=&quot;html_7aa9f27bb6247b76750d364a788b4cb3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_47ed409db5a6831120ec7637c00a2401.setContent(html_7aa9f27bb6247b76750d364a788b4cb3);
#
#
#
#         marker_fb76383b336bc7184e3cf1c74e42d1d1.bindPopup(popup_47ed409db5a6831120ec7637c00a2401)
#         ;
#
#
#
#
#             var marker_287abc8b7aad109b4d7d19ff2e1df8f5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_99eeefc63e50c93e3f3ebf5ccecdca7e);
#
#
#         var popup_44ba48e6f2ffd00730a4e7329cda5258 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bf46aea841e99a33761edca3df0f329 = $(`&lt;div id=&quot;html_7bf46aea841e99a33761edca3df0f329&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_44ba48e6f2ffd00730a4e7329cda5258.setContent(html_7bf46aea841e99a33761edca3df0f329);
#
#
#
#         marker_287abc8b7aad109b4d7d19ff2e1df8f5.bindPopup(popup_44ba48e6f2ffd00730a4e7329cda5258)
#         ;
#
#
#
#
#             var marker_c666bdd1271b14c3ba29920c8e50b846 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_99eeefc63e50c93e3f3ebf5ccecdca7e);
#
#
#         var popup_882b2a647824fe63dc9d55a0bff0ae1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71955ff2b2c0ab062e8bea0456d8db99 = $(`&lt;div id=&quot;html_71955ff2b2c0ab062e8bea0456d8db99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_882b2a647824fe63dc9d55a0bff0ae1e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f69b09232bfee51727d6c021d920d5b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f69b09232bfee51727d6c021d920d5b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f69b09232bfee51727d6c021d920d5b3 = L.map(
#                 &quot;map_f69b09232bfee51727d6c021d920d5b3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2cda8ea4b4e2814b4df1942e4b3cac35 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2cda8ea4b4e2814b4df1942e4b3cac35.addTo(map_f69b09232bfee51727d6c021d920d5b3);
#
#
#             var feature_group_4912dd331795af783894196e3241b1a9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b5eeed3b00382ab64cb2ca0436d4c163 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4912dd331795af783894196e3241b1a9);
#
#
#         var popup_a970d29a83dfca4f9ed961191b2c8eb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5dea8ab5306fd70a1c2bdbfb06eba13a = $(`&lt;div id=&quot;html_5dea8ab5306fd70a1c2bdbfb06eba13a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a970d29a83dfca4f9ed961191b2c8eb6.setContent(html_5dea8ab5306fd70a1c2bdbfb06eba13a);
#
#
#
#         marker_b5eeed3b00382ab64cb2ca0436d4c163.bindPopup(popup_a970d29a83dfca4f9ed961191b2c8eb6)
#         ;
#
#
#
#
#             var marker_03cd4832240c38bbf31516d16f6f444a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4912dd331795af783894196e3241b1a9);
#
#
#         var popup_74b9fe50e24cac7afe504d922d556767 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e49e2c9bd617ab06120deb50f4f9d4f = $(`&lt;div id=&quot;html_6e49e2c9bd617ab06120deb50f4f9d4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_74b9fe50e24cac7afe504d922d556767.setContent(html_6e49e2c9bd617ab06120deb50f4f9d4f);
#
#
#
#         marker_03cd4832240c38bbf31516d16f6f444a.bindPopup(popup_74b9fe50e24cac7afe504d922d556767)
#         ;
#
#
#
#
#             var marker_72a5bc8d907b9cd009324ef45af8a57a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4912dd331795af783894196e3241b1a9);
#
#
#         var popup_c1240194990e6b8290e7077abef4f890 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9a8038af96541321be6940584574b51 = $(`&lt;div id=&quot;html_a9a8038af96541321be6940584574b51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c1240194990e6b8290e7077abef4f890.setContent(html_a9a8038af96541321be6940584574b51);
#
#
#
#         marker_72a5bc8d907b9cd009324ef45af8a57a.bindPopup(popup_c1240194990e6b8290e7077abef4f890)
#         ;
#
#
#
#
#             var marker_23146cd0d653db37f9440da6a9c74a98 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4912dd331795af783894196e3241b1a9);
#
#
#         var popup_b93d14bffb43ea8bd9b2b20a97f82b95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_277d525e5f598e8dafdb82ac3439e727 = $(`&lt;div id=&quot;html_277d525e5f598e8dafdb82ac3439e727&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b93d14bffb43ea8bd9b2b20a97f82b95.setContent(html_277d525e5f598e8dafdb82ac3439e727);
#
#
#
#         marker_23146cd0d653db37f9440da6a9c74a98.bindPopup(popup_b93d14bffb43ea8bd9b2b20a97f82b95)
#         ;
#
#
#
#
#             var marker_b246469db5e9c526b71ba22f3bc868e4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4912dd331795af783894196e3241b1a9);
#
#
#         var popup_fb177d22fe90e366c1345a4727714e6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b989fa8de916355fdf695e0fc0a146f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b989fa8de916355fdf695e0fc0a146f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b989fa8de916355fdf695e0fc0a146f = L.map(
#                 &quot;map_1b989fa8de916355fdf695e0fc0a146f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c8b7579919ac4d21a68da0248b2ccf0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c8b7579919ac4d21a68da0248b2ccf0.addTo(map_1b989fa8de916355fdf695e0fc0a146f);
#
#
#             var feature_group_f6a8c36cc6cff059fd432c0b4054dac6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f6a8c36cc6cff059fd432c0b4054dac6.addTo(map_1b989fa8de916355fdf695e0fc0a146f);
#
#
#             var feature_group_sub_group_d7f5595065bbb641c45e2778099fe09a = L.featureGroup.subGroup(
#                 feature_group_f6a8c36cc6cff059fd432c0b4054dac6
#             );
#
#
#             var marker_b8dbc0b6f8ca9e27febb714f90958a51 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7f5595065bbb641c45e2778099fe09a);
#
#
#         var popup_9cbacab5b04f68c9ae00ebfe3b216ec2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_435a50de53068f1efcfa495b1ac9afad = $(`&lt;div id=&quot;html_435a50de53068f1efcfa495b1ac9afad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9cbacab5b04f68c9ae00ebfe3b216ec2.setContent(html_435a50de53068f1efcfa495b1ac9afad);
#
#
#
#         marker_b8dbc0b6f8ca9e27febb714f90958a51.bindPopup(popup_9cbacab5b04f68c9ae00ebfe3b216ec2)
#         ;
#
#
#
#
#             var marker_c3eeba590da79e63b4a624c97d1bae7e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7f5595065bbb641c45e2778099fe09a);
#
#
#         var popup_a4578e0eeedafd2dbe82414c05183497 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c88cfa8252428dc916d90ae895b92a70 = $(`&lt;div id=&quot;html_c88cfa8252428dc916d90ae895b92a70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a4578e0eeedafd2dbe82414c05183497.setContent(html_c88cfa8252428dc916d90ae895b92a70);
#
#
#
#         marker_c3eeba590da79e63b4a624c97d1bae7e.bindPopup(popup_a4578e0eeedafd2dbe82414c05183497)
#         ;
#
#
#
#
#             var marker_3d6d4cf55b069dfff0fa31000758e6b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7f5595065bbb641c45e2778099fe09a);
#
#
#         var popup_c6525d132d626ed95dcd102e96532a7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b6c43f86baddfbf177048c326e6fd36 = $(`&lt;div id=&quot;html_4b6c43f86baddfbf177048c326e6fd36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c6525d132d626ed95dcd102e96532a7b.setContent(html_4b6c43f86baddfbf177048c326e6fd36);
#
#
#
#         marker_3d6d4cf55b069dfff0fa31000758e6b4.bindPopup(popup_c6525d132d626ed95dcd102e96532a7b)
#         ;
#
#
#
#
#             var marker_5e7d55b93bd51cb5bc6d43fd53ec0976 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d7f5595065bbb641c45e2778099fe09a);
#
#
#         var popup_7c6d4e44f431564fb9869e36bdf9bcab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39ae613762c437cd2f8dac7cf9f764be = $(`&lt;div id=&quot;html_39ae613762c437cd2f8dac7cf9f764be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7c6d4e44f431564fb9869e36bdf9bcab.setContent(html_39ae613762c437cd2f8dac7cf9f764be);
#
#
#
#         marker_
