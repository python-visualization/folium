# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3de0fec142248737850da84e068b4f13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3de0fec142248737850da84e068b4f13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3de0fec142248737850da84e068b4f13 = L.map(
#                 &quot;map_3de0fec142248737850da84e068b4f13&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2ebf3349effc8e1a853bfc238dcc20d0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2ebf3349effc8e1a853bfc238dcc20d0.addTo(map_3de0fec142248737850da84e068b4f13);
#
#
#             var marker_41d073ea2f330cdbb44778581d12a8d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3de0fec142248737850da84e068b4f13);
#
#
#         var popup_7c17b2079cd05667b5a42b5ebb3f9f1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f48c74824f97ae3526925cc646a9b62 = $(`&lt;div id=&quot;html_8f48c74824f97ae3526925cc646a9b62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7c17b2079cd05667b5a42b5ebb3f9f1d.setContent(html_8f48c74824f97ae3526925cc646a9b62);
#
#
#
#         marker_41d073ea2f330cdbb44778581d12a8d6.bindPopup(popup_7c17b2079cd05667b5a42b5ebb3f9f1d)
#         ;
#
#
#
#
#             var marker_8fbeed999dc23e217cf8b66289a051ee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3de0fec142248737850da84e068b4f13);
#
#
#         var popup_5a8f5847baa39040acb546e64989ed05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74d0e2634159c07ad66c3ec6f5a2e524 = $(`&lt;div id=&quot;html_74d0e2634159c07ad66c3ec6f5a2e524&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5a8f5847baa39040acb546e64989ed05.setContent(html_74d0e2634159c07ad66c3ec6f5a2e524);
#
#
#
#         marker_8fbeed999dc23e217cf8b66289a051ee.bindPopup(popup_5a8f5847baa39040acb546e64989ed05)
#         ;
#
#
#
#
#             var marker_3d4fef985e589c045d7bc2c51a2e5e09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3de0fec142248737850da84e068b4f13);
#
#
#         var popup_58047fd485e8694625717c705da33374 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_376f84019c4e6df477c679c8ca9ea85d = $(`&lt;div id=&quot;html_376f84019c4e6df477c679c8ca9ea85d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_58047fd485e8694625717c705da33374.setContent(html_376f84019c4e6df477c679c8ca9ea85d);
#
#
#
#         marker_3d4fef985e589c045d7bc2c51a2e5e09.bindPopup(popup_58047fd485e8694625717c705da33374)
#         ;
#
#
#
#
#             var marker_50dca0f3df2eec2172cc6e18ea4a11f7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3de0fec142248737850da84e068b4f13);
#
#
#         var popup_48e4f382bb3f0fd22836a34c535067f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d82e9230c0d3e8ec35b96cd0b08c3a66 = $(`&lt;div id=&quot;html_d82e9230c0d3e8ec35b96cd0b08c3a66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_48e4f382bb3f0fd22836a34c535067f6.setContent(html_d82e9230c0d3e8ec35b96cd0b08c3a66);
#
#
#
#         marker_50dca0f3df2eec2172cc6e18ea4a11f7.bindPopup(popup_48e4f382bb3f0fd22836a34c535067f6)
#         ;
#
#
#
#
#             var marker_03421d059e00867aca597e3737b115e2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3de0fec142248737850da84e068b4f13);
#
#
#         var popup_fe4b4205822c54750498b17c659427ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4d73bc4dab6c63b872ad0541046bf68 = $(`&lt;div id=&quot;html_f4d73bc4dab6c63b872ad0541046bf68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fe4b4205822c54750498b17c659427ae.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84ad51329150d117dfec0ca86d09e9fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84ad51329150d117dfec0ca86d09e9fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84ad51329150d117dfec0ca86d09e9fa = L.map(
#                 &quot;map_84ad51329150d117dfec0ca86d09e9fa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f0744e47a6b88e2465fd4a1bca01bbf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f0744e47a6b88e2465fd4a1bca01bbf.addTo(map_84ad51329150d117dfec0ca86d09e9fa);
#
#
#             var feature_group_d598e5ffabff9196350c6419a4befca7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_49aa00493fdaaafd1545fed150121fb8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d598e5ffabff9196350c6419a4befca7);
#
#
#         var popup_cb230361c5704c0f35db6fa4932f5d26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c69119f6ad5f8878b78b658514f18b6e = $(`&lt;div id=&quot;html_c69119f6ad5f8878b78b658514f18b6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cb230361c5704c0f35db6fa4932f5d26.setContent(html_c69119f6ad5f8878b78b658514f18b6e);
#
#
#
#         marker_49aa00493fdaaafd1545fed150121fb8.bindPopup(popup_cb230361c5704c0f35db6fa4932f5d26)
#         ;
#
#
#
#
#             var marker_7c1d4ff32fa699a108463e99d6a67ded = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d598e5ffabff9196350c6419a4befca7);
#
#
#         var popup_a9d67b0b8e0ae89b7b58ec148e2775de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f089af8cee39b6c8655b3926b89a9e6 = $(`&lt;div id=&quot;html_6f089af8cee39b6c8655b3926b89a9e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a9d67b0b8e0ae89b7b58ec148e2775de.setContent(html_6f089af8cee39b6c8655b3926b89a9e6);
#
#
#
#         marker_7c1d4ff32fa699a108463e99d6a67ded.bindPopup(popup_a9d67b0b8e0ae89b7b58ec148e2775de)
#         ;
#
#
#
#
#             var marker_2e15064fbced9bc89d997878b4c4b026 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d598e5ffabff9196350c6419a4befca7);
#
#
#         var popup_b986ad9cf16e469dc983b602414cefc6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d66fcafffa5fc561c43e18e2d10cb16b = $(`&lt;div id=&quot;html_d66fcafffa5fc561c43e18e2d10cb16b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b986ad9cf16e469dc983b602414cefc6.setContent(html_d66fcafffa5fc561c43e18e2d10cb16b);
#
#
#
#         marker_2e15064fbced9bc89d997878b4c4b026.bindPopup(popup_b986ad9cf16e469dc983b602414cefc6)
#         ;
#
#
#
#
#             var marker_4aadb780eb9470fd159675a5cee12ec1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d598e5ffabff9196350c6419a4befca7);
#
#
#         var popup_5be54c6d6200fc87e063fd9099e86251 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_379e4870ce4777884a7041f38fcdfac2 = $(`&lt;div id=&quot;html_379e4870ce4777884a7041f38fcdfac2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5be54c6d6200fc87e063fd9099e86251.setContent(html_379e4870ce4777884a7041f38fcdfac2);
#
#
#
#         marker_4aadb780eb9470fd159675a5cee12ec1.bindPopup(popup_5be54c6d6200fc87e063fd9099e86251)
#         ;
#
#
#
#
#             var marker_c64a1a4c39b6e7085473b7073343428c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d598e5ffabff9196350c6419a4befca7);
#
#
#         var popup_dae5c05be19fec3e67f7821f6c775433 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfc3651c8eb94210b929e85d7f0f8e3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfc3651c8eb94210b929e85d7f0f8e3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfc3651c8eb94210b929e85d7f0f8e3f = L.map(
#                 &quot;map_cfc3651c8eb94210b929e85d7f0f8e3f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6c0736c10d0ed5e100420e3150ae29ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6c0736c10d0ed5e100420e3150ae29ed.addTo(map_cfc3651c8eb94210b929e85d7f0f8e3f);
#
#
#             var feature_group_992864c202e991ed869ea7b7d5dce758 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_992864c202e991ed869ea7b7d5dce758.addTo(map_cfc3651c8eb94210b929e85d7f0f8e3f);
#
#
#             var feature_group_sub_group_531f57a5d681edc6c8da0ff0a5607c0b = L.featureGroup.subGroup(
#                 feature_group_992864c202e991ed869ea7b7d5dce758
#             );
#
#
#             var marker_bf8c6aeb74bff4f5634ba83cd4535f2a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_531f57a5d681edc6c8da0ff0a5607c0b);
#
#
#         var popup_d3b482edaa0c379667b39f254bf2bc4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1e372c5611ac61667039bb59c52f475 = $(`&lt;div id=&quot;html_e1e372c5611ac61667039bb59c52f475&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d3b482edaa0c379667b39f254bf2bc4b.setContent(html_e1e372c5611ac61667039bb59c52f475);
#
#
#
#         marker_bf8c6aeb74bff4f5634ba83cd4535f2a.bindPopup(popup_d3b482edaa0c379667b39f254bf2bc4b)
#         ;
#
#
#
#
#             var marker_f337024dcbcb8d30366cbe0a655d5d4e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_531f57a5d681edc6c8da0ff0a5607c0b);
#
#
#         var popup_7849e2f3fa5bb3d83feab2056cf7319d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c0a64756404745a4d6d7f8b5dd35ad8 = $(`&lt;div id=&quot;html_6c0a64756404745a4d6d7f8b5dd35ad8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7849e2f3fa5bb3d83feab2056cf7319d.setContent(html_6c0a64756404745a4d6d7f8b5dd35ad8);
#
#
#
#         marker_f337024dcbcb8d30366cbe0a655d5d4e.bindPopup(popup_7849e2f3fa5bb3d83feab2056cf7319d)
#         ;
#
#
#
#
#             var marker_d22d0d9d09a375d16e52d8f28838b8d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_531f57a5d681edc6c8da0ff0a5607c0b);
#
#
#         var popup_24b88cc70dbd7aee1f751b790295aaab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4c54eb2e555981d04695b6dcd96f14c = $(`&lt;div id=&quot;html_a4c54eb2e555981d04695b6dcd96f14c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_24b88cc70dbd7aee1f751b790295aaab.setContent(html_a4c54eb2e555981d04695b6dcd96f14c);
#
#
#
#         marker_d22d0d9d09a375d16e52d8f28838b8d9.bindPopup(popup_24b88cc70dbd7aee1f751b790295aaab)
#         ;
#
#
#
#
#             var marker_cdae4e4f3738d2ebced7accf8de78bc8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_531f57a5d681edc6c8da0ff0a5607c0b);
#
#
#         var popup_7174c4b5492f9d9e8d3cda5a2317a48e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a0fde5dd6ffcdabbefb21c01d09cdad = $(`&lt;div id=&quot;html_3a0fde5dd6ffcdabbefb21c01d09cdad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7174c4b5492f9d9e8d3cda5a2317a48e.setContent(html_3a0fde5dd6ffcdabbefb21c01d09cdad);
#
#
#
#         marker_
