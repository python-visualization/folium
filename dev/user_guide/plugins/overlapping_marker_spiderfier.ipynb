# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ac461614dcb0f7e8b792f12affec569 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ac461614dcb0f7e8b792f12affec569&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ac461614dcb0f7e8b792f12affec569 = L.map(
#                 &quot;map_3ac461614dcb0f7e8b792f12affec569&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a13b43fc90eba74f07c9c40b6571933d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a13b43fc90eba74f07c9c40b6571933d.addTo(map_3ac461614dcb0f7e8b792f12affec569);
#
#
#             var marker_11d02e9ece5fc1e468830afc7fd2ba56 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3ac461614dcb0f7e8b792f12affec569);
#
#
#         var popup_46672441e635a309310e553ecc2f95f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_351fc73f5b8c7cd1cb42d373a8ab8f3c = $(`&lt;div id=&quot;html_351fc73f5b8c7cd1cb42d373a8ab8f3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_46672441e635a309310e553ecc2f95f1.setContent(html_351fc73f5b8c7cd1cb42d373a8ab8f3c);
#
#
#
#         marker_11d02e9ece5fc1e468830afc7fd2ba56.bindPopup(popup_46672441e635a309310e553ecc2f95f1)
#         ;
#
#
#
#
#             var marker_5a55275ea2ee58c22a907486809bc446 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3ac461614dcb0f7e8b792f12affec569);
#
#
#         var popup_f95bfb47440362ae307c2a20e4175938 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d76533c0d81549b8cdcb33076206626c = $(`&lt;div id=&quot;html_d76533c0d81549b8cdcb33076206626c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f95bfb47440362ae307c2a20e4175938.setContent(html_d76533c0d81549b8cdcb33076206626c);
#
#
#
#         marker_5a55275ea2ee58c22a907486809bc446.bindPopup(popup_f95bfb47440362ae307c2a20e4175938)
#         ;
#
#
#
#
#             var marker_83ceaac1f1406d20527f25d581c3cd07 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3ac461614dcb0f7e8b792f12affec569);
#
#
#         var popup_9bbd0ba3577ef7084dfb7d39170b03b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd4bbad9c973da7cd31359213ced6963 = $(`&lt;div id=&quot;html_cd4bbad9c973da7cd31359213ced6963&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9bbd0ba3577ef7084dfb7d39170b03b2.setContent(html_cd4bbad9c973da7cd31359213ced6963);
#
#
#
#         marker_83ceaac1f1406d20527f25d581c3cd07.bindPopup(popup_9bbd0ba3577ef7084dfb7d39170b03b2)
#         ;
#
#
#
#
#             var marker_73f8784cb414d677fbeab8f34970147a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3ac461614dcb0f7e8b792f12affec569);
#
#
#         var popup_080fee1e386958d3b3fc0783341885a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97f68aa1499684200e24eae1b645bc46 = $(`&lt;div id=&quot;html_97f68aa1499684200e24eae1b645bc46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_080fee1e386958d3b3fc0783341885a7.setContent(html_97f68aa1499684200e24eae1b645bc46);
#
#
#
#         marker_73f8784cb414d677fbeab8f34970147a.bindPopup(popup_080fee1e386958d3b3fc0783341885a7)
#         ;
#
#
#
#
#             var marker_4d8f5b090f22c5beef67aeef84f8b73e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3ac461614dcb0f7e8b792f12affec569);
#
#
#         var popup_a616531e32160cadfa35cc21d3a14f98 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a545c465584f2c80dba542e4d3d16044 = $(`&lt;div id=&quot;html_a545c465584f2c80dba542e4d3d16044&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a616531e32160cadfa35cc21d3a14f98.setContent(html_a545c465584f2c80dba542e4d3d16044);
#
#
#
#         marker_4d8f5b090f22c5beef67aeef84f8b73e.bindPopup(popup_a616531e32160cadfa35cc21d3a14f98)
#         ;
#
#
#
#
#             var marker_6e4dd4e953

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b89272afa2ea3e9fd0d28a2f3c71c23 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b89272afa2ea3e9fd0d28a2f3c71c23&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b89272afa2ea3e9fd0d28a2f3c71c23 = L.map(
#                 &quot;map_3b89272afa2ea3e9fd0d28a2f3c71c23&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7e00b4dc42c9b85e41689d8f99c038d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7e00b4dc42c9b85e41689d8f99c038d.addTo(map_3b89272afa2ea3e9fd0d28a2f3c71c23);
#
#
#             var feature_group_f562e0f7f6c7114533a37447ab18f311 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ea723a9455b732256f72154877f2c19b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f562e0f7f6c7114533a37447ab18f311);
#
#
#         var popup_1c63dc14e3d0badf4caf865a3a0fb0ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_871162ba04efb3430043ba81b54ad023 = $(`&lt;div id=&quot;html_871162ba04efb3430043ba81b54ad023&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_1c63dc14e3d0badf4caf865a3a0fb0ec.setContent(html_871162ba04efb3430043ba81b54ad023);
#
#
#
#         marker_ea723a9455b732256f72154877f2c19b.bindPopup(popup_1c63dc14e3d0badf4caf865a3a0fb0ec)
#         ;
#
#
#
#
#             var marker_454d7bdb36decc489612773c576b956d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f562e0f7f6c7114533a37447ab18f311);
#
#
#         var popup_188d91cea2e6054c4244f99bfb0f359b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7634e5eaa2a86b39ccfd0823743836f3 = $(`&lt;div id=&quot;html_7634e5eaa2a86b39ccfd0823743836f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_188d91cea2e6054c4244f99bfb0f359b.setContent(html_7634e5eaa2a86b39ccfd0823743836f3);
#
#
#
#         marker_454d7bdb36decc489612773c576b956d.bindPopup(popup_188d91cea2e6054c4244f99bfb0f359b)
#         ;
#
#
#
#
#             var marker_3419f8104bc42163ab2f1a1a87e5bd53 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f562e0f7f6c7114533a37447ab18f311);
#
#
#         var popup_fda6664ac6e72e1a70d37105be807baf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2ec3237e8a653871345328e5b3027b4 = $(`&lt;div id=&quot;html_a2ec3237e8a653871345328e5b3027b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fda6664ac6e72e1a70d37105be807baf.setContent(html_a2ec3237e8a653871345328e5b3027b4);
#
#
#
#         marker_3419f8104bc42163ab2f1a1a87e5bd53.bindPopup(popup_fda6664ac6e72e1a70d37105be807baf)
#         ;
#
#
#
#
#             var marker_5e54881f1f2bafdd0307fbc32503b95a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f562e0f7f6c7114533a37447ab18f311);
#
#
#         var popup_18a1e754d5f0bd0a4257a070ba625900 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80a42365180501ef9c4648083ae391f9 = $(`&lt;div id=&quot;html_80a42365180501ef9c4648083ae391f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_18a1e754d5f0bd0a4257a070ba625900.setContent(html_80a42365180501ef9c4648083ae391f9);
#
#
#
#         marker_5e54881f1f2bafdd0307fbc32503b95a.bindPopup(popup_18a1e754d5f0bd0a4257a070ba625900)
#         ;
#
#
#
#
#             var marker_d4dad278cf24d1e2e414a742a4c01b03 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f562e0f7f6c7114533a37447ab18f311);
#
#
#         var popup_701c3a3e8979a2d39847b86b54323892 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94288b0b0424d49edda2d963c471b3d1 = $(`&lt;div id=&quot;html_94288b0b0424d49edda2d963c471b3d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_701c3a3e8979a2d398

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_adb477f23f40da0e8fe85709f303859e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_adb477f23f40da0e8fe85709f303859e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_adb477f23f40da0e8fe85709f303859e = L.map(
#                 &quot;map_adb477f23f40da0e8fe85709f303859e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e7fa8754d447fbe9019424b8ec9196f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e7fa8754d447fbe9019424b8ec9196f.addTo(map_adb477f23f40da0e8fe85709f303859e);
#
#
#             var feature_group_2925454a14dea30525bb1d68b888eb20 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2925454a14dea30525bb1d68b888eb20.addTo(map_adb477f23f40da0e8fe85709f303859e);
#
#
#             var feature_group_sub_group_2e9b02cc0e03e7be1c7b0744fb48ed5c = L.featureGroup.subGroup(
#                 feature_group_2925454a14dea30525bb1d68b888eb20
#             );
#
#
#             var marker_ce708d677df26ab8ce7afd64c0d7d682 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e9b02cc0e03e7be1c7b0744fb48ed5c);
#
#
#         var popup_50613bbeb924e79dedd68b1f4238efee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a776c0fac5f09c0bfea56007012718d = $(`&lt;div id=&quot;html_0a776c0fac5f09c0bfea56007012718d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_50613bbeb924e79dedd68b1f4238efee.setContent(html_0a776c0fac5f09c0bfea56007012718d);
#
#
#
#         marker_ce708d677df26ab8ce7afd64c0d7d682.bindPopup(popup_50613bbeb924e79dedd68b1f4238efee)
#         ;
#
#
#
#
#             var marker_807b42ade6ff5e456c19e95c0bc967a3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e9b02cc0e03e7be1c7b0744fb48ed5c);
#
#
#         var popup_bf5efe51594fcc814bb783653b491ecc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b869c7f60263a91f7120f1d360adf092 = $(`&lt;div id=&quot;html_b869c7f60263a91f7120f1d360adf092&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bf5efe51594fcc814bb783653b491ecc.setContent(html_b869c7f60263a91f7120f1d360adf092);
#
#
#
#         marker_807b42ade6ff5e456c19e95c0bc967a3.bindPopup(popup_bf5efe51594fcc814bb783653b491ecc)
#         ;
#
#
#
#
#             var marker_3238da71ca087e933d9a2767df6038a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e9b02cc0e03e7be1c7b0744fb48ed5c);
#
#
#         var popup_bba4d7b032674efea93855d354e231b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd5c421a9e672fc9508ac40c276bdd5c = $(`&lt;div id=&quot;html_dd5c421a9e672fc9508ac40c276bdd5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bba4d7b032674efea93855d354e231b4.setContent(html_dd5c421a9e672fc9508ac40c276bdd5c);
#
#
#
#         marker_3238da71ca087e933d9a2767df6038a2.bindPopup(popup_bba4d7b032674efea93855d354e231b4)
#         ;
#
#
#
#
#             var marker_b006ee8cccd39a05af396b45989aed7d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e9b02cc0e03e7be1c7b0744fb48ed5c);
#
#
#         var popup_8718104c88f947631bde7ea8115d1e92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34ab142a858503be3f964e67b019a55f = $(`&lt;div id=&quot;html_34ab142a858503be3f964e67b019a55f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8718104c88f947631bde7ea8115d1e92.setContent(html_34ab142a858503be3f964e67b019a55f);
#
#
#
#         marker_b006ee8cccd39a05af396b45989aed7d.bindPopup(popup_8718104c88f947631bde7ea8115d1e92)
#         ;
#
#
#
#
#             var marker_2ab0a70f605c7d623e896584722758ae = L.marker(
#                 [45.050399999999996, 3.0504],
