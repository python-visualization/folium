# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63d0b2cc4ee7abcdb17b20017501733b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63d0b2cc4ee7abcdb17b20017501733b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63d0b2cc4ee7abcdb17b20017501733b = L.map(
#                 &quot;map_63d0b2cc4ee7abcdb17b20017501733b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_645d56ed90d4d1f532c7287d6e9369ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_645d56ed90d4d1f532c7287d6e9369ee.addTo(map_63d0b2cc4ee7abcdb17b20017501733b);
#
#
#             var marker_f217a7b81dfbbeb76a89647ef6c1e977 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_63d0b2cc4ee7abcdb17b20017501733b);
#
#
#         var popup_1cff8be413f97b5a33343c9ea5aadd88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a8413548db39b7681aa8cbfa66b03c9 = $(`&lt;div id=&quot;html_8a8413548db39b7681aa8cbfa66b03c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1cff8be413f97b5a33343c9ea5aadd88.setContent(html_8a8413548db39b7681aa8cbfa66b03c9);
#
#
#
#         marker_f217a7b81dfbbeb76a89647ef6c1e977.bindPopup(popup_1cff8be413f97b5a33343c9ea5aadd88)
#         ;
#
#
#
#
#             var marker_9f148a6daf05d957aa58ff907db2f9d9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_63d0b2cc4ee7abcdb17b20017501733b);
#
#
#         var popup_f583758a32841f5a98c3f582c01a8c54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9c539f5c516008e74ef83a8a4ca2a2a = $(`&lt;div id=&quot;html_b9c539f5c516008e74ef83a8a4ca2a2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f583758a32841f5a98c3f582c01a8c54.setContent(html_b9c539f5c516008e74ef83a8a4ca2a2a);
#
#
#
#         marker_9f148a6daf05d957aa58ff907db2f9d9.bindPopup(popup_f583758a32841f5a98c3f582c01a8c54)
#         ;
#
#
#
#
#             var marker_502dbe6c9393aca334e18738ae75bb87 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_63d0b2cc4ee7abcdb17b20017501733b);
#
#
#         var popup_cea4af3432af3ae2d06d32e0df47f066 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c62d04834486a5217980a27c6897cd10 = $(`&lt;div id=&quot;html_c62d04834486a5217980a27c6897cd10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cea4af3432af3ae2d06d32e0df47f066.setContent(html_c62d04834486a5217980a27c6897cd10);
#
#
#
#         marker_502dbe6c9393aca334e18738ae75bb87.bindPopup(popup_cea4af3432af3ae2d06d32e0df47f066)
#         ;
#
#
#
#
#             var marker_28c0f78282f16e8d90223fd365e48243 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_63d0b2cc4ee7abcdb17b20017501733b);
#
#
#         var popup_47ab283d7a255d11bd01a179eb2dc4dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4234b29e9c367e4444f32f3841fc6f9b = $(`&lt;div id=&quot;html_4234b29e9c367e4444f32f3841fc6f9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_47ab283d7a255d11bd01a179eb2dc4dc.setContent(html_4234b29e9c367e4444f32f3841fc6f9b);
#
#
#
#         marker_28c0f78282f16e8d90223fd365e48243.bindPopup(popup_47ab283d7a255d11bd01a179eb2dc4dc)
#         ;
#
#
#
#
#             var marker_b368bcd486ce4f0098107b0f966233e8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_63d0b2cc4ee7abcdb17b20017501733b);
#
#
#         var popup_ffc75e125f1e5a318b704cf457a6e91a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe9e496c5bfda171c38d953d86cc8214 = $(`&lt;div id=&quot;html_fe9e496c5bfda171c38d953d86cc8214&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ffc75e125f1e5a318b704cf457a6e91a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f90e94e7286b03ec391fafefbaca869 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f90e94e7286b03ec391fafefbaca869&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f90e94e7286b03ec391fafefbaca869 = L.map(
#                 &quot;map_1f90e94e7286b03ec391fafefbaca869&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f791e99bb73a80bfd8b987b2a9e3044 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f791e99bb73a80bfd8b987b2a9e3044.addTo(map_1f90e94e7286b03ec391fafefbaca869);
#
#
#             var feature_group_6d139647a1cdaa26d6b2595944920996 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5715dba9b1a04a035725fba0ee08bb74 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6d139647a1cdaa26d6b2595944920996);
#
#
#         var popup_657165fc7c9d6f40d562d747c681b832 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d61678a0a0ad703643afa1ffaa912c83 = $(`&lt;div id=&quot;html_d61678a0a0ad703643afa1ffaa912c83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_657165fc7c9d6f40d562d747c681b832.setContent(html_d61678a0a0ad703643afa1ffaa912c83);
#
#
#
#         marker_5715dba9b1a04a035725fba0ee08bb74.bindPopup(popup_657165fc7c9d6f40d562d747c681b832)
#         ;
#
#
#
#
#             var marker_6e7534166feb5dc27c94a14334dff7aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6d139647a1cdaa26d6b2595944920996);
#
#
#         var popup_01b96b7aa12a7cfba8406264919782fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b23f7e95fb8edc24be1353cd6877c95e = $(`&lt;div id=&quot;html_b23f7e95fb8edc24be1353cd6877c95e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_01b96b7aa12a7cfba8406264919782fc.setContent(html_b23f7e95fb8edc24be1353cd6877c95e);
#
#
#
#         marker_6e7534166feb5dc27c94a14334dff7aa.bindPopup(popup_01b96b7aa12a7cfba8406264919782fc)
#         ;
#
#
#
#
#             var marker_5db76d6871724834d76ae476d4a4bf44 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6d139647a1cdaa26d6b2595944920996);
#
#
#         var popup_af141c5cc4dd19c7c129e0b6367c3592 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c7dd5c630691d9120a7619e9e884bb6 = $(`&lt;div id=&quot;html_3c7dd5c630691d9120a7619e9e884bb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_af141c5cc4dd19c7c129e0b6367c3592.setContent(html_3c7dd5c630691d9120a7619e9e884bb6);
#
#
#
#         marker_5db76d6871724834d76ae476d4a4bf44.bindPopup(popup_af141c5cc4dd19c7c129e0b6367c3592)
#         ;
#
#
#
#
#             var marker_b27dafecbfab951d79760244300876b5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6d139647a1cdaa26d6b2595944920996);
#
#
#         var popup_671d7fcd5b82cb397ee3b7757c23d85b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9860c6a1553ea7b5f634c19608f8fb55 = $(`&lt;div id=&quot;html_9860c6a1553ea7b5f634c19608f8fb55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_671d7fcd5b82cb397ee3b7757c23d85b.setContent(html_9860c6a1553ea7b5f634c19608f8fb55);
#
#
#
#         marker_b27dafecbfab951d79760244300876b5.bindPopup(popup_671d7fcd5b82cb397ee3b7757c23d85b)
#         ;
#
#
#
#
#             var marker_a72ffdc38b698017b6ca0a570a8e60c4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6d139647a1cdaa26d6b2595944920996);
#
#
#         var popup_b099a2dcf77114585f6ed9959a7b8dba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a16dea59285cef0aeaec3fe69fcf0654 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a16dea59285cef0aeaec3fe69fcf0654&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a16dea59285cef0aeaec3fe69fcf0654 = L.map(
#                 &quot;map_a16dea59285cef0aeaec3fe69fcf0654&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_394839d147df1cea9dd6197cea4c2e71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_394839d147df1cea9dd6197cea4c2e71.addTo(map_a16dea59285cef0aeaec3fe69fcf0654);
#
#
#             var feature_group_b33e8a122cf42846375e200f46cef4fb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b33e8a122cf42846375e200f46cef4fb.addTo(map_a16dea59285cef0aeaec3fe69fcf0654);
#
#
#             var feature_group_sub_group_94bbd0b98c89d5adf20c79f351be099a = L.featureGroup.subGroup(
#                 feature_group_b33e8a122cf42846375e200f46cef4fb
#             );
#
#
#             var marker_e561ad7f0978e7f51906125508563dbe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_94bbd0b98c89d5adf20c79f351be099a);
#
#
#         var popup_5380d2fba556c6a5827a98c23415b07b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91dfc37d529f3e30d5bb3d2a71ed508b = $(`&lt;div id=&quot;html_91dfc37d529f3e30d5bb3d2a71ed508b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5380d2fba556c6a5827a98c23415b07b.setContent(html_91dfc37d529f3e30d5bb3d2a71ed508b);
#
#
#
#         marker_e561ad7f0978e7f51906125508563dbe.bindPopup(popup_5380d2fba556c6a5827a98c23415b07b)
#         ;
#
#
#
#
#             var marker_089a278553f91b2fe88950361e440304 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_94bbd0b98c89d5adf20c79f351be099a);
#
#
#         var popup_61df18829ba3035e52bba91c47750fcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9cdb3b522a303816defc1b5a3c0cece = $(`&lt;div id=&quot;html_a9cdb3b522a303816defc1b5a3c0cece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_61df18829ba3035e52bba91c47750fcd.setContent(html_a9cdb3b522a303816defc1b5a3c0cece);
#
#
#
#         marker_089a278553f91b2fe88950361e440304.bindPopup(popup_61df18829ba3035e52bba91c47750fcd)
#         ;
#
#
#
#
#             var marker_01cd111072c7856f4451bd5fe80dfde2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_94bbd0b98c89d5adf20c79f351be099a);
#
#
#         var popup_b5d3ea294704b07c001f4b804331cfa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b1dafdb6e9f7ea1a72a71fb0f12378d = $(`&lt;div id=&quot;html_5b1dafdb6e9f7ea1a72a71fb0f12378d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b5d3ea294704b07c001f4b804331cfa4.setContent(html_5b1dafdb6e9f7ea1a72a71fb0f12378d);
#
#
#
#         marker_01cd111072c7856f4451bd5fe80dfde2.bindPopup(popup_b5d3ea294704b07c001f4b804331cfa4)
#         ;
#
#
#
#
#             var marker_0bcc797888d2749a57cce590a48618c5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_94bbd0b98c89d5adf20c79f351be099a);
#
#
#         var popup_d84a5937251d7f26f25df6d2e659c55c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08850876112990ed89bb6339c6afb4c7 = $(`&lt;div id=&quot;html_08850876112990ed89bb6339c6afb4c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d84a5937251d7f26f25df6d2e659c55c.setContent(html_08850876112990ed89bb6339c6afb4c7);
#
#
#
#         marker_
