# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85fa108c2e71e2cc374d70c8a40b3910 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85fa108c2e71e2cc374d70c8a40b3910&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85fa108c2e71e2cc374d70c8a40b3910 = L.map(
#                 &quot;map_85fa108c2e71e2cc374d70c8a40b3910&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_26f3068d2b5ed11e69696b8151e15611 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_26f3068d2b5ed11e69696b8151e15611.addTo(map_85fa108c2e71e2cc374d70c8a40b3910);
#
#
#             var marker_7f69db7924b7837a93fc5a3e1019d789 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_85fa108c2e71e2cc374d70c8a40b3910);
#
#
#         var popup_d60bddfa511af5fd3b61544783819db5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fa01c145e1b44e082cc7e77e51d96fb = $(`&lt;div id=&quot;html_9fa01c145e1b44e082cc7e77e51d96fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d60bddfa511af5fd3b61544783819db5.setContent(html_9fa01c145e1b44e082cc7e77e51d96fb);
#
#
#
#         marker_7f69db7924b7837a93fc5a3e1019d789.bindPopup(popup_d60bddfa511af5fd3b61544783819db5)
#         ;
#
#
#
#
#             var marker_14fbb26d077f7a5c6902baf1feb045a9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_85fa108c2e71e2cc374d70c8a40b3910);
#
#
#         var popup_17a9f671b995aa11f5ed88918dc15aca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21a555df957591748535be4df817cb3c = $(`&lt;div id=&quot;html_21a555df957591748535be4df817cb3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_17a9f671b995aa11f5ed88918dc15aca.setContent(html_21a555df957591748535be4df817cb3c);
#
#
#
#         marker_14fbb26d077f7a5c6902baf1feb045a9.bindPopup(popup_17a9f671b995aa11f5ed88918dc15aca)
#         ;
#
#
#
#
#             var marker_522e61a3cb69ac06c02743ea6998932c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_85fa108c2e71e2cc374d70c8a40b3910);
#
#
#         var popup_c96f14f9ceeb9385c5c5db9009d04ddc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1b73d0dbb41d343f67d5f8b7b4ce291 = $(`&lt;div id=&quot;html_e1b73d0dbb41d343f67d5f8b7b4ce291&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c96f14f9ceeb9385c5c5db9009d04ddc.setContent(html_e1b73d0dbb41d343f67d5f8b7b4ce291);
#
#
#
#         marker_522e61a3cb69ac06c02743ea6998932c.bindPopup(popup_c96f14f9ceeb9385c5c5db9009d04ddc)
#         ;
#
#
#
#
#             var marker_7e1e0de7624169bca792d05b5d977a2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_85fa108c2e71e2cc374d70c8a40b3910);
#
#
#         var popup_bf42901d73c5b48c44167a77571db7d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b141f49ce35889b33e4090f071bd20b7 = $(`&lt;div id=&quot;html_b141f49ce35889b33e4090f071bd20b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bf42901d73c5b48c44167a77571db7d7.setContent(html_b141f49ce35889b33e4090f071bd20b7);
#
#
#
#         marker_7e1e0de7624169bca792d05b5d977a2b.bindPopup(popup_bf42901d73c5b48c44167a77571db7d7)
#         ;
#
#
#
#
#             var marker_64fa96cf985a71ec6ac713c36b340504 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_85fa108c2e71e2cc374d70c8a40b3910);
#
#
#         var popup_9808cdbcb8522e486964113583534890 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c479c8f9d48411d3f5c1ee01071e0c1b = $(`&lt;div id=&quot;html_c479c8f9d48411d3f5c1ee01071e0c1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9808cdbcb8522e486964113583534890.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f5a37d325a1917c4ae9bd54342d7355 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f5a37d325a1917c4ae9bd54342d7355&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f5a37d325a1917c4ae9bd54342d7355 = L.map(
#                 &quot;map_9f5a37d325a1917c4ae9bd54342d7355&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7a1b0116afce88038b472b28654afa8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7a1b0116afce88038b472b28654afa8.addTo(map_9f5a37d325a1917c4ae9bd54342d7355);
#
#
#             var feature_group_cc34e175bc9c636511e613c36ce6aebd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_74f9e104cd56ce9c258dff4a0b273efd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cc34e175bc9c636511e613c36ce6aebd);
#
#
#         var popup_4173370ee76c49b5ffafae5987d2984c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_788ae0f26e638f929c1f54a49c5eb924 = $(`&lt;div id=&quot;html_788ae0f26e638f929c1f54a49c5eb924&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4173370ee76c49b5ffafae5987d2984c.setContent(html_788ae0f26e638f929c1f54a49c5eb924);
#
#
#
#         marker_74f9e104cd56ce9c258dff4a0b273efd.bindPopup(popup_4173370ee76c49b5ffafae5987d2984c)
#         ;
#
#
#
#
#             var marker_f730d53b2cdca59dc8b41e25b4be7e06 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cc34e175bc9c636511e613c36ce6aebd);
#
#
#         var popup_485a1d5811438bd239d383a8549fd346 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c33e82584db068f3a753c92da74dfa6c = $(`&lt;div id=&quot;html_c33e82584db068f3a753c92da74dfa6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_485a1d5811438bd239d383a8549fd346.setContent(html_c33e82584db068f3a753c92da74dfa6c);
#
#
#
#         marker_f730d53b2cdca59dc8b41e25b4be7e06.bindPopup(popup_485a1d5811438bd239d383a8549fd346)
#         ;
#
#
#
#
#             var marker_182a1cc2c2ca8657534f362fce8963f7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cc34e175bc9c636511e613c36ce6aebd);
#
#
#         var popup_acae7ca2960a20996cc5fdf58964f6ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_814815bef94df9de8fee69f97adcd35d = $(`&lt;div id=&quot;html_814815bef94df9de8fee69f97adcd35d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_acae7ca2960a20996cc5fdf58964f6ed.setContent(html_814815bef94df9de8fee69f97adcd35d);
#
#
#
#         marker_182a1cc2c2ca8657534f362fce8963f7.bindPopup(popup_acae7ca2960a20996cc5fdf58964f6ed)
#         ;
#
#
#
#
#             var marker_a54bb93eeca1e237b2754b92b2a9670c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cc34e175bc9c636511e613c36ce6aebd);
#
#
#         var popup_69e1f351b1acd2d2aa596e3480faffe5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ddf7f5362013a881534e633f80333be = $(`&lt;div id=&quot;html_8ddf7f5362013a881534e633f80333be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_69e1f351b1acd2d2aa596e3480faffe5.setContent(html_8ddf7f5362013a881534e633f80333be);
#
#
#
#         marker_a54bb93eeca1e237b2754b92b2a9670c.bindPopup(popup_69e1f351b1acd2d2aa596e3480faffe5)
#         ;
#
#
#
#
#             var marker_4c22e9406e6de149d1c84d98c294be62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cc34e175bc9c636511e613c36ce6aebd);
#
#
#         var popup_3eb739a6d7a81280af946887be59d017 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_52de9d9b5b2007973f01270b33b37a39 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_52de9d9b5b2007973f01270b33b37a39&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_52de9d9b5b2007973f01270b33b37a39 = L.map(
#                 &quot;map_52de9d9b5b2007973f01270b33b37a39&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3f571f43b7365e9ebffa74f545b31b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3f571f43b7365e9ebffa74f545b31b1.addTo(map_52de9d9b5b2007973f01270b33b37a39);
#
#
#             var feature_group_9eb349abf3a6361532d62c62146d1322 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9eb349abf3a6361532d62c62146d1322.addTo(map_52de9d9b5b2007973f01270b33b37a39);
#
#
#             var feature_group_sub_group_4745e5b37b2d34889d7ead218a427b00 = L.featureGroup.subGroup(
#                 feature_group_9eb349abf3a6361532d62c62146d1322
#             );
#
#
#             var marker_47966523ccbd0195ec42d823e00e7ab0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4745e5b37b2d34889d7ead218a427b00);
#
#
#         var popup_035a31b8c6242128b1966c0f6724a5bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47237b1a881bdacf3a13826be700a7a3 = $(`&lt;div id=&quot;html_47237b1a881bdacf3a13826be700a7a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_035a31b8c6242128b1966c0f6724a5bd.setContent(html_47237b1a881bdacf3a13826be700a7a3);
#
#
#
#         marker_47966523ccbd0195ec42d823e00e7ab0.bindPopup(popup_035a31b8c6242128b1966c0f6724a5bd)
#         ;
#
#
#
#
#             var marker_e46902a2212fddc66514e6ea2942719e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4745e5b37b2d34889d7ead218a427b00);
#
#
#         var popup_b50dded40580190667aafb29d4e37b14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef374d552a5bb4ce55ec26c743b5bf35 = $(`&lt;div id=&quot;html_ef374d552a5bb4ce55ec26c743b5bf35&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b50dded40580190667aafb29d4e37b14.setContent(html_ef374d552a5bb4ce55ec26c743b5bf35);
#
#
#
#         marker_e46902a2212fddc66514e6ea2942719e.bindPopup(popup_b50dded40580190667aafb29d4e37b14)
#         ;
#
#
#
#
#             var marker_791c181a687178e6f5e53ef888f926cb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4745e5b37b2d34889d7ead218a427b00);
#
#
#         var popup_62c6bcfbda35d07a5c76a6e01bb3202a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a09ce84d1bd585cfaa50762df648905 = $(`&lt;div id=&quot;html_1a09ce84d1bd585cfaa50762df648905&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_62c6bcfbda35d07a5c76a6e01bb3202a.setContent(html_1a09ce84d1bd585cfaa50762df648905);
#
#
#
#         marker_791c181a687178e6f5e53ef888f926cb.bindPopup(popup_62c6bcfbda35d07a5c76a6e01bb3202a)
#         ;
#
#
#
#
#             var marker_c4e6da96846434e0e21891066b08c750 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4745e5b37b2d34889d7ead218a427b00);
#
#
#         var popup_a6e5dfb1bf63836f3e1abe89858da4fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a624f774033b027e26609948ba6b028c = $(`&lt;div id=&quot;html_a624f774033b027e26609948ba6b028c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a6e5dfb1bf63836f3e1abe89858da4fe.setContent(html_a624f774033b027e26609948ba6b028c);
#
#
#
#         marker_
