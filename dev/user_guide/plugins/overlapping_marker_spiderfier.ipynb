# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ed467f8cb395128a7be62304409eb8b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ed467f8cb395128a7be62304409eb8b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ed467f8cb395128a7be62304409eb8b2 = L.map(
#                 &quot;map_ed467f8cb395128a7be62304409eb8b2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eac7765cccf911267ab59417d5549ae0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eac7765cccf911267ab59417d5549ae0.addTo(map_ed467f8cb395128a7be62304409eb8b2);
#
#
#             var marker_0926568481a3bfcfffdce0f133b41e31 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ed467f8cb395128a7be62304409eb8b2);
#
#
#         var popup_54348664eb6d4dd78646c8125d2e2f62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58ca9a526cdc3a253fbb72b93fe1b412 = $(`&lt;div id=&quot;html_58ca9a526cdc3a253fbb72b93fe1b412&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_54348664eb6d4dd78646c8125d2e2f62.setContent(html_58ca9a526cdc3a253fbb72b93fe1b412);
#
#
#
#         marker_0926568481a3bfcfffdce0f133b41e31.bindPopup(popup_54348664eb6d4dd78646c8125d2e2f62)
#         ;
#
#
#
#
#             var marker_3c2d3410ec003cece1e1adfd21e51e79 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ed467f8cb395128a7be62304409eb8b2);
#
#
#         var popup_98b2724050376fe227209d4591f2f181 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2b5ba817a275ba8b34fb2854cebea02 = $(`&lt;div id=&quot;html_b2b5ba817a275ba8b34fb2854cebea02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_98b2724050376fe227209d4591f2f181.setContent(html_b2b5ba817a275ba8b34fb2854cebea02);
#
#
#
#         marker_3c2d3410ec003cece1e1adfd21e51e79.bindPopup(popup_98b2724050376fe227209d4591f2f181)
#         ;
#
#
#
#
#             var marker_302455d826968c81374aa72a016be65c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ed467f8cb395128a7be62304409eb8b2);
#
#
#         var popup_07e088ffd026870225c5138b5a1a711d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9af872da0bb6bfc291e37bac84e56f15 = $(`&lt;div id=&quot;html_9af872da0bb6bfc291e37bac84e56f15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_07e088ffd026870225c5138b5a1a711d.setContent(html_9af872da0bb6bfc291e37bac84e56f15);
#
#
#
#         marker_302455d826968c81374aa72a016be65c.bindPopup(popup_07e088ffd026870225c5138b5a1a711d)
#         ;
#
#
#
#
#             var marker_39368a63e944a3dbe50746cbfbf00509 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ed467f8cb395128a7be62304409eb8b2);
#
#
#         var popup_813ab8ff079200cf39fd5bb8ad6f0399 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a105a5920b907d2911eab63503c60373 = $(`&lt;div id=&quot;html_a105a5920b907d2911eab63503c60373&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_813ab8ff079200cf39fd5bb8ad6f0399.setContent(html_a105a5920b907d2911eab63503c60373);
#
#
#
#         marker_39368a63e944a3dbe50746cbfbf00509.bindPopup(popup_813ab8ff079200cf39fd5bb8ad6f0399)
#         ;
#
#
#
#
#             var marker_a0f11ae0443bb3b22bedb71e7cdb380a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ed467f8cb395128a7be62304409eb8b2);
#
#
#         var popup_b149676599b14bfb3db1bb2eecbae203 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_753eca4482974cacf7f5da9ef1c27559 = $(`&lt;div id=&quot;html_753eca4482974cacf7f5da9ef1c27559&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b149676599b14bfb3db1bb2eecbae203.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_16921ab53f407deb86933ab692f66588 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_16921ab53f407deb86933ab692f66588&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_16921ab53f407deb86933ab692f66588 = L.map(
#                 &quot;map_16921ab53f407deb86933ab692f66588&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15c749dea416580844d28961b3048024 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15c749dea416580844d28961b3048024.addTo(map_16921ab53f407deb86933ab692f66588);
#
#
#             var feature_group_2d09c9679cf8ed1cdd235da36e877b0a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6c79c7e035ae853623e3e85c24dcc207 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2d09c9679cf8ed1cdd235da36e877b0a);
#
#
#         var popup_08f103f4978ea5eb59024fac6da8ad47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cfe98f8b2c9690d8653203789fd5ea9 = $(`&lt;div id=&quot;html_8cfe98f8b2c9690d8653203789fd5ea9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_08f103f4978ea5eb59024fac6da8ad47.setContent(html_8cfe98f8b2c9690d8653203789fd5ea9);
#
#
#
#         marker_6c79c7e035ae853623e3e85c24dcc207.bindPopup(popup_08f103f4978ea5eb59024fac6da8ad47)
#         ;
#
#
#
#
#             var marker_e9667ff97f4862ed4e1168d6503009e0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2d09c9679cf8ed1cdd235da36e877b0a);
#
#
#         var popup_a48dba35fd6b12bc4834dd724e3e0b53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88dd64800e0e9b81bb6fcc17b3163eb1 = $(`&lt;div id=&quot;html_88dd64800e0e9b81bb6fcc17b3163eb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a48dba35fd6b12bc4834dd724e3e0b53.setContent(html_88dd64800e0e9b81bb6fcc17b3163eb1);
#
#
#
#         marker_e9667ff97f4862ed4e1168d6503009e0.bindPopup(popup_a48dba35fd6b12bc4834dd724e3e0b53)
#         ;
#
#
#
#
#             var marker_507b693eae95b380aa7521321b3c1004 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2d09c9679cf8ed1cdd235da36e877b0a);
#
#
#         var popup_746ec890ba8f16ab759e78547cf7b632 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bba538ef14ea4eeb232912e443ca6570 = $(`&lt;div id=&quot;html_bba538ef14ea4eeb232912e443ca6570&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_746ec890ba8f16ab759e78547cf7b632.setContent(html_bba538ef14ea4eeb232912e443ca6570);
#
#
#
#         marker_507b693eae95b380aa7521321b3c1004.bindPopup(popup_746ec890ba8f16ab759e78547cf7b632)
#         ;
#
#
#
#
#             var marker_e7b7613dda16bb9951c869b96f5365e1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2d09c9679cf8ed1cdd235da36e877b0a);
#
#
#         var popup_62b3af1394ca6d46750d72ac582cfbe7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70cacd6bd5d620274a7298901d9d0cd1 = $(`&lt;div id=&quot;html_70cacd6bd5d620274a7298901d9d0cd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_62b3af1394ca6d46750d72ac582cfbe7.setContent(html_70cacd6bd5d620274a7298901d9d0cd1);
#
#
#
#         marker_e7b7613dda16bb9951c869b96f5365e1.bindPopup(popup_62b3af1394ca6d46750d72ac582cfbe7)
#         ;
#
#
#
#
#             var marker_df74bf39e88af9f130b0b7c515a75787 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2d09c9679cf8ed1cdd235da36e877b0a);
#
#
#         var popup_ca11995b93bb5d1fbede2a3d2db96996 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa63904580221bf54a86378a88e52dbb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa63904580221bf54a86378a88e52dbb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa63904580221bf54a86378a88e52dbb = L.map(
#                 &quot;map_aa63904580221bf54a86378a88e52dbb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_825d5917b86d5e044d4dfb034492f009 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_825d5917b86d5e044d4dfb034492f009.addTo(map_aa63904580221bf54a86378a88e52dbb);
#
#
#             var feature_group_85f4ca47eaf73efb0a22106a6a4b463f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_85f4ca47eaf73efb0a22106a6a4b463f.addTo(map_aa63904580221bf54a86378a88e52dbb);
#
#
#             var feature_group_sub_group_229c2b25897ee210faf45538470890ff = L.featureGroup.subGroup(
#                 feature_group_85f4ca47eaf73efb0a22106a6a4b463f
#             );
#
#
#             var marker_09831782fb03f64eed3a8be672dd0bb6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_229c2b25897ee210faf45538470890ff);
#
#
#         var popup_02f99ce107c2a7a2598b2762e26bc331 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96c013e18403a54d9392886148777180 = $(`&lt;div id=&quot;html_96c013e18403a54d9392886148777180&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_02f99ce107c2a7a2598b2762e26bc331.setContent(html_96c013e18403a54d9392886148777180);
#
#
#
#         marker_09831782fb03f64eed3a8be672dd0bb6.bindPopup(popup_02f99ce107c2a7a2598b2762e26bc331)
#         ;
#
#
#
#
#             var marker_4a58c2cba574ade0a7683c8d4a90d721 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_229c2b25897ee210faf45538470890ff);
#
#
#         var popup_443cde9b9a66341db98f56c25d55e74f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32cee8f1c8048944c78eae532072d324 = $(`&lt;div id=&quot;html_32cee8f1c8048944c78eae532072d324&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_443cde9b9a66341db98f56c25d55e74f.setContent(html_32cee8f1c8048944c78eae532072d324);
#
#
#
#         marker_4a58c2cba574ade0a7683c8d4a90d721.bindPopup(popup_443cde9b9a66341db98f56c25d55e74f)
#         ;
#
#
#
#
#             var marker_442a6936004d8f26ab73d0856c323e86 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_229c2b25897ee210faf45538470890ff);
#
#
#         var popup_da2fd1d844ee98cc2f93d8f72d9199a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b30d992f3854a2dc5516232199a9b02 = $(`&lt;div id=&quot;html_9b30d992f3854a2dc5516232199a9b02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_da2fd1d844ee98cc2f93d8f72d9199a0.setContent(html_9b30d992f3854a2dc5516232199a9b02);
#
#
#
#         marker_442a6936004d8f26ab73d0856c323e86.bindPopup(popup_da2fd1d844ee98cc2f93d8f72d9199a0)
#         ;
#
#
#
#
#             var marker_5d4c5564b8987d1b49f5345fd6b1ea25 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_229c2b25897ee210faf45538470890ff);
#
#
#         var popup_22a2634c34e07232a87c0d8184dffc54 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e6b152d64494b4cfd424ee2881c8dd0b = $(`&lt;div id=&quot;html_e6b152d64494b4cfd424ee2881c8dd0b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_22a2634c34e07232a87c0d8184dffc54.setContent(html_e6b152d64494b4cfd424ee2881c8dd0b);
#
#
#
#         marker_
