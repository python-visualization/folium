# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43fb89a12533b564ff6c9f888127a9f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43fb89a12533b564ff6c9f888127a9f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43fb89a12533b564ff6c9f888127a9f0 = L.map(
#                 &quot;map_43fb89a12533b564ff6c9f888127a9f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0769adf03bdb110e95b5f09a40e115b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0769adf03bdb110e95b5f09a40e115b.addTo(map_43fb89a12533b564ff6c9f888127a9f0);
#
#
#             var marker_a7874dd416e1e0e9279aa64f42e8e248 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_43fb89a12533b564ff6c9f888127a9f0);
#
#
#         var popup_c36a9c97234d44a3d0c8f3e639cc2c52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62228eab3b03c370f65f4bd1b247b1b3 = $(`&lt;div id=&quot;html_62228eab3b03c370f65f4bd1b247b1b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c36a9c97234d44a3d0c8f3e639cc2c52.setContent(html_62228eab3b03c370f65f4bd1b247b1b3);
#
#
#
#         marker_a7874dd416e1e0e9279aa64f42e8e248.bindPopup(popup_c36a9c97234d44a3d0c8f3e639cc2c52)
#         ;
#
#
#
#
#             var marker_623b16c0883d1ef0c9c041c64acf54b1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_43fb89a12533b564ff6c9f888127a9f0);
#
#
#         var popup_b1cffcff69c6836f6c9cdcb890618c2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ccda5e256ef6e563f141c07aa9fc6e4 = $(`&lt;div id=&quot;html_8ccda5e256ef6e563f141c07aa9fc6e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b1cffcff69c6836f6c9cdcb890618c2c.setContent(html_8ccda5e256ef6e563f141c07aa9fc6e4);
#
#
#
#         marker_623b16c0883d1ef0c9c041c64acf54b1.bindPopup(popup_b1cffcff69c6836f6c9cdcb890618c2c)
#         ;
#
#
#
#
#             var marker_6812234e0cd9fe7b6f69a4de9fc8ea84 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_43fb89a12533b564ff6c9f888127a9f0);
#
#
#         var popup_d9aee174781f97b060087962e58b0aa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e9d6b75c1012acdbe3d8770e375aefb = $(`&lt;div id=&quot;html_9e9d6b75c1012acdbe3d8770e375aefb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d9aee174781f97b060087962e58b0aa8.setContent(html_9e9d6b75c1012acdbe3d8770e375aefb);
#
#
#
#         marker_6812234e0cd9fe7b6f69a4de9fc8ea84.bindPopup(popup_d9aee174781f97b060087962e58b0aa8)
#         ;
#
#
#
#
#             var marker_4e0658518d8b10e03db27ef6eb87b39e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_43fb89a12533b564ff6c9f888127a9f0);
#
#
#         var popup_6e424afb786f3c103b2019323ead2006 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07c362dd328063cfb39abae7d7f3a3d3 = $(`&lt;div id=&quot;html_07c362dd328063cfb39abae7d7f3a3d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6e424afb786f3c103b2019323ead2006.setContent(html_07c362dd328063cfb39abae7d7f3a3d3);
#
#
#
#         marker_4e0658518d8b10e03db27ef6eb87b39e.bindPopup(popup_6e424afb786f3c103b2019323ead2006)
#         ;
#
#
#
#
#             var marker_25449e39390631b835c88d98fedabcae = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_43fb89a12533b564ff6c9f888127a9f0);
#
#
#         var popup_ac0eeddf5ee502d01c39dfc959bda46f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c815fbb01c178c586ed467919f042e3a = $(`&lt;div id=&quot;html_c815fbb01c178c586ed467919f042e3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ac0eeddf5ee502d01c39dfc959bda46f.setContent(html_c815fbb01c178c586ed467919f042e3a);
#
#
#
#         marker_25449e39390631b835c88d98fedabcae.bindPopup(popup_ac0eeddf5ee502d01c39dfc959bda46f)
#         ;
#
#
#
#
#             var marker_1462287fc9

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a25bce736fbef78b8256cf54ce872cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a25bce736fbef78b8256cf54ce872cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a25bce736fbef78b8256cf54ce872cf = L.map(
#                 &quot;map_4a25bce736fbef78b8256cf54ce872cf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3965cbf917ccd9557d2b9a209e3b98b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b3965cbf917ccd9557d2b9a209e3b98b.addTo(map_4a25bce736fbef78b8256cf54ce872cf);
#
#
#             var feature_group_ffe808f42048c057238f161efc8ec704 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ffa7e4b5eac746fd087e747cda37e262 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ffe808f42048c057238f161efc8ec704);
#
#
#         var popup_bc8cf67c03dd989996900e953638c799 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb47757a6dbd998b71c71205a80ea35f = $(`&lt;div id=&quot;html_bb47757a6dbd998b71c71205a80ea35f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_bc8cf67c03dd989996900e953638c799.setContent(html_bb47757a6dbd998b71c71205a80ea35f);
#
#
#
#         marker_ffa7e4b5eac746fd087e747cda37e262.bindPopup(popup_bc8cf67c03dd989996900e953638c799)
#         ;
#
#
#
#
#             var marker_6eee2c9ea57d33100de6ce1b0a12e4c7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ffe808f42048c057238f161efc8ec704);
#
#
#         var popup_4f5ced5f2b1defd8f680a7d3b1abf9f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_947379ecc2095f10d796008f9c687d02 = $(`&lt;div id=&quot;html_947379ecc2095f10d796008f9c687d02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4f5ced5f2b1defd8f680a7d3b1abf9f3.setContent(html_947379ecc2095f10d796008f9c687d02);
#
#
#
#         marker_6eee2c9ea57d33100de6ce1b0a12e4c7.bindPopup(popup_4f5ced5f2b1defd8f680a7d3b1abf9f3)
#         ;
#
#
#
#
#             var marker_a3bc8e4893ae3e69a83c819dc8c4b9b2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ffe808f42048c057238f161efc8ec704);
#
#
#         var popup_5508b2c75db03c245d596319b28995f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_510a91f77261ee3383ab489263c3474e = $(`&lt;div id=&quot;html_510a91f77261ee3383ab489263c3474e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5508b2c75db03c245d596319b28995f2.setContent(html_510a91f77261ee3383ab489263c3474e);
#
#
#
#         marker_a3bc8e4893ae3e69a83c819dc8c4b9b2.bindPopup(popup_5508b2c75db03c245d596319b28995f2)
#         ;
#
#
#
#
#             var marker_1de155a1480815ca656b8d8cbc0e4a62 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ffe808f42048c057238f161efc8ec704);
#
#
#         var popup_d31e96285ebecc28a88575f867b59612 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c591f4ad12aff192a57fe5eb7a8cdbe7 = $(`&lt;div id=&quot;html_c591f4ad12aff192a57fe5eb7a8cdbe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d31e96285ebecc28a88575f867b59612.setContent(html_c591f4ad12aff192a57fe5eb7a8cdbe7);
#
#
#
#         marker_1de155a1480815ca656b8d8cbc0e4a62.bindPopup(popup_d31e96285ebecc28a88575f867b59612)
#         ;
#
#
#
#
#             var marker_49d969c1b5735968dd7f4c047be8dd04 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ffe808f42048c057238f161efc8ec704);
#
#
#         var popup_137db094c997f65a4d301fa449c975cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4bd53f9e692dbbcb116baf9b0720fea2 = $(`&lt;div id=&quot;html_4bd53f9e692dbbcb116baf9b0720fea2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_137db094c997f65a4d

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d73d345795c0f598868d340abb0aab33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d73d345795c0f598868d340abb0aab33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d73d345795c0f598868d340abb0aab33 = L.map(
#                 &quot;map_d73d345795c0f598868d340abb0aab33&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_09752bcaada0635aaf19a205e9ad9da7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_09752bcaada0635aaf19a205e9ad9da7.addTo(map_d73d345795c0f598868d340abb0aab33);
#
#
#             var feature_group_f4bcefb6c5d425464198ea004d27a87e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f4bcefb6c5d425464198ea004d27a87e.addTo(map_d73d345795c0f598868d340abb0aab33);
#
#
#             var feature_group_sub_group_8b36c3e392ac51f28178a43a015ef311 = L.featureGroup.subGroup(
#                 feature_group_f4bcefb6c5d425464198ea004d27a87e
#             );
#
#
#             var marker_06ca0c49c2e9a5c71e4ce01713634f20 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b36c3e392ac51f28178a43a015ef311);
#
#
#         var popup_e57feda99d4cc0a58a2daa308086291a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_286359c3012473539c15571ef5c12578 = $(`&lt;div id=&quot;html_286359c3012473539c15571ef5c12578&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e57feda99d4cc0a58a2daa308086291a.setContent(html_286359c3012473539c15571ef5c12578);
#
#
#
#         marker_06ca0c49c2e9a5c71e4ce01713634f20.bindPopup(popup_e57feda99d4cc0a58a2daa308086291a)
#         ;
#
#
#
#
#             var marker_5c683aa50e8d0d0229f147e9cb95ef7c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b36c3e392ac51f28178a43a015ef311);
#
#
#         var popup_78035b6dce72f197648ffb382a3b4086 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35a56f1f232479fbcf41801f0afaa38e = $(`&lt;div id=&quot;html_35a56f1f232479fbcf41801f0afaa38e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_78035b6dce72f197648ffb382a3b4086.setContent(html_35a56f1f232479fbcf41801f0afaa38e);
#
#
#
#         marker_5c683aa50e8d0d0229f147e9cb95ef7c.bindPopup(popup_78035b6dce72f197648ffb382a3b4086)
#         ;
#
#
#
#
#             var marker_9e2c8a7f50910adb03413e20587020cb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b36c3e392ac51f28178a43a015ef311);
#
#
#         var popup_eb3117d26c1356beacf27648a4459ef4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a10625c542a75b1d92e52d43ef9954e = $(`&lt;div id=&quot;html_2a10625c542a75b1d92e52d43ef9954e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_eb3117d26c1356beacf27648a4459ef4.setContent(html_2a10625c542a75b1d92e52d43ef9954e);
#
#
#
#         marker_9e2c8a7f50910adb03413e20587020cb.bindPopup(popup_eb3117d26c1356beacf27648a4459ef4)
#         ;
#
#
#
#
#             var marker_45319651e41d88fd782f1c0257e025aa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b36c3e392ac51f28178a43a015ef311);
#
#
#         var popup_5b644277e991e155c90b9b9624a9aca7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbdc2c33a617b327600f4e5d77700e18 = $(`&lt;div id=&quot;html_cbdc2c33a617b327600f4e5d77700e18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5b644277e991e155c90b9b9624a9aca7.setContent(html_cbdc2c33a617b327600f4e5d77700e18);
#
#
#
#         marker_45319651e41d88fd782f1c0257e025aa.bindPopup(popup_5b644277e991e155c90b9b9624a9aca7)
#         ;
#
#
#
#
#             var marker_d0d984e25f16e848889c9d6044a0abda = L.marker(
#                 [45.050399999999996, 3.0504],
