# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3da97cc9b0a6fdf4fdfb47fbc5fd76cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3da97cc9b0a6fdf4fdfb47fbc5fd76cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3da97cc9b0a6fdf4fdfb47fbc5fd76cb = L.map(
#                 &quot;map_3da97cc9b0a6fdf4fdfb47fbc5fd76cb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3794ea1901f6d8b4a84fc9fd612a4864 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3794ea1901f6d8b4a84fc9fd612a4864.addTo(map_3da97cc9b0a6fdf4fdfb47fbc5fd76cb);
#
#
#             var marker_3f1c68c004b01331c086397c892374c6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3da97cc9b0a6fdf4fdfb47fbc5fd76cb);
#
#
#         var popup_d60a3f80b6feae4763b85b07bef3b802 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9763db9fb0104753d86e07b05021fbae = $(`&lt;div id=&quot;html_9763db9fb0104753d86e07b05021fbae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d60a3f80b6feae4763b85b07bef3b802.setContent(html_9763db9fb0104753d86e07b05021fbae);
#
#
#
#         marker_3f1c68c004b01331c086397c892374c6.bindPopup(popup_d60a3f80b6feae4763b85b07bef3b802)
#         ;
#
#
#
#
#             var marker_7a76cac17b8bf4f22a3c75efaac7b0f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3da97cc9b0a6fdf4fdfb47fbc5fd76cb);
#
#
#         var popup_d84072aa82c7965502ccd74ec30ddd10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e7092cdf4a1477fbdff3aea8d57feab = $(`&lt;div id=&quot;html_4e7092cdf4a1477fbdff3aea8d57feab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d84072aa82c7965502ccd74ec30ddd10.setContent(html_4e7092cdf4a1477fbdff3aea8d57feab);
#
#
#
#         marker_7a76cac17b8bf4f22a3c75efaac7b0f4.bindPopup(popup_d84072aa82c7965502ccd74ec30ddd10)
#         ;
#
#
#
#
#             var marker_333416349c454d693f5ffa98a83afb42 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3da97cc9b0a6fdf4fdfb47fbc5fd76cb);
#
#
#         var popup_7012773c3ca74d8d927266fb0e14180c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e9d4dd74ea8ee922a57bcbba6801284 = $(`&lt;div id=&quot;html_4e9d4dd74ea8ee922a57bcbba6801284&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7012773c3ca74d8d927266fb0e14180c.setContent(html_4e9d4dd74ea8ee922a57bcbba6801284);
#
#
#
#         marker_333416349c454d693f5ffa98a83afb42.bindPopup(popup_7012773c3ca74d8d927266fb0e14180c)
#         ;
#
#
#
#
#             var marker_b59f0002e8c8030f1fe2366af4a92e03 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3da97cc9b0a6fdf4fdfb47fbc5fd76cb);
#
#
#         var popup_6eb190bdeec2ad3d02b5466816b7bfa8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98e1d0c5a248b50916f2cd5d9cb815a6 = $(`&lt;div id=&quot;html_98e1d0c5a248b50916f2cd5d9cb815a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6eb190bdeec2ad3d02b5466816b7bfa8.setContent(html_98e1d0c5a248b50916f2cd5d9cb815a6);
#
#
#
#         marker_b59f0002e8c8030f1fe2366af4a92e03.bindPopup(popup_6eb190bdeec2ad3d02b5466816b7bfa8)
#         ;
#
#
#
#
#             var marker_ee416af578c7939594cf5f96354d8b3a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3da97cc9b0a6fdf4fdfb47fbc5fd76cb);
#
#
#         var popup_ee6e4446994b8a0ce4d4a392a20c8dcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c990f6b15db0accdb7c9182a963f9b15 = $(`&lt;div id=&quot;html_c990f6b15db0accdb7c9182a963f9b15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ee6e4446994b8a0ce4d4a392a20c8dcb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e58d0cdaaebb06a8dea8820eb53d304 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e58d0cdaaebb06a8dea8820eb53d304&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e58d0cdaaebb06a8dea8820eb53d304 = L.map(
#                 &quot;map_4e58d0cdaaebb06a8dea8820eb53d304&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_56f90a35a6d4400d4f3fa911be5cc2c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_56f90a35a6d4400d4f3fa911be5cc2c8.addTo(map_4e58d0cdaaebb06a8dea8820eb53d304);
#
#
#             var feature_group_6bfc33d77cdb57437e4a15c72157f48a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2792dc92f3f9deb72a67d230403b5d3c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6bfc33d77cdb57437e4a15c72157f48a);
#
#
#         var popup_cae4127c97ed62f27f4b33daa95419dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28882b7a754925cd85a01c27e9cee842 = $(`&lt;div id=&quot;html_28882b7a754925cd85a01c27e9cee842&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cae4127c97ed62f27f4b33daa95419dd.setContent(html_28882b7a754925cd85a01c27e9cee842);
#
#
#
#         marker_2792dc92f3f9deb72a67d230403b5d3c.bindPopup(popup_cae4127c97ed62f27f4b33daa95419dd)
#         ;
#
#
#
#
#             var marker_7317f1a3e0d8de9a2fd4c0674a4d6599 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6bfc33d77cdb57437e4a15c72157f48a);
#
#
#         var popup_9971eee60eefd127410d31af1859deb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3288389db0f30abaaf77991029547bbc = $(`&lt;div id=&quot;html_3288389db0f30abaaf77991029547bbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9971eee60eefd127410d31af1859deb2.setContent(html_3288389db0f30abaaf77991029547bbc);
#
#
#
#         marker_7317f1a3e0d8de9a2fd4c0674a4d6599.bindPopup(popup_9971eee60eefd127410d31af1859deb2)
#         ;
#
#
#
#
#             var marker_5c058326c391f03c6826c87960e8a26e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6bfc33d77cdb57437e4a15c72157f48a);
#
#
#         var popup_8db1c9e18875e0542c777a6c3b8ca9dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4a59442c3b18b248a971058f7b240b8 = $(`&lt;div id=&quot;html_c4a59442c3b18b248a971058f7b240b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8db1c9e18875e0542c777a6c3b8ca9dc.setContent(html_c4a59442c3b18b248a971058f7b240b8);
#
#
#
#         marker_5c058326c391f03c6826c87960e8a26e.bindPopup(popup_8db1c9e18875e0542c777a6c3b8ca9dc)
#         ;
#
#
#
#
#             var marker_5bb008f2b199036cb1292472d9ee10a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6bfc33d77cdb57437e4a15c72157f48a);
#
#
#         var popup_cc88d01e22895c4ca1afdd806509d761 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17ce731d9a2acb65ef4467615a925550 = $(`&lt;div id=&quot;html_17ce731d9a2acb65ef4467615a925550&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cc88d01e22895c4ca1afdd806509d761.setContent(html_17ce731d9a2acb65ef4467615a925550);
#
#
#
#         marker_5bb008f2b199036cb1292472d9ee10a3.bindPopup(popup_cc88d01e22895c4ca1afdd806509d761)
#         ;
#
#
#
#
#             var marker_24e4c079a3cfde4ee9f6121d7d91eb7c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6bfc33d77cdb57437e4a15c72157f48a);
#
#
#         var popup_3966f71b3e468ea7f1e711d820bbc627 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c3b6cad6fec7bc593e0fcdc654fb282 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c3b6cad6fec7bc593e0fcdc654fb282&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c3b6cad6fec7bc593e0fcdc654fb282 = L.map(
#                 &quot;map_7c3b6cad6fec7bc593e0fcdc654fb282&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c112ca552d3f40259eb79bdb0706586c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c112ca552d3f40259eb79bdb0706586c.addTo(map_7c3b6cad6fec7bc593e0fcdc654fb282);
#
#
#             var feature_group_1c1fcf862ec5bb5314ab5e592b7e0b83 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1c1fcf862ec5bb5314ab5e592b7e0b83.addTo(map_7c3b6cad6fec7bc593e0fcdc654fb282);
#
#
#             var feature_group_sub_group_4386fd41f2ae936abd76778c353c00b5 = L.featureGroup.subGroup(
#                 feature_group_1c1fcf862ec5bb5314ab5e592b7e0b83
#             );
#
#
#             var marker_30f28364a2236b7173558812a24a5d01 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4386fd41f2ae936abd76778c353c00b5);
#
#
#         var popup_a593007fb2f317644443712908711f31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc9b5c135facb0202c1987651d9f12fd = $(`&lt;div id=&quot;html_fc9b5c135facb0202c1987651d9f12fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a593007fb2f317644443712908711f31.setContent(html_fc9b5c135facb0202c1987651d9f12fd);
#
#
#
#         marker_30f28364a2236b7173558812a24a5d01.bindPopup(popup_a593007fb2f317644443712908711f31)
#         ;
#
#
#
#
#             var marker_9646f9a8d11bcf54b134d55fb8c0cd59 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4386fd41f2ae936abd76778c353c00b5);
#
#
#         var popup_5841d53617eff196b682a106cd22c0cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_645e37c0be4ba2a282ab0e791c575178 = $(`&lt;div id=&quot;html_645e37c0be4ba2a282ab0e791c575178&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5841d53617eff196b682a106cd22c0cf.setContent(html_645e37c0be4ba2a282ab0e791c575178);
#
#
#
#         marker_9646f9a8d11bcf54b134d55fb8c0cd59.bindPopup(popup_5841d53617eff196b682a106cd22c0cf)
#         ;
#
#
#
#
#             var marker_2fb649bd3839a8421fcc8ace88350612 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4386fd41f2ae936abd76778c353c00b5);
#
#
#         var popup_cf077c5125226c8e279d8913468cfa5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b53027a92fe689d0cd4f2c47e6e3728 = $(`&lt;div id=&quot;html_0b53027a92fe689d0cd4f2c47e6e3728&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cf077c5125226c8e279d8913468cfa5a.setContent(html_0b53027a92fe689d0cd4f2c47e6e3728);
#
#
#
#         marker_2fb649bd3839a8421fcc8ace88350612.bindPopup(popup_cf077c5125226c8e279d8913468cfa5a)
#         ;
#
#
#
#
#             var marker_28594d45633759397a1f4d636ddb562b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4386fd41f2ae936abd76778c353c00b5);
#
#
#         var popup_e52d835e8a0736bd51476dfb52d5e725 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a72c049c8462f84a13c0493e5aa97b40 = $(`&lt;div id=&quot;html_a72c049c8462f84a13c0493e5aa97b40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e52d835e8a0736bd51476dfb52d5e725.setContent(html_a72c049c8462f84a13c0493e5aa97b40);
#
#
#
#         marker_
