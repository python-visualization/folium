# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5734f0e2c173b8d3b24739a7e493ad5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5734f0e2c173b8d3b24739a7e493ad5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5734f0e2c173b8d3b24739a7e493ad5 = L.map(
#                 &quot;map_a5734f0e2c173b8d3b24739a7e493ad5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5f482ea33d647dda01807e27e476c634 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5f482ea33d647dda01807e27e476c634.addTo(map_a5734f0e2c173b8d3b24739a7e493ad5);
#
#
#             var marker_571242e3286d03acc6f6d3c801e473e3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a5734f0e2c173b8d3b24739a7e493ad5);
#
#
#         var popup_281f309c308dd82c764d1d45589b9ebd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec525fcfdb913e147e6c7cbfc00259a7 = $(`&lt;div id=&quot;html_ec525fcfdb913e147e6c7cbfc00259a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_281f309c308dd82c764d1d45589b9ebd.setContent(html_ec525fcfdb913e147e6c7cbfc00259a7);
#
#
#
#         marker_571242e3286d03acc6f6d3c801e473e3.bindPopup(popup_281f309c308dd82c764d1d45589b9ebd)
#         ;
#
#
#
#
#             var marker_c0c7715583e4bc62d6cd110b72abcb80 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a5734f0e2c173b8d3b24739a7e493ad5);
#
#
#         var popup_f6e2465c2f2ffcc2173fa363d5c970d2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2e05a6021c654a93df922c5abc20217 = $(`&lt;div id=&quot;html_e2e05a6021c654a93df922c5abc20217&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f6e2465c2f2ffcc2173fa363d5c970d2.setContent(html_e2e05a6021c654a93df922c5abc20217);
#
#
#
#         marker_c0c7715583e4bc62d6cd110b72abcb80.bindPopup(popup_f6e2465c2f2ffcc2173fa363d5c970d2)
#         ;
#
#
#
#
#             var marker_9270ba179452294aa336a7763de411e9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a5734f0e2c173b8d3b24739a7e493ad5);
#
#
#         var popup_e705f1916a8a9d44ea951f3922574a13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b0359e9a04118fe1c2df7ab19f43792 = $(`&lt;div id=&quot;html_9b0359e9a04118fe1c2df7ab19f43792&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e705f1916a8a9d44ea951f3922574a13.setContent(html_9b0359e9a04118fe1c2df7ab19f43792);
#
#
#
#         marker_9270ba179452294aa336a7763de411e9.bindPopup(popup_e705f1916a8a9d44ea951f3922574a13)
#         ;
#
#
#
#
#             var marker_3178941d8c3a010944280d1858ba045c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a5734f0e2c173b8d3b24739a7e493ad5);
#
#
#         var popup_2b1f50b888c7ef8334bddb3ff35c0f4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_081bf1eeb8d47d87125bd4f93ce6a126 = $(`&lt;div id=&quot;html_081bf1eeb8d47d87125bd4f93ce6a126&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2b1f50b888c7ef8334bddb3ff35c0f4c.setContent(html_081bf1eeb8d47d87125bd4f93ce6a126);
#
#
#
#         marker_3178941d8c3a010944280d1858ba045c.bindPopup(popup_2b1f50b888c7ef8334bddb3ff35c0f4c)
#         ;
#
#
#
#
#             var marker_5ada4cdc559966f1d6d0457ef6c94496 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a5734f0e2c173b8d3b24739a7e493ad5);
#
#
#         var popup_a3584b61b5dfe53d43fef53f94a1540a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0327e13f71d1a75a8d3aaa35ca7079f = $(`&lt;div id=&quot;html_c0327e13f71d1a75a8d3aaa35ca7079f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a3584b61b5dfe53d43fef53f94a1540a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74b396b013068da683c4fc58bb3d7e4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74b396b013068da683c4fc58bb3d7e4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74b396b013068da683c4fc58bb3d7e4f = L.map(
#                 &quot;map_74b396b013068da683c4fc58bb3d7e4f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4cdb83c2bb2322be1c5719ac19473912 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4cdb83c2bb2322be1c5719ac19473912.addTo(map_74b396b013068da683c4fc58bb3d7e4f);
#
#
#             var feature_group_6787c30601772b48a9278913fde19b90 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_520545871cdafae9d139a69ecea0ddac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6787c30601772b48a9278913fde19b90);
#
#
#         var popup_a88978c9b0884421a26499ab6d03d097 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42a9b883995a39556930be9ab884cd45 = $(`&lt;div id=&quot;html_42a9b883995a39556930be9ab884cd45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a88978c9b0884421a26499ab6d03d097.setContent(html_42a9b883995a39556930be9ab884cd45);
#
#
#
#         marker_520545871cdafae9d139a69ecea0ddac.bindPopup(popup_a88978c9b0884421a26499ab6d03d097)
#         ;
#
#
#
#
#             var marker_9490b16b0ff5392dc73e61b2250b3754 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6787c30601772b48a9278913fde19b90);
#
#
#         var popup_e98a2c2193bac3da99293565f2552f48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c187bfa174c6aba9f7b5bd74a33cf83 = $(`&lt;div id=&quot;html_5c187bfa174c6aba9f7b5bd74a33cf83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e98a2c2193bac3da99293565f2552f48.setContent(html_5c187bfa174c6aba9f7b5bd74a33cf83);
#
#
#
#         marker_9490b16b0ff5392dc73e61b2250b3754.bindPopup(popup_e98a2c2193bac3da99293565f2552f48)
#         ;
#
#
#
#
#             var marker_14d2004b7b2b62fe24594ee4f2f45cb8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6787c30601772b48a9278913fde19b90);
#
#
#         var popup_262dce09b37d98b5bc43fe136a406737 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfb54e3195a01be55c082c2cb219a147 = $(`&lt;div id=&quot;html_dfb54e3195a01be55c082c2cb219a147&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_262dce09b37d98b5bc43fe136a406737.setContent(html_dfb54e3195a01be55c082c2cb219a147);
#
#
#
#         marker_14d2004b7b2b62fe24594ee4f2f45cb8.bindPopup(popup_262dce09b37d98b5bc43fe136a406737)
#         ;
#
#
#
#
#             var marker_64f0d822461f3ce03dbb747c1cbeba98 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6787c30601772b48a9278913fde19b90);
#
#
#         var popup_95a1d9f2323282bf09c60f4fece6c13d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cef1d1561ae175bb4be6e043a0831fee = $(`&lt;div id=&quot;html_cef1d1561ae175bb4be6e043a0831fee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_95a1d9f2323282bf09c60f4fece6c13d.setContent(html_cef1d1561ae175bb4be6e043a0831fee);
#
#
#
#         marker_64f0d822461f3ce03dbb747c1cbeba98.bindPopup(popup_95a1d9f2323282bf09c60f4fece6c13d)
#         ;
#
#
#
#
#             var marker_75e5068c55b900464fde5a4191cd8716 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6787c30601772b48a9278913fde19b90);
#
#
#         var popup_627be5b2a5b124d9e6f56263022767ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bedcdced1cb0c5df6fffecff037120f3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bedcdced1cb0c5df6fffecff037120f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bedcdced1cb0c5df6fffecff037120f3 = L.map(
#                 &quot;map_bedcdced1cb0c5df6fffecff037120f3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d81f61e4931145c04b925765f9187e2b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d81f61e4931145c04b925765f9187e2b.addTo(map_bedcdced1cb0c5df6fffecff037120f3);
#
#
#             var feature_group_dc65ba5b9619704fc35da0761c87d5d6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dc65ba5b9619704fc35da0761c87d5d6.addTo(map_bedcdced1cb0c5df6fffecff037120f3);
#
#
#             var feature_group_sub_group_c7f3b9619d8cf6433afe20397f08c56d = L.featureGroup.subGroup(
#                 feature_group_dc65ba5b9619704fc35da0761c87d5d6
#             );
#
#
#             var marker_0aabdce806c7c6d93f9305347226b287 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7f3b9619d8cf6433afe20397f08c56d);
#
#
#         var popup_a35b22a1bd7bc07e5b4131758fb5b9c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbc25ef94e731b8e62df868fdd87040d = $(`&lt;div id=&quot;html_cbc25ef94e731b8e62df868fdd87040d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a35b22a1bd7bc07e5b4131758fb5b9c3.setContent(html_cbc25ef94e731b8e62df868fdd87040d);
#
#
#
#         marker_0aabdce806c7c6d93f9305347226b287.bindPopup(popup_a35b22a1bd7bc07e5b4131758fb5b9c3)
#         ;
#
#
#
#
#             var marker_ed93c975f350922c43de40b8d6021247 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7f3b9619d8cf6433afe20397f08c56d);
#
#
#         var popup_0d7a96c393a492568208b66735fc6b65 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_655b25e1d137cf85a00f48a05d54923e = $(`&lt;div id=&quot;html_655b25e1d137cf85a00f48a05d54923e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0d7a96c393a492568208b66735fc6b65.setContent(html_655b25e1d137cf85a00f48a05d54923e);
#
#
#
#         marker_ed93c975f350922c43de40b8d6021247.bindPopup(popup_0d7a96c393a492568208b66735fc6b65)
#         ;
#
#
#
#
#             var marker_2445f718fe92b5fd3d56aac47e8cbee0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7f3b9619d8cf6433afe20397f08c56d);
#
#
#         var popup_57df5d0fee56f6aa0639679da641bf10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0da9be8c9285b593d3e0beb4e4e2f1cf = $(`&lt;div id=&quot;html_0da9be8c9285b593d3e0beb4e4e2f1cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_57df5d0fee56f6aa0639679da641bf10.setContent(html_0da9be8c9285b593d3e0beb4e4e2f1cf);
#
#
#
#         marker_2445f718fe92b5fd3d56aac47e8cbee0.bindPopup(popup_57df5d0fee56f6aa0639679da641bf10)
#         ;
#
#
#
#
#             var marker_61a41c7f3b42ba2d76baa6db01f48962 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c7f3b9619d8cf6433afe20397f08c56d);
#
#
#         var popup_d916f7cdd7d35d64debf6291153679fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26d7fe859d7a910ae44be1d4d8e463b7 = $(`&lt;div id=&quot;html_26d7fe859d7a910ae44be1d4d8e463b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d916f7cdd7d35d64debf6291153679fd.setContent(html_26d7fe859d7a910ae44be1d4d8e463b7);
#
#
#
#         marker_
