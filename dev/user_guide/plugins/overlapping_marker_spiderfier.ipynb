# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bfa764fe4390868f1308fda27e718c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bfa764fe4390868f1308fda27e718c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bfa764fe4390868f1308fda27e718c0 = L.map(
#                 &quot;map_8bfa764fe4390868f1308fda27e718c0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_18352a4cfb90efc492155b64b1d61ca3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_18352a4cfb90efc492155b64b1d61ca3.addTo(map_8bfa764fe4390868f1308fda27e718c0);
#
#
#             var marker_f08b8125a81611497343e258f6679981 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8bfa764fe4390868f1308fda27e718c0);
#
#
#         var popup_5d5f70feaac61f8bba4677abfd4b6845 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_076b4d440f4ba98f57b19a1c36c2d0d2 = $(`&lt;div id=&quot;html_076b4d440f4ba98f57b19a1c36c2d0d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5d5f70feaac61f8bba4677abfd4b6845.setContent(html_076b4d440f4ba98f57b19a1c36c2d0d2);
#
#
#
#         marker_f08b8125a81611497343e258f6679981.bindPopup(popup_5d5f70feaac61f8bba4677abfd4b6845)
#         ;
#
#
#
#
#             var marker_6917c4fc45df6d6a2a0416333a5e9069 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8bfa764fe4390868f1308fda27e718c0);
#
#
#         var popup_ff393d424f77f10b877b9735548e6ada = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd9e6dd0b5c1e27a4156bf5dec0eec8e = $(`&lt;div id=&quot;html_fd9e6dd0b5c1e27a4156bf5dec0eec8e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ff393d424f77f10b877b9735548e6ada.setContent(html_fd9e6dd0b5c1e27a4156bf5dec0eec8e);
#
#
#
#         marker_6917c4fc45df6d6a2a0416333a5e9069.bindPopup(popup_ff393d424f77f10b877b9735548e6ada)
#         ;
#
#
#
#
#             var marker_82633e071fd9d3cbc8d10f8659245ba8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8bfa764fe4390868f1308fda27e718c0);
#
#
#         var popup_855ce3af4f8bc2916e2197ef8b36390f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_983c901d54e4bf0e75426c304f0225fa = $(`&lt;div id=&quot;html_983c901d54e4bf0e75426c304f0225fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_855ce3af4f8bc2916e2197ef8b36390f.setContent(html_983c901d54e4bf0e75426c304f0225fa);
#
#
#
#         marker_82633e071fd9d3cbc8d10f8659245ba8.bindPopup(popup_855ce3af4f8bc2916e2197ef8b36390f)
#         ;
#
#
#
#
#             var marker_cd3a207c968297218992f1985229e034 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8bfa764fe4390868f1308fda27e718c0);
#
#
#         var popup_1006157329910cfe4b07d8f2e38c20b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b74c0f7b85f3ab76ec9b0bc559c84f42 = $(`&lt;div id=&quot;html_b74c0f7b85f3ab76ec9b0bc559c84f42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1006157329910cfe4b07d8f2e38c20b8.setContent(html_b74c0f7b85f3ab76ec9b0bc559c84f42);
#
#
#
#         marker_cd3a207c968297218992f1985229e034.bindPopup(popup_1006157329910cfe4b07d8f2e38c20b8)
#         ;
#
#
#
#
#             var marker_f4400d7a5172db3e4dd1088d78e3537e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8bfa764fe4390868f1308fda27e718c0);
#
#
#         var popup_9e20742fa82910ae86ee07fb0c00cb78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd6bed085e1e89c0325b88a20e9f5090 = $(`&lt;div id=&quot;html_fd6bed085e1e89c0325b88a20e9f5090&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9e20742fa82910ae86ee07fb0c00cb78.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef86cdfd8804c8b09356348ae95f01d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef86cdfd8804c8b09356348ae95f01d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef86cdfd8804c8b09356348ae95f01d4 = L.map(
#                 &quot;map_ef86cdfd8804c8b09356348ae95f01d4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d10972d1083a96d33aa28589b0542a54 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d10972d1083a96d33aa28589b0542a54.addTo(map_ef86cdfd8804c8b09356348ae95f01d4);
#
#
#             var feature_group_c5a086c7b00c6fa9bf8f24b95d4302f6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5d35f33900c8da18a65470f0d974e03c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c5a086c7b00c6fa9bf8f24b95d4302f6);
#
#
#         var popup_c580a564a31d8a7583872375767cb305 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aaf20240ed13ec8bf82e004deb0a1dfe = $(`&lt;div id=&quot;html_aaf20240ed13ec8bf82e004deb0a1dfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c580a564a31d8a7583872375767cb305.setContent(html_aaf20240ed13ec8bf82e004deb0a1dfe);
#
#
#
#         marker_5d35f33900c8da18a65470f0d974e03c.bindPopup(popup_c580a564a31d8a7583872375767cb305)
#         ;
#
#
#
#
#             var marker_3ad8774df25259cd82b1d50a00952fb5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c5a086c7b00c6fa9bf8f24b95d4302f6);
#
#
#         var popup_e6d62d4f19e5ed829bd9e26e2a0dc312 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cab4783f6f60097fe58ff3ea5b902837 = $(`&lt;div id=&quot;html_cab4783f6f60097fe58ff3ea5b902837&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e6d62d4f19e5ed829bd9e26e2a0dc312.setContent(html_cab4783f6f60097fe58ff3ea5b902837);
#
#
#
#         marker_3ad8774df25259cd82b1d50a00952fb5.bindPopup(popup_e6d62d4f19e5ed829bd9e26e2a0dc312)
#         ;
#
#
#
#
#             var marker_1394e0038467d273bb9afe1bd9afd80e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c5a086c7b00c6fa9bf8f24b95d4302f6);
#
#
#         var popup_262a427f3211bad250fe554c4bd628ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4686545f8f7db879f6a3ba8d32933d4b = $(`&lt;div id=&quot;html_4686545f8f7db879f6a3ba8d32933d4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_262a427f3211bad250fe554c4bd628ab.setContent(html_4686545f8f7db879f6a3ba8d32933d4b);
#
#
#
#         marker_1394e0038467d273bb9afe1bd9afd80e.bindPopup(popup_262a427f3211bad250fe554c4bd628ab)
#         ;
#
#
#
#
#             var marker_153ced284c22337ce17761ca68deec45 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c5a086c7b00c6fa9bf8f24b95d4302f6);
#
#
#         var popup_14b21734702d31938bd53e6b7ddce0d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cda312f827ab5fcb8fbb3d6fbe2a72e6 = $(`&lt;div id=&quot;html_cda312f827ab5fcb8fbb3d6fbe2a72e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_14b21734702d31938bd53e6b7ddce0d6.setContent(html_cda312f827ab5fcb8fbb3d6fbe2a72e6);
#
#
#
#         marker_153ced284c22337ce17761ca68deec45.bindPopup(popup_14b21734702d31938bd53e6b7ddce0d6)
#         ;
#
#
#
#
#             var marker_d288c469a93ede9c9406316de8cc6a12 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c5a086c7b00c6fa9bf8f24b95d4302f6);
#
#
#         var popup_9c59be921768ec158362c06077829379 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac2fa6a63e7a696c59a7346a3ec2c84b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac2fa6a63e7a696c59a7346a3ec2c84b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac2fa6a63e7a696c59a7346a3ec2c84b = L.map(
#                 &quot;map_ac2fa6a63e7a696c59a7346a3ec2c84b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_33a782f5602e0a3252f7db04e4f93872 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_33a782f5602e0a3252f7db04e4f93872.addTo(map_ac2fa6a63e7a696c59a7346a3ec2c84b);
#
#
#             var feature_group_0c7205946b3ae30be795ef8485ee17f9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0c7205946b3ae30be795ef8485ee17f9.addTo(map_ac2fa6a63e7a696c59a7346a3ec2c84b);
#
#
#             var feature_group_sub_group_9060c179bcc63d4630afdb839e1598dd = L.featureGroup.subGroup(
#                 feature_group_0c7205946b3ae30be795ef8485ee17f9
#             );
#
#
#             var marker_ad54d8b302971ce85ac5db91ea9f16a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9060c179bcc63d4630afdb839e1598dd);
#
#
#         var popup_5d03b544bee34cf3e7460d144bbc5871 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_188685533694cd6aaae788e614a90150 = $(`&lt;div id=&quot;html_188685533694cd6aaae788e614a90150&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5d03b544bee34cf3e7460d144bbc5871.setContent(html_188685533694cd6aaae788e614a90150);
#
#
#
#         marker_ad54d8b302971ce85ac5db91ea9f16a6.bindPopup(popup_5d03b544bee34cf3e7460d144bbc5871)
#         ;
#
#
#
#
#             var marker_f9618288b5cb34b65931d05556db6ff8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9060c179bcc63d4630afdb839e1598dd);
#
#
#         var popup_acbdd9e1a8a2e3a0a6c1d5ff0d1136e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed7218396efab7e5a49ea77089863ca7 = $(`&lt;div id=&quot;html_ed7218396efab7e5a49ea77089863ca7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_acbdd9e1a8a2e3a0a6c1d5ff0d1136e4.setContent(html_ed7218396efab7e5a49ea77089863ca7);
#
#
#
#         marker_f9618288b5cb34b65931d05556db6ff8.bindPopup(popup_acbdd9e1a8a2e3a0a6c1d5ff0d1136e4)
#         ;
#
#
#
#
#             var marker_715c0180ec968abf2cd0491c6c0f64b1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9060c179bcc63d4630afdb839e1598dd);
#
#
#         var popup_09a85ba35134b261bbde21c5da01481c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4e5a733d1bd78620edbf227125a5395 = $(`&lt;div id=&quot;html_d4e5a733d1bd78620edbf227125a5395&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_09a85ba35134b261bbde21c5da01481c.setContent(html_d4e5a733d1bd78620edbf227125a5395);
#
#
#
#         marker_715c0180ec968abf2cd0491c6c0f64b1.bindPopup(popup_09a85ba35134b261bbde21c5da01481c)
#         ;
#
#
#
#
#             var marker_d6d507dc48f8fbf0e77064cea5cd9bd6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9060c179bcc63d4630afdb839e1598dd);
#
#
#         var popup_00ffe66382c5173b493105d54951d138 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad488a76b85b51ba656316fcff18cbc5 = $(`&lt;div id=&quot;html_ad488a76b85b51ba656316fcff18cbc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_00ffe66382c5173b493105d54951d138.setContent(html_ad488a76b85b51ba656316fcff18cbc5);
#
#
#
#         marker_
