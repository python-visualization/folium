# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6b197412b0867b31e208c31f4750c498 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6b197412b0867b31e208c31f4750c498&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6b197412b0867b31e208c31f4750c498 = L.map(
#                 &quot;map_6b197412b0867b31e208c31f4750c498&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10bb1a4c1ae5cf61d8dfaa7970d745c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10bb1a4c1ae5cf61d8dfaa7970d745c8.addTo(map_6b197412b0867b31e208c31f4750c498);
#
#
#             var marker_5ac364827d2834b338515ab9ac2e2e81 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6b197412b0867b31e208c31f4750c498);
#
#
#         var popup_b2f8eef223cbb05cdb944bdc017fc967 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9270db8e987765c76111df0b44b75a25 = $(`&lt;div id=&quot;html_9270db8e987765c76111df0b44b75a25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b2f8eef223cbb05cdb944bdc017fc967.setContent(html_9270db8e987765c76111df0b44b75a25);
#
#
#
#         marker_5ac364827d2834b338515ab9ac2e2e81.bindPopup(popup_b2f8eef223cbb05cdb944bdc017fc967)
#         ;
#
#
#
#
#             var marker_244f61b99e87ecabafefc01d060abfcd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6b197412b0867b31e208c31f4750c498);
#
#
#         var popup_6e4bdba6d56d5e7866e5ed4ab2516325 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_144ec1b79c9acf69fcad5f74a89c96e5 = $(`&lt;div id=&quot;html_144ec1b79c9acf69fcad5f74a89c96e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6e4bdba6d56d5e7866e5ed4ab2516325.setContent(html_144ec1b79c9acf69fcad5f74a89c96e5);
#
#
#
#         marker_244f61b99e87ecabafefc01d060abfcd.bindPopup(popup_6e4bdba6d56d5e7866e5ed4ab2516325)
#         ;
#
#
#
#
#             var marker_2982f854da7596a440db54baaa531804 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6b197412b0867b31e208c31f4750c498);
#
#
#         var popup_701c4202f5946444242262dae52e5371 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56f03da682a82d42df89ee662bf158b7 = $(`&lt;div id=&quot;html_56f03da682a82d42df89ee662bf158b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_701c4202f5946444242262dae52e5371.setContent(html_56f03da682a82d42df89ee662bf158b7);
#
#
#
#         marker_2982f854da7596a440db54baaa531804.bindPopup(popup_701c4202f5946444242262dae52e5371)
#         ;
#
#
#
#
#             var marker_8f4d402fd55f6e5933753ab7c35dea96 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6b197412b0867b31e208c31f4750c498);
#
#
#         var popup_66dacde4be35768f43f6b052b9fbfd32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3071b13684ab23754fd3d0b23eaba165 = $(`&lt;div id=&quot;html_3071b13684ab23754fd3d0b23eaba165&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_66dacde4be35768f43f6b052b9fbfd32.setContent(html_3071b13684ab23754fd3d0b23eaba165);
#
#
#
#         marker_8f4d402fd55f6e5933753ab7c35dea96.bindPopup(popup_66dacde4be35768f43f6b052b9fbfd32)
#         ;
#
#
#
#
#             var marker_a1657c5556944546561ef88a07398b82 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6b197412b0867b31e208c31f4750c498);
#
#
#         var popup_d647f6ceba3e4b09b7786046c9f054c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d552ec2348f9d38ad3ec0595c331238 = $(`&lt;div id=&quot;html_1d552ec2348f9d38ad3ec0595c331238&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d647f6ceba3e4b09b7786046c9f054c2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d91e3d5406f30b09fd3c75462f6a870d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d91e3d5406f30b09fd3c75462f6a870d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d91e3d5406f30b09fd3c75462f6a870d = L.map(
#                 &quot;map_d91e3d5406f30b09fd3c75462f6a870d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_575bde87074474fae447ffe497d34f22 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_575bde87074474fae447ffe497d34f22.addTo(map_d91e3d5406f30b09fd3c75462f6a870d);
#
#
#             var feature_group_8e7a3b3e4873b440a28cb346dba69bd9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_73e6ee0c78608fcfe375477b6d5a50a7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8e7a3b3e4873b440a28cb346dba69bd9);
#
#
#         var popup_099f476e97654ca1c103289184e4ea30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1c307ceb7391519190aaf3b6cd4080e = $(`&lt;div id=&quot;html_a1c307ceb7391519190aaf3b6cd4080e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_099f476e97654ca1c103289184e4ea30.setContent(html_a1c307ceb7391519190aaf3b6cd4080e);
#
#
#
#         marker_73e6ee0c78608fcfe375477b6d5a50a7.bindPopup(popup_099f476e97654ca1c103289184e4ea30)
#         ;
#
#
#
#
#             var marker_0fd9670dfbbe0943256db803d249644d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8e7a3b3e4873b440a28cb346dba69bd9);
#
#
#         var popup_d707ba02db7af206dd104e843fcd954a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a43b88a4c2395879f1959fd0b9991b9 = $(`&lt;div id=&quot;html_3a43b88a4c2395879f1959fd0b9991b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d707ba02db7af206dd104e843fcd954a.setContent(html_3a43b88a4c2395879f1959fd0b9991b9);
#
#
#
#         marker_0fd9670dfbbe0943256db803d249644d.bindPopup(popup_d707ba02db7af206dd104e843fcd954a)
#         ;
#
#
#
#
#             var marker_b00c4744464264840e810437314bd6c0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8e7a3b3e4873b440a28cb346dba69bd9);
#
#
#         var popup_5f2f6550a770301e4bc853127a7324bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad9cf26922e982186a773779ed3dd271 = $(`&lt;div id=&quot;html_ad9cf26922e982186a773779ed3dd271&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5f2f6550a770301e4bc853127a7324bc.setContent(html_ad9cf26922e982186a773779ed3dd271);
#
#
#
#         marker_b00c4744464264840e810437314bd6c0.bindPopup(popup_5f2f6550a770301e4bc853127a7324bc)
#         ;
#
#
#
#
#             var marker_fb72477173262b02198e1bf4b31581a8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8e7a3b3e4873b440a28cb346dba69bd9);
#
#
#         var popup_6f297bb5c3c805d2c906c597637514a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dee7061d772e269c4d23301fd06a108e = $(`&lt;div id=&quot;html_dee7061d772e269c4d23301fd06a108e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6f297bb5c3c805d2c906c597637514a5.setContent(html_dee7061d772e269c4d23301fd06a108e);
#
#
#
#         marker_fb72477173262b02198e1bf4b31581a8.bindPopup(popup_6f297bb5c3c805d2c906c597637514a5)
#         ;
#
#
#
#
#             var marker_5b3b46e9137d7ba7c40d08d5db55bfca = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8e7a3b3e4873b440a28cb346dba69bd9);
#
#
#         var popup_35e47cde587c3a36ee48a135be3ec5ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14ef9da6adc283beb0d900650b88eefd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14ef9da6adc283beb0d900650b88eefd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14ef9da6adc283beb0d900650b88eefd = L.map(
#                 &quot;map_14ef9da6adc283beb0d900650b88eefd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba5f54fb72e9e2b74351598aa1a466ad = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba5f54fb72e9e2b74351598aa1a466ad.addTo(map_14ef9da6adc283beb0d900650b88eefd);
#
#
#             var feature_group_3e02567c79f61f00779d977adee2709d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3e02567c79f61f00779d977adee2709d.addTo(map_14ef9da6adc283beb0d900650b88eefd);
#
#
#             var feature_group_sub_group_b44b8d19d4c64f673ae39be65573e857 = L.featureGroup.subGroup(
#                 feature_group_3e02567c79f61f00779d977adee2709d
#             );
#
#
#             var marker_366e20ecc99eca2031ce212ce68c12c8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b44b8d19d4c64f673ae39be65573e857);
#
#
#         var popup_75bf6111d71e65181f22a640ec675ab8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b03702b2d35a913b3c48ab1bb30c402f = $(`&lt;div id=&quot;html_b03702b2d35a913b3c48ab1bb30c402f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_75bf6111d71e65181f22a640ec675ab8.setContent(html_b03702b2d35a913b3c48ab1bb30c402f);
#
#
#
#         marker_366e20ecc99eca2031ce212ce68c12c8.bindPopup(popup_75bf6111d71e65181f22a640ec675ab8)
#         ;
#
#
#
#
#             var marker_f2f177478192b8bce4d8a58350a9622f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b44b8d19d4c64f673ae39be65573e857);
#
#
#         var popup_a88c4b6b525c14e6e889dccdc62b3730 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f22c0e0437e72dac9d4f2421884b0358 = $(`&lt;div id=&quot;html_f22c0e0437e72dac9d4f2421884b0358&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a88c4b6b525c14e6e889dccdc62b3730.setContent(html_f22c0e0437e72dac9d4f2421884b0358);
#
#
#
#         marker_f2f177478192b8bce4d8a58350a9622f.bindPopup(popup_a88c4b6b525c14e6e889dccdc62b3730)
#         ;
#
#
#
#
#             var marker_0e4c8da393ef526f51efa79e4ad0c451 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b44b8d19d4c64f673ae39be65573e857);
#
#
#         var popup_92b6a151531bb1b4f95629993d88449a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_485c5e1e282931a4286bf131b6ba06b4 = $(`&lt;div id=&quot;html_485c5e1e282931a4286bf131b6ba06b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_92b6a151531bb1b4f95629993d88449a.setContent(html_485c5e1e282931a4286bf131b6ba06b4);
#
#
#
#         marker_0e4c8da393ef526f51efa79e4ad0c451.bindPopup(popup_92b6a151531bb1b4f95629993d88449a)
#         ;
#
#
#
#
#             var marker_b13a2c752c1375f760c45180c9f44965 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b44b8d19d4c64f673ae39be65573e857);
#
#
#         var popup_62c8d5c0a6552ca37e273c190f51f688 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56f212ef8d2c1cd54bcf1facc59baee9 = $(`&lt;div id=&quot;html_56f212ef8d2c1cd54bcf1facc59baee9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_62c8d5c0a6552ca37e273c190f51f688.setContent(html_56f212ef8d2c1cd54bcf1facc59baee9);
#
#
#
#         marker_
