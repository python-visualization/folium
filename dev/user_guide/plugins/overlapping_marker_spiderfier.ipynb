# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fbac57c51d35bde0f1bc8746b97c2af0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fbac57c51d35bde0f1bc8746b97c2af0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fbac57c51d35bde0f1bc8746b97c2af0 = L.map(
#                 &quot;map_fbac57c51d35bde0f1bc8746b97c2af0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_517810aace609163720283eddd6bd861 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_517810aace609163720283eddd6bd861.addTo(map_fbac57c51d35bde0f1bc8746b97c2af0);
#
#
#             var marker_80d83e15c16d07b98588be5ef5be987c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fbac57c51d35bde0f1bc8746b97c2af0);
#
#
#         var popup_d997e2de6d40c470a38e4f32ca2c7607 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44cd7f2f674e6d8eb10bc5eda7217122 = $(`&lt;div id=&quot;html_44cd7f2f674e6d8eb10bc5eda7217122&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d997e2de6d40c470a38e4f32ca2c7607.setContent(html_44cd7f2f674e6d8eb10bc5eda7217122);
#
#
#
#         marker_80d83e15c16d07b98588be5ef5be987c.bindPopup(popup_d997e2de6d40c470a38e4f32ca2c7607)
#         ;
#
#
#
#
#             var marker_8f0054a09f26d4ed0c86a1eac30669b1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fbac57c51d35bde0f1bc8746b97c2af0);
#
#
#         var popup_00fa8775e58a829acc75601f2e08fb8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53f2cffcc53cbc20a50d092b9245f157 = $(`&lt;div id=&quot;html_53f2cffcc53cbc20a50d092b9245f157&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_00fa8775e58a829acc75601f2e08fb8f.setContent(html_53f2cffcc53cbc20a50d092b9245f157);
#
#
#
#         marker_8f0054a09f26d4ed0c86a1eac30669b1.bindPopup(popup_00fa8775e58a829acc75601f2e08fb8f)
#         ;
#
#
#
#
#             var marker_2347a0a287e8112cc63e373ce0f291a2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fbac57c51d35bde0f1bc8746b97c2af0);
#
#
#         var popup_ced27248768b89347cd7a4b9cc7bb2f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_efab48aacb030e6a992e9b160a656f10 = $(`&lt;div id=&quot;html_efab48aacb030e6a992e9b160a656f10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ced27248768b89347cd7a4b9cc7bb2f2.setContent(html_efab48aacb030e6a992e9b160a656f10);
#
#
#
#         marker_2347a0a287e8112cc63e373ce0f291a2.bindPopup(popup_ced27248768b89347cd7a4b9cc7bb2f2)
#         ;
#
#
#
#
#             var marker_48fbd085eb6b83e72d18cd87edb3f344 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fbac57c51d35bde0f1bc8746b97c2af0);
#
#
#         var popup_151bb3f16c1909b0e42c31abfa850011 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28f371870ac7c8993c010b18c56007d9 = $(`&lt;div id=&quot;html_28f371870ac7c8993c010b18c56007d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_151bb3f16c1909b0e42c31abfa850011.setContent(html_28f371870ac7c8993c010b18c56007d9);
#
#
#
#         marker_48fbd085eb6b83e72d18cd87edb3f344.bindPopup(popup_151bb3f16c1909b0e42c31abfa850011)
#         ;
#
#
#
#
#             var marker_8549b1ccfb7140926d86b92e26025d8c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fbac57c51d35bde0f1bc8746b97c2af0);
#
#
#         var popup_c62fba04f351d568f778de4ef64ad9ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c01a2e9cafb77d301d16ace2e864bee = $(`&lt;div id=&quot;html_7c01a2e9cafb77d301d16ace2e864bee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c62fba04f351d568f778de4ef64ad9

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29b892748af7a403185af2783b7eabde {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29b892748af7a403185af2783b7eabde&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29b892748af7a403185af2783b7eabde = L.map(
#                 &quot;map_29b892748af7a403185af2783b7eabde&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be3ecb2976d48a956c3baea423c92409 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be3ecb2976d48a956c3baea423c92409.addTo(map_29b892748af7a403185af2783b7eabde);
#
#
#             var feature_group_8160d6117a01a9f88544f601fa36b380 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2638658160fb48ad2a7f6254594e3dcb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8160d6117a01a9f88544f601fa36b380);
#
#
#         var popup_596ca78319cbde0b49128b165dc6fdec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9852f227d812b07a7976f28dc83fcec0 = $(`&lt;div id=&quot;html_9852f227d812b07a7976f28dc83fcec0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_596ca78319cbde0b49128b165dc6fdec.setContent(html_9852f227d812b07a7976f28dc83fcec0);
#
#
#
#         marker_2638658160fb48ad2a7f6254594e3dcb.bindPopup(popup_596ca78319cbde0b49128b165dc6fdec)
#         ;
#
#
#
#
#             var marker_73d353f5d698349d4a1147ad85cef919 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8160d6117a01a9f88544f601fa36b380);
#
#
#         var popup_1f0c852e02494933a60f39b38e0962df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5eef7d5c87c53abfd9b6ac73d0a4ca6b = $(`&lt;div id=&quot;html_5eef7d5c87c53abfd9b6ac73d0a4ca6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1f0c852e02494933a60f39b38e0962df.setContent(html_5eef7d5c87c53abfd9b6ac73d0a4ca6b);
#
#
#
#         marker_73d353f5d698349d4a1147ad85cef919.bindPopup(popup_1f0c852e02494933a60f39b38e0962df)
#         ;
#
#
#
#
#             var marker_bbd9f4a7c4e866c70fdda85e27b6f224 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8160d6117a01a9f88544f601fa36b380);
#
#
#         var popup_de8809f3cc3cbced3eb92965e1abbc62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c470ee237c057a740188fc923fa66d4 = $(`&lt;div id=&quot;html_0c470ee237c057a740188fc923fa66d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_de8809f3cc3cbced3eb92965e1abbc62.setContent(html_0c470ee237c057a740188fc923fa66d4);
#
#
#
#         marker_bbd9f4a7c4e866c70fdda85e27b6f224.bindPopup(popup_de8809f3cc3cbced3eb92965e1abbc62)
#         ;
#
#
#
#
#             var marker_1d8d101ecb694abdcd13d6e0a01c6d3a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8160d6117a01a9f88544f601fa36b380);
#
#
#         var popup_08f30e8169b671373a8b4861c8ecf178 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e48757fec51e9158dc7a33039d63923 = $(`&lt;div id=&quot;html_3e48757fec51e9158dc7a33039d63923&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_08f30e8169b671373a8b4861c8ecf178.setContent(html_3e48757fec51e9158dc7a33039d63923);
#
#
#
#         marker_1d8d101ecb694abdcd13d6e0a01c6d3a.bindPopup(popup_08f30e8169b671373a8b4861c8ecf178)
#         ;
#
#
#
#
#             var marker_247a8f606e8c2b57219d10d027e10985 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8160d6117a01a9f88544f601fa36b380);
#
#
#         var popup_95bfce16dd670bef9c4d5dfbf4e6c663 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d7590c359d2bb91f1a8909c41c914b7d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d7590c359d2bb91f1a8909c41c914b7d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d7590c359d2bb91f1a8909c41c914b7d = L.map(
#                 &quot;map_d7590c359d2bb91f1a8909c41c914b7d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1840b7484d1e57d691af78d0f5f33a84 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1840b7484d1e57d691af78d0f5f33a84.addTo(map_d7590c359d2bb91f1a8909c41c914b7d);
#
#
#             var feature_group_354fa0a1a5e51f1370bd949624549e6f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_354fa0a1a5e51f1370bd949624549e6f.addTo(map_d7590c359d2bb91f1a8909c41c914b7d);
#
#
#             var feature_group_sub_group_7381e699f25d58cbc0c5c7b3b77e790a = L.featureGroup.subGroup(
#                 feature_group_354fa0a1a5e51f1370bd949624549e6f
#             );
#
#
#             var marker_b0993c911569bc12b9b9f6499b0fcd9d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7381e699f25d58cbc0c5c7b3b77e790a);
#
#
#         var popup_0eedd4fc4fa7b7717ca802f0fce6ccf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3381b7540bea5f23647c5632e2619f78 = $(`&lt;div id=&quot;html_3381b7540bea5f23647c5632e2619f78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0eedd4fc4fa7b7717ca802f0fce6ccf5.setContent(html_3381b7540bea5f23647c5632e2619f78);
#
#
#
#         marker_b0993c911569bc12b9b9f6499b0fcd9d.bindPopup(popup_0eedd4fc4fa7b7717ca802f0fce6ccf5)
#         ;
#
#
#
#
#             var marker_20a5496eab7600fc01b53223191bd7e9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7381e699f25d58cbc0c5c7b3b77e790a);
#
#
#         var popup_8d1780b838db8fb246ef7b039e5101cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7385cb6d26b8481250270005aefcf1e = $(`&lt;div id=&quot;html_c7385cb6d26b8481250270005aefcf1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8d1780b838db8fb246ef7b039e5101cb.setContent(html_c7385cb6d26b8481250270005aefcf1e);
#
#
#
#         marker_20a5496eab7600fc01b53223191bd7e9.bindPopup(popup_8d1780b838db8fb246ef7b039e5101cb)
#         ;
#
#
#
#
#             var marker_8ced9ca492125d11edf31fa7f10b336d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7381e699f25d58cbc0c5c7b3b77e790a);
#
#
#         var popup_ae09ac9356cb71fb366af9b56fa5089b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32bd1c6e8ae462bceb502a2d4781ca32 = $(`&lt;div id=&quot;html_32bd1c6e8ae462bceb502a2d4781ca32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ae09ac9356cb71fb366af9b56fa5089b.setContent(html_32bd1c6e8ae462bceb502a2d4781ca32);
#
#
#
#         marker_8ced9ca492125d11edf31fa7f10b336d.bindPopup(popup_ae09ac9356cb71fb366af9b56fa5089b)
#         ;
#
#
#
#
#             var marker_4cf1790231a371996e68cb0a3f512637 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7381e699f25d58cbc0c5c7b3b77e790a);
#
#
#         var popup_1781a51a096b9f6582ef012380e2b8d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ad0525482761dc6ccbbbd0604a1e69a = $(`&lt;div id=&quot;html_2ad0525482761dc6ccbbbd0604a1e69a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1781a51a096b9f6582ef012380e2b8d1.setContent(html_2ad0525482761dc6ccbbbd0604a1e69a);
#
#
#
#         mark
