# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b90c5ba5ecc33ead0dfcd427bc6428d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b90c5ba5ecc33ead0dfcd427bc6428d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b90c5ba5ecc33ead0dfcd427bc6428d = L.map(
#                 &quot;map_9b90c5ba5ecc33ead0dfcd427bc6428d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f5db3872665a581771055b0d156e2cb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f5db3872665a581771055b0d156e2cb.addTo(map_9b90c5ba5ecc33ead0dfcd427bc6428d);
#
#
#             var marker_25ce02191af40d4121e9620bf4249d78 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9b90c5ba5ecc33ead0dfcd427bc6428d);
#
#
#         var popup_488a093b0fe9800422e44afd402786d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6388643c63cf59cb8fe2a80dfe690de0 = $(`&lt;div id=&quot;html_6388643c63cf59cb8fe2a80dfe690de0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_488a093b0fe9800422e44afd402786d9.setContent(html_6388643c63cf59cb8fe2a80dfe690de0);
#
#
#
#         marker_25ce02191af40d4121e9620bf4249d78.bindPopup(popup_488a093b0fe9800422e44afd402786d9)
#         ;
#
#
#
#
#             var marker_5c954ea68b6f64ba3567c4e1be0b13ec = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9b90c5ba5ecc33ead0dfcd427bc6428d);
#
#
#         var popup_d72028a7daa02d57ce432f88f90d8b05 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97a6ecc7967557e0bba31438585acd76 = $(`&lt;div id=&quot;html_97a6ecc7967557e0bba31438585acd76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d72028a7daa02d57ce432f88f90d8b05.setContent(html_97a6ecc7967557e0bba31438585acd76);
#
#
#
#         marker_5c954ea68b6f64ba3567c4e1be0b13ec.bindPopup(popup_d72028a7daa02d57ce432f88f90d8b05)
#         ;
#
#
#
#
#             var marker_1af4b4d6261cdeac42ec1b4c5d1c3302 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9b90c5ba5ecc33ead0dfcd427bc6428d);
#
#
#         var popup_6ee65f5daf241953f36786c89064a1d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46d85de757c871880ccbe7d5dce8eece = $(`&lt;div id=&quot;html_46d85de757c871880ccbe7d5dce8eece&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6ee65f5daf241953f36786c89064a1d1.setContent(html_46d85de757c871880ccbe7d5dce8eece);
#
#
#
#         marker_1af4b4d6261cdeac42ec1b4c5d1c3302.bindPopup(popup_6ee65f5daf241953f36786c89064a1d1)
#         ;
#
#
#
#
#             var marker_581dc4eebd80ee508522417b0aa544d4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9b90c5ba5ecc33ead0dfcd427bc6428d);
#
#
#         var popup_35c75470d50e8361231abf3a8535f7cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e14863997588473a7e5a189c51163bd7 = $(`&lt;div id=&quot;html_e14863997588473a7e5a189c51163bd7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_35c75470d50e8361231abf3a8535f7cc.setContent(html_e14863997588473a7e5a189c51163bd7);
#
#
#
#         marker_581dc4eebd80ee508522417b0aa544d4.bindPopup(popup_35c75470d50e8361231abf3a8535f7cc)
#         ;
#
#
#
#
#             var marker_bdccc10a98f65b6a7fcbb682c93ac336 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9b90c5ba5ecc33ead0dfcd427bc6428d);
#
#
#         var popup_4f788dd1c1ad61d93753a558cf0a119a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b428231b2875f67811a4f9d764bda5e = $(`&lt;div id=&quot;html_8b428231b2875f67811a4f9d764bda5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4f788dd1c1ad61d93753a558cf0a119a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27c81d15f6d4eb13d3d265362e36f1a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27c81d15f6d4eb13d3d265362e36f1a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27c81d15f6d4eb13d3d265362e36f1a7 = L.map(
#                 &quot;map_27c81d15f6d4eb13d3d265362e36f1a7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fda11709cc475d3fb256c0f01465d112 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fda11709cc475d3fb256c0f01465d112.addTo(map_27c81d15f6d4eb13d3d265362e36f1a7);
#
#
#             var feature_group_fb401bcde0740303bed995701b25cff7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e2a54618d1fee4c9ef4be1027d911462 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fb401bcde0740303bed995701b25cff7);
#
#
#         var popup_a47c0e29bb45022621265bd1fbc6a3c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b93409b01ed708569789f34a347088d1 = $(`&lt;div id=&quot;html_b93409b01ed708569789f34a347088d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a47c0e29bb45022621265bd1fbc6a3c8.setContent(html_b93409b01ed708569789f34a347088d1);
#
#
#
#         marker_e2a54618d1fee4c9ef4be1027d911462.bindPopup(popup_a47c0e29bb45022621265bd1fbc6a3c8)
#         ;
#
#
#
#
#             var marker_be6e7fa9e16692d8e865759c39856994 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fb401bcde0740303bed995701b25cff7);
#
#
#         var popup_f1568efe2d9a95f9df1c97c41512acb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dabe4099b55270ed9d9eb1c66308bf0 = $(`&lt;div id=&quot;html_2dabe4099b55270ed9d9eb1c66308bf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f1568efe2d9a95f9df1c97c41512acb5.setContent(html_2dabe4099b55270ed9d9eb1c66308bf0);
#
#
#
#         marker_be6e7fa9e16692d8e865759c39856994.bindPopup(popup_f1568efe2d9a95f9df1c97c41512acb5)
#         ;
#
#
#
#
#             var marker_0c931bde150774d1b5c709978a2a0097 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fb401bcde0740303bed995701b25cff7);
#
#
#         var popup_cd8bd61282ad598d7241d63480434dc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad48a282a00e2e28c9773de8616171a4 = $(`&lt;div id=&quot;html_ad48a282a00e2e28c9773de8616171a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cd8bd61282ad598d7241d63480434dc9.setContent(html_ad48a282a00e2e28c9773de8616171a4);
#
#
#
#         marker_0c931bde150774d1b5c709978a2a0097.bindPopup(popup_cd8bd61282ad598d7241d63480434dc9)
#         ;
#
#
#
#
#             var marker_f424cde74c342975a96b011892ad135f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fb401bcde0740303bed995701b25cff7);
#
#
#         var popup_2ecfb222f1ae4278ba1e63c306d7327b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_51135aed920c1549a44449c3f170087a = $(`&lt;div id=&quot;html_51135aed920c1549a44449c3f170087a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2ecfb222f1ae4278ba1e63c306d7327b.setContent(html_51135aed920c1549a44449c3f170087a);
#
#
#
#         marker_f424cde74c342975a96b011892ad135f.bindPopup(popup_2ecfb222f1ae4278ba1e63c306d7327b)
#         ;
#
#
#
#
#             var marker_5437ea9d7d6683c03cb5d0cfa508e0c4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fb401bcde0740303bed995701b25cff7);
#
#
#         var popup_196ccdc4c067bab91ef4d217c42ba4d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06a1b45e835c19631dd18dd7d8dc8de4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06a1b45e835c19631dd18dd7d8dc8de4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06a1b45e835c19631dd18dd7d8dc8de4 = L.map(
#                 &quot;map_06a1b45e835c19631dd18dd7d8dc8de4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e073273a8a399652a16f1e7854e4291 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e073273a8a399652a16f1e7854e4291.addTo(map_06a1b45e835c19631dd18dd7d8dc8de4);
#
#
#             var feature_group_bc028123760cf3350e577976b9735330 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bc028123760cf3350e577976b9735330.addTo(map_06a1b45e835c19631dd18dd7d8dc8de4);
#
#
#             var feature_group_sub_group_a8f09231becc82ddece9126711cea0ba = L.featureGroup.subGroup(
#                 feature_group_bc028123760cf3350e577976b9735330
#             );
#
#
#             var marker_ba4a032f3b8535e2493fa1758d15f721 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8f09231becc82ddece9126711cea0ba);
#
#
#         var popup_6b3452d9a0b78f1e206a8045f6b092f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb9fe3dcd3cf684f13e708e49d86def1 = $(`&lt;div id=&quot;html_cb9fe3dcd3cf684f13e708e49d86def1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6b3452d9a0b78f1e206a8045f6b092f5.setContent(html_cb9fe3dcd3cf684f13e708e49d86def1);
#
#
#
#         marker_ba4a032f3b8535e2493fa1758d15f721.bindPopup(popup_6b3452d9a0b78f1e206a8045f6b092f5)
#         ;
#
#
#
#
#             var marker_394de54cb81310bf259fa5629129c068 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8f09231becc82ddece9126711cea0ba);
#
#
#         var popup_6fc43dcd6b0603199d5df624a2e0cf6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2abd7ec5060fe33b59c9b164175db084 = $(`&lt;div id=&quot;html_2abd7ec5060fe33b59c9b164175db084&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6fc43dcd6b0603199d5df624a2e0cf6d.setContent(html_2abd7ec5060fe33b59c9b164175db084);
#
#
#
#         marker_394de54cb81310bf259fa5629129c068.bindPopup(popup_6fc43dcd6b0603199d5df624a2e0cf6d)
#         ;
#
#
#
#
#             var marker_48c2c8c00af700bc691f105fcf66fe65 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8f09231becc82ddece9126711cea0ba);
#
#
#         var popup_6cb1581bbbb548cf8e32871750002aaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47f3d241140ceb491f5af0e62a72589b = $(`&lt;div id=&quot;html_47f3d241140ceb491f5af0e62a72589b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6cb1581bbbb548cf8e32871750002aaf.setContent(html_47f3d241140ceb491f5af0e62a72589b);
#
#
#
#         marker_48c2c8c00af700bc691f105fcf66fe65.bindPopup(popup_6cb1581bbbb548cf8e32871750002aaf)
#         ;
#
#
#
#
#             var marker_d670c3521e0648c55831313f7e749432 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a8f09231becc82ddece9126711cea0ba);
#
#
#         var popup_8a259440787521e06e36380e38f29899 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b44c4249a5c8c02699a2fc380106ee1 = $(`&lt;div id=&quot;html_8b44c4249a5c8c02699a2fc380106ee1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8a259440787521e06e36380e38f29899.setContent(html_8b44c4249a5c8c02699a2fc380106ee1);
#
#
#
#         marker_
