# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_631abc0d305ddec26789d4475dccbb10 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_631abc0d305ddec26789d4475dccbb10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_631abc0d305ddec26789d4475dccbb10 = L.map(
#                 &quot;map_631abc0d305ddec26789d4475dccbb10&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41bb0bbc7b09f5dafc6b6149ee5ff6b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_41bb0bbc7b09f5dafc6b6149ee5ff6b3.addTo(map_631abc0d305ddec26789d4475dccbb10);
#
#
#             var marker_5f3040683215232501a7fb38b5e24e75 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_631abc0d305ddec26789d4475dccbb10);
#
#
#         var popup_b494b60d1d6fa12579d79bf30d043fbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33edff92f10c1167350318f9bd12da96 = $(`&lt;div id=&quot;html_33edff92f10c1167350318f9bd12da96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b494b60d1d6fa12579d79bf30d043fbe.setContent(html_33edff92f10c1167350318f9bd12da96);
#
#
#
#         marker_5f3040683215232501a7fb38b5e24e75.bindPopup(popup_b494b60d1d6fa12579d79bf30d043fbe)
#         ;
#
#
#
#
#             var marker_1300a0829595141db0269dd90658e063 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_631abc0d305ddec26789d4475dccbb10);
#
#
#         var popup_0adef6c3ae327204e0f872bd5db7dd6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0fe19906a13c5bc848b99e17c05c202 = $(`&lt;div id=&quot;html_c0fe19906a13c5bc848b99e17c05c202&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0adef6c3ae327204e0f872bd5db7dd6d.setContent(html_c0fe19906a13c5bc848b99e17c05c202);
#
#
#
#         marker_1300a0829595141db0269dd90658e063.bindPopup(popup_0adef6c3ae327204e0f872bd5db7dd6d)
#         ;
#
#
#
#
#             var marker_c9bfbbdafa923f778f1cb8181859b41b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_631abc0d305ddec26789d4475dccbb10);
#
#
#         var popup_a4394e39c62268763d8d43b4b158640f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d68f95a3623d8bb7d6fc2fbd76bfae97 = $(`&lt;div id=&quot;html_d68f95a3623d8bb7d6fc2fbd76bfae97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a4394e39c62268763d8d43b4b158640f.setContent(html_d68f95a3623d8bb7d6fc2fbd76bfae97);
#
#
#
#         marker_c9bfbbdafa923f778f1cb8181859b41b.bindPopup(popup_a4394e39c62268763d8d43b4b158640f)
#         ;
#
#
#
#
#             var marker_b10c3aaeb7d4013cdbb3b9dcc72b88b6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_631abc0d305ddec26789d4475dccbb10);
#
#
#         var popup_644c26a104d994d6aa75c40dc1339616 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33c546cddaf034ec58719fd3603ce2c6 = $(`&lt;div id=&quot;html_33c546cddaf034ec58719fd3603ce2c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_644c26a104d994d6aa75c40dc1339616.setContent(html_33c546cddaf034ec58719fd3603ce2c6);
#
#
#
#         marker_b10c3aaeb7d4013cdbb3b9dcc72b88b6.bindPopup(popup_644c26a104d994d6aa75c40dc1339616)
#         ;
#
#
#
#
#             var marker_4830e73e1cf74122006db0779ed0d4ed = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_631abc0d305ddec26789d4475dccbb10);
#
#
#         var popup_b5901e76c1d5a31c33cca52453e2a78a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_986198a86f421ec16e6ac2ac351952cd = $(`&lt;div id=&quot;html_986198a86f421ec16e6ac2ac351952cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b5901e76c1d5a31c33cca52453e2a7

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_442d32b8c5a0b6777c25516aa97c4130 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_442d32b8c5a0b6777c25516aa97c4130&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_442d32b8c5a0b6777c25516aa97c4130 = L.map(
#                 &quot;map_442d32b8c5a0b6777c25516aa97c4130&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3e09049ed6480e167de0a9db137a74a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3e09049ed6480e167de0a9db137a74a5.addTo(map_442d32b8c5a0b6777c25516aa97c4130);
#
#
#             var feature_group_4e7e7e9adc6997752ef64ce5ae36f95e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d0f27cb4c6e62bf88dc32aaf6006b60a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4e7e7e9adc6997752ef64ce5ae36f95e);
#
#
#         var popup_2b4757589caaf3d78fa47903a688536d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46f2f748e6782daa530245a3aa5bc942 = $(`&lt;div id=&quot;html_46f2f748e6782daa530245a3aa5bc942&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2b4757589caaf3d78fa47903a688536d.setContent(html_46f2f748e6782daa530245a3aa5bc942);
#
#
#
#         marker_d0f27cb4c6e62bf88dc32aaf6006b60a.bindPopup(popup_2b4757589caaf3d78fa47903a688536d)
#         ;
#
#
#
#
#             var marker_4ebbe3ec98c1403390ff37d32e881f26 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4e7e7e9adc6997752ef64ce5ae36f95e);
#
#
#         var popup_31f0fe783ee03faea4e3c8ecccf97648 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ca0f5df5f89319901fc9a1afbd191e7 = $(`&lt;div id=&quot;html_0ca0f5df5f89319901fc9a1afbd191e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_31f0fe783ee03faea4e3c8ecccf97648.setContent(html_0ca0f5df5f89319901fc9a1afbd191e7);
#
#
#
#         marker_4ebbe3ec98c1403390ff37d32e881f26.bindPopup(popup_31f0fe783ee03faea4e3c8ecccf97648)
#         ;
#
#
#
#
#             var marker_ec5309121e0eb47cce4368b250a3b635 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4e7e7e9adc6997752ef64ce5ae36f95e);
#
#
#         var popup_5e15638fb94b9737f61b968957281fd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5310f8c6ac147f904ec61fd6b78a2e51 = $(`&lt;div id=&quot;html_5310f8c6ac147f904ec61fd6b78a2e51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5e15638fb94b9737f61b968957281fd9.setContent(html_5310f8c6ac147f904ec61fd6b78a2e51);
#
#
#
#         marker_ec5309121e0eb47cce4368b250a3b635.bindPopup(popup_5e15638fb94b9737f61b968957281fd9)
#         ;
#
#
#
#
#             var marker_98934bafdef5aa51627b416dcfedfdf1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4e7e7e9adc6997752ef64ce5ae36f95e);
#
#
#         var popup_6efab979251aedbef36cd70c30250ec1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d8fbb7e4395ed61045b577964e9f1dd = $(`&lt;div id=&quot;html_5d8fbb7e4395ed61045b577964e9f1dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6efab979251aedbef36cd70c30250ec1.setContent(html_5d8fbb7e4395ed61045b577964e9f1dd);
#
#
#
#         marker_98934bafdef5aa51627b416dcfedfdf1.bindPopup(popup_6efab979251aedbef36cd70c30250ec1)
#         ;
#
#
#
#
#             var marker_b3e278ead7d6de6a550d1f61f37d6b14 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4e7e7e9adc6997752ef64ce5ae36f95e);
#
#
#         var popup_002bb05f778ad9badc43dc307f8b40a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_31e0c9a7bd6ef3bcf0dae94c0a48e1e6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_31e0c9a7bd6ef3bcf0dae94c0a48e1e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_31e0c9a7bd6ef3bcf0dae94c0a48e1e6 = L.map(
#                 &quot;map_31e0c9a7bd6ef3bcf0dae94c0a48e1e6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17a18d56ef9544eb6637bf02e6c2ef91 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17a18d56ef9544eb6637bf02e6c2ef91.addTo(map_31e0c9a7bd6ef3bcf0dae94c0a48e1e6);
#
#
#             var feature_group_19fd91038949ab7f3038ff28b8395d92 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_19fd91038949ab7f3038ff28b8395d92.addTo(map_31e0c9a7bd6ef3bcf0dae94c0a48e1e6);
#
#
#             var feature_group_sub_group_f684b34572a48dfcbbcd81114ffd6c8d = L.featureGroup.subGroup(
#                 feature_group_19fd91038949ab7f3038ff28b8395d92
#             );
#
#
#             var marker_840d8f03306e0b02edcee93dd40a9728 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f684b34572a48dfcbbcd81114ffd6c8d);
#
#
#         var popup_93fe30cddc56401a9d7712d0ab79f5bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2e5e0fb01ebe6eeee7689dc041828e6 = $(`&lt;div id=&quot;html_b2e5e0fb01ebe6eeee7689dc041828e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_93fe30cddc56401a9d7712d0ab79f5bb.setContent(html_b2e5e0fb01ebe6eeee7689dc041828e6);
#
#
#
#         marker_840d8f03306e0b02edcee93dd40a9728.bindPopup(popup_93fe30cddc56401a9d7712d0ab79f5bb)
#         ;
#
#
#
#
#             var marker_d326d002ec23ce9a0b4e840918055b6b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f684b34572a48dfcbbcd81114ffd6c8d);
#
#
#         var popup_c2909eccb1953a0e057e2480b1616698 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3793c54802424d489b0c38a7abe29b6 = $(`&lt;div id=&quot;html_d3793c54802424d489b0c38a7abe29b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c2909eccb1953a0e057e2480b1616698.setContent(html_d3793c54802424d489b0c38a7abe29b6);
#
#
#
#         marker_d326d002ec23ce9a0b4e840918055b6b.bindPopup(popup_c2909eccb1953a0e057e2480b1616698)
#         ;
#
#
#
#
#             var marker_4cedc4eac63b440ff42814c57b82ab1a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f684b34572a48dfcbbcd81114ffd6c8d);
#
#
#         var popup_c25e56e7fa31fb707ce90700df30112b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c9c54515119c5153627e4a9200ab9f0 = $(`&lt;div id=&quot;html_6c9c54515119c5153627e4a9200ab9f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c25e56e7fa31fb707ce90700df30112b.setContent(html_6c9c54515119c5153627e4a9200ab9f0);
#
#
#
#         marker_4cedc4eac63b440ff42814c57b82ab1a.bindPopup(popup_c25e56e7fa31fb707ce90700df30112b)
#         ;
#
#
#
#
#             var marker_b8fcc42a70e9cffad68db6827562b2b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f684b34572a48dfcbbcd81114ffd6c8d);
#
#
#         var popup_6fb53e1ba07bf84bf15f7d8992894cd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bbfc615ec5b8035c1626c1d1de7febf = $(`&lt;div id=&quot;html_0bbfc615ec5b8035c1626c1d1de7febf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6fb53e1ba07bf84bf15f7d8992894cd2.setContent(html_0bbfc615ec5b8035c1626c1d1de7febf);
#
#
#
#         mark
