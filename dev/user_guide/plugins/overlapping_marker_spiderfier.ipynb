# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e96ec9b1ccf15ee02a42d683bbb5a999 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e96ec9b1ccf15ee02a42d683bbb5a999&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e96ec9b1ccf15ee02a42d683bbb5a999 = L.map(
#                 &quot;map_e96ec9b1ccf15ee02a42d683bbb5a999&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62ee934844eafe2f7acdbfa3a52757da = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62ee934844eafe2f7acdbfa3a52757da.addTo(map_e96ec9b1ccf15ee02a42d683bbb5a999);
#
#
#             var marker_47cf735de8cc1df45d224aa02cd5e2e6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e96ec9b1ccf15ee02a42d683bbb5a999);
#
#
#         var popup_4b77e54fb68c8b042c509da455d2e237 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1982e8841a21eb83af1f1f6df38f9982 = $(`&lt;div id=&quot;html_1982e8841a21eb83af1f1f6df38f9982&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4b77e54fb68c8b042c509da455d2e237.setContent(html_1982e8841a21eb83af1f1f6df38f9982);
#
#
#
#         marker_47cf735de8cc1df45d224aa02cd5e2e6.bindPopup(popup_4b77e54fb68c8b042c509da455d2e237)
#         ;
#
#
#
#
#             var marker_5d7c0b30dbe839d44b42577a4da79c26 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e96ec9b1ccf15ee02a42d683bbb5a999);
#
#
#         var popup_21cc192f0b6089555085e81a6ad2a045 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9538f178e0086e612d26976ea90e3c2d = $(`&lt;div id=&quot;html_9538f178e0086e612d26976ea90e3c2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_21cc192f0b6089555085e81a6ad2a045.setContent(html_9538f178e0086e612d26976ea90e3c2d);
#
#
#
#         marker_5d7c0b30dbe839d44b42577a4da79c26.bindPopup(popup_21cc192f0b6089555085e81a6ad2a045)
#         ;
#
#
#
#
#             var marker_f312ad34cb6e59d48ee30068643e3407 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e96ec9b1ccf15ee02a42d683bbb5a999);
#
#
#         var popup_1140d56753eee693909aae05c7218ed5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c98474ac8b33c8518c55adc0f14e99a1 = $(`&lt;div id=&quot;html_c98474ac8b33c8518c55adc0f14e99a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1140d56753eee693909aae05c7218ed5.setContent(html_c98474ac8b33c8518c55adc0f14e99a1);
#
#
#
#         marker_f312ad34cb6e59d48ee30068643e3407.bindPopup(popup_1140d56753eee693909aae05c7218ed5)
#         ;
#
#
#
#
#             var marker_292c0158f18ba3fbc53550a4bf0839fe = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e96ec9b1ccf15ee02a42d683bbb5a999);
#
#
#         var popup_5720e3f2d2382080a41301cd144f6a59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_840b9b495e003957bb2c0239b21461b8 = $(`&lt;div id=&quot;html_840b9b495e003957bb2c0239b21461b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5720e3f2d2382080a41301cd144f6a59.setContent(html_840b9b495e003957bb2c0239b21461b8);
#
#
#
#         marker_292c0158f18ba3fbc53550a4bf0839fe.bindPopup(popup_5720e3f2d2382080a41301cd144f6a59)
#         ;
#
#
#
#
#             var marker_085bc7f8110f123574eb1e6f1375d40d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e96ec9b1ccf15ee02a42d683bbb5a999);
#
#
#         var popup_3016d95daa87c1b85de09b94a90eaf8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cdbbb5d50db909267217f33e61e4f2c = $(`&lt;div id=&quot;html_8cdbbb5d50db909267217f33e61e4f2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_3016d95daa87c1b85de09b94a90eaf8e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29f6738f13dd34d34e423182e9d54843 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29f6738f13dd34d34e423182e9d54843&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29f6738f13dd34d34e423182e9d54843 = L.map(
#                 &quot;map_29f6738f13dd34d34e423182e9d54843&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0da6971da328c8ffe19541bb6938ed03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0da6971da328c8ffe19541bb6938ed03.addTo(map_29f6738f13dd34d34e423182e9d54843);
#
#
#             var feature_group_80f0086c2f5264104c86bf0cfb7c29be = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_968820c6d29173413dc31b3ee88d577d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_80f0086c2f5264104c86bf0cfb7c29be);
#
#
#         var popup_82bebc71e3b77b682dc55715b15082af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d79e0c667ee9e65eef3a14b41b9ab1a0 = $(`&lt;div id=&quot;html_d79e0c667ee9e65eef3a14b41b9ab1a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_82bebc71e3b77b682dc55715b15082af.setContent(html_d79e0c667ee9e65eef3a14b41b9ab1a0);
#
#
#
#         marker_968820c6d29173413dc31b3ee88d577d.bindPopup(popup_82bebc71e3b77b682dc55715b15082af)
#         ;
#
#
#
#
#             var marker_75c313fd485a65226a9c67752b04c395 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_80f0086c2f5264104c86bf0cfb7c29be);
#
#
#         var popup_89fab6fcfd4beec1ee75ae86d211a7b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50188d55d4082cdfd22161fff1d7e6bf = $(`&lt;div id=&quot;html_50188d55d4082cdfd22161fff1d7e6bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_89fab6fcfd4beec1ee75ae86d211a7b6.setContent(html_50188d55d4082cdfd22161fff1d7e6bf);
#
#
#
#         marker_75c313fd485a65226a9c67752b04c395.bindPopup(popup_89fab6fcfd4beec1ee75ae86d211a7b6)
#         ;
#
#
#
#
#             var marker_f9cfffb47c0a05caace07a077a879f21 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_80f0086c2f5264104c86bf0cfb7c29be);
#
#
#         var popup_141bc950738511bfe086372d27d5207b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_777596efedd6617639bb0e38b7b9e25d = $(`&lt;div id=&quot;html_777596efedd6617639bb0e38b7b9e25d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_141bc950738511bfe086372d27d5207b.setContent(html_777596efedd6617639bb0e38b7b9e25d);
#
#
#
#         marker_f9cfffb47c0a05caace07a077a879f21.bindPopup(popup_141bc950738511bfe086372d27d5207b)
#         ;
#
#
#
#
#             var marker_d9cabbef21d3f4df424d04b2211fd010 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_80f0086c2f5264104c86bf0cfb7c29be);
#
#
#         var popup_2dee417da884ddc171c2e0bae529189c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81bf89714a179c0d0157f96138de12da = $(`&lt;div id=&quot;html_81bf89714a179c0d0157f96138de12da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2dee417da884ddc171c2e0bae529189c.setContent(html_81bf89714a179c0d0157f96138de12da);
#
#
#
#         marker_d9cabbef21d3f4df424d04b2211fd010.bindPopup(popup_2dee417da884ddc171c2e0bae529189c)
#         ;
#
#
#
#
#             var marker_9d26a77edc3a6fd823e8f7d69c0a15fb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_80f0086c2f5264104c86bf0cfb7c29be);
#
#
#         var popup_b659ced7a9bdd8f14a3226b8ca82d648 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6354e9e15b341251f42c9a5db54d880c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6354e9e15b341251f42c9a5db54d880c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6354e9e15b341251f42c9a5db54d880c = L.map(
#                 &quot;map_6354e9e15b341251f42c9a5db54d880c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf20e9ad045ab15427754a4ac95b3dd6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf20e9ad045ab15427754a4ac95b3dd6.addTo(map_6354e9e15b341251f42c9a5db54d880c);
#
#
#             var feature_group_b436d59560c7b7f233475fb0bc62cb2b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b436d59560c7b7f233475fb0bc62cb2b.addTo(map_6354e9e15b341251f42c9a5db54d880c);
#
#
#             var feature_group_sub_group_20dbaccb99ae6bba38cac05665079262 = L.featureGroup.subGroup(
#                 feature_group_b436d59560c7b7f233475fb0bc62cb2b
#             );
#
#
#             var marker_9b8be51ae415a426c5d1dabc8ab20751 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_20dbaccb99ae6bba38cac05665079262);
#
#
#         var popup_137476eef96c0046098e7ebeb88cac93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27d6794571d5d8d70cfafa13fa6c3fc9 = $(`&lt;div id=&quot;html_27d6794571d5d8d70cfafa13fa6c3fc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_137476eef96c0046098e7ebeb88cac93.setContent(html_27d6794571d5d8d70cfafa13fa6c3fc9);
#
#
#
#         marker_9b8be51ae415a426c5d1dabc8ab20751.bindPopup(popup_137476eef96c0046098e7ebeb88cac93)
#         ;
#
#
#
#
#             var marker_b184afa8237f945c4f785e07ab999b4e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_20dbaccb99ae6bba38cac05665079262);
#
#
#         var popup_af038cda67088a8d0544d1a112527053 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_256e03a263cafdd5326b91ea61be40c0 = $(`&lt;div id=&quot;html_256e03a263cafdd5326b91ea61be40c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_af038cda67088a8d0544d1a112527053.setContent(html_256e03a263cafdd5326b91ea61be40c0);
#
#
#
#         marker_b184afa8237f945c4f785e07ab999b4e.bindPopup(popup_af038cda67088a8d0544d1a112527053)
#         ;
#
#
#
#
#             var marker_5e715e3308aefd3e353ae977c85978d2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_20dbaccb99ae6bba38cac05665079262);
#
#
#         var popup_85e8344c97719f79ece47fd3323da43d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f66719d720b0aaaa6c5fe5e4d512002 = $(`&lt;div id=&quot;html_1f66719d720b0aaaa6c5fe5e4d512002&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_85e8344c97719f79ece47fd3323da43d.setContent(html_1f66719d720b0aaaa6c5fe5e4d512002);
#
#
#
#         marker_5e715e3308aefd3e353ae977c85978d2.bindPopup(popup_85e8344c97719f79ece47fd3323da43d)
#         ;
#
#
#
#
#             var marker_e09a09a154bf83771780ee7d3dbad2cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_20dbaccb99ae6bba38cac05665079262);
#
#
#         var popup_7a792bbe18f4bb8ac19f820c2d4067c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7718a57de607a75162e5eea641f341fa = $(`&lt;div id=&quot;html_7718a57de607a75162e5eea641f341fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7a792bbe18f4bb8ac19f820c2d4067c8.setContent(html_7718a57de607a75162e5eea641f341fa);
#
#
#
#         marker_
