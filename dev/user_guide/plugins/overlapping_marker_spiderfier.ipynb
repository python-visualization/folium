# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e10f782d4a32fc7c5adfeb9cb5fe659 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e10f782d4a32fc7c5adfeb9cb5fe659&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e10f782d4a32fc7c5adfeb9cb5fe659 = L.map(
#                 &quot;map_9e10f782d4a32fc7c5adfeb9cb5fe659&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_85679ee6d48925ba0c4128504f2b094e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_85679ee6d48925ba0c4128504f2b094e.addTo(map_9e10f782d4a32fc7c5adfeb9cb5fe659);
#
#
#             var marker_5ff3fa6e24969211a7b6ad82db7a33f6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9e10f782d4a32fc7c5adfeb9cb5fe659);
#
#
#         var popup_4412874900622e58ea09c223b0a88712 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f400bc93dfbb0cb555fa5fabc77d91c2 = $(`&lt;div id=&quot;html_f400bc93dfbb0cb555fa5fabc77d91c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4412874900622e58ea09c223b0a88712.setContent(html_f400bc93dfbb0cb555fa5fabc77d91c2);
#
#
#
#         marker_5ff3fa6e24969211a7b6ad82db7a33f6.bindPopup(popup_4412874900622e58ea09c223b0a88712)
#         ;
#
#
#
#
#             var marker_90662225310fcf158194a67087370408 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9e10f782d4a32fc7c5adfeb9cb5fe659);
#
#
#         var popup_d378b0f4c6e2b4a25e4159c9978d5f1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12cf2162a004fb5a256b13fb177def96 = $(`&lt;div id=&quot;html_12cf2162a004fb5a256b13fb177def96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d378b0f4c6e2b4a25e4159c9978d5f1b.setContent(html_12cf2162a004fb5a256b13fb177def96);
#
#
#
#         marker_90662225310fcf158194a67087370408.bindPopup(popup_d378b0f4c6e2b4a25e4159c9978d5f1b)
#         ;
#
#
#
#
#             var marker_07b5a3cac94a47635b53fc6b11b15aa0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9e10f782d4a32fc7c5adfeb9cb5fe659);
#
#
#         var popup_878fd92445305d5775bac4027ecbf575 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48589cc1ec8e68aa8b3f34d63256f05a = $(`&lt;div id=&quot;html_48589cc1ec8e68aa8b3f34d63256f05a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_878fd92445305d5775bac4027ecbf575.setContent(html_48589cc1ec8e68aa8b3f34d63256f05a);
#
#
#
#         marker_07b5a3cac94a47635b53fc6b11b15aa0.bindPopup(popup_878fd92445305d5775bac4027ecbf575)
#         ;
#
#
#
#
#             var marker_4f64fa8b5b851f32d0834c155262c4fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9e10f782d4a32fc7c5adfeb9cb5fe659);
#
#
#         var popup_2cc037be82e779a315722d73ff733be6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7927db4f09af44f386ad40b1e15699a = $(`&lt;div id=&quot;html_e7927db4f09af44f386ad40b1e15699a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2cc037be82e779a315722d73ff733be6.setContent(html_e7927db4f09af44f386ad40b1e15699a);
#
#
#
#         marker_4f64fa8b5b851f32d0834c155262c4fc.bindPopup(popup_2cc037be82e779a315722d73ff733be6)
#         ;
#
#
#
#
#             var marker_115aaa184c0a08972fb93f2525f38355 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9e10f782d4a32fc7c5adfeb9cb5fe659);
#
#
#         var popup_09a5dd8ae22d8acf59bfc40080cdb4f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f22a0acc708c01d2824d465903f28e49 = $(`&lt;div id=&quot;html_f22a0acc708c01d2824d465903f28e49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_09a5dd8ae22d8acf59bfc40080cdb4f7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d2f0f896d6f3aa850f91f809f92202c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d2f0f896d6f3aa850f91f809f92202c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d2f0f896d6f3aa850f91f809f92202c = L.map(
#                 &quot;map_6d2f0f896d6f3aa850f91f809f92202c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc70573353226215309d73feb4a7f143 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc70573353226215309d73feb4a7f143.addTo(map_6d2f0f896d6f3aa850f91f809f92202c);
#
#
#             var feature_group_6344240e0029d532fb23c9816e8bddfc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_63fe880bbe79cf5cac3e06bd4592865d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6344240e0029d532fb23c9816e8bddfc);
#
#
#         var popup_b98747be7a5fefa352c04cd2529770f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47919caf57f0d3efa7490984fd2d38e1 = $(`&lt;div id=&quot;html_47919caf57f0d3efa7490984fd2d38e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b98747be7a5fefa352c04cd2529770f4.setContent(html_47919caf57f0d3efa7490984fd2d38e1);
#
#
#
#         marker_63fe880bbe79cf5cac3e06bd4592865d.bindPopup(popup_b98747be7a5fefa352c04cd2529770f4)
#         ;
#
#
#
#
#             var marker_661b29dc9e27afdbacda55552543a2ca = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6344240e0029d532fb23c9816e8bddfc);
#
#
#         var popup_50624887e8339f7c2bf03094a3b1644f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50c5b72d751c30806749190b094a3ca9 = $(`&lt;div id=&quot;html_50c5b72d751c30806749190b094a3ca9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_50624887e8339f7c2bf03094a3b1644f.setContent(html_50c5b72d751c30806749190b094a3ca9);
#
#
#
#         marker_661b29dc9e27afdbacda55552543a2ca.bindPopup(popup_50624887e8339f7c2bf03094a3b1644f)
#         ;
#
#
#
#
#             var marker_990e0cb95ec458287f08843cd2d14e4d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6344240e0029d532fb23c9816e8bddfc);
#
#
#         var popup_43a7785bf9919df5d7f8fbe448fa4cad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e612730774fe1d65abe06467484f1ad = $(`&lt;div id=&quot;html_8e612730774fe1d65abe06467484f1ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_43a7785bf9919df5d7f8fbe448fa4cad.setContent(html_8e612730774fe1d65abe06467484f1ad);
#
#
#
#         marker_990e0cb95ec458287f08843cd2d14e4d.bindPopup(popup_43a7785bf9919df5d7f8fbe448fa4cad)
#         ;
#
#
#
#
#             var marker_c0779ada7f7dcfe40de9b128532d3b91 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6344240e0029d532fb23c9816e8bddfc);
#
#
#         var popup_b5e6be4e696ac0cfd1197a03b4631d5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e50ca20102b5117124df81ba0ae232e = $(`&lt;div id=&quot;html_9e50ca20102b5117124df81ba0ae232e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b5e6be4e696ac0cfd1197a03b4631d5e.setContent(html_9e50ca20102b5117124df81ba0ae232e);
#
#
#
#         marker_c0779ada7f7dcfe40de9b128532d3b91.bindPopup(popup_b5e6be4e696ac0cfd1197a03b4631d5e)
#         ;
#
#
#
#
#             var marker_89061914a2bd143342a4cba7e6369cc8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6344240e0029d532fb23c9816e8bddfc);
#
#
#         var popup_4b7772d492f262bf648bf905a083f93e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6b591f353999ba591d7f607c62a48f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6b591f353999ba591d7f607c62a48f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6b591f353999ba591d7f607c62a48f6 = L.map(
#                 &quot;map_e6b591f353999ba591d7f607c62a48f6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afafe0d5e2b59e7fd6289779ae92e04e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afafe0d5e2b59e7fd6289779ae92e04e.addTo(map_e6b591f353999ba591d7f607c62a48f6);
#
#
#             var feature_group_ee46c3a4125edf99497afddda889d48f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ee46c3a4125edf99497afddda889d48f.addTo(map_e6b591f353999ba591d7f607c62a48f6);
#
#
#             var feature_group_sub_group_dad0d504973cb96074ed3c6d2bae94f2 = L.featureGroup.subGroup(
#                 feature_group_ee46c3a4125edf99497afddda889d48f
#             );
#
#
#             var marker_66dce9b570a3caddc5304bd451218be7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dad0d504973cb96074ed3c6d2bae94f2);
#
#
#         var popup_abe1da32bc4e878b72db0ebd3c0585e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8af1779f0d7c05b6b97d0ae793947df6 = $(`&lt;div id=&quot;html_8af1779f0d7c05b6b97d0ae793947df6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_abe1da32bc4e878b72db0ebd3c0585e8.setContent(html_8af1779f0d7c05b6b97d0ae793947df6);
#
#
#
#         marker_66dce9b570a3caddc5304bd451218be7.bindPopup(popup_abe1da32bc4e878b72db0ebd3c0585e8)
#         ;
#
#
#
#
#             var marker_67168269a14e7f7399fc8435d46ef556 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dad0d504973cb96074ed3c6d2bae94f2);
#
#
#         var popup_17be85e133bc09c50b5c5f030a629196 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9b79bd985979c092e2bdcde122b63f6 = $(`&lt;div id=&quot;html_d9b79bd985979c092e2bdcde122b63f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_17be85e133bc09c50b5c5f030a629196.setContent(html_d9b79bd985979c092e2bdcde122b63f6);
#
#
#
#         marker_67168269a14e7f7399fc8435d46ef556.bindPopup(popup_17be85e133bc09c50b5c5f030a629196)
#         ;
#
#
#
#
#             var marker_19312e91950b9c3430e3b840c8326717 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dad0d504973cb96074ed3c6d2bae94f2);
#
#
#         var popup_2496c4ee82d5d98a54095ffeb99d9bd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a170d452edf500882f47a39f5c438d10 = $(`&lt;div id=&quot;html_a170d452edf500882f47a39f5c438d10&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2496c4ee82d5d98a54095ffeb99d9bd7.setContent(html_a170d452edf500882f47a39f5c438d10);
#
#
#
#         marker_19312e91950b9c3430e3b840c8326717.bindPopup(popup_2496c4ee82d5d98a54095ffeb99d9bd7)
#         ;
#
#
#
#
#             var marker_ea2b2e0497ed3d5fa41b99518610b7ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dad0d504973cb96074ed3c6d2bae94f2);
#
#
#         var popup_f05d29fd7a1ab2cac3ea36efedc8305b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_849c911e45340831dd55fab50759cc23 = $(`&lt;div id=&quot;html_849c911e45340831dd55fab50759cc23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f05d29fd7a1ab2cac3ea36efedc8305b.setContent(html_849c911e45340831dd55fab50759cc23);
#
#
#
#         marker_
