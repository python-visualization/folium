# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3abd75b452f33727b723c9d544acee2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3abd75b452f33727b723c9d544acee2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3abd75b452f33727b723c9d544acee2 = L.map(
#                 &quot;map_d3abd75b452f33727b723c9d544acee2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab614e37598d368e6a8b0a7076cd2f77 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab614e37598d368e6a8b0a7076cd2f77.addTo(map_d3abd75b452f33727b723c9d544acee2);
#
#
#             var marker_4b323a500fca153d9f91920447c86fbd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d3abd75b452f33727b723c9d544acee2);
#
#
#         var popup_68a9b3d647b5e7e30f05d629b4eb7d8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd3d8fc6d26924b75f6e44cc730cd2ce = $(`&lt;div id=&quot;html_dd3d8fc6d26924b75f6e44cc730cd2ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_68a9b3d647b5e7e30f05d629b4eb7d8c.setContent(html_dd3d8fc6d26924b75f6e44cc730cd2ce);
#
#
#
#         marker_4b323a500fca153d9f91920447c86fbd.bindPopup(popup_68a9b3d647b5e7e30f05d629b4eb7d8c)
#         ;
#
#
#
#
#             var marker_17d617d90e914cc323265d442c749c27 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d3abd75b452f33727b723c9d544acee2);
#
#
#         var popup_1b91283570ff012f67dd459ca4c74b1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75f13bd6123e29669151c78cf7312fe3 = $(`&lt;div id=&quot;html_75f13bd6123e29669151c78cf7312fe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1b91283570ff012f67dd459ca4c74b1d.setContent(html_75f13bd6123e29669151c78cf7312fe3);
#
#
#
#         marker_17d617d90e914cc323265d442c749c27.bindPopup(popup_1b91283570ff012f67dd459ca4c74b1d)
#         ;
#
#
#
#
#             var marker_271763d8d4960519998d5cdaf8aec9e5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d3abd75b452f33727b723c9d544acee2);
#
#
#         var popup_00cfad29211919b25230bc22c9aa6aed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a1989ce54e6295ce216fb9a01cdd5c0 = $(`&lt;div id=&quot;html_8a1989ce54e6295ce216fb9a01cdd5c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_00cfad29211919b25230bc22c9aa6aed.setContent(html_8a1989ce54e6295ce216fb9a01cdd5c0);
#
#
#
#         marker_271763d8d4960519998d5cdaf8aec9e5.bindPopup(popup_00cfad29211919b25230bc22c9aa6aed)
#         ;
#
#
#
#
#             var marker_943f5112e7ba64b93295ba2716da2bce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d3abd75b452f33727b723c9d544acee2);
#
#
#         var popup_9cf568ee4c3a714c63cca1602ffac89c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6141988e308d3e04912033bf64330d4 = $(`&lt;div id=&quot;html_b6141988e308d3e04912033bf64330d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9cf568ee4c3a714c63cca1602ffac89c.setContent(html_b6141988e308d3e04912033bf64330d4);
#
#
#
#         marker_943f5112e7ba64b93295ba2716da2bce.bindPopup(popup_9cf568ee4c3a714c63cca1602ffac89c)
#         ;
#
#
#
#
#             var marker_7a0be6ab8c784d4c83f2e6903094eb21 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d3abd75b452f33727b723c9d544acee2);
#
#
#         var popup_2183c28903d78485288a3a68c396a893 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd15b44efa57d99aa7a66e1da7fc195a = $(`&lt;div id=&quot;html_cd15b44efa57d99aa7a66e1da7fc195a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2183c28903d78485288a3a68c396a893.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_78df1e2509752f39504345cface7e1f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_78df1e2509752f39504345cface7e1f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_78df1e2509752f39504345cface7e1f4 = L.map(
#                 &quot;map_78df1e2509752f39504345cface7e1f4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d0603bd5a0377759c0f55746ac927cd3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d0603bd5a0377759c0f55746ac927cd3.addTo(map_78df1e2509752f39504345cface7e1f4);
#
#
#             var feature_group_692db41d4ba0b45a7a87d24d93401ef9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_868315b841862ada2941b9e2553de284 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_692db41d4ba0b45a7a87d24d93401ef9);
#
#
#         var popup_dea93746078b66757a93c45183e2b0c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64d2d517ee4571b5dacb721fa383c202 = $(`&lt;div id=&quot;html_64d2d517ee4571b5dacb721fa383c202&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dea93746078b66757a93c45183e2b0c0.setContent(html_64d2d517ee4571b5dacb721fa383c202);
#
#
#
#         marker_868315b841862ada2941b9e2553de284.bindPopup(popup_dea93746078b66757a93c45183e2b0c0)
#         ;
#
#
#
#
#             var marker_d36c530e95546796e6a58425b9f1e5c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_692db41d4ba0b45a7a87d24d93401ef9);
#
#
#         var popup_aeb5b7460825b8b997677554fb463bff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cfdc2ca63b1718b98a7ca3bae32133d = $(`&lt;div id=&quot;html_8cfdc2ca63b1718b98a7ca3bae32133d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_aeb5b7460825b8b997677554fb463bff.setContent(html_8cfdc2ca63b1718b98a7ca3bae32133d);
#
#
#
#         marker_d36c530e95546796e6a58425b9f1e5c4.bindPopup(popup_aeb5b7460825b8b997677554fb463bff)
#         ;
#
#
#
#
#             var marker_613de1b0a41dd5b7521d8986c3e68adb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_692db41d4ba0b45a7a87d24d93401ef9);
#
#
#         var popup_a3698571f22449ecb2135c9c936bbc29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d7a2467f67761aa4bf301dad7f41a00 = $(`&lt;div id=&quot;html_2d7a2467f67761aa4bf301dad7f41a00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a3698571f22449ecb2135c9c936bbc29.setContent(html_2d7a2467f67761aa4bf301dad7f41a00);
#
#
#
#         marker_613de1b0a41dd5b7521d8986c3e68adb.bindPopup(popup_a3698571f22449ecb2135c9c936bbc29)
#         ;
#
#
#
#
#             var marker_0a0828d098f610330b1965dd7362aab3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_692db41d4ba0b45a7a87d24d93401ef9);
#
#
#         var popup_b2fa43943ef74bcfafa2187d5a38235a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d2ef97c43ed9583140cccfac539a538 = $(`&lt;div id=&quot;html_4d2ef97c43ed9583140cccfac539a538&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b2fa43943ef74bcfafa2187d5a38235a.setContent(html_4d2ef97c43ed9583140cccfac539a538);
#
#
#
#         marker_0a0828d098f610330b1965dd7362aab3.bindPopup(popup_b2fa43943ef74bcfafa2187d5a38235a)
#         ;
#
#
#
#
#             var marker_ad63c12214d5f624723debfc815a1da7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_692db41d4ba0b45a7a87d24d93401ef9);
#
#
#         var popup_cdec40b98a5b595f0008b824ce88ea11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce043e70f8d54ab0b956ceb907f89bfa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce043e70f8d54ab0b956ceb907f89bfa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce043e70f8d54ab0b956ceb907f89bfa = L.map(
#                 &quot;map_ce043e70f8d54ab0b956ceb907f89bfa&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55b35b06479d1f106a2c2a521dad599d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_55b35b06479d1f106a2c2a521dad599d.addTo(map_ce043e70f8d54ab0b956ceb907f89bfa);
#
#
#             var feature_group_6e32048d26d71f68b3b8766988b7f2c5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6e32048d26d71f68b3b8766988b7f2c5.addTo(map_ce043e70f8d54ab0b956ceb907f89bfa);
#
#
#             var feature_group_sub_group_04fb76822d870e86b63572b5ed4e4979 = L.featureGroup.subGroup(
#                 feature_group_6e32048d26d71f68b3b8766988b7f2c5
#             );
#
#
#             var marker_426f6a5c1f8202abd1d5b0b299a9a675 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_04fb76822d870e86b63572b5ed4e4979);
#
#
#         var popup_049822a5c427d05f2c5db328438d9d30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d30daefed3077143117da014662e61a9 = $(`&lt;div id=&quot;html_d30daefed3077143117da014662e61a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_049822a5c427d05f2c5db328438d9d30.setContent(html_d30daefed3077143117da014662e61a9);
#
#
#
#         marker_426f6a5c1f8202abd1d5b0b299a9a675.bindPopup(popup_049822a5c427d05f2c5db328438d9d30)
#         ;
#
#
#
#
#             var marker_44d894ac67dfafe36f892158e5c986e4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_04fb76822d870e86b63572b5ed4e4979);
#
#
#         var popup_c9e344f5122e7092d38f4a2683ba40d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_310237aa0a4cf6945f285bc0631fbc68 = $(`&lt;div id=&quot;html_310237aa0a4cf6945f285bc0631fbc68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c9e344f5122e7092d38f4a2683ba40d0.setContent(html_310237aa0a4cf6945f285bc0631fbc68);
#
#
#
#         marker_44d894ac67dfafe36f892158e5c986e4.bindPopup(popup_c9e344f5122e7092d38f4a2683ba40d0)
#         ;
#
#
#
#
#             var marker_98b5aa1f937d1e164066a119c7a3e3cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_04fb76822d870e86b63572b5ed4e4979);
#
#
#         var popup_af4d1fc4a5352a354461cbf48b7261c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bcae8ea0c04b3feae6155963cb8dd69 = $(`&lt;div id=&quot;html_8bcae8ea0c04b3feae6155963cb8dd69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_af4d1fc4a5352a354461cbf48b7261c3.setContent(html_8bcae8ea0c04b3feae6155963cb8dd69);
#
#
#
#         marker_98b5aa1f937d1e164066a119c7a3e3cf.bindPopup(popup_af4d1fc4a5352a354461cbf48b7261c3)
#         ;
#
#
#
#
#             var marker_8b1c9da7b14d4a4c1f0e2f5244c46f41 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_04fb76822d870e86b63572b5ed4e4979);
#
#
#         var popup_1a8aaa53ff1836f2f041dfbd94fff42f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65c842bb6a468c87a146f305c69825e8 = $(`&lt;div id=&quot;html_65c842bb6a468c87a146f305c69825e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1a8aaa53ff1836f2f041dfbd94fff42f.setContent(html_65c842bb6a468c87a146f305c69825e8);
#
#
#
#         marker_
