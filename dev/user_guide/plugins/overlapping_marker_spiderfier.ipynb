# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6508732368b42651fd33dd9feefb3153 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6508732368b42651fd33dd9feefb3153&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6508732368b42651fd33dd9feefb3153 = L.map(
#                 &quot;map_6508732368b42651fd33dd9feefb3153&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a4d57e7aad1b1ce9ed35b8f1cefec472 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a4d57e7aad1b1ce9ed35b8f1cefec472.addTo(map_6508732368b42651fd33dd9feefb3153);
#
#
#             var marker_264a77bbba84774e153f8ffaaaec27d7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6508732368b42651fd33dd9feefb3153);
#
#
#         var popup_a13706cb1e50a1eade352fc0c858deff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60034e9027d5f5984eb0184dcd4549f6 = $(`&lt;div id=&quot;html_60034e9027d5f5984eb0184dcd4549f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a13706cb1e50a1eade352fc0c858deff.setContent(html_60034e9027d5f5984eb0184dcd4549f6);
#
#
#
#         marker_264a77bbba84774e153f8ffaaaec27d7.bindPopup(popup_a13706cb1e50a1eade352fc0c858deff)
#         ;
#
#
#
#
#             var marker_9623f975dbd6e9989e7a97c6971ed1c3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6508732368b42651fd33dd9feefb3153);
#
#
#         var popup_31cfa09a0cef352ee353743ea3570e42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c9c5cce9756374e3dd489142c3c395b = $(`&lt;div id=&quot;html_6c9c5cce9756374e3dd489142c3c395b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_31cfa09a0cef352ee353743ea3570e42.setContent(html_6c9c5cce9756374e3dd489142c3c395b);
#
#
#
#         marker_9623f975dbd6e9989e7a97c6971ed1c3.bindPopup(popup_31cfa09a0cef352ee353743ea3570e42)
#         ;
#
#
#
#
#             var marker_b987484857be416eaecb4c160d500286 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6508732368b42651fd33dd9feefb3153);
#
#
#         var popup_692f8071dcfce8c31f0a6021f06b01d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57151ccca99034a05f189c6f3e6a1960 = $(`&lt;div id=&quot;html_57151ccca99034a05f189c6f3e6a1960&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_692f8071dcfce8c31f0a6021f06b01d0.setContent(html_57151ccca99034a05f189c6f3e6a1960);
#
#
#
#         marker_b987484857be416eaecb4c160d500286.bindPopup(popup_692f8071dcfce8c31f0a6021f06b01d0)
#         ;
#
#
#
#
#             var marker_81d1bae18d20cf069e7a7dbb3227ff18 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6508732368b42651fd33dd9feefb3153);
#
#
#         var popup_9e070ca3bc360bf7e40d308e6928648a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07730069e569f103fe25e989512e3c0d = $(`&lt;div id=&quot;html_07730069e569f103fe25e989512e3c0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9e070ca3bc360bf7e40d308e6928648a.setContent(html_07730069e569f103fe25e989512e3c0d);
#
#
#
#         marker_81d1bae18d20cf069e7a7dbb3227ff18.bindPopup(popup_9e070ca3bc360bf7e40d308e6928648a)
#         ;
#
#
#
#
#             var marker_ff9accf1604de0ccef18f1146b5c2b88 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6508732368b42651fd33dd9feefb3153);
#
#
#         var popup_b4b8a0f766d9d40c3d875bf859e2653e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10012ea4e1daeee3fe6982e63aa897fd = $(`&lt;div id=&quot;html_10012ea4e1daeee3fe6982e63aa897fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b4b8a0f766d9d40c3d875bf859e2653e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bdddfb1416d2971f5b3d9e1c7cb628d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bdddfb1416d2971f5b3d9e1c7cb628d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bdddfb1416d2971f5b3d9e1c7cb628d8 = L.map(
#                 &quot;map_bdddfb1416d2971f5b3d9e1c7cb628d8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9a6a00a7f3588b5795f365f638e5405 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b9a6a00a7f3588b5795f365f638e5405.addTo(map_bdddfb1416d2971f5b3d9e1c7cb628d8);
#
#
#             var feature_group_fc36461cd08c5f5db038bbfc52d92dd5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2d4ebf88a780811c80b90fc9b936718a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fc36461cd08c5f5db038bbfc52d92dd5);
#
#
#         var popup_243f699625ce521d1f426c1ff76b296b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8b0c56ab70cd4ce9980bf18128e5ba0 = $(`&lt;div id=&quot;html_b8b0c56ab70cd4ce9980bf18128e5ba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_243f699625ce521d1f426c1ff76b296b.setContent(html_b8b0c56ab70cd4ce9980bf18128e5ba0);
#
#
#
#         marker_2d4ebf88a780811c80b90fc9b936718a.bindPopup(popup_243f699625ce521d1f426c1ff76b296b)
#         ;
#
#
#
#
#             var marker_2b0f947e18810366e72339b19a46d6f0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fc36461cd08c5f5db038bbfc52d92dd5);
#
#
#         var popup_24253564e73adc1dd9ce8b5376bea9eb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40e8503339f857d139e0a13283914091 = $(`&lt;div id=&quot;html_40e8503339f857d139e0a13283914091&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_24253564e73adc1dd9ce8b5376bea9eb.setContent(html_40e8503339f857d139e0a13283914091);
#
#
#
#         marker_2b0f947e18810366e72339b19a46d6f0.bindPopup(popup_24253564e73adc1dd9ce8b5376bea9eb)
#         ;
#
#
#
#
#             var marker_369be52d6a4d418aa740a7bea5855768 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fc36461cd08c5f5db038bbfc52d92dd5);
#
#
#         var popup_00a513ff2b2b541f7178a88ddce66d69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2f6549ea10335c47f7b67b15133a84c = $(`&lt;div id=&quot;html_c2f6549ea10335c47f7b67b15133a84c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_00a513ff2b2b541f7178a88ddce66d69.setContent(html_c2f6549ea10335c47f7b67b15133a84c);
#
#
#
#         marker_369be52d6a4d418aa740a7bea5855768.bindPopup(popup_00a513ff2b2b541f7178a88ddce66d69)
#         ;
#
#
#
#
#             var marker_b6e3711d977a0b56c4e96c5735e9a602 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fc36461cd08c5f5db038bbfc52d92dd5);
#
#
#         var popup_4d973378755c834e1eb11798a1e60c4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7b97cb69a3a97477bfed96f7766ebf9 = $(`&lt;div id=&quot;html_d7b97cb69a3a97477bfed96f7766ebf9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4d973378755c834e1eb11798a1e60c4b.setContent(html_d7b97cb69a3a97477bfed96f7766ebf9);
#
#
#
#         marker_b6e3711d977a0b56c4e96c5735e9a602.bindPopup(popup_4d973378755c834e1eb11798a1e60c4b)
#         ;
#
#
#
#
#             var marker_8057074c1c47d5b2383cb603b260ed05 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fc36461cd08c5f5db038bbfc52d92dd5);
#
#
#         var popup_03426a33663ecf66e6a1297b5e585777 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3f09e2cc399250a7f4ee8a7777018924 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3f09e2cc399250a7f4ee8a7777018924&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3f09e2cc399250a7f4ee8a7777018924 = L.map(
#                 &quot;map_3f09e2cc399250a7f4ee8a7777018924&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9082c4504283a84ac4f44eca346f9e8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b9082c4504283a84ac4f44eca346f9e8.addTo(map_3f09e2cc399250a7f4ee8a7777018924);
#
#
#             var feature_group_37a58f4d4d0618e9a4f898a71bc50dca = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_37a58f4d4d0618e9a4f898a71bc50dca.addTo(map_3f09e2cc399250a7f4ee8a7777018924);
#
#
#             var feature_group_sub_group_9eceee9693c012d4b2ddc44598692f3d = L.featureGroup.subGroup(
#                 feature_group_37a58f4d4d0618e9a4f898a71bc50dca
#             );
#
#
#             var marker_f61b52482c36227cb8b549f73911ab81 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9eceee9693c012d4b2ddc44598692f3d);
#
#
#         var popup_34b70203e55fc4dea3beef446a14245d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a91d519843b9ed5cbef634ee2392624 = $(`&lt;div id=&quot;html_3a91d519843b9ed5cbef634ee2392624&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_34b70203e55fc4dea3beef446a14245d.setContent(html_3a91d519843b9ed5cbef634ee2392624);
#
#
#
#         marker_f61b52482c36227cb8b549f73911ab81.bindPopup(popup_34b70203e55fc4dea3beef446a14245d)
#         ;
#
#
#
#
#             var marker_2035b4d6e79fb64432d00287a9b01559 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9eceee9693c012d4b2ddc44598692f3d);
#
#
#         var popup_fff548cc9c8cf381dc32046236abcaa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ccffe3f5dd8f2a5f1fc1ceefe34b8c4 = $(`&lt;div id=&quot;html_4ccffe3f5dd8f2a5f1fc1ceefe34b8c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fff548cc9c8cf381dc32046236abcaa4.setContent(html_4ccffe3f5dd8f2a5f1fc1ceefe34b8c4);
#
#
#
#         marker_2035b4d6e79fb64432d00287a9b01559.bindPopup(popup_fff548cc9c8cf381dc32046236abcaa4)
#         ;
#
#
#
#
#             var marker_a46df091996d740f7a97e7111caf52b2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9eceee9693c012d4b2ddc44598692f3d);
#
#
#         var popup_76e1d44fde8550885685e48763ebbb76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed504f253d929cf0c6519c8a93302efe = $(`&lt;div id=&quot;html_ed504f253d929cf0c6519c8a93302efe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_76e1d44fde8550885685e48763ebbb76.setContent(html_ed504f253d929cf0c6519c8a93302efe);
#
#
#
#         marker_a46df091996d740f7a97e7111caf52b2.bindPopup(popup_76e1d44fde8550885685e48763ebbb76)
#         ;
#
#
#
#
#             var marker_ec9e153ecf53309ae637d4749b676099 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9eceee9693c012d4b2ddc44598692f3d);
#
#
#         var popup_dd397c2500a7e0d6a42f20002aae901d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e9bdc118ec45cc7d0f066b3722c17f9 = $(`&lt;div id=&quot;html_8e9bdc118ec45cc7d0f066b3722c17f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_dd397c2500a7e0d6a42f20002aae901d.setContent(html_8e9bdc118ec45cc7d0f066b3722c17f9);
#
#
#
#         marker_
