# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e3653dfead8a3e97d2721c2a1fe6bd9a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e3653dfead8a3e97d2721c2a1fe6bd9a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e3653dfead8a3e97d2721c2a1fe6bd9a = L.map(
#                 &quot;map_e3653dfead8a3e97d2721c2a1fe6bd9a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fd73572d8237ccecd60cf0e0fa5e8ec5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fd73572d8237ccecd60cf0e0fa5e8ec5.addTo(map_e3653dfead8a3e97d2721c2a1fe6bd9a);
#
#
#             var marker_7ad586c256105a5ed9f00ddf3da9804a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e3653dfead8a3e97d2721c2a1fe6bd9a);
#
#
#         var popup_ebd5540260ec19f4a23d1f41101e6476 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54b6ea6d612aa0bbaa505d18b5a022cb = $(`&lt;div id=&quot;html_54b6ea6d612aa0bbaa505d18b5a022cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ebd5540260ec19f4a23d1f41101e6476.setContent(html_54b6ea6d612aa0bbaa505d18b5a022cb);
#
#
#
#         marker_7ad586c256105a5ed9f00ddf3da9804a.bindPopup(popup_ebd5540260ec19f4a23d1f41101e6476)
#         ;
#
#
#
#
#             var marker_02b51071b96f4bf32c9286a0ae909ae1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e3653dfead8a3e97d2721c2a1fe6bd9a);
#
#
#         var popup_e3ea471c95da72f28cdc13e16cd1aa8a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1754d3f5f597e8bc242ce2c22b2c3c3c = $(`&lt;div id=&quot;html_1754d3f5f597e8bc242ce2c22b2c3c3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e3ea471c95da72f28cdc13e16cd1aa8a.setContent(html_1754d3f5f597e8bc242ce2c22b2c3c3c);
#
#
#
#         marker_02b51071b96f4bf32c9286a0ae909ae1.bindPopup(popup_e3ea471c95da72f28cdc13e16cd1aa8a)
#         ;
#
#
#
#
#             var marker_7c252581bcfae8f3b26e4dbe85afe9e1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e3653dfead8a3e97d2721c2a1fe6bd9a);
#
#
#         var popup_ba5f02f7d08b20f169c96505bc9380ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf94cb0d7c64ec6f10be62987f14e8e9 = $(`&lt;div id=&quot;html_cf94cb0d7c64ec6f10be62987f14e8e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ba5f02f7d08b20f169c96505bc9380ec.setContent(html_cf94cb0d7c64ec6f10be62987f14e8e9);
#
#
#
#         marker_7c252581bcfae8f3b26e4dbe85afe9e1.bindPopup(popup_ba5f02f7d08b20f169c96505bc9380ec)
#         ;
#
#
#
#
#             var marker_7cbc616e19ef51cdbf06e6a12bb1b979 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e3653dfead8a3e97d2721c2a1fe6bd9a);
#
#
#         var popup_5eca7da7f31b44b84e406f26048390c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be1b4b00fb35e35c02f8da5e1f1629f0 = $(`&lt;div id=&quot;html_be1b4b00fb35e35c02f8da5e1f1629f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5eca7da7f31b44b84e406f26048390c5.setContent(html_be1b4b00fb35e35c02f8da5e1f1629f0);
#
#
#
#         marker_7cbc616e19ef51cdbf06e6a12bb1b979.bindPopup(popup_5eca7da7f31b44b84e406f26048390c5)
#         ;
#
#
#
#
#             var marker_1990657dcf61f5aadf390bda0aadce41 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e3653dfead8a3e97d2721c2a1fe6bd9a);
#
#
#         var popup_6c6331b248c9eb11c022a064e5744d49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef1c3ca66de96275fe9a061e801f1d88 = $(`&lt;div id=&quot;html_ef1c3ca66de96275fe9a061e801f1d88&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6c6331b248c9eb11c022a064e5744d49.setContent(html_ef1c3ca66de96275fe9a061e801f1d88);
#
#
#
#         marker_1990657dcf61f5aadf390bda0aadce41.bindPopup(popup_6c6331b248c9eb11c022a064e5744d49)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18c42136fe267dc6b342bb27eef73020 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18c42136fe267dc6b342bb27eef73020&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18c42136fe267dc6b342bb27eef73020 = L.map(
#                 &quot;map_18c42136fe267dc6b342bb27eef73020&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_059508133f5fcd6923c5853f98997a65 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_059508133f5fcd6923c5853f98997a65.addTo(map_18c42136fe267dc6b342bb27eef73020);
#
#
#             var feature_group_b62bb9aeb89ef5b52f2761686c502ebc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_392ea9dd49ddf22c4a90bc143bbb5c69 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b62bb9aeb89ef5b52f2761686c502ebc);
#
#
#         var popup_395b3c99fe771d8dbfe3ed5bfb612d3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f875841a2d1499c13461b31cbd8c818e = $(`&lt;div id=&quot;html_f875841a2d1499c13461b31cbd8c818e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_395b3c99fe771d8dbfe3ed5bfb612d3f.setContent(html_f875841a2d1499c13461b31cbd8c818e);
#
#
#
#         marker_392ea9dd49ddf22c4a90bc143bbb5c69.bindPopup(popup_395b3c99fe771d8dbfe3ed5bfb612d3f)
#         ;
#
#
#
#
#             var marker_c022fc4c8b64e9f9cf274279b569447b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b62bb9aeb89ef5b52f2761686c502ebc);
#
#
#         var popup_75f98dadb949c22664908abf4233df34 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2b12094ae01b236ee0b22ba470f77df = $(`&lt;div id=&quot;html_b2b12094ae01b236ee0b22ba470f77df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_75f98dadb949c22664908abf4233df34.setContent(html_b2b12094ae01b236ee0b22ba470f77df);
#
#
#
#         marker_c022fc4c8b64e9f9cf274279b569447b.bindPopup(popup_75f98dadb949c22664908abf4233df34)
#         ;
#
#
#
#
#             var marker_eead0f99062d4e28c93242ba4b91288c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b62bb9aeb89ef5b52f2761686c502ebc);
#
#
#         var popup_ca548a6e49a3b0428a2830734d5bee5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bfe68bed8725d5767d16d5322355e12 = $(`&lt;div id=&quot;html_7bfe68bed8725d5767d16d5322355e12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ca548a6e49a3b0428a2830734d5bee5f.setContent(html_7bfe68bed8725d5767d16d5322355e12);
#
#
#
#         marker_eead0f99062d4e28c93242ba4b91288c.bindPopup(popup_ca548a6e49a3b0428a2830734d5bee5f)
#         ;
#
#
#
#
#             var marker_efbc5adab0c7b4f0f1fce5519431eb51 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b62bb9aeb89ef5b52f2761686c502ebc);
#
#
#         var popup_f4ac5b4f8cc5d1938a0ccb3e644e6613 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_165a64e08a5e748b1dc454645549bd6c = $(`&lt;div id=&quot;html_165a64e08a5e748b1dc454645549bd6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f4ac5b4f8cc5d1938a0ccb3e644e6613.setContent(html_165a64e08a5e748b1dc454645549bd6c);
#
#
#
#         marker_efbc5adab0c7b4f0f1fce5519431eb51.bindPopup(popup_f4ac5b4f8cc5d1938a0ccb3e644e6613)
#         ;
#
#
#
#
#             var marker_195f00e48bed7321ddfc7b7c769bc163 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b62bb9aeb89ef5b52f2761686c502ebc);
#
#
#         var popup_9e81dea822a07d9a86cf03ee4e9bf04d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a14b7c3130b60c41aa59a8ccf80ea80b = $(`&lt;div id=&quot;html_a14b7c3130b60c41aa59a8ccf80ea80b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_585505dd77c441060891948002211d27 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_585505dd77c441060891948002211d27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_585505dd77c441060891948002211d27 = L.map(
#                 &quot;map_585505dd77c441060891948002211d27&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36c5e463e181538d0b096ed60a9050bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36c5e463e181538d0b096ed60a9050bd.addTo(map_585505dd77c441060891948002211d27);
#
#
#             var feature_group_d23a6611f2d2fcd3c7ea78e8fe6f94a7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d23a6611f2d2fcd3c7ea78e8fe6f94a7.addTo(map_585505dd77c441060891948002211d27);
#
#
#             var feature_group_sub_group_13cdba6fd334bd04197278680b4d04fb = L.featureGroup.subGroup(
#                 feature_group_d23a6611f2d2fcd3c7ea78e8fe6f94a7
#             );
#
#
#             var marker_de19bb6d2bcddd28bcc27e9134040768 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_13cdba6fd334bd04197278680b4d04fb);
#
#
#         var popup_452aa64b99ad123689875dcf7c13b5a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b24a47377897e87aefc90466c47619c7 = $(`&lt;div id=&quot;html_b24a47377897e87aefc90466c47619c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_452aa64b99ad123689875dcf7c13b5a5.setContent(html_b24a47377897e87aefc90466c47619c7);
#
#
#
#         marker_de19bb6d2bcddd28bcc27e9134040768.bindPopup(popup_452aa64b99ad123689875dcf7c13b5a5)
#         ;
#
#
#
#
#             var marker_2e7685f39f420d07d161caf0b8021811 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_13cdba6fd334bd04197278680b4d04fb);
#
#
#         var popup_cdd0043f36e94939eeff4fd0c09fb3a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5a828fa29b8a61413a51ac9f308ac61 = $(`&lt;div id=&quot;html_d5a828fa29b8a61413a51ac9f308ac61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cdd0043f36e94939eeff4fd0c09fb3a5.setContent(html_d5a828fa29b8a61413a51ac9f308ac61);
#
#
#
#         marker_2e7685f39f420d07d161caf0b8021811.bindPopup(popup_cdd0043f36e94939eeff4fd0c09fb3a5)
#         ;
#
#
#
#
#             var marker_b411d1d5248e08bdfac7532984dc2e82 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_13cdba6fd334bd04197278680b4d04fb);
#
#
#         var popup_43386049249b96ca8268fee3e4c9d970 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d82137945c3f4a03d6b6c550dcb5bcc2 = $(`&lt;div id=&quot;html_d82137945c3f4a03d6b6c550dcb5bcc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_43386049249b96ca8268fee3e4c9d970.setContent(html_d82137945c3f4a03d6b6c550dcb5bcc2);
#
#
#
#         marker_b411d1d5248e08bdfac7532984dc2e82.bindPopup(popup_43386049249b96ca8268fee3e4c9d970)
#         ;
#
#
#
#
#             var marker_c08d9c99fe2b27ff8f34493bea8d761c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_13cdba6fd334bd04197278680b4d04fb);
#
#
#         var popup_9b522dab91a3f395510fdcea377d83e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_501abd45908d3a4d7bbed8e094476bed = $(`&lt;div id=&quot;html_501abd45908d3a4d7bbed8e094476bed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9b522dab91a3f395510fdcea377d83e6.setContent(html_501abd45908d3a4d7bbed8e094476bed);
#
#
#
#         marker_c08d9c99fe2b27ff8f34493bea8d761c.bindPopup(popup_9b522dab91a3f395510fdcea377d83e6)
#         ;
#
#
#
#
#             var marker_99ae9b2edd69e256665ce3013cd9c5f4 = L.marker(
#                 [45.0503999
