# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c97ab96d87b14a57d7a49325eb8a6a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c97ab96d87b14a57d7a49325eb8a6a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c97ab96d87b14a57d7a49325eb8a6a4 = L.map(
#                 &quot;map_6c97ab96d87b14a57d7a49325eb8a6a4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bf88e6007d19b652883364a98a3be9fa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bf88e6007d19b652883364a98a3be9fa.addTo(map_6c97ab96d87b14a57d7a49325eb8a6a4);
#
#
#             var marker_de5f45233586117f317e946b5b46ef90 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6c97ab96d87b14a57d7a49325eb8a6a4);
#
#
#         var popup_3e924dc3d3b6ea1d2f04fb7a6e75c2ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fa4e6ccaa8b59318c63a2f9dc01def2 = $(`&lt;div id=&quot;html_5fa4e6ccaa8b59318c63a2f9dc01def2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3e924dc3d3b6ea1d2f04fb7a6e75c2ba.setContent(html_5fa4e6ccaa8b59318c63a2f9dc01def2);
#
#
#
#         marker_de5f45233586117f317e946b5b46ef90.bindPopup(popup_3e924dc3d3b6ea1d2f04fb7a6e75c2ba)
#         ;
#
#
#
#
#             var marker_435ecf871bcc15906e14320fdd5bffc7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6c97ab96d87b14a57d7a49325eb8a6a4);
#
#
#         var popup_ade9229ce4f49a3eb047d2e9d3ce1414 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a207e658170d308eb34807cec3f0dc7b = $(`&lt;div id=&quot;html_a207e658170d308eb34807cec3f0dc7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ade9229ce4f49a3eb047d2e9d3ce1414.setContent(html_a207e658170d308eb34807cec3f0dc7b);
#
#
#
#         marker_435ecf871bcc15906e14320fdd5bffc7.bindPopup(popup_ade9229ce4f49a3eb047d2e9d3ce1414)
#         ;
#
#
#
#
#             var marker_01a40b8efeb8e986944c10e1b25e06be = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6c97ab96d87b14a57d7a49325eb8a6a4);
#
#
#         var popup_25607e28395180ce187540260bc2dc32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e5df2e03d6a76a6735002dbdcc4f878 = $(`&lt;div id=&quot;html_5e5df2e03d6a76a6735002dbdcc4f878&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_25607e28395180ce187540260bc2dc32.setContent(html_5e5df2e03d6a76a6735002dbdcc4f878);
#
#
#
#         marker_01a40b8efeb8e986944c10e1b25e06be.bindPopup(popup_25607e28395180ce187540260bc2dc32)
#         ;
#
#
#
#
#             var marker_d65322b6f841260285fb5f3ece35b193 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6c97ab96d87b14a57d7a49325eb8a6a4);
#
#
#         var popup_7dc8fb8d007b9706c31560d8ee25cb82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d23803a58727691392cf9714258917bc = $(`&lt;div id=&quot;html_d23803a58727691392cf9714258917bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7dc8fb8d007b9706c31560d8ee25cb82.setContent(html_d23803a58727691392cf9714258917bc);
#
#
#
#         marker_d65322b6f841260285fb5f3ece35b193.bindPopup(popup_7dc8fb8d007b9706c31560d8ee25cb82)
#         ;
#
#
#
#
#             var marker_d4f194b88a00f44797a34dda9ec5c78c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6c97ab96d87b14a57d7a49325eb8a6a4);
#
#
#         var popup_283b24ce7a5d366fe5f30b08dfa01af9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76c4cd934166f6c9ac03b49254b0fc42 = $(`&lt;div id=&quot;html_76c4cd934166f6c9ac03b49254b0fc42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_283b24ce7a5d366fe5f30b08dfa01af9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_768b53460e9ce7491d6930b0edf0d1eb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_768b53460e9ce7491d6930b0edf0d1eb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_768b53460e9ce7491d6930b0edf0d1eb = L.map(
#                 &quot;map_768b53460e9ce7491d6930b0edf0d1eb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8daf14e869457e1cb7314f60675ad074 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8daf14e869457e1cb7314f60675ad074.addTo(map_768b53460e9ce7491d6930b0edf0d1eb);
#
#
#             var feature_group_471a26b9bb65757eb90e9fd0b28b884e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4984e826fe8c055dfa3d90afa140d198 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_471a26b9bb65757eb90e9fd0b28b884e);
#
#
#         var popup_3bd376641b85fcca0124b7c96477f9b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a26647e4e64b5feb37a0ee3f0fe6d4ff = $(`&lt;div id=&quot;html_a26647e4e64b5feb37a0ee3f0fe6d4ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3bd376641b85fcca0124b7c96477f9b7.setContent(html_a26647e4e64b5feb37a0ee3f0fe6d4ff);
#
#
#
#         marker_4984e826fe8c055dfa3d90afa140d198.bindPopup(popup_3bd376641b85fcca0124b7c96477f9b7)
#         ;
#
#
#
#
#             var marker_d0e1c34ed3a9324c9cecc8e1c8b60f6c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_471a26b9bb65757eb90e9fd0b28b884e);
#
#
#         var popup_2db96b33614bbef53574ef37dc0640c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7f9310ae722f6df3836feabfa1e6775 = $(`&lt;div id=&quot;html_d7f9310ae722f6df3836feabfa1e6775&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2db96b33614bbef53574ef37dc0640c7.setContent(html_d7f9310ae722f6df3836feabfa1e6775);
#
#
#
#         marker_d0e1c34ed3a9324c9cecc8e1c8b60f6c.bindPopup(popup_2db96b33614bbef53574ef37dc0640c7)
#         ;
#
#
#
#
#             var marker_73e407c0c1080630226981ce0701bc89 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_471a26b9bb65757eb90e9fd0b28b884e);
#
#
#         var popup_6a79e43178a06ac08619e36557936248 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f66aabad98443551e088e98f0e720469 = $(`&lt;div id=&quot;html_f66aabad98443551e088e98f0e720469&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6a79e43178a06ac08619e36557936248.setContent(html_f66aabad98443551e088e98f0e720469);
#
#
#
#         marker_73e407c0c1080630226981ce0701bc89.bindPopup(popup_6a79e43178a06ac08619e36557936248)
#         ;
#
#
#
#
#             var marker_3515d25eee199a259a3141857d2dd64e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_471a26b9bb65757eb90e9fd0b28b884e);
#
#
#         var popup_6f01cece3f9179512c9b9dfa93f69bbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_184d3dd04983cb2ecd62d2392a3ce77d = $(`&lt;div id=&quot;html_184d3dd04983cb2ecd62d2392a3ce77d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6f01cece3f9179512c9b9dfa93f69bbc.setContent(html_184d3dd04983cb2ecd62d2392a3ce77d);
#
#
#
#         marker_3515d25eee199a259a3141857d2dd64e.bindPopup(popup_6f01cece3f9179512c9b9dfa93f69bbc)
#         ;
#
#
#
#
#             var marker_c5525829703bdce79a7708b940d6fd1c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_471a26b9bb65757eb90e9fd0b28b884e);
#
#
#         var popup_836758eb534b3274d6f8c60ee3d9fef1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d6f6867763b30247fbf99cf13a101fce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d6f6867763b30247fbf99cf13a101fce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d6f6867763b30247fbf99cf13a101fce = L.map(
#                 &quot;map_d6f6867763b30247fbf99cf13a101fce&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c1e90572903acc9c59edfba6b6515646 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c1e90572903acc9c59edfba6b6515646.addTo(map_d6f6867763b30247fbf99cf13a101fce);
#
#
#             var feature_group_aa00980fa123480059aa0e89dd49d936 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_aa00980fa123480059aa0e89dd49d936.addTo(map_d6f6867763b30247fbf99cf13a101fce);
#
#
#             var feature_group_sub_group_b993123dd6816306781e64b124f7b99a = L.featureGroup.subGroup(
#                 feature_group_aa00980fa123480059aa0e89dd49d936
#             );
#
#
#             var marker_1b610bfa10c91e9b16fff21d7024456f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b993123dd6816306781e64b124f7b99a);
#
#
#         var popup_508bfc8ca84f408e527a6fe50e9ad076 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37e1960d1dcd2d2477843221241712f3 = $(`&lt;div id=&quot;html_37e1960d1dcd2d2477843221241712f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_508bfc8ca84f408e527a6fe50e9ad076.setContent(html_37e1960d1dcd2d2477843221241712f3);
#
#
#
#         marker_1b610bfa10c91e9b16fff21d7024456f.bindPopup(popup_508bfc8ca84f408e527a6fe50e9ad076)
#         ;
#
#
#
#
#             var marker_6a5ddc833d3398e6b9df6ebdac8ae25c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b993123dd6816306781e64b124f7b99a);
#
#
#         var popup_06b3638df76f9f4f3b8168fcde9876b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_730de561beda2be17c04a6461c855ead = $(`&lt;div id=&quot;html_730de561beda2be17c04a6461c855ead&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_06b3638df76f9f4f3b8168fcde9876b6.setContent(html_730de561beda2be17c04a6461c855ead);
#
#
#
#         marker_6a5ddc833d3398e6b9df6ebdac8ae25c.bindPopup(popup_06b3638df76f9f4f3b8168fcde9876b6)
#         ;
#
#
#
#
#             var marker_fb730064172bac688da606403e622bda = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b993123dd6816306781e64b124f7b99a);
#
#
#         var popup_c53cda5289c4c36d2f03780ae0573b99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90a5d116ebe6c77946760c3272046d1c = $(`&lt;div id=&quot;html_90a5d116ebe6c77946760c3272046d1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c53cda5289c4c36d2f03780ae0573b99.setContent(html_90a5d116ebe6c77946760c3272046d1c);
#
#
#
#         marker_fb730064172bac688da606403e622bda.bindPopup(popup_c53cda5289c4c36d2f03780ae0573b99)
#         ;
#
#
#
#
#             var marker_77e2b0d8f1cf1c1b22b1d71cc54a2f19 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b993123dd6816306781e64b124f7b99a);
#
#
#         var popup_98e84fdc7f608c4b4ca42d714d7046b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b32483d41b71f864087b2ea368408faa = $(`&lt;div id=&quot;html_b32483d41b71f864087b2ea368408faa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_98e84fdc7f608c4b4ca42d714d7046b2.setContent(html_b32483d41b71f864087b2ea368408faa);
#
#
#
#         marker_
