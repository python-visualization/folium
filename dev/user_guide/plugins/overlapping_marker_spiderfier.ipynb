# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90bd2b4b004192c55590c60e229e40b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90bd2b4b004192c55590c60e229e40b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90bd2b4b004192c55590c60e229e40b8 = L.map(
#                 &quot;map_90bd2b4b004192c55590c60e229e40b8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_252f13830ff063b8fa31746b87aa027f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_252f13830ff063b8fa31746b87aa027f.addTo(map_90bd2b4b004192c55590c60e229e40b8);
#
#
#             var marker_c361e238ca3c0bd3c6a440f73872eef5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_90bd2b4b004192c55590c60e229e40b8);
#
#
#         var popup_4a21bbe24cd5a1e89a5418b1c58235fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72f406cb17cc8caa3ee687422197f074 = $(`&lt;div id=&quot;html_72f406cb17cc8caa3ee687422197f074&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4a21bbe24cd5a1e89a5418b1c58235fe.setContent(html_72f406cb17cc8caa3ee687422197f074);
#
#
#
#         marker_c361e238ca3c0bd3c6a440f73872eef5.bindPopup(popup_4a21bbe24cd5a1e89a5418b1c58235fe)
#         ;
#
#
#
#
#             var marker_ba1fd6793b4ebb171fd0ca87bc0a8e87 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_90bd2b4b004192c55590c60e229e40b8);
#
#
#         var popup_ecd088a1f48a0a2fd876c192d7f0c131 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8bda21c43329de281d1bb66820e41f3 = $(`&lt;div id=&quot;html_b8bda21c43329de281d1bb66820e41f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ecd088a1f48a0a2fd876c192d7f0c131.setContent(html_b8bda21c43329de281d1bb66820e41f3);
#
#
#
#         marker_ba1fd6793b4ebb171fd0ca87bc0a8e87.bindPopup(popup_ecd088a1f48a0a2fd876c192d7f0c131)
#         ;
#
#
#
#
#             var marker_2735d841527c94021fbb450af66a2a59 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_90bd2b4b004192c55590c60e229e40b8);
#
#
#         var popup_c61a9c35d1b23f34f04f883c156e41fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74185a0aec4f6276e1b9965423da2fee = $(`&lt;div id=&quot;html_74185a0aec4f6276e1b9965423da2fee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c61a9c35d1b23f34f04f883c156e41fa.setContent(html_74185a0aec4f6276e1b9965423da2fee);
#
#
#
#         marker_2735d841527c94021fbb450af66a2a59.bindPopup(popup_c61a9c35d1b23f34f04f883c156e41fa)
#         ;
#
#
#
#
#             var marker_8302df713e728f5bc3a9d38ad71d6302 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_90bd2b4b004192c55590c60e229e40b8);
#
#
#         var popup_9897534b7085c234600f647c4e5be476 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc1ea64a3fc0e6b2fc3dafc367c032d1 = $(`&lt;div id=&quot;html_fc1ea64a3fc0e6b2fc3dafc367c032d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9897534b7085c234600f647c4e5be476.setContent(html_fc1ea64a3fc0e6b2fc3dafc367c032d1);
#
#
#
#         marker_8302df713e728f5bc3a9d38ad71d6302.bindPopup(popup_9897534b7085c234600f647c4e5be476)
#         ;
#
#
#
#
#             var marker_47b787fcbbbb474287c0217cdd3ff456 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_90bd2b4b004192c55590c60e229e40b8);
#
#
#         var popup_002d08536f5465556d94226dc0f0e9f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c7fac2ab729e81b9f48c61a37e58c23 = $(`&lt;div id=&quot;html_6c7fac2ab729e81b9f48c61a37e58c23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_002d08536f5465556d94226dc0f0e9f5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_08adce2e7ed3c2e3fc979666af0993cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_08adce2e7ed3c2e3fc979666af0993cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_08adce2e7ed3c2e3fc979666af0993cb = L.map(
#                 &quot;map_08adce2e7ed3c2e3fc979666af0993cb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27e214b3bc4ad01a11ac6539b65a11c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27e214b3bc4ad01a11ac6539b65a11c8.addTo(map_08adce2e7ed3c2e3fc979666af0993cb);
#
#
#             var feature_group_e3579580cc068f03516bd70d0b3c0b21 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_07a8c8da35988c1e226d0392db077bce = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e3579580cc068f03516bd70d0b3c0b21);
#
#
#         var popup_0d08703ea7828ba573ab5d8b62f658f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04f9603fc883034e8e5cb358d4bc6879 = $(`&lt;div id=&quot;html_04f9603fc883034e8e5cb358d4bc6879&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0d08703ea7828ba573ab5d8b62f658f8.setContent(html_04f9603fc883034e8e5cb358d4bc6879);
#
#
#
#         marker_07a8c8da35988c1e226d0392db077bce.bindPopup(popup_0d08703ea7828ba573ab5d8b62f658f8)
#         ;
#
#
#
#
#             var marker_4fd8c957ef84d07d1c1461026b94dd26 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e3579580cc068f03516bd70d0b3c0b21);
#
#
#         var popup_2e28606eb4663c1b5d500485213e4eee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55687e230d4a450af9b89cab249a2546 = $(`&lt;div id=&quot;html_55687e230d4a450af9b89cab249a2546&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2e28606eb4663c1b5d500485213e4eee.setContent(html_55687e230d4a450af9b89cab249a2546);
#
#
#
#         marker_4fd8c957ef84d07d1c1461026b94dd26.bindPopup(popup_2e28606eb4663c1b5d500485213e4eee)
#         ;
#
#
#
#
#             var marker_33c212f9b6886b1d835e174cf84ee79c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e3579580cc068f03516bd70d0b3c0b21);
#
#
#         var popup_5d834583e67fed3d8fea7e7d6f9281cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d5f8b9187ee3c9f20331ccbc0388bd5 = $(`&lt;div id=&quot;html_8d5f8b9187ee3c9f20331ccbc0388bd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5d834583e67fed3d8fea7e7d6f9281cd.setContent(html_8d5f8b9187ee3c9f20331ccbc0388bd5);
#
#
#
#         marker_33c212f9b6886b1d835e174cf84ee79c.bindPopup(popup_5d834583e67fed3d8fea7e7d6f9281cd)
#         ;
#
#
#
#
#             var marker_77aa6696c593e7114d5a580009cbbc62 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e3579580cc068f03516bd70d0b3c0b21);
#
#
#         var popup_52f12d1df2f35d13b3b1d2fb4fedbfae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8731cbf14180f069f2e4095cbeb55cd2 = $(`&lt;div id=&quot;html_8731cbf14180f069f2e4095cbeb55cd2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_52f12d1df2f35d13b3b1d2fb4fedbfae.setContent(html_8731cbf14180f069f2e4095cbeb55cd2);
#
#
#
#         marker_77aa6696c593e7114d5a580009cbbc62.bindPopup(popup_52f12d1df2f35d13b3b1d2fb4fedbfae)
#         ;
#
#
#
#
#             var marker_ea54d73be9a872f48b850fde40db5781 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e3579580cc068f03516bd70d0b3c0b21);
#
#
#         var popup_eb2795e48c3d121a614125869e5da5f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4b172963dc6e12e5a4dcdd7188cc683f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4b172963dc6e12e5a4dcdd7188cc683f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4b172963dc6e12e5a4dcdd7188cc683f = L.map(
#                 &quot;map_4b172963dc6e12e5a4dcdd7188cc683f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cb417c2cd8eaf8e9ddc81ce667c44797 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cb417c2cd8eaf8e9ddc81ce667c44797.addTo(map_4b172963dc6e12e5a4dcdd7188cc683f);
#
#
#             var feature_group_c34185b09a16abce9a2b05795ba64a70 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c34185b09a16abce9a2b05795ba64a70.addTo(map_4b172963dc6e12e5a4dcdd7188cc683f);
#
#
#             var feature_group_sub_group_ba69b0b871c82e357f1b1ac0f1ad22e1 = L.featureGroup.subGroup(
#                 feature_group_c34185b09a16abce9a2b05795ba64a70
#             );
#
#
#             var marker_1ed8114b2cdfd791aa839fe8a39ac294 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba69b0b871c82e357f1b1ac0f1ad22e1);
#
#
#         var popup_42507d989712940cdddbc1f2536ef9a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_25763d45108d3dc6ba686bb825bb1807 = $(`&lt;div id=&quot;html_25763d45108d3dc6ba686bb825bb1807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_42507d989712940cdddbc1f2536ef9a4.setContent(html_25763d45108d3dc6ba686bb825bb1807);
#
#
#
#         marker_1ed8114b2cdfd791aa839fe8a39ac294.bindPopup(popup_42507d989712940cdddbc1f2536ef9a4)
#         ;
#
#
#
#
#             var marker_dfbee2b915bef637d119ce8701ea4254 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba69b0b871c82e357f1b1ac0f1ad22e1);
#
#
#         var popup_7ae75d1d179dd2def6aedc04caac9a17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94fc3d70f2390b22c378771e38681592 = $(`&lt;div id=&quot;html_94fc3d70f2390b22c378771e38681592&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7ae75d1d179dd2def6aedc04caac9a17.setContent(html_94fc3d70f2390b22c378771e38681592);
#
#
#
#         marker_dfbee2b915bef637d119ce8701ea4254.bindPopup(popup_7ae75d1d179dd2def6aedc04caac9a17)
#         ;
#
#
#
#
#             var marker_eed58a8c65bf79c1f8627dc55b9ae2f0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba69b0b871c82e357f1b1ac0f1ad22e1);
#
#
#         var popup_bcf52b9cfcf1dbfb2b191f28c0d009c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3d0047bc03cbbd0c7ba6cb475f868c5 = $(`&lt;div id=&quot;html_b3d0047bc03cbbd0c7ba6cb475f868c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bcf52b9cfcf1dbfb2b191f28c0d009c5.setContent(html_b3d0047bc03cbbd0c7ba6cb475f868c5);
#
#
#
#         marker_eed58a8c65bf79c1f8627dc55b9ae2f0.bindPopup(popup_bcf52b9cfcf1dbfb2b191f28c0d009c5)
#         ;
#
#
#
#
#             var marker_dc59bafc240ad4d906200079e510c7e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ba69b0b871c82e357f1b1ac0f1ad22e1);
#
#
#         var popup_f0e983089bb8c3bd936f2e78a77310e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46adfc0ca054bfd782b3249ebc69c2e1 = $(`&lt;div id=&quot;html_46adfc0ca054bfd782b3249ebc69c2e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f0e983089bb8c3bd936f2e78a77310e1.setContent(html_46adfc0ca054bfd782b3249ebc69c2e1);
#
#
#
#         marker_
