# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f55237e8092d5ef3915ab2040ca0dc0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f55237e8092d5ef3915ab2040ca0dc0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f55237e8092d5ef3915ab2040ca0dc0 = L.map(
#                 &quot;map_1f55237e8092d5ef3915ab2040ca0dc0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fab5cb5c1cfb679cc7fed2b151c6ef02 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fab5cb5c1cfb679cc7fed2b151c6ef02.addTo(map_1f55237e8092d5ef3915ab2040ca0dc0);
#
#
#             var marker_265f015ff55e0dddedc31e266799c22a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1f55237e8092d5ef3915ab2040ca0dc0);
#
#
#         var popup_43a0733949b0a8529320b9bfcec579c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_868276252cf5a268db188903730a2c6c = $(`&lt;div id=&quot;html_868276252cf5a268db188903730a2c6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_43a0733949b0a8529320b9bfcec579c5.setContent(html_868276252cf5a268db188903730a2c6c);
#
#
#
#         marker_265f015ff55e0dddedc31e266799c22a.bindPopup(popup_43a0733949b0a8529320b9bfcec579c5)
#         ;
#
#
#
#
#             var marker_a09d8c63777b6e2cd8a3d4ead587fea3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1f55237e8092d5ef3915ab2040ca0dc0);
#
#
#         var popup_2a3d299ef0c74ed1e00bba582e9731ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c8c288d2a510847465ed047494e976b = $(`&lt;div id=&quot;html_5c8c288d2a510847465ed047494e976b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2a3d299ef0c74ed1e00bba582e9731ee.setContent(html_5c8c288d2a510847465ed047494e976b);
#
#
#
#         marker_a09d8c63777b6e2cd8a3d4ead587fea3.bindPopup(popup_2a3d299ef0c74ed1e00bba582e9731ee)
#         ;
#
#
#
#
#             var marker_5ad9e6548a23cd6c9aaa9607b3f080ca = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1f55237e8092d5ef3915ab2040ca0dc0);
#
#
#         var popup_10eac6a5906c3f93535d34e91382f358 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e745d41662bb6fd647b2c4110ad6004 = $(`&lt;div id=&quot;html_1e745d41662bb6fd647b2c4110ad6004&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_10eac6a5906c3f93535d34e91382f358.setContent(html_1e745d41662bb6fd647b2c4110ad6004);
#
#
#
#         marker_5ad9e6548a23cd6c9aaa9607b3f080ca.bindPopup(popup_10eac6a5906c3f93535d34e91382f358)
#         ;
#
#
#
#
#             var marker_b3ccec49be418625a527ea00d65aef99 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1f55237e8092d5ef3915ab2040ca0dc0);
#
#
#         var popup_fc54f6547c447f40c96da701e6f66bd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02332eb5a4c7c52f13eef37395a73afd = $(`&lt;div id=&quot;html_02332eb5a4c7c52f13eef37395a73afd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fc54f6547c447f40c96da701e6f66bd1.setContent(html_02332eb5a4c7c52f13eef37395a73afd);
#
#
#
#         marker_b3ccec49be418625a527ea00d65aef99.bindPopup(popup_fc54f6547c447f40c96da701e6f66bd1)
#         ;
#
#
#
#
#             var marker_cf731733e2d8f8f5a9b2b19e552077d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1f55237e8092d5ef3915ab2040ca0dc0);
#
#
#         var popup_2d37418d97ee49d9eef58f78b929c399 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8b4f0441fd64561d61360d7efe058b1 = $(`&lt;div id=&quot;html_c8b4f0441fd64561d61360d7efe058b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2d37418d97ee49d9eef58f78b929c399.setContent(html_c8b4f0441fd64561d61360d7efe058b1);
#
#
#
#         marker_cf731733e2d8f8f5a9b2b19e552077d7.bindPopup(popup_2d37418d97ee49d9eef58f78b929c399)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7c1e029f39a66d5f97a177fcb1f07a35 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7c1e029f39a66d5f97a177fcb1f07a35&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7c1e029f39a66d5f97a177fcb1f07a35 = L.map(
#                 &quot;map_7c1e029f39a66d5f97a177fcb1f07a35&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec8189d6bf676f26e66c7ff626f8ccd4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec8189d6bf676f26e66c7ff626f8ccd4.addTo(map_7c1e029f39a66d5f97a177fcb1f07a35);
#
#
#             var feature_group_d9ae7c7a7804684ebdf2da7703d6a17e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f1c10acd2b9a6e833107e6f0974c7922 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d9ae7c7a7804684ebdf2da7703d6a17e);
#
#
#         var popup_cae4f6872e2dfe61693cb1e8af17cc22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1aaf3741fe68c46d131c475f5a38f78b = $(`&lt;div id=&quot;html_1aaf3741fe68c46d131c475f5a38f78b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cae4f6872e2dfe61693cb1e8af17cc22.setContent(html_1aaf3741fe68c46d131c475f5a38f78b);
#
#
#
#         marker_f1c10acd2b9a6e833107e6f0974c7922.bindPopup(popup_cae4f6872e2dfe61693cb1e8af17cc22)
#         ;
#
#
#
#
#             var marker_ed7ae1ae697458bbcb2ec8fc94db0d45 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d9ae7c7a7804684ebdf2da7703d6a17e);
#
#
#         var popup_3ef00659cda64a5f3940eb303a81ab5e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7933055b013c62bc782b804c91fd3038 = $(`&lt;div id=&quot;html_7933055b013c62bc782b804c91fd3038&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3ef00659cda64a5f3940eb303a81ab5e.setContent(html_7933055b013c62bc782b804c91fd3038);
#
#
#
#         marker_ed7ae1ae697458bbcb2ec8fc94db0d45.bindPopup(popup_3ef00659cda64a5f3940eb303a81ab5e)
#         ;
#
#
#
#
#             var marker_627ec776d7608fab02c9ee53e001dee8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d9ae7c7a7804684ebdf2da7703d6a17e);
#
#
#         var popup_252e97f0e0cb4ffdf886eae92bf01a60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cdaff1a172e9cab6421ddd4800ea6c2 = $(`&lt;div id=&quot;html_6cdaff1a172e9cab6421ddd4800ea6c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_252e97f0e0cb4ffdf886eae92bf01a60.setContent(html_6cdaff1a172e9cab6421ddd4800ea6c2);
#
#
#
#         marker_627ec776d7608fab02c9ee53e001dee8.bindPopup(popup_252e97f0e0cb4ffdf886eae92bf01a60)
#         ;
#
#
#
#
#             var marker_3cb7329370be057486652b25969934ec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d9ae7c7a7804684ebdf2da7703d6a17e);
#
#
#         var popup_91b09930647caa7152483c0b6cea924d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_035052426c7a92ebc9918b6073a74849 = $(`&lt;div id=&quot;html_035052426c7a92ebc9918b6073a74849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_91b09930647caa7152483c0b6cea924d.setContent(html_035052426c7a92ebc9918b6073a74849);
#
#
#
#         marker_3cb7329370be057486652b25969934ec.bindPopup(popup_91b09930647caa7152483c0b6cea924d)
#         ;
#
#
#
#
#             var marker_55b68855108c1985ea369c07cb13e4b4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d9ae7c7a7804684ebdf2da7703d6a17e);
#
#
#         var popup_2f68d73429745f5a267c60e9968b7ce5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fd62b357daaa49e383a8103719e5a2b = $(`&lt;div id=&quot;html_4fd62b357daaa49e383a8103719e5a2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffacb1a287bc074114894e65c4851737 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffacb1a287bc074114894e65c4851737&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffacb1a287bc074114894e65c4851737 = L.map(
#                 &quot;map_ffacb1a287bc074114894e65c4851737&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_766595b57caa9714fa6f687aa04ccb05 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_766595b57caa9714fa6f687aa04ccb05.addTo(map_ffacb1a287bc074114894e65c4851737);
#
#
#             var feature_group_c6ac6654eff27d295b3ddfe00c6e176a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c6ac6654eff27d295b3ddfe00c6e176a.addTo(map_ffacb1a287bc074114894e65c4851737);
#
#
#             var feature_group_sub_group_c0fdbd5b1277884281928022c53e3de6 = L.featureGroup.subGroup(
#                 feature_group_c6ac6654eff27d295b3ddfe00c6e176a
#             );
#
#
#             var marker_783258b8b3bca6dd127255c19bce4f1b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0fdbd5b1277884281928022c53e3de6);
#
#
#         var popup_6c5c7556ad18a272dd13f012b747793a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1d292367d6f5b1ebef1f3d63c64869d = $(`&lt;div id=&quot;html_a1d292367d6f5b1ebef1f3d63c64869d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_6c5c7556ad18a272dd13f012b747793a.setContent(html_a1d292367d6f5b1ebef1f3d63c64869d);
#
#
#
#         marker_783258b8b3bca6dd127255c19bce4f1b.bindPopup(popup_6c5c7556ad18a272dd13f012b747793a)
#         ;
#
#
#
#
#             var marker_703a60e8ef12c325f4eb0dae50e8b71f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0fdbd5b1277884281928022c53e3de6);
#
#
#         var popup_70390a84151ba07490e98143bace95ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5dc3c1bce5d73591ee8170369176af5 = $(`&lt;div id=&quot;html_a5dc3c1bce5d73591ee8170369176af5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_70390a84151ba07490e98143bace95ee.setContent(html_a5dc3c1bce5d73591ee8170369176af5);
#
#
#
#         marker_703a60e8ef12c325f4eb0dae50e8b71f.bindPopup(popup_70390a84151ba07490e98143bace95ee)
#         ;
#
#
#
#
#             var marker_a0474004f6e79e57a62da0ee0b386777 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0fdbd5b1277884281928022c53e3de6);
#
#
#         var popup_8a3421965cfbc18cea8b44c84d1eefb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77398a4dfc736cba8e3ab72075042506 = $(`&lt;div id=&quot;html_77398a4dfc736cba8e3ab72075042506&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8a3421965cfbc18cea8b44c84d1eefb2.setContent(html_77398a4dfc736cba8e3ab72075042506);
#
#
#
#         marker_a0474004f6e79e57a62da0ee0b386777.bindPopup(popup_8a3421965cfbc18cea8b44c84d1eefb2)
#         ;
#
#
#
#
#             var marker_b89c31c12e7b3f1aaa124c975061b1ef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c0fdbd5b1277884281928022c53e3de6);
#
#
#         var popup_36fbca78674d2ab982b8294ea57875f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca8fe2e3ab86fa40d958addd9d334951 = $(`&lt;div id=&quot;html_ca8fe2e3ab86fa40d958addd9d334951&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_36fbca78674d2ab982b8294ea57875f2.setContent(html_ca8fe2e3ab86fa40d958addd9d334951);
#
#
#
#         marker_b89c31c12e7b3f1aaa124c975061b1ef.bindPopup(popup_36fbca78674d2ab982b8294ea57875f2)
#         ;
#
#
#
#
#             var marker_f216e9217b733176c2ed344013412c07 = L.marker(
#                 [45.0503999
