# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63cac151d5d16162c2db8c9a65bab5c1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63cac151d5d16162c2db8c9a65bab5c1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63cac151d5d16162c2db8c9a65bab5c1 = L.map(
#                 &quot;map_63cac151d5d16162c2db8c9a65bab5c1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9dfbf9e8caaffaa31bb3085fa9e5f07b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9dfbf9e8caaffaa31bb3085fa9e5f07b.addTo(map_63cac151d5d16162c2db8c9a65bab5c1);
#
#
#             var marker_09caebaa00841b81d436c61670008f91 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_63cac151d5d16162c2db8c9a65bab5c1);
#
#
#         var popup_9a2d5c11b4ec1a12ee21b2c975eb4065 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93763b6cde9aa21f5d0219e817f93ef6 = $(`&lt;div id=&quot;html_93763b6cde9aa21f5d0219e817f93ef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9a2d5c11b4ec1a12ee21b2c975eb4065.setContent(html_93763b6cde9aa21f5d0219e817f93ef6);
#
#
#
#         marker_09caebaa00841b81d436c61670008f91.bindPopup(popup_9a2d5c11b4ec1a12ee21b2c975eb4065)
#         ;
#
#
#
#
#             var marker_37e3f0be070b51b1ea183a768a88c9a8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_63cac151d5d16162c2db8c9a65bab5c1);
#
#
#         var popup_4ba2b1cf7603e3dbbc94b0f9ced6ab53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_879b0017f421f1410e66ed0a4b70a818 = $(`&lt;div id=&quot;html_879b0017f421f1410e66ed0a4b70a818&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4ba2b1cf7603e3dbbc94b0f9ced6ab53.setContent(html_879b0017f421f1410e66ed0a4b70a818);
#
#
#
#         marker_37e3f0be070b51b1ea183a768a88c9a8.bindPopup(popup_4ba2b1cf7603e3dbbc94b0f9ced6ab53)
#         ;
#
#
#
#
#             var marker_9d7a7841b7388fd08de01e7e6660ef7c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_63cac151d5d16162c2db8c9a65bab5c1);
#
#
#         var popup_42a277551c77bdec93b16f06a8d9e0fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f8fc050b8e71fe3a54248f438c0b336 = $(`&lt;div id=&quot;html_4f8fc050b8e71fe3a54248f438c0b336&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_42a277551c77bdec93b16f06a8d9e0fe.setContent(html_4f8fc050b8e71fe3a54248f438c0b336);
#
#
#
#         marker_9d7a7841b7388fd08de01e7e6660ef7c.bindPopup(popup_42a277551c77bdec93b16f06a8d9e0fe)
#         ;
#
#
#
#
#             var marker_67a93abdd1563e98782613f2b3c91069 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_63cac151d5d16162c2db8c9a65bab5c1);
#
#
#         var popup_13509b5518d3ca9381f80bdbed7c8bb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9257ca9c3179cb2d07930bff12e36b8 = $(`&lt;div id=&quot;html_e9257ca9c3179cb2d07930bff12e36b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_13509b5518d3ca9381f80bdbed7c8bb4.setContent(html_e9257ca9c3179cb2d07930bff12e36b8);
#
#
#
#         marker_67a93abdd1563e98782613f2b3c91069.bindPopup(popup_13509b5518d3ca9381f80bdbed7c8bb4)
#         ;
#
#
#
#
#             var marker_79c9d879ee2e6a080d189987282b8f19 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_63cac151d5d16162c2db8c9a65bab5c1);
#
#
#         var popup_6d3747b6bc23a69db6093fbc8b17f446 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97b05eac71d3af0bbd512280b81fe881 = $(`&lt;div id=&quot;html_97b05eac71d3af0bbd512280b81fe881&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6d3747b6bc23a69db6093fbc8b17f446.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4dd89007e10f0906d276ebc1f3e7997 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4dd89007e10f0906d276ebc1f3e7997&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4dd89007e10f0906d276ebc1f3e7997 = L.map(
#                 &quot;map_c4dd89007e10f0906d276ebc1f3e7997&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9ebc88310a6b137567088e670c89bdb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9ebc88310a6b137567088e670c89bdb.addTo(map_c4dd89007e10f0906d276ebc1f3e7997);
#
#
#             var feature_group_5dd771c88a7f53feec6cb13221b596bf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2da68ce4dc5585a0429c81a665cff186 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5dd771c88a7f53feec6cb13221b596bf);
#
#
#         var popup_8c9db0c7e94c041e0c8fb4d6079a4fa0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e53b8f4374d0ddd921b1f1f2112d8c20 = $(`&lt;div id=&quot;html_e53b8f4374d0ddd921b1f1f2112d8c20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8c9db0c7e94c041e0c8fb4d6079a4fa0.setContent(html_e53b8f4374d0ddd921b1f1f2112d8c20);
#
#
#
#         marker_2da68ce4dc5585a0429c81a665cff186.bindPopup(popup_8c9db0c7e94c041e0c8fb4d6079a4fa0)
#         ;
#
#
#
#
#             var marker_1fd1134d899a32d9362259e7f7ed47b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5dd771c88a7f53feec6cb13221b596bf);
#
#
#         var popup_2e5d6172690e020555f9dacb2319cfd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d65e7283f0bebe837b8a63afcb6ae9ae = $(`&lt;div id=&quot;html_d65e7283f0bebe837b8a63afcb6ae9ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2e5d6172690e020555f9dacb2319cfd4.setContent(html_d65e7283f0bebe837b8a63afcb6ae9ae);
#
#
#
#         marker_1fd1134d899a32d9362259e7f7ed47b6.bindPopup(popup_2e5d6172690e020555f9dacb2319cfd4)
#         ;
#
#
#
#
#             var marker_4140675e92a8cdd0a8435c0dc0332a81 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5dd771c88a7f53feec6cb13221b596bf);
#
#
#         var popup_4fdef671d26fcef5056677641ca72bd9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_522d4cabab01d9a4417a77997bc431b5 = $(`&lt;div id=&quot;html_522d4cabab01d9a4417a77997bc431b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4fdef671d26fcef5056677641ca72bd9.setContent(html_522d4cabab01d9a4417a77997bc431b5);
#
#
#
#         marker_4140675e92a8cdd0a8435c0dc0332a81.bindPopup(popup_4fdef671d26fcef5056677641ca72bd9)
#         ;
#
#
#
#
#             var marker_723ed19dfbec933a706072b2a66ab8b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5dd771c88a7f53feec6cb13221b596bf);
#
#
#         var popup_786ee07fcced8c28739689386361a695 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20c6dffb2edafb01fd83d311161c57ea = $(`&lt;div id=&quot;html_20c6dffb2edafb01fd83d311161c57ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_786ee07fcced8c28739689386361a695.setContent(html_20c6dffb2edafb01fd83d311161c57ea);
#
#
#
#         marker_723ed19dfbec933a706072b2a66ab8b4.bindPopup(popup_786ee07fcced8c28739689386361a695)
#         ;
#
#
#
#
#             var marker_99acea943159ac3a269717391910d042 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5dd771c88a7f53feec6cb13221b596bf);
#
#
#         var popup_2eb6f00a2059d745a3610619872275db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0efbdb5a68c97b096d1253f1218f1c2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0efbdb5a68c97b096d1253f1218f1c2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0efbdb5a68c97b096d1253f1218f1c2f = L.map(
#                 &quot;map_0efbdb5a68c97b096d1253f1218f1c2f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec19a66e1038bbb596eda62236d2b95f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec19a66e1038bbb596eda62236d2b95f.addTo(map_0efbdb5a68c97b096d1253f1218f1c2f);
#
#
#             var feature_group_c65ea85c7f4df9129d2baa7307208c96 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c65ea85c7f4df9129d2baa7307208c96.addTo(map_0efbdb5a68c97b096d1253f1218f1c2f);
#
#
#             var feature_group_sub_group_78bfb091b8d4b4c3a96fef5923a93cf0 = L.featureGroup.subGroup(
#                 feature_group_c65ea85c7f4df9129d2baa7307208c96
#             );
#
#
#             var marker_c192126f26034fb8abf261a3084c5115 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_78bfb091b8d4b4c3a96fef5923a93cf0);
#
#
#         var popup_ca29fdae0a996cf63a04b6c73386ccbf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c218f166036ff33fa98cd07f9e50880 = $(`&lt;div id=&quot;html_4c218f166036ff33fa98cd07f9e50880&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ca29fdae0a996cf63a04b6c73386ccbf.setContent(html_4c218f166036ff33fa98cd07f9e50880);
#
#
#
#         marker_c192126f26034fb8abf261a3084c5115.bindPopup(popup_ca29fdae0a996cf63a04b6c73386ccbf)
#         ;
#
#
#
#
#             var marker_5667e9a6a4a7aa3e6bf51b44a4df4605 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_78bfb091b8d4b4c3a96fef5923a93cf0);
#
#
#         var popup_4cfb57a11513ff850969b9ff13560868 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3b575a7cf50303270e203360b28259c = $(`&lt;div id=&quot;html_e3b575a7cf50303270e203360b28259c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4cfb57a11513ff850969b9ff13560868.setContent(html_e3b575a7cf50303270e203360b28259c);
#
#
#
#         marker_5667e9a6a4a7aa3e6bf51b44a4df4605.bindPopup(popup_4cfb57a11513ff850969b9ff13560868)
#         ;
#
#
#
#
#             var marker_0cb4d382695acab9c5eee9cfba9f0e6c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_78bfb091b8d4b4c3a96fef5923a93cf0);
#
#
#         var popup_562d14028fb43ff67a950254ab4f210c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c952415b1f013962b57b4ff5a7d9eb47 = $(`&lt;div id=&quot;html_c952415b1f013962b57b4ff5a7d9eb47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_562d14028fb43ff67a950254ab4f210c.setContent(html_c952415b1f013962b57b4ff5a7d9eb47);
#
#
#
#         marker_0cb4d382695acab9c5eee9cfba9f0e6c.bindPopup(popup_562d14028fb43ff67a950254ab4f210c)
#         ;
#
#
#
#
#             var marker_581fa46ca33bb53bdbd6ebd01ef558cc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_78bfb091b8d4b4c3a96fef5923a93cf0);
#
#
#         var popup_291f0673582617bb407abbb0eefad6c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99b62c4bd907aab42768cfe39b3b6c15 = $(`&lt;div id=&quot;html_99b62c4bd907aab42768cfe39b3b6c15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_291f0673582617bb407abbb0eefad6c2.setContent(html_99b62c4bd907aab42768cfe39b3b6c15);
#
#
#
#         marker_
