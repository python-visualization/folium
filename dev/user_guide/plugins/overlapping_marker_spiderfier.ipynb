# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_89ebf2f462dff1b13274e7d15668fb65 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_89ebf2f462dff1b13274e7d15668fb65&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_89ebf2f462dff1b13274e7d15668fb65 = L.map(
#                 &quot;map_89ebf2f462dff1b13274e7d15668fb65&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6369642714d8be7650a8ecbe506ac412 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6369642714d8be7650a8ecbe506ac412.addTo(map_89ebf2f462dff1b13274e7d15668fb65);
#
#
#             var marker_319aab52c2c3ec66078c5424d0639431 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_89ebf2f462dff1b13274e7d15668fb65);
#
#
#         var popup_f3c0cf2040513af58bdc5e7e3e834420 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3c324698f4f588937dd5b6f7d5e3c34 = $(`&lt;div id=&quot;html_b3c324698f4f588937dd5b6f7d5e3c34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f3c0cf2040513af58bdc5e7e3e834420.setContent(html_b3c324698f4f588937dd5b6f7d5e3c34);
#
#
#
#         marker_319aab52c2c3ec66078c5424d0639431.bindPopup(popup_f3c0cf2040513af58bdc5e7e3e834420)
#         ;
#
#
#
#
#             var marker_79fe22f8c9a18356ad83e40b0796fe58 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_89ebf2f462dff1b13274e7d15668fb65);
#
#
#         var popup_c322a92f9fc16164439230ff158edfda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92986bc18e19230c6871e26ac79bfe5b = $(`&lt;div id=&quot;html_92986bc18e19230c6871e26ac79bfe5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c322a92f9fc16164439230ff158edfda.setContent(html_92986bc18e19230c6871e26ac79bfe5b);
#
#
#
#         marker_79fe22f8c9a18356ad83e40b0796fe58.bindPopup(popup_c322a92f9fc16164439230ff158edfda)
#         ;
#
#
#
#
#             var marker_e9cc0a8e2c01b2d0bb386a782a4beb81 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_89ebf2f462dff1b13274e7d15668fb65);
#
#
#         var popup_f7e117dfc6185f273043ee6d08132b41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d7fad595763a03c0fe8c880919b5eb7 = $(`&lt;div id=&quot;html_2d7fad595763a03c0fe8c880919b5eb7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f7e117dfc6185f273043ee6d08132b41.setContent(html_2d7fad595763a03c0fe8c880919b5eb7);
#
#
#
#         marker_e9cc0a8e2c01b2d0bb386a782a4beb81.bindPopup(popup_f7e117dfc6185f273043ee6d08132b41)
#         ;
#
#
#
#
#             var marker_b813b22eb730e0be40fc3faee04b1470 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_89ebf2f462dff1b13274e7d15668fb65);
#
#
#         var popup_3f4d97fa92eb6e5fc463a5cd11b3042c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_059bced64713a5c806c98f0a6dbc54b5 = $(`&lt;div id=&quot;html_059bced64713a5c806c98f0a6dbc54b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3f4d97fa92eb6e5fc463a5cd11b3042c.setContent(html_059bced64713a5c806c98f0a6dbc54b5);
#
#
#
#         marker_b813b22eb730e0be40fc3faee04b1470.bindPopup(popup_3f4d97fa92eb6e5fc463a5cd11b3042c)
#         ;
#
#
#
#
#             var marker_1016a0ed1a08f696d152fa6a2c530294 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_89ebf2f462dff1b13274e7d15668fb65);
#
#
#         var popup_9d3e45e7bc4c7a1eabe048dc4b773135 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bde5a55f3afcc5f2e40cb73644df4df = $(`&lt;div id=&quot;html_9bde5a55f3afcc5f2e40cb73644df4df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9d3e45e7bc4c7a1eabe048dc4b773135.setContent(html_9bde5a55f3afcc5f2e40cb73644df4df);
#
#
#
#         marker_1016a0ed1a08f696d152fa6a2c530294.bindPopup(popup_9d3e45e7bc4c7a1eabe048dc4b773135)
#         ;
#
#
#
#
#             var marker_27e3680664

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ffdd1264ce7c0757d5cfdb1e7bb8a5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ffdd1264ce7c0757d5cfdb1e7bb8a5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ffdd1264ce7c0757d5cfdb1e7bb8a5b = L.map(
#                 &quot;map_7ffdd1264ce7c0757d5cfdb1e7bb8a5b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b46e25822230acbc47abd1470b43f9aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b46e25822230acbc47abd1470b43f9aa.addTo(map_7ffdd1264ce7c0757d5cfdb1e7bb8a5b);
#
#
#             var feature_group_6fa25cb9af79bbe5dac6d0ed93c8a0af = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_231f25eb8899d896895a8897ef8df81c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6fa25cb9af79bbe5dac6d0ed93c8a0af);
#
#
#         var popup_15ff76fd25a6883d8364aa1bbadbba3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fe98a55308fba68ea813ae040349d8d = $(`&lt;div id=&quot;html_7fe98a55308fba68ea813ae040349d8d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_15ff76fd25a6883d8364aa1bbadbba3a.setContent(html_7fe98a55308fba68ea813ae040349d8d);
#
#
#
#         marker_231f25eb8899d896895a8897ef8df81c.bindPopup(popup_15ff76fd25a6883d8364aa1bbadbba3a)
#         ;
#
#
#
#
#             var marker_639d616d7703927043c357ff929a758c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6fa25cb9af79bbe5dac6d0ed93c8a0af);
#
#
#         var popup_85b806582927b3b4be855b8a9a9c19bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e9f9d518a45c20ebb791afb7f919f4e = $(`&lt;div id=&quot;html_3e9f9d518a45c20ebb791afb7f919f4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_85b806582927b3b4be855b8a9a9c19bc.setContent(html_3e9f9d518a45c20ebb791afb7f919f4e);
#
#
#
#         marker_639d616d7703927043c357ff929a758c.bindPopup(popup_85b806582927b3b4be855b8a9a9c19bc)
#         ;
#
#
#
#
#             var marker_3f0d37ca06ac28477d27611aa1d17689 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6fa25cb9af79bbe5dac6d0ed93c8a0af);
#
#
#         var popup_e02c942bb2b7c59f2b06493fa87b3e62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3b9027c78337c8c12b34909350d259a = $(`&lt;div id=&quot;html_f3b9027c78337c8c12b34909350d259a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e02c942bb2b7c59f2b06493fa87b3e62.setContent(html_f3b9027c78337c8c12b34909350d259a);
#
#
#
#         marker_3f0d37ca06ac28477d27611aa1d17689.bindPopup(popup_e02c942bb2b7c59f2b06493fa87b3e62)
#         ;
#
#
#
#
#             var marker_9542d25dd73ec488a3b9107aeac0fc83 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6fa25cb9af79bbe5dac6d0ed93c8a0af);
#
#
#         var popup_bc45b54577b15d73f82c7e37b9f46537 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23b3b214cba252188575ebcb6e413e63 = $(`&lt;div id=&quot;html_23b3b214cba252188575ebcb6e413e63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bc45b54577b15d73f82c7e37b9f46537.setContent(html_23b3b214cba252188575ebcb6e413e63);
#
#
#
#         marker_9542d25dd73ec488a3b9107aeac0fc83.bindPopup(popup_bc45b54577b15d73f82c7e37b9f46537)
#         ;
#
#
#
#
#             var marker_db2ba94c193320890170483e2c9732f9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6fa25cb9af79bbe5dac6d0ed93c8a0af);
#
#
#         var popup_1737e0f1102fa83bada1f36f35b9ac61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fdca2547c5d168bbb7e58688a4eb856 = $(`&lt;div id=&quot;html_3fdca2547c5d168bbb7e58688a4eb856&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_1737e0f1102fa83bad

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee17261efdb08f39be85bf5f72aab65b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee17261efdb08f39be85bf5f72aab65b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee17261efdb08f39be85bf5f72aab65b = L.map(
#                 &quot;map_ee17261efdb08f39be85bf5f72aab65b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04d5a6958ab32a78810efa30570cedf5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_04d5a6958ab32a78810efa30570cedf5.addTo(map_ee17261efdb08f39be85bf5f72aab65b);
#
#
#             var feature_group_75d51a4f37656b02201cc13493060e8e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_75d51a4f37656b02201cc13493060e8e.addTo(map_ee17261efdb08f39be85bf5f72aab65b);
#
#
#             var feature_group_sub_group_07d28aa25cddaa77fa812b67084c73e3 = L.featureGroup.subGroup(
#                 feature_group_75d51a4f37656b02201cc13493060e8e
#             );
#
#
#             var marker_3c4720b464327b370b0ea87ea1f54314 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_07d28aa25cddaa77fa812b67084c73e3);
#
#
#         var popup_175f1e80e30cb02335b82ab9883bd545 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ffe9ee3ea63835cde777197dd3fb31bc = $(`&lt;div id=&quot;html_ffe9ee3ea63835cde777197dd3fb31bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_175f1e80e30cb02335b82ab9883bd545.setContent(html_ffe9ee3ea63835cde777197dd3fb31bc);
#
#
#
#         marker_3c4720b464327b370b0ea87ea1f54314.bindPopup(popup_175f1e80e30cb02335b82ab9883bd545)
#         ;
#
#
#
#
#             var marker_9b5de406991e76bb24c136b743d0ec3e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_07d28aa25cddaa77fa812b67084c73e3);
#
#
#         var popup_6bead0897431db72b82e731eee495f51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0b2c674faa073f1b6024fa26a968616 = $(`&lt;div id=&quot;html_f0b2c674faa073f1b6024fa26a968616&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6bead0897431db72b82e731eee495f51.setContent(html_f0b2c674faa073f1b6024fa26a968616);
#
#
#
#         marker_9b5de406991e76bb24c136b743d0ec3e.bindPopup(popup_6bead0897431db72b82e731eee495f51)
#         ;
#
#
#
#
#             var marker_e4f424d4cecb8c323d19a9f5e23575c0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_07d28aa25cddaa77fa812b67084c73e3);
#
#
#         var popup_475bf35e905f578c4dc540467602511d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_645aa5596abe5a593f80bb9a66836d60 = $(`&lt;div id=&quot;html_645aa5596abe5a593f80bb9a66836d60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_475bf35e905f578c4dc540467602511d.setContent(html_645aa5596abe5a593f80bb9a66836d60);
#
#
#
#         marker_e4f424d4cecb8c323d19a9f5e23575c0.bindPopup(popup_475bf35e905f578c4dc540467602511d)
#         ;
#
#
#
#
#             var marker_b68217d52c7c110733f45ea67a272179 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_07d28aa25cddaa77fa812b67084c73e3);
#
#
#         var popup_e1b4ee1021dccfbfd35c0438f5d72668 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cfd4c6d6498cb9ba24a7caff259d48e = $(`&lt;div id=&quot;html_8cfd4c6d6498cb9ba24a7caff259d48e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e1b4ee1021dccfbfd35c0438f5d72668.setContent(html_8cfd4c6d6498cb9ba24a7caff259d48e);
#
#
#
#         marker_b68217d52c7c110733f45ea67a272179.bindPopup(popup_e1b4ee1021dccfbfd35c0438f5d72668)
#         ;
#
#
#
#
#             var marker_8491be457d99553a42afb68881aaed41 = L.marker(
#                 [45.050399999999996, 3.0504],
