# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5ddc80bcecd6aba580857251c56a818 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5ddc80bcecd6aba580857251c56a818&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5ddc80bcecd6aba580857251c56a818 = L.map(
#                 &quot;map_f5ddc80bcecd6aba580857251c56a818&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d62699bea5e08fc03b7aa1a19bee80b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5d62699bea5e08fc03b7aa1a19bee80b.addTo(map_f5ddc80bcecd6aba580857251c56a818);
#
#
#             var marker_a89f525f95fb82f8597f0b1aac7d0510 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f5ddc80bcecd6aba580857251c56a818);
#
#
#         var popup_debb63da7f307a70619b0fa8dbbc2c04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fa263ea049a81b9a1a7fd3a0864b884 = $(`&lt;div id=&quot;html_1fa263ea049a81b9a1a7fd3a0864b884&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_debb63da7f307a70619b0fa8dbbc2c04.setContent(html_1fa263ea049a81b9a1a7fd3a0864b884);
#
#
#
#         marker_a89f525f95fb82f8597f0b1aac7d0510.bindPopup(popup_debb63da7f307a70619b0fa8dbbc2c04)
#         ;
#
#
#
#
#             var marker_171a2aa29255737ae76f521a9ed3723c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f5ddc80bcecd6aba580857251c56a818);
#
#
#         var popup_547722fa9856a2c7c5bf67db46d8b47f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_294efb72b35c865de4410b29aa6a11a9 = $(`&lt;div id=&quot;html_294efb72b35c865de4410b29aa6a11a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_547722fa9856a2c7c5bf67db46d8b47f.setContent(html_294efb72b35c865de4410b29aa6a11a9);
#
#
#
#         marker_171a2aa29255737ae76f521a9ed3723c.bindPopup(popup_547722fa9856a2c7c5bf67db46d8b47f)
#         ;
#
#
#
#
#             var marker_06210a8dbe6f104316de1668d00dde18 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f5ddc80bcecd6aba580857251c56a818);
#
#
#         var popup_631944b645b6d30b90b71c7e99b374fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_feaa0c0b57ba8c1d2b50fcb89c97de07 = $(`&lt;div id=&quot;html_feaa0c0b57ba8c1d2b50fcb89c97de07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_631944b645b6d30b90b71c7e99b374fd.setContent(html_feaa0c0b57ba8c1d2b50fcb89c97de07);
#
#
#
#         marker_06210a8dbe6f104316de1668d00dde18.bindPopup(popup_631944b645b6d30b90b71c7e99b374fd)
#         ;
#
#
#
#
#             var marker_585906d6a75b7ad18704da31000c659e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f5ddc80bcecd6aba580857251c56a818);
#
#
#         var popup_e7c8bcb3a73a1ef50cc90b6a00d1251f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f1be75404a4d548e77e9756ddacaec9 = $(`&lt;div id=&quot;html_2f1be75404a4d548e77e9756ddacaec9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e7c8bcb3a73a1ef50cc90b6a00d1251f.setContent(html_2f1be75404a4d548e77e9756ddacaec9);
#
#
#
#         marker_585906d6a75b7ad18704da31000c659e.bindPopup(popup_e7c8bcb3a73a1ef50cc90b6a00d1251f)
#         ;
#
#
#
#
#             var marker_dce1ba661e64d11dc65235405d59ccd7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f5ddc80bcecd6aba580857251c56a818);
#
#
#         var popup_6164100a071b6298777693f81f3c9ed3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4403576ee83080a421caca30e5583698 = $(`&lt;div id=&quot;html_4403576ee83080a421caca30e5583698&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6164100a071b6298777693f81f3c9e

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f71b5120abb76627adf544fe9c9d1345 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f71b5120abb76627adf544fe9c9d1345&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f71b5120abb76627adf544fe9c9d1345 = L.map(
#                 &quot;map_f71b5120abb76627adf544fe9c9d1345&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30772b045f44184846a76712853edbd0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30772b045f44184846a76712853edbd0.addTo(map_f71b5120abb76627adf544fe9c9d1345);
#
#
#             var feature_group_ce08e3cfa00df5c6be8587c6b9017bae = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f72f5a4459675a0ff56779d3ea558d65 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ce08e3cfa00df5c6be8587c6b9017bae);
#
#
#         var popup_a5b0611a31bdd97d87adc325628f64af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1af765c7767beb588a514d7e5e6c76d = $(`&lt;div id=&quot;html_b1af765c7767beb588a514d7e5e6c76d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a5b0611a31bdd97d87adc325628f64af.setContent(html_b1af765c7767beb588a514d7e5e6c76d);
#
#
#
#         marker_f72f5a4459675a0ff56779d3ea558d65.bindPopup(popup_a5b0611a31bdd97d87adc325628f64af)
#         ;
#
#
#
#
#             var marker_5f7c7b220d6d903e7f7c5f11e44dd45c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ce08e3cfa00df5c6be8587c6b9017bae);
#
#
#         var popup_81be8c35007bc0dd365db229cb3c7e6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53886e027fbb4982ead16f75c10027eb = $(`&lt;div id=&quot;html_53886e027fbb4982ead16f75c10027eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_81be8c35007bc0dd365db229cb3c7e6d.setContent(html_53886e027fbb4982ead16f75c10027eb);
#
#
#
#         marker_5f7c7b220d6d903e7f7c5f11e44dd45c.bindPopup(popup_81be8c35007bc0dd365db229cb3c7e6d)
#         ;
#
#
#
#
#             var marker_c3b1c40dc3ede766fc59d4663ef899ec = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ce08e3cfa00df5c6be8587c6b9017bae);
#
#
#         var popup_dfde576898e1cfe96edc2ff6613c9cc4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37871b27999f1bca9807090ffcd2a47b = $(`&lt;div id=&quot;html_37871b27999f1bca9807090ffcd2a47b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_dfde576898e1cfe96edc2ff6613c9cc4.setContent(html_37871b27999f1bca9807090ffcd2a47b);
#
#
#
#         marker_c3b1c40dc3ede766fc59d4663ef899ec.bindPopup(popup_dfde576898e1cfe96edc2ff6613c9cc4)
#         ;
#
#
#
#
#             var marker_62c194c472fe77431f7da395072ff453 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ce08e3cfa00df5c6be8587c6b9017bae);
#
#
#         var popup_b676e2a8fc037406a86d1ea2588b9aff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee9ae1454492ed60ae88d166e1b194c6 = $(`&lt;div id=&quot;html_ee9ae1454492ed60ae88d166e1b194c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_b676e2a8fc037406a86d1ea2588b9aff.setContent(html_ee9ae1454492ed60ae88d166e1b194c6);
#
#
#
#         marker_62c194c472fe77431f7da395072ff453.bindPopup(popup_b676e2a8fc037406a86d1ea2588b9aff)
#         ;
#
#
#
#
#             var marker_bd78a2ff60bdddfd56aceeb231708442 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ce08e3cfa00df5c6be8587c6b9017bae);
#
#
#         var popup_4c0549e7cb2d576ab1116a8a5767f445 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c597e8d0cb8046fdd96cb54046d5a5ef {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c597e8d0cb8046fdd96cb54046d5a5ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c597e8d0cb8046fdd96cb54046d5a5ef = L.map(
#                 &quot;map_c597e8d0cb8046fdd96cb54046d5a5ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52fec8e19c225ca9b9e6e9b38e246ca8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52fec8e19c225ca9b9e6e9b38e246ca8.addTo(map_c597e8d0cb8046fdd96cb54046d5a5ef);
#
#
#             var feature_group_86cbbe9707c98f277d0a3c6d6130ab03 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_86cbbe9707c98f277d0a3c6d6130ab03.addTo(map_c597e8d0cb8046fdd96cb54046d5a5ef);
#
#
#             var feature_group_sub_group_be3ec2d45517b9b771de27a03ab5d2d8 = L.featureGroup.subGroup(
#                 feature_group_86cbbe9707c98f277d0a3c6d6130ab03
#             );
#
#
#             var marker_4ca923fae4a0b7721a5b3f7ae3c2c1e4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_be3ec2d45517b9b771de27a03ab5d2d8);
#
#
#         var popup_9916d789a40db097ed9a42efa2d940fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec664e1ae5b180462177c6c0e623e245 = $(`&lt;div id=&quot;html_ec664e1ae5b180462177c6c0e623e245&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9916d789a40db097ed9a42efa2d940fe.setContent(html_ec664e1ae5b180462177c6c0e623e245);
#
#
#
#         marker_4ca923fae4a0b7721a5b3f7ae3c2c1e4.bindPopup(popup_9916d789a40db097ed9a42efa2d940fe)
#         ;
#
#
#
#
#             var marker_fa7c5ecd0f198718557d7da74b60996a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_be3ec2d45517b9b771de27a03ab5d2d8);
#
#
#         var popup_4598421899f8ae5c382205a113123ea4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10b5ad12088f2961dcafe75cd7605b1d = $(`&lt;div id=&quot;html_10b5ad12088f2961dcafe75cd7605b1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4598421899f8ae5c382205a113123ea4.setContent(html_10b5ad12088f2961dcafe75cd7605b1d);
#
#
#
#         marker_fa7c5ecd0f198718557d7da74b60996a.bindPopup(popup_4598421899f8ae5c382205a113123ea4)
#         ;
#
#
#
#
#             var marker_9eb0f5474a20eac536d76809b6386e21 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_be3ec2d45517b9b771de27a03ab5d2d8);
#
#
#         var popup_4c3173720c6b023a56dde3b582644996 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0d486927f24aabd2e10eab3503a8c3d = $(`&lt;div id=&quot;html_b0d486927f24aabd2e10eab3503a8c3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4c3173720c6b023a56dde3b582644996.setContent(html_b0d486927f24aabd2e10eab3503a8c3d);
#
#
#
#         marker_9eb0f5474a20eac536d76809b6386e21.bindPopup(popup_4c3173720c6b023a56dde3b582644996)
#         ;
#
#
#
#
#             var marker_defe1c735242741cc7cab0f5c7515307 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_be3ec2d45517b9b771de27a03ab5d2d8);
#
#
#         var popup_7eb0248693de205cc3a79dfe87168137 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2141faab16f689e730ab7aaa8e914c30 = $(`&lt;div id=&quot;html_2141faab16f689e730ab7aaa8e914c30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7eb0248693de205cc3a79dfe87168137.setContent(html_2141faab16f689e730ab7aaa8e914c30);
#
#
#
#         mark
