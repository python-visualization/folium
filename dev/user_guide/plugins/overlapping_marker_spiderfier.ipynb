# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b955ab90de11c0529709aa5359dd0dd6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b955ab90de11c0529709aa5359dd0dd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b955ab90de11c0529709aa5359dd0dd6 = L.map(
#                 &quot;map_b955ab90de11c0529709aa5359dd0dd6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d60fba69041bd00e45aa4772a3d5b801 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d60fba69041bd00e45aa4772a3d5b801.addTo(map_b955ab90de11c0529709aa5359dd0dd6);
#
#
#             var marker_bc983448df175f3adb45c0aeeaba75d9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b955ab90de11c0529709aa5359dd0dd6);
#
#
#         var popup_c94fe9ec1f001d10e1fec36476ce1ec6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d731031c43a86b4336093d3a7c0b5460 = $(`&lt;div id=&quot;html_d731031c43a86b4336093d3a7c0b5460&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c94fe9ec1f001d10e1fec36476ce1ec6.setContent(html_d731031c43a86b4336093d3a7c0b5460);
#
#
#
#         marker_bc983448df175f3adb45c0aeeaba75d9.bindPopup(popup_c94fe9ec1f001d10e1fec36476ce1ec6)
#         ;
#
#
#
#
#             var marker_89b3f913800b02d7253ece452622ab59 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b955ab90de11c0529709aa5359dd0dd6);
#
#
#         var popup_40163f2e4a7a16851a6d387afeaabe29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_644dbac5ca0713a23026dfcc014e9678 = $(`&lt;div id=&quot;html_644dbac5ca0713a23026dfcc014e9678&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_40163f2e4a7a16851a6d387afeaabe29.setContent(html_644dbac5ca0713a23026dfcc014e9678);
#
#
#
#         marker_89b3f913800b02d7253ece452622ab59.bindPopup(popup_40163f2e4a7a16851a6d387afeaabe29)
#         ;
#
#
#
#
#             var marker_50dc69037a7e9de968b3faacaac7295d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b955ab90de11c0529709aa5359dd0dd6);
#
#
#         var popup_1801c6f0c447f7c9097426a839647d5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44eda842a160c81ee109fa548f1f3576 = $(`&lt;div id=&quot;html_44eda842a160c81ee109fa548f1f3576&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1801c6f0c447f7c9097426a839647d5d.setContent(html_44eda842a160c81ee109fa548f1f3576);
#
#
#
#         marker_50dc69037a7e9de968b3faacaac7295d.bindPopup(popup_1801c6f0c447f7c9097426a839647d5d)
#         ;
#
#
#
#
#             var marker_af8c7a721896c08fd82bfb5da2afe825 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b955ab90de11c0529709aa5359dd0dd6);
#
#
#         var popup_bf6457ee496a3d2b26b277f3b38b3990 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c71705bff2c3ade1df7e57a4022a3725 = $(`&lt;div id=&quot;html_c71705bff2c3ade1df7e57a4022a3725&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bf6457ee496a3d2b26b277f3b38b3990.setContent(html_c71705bff2c3ade1df7e57a4022a3725);
#
#
#
#         marker_af8c7a721896c08fd82bfb5da2afe825.bindPopup(popup_bf6457ee496a3d2b26b277f3b38b3990)
#         ;
#
#
#
#
#             var marker_795100c949a0949b5b061ca86e5d8854 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b955ab90de11c0529709aa5359dd0dd6);
#
#
#         var popup_f6762b9bf484795c1202fd4f22764eba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0e7e26cc6c094cfc9adbd83f4edf710 = $(`&lt;div id=&quot;html_b0e7e26cc6c094cfc9adbd83f4edf710&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f6762b9bf484795c1202fd4f22764eba.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1ec93e7a8a5899838c53a56545c7707 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1ec93e7a8a5899838c53a56545c7707&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1ec93e7a8a5899838c53a56545c7707 = L.map(
#                 &quot;map_b1ec93e7a8a5899838c53a56545c7707&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_80a5cddebe17b0024be13090ea9359d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_80a5cddebe17b0024be13090ea9359d1.addTo(map_b1ec93e7a8a5899838c53a56545c7707);
#
#
#             var feature_group_d0991382577b34983260823f308f5fb8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3db42c6f3bd63fa1510417465b91a363 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d0991382577b34983260823f308f5fb8);
#
#
#         var popup_e93af5729e73bc6b6bc8b2d3e9a02b6f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0dd9822286f89873423e15a9f79db26 = $(`&lt;div id=&quot;html_c0dd9822286f89873423e15a9f79db26&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e93af5729e73bc6b6bc8b2d3e9a02b6f.setContent(html_c0dd9822286f89873423e15a9f79db26);
#
#
#
#         marker_3db42c6f3bd63fa1510417465b91a363.bindPopup(popup_e93af5729e73bc6b6bc8b2d3e9a02b6f)
#         ;
#
#
#
#
#             var marker_5da3fdff34770873634969bf69610111 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d0991382577b34983260823f308f5fb8);
#
#
#         var popup_03f26da688fb88cc2143877673180d27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30c0328a263763bc7e9ee604cb3b5017 = $(`&lt;div id=&quot;html_30c0328a263763bc7e9ee604cb3b5017&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_03f26da688fb88cc2143877673180d27.setContent(html_30c0328a263763bc7e9ee604cb3b5017);
#
#
#
#         marker_5da3fdff34770873634969bf69610111.bindPopup(popup_03f26da688fb88cc2143877673180d27)
#         ;
#
#
#
#
#             var marker_a166836e8f3b80a400ffc042710acd57 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d0991382577b34983260823f308f5fb8);
#
#
#         var popup_6f14733df18e01255e83cbd467b0c05f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf6c962e479e78072b399ac0e0939efb = $(`&lt;div id=&quot;html_cf6c962e479e78072b399ac0e0939efb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6f14733df18e01255e83cbd467b0c05f.setContent(html_cf6c962e479e78072b399ac0e0939efb);
#
#
#
#         marker_a166836e8f3b80a400ffc042710acd57.bindPopup(popup_6f14733df18e01255e83cbd467b0c05f)
#         ;
#
#
#
#
#             var marker_70fb5a196d579970ae356ba00bfa70b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d0991382577b34983260823f308f5fb8);
#
#
#         var popup_73c4debfbd2c2428441dcb5cac10dfce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d10a1bf6673d6f6a6757521691b9560c = $(`&lt;div id=&quot;html_d10a1bf6673d6f6a6757521691b9560c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_73c4debfbd2c2428441dcb5cac10dfce.setContent(html_d10a1bf6673d6f6a6757521691b9560c);
#
#
#
#         marker_70fb5a196d579970ae356ba00bfa70b2.bindPopup(popup_73c4debfbd2c2428441dcb5cac10dfce)
#         ;
#
#
#
#
#             var marker_53c53223b62541ed2380ffe9b1e968f1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d0991382577b34983260823f308f5fb8);
#
#
#         var popup_07edc9fbd311184a8de2d4efaea3fbcd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f34edd781279c777e6b320ae2403a80e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f34edd781279c777e6b320ae2403a80e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f34edd781279c777e6b320ae2403a80e = L.map(
#                 &quot;map_f34edd781279c777e6b320ae2403a80e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_566a9b4c1c22a3e28329aaef69c750f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_566a9b4c1c22a3e28329aaef69c750f1.addTo(map_f34edd781279c777e6b320ae2403a80e);
#
#
#             var feature_group_35f8cfaccd2ff91fc21fb49941f9a72c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_35f8cfaccd2ff91fc21fb49941f9a72c.addTo(map_f34edd781279c777e6b320ae2403a80e);
#
#
#             var feature_group_sub_group_a00d542b3139457d69627bd50083d6a5 = L.featureGroup.subGroup(
#                 feature_group_35f8cfaccd2ff91fc21fb49941f9a72c
#             );
#
#
#             var marker_d3799dd6d387ab8d5cd65c6e436936eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a00d542b3139457d69627bd50083d6a5);
#
#
#         var popup_eaeeefaa36f39e132fd658c24840a30e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ffd695c92052f41c0fbe3ffc26562f6 = $(`&lt;div id=&quot;html_8ffd695c92052f41c0fbe3ffc26562f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_eaeeefaa36f39e132fd658c24840a30e.setContent(html_8ffd695c92052f41c0fbe3ffc26562f6);
#
#
#
#         marker_d3799dd6d387ab8d5cd65c6e436936eb.bindPopup(popup_eaeeefaa36f39e132fd658c24840a30e)
#         ;
#
#
#
#
#             var marker_8f223ed7ae806849daf1e0715b228148 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a00d542b3139457d69627bd50083d6a5);
#
#
#         var popup_19c262eab8f46a52f1ff63ded5975e23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a1f0769014586356e90427c864d2939 = $(`&lt;div id=&quot;html_2a1f0769014586356e90427c864d2939&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_19c262eab8f46a52f1ff63ded5975e23.setContent(html_2a1f0769014586356e90427c864d2939);
#
#
#
#         marker_8f223ed7ae806849daf1e0715b228148.bindPopup(popup_19c262eab8f46a52f1ff63ded5975e23)
#         ;
#
#
#
#
#             var marker_571f6fa69a76c0f482c27f53838a994f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a00d542b3139457d69627bd50083d6a5);
#
#
#         var popup_2081664d9e13acedd3001c709bf7361f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42267c4d06d717550a1c42866afc1041 = $(`&lt;div id=&quot;html_42267c4d06d717550a1c42866afc1041&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_2081664d9e13acedd3001c709bf7361f.setContent(html_42267c4d06d717550a1c42866afc1041);
#
#
#
#         marker_571f6fa69a76c0f482c27f53838a994f.bindPopup(popup_2081664d9e13acedd3001c709bf7361f)
#         ;
#
#
#
#
#             var marker_ba1ef519226acc58f0cd44a457383a2d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a00d542b3139457d69627bd50083d6a5);
#
#
#         var popup_46671916d375a5f53935418e42dd2ff1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6beff7f01228c0da71df6a386c0cc97f = $(`&lt;div id=&quot;html_6beff7f01228c0da71df6a386c0cc97f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_46671916d375a5f53935418e42dd2ff1.setContent(html_6beff7f01228c0da71df6a386c0cc97f);
#
#
#
#         marker_
