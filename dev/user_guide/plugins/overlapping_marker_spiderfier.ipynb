# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39c9b98dad22e86af426cb69bf6f3b5e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39c9b98dad22e86af426cb69bf6f3b5e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39c9b98dad22e86af426cb69bf6f3b5e = L.map(
#                 &quot;map_39c9b98dad22e86af426cb69bf6f3b5e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_180ba3554ce3cb6e24e42c9b53166a9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_180ba3554ce3cb6e24e42c9b53166a9f.addTo(map_39c9b98dad22e86af426cb69bf6f3b5e);
#
#
#             var marker_572b18114be9080b9fb53fd77d2cbad4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_39c9b98dad22e86af426cb69bf6f3b5e);
#
#
#         var popup_9a4601659527c6001a85a84cd6add9b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e5b456181b288f27a108872038d593e = $(`&lt;div id=&quot;html_5e5b456181b288f27a108872038d593e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9a4601659527c6001a85a84cd6add9b9.setContent(html_5e5b456181b288f27a108872038d593e);
#
#
#
#         marker_572b18114be9080b9fb53fd77d2cbad4.bindPopup(popup_9a4601659527c6001a85a84cd6add9b9)
#         ;
#
#
#
#
#             var marker_017723339246e5320cb9b6da5f5227fe = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_39c9b98dad22e86af426cb69bf6f3b5e);
#
#
#         var popup_ce9069963c01224062fb72bc36267729 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eebc9be78890b2b402214cb59afa9eca = $(`&lt;div id=&quot;html_eebc9be78890b2b402214cb59afa9eca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ce9069963c01224062fb72bc36267729.setContent(html_eebc9be78890b2b402214cb59afa9eca);
#
#
#
#         marker_017723339246e5320cb9b6da5f5227fe.bindPopup(popup_ce9069963c01224062fb72bc36267729)
#         ;
#
#
#
#
#             var marker_9bab9a0ebc6279062269b11022b8d578 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_39c9b98dad22e86af426cb69bf6f3b5e);
#
#
#         var popup_8f989dab7917c720fcff794b1b8ce5fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78be3161393d9db2c67ed0b0f68b4bc4 = $(`&lt;div id=&quot;html_78be3161393d9db2c67ed0b0f68b4bc4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8f989dab7917c720fcff794b1b8ce5fc.setContent(html_78be3161393d9db2c67ed0b0f68b4bc4);
#
#
#
#         marker_9bab9a0ebc6279062269b11022b8d578.bindPopup(popup_8f989dab7917c720fcff794b1b8ce5fc)
#         ;
#
#
#
#
#             var marker_bb7414f5c41107ea04219cc7ef9b8017 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_39c9b98dad22e86af426cb69bf6f3b5e);
#
#
#         var popup_7480d08f374d0d9efd52e55fe7812bc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26ea0895ebea8d37d657c4a4b08bcfe5 = $(`&lt;div id=&quot;html_26ea0895ebea8d37d657c4a4b08bcfe5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7480d08f374d0d9efd52e55fe7812bc8.setContent(html_26ea0895ebea8d37d657c4a4b08bcfe5);
#
#
#
#         marker_bb7414f5c41107ea04219cc7ef9b8017.bindPopup(popup_7480d08f374d0d9efd52e55fe7812bc8)
#         ;
#
#
#
#
#             var marker_912ad37cedf9907fdaecdf228b6e1618 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_39c9b98dad22e86af426cb69bf6f3b5e);
#
#
#         var popup_11df9b915d67ffe0805633654027aa6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f6dbe7fb21acf17942ef1b1ad38666f = $(`&lt;div id=&quot;html_7f6dbe7fb21acf17942ef1b1ad38666f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_11df9b915d67ffe0805633654027aa6c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f12385535d8d4aeba55e625d11f916df {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f12385535d8d4aeba55e625d11f916df&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f12385535d8d4aeba55e625d11f916df = L.map(
#                 &quot;map_f12385535d8d4aeba55e625d11f916df&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_66847d9c87075451363f9d31ab45cbb7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_66847d9c87075451363f9d31ab45cbb7.addTo(map_f12385535d8d4aeba55e625d11f916df);
#
#
#             var feature_group_32dcafdfdd24d1f2ff6a75b66da00af6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ae35c638ed7c1fcd90b464e9331ef25d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_32dcafdfdd24d1f2ff6a75b66da00af6);
#
#
#         var popup_aa853dbb54ed5df59bc89cacf2e9fad9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12a0014a16e752ff6d49a57036121c84 = $(`&lt;div id=&quot;html_12a0014a16e752ff6d49a57036121c84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_aa853dbb54ed5df59bc89cacf2e9fad9.setContent(html_12a0014a16e752ff6d49a57036121c84);
#
#
#
#         marker_ae35c638ed7c1fcd90b464e9331ef25d.bindPopup(popup_aa853dbb54ed5df59bc89cacf2e9fad9)
#         ;
#
#
#
#
#             var marker_2d95aa84935e6c04122d5656b9dc7af9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_32dcafdfdd24d1f2ff6a75b66da00af6);
#
#
#         var popup_6efbbc50b90a8cf8f89a70f4b1637f7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56434d56338d324a965c3709d8afa0c6 = $(`&lt;div id=&quot;html_56434d56338d324a965c3709d8afa0c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6efbbc50b90a8cf8f89a70f4b1637f7b.setContent(html_56434d56338d324a965c3709d8afa0c6);
#
#
#
#         marker_2d95aa84935e6c04122d5656b9dc7af9.bindPopup(popup_6efbbc50b90a8cf8f89a70f4b1637f7b)
#         ;
#
#
#
#
#             var marker_480c4d2e86961547d0550cf1c2cdb7bb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_32dcafdfdd24d1f2ff6a75b66da00af6);
#
#
#         var popup_27575a58b2715b945504233e4962731c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54bf679dee200c1430e60c25aef3e92a = $(`&lt;div id=&quot;html_54bf679dee200c1430e60c25aef3e92a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_27575a58b2715b945504233e4962731c.setContent(html_54bf679dee200c1430e60c25aef3e92a);
#
#
#
#         marker_480c4d2e86961547d0550cf1c2cdb7bb.bindPopup(popup_27575a58b2715b945504233e4962731c)
#         ;
#
#
#
#
#             var marker_0979b4fdd68d12746a09cfcd8cb74e14 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_32dcafdfdd24d1f2ff6a75b66da00af6);
#
#
#         var popup_d73dec69cf71cae4b9132a14c0610f8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_858f95df3ab1a9a9679b18b2e2b542b7 = $(`&lt;div id=&quot;html_858f95df3ab1a9a9679b18b2e2b542b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d73dec69cf71cae4b9132a14c0610f8f.setContent(html_858f95df3ab1a9a9679b18b2e2b542b7);
#
#
#
#         marker_0979b4fdd68d12746a09cfcd8cb74e14.bindPopup(popup_d73dec69cf71cae4b9132a14c0610f8f)
#         ;
#
#
#
#
#             var marker_cc2e127ab61fdedfb5c80ff4a65ffb57 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_32dcafdfdd24d1f2ff6a75b66da00af6);
#
#
#         var popup_5c9d4673bb105c183c38f3d42ba3c6ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c75cf16ba4e08ae9c87e9ed0973d6067 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c75cf16ba4e08ae9c87e9ed0973d6067&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c75cf16ba4e08ae9c87e9ed0973d6067 = L.map(
#                 &quot;map_c75cf16ba4e08ae9c87e9ed0973d6067&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_74a84aa60e18309c930b145136338d95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_74a84aa60e18309c930b145136338d95.addTo(map_c75cf16ba4e08ae9c87e9ed0973d6067);
#
#
#             var feature_group_e5dc9b8895fe42489d02d9616cb1bce3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e5dc9b8895fe42489d02d9616cb1bce3.addTo(map_c75cf16ba4e08ae9c87e9ed0973d6067);
#
#
#             var feature_group_sub_group_5d1fde5a17984650ea567e54341dbabd = L.featureGroup.subGroup(
#                 feature_group_e5dc9b8895fe42489d02d9616cb1bce3
#             );
#
#
#             var marker_a8954f122fac43c874b6e29f5ee9ce15 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d1fde5a17984650ea567e54341dbabd);
#
#
#         var popup_18b2dd8c2d3cb2620c04c343ea62c34d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f2c956f44ff30e924a16e255eb12a52 = $(`&lt;div id=&quot;html_5f2c956f44ff30e924a16e255eb12a52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_18b2dd8c2d3cb2620c04c343ea62c34d.setContent(html_5f2c956f44ff30e924a16e255eb12a52);
#
#
#
#         marker_a8954f122fac43c874b6e29f5ee9ce15.bindPopup(popup_18b2dd8c2d3cb2620c04c343ea62c34d)
#         ;
#
#
#
#
#             var marker_bc6878a8cc69576848d04fecac8183a6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d1fde5a17984650ea567e54341dbabd);
#
#
#         var popup_af113832f95a3d68dfb21ed480d01f6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf87c01fdad20466153582faedd10177 = $(`&lt;div id=&quot;html_cf87c01fdad20466153582faedd10177&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_af113832f95a3d68dfb21ed480d01f6b.setContent(html_cf87c01fdad20466153582faedd10177);
#
#
#
#         marker_bc6878a8cc69576848d04fecac8183a6.bindPopup(popup_af113832f95a3d68dfb21ed480d01f6b)
#         ;
#
#
#
#
#             var marker_28bb1e26ef85d028b73b640ae1168f7a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d1fde5a17984650ea567e54341dbabd);
#
#
#         var popup_f47c6ce47c595434dd2ddfa33b85e008 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba15941217b7f61b1c714724573b2c37 = $(`&lt;div id=&quot;html_ba15941217b7f61b1c714724573b2c37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f47c6ce47c595434dd2ddfa33b85e008.setContent(html_ba15941217b7f61b1c714724573b2c37);
#
#
#
#         marker_28bb1e26ef85d028b73b640ae1168f7a.bindPopup(popup_f47c6ce47c595434dd2ddfa33b85e008)
#         ;
#
#
#
#
#             var marker_97e392c3fd4a5107330c1946b0330e67 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5d1fde5a17984650ea567e54341dbabd);
#
#
#         var popup_19c611132b381f852dc15fb868851532 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8867aeee7ea97433b4552365ba0932be = $(`&lt;div id=&quot;html_8867aeee7ea97433b4552365ba0932be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_19c611132b381f852dc15fb868851532.setContent(html_8867aeee7ea97433b4552365ba0932be);
#
#
#
#         marker_
