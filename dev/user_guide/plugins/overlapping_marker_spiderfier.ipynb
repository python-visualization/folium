# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f83f12051c07256329b0e43a8bacf4e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f83f12051c07256329b0e43a8bacf4e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f83f12051c07256329b0e43a8bacf4e = L.map(
#                 &quot;map_5f83f12051c07256329b0e43a8bacf4e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0756b69f89722e1191c1523d0481f5a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0756b69f89722e1191c1523d0481f5a.addTo(map_5f83f12051c07256329b0e43a8bacf4e);
#
#
#             var marker_66baeee39151be9af564018e56ba2235 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5f83f12051c07256329b0e43a8bacf4e);
#
#
#         var popup_a05752d70ce2ea612b7d7e4ec5f662b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c557483a8f896f2105b948bed929dcc = $(`&lt;div id=&quot;html_0c557483a8f896f2105b948bed929dcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a05752d70ce2ea612b7d7e4ec5f662b1.setContent(html_0c557483a8f896f2105b948bed929dcc);
#
#
#
#         marker_66baeee39151be9af564018e56ba2235.bindPopup(popup_a05752d70ce2ea612b7d7e4ec5f662b1)
#         ;
#
#
#
#
#             var marker_fbde27b48889ad8dc341003366ec1c69 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5f83f12051c07256329b0e43a8bacf4e);
#
#
#         var popup_2250b16d29652418657f3f8095bff36b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ba4562e570db1e791debb563090ea75 = $(`&lt;div id=&quot;html_2ba4562e570db1e791debb563090ea75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2250b16d29652418657f3f8095bff36b.setContent(html_2ba4562e570db1e791debb563090ea75);
#
#
#
#         marker_fbde27b48889ad8dc341003366ec1c69.bindPopup(popup_2250b16d29652418657f3f8095bff36b)
#         ;
#
#
#
#
#             var marker_ee2a8caeb28d4d296528bce15dc7a9c8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5f83f12051c07256329b0e43a8bacf4e);
#
#
#         var popup_3e2cd182b44556045b5cab1ed4bfd415 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c12ef62f31fb6eb29d97795b3ae8c521 = $(`&lt;div id=&quot;html_c12ef62f31fb6eb29d97795b3ae8c521&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3e2cd182b44556045b5cab1ed4bfd415.setContent(html_c12ef62f31fb6eb29d97795b3ae8c521);
#
#
#
#         marker_ee2a8caeb28d4d296528bce15dc7a9c8.bindPopup(popup_3e2cd182b44556045b5cab1ed4bfd415)
#         ;
#
#
#
#
#             var marker_8fd8ef14e74e9757318c2d679e2b43d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5f83f12051c07256329b0e43a8bacf4e);
#
#
#         var popup_fde1a44f85481bcb18a327b8871efd10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb33b5f5b3805e2d52e209fdd3ab9b24 = $(`&lt;div id=&quot;html_bb33b5f5b3805e2d52e209fdd3ab9b24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fde1a44f85481bcb18a327b8871efd10.setContent(html_bb33b5f5b3805e2d52e209fdd3ab9b24);
#
#
#
#         marker_8fd8ef14e74e9757318c2d679e2b43d6.bindPopup(popup_fde1a44f85481bcb18a327b8871efd10)
#         ;
#
#
#
#
#             var marker_590a74618a6c4f211854ca7f720ac9c2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5f83f12051c07256329b0e43a8bacf4e);
#
#
#         var popup_e01845a13b8e139986941cc2969f4660 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22a71f02d16ac85080d3de05e2d82d74 = $(`&lt;div id=&quot;html_22a71f02d16ac85080d3de05e2d82d74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e01845a13b8e139986941cc2969f4660.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_766cd26b64f15bae3f8066788f0ecba9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_766cd26b64f15bae3f8066788f0ecba9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_766cd26b64f15bae3f8066788f0ecba9 = L.map(
#                 &quot;map_766cd26b64f15bae3f8066788f0ecba9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00748d883cb0f6c19c7a84917abaffb4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_00748d883cb0f6c19c7a84917abaffb4.addTo(map_766cd26b64f15bae3f8066788f0ecba9);
#
#
#             var feature_group_2b3d6619de0fc5529b8ea9c23e6eb9d9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7a11e6659fe95acd0238a29283867f97 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2b3d6619de0fc5529b8ea9c23e6eb9d9);
#
#
#         var popup_0fe0c7bf84d81ce7992d0e219e3c8ef7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93d5b570814dd0049a84d93dd238cf98 = $(`&lt;div id=&quot;html_93d5b570814dd0049a84d93dd238cf98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0fe0c7bf84d81ce7992d0e219e3c8ef7.setContent(html_93d5b570814dd0049a84d93dd238cf98);
#
#
#
#         marker_7a11e6659fe95acd0238a29283867f97.bindPopup(popup_0fe0c7bf84d81ce7992d0e219e3c8ef7)
#         ;
#
#
#
#
#             var marker_241eaa05dbe2177ccaed7fa7f99638f3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2b3d6619de0fc5529b8ea9c23e6eb9d9);
#
#
#         var popup_04d8c74ad00809a450820a2496c969d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d3b06f985e78040e4d12c32b3bd4fb2 = $(`&lt;div id=&quot;html_0d3b06f985e78040e4d12c32b3bd4fb2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_04d8c74ad00809a450820a2496c969d6.setContent(html_0d3b06f985e78040e4d12c32b3bd4fb2);
#
#
#
#         marker_241eaa05dbe2177ccaed7fa7f99638f3.bindPopup(popup_04d8c74ad00809a450820a2496c969d6)
#         ;
#
#
#
#
#             var marker_67bb20380f0025c052934e93165c3542 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2b3d6619de0fc5529b8ea9c23e6eb9d9);
#
#
#         var popup_87c0ebb2e325dea086d1ab3b3a2d413a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f5717934585ac8d1d3911fd597dfab9 = $(`&lt;div id=&quot;html_7f5717934585ac8d1d3911fd597dfab9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_87c0ebb2e325dea086d1ab3b3a2d413a.setContent(html_7f5717934585ac8d1d3911fd597dfab9);
#
#
#
#         marker_67bb20380f0025c052934e93165c3542.bindPopup(popup_87c0ebb2e325dea086d1ab3b3a2d413a)
#         ;
#
#
#
#
#             var marker_e86055f2134b42fce02181557ab85f49 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2b3d6619de0fc5529b8ea9c23e6eb9d9);
#
#
#         var popup_5f39db6b3dd6e4f7b260dbd331860c76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5cf119dbb2df632145311a4305cf621 = $(`&lt;div id=&quot;html_e5cf119dbb2df632145311a4305cf621&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5f39db6b3dd6e4f7b260dbd331860c76.setContent(html_e5cf119dbb2df632145311a4305cf621);
#
#
#
#         marker_e86055f2134b42fce02181557ab85f49.bindPopup(popup_5f39db6b3dd6e4f7b260dbd331860c76)
#         ;
#
#
#
#
#             var marker_53536c06418a4cfae2008ca1835fd7eb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2b3d6619de0fc5529b8ea9c23e6eb9d9);
#
#
#         var popup_38bc0448c4ab703c778e8c993503fdd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_335006d4e7d2e47896a6ee4d98fe3371 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_335006d4e7d2e47896a6ee4d98fe3371&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_335006d4e7d2e47896a6ee4d98fe3371 = L.map(
#                 &quot;map_335006d4e7d2e47896a6ee4d98fe3371&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1081feaa889a9db48b030b3d0022493 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a1081feaa889a9db48b030b3d0022493.addTo(map_335006d4e7d2e47896a6ee4d98fe3371);
#
#
#             var feature_group_87e4b814f2171969d1885ca306ba2d39 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_87e4b814f2171969d1885ca306ba2d39.addTo(map_335006d4e7d2e47896a6ee4d98fe3371);
#
#
#             var feature_group_sub_group_501614ae650d771bee74b222a7a255c9 = L.featureGroup.subGroup(
#                 feature_group_87e4b814f2171969d1885ca306ba2d39
#             );
#
#
#             var marker_741cd83f2855db4ad3c1f033859202c7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_501614ae650d771bee74b222a7a255c9);
#
#
#         var popup_2734b9b51cc73e87f4b0c0a5730b66c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd8a2969d5242996530c47788f342514 = $(`&lt;div id=&quot;html_fd8a2969d5242996530c47788f342514&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2734b9b51cc73e87f4b0c0a5730b66c0.setContent(html_fd8a2969d5242996530c47788f342514);
#
#
#
#         marker_741cd83f2855db4ad3c1f033859202c7.bindPopup(popup_2734b9b51cc73e87f4b0c0a5730b66c0)
#         ;
#
#
#
#
#             var marker_81d6804b675b194e6304e8c2893db1e5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_501614ae650d771bee74b222a7a255c9);
#
#
#         var popup_53bfd6a6cbc3a53b580352d2f2cc86bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eec029f968ba9d76d86750c1fc37a4ba = $(`&lt;div id=&quot;html_eec029f968ba9d76d86750c1fc37a4ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_53bfd6a6cbc3a53b580352d2f2cc86bd.setContent(html_eec029f968ba9d76d86750c1fc37a4ba);
#
#
#
#         marker_81d6804b675b194e6304e8c2893db1e5.bindPopup(popup_53bfd6a6cbc3a53b580352d2f2cc86bd)
#         ;
#
#
#
#
#             var marker_64cd103a191c40c80af990b6f23f4983 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_501614ae650d771bee74b222a7a255c9);
#
#
#         var popup_d8b62d21e70622c3b39c8df8dc8d8d17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4b3c21dce3d6ee00255e22fd73f32b3 = $(`&lt;div id=&quot;html_a4b3c21dce3d6ee00255e22fd73f32b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d8b62d21e70622c3b39c8df8dc8d8d17.setContent(html_a4b3c21dce3d6ee00255e22fd73f32b3);
#
#
#
#         marker_64cd103a191c40c80af990b6f23f4983.bindPopup(popup_d8b62d21e70622c3b39c8df8dc8d8d17)
#         ;
#
#
#
#
#             var marker_8fab0f446fcf59586e7db3b09f833bef = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_501614ae650d771bee74b222a7a255c9);
#
#
#         var popup_386669cf8227ce7e2f665895c9d8d4c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8a13253fb1bc5d34cf14c9fa60c7cfa = $(`&lt;div id=&quot;html_a8a13253fb1bc5d34cf14c9fa60c7cfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_386669cf8227ce7e2f665895c9d8d4c3.setContent(html_a8a13253fb1bc5d34cf14c9fa60c7cfa);
#
#
#
#         marker_
