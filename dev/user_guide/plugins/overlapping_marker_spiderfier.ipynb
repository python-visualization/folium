# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4e101cdb9923a8be11b6d32e661c012 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4e101cdb9923a8be11b6d32e661c012&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4e101cdb9923a8be11b6d32e661c012 = L.map(
#                 &quot;map_c4e101cdb9923a8be11b6d32e661c012&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d1c15ef30a2164f9d47b3be27ab8c7c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d1c15ef30a2164f9d47b3be27ab8c7c.addTo(map_c4e101cdb9923a8be11b6d32e661c012);
#
#
#             var marker_53b11d537e09b110e73d1339a8e28c44 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c4e101cdb9923a8be11b6d32e661c012);
#
#
#         var popup_e613370a5be44b71203c676b24a01e46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3f06ff01abae6e3e8f9b3ca0f90db60 = $(`&lt;div id=&quot;html_b3f06ff01abae6e3e8f9b3ca0f90db60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e613370a5be44b71203c676b24a01e46.setContent(html_b3f06ff01abae6e3e8f9b3ca0f90db60);
#
#
#
#         marker_53b11d537e09b110e73d1339a8e28c44.bindPopup(popup_e613370a5be44b71203c676b24a01e46)
#         ;
#
#
#
#
#             var marker_e1d3e00ec4974194471ece22e4917350 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c4e101cdb9923a8be11b6d32e661c012);
#
#
#         var popup_e5165cd6c21d0142970eaf2a86075a08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_713dbe0f0b6297e45ed1f655809c3d9d = $(`&lt;div id=&quot;html_713dbe0f0b6297e45ed1f655809c3d9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e5165cd6c21d0142970eaf2a86075a08.setContent(html_713dbe0f0b6297e45ed1f655809c3d9d);
#
#
#
#         marker_e1d3e00ec4974194471ece22e4917350.bindPopup(popup_e5165cd6c21d0142970eaf2a86075a08)
#         ;
#
#
#
#
#             var marker_29d7f4ef0d63f497eac06eb845d640ad = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c4e101cdb9923a8be11b6d32e661c012);
#
#
#         var popup_9b7f7f3b7b4d3e62c4487485353f89a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a8b3781f1e7c5797f18c1a660a7b609 = $(`&lt;div id=&quot;html_0a8b3781f1e7c5797f18c1a660a7b609&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9b7f7f3b7b4d3e62c4487485353f89a7.setContent(html_0a8b3781f1e7c5797f18c1a660a7b609);
#
#
#
#         marker_29d7f4ef0d63f497eac06eb845d640ad.bindPopup(popup_9b7f7f3b7b4d3e62c4487485353f89a7)
#         ;
#
#
#
#
#             var marker_2ff8739c0601a4cc99736d5b1f9fffa5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c4e101cdb9923a8be11b6d32e661c012);
#
#
#         var popup_cfcdeae16cf236b299da77392fe448c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5252a540a35c271894f4120d10d13565 = $(`&lt;div id=&quot;html_5252a540a35c271894f4120d10d13565&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cfcdeae16cf236b299da77392fe448c9.setContent(html_5252a540a35c271894f4120d10d13565);
#
#
#
#         marker_2ff8739c0601a4cc99736d5b1f9fffa5.bindPopup(popup_cfcdeae16cf236b299da77392fe448c9)
#         ;
#
#
#
#
#             var marker_4b71fe075d56b132420b6aa07636c6be = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c4e101cdb9923a8be11b6d32e661c012);
#
#
#         var popup_0eff8c5c2a9df242c4ff5379e687d4d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_960e2131aa3af050c6796d69422d5340 = $(`&lt;div id=&quot;html_960e2131aa3af050c6796d69422d5340&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0eff8c5c2a9df242c4ff5379e687d4d8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3297f2658caee80ac6f0aa3531aa1bf1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3297f2658caee80ac6f0aa3531aa1bf1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3297f2658caee80ac6f0aa3531aa1bf1 = L.map(
#                 &quot;map_3297f2658caee80ac6f0aa3531aa1bf1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e0457cf11b820646883407f140196b3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e0457cf11b820646883407f140196b3e.addTo(map_3297f2658caee80ac6f0aa3531aa1bf1);
#
#
#             var feature_group_2d92e021032fa852dd09b08761ed957b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_22af0d7a06d4de30009cc44a6fc2b380 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2d92e021032fa852dd09b08761ed957b);
#
#
#         var popup_2d85f2f833d49de533c85969bfbb2951 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d33c5453badb00f6c4bed8f4f774856e = $(`&lt;div id=&quot;html_d33c5453badb00f6c4bed8f4f774856e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2d85f2f833d49de533c85969bfbb2951.setContent(html_d33c5453badb00f6c4bed8f4f774856e);
#
#
#
#         marker_22af0d7a06d4de30009cc44a6fc2b380.bindPopup(popup_2d85f2f833d49de533c85969bfbb2951)
#         ;
#
#
#
#
#             var marker_e37ba64c2aed525699d3dae97811d94d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2d92e021032fa852dd09b08761ed957b);
#
#
#         var popup_e747a01666df799ecbad604f08170db3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d44a2eecb07b9a0af30ff21ae218ccfd = $(`&lt;div id=&quot;html_d44a2eecb07b9a0af30ff21ae218ccfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e747a01666df799ecbad604f08170db3.setContent(html_d44a2eecb07b9a0af30ff21ae218ccfd);
#
#
#
#         marker_e37ba64c2aed525699d3dae97811d94d.bindPopup(popup_e747a01666df799ecbad604f08170db3)
#         ;
#
#
#
#
#             var marker_acbc9c7af11da6b3a7cd7192e3795f3f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2d92e021032fa852dd09b08761ed957b);
#
#
#         var popup_49132f3c600c73292af51a3485e1f438 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_529f41a5596e55b09a6ad3ec10089cf0 = $(`&lt;div id=&quot;html_529f41a5596e55b09a6ad3ec10089cf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_49132f3c600c73292af51a3485e1f438.setContent(html_529f41a5596e55b09a6ad3ec10089cf0);
#
#
#
#         marker_acbc9c7af11da6b3a7cd7192e3795f3f.bindPopup(popup_49132f3c600c73292af51a3485e1f438)
#         ;
#
#
#
#
#             var marker_ed8744b46d671a4feb38b22efece46fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2d92e021032fa852dd09b08761ed957b);
#
#
#         var popup_f4b6dd49ddf306d12a60fe3c2ce73f3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcdfc8461a0e39d2a4af7d0333c8afb1 = $(`&lt;div id=&quot;html_bcdfc8461a0e39d2a4af7d0333c8afb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f4b6dd49ddf306d12a60fe3c2ce73f3c.setContent(html_bcdfc8461a0e39d2a4af7d0333c8afb1);
#
#
#
#         marker_ed8744b46d671a4feb38b22efece46fc.bindPopup(popup_f4b6dd49ddf306d12a60fe3c2ce73f3c)
#         ;
#
#
#
#
#             var marker_70f4e15d792801e911c2dc21f4de0c14 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2d92e021032fa852dd09b08761ed957b);
#
#
#         var popup_538a2a43b757f4530fc6546dff503fa4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_27c19fa47964d164141245da8cc89d03 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_27c19fa47964d164141245da8cc89d03&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_27c19fa47964d164141245da8cc89d03 = L.map(
#                 &quot;map_27c19fa47964d164141245da8cc89d03&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e843eea6f094731272499358d4c5175 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e843eea6f094731272499358d4c5175.addTo(map_27c19fa47964d164141245da8cc89d03);
#
#
#             var feature_group_c445345a45227d77cfe0ff82d18b7e04 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c445345a45227d77cfe0ff82d18b7e04.addTo(map_27c19fa47964d164141245da8cc89d03);
#
#
#             var feature_group_sub_group_6f6ada83aa86a47c6c71b4ed44dd3d2d = L.featureGroup.subGroup(
#                 feature_group_c445345a45227d77cfe0ff82d18b7e04
#             );
#
#
#             var marker_1fcbbe4ce6f8023a2633277564349cc1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6f6ada83aa86a47c6c71b4ed44dd3d2d);
#
#
#         var popup_f2a55068cc60d801f7d0db10c8c159f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d172ff40b809ace9b7cf4f6038345d9a = $(`&lt;div id=&quot;html_d172ff40b809ace9b7cf4f6038345d9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f2a55068cc60d801f7d0db10c8c159f1.setContent(html_d172ff40b809ace9b7cf4f6038345d9a);
#
#
#
#         marker_1fcbbe4ce6f8023a2633277564349cc1.bindPopup(popup_f2a55068cc60d801f7d0db10c8c159f1)
#         ;
#
#
#
#
#             var marker_ecf4b7cdbcb02356d3598a1227d8a66f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6f6ada83aa86a47c6c71b4ed44dd3d2d);
#
#
#         var popup_7527f786f9c9d9f46e524e08aa5b65fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8571f8b9a242d5e0ebbffd611ef30c2 = $(`&lt;div id=&quot;html_f8571f8b9a242d5e0ebbffd611ef30c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7527f786f9c9d9f46e524e08aa5b65fe.setContent(html_f8571f8b9a242d5e0ebbffd611ef30c2);
#
#
#
#         marker_ecf4b7cdbcb02356d3598a1227d8a66f.bindPopup(popup_7527f786f9c9d9f46e524e08aa5b65fe)
#         ;
#
#
#
#
#             var marker_22173167bfc34444196f9ccf180515a9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6f6ada83aa86a47c6c71b4ed44dd3d2d);
#
#
#         var popup_613915d21be2d3b084ed1a84a077bba0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b658acc462f00112077cd7266a5ac446 = $(`&lt;div id=&quot;html_b658acc462f00112077cd7266a5ac446&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_613915d21be2d3b084ed1a84a077bba0.setContent(html_b658acc462f00112077cd7266a5ac446);
#
#
#
#         marker_22173167bfc34444196f9ccf180515a9.bindPopup(popup_613915d21be2d3b084ed1a84a077bba0)
#         ;
#
#
#
#
#             var marker_5ffc553a0ac93dbd84ecddf7a2178dcb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6f6ada83aa86a47c6c71b4ed44dd3d2d);
#
#
#         var popup_b65bc511dd1aed571a74a7972059020a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac74ae155161fa34248dfffb118c01c3 = $(`&lt;div id=&quot;html_ac74ae155161fa34248dfffb118c01c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b65bc511dd1aed571a74a7972059020a.setContent(html_ac74ae155161fa34248dfffb118c01c3);
#
#
#
#         marker_
