# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b3e45b6a673339409f965ddc42c5f7c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b3e45b6a673339409f965ddc42c5f7c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b3e45b6a673339409f965ddc42c5f7c = L.map(
#                 &quot;map_2b3e45b6a673339409f965ddc42c5f7c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e01e38f0747b3d10246be25d32d5e901 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e01e38f0747b3d10246be25d32d5e901.addTo(map_2b3e45b6a673339409f965ddc42c5f7c);
#
#
#             var marker_baad2bad5badb7e7c51164db4e5b72fa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2b3e45b6a673339409f965ddc42c5f7c);
#
#
#         var popup_372b9d9940c79348c08dbb53300f5059 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a23bfaefcfe574f1ebee196e350e262e = $(`&lt;div id=&quot;html_a23bfaefcfe574f1ebee196e350e262e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_372b9d9940c79348c08dbb53300f5059.setContent(html_a23bfaefcfe574f1ebee196e350e262e);
#
#
#
#         marker_baad2bad5badb7e7c51164db4e5b72fa.bindPopup(popup_372b9d9940c79348c08dbb53300f5059)
#         ;
#
#
#
#
#             var marker_651bbc19dc079236eb0b3ee5307563df = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2b3e45b6a673339409f965ddc42c5f7c);
#
#
#         var popup_4e31fcfff65d1ce90ddbe983bfc912af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08b0aa111d5b8089ffe15319ee0a1f2b = $(`&lt;div id=&quot;html_08b0aa111d5b8089ffe15319ee0a1f2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4e31fcfff65d1ce90ddbe983bfc912af.setContent(html_08b0aa111d5b8089ffe15319ee0a1f2b);
#
#
#
#         marker_651bbc19dc079236eb0b3ee5307563df.bindPopup(popup_4e31fcfff65d1ce90ddbe983bfc912af)
#         ;
#
#
#
#
#             var marker_2f70cc30f7633c2dde0e31fdd9d12ae1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2b3e45b6a673339409f965ddc42c5f7c);
#
#
#         var popup_67966324132224f810008da601836d57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fc66d8539757b9ff82b200efd5121c0 = $(`&lt;div id=&quot;html_5fc66d8539757b9ff82b200efd5121c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_67966324132224f810008da601836d57.setContent(html_5fc66d8539757b9ff82b200efd5121c0);
#
#
#
#         marker_2f70cc30f7633c2dde0e31fdd9d12ae1.bindPopup(popup_67966324132224f810008da601836d57)
#         ;
#
#
#
#
#             var marker_20a6aa4a90668267b956b6d513a93e9c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2b3e45b6a673339409f965ddc42c5f7c);
#
#
#         var popup_6945e9f6022f87f00824e65734dc29e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_591f805d93cd694871617964518da011 = $(`&lt;div id=&quot;html_591f805d93cd694871617964518da011&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6945e9f6022f87f00824e65734dc29e7.setContent(html_591f805d93cd694871617964518da011);
#
#
#
#         marker_20a6aa4a90668267b956b6d513a93e9c.bindPopup(popup_6945e9f6022f87f00824e65734dc29e7)
#         ;
#
#
#
#
#             var marker_da045ef17c226add67d476dbba74c9b4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2b3e45b6a673339409f965ddc42c5f7c);
#
#
#         var popup_b6de26e810121a7888bd2312c4b8a380 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82fce01570f4deb1ea33e5880b05270e = $(`&lt;div id=&quot;html_82fce01570f4deb1ea33e5880b05270e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b6de26e810121a7888bd2312c4b8a380.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ba0cf78342eaee8cc29097eb149c5711 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ba0cf78342eaee8cc29097eb149c5711&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ba0cf78342eaee8cc29097eb149c5711 = L.map(
#                 &quot;map_ba0cf78342eaee8cc29097eb149c5711&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_be149269010d3c4a2698abc967a3db33 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_be149269010d3c4a2698abc967a3db33.addTo(map_ba0cf78342eaee8cc29097eb149c5711);
#
#
#             var feature_group_5e86f4aec9c87b8afa59521021de4768 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_24fe19e4ba0c23df0e2031b03f0d2610 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5e86f4aec9c87b8afa59521021de4768);
#
#
#         var popup_b5ed9a6f2a7566f83959837cc885056d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0bc9c03e3472f3bd3ea62a337d6087f9 = $(`&lt;div id=&quot;html_0bc9c03e3472f3bd3ea62a337d6087f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b5ed9a6f2a7566f83959837cc885056d.setContent(html_0bc9c03e3472f3bd3ea62a337d6087f9);
#
#
#
#         marker_24fe19e4ba0c23df0e2031b03f0d2610.bindPopup(popup_b5ed9a6f2a7566f83959837cc885056d)
#         ;
#
#
#
#
#             var marker_124af9fd20900b85c7887f578b51712d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5e86f4aec9c87b8afa59521021de4768);
#
#
#         var popup_9ddf592706a790901ae648822b7c95a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94e30dd7b0f7ac4df2c503ab988cea58 = $(`&lt;div id=&quot;html_94e30dd7b0f7ac4df2c503ab988cea58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9ddf592706a790901ae648822b7c95a0.setContent(html_94e30dd7b0f7ac4df2c503ab988cea58);
#
#
#
#         marker_124af9fd20900b85c7887f578b51712d.bindPopup(popup_9ddf592706a790901ae648822b7c95a0)
#         ;
#
#
#
#
#             var marker_836277e1ff9574e8670613b9ef43a93e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5e86f4aec9c87b8afa59521021de4768);
#
#
#         var popup_2ef616950b8ec78b0504311ef9d965c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13c90716ac471986527d81a5e035064a = $(`&lt;div id=&quot;html_13c90716ac471986527d81a5e035064a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2ef616950b8ec78b0504311ef9d965c6.setContent(html_13c90716ac471986527d81a5e035064a);
#
#
#
#         marker_836277e1ff9574e8670613b9ef43a93e.bindPopup(popup_2ef616950b8ec78b0504311ef9d965c6)
#         ;
#
#
#
#
#             var marker_3cba6670c52b627877ff46c264703300 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5e86f4aec9c87b8afa59521021de4768);
#
#
#         var popup_d9ab4a868add2a4f3f81ac9647e48cd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fadf5347a135a0352be7542b52369ecd = $(`&lt;div id=&quot;html_fadf5347a135a0352be7542b52369ecd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d9ab4a868add2a4f3f81ac9647e48cd2.setContent(html_fadf5347a135a0352be7542b52369ecd);
#
#
#
#         marker_3cba6670c52b627877ff46c264703300.bindPopup(popup_d9ab4a868add2a4f3f81ac9647e48cd2)
#         ;
#
#
#
#
#             var marker_d81b042974dbcc423891c6096a5d0c1b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5e86f4aec9c87b8afa59521021de4768);
#
#
#         var popup_18d15410739845388a68f2f38f08a7e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83bf9ce97e064c00d5851f510a2b0994 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83bf9ce97e064c00d5851f510a2b0994&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83bf9ce97e064c00d5851f510a2b0994 = L.map(
#                 &quot;map_83bf9ce97e064c00d5851f510a2b0994&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1b8f48954cb7a98b4e62b78ca603666 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d1b8f48954cb7a98b4e62b78ca603666.addTo(map_83bf9ce97e064c00d5851f510a2b0994);
#
#
#             var feature_group_b117aa78ecf74483f2d9959eb23ce9a8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b117aa78ecf74483f2d9959eb23ce9a8.addTo(map_83bf9ce97e064c00d5851f510a2b0994);
#
#
#             var feature_group_sub_group_8e244d286a844929b6db2063521c47e4 = L.featureGroup.subGroup(
#                 feature_group_b117aa78ecf74483f2d9959eb23ce9a8
#             );
#
#
#             var marker_efa8505ae356fbdef50e892806548af6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e244d286a844929b6db2063521c47e4);
#
#
#         var popup_741d6ac93b7baee4a155a0d7e8b2a068 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce638a15beabb6741361f21c1aa63edf = $(`&lt;div id=&quot;html_ce638a15beabb6741361f21c1aa63edf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_741d6ac93b7baee4a155a0d7e8b2a068.setContent(html_ce638a15beabb6741361f21c1aa63edf);
#
#
#
#         marker_efa8505ae356fbdef50e892806548af6.bindPopup(popup_741d6ac93b7baee4a155a0d7e8b2a068)
#         ;
#
#
#
#
#             var marker_874f98dd5fdc264593496c74f7ad7952 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e244d286a844929b6db2063521c47e4);
#
#
#         var popup_1f7daeaff802be02974a196cdaa108be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_977df5f1fdb3ca9b7d05223ea0c0c5bc = $(`&lt;div id=&quot;html_977df5f1fdb3ca9b7d05223ea0c0c5bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1f7daeaff802be02974a196cdaa108be.setContent(html_977df5f1fdb3ca9b7d05223ea0c0c5bc);
#
#
#
#         marker_874f98dd5fdc264593496c74f7ad7952.bindPopup(popup_1f7daeaff802be02974a196cdaa108be)
#         ;
#
#
#
#
#             var marker_30514774855e645dc98e725166779721 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e244d286a844929b6db2063521c47e4);
#
#
#         var popup_872f60a866725b60669228e953134abf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8102eae719b2039bb2326dea357ce5a = $(`&lt;div id=&quot;html_f8102eae719b2039bb2326dea357ce5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_872f60a866725b60669228e953134abf.setContent(html_f8102eae719b2039bb2326dea357ce5a);
#
#
#
#         marker_30514774855e645dc98e725166779721.bindPopup(popup_872f60a866725b60669228e953134abf)
#         ;
#
#
#
#
#             var marker_7b45c5d25056b07570e639d432a8ee58 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8e244d286a844929b6db2063521c47e4);
#
#
#         var popup_7491bb37f9b4e0ae4f87bb6b53f27039 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29113fe7d15a4bfb0a942523b31c7961 = $(`&lt;div id=&quot;html_29113fe7d15a4bfb0a942523b31c7961&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7491bb37f9b4e0ae4f87bb6b53f27039.setContent(html_29113fe7d15a4bfb0a942523b31c7961);
#
#
#
#         marker_
