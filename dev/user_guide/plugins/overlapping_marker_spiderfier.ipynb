# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3aa54b8ee1d3804d2c8437ed04c92ccd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3aa54b8ee1d3804d2c8437ed04c92ccd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3aa54b8ee1d3804d2c8437ed04c92ccd = L.map(
#                 &quot;map_3aa54b8ee1d3804d2c8437ed04c92ccd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7109f0e64ddf8d4f504888db7a1e2528 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7109f0e64ddf8d4f504888db7a1e2528.addTo(map_3aa54b8ee1d3804d2c8437ed04c92ccd);
#
#
#             var marker_0ad52d73d85b6e1d731bfd278dfe6e91 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3aa54b8ee1d3804d2c8437ed04c92ccd);
#
#
#         var popup_6911b9d37e5b81ae00c774e922570031 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c22702bea207a7f069a963b22b1ea66 = $(`&lt;div id=&quot;html_5c22702bea207a7f069a963b22b1ea66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6911b9d37e5b81ae00c774e922570031.setContent(html_5c22702bea207a7f069a963b22b1ea66);
#
#
#
#         marker_0ad52d73d85b6e1d731bfd278dfe6e91.bindPopup(popup_6911b9d37e5b81ae00c774e922570031)
#         ;
#
#
#
#
#             var marker_b4f6c1e627993e00f869d0e3e6998244 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3aa54b8ee1d3804d2c8437ed04c92ccd);
#
#
#         var popup_7c36f95e19a4cd6fa5be0131092b278f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6776ded84f9a04d19b24a3043f552748 = $(`&lt;div id=&quot;html_6776ded84f9a04d19b24a3043f552748&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7c36f95e19a4cd6fa5be0131092b278f.setContent(html_6776ded84f9a04d19b24a3043f552748);
#
#
#
#         marker_b4f6c1e627993e00f869d0e3e6998244.bindPopup(popup_7c36f95e19a4cd6fa5be0131092b278f)
#         ;
#
#
#
#
#             var marker_b6fa2030f343484e0f25d824af7baa5f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3aa54b8ee1d3804d2c8437ed04c92ccd);
#
#
#         var popup_c188c65e8723eee7f7c1ecb7c16886ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eddb68d42cd0ad7ed56bbce2e7f2e8a0 = $(`&lt;div id=&quot;html_eddb68d42cd0ad7ed56bbce2e7f2e8a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c188c65e8723eee7f7c1ecb7c16886ae.setContent(html_eddb68d42cd0ad7ed56bbce2e7f2e8a0);
#
#
#
#         marker_b6fa2030f343484e0f25d824af7baa5f.bindPopup(popup_c188c65e8723eee7f7c1ecb7c16886ae)
#         ;
#
#
#
#
#             var marker_8ab25bd935fa28a8102f7ca12d1329f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3aa54b8ee1d3804d2c8437ed04c92ccd);
#
#
#         var popup_d3c3546309bed5f69b8df3ee29af871f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea636f81cf42a1f6d274a8c3e9cbf7e3 = $(`&lt;div id=&quot;html_ea636f81cf42a1f6d274a8c3e9cbf7e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d3c3546309bed5f69b8df3ee29af871f.setContent(html_ea636f81cf42a1f6d274a8c3e9cbf7e3);
#
#
#
#         marker_8ab25bd935fa28a8102f7ca12d1329f4.bindPopup(popup_d3c3546309bed5f69b8df3ee29af871f)
#         ;
#
#
#
#
#             var marker_774a2744e6ab0a6d788b643a0e48b74b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3aa54b8ee1d3804d2c8437ed04c92ccd);
#
#
#         var popup_2ce8281db1e26a93ff985033ddb99c52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f91ae551547b83b13aa8d47a6c8bc262 = $(`&lt;div id=&quot;html_f91ae551547b83b13aa8d47a6c8bc262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2ce8281db1e26a93ff985033ddb99c52.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_65c4666c83f9f9fa1eacef5cbe12b0e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_65c4666c83f9f9fa1eacef5cbe12b0e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_65c4666c83f9f9fa1eacef5cbe12b0e9 = L.map(
#                 &quot;map_65c4666c83f9f9fa1eacef5cbe12b0e9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_257d025fa706c2176183813d568f2390 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_257d025fa706c2176183813d568f2390.addTo(map_65c4666c83f9f9fa1eacef5cbe12b0e9);
#
#
#             var feature_group_113273d2481f48821e7f32f243e2dc60 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_da20a59716129945a1f7651ced713721 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_113273d2481f48821e7f32f243e2dc60);
#
#
#         var popup_4ba03a91d5448e258453c9c78fa18abe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27b4271783a230f1016998eacd99c56d = $(`&lt;div id=&quot;html_27b4271783a230f1016998eacd99c56d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4ba03a91d5448e258453c9c78fa18abe.setContent(html_27b4271783a230f1016998eacd99c56d);
#
#
#
#         marker_da20a59716129945a1f7651ced713721.bindPopup(popup_4ba03a91d5448e258453c9c78fa18abe)
#         ;
#
#
#
#
#             var marker_a2777bb993a220417df2c8c4df62c047 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_113273d2481f48821e7f32f243e2dc60);
#
#
#         var popup_0cc67f17412595b36a0b68dda555add7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02328fba7b04419f14ef8d771b9dc3e2 = $(`&lt;div id=&quot;html_02328fba7b04419f14ef8d771b9dc3e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0cc67f17412595b36a0b68dda555add7.setContent(html_02328fba7b04419f14ef8d771b9dc3e2);
#
#
#
#         marker_a2777bb993a220417df2c8c4df62c047.bindPopup(popup_0cc67f17412595b36a0b68dda555add7)
#         ;
#
#
#
#
#             var marker_d6ad23623963435105cb7077e3837198 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_113273d2481f48821e7f32f243e2dc60);
#
#
#         var popup_b0ca68ecfbb0657398b05fd7852f0896 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13b04fec8ac7325093fd93b4ef531005 = $(`&lt;div id=&quot;html_13b04fec8ac7325093fd93b4ef531005&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b0ca68ecfbb0657398b05fd7852f0896.setContent(html_13b04fec8ac7325093fd93b4ef531005);
#
#
#
#         marker_d6ad23623963435105cb7077e3837198.bindPopup(popup_b0ca68ecfbb0657398b05fd7852f0896)
#         ;
#
#
#
#
#             var marker_e49b62d4e37084727b69db3aa75b365d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_113273d2481f48821e7f32f243e2dc60);
#
#
#         var popup_ee25d3cf6e9192f07e7a54be93d2265d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb609435f3b59e33440b85823dcd7f85 = $(`&lt;div id=&quot;html_cb609435f3b59e33440b85823dcd7f85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ee25d3cf6e9192f07e7a54be93d2265d.setContent(html_cb609435f3b59e33440b85823dcd7f85);
#
#
#
#         marker_e49b62d4e37084727b69db3aa75b365d.bindPopup(popup_ee25d3cf6e9192f07e7a54be93d2265d)
#         ;
#
#
#
#
#             var marker_05709d2a2cff5a0b23833bddda1486f8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_113273d2481f48821e7f32f243e2dc60);
#
#
#         var popup_193d161863aec4c9cd676c734d2aa33a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_29407f152af9bac2c2e751e36688994c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_29407f152af9bac2c2e751e36688994c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_29407f152af9bac2c2e751e36688994c = L.map(
#                 &quot;map_29407f152af9bac2c2e751e36688994c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e8747e96afb8ddcdbc29d2f570689b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5e8747e96afb8ddcdbc29d2f570689b8.addTo(map_29407f152af9bac2c2e751e36688994c);
#
#
#             var feature_group_6bbc54995ffbda5678a7eb6fbd717377 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6bbc54995ffbda5678a7eb6fbd717377.addTo(map_29407f152af9bac2c2e751e36688994c);
#
#
#             var feature_group_sub_group_5f4f1f0e00cd69ae2efa37287b26b3b6 = L.featureGroup.subGroup(
#                 feature_group_6bbc54995ffbda5678a7eb6fbd717377
#             );
#
#
#             var marker_e7b28e9ec20842f99199ff89c5e132de = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f4f1f0e00cd69ae2efa37287b26b3b6);
#
#
#         var popup_4256d8f366bddf67eb4e4dae736617c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a292da5e86c83ba0d7e754e24b8ae00f = $(`&lt;div id=&quot;html_a292da5e86c83ba0d7e754e24b8ae00f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4256d8f366bddf67eb4e4dae736617c8.setContent(html_a292da5e86c83ba0d7e754e24b8ae00f);
#
#
#
#         marker_e7b28e9ec20842f99199ff89c5e132de.bindPopup(popup_4256d8f366bddf67eb4e4dae736617c8)
#         ;
#
#
#
#
#             var marker_cf015effb8b936c69c106b7c758e2de8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f4f1f0e00cd69ae2efa37287b26b3b6);
#
#
#         var popup_c3756e5cea511457c2f0f16403c74c20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_beb0e3d0aa24579f96e33d18af6d472a = $(`&lt;div id=&quot;html_beb0e3d0aa24579f96e33d18af6d472a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c3756e5cea511457c2f0f16403c74c20.setContent(html_beb0e3d0aa24579f96e33d18af6d472a);
#
#
#
#         marker_cf015effb8b936c69c106b7c758e2de8.bindPopup(popup_c3756e5cea511457c2f0f16403c74c20)
#         ;
#
#
#
#
#             var marker_02fdbda39b37ecd479f79f4f00be1bea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f4f1f0e00cd69ae2efa37287b26b3b6);
#
#
#         var popup_27bed2133e3c37eb88e6a29972d0cf4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7878e8a1a8a662edd9c42ca4420de21d = $(`&lt;div id=&quot;html_7878e8a1a8a662edd9c42ca4420de21d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_27bed2133e3c37eb88e6a29972d0cf4b.setContent(html_7878e8a1a8a662edd9c42ca4420de21d);
#
#
#
#         marker_02fdbda39b37ecd479f79f4f00be1bea.bindPopup(popup_27bed2133e3c37eb88e6a29972d0cf4b)
#         ;
#
#
#
#
#             var marker_bd9a815f14da4c19ee8d0ab880eaffac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f4f1f0e00cd69ae2efa37287b26b3b6);
#
#
#         var popup_ca88dce358ac7eb795db981355540767 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64d0b7da19a037a12bf0961adebe931d = $(`&lt;div id=&quot;html_64d0b7da19a037a12bf0961adebe931d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ca88dce358ac7eb795db981355540767.setContent(html_64d0b7da19a037a12bf0961adebe931d);
#
#
#
#         marker_
