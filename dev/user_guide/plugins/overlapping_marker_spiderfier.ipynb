# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90984134010478b1de4b5f2bab45874a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90984134010478b1de4b5f2bab45874a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90984134010478b1de4b5f2bab45874a = L.map(
#                 &quot;map_90984134010478b1de4b5f2bab45874a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ffd63aeee7a9bf94654746f6e429c418 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ffd63aeee7a9bf94654746f6e429c418.addTo(map_90984134010478b1de4b5f2bab45874a);
#
#
#             var marker_c83288052e710e75b9db158b6a0ac088 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_90984134010478b1de4b5f2bab45874a);
#
#
#         var popup_afa9e6a8061f88a9a185444edfbf0257 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3318e8126cb316fc95d78e6ad93d76a4 = $(`&lt;div id=&quot;html_3318e8126cb316fc95d78e6ad93d76a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_afa9e6a8061f88a9a185444edfbf0257.setContent(html_3318e8126cb316fc95d78e6ad93d76a4);
#
#
#
#         marker_c83288052e710e75b9db158b6a0ac088.bindPopup(popup_afa9e6a8061f88a9a185444edfbf0257)
#         ;
#
#
#
#
#             var marker_b66ac70bfcb3e79b031d74fde5e4ce9d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_90984134010478b1de4b5f2bab45874a);
#
#
#         var popup_a2b1f3058ac14a6102bcce90d2a6aa01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de8deedf22472bc5695cfb7259232bcd = $(`&lt;div id=&quot;html_de8deedf22472bc5695cfb7259232bcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a2b1f3058ac14a6102bcce90d2a6aa01.setContent(html_de8deedf22472bc5695cfb7259232bcd);
#
#
#
#         marker_b66ac70bfcb3e79b031d74fde5e4ce9d.bindPopup(popup_a2b1f3058ac14a6102bcce90d2a6aa01)
#         ;
#
#
#
#
#             var marker_c475fb1fd9668cea8e6ee8a4a1b83fdb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_90984134010478b1de4b5f2bab45874a);
#
#
#         var popup_e7f647dab8103f667b817c0408614e62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cebe7f626078feac270ce4bb92b15292 = $(`&lt;div id=&quot;html_cebe7f626078feac270ce4bb92b15292&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e7f647dab8103f667b817c0408614e62.setContent(html_cebe7f626078feac270ce4bb92b15292);
#
#
#
#         marker_c475fb1fd9668cea8e6ee8a4a1b83fdb.bindPopup(popup_e7f647dab8103f667b817c0408614e62)
#         ;
#
#
#
#
#             var marker_7806caad44e21bc4e675148a50af55b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_90984134010478b1de4b5f2bab45874a);
#
#
#         var popup_effcb44c1cbdb044cc8123aae24e5774 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdbffc9821a2e1afa0dbfaa7a6797dbc = $(`&lt;div id=&quot;html_cdbffc9821a2e1afa0dbfaa7a6797dbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_effcb44c1cbdb044cc8123aae24e5774.setContent(html_cdbffc9821a2e1afa0dbfaa7a6797dbc);
#
#
#
#         marker_7806caad44e21bc4e675148a50af55b4.bindPopup(popup_effcb44c1cbdb044cc8123aae24e5774)
#         ;
#
#
#
#
#             var marker_d2607e57a9d051da5c1bb8a1fa6db105 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_90984134010478b1de4b5f2bab45874a);
#
#
#         var popup_e2a4ddc1e47e8ada0b2c84975518a449 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d7c529f48278f4bf440dde065021f5a = $(`&lt;div id=&quot;html_6d7c529f48278f4bf440dde065021f5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e2a4ddc1e47e8ada0b2c84975518a449.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e55d812840995e970faeb52737f0f63c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e55d812840995e970faeb52737f0f63c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e55d812840995e970faeb52737f0f63c = L.map(
#                 &quot;map_e55d812840995e970faeb52737f0f63c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_002b971270906741e19d4fbf767d40ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_002b971270906741e19d4fbf767d40ea.addTo(map_e55d812840995e970faeb52737f0f63c);
#
#
#             var feature_group_a781311da355e71d06b9d4787624827e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5be457e43fd40ad7a4c4872dcfc4d816 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a781311da355e71d06b9d4787624827e);
#
#
#         var popup_d0ebf375d1e0f5b68e30cb32031c2544 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ecdada060c1b23e04dec274003f79ce = $(`&lt;div id=&quot;html_3ecdada060c1b23e04dec274003f79ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d0ebf375d1e0f5b68e30cb32031c2544.setContent(html_3ecdada060c1b23e04dec274003f79ce);
#
#
#
#         marker_5be457e43fd40ad7a4c4872dcfc4d816.bindPopup(popup_d0ebf375d1e0f5b68e30cb32031c2544)
#         ;
#
#
#
#
#             var marker_989064c4d0c15f05415daa6708eac804 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a781311da355e71d06b9d4787624827e);
#
#
#         var popup_42c56c57f7538a9992e794ebdd9eee5a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_355995db29d30f82877ceed8e9940d36 = $(`&lt;div id=&quot;html_355995db29d30f82877ceed8e9940d36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_42c56c57f7538a9992e794ebdd9eee5a.setContent(html_355995db29d30f82877ceed8e9940d36);
#
#
#
#         marker_989064c4d0c15f05415daa6708eac804.bindPopup(popup_42c56c57f7538a9992e794ebdd9eee5a)
#         ;
#
#
#
#
#             var marker_dbb06375458297e1ae34552c0119931a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a781311da355e71d06b9d4787624827e);
#
#
#         var popup_25d2a51aab720374f22f052735efc3db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89aefe058e5e19db0495728be6adf1a6 = $(`&lt;div id=&quot;html_89aefe058e5e19db0495728be6adf1a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_25d2a51aab720374f22f052735efc3db.setContent(html_89aefe058e5e19db0495728be6adf1a6);
#
#
#
#         marker_dbb06375458297e1ae34552c0119931a.bindPopup(popup_25d2a51aab720374f22f052735efc3db)
#         ;
#
#
#
#
#             var marker_1368e0f06bff500c0aca3ce18c21186b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a781311da355e71d06b9d4787624827e);
#
#
#         var popup_f9af40ca3b3cbf8a02b90e2c0ca9c3b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e33dce73b3414e3a9c52fe57e732a590 = $(`&lt;div id=&quot;html_e33dce73b3414e3a9c52fe57e732a590&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f9af40ca3b3cbf8a02b90e2c0ca9c3b7.setContent(html_e33dce73b3414e3a9c52fe57e732a590);
#
#
#
#         marker_1368e0f06bff500c0aca3ce18c21186b.bindPopup(popup_f9af40ca3b3cbf8a02b90e2c0ca9c3b7)
#         ;
#
#
#
#
#             var marker_ed75c3a446e257d037c0ac938b8932c8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a781311da355e71d06b9d4787624827e);
#
#
#         var popup_4329053baefde5f7caecfa256a5cfdef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d280404742a2bc1b6b9bac8b46916b2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d280404742a2bc1b6b9bac8b46916b2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d280404742a2bc1b6b9bac8b46916b2 = L.map(
#                 &quot;map_2d280404742a2bc1b6b9bac8b46916b2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92bd39748769cb727a450f9860444451 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92bd39748769cb727a450f9860444451.addTo(map_2d280404742a2bc1b6b9bac8b46916b2);
#
#
#             var feature_group_d1b148d5e5de53acf011a9ae17e7481a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d1b148d5e5de53acf011a9ae17e7481a.addTo(map_2d280404742a2bc1b6b9bac8b46916b2);
#
#
#             var feature_group_sub_group_7d598faf073ebb1af86e78e22c09d6fd = L.featureGroup.subGroup(
#                 feature_group_d1b148d5e5de53acf011a9ae17e7481a
#             );
#
#
#             var marker_24566dbb2346295b4e97ad819be57af9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d598faf073ebb1af86e78e22c09d6fd);
#
#
#         var popup_ee081e7e69c5be992242ee11653d2c89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39b566e1d08a73b2feea079b8d31fba0 = $(`&lt;div id=&quot;html_39b566e1d08a73b2feea079b8d31fba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ee081e7e69c5be992242ee11653d2c89.setContent(html_39b566e1d08a73b2feea079b8d31fba0);
#
#
#
#         marker_24566dbb2346295b4e97ad819be57af9.bindPopup(popup_ee081e7e69c5be992242ee11653d2c89)
#         ;
#
#
#
#
#             var marker_15256573b8941e93cd9ba8b754f24883 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d598faf073ebb1af86e78e22c09d6fd);
#
#
#         var popup_7da8218e485937c84162d994cc689b29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b26a8552ba765858a111b467a93f3d2 = $(`&lt;div id=&quot;html_6b26a8552ba765858a111b467a93f3d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7da8218e485937c84162d994cc689b29.setContent(html_6b26a8552ba765858a111b467a93f3d2);
#
#
#
#         marker_15256573b8941e93cd9ba8b754f24883.bindPopup(popup_7da8218e485937c84162d994cc689b29)
#         ;
#
#
#
#
#             var marker_fd5231969d6b028499e4fad5caef6afe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d598faf073ebb1af86e78e22c09d6fd);
#
#
#         var popup_3d86a4fb2c334041d10a2dc056d2b25d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56fc9fc72025432d7729364b2ebba2df = $(`&lt;div id=&quot;html_56fc9fc72025432d7729364b2ebba2df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3d86a4fb2c334041d10a2dc056d2b25d.setContent(html_56fc9fc72025432d7729364b2ebba2df);
#
#
#
#         marker_fd5231969d6b028499e4fad5caef6afe.bindPopup(popup_3d86a4fb2c334041d10a2dc056d2b25d)
#         ;
#
#
#
#
#             var marker_ebeab7dd648b81462f3fc17a531f930e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7d598faf073ebb1af86e78e22c09d6fd);
#
#
#         var popup_adefaeebb786f781a01354d9fea140ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd922fcb599c9ee24baecfeaba8796c4 = $(`&lt;div id=&quot;html_dd922fcb599c9ee24baecfeaba8796c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_adefaeebb786f781a01354d9fea140ca.setContent(html_dd922fcb599c9ee24baecfeaba8796c4);
#
#
#
#         marker_
