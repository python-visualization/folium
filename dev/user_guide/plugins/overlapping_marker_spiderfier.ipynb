# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f98a665a6280ab705c9aeabcc8fc32c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f98a665a6280ab705c9aeabcc8fc32c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f98a665a6280ab705c9aeabcc8fc32c = L.map(
#                 &quot;map_4f98a665a6280ab705c9aeabcc8fc32c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4b9ce31439b2051d4419c2827d870af1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4b9ce31439b2051d4419c2827d870af1.addTo(map_4f98a665a6280ab705c9aeabcc8fc32c);
#
#
#             var marker_05fb352a7410f783bc06a8905299ef33 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4f98a665a6280ab705c9aeabcc8fc32c);
#
#
#         var popup_6d17f79a5596cbb3331da921e03e9a90 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f73cf5f03b420e0809655d7298da530b = $(`&lt;div id=&quot;html_f73cf5f03b420e0809655d7298da530b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6d17f79a5596cbb3331da921e03e9a90.setContent(html_f73cf5f03b420e0809655d7298da530b);
#
#
#
#         marker_05fb352a7410f783bc06a8905299ef33.bindPopup(popup_6d17f79a5596cbb3331da921e03e9a90)
#         ;
#
#
#
#
#             var marker_a68b23e6d3aa2d10e93e44c198e0be21 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4f98a665a6280ab705c9aeabcc8fc32c);
#
#
#         var popup_453be85191b6f613cc37f7e74e4b2541 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_957269aede8df802f1df168faeb74c13 = $(`&lt;div id=&quot;html_957269aede8df802f1df168faeb74c13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_453be85191b6f613cc37f7e74e4b2541.setContent(html_957269aede8df802f1df168faeb74c13);
#
#
#
#         marker_a68b23e6d3aa2d10e93e44c198e0be21.bindPopup(popup_453be85191b6f613cc37f7e74e4b2541)
#         ;
#
#
#
#
#             var marker_c57624b968c4ca73bd383a5534d562f1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4f98a665a6280ab705c9aeabcc8fc32c);
#
#
#         var popup_72c8cf6ad05927c9a9f209b50c4711a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2f08148f9a28792b2acd099c6071b5d = $(`&lt;div id=&quot;html_d2f08148f9a28792b2acd099c6071b5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_72c8cf6ad05927c9a9f209b50c4711a5.setContent(html_d2f08148f9a28792b2acd099c6071b5d);
#
#
#
#         marker_c57624b968c4ca73bd383a5534d562f1.bindPopup(popup_72c8cf6ad05927c9a9f209b50c4711a5)
#         ;
#
#
#
#
#             var marker_f4d69f26687a35b1de08643e24134dac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4f98a665a6280ab705c9aeabcc8fc32c);
#
#
#         var popup_1217e9df7a49f49e8e630132cb73a4c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28b3de50a2e4e4fca3749d41848a578d = $(`&lt;div id=&quot;html_28b3de50a2e4e4fca3749d41848a578d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1217e9df7a49f49e8e630132cb73a4c6.setContent(html_28b3de50a2e4e4fca3749d41848a578d);
#
#
#
#         marker_f4d69f26687a35b1de08643e24134dac.bindPopup(popup_1217e9df7a49f49e8e630132cb73a4c6)
#         ;
#
#
#
#
#             var marker_5e49645b8ad1b9d73816308431462242 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4f98a665a6280ab705c9aeabcc8fc32c);
#
#
#         var popup_36b76531111a4482342d16bb257d8ce8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6c4ac114d8150650e070f5b1a8534da = $(`&lt;div id=&quot;html_d6c4ac114d8150650e070f5b1a8534da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_36b76531111a4482342d16bb257d8ce8.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70e07826767ec889865a9664c2c05b48 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70e07826767ec889865a9664c2c05b48&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_70e07826767ec889865a9664c2c05b48 = L.map(
#                 &quot;map_70e07826767ec889865a9664c2c05b48&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38c1dbb5a138e7b47ada9585fd61e8c4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38c1dbb5a138e7b47ada9585fd61e8c4.addTo(map_70e07826767ec889865a9664c2c05b48);
#
#
#             var feature_group_b152139a95d89bc199ef9e9f1cf80129 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_891e8a09c4f8f52f1e125ceec78bd6b3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b152139a95d89bc199ef9e9f1cf80129);
#
#
#         var popup_ea29d17d24fb60f991a738bc25932058 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_662b107ef3ff16d982606684011828f8 = $(`&lt;div id=&quot;html_662b107ef3ff16d982606684011828f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ea29d17d24fb60f991a738bc25932058.setContent(html_662b107ef3ff16d982606684011828f8);
#
#
#
#         marker_891e8a09c4f8f52f1e125ceec78bd6b3.bindPopup(popup_ea29d17d24fb60f991a738bc25932058)
#         ;
#
#
#
#
#             var marker_ba3de22c1f4411f946e7a0acc0f7762e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b152139a95d89bc199ef9e9f1cf80129);
#
#
#         var popup_8c9985cd3eaceaf1c389240a08bfdc71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b57f3ed3c74637839b0de67acc93f277 = $(`&lt;div id=&quot;html_b57f3ed3c74637839b0de67acc93f277&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8c9985cd3eaceaf1c389240a08bfdc71.setContent(html_b57f3ed3c74637839b0de67acc93f277);
#
#
#
#         marker_ba3de22c1f4411f946e7a0acc0f7762e.bindPopup(popup_8c9985cd3eaceaf1c389240a08bfdc71)
#         ;
#
#
#
#
#             var marker_a950c42bdf107365debe0b9e08e5bb9c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b152139a95d89bc199ef9e9f1cf80129);
#
#
#         var popup_c02f58c181ab63f5f43acccadb37ec7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bef26b560f5cef8c580b53de58e02ff = $(`&lt;div id=&quot;html_2bef26b560f5cef8c580b53de58e02ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c02f58c181ab63f5f43acccadb37ec7f.setContent(html_2bef26b560f5cef8c580b53de58e02ff);
#
#
#
#         marker_a950c42bdf107365debe0b9e08e5bb9c.bindPopup(popup_c02f58c181ab63f5f43acccadb37ec7f)
#         ;
#
#
#
#
#             var marker_f3541a28680132a336e8936c6ff1f52c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b152139a95d89bc199ef9e9f1cf80129);
#
#
#         var popup_d8fa894531217aee3a9883c2a4dbfa88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bf75a99561db68cd9cb728a6d648eba = $(`&lt;div id=&quot;html_1bf75a99561db68cd9cb728a6d648eba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d8fa894531217aee3a9883c2a4dbfa88.setContent(html_1bf75a99561db68cd9cb728a6d648eba);
#
#
#
#         marker_f3541a28680132a336e8936c6ff1f52c.bindPopup(popup_d8fa894531217aee3a9883c2a4dbfa88)
#         ;
#
#
#
#
#             var marker_227de0cca6272290c6fcbc988446ae8e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b152139a95d89bc199ef9e9f1cf80129);
#
#
#         var popup_9481ee73c1a9b4e11d18bcc67900fdf3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3ff8967ff0ab241bd41dc1144e41c426 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3ff8967ff0ab241bd41dc1144e41c426&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3ff8967ff0ab241bd41dc1144e41c426 = L.map(
#                 &quot;map_3ff8967ff0ab241bd41dc1144e41c426&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1247ef38fb0ed96325e0ee001065b32c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1247ef38fb0ed96325e0ee001065b32c.addTo(map_3ff8967ff0ab241bd41dc1144e41c426);
#
#
#             var feature_group_bbb0c9dce30e840baad336b103cbbeb4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bbb0c9dce30e840baad336b103cbbeb4.addTo(map_3ff8967ff0ab241bd41dc1144e41c426);
#
#
#             var feature_group_sub_group_4b54283174a43801f4225596c4400bde = L.featureGroup.subGroup(
#                 feature_group_bbb0c9dce30e840baad336b103cbbeb4
#             );
#
#
#             var marker_5676fc24d953d65fcd1657a739423c35 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b54283174a43801f4225596c4400bde);
#
#
#         var popup_1b3af564b602c1f7bd882c68f7e1c3dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27dbbff303eba38cf67f555c7a69ec6f = $(`&lt;div id=&quot;html_27dbbff303eba38cf67f555c7a69ec6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1b3af564b602c1f7bd882c68f7e1c3dc.setContent(html_27dbbff303eba38cf67f555c7a69ec6f);
#
#
#
#         marker_5676fc24d953d65fcd1657a739423c35.bindPopup(popup_1b3af564b602c1f7bd882c68f7e1c3dc)
#         ;
#
#
#
#
#             var marker_45f64095be71aa61ccc59e53920b0cd8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b54283174a43801f4225596c4400bde);
#
#
#         var popup_df95a8c7149b0259d3e6d16d78d9af56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5fde609a54ffacbd084798e46c65d0a6 = $(`&lt;div id=&quot;html_5fde609a54ffacbd084798e46c65d0a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_df95a8c7149b0259d3e6d16d78d9af56.setContent(html_5fde609a54ffacbd084798e46c65d0a6);
#
#
#
#         marker_45f64095be71aa61ccc59e53920b0cd8.bindPopup(popup_df95a8c7149b0259d3e6d16d78d9af56)
#         ;
#
#
#
#
#             var marker_4ca0274c4fe1fdb7f08d076f80a54824 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b54283174a43801f4225596c4400bde);
#
#
#         var popup_d79eda48c2305ac0759faca3cc728f9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f51b0b09999469bdbe7ea904914d7ef3 = $(`&lt;div id=&quot;html_f51b0b09999469bdbe7ea904914d7ef3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d79eda48c2305ac0759faca3cc728f9b.setContent(html_f51b0b09999469bdbe7ea904914d7ef3);
#
#
#
#         marker_4ca0274c4fe1fdb7f08d076f80a54824.bindPopup(popup_d79eda48c2305ac0759faca3cc728f9b)
#         ;
#
#
#
#
#             var marker_c1c4ec97040e00aa717b2450bf2e85f9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4b54283174a43801f4225596c4400bde);
#
#
#         var popup_8533dbcfd8334d7464b3f0cd81e4e6c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bce83bcadf020a4d85dc31a42e65783 = $(`&lt;div id=&quot;html_8bce83bcadf020a4d85dc31a42e65783&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8533dbcfd8334d7464b3f0cd81e4e6c0.setContent(html_8bce83bcadf020a4d85dc31a42e65783);
#
#
#
#         marker_
