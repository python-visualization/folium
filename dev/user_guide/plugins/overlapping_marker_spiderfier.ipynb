# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d803cbdb7bae118e9494a627f2157fb {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d803cbdb7bae118e9494a627f2157fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d803cbdb7bae118e9494a627f2157fb = L.map(
#                 &quot;map_3d803cbdb7bae118e9494a627f2157fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_260aee07cf1ca3bf65caef66aabcaec1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_260aee07cf1ca3bf65caef66aabcaec1.addTo(map_3d803cbdb7bae118e9494a627f2157fb);
#
#
#             var marker_f1dc289c8b300c8a795e17708b519eff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3d803cbdb7bae118e9494a627f2157fb);
#
#
#         var popup_b9a1f1516d6ff65ef8251fce6415e4b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3db88c3411fe704da754891ae66284fd = $(`&lt;div id=&quot;html_3db88c3411fe704da754891ae66284fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b9a1f1516d6ff65ef8251fce6415e4b3.setContent(html_3db88c3411fe704da754891ae66284fd);
#
#
#
#         marker_f1dc289c8b300c8a795e17708b519eff.bindPopup(popup_b9a1f1516d6ff65ef8251fce6415e4b3)
#         ;
#
#
#
#
#             var marker_38bed59f5fbd9b21a141a6e9a172444b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3d803cbdb7bae118e9494a627f2157fb);
#
#
#         var popup_5462e1008c538c8599390c26be4044de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6dd4e6de67c5957f8294734bd589dff6 = $(`&lt;div id=&quot;html_6dd4e6de67c5957f8294734bd589dff6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5462e1008c538c8599390c26be4044de.setContent(html_6dd4e6de67c5957f8294734bd589dff6);
#
#
#
#         marker_38bed59f5fbd9b21a141a6e9a172444b.bindPopup(popup_5462e1008c538c8599390c26be4044de)
#         ;
#
#
#
#
#             var marker_dc1bda26cd72a82bc750a7b4b0e5970d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3d803cbdb7bae118e9494a627f2157fb);
#
#
#         var popup_993e93e3e385f270785763b38f89cdde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2cfa2aa0566de4676f9b1a21ea20ebcf = $(`&lt;div id=&quot;html_2cfa2aa0566de4676f9b1a21ea20ebcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_993e93e3e385f270785763b38f89cdde.setContent(html_2cfa2aa0566de4676f9b1a21ea20ebcf);
#
#
#
#         marker_dc1bda26cd72a82bc750a7b4b0e5970d.bindPopup(popup_993e93e3e385f270785763b38f89cdde)
#         ;
#
#
#
#
#             var marker_8e97c88442f4ee1b729a288dc4f2fa20 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3d803cbdb7bae118e9494a627f2157fb);
#
#
#         var popup_adeeaac485584f5856e205913209d10f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7bbc558a3755af56153444b3a8ef9c8 = $(`&lt;div id=&quot;html_c7bbc558a3755af56153444b3a8ef9c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_adeeaac485584f5856e205913209d10f.setContent(html_c7bbc558a3755af56153444b3a8ef9c8);
#
#
#
#         marker_8e97c88442f4ee1b729a288dc4f2fa20.bindPopup(popup_adeeaac485584f5856e205913209d10f)
#         ;
#
#
#
#
#             var marker_a4ae00873c508384c6cff06362a0f2d3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3d803cbdb7bae118e9494a627f2157fb);
#
#
#         var popup_38e44fd9d54746aab5c8e384d2c95f6a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_064e1c682b982874fb025138e9215dae = $(`&lt;div id=&quot;html_064e1c682b982874fb025138e9215dae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_38e44fd9d54746aab5c8e384d2c95f

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab49e9942e5bfe53868e800505083a1f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab49e9942e5bfe53868e800505083a1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab49e9942e5bfe53868e800505083a1f = L.map(
#                 &quot;map_ab49e9942e5bfe53868e800505083a1f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac88fde9aea39ca0f5ca3e1b045a587d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ac88fde9aea39ca0f5ca3e1b045a587d.addTo(map_ab49e9942e5bfe53868e800505083a1f);
#
#
#             var feature_group_e4ad9f3ce5bb3411c1125ae9a36b123b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_372fa1dba59a77cc652aa588262d1349 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e4ad9f3ce5bb3411c1125ae9a36b123b);
#
#
#         var popup_d1646a8698d827cb6b957c285ec321b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_721280ee7737c6e99a1050a22849cc19 = $(`&lt;div id=&quot;html_721280ee7737c6e99a1050a22849cc19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d1646a8698d827cb6b957c285ec321b5.setContent(html_721280ee7737c6e99a1050a22849cc19);
#
#
#
#         marker_372fa1dba59a77cc652aa588262d1349.bindPopup(popup_d1646a8698d827cb6b957c285ec321b5)
#         ;
#
#
#
#
#             var marker_494f3a6f5c85f0a3d6d578586ee54deb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e4ad9f3ce5bb3411c1125ae9a36b123b);
#
#
#         var popup_760c51368fe552a35c3c606deddccc4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_045fb8562002d53aeece2bbea37f4e48 = $(`&lt;div id=&quot;html_045fb8562002d53aeece2bbea37f4e48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_760c51368fe552a35c3c606deddccc4b.setContent(html_045fb8562002d53aeece2bbea37f4e48);
#
#
#
#         marker_494f3a6f5c85f0a3d6d578586ee54deb.bindPopup(popup_760c51368fe552a35c3c606deddccc4b)
#         ;
#
#
#
#
#             var marker_5bc2433b177769927c0015886f86bd45 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e4ad9f3ce5bb3411c1125ae9a36b123b);
#
#
#         var popup_f379014387b2fc6d4b686c2024f99519 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f3dfcf325abfa596afb1302704024c6 = $(`&lt;div id=&quot;html_9f3dfcf325abfa596afb1302704024c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f379014387b2fc6d4b686c2024f99519.setContent(html_9f3dfcf325abfa596afb1302704024c6);
#
#
#
#         marker_5bc2433b177769927c0015886f86bd45.bindPopup(popup_f379014387b2fc6d4b686c2024f99519)
#         ;
#
#
#
#
#             var marker_f6da622ec1a3e7a0f0813c28e3b1193e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e4ad9f3ce5bb3411c1125ae9a36b123b);
#
#
#         var popup_d388b9ce3360cead42a977ffeafc5887 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f95c0e88d1e0e334dcb77fd48e1260b9 = $(`&lt;div id=&quot;html_f95c0e88d1e0e334dcb77fd48e1260b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d388b9ce3360cead42a977ffeafc5887.setContent(html_f95c0e88d1e0e334dcb77fd48e1260b9);
#
#
#
#         marker_f6da622ec1a3e7a0f0813c28e3b1193e.bindPopup(popup_d388b9ce3360cead42a977ffeafc5887)
#         ;
#
#
#
#
#             var marker_8785ec5d46def9a4b6fb042d5d893b6c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e4ad9f3ce5bb3411c1125ae9a36b123b);
#
#
#         var popup_7eeb0767b69cc519326af547569786d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93b811b7ea74902b59863769e868a574 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93b811b7ea74902b59863769e868a574&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93b811b7ea74902b59863769e868a574 = L.map(
#                 &quot;map_93b811b7ea74902b59863769e868a574&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9bb233723a448078528cadb62f9ed9a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b9bb233723a448078528cadb62f9ed9a.addTo(map_93b811b7ea74902b59863769e868a574);
#
#
#             var feature_group_9e2ccf5165bd6efc27bd67c27e968fc3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9e2ccf5165bd6efc27bd67c27e968fc3.addTo(map_93b811b7ea74902b59863769e868a574);
#
#
#             var feature_group_sub_group_7e6b3e181a8a17598bd273fbb4ea0f93 = L.featureGroup.subGroup(
#                 feature_group_9e2ccf5165bd6efc27bd67c27e968fc3
#             );
#
#
#             var marker_67627e6a1c67250826f547e4a55b3c59 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e6b3e181a8a17598bd273fbb4ea0f93);
#
#
#         var popup_a75fc3ef16b47dfec7c341446ab8c531 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b98c29f0a1c6a1b015af6191ccf07f98 = $(`&lt;div id=&quot;html_b98c29f0a1c6a1b015af6191ccf07f98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a75fc3ef16b47dfec7c341446ab8c531.setContent(html_b98c29f0a1c6a1b015af6191ccf07f98);
#
#
#
#         marker_67627e6a1c67250826f547e4a55b3c59.bindPopup(popup_a75fc3ef16b47dfec7c341446ab8c531)
#         ;
#
#
#
#
#             var marker_d39029d6fe6511bcb78a7114dd8fe354 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e6b3e181a8a17598bd273fbb4ea0f93);
#
#
#         var popup_96206aad87585f823c36cc377c63e49c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4324cc9bcfa184b0ee4805eb77df7cd = $(`&lt;div id=&quot;html_e4324cc9bcfa184b0ee4805eb77df7cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_96206aad87585f823c36cc377c63e49c.setContent(html_e4324cc9bcfa184b0ee4805eb77df7cd);
#
#
#
#         marker_d39029d6fe6511bcb78a7114dd8fe354.bindPopup(popup_96206aad87585f823c36cc377c63e49c)
#         ;
#
#
#
#
#             var marker_5f97c5bd97feda7965387076782de233 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e6b3e181a8a17598bd273fbb4ea0f93);
#
#
#         var popup_1dd356795d9a1d7102d71bf6cbdd6df9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_290b9a6321bcc7dd3910d26570cf4f62 = $(`&lt;div id=&quot;html_290b9a6321bcc7dd3910d26570cf4f62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1dd356795d9a1d7102d71bf6cbdd6df9.setContent(html_290b9a6321bcc7dd3910d26570cf4f62);
#
#
#
#         marker_5f97c5bd97feda7965387076782de233.bindPopup(popup_1dd356795d9a1d7102d71bf6cbdd6df9)
#         ;
#
#
#
#
#             var marker_1db93a823be3264b1e13d673ec3f58ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7e6b3e181a8a17598bd273fbb4ea0f93);
#
#
#         var popup_c7aa25b52bec732bbf9ca37e52053433 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_772d964390299c6a3bfe383a2e653313 = $(`&lt;div id=&quot;html_772d964390299c6a3bfe383a2e653313&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c7aa25b52bec732bbf9ca37e52053433.setContent(html_772d964390299c6a3bfe383a2e653313);
#
#
#
#         mark
