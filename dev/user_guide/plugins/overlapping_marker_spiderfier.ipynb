# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43c903d81e726f97153fdc0a93ff15da {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43c903d81e726f97153fdc0a93ff15da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43c903d81e726f97153fdc0a93ff15da = L.map(
#                 &quot;map_43c903d81e726f97153fdc0a93ff15da&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba4148dd27e15427be2472ae6b6acc88 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba4148dd27e15427be2472ae6b6acc88.addTo(map_43c903d81e726f97153fdc0a93ff15da);
#
#
#             var marker_4b5e89b38654d83974dfcd5fb331836c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_43c903d81e726f97153fdc0a93ff15da);
#
#
#         var popup_5f88fe98dc24ad3ecf493690ca2745af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9257b05190f8a0d5a7f6e2d5d80aadc8 = $(`&lt;div id=&quot;html_9257b05190f8a0d5a7f6e2d5d80aadc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5f88fe98dc24ad3ecf493690ca2745af.setContent(html_9257b05190f8a0d5a7f6e2d5d80aadc8);
#
#
#
#         marker_4b5e89b38654d83974dfcd5fb331836c.bindPopup(popup_5f88fe98dc24ad3ecf493690ca2745af)
#         ;
#
#
#
#
#             var marker_763d37e4e6d76a089def5eadb807a80f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_43c903d81e726f97153fdc0a93ff15da);
#
#
#         var popup_169d71c2850dad61e7e739fda4982f13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e584effcbac80d96f107b967c756732 = $(`&lt;div id=&quot;html_3e584effcbac80d96f107b967c756732&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_169d71c2850dad61e7e739fda4982f13.setContent(html_3e584effcbac80d96f107b967c756732);
#
#
#
#         marker_763d37e4e6d76a089def5eadb807a80f.bindPopup(popup_169d71c2850dad61e7e739fda4982f13)
#         ;
#
#
#
#
#             var marker_902b5017b0a89d6a7d17dd8b9f43a72a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_43c903d81e726f97153fdc0a93ff15da);
#
#
#         var popup_24952905060b8dbb920f825988a2cc41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d88dbdc6c2d4321f6cae2692beb01d22 = $(`&lt;div id=&quot;html_d88dbdc6c2d4321f6cae2692beb01d22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_24952905060b8dbb920f825988a2cc41.setContent(html_d88dbdc6c2d4321f6cae2692beb01d22);
#
#
#
#         marker_902b5017b0a89d6a7d17dd8b9f43a72a.bindPopup(popup_24952905060b8dbb920f825988a2cc41)
#         ;
#
#
#
#
#             var marker_347d0e84da17dea1bd1f528f7d58ff14 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_43c903d81e726f97153fdc0a93ff15da);
#
#
#         var popup_4f8a122bc346ad23b3041ec18538fdb2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a18a013a8a19472186b0f98a676e0be2 = $(`&lt;div id=&quot;html_a18a013a8a19472186b0f98a676e0be2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4f8a122bc346ad23b3041ec18538fdb2.setContent(html_a18a013a8a19472186b0f98a676e0be2);
#
#
#
#         marker_347d0e84da17dea1bd1f528f7d58ff14.bindPopup(popup_4f8a122bc346ad23b3041ec18538fdb2)
#         ;
#
#
#
#
#             var marker_aa1e15f317f900da5da1d3b61839dae1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_43c903d81e726f97153fdc0a93ff15da);
#
#
#         var popup_6211314522f3b4d903d99313373058c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c13557167635bfb24b30a5567a7bd5ea = $(`&lt;div id=&quot;html_c13557167635bfb24b30a5567a7bd5ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6211314522f3b4d903d99313373058c5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_770f84e2c57975afe6d1aafaec4d0a4f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_770f84e2c57975afe6d1aafaec4d0a4f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_770f84e2c57975afe6d1aafaec4d0a4f = L.map(
#                 &quot;map_770f84e2c57975afe6d1aafaec4d0a4f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8fc24fe069a6300d4da51ad268ae6cd8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8fc24fe069a6300d4da51ad268ae6cd8.addTo(map_770f84e2c57975afe6d1aafaec4d0a4f);
#
#
#             var feature_group_246c7024dc74b675039543c4b7923a65 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b603c8247d8663c1a46ed9aeb3c1c905 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_246c7024dc74b675039543c4b7923a65);
#
#
#         var popup_802635eff78187d0993228999910cc8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0a2fc3c0166cd426573528a5a0535e9 = $(`&lt;div id=&quot;html_b0a2fc3c0166cd426573528a5a0535e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_802635eff78187d0993228999910cc8f.setContent(html_b0a2fc3c0166cd426573528a5a0535e9);
#
#
#
#         marker_b603c8247d8663c1a46ed9aeb3c1c905.bindPopup(popup_802635eff78187d0993228999910cc8f)
#         ;
#
#
#
#
#             var marker_3ffafa07fc13291a0f9c441d0f27e356 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_246c7024dc74b675039543c4b7923a65);
#
#
#         var popup_84e6c14f7d87d1b81701ebbaffd66090 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ad1cc6a2d20436017aa7b60502c5b9d = $(`&lt;div id=&quot;html_6ad1cc6a2d20436017aa7b60502c5b9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_84e6c14f7d87d1b81701ebbaffd66090.setContent(html_6ad1cc6a2d20436017aa7b60502c5b9d);
#
#
#
#         marker_3ffafa07fc13291a0f9c441d0f27e356.bindPopup(popup_84e6c14f7d87d1b81701ebbaffd66090)
#         ;
#
#
#
#
#             var marker_7a298183879c85c00e1b164253e8175b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_246c7024dc74b675039543c4b7923a65);
#
#
#         var popup_1e8572f5c719cd91c72c17a60718938c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1a8f4767d209db9f0d40e91ad94431b = $(`&lt;div id=&quot;html_c1a8f4767d209db9f0d40e91ad94431b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1e8572f5c719cd91c72c17a60718938c.setContent(html_c1a8f4767d209db9f0d40e91ad94431b);
#
#
#
#         marker_7a298183879c85c00e1b164253e8175b.bindPopup(popup_1e8572f5c719cd91c72c17a60718938c)
#         ;
#
#
#
#
#             var marker_cf50d4f46f47e2088d06919c6a60f168 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_246c7024dc74b675039543c4b7923a65);
#
#
#         var popup_8766f079f311d9e8255a7fc5330097b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06f83350976624b7c0f92f64b4375094 = $(`&lt;div id=&quot;html_06f83350976624b7c0f92f64b4375094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8766f079f311d9e8255a7fc5330097b4.setContent(html_06f83350976624b7c0f92f64b4375094);
#
#
#
#         marker_cf50d4f46f47e2088d06919c6a60f168.bindPopup(popup_8766f079f311d9e8255a7fc5330097b4)
#         ;
#
#
#
#
#             var marker_c7d54f72d68699a3da5c06a21b42c1dd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_246c7024dc74b675039543c4b7923a65);
#
#
#         var popup_0d1e404fad01859c5dd3104ea45602cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98c73bbe2b9be2279f0d72765650be4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98c73bbe2b9be2279f0d72765650be4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98c73bbe2b9be2279f0d72765650be4b = L.map(
#                 &quot;map_98c73bbe2b9be2279f0d72765650be4b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa0d676e6a3f985d7af5b3e67609a302 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_aa0d676e6a3f985d7af5b3e67609a302.addTo(map_98c73bbe2b9be2279f0d72765650be4b);
#
#
#             var feature_group_df53b01b9cfbffa8eb943181218793c4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_df53b01b9cfbffa8eb943181218793c4.addTo(map_98c73bbe2b9be2279f0d72765650be4b);
#
#
#             var feature_group_sub_group_ab5761389fb59cbee9ba8f5b95cb1175 = L.featureGroup.subGroup(
#                 feature_group_df53b01b9cfbffa8eb943181218793c4
#             );
#
#
#             var marker_021fd0e29f8398da25d3e1b8da390dde = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ab5761389fb59cbee9ba8f5b95cb1175);
#
#
#         var popup_7b5501bf23449ebfbdad8a4755ff4b70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6059c8b2e652b80e709ae576fa265793 = $(`&lt;div id=&quot;html_6059c8b2e652b80e709ae576fa265793&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7b5501bf23449ebfbdad8a4755ff4b70.setContent(html_6059c8b2e652b80e709ae576fa265793);
#
#
#
#         marker_021fd0e29f8398da25d3e1b8da390dde.bindPopup(popup_7b5501bf23449ebfbdad8a4755ff4b70)
#         ;
#
#
#
#
#             var marker_448a61f6979dcfa85e48d85c944af9b0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ab5761389fb59cbee9ba8f5b95cb1175);
#
#
#         var popup_541ec0d78290d587735633389c989ea0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92e69f732e676168f02d04ce580176c5 = $(`&lt;div id=&quot;html_92e69f732e676168f02d04ce580176c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_541ec0d78290d587735633389c989ea0.setContent(html_92e69f732e676168f02d04ce580176c5);
#
#
#
#         marker_448a61f6979dcfa85e48d85c944af9b0.bindPopup(popup_541ec0d78290d587735633389c989ea0)
#         ;
#
#
#
#
#             var marker_ee401a1796b65df8fcf26afe88635aa6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ab5761389fb59cbee9ba8f5b95cb1175);
#
#
#         var popup_ca3bf1ab01a28e28d6097c49ba8d0726 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72605b3b1756487a5b474ce639529821 = $(`&lt;div id=&quot;html_72605b3b1756487a5b474ce639529821&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ca3bf1ab01a28e28d6097c49ba8d0726.setContent(html_72605b3b1756487a5b474ce639529821);
#
#
#
#         marker_ee401a1796b65df8fcf26afe88635aa6.bindPopup(popup_ca3bf1ab01a28e28d6097c49ba8d0726)
#         ;
#
#
#
#
#             var marker_2d287a79d124962feec64b3146835b3c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ab5761389fb59cbee9ba8f5b95cb1175);
#
#
#         var popup_44fa57823947c0c77d2603dd9e239f89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e36c103206b97217834ef6191b128a28 = $(`&lt;div id=&quot;html_e36c103206b97217834ef6191b128a28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_44fa57823947c0c77d2603dd9e239f89.setContent(html_e36c103206b97217834ef6191b128a28);
#
#
#
#         marker_
