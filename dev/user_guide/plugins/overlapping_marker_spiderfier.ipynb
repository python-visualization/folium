# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c5f01328b6e4e91c92ee907e8e937c0e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c5f01328b6e4e91c92ee907e8e937c0e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c5f01328b6e4e91c92ee907e8e937c0e = L.map(
#                 &quot;map_c5f01328b6e4e91c92ee907e8e937c0e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b64fa2bec743c4bc018fcf51680368b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b64fa2bec743c4bc018fcf51680368b.addTo(map_c5f01328b6e4e91c92ee907e8e937c0e);
#
#
#             var marker_852c8d53a9667f0b8d9c9fbf97bc68b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c5f01328b6e4e91c92ee907e8e937c0e);
#
#
#         var popup_adba508fb54bab8843a3e73f416b1455 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50f4dbcd93346e52e3d4231662fa9088 = $(`&lt;div id=&quot;html_50f4dbcd93346e52e3d4231662fa9088&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_adba508fb54bab8843a3e73f416b1455.setContent(html_50f4dbcd93346e52e3d4231662fa9088);
#
#
#
#         marker_852c8d53a9667f0b8d9c9fbf97bc68b4.bindPopup(popup_adba508fb54bab8843a3e73f416b1455)
#         ;
#
#
#
#
#             var marker_9e05bc55a2dd7c34ef815f378bfaa37e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c5f01328b6e4e91c92ee907e8e937c0e);
#
#
#         var popup_7017220d2f471873839d01d02c84c8df = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e55e86d5b5ca32a59fdb181791a5af4 = $(`&lt;div id=&quot;html_1e55e86d5b5ca32a59fdb181791a5af4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7017220d2f471873839d01d02c84c8df.setContent(html_1e55e86d5b5ca32a59fdb181791a5af4);
#
#
#
#         marker_9e05bc55a2dd7c34ef815f378bfaa37e.bindPopup(popup_7017220d2f471873839d01d02c84c8df)
#         ;
#
#
#
#
#             var marker_59e1d85160d17db781b873e27a44becf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c5f01328b6e4e91c92ee907e8e937c0e);
#
#
#         var popup_739b2701c6d60f7ea281be121c4cd287 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_103d70bdbd3877b77a453e034773ec23 = $(`&lt;div id=&quot;html_103d70bdbd3877b77a453e034773ec23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_739b2701c6d60f7ea281be121c4cd287.setContent(html_103d70bdbd3877b77a453e034773ec23);
#
#
#
#         marker_59e1d85160d17db781b873e27a44becf.bindPopup(popup_739b2701c6d60f7ea281be121c4cd287)
#         ;
#
#
#
#
#             var marker_df59b21889c0342664baa4fcdbf2b69d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c5f01328b6e4e91c92ee907e8e937c0e);
#
#
#         var popup_f9a675c392168408c15ad61066cd8240 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_511a189d847db1bd4d2419e72ba612ed = $(`&lt;div id=&quot;html_511a189d847db1bd4d2419e72ba612ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f9a675c392168408c15ad61066cd8240.setContent(html_511a189d847db1bd4d2419e72ba612ed);
#
#
#
#         marker_df59b21889c0342664baa4fcdbf2b69d.bindPopup(popup_f9a675c392168408c15ad61066cd8240)
#         ;
#
#
#
#
#             var marker_491dfcb4cc3c57439495fbe16ff6bf0b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c5f01328b6e4e91c92ee907e8e937c0e);
#
#
#         var popup_d063b02fb2d06b40ab67cc472e0fc4c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88b62b34d2ce03a198a050de0e0a7e09 = $(`&lt;div id=&quot;html_88b62b34d2ce03a198a050de0e0a7e09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d063b02fb2d06b40ab67cc472e0fc4

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76141157dccb4ccdea7d0608f55b5c15 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76141157dccb4ccdea7d0608f55b5c15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76141157dccb4ccdea7d0608f55b5c15 = L.map(
#                 &quot;map_76141157dccb4ccdea7d0608f55b5c15&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc7b1aa2b7b26454f776c9723f58a5b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc7b1aa2b7b26454f776c9723f58a5b9.addTo(map_76141157dccb4ccdea7d0608f55b5c15);
#
#
#             var feature_group_a7395b060105a4e5b54d0c5e6985a8ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1fa762d760eb520abf95cbc1a1cd4f50 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a7395b060105a4e5b54d0c5e6985a8ac);
#
#
#         var popup_605f28eb2f92d5b4cdc6865267ad210c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29a000c4057263ccb7792f1e22964faa = $(`&lt;div id=&quot;html_29a000c4057263ccb7792f1e22964faa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_605f28eb2f92d5b4cdc6865267ad210c.setContent(html_29a000c4057263ccb7792f1e22964faa);
#
#
#
#         marker_1fa762d760eb520abf95cbc1a1cd4f50.bindPopup(popup_605f28eb2f92d5b4cdc6865267ad210c)
#         ;
#
#
#
#
#             var marker_8ea35ac06a870a68cd3f7768eec43302 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a7395b060105a4e5b54d0c5e6985a8ac);
#
#
#         var popup_704313c39d6f39a72e79a323530abc02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbd220a5f344f92fb97ca0c17daafb58 = $(`&lt;div id=&quot;html_fbd220a5f344f92fb97ca0c17daafb58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_704313c39d6f39a72e79a323530abc02.setContent(html_fbd220a5f344f92fb97ca0c17daafb58);
#
#
#
#         marker_8ea35ac06a870a68cd3f7768eec43302.bindPopup(popup_704313c39d6f39a72e79a323530abc02)
#         ;
#
#
#
#
#             var marker_10df5211d8e104ba462b10819e70c395 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a7395b060105a4e5b54d0c5e6985a8ac);
#
#
#         var popup_c4805ef57b8baf5ed2cdada7e76eb235 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b10bef577987f1dc7f9353f01116ea9d = $(`&lt;div id=&quot;html_b10bef577987f1dc7f9353f01116ea9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c4805ef57b8baf5ed2cdada7e76eb235.setContent(html_b10bef577987f1dc7f9353f01116ea9d);
#
#
#
#         marker_10df5211d8e104ba462b10819e70c395.bindPopup(popup_c4805ef57b8baf5ed2cdada7e76eb235)
#         ;
#
#
#
#
#             var marker_8dcdb642fb12c0042afccf0dae10d9fa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a7395b060105a4e5b54d0c5e6985a8ac);
#
#
#         var popup_94a5759bcf926dee4024cd88196d7839 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a216c21b6b8c344257a1404557e09af0 = $(`&lt;div id=&quot;html_a216c21b6b8c344257a1404557e09af0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_94a5759bcf926dee4024cd88196d7839.setContent(html_a216c21b6b8c344257a1404557e09af0);
#
#
#
#         marker_8dcdb642fb12c0042afccf0dae10d9fa.bindPopup(popup_94a5759bcf926dee4024cd88196d7839)
#         ;
#
#
#
#
#             var marker_856e35b09c6408bce269216aa771dd10 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a7395b060105a4e5b54d0c5e6985a8ac);
#
#
#         var popup_987de2d75a413ad2535bf0e7d7bc47a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3be6bc8af0eed0d0bfee7d5d16326f71 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3be6bc8af0eed0d0bfee7d5d16326f71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3be6bc8af0eed0d0bfee7d5d16326f71 = L.map(
#                 &quot;map_3be6bc8af0eed0d0bfee7d5d16326f71&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b92814f7e8971b6329ee3db3e20e765 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b92814f7e8971b6329ee3db3e20e765.addTo(map_3be6bc8af0eed0d0bfee7d5d16326f71);
#
#
#             var feature_group_28d54108a4bc824d9a822f99fbeb7d93 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_28d54108a4bc824d9a822f99fbeb7d93.addTo(map_3be6bc8af0eed0d0bfee7d5d16326f71);
#
#
#             var feature_group_sub_group_851bddf0727265cc22fde00bd543d0f9 = L.featureGroup.subGroup(
#                 feature_group_28d54108a4bc824d9a822f99fbeb7d93
#             );
#
#
#             var marker_d6fe9831203d344fc41234a6c563021c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_851bddf0727265cc22fde00bd543d0f9);
#
#
#         var popup_0b01a9a844320eb9ed7d9243a0488591 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3017aa3968186ff1e8c3a7d5b34e73e = $(`&lt;div id=&quot;html_c3017aa3968186ff1e8c3a7d5b34e73e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0b01a9a844320eb9ed7d9243a0488591.setContent(html_c3017aa3968186ff1e8c3a7d5b34e73e);
#
#
#
#         marker_d6fe9831203d344fc41234a6c563021c.bindPopup(popup_0b01a9a844320eb9ed7d9243a0488591)
#         ;
#
#
#
#
#             var marker_d618529b29e18702e8fa59c5512f493e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_851bddf0727265cc22fde00bd543d0f9);
#
#
#         var popup_9c2199baa00334c430930abfe7e6a158 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e328eed33696fd3a2a7087194e59731 = $(`&lt;div id=&quot;html_0e328eed33696fd3a2a7087194e59731&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9c2199baa00334c430930abfe7e6a158.setContent(html_0e328eed33696fd3a2a7087194e59731);
#
#
#
#         marker_d618529b29e18702e8fa59c5512f493e.bindPopup(popup_9c2199baa00334c430930abfe7e6a158)
#         ;
#
#
#
#
#             var marker_0824d271b55cf7465315ddebd25d1d72 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_851bddf0727265cc22fde00bd543d0f9);
#
#
#         var popup_67dc86b0bf01d69cb9686a48027ea2f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84b4246edc3b085217d7aa7508b1ae3c = $(`&lt;div id=&quot;html_84b4246edc3b085217d7aa7508b1ae3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_67dc86b0bf01d69cb9686a48027ea2f0.setContent(html_84b4246edc3b085217d7aa7508b1ae3c);
#
#
#
#         marker_0824d271b55cf7465315ddebd25d1d72.bindPopup(popup_67dc86b0bf01d69cb9686a48027ea2f0)
#         ;
#
#
#
#
#             var marker_1a8a51daf3458ecdcf59227d1c2981c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_851bddf0727265cc22fde00bd543d0f9);
#
#
#         var popup_9b4bbd84ca17ef25bfeb6b8483ee81f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59463048ffc6ded62ac857c7d9057ecc = $(`&lt;div id=&quot;html_59463048ffc6ded62ac857c7d9057ecc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9b4bbd84ca17ef25bfeb6b8483ee81f4.setContent(html_59463048ffc6ded62ac857c7d9057ecc);
#
#
#
#         mark
