# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32cd05f980b07a8d8808ec3a696fbf4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32cd05f980b07a8d8808ec3a696fbf4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32cd05f980b07a8d8808ec3a696fbf4b = L.map(
#                 &quot;map_32cd05f980b07a8d8808ec3a696fbf4b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41e09af56c9358a60c7a3f08a8c66be5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_41e09af56c9358a60c7a3f08a8c66be5.addTo(map_32cd05f980b07a8d8808ec3a696fbf4b);
#
#
#             var marker_f13be70bdf917fb9c33f73efb0f59d24 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_32cd05f980b07a8d8808ec3a696fbf4b);
#
#
#         var popup_839c553bfc4bc13a4a009edafefcbbe5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e35f7af4066ca82bcb9a2f5687232c4c = $(`&lt;div id=&quot;html_e35f7af4066ca82bcb9a2f5687232c4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_839c553bfc4bc13a4a009edafefcbbe5.setContent(html_e35f7af4066ca82bcb9a2f5687232c4c);
#
#
#
#         marker_f13be70bdf917fb9c33f73efb0f59d24.bindPopup(popup_839c553bfc4bc13a4a009edafefcbbe5)
#         ;
#
#
#
#
#             var marker_9a17bcd8c16fdfa714684eeeb53655c2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_32cd05f980b07a8d8808ec3a696fbf4b);
#
#
#         var popup_6d14026c125ce851f336b5e5b62da762 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_366c325628316bd9b4a8013001e4de51 = $(`&lt;div id=&quot;html_366c325628316bd9b4a8013001e4de51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6d14026c125ce851f336b5e5b62da762.setContent(html_366c325628316bd9b4a8013001e4de51);
#
#
#
#         marker_9a17bcd8c16fdfa714684eeeb53655c2.bindPopup(popup_6d14026c125ce851f336b5e5b62da762)
#         ;
#
#
#
#
#             var marker_271d669bb945d1e8a98fef6ee32e7f8f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_32cd05f980b07a8d8808ec3a696fbf4b);
#
#
#         var popup_c19b94e69844ddfa53bc579ee378a186 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d27469ea658cefee56d321c23490fce = $(`&lt;div id=&quot;html_2d27469ea658cefee56d321c23490fce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c19b94e69844ddfa53bc579ee378a186.setContent(html_2d27469ea658cefee56d321c23490fce);
#
#
#
#         marker_271d669bb945d1e8a98fef6ee32e7f8f.bindPopup(popup_c19b94e69844ddfa53bc579ee378a186)
#         ;
#
#
#
#
#             var marker_29faa61a3dc9c08aac7927167eef23a5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_32cd05f980b07a8d8808ec3a696fbf4b);
#
#
#         var popup_bdae3e86a06feda0b52a812da31e2434 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5009fdcf854b8d38b0985921f29a24b = $(`&lt;div id=&quot;html_a5009fdcf854b8d38b0985921f29a24b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bdae3e86a06feda0b52a812da31e2434.setContent(html_a5009fdcf854b8d38b0985921f29a24b);
#
#
#
#         marker_29faa61a3dc9c08aac7927167eef23a5.bindPopup(popup_bdae3e86a06feda0b52a812da31e2434)
#         ;
#
#
#
#
#             var marker_14dad7a38736466a9fa44beb189555b5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_32cd05f980b07a8d8808ec3a696fbf4b);
#
#
#         var popup_79545f5e5d54dcaebd668909ebccf98b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52b6f2e600107d8a8aa1ebe7fb1de166 = $(`&lt;div id=&quot;html_52b6f2e600107d8a8aa1ebe7fb1de166&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_79545f5e5d54dcaebd668909ebccf98b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf89dff89ab0d42ef948c9b2f9f9d463 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf89dff89ab0d42ef948c9b2f9f9d463&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf89dff89ab0d42ef948c9b2f9f9d463 = L.map(
#                 &quot;map_cf89dff89ab0d42ef948c9b2f9f9d463&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7ca81a24eaa012b65228b36b91e4cc93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7ca81a24eaa012b65228b36b91e4cc93.addTo(map_cf89dff89ab0d42ef948c9b2f9f9d463);
#
#
#             var feature_group_1aa03a65543fbdecea210ae01263f633 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5fa9b33051e50f045141433fe9855bdf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_1aa03a65543fbdecea210ae01263f633);
#
#
#         var popup_c6415f783c870cf9c12a69b58be5f987 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_42dd7fcd47706009c1086426da316a4c = $(`&lt;div id=&quot;html_42dd7fcd47706009c1086426da316a4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c6415f783c870cf9c12a69b58be5f987.setContent(html_42dd7fcd47706009c1086426da316a4c);
#
#
#
#         marker_5fa9b33051e50f045141433fe9855bdf.bindPopup(popup_c6415f783c870cf9c12a69b58be5f987)
#         ;
#
#
#
#
#             var marker_273c4e2097248198fb5669743f08c001 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_1aa03a65543fbdecea210ae01263f633);
#
#
#         var popup_290a5b4491fe610257e327e8c4934966 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_856494e2b7d2a5b485e758ad0e85c6cc = $(`&lt;div id=&quot;html_856494e2b7d2a5b485e758ad0e85c6cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_290a5b4491fe610257e327e8c4934966.setContent(html_856494e2b7d2a5b485e758ad0e85c6cc);
#
#
#
#         marker_273c4e2097248198fb5669743f08c001.bindPopup(popup_290a5b4491fe610257e327e8c4934966)
#         ;
#
#
#
#
#             var marker_f0f2904457a41603e20b5307cd40493d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_1aa03a65543fbdecea210ae01263f633);
#
#
#         var popup_169cfce587118dbc51a60bfa5448fdb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d69020ff13a706dd55a0a53a767268ed = $(`&lt;div id=&quot;html_d69020ff13a706dd55a0a53a767268ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_169cfce587118dbc51a60bfa5448fdb5.setContent(html_d69020ff13a706dd55a0a53a767268ed);
#
#
#
#         marker_f0f2904457a41603e20b5307cd40493d.bindPopup(popup_169cfce587118dbc51a60bfa5448fdb5)
#         ;
#
#
#
#
#             var marker_4b1e1eefb07c67b178ceb388a8792581 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_1aa03a65543fbdecea210ae01263f633);
#
#
#         var popup_d6be911ff8d7be72d522601efa69f0c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_535bce87299071f79b6e7402b0ae7b99 = $(`&lt;div id=&quot;html_535bce87299071f79b6e7402b0ae7b99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d6be911ff8d7be72d522601efa69f0c8.setContent(html_535bce87299071f79b6e7402b0ae7b99);
#
#
#
#         marker_4b1e1eefb07c67b178ceb388a8792581.bindPopup(popup_d6be911ff8d7be72d522601efa69f0c8)
#         ;
#
#
#
#
#             var marker_3690287a3236e232e56ce0798ff64f98 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_1aa03a65543fbdecea210ae01263f633);
#
#
#         var popup_af328deda90244c59d9f964aa25295cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e34ae2dc8bda4db4d6dc6f4962a27cdc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e34ae2dc8bda4db4d6dc6f4962a27cdc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e34ae2dc8bda4db4d6dc6f4962a27cdc = L.map(
#                 &quot;map_e34ae2dc8bda4db4d6dc6f4962a27cdc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_007be213128dbc2473441b3e66b98706 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_007be213128dbc2473441b3e66b98706.addTo(map_e34ae2dc8bda4db4d6dc6f4962a27cdc);
#
#
#             var feature_group_8a47d55a2487778c2a511cd8a23b4249 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8a47d55a2487778c2a511cd8a23b4249.addTo(map_e34ae2dc8bda4db4d6dc6f4962a27cdc);
#
#
#             var feature_group_sub_group_f80e36d15bdd5a141d80cde476424348 = L.featureGroup.subGroup(
#                 feature_group_8a47d55a2487778c2a511cd8a23b4249
#             );
#
#
#             var marker_331f0b8c9437f22269475b661308a146 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f80e36d15bdd5a141d80cde476424348);
#
#
#         var popup_5b224b0d30f72168a091377b9784f44a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef3d5cd16acd0c525024c16bbddca198 = $(`&lt;div id=&quot;html_ef3d5cd16acd0c525024c16bbddca198&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5b224b0d30f72168a091377b9784f44a.setContent(html_ef3d5cd16acd0c525024c16bbddca198);
#
#
#
#         marker_331f0b8c9437f22269475b661308a146.bindPopup(popup_5b224b0d30f72168a091377b9784f44a)
#         ;
#
#
#
#
#             var marker_7fb1f3117e9526d99e7917ee2e68e88e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f80e36d15bdd5a141d80cde476424348);
#
#
#         var popup_e0bf164bae7587eea4510197d0489545 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6145bb33b3b03d2e6e3614de69f626f = $(`&lt;div id=&quot;html_b6145bb33b3b03d2e6e3614de69f626f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e0bf164bae7587eea4510197d0489545.setContent(html_b6145bb33b3b03d2e6e3614de69f626f);
#
#
#
#         marker_7fb1f3117e9526d99e7917ee2e68e88e.bindPopup(popup_e0bf164bae7587eea4510197d0489545)
#         ;
#
#
#
#
#             var marker_75a1821d3422dd4db165b699bcc9fa85 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f80e36d15bdd5a141d80cde476424348);
#
#
#         var popup_63f85b2cd5e84e577f3ddcc074b61f73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a63fe47a628bd7aaefdb6c68c6a35649 = $(`&lt;div id=&quot;html_a63fe47a628bd7aaefdb6c68c6a35649&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_63f85b2cd5e84e577f3ddcc074b61f73.setContent(html_a63fe47a628bd7aaefdb6c68c6a35649);
#
#
#
#         marker_75a1821d3422dd4db165b699bcc9fa85.bindPopup(popup_63f85b2cd5e84e577f3ddcc074b61f73)
#         ;
#
#
#
#
#             var marker_991ef14f3fcf138712d48ff3171c29ee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f80e36d15bdd5a141d80cde476424348);
#
#
#         var popup_cce330080eaaa1c850605aeddb2432c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e9e3cb0050de21ac8cdac60aadec939 = $(`&lt;div id=&quot;html_8e9e3cb0050de21ac8cdac60aadec939&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_cce330080eaaa1c850605aeddb2432c3.setContent(html_8e9e3cb0050de21ac8cdac60aadec939);
#
#
#
#         marker_
