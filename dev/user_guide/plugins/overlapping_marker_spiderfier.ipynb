# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4480bb7a26c80a936b784a9a6c91426d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4480bb7a26c80a936b784a9a6c91426d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4480bb7a26c80a936b784a9a6c91426d = L.map(
#                 &quot;map_4480bb7a26c80a936b784a9a6c91426d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77f5310c7da818907277ac882ad4aed3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77f5310c7da818907277ac882ad4aed3.addTo(map_4480bb7a26c80a936b784a9a6c91426d);
#
#
#             var marker_bb1e68fdccf6822a8fc80475516c9dc9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4480bb7a26c80a936b784a9a6c91426d);
#
#
#         var popup_fb577a0275bd4eb7c191cb193f1ac805 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_725e0053f76aa034e4e211f73b18dc7d = $(`&lt;div id=&quot;html_725e0053f76aa034e4e211f73b18dc7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fb577a0275bd4eb7c191cb193f1ac805.setContent(html_725e0053f76aa034e4e211f73b18dc7d);
#
#
#
#         marker_bb1e68fdccf6822a8fc80475516c9dc9.bindPopup(popup_fb577a0275bd4eb7c191cb193f1ac805)
#         ;
#
#
#
#
#             var marker_3c122acc06a8fa604e3550dfcbe18de1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4480bb7a26c80a936b784a9a6c91426d);
#
#
#         var popup_19c53b8014159da7e0620cd990664d3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c9b30e8cc7ac67ea6229e64005dce6d = $(`&lt;div id=&quot;html_3c9b30e8cc7ac67ea6229e64005dce6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_19c53b8014159da7e0620cd990664d3b.setContent(html_3c9b30e8cc7ac67ea6229e64005dce6d);
#
#
#
#         marker_3c122acc06a8fa604e3550dfcbe18de1.bindPopup(popup_19c53b8014159da7e0620cd990664d3b)
#         ;
#
#
#
#
#             var marker_cdeca4d0b35aba4be4fcf777ad1a0722 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4480bb7a26c80a936b784a9a6c91426d);
#
#
#         var popup_f43ddb858a10d6aa99d5914b97806a0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1dc6d6e6007c63cbe262aa9b42b8f82f = $(`&lt;div id=&quot;html_1dc6d6e6007c63cbe262aa9b42b8f82f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f43ddb858a10d6aa99d5914b97806a0f.setContent(html_1dc6d6e6007c63cbe262aa9b42b8f82f);
#
#
#
#         marker_cdeca4d0b35aba4be4fcf777ad1a0722.bindPopup(popup_f43ddb858a10d6aa99d5914b97806a0f)
#         ;
#
#
#
#
#             var marker_0d2d84e7ca1ede77d5a392763049bfa4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4480bb7a26c80a936b784a9a6c91426d);
#
#
#         var popup_fef616306266a072b3722b02e7e0ae71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43af09f406a72e1137ece5e59743b4af = $(`&lt;div id=&quot;html_43af09f406a72e1137ece5e59743b4af&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fef616306266a072b3722b02e7e0ae71.setContent(html_43af09f406a72e1137ece5e59743b4af);
#
#
#
#         marker_0d2d84e7ca1ede77d5a392763049bfa4.bindPopup(popup_fef616306266a072b3722b02e7e0ae71)
#         ;
#
#
#
#
#             var marker_685c1c96fb9a11411775565eeb1fc8e9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4480bb7a26c80a936b784a9a6c91426d);
#
#
#         var popup_39d0d8213e3e71da0ee458582d9e6c4d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b42472065692f81f956c75d0d0e216b = $(`&lt;div id=&quot;html_0b42472065692f81f956c75d0d0e216b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_39d0d8213e3e71da0ee458582d9e6c4d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22fe46434ef7867360163e69b166f3b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22fe46434ef7867360163e69b166f3b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22fe46434ef7867360163e69b166f3b9 = L.map(
#                 &quot;map_22fe46434ef7867360163e69b166f3b9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6e2a89fa51946dd2a1b652bc8c8e9f2c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6e2a89fa51946dd2a1b652bc8c8e9f2c.addTo(map_22fe46434ef7867360163e69b166f3b9);
#
#
#             var feature_group_47fec7c6f91b248f8978bf83166d1c66 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f382d77e14240359a905c166d757f246 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_47fec7c6f91b248f8978bf83166d1c66);
#
#
#         var popup_8efc4e2a228462bca022b8fd9f508317 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc90a03e4ce01223d437f10a7c599839 = $(`&lt;div id=&quot;html_bc90a03e4ce01223d437f10a7c599839&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8efc4e2a228462bca022b8fd9f508317.setContent(html_bc90a03e4ce01223d437f10a7c599839);
#
#
#
#         marker_f382d77e14240359a905c166d757f246.bindPopup(popup_8efc4e2a228462bca022b8fd9f508317)
#         ;
#
#
#
#
#             var marker_eed19d1d3e62d695dfd66245c759bb5f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_47fec7c6f91b248f8978bf83166d1c66);
#
#
#         var popup_9801889324156f19b63d7fa2feb0c146 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d173aa49d00317ec486678a628133b3 = $(`&lt;div id=&quot;html_3d173aa49d00317ec486678a628133b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9801889324156f19b63d7fa2feb0c146.setContent(html_3d173aa49d00317ec486678a628133b3);
#
#
#
#         marker_eed19d1d3e62d695dfd66245c759bb5f.bindPopup(popup_9801889324156f19b63d7fa2feb0c146)
#         ;
#
#
#
#
#             var marker_a9879ecbd6a2b4b70dd177c5a8982f08 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_47fec7c6f91b248f8978bf83166d1c66);
#
#
#         var popup_dc7dc43c4a269271595edad58e7d47a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d9a5263d641edf4236abc47b29e7ddc5 = $(`&lt;div id=&quot;html_d9a5263d641edf4236abc47b29e7ddc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_dc7dc43c4a269271595edad58e7d47a1.setContent(html_d9a5263d641edf4236abc47b29e7ddc5);
#
#
#
#         marker_a9879ecbd6a2b4b70dd177c5a8982f08.bindPopup(popup_dc7dc43c4a269271595edad58e7d47a1)
#         ;
#
#
#
#
#             var marker_55983d88ceb7a01caccd8d2fb64eb8f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_47fec7c6f91b248f8978bf83166d1c66);
#
#
#         var popup_268149334d6b6bf362299ce2e741b846 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6ea5f47e3766de910994697fb7482e9 = $(`&lt;div id=&quot;html_a6ea5f47e3766de910994697fb7482e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_268149334d6b6bf362299ce2e741b846.setContent(html_a6ea5f47e3766de910994697fb7482e9);
#
#
#
#         marker_55983d88ceb7a01caccd8d2fb64eb8f4.bindPopup(popup_268149334d6b6bf362299ce2e741b846)
#         ;
#
#
#
#
#             var marker_3cb764db4df9f76097896049d5e3bcf9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_47fec7c6f91b248f8978bf83166d1c66);
#
#
#         var popup_dae74e0cff6abb1892ff2c815b2dc4b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41ec1e2e2925d21928d3996c1920d2ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41ec1e2e2925d21928d3996c1920d2ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41ec1e2e2925d21928d3996c1920d2ec = L.map(
#                 &quot;map_41ec1e2e2925d21928d3996c1920d2ec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e2ed8de6fc26a2d553584c50c606f044 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e2ed8de6fc26a2d553584c50c606f044.addTo(map_41ec1e2e2925d21928d3996c1920d2ec);
#
#
#             var feature_group_39810b79563a3bd788f3086ae4d77fdd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_39810b79563a3bd788f3086ae4d77fdd.addTo(map_41ec1e2e2925d21928d3996c1920d2ec);
#
#
#             var feature_group_sub_group_2552346c1b3b712a62ff490db010070c = L.featureGroup.subGroup(
#                 feature_group_39810b79563a3bd788f3086ae4d77fdd
#             );
#
#
#             var marker_65073e9abe42eb3a6b8660eac13ce694 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2552346c1b3b712a62ff490db010070c);
#
#
#         var popup_b45438d7ec87005dffa8e2d801f25950 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dab18a0a0496db268c55ffba1f60564e = $(`&lt;div id=&quot;html_dab18a0a0496db268c55ffba1f60564e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b45438d7ec87005dffa8e2d801f25950.setContent(html_dab18a0a0496db268c55ffba1f60564e);
#
#
#
#         marker_65073e9abe42eb3a6b8660eac13ce694.bindPopup(popup_b45438d7ec87005dffa8e2d801f25950)
#         ;
#
#
#
#
#             var marker_8019170907c91ea9c9ec38779f6d1a53 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2552346c1b3b712a62ff490db010070c);
#
#
#         var popup_cd421ccc8922b86463dacce1e5850987 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72330d98f0daae726560c61dd6c51cda = $(`&lt;div id=&quot;html_72330d98f0daae726560c61dd6c51cda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cd421ccc8922b86463dacce1e5850987.setContent(html_72330d98f0daae726560c61dd6c51cda);
#
#
#
#         marker_8019170907c91ea9c9ec38779f6d1a53.bindPopup(popup_cd421ccc8922b86463dacce1e5850987)
#         ;
#
#
#
#
#             var marker_8beaf232d0493a007e598aeca7b82dcd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2552346c1b3b712a62ff490db010070c);
#
#
#         var popup_655ac9ff74b43ebfc709d4b5c05a2b01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70f4df910b7e7cdf1423d4e6beb6a6e7 = $(`&lt;div id=&quot;html_70f4df910b7e7cdf1423d4e6beb6a6e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_655ac9ff74b43ebfc709d4b5c05a2b01.setContent(html_70f4df910b7e7cdf1423d4e6beb6a6e7);
#
#
#
#         marker_8beaf232d0493a007e598aeca7b82dcd.bindPopup(popup_655ac9ff74b43ebfc709d4b5c05a2b01)
#         ;
#
#
#
#
#             var marker_96e2537bc40ae09de9725eeef97a9ae3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2552346c1b3b712a62ff490db010070c);
#
#
#         var popup_85fbba359daed590808e6397f3208e0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8683df02bd7abe725b6c250a5e2fc13f = $(`&lt;div id=&quot;html_8683df02bd7abe725b6c250a5e2fc13f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_85fbba359daed590808e6397f3208e0f.setContent(html_8683df02bd7abe725b6c250a5e2fc13f);
#
#
#
#         marker_
