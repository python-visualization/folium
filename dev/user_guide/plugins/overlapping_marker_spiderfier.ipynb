# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8e9fa0331302155daf137cd794a4d06c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8e9fa0331302155daf137cd794a4d06c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8e9fa0331302155daf137cd794a4d06c = L.map(
#                 &quot;map_8e9fa0331302155daf137cd794a4d06c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc3796e6dbd042efa8a7194b3fc5fa2c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc3796e6dbd042efa8a7194b3fc5fa2c.addTo(map_8e9fa0331302155daf137cd794a4d06c);
#
#
#             var marker_fe8d0cf285b9a74ee22689924fe2a09a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8e9fa0331302155daf137cd794a4d06c);
#
#
#         var popup_bd9c78abf3f45c573c4384755aaf247f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8426a919ac3e0a64e9210b67b3e4f4d2 = $(`&lt;div id=&quot;html_8426a919ac3e0a64e9210b67b3e4f4d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_bd9c78abf3f45c573c4384755aaf247f.setContent(html_8426a919ac3e0a64e9210b67b3e4f4d2);
#
#
#
#         marker_fe8d0cf285b9a74ee22689924fe2a09a.bindPopup(popup_bd9c78abf3f45c573c4384755aaf247f)
#         ;
#
#
#
#
#             var marker_ae73d7a60285b788991b53a7f9954a08 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8e9fa0331302155daf137cd794a4d06c);
#
#
#         var popup_ab95b65aa47295e1a9b78c567b68834a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8826d045ac90f92ba6f2be131a601513 = $(`&lt;div id=&quot;html_8826d045ac90f92ba6f2be131a601513&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ab95b65aa47295e1a9b78c567b68834a.setContent(html_8826d045ac90f92ba6f2be131a601513);
#
#
#
#         marker_ae73d7a60285b788991b53a7f9954a08.bindPopup(popup_ab95b65aa47295e1a9b78c567b68834a)
#         ;
#
#
#
#
#             var marker_17c955bf7c4db276a74c7c90c1b6c165 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8e9fa0331302155daf137cd794a4d06c);
#
#
#         var popup_4549384e24347d96b483602687655f85 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d22182cad6c69a9f045acb65b252155 = $(`&lt;div id=&quot;html_6d22182cad6c69a9f045acb65b252155&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4549384e24347d96b483602687655f85.setContent(html_6d22182cad6c69a9f045acb65b252155);
#
#
#
#         marker_17c955bf7c4db276a74c7c90c1b6c165.bindPopup(popup_4549384e24347d96b483602687655f85)
#         ;
#
#
#
#
#             var marker_e901da5ae6596da3541537d53c405056 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8e9fa0331302155daf137cd794a4d06c);
#
#
#         var popup_e4a468967e26a231b6dc42dfce7ca179 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c2cc5109cfa08238b0d71f5e9640070 = $(`&lt;div id=&quot;html_9c2cc5109cfa08238b0d71f5e9640070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e4a468967e26a231b6dc42dfce7ca179.setContent(html_9c2cc5109cfa08238b0d71f5e9640070);
#
#
#
#         marker_e901da5ae6596da3541537d53c405056.bindPopup(popup_e4a468967e26a231b6dc42dfce7ca179)
#         ;
#
#
#
#
#             var marker_d1448f884e4b4299d28246dfcd48e394 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8e9fa0331302155daf137cd794a4d06c);
#
#
#         var popup_eb70c417624f7bd61a467282675d05d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41190183991806797cd9d4d8ec7f7c7b = $(`&lt;div id=&quot;html_41190183991806797cd9d4d8ec7f7c7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_eb70c417624f7bd61a467282675d05d9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1032bb2c72816404555af69d566305b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1032bb2c72816404555af69d566305b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1032bb2c72816404555af69d566305b = L.map(
#                 &quot;map_d1032bb2c72816404555af69d566305b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8f6d7f9d56aa1bbc84994f0d8c488c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8f6d7f9d56aa1bbc84994f0d8c488c1.addTo(map_d1032bb2c72816404555af69d566305b);
#
#
#             var feature_group_0bc1611d9ecaf04b8607519867eb1633 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0348d5721e13cb401839cfe991eef061 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0bc1611d9ecaf04b8607519867eb1633);
#
#
#         var popup_c0676a00bf34a7196116789dbde536da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f0068a29b1ee7771d9c78294ddb798b = $(`&lt;div id=&quot;html_7f0068a29b1ee7771d9c78294ddb798b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c0676a00bf34a7196116789dbde536da.setContent(html_7f0068a29b1ee7771d9c78294ddb798b);
#
#
#
#         marker_0348d5721e13cb401839cfe991eef061.bindPopup(popup_c0676a00bf34a7196116789dbde536da)
#         ;
#
#
#
#
#             var marker_7cdd6d3bd22d272a21b0e06cd1aa9776 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0bc1611d9ecaf04b8607519867eb1633);
#
#
#         var popup_c568bd3ba0fe3c6d4bd74607e0194d41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddcd876f3c33822a926f4eb25fb1d759 = $(`&lt;div id=&quot;html_ddcd876f3c33822a926f4eb25fb1d759&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c568bd3ba0fe3c6d4bd74607e0194d41.setContent(html_ddcd876f3c33822a926f4eb25fb1d759);
#
#
#
#         marker_7cdd6d3bd22d272a21b0e06cd1aa9776.bindPopup(popup_c568bd3ba0fe3c6d4bd74607e0194d41)
#         ;
#
#
#
#
#             var marker_9c9ad9035c73982209aa7530c5b401a3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0bc1611d9ecaf04b8607519867eb1633);
#
#
#         var popup_cd998137c686d686ca8eaed178338533 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_daca4f17135b5ba6e03678409940ee42 = $(`&lt;div id=&quot;html_daca4f17135b5ba6e03678409940ee42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cd998137c686d686ca8eaed178338533.setContent(html_daca4f17135b5ba6e03678409940ee42);
#
#
#
#         marker_9c9ad9035c73982209aa7530c5b401a3.bindPopup(popup_cd998137c686d686ca8eaed178338533)
#         ;
#
#
#
#
#             var marker_7baf5d8c2f08c69c5310fdefaa6b4bfc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0bc1611d9ecaf04b8607519867eb1633);
#
#
#         var popup_c5b68e526aafc990b2f6c595464bdba3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c21af9d033c09694629c858d147a8d6 = $(`&lt;div id=&quot;html_9c21af9d033c09694629c858d147a8d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c5b68e526aafc990b2f6c595464bdba3.setContent(html_9c21af9d033c09694629c858d147a8d6);
#
#
#
#         marker_7baf5d8c2f08c69c5310fdefaa6b4bfc.bindPopup(popup_c5b68e526aafc990b2f6c595464bdba3)
#         ;
#
#
#
#
#             var marker_13fe668a06e5f4080b2167815be5657f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0bc1611d9ecaf04b8607519867eb1633);
#
#
#         var popup_b1c8bd85854b86c4153cf5319763ee29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_47e89d164464960ba7461752f848eca9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_47e89d164464960ba7461752f848eca9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_47e89d164464960ba7461752f848eca9 = L.map(
#                 &quot;map_47e89d164464960ba7461752f848eca9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4fbcc0cd3b59c0777248bef672b0eb5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4fbcc0cd3b59c0777248bef672b0eb5.addTo(map_47e89d164464960ba7461752f848eca9);
#
#
#             var feature_group_2544703e77ea22b7e1719ab9fe8ba34e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2544703e77ea22b7e1719ab9fe8ba34e.addTo(map_47e89d164464960ba7461752f848eca9);
#
#
#             var feature_group_sub_group_c6df490ea1c27e9208169bbda2ffa04d = L.featureGroup.subGroup(
#                 feature_group_2544703e77ea22b7e1719ab9fe8ba34e
#             );
#
#
#             var marker_e2a0eaa4b5e19023c03af776bb0af07e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6df490ea1c27e9208169bbda2ffa04d);
#
#
#         var popup_150d36c77fb9d3adbedd159f99679ca9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db557f6e9c380ea1dbc522d1e40d0383 = $(`&lt;div id=&quot;html_db557f6e9c380ea1dbc522d1e40d0383&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_150d36c77fb9d3adbedd159f99679ca9.setContent(html_db557f6e9c380ea1dbc522d1e40d0383);
#
#
#
#         marker_e2a0eaa4b5e19023c03af776bb0af07e.bindPopup(popup_150d36c77fb9d3adbedd159f99679ca9)
#         ;
#
#
#
#
#             var marker_c1b93fc1cae15b74e292ec09a4fc1184 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6df490ea1c27e9208169bbda2ffa04d);
#
#
#         var popup_dd30864204724c40b6fa203c31c96d55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3b5658788cc0a8ec5605444bdf2bda4 = $(`&lt;div id=&quot;html_a3b5658788cc0a8ec5605444bdf2bda4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_dd30864204724c40b6fa203c31c96d55.setContent(html_a3b5658788cc0a8ec5605444bdf2bda4);
#
#
#
#         marker_c1b93fc1cae15b74e292ec09a4fc1184.bindPopup(popup_dd30864204724c40b6fa203c31c96d55)
#         ;
#
#
#
#
#             var marker_0e6c7728920750be4b0d3dc0e24196e7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6df490ea1c27e9208169bbda2ffa04d);
#
#
#         var popup_a14796b8e0e1195c2abf952e89492cfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91be96443bd9b3c7adb43edb4783517c = $(`&lt;div id=&quot;html_91be96443bd9b3c7adb43edb4783517c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a14796b8e0e1195c2abf952e89492cfa.setContent(html_91be96443bd9b3c7adb43edb4783517c);
#
#
#
#         marker_0e6c7728920750be4b0d3dc0e24196e7.bindPopup(popup_a14796b8e0e1195c2abf952e89492cfa)
#         ;
#
#
#
#
#             var marker_cb277ecabc391429609f8f15e868f97f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c6df490ea1c27e9208169bbda2ffa04d);
#
#
#         var popup_8a236d6d1a376e2674099f88b993f92d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4adedff56e7f4e7dcc953233a862f41f = $(`&lt;div id=&quot;html_4adedff56e7f4e7dcc953233a862f41f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8a236d6d1a376e2674099f88b993f92d.setContent(html_4adedff56e7f4e7dcc953233a862f41f);
#
#
#
#         marker_
