# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a4e4bf9210adaf65a3844fb2301ece2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a4e4bf9210adaf65a3844fb2301ece2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a4e4bf9210adaf65a3844fb2301ece2b = L.map(
#                 &quot;map_a4e4bf9210adaf65a3844fb2301ece2b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28861f11bda2ca6bf10cfe7536d6229c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_28861f11bda2ca6bf10cfe7536d6229c.addTo(map_a4e4bf9210adaf65a3844fb2301ece2b);
#
#
#             var marker_4abf2b80973ca17a7dca6a2ceab3ecc7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a4e4bf9210adaf65a3844fb2301ece2b);
#
#
#         var popup_f036a222835c50da94f9ce9be4eb363d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb3bb66e8f6bff2b8c1a65741d8f9982 = $(`&lt;div id=&quot;html_cb3bb66e8f6bff2b8c1a65741d8f9982&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f036a222835c50da94f9ce9be4eb363d.setContent(html_cb3bb66e8f6bff2b8c1a65741d8f9982);
#
#
#
#         marker_4abf2b80973ca17a7dca6a2ceab3ecc7.bindPopup(popup_f036a222835c50da94f9ce9be4eb363d)
#         ;
#
#
#
#
#             var marker_cac82d7c35977cf1c1e7392bc873340e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a4e4bf9210adaf65a3844fb2301ece2b);
#
#
#         var popup_66ec79dfe0355afcaeebd18cb37c6f16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29d3ee42817ab522b4a195f660320d78 = $(`&lt;div id=&quot;html_29d3ee42817ab522b4a195f660320d78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_66ec79dfe0355afcaeebd18cb37c6f16.setContent(html_29d3ee42817ab522b4a195f660320d78);
#
#
#
#         marker_cac82d7c35977cf1c1e7392bc873340e.bindPopup(popup_66ec79dfe0355afcaeebd18cb37c6f16)
#         ;
#
#
#
#
#             var marker_9777f644b85a7934a3bd23bc07142eab = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a4e4bf9210adaf65a3844fb2301ece2b);
#
#
#         var popup_ebc55e24276370c9334ffa625243ca52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e11040a51de7bd95fa85ed1aa15788e = $(`&lt;div id=&quot;html_2e11040a51de7bd95fa85ed1aa15788e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ebc55e24276370c9334ffa625243ca52.setContent(html_2e11040a51de7bd95fa85ed1aa15788e);
#
#
#
#         marker_9777f644b85a7934a3bd23bc07142eab.bindPopup(popup_ebc55e24276370c9334ffa625243ca52)
#         ;
#
#
#
#
#             var marker_6b2c44fb604fa64d6ca4a8f184d8f1b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a4e4bf9210adaf65a3844fb2301ece2b);
#
#
#         var popup_d2cf71457178175386ed853fa42d36f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b15a5e98757889839bbfccd94352cfd = $(`&lt;div id=&quot;html_0b15a5e98757889839bbfccd94352cfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d2cf71457178175386ed853fa42d36f1.setContent(html_0b15a5e98757889839bbfccd94352cfd);
#
#
#
#         marker_6b2c44fb604fa64d6ca4a8f184d8f1b2.bindPopup(popup_d2cf71457178175386ed853fa42d36f1)
#         ;
#
#
#
#
#             var marker_01df6889fbc149bdb7b7d53c2cb72c4b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a4e4bf9210adaf65a3844fb2301ece2b);
#
#
#         var popup_74101ba6d5e18b4adaaf6ebb40f6109c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9c25cc491da34c04f74a4b2c40c4870 = $(`&lt;div id=&quot;html_c9c25cc491da34c04f74a4b2c40c4870&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_74101ba6d5e18b4adaaf6ebb40f6109c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2e64c7634dc502c529d202d06101c0d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2e64c7634dc502c529d202d06101c0d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2e64c7634dc502c529d202d06101c0d = L.map(
#                 &quot;map_a2e64c7634dc502c529d202d06101c0d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a0036144de773dd0429ad2a7bfa9060 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a0036144de773dd0429ad2a7bfa9060.addTo(map_a2e64c7634dc502c529d202d06101c0d);
#
#
#             var feature_group_8e9f2cfa3cae2df0dc0b6c6504860d8e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_271c01f01a781b5bc02dfe461c9bbfaf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8e9f2cfa3cae2df0dc0b6c6504860d8e);
#
#
#         var popup_506a1d9c34679f3bcb0c5df0b29edcba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f5df3e4af9544540bd58a050d0e81f4 = $(`&lt;div id=&quot;html_4f5df3e4af9544540bd58a050d0e81f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_506a1d9c34679f3bcb0c5df0b29edcba.setContent(html_4f5df3e4af9544540bd58a050d0e81f4);
#
#
#
#         marker_271c01f01a781b5bc02dfe461c9bbfaf.bindPopup(popup_506a1d9c34679f3bcb0c5df0b29edcba)
#         ;
#
#
#
#
#             var marker_0f4fedc792556771f452ce30ab661cc1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8e9f2cfa3cae2df0dc0b6c6504860d8e);
#
#
#         var popup_06dda557642915dd9edec41868ad7681 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b416724d516e8a0a21f4d458684967f8 = $(`&lt;div id=&quot;html_b416724d516e8a0a21f4d458684967f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_06dda557642915dd9edec41868ad7681.setContent(html_b416724d516e8a0a21f4d458684967f8);
#
#
#
#         marker_0f4fedc792556771f452ce30ab661cc1.bindPopup(popup_06dda557642915dd9edec41868ad7681)
#         ;
#
#
#
#
#             var marker_7013a7e9439f6276f1d49622b0315102 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8e9f2cfa3cae2df0dc0b6c6504860d8e);
#
#
#         var popup_8dbfea1bc96139a67912f20127c1945e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a961a0db5b71496abf88ba92069b9853 = $(`&lt;div id=&quot;html_a961a0db5b71496abf88ba92069b9853&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8dbfea1bc96139a67912f20127c1945e.setContent(html_a961a0db5b71496abf88ba92069b9853);
#
#
#
#         marker_7013a7e9439f6276f1d49622b0315102.bindPopup(popup_8dbfea1bc96139a67912f20127c1945e)
#         ;
#
#
#
#
#             var marker_86869b611b344c868cc87edc995394cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8e9f2cfa3cae2df0dc0b6c6504860d8e);
#
#
#         var popup_7d3a8162f6c2d051a4bd4f76e18be67f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_616d62d64be37d22f57e226895f9eab0 = $(`&lt;div id=&quot;html_616d62d64be37d22f57e226895f9eab0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7d3a8162f6c2d051a4bd4f76e18be67f.setContent(html_616d62d64be37d22f57e226895f9eab0);
#
#
#
#         marker_86869b611b344c868cc87edc995394cf.bindPopup(popup_7d3a8162f6c2d051a4bd4f76e18be67f)
#         ;
#
#
#
#
#             var marker_2f75bf0721b6829119e7be18c19d7a15 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8e9f2cfa3cae2df0dc0b6c6504860d8e);
#
#
#         var popup_b6a8ead55a8a1746cf927df4b2db261c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a70a54f99f149d1c4f9d6f432b8ebef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a70a54f99f149d1c4f9d6f432b8ebef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a70a54f99f149d1c4f9d6f432b8ebef = L.map(
#                 &quot;map_3a70a54f99f149d1c4f9d6f432b8ebef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d242ba615128a70844a85878bf923112 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d242ba615128a70844a85878bf923112.addTo(map_3a70a54f99f149d1c4f9d6f432b8ebef);
#
#
#             var feature_group_438f9d7cdd9a7e2f09504945d0669d0b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_438f9d7cdd9a7e2f09504945d0669d0b.addTo(map_3a70a54f99f149d1c4f9d6f432b8ebef);
#
#
#             var feature_group_sub_group_bbee810d2b3e99d741e24add2286e9ef = L.featureGroup.subGroup(
#                 feature_group_438f9d7cdd9a7e2f09504945d0669d0b
#             );
#
#
#             var marker_202ef2d8ca5c59dcdd371e83c6f43e95 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_bbee810d2b3e99d741e24add2286e9ef);
#
#
#         var popup_d669b7966ab83a2746b775fb7d2b2189 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c627487335af1b94b9a59839e873dbdd = $(`&lt;div id=&quot;html_c627487335af1b94b9a59839e873dbdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d669b7966ab83a2746b775fb7d2b2189.setContent(html_c627487335af1b94b9a59839e873dbdd);
#
#
#
#         marker_202ef2d8ca5c59dcdd371e83c6f43e95.bindPopup(popup_d669b7966ab83a2746b775fb7d2b2189)
#         ;
#
#
#
#
#             var marker_32370b1fa79b51171fa50e259721fc24 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_bbee810d2b3e99d741e24add2286e9ef);
#
#
#         var popup_1ccfe664919c1035d796c3e67c71972c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7083f7cc7eb73c50749723e4c67ecf0 = $(`&lt;div id=&quot;html_f7083f7cc7eb73c50749723e4c67ecf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1ccfe664919c1035d796c3e67c71972c.setContent(html_f7083f7cc7eb73c50749723e4c67ecf0);
#
#
#
#         marker_32370b1fa79b51171fa50e259721fc24.bindPopup(popup_1ccfe664919c1035d796c3e67c71972c)
#         ;
#
#
#
#
#             var marker_f68bcf423036477f229c2235aea297ae = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_bbee810d2b3e99d741e24add2286e9ef);
#
#
#         var popup_cf21277255c7fc56bae938a27c63cbf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e2ccff4a11c42b279f85f78a6b96c90 = $(`&lt;div id=&quot;html_3e2ccff4a11c42b279f85f78a6b96c90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cf21277255c7fc56bae938a27c63cbf4.setContent(html_3e2ccff4a11c42b279f85f78a6b96c90);
#
#
#
#         marker_f68bcf423036477f229c2235aea297ae.bindPopup(popup_cf21277255c7fc56bae938a27c63cbf4)
#         ;
#
#
#
#
#             var marker_bb37e28b049bab1fee7946fe25f2e2cd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_bbee810d2b3e99d741e24add2286e9ef);
#
#
#         var popup_fa869a8916767466a6d5287388322854 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f80a895719bd422a32c4e96647671a99 = $(`&lt;div id=&quot;html_f80a895719bd422a32c4e96647671a99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fa869a8916767466a6d5287388322854.setContent(html_f80a895719bd422a32c4e96647671a99);
#
#
#
#         marker_
