# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f35c5ff0d8615b2a3045fb28daeb8b44 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f35c5ff0d8615b2a3045fb28daeb8b44&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f35c5ff0d8615b2a3045fb28daeb8b44 = L.map(
#                 &quot;map_f35c5ff0d8615b2a3045fb28daeb8b44&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa9cb669641c92b519349b26a195ce33 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa9cb669641c92b519349b26a195ce33.addTo(map_f35c5ff0d8615b2a3045fb28daeb8b44);
#
#
#             var marker_f9e1f2ba70aa0c0294d3e18dd0ed44d4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f35c5ff0d8615b2a3045fb28daeb8b44);
#
#
#         var popup_5921c659b8f8a9c6293ab92e1b958d7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d165c80645663428700b699deb66739 = $(`&lt;div id=&quot;html_8d165c80645663428700b699deb66739&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5921c659b8f8a9c6293ab92e1b958d7b.setContent(html_8d165c80645663428700b699deb66739);
#
#
#
#         marker_f9e1f2ba70aa0c0294d3e18dd0ed44d4.bindPopup(popup_5921c659b8f8a9c6293ab92e1b958d7b)
#         ;
#
#
#
#
#             var marker_d1f17c527a83bf1a2fab9595e2eaab70 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f35c5ff0d8615b2a3045fb28daeb8b44);
#
#
#         var popup_2342ae23e6ee8ca265ce246232cbe8c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4f9e6af7ce5768cc8db160601bc83a9 = $(`&lt;div id=&quot;html_c4f9e6af7ce5768cc8db160601bc83a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2342ae23e6ee8ca265ce246232cbe8c5.setContent(html_c4f9e6af7ce5768cc8db160601bc83a9);
#
#
#
#         marker_d1f17c527a83bf1a2fab9595e2eaab70.bindPopup(popup_2342ae23e6ee8ca265ce246232cbe8c5)
#         ;
#
#
#
#
#             var marker_b515ee4bc8f1ec6752bd17d6d8e4eb7d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f35c5ff0d8615b2a3045fb28daeb8b44);
#
#
#         var popup_cb227c8caf6dfa749b7f411a3782d49f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_319f82cabae5460e7c9de33ca47a8912 = $(`&lt;div id=&quot;html_319f82cabae5460e7c9de33ca47a8912&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cb227c8caf6dfa749b7f411a3782d49f.setContent(html_319f82cabae5460e7c9de33ca47a8912);
#
#
#
#         marker_b515ee4bc8f1ec6752bd17d6d8e4eb7d.bindPopup(popup_cb227c8caf6dfa749b7f411a3782d49f)
#         ;
#
#
#
#
#             var marker_76ec7779265f1608f73ce40d9793e735 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f35c5ff0d8615b2a3045fb28daeb8b44);
#
#
#         var popup_4a92f85aa1f3422920643f0fca3a88bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7505e1a017b5e9cc3970ebc14df2d86c = $(`&lt;div id=&quot;html_7505e1a017b5e9cc3970ebc14df2d86c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4a92f85aa1f3422920643f0fca3a88bb.setContent(html_7505e1a017b5e9cc3970ebc14df2d86c);
#
#
#
#         marker_76ec7779265f1608f73ce40d9793e735.bindPopup(popup_4a92f85aa1f3422920643f0fca3a88bb)
#         ;
#
#
#
#
#             var marker_6cf828844fb242fc1f29b64af5f6b71b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f35c5ff0d8615b2a3045fb28daeb8b44);
#
#
#         var popup_a42b1ac2298442e529aa9cd9ea882e51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70e8227c10db4a19c6932ab532b85a96 = $(`&lt;div id=&quot;html_70e8227c10db4a19c6932ab532b85a96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a42b1ac2298442e529aa9cd9ea882e51.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d98839c4f2b8febf77ffbc714120e0cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d98839c4f2b8febf77ffbc714120e0cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d98839c4f2b8febf77ffbc714120e0cd = L.map(
#                 &quot;map_d98839c4f2b8febf77ffbc714120e0cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7553f2b327a03835a8a5c6da7dbdc24f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7553f2b327a03835a8a5c6da7dbdc24f.addTo(map_d98839c4f2b8febf77ffbc714120e0cd);
#
#
#             var feature_group_6607fe8eb49bdde364bb04349e0c07f7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1bfd82d4bc1ec9d5ea35fff3796d1913 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6607fe8eb49bdde364bb04349e0c07f7);
#
#
#         var popup_aa30d9f4bc3ee666b60775aea2f9c2bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7c3173d7f23224944effcc517ed046c = $(`&lt;div id=&quot;html_c7c3173d7f23224944effcc517ed046c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_aa30d9f4bc3ee666b60775aea2f9c2bf.setContent(html_c7c3173d7f23224944effcc517ed046c);
#
#
#
#         marker_1bfd82d4bc1ec9d5ea35fff3796d1913.bindPopup(popup_aa30d9f4bc3ee666b60775aea2f9c2bf)
#         ;
#
#
#
#
#             var marker_e765d7e53e254c832627670c4b58a990 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6607fe8eb49bdde364bb04349e0c07f7);
#
#
#         var popup_1807bf8a9a3ff6e11d2d16f01069f636 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6eef3d3ef34cad715c5566e15711376f = $(`&lt;div id=&quot;html_6eef3d3ef34cad715c5566e15711376f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1807bf8a9a3ff6e11d2d16f01069f636.setContent(html_6eef3d3ef34cad715c5566e15711376f);
#
#
#
#         marker_e765d7e53e254c832627670c4b58a990.bindPopup(popup_1807bf8a9a3ff6e11d2d16f01069f636)
#         ;
#
#
#
#
#             var marker_4b9c0a5cce730860c23693fdc8e7c03d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6607fe8eb49bdde364bb04349e0c07f7);
#
#
#         var popup_1460699df5e3950e281b059eba14da9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2876428645fd4272f6608821568777a8 = $(`&lt;div id=&quot;html_2876428645fd4272f6608821568777a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1460699df5e3950e281b059eba14da9b.setContent(html_2876428645fd4272f6608821568777a8);
#
#
#
#         marker_4b9c0a5cce730860c23693fdc8e7c03d.bindPopup(popup_1460699df5e3950e281b059eba14da9b)
#         ;
#
#
#
#
#             var marker_0416757a1401d0248fab67e04adec041 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6607fe8eb49bdde364bb04349e0c07f7);
#
#
#         var popup_be0d418f5ff196eb2036bafda5e7579b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91f08680ca8df0b8a902c693d3f0bffe = $(`&lt;div id=&quot;html_91f08680ca8df0b8a902c693d3f0bffe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_be0d418f5ff196eb2036bafda5e7579b.setContent(html_91f08680ca8df0b8a902c693d3f0bffe);
#
#
#
#         marker_0416757a1401d0248fab67e04adec041.bindPopup(popup_be0d418f5ff196eb2036bafda5e7579b)
#         ;
#
#
#
#
#             var marker_3a4e7c8b8f0b5d5c501c6b6353233b64 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6607fe8eb49bdde364bb04349e0c07f7);
#
#
#         var popup_e0102fe592f957d475e2385af03ebb2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5da79dad83e54f6e12aadb57240f68a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5da79dad83e54f6e12aadb57240f68a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5da79dad83e54f6e12aadb57240f68a2 = L.map(
#                 &quot;map_5da79dad83e54f6e12aadb57240f68a2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27a04f0c85aaf5dd75d41be386df6f75 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27a04f0c85aaf5dd75d41be386df6f75.addTo(map_5da79dad83e54f6e12aadb57240f68a2);
#
#
#             var feature_group_681839ddba663f03674bd22954e9d73d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_681839ddba663f03674bd22954e9d73d.addTo(map_5da79dad83e54f6e12aadb57240f68a2);
#
#
#             var feature_group_sub_group_e16c5a6a7f2b0b9b29ef1b54896b11d5 = L.featureGroup.subGroup(
#                 feature_group_681839ddba663f03674bd22954e9d73d
#             );
#
#
#             var marker_5b90a3240f5bb93e24c199a2baaec763 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e16c5a6a7f2b0b9b29ef1b54896b11d5);
#
#
#         var popup_c1c45630805025668667f0920d49fe62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4293df4e4fc04984277715c119b172a2 = $(`&lt;div id=&quot;html_4293df4e4fc04984277715c119b172a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c1c45630805025668667f0920d49fe62.setContent(html_4293df4e4fc04984277715c119b172a2);
#
#
#
#         marker_5b90a3240f5bb93e24c199a2baaec763.bindPopup(popup_c1c45630805025668667f0920d49fe62)
#         ;
#
#
#
#
#             var marker_73f9b673a21e99aec8e10633236c38f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e16c5a6a7f2b0b9b29ef1b54896b11d5);
#
#
#         var popup_e8e06a63de563b41c7ae83176e15a5dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a4c29b2592666c5c92abf8b75607046 = $(`&lt;div id=&quot;html_0a4c29b2592666c5c92abf8b75607046&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e8e06a63de563b41c7ae83176e15a5dd.setContent(html_0a4c29b2592666c5c92abf8b75607046);
#
#
#
#         marker_73f9b673a21e99aec8e10633236c38f9.bindPopup(popup_e8e06a63de563b41c7ae83176e15a5dd)
#         ;
#
#
#
#
#             var marker_3d9eb41333aef85daeec1fdf44bf8db6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e16c5a6a7f2b0b9b29ef1b54896b11d5);
#
#
#         var popup_4b3445900bc945484b61978401044062 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e9f0f6b2e383b6d778c44a07835f63d = $(`&lt;div id=&quot;html_1e9f0f6b2e383b6d778c44a07835f63d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4b3445900bc945484b61978401044062.setContent(html_1e9f0f6b2e383b6d778c44a07835f63d);
#
#
#
#         marker_3d9eb41333aef85daeec1fdf44bf8db6.bindPopup(popup_4b3445900bc945484b61978401044062)
#         ;
#
#
#
#
#             var marker_4f0ba51580f87adc061fef70c63b8f7f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e16c5a6a7f2b0b9b29ef1b54896b11d5);
#
#
#         var popup_3e392d9615969fa8cb6c239b5c203c74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26b9065b06c99957c05515be42c55b9c = $(`&lt;div id=&quot;html_26b9065b06c99957c05515be42c55b9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3e392d9615969fa8cb6c239b5c203c74.setContent(html_26b9065b06c99957c05515be42c55b9c);
#
#
#
#         marker_
