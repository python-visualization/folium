# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5f8ce5b4ee9c9b90694bc52e5424cab {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5f8ce5b4ee9c9b90694bc52e5424cab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5f8ce5b4ee9c9b90694bc52e5424cab = L.map(
#                 &quot;map_d5f8ce5b4ee9c9b90694bc52e5424cab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ace2e4fb08de43d8b35eb6c917c2b3ee = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ace2e4fb08de43d8b35eb6c917c2b3ee.addTo(map_d5f8ce5b4ee9c9b90694bc52e5424cab);
#
#
#             var marker_62311ca37c0461fb4f0afa881e88177b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d5f8ce5b4ee9c9b90694bc52e5424cab);
#
#
#         var popup_789a65711439af86a93d07901ea3a805 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ce416093cc6d6a968bf8fa4c32a1708 = $(`&lt;div id=&quot;html_5ce416093cc6d6a968bf8fa4c32a1708&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_789a65711439af86a93d07901ea3a805.setContent(html_5ce416093cc6d6a968bf8fa4c32a1708);
#
#
#
#         marker_62311ca37c0461fb4f0afa881e88177b.bindPopup(popup_789a65711439af86a93d07901ea3a805)
#         ;
#
#
#
#
#             var marker_fd9637d3c19fa83d0e947bdba0c6c61b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d5f8ce5b4ee9c9b90694bc52e5424cab);
#
#
#         var popup_3e18a1e2cbcb822583d98592522a34a5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6708a00a8db14166c93ccd00d8792c5d = $(`&lt;div id=&quot;html_6708a00a8db14166c93ccd00d8792c5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3e18a1e2cbcb822583d98592522a34a5.setContent(html_6708a00a8db14166c93ccd00d8792c5d);
#
#
#
#         marker_fd9637d3c19fa83d0e947bdba0c6c61b.bindPopup(popup_3e18a1e2cbcb822583d98592522a34a5)
#         ;
#
#
#
#
#             var marker_ff1c260e07e3671193ee5305f6d16897 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d5f8ce5b4ee9c9b90694bc52e5424cab);
#
#
#         var popup_45fe469f543ca95bcc44e3e1b973e1ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_660781d90da688c5bd5caf26ee707eca = $(`&lt;div id=&quot;html_660781d90da688c5bd5caf26ee707eca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_45fe469f543ca95bcc44e3e1b973e1ab.setContent(html_660781d90da688c5bd5caf26ee707eca);
#
#
#
#         marker_ff1c260e07e3671193ee5305f6d16897.bindPopup(popup_45fe469f543ca95bcc44e3e1b973e1ab)
#         ;
#
#
#
#
#             var marker_669c3817c87127c967110fc1dd18fafa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d5f8ce5b4ee9c9b90694bc52e5424cab);
#
#
#         var popup_928f4b9deb21a5bff761cde5b775f9aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2efce709a2c39d9fe165fe80fbd3843d = $(`&lt;div id=&quot;html_2efce709a2c39d9fe165fe80fbd3843d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_928f4b9deb21a5bff761cde5b775f9aa.setContent(html_2efce709a2c39d9fe165fe80fbd3843d);
#
#
#
#         marker_669c3817c87127c967110fc1dd18fafa.bindPopup(popup_928f4b9deb21a5bff761cde5b775f9aa)
#         ;
#
#
#
#
#             var marker_9a1f00558de8ab265c4a15dcfdd97c2f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d5f8ce5b4ee9c9b90694bc52e5424cab);
#
#
#         var popup_ade2744ba6f04fb08b3f1504ddf8ad77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0187e55746dd60ac615327a0fb34691c = $(`&lt;div id=&quot;html_0187e55746dd60ac615327a0fb34691c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ade2744ba6f04fb08b3f1504ddf8ad

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c154969b5a354d5779b9ed36bcf36c90 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c154969b5a354d5779b9ed36bcf36c90&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c154969b5a354d5779b9ed36bcf36c90 = L.map(
#                 &quot;map_c154969b5a354d5779b9ed36bcf36c90&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61da23de3d98c290676890d25c2673a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61da23de3d98c290676890d25c2673a5.addTo(map_c154969b5a354d5779b9ed36bcf36c90);
#
#
#             var feature_group_d174d59c521ab99e080e7deb73085227 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6b2d444ff6ea3c6ff64b00fd79d6dff7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d174d59c521ab99e080e7deb73085227);
#
#
#         var popup_25c3c1603db05f025db4b46ff281a9c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff8f667503cb74961d059ca6661c5aa0 = $(`&lt;div id=&quot;html_ff8f667503cb74961d059ca6661c5aa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_25c3c1603db05f025db4b46ff281a9c2.setContent(html_ff8f667503cb74961d059ca6661c5aa0);
#
#
#
#         marker_6b2d444ff6ea3c6ff64b00fd79d6dff7.bindPopup(popup_25c3c1603db05f025db4b46ff281a9c2)
#         ;
#
#
#
#
#             var marker_cff832f80509b1d6174039e87a724d9e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d174d59c521ab99e080e7deb73085227);
#
#
#         var popup_52b36ec73138219252a063ff265ff20b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2558ed08f9f99e378bbcb669f36d760 = $(`&lt;div id=&quot;html_d2558ed08f9f99e378bbcb669f36d760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_52b36ec73138219252a063ff265ff20b.setContent(html_d2558ed08f9f99e378bbcb669f36d760);
#
#
#
#         marker_cff832f80509b1d6174039e87a724d9e.bindPopup(popup_52b36ec73138219252a063ff265ff20b)
#         ;
#
#
#
#
#             var marker_59802ff0da5321d2a50d4f3157521f59 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d174d59c521ab99e080e7deb73085227);
#
#
#         var popup_af354a930394bb9c7db3d556b48cb75b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f3cdbbc93978c79b80c5ca02c3a27ce = $(`&lt;div id=&quot;html_3f3cdbbc93978c79b80c5ca02c3a27ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_af354a930394bb9c7db3d556b48cb75b.setContent(html_3f3cdbbc93978c79b80c5ca02c3a27ce);
#
#
#
#         marker_59802ff0da5321d2a50d4f3157521f59.bindPopup(popup_af354a930394bb9c7db3d556b48cb75b)
#         ;
#
#
#
#
#             var marker_104e96327195895860096b3e812a5acb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d174d59c521ab99e080e7deb73085227);
#
#
#         var popup_41f23b8aa4d6334696882e7d9443e9b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37aee2a143b50ce75bc973f020367731 = $(`&lt;div id=&quot;html_37aee2a143b50ce75bc973f020367731&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_41f23b8aa4d6334696882e7d9443e9b9.setContent(html_37aee2a143b50ce75bc973f020367731);
#
#
#
#         marker_104e96327195895860096b3e812a5acb.bindPopup(popup_41f23b8aa4d6334696882e7d9443e9b9)
#         ;
#
#
#
#
#             var marker_16f1da75739c10c6fdd72bee9f21f15b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d174d59c521ab99e080e7deb73085227);
#
#
#         var popup_f02e17503be01aba8448f65178c55149 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ef573b77fcb1ccedb0b9d61682a037b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ef573b77fcb1ccedb0b9d61682a037b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ef573b77fcb1ccedb0b9d61682a037b = L.map(
#                 &quot;map_4ef573b77fcb1ccedb0b9d61682a037b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_552ab6f1fbfaa3642cbfac622d4f13fc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_552ab6f1fbfaa3642cbfac622d4f13fc.addTo(map_4ef573b77fcb1ccedb0b9d61682a037b);
#
#
#             var feature_group_02de47efede162bfce8ad83e36e8c37c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_02de47efede162bfce8ad83e36e8c37c.addTo(map_4ef573b77fcb1ccedb0b9d61682a037b);
#
#
#             var feature_group_sub_group_b635973f7f0d117c5eef192486eaa400 = L.featureGroup.subGroup(
#                 feature_group_02de47efede162bfce8ad83e36e8c37c
#             );
#
#
#             var marker_fe798cc5ae0671ee9c89ce3345682bbf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b635973f7f0d117c5eef192486eaa400);
#
#
#         var popup_ef293b7cd25114717173331a39a6d432 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b34b093cd5b6c2fcf1d734c4122b060e = $(`&lt;div id=&quot;html_b34b093cd5b6c2fcf1d734c4122b060e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ef293b7cd25114717173331a39a6d432.setContent(html_b34b093cd5b6c2fcf1d734c4122b060e);
#
#
#
#         marker_fe798cc5ae0671ee9c89ce3345682bbf.bindPopup(popup_ef293b7cd25114717173331a39a6d432)
#         ;
#
#
#
#
#             var marker_025bd89037c0c82244e2bd678c7c95c0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b635973f7f0d117c5eef192486eaa400);
#
#
#         var popup_063acb583811c22cb723094eaf4e4ecf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_97e73f11a5baf076538b447e4cafb0d4 = $(`&lt;div id=&quot;html_97e73f11a5baf076538b447e4cafb0d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_063acb583811c22cb723094eaf4e4ecf.setContent(html_97e73f11a5baf076538b447e4cafb0d4);
#
#
#
#         marker_025bd89037c0c82244e2bd678c7c95c0.bindPopup(popup_063acb583811c22cb723094eaf4e4ecf)
#         ;
#
#
#
#
#             var marker_f145c7c6d00b682ce088dcdbe75f91ed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b635973f7f0d117c5eef192486eaa400);
#
#
#         var popup_af2387be09087d0d70a264b1be938972 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f30900aea3e83466e85cd9e5a6cc1760 = $(`&lt;div id=&quot;html_f30900aea3e83466e85cd9e5a6cc1760&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_af2387be09087d0d70a264b1be938972.setContent(html_f30900aea3e83466e85cd9e5a6cc1760);
#
#
#
#         marker_f145c7c6d00b682ce088dcdbe75f91ed.bindPopup(popup_af2387be09087d0d70a264b1be938972)
#         ;
#
#
#
#
#             var marker_6e2c5d4a22683fec3398c854d22c9625 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b635973f7f0d117c5eef192486eaa400);
#
#
#         var popup_b3094a12826cceb2a51aedbb1f21baaa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_527eb2b12406e525d9342f8482f20ef2 = $(`&lt;div id=&quot;html_527eb2b12406e525d9342f8482f20ef2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b3094a12826cceb2a51aedbb1f21baaa.setContent(html_527eb2b12406e525d9342f8482f20ef2);
#
#
#
#         mark
