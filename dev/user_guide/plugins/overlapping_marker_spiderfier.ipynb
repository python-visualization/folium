# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5525cb485d6b23784a743d00cb3ede56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5525cb485d6b23784a743d00cb3ede56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5525cb485d6b23784a743d00cb3ede56 = L.map(
#                 &quot;map_5525cb485d6b23784a743d00cb3ede56&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b3d414c987819fd10120dad3c116a1f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b3d414c987819fd10120dad3c116a1f7.addTo(map_5525cb485d6b23784a743d00cb3ede56);
#
#
#             var marker_164bdd90e16f7f41dbb775f196024e28 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5525cb485d6b23784a743d00cb3ede56);
#
#
#         var popup_a99f0a18e9eeee2fc472fc50c427b84f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93c1a39a77672f6e319baaada0a14d83 = $(`&lt;div id=&quot;html_93c1a39a77672f6e319baaada0a14d83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a99f0a18e9eeee2fc472fc50c427b84f.setContent(html_93c1a39a77672f6e319baaada0a14d83);
#
#
#
#         marker_164bdd90e16f7f41dbb775f196024e28.bindPopup(popup_a99f0a18e9eeee2fc472fc50c427b84f)
#         ;
#
#
#
#
#             var marker_8340737d1d4e9d76966a293f870b0e5a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5525cb485d6b23784a743d00cb3ede56);
#
#
#         var popup_e6dfa14502d7c8a71d657920e0644ea7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83304c194b0d13720761151e7af9829b = $(`&lt;div id=&quot;html_83304c194b0d13720761151e7af9829b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e6dfa14502d7c8a71d657920e0644ea7.setContent(html_83304c194b0d13720761151e7af9829b);
#
#
#
#         marker_8340737d1d4e9d76966a293f870b0e5a.bindPopup(popup_e6dfa14502d7c8a71d657920e0644ea7)
#         ;
#
#
#
#
#             var marker_a1b0f7e2e1ba2e9ffcd8f37888828b23 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5525cb485d6b23784a743d00cb3ede56);
#
#
#         var popup_8928d0ff4f4d692cc014268af91fea9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14bcdeb7e2e875963782daf87860ddfa = $(`&lt;div id=&quot;html_14bcdeb7e2e875963782daf87860ddfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8928d0ff4f4d692cc014268af91fea9d.setContent(html_14bcdeb7e2e875963782daf87860ddfa);
#
#
#
#         marker_a1b0f7e2e1ba2e9ffcd8f37888828b23.bindPopup(popup_8928d0ff4f4d692cc014268af91fea9d)
#         ;
#
#
#
#
#             var marker_fb935a17bad97fb868b49fe8eeef4c5d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5525cb485d6b23784a743d00cb3ede56);
#
#
#         var popup_0be6ad1f786d027c601e351428a4d22e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f43a035f8f6476d3327ec3b16b76b966 = $(`&lt;div id=&quot;html_f43a035f8f6476d3327ec3b16b76b966&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0be6ad1f786d027c601e351428a4d22e.setContent(html_f43a035f8f6476d3327ec3b16b76b966);
#
#
#
#         marker_fb935a17bad97fb868b49fe8eeef4c5d.bindPopup(popup_0be6ad1f786d027c601e351428a4d22e)
#         ;
#
#
#
#
#             var marker_38a307fbdd3463ffb71fb95b3bae89ad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5525cb485d6b23784a743d00cb3ede56);
#
#
#         var popup_820de7867e3ba7eb59eda4a998a46ea4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_663e17a1f2407c3673904861e658b816 = $(`&lt;div id=&quot;html_663e17a1f2407c3673904861e658b816&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_820de7867e3ba7eb59eda4a998a46ea4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c7e70b73b7375998564db80818da94f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c7e70b73b7375998564db80818da94f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c7e70b73b7375998564db80818da94f = L.map(
#                 &quot;map_2c7e70b73b7375998564db80818da94f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81916bd5a97fe58f5f3f832fe67d7cc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81916bd5a97fe58f5f3f832fe67d7cc5.addTo(map_2c7e70b73b7375998564db80818da94f);
#
#
#             var feature_group_3e91fe2b766a8bfe20c293981d3fe2e6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1ba0ff58b3ffbc04bbe138ff71d1a334 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3e91fe2b766a8bfe20c293981d3fe2e6);
#
#
#         var popup_477cb24b760116444235715635464eac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e9fa32e40286b068f189328f2cc9a52 = $(`&lt;div id=&quot;html_1e9fa32e40286b068f189328f2cc9a52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_477cb24b760116444235715635464eac.setContent(html_1e9fa32e40286b068f189328f2cc9a52);
#
#
#
#         marker_1ba0ff58b3ffbc04bbe138ff71d1a334.bindPopup(popup_477cb24b760116444235715635464eac)
#         ;
#
#
#
#
#             var marker_2d6f3c7fa1c46851e0dde3e92064705c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3e91fe2b766a8bfe20c293981d3fe2e6);
#
#
#         var popup_4c79463084f1a63f76df46f516dda2b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31c2c46e120f14973860ff1c8be11ea4 = $(`&lt;div id=&quot;html_31c2c46e120f14973860ff1c8be11ea4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4c79463084f1a63f76df46f516dda2b3.setContent(html_31c2c46e120f14973860ff1c8be11ea4);
#
#
#
#         marker_2d6f3c7fa1c46851e0dde3e92064705c.bindPopup(popup_4c79463084f1a63f76df46f516dda2b3)
#         ;
#
#
#
#
#             var marker_1be2eca4f4ff0645ca53157353b42daa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3e91fe2b766a8bfe20c293981d3fe2e6);
#
#
#         var popup_18e29e2dd699f3c90737fe4372741695 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_629f3c90e792ed9308546cb0ce302244 = $(`&lt;div id=&quot;html_629f3c90e792ed9308546cb0ce302244&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_18e29e2dd699f3c90737fe4372741695.setContent(html_629f3c90e792ed9308546cb0ce302244);
#
#
#
#         marker_1be2eca4f4ff0645ca53157353b42daa.bindPopup(popup_18e29e2dd699f3c90737fe4372741695)
#         ;
#
#
#
#
#             var marker_a4c5a936ad49444cfa1c702b03b41cae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3e91fe2b766a8bfe20c293981d3fe2e6);
#
#
#         var popup_17a64cb25761d5d60bf98d67206512d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d020315050cef737dd769ad23709bdb = $(`&lt;div id=&quot;html_4d020315050cef737dd769ad23709bdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_17a64cb25761d5d60bf98d67206512d7.setContent(html_4d020315050cef737dd769ad23709bdb);
#
#
#
#         marker_a4c5a936ad49444cfa1c702b03b41cae.bindPopup(popup_17a64cb25761d5d60bf98d67206512d7)
#         ;
#
#
#
#
#             var marker_3e06d080578f33a60cbf0f02c82701ce = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3e91fe2b766a8bfe20c293981d3fe2e6);
#
#
#         var popup_d9e41b17ccc216ca42a6860940f4fd47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc56946af25904010a59e95de351ff1c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc56946af25904010a59e95de351ff1c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc56946af25904010a59e95de351ff1c = L.map(
#                 &quot;map_cc56946af25904010a59e95de351ff1c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec41917ff8a1eb14b8791950e44465b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec41917ff8a1eb14b8791950e44465b0.addTo(map_cc56946af25904010a59e95de351ff1c);
#
#
#             var feature_group_1d39719c78aed60f3f3347c4706958d0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1d39719c78aed60f3f3347c4706958d0.addTo(map_cc56946af25904010a59e95de351ff1c);
#
#
#             var feature_group_sub_group_764422e270af5a67061d40fe991459b2 = L.featureGroup.subGroup(
#                 feature_group_1d39719c78aed60f3f3347c4706958d0
#             );
#
#
#             var marker_43dc9e4cf851bafe6bb9d6ed231b8108 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_764422e270af5a67061d40fe991459b2);
#
#
#         var popup_0749e61f92864e11ade2d5474c733ae2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1efe041749a03d7c0be795833f3d3ed = $(`&lt;div id=&quot;html_a1efe041749a03d7c0be795833f3d3ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0749e61f92864e11ade2d5474c733ae2.setContent(html_a1efe041749a03d7c0be795833f3d3ed);
#
#
#
#         marker_43dc9e4cf851bafe6bb9d6ed231b8108.bindPopup(popup_0749e61f92864e11ade2d5474c733ae2)
#         ;
#
#
#
#
#             var marker_bf21a238891f3d8ae5bb5ce959d99e45 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_764422e270af5a67061d40fe991459b2);
#
#
#         var popup_855df5b7b50a2e688d6442d4c633f54e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c17b731f3a18a1e1cf071fc32e14d99 = $(`&lt;div id=&quot;html_4c17b731f3a18a1e1cf071fc32e14d99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_855df5b7b50a2e688d6442d4c633f54e.setContent(html_4c17b731f3a18a1e1cf071fc32e14d99);
#
#
#
#         marker_bf21a238891f3d8ae5bb5ce959d99e45.bindPopup(popup_855df5b7b50a2e688d6442d4c633f54e)
#         ;
#
#
#
#
#             var marker_3efa09f6dbf79e8870c14626170c9524 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_764422e270af5a67061d40fe991459b2);
#
#
#         var popup_1c91bd93f1a7f4996936d0c23c784caf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f7a18bfb33a10700b3efb38a238c1ca = $(`&lt;div id=&quot;html_5f7a18bfb33a10700b3efb38a238c1ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1c91bd93f1a7f4996936d0c23c784caf.setContent(html_5f7a18bfb33a10700b3efb38a238c1ca);
#
#
#
#         marker_3efa09f6dbf79e8870c14626170c9524.bindPopup(popup_1c91bd93f1a7f4996936d0c23c784caf)
#         ;
#
#
#
#
#             var marker_2aba21d08ff7d96256845096241f7ccb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_764422e270af5a67061d40fe991459b2);
#
#
#         var popup_58827ec84e724bf25ff67d0bae72030c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5d878e5804eabbfcf92f0a67903f633 = $(`&lt;div id=&quot;html_b5d878e5804eabbfcf92f0a67903f633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_58827ec84e724bf25ff67d0bae72030c.setContent(html_b5d878e5804eabbfcf92f0a67903f633);
#
#
#
#         marker_
