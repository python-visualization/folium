# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e777c8c619eb7472751185fd52e55662 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e777c8c619eb7472751185fd52e55662&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e777c8c619eb7472751185fd52e55662 = L.map(
#                 &quot;map_e777c8c619eb7472751185fd52e55662&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_392c1f56095a84eaeb33cb33027c1ba2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_392c1f56095a84eaeb33cb33027c1ba2.addTo(map_e777c8c619eb7472751185fd52e55662);
#
#
#             var marker_f32e3e18f47923ea8a350ddf04a2567b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e777c8c619eb7472751185fd52e55662);
#
#
#         var popup_0a1bf8ebc561d11bfaca542a3c3c4f32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02e5d2d933090a1ee0789a5ead218cae = $(`&lt;div id=&quot;html_02e5d2d933090a1ee0789a5ead218cae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0a1bf8ebc561d11bfaca542a3c3c4f32.setContent(html_02e5d2d933090a1ee0789a5ead218cae);
#
#
#
#         marker_f32e3e18f47923ea8a350ddf04a2567b.bindPopup(popup_0a1bf8ebc561d11bfaca542a3c3c4f32)
#         ;
#
#
#
#
#             var marker_f11a405161aacabc5c63a71e970a78f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e777c8c619eb7472751185fd52e55662);
#
#
#         var popup_e47b9c7ae7f72876f8010ce413aef0b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_68e103a0eca08dbae2a1b31b19afecf5 = $(`&lt;div id=&quot;html_68e103a0eca08dbae2a1b31b19afecf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e47b9c7ae7f72876f8010ce413aef0b7.setContent(html_68e103a0eca08dbae2a1b31b19afecf5);
#
#
#
#         marker_f11a405161aacabc5c63a71e970a78f4.bindPopup(popup_e47b9c7ae7f72876f8010ce413aef0b7)
#         ;
#
#
#
#
#             var marker_bebe68283cba50da07d4154be41bb49e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e777c8c619eb7472751185fd52e55662);
#
#
#         var popup_4a136d16527016b0d893eb7e4eefadee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b01ece031cd61edcb3e8e338a50646a = $(`&lt;div id=&quot;html_2b01ece031cd61edcb3e8e338a50646a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4a136d16527016b0d893eb7e4eefadee.setContent(html_2b01ece031cd61edcb3e8e338a50646a);
#
#
#
#         marker_bebe68283cba50da07d4154be41bb49e.bindPopup(popup_4a136d16527016b0d893eb7e4eefadee)
#         ;
#
#
#
#
#             var marker_8bbfcdf817ae1afd9c5cbebc664e7b3e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e777c8c619eb7472751185fd52e55662);
#
#
#         var popup_c6514361542b4d86fa38b609fd5d037c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0a3b4e7ce10c222073797f5fbf37c78 = $(`&lt;div id=&quot;html_d0a3b4e7ce10c222073797f5fbf37c78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c6514361542b4d86fa38b609fd5d037c.setContent(html_d0a3b4e7ce10c222073797f5fbf37c78);
#
#
#
#         marker_8bbfcdf817ae1afd9c5cbebc664e7b3e.bindPopup(popup_c6514361542b4d86fa38b609fd5d037c)
#         ;
#
#
#
#
#             var marker_f8c46862a69f3cb6f6c4f515f7c835b3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e777c8c619eb7472751185fd52e55662);
#
#
#         var popup_a35688d246d2dbdc503ed2d8fd6f46bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06d981a62047dee4f8077dc9df4e2f93 = $(`&lt;div id=&quot;html_06d981a62047dee4f8077dc9df4e2f93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a35688d246d2dbdc503ed2d8fd6f46bc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bb081cf48b0f4cc7521a2b5071e9dd15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bb081cf48b0f4cc7521a2b5071e9dd15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bb081cf48b0f4cc7521a2b5071e9dd15 = L.map(
#                 &quot;map_bb081cf48b0f4cc7521a2b5071e9dd15&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8008918286af793a31b470681621553d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8008918286af793a31b470681621553d.addTo(map_bb081cf48b0f4cc7521a2b5071e9dd15);
#
#
#             var feature_group_756375d7e51b8f38d2c9010cf00ebc40 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_64b409b2ee2ce2bfee8acd364c9405c6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_756375d7e51b8f38d2c9010cf00ebc40);
#
#
#         var popup_74e13323936eebcd07a862f0404739c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fea0842811ce18f1990d5a32824bd085 = $(`&lt;div id=&quot;html_fea0842811ce18f1990d5a32824bd085&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_74e13323936eebcd07a862f0404739c8.setContent(html_fea0842811ce18f1990d5a32824bd085);
#
#
#
#         marker_64b409b2ee2ce2bfee8acd364c9405c6.bindPopup(popup_74e13323936eebcd07a862f0404739c8)
#         ;
#
#
#
#
#             var marker_6667fca0b36c643379839c87c2d538b2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_756375d7e51b8f38d2c9010cf00ebc40);
#
#
#         var popup_479fd1054866d7792efd491676843b5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf3bd1db7b3d4345986f27d3f0ca8fd5 = $(`&lt;div id=&quot;html_cf3bd1db7b3d4345986f27d3f0ca8fd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_479fd1054866d7792efd491676843b5b.setContent(html_cf3bd1db7b3d4345986f27d3f0ca8fd5);
#
#
#
#         marker_6667fca0b36c643379839c87c2d538b2.bindPopup(popup_479fd1054866d7792efd491676843b5b)
#         ;
#
#
#
#
#             var marker_4fde8025f88f6b1200fd9794a4dd8fe3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_756375d7e51b8f38d2c9010cf00ebc40);
#
#
#         var popup_af5d7f6324fffa890882e8ac8c37995f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73fc10fd457e9150b743628cd6e7bf92 = $(`&lt;div id=&quot;html_73fc10fd457e9150b743628cd6e7bf92&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_af5d7f6324fffa890882e8ac8c37995f.setContent(html_73fc10fd457e9150b743628cd6e7bf92);
#
#
#
#         marker_4fde8025f88f6b1200fd9794a4dd8fe3.bindPopup(popup_af5d7f6324fffa890882e8ac8c37995f)
#         ;
#
#
#
#
#             var marker_6eabb0a580952e8a56944c33917e9c0e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_756375d7e51b8f38d2c9010cf00ebc40);
#
#
#         var popup_e3a8c21d67f8bf9ac58b466b0e81cf76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d331c661c5f0a8c0662b215d078e25e9 = $(`&lt;div id=&quot;html_d331c661c5f0a8c0662b215d078e25e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e3a8c21d67f8bf9ac58b466b0e81cf76.setContent(html_d331c661c5f0a8c0662b215d078e25e9);
#
#
#
#         marker_6eabb0a580952e8a56944c33917e9c0e.bindPopup(popup_e3a8c21d67f8bf9ac58b466b0e81cf76)
#         ;
#
#
#
#
#             var marker_e2be3f8d6cb309c24af31fc2a882b82c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_756375d7e51b8f38d2c9010cf00ebc40);
#
#
#         var popup_6cca41931db3a99e3751fe501ae99a03 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86f6a4c54eb1217678f00577efd20ab6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86f6a4c54eb1217678f00577efd20ab6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86f6a4c54eb1217678f00577efd20ab6 = L.map(
#                 &quot;map_86f6a4c54eb1217678f00577efd20ab6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd0d8ce2258c8999c47beb49c18be028 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd0d8ce2258c8999c47beb49c18be028.addTo(map_86f6a4c54eb1217678f00577efd20ab6);
#
#
#             var feature_group_c913ae96d4b4dd34f24a2022238dbc16 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c913ae96d4b4dd34f24a2022238dbc16.addTo(map_86f6a4c54eb1217678f00577efd20ab6);
#
#
#             var feature_group_sub_group_175e4d8ac3bab0c7b5281564d00a6299 = L.featureGroup.subGroup(
#                 feature_group_c913ae96d4b4dd34f24a2022238dbc16
#             );
#
#
#             var marker_d06ae08d8f3a2dca809c266ee0c7ef30 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_175e4d8ac3bab0c7b5281564d00a6299);
#
#
#         var popup_5de285bae4e54c5461bbf8df6f76e296 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_babf8e6270e4dfa4a2858b615eb7b2e5 = $(`&lt;div id=&quot;html_babf8e6270e4dfa4a2858b615eb7b2e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5de285bae4e54c5461bbf8df6f76e296.setContent(html_babf8e6270e4dfa4a2858b615eb7b2e5);
#
#
#
#         marker_d06ae08d8f3a2dca809c266ee0c7ef30.bindPopup(popup_5de285bae4e54c5461bbf8df6f76e296)
#         ;
#
#
#
#
#             var marker_170a14807f09176f465346cf8b534d23 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_175e4d8ac3bab0c7b5281564d00a6299);
#
#
#         var popup_70a73416bad261f412999f453b606e12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e58dad0a45c73ce5b29107ecd43afd4 = $(`&lt;div id=&quot;html_6e58dad0a45c73ce5b29107ecd43afd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_70a73416bad261f412999f453b606e12.setContent(html_6e58dad0a45c73ce5b29107ecd43afd4);
#
#
#
#         marker_170a14807f09176f465346cf8b534d23.bindPopup(popup_70a73416bad261f412999f453b606e12)
#         ;
#
#
#
#
#             var marker_3258b645100c3977d5b3fa8124d80e59 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_175e4d8ac3bab0c7b5281564d00a6299);
#
#
#         var popup_3acf7d659c3628174d809032d623628a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2c148041d092802e81ffffa64e7d7802 = $(`&lt;div id=&quot;html_2c148041d092802e81ffffa64e7d7802&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3acf7d659c3628174d809032d623628a.setContent(html_2c148041d092802e81ffffa64e7d7802);
#
#
#
#         marker_3258b645100c3977d5b3fa8124d80e59.bindPopup(popup_3acf7d659c3628174d809032d623628a)
#         ;
#
#
#
#
#             var marker_76cf2231564e6b9680198439fbabbe17 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_175e4d8ac3bab0c7b5281564d00a6299);
#
#
#         var popup_98137446421c6c8c96573e581ad83a31 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4661a1e5e38ff9ea6624c3012463724 = $(`&lt;div id=&quot;html_b4661a1e5e38ff9ea6624c3012463724&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_98137446421c6c8c96573e581ad83a31.setContent(html_b4661a1e5e38ff9ea6624c3012463724);
#
#
#
#         marker_
