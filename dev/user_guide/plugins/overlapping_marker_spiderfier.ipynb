# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8c703c8161476755d026dae2df4a2dda {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8c703c8161476755d026dae2df4a2dda&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8c703c8161476755d026dae2df4a2dda = L.map(
#                 &quot;map_8c703c8161476755d026dae2df4a2dda&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_157ed717c6607c7d69a90e403e375f89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_157ed717c6607c7d69a90e403e375f89.addTo(map_8c703c8161476755d026dae2df4a2dda);
#
#
#             var marker_2d42a1ef31792f3160290648bf686e82 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8c703c8161476755d026dae2df4a2dda);
#
#
#         var popup_4ff3904e4d9118d338550915b3f639ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7844313ed4fa5c61556bf8e580dae7f3 = $(`&lt;div id=&quot;html_7844313ed4fa5c61556bf8e580dae7f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4ff3904e4d9118d338550915b3f639ad.setContent(html_7844313ed4fa5c61556bf8e580dae7f3);
#
#
#
#         marker_2d42a1ef31792f3160290648bf686e82.bindPopup(popup_4ff3904e4d9118d338550915b3f639ad)
#         ;
#
#
#
#
#             var marker_d4a132c3698cbb1f72d9cf2be1d8829a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8c703c8161476755d026dae2df4a2dda);
#
#
#         var popup_f7033f377d91779beb82f8ae5404bcea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8cac8d263392efb6f426203aa3365c5 = $(`&lt;div id=&quot;html_e8cac8d263392efb6f426203aa3365c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f7033f377d91779beb82f8ae5404bcea.setContent(html_e8cac8d263392efb6f426203aa3365c5);
#
#
#
#         marker_d4a132c3698cbb1f72d9cf2be1d8829a.bindPopup(popup_f7033f377d91779beb82f8ae5404bcea)
#         ;
#
#
#
#
#             var marker_45760a40d5a1a32d075974628a2a0642 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8c703c8161476755d026dae2df4a2dda);
#
#
#         var popup_ea1ddd54a76617c4499fad7b7e0f78ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ca7480cf1aea1de32475de530705d99 = $(`&lt;div id=&quot;html_0ca7480cf1aea1de32475de530705d99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ea1ddd54a76617c4499fad7b7e0f78ff.setContent(html_0ca7480cf1aea1de32475de530705d99);
#
#
#
#         marker_45760a40d5a1a32d075974628a2a0642.bindPopup(popup_ea1ddd54a76617c4499fad7b7e0f78ff)
#         ;
#
#
#
#
#             var marker_872388f5b8ac9ce7b26d80f0018fcc11 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8c703c8161476755d026dae2df4a2dda);
#
#
#         var popup_2b161434fc6170939cf4790d40ada7ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63fb77b223bc8a621f5ff6783476a97e = $(`&lt;div id=&quot;html_63fb77b223bc8a621f5ff6783476a97e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2b161434fc6170939cf4790d40ada7ff.setContent(html_63fb77b223bc8a621f5ff6783476a97e);
#
#
#
#         marker_872388f5b8ac9ce7b26d80f0018fcc11.bindPopup(popup_2b161434fc6170939cf4790d40ada7ff)
#         ;
#
#
#
#
#             var marker_bae7c275d5636a0db12983e1f58aef59 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8c703c8161476755d026dae2df4a2dda);
#
#
#         var popup_1fe9e5160bff01796d7aeffc7d71a715 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_49de375a9ac7578a6aeae5cc97eab0f6 = $(`&lt;div id=&quot;html_49de375a9ac7578a6aeae5cc97eab0f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1fe9e5160bff01796d7aeffc7d71a715.setContent(html_49de375a9ac7578a6aeae5cc97eab0f6);
#
#
#
#         marker_bae7c275d5636a0db12983e1f58aef59.bindPopup(popup_1fe9e5160bff01796d7aeffc7d71a715)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1197127a2da669483ca092b8f1510d80 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1197127a2da669483ca092b8f1510d80&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1197127a2da669483ca092b8f1510d80 = L.map(
#                 &quot;map_1197127a2da669483ca092b8f1510d80&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48aa29355fe925fccd090fb77ab31afb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48aa29355fe925fccd090fb77ab31afb.addTo(map_1197127a2da669483ca092b8f1510d80);
#
#
#             var feature_group_89e64ddbaf98fe7db62b77fcd59ee5aa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d0b96708e5a1c9292abacd6543b8189d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_89e64ddbaf98fe7db62b77fcd59ee5aa);
#
#
#         var popup_8164c47df6f77b80dadced4474bb0f58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7932c6589cdac8f3063496ed50d82237 = $(`&lt;div id=&quot;html_7932c6589cdac8f3063496ed50d82237&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8164c47df6f77b80dadced4474bb0f58.setContent(html_7932c6589cdac8f3063496ed50d82237);
#
#
#
#         marker_d0b96708e5a1c9292abacd6543b8189d.bindPopup(popup_8164c47df6f77b80dadced4474bb0f58)
#         ;
#
#
#
#
#             var marker_894db1f65d4e299db5fe6788a3903402 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_89e64ddbaf98fe7db62b77fcd59ee5aa);
#
#
#         var popup_e57645293cef54c27d9ad87b40ca66e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff470d7da1a3f9aeac2a4a9662ecf633 = $(`&lt;div id=&quot;html_ff470d7da1a3f9aeac2a4a9662ecf633&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e57645293cef54c27d9ad87b40ca66e7.setContent(html_ff470d7da1a3f9aeac2a4a9662ecf633);
#
#
#
#         marker_894db1f65d4e299db5fe6788a3903402.bindPopup(popup_e57645293cef54c27d9ad87b40ca66e7)
#         ;
#
#
#
#
#             var marker_6688420a4f401caa1571fd7f1c48009f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_89e64ddbaf98fe7db62b77fcd59ee5aa);
#
#
#         var popup_d861adc23891bece04946888243907ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c4068bf6d993a13ae30cd764c6e69d8 = $(`&lt;div id=&quot;html_8c4068bf6d993a13ae30cd764c6e69d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d861adc23891bece04946888243907ba.setContent(html_8c4068bf6d993a13ae30cd764c6e69d8);
#
#
#
#         marker_6688420a4f401caa1571fd7f1c48009f.bindPopup(popup_d861adc23891bece04946888243907ba)
#         ;
#
#
#
#
#             var marker_c2e50f39d48a78eb558b2ae727dfb84a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_89e64ddbaf98fe7db62b77fcd59ee5aa);
#
#
#         var popup_df7dc182ad220f18466f10a30757e059 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33c33cce64f1d25cefe3adea3dbde41c = $(`&lt;div id=&quot;html_33c33cce64f1d25cefe3adea3dbde41c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_df7dc182ad220f18466f10a30757e059.setContent(html_33c33cce64f1d25cefe3adea3dbde41c);
#
#
#
#         marker_c2e50f39d48a78eb558b2ae727dfb84a.bindPopup(popup_df7dc182ad220f18466f10a30757e059)
#         ;
#
#
#
#
#             var marker_0c6bc171a4389bb87c962c12e90d5d65 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_89e64ddbaf98fe7db62b77fcd59ee5aa);
#
#
#         var popup_f88fdb0236c7cac1e66a31096daed605 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0db4e679129b7eec924ef2bdd5a12303 = $(`&lt;div id=&quot;html_0db4e679129b7eec924ef2bdd5a12303&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fb98f21e9c0ba54943a75d6ba8e85ee6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fb98f21e9c0ba54943a75d6ba8e85ee6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fb98f21e9c0ba54943a75d6ba8e85ee6 = L.map(
#                 &quot;map_fb98f21e9c0ba54943a75d6ba8e85ee6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b80fa2328e2c32573681345f4b7a408c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b80fa2328e2c32573681345f4b7a408c.addTo(map_fb98f21e9c0ba54943a75d6ba8e85ee6);
#
#
#             var feature_group_6c21645e466ec709310ae741a978c905 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6c21645e466ec709310ae741a978c905.addTo(map_fb98f21e9c0ba54943a75d6ba8e85ee6);
#
#
#             var feature_group_sub_group_3d2b3356a9b98ad68a98e0f00c7b212a = L.featureGroup.subGroup(
#                 feature_group_6c21645e466ec709310ae741a978c905
#             );
#
#
#             var marker_64c9fbd5e6c0bf28420b7e9ca66b55a0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3d2b3356a9b98ad68a98e0f00c7b212a);
#
#
#         var popup_29357c2ebb92126ec5e6bba3e1309e70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5d6668ec1a6cb7139395c3d07bcf85e = $(`&lt;div id=&quot;html_d5d6668ec1a6cb7139395c3d07bcf85e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_29357c2ebb92126ec5e6bba3e1309e70.setContent(html_d5d6668ec1a6cb7139395c3d07bcf85e);
#
#
#
#         marker_64c9fbd5e6c0bf28420b7e9ca66b55a0.bindPopup(popup_29357c2ebb92126ec5e6bba3e1309e70)
#         ;
#
#
#
#
#             var marker_0b9f7adf21258ccf5d4c6ee91d58226d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3d2b3356a9b98ad68a98e0f00c7b212a);
#
#
#         var popup_6d378f1bbb239ba94864eb1ce777f85b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c89ce5c0d53f3c104cb72bde6a921a9 = $(`&lt;div id=&quot;html_7c89ce5c0d53f3c104cb72bde6a921a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_6d378f1bbb239ba94864eb1ce777f85b.setContent(html_7c89ce5c0d53f3c104cb72bde6a921a9);
#
#
#
#         marker_0b9f7adf21258ccf5d4c6ee91d58226d.bindPopup(popup_6d378f1bbb239ba94864eb1ce777f85b)
#         ;
#
#
#
#
#             var marker_3227dcf4cb6e6a8c40c8b32dd5bf4055 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3d2b3356a9b98ad68a98e0f00c7b212a);
#
#
#         var popup_63b846c2e20f14cff395fdfd8c49210c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb7fb87022dc3e14febfb4fa228ee030 = $(`&lt;div id=&quot;html_fb7fb87022dc3e14febfb4fa228ee030&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_63b846c2e20f14cff395fdfd8c49210c.setContent(html_fb7fb87022dc3e14febfb4fa228ee030);
#
#
#
#         marker_3227dcf4cb6e6a8c40c8b32dd5bf4055.bindPopup(popup_63b846c2e20f14cff395fdfd8c49210c)
#         ;
#
#
#
#
#             var marker_c69f19c91b8b5fd150185fa247969666 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3d2b3356a9b98ad68a98e0f00c7b212a);
#
#
#         var popup_5b2c47d16f5413eee8eb30d7839c6150 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0e56b87f3871448932f0ed706bbddf6 = $(`&lt;div id=&quot;html_d0e56b87f3871448932f0ed706bbddf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5b2c47d16f5413eee8eb30d7839c6150.setContent(html_d0e56b87f3871448932f0ed706bbddf6);
#
#
#
#         marker_c69f19c91b8b5fd150185fa247969666.bindPopup(popup_5b2c47d16f5413eee8eb30d7839c6150)
#         ;
#
#
#
#
#             var marker_875d666f1a7731e6faf2b6dad9f1bb27 = L.marker(
#                 [45.0503999
