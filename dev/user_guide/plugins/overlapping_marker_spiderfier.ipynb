# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f2b7819d3ddc1c40d1f23235855dbe12 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f2b7819d3ddc1c40d1f23235855dbe12&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f2b7819d3ddc1c40d1f23235855dbe12 = L.map(
#                 &quot;map_f2b7819d3ddc1c40d1f23235855dbe12&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed28451579e2f0de2866bae59fa3eee4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed28451579e2f0de2866bae59fa3eee4.addTo(map_f2b7819d3ddc1c40d1f23235855dbe12);
#
#
#             var marker_9a1dff472d18c366654f9058294be95d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f2b7819d3ddc1c40d1f23235855dbe12);
#
#
#         var popup_be78c9b9e6aea515e2707a8b4a03e4b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed279e1ef6c284c9ce1a756b3342b07b = $(`&lt;div id=&quot;html_ed279e1ef6c284c9ce1a756b3342b07b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_be78c9b9e6aea515e2707a8b4a03e4b9.setContent(html_ed279e1ef6c284c9ce1a756b3342b07b);
#
#
#
#         marker_9a1dff472d18c366654f9058294be95d.bindPopup(popup_be78c9b9e6aea515e2707a8b4a03e4b9)
#         ;
#
#
#
#
#             var marker_90ec91629e9bc71a5e0dd9ab9fc77f7c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f2b7819d3ddc1c40d1f23235855dbe12);
#
#
#         var popup_6b6016666d1c0769b0f48ec0fda7f21a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bfc09be649d5baab019e2ceeb6cd848 = $(`&lt;div id=&quot;html_1bfc09be649d5baab019e2ceeb6cd848&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6b6016666d1c0769b0f48ec0fda7f21a.setContent(html_1bfc09be649d5baab019e2ceeb6cd848);
#
#
#
#         marker_90ec91629e9bc71a5e0dd9ab9fc77f7c.bindPopup(popup_6b6016666d1c0769b0f48ec0fda7f21a)
#         ;
#
#
#
#
#             var marker_069b48b3fc30c68409d92de79413e453 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f2b7819d3ddc1c40d1f23235855dbe12);
#
#
#         var popup_428bfe57062042daeacd90fa33e405e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d44ddf954fafe7a882687e38469726a4 = $(`&lt;div id=&quot;html_d44ddf954fafe7a882687e38469726a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_428bfe57062042daeacd90fa33e405e0.setContent(html_d44ddf954fafe7a882687e38469726a4);
#
#
#
#         marker_069b48b3fc30c68409d92de79413e453.bindPopup(popup_428bfe57062042daeacd90fa33e405e0)
#         ;
#
#
#
#
#             var marker_587e711f0ab8b0d451e3b29bf4af5c5a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f2b7819d3ddc1c40d1f23235855dbe12);
#
#
#         var popup_929c62f567e042845e8a7bd5496f3d16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6310122997d4353295453de5e3ce5afd = $(`&lt;div id=&quot;html_6310122997d4353295453de5e3ce5afd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_929c62f567e042845e8a7bd5496f3d16.setContent(html_6310122997d4353295453de5e3ce5afd);
#
#
#
#         marker_587e711f0ab8b0d451e3b29bf4af5c5a.bindPopup(popup_929c62f567e042845e8a7bd5496f3d16)
#         ;
#
#
#
#
#             var marker_7cfef168328b7bf04a667ec366fed7f7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f2b7819d3ddc1c40d1f23235855dbe12);
#
#
#         var popup_f4e69181336dfb01ef88383ea551f290 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f39ff86e00e58fa1e93dddb5330c035a = $(`&lt;div id=&quot;html_f39ff86e00e58fa1e93dddb5330c035a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f4e69181336dfb01ef88383ea551f2

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ee15bfb7ccf9d499db245a6cb3eef4e2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ee15bfb7ccf9d499db245a6cb3eef4e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ee15bfb7ccf9d499db245a6cb3eef4e2 = L.map(
#                 &quot;map_ee15bfb7ccf9d499db245a6cb3eef4e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_53797d523d4178ad8f70cb26207ba28c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_53797d523d4178ad8f70cb26207ba28c.addTo(map_ee15bfb7ccf9d499db245a6cb3eef4e2);
#
#
#             var feature_group_c82c41acc77bbb5c9b9382bec2b90907 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8901c366e5b25df6a70c15ff9b782681 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c82c41acc77bbb5c9b9382bec2b90907);
#
#
#         var popup_67eb53cc31242419f82ba6e4154f6c60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9735081c34ac276d9f58a5d421b50b9a = $(`&lt;div id=&quot;html_9735081c34ac276d9f58a5d421b50b9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_67eb53cc31242419f82ba6e4154f6c60.setContent(html_9735081c34ac276d9f58a5d421b50b9a);
#
#
#
#         marker_8901c366e5b25df6a70c15ff9b782681.bindPopup(popup_67eb53cc31242419f82ba6e4154f6c60)
#         ;
#
#
#
#
#             var marker_8aaab095edbfb9c36f2b9eeca32ca6f7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c82c41acc77bbb5c9b9382bec2b90907);
#
#
#         var popup_cf4997c7ef80fac392fe5f1d3d77b816 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6f8f857c8e9deeecd76de952814794b = $(`&lt;div id=&quot;html_c6f8f857c8e9deeecd76de952814794b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cf4997c7ef80fac392fe5f1d3d77b816.setContent(html_c6f8f857c8e9deeecd76de952814794b);
#
#
#
#         marker_8aaab095edbfb9c36f2b9eeca32ca6f7.bindPopup(popup_cf4997c7ef80fac392fe5f1d3d77b816)
#         ;
#
#
#
#
#             var marker_fde595240cd5cca1b3882d0573e16ff0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c82c41acc77bbb5c9b9382bec2b90907);
#
#
#         var popup_f86172fff2da14fe6156305e4c38b314 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8645f3e3ac67151dd4f5c9febaf915b6 = $(`&lt;div id=&quot;html_8645f3e3ac67151dd4f5c9febaf915b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f86172fff2da14fe6156305e4c38b314.setContent(html_8645f3e3ac67151dd4f5c9febaf915b6);
#
#
#
#         marker_fde595240cd5cca1b3882d0573e16ff0.bindPopup(popup_f86172fff2da14fe6156305e4c38b314)
#         ;
#
#
#
#
#             var marker_2766c8e3d58cf82fd81a541289a00b8a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c82c41acc77bbb5c9b9382bec2b90907);
#
#
#         var popup_9907fa12b0106f2136f18ed843f7af3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7db890924eab39884c9e30507e69bfb = $(`&lt;div id=&quot;html_d7db890924eab39884c9e30507e69bfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9907fa12b0106f2136f18ed843f7af3b.setContent(html_d7db890924eab39884c9e30507e69bfb);
#
#
#
#         marker_2766c8e3d58cf82fd81a541289a00b8a.bindPopup(popup_9907fa12b0106f2136f18ed843f7af3b)
#         ;
#
#
#
#
#             var marker_9624b2f5ecbe24378eaf0e422dd504c5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c82c41acc77bbb5c9b9382bec2b90907);
#
#
#         var popup_fd7fd17646b301a73b2e748d341660ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22efe58b6e39a61c27cbd99ed5933fee {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22efe58b6e39a61c27cbd99ed5933fee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22efe58b6e39a61c27cbd99ed5933fee = L.map(
#                 &quot;map_22efe58b6e39a61c27cbd99ed5933fee&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_189950802a44c3ddf45ce6ac66718c17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_189950802a44c3ddf45ce6ac66718c17.addTo(map_22efe58b6e39a61c27cbd99ed5933fee);
#
#
#             var feature_group_fefbf7bc2f0e210f1535fb91338c36b1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fefbf7bc2f0e210f1535fb91338c36b1.addTo(map_22efe58b6e39a61c27cbd99ed5933fee);
#
#
#             var feature_group_sub_group_c274e7ddd7aacaaa8e6df5d49063b154 = L.featureGroup.subGroup(
#                 feature_group_fefbf7bc2f0e210f1535fb91338c36b1
#             );
#
#
#             var marker_db3d0429f8cc6ffc770e7dd6d96f8ae3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c274e7ddd7aacaaa8e6df5d49063b154);
#
#
#         var popup_e5ca5861af8e79ecf413ad67cec1cdde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2587f0703bbf82b8404fd7bee11ba30c = $(`&lt;div id=&quot;html_2587f0703bbf82b8404fd7bee11ba30c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e5ca5861af8e79ecf413ad67cec1cdde.setContent(html_2587f0703bbf82b8404fd7bee11ba30c);
#
#
#
#         marker_db3d0429f8cc6ffc770e7dd6d96f8ae3.bindPopup(popup_e5ca5861af8e79ecf413ad67cec1cdde)
#         ;
#
#
#
#
#             var marker_a09d5e6290c969b046bea30e0d4a3825 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c274e7ddd7aacaaa8e6df5d49063b154);
#
#
#         var popup_a821b116d667f267a0c4ce03176788f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4937f4763dd28adde3fafb6117cb56dd = $(`&lt;div id=&quot;html_4937f4763dd28adde3fafb6117cb56dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a821b116d667f267a0c4ce03176788f7.setContent(html_4937f4763dd28adde3fafb6117cb56dd);
#
#
#
#         marker_a09d5e6290c969b046bea30e0d4a3825.bindPopup(popup_a821b116d667f267a0c4ce03176788f7)
#         ;
#
#
#
#
#             var marker_1be2668738c3a9eaa12a7e02cec3671f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c274e7ddd7aacaaa8e6df5d49063b154);
#
#
#         var popup_482a07d683ad8c5f0245eb89bc649c09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1657defd7c793740297df5a5e5d953c9 = $(`&lt;div id=&quot;html_1657defd7c793740297df5a5e5d953c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_482a07d683ad8c5f0245eb89bc649c09.setContent(html_1657defd7c793740297df5a5e5d953c9);
#
#
#
#         marker_1be2668738c3a9eaa12a7e02cec3671f.bindPopup(popup_482a07d683ad8c5f0245eb89bc649c09)
#         ;
#
#
#
#
#             var marker_3b72b8ce3a98ecf1ef19570c7730871a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c274e7ddd7aacaaa8e6df5d49063b154);
#
#
#         var popup_1bc8677091223dd05b7c1d491ddb1e57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9f3f4007c812218b4d9430c34ce316a = $(`&lt;div id=&quot;html_b9f3f4007c812218b4d9430c34ce316a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1bc8677091223dd05b7c1d491ddb1e57.setContent(html_b9f3f4007c812218b4d9430c34ce316a);
#
#
#
#         mark
