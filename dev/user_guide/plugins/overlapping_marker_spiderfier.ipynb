# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_618e2368561950c5b8a485f195d80f21 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_618e2368561950c5b8a485f195d80f21&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_618e2368561950c5b8a485f195d80f21 = L.map(
#                 &quot;map_618e2368561950c5b8a485f195d80f21&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4eb3dc0779ef8f4e258bf13aa2c466df = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4eb3dc0779ef8f4e258bf13aa2c466df.addTo(map_618e2368561950c5b8a485f195d80f21);
#
#
#             var marker_1d3ab7395cc327cd70a0dd3c20664e4f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_618e2368561950c5b8a485f195d80f21);
#
#
#         var popup_d8251d62565eb098c2a6273186a1296e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d200490dac39a5b9933099ecdcb02e2 = $(`&lt;div id=&quot;html_2d200490dac39a5b9933099ecdcb02e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d8251d62565eb098c2a6273186a1296e.setContent(html_2d200490dac39a5b9933099ecdcb02e2);
#
#
#
#         marker_1d3ab7395cc327cd70a0dd3c20664e4f.bindPopup(popup_d8251d62565eb098c2a6273186a1296e)
#         ;
#
#
#
#
#             var marker_4240e79b310cd9aa043ad0d043e2b30f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_618e2368561950c5b8a485f195d80f21);
#
#
#         var popup_221374a7600e5e2f82a58843af67c0c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0b89eedc34c428789ff6be45bfcf538 = $(`&lt;div id=&quot;html_a0b89eedc34c428789ff6be45bfcf538&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_221374a7600e5e2f82a58843af67c0c9.setContent(html_a0b89eedc34c428789ff6be45bfcf538);
#
#
#
#         marker_4240e79b310cd9aa043ad0d043e2b30f.bindPopup(popup_221374a7600e5e2f82a58843af67c0c9)
#         ;
#
#
#
#
#             var marker_912a4eae9214287c251e678970d8314d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_618e2368561950c5b8a485f195d80f21);
#
#
#         var popup_a0fa12cfc8b56f31eeb71e497ca30ac5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d6ec24f02c571838a52e575900a0b95 = $(`&lt;div id=&quot;html_4d6ec24f02c571838a52e575900a0b95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a0fa12cfc8b56f31eeb71e497ca30ac5.setContent(html_4d6ec24f02c571838a52e575900a0b95);
#
#
#
#         marker_912a4eae9214287c251e678970d8314d.bindPopup(popup_a0fa12cfc8b56f31eeb71e497ca30ac5)
#         ;
#
#
#
#
#             var marker_223371b53e00012655c1093a6fc134c6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_618e2368561950c5b8a485f195d80f21);
#
#
#         var popup_c74db0cb9ee45d765b49c977b7c77b25 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06ea9acde9e23d631dc3f07e55ec683b = $(`&lt;div id=&quot;html_06ea9acde9e23d631dc3f07e55ec683b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c74db0cb9ee45d765b49c977b7c77b25.setContent(html_06ea9acde9e23d631dc3f07e55ec683b);
#
#
#
#         marker_223371b53e00012655c1093a6fc134c6.bindPopup(popup_c74db0cb9ee45d765b49c977b7c77b25)
#         ;
#
#
#
#
#             var marker_53fedc1af0d059087282ef716a6d8925 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_618e2368561950c5b8a485f195d80f21);
#
#
#         var popup_e3cd5094585f9010b6c2879c69a16fed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7366027c306967a7942aab46380c7c5 = $(`&lt;div id=&quot;html_e7366027c306967a7942aab46380c7c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e3cd5094585f9010b6c2879c69a16fed.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90332ee2a909b730bedda64e6a7d39cb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90332ee2a909b730bedda64e6a7d39cb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90332ee2a909b730bedda64e6a7d39cb = L.map(
#                 &quot;map_90332ee2a909b730bedda64e6a7d39cb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_532df45c260e9e416ca3354b4e0d08e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_532df45c260e9e416ca3354b4e0d08e6.addTo(map_90332ee2a909b730bedda64e6a7d39cb);
#
#
#             var feature_group_4ad7e94878d017952c1dc2010878389d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cdc9308d6b01f7dd83c8498b0ab44e6e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4ad7e94878d017952c1dc2010878389d);
#
#
#         var popup_e30d3390c552214bb408a318525334cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a006b8e0525c3cdb62a86d2c92f2eba6 = $(`&lt;div id=&quot;html_a006b8e0525c3cdb62a86d2c92f2eba6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e30d3390c552214bb408a318525334cd.setContent(html_a006b8e0525c3cdb62a86d2c92f2eba6);
#
#
#
#         marker_cdc9308d6b01f7dd83c8498b0ab44e6e.bindPopup(popup_e30d3390c552214bb408a318525334cd)
#         ;
#
#
#
#
#             var marker_12c7199fa5dc062aa37d57e8343a46ae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4ad7e94878d017952c1dc2010878389d);
#
#
#         var popup_6faad0a90b1a29b334dd0e74536e41bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a157c84cf58cba2dddb87301a3e2a3d = $(`&lt;div id=&quot;html_3a157c84cf58cba2dddb87301a3e2a3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6faad0a90b1a29b334dd0e74536e41bc.setContent(html_3a157c84cf58cba2dddb87301a3e2a3d);
#
#
#
#         marker_12c7199fa5dc062aa37d57e8343a46ae.bindPopup(popup_6faad0a90b1a29b334dd0e74536e41bc)
#         ;
#
#
#
#
#             var marker_d21e4c00f291b8a522618bb6a169bb6b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4ad7e94878d017952c1dc2010878389d);
#
#
#         var popup_c990a8cb30207c15afef3089eb932f32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d802537657e62e2aab9fff7b148f371 = $(`&lt;div id=&quot;html_1d802537657e62e2aab9fff7b148f371&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c990a8cb30207c15afef3089eb932f32.setContent(html_1d802537657e62e2aab9fff7b148f371);
#
#
#
#         marker_d21e4c00f291b8a522618bb6a169bb6b.bindPopup(popup_c990a8cb30207c15afef3089eb932f32)
#         ;
#
#
#
#
#             var marker_12c964e58a4d231bbdbdbf646e7f8cc1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4ad7e94878d017952c1dc2010878389d);
#
#
#         var popup_fdedde38a9fa288d22d8492272d89f59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e513d5db164ef21f4a15236a17cd3418 = $(`&lt;div id=&quot;html_e513d5db164ef21f4a15236a17cd3418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fdedde38a9fa288d22d8492272d89f59.setContent(html_e513d5db164ef21f4a15236a17cd3418);
#
#
#
#         marker_12c964e58a4d231bbdbdbf646e7f8cc1.bindPopup(popup_fdedde38a9fa288d22d8492272d89f59)
#         ;
#
#
#
#
#             var marker_f07d16725f1669546ddc57b1bc757c0d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4ad7e94878d017952c1dc2010878389d);
#
#
#         var popup_d2a3e52ebda1e8630fe67fc6f2edbaef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b212d31636664c76d95417c6f4a20048 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b212d31636664c76d95417c6f4a20048&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b212d31636664c76d95417c6f4a20048 = L.map(
#                 &quot;map_b212d31636664c76d95417c6f4a20048&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_436b0325724038262aecb6cd91f62958 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_436b0325724038262aecb6cd91f62958.addTo(map_b212d31636664c76d95417c6f4a20048);
#
#
#             var feature_group_0434b18b615351d956d60e47672c38c8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0434b18b615351d956d60e47672c38c8.addTo(map_b212d31636664c76d95417c6f4a20048);
#
#
#             var feature_group_sub_group_f831817d6911fe3b59f7c8de56f3f930 = L.featureGroup.subGroup(
#                 feature_group_0434b18b615351d956d60e47672c38c8
#             );
#
#
#             var marker_1a02ebc3054d5f29fc03e3094260cffe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f831817d6911fe3b59f7c8de56f3f930);
#
#
#         var popup_d22c8a647823e63b91069d19335d3ce5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10a18c8a1cd2bbf7d2e826712a5a63b9 = $(`&lt;div id=&quot;html_10a18c8a1cd2bbf7d2e826712a5a63b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d22c8a647823e63b91069d19335d3ce5.setContent(html_10a18c8a1cd2bbf7d2e826712a5a63b9);
#
#
#
#         marker_1a02ebc3054d5f29fc03e3094260cffe.bindPopup(popup_d22c8a647823e63b91069d19335d3ce5)
#         ;
#
#
#
#
#             var marker_e8df9d5fb8dca4f6085cbc41d6c19cff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f831817d6911fe3b59f7c8de56f3f930);
#
#
#         var popup_98cc3499314b5eb2f9194211a93f1c94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d99f82f38cdb3e213c36ddae5a49b2fb = $(`&lt;div id=&quot;html_d99f82f38cdb3e213c36ddae5a49b2fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_98cc3499314b5eb2f9194211a93f1c94.setContent(html_d99f82f38cdb3e213c36ddae5a49b2fb);
#
#
#
#         marker_e8df9d5fb8dca4f6085cbc41d6c19cff.bindPopup(popup_98cc3499314b5eb2f9194211a93f1c94)
#         ;
#
#
#
#
#             var marker_b8f7b50f1866322d084d35ed19a26ac3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f831817d6911fe3b59f7c8de56f3f930);
#
#
#         var popup_ca3110c432b124f1269d4cf305ed057d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d4ccb0e7985a681aa5bbd0d6149db46 = $(`&lt;div id=&quot;html_2d4ccb0e7985a681aa5bbd0d6149db46&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ca3110c432b124f1269d4cf305ed057d.setContent(html_2d4ccb0e7985a681aa5bbd0d6149db46);
#
#
#
#         marker_b8f7b50f1866322d084d35ed19a26ac3.bindPopup(popup_ca3110c432b124f1269d4cf305ed057d)
#         ;
#
#
#
#
#             var marker_c564c677fe980cd509bca1a66c2a8f67 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f831817d6911fe3b59f7c8de56f3f930);
#
#
#         var popup_8eea1cf59f5a98884a33416d4ea3f5d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63d3b8e17061a74ceae4fff1364a8c74 = $(`&lt;div id=&quot;html_63d3b8e17061a74ceae4fff1364a8c74&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8eea1cf59f5a98884a33416d4ea3f5d6.setContent(html_63d3b8e17061a74ceae4fff1364a8c74);
#
#
#
#         marker_
