# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fc818a18b38ba23ce7f45b29f14b816 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fc818a18b38ba23ce7f45b29f14b816&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fc818a18b38ba23ce7f45b29f14b816 = L.map(
#                 &quot;map_8fc818a18b38ba23ce7f45b29f14b816&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a06035dc971e1c5dd46d3e4e7302878 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a06035dc971e1c5dd46d3e4e7302878.addTo(map_8fc818a18b38ba23ce7f45b29f14b816);
#
#
#             var marker_0494e489469718e504c55851cea23873 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8fc818a18b38ba23ce7f45b29f14b816);
#
#
#         var popup_3ab2250337820215e78aeab0e5892fac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d20132bda89a281d4a52d8560516c10a = $(`&lt;div id=&quot;html_d20132bda89a281d4a52d8560516c10a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3ab2250337820215e78aeab0e5892fac.setContent(html_d20132bda89a281d4a52d8560516c10a);
#
#
#
#         marker_0494e489469718e504c55851cea23873.bindPopup(popup_3ab2250337820215e78aeab0e5892fac)
#         ;
#
#
#
#
#             var marker_5d0c0c7bb2353282c023359df4daefe8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8fc818a18b38ba23ce7f45b29f14b816);
#
#
#         var popup_9265682661a59492d7b55076d081c303 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7585602b2a5fd29f86c0c1bc7567294d = $(`&lt;div id=&quot;html_7585602b2a5fd29f86c0c1bc7567294d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9265682661a59492d7b55076d081c303.setContent(html_7585602b2a5fd29f86c0c1bc7567294d);
#
#
#
#         marker_5d0c0c7bb2353282c023359df4daefe8.bindPopup(popup_9265682661a59492d7b55076d081c303)
#         ;
#
#
#
#
#             var marker_6fc1b9b9a18a84b8b3e1970ef6a02a54 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8fc818a18b38ba23ce7f45b29f14b816);
#
#
#         var popup_a80a5df3d8ce50bbde4b4170a1602681 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb5ef54859ab87971b875b865af2d86c = $(`&lt;div id=&quot;html_eb5ef54859ab87971b875b865af2d86c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a80a5df3d8ce50bbde4b4170a1602681.setContent(html_eb5ef54859ab87971b875b865af2d86c);
#
#
#
#         marker_6fc1b9b9a18a84b8b3e1970ef6a02a54.bindPopup(popup_a80a5df3d8ce50bbde4b4170a1602681)
#         ;
#
#
#
#
#             var marker_45f99aca13aa9596a0965889831cc1ce = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8fc818a18b38ba23ce7f45b29f14b816);
#
#
#         var popup_8fe0f0ee0c746666dc76d37ed7c06d78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c6c2689355552a1eb75f41c7f804495 = $(`&lt;div id=&quot;html_9c6c2689355552a1eb75f41c7f804495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8fe0f0ee0c746666dc76d37ed7c06d78.setContent(html_9c6c2689355552a1eb75f41c7f804495);
#
#
#
#         marker_45f99aca13aa9596a0965889831cc1ce.bindPopup(popup_8fe0f0ee0c746666dc76d37ed7c06d78)
#         ;
#
#
#
#
#             var marker_6f7c1cd6d1b6854677d1de6f3871b083 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8fc818a18b38ba23ce7f45b29f14b816);
#
#
#         var popup_aa39814aee938a78a9caadf1620bc80a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_345fcf4d14e3c1303a01402b3aff616d = $(`&lt;div id=&quot;html_345fcf4d14e3c1303a01402b3aff616d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_aa39814aee938a78a9caadf1620bc80a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0508b9ee9c4a17ed30d43fa3a1c6e74f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0508b9ee9c4a17ed30d43fa3a1c6e74f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0508b9ee9c4a17ed30d43fa3a1c6e74f = L.map(
#                 &quot;map_0508b9ee9c4a17ed30d43fa3a1c6e74f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_94845bad74848a5fd9bde9566f944f3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_94845bad74848a5fd9bde9566f944f3e.addTo(map_0508b9ee9c4a17ed30d43fa3a1c6e74f);
#
#
#             var feature_group_cb53a375cf84cff732d770eb01305b83 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e7bb50bae101a5205756438467e60731 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cb53a375cf84cff732d770eb01305b83);
#
#
#         var popup_c289554e68bbe9398a1b609247745be8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96d4e512fc19ffb1eae6a60a8a78be17 = $(`&lt;div id=&quot;html_96d4e512fc19ffb1eae6a60a8a78be17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c289554e68bbe9398a1b609247745be8.setContent(html_96d4e512fc19ffb1eae6a60a8a78be17);
#
#
#
#         marker_e7bb50bae101a5205756438467e60731.bindPopup(popup_c289554e68bbe9398a1b609247745be8)
#         ;
#
#
#
#
#             var marker_42aa1cad9a49f36793ec8a3f6ed8a6d6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cb53a375cf84cff732d770eb01305b83);
#
#
#         var popup_5ed40972175422a5c2af37aceabb04a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ed9702a68f97b26e6e29fa372716de24 = $(`&lt;div id=&quot;html_ed9702a68f97b26e6e29fa372716de24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5ed40972175422a5c2af37aceabb04a0.setContent(html_ed9702a68f97b26e6e29fa372716de24);
#
#
#
#         marker_42aa1cad9a49f36793ec8a3f6ed8a6d6.bindPopup(popup_5ed40972175422a5c2af37aceabb04a0)
#         ;
#
#
#
#
#             var marker_20059219add8c876f8ccd8144e0e5d2a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cb53a375cf84cff732d770eb01305b83);
#
#
#         var popup_d9baea9246a652771c1bb75b1366c0ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8716fa3e45f0290595da76a40747610 = $(`&lt;div id=&quot;html_b8716fa3e45f0290595da76a40747610&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d9baea9246a652771c1bb75b1366c0ef.setContent(html_b8716fa3e45f0290595da76a40747610);
#
#
#
#         marker_20059219add8c876f8ccd8144e0e5d2a.bindPopup(popup_d9baea9246a652771c1bb75b1366c0ef)
#         ;
#
#
#
#
#             var marker_85aab804ebed411915cf5d233ec55169 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cb53a375cf84cff732d770eb01305b83);
#
#
#         var popup_07fdb01d161b460b04281e1cc09f7b28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88099e40e6d3be0182c2e5e032f22cef = $(`&lt;div id=&quot;html_88099e40e6d3be0182c2e5e032f22cef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_07fdb01d161b460b04281e1cc09f7b28.setContent(html_88099e40e6d3be0182c2e5e032f22cef);
#
#
#
#         marker_85aab804ebed411915cf5d233ec55169.bindPopup(popup_07fdb01d161b460b04281e1cc09f7b28)
#         ;
#
#
#
#
#             var marker_b14afe445f54c234bea73c013b034850 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cb53a375cf84cff732d770eb01305b83);
#
#
#         var popup_e9c17d3f8a9828cc1aadad88f8cbd7cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35c1506b61fcde610e2fa63c73f4f4e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35c1506b61fcde610e2fa63c73f4f4e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35c1506b61fcde610e2fa63c73f4f4e2 = L.map(
#                 &quot;map_35c1506b61fcde610e2fa63c73f4f4e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6f08c445ef5979e401dd3b41d1a3e4c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6f08c445ef5979e401dd3b41d1a3e4c.addTo(map_35c1506b61fcde610e2fa63c73f4f4e2);
#
#
#             var feature_group_227b8d9e001d8af316cae026d6a3a7f5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_227b8d9e001d8af316cae026d6a3a7f5.addTo(map_35c1506b61fcde610e2fa63c73f4f4e2);
#
#
#             var feature_group_sub_group_cb310d94ebfcab9a3ba9c33d87aec6fc = L.featureGroup.subGroup(
#                 feature_group_227b8d9e001d8af316cae026d6a3a7f5
#             );
#
#
#             var marker_9285b3dc2cba00dcd3dc8f7a2d723d92 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb310d94ebfcab9a3ba9c33d87aec6fc);
#
#
#         var popup_0bbf9d494f5c39625d0f6fd40d3a97f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07170eba97a1cecebb60a2cb1dd25ade = $(`&lt;div id=&quot;html_07170eba97a1cecebb60a2cb1dd25ade&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0bbf9d494f5c39625d0f6fd40d3a97f4.setContent(html_07170eba97a1cecebb60a2cb1dd25ade);
#
#
#
#         marker_9285b3dc2cba00dcd3dc8f7a2d723d92.bindPopup(popup_0bbf9d494f5c39625d0f6fd40d3a97f4)
#         ;
#
#
#
#
#             var marker_28e983cd85ed16aa3af00369ead81569 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb310d94ebfcab9a3ba9c33d87aec6fc);
#
#
#         var popup_b9d6fdc096462f9e4318c5771948d8f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4542127c31dbbd9999b5eedfb20cbda2 = $(`&lt;div id=&quot;html_4542127c31dbbd9999b5eedfb20cbda2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b9d6fdc096462f9e4318c5771948d8f3.setContent(html_4542127c31dbbd9999b5eedfb20cbda2);
#
#
#
#         marker_28e983cd85ed16aa3af00369ead81569.bindPopup(popup_b9d6fdc096462f9e4318c5771948d8f3)
#         ;
#
#
#
#
#             var marker_998bdfe951b29f85802c7e7880681db8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb310d94ebfcab9a3ba9c33d87aec6fc);
#
#
#         var popup_b6b88b018b85901fc507edc3deca064a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df4b0968097326a37bf53bdfaac7514d = $(`&lt;div id=&quot;html_df4b0968097326a37bf53bdfaac7514d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b6b88b018b85901fc507edc3deca064a.setContent(html_df4b0968097326a37bf53bdfaac7514d);
#
#
#
#         marker_998bdfe951b29f85802c7e7880681db8.bindPopup(popup_b6b88b018b85901fc507edc3deca064a)
#         ;
#
#
#
#
#             var marker_5da67536ad5db87cbd1f04e0674dd9ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cb310d94ebfcab9a3ba9c33d87aec6fc);
#
#
#         var popup_bd6c2b19b87e73002df28762c64e3eb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a70d2b1a56c7d4a6350cefb5f43aa4c = $(`&lt;div id=&quot;html_4a70d2b1a56c7d4a6350cefb5f43aa4c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bd6c2b19b87e73002df28762c64e3eb4.setContent(html_4a70d2b1a56c7d4a6350cefb5f43aa4c);
#
#
#
#         marker_
