# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a846cff6f1c6b1b6a03ed0acfbf8a9d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a846cff6f1c6b1b6a03ed0acfbf8a9d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a846cff6f1c6b1b6a03ed0acfbf8a9d6 = L.map(
#                 &quot;map_a846cff6f1c6b1b6a03ed0acfbf8a9d6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1485585fbfce7871817c086596f7a281 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1485585fbfce7871817c086596f7a281.addTo(map_a846cff6f1c6b1b6a03ed0acfbf8a9d6);
#
#
#             var marker_c4455061a55bf293cb8ee63c8c7c7a4d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a846cff6f1c6b1b6a03ed0acfbf8a9d6);
#
#
#         var popup_c68092a0f166490fc7a7fb66b6e078aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e209db300b2f352b85785745df66afb8 = $(`&lt;div id=&quot;html_e209db300b2f352b85785745df66afb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c68092a0f166490fc7a7fb66b6e078aa.setContent(html_e209db300b2f352b85785745df66afb8);
#
#
#
#         marker_c4455061a55bf293cb8ee63c8c7c7a4d.bindPopup(popup_c68092a0f166490fc7a7fb66b6e078aa)
#         ;
#
#
#
#
#             var marker_842aa81ecb8c8c2dc077b48fe886dce4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a846cff6f1c6b1b6a03ed0acfbf8a9d6);
#
#
#         var popup_86fc9b56648d9602e4f7db265b79cc69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7532ba86836eac039198e9600344e941 = $(`&lt;div id=&quot;html_7532ba86836eac039198e9600344e941&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_86fc9b56648d9602e4f7db265b79cc69.setContent(html_7532ba86836eac039198e9600344e941);
#
#
#
#         marker_842aa81ecb8c8c2dc077b48fe886dce4.bindPopup(popup_86fc9b56648d9602e4f7db265b79cc69)
#         ;
#
#
#
#
#             var marker_2f5313c260da42b797e8cf9fead85f83 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a846cff6f1c6b1b6a03ed0acfbf8a9d6);
#
#
#         var popup_138119b879cb001989f740a0769be925 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85c5fc14be7316607daccd797ccbec2d = $(`&lt;div id=&quot;html_85c5fc14be7316607daccd797ccbec2d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_138119b879cb001989f740a0769be925.setContent(html_85c5fc14be7316607daccd797ccbec2d);
#
#
#
#         marker_2f5313c260da42b797e8cf9fead85f83.bindPopup(popup_138119b879cb001989f740a0769be925)
#         ;
#
#
#
#
#             var marker_782096d20fb1187b0b501bb9d20a8e71 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a846cff6f1c6b1b6a03ed0acfbf8a9d6);
#
#
#         var popup_0a1904a2267f01adafe3283bdfbe5633 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3f477dc5eaa3c98b7f5734eec05569c = $(`&lt;div id=&quot;html_d3f477dc5eaa3c98b7f5734eec05569c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0a1904a2267f01adafe3283bdfbe5633.setContent(html_d3f477dc5eaa3c98b7f5734eec05569c);
#
#
#
#         marker_782096d20fb1187b0b501bb9d20a8e71.bindPopup(popup_0a1904a2267f01adafe3283bdfbe5633)
#         ;
#
#
#
#
#             var marker_93297b40b9b9f60a807dc02a6860b021 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a846cff6f1c6b1b6a03ed0acfbf8a9d6);
#
#
#         var popup_581dd35ff92a8369615607a7bc76e746 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8df2ba27fface89f751bd16e7ad1692 = $(`&lt;div id=&quot;html_b8df2ba27fface89f751bd16e7ad1692&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_581dd35ff92a8369615607a7bc76e746.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6430cd97e6184215e6e537893dbceef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6430cd97e6184215e6e537893dbceef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6430cd97e6184215e6e537893dbceef = L.map(
#                 &quot;map_b6430cd97e6184215e6e537893dbceef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa21c27e4ff44a7dd5b860780e83523d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa21c27e4ff44a7dd5b860780e83523d.addTo(map_b6430cd97e6184215e6e537893dbceef);
#
#
#             var feature_group_2c7319f386012b439a5efa9cf92d9507 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2ecaa097fc49407480e02858e74f4743 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2c7319f386012b439a5efa9cf92d9507);
#
#
#         var popup_dc1f7ae370d08ff28abda4e8784fd5e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f21904a64306e1529739e25ab290d80 = $(`&lt;div id=&quot;html_8f21904a64306e1529739e25ab290d80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dc1f7ae370d08ff28abda4e8784fd5e6.setContent(html_8f21904a64306e1529739e25ab290d80);
#
#
#
#         marker_2ecaa097fc49407480e02858e74f4743.bindPopup(popup_dc1f7ae370d08ff28abda4e8784fd5e6)
#         ;
#
#
#
#
#             var marker_b0107c5e59328128aeb16c6d52ee07a7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2c7319f386012b439a5efa9cf92d9507);
#
#
#         var popup_e440e3d2357296d1f56a9191997f6525 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_642096c6eedbad0c902d8506b4c00fb6 = $(`&lt;div id=&quot;html_642096c6eedbad0c902d8506b4c00fb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e440e3d2357296d1f56a9191997f6525.setContent(html_642096c6eedbad0c902d8506b4c00fb6);
#
#
#
#         marker_b0107c5e59328128aeb16c6d52ee07a7.bindPopup(popup_e440e3d2357296d1f56a9191997f6525)
#         ;
#
#
#
#
#             var marker_af742d0897254eca0afd4a71eb307170 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2c7319f386012b439a5efa9cf92d9507);
#
#
#         var popup_1c34b1e6759a2057b37e7af80e638494 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14ad44aa9dda9e38b2dd2305558efc5c = $(`&lt;div id=&quot;html_14ad44aa9dda9e38b2dd2305558efc5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1c34b1e6759a2057b37e7af80e638494.setContent(html_14ad44aa9dda9e38b2dd2305558efc5c);
#
#
#
#         marker_af742d0897254eca0afd4a71eb307170.bindPopup(popup_1c34b1e6759a2057b37e7af80e638494)
#         ;
#
#
#
#
#             var marker_328aaabbc3079899cb490bc52c08af2e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2c7319f386012b439a5efa9cf92d9507);
#
#
#         var popup_97d622f1275856f215a05a258f705cb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdbd63953ea1383e967fa3981af86c47 = $(`&lt;div id=&quot;html_fdbd63953ea1383e967fa3981af86c47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_97d622f1275856f215a05a258f705cb0.setContent(html_fdbd63953ea1383e967fa3981af86c47);
#
#
#
#         marker_328aaabbc3079899cb490bc52c08af2e.bindPopup(popup_97d622f1275856f215a05a258f705cb0)
#         ;
#
#
#
#
#             var marker_ed4f55f6cad3087de643379fd6106fa2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2c7319f386012b439a5efa9cf92d9507);
#
#
#         var popup_b94b8204eb06e0c33e3f7fab64f194dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c54ea88c41401d827aaf8131acfb0034 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c54ea88c41401d827aaf8131acfb0034&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c54ea88c41401d827aaf8131acfb0034 = L.map(
#                 &quot;map_c54ea88c41401d827aaf8131acfb0034&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_19c33866064aec12793d984bf729274e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_19c33866064aec12793d984bf729274e.addTo(map_c54ea88c41401d827aaf8131acfb0034);
#
#
#             var feature_group_1fc98f66227bc88268532ef37a1fbe8e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1fc98f66227bc88268532ef37a1fbe8e.addTo(map_c54ea88c41401d827aaf8131acfb0034);
#
#
#             var feature_group_sub_group_25e63e00b8d8eeb67018b42de078d615 = L.featureGroup.subGroup(
#                 feature_group_1fc98f66227bc88268532ef37a1fbe8e
#             );
#
#
#             var marker_f267bea8db5088ae5ff7eb62c3efb37c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_25e63e00b8d8eeb67018b42de078d615);
#
#
#         var popup_3ef77722d6a9c1d13a94e0ea7adcabd1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea44ab28609ff77d22d66feb4f54ed18 = $(`&lt;div id=&quot;html_ea44ab28609ff77d22d66feb4f54ed18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3ef77722d6a9c1d13a94e0ea7adcabd1.setContent(html_ea44ab28609ff77d22d66feb4f54ed18);
#
#
#
#         marker_f267bea8db5088ae5ff7eb62c3efb37c.bindPopup(popup_3ef77722d6a9c1d13a94e0ea7adcabd1)
#         ;
#
#
#
#
#             var marker_7022e888cdc6270f4a68a591ad746d76 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_25e63e00b8d8eeb67018b42de078d615);
#
#
#         var popup_fcbbdbde8c0d9ac71947acb7769e5be4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5554a54049a22e6f3b61be135a83103c = $(`&lt;div id=&quot;html_5554a54049a22e6f3b61be135a83103c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fcbbdbde8c0d9ac71947acb7769e5be4.setContent(html_5554a54049a22e6f3b61be135a83103c);
#
#
#
#         marker_7022e888cdc6270f4a68a591ad746d76.bindPopup(popup_fcbbdbde8c0d9ac71947acb7769e5be4)
#         ;
#
#
#
#
#             var marker_060cbebd4b4fce8caeaba989eb58cba7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_25e63e00b8d8eeb67018b42de078d615);
#
#
#         var popup_f402c7167a94e041703834d4b939cd7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7de8d6976768766f5929e64ba18099fb = $(`&lt;div id=&quot;html_7de8d6976768766f5929e64ba18099fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f402c7167a94e041703834d4b939cd7a.setContent(html_7de8d6976768766f5929e64ba18099fb);
#
#
#
#         marker_060cbebd4b4fce8caeaba989eb58cba7.bindPopup(popup_f402c7167a94e041703834d4b939cd7a)
#         ;
#
#
#
#
#             var marker_f38fea0393cc5249cd7af93b20d2edb5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_25e63e00b8d8eeb67018b42de078d615);
#
#
#         var popup_ad4276b21c423edca8620a4f9bdbb7fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00a6baa7bb3ec058b7e824894fa2ac97 = $(`&lt;div id=&quot;html_00a6baa7bb3ec058b7e824894fa2ac97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ad4276b21c423edca8620a4f9bdbb7fd.setContent(html_00a6baa7bb3ec058b7e824894fa2ac97);
#
#
#
#         marker_
