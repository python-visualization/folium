# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42aa2de7432a3bb7cc6866263255a65f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42aa2de7432a3bb7cc6866263255a65f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42aa2de7432a3bb7cc6866263255a65f = L.map(
#                 &quot;map_42aa2de7432a3bb7cc6866263255a65f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e14f0f2d6dfb635a0b8198cbaa159447 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e14f0f2d6dfb635a0b8198cbaa159447.addTo(map_42aa2de7432a3bb7cc6866263255a65f);
#
#
#             var marker_f4c117c12163bd4d826ec93449dd7d31 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_42aa2de7432a3bb7cc6866263255a65f);
#
#
#         var popup_2cdd0f3e10a199f8dee4464e7aea10ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54fc994c4e50527327cf92535b39e5bd = $(`&lt;div id=&quot;html_54fc994c4e50527327cf92535b39e5bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2cdd0f3e10a199f8dee4464e7aea10ce.setContent(html_54fc994c4e50527327cf92535b39e5bd);
#
#
#
#         marker_f4c117c12163bd4d826ec93449dd7d31.bindPopup(popup_2cdd0f3e10a199f8dee4464e7aea10ce)
#         ;
#
#
#
#
#             var marker_8299e7bd7fdfea472827d9cb3fc159ae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_42aa2de7432a3bb7cc6866263255a65f);
#
#
#         var popup_c65523e96e8ac6aa946fc6cbe0831e6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7837603734d96fe20042151dedbacdfc = $(`&lt;div id=&quot;html_7837603734d96fe20042151dedbacdfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c65523e96e8ac6aa946fc6cbe0831e6c.setContent(html_7837603734d96fe20042151dedbacdfc);
#
#
#
#         marker_8299e7bd7fdfea472827d9cb3fc159ae.bindPopup(popup_c65523e96e8ac6aa946fc6cbe0831e6c)
#         ;
#
#
#
#
#             var marker_6f4f45aa85a5269768708f1f2ce2ad0a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_42aa2de7432a3bb7cc6866263255a65f);
#
#
#         var popup_37125dc4005f5bbb17dc3c9675ed0c0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eaefdee6e8ee6d6d02d3b7fb6eea4c93 = $(`&lt;div id=&quot;html_eaefdee6e8ee6d6d02d3b7fb6eea4c93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_37125dc4005f5bbb17dc3c9675ed0c0e.setContent(html_eaefdee6e8ee6d6d02d3b7fb6eea4c93);
#
#
#
#         marker_6f4f45aa85a5269768708f1f2ce2ad0a.bindPopup(popup_37125dc4005f5bbb17dc3c9675ed0c0e)
#         ;
#
#
#
#
#             var marker_3fcda2803f22e1801118e7f8b4960b74 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_42aa2de7432a3bb7cc6866263255a65f);
#
#
#         var popup_adf4b1ae7ca6872d33475472d45e4d7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81e98cafd89ca476c71e152b6518ce0a = $(`&lt;div id=&quot;html_81e98cafd89ca476c71e152b6518ce0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_adf4b1ae7ca6872d33475472d45e4d7e.setContent(html_81e98cafd89ca476c71e152b6518ce0a);
#
#
#
#         marker_3fcda2803f22e1801118e7f8b4960b74.bindPopup(popup_adf4b1ae7ca6872d33475472d45e4d7e)
#         ;
#
#
#
#
#             var marker_ec8f4ab40589d26b0b6ac2b26a217b99 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_42aa2de7432a3bb7cc6866263255a65f);
#
#
#         var popup_bc19ed5869865fcedb91a107cea045d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b94d13ff4de87b3d052e6d5bdd667496 = $(`&lt;div id=&quot;html_b94d13ff4de87b3d052e6d5bdd667496&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_bc19ed5869865fcedb91a107cea045d3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2952caeac6b2fd7d55ebc7d1dda113ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2952caeac6b2fd7d55ebc7d1dda113ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2952caeac6b2fd7d55ebc7d1dda113ba = L.map(
#                 &quot;map_2952caeac6b2fd7d55ebc7d1dda113ba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cf8f0931f3b033f1c7c928d12dcec0d6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cf8f0931f3b033f1c7c928d12dcec0d6.addTo(map_2952caeac6b2fd7d55ebc7d1dda113ba);
#
#
#             var feature_group_4fdc04b02230aff29b34a5ee0c4d284c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_19fc1197085cc5f9ad0448cbdaa0344a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4fdc04b02230aff29b34a5ee0c4d284c);
#
#
#         var popup_93f499529c817d183d3922c9b74dfc35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f4485d7431fa8b47adf982980d17b58 = $(`&lt;div id=&quot;html_9f4485d7431fa8b47adf982980d17b58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_93f499529c817d183d3922c9b74dfc35.setContent(html_9f4485d7431fa8b47adf982980d17b58);
#
#
#
#         marker_19fc1197085cc5f9ad0448cbdaa0344a.bindPopup(popup_93f499529c817d183d3922c9b74dfc35)
#         ;
#
#
#
#
#             var marker_dbfcd2e91e5a2fdf52645ed4653cf6b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4fdc04b02230aff29b34a5ee0c4d284c);
#
#
#         var popup_e8f2a817279ce348bfa9f569cd1a5506 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_577afb3444c6b794ed5b5cc8fccc9f44 = $(`&lt;div id=&quot;html_577afb3444c6b794ed5b5cc8fccc9f44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e8f2a817279ce348bfa9f569cd1a5506.setContent(html_577afb3444c6b794ed5b5cc8fccc9f44);
#
#
#
#         marker_dbfcd2e91e5a2fdf52645ed4653cf6b6.bindPopup(popup_e8f2a817279ce348bfa9f569cd1a5506)
#         ;
#
#
#
#
#             var marker_941a7dd1ff6d0cd232d2f2e44eb64e6d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4fdc04b02230aff29b34a5ee0c4d284c);
#
#
#         var popup_4f580eda80a1a0c03d3b56e90456636d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4cfce2bb14d7fcf848f2e64a1015a223 = $(`&lt;div id=&quot;html_4cfce2bb14d7fcf848f2e64a1015a223&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4f580eda80a1a0c03d3b56e90456636d.setContent(html_4cfce2bb14d7fcf848f2e64a1015a223);
#
#
#
#         marker_941a7dd1ff6d0cd232d2f2e44eb64e6d.bindPopup(popup_4f580eda80a1a0c03d3b56e90456636d)
#         ;
#
#
#
#
#             var marker_a261e460ee7dca480b30eb2da020e88f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4fdc04b02230aff29b34a5ee0c4d284c);
#
#
#         var popup_ed2612ec8c3dbe5d8a6378c41e572633 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ed754da286e8373997a105f27ec58c0 = $(`&lt;div id=&quot;html_7ed754da286e8373997a105f27ec58c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ed2612ec8c3dbe5d8a6378c41e572633.setContent(html_7ed754da286e8373997a105f27ec58c0);
#
#
#
#         marker_a261e460ee7dca480b30eb2da020e88f.bindPopup(popup_ed2612ec8c3dbe5d8a6378c41e572633)
#         ;
#
#
#
#
#             var marker_4107e5dc85167fe150942ba8a42b6210 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4fdc04b02230aff29b34a5ee0c4d284c);
#
#
#         var popup_077cf5eca584ae0204bc9939ba756c45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9005b54b5af840884693dd6dd8015fe9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9005b54b5af840884693dd6dd8015fe9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9005b54b5af840884693dd6dd8015fe9 = L.map(
#                 &quot;map_9005b54b5af840884693dd6dd8015fe9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_db689767de99643740f8117ecd1594e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_db689767de99643740f8117ecd1594e6.addTo(map_9005b54b5af840884693dd6dd8015fe9);
#
#
#             var feature_group_ac672e5a86c045e36000d7ae823fb03a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ac672e5a86c045e36000d7ae823fb03a.addTo(map_9005b54b5af840884693dd6dd8015fe9);
#
#
#             var feature_group_sub_group_0168989b2131f935712975094787038d = L.featureGroup.subGroup(
#                 feature_group_ac672e5a86c045e36000d7ae823fb03a
#             );
#
#
#             var marker_e70a422ec039aff3e593156d702e4591 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0168989b2131f935712975094787038d);
#
#
#         var popup_4a23e1f094f8966efc13622ff6fe0182 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e25574d5d47eaea4754ad02c14014133 = $(`&lt;div id=&quot;html_e25574d5d47eaea4754ad02c14014133&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4a23e1f094f8966efc13622ff6fe0182.setContent(html_e25574d5d47eaea4754ad02c14014133);
#
#
#
#         marker_e70a422ec039aff3e593156d702e4591.bindPopup(popup_4a23e1f094f8966efc13622ff6fe0182)
#         ;
#
#
#
#
#             var marker_ea9db62b312431cf766e6d4e9d5999d0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0168989b2131f935712975094787038d);
#
#
#         var popup_085bf8b2ccc0957b1b93a0ad3c37a2cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a4f46d6beec314d533d0bb9147164ae = $(`&lt;div id=&quot;html_5a4f46d6beec314d533d0bb9147164ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_085bf8b2ccc0957b1b93a0ad3c37a2cd.setContent(html_5a4f46d6beec314d533d0bb9147164ae);
#
#
#
#         marker_ea9db62b312431cf766e6d4e9d5999d0.bindPopup(popup_085bf8b2ccc0957b1b93a0ad3c37a2cd)
#         ;
#
#
#
#
#             var marker_1f0d2177297c7e6292d6eb8a6c518fac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0168989b2131f935712975094787038d);
#
#
#         var popup_1e730e517a5e86a8ccb9c6dba17fdafd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4a8e83eb54f9ed0d32dc078a3a3a233 = $(`&lt;div id=&quot;html_f4a8e83eb54f9ed0d32dc078a3a3a233&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1e730e517a5e86a8ccb9c6dba17fdafd.setContent(html_f4a8e83eb54f9ed0d32dc078a3a3a233);
#
#
#
#         marker_1f0d2177297c7e6292d6eb8a6c518fac.bindPopup(popup_1e730e517a5e86a8ccb9c6dba17fdafd)
#         ;
#
#
#
#
#             var marker_2d0734473de3e878964ab18183cc640a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0168989b2131f935712975094787038d);
#
#
#         var popup_7b3935edf12ad9c972fd106fe883d711 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fbd782414dcb3221f9ce24e95f2d915 = $(`&lt;div id=&quot;html_9fbd782414dcb3221f9ce24e95f2d915&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7b3935edf12ad9c972fd106fe883d711.setContent(html_9fbd782414dcb3221f9ce24e95f2d915);
#
#
#
#         marker_
