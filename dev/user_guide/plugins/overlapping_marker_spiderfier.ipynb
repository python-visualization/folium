# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_358d99e5522640f4c0ad8ec8a5393bfc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_358d99e5522640f4c0ad8ec8a5393bfc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_358d99e5522640f4c0ad8ec8a5393bfc = L.map(
#                 &quot;map_358d99e5522640f4c0ad8ec8a5393bfc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_88e9636c3b8fb23f6ca82f009b4d4772 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_88e9636c3b8fb23f6ca82f009b4d4772.addTo(map_358d99e5522640f4c0ad8ec8a5393bfc);
#
#
#             var marker_5b29cb4435c265cc94ca9f21f1a24cb0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_358d99e5522640f4c0ad8ec8a5393bfc);
#
#
#         var popup_a13fcfbb792ba5047e42fb64b9fb1a76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7a33a05a3343fbd63ffb7ced9ffa0f4 = $(`&lt;div id=&quot;html_f7a33a05a3343fbd63ffb7ced9ffa0f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a13fcfbb792ba5047e42fb64b9fb1a76.setContent(html_f7a33a05a3343fbd63ffb7ced9ffa0f4);
#
#
#
#         marker_5b29cb4435c265cc94ca9f21f1a24cb0.bindPopup(popup_a13fcfbb792ba5047e42fb64b9fb1a76)
#         ;
#
#
#
#
#             var marker_ab66e97003581f7002ca302de6dc5686 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_358d99e5522640f4c0ad8ec8a5393bfc);
#
#
#         var popup_38f07d682e54a277ea79daf774fb2c35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b96b9c7959edb13e25dfd9136056cd6 = $(`&lt;div id=&quot;html_9b96b9c7959edb13e25dfd9136056cd6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_38f07d682e54a277ea79daf774fb2c35.setContent(html_9b96b9c7959edb13e25dfd9136056cd6);
#
#
#
#         marker_ab66e97003581f7002ca302de6dc5686.bindPopup(popup_38f07d682e54a277ea79daf774fb2c35)
#         ;
#
#
#
#
#             var marker_a16a1b4eb32bfb551b47cc5091bdc8b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_358d99e5522640f4c0ad8ec8a5393bfc);
#
#
#         var popup_0e96dfd932a580cf86b56eb520636708 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f921204c78ff7f569e6426793bf8bdd = $(`&lt;div id=&quot;html_6f921204c78ff7f569e6426793bf8bdd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_0e96dfd932a580cf86b56eb520636708.setContent(html_6f921204c78ff7f569e6426793bf8bdd);
#
#
#
#         marker_a16a1b4eb32bfb551b47cc5091bdc8b4.bindPopup(popup_0e96dfd932a580cf86b56eb520636708)
#         ;
#
#
#
#
#             var marker_c0caeea39f8247a8e102af9efefcd436 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_358d99e5522640f4c0ad8ec8a5393bfc);
#
#
#         var popup_1fd1dae78c7ab1aa5069f847234af5d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1a68ab2a33b08bc75a6a52bcb7e2d98 = $(`&lt;div id=&quot;html_c1a68ab2a33b08bc75a6a52bcb7e2d98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1fd1dae78c7ab1aa5069f847234af5d0.setContent(html_c1a68ab2a33b08bc75a6a52bcb7e2d98);
#
#
#
#         marker_c0caeea39f8247a8e102af9efefcd436.bindPopup(popup_1fd1dae78c7ab1aa5069f847234af5d0)
#         ;
#
#
#
#
#             var marker_9058aefc07a3cdf22424474a6c1425f7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_358d99e5522640f4c0ad8ec8a5393bfc);
#
#
#         var popup_dd7c0dd6892d2beea72efb00ea63b16d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_299d45b5a138980b9e873a4f376f193c = $(`&lt;div id=&quot;html_299d45b5a138980b9e873a4f376f193c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_dd7c0dd6892d2beea72efb00ea63b16d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59d87bd1009e721e2f52fb9f26ea6d98 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59d87bd1009e721e2f52fb9f26ea6d98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59d87bd1009e721e2f52fb9f26ea6d98 = L.map(
#                 &quot;map_59d87bd1009e721e2f52fb9f26ea6d98&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_47349c7877122c6eb167d61c3140a698 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_47349c7877122c6eb167d61c3140a698.addTo(map_59d87bd1009e721e2f52fb9f26ea6d98);
#
#
#             var feature_group_e9181c36fdd640bf79d414924740d90c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_606fe313e2f420752cc7f1843afc21e8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e9181c36fdd640bf79d414924740d90c);
#
#
#         var popup_89c25274b5d5b4500eb7ab5647264d7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a540a1e114b38e4ca67978626afb45a3 = $(`&lt;div id=&quot;html_a540a1e114b38e4ca67978626afb45a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_89c25274b5d5b4500eb7ab5647264d7a.setContent(html_a540a1e114b38e4ca67978626afb45a3);
#
#
#
#         marker_606fe313e2f420752cc7f1843afc21e8.bindPopup(popup_89c25274b5d5b4500eb7ab5647264d7a)
#         ;
#
#
#
#
#             var marker_ffac28fd0a0b6891cf0401e07e9c4b82 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e9181c36fdd640bf79d414924740d90c);
#
#
#         var popup_fdc7c02813bd1ca8530a3d0fcf553b1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7640420ccb42eb0f86cb92ef82abc36 = $(`&lt;div id=&quot;html_f7640420ccb42eb0f86cb92ef82abc36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fdc7c02813bd1ca8530a3d0fcf553b1d.setContent(html_f7640420ccb42eb0f86cb92ef82abc36);
#
#
#
#         marker_ffac28fd0a0b6891cf0401e07e9c4b82.bindPopup(popup_fdc7c02813bd1ca8530a3d0fcf553b1d)
#         ;
#
#
#
#
#             var marker_2c2f65d4834c364d1da9a6819004b088 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e9181c36fdd640bf79d414924740d90c);
#
#
#         var popup_c9d85b952f00505637f2b7c620c57a1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88ab3dd1742d0c5f0bbb93852668e12f = $(`&lt;div id=&quot;html_88ab3dd1742d0c5f0bbb93852668e12f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c9d85b952f00505637f2b7c620c57a1d.setContent(html_88ab3dd1742d0c5f0bbb93852668e12f);
#
#
#
#         marker_2c2f65d4834c364d1da9a6819004b088.bindPopup(popup_c9d85b952f00505637f2b7c620c57a1d)
#         ;
#
#
#
#
#             var marker_2bb5998f18d7c0dd262a4f49c0be217b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e9181c36fdd640bf79d414924740d90c);
#
#
#         var popup_cef1a34843555722f276bef4392b160b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3f291e1565f405a4743076b923882a0 = $(`&lt;div id=&quot;html_a3f291e1565f405a4743076b923882a0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cef1a34843555722f276bef4392b160b.setContent(html_a3f291e1565f405a4743076b923882a0);
#
#
#
#         marker_2bb5998f18d7c0dd262a4f49c0be217b.bindPopup(popup_cef1a34843555722f276bef4392b160b)
#         ;
#
#
#
#
#             var marker_ea9c77d709061cd4b30baab21035b38e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e9181c36fdd640bf79d414924740d90c);
#
#
#         var popup_d82833c5fb53e9d80770d56c2da922c2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cbf5378fdcb4902723d45ce0636bdb8b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cbf5378fdcb4902723d45ce0636bdb8b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cbf5378fdcb4902723d45ce0636bdb8b = L.map(
#                 &quot;map_cbf5378fdcb4902723d45ce0636bdb8b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_278bef77ef03798340889b9903c4bf94 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_278bef77ef03798340889b9903c4bf94.addTo(map_cbf5378fdcb4902723d45ce0636bdb8b);
#
#
#             var feature_group_1b31e93457aba461e73431118645b6a8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1b31e93457aba461e73431118645b6a8.addTo(map_cbf5378fdcb4902723d45ce0636bdb8b);
#
#
#             var feature_group_sub_group_28496f4a3ebd408fd2e5be9efd9488dd = L.featureGroup.subGroup(
#                 feature_group_1b31e93457aba461e73431118645b6a8
#             );
#
#
#             var marker_2381be5722923cf54acc573245d13526 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_28496f4a3ebd408fd2e5be9efd9488dd);
#
#
#         var popup_413a2fcf366ec13e58158aeea2973784 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a320af77ba6ae4983e7ee83a816dfc76 = $(`&lt;div id=&quot;html_a320af77ba6ae4983e7ee83a816dfc76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_413a2fcf366ec13e58158aeea2973784.setContent(html_a320af77ba6ae4983e7ee83a816dfc76);
#
#
#
#         marker_2381be5722923cf54acc573245d13526.bindPopup(popup_413a2fcf366ec13e58158aeea2973784)
#         ;
#
#
#
#
#             var marker_339dd64e3e53b050f124a96880a6bedd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_28496f4a3ebd408fd2e5be9efd9488dd);
#
#
#         var popup_254b5b6bfe3224a5909df0c42cb5e509 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ff361e585b558d5c32770ccd401b43c = $(`&lt;div id=&quot;html_3ff361e585b558d5c32770ccd401b43c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_254b5b6bfe3224a5909df0c42cb5e509.setContent(html_3ff361e585b558d5c32770ccd401b43c);
#
#
#
#         marker_339dd64e3e53b050f124a96880a6bedd.bindPopup(popup_254b5b6bfe3224a5909df0c42cb5e509)
#         ;
#
#
#
#
#             var marker_a16d747000e90e9a77ed8a727b09f595 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_28496f4a3ebd408fd2e5be9efd9488dd);
#
#
#         var popup_a064e06fc1a48ff62e87b16c0467588f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d81fb7122635d472e52942145545241d = $(`&lt;div id=&quot;html_d81fb7122635d472e52942145545241d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a064e06fc1a48ff62e87b16c0467588f.setContent(html_d81fb7122635d472e52942145545241d);
#
#
#
#         marker_a16d747000e90e9a77ed8a727b09f595.bindPopup(popup_a064e06fc1a48ff62e87b16c0467588f)
#         ;
#
#
#
#
#             var marker_d43ddc03d8c9b9d56ee4e6b54166846c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_28496f4a3ebd408fd2e5be9efd9488dd);
#
#
#         var popup_08791f623380d3a1d0e49f3b235d0b4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea93846c8312d9cc8e779584a96dd657 = $(`&lt;div id=&quot;html_ea93846c8312d9cc8e779584a96dd657&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_08791f623380d3a1d0e49f3b235d0b4b.setContent(html_ea93846c8312d9cc8e779584a96dd657);
#
#
#
#         marker_
