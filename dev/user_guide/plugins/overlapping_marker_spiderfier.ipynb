# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7359efe0a712951e6cc130aa271e4f8a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7359efe0a712951e6cc130aa271e4f8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7359efe0a712951e6cc130aa271e4f8a = L.map(
#                 &quot;map_7359efe0a712951e6cc130aa271e4f8a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57b70b32f60daa3d9e511de2d0f401e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57b70b32f60daa3d9e511de2d0f401e7.addTo(map_7359efe0a712951e6cc130aa271e4f8a);
#
#
#             var marker_80bb0e9e4ff0d736351e82820e29501e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7359efe0a712951e6cc130aa271e4f8a);
#
#
#         var popup_10df061fe5c00a71d36ab43e1f2e289f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e286e0f284cb0e85a008636d38a75d3a = $(`&lt;div id=&quot;html_e286e0f284cb0e85a008636d38a75d3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_10df061fe5c00a71d36ab43e1f2e289f.setContent(html_e286e0f284cb0e85a008636d38a75d3a);
#
#
#
#         marker_80bb0e9e4ff0d736351e82820e29501e.bindPopup(popup_10df061fe5c00a71d36ab43e1f2e289f)
#         ;
#
#
#
#
#             var marker_1cce216544b51868536eb89fdc6d2b19 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7359efe0a712951e6cc130aa271e4f8a);
#
#
#         var popup_20be7f29d510fcb8c5896964c155d96e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d6c66a3b536df1d2f41756a6f08f01b = $(`&lt;div id=&quot;html_1d6c66a3b536df1d2f41756a6f08f01b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_20be7f29d510fcb8c5896964c155d96e.setContent(html_1d6c66a3b536df1d2f41756a6f08f01b);
#
#
#
#         marker_1cce216544b51868536eb89fdc6d2b19.bindPopup(popup_20be7f29d510fcb8c5896964c155d96e)
#         ;
#
#
#
#
#             var marker_2f141a2c41d7c6fea2ef78eabd6b0e7b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7359efe0a712951e6cc130aa271e4f8a);
#
#
#         var popup_ef05cd3a16aaf7a64d24fb40a4a23954 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2379580c411781cbb6350e3ef6ab31c6 = $(`&lt;div id=&quot;html_2379580c411781cbb6350e3ef6ab31c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ef05cd3a16aaf7a64d24fb40a4a23954.setContent(html_2379580c411781cbb6350e3ef6ab31c6);
#
#
#
#         marker_2f141a2c41d7c6fea2ef78eabd6b0e7b.bindPopup(popup_ef05cd3a16aaf7a64d24fb40a4a23954)
#         ;
#
#
#
#
#             var marker_568d1970bfce0d069f94aa671fe14bf3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7359efe0a712951e6cc130aa271e4f8a);
#
#
#         var popup_60d861befc27a0926a8285112fe129a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fbca076eebe40e738e2264f6b512ce3 = $(`&lt;div id=&quot;html_6fbca076eebe40e738e2264f6b512ce3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_60d861befc27a0926a8285112fe129a2.setContent(html_6fbca076eebe40e738e2264f6b512ce3);
#
#
#
#         marker_568d1970bfce0d069f94aa671fe14bf3.bindPopup(popup_60d861befc27a0926a8285112fe129a2)
#         ;
#
#
#
#
#             var marker_6faa3fe8e37b5a50efcbd1763055c588 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7359efe0a712951e6cc130aa271e4f8a);
#
#
#         var popup_7552453272b1916a5971247f3e355266 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8bb58a7d6c61fcbb0fa7c91f765a4a48 = $(`&lt;div id=&quot;html_8bb58a7d6c61fcbb0fa7c91f765a4a48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7552453272b1916a5971247f3e355266.setContent(html_8bb58a7d6c61fcbb0fa7c91f765a4a48);
#
#
#
#         marker_6faa3fe8e37b5a50efcbd1763055c588.bindPopup(popup_7552453272b1916a5971247f3e355266)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13b8fb16986019c634e23f5480977c8e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13b8fb16986019c634e23f5480977c8e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13b8fb16986019c634e23f5480977c8e = L.map(
#                 &quot;map_13b8fb16986019c634e23f5480977c8e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_101956a1a62977b0111d77dc5fd4a313 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_101956a1a62977b0111d77dc5fd4a313.addTo(map_13b8fb16986019c634e23f5480977c8e);
#
#
#             var feature_group_57c78890b5f4c2b926bbf7ee549a695c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b95f2666b439b47d95fc37bb46eb05c2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_57c78890b5f4c2b926bbf7ee549a695c);
#
#
#         var popup_0109b660c75a3c91040116a7c42e5463 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34565dd5abafaaae93b6e55ec998c9dd = $(`&lt;div id=&quot;html_34565dd5abafaaae93b6e55ec998c9dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0109b660c75a3c91040116a7c42e5463.setContent(html_34565dd5abafaaae93b6e55ec998c9dd);
#
#
#
#         marker_b95f2666b439b47d95fc37bb46eb05c2.bindPopup(popup_0109b660c75a3c91040116a7c42e5463)
#         ;
#
#
#
#
#             var marker_f82f0bda0e40f5e423a8bec6dd1c60ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_57c78890b5f4c2b926bbf7ee549a695c);
#
#
#         var popup_fc43dd692bc200323314bfb1f801f0fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09c1a9d34d82d5fd494dd7aa3bf43518 = $(`&lt;div id=&quot;html_09c1a9d34d82d5fd494dd7aa3bf43518&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fc43dd692bc200323314bfb1f801f0fd.setContent(html_09c1a9d34d82d5fd494dd7aa3bf43518);
#
#
#
#         marker_f82f0bda0e40f5e423a8bec6dd1c60ea.bindPopup(popup_fc43dd692bc200323314bfb1f801f0fd)
#         ;
#
#
#
#
#             var marker_01d8aed9d96ebc533a556649b0b2f4fa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_57c78890b5f4c2b926bbf7ee549a695c);
#
#
#         var popup_7d5317da88a1e25727fede42cbdbf235 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c0fe4181a2d4b1d30e8600a3549320d = $(`&lt;div id=&quot;html_6c0fe4181a2d4b1d30e8600a3549320d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7d5317da88a1e25727fede42cbdbf235.setContent(html_6c0fe4181a2d4b1d30e8600a3549320d);
#
#
#
#         marker_01d8aed9d96ebc533a556649b0b2f4fa.bindPopup(popup_7d5317da88a1e25727fede42cbdbf235)
#         ;
#
#
#
#
#             var marker_f48a6696649cb0bf581db77638b71077 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_57c78890b5f4c2b926bbf7ee549a695c);
#
#
#         var popup_e46a052d691a3dac4c2c20fe3adcaa9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ece56a51250641e6562d9afd4c44ccf = $(`&lt;div id=&quot;html_9ece56a51250641e6562d9afd4c44ccf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_e46a052d691a3dac4c2c20fe3adcaa9e.setContent(html_9ece56a51250641e6562d9afd4c44ccf);
#
#
#
#         marker_f48a6696649cb0bf581db77638b71077.bindPopup(popup_e46a052d691a3dac4c2c20fe3adcaa9e)
#         ;
#
#
#
#
#             var marker_644ed7ec12dcb8c424376d917fde59e3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_57c78890b5f4c2b926bbf7ee549a695c);
#
#
#         var popup_0fc510421eca198227facfe3de9581d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84bda18cc0f93ad9b34ee7ab87aec22e = $(`&lt;div id=&quot;html_84bda18cc0f93ad9b34ee7ab87aec22e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6c482722a0724171fc145d950bc0c5a3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6c482722a0724171fc145d950bc0c5a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6c482722a0724171fc145d950bc0c5a3 = L.map(
#                 &quot;map_6c482722a0724171fc145d950bc0c5a3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_200430e9c67fd8b41fb43d855dac09a5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_200430e9c67fd8b41fb43d855dac09a5.addTo(map_6c482722a0724171fc145d950bc0c5a3);
#
#
#             var feature_group_a5fe91b427d94516ba28f243232ecbcb = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a5fe91b427d94516ba28f243232ecbcb.addTo(map_6c482722a0724171fc145d950bc0c5a3);
#
#
#             var feature_group_sub_group_f65aced628cb7973855ef4a664de6e8c = L.featureGroup.subGroup(
#                 feature_group_a5fe91b427d94516ba28f243232ecbcb
#             );
#
#
#             var marker_73ad9be78be8fdf77e8aba37125d9367 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65aced628cb7973855ef4a664de6e8c);
#
#
#         var popup_c56984a4bad1d5531c3b07ecf37d948a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de86e34e124cf5ca68aa456a06a63539 = $(`&lt;div id=&quot;html_de86e34e124cf5ca68aa456a06a63539&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c56984a4bad1d5531c3b07ecf37d948a.setContent(html_de86e34e124cf5ca68aa456a06a63539);
#
#
#
#         marker_73ad9be78be8fdf77e8aba37125d9367.bindPopup(popup_c56984a4bad1d5531c3b07ecf37d948a)
#         ;
#
#
#
#
#             var marker_ce99fdcb0b257e59ffdc9fa213e649a3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65aced628cb7973855ef4a664de6e8c);
#
#
#         var popup_0ca96c938fd42042f62e09ac679e74f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_276d58c1777f1962e0f3d002b5f0ee20 = $(`&lt;div id=&quot;html_276d58c1777f1962e0f3d002b5f0ee20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0ca96c938fd42042f62e09ac679e74f8.setContent(html_276d58c1777f1962e0f3d002b5f0ee20);
#
#
#
#         marker_ce99fdcb0b257e59ffdc9fa213e649a3.bindPopup(popup_0ca96c938fd42042f62e09ac679e74f8)
#         ;
#
#
#
#
#             var marker_d02567f45ccaaf038c3a3d5f73d13ee5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65aced628cb7973855ef4a664de6e8c);
#
#
#         var popup_27e8cfbdab68090bb8b8aaa14b41c805 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2670ed67578d7db2899131a5198c69b4 = $(`&lt;div id=&quot;html_2670ed67578d7db2899131a5198c69b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_27e8cfbdab68090bb8b8aaa14b41c805.setContent(html_2670ed67578d7db2899131a5198c69b4);
#
#
#
#         marker_d02567f45ccaaf038c3a3d5f73d13ee5.bindPopup(popup_27e8cfbdab68090bb8b8aaa14b41c805)
#         ;
#
#
#
#
#             var marker_7011b7fa80e48a38ebc09be16bc6c324 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f65aced628cb7973855ef4a664de6e8c);
#
#
#         var popup_d5dfe558ed9c4512b4a7e0d5d3920bb8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c293f8debb9ea6a38a5aad88012d2bc = $(`&lt;div id=&quot;html_4c293f8debb9ea6a38a5aad88012d2bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d5dfe558ed9c4512b4a7e0d5d3920bb8.setContent(html_4c293f8debb9ea6a38a5aad88012d2bc);
#
#
#
#         marker_7011b7fa80e48a38ebc09be16bc6c324.bindPopup(popup_d5dfe558ed9c4512b4a7e0d5d3920bb8)
#         ;
#
#
#
#
#             var marker_6acd641b27a3761031fbc9dc460a161b = L.marker(
#                 [45.0503999
