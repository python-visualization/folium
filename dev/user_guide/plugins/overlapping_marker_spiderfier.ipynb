# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_375df9b95f5dd644d4965c9e0b80a623 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_375df9b95f5dd644d4965c9e0b80a623&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_375df9b95f5dd644d4965c9e0b80a623 = L.map(
#                 &quot;map_375df9b95f5dd644d4965c9e0b80a623&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_37a7e4b09b64f4edd06627235fb571a8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_37a7e4b09b64f4edd06627235fb571a8.addTo(map_375df9b95f5dd644d4965c9e0b80a623);
#
#
#             var marker_5bf396b08606932ec4a0285bd4fc8e24 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_375df9b95f5dd644d4965c9e0b80a623);
#
#
#         var popup_7aeaa452fb9ded6804dfbeeeba55293e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e39e66b9bb0a610a1d1943f3435542ab = $(`&lt;div id=&quot;html_e39e66b9bb0a610a1d1943f3435542ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7aeaa452fb9ded6804dfbeeeba55293e.setContent(html_e39e66b9bb0a610a1d1943f3435542ab);
#
#
#
#         marker_5bf396b08606932ec4a0285bd4fc8e24.bindPopup(popup_7aeaa452fb9ded6804dfbeeeba55293e)
#         ;
#
#
#
#
#             var marker_f7351f78b0993abb78954be0bdb4a20c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_375df9b95f5dd644d4965c9e0b80a623);
#
#
#         var popup_6d18670d11cf3cbe92a53ab6c11d077a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_848d77484eba8a15ac81ef523f0b6a47 = $(`&lt;div id=&quot;html_848d77484eba8a15ac81ef523f0b6a47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6d18670d11cf3cbe92a53ab6c11d077a.setContent(html_848d77484eba8a15ac81ef523f0b6a47);
#
#
#
#         marker_f7351f78b0993abb78954be0bdb4a20c.bindPopup(popup_6d18670d11cf3cbe92a53ab6c11d077a)
#         ;
#
#
#
#
#             var marker_1edd9d0a4ee48d312ae3820ae1b375fd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_375df9b95f5dd644d4965c9e0b80a623);
#
#
#         var popup_e775ac1c2c7130433f7b778f9242d8c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cdfdd5772ecd81a6f02cd4d3c91e5b9b = $(`&lt;div id=&quot;html_cdfdd5772ecd81a6f02cd4d3c91e5b9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e775ac1c2c7130433f7b778f9242d8c6.setContent(html_cdfdd5772ecd81a6f02cd4d3c91e5b9b);
#
#
#
#         marker_1edd9d0a4ee48d312ae3820ae1b375fd.bindPopup(popup_e775ac1c2c7130433f7b778f9242d8c6)
#         ;
#
#
#
#
#             var marker_6b41f44f968b53302d45320f8667c8f8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_375df9b95f5dd644d4965c9e0b80a623);
#
#
#         var popup_9baf5150ae0927a3c8b042954202f2fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_311698ed0dc104c4192ea986ee3f03bf = $(`&lt;div id=&quot;html_311698ed0dc104c4192ea986ee3f03bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9baf5150ae0927a3c8b042954202f2fc.setContent(html_311698ed0dc104c4192ea986ee3f03bf);
#
#
#
#         marker_6b41f44f968b53302d45320f8667c8f8.bindPopup(popup_9baf5150ae0927a3c8b042954202f2fc)
#         ;
#
#
#
#
#             var marker_d37caaa9317d6db46ef34896367f4beb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_375df9b95f5dd644d4965c9e0b80a623);
#
#
#         var popup_f2c5775f3eee496c6da1baef18a6eb67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a86b6e4c44702331d169a7b8cd321a1 = $(`&lt;div id=&quot;html_0a86b6e4c44702331d169a7b8cd321a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f2c5775f3eee496c6da1baef18a6eb67.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa8f23cdcf2c477e125d547637acc09c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa8f23cdcf2c477e125d547637acc09c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa8f23cdcf2c477e125d547637acc09c = L.map(
#                 &quot;map_fa8f23cdcf2c477e125d547637acc09c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_165d91d3e5431ba30308efca73b7d2f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_165d91d3e5431ba30308efca73b7d2f9.addTo(map_fa8f23cdcf2c477e125d547637acc09c);
#
#
#             var feature_group_97fbf20884fe2c5601c4c355c29f848a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e270fcec1f80963d7369645d4127a4ef = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_97fbf20884fe2c5601c4c355c29f848a);
#
#
#         var popup_3eadfc21164e378f1c38654f88a85e76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92eaf0b6b04336114ae0c189d47d5b96 = $(`&lt;div id=&quot;html_92eaf0b6b04336114ae0c189d47d5b96&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3eadfc21164e378f1c38654f88a85e76.setContent(html_92eaf0b6b04336114ae0c189d47d5b96);
#
#
#
#         marker_e270fcec1f80963d7369645d4127a4ef.bindPopup(popup_3eadfc21164e378f1c38654f88a85e76)
#         ;
#
#
#
#
#             var marker_8a8ebf8ed2b0fcbe2c3de7199a4fb0e7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_97fbf20884fe2c5601c4c355c29f848a);
#
#
#         var popup_ec7d1f39f90af675cd1eeaddb8a13a0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db215b54a0edd1865edb8a490dcb9b4e = $(`&lt;div id=&quot;html_db215b54a0edd1865edb8a490dcb9b4e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ec7d1f39f90af675cd1eeaddb8a13a0c.setContent(html_db215b54a0edd1865edb8a490dcb9b4e);
#
#
#
#         marker_8a8ebf8ed2b0fcbe2c3de7199a4fb0e7.bindPopup(popup_ec7d1f39f90af675cd1eeaddb8a13a0c)
#         ;
#
#
#
#
#             var marker_8ac9ff55b52542e1bac04453bce5761e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_97fbf20884fe2c5601c4c355c29f848a);
#
#
#         var popup_95cc358c785de7d8266290f4d47a480f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_998c7963ae295c66672dddb01bee9d5c = $(`&lt;div id=&quot;html_998c7963ae295c66672dddb01bee9d5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_95cc358c785de7d8266290f4d47a480f.setContent(html_998c7963ae295c66672dddb01bee9d5c);
#
#
#
#         marker_8ac9ff55b52542e1bac04453bce5761e.bindPopup(popup_95cc358c785de7d8266290f4d47a480f)
#         ;
#
#
#
#
#             var marker_7f0b1fce47fb253efbb227f753801336 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_97fbf20884fe2c5601c4c355c29f848a);
#
#
#         var popup_d1fa726c76e5ed036ff79bd0bf6266f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d48f69d011d7742305a40c0a43843926 = $(`&lt;div id=&quot;html_d48f69d011d7742305a40c0a43843926&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d1fa726c76e5ed036ff79bd0bf6266f6.setContent(html_d48f69d011d7742305a40c0a43843926);
#
#
#
#         marker_7f0b1fce47fb253efbb227f753801336.bindPopup(popup_d1fa726c76e5ed036ff79bd0bf6266f6)
#         ;
#
#
#
#
#             var marker_6e88f92c8cc0410748f51546e056baba = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_97fbf20884fe2c5601c4c355c29f848a);
#
#
#         var popup_5d859ae0c3fba6777d6083c0c3da805a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b1701d00c07bd51f0df79789d95c424 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b1701d00c07bd51f0df79789d95c424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b1701d00c07bd51f0df79789d95c424 = L.map(
#                 &quot;map_8b1701d00c07bd51f0df79789d95c424&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ff259f99f1eaeda6053cdc964853de1f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ff259f99f1eaeda6053cdc964853de1f.addTo(map_8b1701d00c07bd51f0df79789d95c424);
#
#
#             var feature_group_ea06105aefe87fa142b067d7b86b3d5d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ea06105aefe87fa142b067d7b86b3d5d.addTo(map_8b1701d00c07bd51f0df79789d95c424);
#
#
#             var feature_group_sub_group_64c5c1436bf63bdb54473e40b8fcb38f = L.featureGroup.subGroup(
#                 feature_group_ea06105aefe87fa142b067d7b86b3d5d
#             );
#
#
#             var marker_97273fc0e7fc30d85c636058d3bef162 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_64c5c1436bf63bdb54473e40b8fcb38f);
#
#
#         var popup_a351a692a28ae6b709407c0ac77a3596 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02861f6554ec1360b08ec93f148c0138 = $(`&lt;div id=&quot;html_02861f6554ec1360b08ec93f148c0138&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a351a692a28ae6b709407c0ac77a3596.setContent(html_02861f6554ec1360b08ec93f148c0138);
#
#
#
#         marker_97273fc0e7fc30d85c636058d3bef162.bindPopup(popup_a351a692a28ae6b709407c0ac77a3596)
#         ;
#
#
#
#
#             var marker_03e94b24eb3848682857280440092575 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_64c5c1436bf63bdb54473e40b8fcb38f);
#
#
#         var popup_dc9f4833c52bff465d5b2f7fbbc60f47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba1c0074db3b7fd4d8cce17a5a0d3846 = $(`&lt;div id=&quot;html_ba1c0074db3b7fd4d8cce17a5a0d3846&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_dc9f4833c52bff465d5b2f7fbbc60f47.setContent(html_ba1c0074db3b7fd4d8cce17a5a0d3846);
#
#
#
#         marker_03e94b24eb3848682857280440092575.bindPopup(popup_dc9f4833c52bff465d5b2f7fbbc60f47)
#         ;
#
#
#
#
#             var marker_3641553d11a8d489376a42f8445f3e1f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_64c5c1436bf63bdb54473e40b8fcb38f);
#
#
#         var popup_091a24289b05a320c54254cf7dae6738 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce7b281464d03192bf788e9eb2657d07 = $(`&lt;div id=&quot;html_ce7b281464d03192bf788e9eb2657d07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_091a24289b05a320c54254cf7dae6738.setContent(html_ce7b281464d03192bf788e9eb2657d07);
#
#
#
#         marker_3641553d11a8d489376a42f8445f3e1f.bindPopup(popup_091a24289b05a320c54254cf7dae6738)
#         ;
#
#
#
#
#             var marker_5889af91ce86d5f615751f302cd45025 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_64c5c1436bf63bdb54473e40b8fcb38f);
#
#
#         var popup_bcee207aa00b642d9c182a4079afd88d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aba4e28a09ee6d451395c0161788f878 = $(`&lt;div id=&quot;html_aba4e28a09ee6d451395c0161788f878&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bcee207aa00b642d9c182a4079afd88d.setContent(html_aba4e28a09ee6d451395c0161788f878);
#
#
#
#         marker_
