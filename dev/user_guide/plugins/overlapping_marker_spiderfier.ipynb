# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41efc8472596c6ca235900387f5098f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41efc8472596c6ca235900387f5098f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41efc8472596c6ca235900387f5098f4 = L.map(
#                 &quot;map_41efc8472596c6ca235900387f5098f4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deccc12b526ae7402f6fde29f6e1567c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_deccc12b526ae7402f6fde29f6e1567c.addTo(map_41efc8472596c6ca235900387f5098f4);
#
#
#             var marker_c0ada6b003caabd35ff1c005b6e9aab4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_41efc8472596c6ca235900387f5098f4);
#
#
#         var popup_95245c590004c35154cdc153d01e1479 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5a15d264468e9c3db458be80a251aa9 = $(`&lt;div id=&quot;html_d5a15d264468e9c3db458be80a251aa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_95245c590004c35154cdc153d01e1479.setContent(html_d5a15d264468e9c3db458be80a251aa9);
#
#
#
#         marker_c0ada6b003caabd35ff1c005b6e9aab4.bindPopup(popup_95245c590004c35154cdc153d01e1479)
#         ;
#
#
#
#
#             var marker_27770b1a5384a6e2a73f9527f0fd1b35 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_41efc8472596c6ca235900387f5098f4);
#
#
#         var popup_ead76680ea72474ee51ecce8e848da7a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eb1cc6ade076c4dc778d54fb1cbcd2c9 = $(`&lt;div id=&quot;html_eb1cc6ade076c4dc778d54fb1cbcd2c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ead76680ea72474ee51ecce8e848da7a.setContent(html_eb1cc6ade076c4dc778d54fb1cbcd2c9);
#
#
#
#         marker_27770b1a5384a6e2a73f9527f0fd1b35.bindPopup(popup_ead76680ea72474ee51ecce8e848da7a)
#         ;
#
#
#
#
#             var marker_dac1b0d720f197931bc40837408cc094 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_41efc8472596c6ca235900387f5098f4);
#
#
#         var popup_f950888229fcafcb7d0f0b0b3c5f5817 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2180578bdd777f5fcd74c06641d7ea89 = $(`&lt;div id=&quot;html_2180578bdd777f5fcd74c06641d7ea89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f950888229fcafcb7d0f0b0b3c5f5817.setContent(html_2180578bdd777f5fcd74c06641d7ea89);
#
#
#
#         marker_dac1b0d720f197931bc40837408cc094.bindPopup(popup_f950888229fcafcb7d0f0b0b3c5f5817)
#         ;
#
#
#
#
#             var marker_12cddff918bc783e8277b89154e8098b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_41efc8472596c6ca235900387f5098f4);
#
#
#         var popup_2c820431e155cb8f1c87e64450b0f4ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f81e1b616608f49d18cf311b5595bf94 = $(`&lt;div id=&quot;html_f81e1b616608f49d18cf311b5595bf94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2c820431e155cb8f1c87e64450b0f4ca.setContent(html_f81e1b616608f49d18cf311b5595bf94);
#
#
#
#         marker_12cddff918bc783e8277b89154e8098b.bindPopup(popup_2c820431e155cb8f1c87e64450b0f4ca)
#         ;
#
#
#
#
#             var marker_3c034839ceb3c74f282f3d8a88797742 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_41efc8472596c6ca235900387f5098f4);
#
#
#         var popup_c8e57b705a293b7985d8336316909ce0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b4936580c3eeffe44131e1dca753a55 = $(`&lt;div id=&quot;html_6b4936580c3eeffe44131e1dca753a55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c8e57b705a293b7985d8336316909ce0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bd8cfaa9831e3105470252c5075cfd4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bd8cfaa9831e3105470252c5075cfd4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bd8cfaa9831e3105470252c5075cfd4 = L.map(
#                 &quot;map_2bd8cfaa9831e3105470252c5075cfd4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_065a7cc1c9e511e52db8bc451d42a4b6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_065a7cc1c9e511e52db8bc451d42a4b6.addTo(map_2bd8cfaa9831e3105470252c5075cfd4);
#
#
#             var feature_group_379098cdba0345e878447edd0c8c9094 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9be88251a2ca2d804c2db18c67e6befa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_379098cdba0345e878447edd0c8c9094);
#
#
#         var popup_abc576d1eb96c1a0e553e32e7f18ee1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d15830499d2ad6c54162d83fd3ccf385 = $(`&lt;div id=&quot;html_d15830499d2ad6c54162d83fd3ccf385&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_abc576d1eb96c1a0e553e32e7f18ee1e.setContent(html_d15830499d2ad6c54162d83fd3ccf385);
#
#
#
#         marker_9be88251a2ca2d804c2db18c67e6befa.bindPopup(popup_abc576d1eb96c1a0e553e32e7f18ee1e)
#         ;
#
#
#
#
#             var marker_f1229c7cfe30ab4dc02f8005fd383f69 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_379098cdba0345e878447edd0c8c9094);
#
#
#         var popup_597376a8883ccc1f98a9c89071c630e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_408b9e81dfe88c645f9f25a1678f6fac = $(`&lt;div id=&quot;html_408b9e81dfe88c645f9f25a1678f6fac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_597376a8883ccc1f98a9c89071c630e1.setContent(html_408b9e81dfe88c645f9f25a1678f6fac);
#
#
#
#         marker_f1229c7cfe30ab4dc02f8005fd383f69.bindPopup(popup_597376a8883ccc1f98a9c89071c630e1)
#         ;
#
#
#
#
#             var marker_d555a3494a54caafe45462c48f3d2d60 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_379098cdba0345e878447edd0c8c9094);
#
#
#         var popup_2da54d97f1e165e2570706ccb08c3897 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f1043791b829aa0a97bd85f5288bbb1 = $(`&lt;div id=&quot;html_2f1043791b829aa0a97bd85f5288bbb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2da54d97f1e165e2570706ccb08c3897.setContent(html_2f1043791b829aa0a97bd85f5288bbb1);
#
#
#
#         marker_d555a3494a54caafe45462c48f3d2d60.bindPopup(popup_2da54d97f1e165e2570706ccb08c3897)
#         ;
#
#
#
#
#             var marker_0fca18790988aacf76d70d0ebff178d2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_379098cdba0345e878447edd0c8c9094);
#
#
#         var popup_c4cd27933f46dfd1fb765c030b67248c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af4bfd545c5b61970807364e3c3897b3 = $(`&lt;div id=&quot;html_af4bfd545c5b61970807364e3c3897b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c4cd27933f46dfd1fb765c030b67248c.setContent(html_af4bfd545c5b61970807364e3c3897b3);
#
#
#
#         marker_0fca18790988aacf76d70d0ebff178d2.bindPopup(popup_c4cd27933f46dfd1fb765c030b67248c)
#         ;
#
#
#
#
#             var marker_338c42b3fb506a6c1bd0335a8ef407eb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_379098cdba0345e878447edd0c8c9094);
#
#
#         var popup_86c6c6f4c0cb851caa42ab587bb6f479 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1c784abe8eba5286f83a591abcec0a6d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1c784abe8eba5286f83a591abcec0a6d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1c784abe8eba5286f83a591abcec0a6d = L.map(
#                 &quot;map_1c784abe8eba5286f83a591abcec0a6d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b92762ab1e2dd993faf6b802cba3894b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b92762ab1e2dd993faf6b802cba3894b.addTo(map_1c784abe8eba5286f83a591abcec0a6d);
#
#
#             var feature_group_33a29cf4b1519090faabc605b2757935 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_33a29cf4b1519090faabc605b2757935.addTo(map_1c784abe8eba5286f83a591abcec0a6d);
#
#
#             var feature_group_sub_group_7359531ce1c9b2bf027a32e4c2adbc96 = L.featureGroup.subGroup(
#                 feature_group_33a29cf4b1519090faabc605b2757935
#             );
#
#
#             var marker_b871ec2fb218172fa99f591fc73f5c70 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_7359531ce1c9b2bf027a32e4c2adbc96);
#
#
#         var popup_eda593d769c380d6753da764f408ae9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3761ee626b9850b13814c92d30e0f3dc = $(`&lt;div id=&quot;html_3761ee626b9850b13814c92d30e0f3dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_eda593d769c380d6753da764f408ae9d.setContent(html_3761ee626b9850b13814c92d30e0f3dc);
#
#
#
#         marker_b871ec2fb218172fa99f591fc73f5c70.bindPopup(popup_eda593d769c380d6753da764f408ae9d)
#         ;
#
#
#
#
#             var marker_786899cbc26422d20355c934079a8b40 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_7359531ce1c9b2bf027a32e4c2adbc96);
#
#
#         var popup_f181f46a086d577b0e5153785671b9b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34358264f259307c9eaa4096a2c089be = $(`&lt;div id=&quot;html_34358264f259307c9eaa4096a2c089be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f181f46a086d577b0e5153785671b9b3.setContent(html_34358264f259307c9eaa4096a2c089be);
#
#
#
#         marker_786899cbc26422d20355c934079a8b40.bindPopup(popup_f181f46a086d577b0e5153785671b9b3)
#         ;
#
#
#
#
#             var marker_4bfd4fe04fd4e8163b4c4cbebdedb320 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_7359531ce1c9b2bf027a32e4c2adbc96);
#
#
#         var popup_808b3bb718f9eca99c465a093f83a517 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5536a12df19108d882ca705fbaff4c1 = $(`&lt;div id=&quot;html_e5536a12df19108d882ca705fbaff4c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_808b3bb718f9eca99c465a093f83a517.setContent(html_e5536a12df19108d882ca705fbaff4c1);
#
#
#
#         marker_4bfd4fe04fd4e8163b4c4cbebdedb320.bindPopup(popup_808b3bb718f9eca99c465a093f83a517)
#         ;
#
#
#
#
#             var marker_745547ff1d32f8846deb126a8c7ac41c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_7359531ce1c9b2bf027a32e4c2adbc96);
#
#
#         var popup_208307aefc79cb1c49a88c66e91f7665 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef5bf4aceba92fc03d6bcc91f9cb7603 = $(`&lt;div id=&quot;html_ef5bf4aceba92fc03d6bcc91f9cb7603&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_208307aefc79cb1c49a88c66e91f7665.setContent(html_ef5bf4aceba92fc03d6bcc91f9cb7603);
#
#
#
#         marker_
