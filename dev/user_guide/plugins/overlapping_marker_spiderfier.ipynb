# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_911aae12615e67388226c6e9bf848017 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_911aae12615e67388226c6e9bf848017&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_911aae12615e67388226c6e9bf848017 = L.map(
#                 &quot;map_911aae12615e67388226c6e9bf848017&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_524d4bf80e9fd9f52a23d93b026aa4cc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_524d4bf80e9fd9f52a23d93b026aa4cc.addTo(map_911aae12615e67388226c6e9bf848017);
#
#
#             var marker_0ca29e3a09e2b20a3ddd44b2f74d8857 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_911aae12615e67388226c6e9bf848017);
#
#
#         var popup_301cf2a3877e5f37aa049bab9bed1761 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6658eb18898f1fe2a1fe8644fc682dfb = $(`&lt;div id=&quot;html_6658eb18898f1fe2a1fe8644fc682dfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_301cf2a3877e5f37aa049bab9bed1761.setContent(html_6658eb18898f1fe2a1fe8644fc682dfb);
#
#
#
#         marker_0ca29e3a09e2b20a3ddd44b2f74d8857.bindPopup(popup_301cf2a3877e5f37aa049bab9bed1761)
#         ;
#
#
#
#
#             var marker_f63e7770a270160f7fc69f9e7fcaa9a4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_911aae12615e67388226c6e9bf848017);
#
#
#         var popup_67378c5f072764b50e7bd867eb570e18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e40ed48f3f0e8c586e16cd6adc1fe7fe = $(`&lt;div id=&quot;html_e40ed48f3f0e8c586e16cd6adc1fe7fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_67378c5f072764b50e7bd867eb570e18.setContent(html_e40ed48f3f0e8c586e16cd6adc1fe7fe);
#
#
#
#         marker_f63e7770a270160f7fc69f9e7fcaa9a4.bindPopup(popup_67378c5f072764b50e7bd867eb570e18)
#         ;
#
#
#
#
#             var marker_d8d1379c42aaccd9795d8c31b999b72b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_911aae12615e67388226c6e9bf848017);
#
#
#         var popup_568b8f32b9e213e41d5114e3ae266f99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bbcbb8ab71bc57456cd6a57708fa5e9 = $(`&lt;div id=&quot;html_1bbcbb8ab71bc57456cd6a57708fa5e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_568b8f32b9e213e41d5114e3ae266f99.setContent(html_1bbcbb8ab71bc57456cd6a57708fa5e9);
#
#
#
#         marker_d8d1379c42aaccd9795d8c31b999b72b.bindPopup(popup_568b8f32b9e213e41d5114e3ae266f99)
#         ;
#
#
#
#
#             var marker_e4b42babf53c4ebb97ca6d3b065fa5bb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_911aae12615e67388226c6e9bf848017);
#
#
#         var popup_9bd940e5a45d79232325712903c79011 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a4b38dfa80b078cf0a96e125d84399d = $(`&lt;div id=&quot;html_2a4b38dfa80b078cf0a96e125d84399d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9bd940e5a45d79232325712903c79011.setContent(html_2a4b38dfa80b078cf0a96e125d84399d);
#
#
#
#         marker_e4b42babf53c4ebb97ca6d3b065fa5bb.bindPopup(popup_9bd940e5a45d79232325712903c79011)
#         ;
#
#
#
#
#             var marker_d8c31705e70a3b39ed67f4cb87d50872 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_911aae12615e67388226c6e9bf848017);
#
#
#         var popup_05a0705917d834d79d381ed15fe80675 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10394dfbbfd279963888e1b41b65cc00 = $(`&lt;div id=&quot;html_10394dfbbfd279963888e1b41b65cc00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_05a0705917d834d79d381ed15fe80675.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2bbbfd0db737493fae0b27c2e27ca7c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2bbbfd0db737493fae0b27c2e27ca7c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2bbbfd0db737493fae0b27c2e27ca7c4 = L.map(
#                 &quot;map_2bbbfd0db737493fae0b27c2e27ca7c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_690986d8496641a2655b8ceb0895b6bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_690986d8496641a2655b8ceb0895b6bd.addTo(map_2bbbfd0db737493fae0b27c2e27ca7c4);
#
#
#             var feature_group_71a2a31aff3104522491f316f63ef279 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d70f73491739809dd476d27641e4f500 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_71a2a31aff3104522491f316f63ef279);
#
#
#         var popup_60167747497c907ee5e29a8b3805f377 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2692838eebdbcc96d5fba48108be018 = $(`&lt;div id=&quot;html_d2692838eebdbcc96d5fba48108be018&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_60167747497c907ee5e29a8b3805f377.setContent(html_d2692838eebdbcc96d5fba48108be018);
#
#
#
#         marker_d70f73491739809dd476d27641e4f500.bindPopup(popup_60167747497c907ee5e29a8b3805f377)
#         ;
#
#
#
#
#             var marker_0953d8b9b54afd4e2b0b8a96b0ef764b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_71a2a31aff3104522491f316f63ef279);
#
#
#         var popup_2aa6dc5e94bf0cb0f491752c8d6a3b7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d6479e4f4fbdfc1505aa9387c2b62390 = $(`&lt;div id=&quot;html_d6479e4f4fbdfc1505aa9387c2b62390&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2aa6dc5e94bf0cb0f491752c8d6a3b7b.setContent(html_d6479e4f4fbdfc1505aa9387c2b62390);
#
#
#
#         marker_0953d8b9b54afd4e2b0b8a96b0ef764b.bindPopup(popup_2aa6dc5e94bf0cb0f491752c8d6a3b7b)
#         ;
#
#
#
#
#             var marker_05c6a01b6a6ec57b6e572922040d20e0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_71a2a31aff3104522491f316f63ef279);
#
#
#         var popup_8b08c8b1e966c0e73f0dc0e3a1109424 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_970186dd4d2aaaf8b010e095f842165e = $(`&lt;div id=&quot;html_970186dd4d2aaaf8b010e095f842165e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8b08c8b1e966c0e73f0dc0e3a1109424.setContent(html_970186dd4d2aaaf8b010e095f842165e);
#
#
#
#         marker_05c6a01b6a6ec57b6e572922040d20e0.bindPopup(popup_8b08c8b1e966c0e73f0dc0e3a1109424)
#         ;
#
#
#
#
#             var marker_ee04242eee717092ae1c8ae959187946 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_71a2a31aff3104522491f316f63ef279);
#
#
#         var popup_813cf41574f406bc2cd9726b5f134a32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a52cb81a91c6c66c1091e164fd188c5 = $(`&lt;div id=&quot;html_9a52cb81a91c6c66c1091e164fd188c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_813cf41574f406bc2cd9726b5f134a32.setContent(html_9a52cb81a91c6c66c1091e164fd188c5);
#
#
#
#         marker_ee04242eee717092ae1c8ae959187946.bindPopup(popup_813cf41574f406bc2cd9726b5f134a32)
#         ;
#
#
#
#
#             var marker_1c6fd3820c5340987b8e533e6c6dd64f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_71a2a31aff3104522491f316f63ef279);
#
#
#         var popup_3cd45b341434bf9eb48cc8dde9226d71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca9725385c38352cb39c529c6379a0e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca9725385c38352cb39c529c6379a0e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca9725385c38352cb39c529c6379a0e6 = L.map(
#                 &quot;map_ca9725385c38352cb39c529c6379a0e6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ad0064e975153c13ff9d3ac5e1f4663 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ad0064e975153c13ff9d3ac5e1f4663.addTo(map_ca9725385c38352cb39c529c6379a0e6);
#
#
#             var feature_group_0de55d0a76e8d559f60bf295e7ac3d65 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0de55d0a76e8d559f60bf295e7ac3d65.addTo(map_ca9725385c38352cb39c529c6379a0e6);
#
#
#             var feature_group_sub_group_f4c6887e4a36f7316dab927f63fc95b2 = L.featureGroup.subGroup(
#                 feature_group_0de55d0a76e8d559f60bf295e7ac3d65
#             );
#
#
#             var marker_42d6d83d786a88579457974b0cc6b28a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f4c6887e4a36f7316dab927f63fc95b2);
#
#
#         var popup_112e1b471d73962ad57afaefba8e0190 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59a5a79f23c790384e9c5bdb01139d0e = $(`&lt;div id=&quot;html_59a5a79f23c790384e9c5bdb01139d0e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_112e1b471d73962ad57afaefba8e0190.setContent(html_59a5a79f23c790384e9c5bdb01139d0e);
#
#
#
#         marker_42d6d83d786a88579457974b0cc6b28a.bindPopup(popup_112e1b471d73962ad57afaefba8e0190)
#         ;
#
#
#
#
#             var marker_8b71f88fd98c1c16225cd54793a6d83a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f4c6887e4a36f7316dab927f63fc95b2);
#
#
#         var popup_e0e537fcefb5877a8bd30df9671246fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fce93b81388a7a0cec167a95fa0de44 = $(`&lt;div id=&quot;html_6fce93b81388a7a0cec167a95fa0de44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e0e537fcefb5877a8bd30df9671246fc.setContent(html_6fce93b81388a7a0cec167a95fa0de44);
#
#
#
#         marker_8b71f88fd98c1c16225cd54793a6d83a.bindPopup(popup_e0e537fcefb5877a8bd30df9671246fc)
#         ;
#
#
#
#
#             var marker_18f78e2cd5d817d413cbc63a3880c5c1 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f4c6887e4a36f7316dab927f63fc95b2);
#
#
#         var popup_12160112b6e3b2d106e51d5e94e81c4f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a294670b191791512a35b8ae7dcc275 = $(`&lt;div id=&quot;html_7a294670b191791512a35b8ae7dcc275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_12160112b6e3b2d106e51d5e94e81c4f.setContent(html_7a294670b191791512a35b8ae7dcc275);
#
#
#
#         marker_18f78e2cd5d817d413cbc63a3880c5c1.bindPopup(popup_12160112b6e3b2d106e51d5e94e81c4f)
#         ;
#
#
#
#
#             var marker_467b73c297fa06661a3fb5c3f08b89cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f4c6887e4a36f7316dab927f63fc95b2);
#
#
#         var popup_9f59a02197fbb48af08f7dc938fc10f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fce5b11c67bf1fcb8f02a9a0b4b370aa = $(`&lt;div id=&quot;html_fce5b11c67bf1fcb8f02a9a0b4b370aa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9f59a02197fbb48af08f7dc938fc10f1.setContent(html_fce5b11c67bf1fcb8f02a9a0b4b370aa);
#
#
#
#         marker_
