# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_40df884a9ba2342807cb8fa4966aafc6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_40df884a9ba2342807cb8fa4966aafc6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_40df884a9ba2342807cb8fa4966aafc6 = L.map(
#                 &quot;map_40df884a9ba2342807cb8fa4966aafc6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c162ad016e37b10b0973c76692a97dea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c162ad016e37b10b0973c76692a97dea.addTo(map_40df884a9ba2342807cb8fa4966aafc6);
#
#
#             var marker_2cf02c4f5bfc76900a5e4e557ee41661 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_40df884a9ba2342807cb8fa4966aafc6);
#
#
#         var popup_e1db2e5a99e272708122a6113baa9554 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caef8a12bfb7951f1ce6c5e45f9445cc = $(`&lt;div id=&quot;html_caef8a12bfb7951f1ce6c5e45f9445cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e1db2e5a99e272708122a6113baa9554.setContent(html_caef8a12bfb7951f1ce6c5e45f9445cc);
#
#
#
#         marker_2cf02c4f5bfc76900a5e4e557ee41661.bindPopup(popup_e1db2e5a99e272708122a6113baa9554)
#         ;
#
#
#
#
#             var marker_6918fb13ca333e1f0d236e15add01134 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_40df884a9ba2342807cb8fa4966aafc6);
#
#
#         var popup_b1f3dc9f80ccc5679ac3542a4fb7bad6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e096f0a61896b18f4c9c186a797d7005 = $(`&lt;div id=&quot;html_e096f0a61896b18f4c9c186a797d7005&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b1f3dc9f80ccc5679ac3542a4fb7bad6.setContent(html_e096f0a61896b18f4c9c186a797d7005);
#
#
#
#         marker_6918fb13ca333e1f0d236e15add01134.bindPopup(popup_b1f3dc9f80ccc5679ac3542a4fb7bad6)
#         ;
#
#
#
#
#             var marker_25b6d2099af7fb78382de9f7044654e9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_40df884a9ba2342807cb8fa4966aafc6);
#
#
#         var popup_e31dc016e3e08fd89a1ed47148296ac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_050a2593bdf8961186fb6dab6ee9d51c = $(`&lt;div id=&quot;html_050a2593bdf8961186fb6dab6ee9d51c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e31dc016e3e08fd89a1ed47148296ac1.setContent(html_050a2593bdf8961186fb6dab6ee9d51c);
#
#
#
#         marker_25b6d2099af7fb78382de9f7044654e9.bindPopup(popup_e31dc016e3e08fd89a1ed47148296ac1)
#         ;
#
#
#
#
#             var marker_f23b65745c8e3486307067dc736ea7b0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_40df884a9ba2342807cb8fa4966aafc6);
#
#
#         var popup_1428dcd530c02f0d2734627723ba74db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_852c81c6666e7b6c4e25f784d9f9ec2b = $(`&lt;div id=&quot;html_852c81c6666e7b6c4e25f784d9f9ec2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1428dcd530c02f0d2734627723ba74db.setContent(html_852c81c6666e7b6c4e25f784d9f9ec2b);
#
#
#
#         marker_f23b65745c8e3486307067dc736ea7b0.bindPopup(popup_1428dcd530c02f0d2734627723ba74db)
#         ;
#
#
#
#
#             var marker_2d4ceacdff02ce481f565194a2d8364e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_40df884a9ba2342807cb8fa4966aafc6);
#
#
#         var popup_07d27402b8e994514a17f81bc6b5d8fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7b618b7ef92324eb3fc5068cb2f6f47 = $(`&lt;div id=&quot;html_d7b618b7ef92324eb3fc5068cb2f6f47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_07d27402b8e994514a17f81bc6b5d8

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4603e399902f99d1f508b6b0fab9c230 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4603e399902f99d1f508b6b0fab9c230&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4603e399902f99d1f508b6b0fab9c230 = L.map(
#                 &quot;map_4603e399902f99d1f508b6b0fab9c230&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_92da0375ac2960a5f9aa77af37feffa8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_92da0375ac2960a5f9aa77af37feffa8.addTo(map_4603e399902f99d1f508b6b0fab9c230);
#
#
#             var feature_group_434edf409460167f3095d5a6e618a94f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_58cec01b026ef22e0887f75d7e687e4f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_434edf409460167f3095d5a6e618a94f);
#
#
#         var popup_351c4b06b380bee05562eeeddcf0d270 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9403a177c53e84f395a49f47ccbe2a0d = $(`&lt;div id=&quot;html_9403a177c53e84f395a49f47ccbe2a0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_351c4b06b380bee05562eeeddcf0d270.setContent(html_9403a177c53e84f395a49f47ccbe2a0d);
#
#
#
#         marker_58cec01b026ef22e0887f75d7e687e4f.bindPopup(popup_351c4b06b380bee05562eeeddcf0d270)
#         ;
#
#
#
#
#             var marker_0fdc3aabffe4c1d6ff4526e958532486 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_434edf409460167f3095d5a6e618a94f);
#
#
#         var popup_f06b7f20cb394b026735991870bbe885 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7279ead9904a525499431cb15df4c5c0 = $(`&lt;div id=&quot;html_7279ead9904a525499431cb15df4c5c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f06b7f20cb394b026735991870bbe885.setContent(html_7279ead9904a525499431cb15df4c5c0);
#
#
#
#         marker_0fdc3aabffe4c1d6ff4526e958532486.bindPopup(popup_f06b7f20cb394b026735991870bbe885)
#         ;
#
#
#
#
#             var marker_01ecd457e86e7c4bb4dcd3d33c5e2ed7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_434edf409460167f3095d5a6e618a94f);
#
#
#         var popup_d82acdbf3574b91d12bc96e9c6abb699 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b9a84a319045c11730047c4eb905c676 = $(`&lt;div id=&quot;html_b9a84a319045c11730047c4eb905c676&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d82acdbf3574b91d12bc96e9c6abb699.setContent(html_b9a84a319045c11730047c4eb905c676);
#
#
#
#         marker_01ecd457e86e7c4bb4dcd3d33c5e2ed7.bindPopup(popup_d82acdbf3574b91d12bc96e9c6abb699)
#         ;
#
#
#
#
#             var marker_16ac7f358159e1adf568eb6cdc2db05a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_434edf409460167f3095d5a6e618a94f);
#
#
#         var popup_fb119d51b6465a6ccf03c59cb561e76a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff62797088fd8ab9d992e1a7d6bbb78e = $(`&lt;div id=&quot;html_ff62797088fd8ab9d992e1a7d6bbb78e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_fb119d51b6465a6ccf03c59cb561e76a.setContent(html_ff62797088fd8ab9d992e1a7d6bbb78e);
#
#
#
#         marker_16ac7f358159e1adf568eb6cdc2db05a.bindPopup(popup_fb119d51b6465a6ccf03c59cb561e76a)
#         ;
#
#
#
#
#             var marker_af0ee5c6cd0f43235500ca18b5af216a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_434edf409460167f3095d5a6e618a94f);
#
#
#         var popup_b6318ff270e43bf3db1d4e5c91f6fed0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2706a9ae3f332d7cb987503e50600567 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2706a9ae3f332d7cb987503e50600567&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2706a9ae3f332d7cb987503e50600567 = L.map(
#                 &quot;map_2706a9ae3f332d7cb987503e50600567&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5af6827c23172a17bd46f2f14f55c58f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5af6827c23172a17bd46f2f14f55c58f.addTo(map_2706a9ae3f332d7cb987503e50600567);
#
#
#             var feature_group_83a1441436413bd8c10ac2b85d4b371f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_83a1441436413bd8c10ac2b85d4b371f.addTo(map_2706a9ae3f332d7cb987503e50600567);
#
#
#             var feature_group_sub_group_ae65edc8ca26155ef773e2ea166d6093 = L.featureGroup.subGroup(
#                 feature_group_83a1441436413bd8c10ac2b85d4b371f
#             );
#
#
#             var marker_262d2e1d67d9e8267b2e759bc28e6575 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae65edc8ca26155ef773e2ea166d6093);
#
#
#         var popup_bf51620de8dc3ddbd5faa730c3c13970 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4ee1d3adabac0a81a2738a31f8f0db6 = $(`&lt;div id=&quot;html_f4ee1d3adabac0a81a2738a31f8f0db6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bf51620de8dc3ddbd5faa730c3c13970.setContent(html_f4ee1d3adabac0a81a2738a31f8f0db6);
#
#
#
#         marker_262d2e1d67d9e8267b2e759bc28e6575.bindPopup(popup_bf51620de8dc3ddbd5faa730c3c13970)
#         ;
#
#
#
#
#             var marker_82fc7116758528f315cdaf89781d5c69 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae65edc8ca26155ef773e2ea166d6093);
#
#
#         var popup_4fe69f38ca25fbaf5f9123cf05644b4c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_070ec0e0a02add29914aca00622fbce8 = $(`&lt;div id=&quot;html_070ec0e0a02add29914aca00622fbce8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4fe69f38ca25fbaf5f9123cf05644b4c.setContent(html_070ec0e0a02add29914aca00622fbce8);
#
#
#
#         marker_82fc7116758528f315cdaf89781d5c69.bindPopup(popup_4fe69f38ca25fbaf5f9123cf05644b4c)
#         ;
#
#
#
#
#             var marker_688c35f6e9241e0aca1a453841bf9df7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae65edc8ca26155ef773e2ea166d6093);
#
#
#         var popup_816efa60f527273b2c464012d0bda6ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56199f3a5050a8476da7632f9b54aac2 = $(`&lt;div id=&quot;html_56199f3a5050a8476da7632f9b54aac2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_816efa60f527273b2c464012d0bda6ad.setContent(html_56199f3a5050a8476da7632f9b54aac2);
#
#
#
#         marker_688c35f6e9241e0aca1a453841bf9df7.bindPopup(popup_816efa60f527273b2c464012d0bda6ad)
#         ;
#
#
#
#
#             var marker_b6f6a952260eab3a7066a06ed77a0f15 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ae65edc8ca26155ef773e2ea166d6093);
#
#
#         var popup_4ecef034e818c09906f9bac47e4a560f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b13776e428a1a2c3b61cbf97a0cbb1ea = $(`&lt;div id=&quot;html_b13776e428a1a2c3b61cbf97a0cbb1ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4ecef034e818c09906f9bac47e4a560f.setContent(html_b13776e428a1a2c3b61cbf97a0cbb1ea);
#
#
#
#         mark
