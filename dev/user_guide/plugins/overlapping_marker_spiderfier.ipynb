# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c18196199de24d696413cabaafb1e794 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c18196199de24d696413cabaafb1e794&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c18196199de24d696413cabaafb1e794 = L.map(
#                 &quot;map_c18196199de24d696413cabaafb1e794&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e7319022c8bfdc160eafd3e022f708b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e7319022c8bfdc160eafd3e022f708b1.addTo(map_c18196199de24d696413cabaafb1e794);
#
#
#             var marker_f25a6a2439664f056e7cf5b3e3f144b7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c18196199de24d696413cabaafb1e794);
#
#
#         var popup_c6e72fe33d9fffb91b706ce2b1bf6732 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24818d54caf88ea399ebe5834ba26ccb = $(`&lt;div id=&quot;html_24818d54caf88ea399ebe5834ba26ccb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c6e72fe33d9fffb91b706ce2b1bf6732.setContent(html_24818d54caf88ea399ebe5834ba26ccb);
#
#
#
#         marker_f25a6a2439664f056e7cf5b3e3f144b7.bindPopup(popup_c6e72fe33d9fffb91b706ce2b1bf6732)
#         ;
#
#
#
#
#             var marker_2f49ad507e1c24234b1d7b762ff91787 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c18196199de24d696413cabaafb1e794);
#
#
#         var popup_4915c80d59f0fdc77de59392b0551fb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76669131dd13034f1b1b5046fbfa8cc8 = $(`&lt;div id=&quot;html_76669131dd13034f1b1b5046fbfa8cc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4915c80d59f0fdc77de59392b0551fb5.setContent(html_76669131dd13034f1b1b5046fbfa8cc8);
#
#
#
#         marker_2f49ad507e1c24234b1d7b762ff91787.bindPopup(popup_4915c80d59f0fdc77de59392b0551fb5)
#         ;
#
#
#
#
#             var marker_3991518fec41a6322d7c5980d726e5e4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c18196199de24d696413cabaafb1e794);
#
#
#         var popup_fbdf097a55e22f00a3e08f4f1760eb9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ab28b997093d978fecb1de88ae8b902 = $(`&lt;div id=&quot;html_3ab28b997093d978fecb1de88ae8b902&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fbdf097a55e22f00a3e08f4f1760eb9d.setContent(html_3ab28b997093d978fecb1de88ae8b902);
#
#
#
#         marker_3991518fec41a6322d7c5980d726e5e4.bindPopup(popup_fbdf097a55e22f00a3e08f4f1760eb9d)
#         ;
#
#
#
#
#             var marker_73cce282044898ead4849c49473481fb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c18196199de24d696413cabaafb1e794);
#
#
#         var popup_a4ac153f694386232652556b974dff76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a738e40df027f3ed67541354ad69ca53 = $(`&lt;div id=&quot;html_a738e40df027f3ed67541354ad69ca53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a4ac153f694386232652556b974dff76.setContent(html_a738e40df027f3ed67541354ad69ca53);
#
#
#
#         marker_73cce282044898ead4849c49473481fb.bindPopup(popup_a4ac153f694386232652556b974dff76)
#         ;
#
#
#
#
#             var marker_78e28d7a712326040bcc355a12832961 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c18196199de24d696413cabaafb1e794);
#
#
#         var popup_a97953b04f7b6a071c7ec73077735bf5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfcb23027e9e9878cdfc3150065c98df = $(`&lt;div id=&quot;html_dfcb23027e9e9878cdfc3150065c98df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a97953b04f7b6a071c7ec73077735b

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_38644d7b7f834ebede18661d97cdc553 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_38644d7b7f834ebede18661d97cdc553&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_38644d7b7f834ebede18661d97cdc553 = L.map(
#                 &quot;map_38644d7b7f834ebede18661d97cdc553&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4f6a80838c50f914a912da3549551055 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4f6a80838c50f914a912da3549551055.addTo(map_38644d7b7f834ebede18661d97cdc553);
#
#
#             var feature_group_c772b17317a87fb6644b9cfcd6facb77 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_51efc0e3887bfc306912e46699fc5a31 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c772b17317a87fb6644b9cfcd6facb77);
#
#
#         var popup_4885bc5de5a7926dd4cc94ec88e15040 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84f83b2b962b223dd0fe898e811ddf9f = $(`&lt;div id=&quot;html_84f83b2b962b223dd0fe898e811ddf9f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4885bc5de5a7926dd4cc94ec88e15040.setContent(html_84f83b2b962b223dd0fe898e811ddf9f);
#
#
#
#         marker_51efc0e3887bfc306912e46699fc5a31.bindPopup(popup_4885bc5de5a7926dd4cc94ec88e15040)
#         ;
#
#
#
#
#             var marker_f21ebfbc1b917aa66170fd2855da7f28 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c772b17317a87fb6644b9cfcd6facb77);
#
#
#         var popup_bc9d976ab627c18a92358f50581fb001 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15d0d277032ce673bc25af9ca3d46352 = $(`&lt;div id=&quot;html_15d0d277032ce673bc25af9ca3d46352&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bc9d976ab627c18a92358f50581fb001.setContent(html_15d0d277032ce673bc25af9ca3d46352);
#
#
#
#         marker_f21ebfbc1b917aa66170fd2855da7f28.bindPopup(popup_bc9d976ab627c18a92358f50581fb001)
#         ;
#
#
#
#
#             var marker_42b0ad9273c0853663cd4cf940493225 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c772b17317a87fb6644b9cfcd6facb77);
#
#
#         var popup_8dab68587a052bf8fe413eb507d01f3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f68e26b3f7b0ef82606b800a6f0fa151 = $(`&lt;div id=&quot;html_f68e26b3f7b0ef82606b800a6f0fa151&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8dab68587a052bf8fe413eb507d01f3d.setContent(html_f68e26b3f7b0ef82606b800a6f0fa151);
#
#
#
#         marker_42b0ad9273c0853663cd4cf940493225.bindPopup(popup_8dab68587a052bf8fe413eb507d01f3d)
#         ;
#
#
#
#
#             var marker_c4c275b36fd6412b7a4e39e53854b2ae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c772b17317a87fb6644b9cfcd6facb77);
#
#
#         var popup_45bcc2689e4540e9ab32a7c62d5e2fe9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a49851378caa0528ab948fff0d677513 = $(`&lt;div id=&quot;html_a49851378caa0528ab948fff0d677513&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_45bcc2689e4540e9ab32a7c62d5e2fe9.setContent(html_a49851378caa0528ab948fff0d677513);
#
#
#
#         marker_c4c275b36fd6412b7a4e39e53854b2ae.bindPopup(popup_45bcc2689e4540e9ab32a7c62d5e2fe9)
#         ;
#
#
#
#
#             var marker_0cc70eddd1ccd886112a0239053f7e47 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c772b17317a87fb6644b9cfcd6facb77);
#
#
#         var popup_b5376205f252712a3671969c7c7dc05c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_18898131dc33dd2af3f5525b8ee1397f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_18898131dc33dd2af3f5525b8ee1397f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_18898131dc33dd2af3f5525b8ee1397f = L.map(
#                 &quot;map_18898131dc33dd2af3f5525b8ee1397f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0cd75d77005ceac0cc9df3f9c5ff9901 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0cd75d77005ceac0cc9df3f9c5ff9901.addTo(map_18898131dc33dd2af3f5525b8ee1397f);
#
#
#             var feature_group_8c4ab29f265200938b180e89da74f369 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8c4ab29f265200938b180e89da74f369.addTo(map_18898131dc33dd2af3f5525b8ee1397f);
#
#
#             var feature_group_sub_group_acab48619551c0ad3d2432839db25800 = L.featureGroup.subGroup(
#                 feature_group_8c4ab29f265200938b180e89da74f369
#             );
#
#
#             var marker_262f271f1f4d6c984beaa30ebc920449 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_acab48619551c0ad3d2432839db25800);
#
#
#         var popup_d60d1573736eb3b4d64236b6302208ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fba8ab3d591d40a113b57767995c30d9 = $(`&lt;div id=&quot;html_fba8ab3d591d40a113b57767995c30d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d60d1573736eb3b4d64236b6302208ee.setContent(html_fba8ab3d591d40a113b57767995c30d9);
#
#
#
#         marker_262f271f1f4d6c984beaa30ebc920449.bindPopup(popup_d60d1573736eb3b4d64236b6302208ee)
#         ;
#
#
#
#
#             var marker_7e39807a0ff76adf61d875439c7dab67 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_acab48619551c0ad3d2432839db25800);
#
#
#         var popup_a9acdf3c79bc738f2b43c36b24900a0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71e04f2edca3c5f9d2fa6cd0c10ce527 = $(`&lt;div id=&quot;html_71e04f2edca3c5f9d2fa6cd0c10ce527&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a9acdf3c79bc738f2b43c36b24900a0d.setContent(html_71e04f2edca3c5f9d2fa6cd0c10ce527);
#
#
#
#         marker_7e39807a0ff76adf61d875439c7dab67.bindPopup(popup_a9acdf3c79bc738f2b43c36b24900a0d)
#         ;
#
#
#
#
#             var marker_b1dbda4f72170dc3d71e494e9ceed164 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_acab48619551c0ad3d2432839db25800);
#
#
#         var popup_261e7aae81eeab903debeaf7ae2e1f49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d0578b6179dfb008b928ac3e3b6c5ca = $(`&lt;div id=&quot;html_3d0578b6179dfb008b928ac3e3b6c5ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_261e7aae81eeab903debeaf7ae2e1f49.setContent(html_3d0578b6179dfb008b928ac3e3b6c5ca);
#
#
#
#         marker_b1dbda4f72170dc3d71e494e9ceed164.bindPopup(popup_261e7aae81eeab903debeaf7ae2e1f49)
#         ;
#
#
#
#
#             var marker_0674e3fecd47359179eac2032d371ae9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_acab48619551c0ad3d2432839db25800);
#
#
#         var popup_1ace3b20d9ce4d22675c5e94016c2ea7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4af6ed9887eeade7e6486752e5ee3f25 = $(`&lt;div id=&quot;html_4af6ed9887eeade7e6486752e5ee3f25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1ace3b20d9ce4d22675c5e94016c2ea7.setContent(html_4af6ed9887eeade7e6486752e5ee3f25);
#
#
#
#         mark
