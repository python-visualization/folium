# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa0bd19fc64e57c7f6dee45eb9cc18ef {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa0bd19fc64e57c7f6dee45eb9cc18ef&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa0bd19fc64e57c7f6dee45eb9cc18ef = L.map(
#                 &quot;map_aa0bd19fc64e57c7f6dee45eb9cc18ef&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0479890d4e76d7db714f6144bacf7f1a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0479890d4e76d7db714f6144bacf7f1a.addTo(map_aa0bd19fc64e57c7f6dee45eb9cc18ef);
#
#
#             var marker_f36702bfdef6966d49651ab4e90003fc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_aa0bd19fc64e57c7f6dee45eb9cc18ef);
#
#
#         var popup_e042c97a6884d2c2451220c64fa8368d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f14f697cace42adc3fa9fc6959bb3cf = $(`&lt;div id=&quot;html_7f14f697cace42adc3fa9fc6959bb3cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e042c97a6884d2c2451220c64fa8368d.setContent(html_7f14f697cace42adc3fa9fc6959bb3cf);
#
#
#
#         marker_f36702bfdef6966d49651ab4e90003fc.bindPopup(popup_e042c97a6884d2c2451220c64fa8368d)
#         ;
#
#
#
#
#             var marker_1b93a38707b0b3814f15ded2c23105db = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_aa0bd19fc64e57c7f6dee45eb9cc18ef);
#
#
#         var popup_2f92caa44322e42f950b481bbc64a8b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c13483740292bee79092b274e935632a = $(`&lt;div id=&quot;html_c13483740292bee79092b274e935632a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2f92caa44322e42f950b481bbc64a8b3.setContent(html_c13483740292bee79092b274e935632a);
#
#
#
#         marker_1b93a38707b0b3814f15ded2c23105db.bindPopup(popup_2f92caa44322e42f950b481bbc64a8b3)
#         ;
#
#
#
#
#             var marker_0f3f45e9cd8a266c12e729bc0d7e6f23 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_aa0bd19fc64e57c7f6dee45eb9cc18ef);
#
#
#         var popup_6c48a8308b7c10798d211044d50c807e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f79cf97e45a0f3115af3fdd2bafc1d8 = $(`&lt;div id=&quot;html_6f79cf97e45a0f3115af3fdd2bafc1d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_6c48a8308b7c10798d211044d50c807e.setContent(html_6f79cf97e45a0f3115af3fdd2bafc1d8);
#
#
#
#         marker_0f3f45e9cd8a266c12e729bc0d7e6f23.bindPopup(popup_6c48a8308b7c10798d211044d50c807e)
#         ;
#
#
#
#
#             var marker_73f16132f04b8759d84a15745f92038c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_aa0bd19fc64e57c7f6dee45eb9cc18ef);
#
#
#         var popup_8b86eb2122619bbed36a9cdc28741961 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f5783bd011c3c1ad99d2654f3aa5b6d = $(`&lt;div id=&quot;html_8f5783bd011c3c1ad99d2654f3aa5b6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8b86eb2122619bbed36a9cdc28741961.setContent(html_8f5783bd011c3c1ad99d2654f3aa5b6d);
#
#
#
#         marker_73f16132f04b8759d84a15745f92038c.bindPopup(popup_8b86eb2122619bbed36a9cdc28741961)
#         ;
#
#
#
#
#             var marker_3e7e272cc5888f75dfef4c43dc158691 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_aa0bd19fc64e57c7f6dee45eb9cc18ef);
#
#
#         var popup_463005befe46ed3086209b771f00b979 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_349b7c26f1a99e1a0ebda8d157280fb5 = $(`&lt;div id=&quot;html_349b7c26f1a99e1a0ebda8d157280fb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_463005befe46ed3086209b771f00b979.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4f784f95dd60af95b13d0b8b0368e5a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4f784f95dd60af95b13d0b8b0368e5a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4f784f95dd60af95b13d0b8b0368e5a7 = L.map(
#                 &quot;map_4f784f95dd60af95b13d0b8b0368e5a7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_573a65ea5a242e6747f4b261957f41d4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_573a65ea5a242e6747f4b261957f41d4.addTo(map_4f784f95dd60af95b13d0b8b0368e5a7);
#
#
#             var feature_group_2825699cb4431b673689a90c22f64ddc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_74920d34d5645001d21777d9707de8ac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2825699cb4431b673689a90c22f64ddc);
#
#
#         var popup_9676704d8390fbaf0a8885bdc9f9c413 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_036aad9343da9c70d56ff47decf00605 = $(`&lt;div id=&quot;html_036aad9343da9c70d56ff47decf00605&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_9676704d8390fbaf0a8885bdc9f9c413.setContent(html_036aad9343da9c70d56ff47decf00605);
#
#
#
#         marker_74920d34d5645001d21777d9707de8ac.bindPopup(popup_9676704d8390fbaf0a8885bdc9f9c413)
#         ;
#
#
#
#
#             var marker_dc593eef0406f15112f9604f763e689e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2825699cb4431b673689a90c22f64ddc);
#
#
#         var popup_cdc5e274bad96896586d547aef9a2ddd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4092421754d35033e8cdc1df04c1004f = $(`&lt;div id=&quot;html_4092421754d35033e8cdc1df04c1004f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cdc5e274bad96896586d547aef9a2ddd.setContent(html_4092421754d35033e8cdc1df04c1004f);
#
#
#
#         marker_dc593eef0406f15112f9604f763e689e.bindPopup(popup_cdc5e274bad96896586d547aef9a2ddd)
#         ;
#
#
#
#
#             var marker_6985911a1ff0f36cf8d5dfaba0634f1e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2825699cb4431b673689a90c22f64ddc);
#
#
#         var popup_2d1b89f15eea16972e77268b345d82a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e756e46a7f36427b2ea59ce354ec0d3 = $(`&lt;div id=&quot;html_6e756e46a7f36427b2ea59ce354ec0d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2d1b89f15eea16972e77268b345d82a4.setContent(html_6e756e46a7f36427b2ea59ce354ec0d3);
#
#
#
#         marker_6985911a1ff0f36cf8d5dfaba0634f1e.bindPopup(popup_2d1b89f15eea16972e77268b345d82a4)
#         ;
#
#
#
#
#             var marker_8f32a2085691c2ef3e1db79a6d9a71c5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2825699cb4431b673689a90c22f64ddc);
#
#
#         var popup_94d4db2ec9da11b7aabe6df721c88de5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_325c34bfde77ddef2ec9bd1762341d9d = $(`&lt;div id=&quot;html_325c34bfde77ddef2ec9bd1762341d9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_94d4db2ec9da11b7aabe6df721c88de5.setContent(html_325c34bfde77ddef2ec9bd1762341d9d);
#
#
#
#         marker_8f32a2085691c2ef3e1db79a6d9a71c5.bindPopup(popup_94d4db2ec9da11b7aabe6df721c88de5)
#         ;
#
#
#
#
#             var marker_9f6c7f140a2b7e8402be5c2f66be7c6c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2825699cb4431b673689a90c22f64ddc);
#
#
#         var popup_a9431d8e118fc8f2999240a11a580e44 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9730db28390972caf33ed15f53c310d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9730db28390972caf33ed15f53c310d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9730db28390972caf33ed15f53c310d6 = L.map(
#                 &quot;map_9730db28390972caf33ed15f53c310d6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5d7b65668b8877d0bfc437807877adb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a5d7b65668b8877d0bfc437807877adb.addTo(map_9730db28390972caf33ed15f53c310d6);
#
#
#             var feature_group_bc3f513c08af10ffa7f5109617d587be = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bc3f513c08af10ffa7f5109617d587be.addTo(map_9730db28390972caf33ed15f53c310d6);
#
#
#             var feature_group_sub_group_427a0bfaf1187188afdf9b8b43e4fa46 = L.featureGroup.subGroup(
#                 feature_group_bc3f513c08af10ffa7f5109617d587be
#             );
#
#
#             var marker_8ce77206da15f30857c961a36f97ab46 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_427a0bfaf1187188afdf9b8b43e4fa46);
#
#
#         var popup_1c0f4417d5f1b5b37e20d751a1138799 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cc6703c62c92a2f1b0a60a631ebfb53 = $(`&lt;div id=&quot;html_1cc6703c62c92a2f1b0a60a631ebfb53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1c0f4417d5f1b5b37e20d751a1138799.setContent(html_1cc6703c62c92a2f1b0a60a631ebfb53);
#
#
#
#         marker_8ce77206da15f30857c961a36f97ab46.bindPopup(popup_1c0f4417d5f1b5b37e20d751a1138799)
#         ;
#
#
#
#
#             var marker_9098336a7ff32f2cf41d1c8f6171c27a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_427a0bfaf1187188afdf9b8b43e4fa46);
#
#
#         var popup_ba81cc9a6566b1bd4d71e9371305f2d4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07511aaeca28af8bc6b052ff1735776b = $(`&lt;div id=&quot;html_07511aaeca28af8bc6b052ff1735776b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ba81cc9a6566b1bd4d71e9371305f2d4.setContent(html_07511aaeca28af8bc6b052ff1735776b);
#
#
#
#         marker_9098336a7ff32f2cf41d1c8f6171c27a.bindPopup(popup_ba81cc9a6566b1bd4d71e9371305f2d4)
#         ;
#
#
#
#
#             var marker_4a88149c5f7cd0f8fed16e28f56beed9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_427a0bfaf1187188afdf9b8b43e4fa46);
#
#
#         var popup_771741d3e2e869227be165dd4399731d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a89714c967c5933285eed9e437dd8c4 = $(`&lt;div id=&quot;html_9a89714c967c5933285eed9e437dd8c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_771741d3e2e869227be165dd4399731d.setContent(html_9a89714c967c5933285eed9e437dd8c4);
#
#
#
#         marker_4a88149c5f7cd0f8fed16e28f56beed9.bindPopup(popup_771741d3e2e869227be165dd4399731d)
#         ;
#
#
#
#
#             var marker_cb694fa975423ccf9f5e4c4b16a33a80 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_427a0bfaf1187188afdf9b8b43e4fa46);
#
#
#         var popup_556ab14e6bd2186e0002f5553b9bb8fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_298e6f0fed2aac3cc8cb701253792eae = $(`&lt;div id=&quot;html_298e6f0fed2aac3cc8cb701253792eae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_556ab14e6bd2186e0002f5553b9bb8fd.setContent(html_298e6f0fed2aac3cc8cb701253792eae);
#
#
#
#         marker_
