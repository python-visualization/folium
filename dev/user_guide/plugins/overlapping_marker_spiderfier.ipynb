# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a9ed38f73c811acf7eedc96642987e6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a9ed38f73c811acf7eedc96642987e6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a9ed38f73c811acf7eedc96642987e6c = L.map(
#                 &quot;map_a9ed38f73c811acf7eedc96642987e6c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c6e6ee8fb1ed9653270f7a83bd207ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c6e6ee8fb1ed9653270f7a83bd207ac.addTo(map_a9ed38f73c811acf7eedc96642987e6c);
#
#
#             var marker_a71fbe72081de5f9864388d0b5736ae8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a9ed38f73c811acf7eedc96642987e6c);
#
#
#         var popup_ce2addbbb6da77f643c8237c09a8a97e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2171269fadb48462d21e69414743f9ae = $(`&lt;div id=&quot;html_2171269fadb48462d21e69414743f9ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ce2addbbb6da77f643c8237c09a8a97e.setContent(html_2171269fadb48462d21e69414743f9ae);
#
#
#
#         marker_a71fbe72081de5f9864388d0b5736ae8.bindPopup(popup_ce2addbbb6da77f643c8237c09a8a97e)
#         ;
#
#
#
#
#             var marker_6d9700d7737f2942ddee044194ac5a0b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a9ed38f73c811acf7eedc96642987e6c);
#
#
#         var popup_ab25706f67a3d7734734dc2a4b23f0e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5520946936e3c2756b071ab600bebd9a = $(`&lt;div id=&quot;html_5520946936e3c2756b071ab600bebd9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ab25706f67a3d7734734dc2a4b23f0e1.setContent(html_5520946936e3c2756b071ab600bebd9a);
#
#
#
#         marker_6d9700d7737f2942ddee044194ac5a0b.bindPopup(popup_ab25706f67a3d7734734dc2a4b23f0e1)
#         ;
#
#
#
#
#             var marker_42f2e88214e99566633753aee193bf94 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a9ed38f73c811acf7eedc96642987e6c);
#
#
#         var popup_63d6d3f2ca42affd209b6f26cf5e342a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30c083a90f69d496fbdce0ba0101e692 = $(`&lt;div id=&quot;html_30c083a90f69d496fbdce0ba0101e692&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_63d6d3f2ca42affd209b6f26cf5e342a.setContent(html_30c083a90f69d496fbdce0ba0101e692);
#
#
#
#         marker_42f2e88214e99566633753aee193bf94.bindPopup(popup_63d6d3f2ca42affd209b6f26cf5e342a)
#         ;
#
#
#
#
#             var marker_0c50d4085018fb2cbe965da92d0c865e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a9ed38f73c811acf7eedc96642987e6c);
#
#
#         var popup_68e9be93eac73baa7ea6cfe7eace3e32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcadd34af86b40b4e7dce950445d08ed = $(`&lt;div id=&quot;html_dcadd34af86b40b4e7dce950445d08ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_68e9be93eac73baa7ea6cfe7eace3e32.setContent(html_dcadd34af86b40b4e7dce950445d08ed);
#
#
#
#         marker_0c50d4085018fb2cbe965da92d0c865e.bindPopup(popup_68e9be93eac73baa7ea6cfe7eace3e32)
#         ;
#
#
#
#
#             var marker_dc97aa18b3e8c707792a6ca2baf67f0d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a9ed38f73c811acf7eedc96642987e6c);
#
#
#         var popup_16282c975cb448d6bf807ca9531d16bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c271132cdd5b6fbb1362d92f64f5486 = $(`&lt;div id=&quot;html_5c271132cdd5b6fbb1362d92f64f5486&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_16282c975cb448d6bf807ca9531d16bc.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a979307e3a90b90b8d6dec6092a5e8b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a979307e3a90b90b8d6dec6092a5e8b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a979307e3a90b90b8d6dec6092a5e8b1 = L.map(
#                 &quot;map_a979307e3a90b90b8d6dec6092a5e8b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd4c23d533b2466d2ac54bb12fa34c3e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd4c23d533b2466d2ac54bb12fa34c3e.addTo(map_a979307e3a90b90b8d6dec6092a5e8b1);
#
#
#             var feature_group_30aed805fae4a0560a5a9af8adaaa586 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_93cb021dc26295266b5f92d4f41ff576 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_30aed805fae4a0560a5a9af8adaaa586);
#
#
#         var popup_b845f5d75a16204884cb9354cdc876a2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6735c14836e5ec79adacc9e8a3fbb76 = $(`&lt;div id=&quot;html_a6735c14836e5ec79adacc9e8a3fbb76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b845f5d75a16204884cb9354cdc876a2.setContent(html_a6735c14836e5ec79adacc9e8a3fbb76);
#
#
#
#         marker_93cb021dc26295266b5f92d4f41ff576.bindPopup(popup_b845f5d75a16204884cb9354cdc876a2)
#         ;
#
#
#
#
#             var marker_3f0b9a206fd272de2068833285eb2816 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_30aed805fae4a0560a5a9af8adaaa586);
#
#
#         var popup_51e48203ca22bb974f820892ae7423d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_59c0e34f0b443b6ffc5719ab7aeb0f1a = $(`&lt;div id=&quot;html_59c0e34f0b443b6ffc5719ab7aeb0f1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_51e48203ca22bb974f820892ae7423d1.setContent(html_59c0e34f0b443b6ffc5719ab7aeb0f1a);
#
#
#
#         marker_3f0b9a206fd272de2068833285eb2816.bindPopup(popup_51e48203ca22bb974f820892ae7423d1)
#         ;
#
#
#
#
#             var marker_1c99534d22b9c5af7aa4f459373b1fc2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_30aed805fae4a0560a5a9af8adaaa586);
#
#
#         var popup_93f6f06f8ed2247683064387a61f0d3c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71e151e4e0bbbfa0e9e0480bb8232a21 = $(`&lt;div id=&quot;html_71e151e4e0bbbfa0e9e0480bb8232a21&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_93f6f06f8ed2247683064387a61f0d3c.setContent(html_71e151e4e0bbbfa0e9e0480bb8232a21);
#
#
#
#         marker_1c99534d22b9c5af7aa4f459373b1fc2.bindPopup(popup_93f6f06f8ed2247683064387a61f0d3c)
#         ;
#
#
#
#
#             var marker_025f09825c52eab1e476e00025b06ce8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_30aed805fae4a0560a5a9af8adaaa586);
#
#
#         var popup_ec25d960a55216501f68e202bf34a91a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a3ef85b46ebb69a90762b30e7fde7bb = $(`&lt;div id=&quot;html_2a3ef85b46ebb69a90762b30e7fde7bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ec25d960a55216501f68e202bf34a91a.setContent(html_2a3ef85b46ebb69a90762b30e7fde7bb);
#
#
#
#         marker_025f09825c52eab1e476e00025b06ce8.bindPopup(popup_ec25d960a55216501f68e202bf34a91a)
#         ;
#
#
#
#
#             var marker_b19f11c76e24408fea467ac4760590b3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_30aed805fae4a0560a5a9af8adaaa586);
#
#
#         var popup_dad91b4ba906bdad79a500c63e2c4411 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e19c74ad66f75727c3e66da292cec27 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e19c74ad66f75727c3e66da292cec27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e19c74ad66f75727c3e66da292cec27 = L.map(
#                 &quot;map_7e19c74ad66f75727c3e66da292cec27&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b38bb54db4626f5252e240cb1c86412d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b38bb54db4626f5252e240cb1c86412d.addTo(map_7e19c74ad66f75727c3e66da292cec27);
#
#
#             var feature_group_75af0ff1f0f8bfcf337f6fd134e80c1b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_75af0ff1f0f8bfcf337f6fd134e80c1b.addTo(map_7e19c74ad66f75727c3e66da292cec27);
#
#
#             var feature_group_sub_group_f808c4f5bd965520ceaf219ab03bda54 = L.featureGroup.subGroup(
#                 feature_group_75af0ff1f0f8bfcf337f6fd134e80c1b
#             );
#
#
#             var marker_fccde8791700fb1d9fca8feff668d312 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f808c4f5bd965520ceaf219ab03bda54);
#
#
#         var popup_b449d6b025fa122e5a0308bc3ab83d00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0844bb837b903b8e3dfa51ec1f5142fd = $(`&lt;div id=&quot;html_0844bb837b903b8e3dfa51ec1f5142fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b449d6b025fa122e5a0308bc3ab83d00.setContent(html_0844bb837b903b8e3dfa51ec1f5142fd);
#
#
#
#         marker_fccde8791700fb1d9fca8feff668d312.bindPopup(popup_b449d6b025fa122e5a0308bc3ab83d00)
#         ;
#
#
#
#
#             var marker_ada23d469eb15739b1ad4c9870af6298 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f808c4f5bd965520ceaf219ab03bda54);
#
#
#         var popup_e566961405851c2a1c500a1afcdc9da2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2aca13a16c44e97c22ece9a4d24ffeb = $(`&lt;div id=&quot;html_b2aca13a16c44e97c22ece9a4d24ffeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e566961405851c2a1c500a1afcdc9da2.setContent(html_b2aca13a16c44e97c22ece9a4d24ffeb);
#
#
#
#         marker_ada23d469eb15739b1ad4c9870af6298.bindPopup(popup_e566961405851c2a1c500a1afcdc9da2)
#         ;
#
#
#
#
#             var marker_bc787a3805f96f4ff778fb1ba6e38156 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f808c4f5bd965520ceaf219ab03bda54);
#
#
#         var popup_17b96ab68a172e4551319747a3a4f755 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33b344c6374d4d78ce099c95fabebcad = $(`&lt;div id=&quot;html_33b344c6374d4d78ce099c95fabebcad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_17b96ab68a172e4551319747a3a4f755.setContent(html_33b344c6374d4d78ce099c95fabebcad);
#
#
#
#         marker_bc787a3805f96f4ff778fb1ba6e38156.bindPopup(popup_17b96ab68a172e4551319747a3a4f755)
#         ;
#
#
#
#
#             var marker_d66ccaf423eda0f10ec6f080523a395d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f808c4f5bd965520ceaf219ab03bda54);
#
#
#         var popup_9a93bb2b566dc2a22417a1b660b78cf9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df509fd7d71c88d457864d91e14be953 = $(`&lt;div id=&quot;html_df509fd7d71c88d457864d91e14be953&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_9a93bb2b566dc2a22417a1b660b78cf9.setContent(html_df509fd7d71c88d457864d91e14be953);
#
#
#
#         marker_
