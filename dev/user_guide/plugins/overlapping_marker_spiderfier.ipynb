# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9a2c31d36aaa184d5d21ce934a00c3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9a2c31d36aaa184d5d21ce934a00c3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9a2c31d36aaa184d5d21ce934a00c3f = L.map(
#                 &quot;map_f9a2c31d36aaa184d5d21ce934a00c3f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6edf43c555b8f79b02a19cbf44e90c68 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6edf43c555b8f79b02a19cbf44e90c68.addTo(map_f9a2c31d36aaa184d5d21ce934a00c3f);
#
#
#             var marker_dccce120fb32b27aa5d132e013c0b08a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f9a2c31d36aaa184d5d21ce934a00c3f);
#
#
#         var popup_309069236279ea94236fd5f5d107d183 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_953e4ff9dfb13729967d94280feaa836 = $(`&lt;div id=&quot;html_953e4ff9dfb13729967d94280feaa836&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_309069236279ea94236fd5f5d107d183.setContent(html_953e4ff9dfb13729967d94280feaa836);
#
#
#
#         marker_dccce120fb32b27aa5d132e013c0b08a.bindPopup(popup_309069236279ea94236fd5f5d107d183)
#         ;
#
#
#
#
#             var marker_66c4d012a6656968fe4e0fa4fa614295 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f9a2c31d36aaa184d5d21ce934a00c3f);
#
#
#         var popup_06505e3336e2e7c606816a79d89c189e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e09c93968a3e8e1a3e5c8248c653164 = $(`&lt;div id=&quot;html_5e09c93968a3e8e1a3e5c8248c653164&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_06505e3336e2e7c606816a79d89c189e.setContent(html_5e09c93968a3e8e1a3e5c8248c653164);
#
#
#
#         marker_66c4d012a6656968fe4e0fa4fa614295.bindPopup(popup_06505e3336e2e7c606816a79d89c189e)
#         ;
#
#
#
#
#             var marker_80d2e96e63c11ce08ace7ccf8fec77a6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f9a2c31d36aaa184d5d21ce934a00c3f);
#
#
#         var popup_5a62956efc313ef130f1959468b6fc22 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b69fc61e9561bbc156f48692ab9bcb6a = $(`&lt;div id=&quot;html_b69fc61e9561bbc156f48692ab9bcb6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_5a62956efc313ef130f1959468b6fc22.setContent(html_b69fc61e9561bbc156f48692ab9bcb6a);
#
#
#
#         marker_80d2e96e63c11ce08ace7ccf8fec77a6.bindPopup(popup_5a62956efc313ef130f1959468b6fc22)
#         ;
#
#
#
#
#             var marker_3fbc0abf480104a6270573799c42d1d2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f9a2c31d36aaa184d5d21ce934a00c3f);
#
#
#         var popup_6e3cb7f34181c556a4b81f3a67bfc85f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8eba71d81f3a3369bf82ec8e3f3dba5 = $(`&lt;div id=&quot;html_c8eba71d81f3a3369bf82ec8e3f3dba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6e3cb7f34181c556a4b81f3a67bfc85f.setContent(html_c8eba71d81f3a3369bf82ec8e3f3dba5);
#
#
#
#         marker_3fbc0abf480104a6270573799c42d1d2.bindPopup(popup_6e3cb7f34181c556a4b81f3a67bfc85f)
#         ;
#
#
#
#
#             var marker_58d82eb3068e04e6c80d2aead866eeb7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f9a2c31d36aaa184d5d21ce934a00c3f);
#
#
#         var popup_4336a10053f89735c81da17b69af6b3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a6edb3c32aa91514966cfc577170590 = $(`&lt;div id=&quot;html_1a6edb3c32aa91514966cfc577170590&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4336a10053f89735c81da17b69af6b3f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12b67cbc61c35be9c1c819aa01ec23ec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12b67cbc61c35be9c1c819aa01ec23ec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12b67cbc61c35be9c1c819aa01ec23ec = L.map(
#                 &quot;map_12b67cbc61c35be9c1c819aa01ec23ec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0771e0d8c27d042f940dbf3070981a9d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0771e0d8c27d042f940dbf3070981a9d.addTo(map_12b67cbc61c35be9c1c819aa01ec23ec);
#
#
#             var feature_group_9367b22c1caddebe7fb0d28902fe08de = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6f06f192583c918fcb19ae10b83bb311 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9367b22c1caddebe7fb0d28902fe08de);
#
#
#         var popup_fb15d45a42279e5bfe8a50170ad1b98f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e7e2a5aca47b7ec1ae0dfbc9ea0c948 = $(`&lt;div id=&quot;html_9e7e2a5aca47b7ec1ae0dfbc9ea0c948&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fb15d45a42279e5bfe8a50170ad1b98f.setContent(html_9e7e2a5aca47b7ec1ae0dfbc9ea0c948);
#
#
#
#         marker_6f06f192583c918fcb19ae10b83bb311.bindPopup(popup_fb15d45a42279e5bfe8a50170ad1b98f)
#         ;
#
#
#
#
#             var marker_f39c2301df203e5fe363e77a505ade4d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9367b22c1caddebe7fb0d28902fe08de);
#
#
#         var popup_3e140d0ee81ee9034ce330a176b3bd58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4697e8773687f0b5c1bd617deeb69dcc = $(`&lt;div id=&quot;html_4697e8773687f0b5c1bd617deeb69dcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3e140d0ee81ee9034ce330a176b3bd58.setContent(html_4697e8773687f0b5c1bd617deeb69dcc);
#
#
#
#         marker_f39c2301df203e5fe363e77a505ade4d.bindPopup(popup_3e140d0ee81ee9034ce330a176b3bd58)
#         ;
#
#
#
#
#             var marker_5ab111345a698ea2da9d2fc1b755fb45 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9367b22c1caddebe7fb0d28902fe08de);
#
#
#         var popup_7559566d9fe15f5452f8aa5f07442692 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e0a2fdba99b1773cfba0b2593408c32 = $(`&lt;div id=&quot;html_7e0a2fdba99b1773cfba0b2593408c32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7559566d9fe15f5452f8aa5f07442692.setContent(html_7e0a2fdba99b1773cfba0b2593408c32);
#
#
#
#         marker_5ab111345a698ea2da9d2fc1b755fb45.bindPopup(popup_7559566d9fe15f5452f8aa5f07442692)
#         ;
#
#
#
#
#             var marker_9bc13d301dbcfacfce90d65e05a9a589 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9367b22c1caddebe7fb0d28902fe08de);
#
#
#         var popup_99d75af399e8932981d04f8bb380dd21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f37718e15a1bb6c33321c2b7ceed04e6 = $(`&lt;div id=&quot;html_f37718e15a1bb6c33321c2b7ceed04e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_99d75af399e8932981d04f8bb380dd21.setContent(html_f37718e15a1bb6c33321c2b7ceed04e6);
#
#
#
#         marker_9bc13d301dbcfacfce90d65e05a9a589.bindPopup(popup_99d75af399e8932981d04f8bb380dd21)
#         ;
#
#
#
#
#             var marker_61703ced8ec87347a34707fd12c89ab1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9367b22c1caddebe7fb0d28902fe08de);
#
#
#         var popup_42c227fd4cb50b1e86fa5e387bbe9928 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9a4d8852609023efb43d40f3a3351dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9a4d8852609023efb43d40f3a3351dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9a4d8852609023efb43d40f3a3351dc = L.map(
#                 &quot;map_c9a4d8852609023efb43d40f3a3351dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b76d2b3c8e34d1e3aa2efdc51bf6d47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0b76d2b3c8e34d1e3aa2efdc51bf6d47.addTo(map_c9a4d8852609023efb43d40f3a3351dc);
#
#
#             var feature_group_f07c225113a4c33390fca6a30822c6dc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f07c225113a4c33390fca6a30822c6dc.addTo(map_c9a4d8852609023efb43d40f3a3351dc);
#
#
#             var feature_group_sub_group_0169253c36ba7885b264d660ccfc67ea = L.featureGroup.subGroup(
#                 feature_group_f07c225113a4c33390fca6a30822c6dc
#             );
#
#
#             var marker_e4a7d24c1ed1db84003390add50a3f7d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0169253c36ba7885b264d660ccfc67ea);
#
#
#         var popup_1bcea4575d811356aa5a809251f8a85c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61a85b0dce55640a9a81a65fbe0fca09 = $(`&lt;div id=&quot;html_61a85b0dce55640a9a81a65fbe0fca09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1bcea4575d811356aa5a809251f8a85c.setContent(html_61a85b0dce55640a9a81a65fbe0fca09);
#
#
#
#         marker_e4a7d24c1ed1db84003390add50a3f7d.bindPopup(popup_1bcea4575d811356aa5a809251f8a85c)
#         ;
#
#
#
#
#             var marker_03fa3f0856dd0e6bb0d87c22d02ecc86 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0169253c36ba7885b264d660ccfc67ea);
#
#
#         var popup_f44f26cac82b11ab7e5c718c111170aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88fc7a2ab28bd264989a107fec662cfa = $(`&lt;div id=&quot;html_88fc7a2ab28bd264989a107fec662cfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f44f26cac82b11ab7e5c718c111170aa.setContent(html_88fc7a2ab28bd264989a107fec662cfa);
#
#
#
#         marker_03fa3f0856dd0e6bb0d87c22d02ecc86.bindPopup(popup_f44f26cac82b11ab7e5c718c111170aa)
#         ;
#
#
#
#
#             var marker_a38255b66632bd1233d4bdbfc41c5502 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0169253c36ba7885b264d660ccfc67ea);
#
#
#         var popup_f2d8be538786d37b5309f736ef43a4ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faff2fe013a12f87415fa17c7e19b91d = $(`&lt;div id=&quot;html_faff2fe013a12f87415fa17c7e19b91d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f2d8be538786d37b5309f736ef43a4ca.setContent(html_faff2fe013a12f87415fa17c7e19b91d);
#
#
#
#         marker_a38255b66632bd1233d4bdbfc41c5502.bindPopup(popup_f2d8be538786d37b5309f736ef43a4ca)
#         ;
#
#
#
#
#             var marker_ba99e9253e5985bb55020dfa46d4a220 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0169253c36ba7885b264d660ccfc67ea);
#
#
#         var popup_6a23e1d4f0eb87717040aaefea49a007 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c908f383e694ef43e25c91d89fe49c12 = $(`&lt;div id=&quot;html_c908f383e694ef43e25c91d89fe49c12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_6a23e1d4f0eb87717040aaefea49a007.setContent(html_c908f383e694ef43e25c91d89fe49c12);
#
#
#
#         marker_
