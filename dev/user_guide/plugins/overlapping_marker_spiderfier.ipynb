# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bb4544ff3d2a06a3231e97c10b896f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bb4544ff3d2a06a3231e97c10b896f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bb4544ff3d2a06a3231e97c10b896f6 = L.map(
#                 &quot;map_1bb4544ff3d2a06a3231e97c10b896f6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67c68a3eb395c5177ab4ea6f5056239b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67c68a3eb395c5177ab4ea6f5056239b.addTo(map_1bb4544ff3d2a06a3231e97c10b896f6);
#
#
#             var marker_d3fcbb0ac54650d86df803209a952578 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1bb4544ff3d2a06a3231e97c10b896f6);
#
#
#         var popup_33bb5ec66a696ab49ffbf153556805d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfa95c17bacece5720d229ad44d60cdf = $(`&lt;div id=&quot;html_dfa95c17bacece5720d229ad44d60cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_33bb5ec66a696ab49ffbf153556805d6.setContent(html_dfa95c17bacece5720d229ad44d60cdf);
#
#
#
#         marker_d3fcbb0ac54650d86df803209a952578.bindPopup(popup_33bb5ec66a696ab49ffbf153556805d6)
#         ;
#
#
#
#
#             var marker_584bca7c2ca9952839b000b1b458c7d5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1bb4544ff3d2a06a3231e97c10b896f6);
#
#
#         var popup_a8b3fff5c452e300e5d205846aafb465 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7bf52e5a78f67e6dc298329bf45f58b2 = $(`&lt;div id=&quot;html_7bf52e5a78f67e6dc298329bf45f58b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a8b3fff5c452e300e5d205846aafb465.setContent(html_7bf52e5a78f67e6dc298329bf45f58b2);
#
#
#
#         marker_584bca7c2ca9952839b000b1b458c7d5.bindPopup(popup_a8b3fff5c452e300e5d205846aafb465)
#         ;
#
#
#
#
#             var marker_5a2b419b5fd0c9eb23d662e23ffa63cd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1bb4544ff3d2a06a3231e97c10b896f6);
#
#
#         var popup_52627df50c441dd5740d2da8c50d64b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_16ca6986bf63e1e7bd589b3163d7bcdb = $(`&lt;div id=&quot;html_16ca6986bf63e1e7bd589b3163d7bcdb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_52627df50c441dd5740d2da8c50d64b4.setContent(html_16ca6986bf63e1e7bd589b3163d7bcdb);
#
#
#
#         marker_5a2b419b5fd0c9eb23d662e23ffa63cd.bindPopup(popup_52627df50c441dd5740d2da8c50d64b4)
#         ;
#
#
#
#
#             var marker_4449045ca01150a9388a74ac1367eaf5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1bb4544ff3d2a06a3231e97c10b896f6);
#
#
#         var popup_f7fb2969b33ea29252e64b64f480a460 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f06cdd219758a1e4c404f894ab3baf2e = $(`&lt;div id=&quot;html_f06cdd219758a1e4c404f894ab3baf2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f7fb2969b33ea29252e64b64f480a460.setContent(html_f06cdd219758a1e4c404f894ab3baf2e);
#
#
#
#         marker_4449045ca01150a9388a74ac1367eaf5.bindPopup(popup_f7fb2969b33ea29252e64b64f480a460)
#         ;
#
#
#
#
#             var marker_54bf188f64478f58ede1f7fa3ae9027c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1bb4544ff3d2a06a3231e97c10b896f6);
#
#
#         var popup_29ffe0517002b5de61291d12378273be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6073f00410d5c8602ab9d80eaf9131ae = $(`&lt;div id=&quot;html_6073f00410d5c8602ab9d80eaf9131ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_29ffe0517002b5de61291d12378273be.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2026ce705082b0a92367c7124a9fac56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2026ce705082b0a92367c7124a9fac56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2026ce705082b0a92367c7124a9fac56 = L.map(
#                 &quot;map_2026ce705082b0a92367c7124a9fac56&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_430c469628ddee8238b7129abddd72f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_430c469628ddee8238b7129abddd72f5.addTo(map_2026ce705082b0a92367c7124a9fac56);
#
#
#             var feature_group_f44ed8d1c1d92a6383fc5786c522652d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2c2f384e60868fc1554d567537a3fdd2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f44ed8d1c1d92a6383fc5786c522652d);
#
#
#         var popup_4cbc1fa4d8421480e38885caa5c4102a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_475769644aec9f0516849758729ef23f = $(`&lt;div id=&quot;html_475769644aec9f0516849758729ef23f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4cbc1fa4d8421480e38885caa5c4102a.setContent(html_475769644aec9f0516849758729ef23f);
#
#
#
#         marker_2c2f384e60868fc1554d567537a3fdd2.bindPopup(popup_4cbc1fa4d8421480e38885caa5c4102a)
#         ;
#
#
#
#
#             var marker_38edadf653388bc0390cdcfd2ba67d87 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f44ed8d1c1d92a6383fc5786c522652d);
#
#
#         var popup_0f4a90a17d2bfefe01f9eb621898fbca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87852cc883dcc16d9bcdcb55b54234a8 = $(`&lt;div id=&quot;html_87852cc883dcc16d9bcdcb55b54234a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0f4a90a17d2bfefe01f9eb621898fbca.setContent(html_87852cc883dcc16d9bcdcb55b54234a8);
#
#
#
#         marker_38edadf653388bc0390cdcfd2ba67d87.bindPopup(popup_0f4a90a17d2bfefe01f9eb621898fbca)
#         ;
#
#
#
#
#             var marker_fe2773d16c339aa80c1a65b10d686ac9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f44ed8d1c1d92a6383fc5786c522652d);
#
#
#         var popup_8ec972d66f26d6097d861b838529cd16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6fb6163faa60268b0d56d458df88902 = $(`&lt;div id=&quot;html_b6fb6163faa60268b0d56d458df88902&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8ec972d66f26d6097d861b838529cd16.setContent(html_b6fb6163faa60268b0d56d458df88902);
#
#
#
#         marker_fe2773d16c339aa80c1a65b10d686ac9.bindPopup(popup_8ec972d66f26d6097d861b838529cd16)
#         ;
#
#
#
#
#             var marker_216c4c889118c67ece78dd8ea04f62f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f44ed8d1c1d92a6383fc5786c522652d);
#
#
#         var popup_42bcf67602f0c8702ab3606284e67e32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b61ba0229683eed5704f4f50ace2b64a = $(`&lt;div id=&quot;html_b61ba0229683eed5704f4f50ace2b64a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_42bcf67602f0c8702ab3606284e67e32.setContent(html_b61ba0229683eed5704f4f50ace2b64a);
#
#
#
#         marker_216c4c889118c67ece78dd8ea04f62f0.bindPopup(popup_42bcf67602f0c8702ab3606284e67e32)
#         ;
#
#
#
#
#             var marker_cb167fb095bbbc3e842168ecbcf902a9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f44ed8d1c1d92a6383fc5786c522652d);
#
#
#         var popup_b22f6d81a6fd3ae7aa1b4a0345538456 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_10411d3669cd58d2b17ad93ef80943ee {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_10411d3669cd58d2b17ad93ef80943ee&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_10411d3669cd58d2b17ad93ef80943ee = L.map(
#                 &quot;map_10411d3669cd58d2b17ad93ef80943ee&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a83920face810af8d9be080f45a9e19 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a83920face810af8d9be080f45a9e19.addTo(map_10411d3669cd58d2b17ad93ef80943ee);
#
#
#             var feature_group_d400bbb35518a138d8e4d70646ee9587 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d400bbb35518a138d8e4d70646ee9587.addTo(map_10411d3669cd58d2b17ad93ef80943ee);
#
#
#             var feature_group_sub_group_b5802bc99b8325fe884b82047f0b816f = L.featureGroup.subGroup(
#                 feature_group_d400bbb35518a138d8e4d70646ee9587
#             );
#
#
#             var marker_3f385a890ccfdbfcec1dcb32f5ced6e5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5802bc99b8325fe884b82047f0b816f);
#
#
#         var popup_db5cb70f309ce29b34271790226a7df8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27849d4cc03b440f1de2a02ee2551da4 = $(`&lt;div id=&quot;html_27849d4cc03b440f1de2a02ee2551da4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_db5cb70f309ce29b34271790226a7df8.setContent(html_27849d4cc03b440f1de2a02ee2551da4);
#
#
#
#         marker_3f385a890ccfdbfcec1dcb32f5ced6e5.bindPopup(popup_db5cb70f309ce29b34271790226a7df8)
#         ;
#
#
#
#
#             var marker_d310c65b093d0105ea26dd7d1bd343d0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5802bc99b8325fe884b82047f0b816f);
#
#
#         var popup_79b6e7f5e7c53e53ab35b6a883c13b7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2336db471fce8e8c3d796e427f1b9924 = $(`&lt;div id=&quot;html_2336db471fce8e8c3d796e427f1b9924&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_79b6e7f5e7c53e53ab35b6a883c13b7e.setContent(html_2336db471fce8e8c3d796e427f1b9924);
#
#
#
#         marker_d310c65b093d0105ea26dd7d1bd343d0.bindPopup(popup_79b6e7f5e7c53e53ab35b6a883c13b7e)
#         ;
#
#
#
#
#             var marker_9e7c77249c3980e1ee15b49136fdaac5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5802bc99b8325fe884b82047f0b816f);
#
#
#         var popup_0189b37ba8341275d4026843eb0e2529 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d59f8072c7916058551783a6506b203c = $(`&lt;div id=&quot;html_d59f8072c7916058551783a6506b203c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0189b37ba8341275d4026843eb0e2529.setContent(html_d59f8072c7916058551783a6506b203c);
#
#
#
#         marker_9e7c77249c3980e1ee15b49136fdaac5.bindPopup(popup_0189b37ba8341275d4026843eb0e2529)
#         ;
#
#
#
#
#             var marker_74c2ff030646f4d58991ed03669b081f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5802bc99b8325fe884b82047f0b816f);
#
#
#         var popup_01914bbdb769347d7a1d74974b305f79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b3bdad454b79ea3782ebdf49dfbe61b = $(`&lt;div id=&quot;html_0b3bdad454b79ea3782ebdf49dfbe61b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_01914bbdb769347d7a1d74974b305f79.setContent(html_0b3bdad454b79ea3782ebdf49dfbe61b);
#
#
#
#         marker_
