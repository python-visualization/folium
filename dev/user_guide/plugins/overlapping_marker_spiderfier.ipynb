# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_81f9d4556abb02a4c01c91cdad7a0685 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_81f9d4556abb02a4c01c91cdad7a0685&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_81f9d4556abb02a4c01c91cdad7a0685 = L.map(
#                 &quot;map_81f9d4556abb02a4c01c91cdad7a0685&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd0e715c0605c37de0354bafe9c25823 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd0e715c0605c37de0354bafe9c25823.addTo(map_81f9d4556abb02a4c01c91cdad7a0685);
#
#
#             var marker_03ec2eea362f3ac12ec9bc07c1fba955 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_81f9d4556abb02a4c01c91cdad7a0685);
#
#
#         var popup_34d14fac34e5525f773a99eb633b3907 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76bf1e1b732b84605f9db130798a23d1 = $(`&lt;div id=&quot;html_76bf1e1b732b84605f9db130798a23d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_34d14fac34e5525f773a99eb633b3907.setContent(html_76bf1e1b732b84605f9db130798a23d1);
#
#
#
#         marker_03ec2eea362f3ac12ec9bc07c1fba955.bindPopup(popup_34d14fac34e5525f773a99eb633b3907)
#         ;
#
#
#
#
#             var marker_4dcdf2e12b31545738ec8fd56aa85d40 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_81f9d4556abb02a4c01c91cdad7a0685);
#
#
#         var popup_445c2ce82eaa48ac52eec0813c0c33a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef7feea3f0d9cceed9f0b5d44392a470 = $(`&lt;div id=&quot;html_ef7feea3f0d9cceed9f0b5d44392a470&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_445c2ce82eaa48ac52eec0813c0c33a6.setContent(html_ef7feea3f0d9cceed9f0b5d44392a470);
#
#
#
#         marker_4dcdf2e12b31545738ec8fd56aa85d40.bindPopup(popup_445c2ce82eaa48ac52eec0813c0c33a6)
#         ;
#
#
#
#
#             var marker_88944e6ae452e5572de223e509d08643 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_81f9d4556abb02a4c01c91cdad7a0685);
#
#
#         var popup_57610024143cb89c5fba900acea7bd0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2dff51bc89eae75b1500c6e09b2f5e0 = $(`&lt;div id=&quot;html_d2dff51bc89eae75b1500c6e09b2f5e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_57610024143cb89c5fba900acea7bd0f.setContent(html_d2dff51bc89eae75b1500c6e09b2f5e0);
#
#
#
#         marker_88944e6ae452e5572de223e509d08643.bindPopup(popup_57610024143cb89c5fba900acea7bd0f)
#         ;
#
#
#
#
#             var marker_b10b00eff075d4a93302062fcaceaae5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_81f9d4556abb02a4c01c91cdad7a0685);
#
#
#         var popup_6681b5e60bcdb98c6e90e0a73f6a3870 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7d0c92a10580d1092c698c4ff98f8f2 = $(`&lt;div id=&quot;html_c7d0c92a10580d1092c698c4ff98f8f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6681b5e60bcdb98c6e90e0a73f6a3870.setContent(html_c7d0c92a10580d1092c698c4ff98f8f2);
#
#
#
#         marker_b10b00eff075d4a93302062fcaceaae5.bindPopup(popup_6681b5e60bcdb98c6e90e0a73f6a3870)
#         ;
#
#
#
#
#             var marker_ca98240e5fcd68620bd671ac39da0e22 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_81f9d4556abb02a4c01c91cdad7a0685);
#
#
#         var popup_b9ab8d06e032a7e324745565af6b3081 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_408a7bae17da120af6ea18edc82c73f1 = $(`&lt;div id=&quot;html_408a7bae17da120af6ea18edc82c73f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b9ab8d06e032a7e324745565af6b30

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51838cb1740d38ca99d7b4e861f68bc9 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51838cb1740d38ca99d7b4e861f68bc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51838cb1740d38ca99d7b4e861f68bc9 = L.map(
#                 &quot;map_51838cb1740d38ca99d7b4e861f68bc9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1f0be344a6fa710fbf5d8a2f969edeb1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1f0be344a6fa710fbf5d8a2f969edeb1.addTo(map_51838cb1740d38ca99d7b4e861f68bc9);
#
#
#             var feature_group_8525279bbd1fb6b12b0919b1b023d0bf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dfbb39519f1f106fdbd89541bd710157 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8525279bbd1fb6b12b0919b1b023d0bf);
#
#
#         var popup_8b02e166f9961a6e322631e0061b137c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf8754f012efd527a5e4ad83f48594c7 = $(`&lt;div id=&quot;html_cf8754f012efd527a5e4ad83f48594c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_8b02e166f9961a6e322631e0061b137c.setContent(html_cf8754f012efd527a5e4ad83f48594c7);
#
#
#
#         marker_dfbb39519f1f106fdbd89541bd710157.bindPopup(popup_8b02e166f9961a6e322631e0061b137c)
#         ;
#
#
#
#
#             var marker_807c5f0061214ca79d3bb8053bb09b08 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8525279bbd1fb6b12b0919b1b023d0bf);
#
#
#         var popup_5916dc9de7f7b4e097c72f387d340d08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29be7302aa8c440892542faf8cee7065 = $(`&lt;div id=&quot;html_29be7302aa8c440892542faf8cee7065&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_5916dc9de7f7b4e097c72f387d340d08.setContent(html_29be7302aa8c440892542faf8cee7065);
#
#
#
#         marker_807c5f0061214ca79d3bb8053bb09b08.bindPopup(popup_5916dc9de7f7b4e097c72f387d340d08)
#         ;
#
#
#
#
#             var marker_a5df810b0d6cc090cb7e1dab0b599ac5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8525279bbd1fb6b12b0919b1b023d0bf);
#
#
#         var popup_0271b597231d42dfc68e1cc0312917c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56abd1242d4641b7f8c806de2efda75a = $(`&lt;div id=&quot;html_56abd1242d4641b7f8c806de2efda75a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0271b597231d42dfc68e1cc0312917c8.setContent(html_56abd1242d4641b7f8c806de2efda75a);
#
#
#
#         marker_a5df810b0d6cc090cb7e1dab0b599ac5.bindPopup(popup_0271b597231d42dfc68e1cc0312917c8)
#         ;
#
#
#
#
#             var marker_4a128232003a7ff5076d3a4a9fcc2d71 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8525279bbd1fb6b12b0919b1b023d0bf);
#
#
#         var popup_ec0381b0fa8c43c69f4a71c4d39c39a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_35df6ab80bd8ff281737d146b9137275 = $(`&lt;div id=&quot;html_35df6ab80bd8ff281737d146b9137275&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ec0381b0fa8c43c69f4a71c4d39c39a8.setContent(html_35df6ab80bd8ff281737d146b9137275);
#
#
#
#         marker_4a128232003a7ff5076d3a4a9fcc2d71.bindPopup(popup_ec0381b0fa8c43c69f4a71c4d39c39a8)
#         ;
#
#
#
#
#             var marker_46d668921ec064d20bd8700f9cba3f4a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8525279bbd1fb6b12b0919b1b023d0bf);
#
#
#         var popup_55622ef84b9f6649f40c3a11edb90914 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_20b412620a35b1f9944c8338bb079332 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_20b412620a35b1f9944c8338bb079332&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_20b412620a35b1f9944c8338bb079332 = L.map(
#                 &quot;map_20b412620a35b1f9944c8338bb079332&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_24676a98f4ed07b0c3d347601061e17d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_24676a98f4ed07b0c3d347601061e17d.addTo(map_20b412620a35b1f9944c8338bb079332);
#
#
#             var feature_group_c3ef0b91dd81cad421ffa4a567660f95 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c3ef0b91dd81cad421ffa4a567660f95.addTo(map_20b412620a35b1f9944c8338bb079332);
#
#
#             var feature_group_sub_group_1244b7252ce743dd16f004e9015a26e4 = L.featureGroup.subGroup(
#                 feature_group_c3ef0b91dd81cad421ffa4a567660f95
#             );
#
#
#             var marker_64a813e2b78fbfcb7b268572350c6858 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1244b7252ce743dd16f004e9015a26e4);
#
#
#         var popup_9b95e2984464a7557158ceebd1640372 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b056980d1cdfe845aaac3cfceabf97d = $(`&lt;div id=&quot;html_6b056980d1cdfe845aaac3cfceabf97d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_9b95e2984464a7557158ceebd1640372.setContent(html_6b056980d1cdfe845aaac3cfceabf97d);
#
#
#
#         marker_64a813e2b78fbfcb7b268572350c6858.bindPopup(popup_9b95e2984464a7557158ceebd1640372)
#         ;
#
#
#
#
#             var marker_5bbd0bdcc3d5acefa6433b27955fa069 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1244b7252ce743dd16f004e9015a26e4);
#
#
#         var popup_b29cf9659b8c6beed19b63ffc7961492 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0cc28ef983c0a7d43ff91b067368a637 = $(`&lt;div id=&quot;html_0cc28ef983c0a7d43ff91b067368a637&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b29cf9659b8c6beed19b63ffc7961492.setContent(html_0cc28ef983c0a7d43ff91b067368a637);
#
#
#
#         marker_5bbd0bdcc3d5acefa6433b27955fa069.bindPopup(popup_b29cf9659b8c6beed19b63ffc7961492)
#         ;
#
#
#
#
#             var marker_736e61b8cb3ad2d4993cbc678b7029d2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1244b7252ce743dd16f004e9015a26e4);
#
#
#         var popup_b121d3e80dcdaa590b1ffefbd68f4e9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c06265cf734a5d1d121b2c4aa3b42bb0 = $(`&lt;div id=&quot;html_c06265cf734a5d1d121b2c4aa3b42bb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b121d3e80dcdaa590b1ffefbd68f4e9b.setContent(html_c06265cf734a5d1d121b2c4aa3b42bb0);
#
#
#
#         marker_736e61b8cb3ad2d4993cbc678b7029d2.bindPopup(popup_b121d3e80dcdaa590b1ffefbd68f4e9b)
#         ;
#
#
#
#
#             var marker_a55986a7244868690e4e8f1914f822ab = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1244b7252ce743dd16f004e9015a26e4);
#
#
#         var popup_4c3a0b6786d0c5953bc09939c29d7807 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9445f981863b9595e5fbfb9d72a0f313 = $(`&lt;div id=&quot;html_9445f981863b9595e5fbfb9d72a0f313&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4c3a0b6786d0c5953bc09939c29d7807.setContent(html_9445f981863b9595e5fbfb9d72a0f313);
#
#
#
#         mark
