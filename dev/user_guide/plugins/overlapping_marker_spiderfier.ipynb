# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dd1ea42e3b24caa5267c8e6d738f5d47 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dd1ea42e3b24caa5267c8e6d738f5d47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dd1ea42e3b24caa5267c8e6d738f5d47 = L.map(
#                 &quot;map_dd1ea42e3b24caa5267c8e6d738f5d47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c8e4b59727fc0c18eef8cf612e39c36e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c8e4b59727fc0c18eef8cf612e39c36e.addTo(map_dd1ea42e3b24caa5267c8e6d738f5d47);
#
#
#             var marker_30691c16feb624838f1070a6d40ef62c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_dd1ea42e3b24caa5267c8e6d738f5d47);
#
#
#         var popup_ce2fcb57094a42656094ab053814554f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_955973c688c5bd1d70eac736b6805a3d = $(`&lt;div id=&quot;html_955973c688c5bd1d70eac736b6805a3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ce2fcb57094a42656094ab053814554f.setContent(html_955973c688c5bd1d70eac736b6805a3d);
#
#
#
#         marker_30691c16feb624838f1070a6d40ef62c.bindPopup(popup_ce2fcb57094a42656094ab053814554f)
#         ;
#
#
#
#
#             var marker_eb3e9f2b5782e28a1f93d642b8986473 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_dd1ea42e3b24caa5267c8e6d738f5d47);
#
#
#         var popup_1b672cfdcc47975263cf98d1f71beed7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b1425bee7d150df08befb58a61c9949 = $(`&lt;div id=&quot;html_5b1425bee7d150df08befb58a61c9949&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1b672cfdcc47975263cf98d1f71beed7.setContent(html_5b1425bee7d150df08befb58a61c9949);
#
#
#
#         marker_eb3e9f2b5782e28a1f93d642b8986473.bindPopup(popup_1b672cfdcc47975263cf98d1f71beed7)
#         ;
#
#
#
#
#             var marker_bca9f9deafbfdda05dc7e6cdd4bf4c54 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_dd1ea42e3b24caa5267c8e6d738f5d47);
#
#
#         var popup_a5a938ec35441335ee124bf4d12c0efa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4baeb24608f8624073f14c6fb9dd83f = $(`&lt;div id=&quot;html_a4baeb24608f8624073f14c6fb9dd83f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a5a938ec35441335ee124bf4d12c0efa.setContent(html_a4baeb24608f8624073f14c6fb9dd83f);
#
#
#
#         marker_bca9f9deafbfdda05dc7e6cdd4bf4c54.bindPopup(popup_a5a938ec35441335ee124bf4d12c0efa)
#         ;
#
#
#
#
#             var marker_caec02bbc1bf620b925cd76856152312 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_dd1ea42e3b24caa5267c8e6d738f5d47);
#
#
#         var popup_9aaa12606a90da2bc7826914a8d000f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_183a45f53c39b9ddb7130c4bc5faaf6a = $(`&lt;div id=&quot;html_183a45f53c39b9ddb7130c4bc5faaf6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9aaa12606a90da2bc7826914a8d000f3.setContent(html_183a45f53c39b9ddb7130c4bc5faaf6a);
#
#
#
#         marker_caec02bbc1bf620b925cd76856152312.bindPopup(popup_9aaa12606a90da2bc7826914a8d000f3)
#         ;
#
#
#
#
#             var marker_508d8831155a72ee70c5661488ffe435 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_dd1ea42e3b24caa5267c8e6d738f5d47);
#
#
#         var popup_c3d5a7dfb5ee48af4f4dd6cf4b0119ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5f40bb8636387bcba3b7cec653f57e2 = $(`&lt;div id=&quot;html_f5f40bb8636387bcba3b7cec653f57e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c3d5a7dfb5ee48af4f4dd6cf4b0119

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59abe3614e7abd9c8820a6c4c533c39d {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59abe3614e7abd9c8820a6c4c533c39d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59abe3614e7abd9c8820a6c4c533c39d = L.map(
#                 &quot;map_59abe3614e7abd9c8820a6c4c533c39d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45a63ce5ef59265b47666ec21a0056e7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45a63ce5ef59265b47666ec21a0056e7.addTo(map_59abe3614e7abd9c8820a6c4c533c39d);
#
#
#             var feature_group_b56f39fcb56bee0f96b6d1fce0a746b7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ae12fdb3214decdda07cd0082636270a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b56f39fcb56bee0f96b6d1fce0a746b7);
#
#
#         var popup_00e4da280e35ad5664cb3c15df709d14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_27c6dd79e1fd8d3de95d2976562208de = $(`&lt;div id=&quot;html_27c6dd79e1fd8d3de95d2976562208de&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_00e4da280e35ad5664cb3c15df709d14.setContent(html_27c6dd79e1fd8d3de95d2976562208de);
#
#
#
#         marker_ae12fdb3214decdda07cd0082636270a.bindPopup(popup_00e4da280e35ad5664cb3c15df709d14)
#         ;
#
#
#
#
#             var marker_bc33463ab9e347d96410815cd5228f5e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b56f39fcb56bee0f96b6d1fce0a746b7);
#
#
#         var popup_a008e5f61797c106ec0c350c0747f0dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26a6869d7e0c72f91ce7a04d08edab57 = $(`&lt;div id=&quot;html_26a6869d7e0c72f91ce7a04d08edab57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a008e5f61797c106ec0c350c0747f0dd.setContent(html_26a6869d7e0c72f91ce7a04d08edab57);
#
#
#
#         marker_bc33463ab9e347d96410815cd5228f5e.bindPopup(popup_a008e5f61797c106ec0c350c0747f0dd)
#         ;
#
#
#
#
#             var marker_916692d76e35efb5fa9bc22796e690ef = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b56f39fcb56bee0f96b6d1fce0a746b7);
#
#
#         var popup_307e17eb6ebdc77c90ead010fe9928f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89d1686908c3292844fba23f7a3ab651 = $(`&lt;div id=&quot;html_89d1686908c3292844fba23f7a3ab651&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_307e17eb6ebdc77c90ead010fe9928f1.setContent(html_89d1686908c3292844fba23f7a3ab651);
#
#
#
#         marker_916692d76e35efb5fa9bc22796e690ef.bindPopup(popup_307e17eb6ebdc77c90ead010fe9928f1)
#         ;
#
#
#
#
#             var marker_0be4eb0a304ba1b12a4726f7365ecef0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b56f39fcb56bee0f96b6d1fce0a746b7);
#
#
#         var popup_d6b7ac374780beb915bcbf8ee66049aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ed497b0b11cadb199c74b2d6a359a5d = $(`&lt;div id=&quot;html_8ed497b0b11cadb199c74b2d6a359a5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d6b7ac374780beb915bcbf8ee66049aa.setContent(html_8ed497b0b11cadb199c74b2d6a359a5d);
#
#
#
#         marker_0be4eb0a304ba1b12a4726f7365ecef0.bindPopup(popup_d6b7ac374780beb915bcbf8ee66049aa)
#         ;
#
#
#
#
#             var marker_42e1c5d01548b9fd0a84aa7cb0ad327e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b56f39fcb56bee0f96b6d1fce0a746b7);
#
#
#         var popup_a0b6a18e55a3cee6a8a01d3b16614c48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_563f6b92a6e1e7eb95a29f892cf0338f {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_563f6b92a6e1e7eb95a29f892cf0338f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_563f6b92a6e1e7eb95a29f892cf0338f = L.map(
#                 &quot;map_563f6b92a6e1e7eb95a29f892cf0338f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bacb1a160c41842ee34942d9293ff3b2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bacb1a160c41842ee34942d9293ff3b2.addTo(map_563f6b92a6e1e7eb95a29f892cf0338f);
#
#
#             var feature_group_3be326a4d3b00cbc2f1f5c75eedf6696 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3be326a4d3b00cbc2f1f5c75eedf6696.addTo(map_563f6b92a6e1e7eb95a29f892cf0338f);
#
#
#             var feature_group_sub_group_f46fddba458def3b69c43ceb54b7647e = L.featureGroup.subGroup(
#                 feature_group_3be326a4d3b00cbc2f1f5c75eedf6696
#             );
#
#
#             var marker_725e97b3dddfb56b6b834dc93a801feb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f46fddba458def3b69c43ceb54b7647e);
#
#
#         var popup_8a910fb48d81bdda66773755978b232d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96f1b58a56fdb326b413edf82d928eac = $(`&lt;div id=&quot;html_96f1b58a56fdb326b413edf82d928eac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8a910fb48d81bdda66773755978b232d.setContent(html_96f1b58a56fdb326b413edf82d928eac);
#
#
#
#         marker_725e97b3dddfb56b6b834dc93a801feb.bindPopup(popup_8a910fb48d81bdda66773755978b232d)
#         ;
#
#
#
#
#             var marker_6f182416724863678366261e0a088b2d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f46fddba458def3b69c43ceb54b7647e);
#
#
#         var popup_ee5f1b820b069b18ce8bd9c4f05685ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b60e5aedc68eec5c19c114796896d186 = $(`&lt;div id=&quot;html_b60e5aedc68eec5c19c114796896d186&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ee5f1b820b069b18ce8bd9c4f05685ee.setContent(html_b60e5aedc68eec5c19c114796896d186);
#
#
#
#         marker_6f182416724863678366261e0a088b2d.bindPopup(popup_ee5f1b820b069b18ce8bd9c4f05685ee)
#         ;
#
#
#
#
#             var marker_3b093a83693e7479a6ea351d619dc174 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f46fddba458def3b69c43ceb54b7647e);
#
#
#         var popup_f41be4465defaddaf59acebdfc32ba2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93d15bbf6b45c0917036a65047da1ac2 = $(`&lt;div id=&quot;html_93d15bbf6b45c0917036a65047da1ac2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f41be4465defaddaf59acebdfc32ba2e.setContent(html_93d15bbf6b45c0917036a65047da1ac2);
#
#
#
#         marker_3b093a83693e7479a6ea351d619dc174.bindPopup(popup_f41be4465defaddaf59acebdfc32ba2e)
#         ;
#
#
#
#
#             var marker_64de52feb98f36e8fbaa60a87fd41c92 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f46fddba458def3b69c43ceb54b7647e);
#
#
#         var popup_c8ec15c49c6212a27972b1395e024cef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_786a421ae95092c529f3e8e82a2d332a = $(`&lt;div id=&quot;html_786a421ae95092c529f3e8e82a2d332a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c8ec15c49c6212a27972b1395e024cef.setContent(html_786a421ae95092c529f3e8e82a2d332a);
#
#
#
#         mark
