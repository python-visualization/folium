# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ce264dd0aba383624406b244dba40327 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ce264dd0aba383624406b244dba40327&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ce264dd0aba383624406b244dba40327 = L.map(
#                 &quot;map_ce264dd0aba383624406b244dba40327&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_091ac807b9f2229cfd038c207880185a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_091ac807b9f2229cfd038c207880185a.addTo(map_ce264dd0aba383624406b244dba40327);
#
#
#             var marker_3ebf5499ee187c6692d612d9a04c2dc0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ce264dd0aba383624406b244dba40327);
#
#
#         var popup_2dec297a70aa75e61a8fe225d05800c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e4c4d2c8562b9ed05ce48b2eb93fce6 = $(`&lt;div id=&quot;html_6e4c4d2c8562b9ed05ce48b2eb93fce6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2dec297a70aa75e61a8fe225d05800c1.setContent(html_6e4c4d2c8562b9ed05ce48b2eb93fce6);
#
#
#
#         marker_3ebf5499ee187c6692d612d9a04c2dc0.bindPopup(popup_2dec297a70aa75e61a8fe225d05800c1)
#         ;
#
#
#
#
#             var marker_9bf2754f5e3d56b5f4409c32472e9498 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ce264dd0aba383624406b244dba40327);
#
#
#         var popup_d4a01bbf6c127ccb83bbe39608f37a5c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b4ee956fbdf19d15b2766112fefd1ac = $(`&lt;div id=&quot;html_0b4ee956fbdf19d15b2766112fefd1ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d4a01bbf6c127ccb83bbe39608f37a5c.setContent(html_0b4ee956fbdf19d15b2766112fefd1ac);
#
#
#
#         marker_9bf2754f5e3d56b5f4409c32472e9498.bindPopup(popup_d4a01bbf6c127ccb83bbe39608f37a5c)
#         ;
#
#
#
#
#             var marker_56086d8a1df9547115c7d013c12de8f3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ce264dd0aba383624406b244dba40327);
#
#
#         var popup_e122683f9f99953933756697436d1bd8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e0c88a0018622d937ed2852c1ab50ce = $(`&lt;div id=&quot;html_2e0c88a0018622d937ed2852c1ab50ce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e122683f9f99953933756697436d1bd8.setContent(html_2e0c88a0018622d937ed2852c1ab50ce);
#
#
#
#         marker_56086d8a1df9547115c7d013c12de8f3.bindPopup(popup_e122683f9f99953933756697436d1bd8)
#         ;
#
#
#
#
#             var marker_92b2d3f0e539ac527424886474900072 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ce264dd0aba383624406b244dba40327);
#
#
#         var popup_a38619d93255c9d9a709e0a71052a484 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa64ba7878c7929153fdfb30b26a7ed0 = $(`&lt;div id=&quot;html_fa64ba7878c7929153fdfb30b26a7ed0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a38619d93255c9d9a709e0a71052a484.setContent(html_fa64ba7878c7929153fdfb30b26a7ed0);
#
#
#
#         marker_92b2d3f0e539ac527424886474900072.bindPopup(popup_a38619d93255c9d9a709e0a71052a484)
#         ;
#
#
#
#
#             var marker_26d43e852468561f7bc609dc656a569c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ce264dd0aba383624406b244dba40327);
#
#
#         var popup_fd71f6e898e15445605e99da4aa28031 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfb83b40a5e638c45b6d4413781c8143 = $(`&lt;div id=&quot;html_cfb83b40a5e638c45b6d4413781c8143&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fd71f6e898e15445605e99da4aa28031.setContent(html_cfb83b40a5e638c45b6d4413781c8143);
#
#
#
#         marker_26d43e852468561f7bc609dc656a569c.bindPopup(popup_fd71f6e898e15445605e99da4aa28031)
#         ;
#
#
#
#
#             var marker_618673672f

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_035fd719fa01c6666c5c2db6bd0de22c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_035fd719fa01c6666c5c2db6bd0de22c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_035fd719fa01c6666c5c2db6bd0de22c = L.map(
#                 &quot;map_035fd719fa01c6666c5c2db6bd0de22c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_317cd887f3746770d9641021abef5b8a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_317cd887f3746770d9641021abef5b8a.addTo(map_035fd719fa01c6666c5c2db6bd0de22c);
#
#
#             var feature_group_99491d7ebee17e57cdddb263d820009b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_aaf86e3b7437bfe62d2b1a37bedd70d3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_99491d7ebee17e57cdddb263d820009b);
#
#
#         var popup_55d7b7e7649b2d9b5f9caf99e3050eb6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_085114691b4cd4ac6eb3d78b12e9ecc8 = $(`&lt;div id=&quot;html_085114691b4cd4ac6eb3d78b12e9ecc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_55d7b7e7649b2d9b5f9caf99e3050eb6.setContent(html_085114691b4cd4ac6eb3d78b12e9ecc8);
#
#
#
#         marker_aaf86e3b7437bfe62d2b1a37bedd70d3.bindPopup(popup_55d7b7e7649b2d9b5f9caf99e3050eb6)
#         ;
#
#
#
#
#             var marker_d2719d03eaa64afec101e50251e65bf2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_99491d7ebee17e57cdddb263d820009b);
#
#
#         var popup_b4700a67750c23fd342d765720d1d405 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbbd5f6ef05787725f087e17e1fcee4a = $(`&lt;div id=&quot;html_bbbd5f6ef05787725f087e17e1fcee4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_b4700a67750c23fd342d765720d1d405.setContent(html_bbbd5f6ef05787725f087e17e1fcee4a);
#
#
#
#         marker_d2719d03eaa64afec101e50251e65bf2.bindPopup(popup_b4700a67750c23fd342d765720d1d405)
#         ;
#
#
#
#
#             var marker_923b63338441e00986b4430bd3d9d870 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_99491d7ebee17e57cdddb263d820009b);
#
#
#         var popup_d27cd0f260ea7f758079fdb85f74644e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4a0ae754cbae5060597f54a001b9c79 = $(`&lt;div id=&quot;html_b4a0ae754cbae5060597f54a001b9c79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d27cd0f260ea7f758079fdb85f74644e.setContent(html_b4a0ae754cbae5060597f54a001b9c79);
#
#
#
#         marker_923b63338441e00986b4430bd3d9d870.bindPopup(popup_d27cd0f260ea7f758079fdb85f74644e)
#         ;
#
#
#
#
#             var marker_96ee6dbd971529bf5cfa62270446862d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_99491d7ebee17e57cdddb263d820009b);
#
#
#         var popup_bc89779ceaebf29c7cb1d472a8ec292d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc2d2c937a7318f1ee065acadad29d14 = $(`&lt;div id=&quot;html_cc2d2c937a7318f1ee065acadad29d14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_bc89779ceaebf29c7cb1d472a8ec292d.setContent(html_cc2d2c937a7318f1ee065acadad29d14);
#
#
#
#         marker_96ee6dbd971529bf5cfa62270446862d.bindPopup(popup_bc89779ceaebf29c7cb1d472a8ec292d)
#         ;
#
#
#
#
#             var marker_6ef1be802cd92da0ff3d96e30a5a6ac4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_99491d7ebee17e57cdddb263d820009b);
#
#
#         var popup_328c3fcc8923148d6a2dabd24a244072 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82d90a0f2811d60d3b027897d9735172 = $(`&lt;div id=&quot;html_82d90a0f2811d60d3b027897d9735172&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_328c3fcc8923148d6a

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_761ceca174595d9c8604f5d6b24682d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_761ceca174595d9c8604f5d6b24682d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_761ceca174595d9c8604f5d6b24682d8 = L.map(
#                 &quot;map_761ceca174595d9c8604f5d6b24682d8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_64a5aac1fe9eebc54b6b74c72951e35f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_64a5aac1fe9eebc54b6b74c72951e35f.addTo(map_761ceca174595d9c8604f5d6b24682d8);
#
#
#             var feature_group_45051059f63e2011fb256c0a626c2537 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_45051059f63e2011fb256c0a626c2537.addTo(map_761ceca174595d9c8604f5d6b24682d8);
#
#
#             var feature_group_sub_group_5f8d759b7fee16f20e0d57fd3eb70eda = L.featureGroup.subGroup(
#                 feature_group_45051059f63e2011fb256c0a626c2537
#             );
#
#
#             var marker_21f923774ab03262a93d1969ffc13912 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f8d759b7fee16f20e0d57fd3eb70eda);
#
#
#         var popup_a18e6bb9e210f2381bf95c9d28478d1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd8b436275d6e2cf2e51f7406c3433e2 = $(`&lt;div id=&quot;html_bd8b436275d6e2cf2e51f7406c3433e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a18e6bb9e210f2381bf95c9d28478d1c.setContent(html_bd8b436275d6e2cf2e51f7406c3433e2);
#
#
#
#         marker_21f923774ab03262a93d1969ffc13912.bindPopup(popup_a18e6bb9e210f2381bf95c9d28478d1c)
#         ;
#
#
#
#
#             var marker_24360e5ec36d8bec96f0c570af217727 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f8d759b7fee16f20e0d57fd3eb70eda);
#
#
#         var popup_a8b8b44b6cfe4b08e33f7478b6f78c60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b07a37adbcafcaeeea1b5c57f9f03c8 = $(`&lt;div id=&quot;html_2b07a37adbcafcaeeea1b5c57f9f03c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a8b8b44b6cfe4b08e33f7478b6f78c60.setContent(html_2b07a37adbcafcaeeea1b5c57f9f03c8);
#
#
#
#         marker_24360e5ec36d8bec96f0c570af217727.bindPopup(popup_a8b8b44b6cfe4b08e33f7478b6f78c60)
#         ;
#
#
#
#
#             var marker_e5aacdae1c984f38d73899f9e459f97d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f8d759b7fee16f20e0d57fd3eb70eda);
#
#
#         var popup_09baf76aa621040059dba55dae078e49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fb4b11c7d988729224b2a3068715349 = $(`&lt;div id=&quot;html_8fb4b11c7d988729224b2a3068715349&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_09baf76aa621040059dba55dae078e49.setContent(html_8fb4b11c7d988729224b2a3068715349);
#
#
#
#         marker_e5aacdae1c984f38d73899f9e459f97d.bindPopup(popup_09baf76aa621040059dba55dae078e49)
#         ;
#
#
#
#
#             var marker_522a3e68601fd8d9e6b5ae77829ee212 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5f8d759b7fee16f20e0d57fd3eb70eda);
#
#
#         var popup_a737eb21e931aaf16de3f5f84c2ec827 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_db77f7f548165b34f6885b870486c227 = $(`&lt;div id=&quot;html_db77f7f548165b34f6885b870486c227&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a737eb21e931aaf16de3f5f84c2ec827.setContent(html_db77f7f548165b34f6885b870486c227);
#
#
#
#         marker_522a3e68601fd8d9e6b5ae77829ee212.bindPopup(popup_a737eb21e931aaf16de3f5f84c2ec827)
#         ;
#
#
#
#
#             var marker_cc155711f7654d9e1adb7eaeb75e617c = L.marker(
#                 [45.050399999999996, 3.0504],
