# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51245fdbee0cce59652322461f78dec6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51245fdbee0cce59652322461f78dec6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51245fdbee0cce59652322461f78dec6 = L.map(
#                 &quot;map_51245fdbee0cce59652322461f78dec6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0ea3b97c8f2791a4d891a8eaaa1df54e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0ea3b97c8f2791a4d891a8eaaa1df54e.addTo(map_51245fdbee0cce59652322461f78dec6);
#
#
#             var marker_0facdef023eee95115f2ac3bcc2a38cf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_51245fdbee0cce59652322461f78dec6);
#
#
#         var popup_e2f67da379de0e97de8828590b6d76f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06103840f27791f0ca5e098ad80e21e8 = $(`&lt;div id=&quot;html_06103840f27791f0ca5e098ad80e21e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e2f67da379de0e97de8828590b6d76f7.setContent(html_06103840f27791f0ca5e098ad80e21e8);
#
#
#
#         marker_0facdef023eee95115f2ac3bcc2a38cf.bindPopup(popup_e2f67da379de0e97de8828590b6d76f7)
#         ;
#
#
#
#
#             var marker_e481ffa67d24df766f774cc085fd4414 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_51245fdbee0cce59652322461f78dec6);
#
#
#         var popup_b910fc931f1b6439427796d5d392f220 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08ff752f836b3d95fa80ec63105afbe8 = $(`&lt;div id=&quot;html_08ff752f836b3d95fa80ec63105afbe8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b910fc931f1b6439427796d5d392f220.setContent(html_08ff752f836b3d95fa80ec63105afbe8);
#
#
#
#         marker_e481ffa67d24df766f774cc085fd4414.bindPopup(popup_b910fc931f1b6439427796d5d392f220)
#         ;
#
#
#
#
#             var marker_f5a329953ec2a6ff204b5c39fa0da1c7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_51245fdbee0cce59652322461f78dec6);
#
#
#         var popup_369134fac4894dc3e6da3f54c95f8962 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e9cff9205a7a62a5a2b39339cd15c6d = $(`&lt;div id=&quot;html_0e9cff9205a7a62a5a2b39339cd15c6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_369134fac4894dc3e6da3f54c95f8962.setContent(html_0e9cff9205a7a62a5a2b39339cd15c6d);
#
#
#
#         marker_f5a329953ec2a6ff204b5c39fa0da1c7.bindPopup(popup_369134fac4894dc3e6da3f54c95f8962)
#         ;
#
#
#
#
#             var marker_28df2dcfc9d3f7cce425a0d011ddd4c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_51245fdbee0cce59652322461f78dec6);
#
#
#         var popup_124d81d6d71fe1f3e349f7339dbfa23e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b10044b67682ea904881efebd60c628b = $(`&lt;div id=&quot;html_b10044b67682ea904881efebd60c628b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_124d81d6d71fe1f3e349f7339dbfa23e.setContent(html_b10044b67682ea904881efebd60c628b);
#
#
#
#         marker_28df2dcfc9d3f7cce425a0d011ddd4c0.bindPopup(popup_124d81d6d71fe1f3e349f7339dbfa23e)
#         ;
#
#
#
#
#             var marker_fffac487bccfc415850fbef952b199a7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_51245fdbee0cce59652322461f78dec6);
#
#
#         var popup_264e43e235713cf1885ffb7d15aca3ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b53c7a96432eee8085fb3254d1821e2e = $(`&lt;div id=&quot;html_b53c7a96432eee8085fb3254d1821e2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_264e43e235713cf1885ffb7d15aca3ef.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_41449f26639056306bc78095176befd5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_41449f26639056306bc78095176befd5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_41449f26639056306bc78095176befd5 = L.map(
#                 &quot;map_41449f26639056306bc78095176befd5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec3e1cee1f87f5d6737253c3549fe8ed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec3e1cee1f87f5d6737253c3549fe8ed.addTo(map_41449f26639056306bc78095176befd5);
#
#
#             var feature_group_b8eaaa4f146b2a4a1b63bca7b944f297 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3a39b01ded9549a6ebbd32d1a404a37b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b8eaaa4f146b2a4a1b63bca7b944f297);
#
#
#         var popup_dbaa175785469133acc51b32c2f37946 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83a0aaf5cad2fedcabbfa291737b29da = $(`&lt;div id=&quot;html_83a0aaf5cad2fedcabbfa291737b29da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dbaa175785469133acc51b32c2f37946.setContent(html_83a0aaf5cad2fedcabbfa291737b29da);
#
#
#
#         marker_3a39b01ded9549a6ebbd32d1a404a37b.bindPopup(popup_dbaa175785469133acc51b32c2f37946)
#         ;
#
#
#
#
#             var marker_e0d93a1023ee2a4f6eade22e67b19508 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b8eaaa4f146b2a4a1b63bca7b944f297);
#
#
#         var popup_ac25d435375ca487311bef93f4a01a0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34adfd15d41159729bca7bb3e0bc5753 = $(`&lt;div id=&quot;html_34adfd15d41159729bca7bb3e0bc5753&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ac25d435375ca487311bef93f4a01a0a.setContent(html_34adfd15d41159729bca7bb3e0bc5753);
#
#
#
#         marker_e0d93a1023ee2a4f6eade22e67b19508.bindPopup(popup_ac25d435375ca487311bef93f4a01a0a)
#         ;
#
#
#
#
#             var marker_4f7cf1c17c24f9aef2a414b54d8d3841 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b8eaaa4f146b2a4a1b63bca7b944f297);
#
#
#         var popup_19635b1f6014098604aabcae0be4c5e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc6233381373c66ee35553c70baac350 = $(`&lt;div id=&quot;html_bc6233381373c66ee35553c70baac350&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_19635b1f6014098604aabcae0be4c5e2.setContent(html_bc6233381373c66ee35553c70baac350);
#
#
#
#         marker_4f7cf1c17c24f9aef2a414b54d8d3841.bindPopup(popup_19635b1f6014098604aabcae0be4c5e2)
#         ;
#
#
#
#
#             var marker_9ae0304e18aa3c6b5147d59d31780e1a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b8eaaa4f146b2a4a1b63bca7b944f297);
#
#
#         var popup_6d070bbf84e17a6b4e04877364eb4045 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cda66c8a103b3d19a5200772a865a0e8 = $(`&lt;div id=&quot;html_cda66c8a103b3d19a5200772a865a0e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6d070bbf84e17a6b4e04877364eb4045.setContent(html_cda66c8a103b3d19a5200772a865a0e8);
#
#
#
#         marker_9ae0304e18aa3c6b5147d59d31780e1a.bindPopup(popup_6d070bbf84e17a6b4e04877364eb4045)
#         ;
#
#
#
#
#             var marker_10ec4410e46adbfb1b27b7e5a764d832 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b8eaaa4f146b2a4a1b63bca7b944f297);
#
#
#         var popup_8ac61bfc3c22bee0b361f9b12613c421 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01872252d9f819c78e0711b86e344f8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01872252d9f819c78e0711b86e344f8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01872252d9f819c78e0711b86e344f8a = L.map(
#                 &quot;map_01872252d9f819c78e0711b86e344f8a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_55011ba633d0f7b3b333eba4f8c2da55 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_55011ba633d0f7b3b333eba4f8c2da55.addTo(map_01872252d9f819c78e0711b86e344f8a);
#
#
#             var feature_group_510b3efa46bcae8d6ea8ded76fc3aa99 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_510b3efa46bcae8d6ea8ded76fc3aa99.addTo(map_01872252d9f819c78e0711b86e344f8a);
#
#
#             var feature_group_sub_group_073f2e1851630045b1945204cfdc5f92 = L.featureGroup.subGroup(
#                 feature_group_510b3efa46bcae8d6ea8ded76fc3aa99
#             );
#
#
#             var marker_507fc55100e211af8261b48e300dfaed = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_073f2e1851630045b1945204cfdc5f92);
#
#
#         var popup_4988297664c4ac58ac8f68bd7ad0f2ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_315b13153643cd3ed7c401105104d929 = $(`&lt;div id=&quot;html_315b13153643cd3ed7c401105104d929&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4988297664c4ac58ac8f68bd7ad0f2ce.setContent(html_315b13153643cd3ed7c401105104d929);
#
#
#
#         marker_507fc55100e211af8261b48e300dfaed.bindPopup(popup_4988297664c4ac58ac8f68bd7ad0f2ce)
#         ;
#
#
#
#
#             var marker_c59e9445a91cc44b25ee5986d9e7082f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_073f2e1851630045b1945204cfdc5f92);
#
#
#         var popup_b4678b5fe0d28d0e5ea58dff6df6b71a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d5c7007e1ee49c2d0e23310651d88a8 = $(`&lt;div id=&quot;html_1d5c7007e1ee49c2d0e23310651d88a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_b4678b5fe0d28d0e5ea58dff6df6b71a.setContent(html_1d5c7007e1ee49c2d0e23310651d88a8);
#
#
#
#         marker_c59e9445a91cc44b25ee5986d9e7082f.bindPopup(popup_b4678b5fe0d28d0e5ea58dff6df6b71a)
#         ;
#
#
#
#
#             var marker_5271d83fc87070597b0e252923f09eaf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_073f2e1851630045b1945204cfdc5f92);
#
#
#         var popup_f7a91e5fedca68adb5f92d68e01ea7ba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc4c5751780d641e9f1e4bc89a05ca45 = $(`&lt;div id=&quot;html_bc4c5751780d641e9f1e4bc89a05ca45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f7a91e5fedca68adb5f92d68e01ea7ba.setContent(html_bc4c5751780d641e9f1e4bc89a05ca45);
#
#
#
#         marker_5271d83fc87070597b0e252923f09eaf.bindPopup(popup_f7a91e5fedca68adb5f92d68e01ea7ba)
#         ;
#
#
#
#
#             var marker_b2f1fa782d87747ae3757b7aeb1125f0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_073f2e1851630045b1945204cfdc5f92);
#
#
#         var popup_0b999debd89e7ac8399c3aa259d70e33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8795341d56df92534eb996140a2e8004 = $(`&lt;div id=&quot;html_8795341d56df92534eb996140a2e8004&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0b999debd89e7ac8399c3aa259d70e33.setContent(html_8795341d56df92534eb996140a2e8004);
#
#
#
#         marker_
