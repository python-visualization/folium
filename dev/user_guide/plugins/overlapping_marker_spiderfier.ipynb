# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_61cc8c0de155c1e092bd39fd41b4dbc1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_61cc8c0de155c1e092bd39fd41b4dbc1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_61cc8c0de155c1e092bd39fd41b4dbc1 = L.map(
#                 &quot;map_61cc8c0de155c1e092bd39fd41b4dbc1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5553e14dfe72693c6fae7c5efca2bed6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5553e14dfe72693c6fae7c5efca2bed6.addTo(map_61cc8c0de155c1e092bd39fd41b4dbc1);
#
#
#             var marker_be6691e6e0562489ceb68f63df5bd400 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_61cc8c0de155c1e092bd39fd41b4dbc1);
#
#
#         var popup_84cd07c6ee28e07083ac599b2183d4b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4e5e3c20cad0d66632a28721db5b21d = $(`&lt;div id=&quot;html_e4e5e3c20cad0d66632a28721db5b21d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_84cd07c6ee28e07083ac599b2183d4b4.setContent(html_e4e5e3c20cad0d66632a28721db5b21d);
#
#
#
#         marker_be6691e6e0562489ceb68f63df5bd400.bindPopup(popup_84cd07c6ee28e07083ac599b2183d4b4)
#         ;
#
#
#
#
#             var marker_dca56dd97b76737aa8588afd879eb179 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_61cc8c0de155c1e092bd39fd41b4dbc1);
#
#
#         var popup_2cf6eadff85c6b70705db54ba85a19ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_947622ce48ba654a8fcf2caedee7447b = $(`&lt;div id=&quot;html_947622ce48ba654a8fcf2caedee7447b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2cf6eadff85c6b70705db54ba85a19ae.setContent(html_947622ce48ba654a8fcf2caedee7447b);
#
#
#
#         marker_dca56dd97b76737aa8588afd879eb179.bindPopup(popup_2cf6eadff85c6b70705db54ba85a19ae)
#         ;
#
#
#
#
#             var marker_2a032ee2424b65f3a7b06d932f2d1dbe = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_61cc8c0de155c1e092bd39fd41b4dbc1);
#
#
#         var popup_42eb51bf2a746dc8700834731b3c23a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4f23893311cda7e2c7ffbb7ee36af71 = $(`&lt;div id=&quot;html_a4f23893311cda7e2c7ffbb7ee36af71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_42eb51bf2a746dc8700834731b3c23a9.setContent(html_a4f23893311cda7e2c7ffbb7ee36af71);
#
#
#
#         marker_2a032ee2424b65f3a7b06d932f2d1dbe.bindPopup(popup_42eb51bf2a746dc8700834731b3c23a9)
#         ;
#
#
#
#
#             var marker_7f9649d0a50a84746d385420fd398544 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_61cc8c0de155c1e092bd39fd41b4dbc1);
#
#
#         var popup_8b322a3e8a77af7e43c04e2532aebeed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e4190285895a6464ae90e8fecd92f81 = $(`&lt;div id=&quot;html_4e4190285895a6464ae90e8fecd92f81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8b322a3e8a77af7e43c04e2532aebeed.setContent(html_4e4190285895a6464ae90e8fecd92f81);
#
#
#
#         marker_7f9649d0a50a84746d385420fd398544.bindPopup(popup_8b322a3e8a77af7e43c04e2532aebeed)
#         ;
#
#
#
#
#             var marker_137c645e5603d2eb253468f502e15bff = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_61cc8c0de155c1e092bd39fd41b4dbc1);
#
#
#         var popup_9d39fbabe6c75cdfc92e7436931ccc00 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d60ab8f804c2b4902090bb22254a1c4 = $(`&lt;div id=&quot;html_3d60ab8f804c2b4902090bb22254a1c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9d39fbabe6c75cdfc92e7436931ccc00.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9520f368473335978276a7409de0d462 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9520f368473335978276a7409de0d462&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9520f368473335978276a7409de0d462 = L.map(
#                 &quot;map_9520f368473335978276a7409de0d462&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c63508952596a3f0f25e44925903a47 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c63508952596a3f0f25e44925903a47.addTo(map_9520f368473335978276a7409de0d462);
#
#
#             var feature_group_fd4ea2695ced0a0c6a39788b62cda39b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3cdbaa51eff45f260561d9570325a0b9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fd4ea2695ced0a0c6a39788b62cda39b);
#
#
#         var popup_85ea9e02a1ec39344e73b99488cd9006 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f32b11af4a2370d2c357b8637b423316 = $(`&lt;div id=&quot;html_f32b11af4a2370d2c357b8637b423316&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_85ea9e02a1ec39344e73b99488cd9006.setContent(html_f32b11af4a2370d2c357b8637b423316);
#
#
#
#         marker_3cdbaa51eff45f260561d9570325a0b9.bindPopup(popup_85ea9e02a1ec39344e73b99488cd9006)
#         ;
#
#
#
#
#             var marker_4a1b1735142d84da5ec3138af7e6d39a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fd4ea2695ced0a0c6a39788b62cda39b);
#
#
#         var popup_ca256fcf24a37faf29dd157d21bab0d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b18f110d2aa4d06c40fdeb60413e6d4d = $(`&lt;div id=&quot;html_b18f110d2aa4d06c40fdeb60413e6d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ca256fcf24a37faf29dd157d21bab0d6.setContent(html_b18f110d2aa4d06c40fdeb60413e6d4d);
#
#
#
#         marker_4a1b1735142d84da5ec3138af7e6d39a.bindPopup(popup_ca256fcf24a37faf29dd157d21bab0d6)
#         ;
#
#
#
#
#             var marker_b438dc2c43fa1d8e6406538c33ebe9b3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fd4ea2695ced0a0c6a39788b62cda39b);
#
#
#         var popup_16e151bfb55ddf770ea9721d84f2d202 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1be6595f625aa52d94a6b5349860efb4 = $(`&lt;div id=&quot;html_1be6595f625aa52d94a6b5349860efb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_16e151bfb55ddf770ea9721d84f2d202.setContent(html_1be6595f625aa52d94a6b5349860efb4);
#
#
#
#         marker_b438dc2c43fa1d8e6406538c33ebe9b3.bindPopup(popup_16e151bfb55ddf770ea9721d84f2d202)
#         ;
#
#
#
#
#             var marker_85e018134c84652917ddcad0cbd702ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fd4ea2695ced0a0c6a39788b62cda39b);
#
#
#         var popup_0989871b334124d2f6b804cc659a54ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69a35ad99214d4533e5e7bbe017f2bb6 = $(`&lt;div id=&quot;html_69a35ad99214d4533e5e7bbe017f2bb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0989871b334124d2f6b804cc659a54ed.setContent(html_69a35ad99214d4533e5e7bbe017f2bb6);
#
#
#
#         marker_85e018134c84652917ddcad0cbd702ed.bindPopup(popup_0989871b334124d2f6b804cc659a54ed)
#         ;
#
#
#
#
#             var marker_95e9a291e8c615e6fcb9cd93256401dd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fd4ea2695ced0a0c6a39788b62cda39b);
#
#
#         var popup_f393f321ff7235c6c6ca3a71218bcee7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e238a9d2d66a5cfec23046d03195a2db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e238a9d2d66a5cfec23046d03195a2db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e238a9d2d66a5cfec23046d03195a2db = L.map(
#                 &quot;map_e238a9d2d66a5cfec23046d03195a2db&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d6bdf0b786acf7e8146745cc5ad76f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2d6bdf0b786acf7e8146745cc5ad76f1.addTo(map_e238a9d2d66a5cfec23046d03195a2db);
#
#
#             var feature_group_a2e83a8732df9b46af54d0d2b10261f6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a2e83a8732df9b46af54d0d2b10261f6.addTo(map_e238a9d2d66a5cfec23046d03195a2db);
#
#
#             var feature_group_sub_group_07d30fabda6145cfd46af5e0eb5241b7 = L.featureGroup.subGroup(
#                 feature_group_a2e83a8732df9b46af54d0d2b10261f6
#             );
#
#
#             var marker_ffc3043f21f0ab24e24fcecf8ea37c33 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_07d30fabda6145cfd46af5e0eb5241b7);
#
#
#         var popup_b57f2930f75d646686f691252c917664 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ea682c423a9ec33e5fb1079e498d3b45 = $(`&lt;div id=&quot;html_ea682c423a9ec33e5fb1079e498d3b45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b57f2930f75d646686f691252c917664.setContent(html_ea682c423a9ec33e5fb1079e498d3b45);
#
#
#
#         marker_ffc3043f21f0ab24e24fcecf8ea37c33.bindPopup(popup_b57f2930f75d646686f691252c917664)
#         ;
#
#
#
#
#             var marker_98fe1b46c00f6b5a51967bc96b3755de = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_07d30fabda6145cfd46af5e0eb5241b7);
#
#
#         var popup_afc11125e010f766fb76d8f3f45f76f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86b1838a821d47a41cb3338ff625408d = $(`&lt;div id=&quot;html_86b1838a821d47a41cb3338ff625408d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_afc11125e010f766fb76d8f3f45f76f5.setContent(html_86b1838a821d47a41cb3338ff625408d);
#
#
#
#         marker_98fe1b46c00f6b5a51967bc96b3755de.bindPopup(popup_afc11125e010f766fb76d8f3f45f76f5)
#         ;
#
#
#
#
#             var marker_28aa751148260c826cc2ba74b6bbd953 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_07d30fabda6145cfd46af5e0eb5241b7);
#
#
#         var popup_09b2eb1994692044fd97f8d3827a67d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5b781016c7c191f54791e2ec52cf4e2 = $(`&lt;div id=&quot;html_e5b781016c7c191f54791e2ec52cf4e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_09b2eb1994692044fd97f8d3827a67d8.setContent(html_e5b781016c7c191f54791e2ec52cf4e2);
#
#
#
#         marker_28aa751148260c826cc2ba74b6bbd953.bindPopup(popup_09b2eb1994692044fd97f8d3827a67d8)
#         ;
#
#
#
#
#             var marker_1e0b174431886be9a2056f4d7a1b33e1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_07d30fabda6145cfd46af5e0eb5241b7);
#
#
#         var popup_15775ce411c38018675b14949287b949 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57efe115888ff0bd9713470420a80f72 = $(`&lt;div id=&quot;html_57efe115888ff0bd9713470420a80f72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_15775ce411c38018675b14949287b949.setContent(html_57efe115888ff0bd9713470420a80f72);
#
#
#
#         marker_
