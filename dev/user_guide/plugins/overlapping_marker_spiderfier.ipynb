# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2b4caabbb7ef9df668b36d359c46b5cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2b4caabbb7ef9df668b36d359c46b5cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2b4caabbb7ef9df668b36d359c46b5cc = L.map(
#                 &quot;map_2b4caabbb7ef9df668b36d359c46b5cc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_27c065c5d452d96d2047eda73d987cae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_27c065c5d452d96d2047eda73d987cae.addTo(map_2b4caabbb7ef9df668b36d359c46b5cc);
#
#
#             var marker_e51dbd83072bd595e97eaf03068a3002 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2b4caabbb7ef9df668b36d359c46b5cc);
#
#
#         var popup_b174563f5d79d4223c0b4d61020174f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_764b91214dac562c90d8dbf4f1cbd568 = $(`&lt;div id=&quot;html_764b91214dac562c90d8dbf4f1cbd568&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b174563f5d79d4223c0b4d61020174f6.setContent(html_764b91214dac562c90d8dbf4f1cbd568);
#
#
#
#         marker_e51dbd83072bd595e97eaf03068a3002.bindPopup(popup_b174563f5d79d4223c0b4d61020174f6)
#         ;
#
#
#
#
#             var marker_16802380369000a5c0bf53c71b896028 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2b4caabbb7ef9df668b36d359c46b5cc);
#
#
#         var popup_381522985d646fa85e93522cc044a5d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fda127db5a08146388dc09c2390b5d95 = $(`&lt;div id=&quot;html_fda127db5a08146388dc09c2390b5d95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_381522985d646fa85e93522cc044a5d8.setContent(html_fda127db5a08146388dc09c2390b5d95);
#
#
#
#         marker_16802380369000a5c0bf53c71b896028.bindPopup(popup_381522985d646fa85e93522cc044a5d8)
#         ;
#
#
#
#
#             var marker_f00039cf86a772810038a3c865110d66 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2b4caabbb7ef9df668b36d359c46b5cc);
#
#
#         var popup_935a1d20398c04e05ff40e7ae0cb56fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_572f022341c767bf63c9547860a659f2 = $(`&lt;div id=&quot;html_572f022341c767bf63c9547860a659f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_935a1d20398c04e05ff40e7ae0cb56fc.setContent(html_572f022341c767bf63c9547860a659f2);
#
#
#
#         marker_f00039cf86a772810038a3c865110d66.bindPopup(popup_935a1d20398c04e05ff40e7ae0cb56fc)
#         ;
#
#
#
#
#             var marker_ebeb30af249e02a149f16d2ccb446476 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2b4caabbb7ef9df668b36d359c46b5cc);
#
#
#         var popup_335a4f2e23138d12d50d0b619d304081 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bea98063a32f7546eef269fe9d625746 = $(`&lt;div id=&quot;html_bea98063a32f7546eef269fe9d625746&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_335a4f2e23138d12d50d0b619d304081.setContent(html_bea98063a32f7546eef269fe9d625746);
#
#
#
#         marker_ebeb30af249e02a149f16d2ccb446476.bindPopup(popup_335a4f2e23138d12d50d0b619d304081)
#         ;
#
#
#
#
#             var marker_e7ac3c972cdcbbe246b822f01e3e4850 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2b4caabbb7ef9df668b36d359c46b5cc);
#
#
#         var popup_b07860049c182d814613fd51e9efcb08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adfe0f4c50e7a9a53ebb255eb362e21d = $(`&lt;div id=&quot;html_adfe0f4c50e7a9a53ebb255eb362e21d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_b07860049c182d814613fd51e9efcb08.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a7618e55e885befb8f5e7c067ac5f23e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a7618e55e885befb8f5e7c067ac5f23e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a7618e55e885befb8f5e7c067ac5f23e = L.map(
#                 &quot;map_a7618e55e885befb8f5e7c067ac5f23e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f18a7c85c583c47003536d593eae072 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f18a7c85c583c47003536d593eae072.addTo(map_a7618e55e885befb8f5e7c067ac5f23e);
#
#
#             var feature_group_4103495fa533dd723921919dbbb9858a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_deda4f9f860efb6a41057c8e5275f306 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4103495fa533dd723921919dbbb9858a);
#
#
#         var popup_d3fa0da510c96b4c408e93fe0fd5221e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a1d0bf1fc67b8bd2bfef6205c837ff5 = $(`&lt;div id=&quot;html_4a1d0bf1fc67b8bd2bfef6205c837ff5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d3fa0da510c96b4c408e93fe0fd5221e.setContent(html_4a1d0bf1fc67b8bd2bfef6205c837ff5);
#
#
#
#         marker_deda4f9f860efb6a41057c8e5275f306.bindPopup(popup_d3fa0da510c96b4c408e93fe0fd5221e)
#         ;
#
#
#
#
#             var marker_4d4e739dc69b6c0ed77d8f0b7e100c82 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4103495fa533dd723921919dbbb9858a);
#
#
#         var popup_66af12d51c38409eea09b9569319592a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_876c5c1fa77a6e6b98d7075d202dba53 = $(`&lt;div id=&quot;html_876c5c1fa77a6e6b98d7075d202dba53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_66af12d51c38409eea09b9569319592a.setContent(html_876c5c1fa77a6e6b98d7075d202dba53);
#
#
#
#         marker_4d4e739dc69b6c0ed77d8f0b7e100c82.bindPopup(popup_66af12d51c38409eea09b9569319592a)
#         ;
#
#
#
#
#             var marker_2b55e3735432c1329e18006e6ff97f78 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4103495fa533dd723921919dbbb9858a);
#
#
#         var popup_31cef9b0444427638ebd133e8f221402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddceb229154119378d81e88d61ed0e2f = $(`&lt;div id=&quot;html_ddceb229154119378d81e88d61ed0e2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_31cef9b0444427638ebd133e8f221402.setContent(html_ddceb229154119378d81e88d61ed0e2f);
#
#
#
#         marker_2b55e3735432c1329e18006e6ff97f78.bindPopup(popup_31cef9b0444427638ebd133e8f221402)
#         ;
#
#
#
#
#             var marker_c106a5c3f6c0b19ebd93238b2031b030 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4103495fa533dd723921919dbbb9858a);
#
#
#         var popup_a2b15b78354318a5e60904c13d38ad10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c012c5e37365b1bdd33a1d98973b864a = $(`&lt;div id=&quot;html_c012c5e37365b1bdd33a1d98973b864a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a2b15b78354318a5e60904c13d38ad10.setContent(html_c012c5e37365b1bdd33a1d98973b864a);
#
#
#
#         marker_c106a5c3f6c0b19ebd93238b2031b030.bindPopup(popup_a2b15b78354318a5e60904c13d38ad10)
#         ;
#
#
#
#
#             var marker_5b78b3eac1117884a50c05fd74d65e15 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4103495fa533dd723921919dbbb9858a);
#
#
#         var popup_846359722426f0f3003184d7053bcd8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67ea0e9a6d78ae943305515bbb5fdeec {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67ea0e9a6d78ae943305515bbb5fdeec&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67ea0e9a6d78ae943305515bbb5fdeec = L.map(
#                 &quot;map_67ea0e9a6d78ae943305515bbb5fdeec&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15a5ceb0534cd44247645d573998db82 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_15a5ceb0534cd44247645d573998db82.addTo(map_67ea0e9a6d78ae943305515bbb5fdeec);
#
#
#             var feature_group_07201ac6fe959befb24075afab774a11 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_07201ac6fe959befb24075afab774a11.addTo(map_67ea0e9a6d78ae943305515bbb5fdeec);
#
#
#             var feature_group_sub_group_79999d6e509d99308ed450093cfa8281 = L.featureGroup.subGroup(
#                 feature_group_07201ac6fe959befb24075afab774a11
#             );
#
#
#             var marker_2339b8a8fe9b1746c8018044252d201c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_79999d6e509d99308ed450093cfa8281);
#
#
#         var popup_0e7073341c6de2096be426a9547fb643 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e606f230ba9a4fcf13b023baf181e2f1 = $(`&lt;div id=&quot;html_e606f230ba9a4fcf13b023baf181e2f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0e7073341c6de2096be426a9547fb643.setContent(html_e606f230ba9a4fcf13b023baf181e2f1);
#
#
#
#         marker_2339b8a8fe9b1746c8018044252d201c.bindPopup(popup_0e7073341c6de2096be426a9547fb643)
#         ;
#
#
#
#
#             var marker_edb7c62c797c4e6504fb877179bbf0fb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_79999d6e509d99308ed450093cfa8281);
#
#
#         var popup_648581c82ee056a177763bf77963477c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b33d6a60300521f07571c0b8e09d0e6b = $(`&lt;div id=&quot;html_b33d6a60300521f07571c0b8e09d0e6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_648581c82ee056a177763bf77963477c.setContent(html_b33d6a60300521f07571c0b8e09d0e6b);
#
#
#
#         marker_edb7c62c797c4e6504fb877179bbf0fb.bindPopup(popup_648581c82ee056a177763bf77963477c)
#         ;
#
#
#
#
#             var marker_9519eeec198d9a7bc358913168b05b43 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_79999d6e509d99308ed450093cfa8281);
#
#
#         var popup_c751be803a2e3ecf47bc773914cd762c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4691850dfa30a73ad8ad90e4171c3636 = $(`&lt;div id=&quot;html_4691850dfa30a73ad8ad90e4171c3636&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c751be803a2e3ecf47bc773914cd762c.setContent(html_4691850dfa30a73ad8ad90e4171c3636);
#
#
#
#         marker_9519eeec198d9a7bc358913168b05b43.bindPopup(popup_c751be803a2e3ecf47bc773914cd762c)
#         ;
#
#
#
#
#             var marker_ccaaad45fc77d62cf684ff63813087c9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_79999d6e509d99308ed450093cfa8281);
#
#
#         var popup_e2afc0a3eb619107fc9d15a667a8907b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb554dadfef6d8810e36df5147aa5903 = $(`&lt;div id=&quot;html_bb554dadfef6d8810e36df5147aa5903&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e2afc0a3eb619107fc9d15a667a8907b.setContent(html_bb554dadfef6d8810e36df5147aa5903);
#
#
#
#         marker_
