# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fcda506ce5476c4b9c89a2efb60b32c9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fcda506ce5476c4b9c89a2efb60b32c9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fcda506ce5476c4b9c89a2efb60b32c9 = L.map(
#                 &quot;map_fcda506ce5476c4b9c89a2efb60b32c9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac98d48acd1e79bc5d8cce5e0c5dd25a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ac98d48acd1e79bc5d8cce5e0c5dd25a.addTo(map_fcda506ce5476c4b9c89a2efb60b32c9);
#
#
#             var marker_ddf72136b0d89661146e91cc76186fbd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fcda506ce5476c4b9c89a2efb60b32c9);
#
#
#         var popup_0aecbc671d49db3784d75ccce37f3e1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5168f8d588aafa02640c6a9eeefbce1 = $(`&lt;div id=&quot;html_a5168f8d588aafa02640c6a9eeefbce1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0aecbc671d49db3784d75ccce37f3e1b.setContent(html_a5168f8d588aafa02640c6a9eeefbce1);
#
#
#
#         marker_ddf72136b0d89661146e91cc76186fbd.bindPopup(popup_0aecbc671d49db3784d75ccce37f3e1b)
#         ;
#
#
#
#
#             var marker_e3210b637b484db6cfb253dad9f5551d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fcda506ce5476c4b9c89a2efb60b32c9);
#
#
#         var popup_89c23b8f7760abe7f37f285fd26b2523 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8883c1a6de53f24bcc49ba545d0afab1 = $(`&lt;div id=&quot;html_8883c1a6de53f24bcc49ba545d0afab1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_89c23b8f7760abe7f37f285fd26b2523.setContent(html_8883c1a6de53f24bcc49ba545d0afab1);
#
#
#
#         marker_e3210b637b484db6cfb253dad9f5551d.bindPopup(popup_89c23b8f7760abe7f37f285fd26b2523)
#         ;
#
#
#
#
#             var marker_e352e75741819405436edc231044fe21 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fcda506ce5476c4b9c89a2efb60b32c9);
#
#
#         var popup_abd2bbdfe76ee357ead3782ac5791efa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a1f98e1b8869c6b94f3414ad1336094 = $(`&lt;div id=&quot;html_4a1f98e1b8869c6b94f3414ad1336094&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_abd2bbdfe76ee357ead3782ac5791efa.setContent(html_4a1f98e1b8869c6b94f3414ad1336094);
#
#
#
#         marker_e352e75741819405436edc231044fe21.bindPopup(popup_abd2bbdfe76ee357ead3782ac5791efa)
#         ;
#
#
#
#
#             var marker_732ac568c1d7c84988d1589a8fb9834f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fcda506ce5476c4b9c89a2efb60b32c9);
#
#
#         var popup_73fc6905a508972b64d112de21bff467 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b52c7249784b36c5f5eb492619682bad = $(`&lt;div id=&quot;html_b52c7249784b36c5f5eb492619682bad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_73fc6905a508972b64d112de21bff467.setContent(html_b52c7249784b36c5f5eb492619682bad);
#
#
#
#         marker_732ac568c1d7c84988d1589a8fb9834f.bindPopup(popup_73fc6905a508972b64d112de21bff467)
#         ;
#
#
#
#
#             var marker_b4396739de4b8f7c707257d443792504 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fcda506ce5476c4b9c89a2efb60b32c9);
#
#
#         var popup_01525cd82200732e1d30761b0ece30e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3519cd78947815f595f4783f72d7533 = $(`&lt;div id=&quot;html_d3519cd78947815f595f4783f72d7533&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_01525cd82200732e1d30761b0ece30e0.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f15812bdd83d2a0931c536faabca856 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f15812bdd83d2a0931c536faabca856&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f15812bdd83d2a0931c536faabca856 = L.map(
#                 &quot;map_9f15812bdd83d2a0931c536faabca856&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbee41f30287dcb0403f5d755ca85c3c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbee41f30287dcb0403f5d755ca85c3c.addTo(map_9f15812bdd83d2a0931c536faabca856);
#
#
#             var feature_group_65d8d89dc8687b110451b2c05f0e7d92 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_906bc7f79e8fd5441a5bfa89b711e616 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_65d8d89dc8687b110451b2c05f0e7d92);
#
#
#         var popup_25493cb9367a40578952307aad2cd798 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d42567b76804323b4e381a8c6cd1c816 = $(`&lt;div id=&quot;html_d42567b76804323b4e381a8c6cd1c816&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_25493cb9367a40578952307aad2cd798.setContent(html_d42567b76804323b4e381a8c6cd1c816);
#
#
#
#         marker_906bc7f79e8fd5441a5bfa89b711e616.bindPopup(popup_25493cb9367a40578952307aad2cd798)
#         ;
#
#
#
#
#             var marker_5fe653686b05290f269fca0400d2402c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_65d8d89dc8687b110451b2c05f0e7d92);
#
#
#         var popup_dc02b6e2a73aaf1cb62d3406db561af9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_141d95f13bae9d9d4e465bb107567b1d = $(`&lt;div id=&quot;html_141d95f13bae9d9d4e465bb107567b1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dc02b6e2a73aaf1cb62d3406db561af9.setContent(html_141d95f13bae9d9d4e465bb107567b1d);
#
#
#
#         marker_5fe653686b05290f269fca0400d2402c.bindPopup(popup_dc02b6e2a73aaf1cb62d3406db561af9)
#         ;
#
#
#
#
#             var marker_b607b49af42e642e33e1fa2f12d9aeda = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_65d8d89dc8687b110451b2c05f0e7d92);
#
#
#         var popup_9be0961707aca92b99839060d3f38f1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2a246a427ada3a8b03523cd6e961180 = $(`&lt;div id=&quot;html_e2a246a427ada3a8b03523cd6e961180&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9be0961707aca92b99839060d3f38f1d.setContent(html_e2a246a427ada3a8b03523cd6e961180);
#
#
#
#         marker_b607b49af42e642e33e1fa2f12d9aeda.bindPopup(popup_9be0961707aca92b99839060d3f38f1d)
#         ;
#
#
#
#
#             var marker_b2c1fb4f26bced6670985a45b07db382 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_65d8d89dc8687b110451b2c05f0e7d92);
#
#
#         var popup_36b6f625d44533e92865b0409cc10355 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9be103e744bf7cc2d5cc3f9819a12c7d = $(`&lt;div id=&quot;html_9be103e744bf7cc2d5cc3f9819a12c7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_36b6f625d44533e92865b0409cc10355.setContent(html_9be103e744bf7cc2d5cc3f9819a12c7d);
#
#
#
#         marker_b2c1fb4f26bced6670985a45b07db382.bindPopup(popup_36b6f625d44533e92865b0409cc10355)
#         ;
#
#
#
#
#             var marker_064e308d3ee9a0c9fa5f6693346e7faa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_65d8d89dc8687b110451b2c05f0e7d92);
#
#
#         var popup_8ada6b4c6230e8638b5bba51ae272b6b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4787b7f2507daff68f215cc553240b42 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4787b7f2507daff68f215cc553240b42&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4787b7f2507daff68f215cc553240b42 = L.map(
#                 &quot;map_4787b7f2507daff68f215cc553240b42&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_670926007abf593529ec55bd2bb468cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_670926007abf593529ec55bd2bb468cd.addTo(map_4787b7f2507daff68f215cc553240b42);
#
#
#             var feature_group_302f618773de4e88e7cdddc656ae4377 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_302f618773de4e88e7cdddc656ae4377.addTo(map_4787b7f2507daff68f215cc553240b42);
#
#
#             var feature_group_sub_group_f72f983099fce5412d700be94c662e00 = L.featureGroup.subGroup(
#                 feature_group_302f618773de4e88e7cdddc656ae4377
#             );
#
#
#             var marker_d7e428a61bd212bc806ee226f42781d9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f72f983099fce5412d700be94c662e00);
#
#
#         var popup_24092b0223d655b3ae3cc7a73c480633 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67a11da6a0f87492b2b4202dfc1caf7a = $(`&lt;div id=&quot;html_67a11da6a0f87492b2b4202dfc1caf7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_24092b0223d655b3ae3cc7a73c480633.setContent(html_67a11da6a0f87492b2b4202dfc1caf7a);
#
#
#
#         marker_d7e428a61bd212bc806ee226f42781d9.bindPopup(popup_24092b0223d655b3ae3cc7a73c480633)
#         ;
#
#
#
#
#             var marker_b3b91edbceb5305c9d7499216d64ce0b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f72f983099fce5412d700be94c662e00);
#
#
#         var popup_42403cdd1a8fdff75057fc82334508d6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64ca608e03d60e9d8ef5661930e5bad4 = $(`&lt;div id=&quot;html_64ca608e03d60e9d8ef5661930e5bad4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_42403cdd1a8fdff75057fc82334508d6.setContent(html_64ca608e03d60e9d8ef5661930e5bad4);
#
#
#
#         marker_b3b91edbceb5305c9d7499216d64ce0b.bindPopup(popup_42403cdd1a8fdff75057fc82334508d6)
#         ;
#
#
#
#
#             var marker_ab89107f59499a90eca7ffa0484b11bc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f72f983099fce5412d700be94c662e00);
#
#
#         var popup_dc9776cb45feac2dec90fc913f53ddeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1a5c98375d80a3386b2ddbf1486d026 = $(`&lt;div id=&quot;html_d1a5c98375d80a3386b2ddbf1486d026&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_dc9776cb45feac2dec90fc913f53ddeb.setContent(html_d1a5c98375d80a3386b2ddbf1486d026);
#
#
#
#         marker_ab89107f59499a90eca7ffa0484b11bc.bindPopup(popup_dc9776cb45feac2dec90fc913f53ddeb)
#         ;
#
#
#
#
#             var marker_d5a211aa096f9202d0e8dfec35df3527 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f72f983099fce5412d700be94c662e00);
#
#
#         var popup_e8394f66be0a7cc7935c632e36b0a6a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_882e52c452f652b80f73fcf66be096c6 = $(`&lt;div id=&quot;html_882e52c452f652b80f73fcf66be096c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e8394f66be0a7cc7935c632e36b0a6a6.setContent(html_882e52c452f652b80f73fcf66be096c6);
#
#
#
#         marker_
