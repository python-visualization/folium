# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9daba4b04ca9e6987367ca4ededf0fc4 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9daba4b04ca9e6987367ca4ededf0fc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9daba4b04ca9e6987367ca4ededf0fc4 = L.map(
#                 &quot;map_9daba4b04ca9e6987367ca4ededf0fc4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7d93cf7d46be3952d6b998fc308d6698 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7d93cf7d46be3952d6b998fc308d6698.addTo(map_9daba4b04ca9e6987367ca4ededf0fc4);
#
#
#             var marker_8061023032161bbd3cd48dded0521c9d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_9daba4b04ca9e6987367ca4ededf0fc4);
#
#
#         var popup_1bd336c984e230678eb64b8b27291a10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc61663c31cb769acb61676141a66686 = $(`&lt;div id=&quot;html_bc61663c31cb769acb61676141a66686&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1bd336c984e230678eb64b8b27291a10.setContent(html_bc61663c31cb769acb61676141a66686);
#
#
#
#         marker_8061023032161bbd3cd48dded0521c9d.bindPopup(popup_1bd336c984e230678eb64b8b27291a10)
#         ;
#
#
#
#
#             var marker_a27f07564df846a96a507f96c182bbbd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_9daba4b04ca9e6987367ca4ededf0fc4);
#
#
#         var popup_1f2c62020ffdd7c3e8e62dd7e3790870 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05a05d46508e64c6609554f636c65552 = $(`&lt;div id=&quot;html_05a05d46508e64c6609554f636c65552&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1f2c62020ffdd7c3e8e62dd7e3790870.setContent(html_05a05d46508e64c6609554f636c65552);
#
#
#
#         marker_a27f07564df846a96a507f96c182bbbd.bindPopup(popup_1f2c62020ffdd7c3e8e62dd7e3790870)
#         ;
#
#
#
#
#             var marker_e17fefd371ba39837c799be4150231d5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_9daba4b04ca9e6987367ca4ededf0fc4);
#
#
#         var popup_de4cd4ab6b14aec381fa96f6f136e933 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f6630d35ee2116816880963e8e3087f = $(`&lt;div id=&quot;html_4f6630d35ee2116816880963e8e3087f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_de4cd4ab6b14aec381fa96f6f136e933.setContent(html_4f6630d35ee2116816880963e8e3087f);
#
#
#
#         marker_e17fefd371ba39837c799be4150231d5.bindPopup(popup_de4cd4ab6b14aec381fa96f6f136e933)
#         ;
#
#
#
#
#             var marker_10eb6538642faf3a1bd619c9f5885db3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_9daba4b04ca9e6987367ca4ededf0fc4);
#
#
#         var popup_8dfd8889d336d2ba5e50f1783a207a24 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8af96587181de2a12026dce6b6684138 = $(`&lt;div id=&quot;html_8af96587181de2a12026dce6b6684138&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8dfd8889d336d2ba5e50f1783a207a24.setContent(html_8af96587181de2a12026dce6b6684138);
#
#
#
#         marker_10eb6538642faf3a1bd619c9f5885db3.bindPopup(popup_8dfd8889d336d2ba5e50f1783a207a24)
#         ;
#
#
#
#
#             var marker_0f2327be91994bc108a9567cbf095b11 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_9daba4b04ca9e6987367ca4ededf0fc4);
#
#
#         var popup_44dbb2c079dede3b75873d079834aec3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_256571ca182d79f1021d8a578fa2a684 = $(`&lt;div id=&quot;html_256571ca182d79f1021d8a578fa2a684&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_44dbb2c079dede3b75873d079834aec3.setContent(html_256571ca182d79f1021d8a578fa2a684);
#
#
#
#         marker_0f2327be91994bc108a9567cbf095b11.bindPopup(popup_44dbb2c079dede3b75873d079834aec3)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88bee754c63ea827b7dc332a3b605da2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88bee754c63ea827b7dc332a3b605da2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88bee754c63ea827b7dc332a3b605da2 = L.map(
#                 &quot;map_88bee754c63ea827b7dc332a3b605da2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c78241ee9a84226b697c37895f6f8de8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c78241ee9a84226b697c37895f6f8de8.addTo(map_88bee754c63ea827b7dc332a3b605da2);
#
#
#             var feature_group_48f29005cba1faec8a8ff0264205a158 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e19314ddab59ea4d727fdd436266c477 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_48f29005cba1faec8a8ff0264205a158);
#
#
#         var popup_f1775b56b29ec4a9010e9aa14d52249f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_046f503a591bf20a3ff37cbec068f1f3 = $(`&lt;div id=&quot;html_046f503a591bf20a3ff37cbec068f1f3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f1775b56b29ec4a9010e9aa14d52249f.setContent(html_046f503a591bf20a3ff37cbec068f1f3);
#
#
#
#         marker_e19314ddab59ea4d727fdd436266c477.bindPopup(popup_f1775b56b29ec4a9010e9aa14d52249f)
#         ;
#
#
#
#
#             var marker_1fb0f317a40915132055ef1f90f513e2 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_48f29005cba1faec8a8ff0264205a158);
#
#
#         var popup_dc3c509d10c3e19491d2208a3d84e450 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_192375ec8ba6510563a4a35211144e1a = $(`&lt;div id=&quot;html_192375ec8ba6510563a4a35211144e1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_dc3c509d10c3e19491d2208a3d84e450.setContent(html_192375ec8ba6510563a4a35211144e1a);
#
#
#
#         marker_1fb0f317a40915132055ef1f90f513e2.bindPopup(popup_dc3c509d10c3e19491d2208a3d84e450)
#         ;
#
#
#
#
#             var marker_a93ffdf86c58d4d33668deec84a5cd3b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_48f29005cba1faec8a8ff0264205a158);
#
#
#         var popup_a2749c4f6c26341581241255ff0e891e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3c244485894a797e7a7894c75ac6d5d = $(`&lt;div id=&quot;html_d3c244485894a797e7a7894c75ac6d5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a2749c4f6c26341581241255ff0e891e.setContent(html_d3c244485894a797e7a7894c75ac6d5d);
#
#
#
#         marker_a93ffdf86c58d4d33668deec84a5cd3b.bindPopup(popup_a2749c4f6c26341581241255ff0e891e)
#         ;
#
#
#
#
#             var marker_0479a0c7f3a007f115db08fc611b97c9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_48f29005cba1faec8a8ff0264205a158);
#
#
#         var popup_0009a0c7f1675e5a20c6dae395431724 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9907c84166871b6c969fa09802dbb060 = $(`&lt;div id=&quot;html_9907c84166871b6c969fa09802dbb060&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0009a0c7f1675e5a20c6dae395431724.setContent(html_9907c84166871b6c969fa09802dbb060);
#
#
#
#         marker_0479a0c7f3a007f115db08fc611b97c9.bindPopup(popup_0009a0c7f1675e5a20c6dae395431724)
#         ;
#
#
#
#
#             var marker_d50fa976af299ea03be893641c588b62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_48f29005cba1faec8a8ff0264205a158);
#
#
#         var popup_ddb18b69aeb740e18cadc8a68fa81a30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d43e3cd54ab7f6ad81e7d7717bc94d71 = $(`&lt;div id=&quot;html_d43e3cd54ab7f6ad81e7d7717bc94d71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0f0aeffd32f367ad000bc70452e82f3b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0f0aeffd32f367ad000bc70452e82f3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0f0aeffd32f367ad000bc70452e82f3b = L.map(
#                 &quot;map_0f0aeffd32f367ad000bc70452e82f3b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7b97a1bb0c3ef10d816e2bf880160401 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7b97a1bb0c3ef10d816e2bf880160401.addTo(map_0f0aeffd32f367ad000bc70452e82f3b);
#
#
#             var feature_group_9ee47ed6dc22e9851f1c3c4a8f99f580 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_9ee47ed6dc22e9851f1c3c4a8f99f580.addTo(map_0f0aeffd32f367ad000bc70452e82f3b);
#
#
#             var feature_group_sub_group_26e124e59a264d608289d3e71826932d = L.featureGroup.subGroup(
#                 feature_group_9ee47ed6dc22e9851f1c3c4a8f99f580
#             );
#
#
#             var marker_12ee88f71d9f81266c741ca637a4dbe6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_26e124e59a264d608289d3e71826932d);
#
#
#         var popup_4573d4e705e5fb9c81105f1bfc20cf58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24d22fb8983d9ef5288538bd63c5d580 = $(`&lt;div id=&quot;html_24d22fb8983d9ef5288538bd63c5d580&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4573d4e705e5fb9c81105f1bfc20cf58.setContent(html_24d22fb8983d9ef5288538bd63c5d580);
#
#
#
#         marker_12ee88f71d9f81266c741ca637a4dbe6.bindPopup(popup_4573d4e705e5fb9c81105f1bfc20cf58)
#         ;
#
#
#
#
#             var marker_9008ff007ee7995bdb5a67d92dc5f932 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_26e124e59a264d608289d3e71826932d);
#
#
#         var popup_2e3bb1f1f0b9214544cc0947cc8a79a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c687926e31d6afd2fb19ba5c9a743946 = $(`&lt;div id=&quot;html_c687926e31d6afd2fb19ba5c9a743946&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2e3bb1f1f0b9214544cc0947cc8a79a0.setContent(html_c687926e31d6afd2fb19ba5c9a743946);
#
#
#
#         marker_9008ff007ee7995bdb5a67d92dc5f932.bindPopup(popup_2e3bb1f1f0b9214544cc0947cc8a79a0)
#         ;
#
#
#
#
#             var marker_772ae6865fb6a893db5f90f89572a4e9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_26e124e59a264d608289d3e71826932d);
#
#
#         var popup_d2c146a15bc77d660ea329ea6d5e931e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4377ac357f4fabf57170da5a90663559 = $(`&lt;div id=&quot;html_4377ac357f4fabf57170da5a90663559&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d2c146a15bc77d660ea329ea6d5e931e.setContent(html_4377ac357f4fabf57170da5a90663559);
#
#
#
#         marker_772ae6865fb6a893db5f90f89572a4e9.bindPopup(popup_d2c146a15bc77d660ea329ea6d5e931e)
#         ;
#
#
#
#
#             var marker_e401ae3233fdc844357e0191fbe49bac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_26e124e59a264d608289d3e71826932d);
#
#
#         var popup_50ace1093f2b9b6297ac3f8120803a0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fd79a90faa8381eb02b3cabc7a61c45 = $(`&lt;div id=&quot;html_0fd79a90faa8381eb02b3cabc7a61c45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_50ace1093f2b9b6297ac3f8120803a0a.setContent(html_0fd79a90faa8381eb02b3cabc7a61c45);
#
#
#
#         marker_e401ae3233fdc844357e0191fbe49bac.bindPopup(popup_50ace1093f2b9b6297ac3f8120803a0a)
#         ;
#
#
#
#
#             var marker_154df10f80cf7ba131d0787302a7c2b9 = L.marker(
#                 [45.0503999
