# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ffa03e6c307c1b166595fb09000d4fa0 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ffa03e6c307c1b166595fb09000d4fa0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ffa03e6c307c1b166595fb09000d4fa0 = L.map(
#                 &quot;map_ffa03e6c307c1b166595fb09000d4fa0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c05f75a8ce99cfa090984f0a5a5933d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c05f75a8ce99cfa090984f0a5a5933d8.addTo(map_ffa03e6c307c1b166595fb09000d4fa0);
#
#
#             var marker_2155d77de6cb4e202cdef5e34206f657 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ffa03e6c307c1b166595fb09000d4fa0);
#
#
#         var popup_8007ac9c592aa9110a16b01300d97d43 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcd77da20e5b3c3af859994ed3614391 = $(`&lt;div id=&quot;html_dcd77da20e5b3c3af859994ed3614391&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8007ac9c592aa9110a16b01300d97d43.setContent(html_dcd77da20e5b3c3af859994ed3614391);
#
#
#
#         marker_2155d77de6cb4e202cdef5e34206f657.bindPopup(popup_8007ac9c592aa9110a16b01300d97d43)
#         ;
#
#
#
#
#             var marker_7eeb290d184c12e343d7041f15791613 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ffa03e6c307c1b166595fb09000d4fa0);
#
#
#         var popup_c0952d9e7e92287bfc07db7be24356a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_066ac4c3603ce6a8ca8d2b57dd71b597 = $(`&lt;div id=&quot;html_066ac4c3603ce6a8ca8d2b57dd71b597&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c0952d9e7e92287bfc07db7be24356a6.setContent(html_066ac4c3603ce6a8ca8d2b57dd71b597);
#
#
#
#         marker_7eeb290d184c12e343d7041f15791613.bindPopup(popup_c0952d9e7e92287bfc07db7be24356a6)
#         ;
#
#
#
#
#             var marker_a6affcba342faed243e3e359c16c8bea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ffa03e6c307c1b166595fb09000d4fa0);
#
#
#         var popup_bfe4a231a3d2d0fd1e9ada4c21d2f1a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c67dece75681dbf91b588be1ebfb622f = $(`&lt;div id=&quot;html_c67dece75681dbf91b588be1ebfb622f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bfe4a231a3d2d0fd1e9ada4c21d2f1a4.setContent(html_c67dece75681dbf91b588be1ebfb622f);
#
#
#
#         marker_a6affcba342faed243e3e359c16c8bea.bindPopup(popup_bfe4a231a3d2d0fd1e9ada4c21d2f1a4)
#         ;
#
#
#
#
#             var marker_8e832f41c6fc969aaa1f40ec6ae7254a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ffa03e6c307c1b166595fb09000d4fa0);
#
#
#         var popup_fce52ea633806470dc9759d6287c88b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b9c0607ef239336d6fa74e2b529ee7d = $(`&lt;div id=&quot;html_8b9c0607ef239336d6fa74e2b529ee7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fce52ea633806470dc9759d6287c88b2.setContent(html_8b9c0607ef239336d6fa74e2b529ee7d);
#
#
#
#         marker_8e832f41c6fc969aaa1f40ec6ae7254a.bindPopup(popup_fce52ea633806470dc9759d6287c88b2)
#         ;
#
#
#
#
#             var marker_25becb6e6755ad53c1b83e407749199c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ffa03e6c307c1b166595fb09000d4fa0);
#
#
#         var popup_2af5718303db89995c1a9831e758968c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca4c4bfd4032d12f7e37a1547dcd271d = $(`&lt;div id=&quot;html_ca4c4bfd4032d12f7e37a1547dcd271d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_2af5718303db89995c1a9831e75896

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb1cfab29ab8f822559af4942946cf7b {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb1cfab29ab8f822559af4942946cf7b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb1cfab29ab8f822559af4942946cf7b = L.map(
#                 &quot;map_eb1cfab29ab8f822559af4942946cf7b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bd038668f766dfae7f3ab5860f4c864f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bd038668f766dfae7f3ab5860f4c864f.addTo(map_eb1cfab29ab8f822559af4942946cf7b);
#
#
#             var feature_group_4f338f1a32f122b06529d7ac2e982ab3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_df53004621b55551286053f109695f6f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4f338f1a32f122b06529d7ac2e982ab3);
#
#
#         var popup_b304de51a24c1c248ab435c6a304b61e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a9f7bb2d8dffeacbf6dbe88465de44f = $(`&lt;div id=&quot;html_6a9f7bb2d8dffeacbf6dbe88465de44f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b304de51a24c1c248ab435c6a304b61e.setContent(html_6a9f7bb2d8dffeacbf6dbe88465de44f);
#
#
#
#         marker_df53004621b55551286053f109695f6f.bindPopup(popup_b304de51a24c1c248ab435c6a304b61e)
#         ;
#
#
#
#
#             var marker_32215b54b5b661df299cd29a7239554e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4f338f1a32f122b06529d7ac2e982ab3);
#
#
#         var popup_2948435aee8eecdef84404b483b28183 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5530e9b09bc54b3b7669a2284fc5461d = $(`&lt;div id=&quot;html_5530e9b09bc54b3b7669a2284fc5461d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2948435aee8eecdef84404b483b28183.setContent(html_5530e9b09bc54b3b7669a2284fc5461d);
#
#
#
#         marker_32215b54b5b661df299cd29a7239554e.bindPopup(popup_2948435aee8eecdef84404b483b28183)
#         ;
#
#
#
#
#             var marker_f66732874145a1c63fbb8c9f77f16a35 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4f338f1a32f122b06529d7ac2e982ab3);
#
#
#         var popup_1e299ce7fe4fff83128e88966681f28f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f42f48e378f9a5c6c8c1040ec6713ab4 = $(`&lt;div id=&quot;html_f42f48e378f9a5c6c8c1040ec6713ab4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1e299ce7fe4fff83128e88966681f28f.setContent(html_f42f48e378f9a5c6c8c1040ec6713ab4);
#
#
#
#         marker_f66732874145a1c63fbb8c9f77f16a35.bindPopup(popup_1e299ce7fe4fff83128e88966681f28f)
#         ;
#
#
#
#
#             var marker_4415ebbdb5833b398e6329c0641742c9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4f338f1a32f122b06529d7ac2e982ab3);
#
#
#         var popup_168ba6125f5449a337260cb9167d4ee9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c23128351fd5517c4e8e4f31a38aeef6 = $(`&lt;div id=&quot;html_c23128351fd5517c4e8e4f31a38aeef6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_168ba6125f5449a337260cb9167d4ee9.setContent(html_c23128351fd5517c4e8e4f31a38aeef6);
#
#
#
#         marker_4415ebbdb5833b398e6329c0641742c9.bindPopup(popup_168ba6125f5449a337260cb9167d4ee9)
#         ;
#
#
#
#
#             var marker_3e28c8d96ec07d25ceac292603f824d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4f338f1a32f122b06529d7ac2e982ab3);
#
#
#         var popup_b42d1e813042aa0ea8871de6e3d55569 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eae0801d9e7c806e4518079e40550507 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eae0801d9e7c806e4518079e40550507&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eae0801d9e7c806e4518079e40550507 = L.map(
#                 &quot;map_eae0801d9e7c806e4518079e40550507&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dd4c69e567a770f534732d2b1c087c9a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dd4c69e567a770f534732d2b1c087c9a.addTo(map_eae0801d9e7c806e4518079e40550507);
#
#
#             var feature_group_e5d38b7e72c620ff0ab5018f303dc846 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e5d38b7e72c620ff0ab5018f303dc846.addTo(map_eae0801d9e7c806e4518079e40550507);
#
#
#             var feature_group_sub_group_02f4308cf23e9de4132c1ace6ad1b301 = L.featureGroup.subGroup(
#                 feature_group_e5d38b7e72c620ff0ab5018f303dc846
#             );
#
#
#             var marker_bd198f47140c66e804f4f4501dc8aacd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_02f4308cf23e9de4132c1ace6ad1b301);
#
#
#         var popup_dd936764d4f78a09b06980b007118e17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7db9c5bc730267064cd12a1501fce47d = $(`&lt;div id=&quot;html_7db9c5bc730267064cd12a1501fce47d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_dd936764d4f78a09b06980b007118e17.setContent(html_7db9c5bc730267064cd12a1501fce47d);
#
#
#
#         marker_bd198f47140c66e804f4f4501dc8aacd.bindPopup(popup_dd936764d4f78a09b06980b007118e17)
#         ;
#
#
#
#
#             var marker_cc36fc11930db10bde8b081d5e59e914 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_02f4308cf23e9de4132c1ace6ad1b301);
#
#
#         var popup_a814099265e4da05021fcc24d69b1dac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_520103d62e5780e41036b24e6194b7bd = $(`&lt;div id=&quot;html_520103d62e5780e41036b24e6194b7bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a814099265e4da05021fcc24d69b1dac.setContent(html_520103d62e5780e41036b24e6194b7bd);
#
#
#
#         marker_cc36fc11930db10bde8b081d5e59e914.bindPopup(popup_a814099265e4da05021fcc24d69b1dac)
#         ;
#
#
#
#
#             var marker_fe256e7c6542336d0bf427849959feed = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_02f4308cf23e9de4132c1ace6ad1b301);
#
#
#         var popup_6de7f63bdde4cf718ca0868fc386dbaf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54691fff7949bc35049a82f6a3e98c27 = $(`&lt;div id=&quot;html_54691fff7949bc35049a82f6a3e98c27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_6de7f63bdde4cf718ca0868fc386dbaf.setContent(html_54691fff7949bc35049a82f6a3e98c27);
#
#
#
#         marker_fe256e7c6542336d0bf427849959feed.bindPopup(popup_6de7f63bdde4cf718ca0868fc386dbaf)
#         ;
#
#
#
#
#             var marker_256eb4d712cb776c7d1c62ca26637e14 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_02f4308cf23e9de4132c1ace6ad1b301);
#
#
#         var popup_ed24f1b5d269236db36ca8138486a8e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6d71b89d8bce2887b8a7b4921e9f6ef = $(`&lt;div id=&quot;html_a6d71b89d8bce2887b8a7b4921e9f6ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ed24f1b5d269236db36ca8138486a8e9.setContent(html_a6d71b89d8bce2887b8a7b4921e9f6ef);
#
#
#
#         mark
