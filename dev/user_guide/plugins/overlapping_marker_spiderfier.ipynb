# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4257c522cdd87570af32a3526e1a5469 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4257c522cdd87570af32a3526e1a5469&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4257c522cdd87570af32a3526e1a5469 = L.map(
#                 &quot;map_4257c522cdd87570af32a3526e1a5469&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3b0bbf65ee7b6aaef4732f453fb8f8bf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3b0bbf65ee7b6aaef4732f453fb8f8bf.addTo(map_4257c522cdd87570af32a3526e1a5469);
#
#
#             var marker_991e00dfaef216d16bea7715e6047ee5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4257c522cdd87570af32a3526e1a5469);
#
#
#         var popup_c2499756e2f7b1fd5b4e5828e583f993 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b36d2a0df9398a4c4be4da1ad2a11d7 = $(`&lt;div id=&quot;html_6b36d2a0df9398a4c4be4da1ad2a11d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c2499756e2f7b1fd5b4e5828e583f993.setContent(html_6b36d2a0df9398a4c4be4da1ad2a11d7);
#
#
#
#         marker_991e00dfaef216d16bea7715e6047ee5.bindPopup(popup_c2499756e2f7b1fd5b4e5828e583f993)
#         ;
#
#
#
#
#             var marker_4a4de7ae7007f21185b45609f238e291 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4257c522cdd87570af32a3526e1a5469);
#
#
#         var popup_d0ff4ce6d30f91a2cdbeea1e887ffa2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9b6f78429b43dff8fcab1f376f5d5503 = $(`&lt;div id=&quot;html_9b6f78429b43dff8fcab1f376f5d5503&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d0ff4ce6d30f91a2cdbeea1e887ffa2e.setContent(html_9b6f78429b43dff8fcab1f376f5d5503);
#
#
#
#         marker_4a4de7ae7007f21185b45609f238e291.bindPopup(popup_d0ff4ce6d30f91a2cdbeea1e887ffa2e)
#         ;
#
#
#
#
#             var marker_56ebf75efbaee68a9ce8126d6adf0945 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4257c522cdd87570af32a3526e1a5469);
#
#
#         var popup_99f2cac52483001131793bad4f859be5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_025e3b507b60fc438142ac18d9b01f93 = $(`&lt;div id=&quot;html_025e3b507b60fc438142ac18d9b01f93&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_99f2cac52483001131793bad4f859be5.setContent(html_025e3b507b60fc438142ac18d9b01f93);
#
#
#
#         marker_56ebf75efbaee68a9ce8126d6adf0945.bindPopup(popup_99f2cac52483001131793bad4f859be5)
#         ;
#
#
#
#
#             var marker_9f8eb652e79610196db3e6e3049ad7e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4257c522cdd87570af32a3526e1a5469);
#
#
#         var popup_9335c037e6a2eb35dd77a5a56b56f026 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8a2e27eda4b5d22c4b10a56893b8077c = $(`&lt;div id=&quot;html_8a2e27eda4b5d22c4b10a56893b8077c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9335c037e6a2eb35dd77a5a56b56f026.setContent(html_8a2e27eda4b5d22c4b10a56893b8077c);
#
#
#
#         marker_9f8eb652e79610196db3e6e3049ad7e4.bindPopup(popup_9335c037e6a2eb35dd77a5a56b56f026)
#         ;
#
#
#
#
#             var marker_bfd2af3da3bfed9d1170c85bf491c902 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4257c522cdd87570af32a3526e1a5469);
#
#
#         var popup_6432fcabb5dcb3ec3d2277a87b061713 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c30d91c0025f93baae274505c18c7f57 = $(`&lt;div id=&quot;html_c30d91c0025f93baae274505c18c7f57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_6432fcabb5dcb3ec3d2277a87b061713.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7d4f116a003889a4f759663e719a4f04 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7d4f116a003889a4f759663e719a4f04&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7d4f116a003889a4f759663e719a4f04 = L.map(
#                 &quot;map_7d4f116a003889a4f759663e719a4f04&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9373dfa847ada758d5590c04ffb609e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a9373dfa847ada758d5590c04ffb609e.addTo(map_7d4f116a003889a4f759663e719a4f04);
#
#
#             var feature_group_2957f64a1b1851115d8df7696026fe8e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_4e8d48d474552681913415a338aaf626 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2957f64a1b1851115d8df7696026fe8e);
#
#
#         var popup_32cf67b1af82fcdb8b624b166005a3b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4773a0f2ce4a8780d3a088b6473b2617 = $(`&lt;div id=&quot;html_4773a0f2ce4a8780d3a088b6473b2617&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_32cf67b1af82fcdb8b624b166005a3b6.setContent(html_4773a0f2ce4a8780d3a088b6473b2617);
#
#
#
#         marker_4e8d48d474552681913415a338aaf626.bindPopup(popup_32cf67b1af82fcdb8b624b166005a3b6)
#         ;
#
#
#
#
#             var marker_872beabb7e4ce4200491f334633624c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2957f64a1b1851115d8df7696026fe8e);
#
#
#         var popup_df9888ead4ebe2254743e11034b0b175 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f16379a2235490ef27d1e2f102918ea8 = $(`&lt;div id=&quot;html_f16379a2235490ef27d1e2f102918ea8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_df9888ead4ebe2254743e11034b0b175.setContent(html_f16379a2235490ef27d1e2f102918ea8);
#
#
#
#         marker_872beabb7e4ce4200491f334633624c9.bindPopup(popup_df9888ead4ebe2254743e11034b0b175)
#         ;
#
#
#
#
#             var marker_321737caa9442d3fa34506fe4dd9f958 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2957f64a1b1851115d8df7696026fe8e);
#
#
#         var popup_72da32853e96053fbb605681d3dde611 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba79afb8c040e4716ba728eb5338a2b0 = $(`&lt;div id=&quot;html_ba79afb8c040e4716ba728eb5338a2b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_72da32853e96053fbb605681d3dde611.setContent(html_ba79afb8c040e4716ba728eb5338a2b0);
#
#
#
#         marker_321737caa9442d3fa34506fe4dd9f958.bindPopup(popup_72da32853e96053fbb605681d3dde611)
#         ;
#
#
#
#
#             var marker_92f01fa59ef3a32406fa99dc997890f6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2957f64a1b1851115d8df7696026fe8e);
#
#
#         var popup_f4d6ce5fdcc94182f19b9928b8977818 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c66411a917fd7e91f895c6c3496d9e6c = $(`&lt;div id=&quot;html_c66411a917fd7e91f895c6c3496d9e6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f4d6ce5fdcc94182f19b9928b8977818.setContent(html_c66411a917fd7e91f895c6c3496d9e6c);
#
#
#
#         marker_92f01fa59ef3a32406fa99dc997890f6.bindPopup(popup_f4d6ce5fdcc94182f19b9928b8977818)
#         ;
#
#
#
#
#             var marker_39b1013a12aad6dd15b4b55c7687a667 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2957f64a1b1851115d8df7696026fe8e);
#
#
#         var popup_79387cac5fcf3c079281ea71a5b1d988 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e173cc07540eb6b79e77b980cc5c4542 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e173cc07540eb6b79e77b980cc5c4542&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e173cc07540eb6b79e77b980cc5c4542 = L.map(
#                 &quot;map_e173cc07540eb6b79e77b980cc5c4542&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dccb376bb936ab81f57b8cba3be0945a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dccb376bb936ab81f57b8cba3be0945a.addTo(map_e173cc07540eb6b79e77b980cc5c4542);
#
#
#             var feature_group_7c5f6ceea2aa28846750d3e1c31e7395 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7c5f6ceea2aa28846750d3e1c31e7395.addTo(map_e173cc07540eb6b79e77b980cc5c4542);
#
#
#             var feature_group_sub_group_b57ea519acff6215f1c300e1a793a37a = L.featureGroup.subGroup(
#                 feature_group_7c5f6ceea2aa28846750d3e1c31e7395
#             );
#
#
#             var marker_89c94639601505e433d77f1c9a58e786 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b57ea519acff6215f1c300e1a793a37a);
#
#
#         var popup_151991c7b69ecd06f676f4fa8fe9e02e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c99b3472f7f72239e30dbafd1640818 = $(`&lt;div id=&quot;html_8c99b3472f7f72239e30dbafd1640818&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_151991c7b69ecd06f676f4fa8fe9e02e.setContent(html_8c99b3472f7f72239e30dbafd1640818);
#
#
#
#         marker_89c94639601505e433d77f1c9a58e786.bindPopup(popup_151991c7b69ecd06f676f4fa8fe9e02e)
#         ;
#
#
#
#
#             var marker_6eb82fbef42c145afd2d8c477d4ad034 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b57ea519acff6215f1c300e1a793a37a);
#
#
#         var popup_1a5b382e376d0532bdef6a41f784b31f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57417023f0bcd8f2e5a154dc5bda8c6f = $(`&lt;div id=&quot;html_57417023f0bcd8f2e5a154dc5bda8c6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1a5b382e376d0532bdef6a41f784b31f.setContent(html_57417023f0bcd8f2e5a154dc5bda8c6f);
#
#
#
#         marker_6eb82fbef42c145afd2d8c477d4ad034.bindPopup(popup_1a5b382e376d0532bdef6a41f784b31f)
#         ;
#
#
#
#
#             var marker_bf55ff8acb37a58d8bddd7a1a615b91b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b57ea519acff6215f1c300e1a793a37a);
#
#
#         var popup_58ef108b21d3745fcabe4b0a1b0154b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d831a4d404844de6097256dd8784cc6d = $(`&lt;div id=&quot;html_d831a4d404844de6097256dd8784cc6d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_58ef108b21d3745fcabe4b0a1b0154b8.setContent(html_d831a4d404844de6097256dd8784cc6d);
#
#
#
#         marker_bf55ff8acb37a58d8bddd7a1a615b91b.bindPopup(popup_58ef108b21d3745fcabe4b0a1b0154b8)
#         ;
#
#
#
#
#             var marker_71e917e8cba383d167fd06692088fc5b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b57ea519acff6215f1c300e1a793a37a);
#
#
#         var popup_f2cf604078ad33cae7bce70735a29440 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e00c46e40d0a946432ab441fb3048ff = $(`&lt;div id=&quot;html_4e00c46e40d0a946432ab441fb3048ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f2cf604078ad33cae7bce70735a29440.setContent(html_4e00c46e40d0a946432ab441fb3048ff);
#
#
#
#         marker_
