# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_645d7dc0e5b02f268e49fc319af2b27b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_645d7dc0e5b02f268e49fc319af2b27b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_645d7dc0e5b02f268e49fc319af2b27b = L.map(
#                 &quot;map_645d7dc0e5b02f268e49fc319af2b27b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c3baf85167300fc6d7772775a661cf2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8c3baf85167300fc6d7772775a661cf2.addTo(map_645d7dc0e5b02f268e49fc319af2b27b);
#
#
#             var marker_a39c9e4af4684260388d6122f1b34fa2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_645d7dc0e5b02f268e49fc319af2b27b);
#
#
#         var popup_6c0f1f78c52fef7ac567775e8895a517 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_950d2f6cbb698789c8fd88408dba75b5 = $(`&lt;div id=&quot;html_950d2f6cbb698789c8fd88408dba75b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6c0f1f78c52fef7ac567775e8895a517.setContent(html_950d2f6cbb698789c8fd88408dba75b5);
#
#
#
#         marker_a39c9e4af4684260388d6122f1b34fa2.bindPopup(popup_6c0f1f78c52fef7ac567775e8895a517)
#         ;
#
#
#
#
#             var marker_e615d7d932720fac20f818fd0c728d34 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_645d7dc0e5b02f268e49fc319af2b27b);
#
#
#         var popup_b4931853a8d47a679d019e4354cb4e5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ae941bcb1074855c761859d075463a6 = $(`&lt;div id=&quot;html_2ae941bcb1074855c761859d075463a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b4931853a8d47a679d019e4354cb4e5f.setContent(html_2ae941bcb1074855c761859d075463a6);
#
#
#
#         marker_e615d7d932720fac20f818fd0c728d34.bindPopup(popup_b4931853a8d47a679d019e4354cb4e5f)
#         ;
#
#
#
#
#             var marker_48b8c378f637343abac965ad4839be60 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_645d7dc0e5b02f268e49fc319af2b27b);
#
#
#         var popup_b3065ec558a3bf1def9935a226492d62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e58d69c2b01ed7c82984d55283ca8a39 = $(`&lt;div id=&quot;html_e58d69c2b01ed7c82984d55283ca8a39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_b3065ec558a3bf1def9935a226492d62.setContent(html_e58d69c2b01ed7c82984d55283ca8a39);
#
#
#
#         marker_48b8c378f637343abac965ad4839be60.bindPopup(popup_b3065ec558a3bf1def9935a226492d62)
#         ;
#
#
#
#
#             var marker_7f44893234a5b4d1d168bbb760e52ad5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_645d7dc0e5b02f268e49fc319af2b27b);
#
#
#         var popup_cbe619d0eca4f9b6c4f875cd3331a319 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fcd713974b173252ae9a934e154bd67 = $(`&lt;div id=&quot;html_4fcd713974b173252ae9a934e154bd67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cbe619d0eca4f9b6c4f875cd3331a319.setContent(html_4fcd713974b173252ae9a934e154bd67);
#
#
#
#         marker_7f44893234a5b4d1d168bbb760e52ad5.bindPopup(popup_cbe619d0eca4f9b6c4f875cd3331a319)
#         ;
#
#
#
#
#             var marker_ad75f306c59128122b1b52a62d64400a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_645d7dc0e5b02f268e49fc319af2b27b);
#
#
#         var popup_862b4806edaf95124e8d0df00d669054 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_777c81709a420aa53379501be62f717a = $(`&lt;div id=&quot;html_777c81709a420aa53379501be62f717a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_862b4806edaf95124e8d0df00d669054.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e054d3ed19ae9b41c5451cdd331739dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e054d3ed19ae9b41c5451cdd331739dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e054d3ed19ae9b41c5451cdd331739dc = L.map(
#                 &quot;map_e054d3ed19ae9b41c5451cdd331739dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_312d564898e27820e268fb5dd248c2d7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_312d564898e27820e268fb5dd248c2d7.addTo(map_e054d3ed19ae9b41c5451cdd331739dc);
#
#
#             var feature_group_d75d97bf8ecf3b74b446fbbc36485b1a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8e4f43129f84ec88bb13e529226e7258 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d75d97bf8ecf3b74b446fbbc36485b1a);
#
#
#         var popup_fd7495b333c1c46291dc379f6e9a8ef8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d3a05aa2cc62d40baa14ffe873d549c = $(`&lt;div id=&quot;html_0d3a05aa2cc62d40baa14ffe873d549c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fd7495b333c1c46291dc379f6e9a8ef8.setContent(html_0d3a05aa2cc62d40baa14ffe873d549c);
#
#
#
#         marker_8e4f43129f84ec88bb13e529226e7258.bindPopup(popup_fd7495b333c1c46291dc379f6e9a8ef8)
#         ;
#
#
#
#
#             var marker_50afeee19a6de50ec6d37d9a78411641 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d75d97bf8ecf3b74b446fbbc36485b1a);
#
#
#         var popup_bb70a91e6e61add0ad162c29147c3bac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5aa8d184eb31dfe84f8ecfa134ff907 = $(`&lt;div id=&quot;html_b5aa8d184eb31dfe84f8ecfa134ff907&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bb70a91e6e61add0ad162c29147c3bac.setContent(html_b5aa8d184eb31dfe84f8ecfa134ff907);
#
#
#
#         marker_50afeee19a6de50ec6d37d9a78411641.bindPopup(popup_bb70a91e6e61add0ad162c29147c3bac)
#         ;
#
#
#
#
#             var marker_66a2a77b08cb4f24c78b9dab9b874fa0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d75d97bf8ecf3b74b446fbbc36485b1a);
#
#
#         var popup_a429ff6bbbd89e9b88c6fc3e11f9a7fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ac8239cb5faec4ac476a773133c11fd = $(`&lt;div id=&quot;html_7ac8239cb5faec4ac476a773133c11fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a429ff6bbbd89e9b88c6fc3e11f9a7fd.setContent(html_7ac8239cb5faec4ac476a773133c11fd);
#
#
#
#         marker_66a2a77b08cb4f24c78b9dab9b874fa0.bindPopup(popup_a429ff6bbbd89e9b88c6fc3e11f9a7fd)
#         ;
#
#
#
#
#             var marker_f013eddfaf26cc4d23ee3452f4b814c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d75d97bf8ecf3b74b446fbbc36485b1a);
#
#
#         var popup_db036dac00375cf50a7c782e87d8e8e7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71bbaa7fd4e1bca4ea34a32d69a68824 = $(`&lt;div id=&quot;html_71bbaa7fd4e1bca4ea34a32d69a68824&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_db036dac00375cf50a7c782e87d8e8e7.setContent(html_71bbaa7fd4e1bca4ea34a32d69a68824);
#
#
#
#         marker_f013eddfaf26cc4d23ee3452f4b814c4.bindPopup(popup_db036dac00375cf50a7c782e87d8e8e7)
#         ;
#
#
#
#
#             var marker_8ca88a3a4ed1a6b10fb894dde43e3f47 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d75d97bf8ecf3b74b446fbbc36485b1a);
#
#
#         var popup_5c4652e630d155b8fa343701922b51d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83e07fa63caed210a43a5627c0570ede {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83e07fa63caed210a43a5627c0570ede&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83e07fa63caed210a43a5627c0570ede = L.map(
#                 &quot;map_83e07fa63caed210a43a5627c0570ede&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f8e4330b3e57c141ed74c733c80dc063 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f8e4330b3e57c141ed74c733c80dc063.addTo(map_83e07fa63caed210a43a5627c0570ede);
#
#
#             var feature_group_d0488785f47d016320fab10f7ce6111a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d0488785f47d016320fab10f7ce6111a.addTo(map_83e07fa63caed210a43a5627c0570ede);
#
#
#             var feature_group_sub_group_e127a98d3a5c8549a8dcd9dfd324f76f = L.featureGroup.subGroup(
#                 feature_group_d0488785f47d016320fab10f7ce6111a
#             );
#
#
#             var marker_8a13ed1fe8b7df44367ca40ce415856f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e127a98d3a5c8549a8dcd9dfd324f76f);
#
#
#         var popup_d231b82a2d0392dbfa2466d2397dbcce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_471fa9393c1cbcfb81270cd9b655fdd4 = $(`&lt;div id=&quot;html_471fa9393c1cbcfb81270cd9b655fdd4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d231b82a2d0392dbfa2466d2397dbcce.setContent(html_471fa9393c1cbcfb81270cd9b655fdd4);
#
#
#
#         marker_8a13ed1fe8b7df44367ca40ce415856f.bindPopup(popup_d231b82a2d0392dbfa2466d2397dbcce)
#         ;
#
#
#
#
#             var marker_9ac32e071d2c22eee4a731af6b1e7269 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e127a98d3a5c8549a8dcd9dfd324f76f);
#
#
#         var popup_33625639bfbfc9276f904d47985f3c04 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f4b279d28fae8755ecf1bfe78f03a9b = $(`&lt;div id=&quot;html_6f4b279d28fae8755ecf1bfe78f03a9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_33625639bfbfc9276f904d47985f3c04.setContent(html_6f4b279d28fae8755ecf1bfe78f03a9b);
#
#
#
#         marker_9ac32e071d2c22eee4a731af6b1e7269.bindPopup(popup_33625639bfbfc9276f904d47985f3c04)
#         ;
#
#
#
#
#             var marker_e32445f7025b52c652136b9867a95d4e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e127a98d3a5c8549a8dcd9dfd324f76f);
#
#
#         var popup_c41a3f75794f3b0cc251c2c844fc0d3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f89ab5002a48b79f56d746d49c56eac7 = $(`&lt;div id=&quot;html_f89ab5002a48b79f56d746d49c56eac7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c41a3f75794f3b0cc251c2c844fc0d3b.setContent(html_f89ab5002a48b79f56d746d49c56eac7);
#
#
#
#         marker_e32445f7025b52c652136b9867a95d4e.bindPopup(popup_c41a3f75794f3b0cc251c2c844fc0d3b)
#         ;
#
#
#
#
#             var marker_4b8bed2c980a82a4972e29ff1c87979f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e127a98d3a5c8549a8dcd9dfd324f76f);
#
#
#         var popup_e0dd1b44d048c58dd76714f5c16115fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_295db94909a4f8aeada72680048ec206 = $(`&lt;div id=&quot;html_295db94909a4f8aeada72680048ec206&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e0dd1b44d048c58dd76714f5c16115fe.setContent(html_295db94909a4f8aeada72680048ec206);
#
#
#
#         marker_
