# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_515b0468eacee9b28db6a472f51109fd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_515b0468eacee9b28db6a472f51109fd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_515b0468eacee9b28db6a472f51109fd = L.map(
#                 &quot;map_515b0468eacee9b28db6a472f51109fd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_43b8186213c2bafbead34f43cfff6996 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_43b8186213c2bafbead34f43cfff6996.addTo(map_515b0468eacee9b28db6a472f51109fd);
#
#
#             var marker_a2a54a9528e8044640f5e78c8ab405ad = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_515b0468eacee9b28db6a472f51109fd);
#
#
#         var popup_a452820de66628a7dec26e1a6daffbc7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2dbf544abf335d878ac5bc6e242b6a83 = $(`&lt;div id=&quot;html_2dbf544abf335d878ac5bc6e242b6a83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a452820de66628a7dec26e1a6daffbc7.setContent(html_2dbf544abf335d878ac5bc6e242b6a83);
#
#
#
#         marker_a2a54a9528e8044640f5e78c8ab405ad.bindPopup(popup_a452820de66628a7dec26e1a6daffbc7)
#         ;
#
#
#
#
#             var marker_fa75603be607a28ad654c8079af6db6d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_515b0468eacee9b28db6a472f51109fd);
#
#
#         var popup_d478b06409504bb3e70de33d103c8ecc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9910c306872c6a3a63461786f7772077 = $(`&lt;div id=&quot;html_9910c306872c6a3a63461786f7772077&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d478b06409504bb3e70de33d103c8ecc.setContent(html_9910c306872c6a3a63461786f7772077);
#
#
#
#         marker_fa75603be607a28ad654c8079af6db6d.bindPopup(popup_d478b06409504bb3e70de33d103c8ecc)
#         ;
#
#
#
#
#             var marker_0aa816cdc5402b91df4dace3d1abf046 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_515b0468eacee9b28db6a472f51109fd);
#
#
#         var popup_ba91b5ce5af0634b4bd74b3bad13ec7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_216a838d98c31b5e6757d4f76bc2b4f5 = $(`&lt;div id=&quot;html_216a838d98c31b5e6757d4f76bc2b4f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ba91b5ce5af0634b4bd74b3bad13ec7f.setContent(html_216a838d98c31b5e6757d4f76bc2b4f5);
#
#
#
#         marker_0aa816cdc5402b91df4dace3d1abf046.bindPopup(popup_ba91b5ce5af0634b4bd74b3bad13ec7f)
#         ;
#
#
#
#
#             var marker_13ed2e80bd0fb3546353c4aa934e87d8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_515b0468eacee9b28db6a472f51109fd);
#
#
#         var popup_0746709d128270ba76fca0bd546f9b13 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc8b57ba1599569fa0c7553d2e8fe108 = $(`&lt;div id=&quot;html_fc8b57ba1599569fa0c7553d2e8fe108&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0746709d128270ba76fca0bd546f9b13.setContent(html_fc8b57ba1599569fa0c7553d2e8fe108);
#
#
#
#         marker_13ed2e80bd0fb3546353c4aa934e87d8.bindPopup(popup_0746709d128270ba76fca0bd546f9b13)
#         ;
#
#
#
#
#             var marker_eb78d1644e32b2aac54fa9065af8c236 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_515b0468eacee9b28db6a472f51109fd);
#
#
#         var popup_ab72655735c7b054fc3269b0ff9a9a70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d331d9d7566e1805746323d245f538b7 = $(`&lt;div id=&quot;html_d331d9d7566e1805746323d245f538b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ab72655735c7b054fc3269b0ff9a9a70.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c02300f2e1ab6f3a618a9939675e413 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c02300f2e1ab6f3a618a9939675e413&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c02300f2e1ab6f3a618a9939675e413 = L.map(
#                 &quot;map_5c02300f2e1ab6f3a618a9939675e413&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d3177a9e3233f7a1d74a7c62bd39cc7a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d3177a9e3233f7a1d74a7c62bd39cc7a.addTo(map_5c02300f2e1ab6f3a618a9939675e413);
#
#
#             var feature_group_ce40935035b4add047754e92808ab335 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_66fed9b65dc80be5f36ec9be80b20b2c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ce40935035b4add047754e92808ab335);
#
#
#         var popup_5a350da46f7518e0f846569eb8bd8941 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5947759484fb8c99b8686821946c8abb = $(`&lt;div id=&quot;html_5947759484fb8c99b8686821946c8abb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5a350da46f7518e0f846569eb8bd8941.setContent(html_5947759484fb8c99b8686821946c8abb);
#
#
#
#         marker_66fed9b65dc80be5f36ec9be80b20b2c.bindPopup(popup_5a350da46f7518e0f846569eb8bd8941)
#         ;
#
#
#
#
#             var marker_c8a3dd0a6d14b6cb8cd1181de91926da = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ce40935035b4add047754e92808ab335);
#
#
#         var popup_0f381e517856720b82adcadcd220185e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cee480f87038f361b5f16b5352de873c = $(`&lt;div id=&quot;html_cee480f87038f361b5f16b5352de873c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_0f381e517856720b82adcadcd220185e.setContent(html_cee480f87038f361b5f16b5352de873c);
#
#
#
#         marker_c8a3dd0a6d14b6cb8cd1181de91926da.bindPopup(popup_0f381e517856720b82adcadcd220185e)
#         ;
#
#
#
#
#             var marker_53a68b476709dbd061698fd49d4b2e1e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ce40935035b4add047754e92808ab335);
#
#
#         var popup_a6ff00fa18109da8ee916fd4daceb693 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_61d86009e74672be9c1144f0f7d84a18 = $(`&lt;div id=&quot;html_61d86009e74672be9c1144f0f7d84a18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_a6ff00fa18109da8ee916fd4daceb693.setContent(html_61d86009e74672be9c1144f0f7d84a18);
#
#
#
#         marker_53a68b476709dbd061698fd49d4b2e1e.bindPopup(popup_a6ff00fa18109da8ee916fd4daceb693)
#         ;
#
#
#
#
#             var marker_e9b432121c7706a61ed5f6b97c05beca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ce40935035b4add047754e92808ab335);
#
#
#         var popup_1cfb3145a6f84084038d4309aebdf842 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a1331714dc827932095d4ada6623b489 = $(`&lt;div id=&quot;html_a1331714dc827932095d4ada6623b489&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_1cfb3145a6f84084038d4309aebdf842.setContent(html_a1331714dc827932095d4ada6623b489);
#
#
#
#         marker_e9b432121c7706a61ed5f6b97c05beca.bindPopup(popup_1cfb3145a6f84084038d4309aebdf842)
#         ;
#
#
#
#
#             var marker_bf2060d6bd39a94277f366d2ba3e2eed = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ce40935035b4add047754e92808ab335);
#
#
#         var popup_cd5d901fae732f74b91c8d3dd767e9bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c83a7f79adfac91fba40814dca6ec2a6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c83a7f79adfac91fba40814dca6ec2a6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c83a7f79adfac91fba40814dca6ec2a6 = L.map(
#                 &quot;map_c83a7f79adfac91fba40814dca6ec2a6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ef469324066be4a5b92c8464eb88f715 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ef469324066be4a5b92c8464eb88f715.addTo(map_c83a7f79adfac91fba40814dca6ec2a6);
#
#
#             var feature_group_b5aa20c2c65ef735601da4cb43bc5154 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b5aa20c2c65ef735601da4cb43bc5154.addTo(map_c83a7f79adfac91fba40814dca6ec2a6);
#
#
#             var feature_group_sub_group_4729cf05f942f740b0e180e821cc3acb = L.featureGroup.subGroup(
#                 feature_group_b5aa20c2c65ef735601da4cb43bc5154
#             );
#
#
#             var marker_a10d940abc65307275bdc37edf00cc5c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4729cf05f942f740b0e180e821cc3acb);
#
#
#         var popup_d04679e015614076b894b09742abb002 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eeb1b4e7b01bfb937760aaef41dc1d15 = $(`&lt;div id=&quot;html_eeb1b4e7b01bfb937760aaef41dc1d15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d04679e015614076b894b09742abb002.setContent(html_eeb1b4e7b01bfb937760aaef41dc1d15);
#
#
#
#         marker_a10d940abc65307275bdc37edf00cc5c.bindPopup(popup_d04679e015614076b894b09742abb002)
#         ;
#
#
#
#
#             var marker_e1484d38c188ea82580e0182d86137ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4729cf05f942f740b0e180e821cc3acb);
#
#
#         var popup_8fe7b0ec4ff704abee1374b94632ce09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bed927d631fec79fa5a5bb8d0d8d3f01 = $(`&lt;div id=&quot;html_bed927d631fec79fa5a5bb8d0d8d3f01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8fe7b0ec4ff704abee1374b94632ce09.setContent(html_bed927d631fec79fa5a5bb8d0d8d3f01);
#
#
#
#         marker_e1484d38c188ea82580e0182d86137ed.bindPopup(popup_8fe7b0ec4ff704abee1374b94632ce09)
#         ;
#
#
#
#
#             var marker_0117703bf96f9b9d50047d7be59b4427 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4729cf05f942f740b0e180e821cc3acb);
#
#
#         var popup_8366bab98e05d43dcba8a1bc955e3dd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3fa8a964da2c4e23f203be446c74a37 = $(`&lt;div id=&quot;html_d3fa8a964da2c4e23f203be446c74a37&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8366bab98e05d43dcba8a1bc955e3dd2.setContent(html_d3fa8a964da2c4e23f203be446c74a37);
#
#
#
#         marker_0117703bf96f9b9d50047d7be59b4427.bindPopup(popup_8366bab98e05d43dcba8a1bc955e3dd2)
#         ;
#
#
#
#
#             var marker_943b653125b79c2fa183215bf45eac71 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4729cf05f942f740b0e180e821cc3acb);
#
#
#         var popup_17f8f4e4ae4590c052239ae13e9c2639 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a40f044725170a66e374fae8957f576 = $(`&lt;div id=&quot;html_5a40f044725170a66e374fae8957f576&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_17f8f4e4ae4590c052239ae13e9c2639.setContent(html_5a40f044725170a66e374fae8957f576);
#
#
#
#         marker_
