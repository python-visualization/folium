# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_30b66fff815be04c0221fa55db2d3e98 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_30b66fff815be04c0221fa55db2d3e98&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_30b66fff815be04c0221fa55db2d3e98 = L.map(
#                 &quot;map_30b66fff815be04c0221fa55db2d3e98&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a56ea83da176e6c234e819c59e5fefe1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a56ea83da176e6c234e819c59e5fefe1.addTo(map_30b66fff815be04c0221fa55db2d3e98);
#
#
#             var marker_d60bd679fc33f406ac2cbba7ead61c9f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_30b66fff815be04c0221fa55db2d3e98);
#
#
#         var popup_16204acb7a0713be78bca070063f33ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c2ad862b5781a186629ec904a510ca8 = $(`&lt;div id=&quot;html_6c2ad862b5781a186629ec904a510ca8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_16204acb7a0713be78bca070063f33ee.setContent(html_6c2ad862b5781a186629ec904a510ca8);
#
#
#
#         marker_d60bd679fc33f406ac2cbba7ead61c9f.bindPopup(popup_16204acb7a0713be78bca070063f33ee)
#         ;
#
#
#
#
#             var marker_77ad5f6efc9d45089955173adf5b2b9a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_30b66fff815be04c0221fa55db2d3e98);
#
#
#         var popup_4f503a81660524a5e44768d44c2b995d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a58f8accb8a554a54a68fc3d1b833eec = $(`&lt;div id=&quot;html_a58f8accb8a554a54a68fc3d1b833eec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4f503a81660524a5e44768d44c2b995d.setContent(html_a58f8accb8a554a54a68fc3d1b833eec);
#
#
#
#         marker_77ad5f6efc9d45089955173adf5b2b9a.bindPopup(popup_4f503a81660524a5e44768d44c2b995d)
#         ;
#
#
#
#
#             var marker_b6c9127664c90787cc3be0581e681220 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_30b66fff815be04c0221fa55db2d3e98);
#
#
#         var popup_8b5ab1fe1f9198f13ddeb01fecb9982f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37feb12d233ac98668b33f600cdccc97 = $(`&lt;div id=&quot;html_37feb12d233ac98668b33f600cdccc97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8b5ab1fe1f9198f13ddeb01fecb9982f.setContent(html_37feb12d233ac98668b33f600cdccc97);
#
#
#
#         marker_b6c9127664c90787cc3be0581e681220.bindPopup(popup_8b5ab1fe1f9198f13ddeb01fecb9982f)
#         ;
#
#
#
#
#             var marker_9bb5a145d9110c5f2f559c4d0e0a908e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_30b66fff815be04c0221fa55db2d3e98);
#
#
#         var popup_c02a74206d091015c8193438b86f6036 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72acdb67cd7208bd05aab5e06510d460 = $(`&lt;div id=&quot;html_72acdb67cd7208bd05aab5e06510d460&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c02a74206d091015c8193438b86f6036.setContent(html_72acdb67cd7208bd05aab5e06510d460);
#
#
#
#         marker_9bb5a145d9110c5f2f559c4d0e0a908e.bindPopup(popup_c02a74206d091015c8193438b86f6036)
#         ;
#
#
#
#
#             var marker_1b0a75ddd318a49c55e3d36345c34ec7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_30b66fff815be04c0221fa55db2d3e98);
#
#
#         var popup_117ad30b92fe19792f85c2b3965ed3d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90fed8e8c790b5ea3c36a9212c4fea43 = $(`&lt;div id=&quot;html_90fed8e8c790b5ea3c36a9212c4fea43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_117ad30b92fe19792f85c2b3965ed3

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cb873b786378fdc21d7b8e3f614a9031 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cb873b786378fdc21d7b8e3f614a9031&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cb873b786378fdc21d7b8e3f614a9031 = L.map(
#                 &quot;map_cb873b786378fdc21d7b8e3f614a9031&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b523c55fe904cc900bc44596285b5e9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b523c55fe904cc900bc44596285b5e9.addTo(map_cb873b786378fdc21d7b8e3f614a9031);
#
#
#             var feature_group_7eeb52b940f33498cd29ee75f8be6a2f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b2fcde3439858324456f80dd8d90a3f0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7eeb52b940f33498cd29ee75f8be6a2f);
#
#
#         var popup_c099938bba52430da5255024f45f3261 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b635f5432136302da082dcb4ccc8661 = $(`&lt;div id=&quot;html_8b635f5432136302da082dcb4ccc8661&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c099938bba52430da5255024f45f3261.setContent(html_8b635f5432136302da082dcb4ccc8661);
#
#
#
#         marker_b2fcde3439858324456f80dd8d90a3f0.bindPopup(popup_c099938bba52430da5255024f45f3261)
#         ;
#
#
#
#
#             var marker_ca70174c860e3038b3822042c4689693 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7eeb52b940f33498cd29ee75f8be6a2f);
#
#
#         var popup_f2fb35a393b80ffba3055f65f10e84b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57f5ffe64330d44d49fb73074f30c600 = $(`&lt;div id=&quot;html_57f5ffe64330d44d49fb73074f30c600&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f2fb35a393b80ffba3055f65f10e84b5.setContent(html_57f5ffe64330d44d49fb73074f30c600);
#
#
#
#         marker_ca70174c860e3038b3822042c4689693.bindPopup(popup_f2fb35a393b80ffba3055f65f10e84b5)
#         ;
#
#
#
#
#             var marker_7e4ab79be5ccc13da23758e7e27f37a6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7eeb52b940f33498cd29ee75f8be6a2f);
#
#
#         var popup_7d29d9ade476fd88b289746c607e2e50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dda4e3b2c004ee08f3f353e036f6607b = $(`&lt;div id=&quot;html_dda4e3b2c004ee08f3f353e036f6607b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7d29d9ade476fd88b289746c607e2e50.setContent(html_dda4e3b2c004ee08f3f353e036f6607b);
#
#
#
#         marker_7e4ab79be5ccc13da23758e7e27f37a6.bindPopup(popup_7d29d9ade476fd88b289746c607e2e50)
#         ;
#
#
#
#
#             var marker_ee43b71d43d5c6f7e1684802c509b1e2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7eeb52b940f33498cd29ee75f8be6a2f);
#
#
#         var popup_f44acb09a5cb8be742951339ff4b86fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9442610b540aa3bf80ab46a182348d1a = $(`&lt;div id=&quot;html_9442610b540aa3bf80ab46a182348d1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f44acb09a5cb8be742951339ff4b86fc.setContent(html_9442610b540aa3bf80ab46a182348d1a);
#
#
#
#         marker_ee43b71d43d5c6f7e1684802c509b1e2.bindPopup(popup_f44acb09a5cb8be742951339ff4b86fc)
#         ;
#
#
#
#
#             var marker_631e7708772a645c69c740e761b4d81d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7eeb52b940f33498cd29ee75f8be6a2f);
#
#
#         var popup_5bb2d6b4ba28fde3f2d4564d3f69e60d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b8e620d4f19bfcdca47f9b3f587c3753 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b8e620d4f19bfcdca47f9b3f587c3753&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b8e620d4f19bfcdca47f9b3f587c3753 = L.map(
#                 &quot;map_b8e620d4f19bfcdca47f9b3f587c3753&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5697bfce792761280846b16581f34f00 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5697bfce792761280846b16581f34f00.addTo(map_b8e620d4f19bfcdca47f9b3f587c3753);
#
#
#             var feature_group_1f1c8aac40831895e9702fc7564acbb8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1f1c8aac40831895e9702fc7564acbb8.addTo(map_b8e620d4f19bfcdca47f9b3f587c3753);
#
#
#             var feature_group_sub_group_47b6c308b84058b2ececd8708e2bd5f1 = L.featureGroup.subGroup(
#                 feature_group_1f1c8aac40831895e9702fc7564acbb8
#             );
#
#
#             var marker_64573b58f73ab7cb6f9b31d5c9ed1978 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_47b6c308b84058b2ececd8708e2bd5f1);
#
#
#         var popup_b90f98f65cdf1d5c027a5f70bd671fb1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7c0af52fc36393f39e288c67ac77f43 = $(`&lt;div id=&quot;html_c7c0af52fc36393f39e288c67ac77f43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b90f98f65cdf1d5c027a5f70bd671fb1.setContent(html_c7c0af52fc36393f39e288c67ac77f43);
#
#
#
#         marker_64573b58f73ab7cb6f9b31d5c9ed1978.bindPopup(popup_b90f98f65cdf1d5c027a5f70bd671fb1)
#         ;
#
#
#
#
#             var marker_7003e8e68cef43489caca9b8679f5d63 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_47b6c308b84058b2ececd8708e2bd5f1);
#
#
#         var popup_73811efcba01d63f6d00ecf91a8bd65e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfc42ed14dd99b16e098988046c6ca41 = $(`&lt;div id=&quot;html_bfc42ed14dd99b16e098988046c6ca41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_73811efcba01d63f6d00ecf91a8bd65e.setContent(html_bfc42ed14dd99b16e098988046c6ca41);
#
#
#
#         marker_7003e8e68cef43489caca9b8679f5d63.bindPopup(popup_73811efcba01d63f6d00ecf91a8bd65e)
#         ;
#
#
#
#
#             var marker_38e56dd14f4baec72bab77fa6159495b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_47b6c308b84058b2ececd8708e2bd5f1);
#
#
#         var popup_3a26facf8b5e2562b3e1d89ac890abbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7772c4f038faa592ba1b82723f9624da = $(`&lt;div id=&quot;html_7772c4f038faa592ba1b82723f9624da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_3a26facf8b5e2562b3e1d89ac890abbb.setContent(html_7772c4f038faa592ba1b82723f9624da);
#
#
#
#         marker_38e56dd14f4baec72bab77fa6159495b.bindPopup(popup_3a26facf8b5e2562b3e1d89ac890abbb)
#         ;
#
#
#
#
#             var marker_7ecd1291857fa569c4b129abd3af2dd5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_47b6c308b84058b2ececd8708e2bd5f1);
#
#
#         var popup_a4ee36feded028796440ed64f7e025ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3c930a745ff648711da8b69a2b0d114a = $(`&lt;div id=&quot;html_3c930a745ff648711da8b69a2b0d114a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a4ee36feded028796440ed64f7e025ce.setContent(html_3c930a745ff648711da8b69a2b0d114a);
#
#
#
#         mark
