# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e42cc14704c62320ce2d27ba59bdd47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e42cc14704c62320ce2d27ba59bdd47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e42cc14704c62320ce2d27ba59bdd47 = L.map(
#                 &quot;map_5e42cc14704c62320ce2d27ba59bdd47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a32b3c86008bc211c2e3a6cbce8cc9a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a32b3c86008bc211c2e3a6cbce8cc9a.addTo(map_5e42cc14704c62320ce2d27ba59bdd47);
#
#
#             var marker_61d5cf9e1265a29ccc9a5b73730dd378 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5e42cc14704c62320ce2d27ba59bdd47);
#
#
#         var popup_6c38bf09d90d10e6493dfea3a1a26393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_010cc6330acdf52441cc62709c285c62 = $(`&lt;div id=&quot;html_010cc6330acdf52441cc62709c285c62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6c38bf09d90d10e6493dfea3a1a26393.setContent(html_010cc6330acdf52441cc62709c285c62);
#
#
#
#         marker_61d5cf9e1265a29ccc9a5b73730dd378.bindPopup(popup_6c38bf09d90d10e6493dfea3a1a26393)
#         ;
#
#
#
#
#             var marker_305ff7cbc197e7172bb5dd197bbbe5aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5e42cc14704c62320ce2d27ba59bdd47);
#
#
#         var popup_58603697924cf3f009c5888d22369eda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f6b181963cc6fd056c55ecd37d90732 = $(`&lt;div id=&quot;html_3f6b181963cc6fd056c55ecd37d90732&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_58603697924cf3f009c5888d22369eda.setContent(html_3f6b181963cc6fd056c55ecd37d90732);
#
#
#
#         marker_305ff7cbc197e7172bb5dd197bbbe5aa.bindPopup(popup_58603697924cf3f009c5888d22369eda)
#         ;
#
#
#
#
#             var marker_50d52123c81ce9b71fc3c4db01509dd7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5e42cc14704c62320ce2d27ba59bdd47);
#
#
#         var popup_a9e968a0e7b0d99d071794d2d5730802 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cae8fdcab34ddb3ec4c89ec5a0990d7 = $(`&lt;div id=&quot;html_1cae8fdcab34ddb3ec4c89ec5a0990d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a9e968a0e7b0d99d071794d2d5730802.setContent(html_1cae8fdcab34ddb3ec4c89ec5a0990d7);
#
#
#
#         marker_50d52123c81ce9b71fc3c4db01509dd7.bindPopup(popup_a9e968a0e7b0d99d071794d2d5730802)
#         ;
#
#
#
#
#             var marker_cde42c9c0d1c84b9dac802f53fc59c6c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5e42cc14704c62320ce2d27ba59bdd47);
#
#
#         var popup_8ce091008187a621af8fc18ccb4a7329 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71f062627187c742d09c30e1816edf72 = $(`&lt;div id=&quot;html_71f062627187c742d09c30e1816edf72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8ce091008187a621af8fc18ccb4a7329.setContent(html_71f062627187c742d09c30e1816edf72);
#
#
#
#         marker_cde42c9c0d1c84b9dac802f53fc59c6c.bindPopup(popup_8ce091008187a621af8fc18ccb4a7329)
#         ;
#
#
#
#
#             var marker_3a5c50a3584db8d40e6c022c617e3dbc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5e42cc14704c62320ce2d27ba59bdd47);
#
#
#         var popup_093e73b2cfadb41796a66d255513f4d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55b68ec161715c791c860a76f8080311 = $(`&lt;div id=&quot;html_55b68ec161715c791c860a76f8080311&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_093e73b2cfadb41796a66d255513f4d3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_79dfe5acd5f6317c7bfbac2ff3c0ea9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_79dfe5acd5f6317c7bfbac2ff3c0ea9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_79dfe5acd5f6317c7bfbac2ff3c0ea9c = L.map(
#                 &quot;map_79dfe5acd5f6317c7bfbac2ff3c0ea9c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e321752f3d1a2606bc0a330b93bec5c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7e321752f3d1a2606bc0a330b93bec5c.addTo(map_79dfe5acd5f6317c7bfbac2ff3c0ea9c);
#
#
#             var feature_group_f23cc5ca9b1101e2d2973d0542f994a3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_92cd79886d31873ee9a1c2a341222ec4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f23cc5ca9b1101e2d2973d0542f994a3);
#
#
#         var popup_6b5c528f72877d724214fc51e39b9527 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_373bbe930d3f14c52be4d94d43798713 = $(`&lt;div id=&quot;html_373bbe930d3f14c52be4d94d43798713&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6b5c528f72877d724214fc51e39b9527.setContent(html_373bbe930d3f14c52be4d94d43798713);
#
#
#
#         marker_92cd79886d31873ee9a1c2a341222ec4.bindPopup(popup_6b5c528f72877d724214fc51e39b9527)
#         ;
#
#
#
#
#             var marker_6c24be997795f2a1e8e1a01abffa94e9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f23cc5ca9b1101e2d2973d0542f994a3);
#
#
#         var popup_ece59457a848a6120beed2b6d45c03b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e8064f979e4481c3bf3392b49cb5dea = $(`&lt;div id=&quot;html_1e8064f979e4481c3bf3392b49cb5dea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ece59457a848a6120beed2b6d45c03b8.setContent(html_1e8064f979e4481c3bf3392b49cb5dea);
#
#
#
#         marker_6c24be997795f2a1e8e1a01abffa94e9.bindPopup(popup_ece59457a848a6120beed2b6d45c03b8)
#         ;
#
#
#
#
#             var marker_3f653cd5dc55ab9debdedc646af79767 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f23cc5ca9b1101e2d2973d0542f994a3);
#
#
#         var popup_71785a376d9a8be6507bc7cf178f9ffc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ee2c71dc45cf1b8545fd5b21957991e = $(`&lt;div id=&quot;html_4ee2c71dc45cf1b8545fd5b21957991e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_71785a376d9a8be6507bc7cf178f9ffc.setContent(html_4ee2c71dc45cf1b8545fd5b21957991e);
#
#
#
#         marker_3f653cd5dc55ab9debdedc646af79767.bindPopup(popup_71785a376d9a8be6507bc7cf178f9ffc)
#         ;
#
#
#
#
#             var marker_0d54ae122ad4974fcf5296370f40e6ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f23cc5ca9b1101e2d2973d0542f994a3);
#
#
#         var popup_7244a3c6ea5dfba45ac95a8bece8841b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fe410be57fd24d9bc6a5b2783cd9682 = $(`&lt;div id=&quot;html_4fe410be57fd24d9bc6a5b2783cd9682&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7244a3c6ea5dfba45ac95a8bece8841b.setContent(html_4fe410be57fd24d9bc6a5b2783cd9682);
#
#
#
#         marker_0d54ae122ad4974fcf5296370f40e6ea.bindPopup(popup_7244a3c6ea5dfba45ac95a8bece8841b)
#         ;
#
#
#
#
#             var marker_abd4eabf4e116ae34ceb784ce9b868ee = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f23cc5ca9b1101e2d2973d0542f994a3);
#
#
#         var popup_ee61e2cb2ee694e232ac71f34dc75baa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fb481ea5f2f77fb97293c963597decf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fb481ea5f2f77fb97293c963597decf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fb481ea5f2f77fb97293c963597decf = L.map(
#                 &quot;map_8fb481ea5f2f77fb97293c963597decf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b9d8e747cf8d11ee607c66a438bfd1b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b9d8e747cf8d11ee607c66a438bfd1b3.addTo(map_8fb481ea5f2f77fb97293c963597decf);
#
#
#             var feature_group_0d2c88f9e051e7274bb9405ce344082b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_0d2c88f9e051e7274bb9405ce344082b.addTo(map_8fb481ea5f2f77fb97293c963597decf);
#
#
#             var feature_group_sub_group_b7e8b70944dabf8a3024b74b7aa566bf = L.featureGroup.subGroup(
#                 feature_group_0d2c88f9e051e7274bb9405ce344082b
#             );
#
#
#             var marker_e10701d4bec22abd66c759cb6b8b4d18 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b7e8b70944dabf8a3024b74b7aa566bf);
#
#
#         var popup_b2024e5f34fb6ba2a404da636dd1e615 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e7587bfd6739e1fb933b424492884f7 = $(`&lt;div id=&quot;html_9e7587bfd6739e1fb933b424492884f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b2024e5f34fb6ba2a404da636dd1e615.setContent(html_9e7587bfd6739e1fb933b424492884f7);
#
#
#
#         marker_e10701d4bec22abd66c759cb6b8b4d18.bindPopup(popup_b2024e5f34fb6ba2a404da636dd1e615)
#         ;
#
#
#
#
#             var marker_689ea443ccf69c5acd3c1dd3640f770e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b7e8b70944dabf8a3024b74b7aa566bf);
#
#
#         var popup_d0149f68d59ccf47c1bd34b7d1757ad7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f995da5829848b6c681171744c992063 = $(`&lt;div id=&quot;html_f995da5829848b6c681171744c992063&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d0149f68d59ccf47c1bd34b7d1757ad7.setContent(html_f995da5829848b6c681171744c992063);
#
#
#
#         marker_689ea443ccf69c5acd3c1dd3640f770e.bindPopup(popup_d0149f68d59ccf47c1bd34b7d1757ad7)
#         ;
#
#
#
#
#             var marker_48fbe6141b222584723a68e1bb32cafc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b7e8b70944dabf8a3024b74b7aa566bf);
#
#
#         var popup_aecb68f998c12aa5a54dd9ea17f23e0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b214b761ab5edf035fcd7c4cf116503 = $(`&lt;div id=&quot;html_1b214b761ab5edf035fcd7c4cf116503&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_aecb68f998c12aa5a54dd9ea17f23e0e.setContent(html_1b214b761ab5edf035fcd7c4cf116503);
#
#
#
#         marker_48fbe6141b222584723a68e1bb32cafc.bindPopup(popup_aecb68f998c12aa5a54dd9ea17f23e0e)
#         ;
#
#
#
#
#             var marker_84edeeb6fb39f3db4df489660cfc5d12 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b7e8b70944dabf8a3024b74b7aa566bf);
#
#
#         var popup_3d20cb4de0565d0bf59d53c703f986f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46c766390a7d5316e00562cc2d46efad = $(`&lt;div id=&quot;html_46c766390a7d5316e00562cc2d46efad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3d20cb4de0565d0bf59d53c703f986f9.setContent(html_46c766390a7d5316e00562cc2d46efad);
#
#
#
#         marker_
