# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5f50419a8ab13105c75a2997eaee906 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5f50419a8ab13105c75a2997eaee906&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5f50419a8ab13105c75a2997eaee906 = L.map(
#                 &quot;map_d5f50419a8ab13105c75a2997eaee906&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b4428f9a69d82e4c0d90ea0527e36e28 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b4428f9a69d82e4c0d90ea0527e36e28.addTo(map_d5f50419a8ab13105c75a2997eaee906);
#
#
#             var marker_825a625346e779aaab76c1ae40aeeaff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d5f50419a8ab13105c75a2997eaee906);
#
#
#         var popup_9d8ef9fddda768e45a4e84dc623b5de8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbb1390bc128d2b8b3d28289dae90673 = $(`&lt;div id=&quot;html_bbb1390bc128d2b8b3d28289dae90673&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_9d8ef9fddda768e45a4e84dc623b5de8.setContent(html_bbb1390bc128d2b8b3d28289dae90673);
#
#
#
#         marker_825a625346e779aaab76c1ae40aeeaff.bindPopup(popup_9d8ef9fddda768e45a4e84dc623b5de8)
#         ;
#
#
#
#
#             var marker_5dec96eda3b2a489b57568f49928cf9f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d5f50419a8ab13105c75a2997eaee906);
#
#
#         var popup_a391f2c947206142b0389ee222945aa1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c4470eb7164fcfe73eb4eaaef696614d = $(`&lt;div id=&quot;html_c4470eb7164fcfe73eb4eaaef696614d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a391f2c947206142b0389ee222945aa1.setContent(html_c4470eb7164fcfe73eb4eaaef696614d);
#
#
#
#         marker_5dec96eda3b2a489b57568f49928cf9f.bindPopup(popup_a391f2c947206142b0389ee222945aa1)
#         ;
#
#
#
#
#             var marker_3ef621322691a2109afaab96ba87d080 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d5f50419a8ab13105c75a2997eaee906);
#
#
#         var popup_402fd6ccd5dbbe7a92852987ec1a64da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a14680d2ccf9812198543c9afded0ea = $(`&lt;div id=&quot;html_9a14680d2ccf9812198543c9afded0ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_402fd6ccd5dbbe7a92852987ec1a64da.setContent(html_9a14680d2ccf9812198543c9afded0ea);
#
#
#
#         marker_3ef621322691a2109afaab96ba87d080.bindPopup(popup_402fd6ccd5dbbe7a92852987ec1a64da)
#         ;
#
#
#
#
#             var marker_a9ddca8b94a3b72dbd75a0473bb47268 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d5f50419a8ab13105c75a2997eaee906);
#
#
#         var popup_9aae1deed3498c1efb505a05d75fc390 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54b0a24c6bcdbcdc53ddc686ce695483 = $(`&lt;div id=&quot;html_54b0a24c6bcdbcdc53ddc686ce695483&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9aae1deed3498c1efb505a05d75fc390.setContent(html_54b0a24c6bcdbcdc53ddc686ce695483);
#
#
#
#         marker_a9ddca8b94a3b72dbd75a0473bb47268.bindPopup(popup_9aae1deed3498c1efb505a05d75fc390)
#         ;
#
#
#
#
#             var marker_70c6f38a038a2219a13ab024ce076250 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d5f50419a8ab13105c75a2997eaee906);
#
#
#         var popup_1b96ebdfdd56e0c1585e1114823f63fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4d3c1cccb7e1ac6b3b2daf365b8ee19 = $(`&lt;div id=&quot;html_b4d3c1cccb7e1ac6b3b2daf365b8ee19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1b96ebdfdd56e0c1585e1114823f63fa.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e7fe7313de368438c490c25e09166325 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e7fe7313de368438c490c25e09166325&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e7fe7313de368438c490c25e09166325 = L.map(
#                 &quot;map_e7fe7313de368438c490c25e09166325&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d39d65a63e0fc510c5237f592616155 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d39d65a63e0fc510c5237f592616155.addTo(map_e7fe7313de368438c490c25e09166325);
#
#
#             var feature_group_e9eba942c0b139b8a0bffb79e81bc5dc = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_281bfd0616cbd6746f6bada93ece5bb3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_e9eba942c0b139b8a0bffb79e81bc5dc);
#
#
#         var popup_cf9fb941bc7b7f6ea851cfd0216d0d17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_63a7e56056dd2b9670dde9303bd27bcf = $(`&lt;div id=&quot;html_63a7e56056dd2b9670dde9303bd27bcf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cf9fb941bc7b7f6ea851cfd0216d0d17.setContent(html_63a7e56056dd2b9670dde9303bd27bcf);
#
#
#
#         marker_281bfd0616cbd6746f6bada93ece5bb3.bindPopup(popup_cf9fb941bc7b7f6ea851cfd0216d0d17)
#         ;
#
#
#
#
#             var marker_de60efea163a3e72d176db735938c3b0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_e9eba942c0b139b8a0bffb79e81bc5dc);
#
#
#         var popup_9fb9e9a60c5daa875e54d38c57815539 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41f163c27bdc4d7018e8751d40c26348 = $(`&lt;div id=&quot;html_41f163c27bdc4d7018e8751d40c26348&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9fb9e9a60c5daa875e54d38c57815539.setContent(html_41f163c27bdc4d7018e8751d40c26348);
#
#
#
#         marker_de60efea163a3e72d176db735938c3b0.bindPopup(popup_9fb9e9a60c5daa875e54d38c57815539)
#         ;
#
#
#
#
#             var marker_04f1c3665cfdfa023c8831319c51b231 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_e9eba942c0b139b8a0bffb79e81bc5dc);
#
#
#         var popup_2147c5a54cb7dc824e0d3a498b71cc42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aded672811f9952fba4b93c76fd470fa = $(`&lt;div id=&quot;html_aded672811f9952fba4b93c76fd470fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2147c5a54cb7dc824e0d3a498b71cc42.setContent(html_aded672811f9952fba4b93c76fd470fa);
#
#
#
#         marker_04f1c3665cfdfa023c8831319c51b231.bindPopup(popup_2147c5a54cb7dc824e0d3a498b71cc42)
#         ;
#
#
#
#
#             var marker_d6cfbe584bf3b209381d10a98be233ee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_e9eba942c0b139b8a0bffb79e81bc5dc);
#
#
#         var popup_89c777f6848b6c239ccbab6d7d4e63d1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a558120d5ab3db56085202b096f6d340 = $(`&lt;div id=&quot;html_a558120d5ab3db56085202b096f6d340&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_89c777f6848b6c239ccbab6d7d4e63d1.setContent(html_a558120d5ab3db56085202b096f6d340);
#
#
#
#         marker_d6cfbe584bf3b209381d10a98be233ee.bindPopup(popup_89c777f6848b6c239ccbab6d7d4e63d1)
#         ;
#
#
#
#
#             var marker_864642d231a0c58c80a778d20b9420c5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_e9eba942c0b139b8a0bffb79e81bc5dc);
#
#
#         var popup_0fdeb0f95f33a8f6ce6733d2ed2627dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3ab0df22ff22085e7468bb790f27711 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3ab0df22ff22085e7468bb790f27711&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3ab0df22ff22085e7468bb790f27711 = L.map(
#                 &quot;map_d3ab0df22ff22085e7468bb790f27711&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1978cdf7264f5c3ef427b7d6708a84f3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1978cdf7264f5c3ef427b7d6708a84f3.addTo(map_d3ab0df22ff22085e7468bb790f27711);
#
#
#             var feature_group_3a5db67a3c2008e11448ebe5c8410a3a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_3a5db67a3c2008e11448ebe5c8410a3a.addTo(map_d3ab0df22ff22085e7468bb790f27711);
#
#
#             var feature_group_sub_group_2e339016e4bbe17bc87aae36abed6ae9 = L.featureGroup.subGroup(
#                 feature_group_3a5db67a3c2008e11448ebe5c8410a3a
#             );
#
#
#             var marker_eaeca0c8b1e0ba0b8f2cf1791607a4dd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e339016e4bbe17bc87aae36abed6ae9);
#
#
#         var popup_173e9c134b757d076e66d125e644a060 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d73050e2514884beea719594c347195 = $(`&lt;div id=&quot;html_2d73050e2514884beea719594c347195&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_173e9c134b757d076e66d125e644a060.setContent(html_2d73050e2514884beea719594c347195);
#
#
#
#         marker_eaeca0c8b1e0ba0b8f2cf1791607a4dd.bindPopup(popup_173e9c134b757d076e66d125e644a060)
#         ;
#
#
#
#
#             var marker_483be3c4190817506a459e2e55ef059a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e339016e4bbe17bc87aae36abed6ae9);
#
#
#         var popup_ab858b7f9b2430d990d8a2a96357de1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8599773bd24b480a50db600950226fde = $(`&lt;div id=&quot;html_8599773bd24b480a50db600950226fde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ab858b7f9b2430d990d8a2a96357de1a.setContent(html_8599773bd24b480a50db600950226fde);
#
#
#
#         marker_483be3c4190817506a459e2e55ef059a.bindPopup(popup_ab858b7f9b2430d990d8a2a96357de1a)
#         ;
#
#
#
#
#             var marker_096d869026d9df4fbce2247a53353696 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e339016e4bbe17bc87aae36abed6ae9);
#
#
#         var popup_f475c56829546eb6e2111d8f1dd7842d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_795264eabd11ce57ec293f31129917ee = $(`&lt;div id=&quot;html_795264eabd11ce57ec293f31129917ee&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_f475c56829546eb6e2111d8f1dd7842d.setContent(html_795264eabd11ce57ec293f31129917ee);
#
#
#
#         marker_096d869026d9df4fbce2247a53353696.bindPopup(popup_f475c56829546eb6e2111d8f1dd7842d)
#         ;
#
#
#
#
#             var marker_98daea031f7e3976ea943334934bf360 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2e339016e4bbe17bc87aae36abed6ae9);
#
#
#         var popup_a36cd83437999c803b033e1b7137b72b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7a43ed51705aa5159ae6fcfc4a0b0a04 = $(`&lt;div id=&quot;html_7a43ed51705aa5159ae6fcfc4a0b0a04&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_a36cd83437999c803b033e1b7137b72b.setContent(html_7a43ed51705aa5159ae6fcfc4a0b0a04);
#
#
#
#         marker_
