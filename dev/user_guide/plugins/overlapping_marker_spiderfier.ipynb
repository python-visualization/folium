# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5c439071d968bdd0e43b95b3b434500 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5c439071d968bdd0e43b95b3b434500&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5c439071d968bdd0e43b95b3b434500 = L.map(
#                 &quot;map_f5c439071d968bdd0e43b95b3b434500&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e767b50e0c7c3aa91f55d77460dcb5bc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e767b50e0c7c3aa91f55d77460dcb5bc.addTo(map_f5c439071d968bdd0e43b95b3b434500);
#
#
#             var marker_f70bcb5ddd6b57fdb82312391eb1c322 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f5c439071d968bdd0e43b95b3b434500);
#
#
#         var popup_246d7b7e46bc21841e9ae08f978aa6ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e546aed447ab001b6316db8cd7e5ee1 = $(`&lt;div id=&quot;html_5e546aed447ab001b6316db8cd7e5ee1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_246d7b7e46bc21841e9ae08f978aa6ce.setContent(html_5e546aed447ab001b6316db8cd7e5ee1);
#
#
#
#         marker_f70bcb5ddd6b57fdb82312391eb1c322.bindPopup(popup_246d7b7e46bc21841e9ae08f978aa6ce)
#         ;
#
#
#
#
#             var marker_66e9ddf7a901f4d0d41db90d94ebeb67 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f5c439071d968bdd0e43b95b3b434500);
#
#
#         var popup_2946b7c9c1a69b8eac75e1109c005f16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c53702190998d9c6a44c43089968da2b = $(`&lt;div id=&quot;html_c53702190998d9c6a44c43089968da2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_2946b7c9c1a69b8eac75e1109c005f16.setContent(html_c53702190998d9c6a44c43089968da2b);
#
#
#
#         marker_66e9ddf7a901f4d0d41db90d94ebeb67.bindPopup(popup_2946b7c9c1a69b8eac75e1109c005f16)
#         ;
#
#
#
#
#             var marker_c0deaee5ac7b4416a2619a6c24952c4e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f5c439071d968bdd0e43b95b3b434500);
#
#
#         var popup_9a0c74a169fb0649ac22350da6f06de5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_37819c69716519e6012a777a35913698 = $(`&lt;div id=&quot;html_37819c69716519e6012a777a35913698&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9a0c74a169fb0649ac22350da6f06de5.setContent(html_37819c69716519e6012a777a35913698);
#
#
#
#         marker_c0deaee5ac7b4416a2619a6c24952c4e.bindPopup(popup_9a0c74a169fb0649ac22350da6f06de5)
#         ;
#
#
#
#
#             var marker_a37632be97f35a68921eb28e143ac30b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f5c439071d968bdd0e43b95b3b434500);
#
#
#         var popup_9ce1455e196823878d8e7386abbe151a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56b44ec8d426ad5cea4703a78550f7e6 = $(`&lt;div id=&quot;html_56b44ec8d426ad5cea4703a78550f7e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9ce1455e196823878d8e7386abbe151a.setContent(html_56b44ec8d426ad5cea4703a78550f7e6);
#
#
#
#         marker_a37632be97f35a68921eb28e143ac30b.bindPopup(popup_9ce1455e196823878d8e7386abbe151a)
#         ;
#
#
#
#
#             var marker_dcd60eb1fb50f45c80d1e11fdbc24c62 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f5c439071d968bdd0e43b95b3b434500);
#
#
#         var popup_0f010bd9d18e2f81830a836e0c7235db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_abde0948fde8a6d76fa2f40fbe0de974 = $(`&lt;div id=&quot;html_abde0948fde8a6d76fa2f40fbe0de974&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0f010bd9d18e2f81830a836e0c7235db.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0ccdd67d82b471211c05c44e39be7684 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0ccdd67d82b471211c05c44e39be7684&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0ccdd67d82b471211c05c44e39be7684 = L.map(
#                 &quot;map_0ccdd67d82b471211c05c44e39be7684&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05bc8c23cd441c997e3ad1cc4466166b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05bc8c23cd441c997e3ad1cc4466166b.addTo(map_0ccdd67d82b471211c05c44e39be7684);
#
#
#             var feature_group_0cf1b1de2ba18ee1a900c7356eb9fdd3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_12330dabcdc9ea61189be2c257a7d444 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0cf1b1de2ba18ee1a900c7356eb9fdd3);
#
#
#         var popup_366c32efc2005d5ad2d1fa9a8d6143fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50ad21b3b845a3a501e3a95d97d4086c = $(`&lt;div id=&quot;html_50ad21b3b845a3a501e3a95d97d4086c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_366c32efc2005d5ad2d1fa9a8d6143fd.setContent(html_50ad21b3b845a3a501e3a95d97d4086c);
#
#
#
#         marker_12330dabcdc9ea61189be2c257a7d444.bindPopup(popup_366c32efc2005d5ad2d1fa9a8d6143fd)
#         ;
#
#
#
#
#             var marker_0f6c6041a8e103010083c2dd8042dc62 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0cf1b1de2ba18ee1a900c7356eb9fdd3);
#
#
#         var popup_e5080e012ffbbcd4f1cd0bd23caf9684 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_364828e53286da7d6790687501e2b43f = $(`&lt;div id=&quot;html_364828e53286da7d6790687501e2b43f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e5080e012ffbbcd4f1cd0bd23caf9684.setContent(html_364828e53286da7d6790687501e2b43f);
#
#
#
#         marker_0f6c6041a8e103010083c2dd8042dc62.bindPopup(popup_e5080e012ffbbcd4f1cd0bd23caf9684)
#         ;
#
#
#
#
#             var marker_935351f1c2b554c92e8b6e81a5e14556 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0cf1b1de2ba18ee1a900c7356eb9fdd3);
#
#
#         var popup_9d442783d0ee2f3a8644bfde0b76a3f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e16a864bf9d5e2a51366cd4cd269e33f = $(`&lt;div id=&quot;html_e16a864bf9d5e2a51366cd4cd269e33f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_9d442783d0ee2f3a8644bfde0b76a3f3.setContent(html_e16a864bf9d5e2a51366cd4cd269e33f);
#
#
#
#         marker_935351f1c2b554c92e8b6e81a5e14556.bindPopup(popup_9d442783d0ee2f3a8644bfde0b76a3f3)
#         ;
#
#
#
#
#             var marker_b24436d5cce473568ab260604f7362b4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0cf1b1de2ba18ee1a900c7356eb9fdd3);
#
#
#         var popup_f90270930f96d2ba6e73f7b45bb1983a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9dc504f0b208e5e7ee2d049af3b5232f = $(`&lt;div id=&quot;html_9dc504f0b208e5e7ee2d049af3b5232f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f90270930f96d2ba6e73f7b45bb1983a.setContent(html_9dc504f0b208e5e7ee2d049af3b5232f);
#
#
#
#         marker_b24436d5cce473568ab260604f7362b4.bindPopup(popup_f90270930f96d2ba6e73f7b45bb1983a)
#         ;
#
#
#
#
#             var marker_553d8684af8e37c69e4df47821e935d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0cf1b1de2ba18ee1a900c7356eb9fdd3);
#
#
#         var popup_3ec6a9c400e7a330e97ddad729d325b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_026ac513676b339c50a50310f176f1a3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_026ac513676b339c50a50310f176f1a3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_026ac513676b339c50a50310f176f1a3 = L.map(
#                 &quot;map_026ac513676b339c50a50310f176f1a3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9ba7ed62b9eff69d77ff6aaf43c7f1f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9ba7ed62b9eff69d77ff6aaf43c7f1f0.addTo(map_026ac513676b339c50a50310f176f1a3);
#
#
#             var feature_group_d42cc67bb3571b88b83614c6010b10cc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d42cc67bb3571b88b83614c6010b10cc.addTo(map_026ac513676b339c50a50310f176f1a3);
#
#
#             var feature_group_sub_group_92bea913a5e37098344df711d27244d1 = L.featureGroup.subGroup(
#                 feature_group_d42cc67bb3571b88b83614c6010b10cc
#             );
#
#
#             var marker_77bffe8e2d3c0aeda85f559cda5eb7b8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_92bea913a5e37098344df711d27244d1);
#
#
#         var popup_8fd474fb436744af929e031f042b0179 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9074e58e2b42d41d35959da7a5071dfe = $(`&lt;div id=&quot;html_9074e58e2b42d41d35959da7a5071dfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8fd474fb436744af929e031f042b0179.setContent(html_9074e58e2b42d41d35959da7a5071dfe);
#
#
#
#         marker_77bffe8e2d3c0aeda85f559cda5eb7b8.bindPopup(popup_8fd474fb436744af929e031f042b0179)
#         ;
#
#
#
#
#             var marker_56f7ee184e6f705447f110ba6143fc94 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_92bea913a5e37098344df711d27244d1);
#
#
#         var popup_2799cbbab4e7af63b73e107150521cad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_172a3e6af6766c5afa9283d765e1f050 = $(`&lt;div id=&quot;html_172a3e6af6766c5afa9283d765e1f050&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2799cbbab4e7af63b73e107150521cad.setContent(html_172a3e6af6766c5afa9283d765e1f050);
#
#
#
#         marker_56f7ee184e6f705447f110ba6143fc94.bindPopup(popup_2799cbbab4e7af63b73e107150521cad)
#         ;
#
#
#
#
#             var marker_a7b8a7fb604ae6259119aa8d65e990a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_92bea913a5e37098344df711d27244d1);
#
#
#         var popup_b2885e7efaafc3d17ea02067e4d37023 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_276a45a445cf8a3271a77462a2ab60d2 = $(`&lt;div id=&quot;html_276a45a445cf8a3271a77462a2ab60d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b2885e7efaafc3d17ea02067e4d37023.setContent(html_276a45a445cf8a3271a77462a2ab60d2);
#
#
#
#         marker_a7b8a7fb604ae6259119aa8d65e990a4.bindPopup(popup_b2885e7efaafc3d17ea02067e4d37023)
#         ;
#
#
#
#
#             var marker_a1418f695ad14b5544465fc2226fd7b6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_92bea913a5e37098344df711d27244d1);
#
#
#         var popup_fee7ba8be34e9993f28c25042d730841 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_559a0865cb52dd9a91104516f4dbf4c7 = $(`&lt;div id=&quot;html_559a0865cb52dd9a91104516f4dbf4c7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fee7ba8be34e9993f28c25042d730841.setContent(html_559a0865cb52dd9a91104516f4dbf4c7);
#
#
#
#         marker_
