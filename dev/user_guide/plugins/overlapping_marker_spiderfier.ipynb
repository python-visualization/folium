# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3a7016cb323517cc2f8159dafa367d2e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3a7016cb323517cc2f8159dafa367d2e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3a7016cb323517cc2f8159dafa367d2e = L.map(
#                 &quot;map_3a7016cb323517cc2f8159dafa367d2e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba82c4c73f6b7166965db47c4859b86f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba82c4c73f6b7166965db47c4859b86f.addTo(map_3a7016cb323517cc2f8159dafa367d2e);
#
#
#             var marker_cf93f7f1ad93a2bac4f5f6f2bc977b7f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3a7016cb323517cc2f8159dafa367d2e);
#
#
#         var popup_81d54a977fb3d23a3ac508194053fb77 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b9e433fbcc222a1bdacc0b76ffe1869 = $(`&lt;div id=&quot;html_3b9e433fbcc222a1bdacc0b76ffe1869&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_81d54a977fb3d23a3ac508194053fb77.setContent(html_3b9e433fbcc222a1bdacc0b76ffe1869);
#
#
#
#         marker_cf93f7f1ad93a2bac4f5f6f2bc977b7f.bindPopup(popup_81d54a977fb3d23a3ac508194053fb77)
#         ;
#
#
#
#
#             var marker_aaf64d3220701c91b601f4fe887e2d09 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3a7016cb323517cc2f8159dafa367d2e);
#
#
#         var popup_a7be6808ef3e9582787e4c0f5a270adb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1c5c408d9c3185d63bd947ea7f43846b = $(`&lt;div id=&quot;html_1c5c408d9c3185d63bd947ea7f43846b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a7be6808ef3e9582787e4c0f5a270adb.setContent(html_1c5c408d9c3185d63bd947ea7f43846b);
#
#
#
#         marker_aaf64d3220701c91b601f4fe887e2d09.bindPopup(popup_a7be6808ef3e9582787e4c0f5a270adb)
#         ;
#
#
#
#
#             var marker_29dfbc1472b2069f0b06c43fb6353942 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3a7016cb323517cc2f8159dafa367d2e);
#
#
#         var popup_e4466ea8092cecb07a72a7bfdc6a5a09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13469d57306f3508020fac061e93b9f7 = $(`&lt;div id=&quot;html_13469d57306f3508020fac061e93b9f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e4466ea8092cecb07a72a7bfdc6a5a09.setContent(html_13469d57306f3508020fac061e93b9f7);
#
#
#
#         marker_29dfbc1472b2069f0b06c43fb6353942.bindPopup(popup_e4466ea8092cecb07a72a7bfdc6a5a09)
#         ;
#
#
#
#
#             var marker_794c8a8b5302d059cead3ebe17ee6163 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3a7016cb323517cc2f8159dafa367d2e);
#
#
#         var popup_ac63cbd79ecce407f11d12724177375c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84a148abd05aa65e2773e0e7ffc2e105 = $(`&lt;div id=&quot;html_84a148abd05aa65e2773e0e7ffc2e105&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ac63cbd79ecce407f11d12724177375c.setContent(html_84a148abd05aa65e2773e0e7ffc2e105);
#
#
#
#         marker_794c8a8b5302d059cead3ebe17ee6163.bindPopup(popup_ac63cbd79ecce407f11d12724177375c)
#         ;
#
#
#
#
#             var marker_492a35c51675a4b5e0ae2b1f346810ad = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3a7016cb323517cc2f8159dafa367d2e);
#
#
#         var popup_f28af74bcb31593b4e774fdb4465c69d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77ec5561e8d6b67d4ddc6f511e738524 = $(`&lt;div id=&quot;html_77ec5561e8d6b67d4ddc6f511e738524&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f28af74bcb31593b4e774fdb4465c69d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bc3d8c824f0acf9ebf7c6136750af5e9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bc3d8c824f0acf9ebf7c6136750af5e9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bc3d8c824f0acf9ebf7c6136750af5e9 = L.map(
#                 &quot;map_bc3d8c824f0acf9ebf7c6136750af5e9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0a96dce1d7cbbb4abc172242852b6c63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0a96dce1d7cbbb4abc172242852b6c63.addTo(map_bc3d8c824f0acf9ebf7c6136750af5e9);
#
#
#             var feature_group_4cd07c8117f0730ac8af93a327a3d373 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_02d9f0086a6d89f09a5f27da98420a3b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4cd07c8117f0730ac8af93a327a3d373);
#
#
#         var popup_b07ec4b651fee24fc82d3e4bbe871d3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a02dcf3f897bc80fae85095d94ff249 = $(`&lt;div id=&quot;html_1a02dcf3f897bc80fae85095d94ff249&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b07ec4b651fee24fc82d3e4bbe871d3a.setContent(html_1a02dcf3f897bc80fae85095d94ff249);
#
#
#
#         marker_02d9f0086a6d89f09a5f27da98420a3b.bindPopup(popup_b07ec4b651fee24fc82d3e4bbe871d3a)
#         ;
#
#
#
#
#             var marker_7030a2543f35b2675b2161a824c7de0e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4cd07c8117f0730ac8af93a327a3d373);
#
#
#         var popup_3446fc8ba2127091fe5a971e3897e259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f1a7ca159f4ccd5f403810db3a07e39 = $(`&lt;div id=&quot;html_4f1a7ca159f4ccd5f403810db3a07e39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3446fc8ba2127091fe5a971e3897e259.setContent(html_4f1a7ca159f4ccd5f403810db3a07e39);
#
#
#
#         marker_7030a2543f35b2675b2161a824c7de0e.bindPopup(popup_3446fc8ba2127091fe5a971e3897e259)
#         ;
#
#
#
#
#             var marker_899117731fea5de1a1c9b181fd7b8c57 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4cd07c8117f0730ac8af93a327a3d373);
#
#
#         var popup_4dbc5c30d5f599879db7cfa6b8c26074 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2f616d6edbe3085f4f7d3f86e3c1a04c = $(`&lt;div id=&quot;html_2f616d6edbe3085f4f7d3f86e3c1a04c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_4dbc5c30d5f599879db7cfa6b8c26074.setContent(html_2f616d6edbe3085f4f7d3f86e3c1a04c);
#
#
#
#         marker_899117731fea5de1a1c9b181fd7b8c57.bindPopup(popup_4dbc5c30d5f599879db7cfa6b8c26074)
#         ;
#
#
#
#
#             var marker_9b0ec5b397331129f778e559ea848219 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4cd07c8117f0730ac8af93a327a3d373);
#
#
#         var popup_4f566150524ef327ee48ab4e3c1f9873 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f291f061e14bd9b9c069a8e9a5726e9 = $(`&lt;div id=&quot;html_1f291f061e14bd9b9c069a8e9a5726e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4f566150524ef327ee48ab4e3c1f9873.setContent(html_1f291f061e14bd9b9c069a8e9a5726e9);
#
#
#
#         marker_9b0ec5b397331129f778e559ea848219.bindPopup(popup_4f566150524ef327ee48ab4e3c1f9873)
#         ;
#
#
#
#
#             var marker_d7edf3d17a075b1b5d3dd6f0a0110276 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4cd07c8117f0730ac8af93a327a3d373);
#
#
#         var popup_4cdfb62d0e201a90f63eb4864def45a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9f7f232e8db04e8e0b5420176a624642 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9f7f232e8db04e8e0b5420176a624642&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9f7f232e8db04e8e0b5420176a624642 = L.map(
#                 &quot;map_9f7f232e8db04e8e0b5420176a624642&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c2d14405866a90b14de854ab4b2a8e6c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c2d14405866a90b14de854ab4b2a8e6c.addTo(map_9f7f232e8db04e8e0b5420176a624642);
#
#
#             var feature_group_6c8880eb2cde9b2b78040de542b8f420 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6c8880eb2cde9b2b78040de542b8f420.addTo(map_9f7f232e8db04e8e0b5420176a624642);
#
#
#             var feature_group_sub_group_8c2a786a2837026de3366371abd8adb2 = L.featureGroup.subGroup(
#                 feature_group_6c8880eb2cde9b2b78040de542b8f420
#             );
#
#
#             var marker_5825af6955a7de74a395b5bbff570b9f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c2a786a2837026de3366371abd8adb2);
#
#
#         var popup_3b00c45411ba39f4710623c17d6afed8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5874d28d33f69e22ee4f31eab8ea608f = $(`&lt;div id=&quot;html_5874d28d33f69e22ee4f31eab8ea608f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3b00c45411ba39f4710623c17d6afed8.setContent(html_5874d28d33f69e22ee4f31eab8ea608f);
#
#
#
#         marker_5825af6955a7de74a395b5bbff570b9f.bindPopup(popup_3b00c45411ba39f4710623c17d6afed8)
#         ;
#
#
#
#
#             var marker_e102d0b0c40eda6b6dfb64a368c89354 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c2a786a2837026de3366371abd8adb2);
#
#
#         var popup_0209ec972382d0c7e5d5db3166f95a83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3c2b0cdfecfc67d31ad8c946cb9b309 = $(`&lt;div id=&quot;html_b3c2b0cdfecfc67d31ad8c946cb9b309&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0209ec972382d0c7e5d5db3166f95a83.setContent(html_b3c2b0cdfecfc67d31ad8c946cb9b309);
#
#
#
#         marker_e102d0b0c40eda6b6dfb64a368c89354.bindPopup(popup_0209ec972382d0c7e5d5db3166f95a83)
#         ;
#
#
#
#
#             var marker_c900058a2477e4883bc3af3cd4a2c997 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c2a786a2837026de3366371abd8adb2);
#
#
#         var popup_7db01c8838a1ccb76e94ad7d6139f73b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_19d0a795dbf66c3aaac054556a374668 = $(`&lt;div id=&quot;html_19d0a795dbf66c3aaac054556a374668&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7db01c8838a1ccb76e94ad7d6139f73b.setContent(html_19d0a795dbf66c3aaac054556a374668);
#
#
#
#         marker_c900058a2477e4883bc3af3cd4a2c997.bindPopup(popup_7db01c8838a1ccb76e94ad7d6139f73b)
#         ;
#
#
#
#
#             var marker_18680c5e998b0ba4e1a835cfc63d24cc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8c2a786a2837026de3366371abd8adb2);
#
#
#         var popup_bc0298623e17e9aae4e4037e913c2d55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb430e5229fdbdf1dcbdf9a5b505722c = $(`&lt;div id=&quot;html_fb430e5229fdbdf1dcbdf9a5b505722c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_bc0298623e17e9aae4e4037e913c2d55.setContent(html_fb430e5229fdbdf1dcbdf9a5b505722c);
#
#
#
#         marker_
