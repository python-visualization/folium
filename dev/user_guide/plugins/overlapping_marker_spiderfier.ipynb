# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5eeba407882ff44d62c967783217c143 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5eeba407882ff44d62c967783217c143&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5eeba407882ff44d62c967783217c143 = L.map(
#                 &quot;map_5eeba407882ff44d62c967783217c143&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fe2a5ea0eb13da702c61fdf5210077a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4fe2a5ea0eb13da702c61fdf5210077a.addTo(map_5eeba407882ff44d62c967783217c143);
#
#
#             var marker_c6fd11383bb85a6a13834e0c0396520f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5eeba407882ff44d62c967783217c143);
#
#
#         var popup_745209387de428252885901fca6c64e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8e4c75ae68f3d85a34428180829ae0cf = $(`&lt;div id=&quot;html_8e4c75ae68f3d85a34428180829ae0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_745209387de428252885901fca6c64e1.setContent(html_8e4c75ae68f3d85a34428180829ae0cf);
#
#
#
#         marker_c6fd11383bb85a6a13834e0c0396520f.bindPopup(popup_745209387de428252885901fca6c64e1)
#         ;
#
#
#
#
#             var marker_94bcfde4978c48b6b87f9826d47fd58b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5eeba407882ff44d62c967783217c143);
#
#
#         var popup_d5c6e00cc1517760d6dcb64c08e3378f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7ebc3838bef06b7aaab763790fc04c6f = $(`&lt;div id=&quot;html_7ebc3838bef06b7aaab763790fc04c6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d5c6e00cc1517760d6dcb64c08e3378f.setContent(html_7ebc3838bef06b7aaab763790fc04c6f);
#
#
#
#         marker_94bcfde4978c48b6b87f9826d47fd58b.bindPopup(popup_d5c6e00cc1517760d6dcb64c08e3378f)
#         ;
#
#
#
#
#             var marker_92707baf60750c65210b9e8637d25a66 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5eeba407882ff44d62c967783217c143);
#
#
#         var popup_d5aca3f983a8f4c49d838a59738a2781 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ee335727597d13626ee57651a13d6e4 = $(`&lt;div id=&quot;html_9ee335727597d13626ee57651a13d6e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d5aca3f983a8f4c49d838a59738a2781.setContent(html_9ee335727597d13626ee57651a13d6e4);
#
#
#
#         marker_92707baf60750c65210b9e8637d25a66.bindPopup(popup_d5aca3f983a8f4c49d838a59738a2781)
#         ;
#
#
#
#
#             var marker_dd43671df4ed7902ee72bdf6c620e1f7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5eeba407882ff44d62c967783217c143);
#
#
#         var popup_bedf88d982f1d3a311c4b2caf7d692b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da0a1809667fa42ced4944a87d129e4f = $(`&lt;div id=&quot;html_da0a1809667fa42ced4944a87d129e4f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bedf88d982f1d3a311c4b2caf7d692b6.setContent(html_da0a1809667fa42ced4944a87d129e4f);
#
#
#
#         marker_dd43671df4ed7902ee72bdf6c620e1f7.bindPopup(popup_bedf88d982f1d3a311c4b2caf7d692b6)
#         ;
#
#
#
#
#             var marker_752a3f83845b4dfb00d2788c9389c63e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5eeba407882ff44d62c967783217c143);
#
#
#         var popup_1099d957b79c9bfe65805ab3fcbde45c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d0e968053bcb4fe2fe194e3bd65a1f7 = $(`&lt;div id=&quot;html_1d0e968053bcb4fe2fe194e3bd65a1f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1099d957b79c9bfe65805ab3fcbde45c.setContent(html_1d0e968053bcb4fe2fe194e3bd65a1f7);
#
#
#
#         marker_752a3f83845b4dfb00d2788c9389c63e.bindPopup(popup_1099d957b79c9bfe65805ab3fcbde45c)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_14d6c16af4428cf4966085e03ea0e4f6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_14d6c16af4428cf4966085e03ea0e4f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_14d6c16af4428cf4966085e03ea0e4f6 = L.map(
#                 &quot;map_14d6c16af4428cf4966085e03ea0e4f6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5551ea55d19a018814f6ec0a34134c3d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5551ea55d19a018814f6ec0a34134c3d.addTo(map_14d6c16af4428cf4966085e03ea0e4f6);
#
#
#             var feature_group_4912dc1f938a6a4e0df0656bf08abe62 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_76e4714d035b452c8215bdb23bd4a32e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4912dc1f938a6a4e0df0656bf08abe62);
#
#
#         var popup_3f4c5ce8392bb91c67d20c4407baf57f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83a54bebb95967ecd42922c72c7367cc = $(`&lt;div id=&quot;html_83a54bebb95967ecd42922c72c7367cc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3f4c5ce8392bb91c67d20c4407baf57f.setContent(html_83a54bebb95967ecd42922c72c7367cc);
#
#
#
#         marker_76e4714d035b452c8215bdb23bd4a32e.bindPopup(popup_3f4c5ce8392bb91c67d20c4407baf57f)
#         ;
#
#
#
#
#             var marker_e1e53c9dd45b781e1c81a1bb1750ac01 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4912dc1f938a6a4e0df0656bf08abe62);
#
#
#         var popup_330881480fb7960a514299c7d3724455 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c9525de180dd8aed9c73223c03bfd30 = $(`&lt;div id=&quot;html_0c9525de180dd8aed9c73223c03bfd30&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_330881480fb7960a514299c7d3724455.setContent(html_0c9525de180dd8aed9c73223c03bfd30);
#
#
#
#         marker_e1e53c9dd45b781e1c81a1bb1750ac01.bindPopup(popup_330881480fb7960a514299c7d3724455)
#         ;
#
#
#
#
#             var marker_d448d85b39c7713f93d5b0ecddd33588 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4912dc1f938a6a4e0df0656bf08abe62);
#
#
#         var popup_cfff02f7f4761a34530814d52926b84e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7d1fed9836efbd5fc5010a54da148ec = $(`&lt;div id=&quot;html_a7d1fed9836efbd5fc5010a54da148ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cfff02f7f4761a34530814d52926b84e.setContent(html_a7d1fed9836efbd5fc5010a54da148ec);
#
#
#
#         marker_d448d85b39c7713f93d5b0ecddd33588.bindPopup(popup_cfff02f7f4761a34530814d52926b84e)
#         ;
#
#
#
#
#             var marker_09b1b0e9cacade6fa453a71a03cf6c08 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4912dc1f938a6a4e0df0656bf08abe62);
#
#
#         var popup_3c00dea748bfc465da3f5df35b26342a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9ba08c5f539813ec7794b984bd51fdc0 = $(`&lt;div id=&quot;html_9ba08c5f539813ec7794b984bd51fdc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3c00dea748bfc465da3f5df35b26342a.setContent(html_9ba08c5f539813ec7794b984bd51fdc0);
#
#
#
#         marker_09b1b0e9cacade6fa453a71a03cf6c08.bindPopup(popup_3c00dea748bfc465da3f5df35b26342a)
#         ;
#
#
#
#
#             var marker_b334dc4883a6ea720b4b0ff87e3d73ee = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4912dc1f938a6a4e0df0656bf08abe62);
#
#
#         var popup_daa125a3ef8360fa34e69dcc64f0b20d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f8b0e2d8027d554901cb8b909fc2014 = $(`&lt;div id=&quot;html_6f8b0e2d8027d554901cb8b909fc2014&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.4/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_59bd1cc7d02948291c0054f4f7d7efd6 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_59bd1cc7d02948291c0054f4f7d7efd6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_59bd1cc7d02948291c0054f4f7d7efd6 = L.map(
#                 &quot;map_59bd1cc7d02948291c0054f4f7d7efd6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_da225cde6e776fbf0ef1bb01a0204cab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_da225cde6e776fbf0ef1bb01a0204cab.addTo(map_59bd1cc7d02948291c0054f4f7d7efd6);
#
#
#             var feature_group_47e64e15736ca2f142bd070a711e0486 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_47e64e15736ca2f142bd070a711e0486.addTo(map_59bd1cc7d02948291c0054f4f7d7efd6);
#
#
#             var feature_group_sub_group_df13f21fbc7e8efdb8b8e3a26c83b132 = L.featureGroup.subGroup(
#                 feature_group_47e64e15736ca2f142bd070a711e0486
#             );
#
#
#             var marker_e13e73a6720011722a14c9a5c06ab6f3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_df13f21fbc7e8efdb8b8e3a26c83b132);
#
#
#         var popup_1cd8aab3df5557d047f2ece66c2cdaf4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b112547e8083425b9f40196cd1a193fd = $(`&lt;div id=&quot;html_b112547e8083425b9f40196cd1a193fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1cd8aab3df5557d047f2ece66c2cdaf4.setContent(html_b112547e8083425b9f40196cd1a193fd);
#
#
#
#         marker_e13e73a6720011722a14c9a5c06ab6f3.bindPopup(popup_1cd8aab3df5557d047f2ece66c2cdaf4)
#         ;
#
#
#
#
#             var marker_cb1efce6fe4f5abb6997185a05600207 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_df13f21fbc7e8efdb8b8e3a26c83b132);
#
#
#         var popup_7cf59562e35a61f66447c0acb6e1707f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bec4e33e6cadfe745a112696517107e9 = $(`&lt;div id=&quot;html_bec4e33e6cadfe745a112696517107e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7cf59562e35a61f66447c0acb6e1707f.setContent(html_bec4e33e6cadfe745a112696517107e9);
#
#
#
#         marker_cb1efce6fe4f5abb6997185a05600207.bindPopup(popup_7cf59562e35a61f66447c0acb6e1707f)
#         ;
#
#
#
#
#             var marker_969164dd6661ac32d22419f449a15db5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_df13f21fbc7e8efdb8b8e3a26c83b132);
#
#
#         var popup_afca5d1b886dc6ee167f736db3c6700f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6377f8a70e762094bee57fbf6087787 = $(`&lt;div id=&quot;html_f6377f8a70e762094bee57fbf6087787&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_afca5d1b886dc6ee167f736db3c6700f.setContent(html_f6377f8a70e762094bee57fbf6087787);
#
#
#
#         marker_969164dd6661ac32d22419f449a15db5.bindPopup(popup_afca5d1b886dc6ee167f736db3c6700f)
#         ;
#
#
#
#
#             var marker_d8c6654fb85eb4af1682dd5a01b540ee = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_df13f21fbc7e8efdb8b8e3a26c83b132);
#
#
#         var popup_96fdbf33b3fbf5be647153439169e713 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2bfa527fdfdc4abfe92ad00ea098d39 = $(`&lt;div id=&quot;html_c2bfa527fdfdc4abfe92ad00ea098d39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_96fdbf33b3fbf5be647153439169e713.setContent(html_c2bfa527fdfdc4abfe92ad00ea098d39);
#
#
#
#         marker_d8c6654fb85eb4af1682dd5a01b540ee.bindPopup(popup_96fdbf33b3fbf5be647153439169e713)
#         ;
#
#
#
#
#             var marker_e950d8d22ee480ed156bf528278b41b4 = L.marker(
#                 [45.0503999
