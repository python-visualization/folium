# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab260437d541da9f4287575274753af5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab260437d541da9f4287575274753af5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab260437d541da9f4287575274753af5 = L.map(
#                 &quot;map_ab260437d541da9f4287575274753af5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ea9ba07ced02fb874f8dec5d9bdadc5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ea9ba07ced02fb874f8dec5d9bdadc5.addTo(map_ab260437d541da9f4287575274753af5);
#
#
#             var marker_0f3ef31f18fa72a0419224e7330264ab = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ab260437d541da9f4287575274753af5);
#
#
#         var popup_e3b10113c626d120c92da00ac9dc8c1e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aec821c3d47870bd283fe8b37aa6ea12 = $(`&lt;div id=&quot;html_aec821c3d47870bd283fe8b37aa6ea12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e3b10113c626d120c92da00ac9dc8c1e.setContent(html_aec821c3d47870bd283fe8b37aa6ea12);
#
#
#
#         marker_0f3ef31f18fa72a0419224e7330264ab.bindPopup(popup_e3b10113c626d120c92da00ac9dc8c1e)
#         ;
#
#
#
#
#             var marker_de2eec26dce7eaed5f5c68f91814bfd4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ab260437d541da9f4287575274753af5);
#
#
#         var popup_6f3fb5f847cdee1c59ce2c40e6b5bac8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76de1fb66e0509ecc04f3c097d31165a = $(`&lt;div id=&quot;html_76de1fb66e0509ecc04f3c097d31165a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6f3fb5f847cdee1c59ce2c40e6b5bac8.setContent(html_76de1fb66e0509ecc04f3c097d31165a);
#
#
#
#         marker_de2eec26dce7eaed5f5c68f91814bfd4.bindPopup(popup_6f3fb5f847cdee1c59ce2c40e6b5bac8)
#         ;
#
#
#
#
#             var marker_1cb5da4e9d437b3fa83dc1547be4e7b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ab260437d541da9f4287575274753af5);
#
#
#         var popup_807a35548229e52145998b223be1d795 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4fabe3247c2da150f6da592d245ebe4 = $(`&lt;div id=&quot;html_d4fabe3247c2da150f6da592d245ebe4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_807a35548229e52145998b223be1d795.setContent(html_d4fabe3247c2da150f6da592d245ebe4);
#
#
#
#         marker_1cb5da4e9d437b3fa83dc1547be4e7b4.bindPopup(popup_807a35548229e52145998b223be1d795)
#         ;
#
#
#
#
#             var marker_8ba00e8204d4b392e6d77e7ae386d5a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ab260437d541da9f4287575274753af5);
#
#
#         var popup_541c1573b059039f14870eba28f4d410 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3bddb9bdc6c7bf72b2a4c88c95dc36a4 = $(`&lt;div id=&quot;html_3bddb9bdc6c7bf72b2a4c88c95dc36a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_541c1573b059039f14870eba28f4d410.setContent(html_3bddb9bdc6c7bf72b2a4c88c95dc36a4);
#
#
#
#         marker_8ba00e8204d4b392e6d77e7ae386d5a3.bindPopup(popup_541c1573b059039f14870eba28f4d410)
#         ;
#
#
#
#
#             var marker_25a5aa3967411347692390913fdd35c3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ab260437d541da9f4287575274753af5);
#
#
#         var popup_5429ece7612962383c5f60908e0e6842 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff9c6b5fcbb64423f759da3bf0d8ad3c = $(`&lt;div id=&quot;html_ff9c6b5fcbb64423f759da3bf0d8ad3c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5429ece7612962383c5f60908e0e6842.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a0b64f835285e0b484dd5661d26f9926 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a0b64f835285e0b484dd5661d26f9926&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a0b64f835285e0b484dd5661d26f9926 = L.map(
#                 &quot;map_a0b64f835285e0b484dd5661d26f9926&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df8ba6a9170e2b72cc1c27bdb8b6ee29 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df8ba6a9170e2b72cc1c27bdb8b6ee29.addTo(map_a0b64f835285e0b484dd5661d26f9926);
#
#
#             var feature_group_721243c0941a7430b294f3151aac8e24 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d02c916feba964149a5450fa882bac5a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_721243c0941a7430b294f3151aac8e24);
#
#
#         var popup_6fdf09b3ca3eeed123b8aeaa2f9732c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da4e25ac3cd26462b1707c5f79f6621f = $(`&lt;div id=&quot;html_da4e25ac3cd26462b1707c5f79f6621f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6fdf09b3ca3eeed123b8aeaa2f9732c7.setContent(html_da4e25ac3cd26462b1707c5f79f6621f);
#
#
#
#         marker_d02c916feba964149a5450fa882bac5a.bindPopup(popup_6fdf09b3ca3eeed123b8aeaa2f9732c7)
#         ;
#
#
#
#
#             var marker_ebb4ea7e591f1a992addb8baca8eca27 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_721243c0941a7430b294f3151aac8e24);
#
#
#         var popup_66286d635a1ae2ddbcc11f3c9c749d2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f47518ffd86ed8689666ae47de05ba0 = $(`&lt;div id=&quot;html_9f47518ffd86ed8689666ae47de05ba0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_66286d635a1ae2ddbcc11f3c9c749d2d.setContent(html_9f47518ffd86ed8689666ae47de05ba0);
#
#
#
#         marker_ebb4ea7e591f1a992addb8baca8eca27.bindPopup(popup_66286d635a1ae2ddbcc11f3c9c749d2d)
#         ;
#
#
#
#
#             var marker_d1c286953fd3683c48a2bd4dbda7f01b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_721243c0941a7430b294f3151aac8e24);
#
#
#         var popup_2278c5e3126ad4576f2506a7cc562fd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62f520b77204f8bd2edfc4862f63fdd8 = $(`&lt;div id=&quot;html_62f520b77204f8bd2edfc4862f63fdd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2278c5e3126ad4576f2506a7cc562fd2.setContent(html_62f520b77204f8bd2edfc4862f63fdd8);
#
#
#
#         marker_d1c286953fd3683c48a2bd4dbda7f01b.bindPopup(popup_2278c5e3126ad4576f2506a7cc562fd2)
#         ;
#
#
#
#
#             var marker_98d8a21eece20b10b8cb233502ae3da7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_721243c0941a7430b294f3151aac8e24);
#
#
#         var popup_245784b99d8b6244d853b350e80f7140 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9368af5d479f92f699a39b6d7b1c4d6 = $(`&lt;div id=&quot;html_f9368af5d479f92f699a39b6d7b1c4d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_245784b99d8b6244d853b350e80f7140.setContent(html_f9368af5d479f92f699a39b6d7b1c4d6);
#
#
#
#         marker_98d8a21eece20b10b8cb233502ae3da7.bindPopup(popup_245784b99d8b6244d853b350e80f7140)
#         ;
#
#
#
#
#             var marker_a1bd7a32f29259f20eb63b3c88f39365 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_721243c0941a7430b294f3151aac8e24);
#
#
#         var popup_cfeb050bb6e1480f9917924fd590a692 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_193217e08c5ae09d86f41bf0fd20fb93 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_193217e08c5ae09d86f41bf0fd20fb93&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_193217e08c5ae09d86f41bf0fd20fb93 = L.map(
#                 &quot;map_193217e08c5ae09d86f41bf0fd20fb93&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48cda28043434a10bf19311ef888d7d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48cda28043434a10bf19311ef888d7d9.addTo(map_193217e08c5ae09d86f41bf0fd20fb93);
#
#
#             var feature_group_fe56392a8671c09c78196510c8f0debd = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fe56392a8671c09c78196510c8f0debd.addTo(map_193217e08c5ae09d86f41bf0fd20fb93);
#
#
#             var feature_group_sub_group_dfe66260d796f85a95b4b18ee0c90f9f = L.featureGroup.subGroup(
#                 feature_group_fe56392a8671c09c78196510c8f0debd
#             );
#
#
#             var marker_a719e0004ad2b10c258ed74faf95a1fb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_dfe66260d796f85a95b4b18ee0c90f9f);
#
#
#         var popup_1b4fbd3983f974e10c6f238f585e2a3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73f68235dd904d4ab96071f36297818a = $(`&lt;div id=&quot;html_73f68235dd904d4ab96071f36297818a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1b4fbd3983f974e10c6f238f585e2a3f.setContent(html_73f68235dd904d4ab96071f36297818a);
#
#
#
#         marker_a719e0004ad2b10c258ed74faf95a1fb.bindPopup(popup_1b4fbd3983f974e10c6f238f585e2a3f)
#         ;
#
#
#
#
#             var marker_0e851358c1157b73ce45ca326f2288b3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_dfe66260d796f85a95b4b18ee0c90f9f);
#
#
#         var popup_3d0e8acb21c8250a3d9825c897548c12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c33e352507d1bc38e49d011acdb24491 = $(`&lt;div id=&quot;html_c33e352507d1bc38e49d011acdb24491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3d0e8acb21c8250a3d9825c897548c12.setContent(html_c33e352507d1bc38e49d011acdb24491);
#
#
#
#         marker_0e851358c1157b73ce45ca326f2288b3.bindPopup(popup_3d0e8acb21c8250a3d9825c897548c12)
#         ;
#
#
#
#
#             var marker_62573378f9db765d54ffb4e111aecb5a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_dfe66260d796f85a95b4b18ee0c90f9f);
#
#
#         var popup_9984be9ddd37dc2d7849cfad7f0cc769 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbc538f1a2c56f73392437c0b4e2cbfd = $(`&lt;div id=&quot;html_dbc538f1a2c56f73392437c0b4e2cbfd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_9984be9ddd37dc2d7849cfad7f0cc769.setContent(html_dbc538f1a2c56f73392437c0b4e2cbfd);
#
#
#
#         marker_62573378f9db765d54ffb4e111aecb5a.bindPopup(popup_9984be9ddd37dc2d7849cfad7f0cc769)
#         ;
#
#
#
#
#             var marker_6d0d20060c48e8bcf570ffe656e53fd1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_dfe66260d796f85a95b4b18ee0c90f9f);
#
#
#         var popup_06d26bf2f4a7d1d5282a3794b3c50596 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32a124d8e6f1339147496ae5c28dc53a = $(`&lt;div id=&quot;html_32a124d8e6f1339147496ae5c28dc53a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_06d26bf2f4a7d1d5282a3794b3c50596.setContent(html_32a124d8e6f1339147496ae5c28dc53a);
#
#
#
#         marker_
