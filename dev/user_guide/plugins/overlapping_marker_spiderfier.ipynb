# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_114163761f7e77b59fa480690ba0a130 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_114163761f7e77b59fa480690ba0a130&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_114163761f7e77b59fa480690ba0a130 = L.map(
#                 &quot;map_114163761f7e77b59fa480690ba0a130&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_008d5891c89038f6435dc84e22329407 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_008d5891c89038f6435dc84e22329407.addTo(map_114163761f7e77b59fa480690ba0a130);
#
#
#             var marker_44ca07e05840759d8ccd96e484124d7e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_114163761f7e77b59fa480690ba0a130);
#
#
#         var popup_38947a2352953552381c47349cbd3aee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d093deda893288e91bf7dcadb89be59 = $(`&lt;div id=&quot;html_6d093deda893288e91bf7dcadb89be59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_38947a2352953552381c47349cbd3aee.setContent(html_6d093deda893288e91bf7dcadb89be59);
#
#
#
#         marker_44ca07e05840759d8ccd96e484124d7e.bindPopup(popup_38947a2352953552381c47349cbd3aee)
#         ;
#
#
#
#
#             var marker_c0bddb4e371e22a86e9f7fdf60168fb6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_114163761f7e77b59fa480690ba0a130);
#
#
#         var popup_38a3ecf0df9c0407dcf1e01ad3b9c4e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f50e3a28cc6da51f5d8aabd5b2a76f8f = $(`&lt;div id=&quot;html_f50e3a28cc6da51f5d8aabd5b2a76f8f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_38a3ecf0df9c0407dcf1e01ad3b9c4e8.setContent(html_f50e3a28cc6da51f5d8aabd5b2a76f8f);
#
#
#
#         marker_c0bddb4e371e22a86e9f7fdf60168fb6.bindPopup(popup_38a3ecf0df9c0407dcf1e01ad3b9c4e8)
#         ;
#
#
#
#
#             var marker_fe49ab29bb6b420ba941ee7d9d166f5a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_114163761f7e77b59fa480690ba0a130);
#
#
#         var popup_95e3de9ffec4caaba890e5daee4148b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fbc3c53655d21a6b49da394fa77398c = $(`&lt;div id=&quot;html_9fbc3c53655d21a6b49da394fa77398c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_95e3de9ffec4caaba890e5daee4148b9.setContent(html_9fbc3c53655d21a6b49da394fa77398c);
#
#
#
#         marker_fe49ab29bb6b420ba941ee7d9d166f5a.bindPopup(popup_95e3de9ffec4caaba890e5daee4148b9)
#         ;
#
#
#
#
#             var marker_b76d83932a3f1344b16951dd3160703a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_114163761f7e77b59fa480690ba0a130);
#
#
#         var popup_13b6dc47eb3288a9510a49fa1b6e59fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c66ab2e41da808a254715824e7f6e11f = $(`&lt;div id=&quot;html_c66ab2e41da808a254715824e7f6e11f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_13b6dc47eb3288a9510a49fa1b6e59fa.setContent(html_c66ab2e41da808a254715824e7f6e11f);
#
#
#
#         marker_b76d83932a3f1344b16951dd3160703a.bindPopup(popup_13b6dc47eb3288a9510a49fa1b6e59fa)
#         ;
#
#
#
#
#             var marker_76cee232ec52f277dead4668723b04fc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_114163761f7e77b59fa480690ba0a130);
#
#
#         var popup_cf537d9e6ddc53161a47cbe1ffe805e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_81ad54bdb8cf34547aa54e80034bb8c3 = $(`&lt;div id=&quot;html_81ad54bdb8cf34547aa54e80034bb8c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_cf537d9e6ddc53161a47cbe1ffe805e3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1810293c0d389bdc13c884cf5bffa3ad {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1810293c0d389bdc13c884cf5bffa3ad&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1810293c0d389bdc13c884cf5bffa3ad = L.map(
#                 &quot;map_1810293c0d389bdc13c884cf5bffa3ad&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_404defe0f53665ff08172022902761b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_404defe0f53665ff08172022902761b4.addTo(map_1810293c0d389bdc13c884cf5bffa3ad);
#
#
#             var feature_group_4af3adb74f2d935d5bf0925d19bac026 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7f05fc02551d2be22f39421856c55b92 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_4af3adb74f2d935d5bf0925d19bac026);
#
#
#         var popup_419ccf49d78a0b85735e459680dc5d37 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f46b81ba334034be778923dcfbe8f018 = $(`&lt;div id=&quot;html_f46b81ba334034be778923dcfbe8f018&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_419ccf49d78a0b85735e459680dc5d37.setContent(html_f46b81ba334034be778923dcfbe8f018);
#
#
#
#         marker_7f05fc02551d2be22f39421856c55b92.bindPopup(popup_419ccf49d78a0b85735e459680dc5d37)
#         ;
#
#
#
#
#             var marker_3be77e878a530b9c4b96ebf1fc519e0f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_4af3adb74f2d935d5bf0925d19bac026);
#
#
#         var popup_e308454c6b1bb1e7e1fcafbb8ef00d50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8447b603a788214a578b4dfd96dc2fef = $(`&lt;div id=&quot;html_8447b603a788214a578b4dfd96dc2fef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e308454c6b1bb1e7e1fcafbb8ef00d50.setContent(html_8447b603a788214a578b4dfd96dc2fef);
#
#
#
#         marker_3be77e878a530b9c4b96ebf1fc519e0f.bindPopup(popup_e308454c6b1bb1e7e1fcafbb8ef00d50)
#         ;
#
#
#
#
#             var marker_a7e295eb6acab486b2d8d4ffbcdbfd76 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_4af3adb74f2d935d5bf0925d19bac026);
#
#
#         var popup_80caf3498a033ec3cb48dfdedfe65a45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28800625d3bc09b83432088e7639752a = $(`&lt;div id=&quot;html_28800625d3bc09b83432088e7639752a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_80caf3498a033ec3cb48dfdedfe65a45.setContent(html_28800625d3bc09b83432088e7639752a);
#
#
#
#         marker_a7e295eb6acab486b2d8d4ffbcdbfd76.bindPopup(popup_80caf3498a033ec3cb48dfdedfe65a45)
#         ;
#
#
#
#
#             var marker_83a0e5f569d94e19efb3d3550f90ab0d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_4af3adb74f2d935d5bf0925d19bac026);
#
#
#         var popup_4446c819297c8351299bf770d2e65289 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e25a9b4bb49c9b1364cf5e909891114f = $(`&lt;div id=&quot;html_e25a9b4bb49c9b1364cf5e909891114f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4446c819297c8351299bf770d2e65289.setContent(html_e25a9b4bb49c9b1364cf5e909891114f);
#
#
#
#         marker_83a0e5f569d94e19efb3d3550f90ab0d.bindPopup(popup_4446c819297c8351299bf770d2e65289)
#         ;
#
#
#
#
#             var marker_1f8a6c319bb108757229588206d18399 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_4af3adb74f2d935d5bf0925d19bac026);
#
#
#         var popup_a5185a8207d387ac170e99d3f611bde9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e76e0f8106d027baadc85afab35da1b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e76e0f8106d027baadc85afab35da1b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e76e0f8106d027baadc85afab35da1b5 = L.map(
#                 &quot;map_e76e0f8106d027baadc85afab35da1b5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6dacbd55a0049083148e43f70b95438c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6dacbd55a0049083148e43f70b95438c.addTo(map_e76e0f8106d027baadc85afab35da1b5);
#
#
#             var feature_group_bd4a32c4374b59536ec9a7bbcd2ac981 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bd4a32c4374b59536ec9a7bbcd2ac981.addTo(map_e76e0f8106d027baadc85afab35da1b5);
#
#
#             var feature_group_sub_group_5b90632fd1a6ace74366d842631e200d = L.featureGroup.subGroup(
#                 feature_group_bd4a32c4374b59536ec9a7bbcd2ac981
#             );
#
#
#             var marker_c28d208c1005e6aeafc8864feab4bf0f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b90632fd1a6ace74366d842631e200d);
#
#
#         var popup_f20ccad3c3ff4863eb53290131a8b60c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_939ba07eee34c5ac4d613efc342b782f = $(`&lt;div id=&quot;html_939ba07eee34c5ac4d613efc342b782f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f20ccad3c3ff4863eb53290131a8b60c.setContent(html_939ba07eee34c5ac4d613efc342b782f);
#
#
#
#         marker_c28d208c1005e6aeafc8864feab4bf0f.bindPopup(popup_f20ccad3c3ff4863eb53290131a8b60c)
#         ;
#
#
#
#
#             var marker_ea5aeee7b3285d07e007418117adb19c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b90632fd1a6ace74366d842631e200d);
#
#
#         var popup_deac7ae238b8349733227952e331df9c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d2bd63ae89acdfd2c4b413ca54a4b70 = $(`&lt;div id=&quot;html_7d2bd63ae89acdfd2c4b413ca54a4b70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_deac7ae238b8349733227952e331df9c.setContent(html_7d2bd63ae89acdfd2c4b413ca54a4b70);
#
#
#
#         marker_ea5aeee7b3285d07e007418117adb19c.bindPopup(popup_deac7ae238b8349733227952e331df9c)
#         ;
#
#
#
#
#             var marker_8e61f9c63838190a070eb4ea834464a8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b90632fd1a6ace74366d842631e200d);
#
#
#         var popup_aee0f563150479a183f2408545cf9f9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bd7b651ae9115f6738362630dc2f8f71 = $(`&lt;div id=&quot;html_bd7b651ae9115f6738362630dc2f8f71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_aee0f563150479a183f2408545cf9f9d.setContent(html_bd7b651ae9115f6738362630dc2f8f71);
#
#
#
#         marker_8e61f9c63838190a070eb4ea834464a8.bindPopup(popup_aee0f563150479a183f2408545cf9f9d)
#         ;
#
#
#
#
#             var marker_0f7dbc96a0a36ff99fa953d27d2908b9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5b90632fd1a6ace74366d842631e200d);
#
#
#         var popup_8b4fdcfe5fb5b8e4c069ac2678744dd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aad8c267335972bc4693d5678b1594bf = $(`&lt;div id=&quot;html_aad8c267335972bc4693d5678b1594bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8b4fdcfe5fb5b8e4c069ac2678744dd7.setContent(html_aad8c267335972bc4693d5678b1594bf);
#
#
#
#         marker_
