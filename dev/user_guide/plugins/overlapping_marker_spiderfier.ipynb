# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_818d52954a4199b8d1dbc4537e8b1ee7 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_818d52954a4199b8d1dbc4537e8b1ee7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_818d52954a4199b8d1dbc4537e8b1ee7 = L.map(
#                 &quot;map_818d52954a4199b8d1dbc4537e8b1ee7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_48d6b525dae29528d4c02138f50cd0f8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_48d6b525dae29528d4c02138f50cd0f8.addTo(map_818d52954a4199b8d1dbc4537e8b1ee7);
#
#
#             var marker_2797058190726108550ef579c1acbf21 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_818d52954a4199b8d1dbc4537e8b1ee7);
#
#
#         var popup_67fa481e56e8b0ea20e4b56c0426eb1a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_de384c6b7c9dc3e5e213d2e321b7e9d5 = $(`&lt;div id=&quot;html_de384c6b7c9dc3e5e213d2e321b7e9d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_67fa481e56e8b0ea20e4b56c0426eb1a.setContent(html_de384c6b7c9dc3e5e213d2e321b7e9d5);
#
#
#
#         marker_2797058190726108550ef579c1acbf21.bindPopup(popup_67fa481e56e8b0ea20e4b56c0426eb1a)
#         ;
#
#
#
#
#             var marker_c52b2c2ff81d851b065f821cb31d529e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_818d52954a4199b8d1dbc4537e8b1ee7);
#
#
#         var popup_56eb04bef522e67acc516184ae0c6d63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_66b5f13eaae34a2d458a5c4e5c0b803c = $(`&lt;div id=&quot;html_66b5f13eaae34a2d458a5c4e5c0b803c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_56eb04bef522e67acc516184ae0c6d63.setContent(html_66b5f13eaae34a2d458a5c4e5c0b803c);
#
#
#
#         marker_c52b2c2ff81d851b065f821cb31d529e.bindPopup(popup_56eb04bef522e67acc516184ae0c6d63)
#         ;
#
#
#
#
#             var marker_3734eb1744dc9142ae1be527747d9a94 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_818d52954a4199b8d1dbc4537e8b1ee7);
#
#
#         var popup_e7c3cdd25336e5c0f01e969505281196 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc9d1b160c3174791f18873697de3553 = $(`&lt;div id=&quot;html_cc9d1b160c3174791f18873697de3553&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e7c3cdd25336e5c0f01e969505281196.setContent(html_cc9d1b160c3174791f18873697de3553);
#
#
#
#         marker_3734eb1744dc9142ae1be527747d9a94.bindPopup(popup_e7c3cdd25336e5c0f01e969505281196)
#         ;
#
#
#
#
#             var marker_11b145f879f8e22ef22d0ae7c58b62e3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_818d52954a4199b8d1dbc4537e8b1ee7);
#
#
#         var popup_5d39de6d42ec018acd74fbd0fbdeeef4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_252e44ca01363ca01725f1a4c703aa87 = $(`&lt;div id=&quot;html_252e44ca01363ca01725f1a4c703aa87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_5d39de6d42ec018acd74fbd0fbdeeef4.setContent(html_252e44ca01363ca01725f1a4c703aa87);
#
#
#
#         marker_11b145f879f8e22ef22d0ae7c58b62e3.bindPopup(popup_5d39de6d42ec018acd74fbd0fbdeeef4)
#         ;
#
#
#
#
#             var marker_3ab2f15c34c0db9e63d3d91fc0949b39 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_818d52954a4199b8d1dbc4537e8b1ee7);
#
#
#         var popup_5045fd3b36c9e04316bdb50930f2efc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_518aef2f0833a601ef28812491773cf4 = $(`&lt;div id=&quot;html_518aef2f0833a601ef28812491773cf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5045fd3b36c9e04316bdb50930f2efc0.setContent(html_518aef2f0833a601ef28812491773cf4);
#
#
#
#         marker_3ab2f15c34c0db9e63d3d91fc0949b39.bindPopup(popup_5045fd3b36c9e04316bdb50930f2efc0)
#         ;

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2dd6855818a50046bc6fca3a6c49dfa2 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2dd6855818a50046bc6fca3a6c49dfa2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2dd6855818a50046bc6fca3a6c49dfa2 = L.map(
#                 &quot;map_2dd6855818a50046bc6fca3a6c49dfa2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_05df4c10a42a4ebd0a3989bd8e069b12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_05df4c10a42a4ebd0a3989bd8e069b12.addTo(map_2dd6855818a50046bc6fca3a6c49dfa2);
#
#
#             var feature_group_66c9f69ae01a91ca2c98492e8f3847bf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d6e185d7f771a8d18f356feab4d31307 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_66c9f69ae01a91ca2c98492e8f3847bf);
#
#
#         var popup_7eb61c8347340a3fe1ef8a3c1e090fb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03d366cb5863d8e5e52112c65087ff17 = $(`&lt;div id=&quot;html_03d366cb5863d8e5e52112c65087ff17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7eb61c8347340a3fe1ef8a3c1e090fb9.setContent(html_03d366cb5863d8e5e52112c65087ff17);
#
#
#
#         marker_d6e185d7f771a8d18f356feab4d31307.bindPopup(popup_7eb61c8347340a3fe1ef8a3c1e090fb9)
#         ;
#
#
#
#
#             var marker_493f25f8197e971fb602bc5909296076 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_66c9f69ae01a91ca2c98492e8f3847bf);
#
#
#         var popup_188e2020fd917e7cd0f39b30e95c6ac1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b08d2f1abcb3d1b167fcb004d01ea80 = $(`&lt;div id=&quot;html_5b08d2f1abcb3d1b167fcb004d01ea80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_188e2020fd917e7cd0f39b30e95c6ac1.setContent(html_5b08d2f1abcb3d1b167fcb004d01ea80);
#
#
#
#         marker_493f25f8197e971fb602bc5909296076.bindPopup(popup_188e2020fd917e7cd0f39b30e95c6ac1)
#         ;
#
#
#
#
#             var marker_f6e640e573aba564ba89ca86ff9102a9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_66c9f69ae01a91ca2c98492e8f3847bf);
#
#
#         var popup_0d1bb69497423f2ee651aafddcee4ebb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_687d1139a7767de2b069cffcbb8db51b = $(`&lt;div id=&quot;html_687d1139a7767de2b069cffcbb8db51b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0d1bb69497423f2ee651aafddcee4ebb.setContent(html_687d1139a7767de2b069cffcbb8db51b);
#
#
#
#         marker_f6e640e573aba564ba89ca86ff9102a9.bindPopup(popup_0d1bb69497423f2ee651aafddcee4ebb)
#         ;
#
#
#
#
#             var marker_aade61a414b7e1ec2e809af0e3bfb75f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_66c9f69ae01a91ca2c98492e8f3847bf);
#
#
#         var popup_aaacd245d24dde699fc0bfe1410a67b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_052cb2571493b5d37427eb27fe882d83 = $(`&lt;div id=&quot;html_052cb2571493b5d37427eb27fe882d83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_aaacd245d24dde699fc0bfe1410a67b9.setContent(html_052cb2571493b5d37427eb27fe882d83);
#
#
#
#         marker_aade61a414b7e1ec2e809af0e3bfb75f.bindPopup(popup_aaacd245d24dde699fc0bfe1410a67b9)
#         ;
#
#
#
#
#             var marker_59dffab214ceb9ede99bbbce99f03fb0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_66c9f69ae01a91ca2c98492e8f3847bf);
#
#
#         var popup_8b80934eb98ce6769aa255b314c9e3a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_450a35a144f5b6f3cdf131e07ce76884 = $(`&lt;div id=&quot;html_450a35a144f5b6f3cdf131e07ce76884&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6f0d3aed9cded246b3342f135369eef3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6f0d3aed9cded246b3342f135369eef3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6f0d3aed9cded246b3342f135369eef3 = L.map(
#                 &quot;map_6f0d3aed9cded246b3342f135369eef3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9d336444ed4f647df17549a76fea28f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9d336444ed4f647df17549a76fea28f.addTo(map_6f0d3aed9cded246b3342f135369eef3);
#
#
#             var feature_group_82d9970ed75a57e83d8bd0a0872f82e7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_82d9970ed75a57e83d8bd0a0872f82e7.addTo(map_6f0d3aed9cded246b3342f135369eef3);
#
#
#             var feature_group_sub_group_0e56b779b7a48ecf8862f278bc27ad78 = L.featureGroup.subGroup(
#                 feature_group_82d9970ed75a57e83d8bd0a0872f82e7
#             );
#
#
#             var marker_463ab4e74a2d6189471a45ee403692e5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e56b779b7a48ecf8862f278bc27ad78);
#
#
#         var popup_48bb19650aeff47347eae34edb5fe7fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_023287df6c9983fb9b2acb137091a87f = $(`&lt;div id=&quot;html_023287df6c9983fb9b2acb137091a87f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_48bb19650aeff47347eae34edb5fe7fb.setContent(html_023287df6c9983fb9b2acb137091a87f);
#
#
#
#         marker_463ab4e74a2d6189471a45ee403692e5.bindPopup(popup_48bb19650aeff47347eae34edb5fe7fb)
#         ;
#
#
#
#
#             var marker_636495c23182270915551162da59130a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e56b779b7a48ecf8862f278bc27ad78);
#
#
#         var popup_c2df93ac44a5911f806178497ca5fad0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14a9656b258ee9cb874b17d59caffe7a = $(`&lt;div id=&quot;html_14a9656b258ee9cb874b17d59caffe7a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c2df93ac44a5911f806178497ca5fad0.setContent(html_14a9656b258ee9cb874b17d59caffe7a);
#
#
#
#         marker_636495c23182270915551162da59130a.bindPopup(popup_c2df93ac44a5911f806178497ca5fad0)
#         ;
#
#
#
#
#             var marker_5d97b2947f106b6773935fc18b8ccfac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e56b779b7a48ecf8862f278bc27ad78);
#
#
#         var popup_7b6958f97e88023c5257e1f9b864bd15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d0aa2d379e22210d890fa91a80ce800 = $(`&lt;div id=&quot;html_2d0aa2d379e22210d890fa91a80ce800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7b6958f97e88023c5257e1f9b864bd15.setContent(html_2d0aa2d379e22210d890fa91a80ce800);
#
#
#
#         marker_5d97b2947f106b6773935fc18b8ccfac.bindPopup(popup_7b6958f97e88023c5257e1f9b864bd15)
#         ;
#
#
#
#
#             var marker_8357994dc117e6dce8385af1b4bf4273 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0e56b779b7a48ecf8862f278bc27ad78);
#
#
#         var popup_4a26c861414d0549639841132665dc2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4e8161c9b2fa4bf8423496b10d28058 = $(`&lt;div id=&quot;html_a4e8161c9b2fa4bf8423496b10d28058&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_4a26c861414d0549639841132665dc2b.setContent(html_a4e8161c9b2fa4bf8423496b10d28058);
#
#
#
#         marker_8357994dc117e6dce8385af1b4bf4273.bindPopup(popup_4a26c861414d0549639841132665dc2b)
#         ;
#
#
#
#
#             var marker_b2225165cb95c834e6fd480141212f7b = L.marker(
#                 [45.0503999
