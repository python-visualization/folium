# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fa181a16fab1af8636aa8d8a6428d2a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fa181a16fab1af8636aa8d8a6428d2a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fa181a16fab1af8636aa8d8a6428d2a7 = L.map(
#                 &quot;map_fa181a16fab1af8636aa8d8a6428d2a7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_725930a58d3558088b43328120795480 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_725930a58d3558088b43328120795480.addTo(map_fa181a16fab1af8636aa8d8a6428d2a7);
#
#
#             var marker_000b2467dd09e2e5a482cddd9666e065 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fa181a16fab1af8636aa8d8a6428d2a7);
#
#
#         var popup_2c320978093ef0677927e696ba040c28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_17b03a4d559eee81d235baadc99265d4 = $(`&lt;div id=&quot;html_17b03a4d559eee81d235baadc99265d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2c320978093ef0677927e696ba040c28.setContent(html_17b03a4d559eee81d235baadc99265d4);
#
#
#
#         marker_000b2467dd09e2e5a482cddd9666e065.bindPopup(popup_2c320978093ef0677927e696ba040c28)
#         ;
#
#
#
#
#             var marker_79357cc48c77172f0155a5e46d3e8d11 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fa181a16fab1af8636aa8d8a6428d2a7);
#
#
#         var popup_8512c0b03a66e3a30b4ebe3ed76bfa99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dfd415de5c948cc7fb228157f9a69fa7 = $(`&lt;div id=&quot;html_dfd415de5c948cc7fb228157f9a69fa7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8512c0b03a66e3a30b4ebe3ed76bfa99.setContent(html_dfd415de5c948cc7fb228157f9a69fa7);
#
#
#
#         marker_79357cc48c77172f0155a5e46d3e8d11.bindPopup(popup_8512c0b03a66e3a30b4ebe3ed76bfa99)
#         ;
#
#
#
#
#             var marker_2b00235eee2fff12a098be6cf2eb09ce = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fa181a16fab1af8636aa8d8a6428d2a7);
#
#
#         var popup_ffd03e893abf70c0b44899f76fdec626 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_790ee7f2d82fafcb6f91033071f8bd1d = $(`&lt;div id=&quot;html_790ee7f2d82fafcb6f91033071f8bd1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ffd03e893abf70c0b44899f76fdec626.setContent(html_790ee7f2d82fafcb6f91033071f8bd1d);
#
#
#
#         marker_2b00235eee2fff12a098be6cf2eb09ce.bindPopup(popup_ffd03e893abf70c0b44899f76fdec626)
#         ;
#
#
#
#
#             var marker_74586699ba4ca5e649a6c28e7b8ed3ae = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fa181a16fab1af8636aa8d8a6428d2a7);
#
#
#         var popup_887cc3eead8e14289463422967f6789c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd7638686780fad7b5abcbb276cddc57 = $(`&lt;div id=&quot;html_fd7638686780fad7b5abcbb276cddc57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_887cc3eead8e14289463422967f6789c.setContent(html_fd7638686780fad7b5abcbb276cddc57);
#
#
#
#         marker_74586699ba4ca5e649a6c28e7b8ed3ae.bindPopup(popup_887cc3eead8e14289463422967f6789c)
#         ;
#
#
#
#
#             var marker_4a384381d29dcca5e0640a672c513713 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fa181a16fab1af8636aa8d8a6428d2a7);
#
#
#         var popup_19cb11a75b73d78587c31f421553258e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e32e4009ce135bd3f6a7b5c73161ad5d = $(`&lt;div id=&quot;html_e32e4009ce135bd3f6a7b5c73161ad5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_19cb11a75b73d78587c31f421553258e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b0fb8c31216bcba8e58baa6ec16cfbe8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b0fb8c31216bcba8e58baa6ec16cfbe8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b0fb8c31216bcba8e58baa6ec16cfbe8 = L.map(
#                 &quot;map_b0fb8c31216bcba8e58baa6ec16cfbe8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fc63c21dc232a1b413c27b27f99e4454 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fc63c21dc232a1b413c27b27f99e4454.addTo(map_b0fb8c31216bcba8e58baa6ec16cfbe8);
#
#
#             var feature_group_31f5a936f78065e6060f680ea07a20a7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_235d1026c5b0e13f5ef9798c94266eda = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_31f5a936f78065e6060f680ea07a20a7);
#
#
#         var popup_fee9f37cf1ee13b1e3e122efd34ded82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ce6ad0926ff237a37e18fda310a7822 = $(`&lt;div id=&quot;html_3ce6ad0926ff237a37e18fda310a7822&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fee9f37cf1ee13b1e3e122efd34ded82.setContent(html_3ce6ad0926ff237a37e18fda310a7822);
#
#
#
#         marker_235d1026c5b0e13f5ef9798c94266eda.bindPopup(popup_fee9f37cf1ee13b1e3e122efd34ded82)
#         ;
#
#
#
#
#             var marker_9e9e9f62fa9457c29ff64ce63d1f8357 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_31f5a936f78065e6060f680ea07a20a7);
#
#
#         var popup_952906815057a45aa4272dfe72037724 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e5bb5db092e93a0a69ec8f13fe8c509 = $(`&lt;div id=&quot;html_9e5bb5db092e93a0a69ec8f13fe8c509&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_952906815057a45aa4272dfe72037724.setContent(html_9e5bb5db092e93a0a69ec8f13fe8c509);
#
#
#
#         marker_9e9e9f62fa9457c29ff64ce63d1f8357.bindPopup(popup_952906815057a45aa4272dfe72037724)
#         ;
#
#
#
#
#             var marker_0d2eae0d02948a56b379b5cd8607d14d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_31f5a936f78065e6060f680ea07a20a7);
#
#
#         var popup_86b734afd4d17b1ca499bc7a9f12df7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ed3e12c43ea8f7fdfe398cd98133724 = $(`&lt;div id=&quot;html_8ed3e12c43ea8f7fdfe398cd98133724&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_86b734afd4d17b1ca499bc7a9f12df7c.setContent(html_8ed3e12c43ea8f7fdfe398cd98133724);
#
#
#
#         marker_0d2eae0d02948a56b379b5cd8607d14d.bindPopup(popup_86b734afd4d17b1ca499bc7a9f12df7c)
#         ;
#
#
#
#
#             var marker_bd341aae056c09dbca43a7b4b7d56f65 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_31f5a936f78065e6060f680ea07a20a7);
#
#
#         var popup_59cafce884ff067dd7895f11c8a8fb1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70a43db93f9c70971af1dd5e22265d4d = $(`&lt;div id=&quot;html_70a43db93f9c70971af1dd5e22265d4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_59cafce884ff067dd7895f11c8a8fb1d.setContent(html_70a43db93f9c70971af1dd5e22265d4d);
#
#
#
#         marker_bd341aae056c09dbca43a7b4b7d56f65.bindPopup(popup_59cafce884ff067dd7895f11c8a8fb1d)
#         ;
#
#
#
#
#             var marker_10720b3ab271457d9bfdd0d21e62e6af = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_31f5a936f78065e6060f680ea07a20a7);
#
#
#         var popup_17d14e6e1eeedf239f75ccfde89dad63 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b3b600a2805e8d135b50a5c8b6529ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b3b600a2805e8d135b50a5c8b6529ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b3b600a2805e8d135b50a5c8b6529ab = L.map(
#                 &quot;map_3b3b600a2805e8d135b50a5c8b6529ab&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_303ca34ecb79374701261165a276fbcc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_303ca34ecb79374701261165a276fbcc.addTo(map_3b3b600a2805e8d135b50a5c8b6529ab);
#
#
#             var feature_group_232598a357548c43ad617a1dbc970763 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_232598a357548c43ad617a1dbc970763.addTo(map_3b3b600a2805e8d135b50a5c8b6529ab);
#
#
#             var feature_group_sub_group_96f89a792aa07864c395eb92dd353515 = L.featureGroup.subGroup(
#                 feature_group_232598a357548c43ad617a1dbc970763
#             );
#
#
#             var marker_1d098a070a2f81affd42640302c0c89c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_96f89a792aa07864c395eb92dd353515);
#
#
#         var popup_fd0873704723dcc532e44f5836878504 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b8393fbb63e79621ae214f92c2d7366 = $(`&lt;div id=&quot;html_3b8393fbb63e79621ae214f92c2d7366&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fd0873704723dcc532e44f5836878504.setContent(html_3b8393fbb63e79621ae214f92c2d7366);
#
#
#
#         marker_1d098a070a2f81affd42640302c0c89c.bindPopup(popup_fd0873704723dcc532e44f5836878504)
#         ;
#
#
#
#
#             var marker_2b4c795e8eeb789de7574e63add4f6a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_96f89a792aa07864c395eb92dd353515);
#
#
#         var popup_cf4bcecd54bacaa808ae39bdb36246d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2265c15d8bf6fae2ae846c32a57fa13e = $(`&lt;div id=&quot;html_2265c15d8bf6fae2ae846c32a57fa13e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cf4bcecd54bacaa808ae39bdb36246d5.setContent(html_2265c15d8bf6fae2ae846c32a57fa13e);
#
#
#
#         marker_2b4c795e8eeb789de7574e63add4f6a0.bindPopup(popup_cf4bcecd54bacaa808ae39bdb36246d5)
#         ;
#
#
#
#
#             var marker_beaca2d57139962948ba942571c6f555 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_96f89a792aa07864c395eb92dd353515);
#
#
#         var popup_458a9abcacb5dbf452c8ab38b59f3c60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4569a0015f7f5d92369783138914cf6 = $(`&lt;div id=&quot;html_b4569a0015f7f5d92369783138914cf6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_458a9abcacb5dbf452c8ab38b59f3c60.setContent(html_b4569a0015f7f5d92369783138914cf6);
#
#
#
#         marker_beaca2d57139962948ba942571c6f555.bindPopup(popup_458a9abcacb5dbf452c8ab38b59f3c60)
#         ;
#
#
#
#
#             var marker_dfee700230b66743abbf39a8af54cb90 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_96f89a792aa07864c395eb92dd353515);
#
#
#         var popup_61950cba72f1fe7c2f736c5f31f2603d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccf257aa314ef39d4c0a908072adc59f = $(`&lt;div id=&quot;html_ccf257aa314ef39d4c0a908072adc59f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_61950cba72f1fe7c2f736c5f31f2603d.setContent(html_ccf257aa314ef39d4c0a908072adc59f);
#
#
#
#         marker_
