# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fe7132001ad0f5e61785ba5cfe112ead {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fe7132001ad0f5e61785ba5cfe112ead&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fe7132001ad0f5e61785ba5cfe112ead = L.map(
#                 &quot;map_fe7132001ad0f5e61785ba5cfe112ead&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39a15e6b0ff4d9aaa788ee2cc5cb556d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_39a15e6b0ff4d9aaa788ee2cc5cb556d.addTo(map_fe7132001ad0f5e61785ba5cfe112ead);
#
#
#             var marker_20da55f516ac6454a3039e76059d1156 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fe7132001ad0f5e61785ba5cfe112ead);
#
#
#         var popup_e0e85c3f5fe4096c533fc600b2eecfc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d561a21def43cae11530b19be18ae491 = $(`&lt;div id=&quot;html_d561a21def43cae11530b19be18ae491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e0e85c3f5fe4096c533fc600b2eecfc5.setContent(html_d561a21def43cae11530b19be18ae491);
#
#
#
#         marker_20da55f516ac6454a3039e76059d1156.bindPopup(popup_e0e85c3f5fe4096c533fc600b2eecfc5)
#         ;
#
#
#
#
#             var marker_ff7bf321d57858675c7b3c523e6d4bd7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fe7132001ad0f5e61785ba5cfe112ead);
#
#
#         var popup_fa40f9f79e26aba3fdc06a8ecfe7278e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e329b8993d5d1f48db88173a6bde244 = $(`&lt;div id=&quot;html_4e329b8993d5d1f48db88173a6bde244&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fa40f9f79e26aba3fdc06a8ecfe7278e.setContent(html_4e329b8993d5d1f48db88173a6bde244);
#
#
#
#         marker_ff7bf321d57858675c7b3c523e6d4bd7.bindPopup(popup_fa40f9f79e26aba3fdc06a8ecfe7278e)
#         ;
#
#
#
#
#             var marker_fa1043975ad48ff7e5b87f52ca4495e6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fe7132001ad0f5e61785ba5cfe112ead);
#
#
#         var popup_17836117e01c008cc412b82392f944a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_acabc926496bb13a7effe612dd57e690 = $(`&lt;div id=&quot;html_acabc926496bb13a7effe612dd57e690&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_17836117e01c008cc412b82392f944a8.setContent(html_acabc926496bb13a7effe612dd57e690);
#
#
#
#         marker_fa1043975ad48ff7e5b87f52ca4495e6.bindPopup(popup_17836117e01c008cc412b82392f944a8)
#         ;
#
#
#
#
#             var marker_15c9117a33e7adba535647fcc7099c58 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fe7132001ad0f5e61785ba5cfe112ead);
#
#
#         var popup_34b757eb0d848695768e58fcd46fa452 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bf880b1091938cc08c575082be7cee0 = $(`&lt;div id=&quot;html_2bf880b1091938cc08c575082be7cee0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_34b757eb0d848695768e58fcd46fa452.setContent(html_2bf880b1091938cc08c575082be7cee0);
#
#
#
#         marker_15c9117a33e7adba535647fcc7099c58.bindPopup(popup_34b757eb0d848695768e58fcd46fa452)
#         ;
#
#
#
#
#             var marker_f6efe600abe409777bfa9a767439bf40 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fe7132001ad0f5e61785ba5cfe112ead);
#
#
#         var popup_94f27721d104d558a2d81863ed905b82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f27e750c48c99933f9ef0e22bcc5f49 = $(`&lt;div id=&quot;html_9f27e750c48c99933f9ef0e22bcc5f49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_94f27721d104d558a2d81863ed905b82.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a461b7e619885a570562af48fa0c0c5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a461b7e619885a570562af48fa0c0c5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a461b7e619885a570562af48fa0c0c5a = L.map(
#                 &quot;map_a461b7e619885a570562af48fa0c0c5a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efa463f1c243d397e158b7b0c9decd0f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_efa463f1c243d397e158b7b0c9decd0f.addTo(map_a461b7e619885a570562af48fa0c0c5a);
#
#
#             var feature_group_5e89bc395b78ca3bd5b32df4df8e5ebf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_275905e371358ca8d0ffce1f19c2c565 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5e89bc395b78ca3bd5b32df4df8e5ebf);
#
#
#         var popup_c05b37f594e49e01c93ecc07578c3b9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a87b86a6ff2bb497cec46916e6236fe = $(`&lt;div id=&quot;html_4a87b86a6ff2bb497cec46916e6236fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c05b37f594e49e01c93ecc07578c3b9b.setContent(html_4a87b86a6ff2bb497cec46916e6236fe);
#
#
#
#         marker_275905e371358ca8d0ffce1f19c2c565.bindPopup(popup_c05b37f594e49e01c93ecc07578c3b9b)
#         ;
#
#
#
#
#             var marker_59fb6d7aef6b3cd27bec37a1228e3cc5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5e89bc395b78ca3bd5b32df4df8e5ebf);
#
#
#         var popup_a8700223db8ae2d682ea09402828770e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_363a5ac1cb591184cb382c67a602ac1b = $(`&lt;div id=&quot;html_363a5ac1cb591184cb382c67a602ac1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a8700223db8ae2d682ea09402828770e.setContent(html_363a5ac1cb591184cb382c67a602ac1b);
#
#
#
#         marker_59fb6d7aef6b3cd27bec37a1228e3cc5.bindPopup(popup_a8700223db8ae2d682ea09402828770e)
#         ;
#
#
#
#
#             var marker_e33d4d3d446626cbfa8f70d54209b50e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5e89bc395b78ca3bd5b32df4df8e5ebf);
#
#
#         var popup_d935f14955c86bd9b38a620f687c0ec3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9a8455d1425aa327312254daabe0e0a = $(`&lt;div id=&quot;html_e9a8455d1425aa327312254daabe0e0a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d935f14955c86bd9b38a620f687c0ec3.setContent(html_e9a8455d1425aa327312254daabe0e0a);
#
#
#
#         marker_e33d4d3d446626cbfa8f70d54209b50e.bindPopup(popup_d935f14955c86bd9b38a620f687c0ec3)
#         ;
#
#
#
#
#             var marker_1fab5e03ee8ed8c6b6f1612497555c15 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5e89bc395b78ca3bd5b32df4df8e5ebf);
#
#
#         var popup_cc7a4f0f98c783664f7c97c2060b0c28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_234090eff68ad8cd4b4a9fb3b695afa8 = $(`&lt;div id=&quot;html_234090eff68ad8cd4b4a9fb3b695afa8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cc7a4f0f98c783664f7c97c2060b0c28.setContent(html_234090eff68ad8cd4b4a9fb3b695afa8);
#
#
#
#         marker_1fab5e03ee8ed8c6b6f1612497555c15.bindPopup(popup_cc7a4f0f98c783664f7c97c2060b0c28)
#         ;
#
#
#
#
#             var marker_70b67c8109faf5c7545ac4a9cc802562 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5e89bc395b78ca3bd5b32df4df8e5ebf);
#
#
#         var popup_5edf00cd4feeb2668f99373ab8ebb6ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b816cba964b577396c258e86bad6461 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b816cba964b577396c258e86bad6461&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b816cba964b577396c258e86bad6461 = L.map(
#                 &quot;map_1b816cba964b577396c258e86bad6461&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc3fea4a0e6e1a9afda4bdab17c295f0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc3fea4a0e6e1a9afda4bdab17c295f0.addTo(map_1b816cba964b577396c258e86bad6461);
#
#
#             var feature_group_958ed9e3a971f0d49a7d0de5c06c2321 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_958ed9e3a971f0d49a7d0de5c06c2321.addTo(map_1b816cba964b577396c258e86bad6461);
#
#
#             var feature_group_sub_group_06be27b84123e2cc721f0e2dd791956d = L.featureGroup.subGroup(
#                 feature_group_958ed9e3a971f0d49a7d0de5c06c2321
#             );
#
#
#             var marker_37f379016a20095d0d2f4301475b305b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_06be27b84123e2cc721f0e2dd791956d);
#
#
#         var popup_1274a817a9cec676c75df3ff9d88c5cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4aa1dd1b19f10cd97d3dd463e70e6559 = $(`&lt;div id=&quot;html_4aa1dd1b19f10cd97d3dd463e70e6559&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1274a817a9cec676c75df3ff9d88c5cc.setContent(html_4aa1dd1b19f10cd97d3dd463e70e6559);
#
#
#
#         marker_37f379016a20095d0d2f4301475b305b.bindPopup(popup_1274a817a9cec676c75df3ff9d88c5cc)
#         ;
#
#
#
#
#             var marker_8c7e0db0b34f55d7d02c62e052641191 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_06be27b84123e2cc721f0e2dd791956d);
#
#
#         var popup_f8596eaf3741c29c0feacfa2c03db020 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45ef98076930c5aef68808830f7d0405 = $(`&lt;div id=&quot;html_45ef98076930c5aef68808830f7d0405&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f8596eaf3741c29c0feacfa2c03db020.setContent(html_45ef98076930c5aef68808830f7d0405);
#
#
#
#         marker_8c7e0db0b34f55d7d02c62e052641191.bindPopup(popup_f8596eaf3741c29c0feacfa2c03db020)
#         ;
#
#
#
#
#             var marker_9811a26a645327d2078cf174b0f1630a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_06be27b84123e2cc721f0e2dd791956d);
#
#
#         var popup_5391086ce3ab49a9331bd5c0344eefb0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a221cc616ddc44289bce12cb81f5e75c = $(`&lt;div id=&quot;html_a221cc616ddc44289bce12cb81f5e75c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5391086ce3ab49a9331bd5c0344eefb0.setContent(html_a221cc616ddc44289bce12cb81f5e75c);
#
#
#
#         marker_9811a26a645327d2078cf174b0f1630a.bindPopup(popup_5391086ce3ab49a9331bd5c0344eefb0)
#         ;
#
#
#
#
#             var marker_d7a8488edb09c1ddd88ca05fcc55ff05 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_06be27b84123e2cc721f0e2dd791956d);
#
#
#         var popup_97eded1a4f21311b56de6077be68bc39 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a37453a6ade51f09aacca22cab6be483 = $(`&lt;div id=&quot;html_a37453a6ade51f09aacca22cab6be483&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_97eded1a4f21311b56de6077be68bc39.setContent(html_a37453a6ade51f09aacca22cab6be483);
#
#
#
#         marker_
