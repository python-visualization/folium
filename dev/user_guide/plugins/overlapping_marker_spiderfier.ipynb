# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e4449a101e4ee3aa113ed22f87836ed {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e4449a101e4ee3aa113ed22f87836ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e4449a101e4ee3aa113ed22f87836ed = L.map(
#                 &quot;map_6e4449a101e4ee3aa113ed22f87836ed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_12551ce028b523751f187b5898da3244 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_12551ce028b523751f187b5898da3244.addTo(map_6e4449a101e4ee3aa113ed22f87836ed);
#
#
#             var marker_be8648f6f7506fb030db15f76c3f46dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6e4449a101e4ee3aa113ed22f87836ed);
#
#
#         var popup_d35b9592ec3dcce07aa448cb07962cfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_569829426a44d331396d43b43384c11c = $(`&lt;div id=&quot;html_569829426a44d331396d43b43384c11c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d35b9592ec3dcce07aa448cb07962cfa.setContent(html_569829426a44d331396d43b43384c11c);
#
#
#
#         marker_be8648f6f7506fb030db15f76c3f46dc.bindPopup(popup_d35b9592ec3dcce07aa448cb07962cfa)
#         ;
#
#
#
#
#             var marker_faec712fa026f46abc89ab9f0d1620c4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6e4449a101e4ee3aa113ed22f87836ed);
#
#
#         var popup_55bea04fcbaeddbe6fe4a3904c84ddd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_03f1f3ba1543a03978131b2d7add16f0 = $(`&lt;div id=&quot;html_03f1f3ba1543a03978131b2d7add16f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_55bea04fcbaeddbe6fe4a3904c84ddd4.setContent(html_03f1f3ba1543a03978131b2d7add16f0);
#
#
#
#         marker_faec712fa026f46abc89ab9f0d1620c4.bindPopup(popup_55bea04fcbaeddbe6fe4a3904c84ddd4)
#         ;
#
#
#
#
#             var marker_0930b31a58396a88b0dc380e1a9fe9cb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6e4449a101e4ee3aa113ed22f87836ed);
#
#
#         var popup_f11e5788f9d17bc5fcc1871619427d10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3fc7d40eaccd5c9d85d31feebfb0ba8 = $(`&lt;div id=&quot;html_b3fc7d40eaccd5c9d85d31feebfb0ba8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f11e5788f9d17bc5fcc1871619427d10.setContent(html_b3fc7d40eaccd5c9d85d31feebfb0ba8);
#
#
#
#         marker_0930b31a58396a88b0dc380e1a9fe9cb.bindPopup(popup_f11e5788f9d17bc5fcc1871619427d10)
#         ;
#
#
#
#
#             var marker_9eb83dc5bb539f13d75acdc2df89085c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6e4449a101e4ee3aa113ed22f87836ed);
#
#
#         var popup_bc64419e51ebac108e1b9ef26f6bf7a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d0e4eb8bbb720b830dc191758cd9cb28 = $(`&lt;div id=&quot;html_d0e4eb8bbb720b830dc191758cd9cb28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bc64419e51ebac108e1b9ef26f6bf7a4.setContent(html_d0e4eb8bbb720b830dc191758cd9cb28);
#
#
#
#         marker_9eb83dc5bb539f13d75acdc2df89085c.bindPopup(popup_bc64419e51ebac108e1b9ef26f6bf7a4)
#         ;
#
#
#
#
#             var marker_2572d7b1af3af2fd90d196d4b59d09e3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6e4449a101e4ee3aa113ed22f87836ed);
#
#
#         var popup_f6d9cffab213e4803d035d62912f7393 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_11b6099240ee2373a39195ab7aacdd65 = $(`&lt;div id=&quot;html_11b6099240ee2373a39195ab7aacdd65&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f6d9cffab213e4803d035d62912f73

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cd3dd19fbbd22ba630fd03e675e2847 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cd3dd19fbbd22ba630fd03e675e2847&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cd3dd19fbbd22ba630fd03e675e2847 = L.map(
#                 &quot;map_4cd3dd19fbbd22ba630fd03e675e2847&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6b831aeca154565e1aad0a9cc78c8f55 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6b831aeca154565e1aad0a9cc78c8f55.addTo(map_4cd3dd19fbbd22ba630fd03e675e2847);
#
#
#             var feature_group_28a07a8ecd0ed2f72c6717b7afa7ae46 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_068ef2e03a77cb8ec804f1542791412c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_28a07a8ecd0ed2f72c6717b7afa7ae46);
#
#
#         var popup_cdc09ef14f03332f19f116eac8df12c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdd8f3f6252553b1fb1bc7c166dde122 = $(`&lt;div id=&quot;html_fdd8f3f6252553b1fb1bc7c166dde122&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cdc09ef14f03332f19f116eac8df12c5.setContent(html_fdd8f3f6252553b1fb1bc7c166dde122);
#
#
#
#         marker_068ef2e03a77cb8ec804f1542791412c.bindPopup(popup_cdc09ef14f03332f19f116eac8df12c5)
#         ;
#
#
#
#
#             var marker_0844d94a078c39271486aaf2ba9175e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_28a07a8ecd0ed2f72c6717b7afa7ae46);
#
#
#         var popup_8d6416be70a8061b0b91569678d4c6b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c595dbe9667441ec1762e702b5538b48 = $(`&lt;div id=&quot;html_c595dbe9667441ec1762e702b5538b48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_8d6416be70a8061b0b91569678d4c6b7.setContent(html_c595dbe9667441ec1762e702b5538b48);
#
#
#
#         marker_0844d94a078c39271486aaf2ba9175e8.bindPopup(popup_8d6416be70a8061b0b91569678d4c6b7)
#         ;
#
#
#
#
#             var marker_e1b52fae47d16542cc2d6f86f9af1090 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_28a07a8ecd0ed2f72c6717b7afa7ae46);
#
#
#         var popup_75ce79f8865fc4b1f3a0bd3e1636fce8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2cffbbe2bc494f9b0f8ec360cf6c167 = $(`&lt;div id=&quot;html_c2cffbbe2bc494f9b0f8ec360cf6c167&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_75ce79f8865fc4b1f3a0bd3e1636fce8.setContent(html_c2cffbbe2bc494f9b0f8ec360cf6c167);
#
#
#
#         marker_e1b52fae47d16542cc2d6f86f9af1090.bindPopup(popup_75ce79f8865fc4b1f3a0bd3e1636fce8)
#         ;
#
#
#
#
#             var marker_794a9fdfe17d4fc3986501c012bddf02 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_28a07a8ecd0ed2f72c6717b7afa7ae46);
#
#
#         var popup_0671ed592bfb9a88aa1a653d717ea086 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e50d428b182fc402f28afae5341f999 = $(`&lt;div id=&quot;html_7e50d428b182fc402f28afae5341f999&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_0671ed592bfb9a88aa1a653d717ea086.setContent(html_7e50d428b182fc402f28afae5341f999);
#
#
#
#         marker_794a9fdfe17d4fc3986501c012bddf02.bindPopup(popup_0671ed592bfb9a88aa1a653d717ea086)
#         ;
#
#
#
#
#             var marker_a0a368124d562842060607774fb85b1c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_28a07a8ecd0ed2f72c6717b7afa7ae46);
#
#
#         var popup_995a3d79dc8d1ebc6dca59360bc0bf9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3d9c841f75c49c11af588ef8c7321f3 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3d9c841f75c49c11af588ef8c7321f3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3d9c841f75c49c11af588ef8c7321f3 = L.map(
#                 &quot;map_f3d9c841f75c49c11af588ef8c7321f3&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c8a1fab96423ef2adea3fdca7e91fe6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9c8a1fab96423ef2adea3fdca7e91fe6.addTo(map_f3d9c841f75c49c11af588ef8c7321f3);
#
#
#             var feature_group_dd5a6f41e71366b2bcc6726957f21974 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dd5a6f41e71366b2bcc6726957f21974.addTo(map_f3d9c841f75c49c11af588ef8c7321f3);
#
#
#             var feature_group_sub_group_09a967d148292a73b28b0dfd65cab311 = L.featureGroup.subGroup(
#                 feature_group_dd5a6f41e71366b2bcc6726957f21974
#             );
#
#
#             var marker_d4fa12fd808ff2839cf3f5c1181addb6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_09a967d148292a73b28b0dfd65cab311);
#
#
#         var popup_ad49383dd30c299aeeb499350433b8c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9288f4bd24e2274b5f2d56d4c988ee97 = $(`&lt;div id=&quot;html_9288f4bd24e2274b5f2d56d4c988ee97&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ad49383dd30c299aeeb499350433b8c0.setContent(html_9288f4bd24e2274b5f2d56d4c988ee97);
#
#
#
#         marker_d4fa12fd808ff2839cf3f5c1181addb6.bindPopup(popup_ad49383dd30c299aeeb499350433b8c0)
#         ;
#
#
#
#
#             var marker_9cfbd4eb6a001895c96d8f845fdd0418 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_09a967d148292a73b28b0dfd65cab311);
#
#
#         var popup_69b0fc9b278b4f783d75c94302955de3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5f97d0c39e001aeb7509bc4e86929ea = $(`&lt;div id=&quot;html_d5f97d0c39e001aeb7509bc4e86929ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_69b0fc9b278b4f783d75c94302955de3.setContent(html_d5f97d0c39e001aeb7509bc4e86929ea);
#
#
#
#         marker_9cfbd4eb6a001895c96d8f845fdd0418.bindPopup(popup_69b0fc9b278b4f783d75c94302955de3)
#         ;
#
#
#
#
#             var marker_90ab140a33cb35fc33cb0da30c206698 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_09a967d148292a73b28b0dfd65cab311);
#
#
#         var popup_526eda6312f9c5486595271cc7491034 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60079a3e7125555ec3de9f619d93b5ac = $(`&lt;div id=&quot;html_60079a3e7125555ec3de9f619d93b5ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_526eda6312f9c5486595271cc7491034.setContent(html_60079a3e7125555ec3de9f619d93b5ac);
#
#
#
#         marker_90ab140a33cb35fc33cb0da30c206698.bindPopup(popup_526eda6312f9c5486595271cc7491034)
#         ;
#
#
#
#
#             var marker_f7e11073d1ba2ef93fe250cb23f83edd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_09a967d148292a73b28b0dfd65cab311);
#
#
#         var popup_eb16992080e08d550144545ffd9e2ee8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72f32a8709a60f4694ef866df6ac35b5 = $(`&lt;div id=&quot;html_72f32a8709a60f4694ef866df6ac35b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_eb16992080e08d550144545ffd9e2ee8.setContent(html_72f32a8709a60f4694ef866df6ac35b5);
#
#
#
#         mark
