# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d19d16354de9bd11e080eb12cce4d6da {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d19d16354de9bd11e080eb12cce4d6da&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d19d16354de9bd11e080eb12cce4d6da = L.map(
#                 &quot;map_d19d16354de9bd11e080eb12cce4d6da&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1e09f38e247acdee56219ca6f3442873 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1e09f38e247acdee56219ca6f3442873.addTo(map_d19d16354de9bd11e080eb12cce4d6da);
#
#
#             var marker_81f39f5b00fdad962c7ec7261f52bdf9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d19d16354de9bd11e080eb12cce4d6da);
#
#
#         var popup_8904293930a53ddb97f3819df0f9fc47 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e467cbeda8f5fc987d47a380e708b16 = $(`&lt;div id=&quot;html_0e467cbeda8f5fc987d47a380e708b16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_8904293930a53ddb97f3819df0f9fc47.setContent(html_0e467cbeda8f5fc987d47a380e708b16);
#
#
#
#         marker_81f39f5b00fdad962c7ec7261f52bdf9.bindPopup(popup_8904293930a53ddb97f3819df0f9fc47)
#         ;
#
#
#
#
#             var marker_7d83964fd152fa3dbc7b72e54398e38d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d19d16354de9bd11e080eb12cce4d6da);
#
#
#         var popup_8af60141666af878614d664eed5f331c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3387222b88dbdf256b85d592cba4a61 = $(`&lt;div id=&quot;html_d3387222b88dbdf256b85d592cba4a61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8af60141666af878614d664eed5f331c.setContent(html_d3387222b88dbdf256b85d592cba4a61);
#
#
#
#         marker_7d83964fd152fa3dbc7b72e54398e38d.bindPopup(popup_8af60141666af878614d664eed5f331c)
#         ;
#
#
#
#
#             var marker_43523e1ba267f6078dc386a7e374b70b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d19d16354de9bd11e080eb12cce4d6da);
#
#
#         var popup_c2cfe9bc3c21054bacc7b0fe65f7afd2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b73544e49e40f4c4e68db1562193da78 = $(`&lt;div id=&quot;html_b73544e49e40f4c4e68db1562193da78&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c2cfe9bc3c21054bacc7b0fe65f7afd2.setContent(html_b73544e49e40f4c4e68db1562193da78);
#
#
#
#         marker_43523e1ba267f6078dc386a7e374b70b.bindPopup(popup_c2cfe9bc3c21054bacc7b0fe65f7afd2)
#         ;
#
#
#
#
#             var marker_75a4d0e3d13e4c956201b21c997a6d9f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d19d16354de9bd11e080eb12cce4d6da);
#
#
#         var popup_4cb01c35306574fdf35b9badbe501029 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d93b4f7a9b47c3b5e5aa7e28cfc126b3 = $(`&lt;div id=&quot;html_d93b4f7a9b47c3b5e5aa7e28cfc126b3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4cb01c35306574fdf35b9badbe501029.setContent(html_d93b4f7a9b47c3b5e5aa7e28cfc126b3);
#
#
#
#         marker_75a4d0e3d13e4c956201b21c997a6d9f.bindPopup(popup_4cb01c35306574fdf35b9badbe501029)
#         ;
#
#
#
#
#             var marker_6ddf96948b20c1e9703a1432ca4ed775 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d19d16354de9bd11e080eb12cce4d6da);
#
#
#         var popup_0545928cbecb34281a7726cc269ef72c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f10d914189959b5740b44fcf6559a90f = $(`&lt;div id=&quot;html_f10d914189959b5740b44fcf6559a90f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0545928cbecb34281a7726cc269ef7

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c7ff59ffb029daeec6b556fd9925246a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c7ff59ffb029daeec6b556fd9925246a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c7ff59ffb029daeec6b556fd9925246a = L.map(
#                 &quot;map_c7ff59ffb029daeec6b556fd9925246a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_514f3899f8a525decd2db4307c2b48eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_514f3899f8a525decd2db4307c2b48eb.addTo(map_c7ff59ffb029daeec6b556fd9925246a);
#
#
#             var feature_group_aa36d30f45c8b7fc666541b19d3adc13 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fc104148bf0d72ecee073d77fe7b4701 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_aa36d30f45c8b7fc666541b19d3adc13);
#
#
#         var popup_93fc471728c0e05ac6f8b572953a1423 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7687eb03e290c9ddb102b3d4c19187dc = $(`&lt;div id=&quot;html_7687eb03e290c9ddb102b3d4c19187dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_93fc471728c0e05ac6f8b572953a1423.setContent(html_7687eb03e290c9ddb102b3d4c19187dc);
#
#
#
#         marker_fc104148bf0d72ecee073d77fe7b4701.bindPopup(popup_93fc471728c0e05ac6f8b572953a1423)
#         ;
#
#
#
#
#             var marker_7683462239bf99277925a98785ff8bc5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_aa36d30f45c8b7fc666541b19d3adc13);
#
#
#         var popup_625bfa2787211831d399f1cfa2b0b01e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3fa6d13bcb32171c31adc0833e1bea12 = $(`&lt;div id=&quot;html_3fa6d13bcb32171c31adc0833e1bea12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_625bfa2787211831d399f1cfa2b0b01e.setContent(html_3fa6d13bcb32171c31adc0833e1bea12);
#
#
#
#         marker_7683462239bf99277925a98785ff8bc5.bindPopup(popup_625bfa2787211831d399f1cfa2b0b01e)
#         ;
#
#
#
#
#             var marker_66fcf040978e54344a47b412abc39e5f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_aa36d30f45c8b7fc666541b19d3adc13);
#
#
#         var popup_16d46a0b2dc2f9f421ee544f9c654faa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fd6e0dfdae1fae010018795d4b88bf6c = $(`&lt;div id=&quot;html_fd6e0dfdae1fae010018795d4b88bf6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_16d46a0b2dc2f9f421ee544f9c654faa.setContent(html_fd6e0dfdae1fae010018795d4b88bf6c);
#
#
#
#         marker_66fcf040978e54344a47b412abc39e5f.bindPopup(popup_16d46a0b2dc2f9f421ee544f9c654faa)
#         ;
#
#
#
#
#             var marker_2682b0d3bdec7f6ac155ffd5bfb25a6a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_aa36d30f45c8b7fc666541b19d3adc13);
#
#
#         var popup_22ada7598a1f84aa5d6bdd468b7d7e93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f789ef968da27ad72f620c06541cf876 = $(`&lt;div id=&quot;html_f789ef968da27ad72f620c06541cf876&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_22ada7598a1f84aa5d6bdd468b7d7e93.setContent(html_f789ef968da27ad72f620c06541cf876);
#
#
#
#         marker_2682b0d3bdec7f6ac155ffd5bfb25a6a.bindPopup(popup_22ada7598a1f84aa5d6bdd468b7d7e93)
#         ;
#
#
#
#
#             var marker_bfe1975bd42555b8fc4473a008372f5a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_aa36d30f45c8b7fc666541b19d3adc13);
#
#
#         var popup_539028c8d17a5121ddb7feeab45947f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f7e59210d0341404ef636f1e9ccd2446 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f7e59210d0341404ef636f1e9ccd2446&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f7e59210d0341404ef636f1e9ccd2446 = L.map(
#                 &quot;map_f7e59210d0341404ef636f1e9ccd2446&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3664b0497917a1f3715569177a8ab2b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3664b0497917a1f3715569177a8ab2b8.addTo(map_f7e59210d0341404ef636f1e9ccd2446);
#
#
#             var feature_group_280343a78eb11a4b18de5e78402b183f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_280343a78eb11a4b18de5e78402b183f.addTo(map_f7e59210d0341404ef636f1e9ccd2446);
#
#
#             var feature_group_sub_group_9d69d9741635b3a8088021c39d58a755 = L.featureGroup.subGroup(
#                 feature_group_280343a78eb11a4b18de5e78402b183f
#             );
#
#
#             var marker_1a126e05e213ca35c780f93d7fe13e8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9d69d9741635b3a8088021c39d58a755);
#
#
#         var popup_e41b3bfa0ba7b1095bf84b717b3bbbf7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c98c656690f9dfe23ce04efee302a5c = $(`&lt;div id=&quot;html_8c98c656690f9dfe23ce04efee302a5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e41b3bfa0ba7b1095bf84b717b3bbbf7.setContent(html_8c98c656690f9dfe23ce04efee302a5c);
#
#
#
#         marker_1a126e05e213ca35c780f93d7fe13e8e.bindPopup(popup_e41b3bfa0ba7b1095bf84b717b3bbbf7)
#         ;
#
#
#
#
#             var marker_7f5125af23e902ee92318996bae62d58 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9d69d9741635b3a8088021c39d58a755);
#
#
#         var popup_51df5ba21e5bd63a8e3d50ccc0b90801 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_88e61d4698c6c2d0226601f06a7244d5 = $(`&lt;div id=&quot;html_88e61d4698c6c2d0226601f06a7244d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_51df5ba21e5bd63a8e3d50ccc0b90801.setContent(html_88e61d4698c6c2d0226601f06a7244d5);
#
#
#
#         marker_7f5125af23e902ee92318996bae62d58.bindPopup(popup_51df5ba21e5bd63a8e3d50ccc0b90801)
#         ;
#
#
#
#
#             var marker_5c461246ea635c5edd9361ef8c819855 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9d69d9741635b3a8088021c39d58a755);
#
#
#         var popup_e780fcdc8dd015558e0242db7962d9d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c486b1448fa61c881903afb564e6c7d = $(`&lt;div id=&quot;html_7c486b1448fa61c881903afb564e6c7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e780fcdc8dd015558e0242db7962d9d5.setContent(html_7c486b1448fa61c881903afb564e6c7d);
#
#
#
#         marker_5c461246ea635c5edd9361ef8c819855.bindPopup(popup_e780fcdc8dd015558e0242db7962d9d5)
#         ;
#
#
#
#
#             var marker_0540c8fd2a2b43aa987dd4ff51a230fa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9d69d9741635b3a8088021c39d58a755);
#
#
#         var popup_70923b235645777efeb86d0e96fcf08f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c63d723655c628def7dd9e78ecb103a3 = $(`&lt;div id=&quot;html_c63d723655c628def7dd9e78ecb103a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_70923b235645777efeb86d0e96fcf08f.setContent(html_c63d723655c628def7dd9e78ecb103a3);
#
#
#
#         mark
