# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7bf7affcbc619770fc966832ad2d6ad4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7bf7affcbc619770fc966832ad2d6ad4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7bf7affcbc619770fc966832ad2d6ad4 = L.map(
#                 &quot;map_7bf7affcbc619770fc966832ad2d6ad4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3f6d27767d2b2bf9b8ef87ebf1fd0df5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3f6d27767d2b2bf9b8ef87ebf1fd0df5.addTo(map_7bf7affcbc619770fc966832ad2d6ad4);
#
#
#             var marker_1b7afb335ba4645cb59713d507de6c19 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_7bf7affcbc619770fc966832ad2d6ad4);
#
#
#         var popup_cd4e3943d2723c80cf2ad7752d04b550 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df66f511f26d03e3a1d85a0e983af419 = $(`&lt;div id=&quot;html_df66f511f26d03e3a1d85a0e983af419&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_cd4e3943d2723c80cf2ad7752d04b550.setContent(html_df66f511f26d03e3a1d85a0e983af419);
#
#
#
#         marker_1b7afb335ba4645cb59713d507de6c19.bindPopup(popup_cd4e3943d2723c80cf2ad7752d04b550)
#         ;
#
#
#
#
#             var marker_f5f0cdcb1001cf69e0736842cc06d343 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_7bf7affcbc619770fc966832ad2d6ad4);
#
#
#         var popup_1471e85d52c8d3f3da153953452bdd7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45a93913b01bb1a1ef2bd0d165ad511a = $(`&lt;div id=&quot;html_45a93913b01bb1a1ef2bd0d165ad511a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_1471e85d52c8d3f3da153953452bdd7b.setContent(html_45a93913b01bb1a1ef2bd0d165ad511a);
#
#
#
#         marker_f5f0cdcb1001cf69e0736842cc06d343.bindPopup(popup_1471e85d52c8d3f3da153953452bdd7b)
#         ;
#
#
#
#
#             var marker_149588a9d4f4c7690feecfdc0b2e14bd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_7bf7affcbc619770fc966832ad2d6ad4);
#
#
#         var popup_bf8b0a6b2a944e4a1f9f5d0b773cb030 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98b71c313d90f3a0c9e06644db240858 = $(`&lt;div id=&quot;html_98b71c313d90f3a0c9e06644db240858&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bf8b0a6b2a944e4a1f9f5d0b773cb030.setContent(html_98b71c313d90f3a0c9e06644db240858);
#
#
#
#         marker_149588a9d4f4c7690feecfdc0b2e14bd.bindPopup(popup_bf8b0a6b2a944e4a1f9f5d0b773cb030)
#         ;
#
#
#
#
#             var marker_6bd9eef606f6f3a7640332dc48917401 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_7bf7affcbc619770fc966832ad2d6ad4);
#
#
#         var popup_18888a8b8b1eed7816314820446dd6f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_376fed413f51a4eb078eb2a27e0e98e1 = $(`&lt;div id=&quot;html_376fed413f51a4eb078eb2a27e0e98e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_18888a8b8b1eed7816314820446dd6f3.setContent(html_376fed413f51a4eb078eb2a27e0e98e1);
#
#
#
#         marker_6bd9eef606f6f3a7640332dc48917401.bindPopup(popup_18888a8b8b1eed7816314820446dd6f3)
#         ;
#
#
#
#
#             var marker_2946192e01745b8ee6805b915ddf1ecf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_7bf7affcbc619770fc966832ad2d6ad4);
#
#
#         var popup_90428fe57a94c7cab4fc65c46636ed4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23a29e60611d551dd52447ad79665ed0 = $(`&lt;div id=&quot;html_23a29e60611d551dd52447ad79665ed0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_90428fe57a94c7cab4fc65c46636ed4b.setContent(html_23a29e60611d551dd52447ad79665ed0);
#
#
#
#         marker_2946192e01745b8ee6805b915ddf1ecf.bindPopup(popup_90428fe57a94c7cab4fc65c46636ed4b)
#         ;
#
#
#
#
#             var marker_a515e037be

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c6fb9725437be0d8ccb5246d251118d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c6fb9725437be0d8ccb5246d251118d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c6fb9725437be0d8ccb5246d251118d4 = L.map(
#                 &quot;map_c6fb9725437be0d8ccb5246d251118d4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d83cd03c789eae767636568b84eec9ae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d83cd03c789eae767636568b84eec9ae.addTo(map_c6fb9725437be0d8ccb5246d251118d4);
#
#
#             var feature_group_859e2beb03cca9c3426c1d3b675b4e19 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_553bcf01dd99070f6a7254cc5d6ae8c4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_859e2beb03cca9c3426c1d3b675b4e19);
#
#
#         var popup_b7c20eac51344b19fe1ff241be718cf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7ec85afeac4c3ab87152f8e91a4020b = $(`&lt;div id=&quot;html_f7ec85afeac4c3ab87152f8e91a4020b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b7c20eac51344b19fe1ff241be718cf8.setContent(html_f7ec85afeac4c3ab87152f8e91a4020b);
#
#
#
#         marker_553bcf01dd99070f6a7254cc5d6ae8c4.bindPopup(popup_b7c20eac51344b19fe1ff241be718cf8)
#         ;
#
#
#
#
#             var marker_5724411ec06b238394360c35c6f66433 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_859e2beb03cca9c3426c1d3b675b4e19);
#
#
#         var popup_db2fa6bb3cd7f1aace7a63a40eba1ba3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9678d4dc2a0f4790e1bc46c774253ec = $(`&lt;div id=&quot;html_f9678d4dc2a0f4790e1bc46c774253ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_db2fa6bb3cd7f1aace7a63a40eba1ba3.setContent(html_f9678d4dc2a0f4790e1bc46c774253ec);
#
#
#
#         marker_5724411ec06b238394360c35c6f66433.bindPopup(popup_db2fa6bb3cd7f1aace7a63a40eba1ba3)
#         ;
#
#
#
#
#             var marker_0f9d5edf52b992b767871150b0d49219 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_859e2beb03cca9c3426c1d3b675b4e19);
#
#
#         var popup_cd54f0c8065a0a77034791adf71ca596 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c7dfcdb9c5d49761825e22b89bbe23b = $(`&lt;div id=&quot;html_4c7dfcdb9c5d49761825e22b89bbe23b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_cd54f0c8065a0a77034791adf71ca596.setContent(html_4c7dfcdb9c5d49761825e22b89bbe23b);
#
#
#
#         marker_0f9d5edf52b992b767871150b0d49219.bindPopup(popup_cd54f0c8065a0a77034791adf71ca596)
#         ;
#
#
#
#
#             var marker_84038d6b9f2905e38765a3eb81de741b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_859e2beb03cca9c3426c1d3b675b4e19);
#
#
#         var popup_ff7af361690c8c00f5a64803c5f95b96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60cf7184cb57a7e4d93bf2997610adbf = $(`&lt;div id=&quot;html_60cf7184cb57a7e4d93bf2997610adbf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ff7af361690c8c00f5a64803c5f95b96.setContent(html_60cf7184cb57a7e4d93bf2997610adbf);
#
#
#
#         marker_84038d6b9f2905e38765a3eb81de741b.bindPopup(popup_ff7af361690c8c00f5a64803c5f95b96)
#         ;
#
#
#
#
#             var marker_960d9cad6fd189712e9b7e735179e472 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_859e2beb03cca9c3426c1d3b675b4e19);
#
#
#         var popup_8f042c6c704115c0910762f1e22a3bb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa910c3a14849315f6516148d7958314 = $(`&lt;div id=&quot;html_aa910c3a14849315f6516148d7958314&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 4&lt;/div&gt;`)[0];
#                 popup_8f042c6c704115c091

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50851b2230139536ed3cccdd81a76299 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50851b2230139536ed3cccdd81a76299&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50851b2230139536ed3cccdd81a76299 = L.map(
#                 &quot;map_50851b2230139536ed3cccdd81a76299&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41b1444dd78b3084eeba3ba15d85ffb3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_41b1444dd78b3084eeba3ba15d85ffb3.addTo(map_50851b2230139536ed3cccdd81a76299);
#
#
#             var feature_group_ef33b8e83f946abf3ad6a2d571710345 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ef33b8e83f946abf3ad6a2d571710345.addTo(map_50851b2230139536ed3cccdd81a76299);
#
#
#             var feature_group_sub_group_37859c4cc200367ec25c9bf0048c9618 = L.featureGroup.subGroup(
#                 feature_group_ef33b8e83f946abf3ad6a2d571710345
#             );
#
#
#             var marker_b71ab99e567b0019491359b4821345b1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_37859c4cc200367ec25c9bf0048c9618);
#
#
#         var popup_197ddbe7e4acc66b6a01d59dc7e7da51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83aba356070699b9ec7c5924820ad9c9 = $(`&lt;div id=&quot;html_83aba356070699b9ec7c5924820ad9c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_197ddbe7e4acc66b6a01d59dc7e7da51.setContent(html_83aba356070699b9ec7c5924820ad9c9);
#
#
#
#         marker_b71ab99e567b0019491359b4821345b1.bindPopup(popup_197ddbe7e4acc66b6a01d59dc7e7da51)
#         ;
#
#
#
#
#             var marker_986858e90ca094391724d18838888f07 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_37859c4cc200367ec25c9bf0048c9618);
#
#
#         var popup_5dbbc09521a0de4d2cd5d9f05b3df041 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b9de3bbfb127e381d7d3e802b2f6f98 = $(`&lt;div id=&quot;html_5b9de3bbfb127e381d7d3e802b2f6f98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_5dbbc09521a0de4d2cd5d9f05b3df041.setContent(html_5b9de3bbfb127e381d7d3e802b2f6f98);
#
#
#
#         marker_986858e90ca094391724d18838888f07.bindPopup(popup_5dbbc09521a0de4d2cd5d9f05b3df041)
#         ;
#
#
#
#
#             var marker_c03affea7ad116cd6d15827f8fcd9bb8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_37859c4cc200367ec25c9bf0048c9618);
#
#
#         var popup_095aeff024a4a3928af2eee55862291d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f0f9451e74725b09ec7da8c0951e5416 = $(`&lt;div id=&quot;html_f0f9451e74725b09ec7da8c0951e5416&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_095aeff024a4a3928af2eee55862291d.setContent(html_f0f9451e74725b09ec7da8c0951e5416);
#
#
#
#         marker_c03affea7ad116cd6d15827f8fcd9bb8.bindPopup(popup_095aeff024a4a3928af2eee55862291d)
#         ;
#
#
#
#
#             var marker_bbf68f3e085d73b35593c271913ee0c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_37859c4cc200367ec25c9bf0048c9618);
#
#
#         var popup_f19535ba6d2579eb80350dfedde795f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3550e9161cfe76f8d49ffe682878accd = $(`&lt;div id=&quot;html_3550e9161cfe76f8d49ffe682878accd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f19535ba6d2579eb80350dfedde795f2.setContent(html_3550e9161cfe76f8d49ffe682878accd);
#
#
#
#         marker_bbf68f3e085d73b35593c271913ee0c0.bindPopup(popup_f19535ba6d2579eb80350dfedde795f2)
#         ;
#
#
#
#
#             var marker_0e6559aba8a118602362a6847c2b4294 = L.marker(
#                 [45.050399999999996, 3.0504],
