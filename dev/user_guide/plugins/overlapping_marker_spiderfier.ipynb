# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5ab42d020df978c484eb3390bef73373 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5ab42d020df978c484eb3390bef73373&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5ab42d020df978c484eb3390bef73373 = L.map(
#                 &quot;map_5ab42d020df978c484eb3390bef73373&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60afc373f1c88a8afa1ba82d6305ff7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_60afc373f1c88a8afa1ba82d6305ff7b.addTo(map_5ab42d020df978c484eb3390bef73373);
#
#
#             var marker_fe3ce5d9545c1d04bbff5fecdbe2b17a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5ab42d020df978c484eb3390bef73373);
#
#
#         var popup_c456b7ae63a68fb3d2d8aa76143791c6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15d735c2daf877afe671ba58ad2f2e66 = $(`&lt;div id=&quot;html_15d735c2daf877afe671ba58ad2f2e66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c456b7ae63a68fb3d2d8aa76143791c6.setContent(html_15d735c2daf877afe671ba58ad2f2e66);
#
#
#
#         marker_fe3ce5d9545c1d04bbff5fecdbe2b17a.bindPopup(popup_c456b7ae63a68fb3d2d8aa76143791c6)
#         ;
#
#
#
#
#             var marker_0879ed629e3e94828dd33f64496a58e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5ab42d020df978c484eb3390bef73373);
#
#
#         var popup_76b4c013c3103c9a682189ba41b62065 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b033fb421bb66c21d43d084715cf9a03 = $(`&lt;div id=&quot;html_b033fb421bb66c21d43d084715cf9a03&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_76b4c013c3103c9a682189ba41b62065.setContent(html_b033fb421bb66c21d43d084715cf9a03);
#
#
#
#         marker_0879ed629e3e94828dd33f64496a58e8.bindPopup(popup_76b4c013c3103c9a682189ba41b62065)
#         ;
#
#
#
#
#             var marker_0657b325722e5a9fed3e4dea4a73a75d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5ab42d020df978c484eb3390bef73373);
#
#
#         var popup_12a42d58e0f2f7013467816d0688c10d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edff304059baf400e4860f185065d6b7 = $(`&lt;div id=&quot;html_edff304059baf400e4860f185065d6b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_12a42d58e0f2f7013467816d0688c10d.setContent(html_edff304059baf400e4860f185065d6b7);
#
#
#
#         marker_0657b325722e5a9fed3e4dea4a73a75d.bindPopup(popup_12a42d58e0f2f7013467816d0688c10d)
#         ;
#
#
#
#
#             var marker_0e7a4fc05b36629a4fdee0eef6b178c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5ab42d020df978c484eb3390bef73373);
#
#
#         var popup_cad5f58a73667f87c6515027924d3144 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9bb73f68226462da0207e7afc7e6bfa9 = $(`&lt;div id=&quot;html_9bb73f68226462da0207e7afc7e6bfa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_cad5f58a73667f87c6515027924d3144.setContent(html_9bb73f68226462da0207e7afc7e6bfa9);
#
#
#
#         marker_0e7a4fc05b36629a4fdee0eef6b178c4.bindPopup(popup_cad5f58a73667f87c6515027924d3144)
#         ;
#
#
#
#
#             var marker_ff84a4183ee3ed405fac00f7a8a403ac = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5ab42d020df978c484eb3390bef73373);
#
#
#         var popup_c196ed95d9825ee3cebbfa18f48fd738 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2cec126a70e12ad45522e57cebd470d = $(`&lt;div id=&quot;html_d2cec126a70e12ad45522e57cebd470d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c196ed95d9825ee3cebbfa18f48fd738.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dbe3e11d7eb9b52f8a8023c6af4fdddd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dbe3e11d7eb9b52f8a8023c6af4fdddd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dbe3e11d7eb9b52f8a8023c6af4fdddd = L.map(
#                 &quot;map_dbe3e11d7eb9b52f8a8023c6af4fdddd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ee9bd05c2a15666d673284df9e10bfb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ee9bd05c2a15666d673284df9e10bfb.addTo(map_dbe3e11d7eb9b52f8a8023c6af4fdddd);
#
#
#             var feature_group_ad585ef197f2f2ca71030dcc9bd54c7b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_147ff4bc0c360eeb12baa03f8b9fe75d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ad585ef197f2f2ca71030dcc9bd54c7b);
#
#
#         var popup_348229f399dd4736ff2cdd6e58849f46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2711c4817fedc9f241bb0a3109b0490c = $(`&lt;div id=&quot;html_2711c4817fedc9f241bb0a3109b0490c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_348229f399dd4736ff2cdd6e58849f46.setContent(html_2711c4817fedc9f241bb0a3109b0490c);
#
#
#
#         marker_147ff4bc0c360eeb12baa03f8b9fe75d.bindPopup(popup_348229f399dd4736ff2cdd6e58849f46)
#         ;
#
#
#
#
#             var marker_ad0bf8f6ac68c7dee4521dad1a6f06ac = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ad585ef197f2f2ca71030dcc9bd54c7b);
#
#
#         var popup_4585117610ced120d96c2e38184962e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_238ce5c315bf58f618922ad57a9f0153 = $(`&lt;div id=&quot;html_238ce5c315bf58f618922ad57a9f0153&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_4585117610ced120d96c2e38184962e8.setContent(html_238ce5c315bf58f618922ad57a9f0153);
#
#
#
#         marker_ad0bf8f6ac68c7dee4521dad1a6f06ac.bindPopup(popup_4585117610ced120d96c2e38184962e8)
#         ;
#
#
#
#
#             var marker_ae0491aa6b21e6584b66588b0b210e48 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ad585ef197f2f2ca71030dcc9bd54c7b);
#
#
#         var popup_d284575dd2ac5d13e84ecda8323e89fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7730b772b9d092a0b8137bf9d7657439 = $(`&lt;div id=&quot;html_7730b772b9d092a0b8137bf9d7657439&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d284575dd2ac5d13e84ecda8323e89fc.setContent(html_7730b772b9d092a0b8137bf9d7657439);
#
#
#
#         marker_ae0491aa6b21e6584b66588b0b210e48.bindPopup(popup_d284575dd2ac5d13e84ecda8323e89fc)
#         ;
#
#
#
#
#             var marker_4135f3b1d134b443d0c802b4f1e73bd5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ad585ef197f2f2ca71030dcc9bd54c7b);
#
#
#         var popup_8ae3f8023fa66a3893a322ac1a476d15 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f97a224ff4039e9b1ce20e1c4adc36d5 = $(`&lt;div id=&quot;html_f97a224ff4039e9b1ce20e1c4adc36d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8ae3f8023fa66a3893a322ac1a476d15.setContent(html_f97a224ff4039e9b1ce20e1c4adc36d5);
#
#
#
#         marker_4135f3b1d134b443d0c802b4f1e73bd5.bindPopup(popup_8ae3f8023fa66a3893a322ac1a476d15)
#         ;
#
#
#
#
#             var marker_4c0b2a77faa5eda6624ef7361bc1d34f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ad585ef197f2f2ca71030dcc9bd54c7b);
#
#
#         var popup_e150eeb20109d8f4f2fe3d8254be4d0f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3eaeb13cd1ee6508dc9c40c0daee8a2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3eaeb13cd1ee6508dc9c40c0daee8a2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3eaeb13cd1ee6508dc9c40c0daee8a2 = L.map(
#                 &quot;map_a3eaeb13cd1ee6508dc9c40c0daee8a2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cbcbf0d8c994737108fafa839d2e645f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cbcbf0d8c994737108fafa839d2e645f.addTo(map_a3eaeb13cd1ee6508dc9c40c0daee8a2);
#
#
#             var feature_group_6f19016035fe9b4a776a91b085ba7fee = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6f19016035fe9b4a776a91b085ba7fee.addTo(map_a3eaeb13cd1ee6508dc9c40c0daee8a2);
#
#
#             var feature_group_sub_group_2d873e60f9af312df05f6cb872fb70eb = L.featureGroup.subGroup(
#                 feature_group_6f19016035fe9b4a776a91b085ba7fee
#             );
#
#
#             var marker_d4144ba9e2986f62e265ee2dc0d025bf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2d873e60f9af312df05f6cb872fb70eb);
#
#
#         var popup_d37b4e5c5367f5c1714e67549f57a88e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e161b49dd65401854fd141b3165d0399 = $(`&lt;div id=&quot;html_e161b49dd65401854fd141b3165d0399&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d37b4e5c5367f5c1714e67549f57a88e.setContent(html_e161b49dd65401854fd141b3165d0399);
#
#
#
#         marker_d4144ba9e2986f62e265ee2dc0d025bf.bindPopup(popup_d37b4e5c5367f5c1714e67549f57a88e)
#         ;
#
#
#
#
#             var marker_f14d69070a6ecbfdd5404f8ea7dcbe17 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2d873e60f9af312df05f6cb872fb70eb);
#
#
#         var popup_8b1ff39b3c55864dd6a1f8d1bc0489dc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ccdd83245d3019292356518c0c2dc14 = $(`&lt;div id=&quot;html_2ccdd83245d3019292356518c0c2dc14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8b1ff39b3c55864dd6a1f8d1bc0489dc.setContent(html_2ccdd83245d3019292356518c0c2dc14);
#
#
#
#         marker_f14d69070a6ecbfdd5404f8ea7dcbe17.bindPopup(popup_8b1ff39b3c55864dd6a1f8d1bc0489dc)
#         ;
#
#
#
#
#             var marker_ba2d79b6a2fd90a1309231e080e43498 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2d873e60f9af312df05f6cb872fb70eb);
#
#
#         var popup_0f96074e06a1a668d7acea59bb0f1412 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99eca91bfa75011aac351fe027a99639 = $(`&lt;div id=&quot;html_99eca91bfa75011aac351fe027a99639&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0f96074e06a1a668d7acea59bb0f1412.setContent(html_99eca91bfa75011aac351fe027a99639);
#
#
#
#         marker_ba2d79b6a2fd90a1309231e080e43498.bindPopup(popup_0f96074e06a1a668d7acea59bb0f1412)
#         ;
#
#
#
#
#             var marker_9168b49520ebd3881327ac0bc327b92f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2d873e60f9af312df05f6cb872fb70eb);
#
#
#         var popup_c0f3437a5f120bc82e70cc016041afa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a3838e0269a5efcd01729a9c7299100 = $(`&lt;div id=&quot;html_2a3838e0269a5efcd01729a9c7299100&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c0f3437a5f120bc82e70cc016041afa5.setContent(html_2a3838e0269a5efcd01729a9c7299100);
#
#
#
#         marker_
