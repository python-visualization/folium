# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_be66eadab56171fbf58c35d37fc43eba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_be66eadab56171fbf58c35d37fc43eba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_be66eadab56171fbf58c35d37fc43eba = L.map(
#                 &quot;map_be66eadab56171fbf58c35d37fc43eba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e6585bf45e6ed20e0c5e5c072ebf8e8a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e6585bf45e6ed20e0c5e5c072ebf8e8a.addTo(map_be66eadab56171fbf58c35d37fc43eba);
#
#
#             var marker_2f834552986413db035c93ba255d89a0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_be66eadab56171fbf58c35d37fc43eba);
#
#
#         var popup_ea08c068e69e7e09f078dd3717c3d333 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7bb11df58c0f1cdbc7bc983bdb5607d = $(`&lt;div id=&quot;html_e7bb11df58c0f1cdbc7bc983bdb5607d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ea08c068e69e7e09f078dd3717c3d333.setContent(html_e7bb11df58c0f1cdbc7bc983bdb5607d);
#
#
#
#         marker_2f834552986413db035c93ba255d89a0.bindPopup(popup_ea08c068e69e7e09f078dd3717c3d333)
#         ;
#
#
#
#
#             var marker_3af71b1dbac8fc4e13ea51fdac294087 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_be66eadab56171fbf58c35d37fc43eba);
#
#
#         var popup_a77ab1571e5b35d4a593dfc299ae0abd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f5bae80cb37670aa00e704a8a4cbcabe = $(`&lt;div id=&quot;html_f5bae80cb37670aa00e704a8a4cbcabe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a77ab1571e5b35d4a593dfc299ae0abd.setContent(html_f5bae80cb37670aa00e704a8a4cbcabe);
#
#
#
#         marker_3af71b1dbac8fc4e13ea51fdac294087.bindPopup(popup_a77ab1571e5b35d4a593dfc299ae0abd)
#         ;
#
#
#
#
#             var marker_f864472728c28858acd2bc9ea33140da = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_be66eadab56171fbf58c35d37fc43eba);
#
#
#         var popup_cd5215a77d0bd7e46b03e0cb78658f14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36326ac625a0be18aeaca0c684518bc2 = $(`&lt;div id=&quot;html_36326ac625a0be18aeaca0c684518bc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_cd5215a77d0bd7e46b03e0cb78658f14.setContent(html_36326ac625a0be18aeaca0c684518bc2);
#
#
#
#         marker_f864472728c28858acd2bc9ea33140da.bindPopup(popup_cd5215a77d0bd7e46b03e0cb78658f14)
#         ;
#
#
#
#
#             var marker_2c9efcb150776bbfedbc2788a86287ad = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_be66eadab56171fbf58c35d37fc43eba);
#
#
#         var popup_b1a5f927748a234618ee499370161df6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d90ffb1fcf2953762229840ab28464ff = $(`&lt;div id=&quot;html_d90ffb1fcf2953762229840ab28464ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b1a5f927748a234618ee499370161df6.setContent(html_d90ffb1fcf2953762229840ab28464ff);
#
#
#
#         marker_2c9efcb150776bbfedbc2788a86287ad.bindPopup(popup_b1a5f927748a234618ee499370161df6)
#         ;
#
#
#
#
#             var marker_b42f38e1c4ea1728cede61dc222624a9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_be66eadab56171fbf58c35d37fc43eba);
#
#
#         var popup_5892d64ee6667e328165e419cdc7dfc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_196edaad1b4c6505fa34d0816312a400 = $(`&lt;div id=&quot;html_196edaad1b4c6505fa34d0816312a400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5892d64ee6667e328165e419cdc7dfc5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_faaf5dbd935b94bc65a4ca49348da7cf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_faaf5dbd935b94bc65a4ca49348da7cf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_faaf5dbd935b94bc65a4ca49348da7cf = L.map(
#                 &quot;map_faaf5dbd935b94bc65a4ca49348da7cf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c4070b2362fa231fc8f12e840c0a7b89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c4070b2362fa231fc8f12e840c0a7b89.addTo(map_faaf5dbd935b94bc65a4ca49348da7cf);
#
#
#             var feature_group_d4dc877b387431ce7746f312204cfa0a = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_139239866af4287373321ce420b8d246 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d4dc877b387431ce7746f312204cfa0a);
#
#
#         var popup_fdecd9dda138133361cde8b93ea14447 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24c447f627dab28c3a42c14c9d2c4f75 = $(`&lt;div id=&quot;html_24c447f627dab28c3a42c14c9d2c4f75&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fdecd9dda138133361cde8b93ea14447.setContent(html_24c447f627dab28c3a42c14c9d2c4f75);
#
#
#
#         marker_139239866af4287373321ce420b8d246.bindPopup(popup_fdecd9dda138133361cde8b93ea14447)
#         ;
#
#
#
#
#             var marker_031afc18483edea7c2add60920a2ee1a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d4dc877b387431ce7746f312204cfa0a);
#
#
#         var popup_1ab87c6e465345c84cb50f6b931e8fea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e27b3728e7abaee0378c5afabb172c9 = $(`&lt;div id=&quot;html_9e27b3728e7abaee0378c5afabb172c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1ab87c6e465345c84cb50f6b931e8fea.setContent(html_9e27b3728e7abaee0378c5afabb172c9);
#
#
#
#         marker_031afc18483edea7c2add60920a2ee1a.bindPopup(popup_1ab87c6e465345c84cb50f6b931e8fea)
#         ;
#
#
#
#
#             var marker_b40a16dac33d1a6e436d5ddc61b8d93a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d4dc877b387431ce7746f312204cfa0a);
#
#
#         var popup_c9b48297f4f06c204163f14a80f8971d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a7b606e624ac78c3d44e9639c4ef38e = $(`&lt;div id=&quot;html_4a7b606e624ac78c3d44e9639c4ef38e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c9b48297f4f06c204163f14a80f8971d.setContent(html_4a7b606e624ac78c3d44e9639c4ef38e);
#
#
#
#         marker_b40a16dac33d1a6e436d5ddc61b8d93a.bindPopup(popup_c9b48297f4f06c204163f14a80f8971d)
#         ;
#
#
#
#
#             var marker_6336b69cb15d391ebe9ad827917d8055 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d4dc877b387431ce7746f312204cfa0a);
#
#
#         var popup_889bb4b1a816e36762f194996d07c4b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_393bf9b0b31ae7ada09a46275322b825 = $(`&lt;div id=&quot;html_393bf9b0b31ae7ada09a46275322b825&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_889bb4b1a816e36762f194996d07c4b2.setContent(html_393bf9b0b31ae7ada09a46275322b825);
#
#
#
#         marker_6336b69cb15d391ebe9ad827917d8055.bindPopup(popup_889bb4b1a816e36762f194996d07c4b2)
#         ;
#
#
#
#
#             var marker_ed5a2ee0708e209a88d71be4c6645248 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d4dc877b387431ce7746f312204cfa0a);
#
#
#         var popup_cea0e6c2ea7720e6e274773d73dce9c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_469e14cd96519e4449ac3603b2b4d4f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_469e14cd96519e4449ac3603b2b4d4f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_469e14cd96519e4449ac3603b2b4d4f0 = L.map(
#                 &quot;map_469e14cd96519e4449ac3603b2b4d4f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_65659cbfa4b64e0cc1b7452f36be00f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_65659cbfa4b64e0cc1b7452f36be00f9.addTo(map_469e14cd96519e4449ac3603b2b4d4f0);
#
#
#             var feature_group_75ada3f615054e40169a8e130c70d121 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_75ada3f615054e40169a8e130c70d121.addTo(map_469e14cd96519e4449ac3603b2b4d4f0);
#
#
#             var feature_group_sub_group_974bbe2502bf6aaffa697a7afd591c62 = L.featureGroup.subGroup(
#                 feature_group_75ada3f615054e40169a8e130c70d121
#             );
#
#
#             var marker_1594e9913836a3e8e9fba8c73bbb7053 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_974bbe2502bf6aaffa697a7afd591c62);
#
#
#         var popup_bd4a773954e1b7d60b5cdf917e3829ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_760dcd60068d4f5e9b2a42e26e2b31e1 = $(`&lt;div id=&quot;html_760dcd60068d4f5e9b2a42e26e2b31e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bd4a773954e1b7d60b5cdf917e3829ee.setContent(html_760dcd60068d4f5e9b2a42e26e2b31e1);
#
#
#
#         marker_1594e9913836a3e8e9fba8c73bbb7053.bindPopup(popup_bd4a773954e1b7d60b5cdf917e3829ee)
#         ;
#
#
#
#
#             var marker_d1151008d9c885464a30f6d36ab2388c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_974bbe2502bf6aaffa697a7afd591c62);
#
#
#         var popup_490a131d534166a4d8b8b9245e3858f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50f367c767715d01e400b83c3807204b = $(`&lt;div id=&quot;html_50f367c767715d01e400b83c3807204b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_490a131d534166a4d8b8b9245e3858f7.setContent(html_50f367c767715d01e400b83c3807204b);
#
#
#
#         marker_d1151008d9c885464a30f6d36ab2388c.bindPopup(popup_490a131d534166a4d8b8b9245e3858f7)
#         ;
#
#
#
#
#             var marker_aa981a1e749e2a89726db1f98f628d7b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_974bbe2502bf6aaffa697a7afd591c62);
#
#
#         var popup_5569321379b16ff612a976ce5dc7a3f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8515d8f205971ef33c0d1e5f699a7081 = $(`&lt;div id=&quot;html_8515d8f205971ef33c0d1e5f699a7081&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5569321379b16ff612a976ce5dc7a3f9.setContent(html_8515d8f205971ef33c0d1e5f699a7081);
#
#
#
#         marker_aa981a1e749e2a89726db1f98f628d7b.bindPopup(popup_5569321379b16ff612a976ce5dc7a3f9)
#         ;
#
#
#
#
#             var marker_7e40a86a5380025b53b106a524781e8a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_974bbe2502bf6aaffa697a7afd591c62);
#
#
#         var popup_953523893064e42f5eb86c3d03860bb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f5c7d71ad46d42434b16e09035bbe2a = $(`&lt;div id=&quot;html_0f5c7d71ad46d42434b16e09035bbe2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_953523893064e42f5eb86c3d03860bb9.setContent(html_0f5c7d71ad46d42434b16e09035bbe2a);
#
#
#
#         marker_
