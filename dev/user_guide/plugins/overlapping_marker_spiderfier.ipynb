# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca36721ab0773ed05994866782e0b6f4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca36721ab0773ed05994866782e0b6f4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca36721ab0773ed05994866782e0b6f4 = L.map(
#                 &quot;map_ca36721ab0773ed05994866782e0b6f4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9298bb260445f61d0a73a0c904d3d847 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9298bb260445f61d0a73a0c904d3d847.addTo(map_ca36721ab0773ed05994866782e0b6f4);
#
#
#             var marker_c969bc5888d9f767fde11be8a7be3979 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_ca36721ab0773ed05994866782e0b6f4);
#
#
#         var popup_72ae1b512e93fff3a1450e8ab3b0273e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbbaab9a517c23fe6f2fa8cbfd34b4c1 = $(`&lt;div id=&quot;html_fbbaab9a517c23fe6f2fa8cbfd34b4c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_72ae1b512e93fff3a1450e8ab3b0273e.setContent(html_fbbaab9a517c23fe6f2fa8cbfd34b4c1);
#
#
#
#         marker_c969bc5888d9f767fde11be8a7be3979.bindPopup(popup_72ae1b512e93fff3a1450e8ab3b0273e)
#         ;
#
#
#
#
#             var marker_385870f20c08fb26f38533bd281e49d4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_ca36721ab0773ed05994866782e0b6f4);
#
#
#         var popup_935b38ec352afef0d75907c5af88f621 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3df94664a3849eae6bfa4456273db7e = $(`&lt;div id=&quot;html_d3df94664a3849eae6bfa4456273db7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_935b38ec352afef0d75907c5af88f621.setContent(html_d3df94664a3849eae6bfa4456273db7e);
#
#
#
#         marker_385870f20c08fb26f38533bd281e49d4.bindPopup(popup_935b38ec352afef0d75907c5af88f621)
#         ;
#
#
#
#
#             var marker_1a04b4e66ab09d9f5361e92608ea43e6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_ca36721ab0773ed05994866782e0b6f4);
#
#
#         var popup_4e3852001cc20c3775ff125e12064fc8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e292efe42ead0435230d7334d19dda6 = $(`&lt;div id=&quot;html_4e292efe42ead0435230d7334d19dda6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4e3852001cc20c3775ff125e12064fc8.setContent(html_4e292efe42ead0435230d7334d19dda6);
#
#
#
#         marker_1a04b4e66ab09d9f5361e92608ea43e6.bindPopup(popup_4e3852001cc20c3775ff125e12064fc8)
#         ;
#
#
#
#
#             var marker_664b96a603edede578d0c5160779feea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_ca36721ab0773ed05994866782e0b6f4);
#
#
#         var popup_1f990ca198eb78eee96deadf810e8561 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f5250ae83b8d2486c5bcf406dc09528 = $(`&lt;div id=&quot;html_6f5250ae83b8d2486c5bcf406dc09528&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1f990ca198eb78eee96deadf810e8561.setContent(html_6f5250ae83b8d2486c5bcf406dc09528);
#
#
#
#         marker_664b96a603edede578d0c5160779feea.bindPopup(popup_1f990ca198eb78eee96deadf810e8561)
#         ;
#
#
#
#
#             var marker_d4b51899fd43f32121b6f3af9a4dee50 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_ca36721ab0773ed05994866782e0b6f4);
#
#
#         var popup_c5563ae4242e3e11bce55382e6309531 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad6e9f4f7e4785623f74aa5327808c22 = $(`&lt;div id=&quot;html_ad6e9f4f7e4785623f74aa5327808c22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c5563ae4242e3e11bce55382e6309531.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6063c7192589c006b6f481d2858704fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6063c7192589c006b6f481d2858704fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6063c7192589c006b6f481d2858704fb = L.map(
#                 &quot;map_6063c7192589c006b6f481d2858704fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e02d8c502cedc5ad987f8182801aa09f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e02d8c502cedc5ad987f8182801aa09f.addTo(map_6063c7192589c006b6f481d2858704fb);
#
#
#             var feature_group_c56b9e6fc5ff0f2ee3acd1d6aaf37754 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e6a040790b4d70470ccfee85f310cf31 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_c56b9e6fc5ff0f2ee3acd1d6aaf37754);
#
#
#         var popup_92724f21b96990f662c56e270b3858cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d521e14e1cb53bdd4fb73f20218ad7a1 = $(`&lt;div id=&quot;html_d521e14e1cb53bdd4fb73f20218ad7a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_92724f21b96990f662c56e270b3858cd.setContent(html_d521e14e1cb53bdd4fb73f20218ad7a1);
#
#
#
#         marker_e6a040790b4d70470ccfee85f310cf31.bindPopup(popup_92724f21b96990f662c56e270b3858cd)
#         ;
#
#
#
#
#             var marker_6e1c8cac316d3873dbc64556c42df330 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_c56b9e6fc5ff0f2ee3acd1d6aaf37754);
#
#
#         var popup_e3501180317225642d78ad25b0dc217d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ef90f36168f32f943eb2649d5864751b = $(`&lt;div id=&quot;html_ef90f36168f32f943eb2649d5864751b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_e3501180317225642d78ad25b0dc217d.setContent(html_ef90f36168f32f943eb2649d5864751b);
#
#
#
#         marker_6e1c8cac316d3873dbc64556c42df330.bindPopup(popup_e3501180317225642d78ad25b0dc217d)
#         ;
#
#
#
#
#             var marker_80278ccf46a1b739634c6702e48e217b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_c56b9e6fc5ff0f2ee3acd1d6aaf37754);
#
#
#         var popup_1be2c9198c2bf7e47e2fd6d70dc4bbbc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6e29c8d5ec5e6fb8fce9d117cb1eb01 = $(`&lt;div id=&quot;html_a6e29c8d5ec5e6fb8fce9d117cb1eb01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1be2c9198c2bf7e47e2fd6d70dc4bbbc.setContent(html_a6e29c8d5ec5e6fb8fce9d117cb1eb01);
#
#
#
#         marker_80278ccf46a1b739634c6702e48e217b.bindPopup(popup_1be2c9198c2bf7e47e2fd6d70dc4bbbc)
#         ;
#
#
#
#
#             var marker_4fe776c4b2ac7ee8075a835e2b3563c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_c56b9e6fc5ff0f2ee3acd1d6aaf37754);
#
#
#         var popup_c7b3fd6bce997ee4a600f6ca8437bcbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8e492fc76e28f03542cce85531c8ebf = $(`&lt;div id=&quot;html_d8e492fc76e28f03542cce85531c8ebf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_c7b3fd6bce997ee4a600f6ca8437bcbb.setContent(html_d8e492fc76e28f03542cce85531c8ebf);
#
#
#
#         marker_4fe776c4b2ac7ee8075a835e2b3563c4.bindPopup(popup_c7b3fd6bce997ee4a600f6ca8437bcbb)
#         ;
#
#
#
#
#             var marker_05c63f8841599705e0ae430008e5a2c1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_c56b9e6fc5ff0f2ee3acd1d6aaf37754);
#
#
#         var popup_05369c5a7f205d6bd1f03e62cc412369 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a06e2fe4042718be8635bdbb0ce4a47d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a06e2fe4042718be8635bdbb0ce4a47d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a06e2fe4042718be8635bdbb0ce4a47d = L.map(
#                 &quot;map_a06e2fe4042718be8635bdbb0ce4a47d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8d74d45ec5945e5fac7395fd2b19beac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8d74d45ec5945e5fac7395fd2b19beac.addTo(map_a06e2fe4042718be8635bdbb0ce4a47d);
#
#
#             var feature_group_7cdab593c8eb737e77b8b5b54238d5b1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7cdab593c8eb737e77b8b5b54238d5b1.addTo(map_a06e2fe4042718be8635bdbb0ce4a47d);
#
#
#             var feature_group_sub_group_6439a636a13090b5c6d6e05c2dd3f3ee = L.featureGroup.subGroup(
#                 feature_group_7cdab593c8eb737e77b8b5b54238d5b1
#             );
#
#
#             var marker_ec08483cc351535e54c97db6594263e2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6439a636a13090b5c6d6e05c2dd3f3ee);
#
#
#         var popup_189804553dc74d99d0d7badb3f862a2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f296bd48de4c059e817e25dfb265abd0 = $(`&lt;div id=&quot;html_f296bd48de4c059e817e25dfb265abd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_189804553dc74d99d0d7badb3f862a2b.setContent(html_f296bd48de4c059e817e25dfb265abd0);
#
#
#
#         marker_ec08483cc351535e54c97db6594263e2.bindPopup(popup_189804553dc74d99d0d7badb3f862a2b)
#         ;
#
#
#
#
#             var marker_032647a6a34e2b94c37de8a3bf54d695 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6439a636a13090b5c6d6e05c2dd3f3ee);
#
#
#         var popup_552dc613994edc59c6d99165202bb6b7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdb9dfee73fe5ca7d85a8e323b40ca48 = $(`&lt;div id=&quot;html_bdb9dfee73fe5ca7d85a8e323b40ca48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_552dc613994edc59c6d99165202bb6b7.setContent(html_bdb9dfee73fe5ca7d85a8e323b40ca48);
#
#
#
#         marker_032647a6a34e2b94c37de8a3bf54d695.bindPopup(popup_552dc613994edc59c6d99165202bb6b7)
#         ;
#
#
#
#
#             var marker_dd4817173318239e87044a5bcefea698 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6439a636a13090b5c6d6e05c2dd3f3ee);
#
#
#         var popup_c2e6d0a7d8303685353ec0cafa6106da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52a6e7a00c904c8a7c12b059f0c899c1 = $(`&lt;div id=&quot;html_52a6e7a00c904c8a7c12b059f0c899c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c2e6d0a7d8303685353ec0cafa6106da.setContent(html_52a6e7a00c904c8a7c12b059f0c899c1);
#
#
#
#         marker_dd4817173318239e87044a5bcefea698.bindPopup(popup_c2e6d0a7d8303685353ec0cafa6106da)
#         ;
#
#
#
#
#             var marker_3789e62ceb1b28a2a82c5763c842df12 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6439a636a13090b5c6d6e05c2dd3f3ee);
#
#
#         var popup_3f0138941391956c02ea636da4ebe674 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7b0093db28a14507e40bb43c93eb6ea = $(`&lt;div id=&quot;html_c7b0093db28a14507e40bb43c93eb6ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3f0138941391956c02ea636da4ebe674.setContent(html_c7b0093db28a14507e40bb43c93eb6ea);
#
#
#
#         marker_
