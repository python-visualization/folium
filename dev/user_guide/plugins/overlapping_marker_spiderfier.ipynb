# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6096d3e0f35486455db0631540226a9c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6096d3e0f35486455db0631540226a9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6096d3e0f35486455db0631540226a9c = L.map(
#                 &quot;map_6096d3e0f35486455db0631540226a9c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96508eaff53fa6606a56f1329ca43023 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96508eaff53fa6606a56f1329ca43023.addTo(map_6096d3e0f35486455db0631540226a9c);
#
#
#             var marker_74e0e8a1aea06f521169ffd63ede9913 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_6096d3e0f35486455db0631540226a9c);
#
#
#         var popup_15a7c0c615ff14006e62837d05a3239f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07aca14fd77ec0d15113b3cbe703f7e1 = $(`&lt;div id=&quot;html_07aca14fd77ec0d15113b3cbe703f7e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_15a7c0c615ff14006e62837d05a3239f.setContent(html_07aca14fd77ec0d15113b3cbe703f7e1);
#
#
#
#         marker_74e0e8a1aea06f521169ffd63ede9913.bindPopup(popup_15a7c0c615ff14006e62837d05a3239f)
#         ;
#
#
#
#
#             var marker_6ee55874f749850227619362faf20ff6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_6096d3e0f35486455db0631540226a9c);
#
#
#         var popup_e6d31f914f4b7356a13ca38b005c06f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9894c7018fd90e0eb4d793b4102a729 = $(`&lt;div id=&quot;html_a9894c7018fd90e0eb4d793b4102a729&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e6d31f914f4b7356a13ca38b005c06f5.setContent(html_a9894c7018fd90e0eb4d793b4102a729);
#
#
#
#         marker_6ee55874f749850227619362faf20ff6.bindPopup(popup_e6d31f914f4b7356a13ca38b005c06f5)
#         ;
#
#
#
#
#             var marker_08e06e06337a0991b8f556d75ba124b4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_6096d3e0f35486455db0631540226a9c);
#
#
#         var popup_61627e8b83e64c293add6509eee67f7c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a2c4cabf79ffdd4ddb948bedb3d4f3ef = $(`&lt;div id=&quot;html_a2c4cabf79ffdd4ddb948bedb3d4f3ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_61627e8b83e64c293add6509eee67f7c.setContent(html_a2c4cabf79ffdd4ddb948bedb3d4f3ef);
#
#
#
#         marker_08e06e06337a0991b8f556d75ba124b4.bindPopup(popup_61627e8b83e64c293add6509eee67f7c)
#         ;
#
#
#
#
#             var marker_18f1ca65d1b65bdf8d63ad3be43e900a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_6096d3e0f35486455db0631540226a9c);
#
#
#         var popup_8f89cc9320022dced87df92c3a73fe99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a67ccd7e28b787ca209b2da0a2f97ac = $(`&lt;div id=&quot;html_5a67ccd7e28b787ca209b2da0a2f97ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_8f89cc9320022dced87df92c3a73fe99.setContent(html_5a67ccd7e28b787ca209b2da0a2f97ac);
#
#
#
#         marker_18f1ca65d1b65bdf8d63ad3be43e900a.bindPopup(popup_8f89cc9320022dced87df92c3a73fe99)
#         ;
#
#
#
#
#             var marker_f3e083270a9f36a7a4c7b1bb47c32894 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_6096d3e0f35486455db0631540226a9c);
#
#
#         var popup_9db491971012a8ddcad4f088bfaa067c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48a4aaf4e86977bb7ef8ef92c5567b9a = $(`&lt;div id=&quot;html_48a4aaf4e86977bb7ef8ef92c5567b9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9db491971012a8ddcad4f088bfaa067c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_09e602daf78c1854c8910ef93604bf4b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_09e602daf78c1854c8910ef93604bf4b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_09e602daf78c1854c8910ef93604bf4b = L.map(
#                 &quot;map_09e602daf78c1854c8910ef93604bf4b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fbf84211edb0f1439ab5fa9a50ffb900 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fbf84211edb0f1439ab5fa9a50ffb900.addTo(map_09e602daf78c1854c8910ef93604bf4b);
#
#
#             var feature_group_b329e3b78473ce893616367a6554e5c6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bdbe31c33b341957dac42926ea1cab7b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b329e3b78473ce893616367a6554e5c6);
#
#
#         var popup_297ee32d740054a5c0466a1c68e2dc2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_817f63bbc790dab41c11ad01c68df04f = $(`&lt;div id=&quot;html_817f63bbc790dab41c11ad01c68df04f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_297ee32d740054a5c0466a1c68e2dc2e.setContent(html_817f63bbc790dab41c11ad01c68df04f);
#
#
#
#         marker_bdbe31c33b341957dac42926ea1cab7b.bindPopup(popup_297ee32d740054a5c0466a1c68e2dc2e)
#         ;
#
#
#
#
#             var marker_2330021c79ad6cb1fc23ccdbd4fab77b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b329e3b78473ce893616367a6554e5c6);
#
#
#         var popup_1262781438be8fad1ab635d1e3ba63ea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_266304d67198680d36b2b59acddbe770 = $(`&lt;div id=&quot;html_266304d67198680d36b2b59acddbe770&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1262781438be8fad1ab635d1e3ba63ea.setContent(html_266304d67198680d36b2b59acddbe770);
#
#
#
#         marker_2330021c79ad6cb1fc23ccdbd4fab77b.bindPopup(popup_1262781438be8fad1ab635d1e3ba63ea)
#         ;
#
#
#
#
#             var marker_3397ae5727ebce3c6839c87ffc08873e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b329e3b78473ce893616367a6554e5c6);
#
#
#         var popup_32975a1264cf96f4fc04a90f26417b75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a32188b4ff1f56565d63c5ad961aade = $(`&lt;div id=&quot;html_4a32188b4ff1f56565d63c5ad961aade&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_32975a1264cf96f4fc04a90f26417b75.setContent(html_4a32188b4ff1f56565d63c5ad961aade);
#
#
#
#         marker_3397ae5727ebce3c6839c87ffc08873e.bindPopup(popup_32975a1264cf96f4fc04a90f26417b75)
#         ;
#
#
#
#
#             var marker_ff1a6dc3e17a3560fd554146ce677cc1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b329e3b78473ce893616367a6554e5c6);
#
#
#         var popup_d2621921a85491c9ef30df9d5214fd08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2de45e7b4829a6434196bc81e9506500 = $(`&lt;div id=&quot;html_2de45e7b4829a6434196bc81e9506500&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d2621921a85491c9ef30df9d5214fd08.setContent(html_2de45e7b4829a6434196bc81e9506500);
#
#
#
#         marker_ff1a6dc3e17a3560fd554146ce677cc1.bindPopup(popup_d2621921a85491c9ef30df9d5214fd08)
#         ;
#
#
#
#
#             var marker_ff784a7b58a7f4393c9bb0235c698063 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b329e3b78473ce893616367a6554e5c6);
#
#
#         var popup_3ecf3b860ac8c99505dde9b763782874 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e6050fb85f84884847c79cda32121d0c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e6050fb85f84884847c79cda32121d0c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e6050fb85f84884847c79cda32121d0c = L.map(
#                 &quot;map_e6050fb85f84884847c79cda32121d0c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f12e9a4c3f417fd612b5c0ed5c88f192 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f12e9a4c3f417fd612b5c0ed5c88f192.addTo(map_e6050fb85f84884847c79cda32121d0c);
#
#
#             var feature_group_04286159f69d0084f2eb730acd66a5b5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_04286159f69d0084f2eb730acd66a5b5.addTo(map_e6050fb85f84884847c79cda32121d0c);
#
#
#             var feature_group_sub_group_8f33a18da242e1a1e1e86b72dc9d9466 = L.featureGroup.subGroup(
#                 feature_group_04286159f69d0084f2eb730acd66a5b5
#             );
#
#
#             var marker_97c317a9189b86fdf379560474e3408c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8f33a18da242e1a1e1e86b72dc9d9466);
#
#
#         var popup_4d4f2e017003bc3ebbeed7614306b3c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32e6587a67e1e7bf81a7e1cc37b25dda = $(`&lt;div id=&quot;html_32e6587a67e1e7bf81a7e1cc37b25dda&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4d4f2e017003bc3ebbeed7614306b3c7.setContent(html_32e6587a67e1e7bf81a7e1cc37b25dda);
#
#
#
#         marker_97c317a9189b86fdf379560474e3408c.bindPopup(popup_4d4f2e017003bc3ebbeed7614306b3c7)
#         ;
#
#
#
#
#             var marker_18d0682d62c2295d8ea596fb9ed89dc1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8f33a18da242e1a1e1e86b72dc9d9466);
#
#
#         var popup_8dcac37170f8ac7c1864658c312e2daf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07ca6df283cdfd67b2eceb79d2809ad4 = $(`&lt;div id=&quot;html_07ca6df283cdfd67b2eceb79d2809ad4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8dcac37170f8ac7c1864658c312e2daf.setContent(html_07ca6df283cdfd67b2eceb79d2809ad4);
#
#
#
#         marker_18d0682d62c2295d8ea596fb9ed89dc1.bindPopup(popup_8dcac37170f8ac7c1864658c312e2daf)
#         ;
#
#
#
#
#             var marker_6f3008358b6294b821ba87867b55a758 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8f33a18da242e1a1e1e86b72dc9d9466);
#
#
#         var popup_11ae1af6e1b613447653fbee0a34c545 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74580d58089019b5d30d28e347135896 = $(`&lt;div id=&quot;html_74580d58089019b5d30d28e347135896&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_11ae1af6e1b613447653fbee0a34c545.setContent(html_74580d58089019b5d30d28e347135896);
#
#
#
#         marker_6f3008358b6294b821ba87867b55a758.bindPopup(popup_11ae1af6e1b613447653fbee0a34c545)
#         ;
#
#
#
#
#             var marker_bbb89f297d7554a810f4e9f3484b7ec8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8f33a18da242e1a1e1e86b72dc9d9466);
#
#
#         var popup_27d256507df42caa0e27d280e4f3984a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7ed826d71f14e33de4cc518252d2497 = $(`&lt;div id=&quot;html_a7ed826d71f14e33de4cc518252d2497&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_27d256507df42caa0e27d280e4f3984a.setContent(html_a7ed826d71f14e33de4cc518252d2497);
#
#
#
#         marker_
