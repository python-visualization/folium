# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_164efb6e1f03a8ec27c76cebdc843345 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_164efb6e1f03a8ec27c76cebdc843345&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_164efb6e1f03a8ec27c76cebdc843345 = L.map(
#                 &quot;map_164efb6e1f03a8ec27c76cebdc843345&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dcd51e7fc95f2aee7aa25105a0515cd4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dcd51e7fc95f2aee7aa25105a0515cd4.addTo(map_164efb6e1f03a8ec27c76cebdc843345);
#
#
#             var marker_686b731358bf5b71e4ed11c3893975c8 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_164efb6e1f03a8ec27c76cebdc843345);
#
#
#         var popup_fee14b928481d4a7c57233a2a4366b27 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_377681ae14ff27724122d5fd94cd4769 = $(`&lt;div id=&quot;html_377681ae14ff27724122d5fd94cd4769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fee14b928481d4a7c57233a2a4366b27.setContent(html_377681ae14ff27724122d5fd94cd4769);
#
#
#
#         marker_686b731358bf5b71e4ed11c3893975c8.bindPopup(popup_fee14b928481d4a7c57233a2a4366b27)
#         ;
#
#
#
#
#             var marker_1381fd0c1fede1c6022a85eb1f725334 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_164efb6e1f03a8ec27c76cebdc843345);
#
#
#         var popup_e6b63dcf728274ceaf166dfe21146478 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d192c9a589275b01f55e18223355f57 = $(`&lt;div id=&quot;html_5d192c9a589275b01f55e18223355f57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e6b63dcf728274ceaf166dfe21146478.setContent(html_5d192c9a589275b01f55e18223355f57);
#
#
#
#         marker_1381fd0c1fede1c6022a85eb1f725334.bindPopup(popup_e6b63dcf728274ceaf166dfe21146478)
#         ;
#
#
#
#
#             var marker_7d997141ee018f79e9a363fa1bdec43d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_164efb6e1f03a8ec27c76cebdc843345);
#
#
#         var popup_7cf142ba089787c50ceaab6866fc3831 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3503977b1a7cc49ef7cb379da2d1dc19 = $(`&lt;div id=&quot;html_3503977b1a7cc49ef7cb379da2d1dc19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7cf142ba089787c50ceaab6866fc3831.setContent(html_3503977b1a7cc49ef7cb379da2d1dc19);
#
#
#
#         marker_7d997141ee018f79e9a363fa1bdec43d.bindPopup(popup_7cf142ba089787c50ceaab6866fc3831)
#         ;
#
#
#
#
#             var marker_d5d79e5d84c07e897cff26ed463a5c38 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_164efb6e1f03a8ec27c76cebdc843345);
#
#
#         var popup_72da51718cc97e2bc4a825ede89df08e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_387aae0f1c4206214190a35c391878a3 = $(`&lt;div id=&quot;html_387aae0f1c4206214190a35c391878a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_72da51718cc97e2bc4a825ede89df08e.setContent(html_387aae0f1c4206214190a35c391878a3);
#
#
#
#         marker_d5d79e5d84c07e897cff26ed463a5c38.bindPopup(popup_72da51718cc97e2bc4a825ede89df08e)
#         ;
#
#
#
#
#             var marker_d4494a302f4cc15b441944a28b86d43a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_164efb6e1f03a8ec27c76cebdc843345);
#
#
#         var popup_9da361ddd3ccfc72fa350d42c90db977 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7df90a1e1e3ec6b6d2c91ac20ca8c6b = $(`&lt;div id=&quot;html_f7df90a1e1e3ec6b6d2c91ac20ca8c6b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_9da361ddd3ccfc72fa350d42c90db977.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_140cf2406463e0ed4fc5c7ad896c5e57 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_140cf2406463e0ed4fc5c7ad896c5e57&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_140cf2406463e0ed4fc5c7ad896c5e57 = L.map(
#                 &quot;map_140cf2406463e0ed4fc5c7ad896c5e57&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_29040b2d81685f73aacc218bc4900938 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29040b2d81685f73aacc218bc4900938.addTo(map_140cf2406463e0ed4fc5c7ad896c5e57);
#
#
#             var feature_group_5bb0899f40d17f2f06ff702f0d1326c9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d620a84497203d9ee5d9d6e64ad980e1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_5bb0899f40d17f2f06ff702f0d1326c9);
#
#
#         var popup_ae058c088c1b9e9f7ad98c6576f70dae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6417be6cf12df008fae1ea9b9ac55d1 = $(`&lt;div id=&quot;html_c6417be6cf12df008fae1ea9b9ac55d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_ae058c088c1b9e9f7ad98c6576f70dae.setContent(html_c6417be6cf12df008fae1ea9b9ac55d1);
#
#
#
#         marker_d620a84497203d9ee5d9d6e64ad980e1.bindPopup(popup_ae058c088c1b9e9f7ad98c6576f70dae)
#         ;
#
#
#
#
#             var marker_bf044605092f97bbe11b5efcb12202fb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_5bb0899f40d17f2f06ff702f0d1326c9);
#
#
#         var popup_99ee1f0853fe8e602d0e8063c53deba1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d38956eb80f6e1a91a9f49f3385ea352 = $(`&lt;div id=&quot;html_d38956eb80f6e1a91a9f49f3385ea352&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_99ee1f0853fe8e602d0e8063c53deba1.setContent(html_d38956eb80f6e1a91a9f49f3385ea352);
#
#
#
#         marker_bf044605092f97bbe11b5efcb12202fb.bindPopup(popup_99ee1f0853fe8e602d0e8063c53deba1)
#         ;
#
#
#
#
#             var marker_c61c8679a537022a16bfad29b0b43884 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_5bb0899f40d17f2f06ff702f0d1326c9);
#
#
#         var popup_2e725fb38205265a49e301b1ad19af8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cc4ea1473e12e683cd8d51064af1601e = $(`&lt;div id=&quot;html_cc4ea1473e12e683cd8d51064af1601e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2e725fb38205265a49e301b1ad19af8c.setContent(html_cc4ea1473e12e683cd8d51064af1601e);
#
#
#
#         marker_c61c8679a537022a16bfad29b0b43884.bindPopup(popup_2e725fb38205265a49e301b1ad19af8c)
#         ;
#
#
#
#
#             var marker_06283d3c616708545e5bd9053b160ffa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_5bb0899f40d17f2f06ff702f0d1326c9);
#
#
#         var popup_be2aef9752fafc94e0a055deab93f72a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_813e74093610b167e6e67aa8db9f99c6 = $(`&lt;div id=&quot;html_813e74093610b167e6e67aa8db9f99c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_be2aef9752fafc94e0a055deab93f72a.setContent(html_813e74093610b167e6e67aa8db9f99c6);
#
#
#
#         marker_06283d3c616708545e5bd9053b160ffa.bindPopup(popup_be2aef9752fafc94e0a055deab93f72a)
#         ;
#
#
#
#
#             var marker_b691302d28a117d4baff31090fbd9779 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_5bb0899f40d17f2f06ff702f0d1326c9);
#
#
#         var popup_821190ea268aa9372a7690b48464bdfa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2a58743d139727c3efe0eb30cd4d02d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2a58743d139727c3efe0eb30cd4d02d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2a58743d139727c3efe0eb30cd4d02d1 = L.map(
#                 &quot;map_2a58743d139727c3efe0eb30cd4d02d1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fbf81c275663f55747b625795866bdbf = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fbf81c275663f55747b625795866bdbf.addTo(map_2a58743d139727c3efe0eb30cd4d02d1);
#
#
#             var feature_group_8c18d9adcb0c2e18a58f85a4a1461f2f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_8c18d9adcb0c2e18a58f85a4a1461f2f.addTo(map_2a58743d139727c3efe0eb30cd4d02d1);
#
#
#             var feature_group_sub_group_6b77c2e4d287f4943afcc99850706365 = L.featureGroup.subGroup(
#                 feature_group_8c18d9adcb0c2e18a58f85a4a1461f2f
#             );
#
#
#             var marker_2d5b4027252c3410f780cbe1e86353d2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b77c2e4d287f4943afcc99850706365);
#
#
#         var popup_f82e6baf61592e1a13c4fd0512290886 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0cc2f3a3460035ddd6927a5034825ec = $(`&lt;div id=&quot;html_c0cc2f3a3460035ddd6927a5034825ec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f82e6baf61592e1a13c4fd0512290886.setContent(html_c0cc2f3a3460035ddd6927a5034825ec);
#
#
#
#         marker_2d5b4027252c3410f780cbe1e86353d2.bindPopup(popup_f82e6baf61592e1a13c4fd0512290886)
#         ;
#
#
#
#
#             var marker_62f0401c5b2c10482aef5a77379c6b1f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b77c2e4d287f4943afcc99850706365);
#
#
#         var popup_ada27a20a9dafa1f3d4e3b75aa96f14e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdcddf01b0e29cf0f15a921b532271e0 = $(`&lt;div id=&quot;html_fdcddf01b0e29cf0f15a921b532271e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ada27a20a9dafa1f3d4e3b75aa96f14e.setContent(html_fdcddf01b0e29cf0f15a921b532271e0);
#
#
#
#         marker_62f0401c5b2c10482aef5a77379c6b1f.bindPopup(popup_ada27a20a9dafa1f3d4e3b75aa96f14e)
#         ;
#
#
#
#
#             var marker_608c65a74a203c1bb41714ad58a3557b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b77c2e4d287f4943afcc99850706365);
#
#
#         var popup_fe16a8677b59a21bae8a1423689c271e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2179f9c0384dd9431887a88ec9cb901f = $(`&lt;div id=&quot;html_2179f9c0384dd9431887a88ec9cb901f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fe16a8677b59a21bae8a1423689c271e.setContent(html_2179f9c0384dd9431887a88ec9cb901f);
#
#
#
#         marker_608c65a74a203c1bb41714ad58a3557b.bindPopup(popup_fe16a8677b59a21bae8a1423689c271e)
#         ;
#
#
#
#
#             var marker_da23fe929c76c22ef8d87f7936784644 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6b77c2e4d287f4943afcc99850706365);
#
#
#         var popup_8302a52887b5de6437821610b2fbac49 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05f839986e442e33055e94bad7fa1807 = $(`&lt;div id=&quot;html_05f839986e442e33055e94bad7fa1807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8302a52887b5de6437821610b2fbac49.setContent(html_05f839986e442e33055e94bad7fa1807);
#
#
#
#         marker_
