# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_770b839ccd0eba16d93c1aa4e8dd2bc5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_770b839ccd0eba16d93c1aa4e8dd2bc5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_770b839ccd0eba16d93c1aa4e8dd2bc5 = L.map(
#                 &quot;map_770b839ccd0eba16d93c1aa4e8dd2bc5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d8a8420b2b95058da02515fc27de5b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5d8a8420b2b95058da02515fc27de5b5.addTo(map_770b839ccd0eba16d93c1aa4e8dd2bc5);
#
#
#             var marker_3b40fc6f6cd8a0bb0549bc9182b5fd91 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_770b839ccd0eba16d93c1aa4e8dd2bc5);
#
#
#         var popup_050d32afc0100459f870ac1e9b257557 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7fe6fb2f6c3c7389e9c5acc0840fbaa = $(`&lt;div id=&quot;html_f7fe6fb2f6c3c7389e9c5acc0840fbaa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_050d32afc0100459f870ac1e9b257557.setContent(html_f7fe6fb2f6c3c7389e9c5acc0840fbaa);
#
#
#
#         marker_3b40fc6f6cd8a0bb0549bc9182b5fd91.bindPopup(popup_050d32afc0100459f870ac1e9b257557)
#         ;
#
#
#
#
#             var marker_aed25906b670f0483f250473f903d86f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_770b839ccd0eba16d93c1aa4e8dd2bc5);
#
#
#         var popup_091c5f8983c0af33a27b47ff104277c1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78c848851422d8a36d5d6e1c4ab47b3f = $(`&lt;div id=&quot;html_78c848851422d8a36d5d6e1c4ab47b3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_091c5f8983c0af33a27b47ff104277c1.setContent(html_78c848851422d8a36d5d6e1c4ab47b3f);
#
#
#
#         marker_aed25906b670f0483f250473f903d86f.bindPopup(popup_091c5f8983c0af33a27b47ff104277c1)
#         ;
#
#
#
#
#             var marker_87d017b5356743095a247847e0029a47 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_770b839ccd0eba16d93c1aa4e8dd2bc5);
#
#
#         var popup_43b999ca680bc2d87aef3f6998e66ed4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_950ea61faf7f4024f65e67127ba7b22e = $(`&lt;div id=&quot;html_950ea61faf7f4024f65e67127ba7b22e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_43b999ca680bc2d87aef3f6998e66ed4.setContent(html_950ea61faf7f4024f65e67127ba7b22e);
#
#
#
#         marker_87d017b5356743095a247847e0029a47.bindPopup(popup_43b999ca680bc2d87aef3f6998e66ed4)
#         ;
#
#
#
#
#             var marker_85958af8cb9a35eaa32ed64c57257dcd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_770b839ccd0eba16d93c1aa4e8dd2bc5);
#
#
#         var popup_d9efc6fe221d83cce928827d410c0619 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c45dec304c85863dbcfc918a27ba63b = $(`&lt;div id=&quot;html_6c45dec304c85863dbcfc918a27ba63b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d9efc6fe221d83cce928827d410c0619.setContent(html_6c45dec304c85863dbcfc918a27ba63b);
#
#
#
#         marker_85958af8cb9a35eaa32ed64c57257dcd.bindPopup(popup_d9efc6fe221d83cce928827d410c0619)
#         ;
#
#
#
#
#             var marker_91c39484dd44fb596d76968685ec0bd8 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_770b839ccd0eba16d93c1aa4e8dd2bc5);
#
#
#         var popup_935831d93efb47f05947727e91a3fac2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_398cf9b3f1f78e268516c9b8d0bea97f = $(`&lt;div id=&quot;html_398cf9b3f1f78e268516c9b8d0bea97f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_935831d93efb47f05947727e91a3fac2.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4254c32cf7482c038e0ad3996afb3617 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4254c32cf7482c038e0ad3996afb3617&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4254c32cf7482c038e0ad3996afb3617 = L.map(
#                 &quot;map_4254c32cf7482c038e0ad3996afb3617&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0de50de356d58beac0eaf774f1f2d89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a0de50de356d58beac0eaf774f1f2d89.addTo(map_4254c32cf7482c038e0ad3996afb3617);
#
#
#             var feature_group_befe59ad542888def5c8f385b02308d8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_a41e81b0e20ad2664ba9763300fff431 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_befe59ad542888def5c8f385b02308d8);
#
#
#         var popup_51aebe6919e98fbc9bdd525948ac53fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8d9d2bec352f035e6a9ce9467ed2363 = $(`&lt;div id=&quot;html_b8d9d2bec352f035e6a9ce9467ed2363&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_51aebe6919e98fbc9bdd525948ac53fa.setContent(html_b8d9d2bec352f035e6a9ce9467ed2363);
#
#
#
#         marker_a41e81b0e20ad2664ba9763300fff431.bindPopup(popup_51aebe6919e98fbc9bdd525948ac53fa)
#         ;
#
#
#
#
#             var marker_cc715f1be281b636342095ba19e68932 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_befe59ad542888def5c8f385b02308d8);
#
#
#         var popup_ce526a3954f3cc7e195022ec059dcd3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f848a26ee634f7cfda626f0a93de0cd5 = $(`&lt;div id=&quot;html_f848a26ee634f7cfda626f0a93de0cd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ce526a3954f3cc7e195022ec059dcd3b.setContent(html_f848a26ee634f7cfda626f0a93de0cd5);
#
#
#
#         marker_cc715f1be281b636342095ba19e68932.bindPopup(popup_ce526a3954f3cc7e195022ec059dcd3b)
#         ;
#
#
#
#
#             var marker_4cde3f9bf42b086b255c93f4d166b609 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_befe59ad542888def5c8f385b02308d8);
#
#
#         var popup_91a577a40fc4de387babc98a1dec08cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4a1be4f751b58e0685a48cdbb9561e6 = $(`&lt;div id=&quot;html_b4a1be4f751b58e0685a48cdbb9561e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_91a577a40fc4de387babc98a1dec08cd.setContent(html_b4a1be4f751b58e0685a48cdbb9561e6);
#
#
#
#         marker_4cde3f9bf42b086b255c93f4d166b609.bindPopup(popup_91a577a40fc4de387babc98a1dec08cd)
#         ;
#
#
#
#
#             var marker_5e692b62bd6b52f624b9e7aa22951faf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_befe59ad542888def5c8f385b02308d8);
#
#
#         var popup_72e269512a53a6919452112ad9c37ac4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_edd546a58d3b07c34f77c096f42a9cc0 = $(`&lt;div id=&quot;html_edd546a58d3b07c34f77c096f42a9cc0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_72e269512a53a6919452112ad9c37ac4.setContent(html_edd546a58d3b07c34f77c096f42a9cc0);
#
#
#
#         marker_5e692b62bd6b52f624b9e7aa22951faf.bindPopup(popup_72e269512a53a6919452112ad9c37ac4)
#         ;
#
#
#
#
#             var marker_e808f70b431983c692e4ed60a2ec31c0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_befe59ad542888def5c8f385b02308d8);
#
#
#         var popup_81523dec32ce1e15d3f55e7208cc77da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86cb7dcdd77559ffd4dcc34762ba0e0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86cb7dcdd77559ffd4dcc34762ba0e0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86cb7dcdd77559ffd4dcc34762ba0e0f = L.map(
#                 &quot;map_86cb7dcdd77559ffd4dcc34762ba0e0f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_07f809ed1d84ecb52fee714cf453538c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_07f809ed1d84ecb52fee714cf453538c.addTo(map_86cb7dcdd77559ffd4dcc34762ba0e0f);
#
#
#             var feature_group_7ad6158e1587a1693b3f026408f5329f = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7ad6158e1587a1693b3f026408f5329f.addTo(map_86cb7dcdd77559ffd4dcc34762ba0e0f);
#
#
#             var feature_group_sub_group_2ab83c4cb253d517069619777139b18a = L.featureGroup.subGroup(
#                 feature_group_7ad6158e1587a1693b3f026408f5329f
#             );
#
#
#             var marker_aa09eae46bc10332518c23fde4436b2a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2ab83c4cb253d517069619777139b18a);
#
#
#         var popup_bdf2452b758831892a6c1220b536811c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_185a4963bdbe91fdfda223ffa29f8241 = $(`&lt;div id=&quot;html_185a4963bdbe91fdfda223ffa29f8241&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_bdf2452b758831892a6c1220b536811c.setContent(html_185a4963bdbe91fdfda223ffa29f8241);
#
#
#
#         marker_aa09eae46bc10332518c23fde4436b2a.bindPopup(popup_bdf2452b758831892a6c1220b536811c)
#         ;
#
#
#
#
#             var marker_bf2a04e4e323a1f11fb2140cc964ff88 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2ab83c4cb253d517069619777139b18a);
#
#
#         var popup_26f2dd37fc5c720f84a6599f3404f539 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc1ea5ff33f94136b4a9cf7f2e301a7b = $(`&lt;div id=&quot;html_dc1ea5ff33f94136b4a9cf7f2e301a7b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_26f2dd37fc5c720f84a6599f3404f539.setContent(html_dc1ea5ff33f94136b4a9cf7f2e301a7b);
#
#
#
#         marker_bf2a04e4e323a1f11fb2140cc964ff88.bindPopup(popup_26f2dd37fc5c720f84a6599f3404f539)
#         ;
#
#
#
#
#             var marker_e1b710f2a851332a763b042b54ea45f8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2ab83c4cb253d517069619777139b18a);
#
#
#         var popup_ffb093db9f3b26acab3d84ed6199782c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f901694f4d9e215c414636a0f6105f63 = $(`&lt;div id=&quot;html_f901694f4d9e215c414636a0f6105f63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ffb093db9f3b26acab3d84ed6199782c.setContent(html_f901694f4d9e215c414636a0f6105f63);
#
#
#
#         marker_e1b710f2a851332a763b042b54ea45f8.bindPopup(popup_ffb093db9f3b26acab3d84ed6199782c)
#         ;
#
#
#
#
#             var marker_76fa8dbca5302113f9c1601767e5d238 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2ab83c4cb253d517069619777139b18a);
#
#
#         var popup_478e9402c516465e1ee2ff886193bd26 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b008be702898973b756c348ad7d898b = $(`&lt;div id=&quot;html_4b008be702898973b756c348ad7d898b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_478e9402c516465e1ee2ff886193bd26.setContent(html_4b008be702898973b756c348ad7d898b);
#
#
#
#         marker_
