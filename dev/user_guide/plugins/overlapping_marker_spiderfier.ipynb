# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66159e78d9b3ee5eacb078e3675584f0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66159e78d9b3ee5eacb078e3675584f0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66159e78d9b3ee5eacb078e3675584f0 = L.map(
#                 &quot;map_66159e78d9b3ee5eacb078e3675584f0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5082a92708a4cd8afadfef4cbfcec92a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5082a92708a4cd8afadfef4cbfcec92a.addTo(map_66159e78d9b3ee5eacb078e3675584f0);
#
#
#             var marker_fb912b60f5d5b37280a78e48568fa452 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_66159e78d9b3ee5eacb078e3675584f0);
#
#
#         var popup_ed67f46201b70f345fbe7c61c3df61e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_559fd361f06736001d14480d187bc84b = $(`&lt;div id=&quot;html_559fd361f06736001d14480d187bc84b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ed67f46201b70f345fbe7c61c3df61e1.setContent(html_559fd361f06736001d14480d187bc84b);
#
#
#
#         marker_fb912b60f5d5b37280a78e48568fa452.bindPopup(popup_ed67f46201b70f345fbe7c61c3df61e1)
#         ;
#
#
#
#
#             var marker_90811ee9036d603677e23c7f606384f7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_66159e78d9b3ee5eacb078e3675584f0);
#
#
#         var popup_eced385ac54dec7107f2f834f7de09a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c57851f103b501d9210c2a8c2adfd3ef = $(`&lt;div id=&quot;html_c57851f103b501d9210c2a8c2adfd3ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_eced385ac54dec7107f2f834f7de09a8.setContent(html_c57851f103b501d9210c2a8c2adfd3ef);
#
#
#
#         marker_90811ee9036d603677e23c7f606384f7.bindPopup(popup_eced385ac54dec7107f2f834f7de09a8)
#         ;
#
#
#
#
#             var marker_b0d68cd1afc827b80c3de238a5c81137 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_66159e78d9b3ee5eacb078e3675584f0);
#
#
#         var popup_10499552cf1d9916785d35f65e52d210 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8163dd545370d7060d3460f6f7433c7d = $(`&lt;div id=&quot;html_8163dd545370d7060d3460f6f7433c7d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_10499552cf1d9916785d35f65e52d210.setContent(html_8163dd545370d7060d3460f6f7433c7d);
#
#
#
#         marker_b0d68cd1afc827b80c3de238a5c81137.bindPopup(popup_10499552cf1d9916785d35f65e52d210)
#         ;
#
#
#
#
#             var marker_180a5acc3c3f3aa527b1462801752195 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_66159e78d9b3ee5eacb078e3675584f0);
#
#
#         var popup_9a9fc5400a5ed5f2101437630c96c78b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e7556ba0ef0105e58b61b4a328f2488 = $(`&lt;div id=&quot;html_7e7556ba0ef0105e58b61b4a328f2488&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_9a9fc5400a5ed5f2101437630c96c78b.setContent(html_7e7556ba0ef0105e58b61b4a328f2488);
#
#
#
#         marker_180a5acc3c3f3aa527b1462801752195.bindPopup(popup_9a9fc5400a5ed5f2101437630c96c78b)
#         ;
#
#
#
#
#             var marker_f847cfa47ec22cb2e5b94a493e98dd25 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_66159e78d9b3ee5eacb078e3675584f0);
#
#
#         var popup_125d8591de750334aa5cfa17f25fc45a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e85a03c9f38fda02a7344a831ddea8a9 = $(`&lt;div id=&quot;html_e85a03c9f38fda02a7344a831ddea8a9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_125d8591de750334aa5cfa17f25fc45a.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_17ca3016846a409fd42049bcbd76e026 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_17ca3016846a409fd42049bcbd76e026&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_17ca3016846a409fd42049bcbd76e026 = L.map(
#                 &quot;map_17ca3016846a409fd42049bcbd76e026&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96b414e692dfe448f77974dccc1b8975 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_96b414e692dfe448f77974dccc1b8975.addTo(map_17ca3016846a409fd42049bcbd76e026);
#
#
#             var feature_group_33143c554d4b074dfd8c0eb4f2a1b081 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_63b93710511bc427799ccd45622eaba7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_33143c554d4b074dfd8c0eb4f2a1b081);
#
#
#         var popup_44c3d1a0f59b35bcff23fce0b338d881 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e0cc49b2e40b179b4bdad36fbd9d2f4 = $(`&lt;div id=&quot;html_4e0cc49b2e40b179b4bdad36fbd9d2f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_44c3d1a0f59b35bcff23fce0b338d881.setContent(html_4e0cc49b2e40b179b4bdad36fbd9d2f4);
#
#
#
#         marker_63b93710511bc427799ccd45622eaba7.bindPopup(popup_44c3d1a0f59b35bcff23fce0b338d881)
#         ;
#
#
#
#
#             var marker_f1db8165d5b08f416cfa2ea89bcdfe0a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_33143c554d4b074dfd8c0eb4f2a1b081);
#
#
#         var popup_212d025099df249bea0fb947ab593ce9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_af99753ea52b247f0f861ea1eb8ac070 = $(`&lt;div id=&quot;html_af99753ea52b247f0f861ea1eb8ac070&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_212d025099df249bea0fb947ab593ce9.setContent(html_af99753ea52b247f0f861ea1eb8ac070);
#
#
#
#         marker_f1db8165d5b08f416cfa2ea89bcdfe0a.bindPopup(popup_212d025099df249bea0fb947ab593ce9)
#         ;
#
#
#
#
#             var marker_2225f14ab3d1c123685072031f41e024 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_33143c554d4b074dfd8c0eb4f2a1b081);
#
#
#         var popup_94e5fff10fe82f97dd8cdfb8530ad3ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a07054dd74696737a86a7746de9aa325 = $(`&lt;div id=&quot;html_a07054dd74696737a86a7746de9aa325&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_94e5fff10fe82f97dd8cdfb8530ad3ce.setContent(html_a07054dd74696737a86a7746de9aa325);
#
#
#
#         marker_2225f14ab3d1c123685072031f41e024.bindPopup(popup_94e5fff10fe82f97dd8cdfb8530ad3ce)
#         ;
#
#
#
#
#             var marker_3749a5a290dff6b5b759b3b7089c13f1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_33143c554d4b074dfd8c0eb4f2a1b081);
#
#
#         var popup_a98f7a7336172249d9dc9001bb7fbab1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86e0c6ea5a5698030edd83dd1d3b3a87 = $(`&lt;div id=&quot;html_86e0c6ea5a5698030edd83dd1d3b3a87&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a98f7a7336172249d9dc9001bb7fbab1.setContent(html_86e0c6ea5a5698030edd83dd1d3b3a87);
#
#
#
#         marker_3749a5a290dff6b5b759b3b7089c13f1.bindPopup(popup_a98f7a7336172249d9dc9001bb7fbab1)
#         ;
#
#
#
#
#             var marker_f5e059b3e0ec33613fcfbc91a936f348 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_33143c554d4b074dfd8c0eb4f2a1b081);
#
#
#         var popup_5ff83a79231f691f68334a133c8e5583 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c2310d9ddf116b4a92687960f1b1f25c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c2310d9ddf116b4a92687960f1b1f25c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c2310d9ddf116b4a92687960f1b1f25c = L.map(
#                 &quot;map_c2310d9ddf116b4a92687960f1b1f25c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6d2e88bed647ce5f3ddb761dac884932 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6d2e88bed647ce5f3ddb761dac884932.addTo(map_c2310d9ddf116b4a92687960f1b1f25c);
#
#
#             var feature_group_e86b8d0279f11ca51c5a2c0cf61b47f9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e86b8d0279f11ca51c5a2c0cf61b47f9.addTo(map_c2310d9ddf116b4a92687960f1b1f25c);
#
#
#             var feature_group_sub_group_ad597f26d589e936f21ab4406c7acf99 = L.featureGroup.subGroup(
#                 feature_group_e86b8d0279f11ca51c5a2c0cf61b47f9
#             );
#
#
#             var marker_38e9e3abf03f8217a92fa34101559f36 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad597f26d589e936f21ab4406c7acf99);
#
#
#         var popup_0b5cf11bf461938c26e40ba8972ae2ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_57eb91a9b06ca74d47cd9aaf007994ae = $(`&lt;div id=&quot;html_57eb91a9b06ca74d47cd9aaf007994ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0b5cf11bf461938c26e40ba8972ae2ac.setContent(html_57eb91a9b06ca74d47cd9aaf007994ae);
#
#
#
#         marker_38e9e3abf03f8217a92fa34101559f36.bindPopup(popup_0b5cf11bf461938c26e40ba8972ae2ac)
#         ;
#
#
#
#
#             var marker_4e45e7b70f18f242e932ee0c129dc370 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad597f26d589e936f21ab4406c7acf99);
#
#
#         var popup_4106d14b07e6caac3f3e628d5b43d7fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_84cb163d39382cfdb63773b322a9848b = $(`&lt;div id=&quot;html_84cb163d39382cfdb63773b322a9848b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4106d14b07e6caac3f3e628d5b43d7fa.setContent(html_84cb163d39382cfdb63773b322a9848b);
#
#
#
#         marker_4e45e7b70f18f242e932ee0c129dc370.bindPopup(popup_4106d14b07e6caac3f3e628d5b43d7fa)
#         ;
#
#
#
#
#             var marker_240d3e4fd308eee9fc80856baef423d8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad597f26d589e936f21ab4406c7acf99);
#
#
#         var popup_8bccbc6f20c65f2e7943372d6b4a5015 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_137cd0e0d45c33f5e46348ac5e96bb28 = $(`&lt;div id=&quot;html_137cd0e0d45c33f5e46348ac5e96bb28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8bccbc6f20c65f2e7943372d6b4a5015.setContent(html_137cd0e0d45c33f5e46348ac5e96bb28);
#
#
#
#         marker_240d3e4fd308eee9fc80856baef423d8.bindPopup(popup_8bccbc6f20c65f2e7943372d6b4a5015)
#         ;
#
#
#
#
#             var marker_79069295bd1749ed22ff30d2eacfac09 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ad597f26d589e936f21ab4406c7acf99);
#
#
#         var popup_da26a0c6f96ccd8b082c2b80039934ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dbde1dcf00626d76d2a9d357bf2b0796 = $(`&lt;div id=&quot;html_dbde1dcf00626d76d2a9d357bf2b0796&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_da26a0c6f96ccd8b082c2b80039934ed.setContent(html_dbde1dcf00626d76d2a9d357bf2b0796);
#
#
#
#         marker_
