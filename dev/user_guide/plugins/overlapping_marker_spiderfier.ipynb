# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc2ead04aae983350ca7bac8fc3e1162 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc2ead04aae983350ca7bac8fc3e1162&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc2ead04aae983350ca7bac8fc3e1162 = L.map(
#                 &quot;map_cc2ead04aae983350ca7bac8fc3e1162&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87d5ccff7ff9ad123a583f8e8284b934 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_87d5ccff7ff9ad123a583f8e8284b934.addTo(map_cc2ead04aae983350ca7bac8fc3e1162);
#
#
#             var marker_cb0ca25f1de34ec77729ae82493b8ee5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cc2ead04aae983350ca7bac8fc3e1162);
#
#
#         var popup_2fcf83856191639086823adfdd23dd40 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3a872cac505cf7bee3b7a29100d6be9d = $(`&lt;div id=&quot;html_3a872cac505cf7bee3b7a29100d6be9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2fcf83856191639086823adfdd23dd40.setContent(html_3a872cac505cf7bee3b7a29100d6be9d);
#
#
#
#         marker_cb0ca25f1de34ec77729ae82493b8ee5.bindPopup(popup_2fcf83856191639086823adfdd23dd40)
#         ;
#
#
#
#
#             var marker_1ea725e9dceb32de472f8610024c1cae = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cc2ead04aae983350ca7bac8fc3e1162);
#
#
#         var popup_ebfbe4440473c756750922a48693d7cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d27ef4d838ae2ea757a6b349204e49b0 = $(`&lt;div id=&quot;html_d27ef4d838ae2ea757a6b349204e49b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ebfbe4440473c756750922a48693d7cd.setContent(html_d27ef4d838ae2ea757a6b349204e49b0);
#
#
#
#         marker_1ea725e9dceb32de472f8610024c1cae.bindPopup(popup_ebfbe4440473c756750922a48693d7cd)
#         ;
#
#
#
#
#             var marker_c972b6070ddbbd09554593ee8b0f32be = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cc2ead04aae983350ca7bac8fc3e1162);
#
#
#         var popup_50ab7c85efbea2c249bc64709640d949 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4dcf5dff98fd8defe9868d61e0b32c4a = $(`&lt;div id=&quot;html_4dcf5dff98fd8defe9868d61e0b32c4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_50ab7c85efbea2c249bc64709640d949.setContent(html_4dcf5dff98fd8defe9868d61e0b32c4a);
#
#
#
#         marker_c972b6070ddbbd09554593ee8b0f32be.bindPopup(popup_50ab7c85efbea2c249bc64709640d949)
#         ;
#
#
#
#
#             var marker_37c79d2d735dd67312bed82a415ca228 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cc2ead04aae983350ca7bac8fc3e1162);
#
#
#         var popup_faa6bdb2eb4c809eae65e1888e5deb1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b89f8dad10f8bebc4de4667e65ef975 = $(`&lt;div id=&quot;html_7b89f8dad10f8bebc4de4667e65ef975&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_faa6bdb2eb4c809eae65e1888e5deb1b.setContent(html_7b89f8dad10f8bebc4de4667e65ef975);
#
#
#
#         marker_37c79d2d735dd67312bed82a415ca228.bindPopup(popup_faa6bdb2eb4c809eae65e1888e5deb1b)
#         ;
#
#
#
#
#             var marker_01be0a8fac79dce0954a0b25cc441d8e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cc2ead04aae983350ca7bac8fc3e1162);
#
#
#         var popup_a715c1ca1655d33670b25a0d0e4a1acf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1aba951387cd1c4a5359c8194a5df3ed = $(`&lt;div id=&quot;html_1aba951387cd1c4a5359c8194a5df3ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a715c1ca1655d33670b25a0d0e4a1acf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_06bbf5cb42f9068a47bf747397d1f17a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_06bbf5cb42f9068a47bf747397d1f17a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_06bbf5cb42f9068a47bf747397d1f17a = L.map(
#                 &quot;map_06bbf5cb42f9068a47bf747397d1f17a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78a563c815c1e4fc09318806e59055ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_78a563c815c1e4fc09318806e59055ef.addTo(map_06bbf5cb42f9068a47bf747397d1f17a);
#
#
#             var feature_group_50c7628b4e6e1b239c0c499262da24bf = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1e94eb868a8786786a83159a7afcb57b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_50c7628b4e6e1b239c0c499262da24bf);
#
#
#         var popup_a0e763223f415f54de1eba3765ab92bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23a954e9901237fb17ce51c27b8052fc = $(`&lt;div id=&quot;html_23a954e9901237fb17ce51c27b8052fc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a0e763223f415f54de1eba3765ab92bd.setContent(html_23a954e9901237fb17ce51c27b8052fc);
#
#
#
#         marker_1e94eb868a8786786a83159a7afcb57b.bindPopup(popup_a0e763223f415f54de1eba3765ab92bd)
#         ;
#
#
#
#
#             var marker_8de0f5a43b4425074d4e37b147464f4e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_50c7628b4e6e1b239c0c499262da24bf);
#
#
#         var popup_9cbd885440461bd3a8ec47e98337bc92 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bb5669ec5f9a4bf9914154f14728f2c1 = $(`&lt;div id=&quot;html_bb5669ec5f9a4bf9914154f14728f2c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9cbd885440461bd3a8ec47e98337bc92.setContent(html_bb5669ec5f9a4bf9914154f14728f2c1);
#
#
#
#         marker_8de0f5a43b4425074d4e37b147464f4e.bindPopup(popup_9cbd885440461bd3a8ec47e98337bc92)
#         ;
#
#
#
#
#             var marker_aaf27db3301e337b7cf1537c03965775 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_50c7628b4e6e1b239c0c499262da24bf);
#
#
#         var popup_65b9e143e04585b39a3b46c5ea809dfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb48afadb070e9bfa43509923f063f59 = $(`&lt;div id=&quot;html_fb48afadb070e9bfa43509923f063f59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_65b9e143e04585b39a3b46c5ea809dfc.setContent(html_fb48afadb070e9bfa43509923f063f59);
#
#
#
#         marker_aaf27db3301e337b7cf1537c03965775.bindPopup(popup_65b9e143e04585b39a3b46c5ea809dfc)
#         ;
#
#
#
#
#             var marker_dc3f595e916216e6e7b40abda63fed19 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_50c7628b4e6e1b239c0c499262da24bf);
#
#
#         var popup_7a78f5b42f66bff5e4608a5e14f066e3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d877364be1bd9c349e7a9479d9d6cb62 = $(`&lt;div id=&quot;html_d877364be1bd9c349e7a9479d9d6cb62&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7a78f5b42f66bff5e4608a5e14f066e3.setContent(html_d877364be1bd9c349e7a9479d9d6cb62);
#
#
#
#         marker_dc3f595e916216e6e7b40abda63fed19.bindPopup(popup_7a78f5b42f66bff5e4608a5e14f066e3)
#         ;
#
#
#
#
#             var marker_39166cafca20e058841a845811c02131 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_50c7628b4e6e1b239c0c499262da24bf);
#
#
#         var popup_f3946a334d1f4b08260f089210958642 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7ff606bd5d7f897379914a45fe1e42b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7ff606bd5d7f897379914a45fe1e42b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7ff606bd5d7f897379914a45fe1e42b8 = L.map(
#                 &quot;map_7ff606bd5d7f897379914a45fe1e42b8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d6506b6e83bb424a6f659912f4b16bab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d6506b6e83bb424a6f659912f4b16bab.addTo(map_7ff606bd5d7f897379914a45fe1e42b8);
#
#
#             var feature_group_e0f7b577e0ede87d21862d29cbb60850 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e0f7b577e0ede87d21862d29cbb60850.addTo(map_7ff606bd5d7f897379914a45fe1e42b8);
#
#
#             var feature_group_sub_group_525c342b47f84d4a69df9d5547517bb4 = L.featureGroup.subGroup(
#                 feature_group_e0f7b577e0ede87d21862d29cbb60850
#             );
#
#
#             var marker_7a6ac48b664a67d8971943536ec4c6b1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_525c342b47f84d4a69df9d5547517bb4);
#
#
#         var popup_cb89916c09d5f9af4b7ce438996d590d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93a744b5aefe164822b3093955c74fec = $(`&lt;div id=&quot;html_93a744b5aefe164822b3093955c74fec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cb89916c09d5f9af4b7ce438996d590d.setContent(html_93a744b5aefe164822b3093955c74fec);
#
#
#
#         marker_7a6ac48b664a67d8971943536ec4c6b1.bindPopup(popup_cb89916c09d5f9af4b7ce438996d590d)
#         ;
#
#
#
#
#             var marker_13028f40c357f5c7d0f3b733c17d5950 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_525c342b47f84d4a69df9d5547517bb4);
#
#
#         var popup_c2f4cc39749d0096f06c8b18305ff593 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc673cbffa7172e6a84b80ded966f9ca = $(`&lt;div id=&quot;html_fc673cbffa7172e6a84b80ded966f9ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c2f4cc39749d0096f06c8b18305ff593.setContent(html_fc673cbffa7172e6a84b80ded966f9ca);
#
#
#
#         marker_13028f40c357f5c7d0f3b733c17d5950.bindPopup(popup_c2f4cc39749d0096f06c8b18305ff593)
#         ;
#
#
#
#
#             var marker_5417195636abf552507f9cefe161207e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_525c342b47f84d4a69df9d5547517bb4);
#
#
#         var popup_bca5cfe3ee84b97e567b1b6c27f3f1de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b665a81b33fd922b4e82a3878a162baa = $(`&lt;div id=&quot;html_b665a81b33fd922b4e82a3878a162baa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bca5cfe3ee84b97e567b1b6c27f3f1de.setContent(html_b665a81b33fd922b4e82a3878a162baa);
#
#
#
#         marker_5417195636abf552507f9cefe161207e.bindPopup(popup_bca5cfe3ee84b97e567b1b6c27f3f1de)
#         ;
#
#
#
#
#             var marker_5570d35a9d3ff607a099a515cc508303 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_525c342b47f84d4a69df9d5547517bb4);
#
#
#         var popup_07e56bd2af26943570710cb9284244ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a053fd1052e959992700d738f1cde99 = $(`&lt;div id=&quot;html_4a053fd1052e959992700d738f1cde99&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_07e56bd2af26943570710cb9284244ad.setContent(html_4a053fd1052e959992700d738f1cde99);
#
#
#
#         marker_
