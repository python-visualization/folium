# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b102b28678a1b21dcd0353e0e992154d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b102b28678a1b21dcd0353e0e992154d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b102b28678a1b21dcd0353e0e992154d = L.map(
#                 &quot;map_b102b28678a1b21dcd0353e0e992154d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_933f78d620ccbcd05c396fd4fbe824d1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_933f78d620ccbcd05c396fd4fbe824d1.addTo(map_b102b28678a1b21dcd0353e0e992154d);
#
#
#             var marker_2574333720720bca3ce59ababbac0c1e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b102b28678a1b21dcd0353e0e992154d);
#
#
#         var popup_43da90599db7317f4c8c6ab33b561e0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5dc23ad4ec7643492b140e85742be7c = $(`&lt;div id=&quot;html_d5dc23ad4ec7643492b140e85742be7c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_43da90599db7317f4c8c6ab33b561e0b.setContent(html_d5dc23ad4ec7643492b140e85742be7c);
#
#
#
#         marker_2574333720720bca3ce59ababbac0c1e.bindPopup(popup_43da90599db7317f4c8c6ab33b561e0b)
#         ;
#
#
#
#
#             var marker_d61742ad2e8a3b835275eb7457ff4516 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b102b28678a1b21dcd0353e0e992154d);
#
#
#         var popup_553d3b31dee78154591095da9045e6b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b6bb63b1a520969b2e1bcc59ffdc72f2 = $(`&lt;div id=&quot;html_b6bb63b1a520969b2e1bcc59ffdc72f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_553d3b31dee78154591095da9045e6b9.setContent(html_b6bb63b1a520969b2e1bcc59ffdc72f2);
#
#
#
#         marker_d61742ad2e8a3b835275eb7457ff4516.bindPopup(popup_553d3b31dee78154591095da9045e6b9)
#         ;
#
#
#
#
#             var marker_dd7621df561d2ae846ec1382c3de3ea7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b102b28678a1b21dcd0353e0e992154d);
#
#
#         var popup_a9ad2fad4f0b4f2fb7308f5c55f3f880 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ae823b4c41cffbeedf9374a3d57d479 = $(`&lt;div id=&quot;html_3ae823b4c41cffbeedf9374a3d57d479&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a9ad2fad4f0b4f2fb7308f5c55f3f880.setContent(html_3ae823b4c41cffbeedf9374a3d57d479);
#
#
#
#         marker_dd7621df561d2ae846ec1382c3de3ea7.bindPopup(popup_a9ad2fad4f0b4f2fb7308f5c55f3f880)
#         ;
#
#
#
#
#             var marker_fd93c7c13a4d5610f1c3816bf706a283 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b102b28678a1b21dcd0353e0e992154d);
#
#
#         var popup_2bbcf4abfd4fc5416191fbfe2b7dda89 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_530728e6d5ebb6dceb80a216c36138c3 = $(`&lt;div id=&quot;html_530728e6d5ebb6dceb80a216c36138c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_2bbcf4abfd4fc5416191fbfe2b7dda89.setContent(html_530728e6d5ebb6dceb80a216c36138c3);
#
#
#
#         marker_fd93c7c13a4d5610f1c3816bf706a283.bindPopup(popup_2bbcf4abfd4fc5416191fbfe2b7dda89)
#         ;
#
#
#
#
#             var marker_b28b9c61a7458b61fc26253a0a0bf82d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b102b28678a1b21dcd0353e0e992154d);
#
#
#         var popup_ac0df34eca47b795b5ff4d9567a2e20f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c0bef6fed2f0a1ef6ce1778fccdd6f6a = $(`&lt;div id=&quot;html_c0bef6fed2f0a1ef6ce1778fccdd6f6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ac0df34eca47b795b5ff4d9567a2e20f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1288db5af2a3f3cd8bd1613a25a9b3cc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1288db5af2a3f3cd8bd1613a25a9b3cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1288db5af2a3f3cd8bd1613a25a9b3cc = L.map(
#                 &quot;map_1288db5af2a3f3cd8bd1613a25a9b3cc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ad79739f6c2ec4e799288adb9252654 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ad79739f6c2ec4e799288adb9252654.addTo(map_1288db5af2a3f3cd8bd1613a25a9b3cc);
#
#
#             var feature_group_8fe9b6289ff6b6cab0a9659b030a2423 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cc3b4b65459b8807b003682dfef4551f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8fe9b6289ff6b6cab0a9659b030a2423);
#
#
#         var popup_4455df5edee64de911861a26850dadf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_10b4d55e45f78bbb09e482c87d4eb875 = $(`&lt;div id=&quot;html_10b4d55e45f78bbb09e482c87d4eb875&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4455df5edee64de911861a26850dadf8.setContent(html_10b4d55e45f78bbb09e482c87d4eb875);
#
#
#
#         marker_cc3b4b65459b8807b003682dfef4551f.bindPopup(popup_4455df5edee64de911861a26850dadf8)
#         ;
#
#
#
#
#             var marker_4e5feaa4361fd8a39e4350c906517deb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8fe9b6289ff6b6cab0a9659b030a2423);
#
#
#         var popup_cb9e2821c05ee8a2a7e6307caa0c05ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6dd1d77a7c95cfe447f374e462972a61 = $(`&lt;div id=&quot;html_6dd1d77a7c95cfe447f374e462972a61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_cb9e2821c05ee8a2a7e6307caa0c05ed.setContent(html_6dd1d77a7c95cfe447f374e462972a61);
#
#
#
#         marker_4e5feaa4361fd8a39e4350c906517deb.bindPopup(popup_cb9e2821c05ee8a2a7e6307caa0c05ed)
#         ;
#
#
#
#
#             var marker_e662a8cabe06f37294629a351c3f8926 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8fe9b6289ff6b6cab0a9659b030a2423);
#
#
#         var popup_625d41f4925f0a00e61e16c9dd500590 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9304d0fa5d1f951ed98de58b5c23566 = $(`&lt;div id=&quot;html_e9304d0fa5d1f951ed98de58b5c23566&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_625d41f4925f0a00e61e16c9dd500590.setContent(html_e9304d0fa5d1f951ed98de58b5c23566);
#
#
#
#         marker_e662a8cabe06f37294629a351c3f8926.bindPopup(popup_625d41f4925f0a00e61e16c9dd500590)
#         ;
#
#
#
#
#             var marker_7f6973979ebe3fe9205816c1d47a9432 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8fe9b6289ff6b6cab0a9659b030a2423);
#
#
#         var popup_5eacbcf933aa8967d9cd2c955f588cb7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5956b3f06763b94ac2d2b7c618e81a40 = $(`&lt;div id=&quot;html_5956b3f06763b94ac2d2b7c618e81a40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5eacbcf933aa8967d9cd2c955f588cb7.setContent(html_5956b3f06763b94ac2d2b7c618e81a40);
#
#
#
#         marker_7f6973979ebe3fe9205816c1d47a9432.bindPopup(popup_5eacbcf933aa8967d9cd2c955f588cb7)
#         ;
#
#
#
#
#             var marker_8029663130f2c3f067c3fd2804fb07f7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8fe9b6289ff6b6cab0a9659b030a2423);
#
#
#         var popup_b4d4876322f1ff2b7870c6c1a59f1f83 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c02f41bc491a61c4852262e6d3c77e5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c02f41bc491a61c4852262e6d3c77e5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c02f41bc491a61c4852262e6d3c77e5d = L.map(
#                 &quot;map_c02f41bc491a61c4852262e6d3c77e5d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0e3037a0372474fab6a7302a04d99a17 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0e3037a0372474fab6a7302a04d99a17.addTo(map_c02f41bc491a61c4852262e6d3c77e5d);
#
#
#             var feature_group_15dd2a3d763e7e12594dfa0b2d45e08a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_15dd2a3d763e7e12594dfa0b2d45e08a.addTo(map_c02f41bc491a61c4852262e6d3c77e5d);
#
#
#             var feature_group_sub_group_881172488b1785ad0118dbb27e5cc427 = L.featureGroup.subGroup(
#                 feature_group_15dd2a3d763e7e12594dfa0b2d45e08a
#             );
#
#
#             var marker_afed5e9d023bc35e9126fcd5e3488871 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_881172488b1785ad0118dbb27e5cc427);
#
#
#         var popup_cdb4587e91c49c5230ecbcc807e6064d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31324a158e7e2fbde3b8822a93aa1fc3 = $(`&lt;div id=&quot;html_31324a158e7e2fbde3b8822a93aa1fc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_cdb4587e91c49c5230ecbcc807e6064d.setContent(html_31324a158e7e2fbde3b8822a93aa1fc3);
#
#
#
#         marker_afed5e9d023bc35e9126fcd5e3488871.bindPopup(popup_cdb4587e91c49c5230ecbcc807e6064d)
#         ;
#
#
#
#
#             var marker_242452d7ed6e380bf3158b1511895d92 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_881172488b1785ad0118dbb27e5cc427);
#
#
#         var popup_295e2afab35b6cce556c1ed1e86968dd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e56101e74c29a6d0c97b9edc95f058a1 = $(`&lt;div id=&quot;html_e56101e74c29a6d0c97b9edc95f058a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_295e2afab35b6cce556c1ed1e86968dd.setContent(html_e56101e74c29a6d0c97b9edc95f058a1);
#
#
#
#         marker_242452d7ed6e380bf3158b1511895d92.bindPopup(popup_295e2afab35b6cce556c1ed1e86968dd)
#         ;
#
#
#
#
#             var marker_daecbc23ef744cebfd75250f1b714c16 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_881172488b1785ad0118dbb27e5cc427);
#
#
#         var popup_d9082d772de338cb554f224a292e820a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a18dfd09c58497d3816310018462f09 = $(`&lt;div id=&quot;html_2a18dfd09c58497d3816310018462f09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d9082d772de338cb554f224a292e820a.setContent(html_2a18dfd09c58497d3816310018462f09);
#
#
#
#         marker_daecbc23ef744cebfd75250f1b714c16.bindPopup(popup_d9082d772de338cb554f224a292e820a)
#         ;
#
#
#
#
#             var marker_4b21788f31649fb50e5e21a0705bdc2e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_881172488b1785ad0118dbb27e5cc427);
#
#
#         var popup_45fffcdecd32548a63214753c80ef239 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c88b186805a8f8def102d6e6c7e6d920 = $(`&lt;div id=&quot;html_c88b186805a8f8def102d6e6c7e6d920&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_45fffcdecd32548a63214753c80ef239.setContent(html_c88b186805a8f8def102d6e6c7e6d920);
#
#
#
#         marker_
