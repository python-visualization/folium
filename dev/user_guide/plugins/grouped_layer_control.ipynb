# %% [markdown]
# # GroupedLayerControl
#
# We can create a GroupedLayerControl and define what layers we want to group together. Those layers won't show up in the regular layer control.
#
# `GroupedLayerControl` takes the same arguments as `LayerControl`.
#
# By default, groups are exclusive, meaning only one layer in a group can be active at a time.

# %%
import folium
from folium.plugins import GroupedLayerControl

m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1')
fg2 = folium.FeatureGroup(name='g2')
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d4b5955da7f1f7924bf3b92cff1763b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d4b5955da7f1f7924bf3b92cff1763b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d4b5955da7f1f7924bf3b92cff1763b3 = L.map(
#                 &quot;map_d4b5955da7f1f7924bf3b92cff1763b3&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f898c307c3dc4e3d6cb9a7165c6d9eed = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f898c307c3dc4e3d6cb9a7165c6d9eed.addTo(map_d4b5955da7f1f7924bf3b92cff1763b3);
#
#
#             var feature_group_655ef896662eeb478b89a12b6ef35532 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5f495a4be6ee67b67d96007ed368a21f = L.marker(
#                 [40.0, 74.0],
#                 {
# }
#             ).addTo(feature_group_655ef896662eeb478b89a12b6ef35532);
#
#
#             feature_group_655ef896662eeb478b89a12b6ef35532.addTo(map_d4b5955da7f1f7924bf3b92cff1763b3);
#
#
#             var feature_group_bd78c48516613c9762fd1a70e5b28184 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_afc7548745fa1e0371821b4fb4cb3c65 = L.marker(
#                 [38.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_bd78c48516613c9762fd1a70e5b28184);
#
#
#             feature_group_bd78c48516613c9762fd1a70e5b28184.addTo(map_d4b5955da7f1f7924bf3b92cff1763b3);
#
#
#             var feature_group_1bf24d59c7f3b822dbaea0f3e850ee7e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2e609a5c2d41a50f3cc13e6455f68d95 = L.marker(
#                 [40.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_1bf24d59c7f3b822dbaea0f3e850ee7e);
#
#
#             feature_group_1bf24d59c7f3b822dbaea0f3e850ee7e.addTo(map_d4b5955da7f1f7924bf3b92cff1763b3);
#
#
#             var layer_control_3cf3f5713fa665e477227e89d357b29d_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_f898c307c3dc4e3d6cb9a7165c6d9eed,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_1bf24d59c7f3b822dbaea0f3e850ee7e,
#                 },
#             };
#             let layer_control_3cf3f5713fa665e477227e89d357b29d = L.control.layers(
#                 layer_control_3cf3f5713fa665e477227e89d357b29d_layers.base_layers,
#                 layer_control_3cf3f5713fa665e477227e89d357b29d_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_d4b5955da7f1f7924bf3b92cff1763b3);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_655ef896662eeb478b89a12b6ef35532,
#                         &quot;g2&quot; : feature_group_bd78c48516613c9762fd1a70e5b28184,
#                     },
#                 },
#                 {
#   &quot;collapsed&quot;: false,
#   &quot;exclusiveGroups&quot;: [
# &quot;groups1&quot;,
# ],
# },
#             ).addTo(map_d4b5955da7f1f7924bf3b92cff1763b3);
#             feature_group_bd78c48516613c9762fd1a70e5b28184.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It's also possible to have check boxes instead of radio buttons, so multiple layers within a group can be active.
#
# In this example the layers are not shown by default, but can all be activated.

# %%
m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1', show=False)
fg2 = folium.FeatureGroup(name='g2', show=False)
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    exclusive_groups=False,
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bd94f13cbfe9f4dd5aa288d6644d61c0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bd94f13cbfe9f4dd5aa288d6644d61c0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bd94f13cbfe9f4dd5aa288d6644d61c0 = L.map(
#                 &quot;map_bd94f13cbfe9f4dd5aa288d6644d61c0&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_591271777c6379121f4ed32a133bb62c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_591271777c6379121f4ed32a133bb62c.addTo(map_bd94f13cbfe9f4dd5aa288d6644d61c0);
#
#
#             var feature_group_6f3293565eefb3e48e7f790c1312d565 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d956446613c7ed905a27100471ddbde0 = L.marker(
#                 [40.0, 74.0],
#                 {
# }
#             ).addTo(feature_group_6f3293565eefb3e48e7f790c1312d565);
#
#
#             var feature_group_44f7dbef4030c9ba05069678a1e56557 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d4af6b6ab0c494dd43b6c4abde5cda31 = L.marker(
#                 [38.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_44f7dbef4030c9ba05069678a1e56557);
#
#
#             var feature_group_5ee839c5157ce43fe9d5987fd34386fa = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_41baf61544cd6ba1bc3c4705f1114145 = L.marker(
#                 [40.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_5ee839c5157ce43fe9d5987fd34386fa);
#
#
#             feature_group_5ee839c5157ce43fe9d5987fd34386fa.addTo(map_bd94f13cbfe9f4dd5aa288d6644d61c0);
#
#
#             var layer_control_222da9de31a837af32c20633528f27af_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_591271777c6379121f4ed32a133bb62c,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_5ee839c5157ce43fe9d5987fd34386fa,
#                 },
#             };
#             let layer_control_222da9de31a837af32c20633528f27af = L.control.layers(
#                 layer_control_222da9de31a837af32c20633528f27af_layers.base_layers,
#                 layer_control_222da9de31a837af32c20633528f27af_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_bd94f13cbfe9f4dd5aa288d6644d61c0);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_6f3293565eefb3e48e7f790c1312d565,
#                         &quot;g2&quot; : feature_group_44f7dbef4030c9ba05069678a1e56557,
#                     },
#                 },
#                 {
#   &quot;collapsed&quot;: false,
# },
#             ).addTo(map_bd94f13cbfe9f4dd5aa288d6644d61c0);
#             feature_group_6f3293565eefb3e48e7f790c1312d565.remove();
#             feature_group_44f7dbef4030c9ba05069678a1e56557.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
