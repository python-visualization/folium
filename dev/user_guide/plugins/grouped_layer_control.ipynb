# %% [markdown]
# # GroupedLayerControl
#
# We can create a GroupedLayerControl and define what layers we want to group together. Those layers won't show up in the regular layer control.
#
# `GroupedLayerControl` takes the same arguments as `LayerControl`.
#
# By default, groups are exclusive, meaning only one layer in a group can be active at a time.

# %%
import folium
from folium.plugins import GroupedLayerControl

m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1')
fg2 = folium.FeatureGroup(name='g2')
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd9558d1c316d038edd0bf6ac591fec8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd9558d1c316d038edd0bf6ac591fec8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd9558d1c316d038edd0bf6ac591fec8 = L.map(
#                 &quot;map_cd9558d1c316d038edd0bf6ac591fec8&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3368fdbc8f344b0f3c827494fd1fb922 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3368fdbc8f344b0f3c827494fd1fb922.addTo(map_cd9558d1c316d038edd0bf6ac591fec8);
#
#
#             var feature_group_db957dbc53f36e0558ae6436d2943e97 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cc18fd774a01953fc4d6470d60da7f50 = L.marker(
#                 [40.0, 74.0],
#                 {
# }
#             ).addTo(feature_group_db957dbc53f36e0558ae6436d2943e97);
#
#
#             feature_group_db957dbc53f36e0558ae6436d2943e97.addTo(map_cd9558d1c316d038edd0bf6ac591fec8);
#
#
#             var feature_group_177e54a3599429fdf0519e13520386f0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2c48a851cab0e26de84f49db6edc7cbf = L.marker(
#                 [38.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_177e54a3599429fdf0519e13520386f0);
#
#
#             feature_group_177e54a3599429fdf0519e13520386f0.addTo(map_cd9558d1c316d038edd0bf6ac591fec8);
#
#
#             var feature_group_0fcbad06e65967efb42f21743039b9ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_789a7b57bd88124a619b98c3dfef7a1b = L.marker(
#                 [40.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_0fcbad06e65967efb42f21743039b9ac);
#
#
#             feature_group_0fcbad06e65967efb42f21743039b9ac.addTo(map_cd9558d1c316d038edd0bf6ac591fec8);
#
#
#             var layer_control_602e4aa8a0dd69a3936bb753239ef887_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_3368fdbc8f344b0f3c827494fd1fb922,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_0fcbad06e65967efb42f21743039b9ac,
#                 },
#             };
#             let layer_control_602e4aa8a0dd69a3936bb753239ef887 = L.control.layers(
#                 layer_control_602e4aa8a0dd69a3936bb753239ef887_layers.base_layers,
#                 layer_control_602e4aa8a0dd69a3936bb753239ef887_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_cd9558d1c316d038edd0bf6ac591fec8);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_db957dbc53f36e0558ae6436d2943e97,
#                         &quot;g2&quot; : feature_group_177e54a3599429fdf0519e13520386f0,
#                     },
#                 },
#                 {
#   &quot;collapsed&quot;: false,
#   &quot;exclusiveGroups&quot;: [
# &quot;groups1&quot;,
# ],
# },
#             ).addTo(map_cd9558d1c316d038edd0bf6ac591fec8);
#             feature_group_177e54a3599429fdf0519e13520386f0.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It's also possible to have check boxes instead of radio buttons, so multiple layers within a group can be active.
#
# In this example the layers are not shown by default, but can all be activated.

# %%
m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1', show=False)
fg2 = folium.FeatureGroup(name='g2', show=False)
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    exclusive_groups=False,
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1b5711a5e72fbc251682c7f5cdcf4bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1b5711a5e72fbc251682c7f5cdcf4bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1b5711a5e72fbc251682c7f5cdcf4bb = L.map(
#                 &quot;map_d1b5711a5e72fbc251682c7f5cdcf4bb&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_faa2a0a01feb5cd9eba7bf7b2352d319 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_faa2a0a01feb5cd9eba7bf7b2352d319.addTo(map_d1b5711a5e72fbc251682c7f5cdcf4bb);
#
#
#             var feature_group_16e15c6e37d79d7ef8d17c88179cb883 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f0b69a8f55d168abcf1119a83073acbb = L.marker(
#                 [40.0, 74.0],
#                 {
# }
#             ).addTo(feature_group_16e15c6e37d79d7ef8d17c88179cb883);
#
#
#             var feature_group_714566d9f6089c51b6f1dbdbdbbdc4bb = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6bbcd6994fe80f01e1024781793620c5 = L.marker(
#                 [38.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_714566d9f6089c51b6f1dbdbdbbdc4bb);
#
#
#             var feature_group_52904e0baf39a5206d7b4427ad39d9e4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3017c5252b7b72bd05b44b70b91a0272 = L.marker(
#                 [40.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_52904e0baf39a5206d7b4427ad39d9e4);
#
#
#             feature_group_52904e0baf39a5206d7b4427ad39d9e4.addTo(map_d1b5711a5e72fbc251682c7f5cdcf4bb);
#
#
#             var layer_control_37f24e3854879ba61ded3eff3d79cf93_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_faa2a0a01feb5cd9eba7bf7b2352d319,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_52904e0baf39a5206d7b4427ad39d9e4,
#                 },
#             };
#             let layer_control_37f24e3854879ba61ded3eff3d79cf93 = L.control.layers(
#                 layer_control_37f24e3854879ba61ded3eff3d79cf93_layers.base_layers,
#                 layer_control_37f24e3854879ba61ded3eff3d79cf93_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_d1b5711a5e72fbc251682c7f5cdcf4bb);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_16e15c6e37d79d7ef8d17c88179cb883,
#                         &quot;g2&quot; : feature_group_714566d9f6089c51b6f1dbdbdbbdc4bb,
#                     },
#                 },
#                 {
#   &quot;collapsed&quot;: false,
# },
#             ).addTo(map_d1b5711a5e72fbc251682c7f5cdcf4bb);
#             feature_group_714566d9f6089c51b6f1dbdbdbbdc4bb.remove();
#             feature_group_16e15c6e37d79d7ef8d17c88179cb883.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
