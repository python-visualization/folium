# %% [markdown]
# # GroupedLayerControl
#
# We can create a GroupedLayerControl and define what layers we want to group together. Those layers won't show up in the regular layer control.
#
# `GroupedLayerControl` takes the same arguments as `LayerControl`.
#
# By default, groups are exclusive, meaning only one layer in a group can be active at a time.

# %%
import folium
from folium.plugins import GroupedLayerControl

m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1')
fg2 = folium.FeatureGroup(name='g2')
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_420621b15b36babccb44c7ea28333297 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_420621b15b36babccb44c7ea28333297&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_420621b15b36babccb44c7ea28333297 = L.map(
#                 &quot;map_420621b15b36babccb44c7ea28333297&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_77b442c2cb6123a00b5efec499ddef79 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_77b442c2cb6123a00b5efec499ddef79.addTo(map_420621b15b36babccb44c7ea28333297);
#
#
#             var feature_group_a0db3855ae7cb9d1109a8c21f4365e58 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_63d72aca8e8ca0667e3b30a65fe85b2d = L.marker(
#                 [40.0, 74.0],
#                 {
# }
#             ).addTo(feature_group_a0db3855ae7cb9d1109a8c21f4365e58);
#
#
#             feature_group_a0db3855ae7cb9d1109a8c21f4365e58.addTo(map_420621b15b36babccb44c7ea28333297);
#
#
#             var feature_group_6e13b6a5b01585ce5bea9d415929d267 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5242bad1fb1cefc06af52cece39c3f85 = L.marker(
#                 [38.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_6e13b6a5b01585ce5bea9d415929d267);
#
#
#             feature_group_6e13b6a5b01585ce5bea9d415929d267.addTo(map_420621b15b36babccb44c7ea28333297);
#
#
#             var feature_group_cc2f78cdf44210fa816fb62ebe267ef5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_dbf4b3ca4165d52c0077fbad35b1345e = L.marker(
#                 [40.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_cc2f78cdf44210fa816fb62ebe267ef5);
#
#
#             feature_group_cc2f78cdf44210fa816fb62ebe267ef5.addTo(map_420621b15b36babccb44c7ea28333297);
#
#
#             var layer_control_6bc5f6e57e6935b6abafd3288188df47_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_77b442c2cb6123a00b5efec499ddef79,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_cc2f78cdf44210fa816fb62ebe267ef5,
#                 },
#             };
#             let layer_control_6bc5f6e57e6935b6abafd3288188df47 = L.control.layers(
#                 layer_control_6bc5f6e57e6935b6abafd3288188df47_layers.base_layers,
#                 layer_control_6bc5f6e57e6935b6abafd3288188df47_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_420621b15b36babccb44c7ea28333297);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_a0db3855ae7cb9d1109a8c21f4365e58,
#                         &quot;g2&quot; : feature_group_6e13b6a5b01585ce5bea9d415929d267,
#                     },
#                 },
#                 {
#   &quot;collapsed&quot;: false,
#   &quot;exclusiveGroups&quot;: [
# &quot;groups1&quot;,
# ],
# },
#             ).addTo(map_420621b15b36babccb44c7ea28333297);
#             feature_group_6e13b6a5b01585ce5bea9d415929d267.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It's also possible to have check boxes instead of radio buttons, so multiple layers within a group can be active.
#
# In this example the layers are not shown by default, but can all be activated.

# %%
m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1', show=False)
fg2 = folium.FeatureGroup(name='g2', show=False)
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    exclusive_groups=False,
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9946a61d9eb4e9283ba917a6076d59be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9946a61d9eb4e9283ba917a6076d59be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9946a61d9eb4e9283ba917a6076d59be = L.map(
#                 &quot;map_9946a61d9eb4e9283ba917a6076d59be&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_98049e8e49f4e7e604200cac9f135dbe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_98049e8e49f4e7e604200cac9f135dbe.addTo(map_9946a61d9eb4e9283ba917a6076d59be);
#
#
#             var feature_group_328d91d4bc7ff02d4d95094b7c78ba03 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5308cc62dcab2de6b44dc1388ef7e634 = L.marker(
#                 [40.0, 74.0],
#                 {
# }
#             ).addTo(feature_group_328d91d4bc7ff02d4d95094b7c78ba03);
#
#
#             var feature_group_3e68af63003072189e21d54ba929b6fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_754382ab3b1b053da4ac184127ddab38 = L.marker(
#                 [38.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_3e68af63003072189e21d54ba929b6fe);
#
#
#             var feature_group_d183899041afafb0cfc26aadc9e06390 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5fba33858d25a360182328ffff72d1eb = L.marker(
#                 [40.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_d183899041afafb0cfc26aadc9e06390);
#
#
#             feature_group_d183899041afafb0cfc26aadc9e06390.addTo(map_9946a61d9eb4e9283ba917a6076d59be);
#
#
#             var layer_control_cfb6adbca97c85fddc7ac67daa689425_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_98049e8e49f4e7e604200cac9f135dbe,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_d183899041afafb0cfc26aadc9e06390,
#                 },
#             };
#             let layer_control_cfb6adbca97c85fddc7ac67daa689425 = L.control.layers(
#                 layer_control_cfb6adbca97c85fddc7ac67daa689425_layers.base_layers,
#                 layer_control_cfb6adbca97c85fddc7ac67daa689425_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_9946a61d9eb4e9283ba917a6076d59be);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_328d91d4bc7ff02d4d95094b7c78ba03,
#                         &quot;g2&quot; : feature_group_3e68af63003072189e21d54ba929b6fe,
#                     },
#                 },
#                 {
#   &quot;collapsed&quot;: false,
# },
#             ).addTo(map_9946a61d9eb4e9283ba917a6076d59be);
#             feature_group_328d91d4bc7ff02d4d95094b7c78ba03.remove();
#             feature_group_3e68af63003072189e21d54ba929b6fe.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
