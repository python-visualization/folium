# %% [markdown]
# # GroupedLayerControl
#
# We can create a GroupedLayerControl and define what layers we want to group together. Those layers won't show up in the regular layer control.
#
# `GroupedLayerControl` takes the same arguments as `LayerControl`.
#
# By default, groups are exclusive, meaning only one layer in a group can be active at a time.

# %%
import folium
from folium.plugins import GroupedLayerControl

m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1')
fg2 = folium.FeatureGroup(name='g2')
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1b0ef43b0be38796eb82a7e451f6a27e {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1b0ef43b0be38796eb82a7e451f6a27e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1b0ef43b0be38796eb82a7e451f6a27e = L.map(
#                 &quot;map_1b0ef43b0be38796eb82a7e451f6a27e&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_715c0d665c1e5b9a3a7d2069bb6abf89 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_715c0d665c1e5b9a3a7d2069bb6abf89.addTo(map_1b0ef43b0be38796eb82a7e451f6a27e);
#
#
#             var feature_group_3bc481a968b5af52ae5a640edeb5bb9e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6b24896d3e0a41eb469eaa30692367d6 = L.marker(
#                 [40.0, 74.0],
#                 {
# }
#             ).addTo(feature_group_3bc481a968b5af52ae5a640edeb5bb9e);
#
#
#             feature_group_3bc481a968b5af52ae5a640edeb5bb9e.addTo(map_1b0ef43b0be38796eb82a7e451f6a27e);
#
#
#             var feature_group_4700c56d73183a461caa4136a036f06d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_cabfb8bf904ada14ae097b991e5e04eb = L.marker(
#                 [38.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_4700c56d73183a461caa4136a036f06d);
#
#
#             feature_group_4700c56d73183a461caa4136a036f06d.addTo(map_1b0ef43b0be38796eb82a7e451f6a27e);
#
#
#             var feature_group_52c361887c5253ff0bc37713571a1c09 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5e3ca8d34a0d5223cfce9fef00e45ed8 = L.marker(
#                 [40.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_52c361887c5253ff0bc37713571a1c09);
#
#
#             feature_group_52c361887c5253ff0bc37713571a1c09.addTo(map_1b0ef43b0be38796eb82a7e451f6a27e);
#
#
#             var layer_control_b02b1dd7306a2a31e88803c7c0407faf_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_715c0d665c1e5b9a3a7d2069bb6abf89,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_52c361887c5253ff0bc37713571a1c09,
#                 },
#             };
#             let layer_control_b02b1dd7306a2a31e88803c7c0407faf = L.control.layers(
#                 layer_control_b02b1dd7306a2a31e88803c7c0407faf_layers.base_layers,
#                 layer_control_b02b1dd7306a2a31e88803c7c0407faf_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_1b0ef43b0be38796eb82a7e451f6a27e);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_3bc481a968b5af52ae5a640edeb5bb9e,
#                         &quot;g2&quot; : feature_group_4700c56d73183a461caa4136a036f06d,
#                     },
#                 },
#                 {
#   &quot;collapsed&quot;: false,
#   &quot;exclusiveGroups&quot;: [
# &quot;groups1&quot;,
# ],
# },
#             ).addTo(map_1b0ef43b0be38796eb82a7e451f6a27e);
#             feature_group_4700c56d73183a461caa4136a036f06d.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# It's also possible to have check boxes instead of radio buttons, so multiple layers within a group can be active.
#
# In this example the layers are not shown by default, but can all be activated.

# %%
m = folium.Map([40., 70.], zoom_start=6)

fg1 = folium.FeatureGroup(name='g1', show=False)
fg2 = folium.FeatureGroup(name='g2', show=False)
fg3 = folium.FeatureGroup(name='g3')
folium.Marker([40, 74]).add_to(fg1)
folium.Marker([38, 72]).add_to(fg2)
folium.Marker([40, 72]).add_to(fg3)
m.add_child(fg1)
m.add_child(fg2)
m.add_child(fg3)

folium.LayerControl(collapsed=False).add_to(m)

GroupedLayerControl(
    groups={'groups1': [fg1, fg2]},
    exclusive_groups=False,
    collapsed=False,
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fc9b721ff396df8208de482fbb63b27 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-groupedlayercontrol/0.6.1/leaflet.groupedlayercontrol.min.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fc9b721ff396df8208de482fbb63b27&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fc9b721ff396df8208de482fbb63b27 = L.map(
#                 &quot;map_8fc9b721ff396df8208de482fbb63b27&quot;,
#                 {
#                     center: [40.0, 70.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 6,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6996684fb77764864e34941ebd35e3c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a6996684fb77764864e34941ebd35e3c.addTo(map_8fc9b721ff396df8208de482fbb63b27);
#
#
#             var feature_group_b7f50f5d3c0e3e97add87b4b596f69b1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5801b14427d57228a0f4039f6dcef09a = L.marker(
#                 [40.0, 74.0],
#                 {
# }
#             ).addTo(feature_group_b7f50f5d3c0e3e97add87b4b596f69b1);
#
#
#             var feature_group_671f2e1eba31be2e3eb53fb76e1425ba = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_7553f8ddeabc092fd97e4a433e6e110c = L.marker(
#                 [38.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_671f2e1eba31be2e3eb53fb76e1425ba);
#
#
#             var feature_group_ceb5f3c4d8ba9d391c932a40ef395a90 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d5d7557d62ecab73a42ae2e5ced580fe = L.marker(
#                 [40.0, 72.0],
#                 {
# }
#             ).addTo(feature_group_ceb5f3c4d8ba9d391c932a40ef395a90);
#
#
#             feature_group_ceb5f3c4d8ba9d391c932a40ef395a90.addTo(map_8fc9b721ff396df8208de482fbb63b27);
#
#
#             var layer_control_6deba4d3e22fe0c023cddf7c3ecaa00c_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a6996684fb77764864e34941ebd35e3c,
#                 },
#                 overlays :  {
#                     &quot;g3&quot; : feature_group_ceb5f3c4d8ba9d391c932a40ef395a90,
#                 },
#             };
#             let layer_control_6deba4d3e22fe0c023cddf7c3ecaa00c = L.control.layers(
#                 layer_control_6deba4d3e22fe0c023cddf7c3ecaa00c_layers.base_layers,
#                 layer_control_6deba4d3e22fe0c023cddf7c3ecaa00c_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: false,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_8fc9b721ff396df8208de482fbb63b27);
#
#
#
#
#             L.control.groupedLayers(
#                 null,
#                 {
#                     &quot;groups1&quot; : {
#                         &quot;g1&quot; : feature_group_b7f50f5d3c0e3e97add87b4b596f69b1,
#                         &quot;g2&quot; : feature_group_671f2e1eba31be2e3eb53fb76e1425ba,
#                     },
#                 },
#                 {
#   &quot;collapsed&quot;: false,
# },
#             ).addTo(map_8fc9b721ff396df8208de482fbb63b27);
#             feature_group_671f2e1eba31be2e3eb53fb76e1425ba.remove();
#             feature_group_b7f50f5d3c0e3e97add87b4b596f69b1.remove();
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
