# %%
import folium

# %% [markdown]
# # Using GeoPandas.GeoDataFrame in folium
#
# GeoPandas is a project to add support for geographic data to [pandas](https://pandas.pydata.org) objects.
# (See https://github.com/geopandas/geopandas)
#
# It provides (among other cool things) a `GeoDataFrame` object that represents a Feature collection.
# When you have one, you may be willing to use it on a folium map. Here's the simplest way to do so.
#
# In this example, we'll use the same file as GeoPandas demo ; it's containing the boroughs of New York City.

# %%
import geopandas

boros = geopandas.read_file(
    "https://raw.githubusercontent.com/python-visualization/folium-example-data/main/new_york_boroughs.zip"
)

boros
# Out:
#    BoroCode       BoroName     Shape_Leng    Shape_Area  \
# 0         5  Staten Island  330454.175933  1.623847e+09
# 1         3       Brooklyn  741227.337073  1.937810e+09
# 2         4         Queens  896875.396449  3.045079e+09
# 3         1      Manhattan  358400.912836  6.364308e+08
# 4         2          Bronx  464475.145651  1.186822e+09
#
#                                             geometry
# 0  MULTIPOLYGON (((970217.022 145643.332, 970227....
# 1  MULTIPOLYGON (((1021176.479 151374.797, 102100...
# 2  MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...

# %% [markdown]
# To create a map with these features, simply put them in a `GeoJson`:

# %%
m = folium.Map([40.7, -74], zoom_start=10, tiles="cartodbpositron")

folium.GeoJson(boros).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d04459b23696c26ccd16ac5264b8da56 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d04459b23696c26ccd16ac5264b8da56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d04459b23696c26ccd16ac5264b8da56 = L.map(
#                 &quot;map_d04459b23696c26ccd16ac5264b8da56&quot;,
#                 {
#                     center: [40.7, -74.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a193e4cd75473b9f22fc768dafc47bb2 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a193e4cd75473b9f22fc768dafc47bb2.addTo(map_d04459b23696c26ccd16ac5264b8da56);
#
#
#
#         function geo_json_9bf04450dc70df8fa13097b73315c602_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_9bf04450dc70df8fa13097b73315c602 = L.geoJson(null, {
#                 onEachFeature: geo_json_9bf04450dc70df8fa13097b73315c602_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_9bf04450dc70df8fa13097b73315c602_add (data) {
#             geo_json_9bf04450dc70df8fa13097b73315c602
#                 .addData(data);
#         }
#             geo_json_9bf04450dc70df8fa13097b73315c602_add({&quot;bbox&quot;: [-74.25559212524018, 40.496115120423646, -73.7000092406609, 40.91553239634786], &quot;features&quot;: [{&quot;bbox&quot;: [-74.25559212524018, 40.496115120423646, -74.0492365668585, 40.64892533901372], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-74.05050833038692, 40.566421876967354], [-74.05047163761672, 40.56641723074757], [-74.05030347887369, 40.56641730449825], [-74.05012613976346, 40.566405723130266], [-74.04998379151863, 40.566395767724394], [-74.04931667045423, 40.56588759118847], [-74.0492365668585, 40.5653625804611], [-74.05002647099916, 40.56531802482504], [-74.0507443681013, 40.565886969452016], [-74.05074795754949, 40.56595392018471], [-74.05073250752015, 40.565991962900846], [-74.05073597822012, 40.56603261792412], [-74.05080353681318, 40.56605204376972], [-74.05087359829297, 40.56608108348652], [-74.05090628487926, 40.566094185392956], [-74.05091319289849, 40.566133527969406], [-74.050882271248, 40.56617813315639], [-74.0508527688992, 40.56618939883865], [-74.0508341302955, 40.56619651670304], [-74.05076534091319, 40.566199169458585], [-74.0507085833654, 40.56619394867372], [-74.05068796339759, 40.56621756585
MULTIPOLYGON (((1029606.077 156073.814, 102957...
# 3  MULTIPOLYGON (((981219.056 188655.316, 980940....
# 4  MULTIPOLYGON (((1012821.806 229228.265, 101278...
#
#                                                style
# 0  {'fillColor': '#ff0000', 'weight': 2, 'color':...
# 1  {'fillColor': '#00ff00', 'weight': 2, 'color':...
# 2  {'fillColor': '#0000ff', 'weight': 2, 'color':...
# 3  {'fillColor': '#ffff00', 'weight': 2, 'color':...
# 4  {'fillColor': '#00ffff', 'weight': 2, 'color':...

# %%
m = folium.Map([40.7, -74], zoom_start=10, tiles="cartodbpositron")

folium.GeoJson(boros).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13a76fd77285dc924057088981d15206 {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13a76fd77285dc924057088981d15206&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13a76fd77285dc924057088981d15206 = L.map(
#                 &quot;map_13a76fd77285dc924057088981d15206&quot;,
#                 {
#                     center: [40.7, -74.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_033c08a4dfa48aa8728be238c4c8dd5a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_033c08a4dfa48aa8728be238c4c8dd5a.addTo(map_13a76fd77285dc924057088981d15206);
#
#
#
#         function geo_json_2f9c00e00d5e61433c695bfb9412f435_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_2f9c00e00d5e61433c695bfb9412f435 = L.geoJson(null, {
#                 onEachFeature: geo_json_2f9c00e00d5e61433c695bfb9412f435_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_2f9c00e00d5e61433c695bfb9412f435_add (data) {
#             geo_json_2f9c00e00d5e61433c695bfb9412f435
#                 .addData(data);
#         }
#             geo_json_2f9c00e00d5e61433c695bfb9412f435_add({&quot;bbox&quot;: [-74.25559212524018, 40.496115120423646, -73.7000092406609, 40.91553239634786], &quot;features&quot;: [{&quot;bbox&quot;: [-74.25559212524018, 40.496115120423646, -74.0492365668585, 40.64892533901372], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-74.05050833038692, 40.566421876967354], [-74.05047163761672, 40.56641723074757], [-74.05030347887369, 40.56641730449825], [-74.05012613976346, 40.566405723130266], [-74.04998379151863, 40.566395767724394], [-74.04931667045423, 40.56588759118847], [-74.0492365668585, 40.5653625804611], [-74.05002647099916, 40.56531802482504], [-74.0507443681013, 40.565886969452016], [-74.05074795754949, 40.56595392018471], [-74.05073250752015, 40.565991962900846], [-74.05073597822012, 40.56603261792412], [-74.05080353681318, 40.56605204376972], [-74.05087359829297, 40.56608108348652], [-74.05090628487926, 40.566094185392956], [-74.05091319289849, 40.566133527969406], [-74.050882271248, 40.56617813315639], [-74.0508527688992, 40.56618939883865], [-74.0508341302955, 40.56619651670304], [-74.05076534091319, 40.566199169458585], [-74.0507085833654, 40.56619394867372], [-74.05068796339759, 40.56621756585894], [-74.05068281908105, 40.56623724061192], [-74.05068284385143, 40.566270028966834], [-74.05067943437795, 40.566310688701066], [-74.05069666990961, 40.566360518434166], [-74.05073453165674, 40.56639460150687], [-74.05078443413514, 40.56643130275681], [-74.05083949685985, 40.56646931312237], [-74.05088422566462, 40.566487654383074], [-74.0509341306231, 40.566528290499015], [-74.0509702690562, 40.566558439325675], [-74.05099155939799, 40.56657660213488], [-74.05101329291581, 40.56659514302491], [-74.05103910823226, 40.56661873947719], [-74.0510563351286, 40.56665676603819], [-74.05107526972763, 40.56667905361655], [-74.051073568036, 40.56670266245811], [-74.05107186400622, 40.566722335865926], [-74.05104939764988, 40.56673796093723], [-74.05091691410581, 40.56669541765421], [-74.05085093103425, 40.566643230288065], [-74.05075916281113, 40.566584979492895], [-74.05066741433497, 40.56655004570214], [-74.05061540531044, 40.566508099479535], [-74.05053891933666, 40.5664405165817], [-74.05050833038692, 40.566421876967354]]], [[[-74.05314060054307, 40.57770254447042], [-74.05406068449096, 40.577116275140554], [-74.05489801579044, 40.5777822702305], [-74.05469339631574, 40.579691459146396], [-74.0548515735841, 40.57970742002389], [-74.05484582706612, 40.57994561808111], [-74.05368651504524, 40.58054858515683], [-74.05293213137546, 40.57990230077495], [-74.05314060054307, 40.57770254447042]]], [[[-74.15945607238793, 40.64144822609145], [-74.15974820695403, 40.641416418934604], [-74.1599788051255, 40.641446374308565], [-74.16014982767045, 40.64149457542746], [-74.16032490397322, 40.641576072185416], [-74.16046977676612, 40.641643516758464], [-74.16058346372536, 40.64166653799772], [-74.16069642883313, 40.64168941572269], [-74.16077837844456, 40.64173892934393], [-74.1608539328126, 40.641753961353025], [-74.16094543085485, 40.64178713432407], [-74.16102494949115, 40.641799136448384], [-74.16111247187393, 40.64183534896206], [-74.16114209237126, 40.641911545157704], [-74.1611790169537, 40.6420065077437

# %% [markdown]
# ## Use any object with `__geo_interface__`
#
# Folium should work with any object that implements the `__geo_interface__` but be aware that sometimes you may need to convert your data to `epsg='4326'` before sending it to `folium`.

# %%
import fiona
import shapely

url = "https://raw.githubusercontent.com/python-visualization/folium-example-data/main/route_farol.gpx"
with fiona.open(url, "r", layer="tracks") as records:
    tracks = [shapely.geometry.shape(record["geometry"]) for record in records]

track = tracks[0]

m = folium.Map(tiles="cartodbpositron")
folium.GeoJson(track).add_to(m)

m.fit_bounds(m.get_bounds())

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8d976af4a4bd6341f353171ca00dd60a {
#                     position: relative;
#                     width: 100.0vw;
#                     height: 100.0vh;
#
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8d976af4a4bd6341f353171ca00dd60a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8d976af4a4bd6341f353171ca00dd60a = L.map(
#                 &quot;map_8d976af4a4bd6341f353171ca00dd60a&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_131940c86b2dfb7d205279bd34bf4e45 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_131940c86b2dfb7d205279bd34bf4e45.addTo(map_8d976af4a4bd6341f353171ca00dd60a);
#
#
#
#         function geo_json_d0b085fc63911e06d441a99f6110ed43_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_d0b085fc63911e06d441a99f6110ed43 = L.geoJson(null, {
#                 onEachFeature: geo_json_d0b085fc63911e06d441a99f6110ed43_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_d0b085fc63911e06d441a99f6110ed43_add (data) {
#             geo_json_d0b085fc63911e06d441a99f6110ed43
#                 .addData(data);
#         }
#             geo_json_d0b085fc63911e06d441a99f6110ed43_add({&quot;coordinates&quot;: [[[-38.502595, -13.00539], [-38.502605, -13.005415], [-38.502575, -13.005506666666667], [-38.502545, -13.005595], [-38.502515, -13.00568], [-38.50248, -13.00575], [-38.502445, -13.005815], [-38.5024, -13.00588], [-38.502361666666665, -13.005956666666666], [-38.50231, -13.00603], [-38.50225666666667, -13.006105], [-38.502