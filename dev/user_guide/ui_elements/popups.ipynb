# %% [markdown]
# # Popups
#
# ## Simple popups
#
# You can define your popup at the feature creation, but you can also overwrite them afterwards:

# %%
import folium


m = folium.Map([45, 0], zoom_start=4)

folium.Marker([45, -30], popup="inline implicit popup").add_to(m)

folium.CircleMarker(
    location=[45, -10],
    radius=25,
    fill=True,
    popup=folium.Popup("inline explicit Popup"),
).add_to(m)

ls = folium.PolyLine(
    locations=[[43, 7], [43, 13], [47, 13], [47, 7], [43, 7]], color="red"
)

ls.add_child(folium.Popup("outline Popup on Polyline"))
ls.add_to(m)

gj = folium.GeoJson(
    data={"type": "Polygon", "coordinates": [[[27, 43], [33, 43], [33, 47], [27, 47]]]}
)

gj.add_child(folium.Popup("outline Popup on GeoJSON"))
gj.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3b4a2d775a8d0cf3b65fbdb26d73a8ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3b4a2d775a8d0cf3b65fbdb26d73a8ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3b4a2d775a8d0cf3b65fbdb26d73a8ac = L.map(
#                 &quot;map_3b4a2d775a8d0cf3b65fbdb26d73a8ac&quot;,
#                 {
#                     center: [45.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3896396fb029ac33a47e2bd5d429cabd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3896396fb029ac33a47e2bd5d429cabd.addTo(map_3b4a2d775a8d0cf3b65fbdb26d73a8ac);
#
#
#             var marker_1be5620ab2a33b7bcfce9cb22032bc5d = L.marker(
#                 [45.0, -30.0],
#                 {
# }
#             ).addTo(map_3b4a2d775a8d0cf3b65fbdb26d73a8ac);
#
#
#         var popup_c90691fdcc836c64d84a7e540ba0a876 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1a2048f0cc3c4ffbf08631a69258211a = $(`&lt;div id=&quot;html_1a2048f0cc3c4ffbf08631a69258211a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;inline implicit popup&lt;/div&gt;`)[0];
#                 popup_c90691fdcc836c64d84a7e540ba0a876.setContent(html_1a2048f0cc3c4ffbf08631a69258211a);
#
#
#
#         marker_1be5620ab2a33b7bcfce9cb22032bc5d.bindPopup(popup_c90691fdcc836c64d84a7e540ba0a876)
#         ;
#
#
#
#
#             var circle_marker_6530fea99dc621ad2e855a72d0a10eff = L.circleMarker(
#                 [45.0, -10.0],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3b4a2d775a8d0cf3b65fbdb26d73a8ac);
#
#
#         var popup_0936c541ae62572a38a8d410dd2557e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5aaa78014b01c7ebe74732e07482e41b = $(`&lt;div id=&quot;html_5aaa78014b01c7ebe74732e07482e41b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;inline explicit Popup&lt;/div&gt;`)[0];
#                 popup_0936c541ae62572a38a8d410dd2557e4.setContent(html_5aaa78014b01c7ebe74732e07482e41b);
#
#
#
#         circle_marker_6530fea99dc621ad2e855a72d0a10eff.bindPopup(popup_0936c541ae62572a38a8d410dd2557e4)
#         ;
#
#
#
#
#             var poly_line_918da9e18f5f93f4aebb4fcce4153638 = L.polyline(
#                 [[43.0, 7.0], [43.0, 13.0], [47.0, 13.0], [47.0, 7.0], [43.0, 7.0]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3b4a2d775a8d0cf3b65fbdb26d73a8ac);
#
#
#         var popup_291f0229e54a090cf6efed6f0df1bd01 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39178ca3e257698a42c2cbedde5a521b = $(`&lt;div id=&quot;html_39178ca3e257698a42c2cbedde5a521b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;outline Popup on Polyline&lt;/div&gt;`)[0];
#                 popup_291f0229e54a090cf6efed6f0df1bd01.setContent(html_39178ca3e257698a42c2cbedde5a521b);
#
#
#
#         poly_line_918da9e18f5f93f4aebb4fcce4153638.bindPopup(popup_291f0229e54a090cf6efed6f0df1bd01)
#         ;
#
#
#
#
#
#         function geo_json_399e1cae8f7ac4023ee4ca2f16d7ba87_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_399e1cae8f7ac4023ee4ca2f16d7ba87 = L.geoJson(null, {
#                 onEachFeature: geo_json_399e1cae8f7ac4023ee4ca2f16d7ba87_onEachFeature,
#
#             ...{
# }
#         });
#
#         function geo_json_399e1cae8f7ac4023ee4ca2f16d7ba87_add (data) {
#             geo_json_399e1cae8f7ac4023ee4ca2f16d7ba8

# %%
m = folium.Map([45, 0], zoom_start=2)

folium.Marker(
    location=[45, -10],
    popup=folium.Popup("Let's try quotes", parse_html=True, max_width=100),
).add_to(m)

folium.Marker(
    location=[45, -30],
    popup=folium.Popup(u"Ça c'est chouette", parse_html=True, max_width="100%"),
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_94726d20a49ddfba888a4d05a3045e81 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_94726d20a49ddfba888a4d05a3045e81&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_94726d20a49ddfba888a4d05a3045e81 = L.map(
#                 &quot;map_94726d20a49ddfba888a4d05a3045e81&quot;,
#                 {
#                     center: [45.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_30fe8fa842bfc9bd28d75cc45c63493e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_30fe8fa842bfc9bd28d75cc45c63493e.addTo(map_94726d20a49ddfba888a4d05a3045e81);
#
#
#             var marker_51d9c7906d04d1f5b3ae1c0876ef6b49 = L.marker(
#                 [45.0, -10.0],
#                 {
# }
#             ).addTo(map_94726d20a49ddfba888a4d05a3045e81);
#
#
#         var popup_b137b4450c4ab489c529fff133067e37 = L.popup({
#   &quot;maxWidth&quot;: 100,
# });
#
#
#
#                 var html_d9538e75b42024b8ffa603edd2de5a5e = $(`&lt;div id=&quot;html_d9538e75b42024b8ffa603edd2de5a5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Let&amp;#39;s try quotes&lt;/div&gt;`)[0];
#                 popup_b137b4450c4ab489c529fff133067e37.setContent(html_d9538e75b42024b8ffa603edd2de5a5e);
#
#
#
#         marker_51d9c7906d04d1f5b3ae1c0876ef6b49.bindPopup(popup_b137b4450c4ab489c529fff133067e37)
#         ;
#
#
#
#
#             var marker_7539599822ab65b32d9fa093c8e1baa6 = L.marker(
#                 [45.0, -30.0],
#                 {
# }
#             ).addTo(map_94726d20a49ddfba888a4d05a3045e81);
#
#
#         var popup_857ec01206ca8e11365d08b74a76084e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ab1c91557a9f857461d5c2398269e726 = $(`&lt;div id=&quot;html_ab1c91557a9f857461d5c2398269e726&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Ça c&amp;#39;est chouette&lt;/div&gt;`)[0];
#                 popup_857ec01206ca8e11365d08b74a76084e.setContent(html_ab1c91557a9f857461d5c2398269e726);
#
#
#
#         marker_7539599822ab65b32d9fa093c8e1baa6.bindPopup(popup_857ec01206ca8e11365d08b74a76084e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## HTML in popup

# %%
import branca

m = folium.Map([43, -100], zoom_start=4)

html = """
    <h1> This is a big popup</h1><br>
    With a few lines of code...
    <p>
    <code>
        from numpy import *<br>
        exp(-2*pi)
    </code>
    </p>
    """


folium.Marker([30, -100], popup=html).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_625350eec6c078ee2a9e45726e765276 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_625350eec6c078ee2a9e45726e765276&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_625350eec6c078ee2a9e45726e765276 = L.map(
#                 &quot;map_625350eec6c078ee2a9e45726e765276&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_514a589bb32e35498463cdceaca4c2d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_514a589bb32e35498463cdceaca4c2d8.addTo(map_625350eec6c078ee2a9e45726e765276);
#
#
#             var marker_17c7a92e58858ee3ed0c616079ac2bff = L.marker(
#                 [30.0, -100.0],
#                 {
# }
#             ).addTo(map_625350eec6c078ee2a9e45726e765276);
#
#
#         var popup_0757d5fbbfbd843b52f570432f20447b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6a093d508615a61b2f0a1e19aa8b0629 = $(`&lt;div id=&quot;html_6a093d508615a61b2f0a1e19aa8b0629&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;     &lt;h1&gt; This is a big popup&lt;/h1&gt;&lt;br&gt;     With a few lines of code...     &lt;p&gt;     &lt;code&gt;         from numpy import *&lt;br&gt;         exp(-2*pi)     &lt;/code&gt;     &lt;/p&gt;     &lt;/div&gt;`)[0];
#                 popup_0757d5fbbfbd843b52f570432f20447b.setContent(html_6a093d508615a61b2f0a1e19aa8b0629);
#
#
#
#         marker_17c7a92e58858ee3ed0c616079ac2bff.bindPopup(popup_0757d5fbbfbd843b52f570432f20447b)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Iframe in popup
#
# You can also put any HTML code inside a Popup, thaks to the `IFrame` object.

# %%
m = folium.Map([43, -100], zoom_start=4)

html = """
    <h1> This popup is an Iframe</h1><br>
    With a few lines of code...
    <p>
    <code>
        from numpy import *<br>
        exp(-2*pi)
    </code>
    </p>
    """

iframe = branca.element.IFrame(html=html, width=500, height=300)
popup = folium.Popup(iframe, max_width=500)

folium.Marker([30, -100], popup=popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cbb573001597ac024f8dc80e79bda36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cbb573001597ac024f8dc80e79bda36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cbb573001597ac024f8dc80e79bda36 = L.map(
#                 &quot;map_4cbb573001597ac024f8dc80e79bda36&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3a1b04d4460fdcd6fff1fab5c241bdd7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3a1b04d4460fdcd6fff1fab5c241bdd7.addTo(map_4cbb573001597ac024f8dc80e79bda36);
#
#
#             var marker_186d04427964f8da71eb18b2269ed503 = L.marker(
#                 [30.0, -100.0],
#                 {
# }
#             ).addTo(map_4cbb573001597ac024f8dc80e79bda36);
#
#
#         var popup_0599957f743928d45c2f9d9d68dc00ce = L.popup({
#   &quot;maxWidth&quot;: 500,
# });
#
#
#
#                 var i_frame_56aa0bbf1db58be72d8565ee6eece324 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICAKICAgIDxoMT4gVGhpcyBwb3B1cCBpcyBhbiBJZnJhbWU8L2gxPjxicj4KICAgIFdpdGggYSBmZXcgbGluZXMgb2YgY29kZS4uLgogICAgPHA+CiAgICA8Y29kZT4KICAgICAgICBmcm9tIG51bXB5IGltcG9ydCAqPGJyPgogICAgICAgIGV4cCgtMipwaSkKICAgIDwvY29kZT4KICAgIDwvcD4KICAgIA==&quot; width=&quot;500&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_0599957f743928d45c2f9d9d68dc00ce.setContent(i_frame_56aa0bbf1db58be72d8565ee6eece324);
#
#
#
#         marker_186d04427964f8da71eb18b2269ed503.bindPopup(popup_0599957f743928d45c2f9d9d68dc00ce)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd

df = pd.DataFrame(
    data=[["apple", "oranges"], ["other", "stuff"]], columns=["cats", "dogs"]
)

m = folium.Map([43, -100], zoom_start=4)

html = df.to_html(
    classes="table table-striped table-hover table-condensed table-responsive"
)

popup = folium.Popup(html)

folium.Marker([30, -100], popup=popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cb5397a770a076e2848994b326bfcc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cb5397a770a076e2848994b326bfcc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cb5397a770a076e2848994b326bfcc9 = L.map(
#                 &quot;map_3cb5397a770a076e2848994b326bfcc9&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fe680cb1b06502fd3194ec79694c6784 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fe680cb1b06502fd3194ec79694c6784.addTo(map_3cb5397a770a076e2848994b326bfcc9);
#
#
#             var marker_c41cc00754f9c28be8ac51f78f7ca0c6 = L.marker(
#                 [30.0, -100.0],
#                 {
# }
#             ).addTo(map_3cb5397a770a076e2848994b326bfcc9);
#
#
#         var popup_d4f6469c60106b342e1d8b4460a3c632 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_08e223f2186f4f84becb464ddcc523f0 = $(`&lt;div id=&quot;html_08e223f2186f4f84becb464ddcc523f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;table border=&quot;1&quot; class=&quot;dataframe table table-striped table-hover table-condensed table-responsive&quot;&gt;   &lt;thead&gt;     &lt;tr style=&quot;text-align: right;&quot;&gt;       &lt;th&gt;&lt;/th&gt;       &lt;th&gt;cats&lt;/th&gt;       &lt;th&gt;dogs&lt;/th&gt;     &lt;/tr&gt;   &lt;/thead&gt;   &lt;tbody&gt;     &lt;tr&gt;       &lt;th&gt;0&lt;/th&gt;       &lt;td&gt;apple&lt;/td&gt;       &lt;td&gt;oranges&lt;/td&gt;     &lt;/tr&gt;     &lt;tr&gt;       &lt;th&gt;1&lt;/th&gt;       &lt;td&gt;other&lt;/td&gt;       &lt;td&gt;stuff&lt;/td&gt;     &lt;/tr&gt;   &lt;/tbody&gt; &lt;/table&gt;&lt;/div&gt;`)[0];
#                 popup_d4f6469c60106b342e1d8b4460a3c632.setContent(html_08e223f2186f4f84becb464ddcc523f0);
#
#
#
#         marker_c41cc00754f9c28be8ac51f78f7ca0c6.bindPopup(popup_d4f6469c60106b342e1d8b4460a3c632)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Note that you can put another `Figure` into an `IFrame` ; this should let you do strange things...

# %%
# Let's create a Figure, with a map inside.
f = branca.element.Figure()
folium.Map([-25, 150], zoom_start=3).add_to(f)

# Let's put the figure into an IFrame.
iframe = branca.element.IFrame(width=500, height=300)
f.add_to(iframe)

# Let's put the IFrame in a Popup
popup = folium.Popup(iframe, max_width=2650)

# Let's create another map.
m = folium.Map([43, -100], zoom_start=4)

# Let's put the Popup on a marker, in the second map.
folium.Marker([30, -100], popup=popup).add_to(m)

# We get a map in a Popup. Not really useful, but powerful.
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9834f5dc097b414176cb64f51c433a36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9834f5dc097b414176cb64f51c433a36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9834f5dc097b414176cb64f51c433a36 = L.map(
#                 &quot;map_9834f5dc097b414176cb64f51c433a36&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3d744e44abab0c0e0b5b1bd20fa7690 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3d744e44abab0c0e0b5b1bd20fa7690.addTo(map_9834f5dc097b414176cb64f51c433a36);
#
#
#             var marker_fab6aa277c90be0d0950bd2605470e94 = L.marker(
#                 [30.0, -100.0],
#                 {
# }
#             ).addTo(map_9834f5dc097b414176cb64f51c433a36);
#
#
#         var popup_8fdee2ed9d5849d9870eeb7b03ad683f = L.popup({
#   &quot;maxWidth&quot;: 2650,
# });
#
#
#
#                 var i_frame_8b647655ea8db2848c092b72ae6c4775 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,...&quot; width=&quot;500&quot; style=&quot;border:none !important;&quot; height=&quot;300&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_8fdee2ed9d5849d9870eeb7b03ad683f.setContent(i_frame_8b647655ea8db2848c092b72ae6c4775);
#
#
#
#         marker_fab6aa277c90be0d0950bd2605470e94.bindPopup(popup_8fdee2ed9d5849d9870eeb7b03ad683f)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Vega chart in popup
#
# [Vega](https://vega.github.io/vega/) is a way to describe charts. You can embed
# a Vega chart in a popup using the `Vega` class.

# %%
import json

import numpy as np
import vincent

multi_iter2 = {
    "x": np.random.uniform(size=(100,)),
    "y": np.random.uniform(size=(100,)),
}
scatter = vincent.Scatter(multi_iter2, iter_idx="x", height=100, width=200)
data = json.loads(scatter.to_json())

m = folium.Map([0, 0], zoom_start=1)
marker = folium.Marker([0, 0]).add_to(m)
popup = folium.Popup("Hello").add_to(marker)
folium.Vega(data, width="100%", height="100%").add_to(popup)

m
# Out:
# /home/runner/micromamba/envs/TEST/lib/python3.14/site-packages/vincent/core.py:10: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   from pkg_resources import resource_string
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5996627b7a019ea5fd653d12869adf6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/vega/1.4.3/vega.min.js&quot;&gt;&lt;/script&gt;
#
#             &lt;style&gt; #vega_462730c1a1332cbb13ff4662b6cae1b1 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5996627b7a019ea5fd653d12869adf6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5996627b7a019ea5fd653d12869adf6c = L.map(
#                 &quot;map_5996627b7a019ea5fd653d12869adf6c&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df58165b26203dfd77f042ec6140edce = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df58165b26203dfd77f042ec6140edce.addTo(map_5996627b7a019ea5fd653d12869adf6c);
#
#
#             var marker_3bd4ddeff29226488cdf3062dc40d29b = L.marker(
#                 [0.0, 0.0],
#                 {
# }
#             ).addTo(map_5996627b7a019ea5fd653d12869adf6c);
#
#     function vega_parse(spec, div) {
#             vg.parse.spec(spec, function(chart) { chart({el:div}).update(); });}
#
#         var popup_997d8ef7cf4910961b5f85708ae475e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48a485b1370b353dc3bac09c9f64c53d = $(`&lt;div id=&quot;html_48a485b1370b353dc3bac09c9f64c53d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Hello&lt;/div&gt;`)[0];
#                 popup_997d8ef7cf4910961b5f85708ae475e1.setContent(html_48a485b1370b353dc3bac09c9f64c53d);
#
#
#
#                 var vega_462730c1a1332cbb13ff4662b6cae1b1 = $(`             &lt;div id=&quot;vega_462730c1a1332cbb13ff4662b6cae1b1&quot;&gt;&lt;/div&gt;             `)[0];
#                 popup_997d8ef7cf4910961b5f85708ae475e1.setContent(vega_462730c1a1332cbb13ff4662b6cae1b1);
#
#
#
#         marker_3bd4ddeff29226488cdf3062dc40d29b.bindPopup(popup_997d8ef7cf4910961b5f85708ae475e1)
#         ;
#
#
#
#             vega_parse({&quot;axes&quot;: [{&quot;scale&quot;: &quot;x&quot;, &quot;type&quot;: &quot;x&quot;}, {&quot;scale&quot;: &quot;y&quot;, &quot;type&quot;: &quot;y&quot;}], &quot;data&quot;: [{&quot;name&quot;: &quot;table&quot;, &quot;values&quot;: [{&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.533183425015296, &quot;val&quot;: 0.03029431218019485}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.11163568519085842, &quot;val&quot;: 0.6180792480391424}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.44414748288757044, &quot;val&quot;: 0.7154737912670396}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.12060344007598067, &quot;val&quot;: 0.4954174991857996}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.04819038993159852, &quot;val&quot;: 0.2239055133665897}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.5131835564628435, &quot;val&quot;: 0.47349536265433056}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.12245522872248849, &quot;val&quot;: 0.5630614753853986}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.508651006729059, &quot;val&quot;: 0.14839172367398423}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.6764067421827805, &quot;val&quot;: 0.08218772855567469}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.12884754167571566, &quot;val&quot;: 0.7893184726379411}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.36384856422424106, &quot;val&quot;: 0.698086344281274}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.21222841836337547, &quot;val&quot;: 0.20776020826162478}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.3019952684415562, &quot;val&quot;: 0.5473682015312147}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.825952258254243, &quot;val&quot;: 0.4966193686980678}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.7223995612557247, &quot;val&quot;: 0.25112493910149136}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.26293425802921955, &quot;val&quot;: 0.9109360810637798}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.1789348586931867, &quot;val&quot;: 0.01622768521242446}, {&quot;col&quot;: &quot;y&quot;, &quot;idx&quot;: 0.019195381180314164, &quot;val&q

# %% [markdown]
# ## Vega-Lite chart in popup
#
# [Vega-lite](https://vega.github.io/vega-lite/) is a higher-level version of Vega.
# Folium supports it as well in the `VegaLite` class.

# %%
from altair import Chart

import vega_datasets

# load built-in dataset as a pandas DataFrame
cars = vega_datasets.data.cars()

scatter = (
    Chart(cars)
    .mark_circle()
    .encode(
        x="Horsepower",
        y="Miles_per_Gallon",
        color="Origin",
    )
)

vega_lite = folium.VegaLite(
    scatter,
    width="100%",
    height="100%",
)

m = folium.Map(location=[-27.5717, -48.6256])

marker = folium.Marker([-27.57, -48.62])

popup = folium.Popup()

vega_lite.add_to(popup)
popup.add_to(marker)

marker.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4e75aa04e84a15dd5e371fc4820bc41e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#             &lt;style&gt; #vega_lite_9085739174f0e30dbfee4f16a43a8b91 {
#                 position : relative;
#                 width : 100.0%;
#                 height: 100.0%;
#                 left: 0.0%;
#                 top: 0.0%;
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega@3&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-lite@2&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/vega-embed@3&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4e75aa04e84a15dd5e371fc4820bc41e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4e75aa04e84a15dd5e371fc4820bc41e = L.map(
#                 &quot;map_4e75aa04e84a15dd5e371fc4820bc41e&quot;,
#                 {
#                     center: [-27.5717, -48.6256],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c587a02b3d48739c3929a58c0684cf23 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c587a02b3d48739c3929a58c0684cf23.addTo(map_4e75aa04e84a15dd5e371fc4820bc41e);
#
#
#             var marker_226016cb599318b77fa60c8082a00381 = L.marker(
#                 [-27.57, -48.62],
#                 {
# }
#             ).addTo(map_4e75aa04e84a15dd5e371fc4820bc41e);
#
#
#         var popup_6fc8c25c7dc16dfd872c5627bbea538e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var vega_lite_9085739174f0e30dbfee4f16a43a8b91 = $(`             &lt;div id=&quot;vega_lite_9085739174f0e30dbfee4f16a43a8b91&quot;&gt;&lt;/div&gt;             `)[0];
#                 popup_6fc8c25c7dc16dfd872c5627bbea538e.setContent(vega_lite_9085739174f0e30dbfee4f16a43a8b91);
#
#
#
#         marker_226016cb599318b77fa60c8082a00381.bindPopup(popup_6fc8c25c7dc16dfd872c5627bbea538e)
#         ;
#
#
#
#                     vegaEmbed(vega_lite_9085739174f0e30dbfee4f16a43a8b91, {&quot;$schema&quot;: &quot;https://vega.github.io/schema/vega-lite/v6.1.0.json&quot;, &quot;config&quot;: {&quot;view&quot;: {&quot;continuousHeight&quot;: 300, &quot;continuousWidth&quot;: 300}}, &quot;data&quot;: {&quot;name&quot;: &quot;data-583e73726c1545c56c203344161a975c&quot;}, &quot;datasets&quot;: {&quot;data-583e73726c1545c56c203344161a975c&quot;: [{&quot;Acceleration&quot;: 12.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 307.0, &quot;Horsepower&quot;: 130.0, &quot;Miles_per_Gallon&quot;: 18.0, &quot;Name&quot;: &quot;chevrolet chevelle malibu&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3504, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 11.5, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 350.0, &quot;Horsepower&quot;: 165.0, &quot;Miles_per_Gallon&quot;: 15.0, &quot;Name&quot;: &quot;buick skylark 320&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3693, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 11.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 318.0, &quot;Horsepower&quot;: 150.0, &quot;Miles_per_Gallon&quot;: 18.0, &quot;Name&quot;: &quot;plymouth satellite&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3436, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 12.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 304.0, &quot;Horsepower&quot;: 150.0, &quot;Miles_per_Gallon&quot;: 16.0, &quot;Name&quot;: &quot;amc rebel sst&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3433, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 10.5, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 302.0, &quot;Horsepower&quot;: 140.0, &quot;Miles_per_Gallon&quot;: 17.0, &quot;Name&quot;: &quot;ford torino&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 3449, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 10.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 429.0, &quot;Horsepower&quot;: 198.0, &quot;Miles_per_Gallon&quot;: 15.0, &quot;Name&quot;: &quot;ford galaxie 500&quot;, &quot;Origin&quot;: &quot;USA&quot;, &quot;Weight_in_lbs&quot;: 4341, &quot;Year&quot;: &quot;1970-01-01T00:00:00&quot;}, {&quot;Acceleration&quot;: 9.0, &quot;Cylinders&quot;: 8, &quot;Displacement&quot;: 454.0, &quot;Horsepower&quot;: 220.0, &quot;Miles_per_Gallon&quot;

# %% [markdown]
# ## Lazy loading
#
# If whatever you are showing in the popup is slow or heavy to load and you have many popups, you may not want to render the popup contents immediately. There's an argument to prevent loading until the popup is opened.

# %%
m = folium.Map([43, -100], zoom_start=4)

html = "{a resource that is heavy to load, such as an image}"

folium.Marker([30, -100], popup=html, lazy=True).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_74a6608636f11c987816025f9a7b12ac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_74a6608636f11c987816025f9a7b12ac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_74a6608636f11c987816025f9a7b12ac = L.map(
#                 &quot;map_74a6608636f11c987816025f9a7b12ac&quot;,
#                 {
#                     center: [43.0, -100.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 4,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba654450b4a567f4579afed75fb720e6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba654450b4a567f4579afed75fb720e6.addTo(map_74a6608636f11c987816025f9a7b12ac);
#
#
#             var marker_470f94bc0ea41ade5813bc1cdb68710e = L.marker(
#                 [30.0, -100.0],
#                 {
#   &quot;lazy&quot;: true,
# }
#             ).addTo(map_74a6608636f11c987816025f9a7b12ac);
#
#
#         var popup_b3b27cd54feba17c7423972d5688ef8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8508e028437b7385e65fd51d5ce5e29f = $(`&lt;div id=&quot;html_8508e028437b7385e65fd51d5ce5e29f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;{a resource that is heavy to load, such as an image}&lt;/div&gt;`)[0];
#                 popup_b3b27cd54feba17c7423972d5688ef8e.setContent(html_8508e028437b7385e65fd51d5ce5e29f);
#
#
#
#         marker_470f94bc0ea41ade5813bc1cdb68710e.bindPopup(popup_b3b27cd54feba17c7423972d5688ef8e)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
