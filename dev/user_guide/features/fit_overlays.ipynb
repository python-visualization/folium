# %%
import folium

# %% [markdown]
# ## FitOverlays
#
# When you add this class to your map, the map will pan and zoom to fit the enabled overlays.
#
# By default, the map won't necessarily show all elements that were added. You may have to pan or zoom out to find them.
#
# If we add the `FitOverlays` class, it will automatically pan and zoom to show the enabled overlays.
# In this example we show only the first marker by default. If you enable the second marker, the view changes to include it.

# %%
m = folium.Map((52, 0), tiles='cartodbpositron', zoom_start=8)

fg1 = folium.FeatureGroup().add_to(m)
folium.Marker((52, 5)).add_to(fg1)

fg2 = folium.FeatureGroup(show=False).add_to(m)
folium.Marker((52, 5.1)).add_to(fg2)

folium.FitOverlays().add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cdad515d8ddab46dda6f66a9885d863 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cdad515d8ddab46dda6f66a9885d863&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cdad515d8ddab46dda6f66a9885d863 = L.map(
#                 &quot;map_0cdad515d8ddab46dda6f66a9885d863&quot;,
#                 {
#                     center: [52.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;maxBounds&quot;: null,
#   &quot;zoom&quot;: 8,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_724b51eaf88213e68545dcb999e67bea = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_724b51eaf88213e68545dcb999e67bea.addTo(map_0cdad515d8ddab46dda6f66a9885d863);
#
#
#             var feature_group_dbc865fccf948ca23be605f7dba0d8da = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c42524b9350c581f86a325c370630ef2 = L.marker(
#                 [52.0, 5.0],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_dbc865fccf948ca23be605f7dba0d8da);
#
#
#             feature_group_dbc865fccf948ca23be605f7dba0d8da.addTo(map_0cdad515d8ddab46dda6f66a9885d863);
#
#
#             var feature_group_a4b54ea25ff3556c3e903c13a5e179ff = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5553b9c0b5b6f810af204eeb7b3c67c5 = L.marker(
#                 [52.0, 5.1],
#                 {
#   &quot;draggable&quot;: null,
#   &quot;autoPan&quot;: null,
# }
#             ).addTo(feature_group_a4b54ea25ff3556c3e903c13a5e179ff);
#
#
#         function customFlyToBounds() {
#             let bounds = L.latLngBounds([]);
#             map_0cdad515d8ddab46dda6f66a9885d863.eachLayer(function(layer) {
#                 if (typeof layer.getBounds === &#x27;function&#x27;) {
#                     bounds.extend(layer.getBounds());
#                 }
#             });
#             if (bounds.isValid()) {
#                 map_0cdad515d8ddab46dda6f66a9885d863.fitBounds(bounds, {
#   &quot;padding&quot;: [0, 0],
#   &quot;maxZoom&quot;: null,
# });
#             }
#         }
#         map_0cdad515d8ddab46dda6f66a9885d863.on(&#x27;overlayadd&#x27;, customFlyToBounds);
#         customFlyToBounds();
#
#
#             var layer_control_ec06af30fafaa972d13a145fc6352ba1_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_724b51eaf88213e68545dcb999e67bea,
#                 },
#                 overlays :  {
#                     &quot;macro_element_dbc865fccf948ca23be605f7dba0d8da&quot; : feature_group_dbc865fccf948ca23be605f7dba0d8da,
#                     &quot;macro_element_a4b54ea25ff3556c3e903c13a5e179ff&quot; : feature_group_a4b54ea25ff3556c3e903c13a5e179ff,
#                 },
#             };
#             let layer_control_ec06af30fafaa972d13a145fc6352ba1 = L.control.layers(
#                 layer_control_ec06af30fafaa972d13a145fc6352ba1_layers.base_layers,
#                 layer_control_ec06af30fafaa972d13a145fc6352ba1_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_0cdad515d8ddab46dda6f66a9885d863);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# `FitOverlays` has a couple options:
#
# - `padding` adds pixels around the bounds.
# - `max_zoom` can be used to prevent zooming in too far.
# - `fly` enables a smoother, longer animation, so you can see how the view changes.
# - `fit_on_map_load` can be used to disable the fitting that happens when the map loads.
#
# Note that `padding` and `max_zoom` can achieve the same effect.
