# %%
import folium
import folium.plugins

# %% [markdown]
# ## FeatureGroupSubGroup
#
# ### Sub categories
#
# Disable all markers in the category, or just one of the subgroup.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

fg = folium.FeatureGroup(name="groups")
m.add_child(fg)

g1 = folium.plugins.FeatureGroupSubGroup(fg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(fg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_319f7a714f4d22bb7dbb4f8c6afdebae {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_319f7a714f4d22bb7dbb4f8c6afdebae&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_319f7a714f4d22bb7dbb4f8c6afdebae = L.map(
#                 &quot;map_319f7a714f4d22bb7dbb4f8c6afdebae&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8c494e86893468ef1662435ab4bc2c7b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8c494e86893468ef1662435ab4bc2c7b.addTo(map_319f7a714f4d22bb7dbb4f8c6afdebae);
#
#
#             var feature_group_c214e458fa0605fc2aa764a106ca1603 = L.featureGroup(
#                 {}
#             );
#
#
#             feature_group_c214e458fa0605fc2aa764a106ca1603.addTo(map_319f7a714f4d22bb7dbb4f8c6afdebae);
#
#
#             var feature_group_sub_group_3d6ec92c6680db9874ea8c8c68e9d90f = L.featureGroup.subGroup(
#                 feature_group_c214e458fa0605fc2aa764a106ca1603
#             );
#
#
#             var marker_c7defcfdd09a25e4d9456242a3f7ac28 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_3d6ec92c6680db9874ea8c8c68e9d90f);
#
#
#             var marker_eecfe020211f054fd0cfc29a5ce9df2b = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_3d6ec92c6680db9874ea8c8c68e9d90f);
#
#
#             feature_group_sub_group_3d6ec92c6680db9874ea8c8c68e9d90f.addTo(map_319f7a714f4d22bb7dbb4f8c6afdebae);
#
#
#             var feature_group_sub_group_7fd40bc39a5a898497c58e8e84722483 = L.featureGroup.subGroup(
#                 feature_group_c214e458fa0605fc2aa764a106ca1603
#             );
#
#
#             var marker_c6ee0d6f95dfe4a5ca09210e750df400 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_7fd40bc39a5a898497c58e8e84722483);
#
#
#             var marker_42aee06d75d44179485432a16c4d3d64 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_7fd40bc39a5a898497c58e8e84722483);
#
#
#             feature_group_sub_group_7fd40bc39a5a898497c58e8e84722483.addTo(map_319f7a714f4d22bb7dbb4f8c6afdebae);
#
#
#             var layer_control_273ac409867a6ca873c8d0e1434155b5_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_8c494e86893468ef1662435ab4bc2c7b,
#                 },
#                 overlays :  {
#                     &quot;groups&quot; : feature_group_c214e458fa0605fc2aa764a106ca1603,
#                     &quot;group1&quot; : feature_group_sub_group_3d6ec92c6680db9874ea8c8c68e9d90f,
#                     &quot;group2&quot; : feature_group_sub_group_7fd40bc39a5a898497c58e8e84722483,
#                 },
#             };
#             let layer_control_273ac409867a6ca873c8d0e1434155b5 = L.control.layers(
#                 layer_control_273ac409867a6ca873c8d0e1434155b5_layers.base_layers,
#                 layer_control_273ac409867a6ca873c8d0e1434155b5_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_319f7a714f4d22bb7dbb4f8c6afdebae);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Marker clusters across groups
#
# Create two subgroups, but cluster markers together.

# %%
m = folium.Map(location=[0, 0], zoom_start=6)

mcg = folium.plugins.MarkerCluster(control=False)
m.add_child(mcg)

g1 = folium.plugins.FeatureGroupSubGroup(mcg, "group1")
m.add_child(g1)

g2 = folium.plugins.FeatureGroupSubGroup(mcg, "group2")
m.add_child(g2)

folium.Marker([-1, -1]).add_to(g1)
folium.Marker([1, 1]).add_to(g1)

folium.Marker([-1, 1]).add_to(g2)
folium.Marker([1, -1]).add_to(g2)

folium.LayerControl(collapsed=False).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_54dbaf771d2c17b449d0bff41e5c519e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_54dbaf771d2c17b449d0bff41e5c519e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_54dbaf771d2c17b449d0bff41e5c519e = L.map(
#                 &quot;map_54dbaf771d2c17b449d0bff41e5c519e&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5661a760ff2cffa85c0901014245899 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a5661a760ff2cffa85c0901014245899.addTo(map_54dbaf771d2c17b449d0bff41e5c519e);
#
#
#             var marker_cluster_938cba6ade1ebf39d644f4f11b1d4ec3 = L.markerClusterGroup(
#                 {}
#             );
#
#
#             marker_cluster_938cba6ade1ebf39d644f4f11b1d4ec3.addTo(map_54dbaf771d2c17b449d0bff41e5c519e);
#
#
#             var feature_group_sub_group_8ebc3e094fb09eb4eabe6c773b0a4b72 = L.featureGroup.subGroup(
#                 marker_cluster_938cba6ade1ebf39d644f4f11b1d4ec3
#             );
#
#
#             var marker_39206ebaa6ea567ccae0b827c65c92e5 = L.marker(
#                 [-1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_8ebc3e094fb09eb4eabe6c773b0a4b72);
#
#
#             var marker_96b5c3dd9649f25f1766d82e43ae7915 = L.marker(
#                 [1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_8ebc3e094fb09eb4eabe6c773b0a4b72);
#
#
#             feature_group_sub_group_8ebc3e094fb09eb4eabe6c773b0a4b72.addTo(map_54dbaf771d2c17b449d0bff41e5c519e);
#
#
#             var feature_group_sub_group_020fcf59d47396a9e22d0fe0d54f686c = L.featureGroup.subGroup(
#                 marker_cluster_938cba6ade1ebf39d644f4f11b1d4ec3
#             );
#
#
#             var marker_5c504e5b124cabe77edfbf6076b4ab17 = L.marker(
#                 [-1.0, 1.0],
#                 {}
#             ).addTo(feature_group_sub_group_020fcf59d47396a9e22d0fe0d54f686c);
#
#
#             var marker_10cd367055d2e6da7dfd240702b748f8 = L.marker(
#                 [1.0, -1.0],
#                 {}
#             ).addTo(feature_group_sub_group_020fcf59d47396a9e22d0fe0d54f686c);
#
#
#             feature_group_sub_group_020fcf59d47396a9e22d0fe0d54f686c.addTo(map_54dbaf771d2c17b449d0bff41e5c519e);
#
#
#             var layer_control_d489c007a01d1192b36e7241a3abcab4_layers = {
#                 base_layers : {
#                     &quot;openstreetmap&quot; : tile_layer_a5661a760ff2cffa85c0901014245899,
#                 },
#                 overlays :  {
#                     &quot;group1&quot; : feature_group_sub_group_8ebc3e094fb09eb4eabe6c773b0a4b72,
#                     &quot;group2&quot; : feature_group_sub_group_020fcf59d47396a9e22d0fe0d54f686c,
#                 },
#             };
#             let layer_control_d489c007a01d1192b36e7241a3abcab4 = L.control.layers(
#                 layer_control_d489c007a01d1192b36e7241a3abcab4_layers.base_layers,
#                 layer_control_d489c007a01d1192b36e7241a3abcab4_layers.overlays,
#                 {&quot;autoZIndex&quot;: true, &quot;collapsed&quot;: false, &quot;position&quot;: &quot;topright&quot;}
#             ).addTo(map_54dbaf771d2c17b449d0bff41e5c519e);
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
